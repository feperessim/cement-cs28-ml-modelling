# %%
# %load_ext nb_black

# %%
import pandas as pd
import numpy as np

# %%
def flat_list(lst):
    return [item for tup in list(lst) for item in tup]

# %%
def extract_and_fill_lists(text, train_rmse_mean, train_rmse_std, test_rmse_mean, test_rmse_std,
                           train_mae_mean, train_mae_std, test_mae_mean, test_mae_std,
                           train_mape_mean, train_mape_std, test_mape_mean, test_mape_std,
                           train_r2_mean, train_r2_std, test_r2_mean, test_r2_std):

    train_flag = False
    test_flag = False
    timesteps_flag = False

    for line in text.split("\n"):
        line = line.strip()

        if line.startswith("TIMESTEPS:"):
            timesteps_flag = True

        elif line.startswith("[TRAIN]"):
            train_flag = True
            test_flag = False

        elif line.startswith("[TEST]"):
            train_flag = False
            test_flag = True

        elif line.startswith("RMSE:"):
            parts = line.split(" ")
            if train_flag:
                train_rmse_mean.append(float(parts[1]))
                train_rmse_std.append(float(parts[2].lstrip("(").rstrip(")")))
            elif test_flag:
                test_rmse_mean.append(float(parts[1]))
                test_rmse_std.append(float(parts[2].lstrip("(").rstrip(")")))

        elif line.startswith("MAE:"):
            parts = line.split(" ")
            if train_flag:
                train_mae_mean.append(float(parts[1]))
                train_mae_std.append(float(parts[2].lstrip("(").rstrip(")")))
            elif test_flag:
                test_mae_mean.append(float(parts[1]))
                test_mae_std.append(float(parts[2].lstrip("(").rstrip(")")))

        elif line.startswith("MAPE:"):
            parts = line.split(" ")
            if train_flag:
                train_mape_mean.append(float(parts[1]))
                train_mape_std.append(float(parts[2].lstrip("(").rstrip(")")))
            elif test_flag:
                test_mape_mean.append(float(parts[1]))
                test_mape_std.append(float(parts[2].lstrip("(").rstrip(")")))

        elif line.startswith("R2:"):
            parts = line.split(" ")
            if train_flag:
                train_r2_mean.append(float(parts[1]))
                train_r2_std.append(float(parts[2].lstrip("(").rstrip(")")))
            elif test_flag:
                test_r2_mean.append(float(parts[1]))
                test_r2_std.append(float(parts[2].lstrip("(").rstrip(")")))

        elif line.startswith("="):
            train_flag = False
            test_flag = False
            timesteps_flag = False

        else:
            continue

# %% [markdown]
# # All Cements

# %%
results = []

# %% [markdown]
# ## No previous Compressive Strength

# %% [markdown]
# ## Repeated KFold Cross validation

# %% [markdown]
# ## Blocking Time Series Split Results

# %% [markdown]
# ## Time Series Split Cross Validation

# %% [markdown]
# ## Blocking Time Series Split Results - Period Specific

# %%
# Define the train and test periods for each row
periods = [
    ["6 months", "One Month"],
    ["11 months", "One Month"],
    ["1 year", "One Month"],
    ["1 year and one month", "One Month"],
    ["1 year and two months", "One Month"],
    ["2 years", "One Month"],
    ["2 years", "Two Months"],
    ["2 years", "One Year"],
    ["2 years, 8 months and 15 days", "8 months and 6 days"],
]

train_mean = []
test_mean = []

train_std = []
test_std = []

###########################
# 6 months", "One Month"  #
###########################
train_rmse_mean = [2.516, 0.853, 0.901, 1.069, 1.098, 1.197]
train_rmse_std = [0.897, 0.103, 0.15, 0.292, 0.227, 0.285]
test_rmse_mean = [21.676, 36.965, 37.07, 123.568, 178.71, 159.913]
test_rmse_std = [29.095, 73.51, 78.679, 191.517, 385.259, 319.972]
train_mae_mean = [1.965, 0.677, 0.73, 0.88, 0.901, 0.984]
train_mae_std = [0.707, 0.08, 0.146, 0.287, 0.227, 0.271]
test_mae_mean = [8.535, 20.998, 25.298, 46.492, 101.144, 51.75]
test_mae_std = [8.573, 40.347, 52.449, 58.238, 216.213, 101.583]
train_mape_mean = [0.046, 0.016, 0.017, 0.02, 0.021, 0.022]
train_mape_std = [0.017, 0.002, 0.003, 0.007, 0.005, 0.006]
test_mape_mean = [0.205, 0.488, 0.584, 1.197, 2.711, 1.168]
test_mape_std = [0.21, 0.925, 1.208, 1.529, 5.816, 2.292]
train_r2_mean = [0.717, 0.971, 0.967, 0.952, 0.951, 0.942]
train_r2_std = [0.177, 0.008, 0.012, 0.032, 0.022, 0.027]
test_r2_mean = [53.858, 276.801, 331.626, 1723.352, 5797.165, 5707.505]
test_r2_std = [97.529, 727.41, 939.071, 3283.037, 14825.282, 12061.309]


train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

###########################
# 11 months", "One Month  #
###########################
train_rmse_mean = [1.404, 0.908, 1.021, 1.114, 1.022, 1.086]
train_rmse_std = [0.217, 0.079, 0.232, 0.276, 0.202, 0.214]
test_rmse_mean = [16.444, 13.877, 13.437, 13.782, 1.634, 4.644]
test_rmse_std = [18.394, 15.434, 15.589, 18.049, 0.504, 6.762]
train_mae_mean = [1.067, 0.716, 0.838, 0.92, 0.84, 0.896]
train_mae_std = [0.157, 0.067, 0.219, 0.257, 0.198, 0.199]
test_mae_mean = [4.321, 5.543, 6.504, 7.366, 1.297, 2.351]
test_mae_std = [3.085, 4.67, 6.218, 8.831, 0.374, 2.611]
train_mape_mean = [0.025, 0.017, 0.02, 0.022, 0.02, 0.021]
train_mape_std = [0.003, 0.002, 0.005, 0.006, 0.004, 0.005]
test_mape_mean = [0.095, 0.121, 0.141, 0.158, 0.03, 0.055]
test_mape_std = [0.065, 0.099, 0.131, 0.187, 0.008, 0.06]
train_r2_mean = [0.92, 0.967, 0.958, 0.948, 0.958, 0.952]
train_r2_std = [0.03, 0.006, 0.018, 0.027, 0.016, 0.019]
test_r2_mean = [27.444, 17.677, 16.037, 18.723, 0.892, 1.762]
test_r2_std = [40.457, 27.553, 25.967, 31.97, 0.072, 6.159]


train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

###########################
# "1 year", "One Month"   #
###########################
train_rmse_mean = [1.334, 0.886, 0.934, 0.977, 1.01, 1.101]
train_rmse_std = [0.139, 0.097, 0.177, 0.122, 0.121, 0.158]
test_rmse_mean = [1.678, 1.747, 1.742, 1.691, 30.738, 3.778]
test_rmse_std = [0.214, 0.402, 0.223, 0.296, 50.707, 2.885]
train_mae_mean = [1.022, 0.693, 0.744, 0.789, 0.8, 0.903]
train_mae_std = [0.116, 0.075, 0.144, 0.102, 0.101, 0.144]
test_mae_mean = [1.359, 1.424, 1.422, 1.425, 22.687, 2.827]
test_mae_std = [0.199, 0.294, 0.232, 0.287, 37.178, 2.058]
train_mape_mean = [0.024, 0.016, 0.017, 0.018, 0.018, 0.021]
train_mape_std = [0.003, 0.002, 0.003, 0.002, 0.002, 0.003]
test_mape_mean = [0.032, 0.034, 0.034, 0.034, 0.525, 0.064]
test_mape_std = [0.005, 0.008, 0.005, 0.007, 0.859, 0.047]
train_r2_mean = [0.928, 0.968, 0.964, 0.962, 0.959, 0.951]
train_r2_std = [0.017, 0.007, 0.015, 0.01, 0.01, 0.013]
test_r2_mean = [0.89, 0.882, 0.882, 0.884, 150.471, 0.033]
test_r2_std = [0.035, 0.059, 0.03, 0.051, 300.157, 1.456]


train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

#########################################
# "1 year and one month", "One Month"   #
#########################################
train_rmse_mean = [1.311, 1.067, 1.07, 1.065, 0.941, 1.122]
train_rmse_std = [0.122, 0.215, 0.273, 0.213, 0.101, 0.234]
test_rmse_mean = [29.284, 159.771, 144.782, 119.208, 2.329, 1.672]
test_rmse_std = [31.308, 190.163, 176.777, 147.467, 0.881, 0.439]
train_mae_mean = [0.999, 0.807, 0.868, 0.847, 0.737, 0.902]
train_mae_std = [0.11, 0.129, 0.261, 0.201, 0.082, 0.207]
test_mae_mean = [16.427, 110.432, 115.141, 108.474, 1.949, 1.428]
test_mae_std = [17.079, 131.674, 140.304, 134.217, 0.762, 0.43]
train_mape_mean = [0.023, 0.019, 0.02, 0.02, 0.017, 0.021]
train_mape_std = [0.002, 0.003, 0.006, 0.005, 0.002, 0.005]
test_mape_mean = [0.386, 2.579, 2.649, 2.529, 0.043, 0.032]
test_mape_std = [0.401, 3.074, 3.224, 3.129, 0.017, 0.01]
train_r2_mean = [0.929, 0.952, 0.951, 0.953, 0.965, 0.949]
train_r2_std = [0.015, 0.019, 0.027, 0.019, 0.007, 0.021]
test_r2_mean = [73.911, 2665.507, 2344.69, 1435.431, 0.747, 0.88]
test_r2_std = [101.074, 4006.053, 3641.794, 2331.617, 0.253, 0.079]


train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

##########################################
# "1 year and two months", "One Month"   #
#########################################
train_rmse_mean = [1.325, 1.045, 1.025, 1.103, 1.034, 0.994]
train_rmse_std = [0.071, 0.169, 0.11, 0.107, 0.139, 0.084]
test_rmse_mean = [2.889, 2.156, 2.227, 1.953, 1.593, 1.298]
test_rmse_std = [1.027, 0.676, 0.578, 0.436, 0.479, 0.207]
train_mae_mean = [1.01, 0.831, 0.817, 0.88, 0.815, 0.801]
train_mae_std = [0.051, 0.138, 0.093, 0.085, 0.101, 0.077]
test_mae_mean = [2.27, 1.684, 1.706, 1.518, 1.269, 0.997]
test_mae_std = [0.665, 0.524, 0.423, 0.289, 0.382, 0.172]
train_mape_mean = [0.023, 0.019, 0.019, 0.02, 0.019, 0.019]
train_mape_std = [0.001, 0.003, 0.002, 0.002, 0.002, 0.002]
test_mape_mean = [0.051, 0.038, 0.039, 0.035, 0.029, 0.023]
test_mape_std = [0.016, 0.012, 0.01, 0.007, 0.008, 0.004]
train_r2_mean = [0.93, 0.956, 0.958, 0.952, 0.958, 0.961]
train_r2_std = [0.01, 0.013, 0.008, 0.009, 0.01, 0.006]
test_r2_mean = [0.607, 0.776, 0.775, 0.83, 0.876, 0.932]
test_r2_std = [0.287, 0.175, 0.128, 0.081, 0.076, 0.022]


train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

############################
# "2 years", "One Month"   #
############################
train_rmse_mean = [0.992, 0.949, 0.946, 0.903, 0.98, 0.993]
train_rmse_std = [0.027, 0.104, 0.093, 0.061, 0.041, 0.07]
test_rmse_mean = [1.268, 1.365, 1.574, 1.3, 1.457, 0.981]
test_rmse_std = [0.027, 0.069, 0.171, 0.184, 0.078, 0.081]
train_mae_mean = [0.744, 0.741, 0.738, 0.703, 0.775, 0.776]
train_mae_std = [0.015, 0.091, 0.071, 0.033, 0.05, 0.047]
test_mae_mean = [1.028, 1.067, 1.218, 0.992, 1.148, 0.714]
test_mae_std = [0.041, 0.059, 0.122, 0.115, 0.063, 0.077]
train_mape_mean = [0.017, 0.017, 0.017, 0.016, 0.018, 0.018]
train_mape_std = [0.0, 0.002, 0.002, 0.001, 0.001, 0.001]
test_mape_mean = [0.024, 0.024, 0.027, 0.023, 0.028, 0.017]
test_mape_std = [0.001, 0.001, 0.003, 0.002, 0.002, 0.002]
train_r2_mean = [0.959, 0.962, 0.963, 0.966, 0.961, 0.96]
train_r2_std = [0.002, 0.008, 0.007, 0.005, 0.003, 0.006]
test_r2_mean = [0.943, 0.937, 0.907, 0.94, 0.935, 0.965]
test_r2_std = [0.002, 0.006, 0.02, 0.017, 0.007, 0.006]


train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

############################
# "2 years", "Two Months"  #
############################
train_rmse_mean = [0.992, 0.949, 0.946, 0.903, 0.98, 0.993]
train_rmse_std = [0.027, 0.104, 0.093, 0.061, 0.041, 0.07]
test_rmse_mean = [1.378, 1.454, 1.641, 1.402, 1.308, 1.117]
test_rmse_std = [0.039, 0.08, 0.117, 0.156, 0.12, 0.05]
train_mae_mean = [0.744, 0.741, 0.738, 0.703, 0.775, 0.776]
train_mae_std = [0.015, 0.091, 0.071, 0.033, 0.05, 0.047]
test_mae_mean = [1.074, 1.172, 1.306, 1.099, 0.994, 0.859]
test_mae_std = [0.045, 0.093, 0.103, 0.134, 0.125, 0.041]
train_mape_mean = [0.017, 0.017, 0.017, 0.016, 0.018, 0.018]
train_mape_std = [0.0, 0.002, 0.002, 0.001, 0.001, 0.001]
test_mape_mean = [0.026, 0.027, 0.03, 0.026, 0.025, 0.02]
test_mape_std = [0.001, 0.002, 0.002, 0.003, 0.004, 0.001]
train_r2_mean = [0.959, 0.962, 0.963, 0.966, 0.961, 0.96]
train_r2_std = [0.002, 0.008, 0.007, 0.005, 0.003, 0.006]
test_r2_mean = [0.936, 0.933, 0.912, 0.935, 0.943, 0.957]
test_r2_std = [0.004, 0.007, 0.013, 0.015, 0.011, 0.004]

train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

##########################
# "2 years", "One Year"  #
##########################
train_rmse_mean = [0.992, 0.949, 0.946, 0.903, 0.98, 0.993]
train_rmse_std = [0.027, 0.104, 0.093, 0.061, 0.041, 0.07]
test_rmse_mean = [2.385, 2.402, 2.483, 2.298, 1.963, 2.339]
test_rmse_std = [0.27, 0.126, 0.307, 0.324, 0.17, 0.718]
train_mae_mean = [0.744, 0.741, 0.738, 0.703, 0.775, 0.776]
train_mae_std = [0.015, 0.091, 0.071, 0.033, 0.05, 0.047]
test_mae_mean = [1.652, 1.849, 1.914, 1.781, 1.521, 1.739]
test_mae_std = [0.064, 0.108, 0.193, 0.251, 0.126, 0.433]
train_mape_mean = [0.017, 0.017, 0.017, 0.016, 0.018, 0.018]
train_mape_std = [0.0, 0.002, 0.002, 0.001, 0.001, 0.001]
test_mape_mean = [0.037, 0.041, 0.043, 0.04, 0.034, 0.04]
test_mape_std = [0.001, 0.002, 0.004, 0.006, 0.003, 0.011]
train_r2_mean = [0.959, 0.962, 0.963, 0.966, 0.961, 0.96]
train_r2_std = [0.002, 0.008, 0.007, 0.005, 0.003, 0.006]
test_r2_mean = [0.797, 0.796, 0.778, 0.811, 0.862, 0.78]
test_r2_std = [0.047, 0.021, 0.055, 0.053, 0.025, 0.148]

train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

###########################################################
# "2 years, 8 months and 15 days", "8 months and 6 days"  #
###########################################################
train_rmse_mean = [1.13, 1.038, 1.226, 1.179, 1.025, 0.987]
train_rmse_std = [0.028, 0.071, 0.131, 0.159, 0.116, 0.04]
test_rmse_mean = [1.492, 1.741, 2.03, 1.97, 1.658, 1.553]
test_rmse_std = [0.092, 0.08, 0.206, 0.147, 0.147, 0.094]
train_mae_mean = [0.836, 0.781, 0.98, 0.926, 0.789, 0.764]
train_mae_std = [0.022, 0.042, 0.108, 0.129, 0.086, 0.023]
test_mae_mean = [1.177, 1.408, 1.645, 1.578, 1.31, 1.248]
test_mae_std = [0.062, 0.062, 0.169, 0.116, 0.112, 0.067]
train_mape_mean = [0.019, 0.018, 0.023, 0.021, 0.018, 0.018]
train_mape_std = [0.001, 0.001, 0.002, 0.003, 0.002, 0.001]
test_mape_mean = [0.026, 0.032, 0.037, 0.036, 0.03, 0.028]
test_mape_std = [0.001, 0.001, 0.004, 0.003, 0.003, 0.002]
train_r2_mean = [0.95, 0.958, 0.94, 0.945, 0.958, 0.962]
train_r2_std = [0.003, 0.006, 0.012, 0.014, 0.01, 0.003]
test_r2_mean = [0.91, 0.877, 0.832, 0.842, 0.888, 0.902]
test_r2_std = [0.011, 0.011, 0.033, 0.022, 0.02, 0.012]

train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))


# Extract the relevant information and store it in a dictionary
data = {
    "Validation": ["Blocking Time Series - Period Specific"] * 216,
    "Repeats": [5] * 216,
    "Splits": [np.nan] * 216,
    "Metric": ["RMSE", "MAE", "MAPE", "R2"] * len(periods) * 6,
    "Time Steps": sorted([1, 3, 5, 7, 14, 21] * 4 * 9),
    "Train Mean": train_mean,
    "Train Std": train_std,
    "Test Mean": test_mean,
    "Test Std": test_std,
    "Train Period": [
        item
        for sublist in [[result[0]] * 4 * 6 for result in periods]
        for item in sublist
    ],
    "Test Period": [
        item
        for sublist in [[result[1]] * 4 * 6 for result in periods]
        for item in sublist
    ],
}

df = pd.DataFrame(data)

# %%
idx = df[df["Metric"] == "RMSE"]["Test Mean"].idxmin()
df.iloc[idx : idx + 4]
# Out:
#                                  Validation  Repeats  Splits Metric  \
# 140  Blocking Time Series - Period Specific        5     NaN   RMSE
# 141  Blocking Time Series - Period Specific        5     NaN    MAE
# 142  Blocking Time Series - Period Specific        5     NaN   MAPE
# 143  Blocking Time Series - Period Specific        5     NaN     R2
#
#      Time Steps  Train Mean  Train Std  Test Mean  Test Std Train Period  \
# 140           7       0.993      0.070      0.981     0.081      2 years
# 141           7       0.776      0.047      0.714     0.077      2 years
# 142           7       0.018      0.001      0.017     0.002      2 years
# 143           7       0.960      0.006      0.965     0.006      2 years
#
#     Test Period
# 140   One Month
# 141   One Month
# 142   One Month
# 143   One Month

# %%
s = """

"""

# %%
train_rmse_mean, train_rmse_std, test_rmse_mean, test_rmse_std = [], [], [], []
train_mae_mean, train_mae_std, test_mae_mean, test_mae_std = [], [], [], []
train_mape_mean, train_mape_std, test_mape_mean, test_mape_std = [], [], [], []
train_r2_mean, train_r2_std, test_r2_mean, test_r2_std = [], [], [], []

extract_and_fill_lists(
    s,
    train_rmse_mean,
    train_rmse_std,
    test_rmse_mean,
    test_rmse_std,
    train_mae_mean,
    train_mae_std,
    test_mae_mean,
    test_mae_std,
    train_mape_mean,
    train_mape_std,
    test_mape_mean,
    test_mape_std,
    train_r2_mean,
    train_r2_std,
    test_r2_mean,
    test_r2_std,
)

for x, y in zip(
    [
        "train_rmse_mean",
        "train_rmse_std",
        "test_rmse_mean",
        "test_rmse_std",
        "train_mae_mean",
        "train_mae_std",
        "test_mae_mean",
        "test_mae_std",
        "train_mape_mean",
        "train_mape_std",
        "test_mape_mean",
        "test_mape_std",
        "train_r2_mean",
        "train_r2_std",
        "test_r2_mean",
        "test_r2_std",
    ],
    [
        train_rmse_mean,
        train_rmse_std,
        test_rmse_mean,
        test_rmse_std,
        train_mae_mean,
        train_mae_std,
        test_mae_mean,
        test_mae_std,
        train_mape_mean,
        train_mape_std,
        test_mape_mean,
        test_mape_std,
        train_r2_mean,
        train_r2_std,
        test_r2_mean,
        test_r2_std,
    ],
):
    print(f"{x} = {y}")
# Out:
# train_rmse_mean = []
# train_rmse_std = []
# test_rmse_mean = []
# test_rmse_std = []
# train_mae_mean = []
# train_mae_std = []
# test_mae_mean = []
# test_mae_std = []
# train_mape_mean = []
# train_mape_std = []
# test_mape_mean = []
# test_mape_std = []
# train_r2_mean = []
# train_r2_std = []
# test_r2_mean = []
# test_r2_std = []
