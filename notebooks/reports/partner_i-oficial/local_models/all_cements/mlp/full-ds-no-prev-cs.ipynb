# %%
# %load_ext nb_black

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # All Cements

# %%
results = []

# %% [markdown]
# ## No previous Compressive Strength

# %% [markdown]
# ## Repeated KFold Cross validation

# %%
data = {
    "Metric": ["RMSE", "MAE", "MAPE", "R2"],
    "Train Mean": [1.283, 0.955, 0.022, 0.935],
    "Train Std": [0.088, 0.046, 0.001, 0.009],
    "Test Mean": [1.361, 0.988, 0.023, 0.924],
    "Test Std": [0.218, 0.096, 0.002, 0.028],
    "Validation": ["Repeated KFold"] * 4,
    "Repeats": [10] * 4,
    "Splits": [10] * 4,
}
df = pd.DataFrame(data)
df = df[
    [
        "Validation",
        "Repeats",
        "Splits",
        "Metric",
        "Train Mean",
        "Train Std",
        "Test Mean",
        "Test Std",
    ]
]
results.append(df)

# %% [markdown]
# ## Blocking Time Series Split Results

# %%
df = [
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 10,
        "Splits": 5,
        "Metric": "RMSE",
        "Train Mean": 3.278,
        "Train Std": 1.186,
        "Test Mean": 122.056,
        "Test Std": 177.769,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 10,
        "Splits": 5,
        "Metric": "MAE",
        "Train Mean": 2.565,
        "Train Std": 0.977,
        "Test Mean": 29.136,
        "Test Std": 38.514,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 10,
        "Splits": 5,
        "Metric": "MAPE",
        "Train Mean": 0.060,
        "Train Std": 0.023,
        "Test Mean": 0.665,
        "Test Std": 0.895,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 10,
        "Splits": 5,
        "Metric": "R2",
        "Train Mean": 0.515,
        "Train Std": 0.380,
        "Test Mean": 1956.831,
        "Test Std": 4303.558,
    },
]
df = pd.DataFrame(df)
results.append(df)

# %% [markdown]
# ## Time Series Split Cross Validation

# %%
# define dictionary with results
tss_results = {
    "Validation": "Time Series Split Cross Validation",
    "Repeats": 10,
    "Splits": 10,
    "RMSE Train Mean": 1.889,
    "RMSE Train Std": 1.263,
    "MAE Train Mean": 1.419,
    "MAE Train Std": 0.984,
    "MAPE Train Mean": 0.033,
    "MAPE Train Std": 0.023,
    "R2 Train Mean": 0.784,
    "R2 Train Std": 0.367,
    "RMSE Test Mean": 389.484,
    "RMSE Test Std": 830.736,
    "MAE Test Mean": 47.916,
    "MAE Test Std": 89.615,
    "MAPE Test Mean": 1.065,
    "MAPE Test Std": 1.992,
    "R2 Test Mean": 35330.487,
    "R2 Test Std": 95779.316,
}

# create dataframe
df = pd.DataFrame(
    columns=[
        "Validation",
        "Repeats",
        "Splits",
        "Metric",
        "Train Mean",
        "Train Std",
        "Test Mean",
        "Test Std",
    ]
)

# populate dataframe
for i, metric in enumerate(["RMSE", "MAE", "MAPE", "R2"]):
    df.loc[i * 4] = [
        tss_results["Validation"],
        tss_results["Repeats"],
        tss_results["Splits"],
        metric,
        tss_results[f"{metric} Train Mean"],
        tss_results[f"{metric} Train Std"],
        tss_results[f"{metric} Test Mean"],
        tss_results[f"{metric} Test Std"],
    ]
results.append(df)

# %% [markdown]
# ## Blocking Time Series Split Results - Period Specific

# %%
# Define the train and test periods for each row
periods = [
    ["6 months", "One Month"],
    ["11 months", "One Month"],
    ["1 year", "One Month"],
    ["1 year and one month", "One Month"],
    ["1 year and two months", "One Month"],
    ["2 years", "One Month"],
    ["2 years", "Two Months"],
    ["2 years", "One Year"],
    ["2 years, 8 months and 15 days", "8 months and 6 days"],
]

# Extract the relevant information and store it in a dictionary
data = {
    "Validation": ["Blocking Time Series - Period Specific"] * 36,
    "Repeats": [10] * 36,
    "Splits": [np.nan] * 36,
    "Metric": ["RMSE", "MAE", "MAPE", "R2"] * len(periods),
    "Train Mean": [
        2.961,
        2.232,
        0.052,
        0.606,
        1.719,
        1.291,
        0.030,
        0.883,
        1.482,
        1.105,
        0.025,
        0.912,
        1.779,
        1.136,
        0.026,
        0.807,
        1.774,
        1.135,
        0.026,
        0.813,
        1.274,
        0.904,
        0.021,
        0.932,
        1.274,
        0.904,
        0.021,
        0.932,
        1.274,
        0.904,
        0.021,
        0.932,
        1.277,
        0.946,
        0.022,
        0.936,
    ],
    "Train Std": [
        1.095,
        0.877,
        0.021,
        0.272,
        0.166,
        0.144,
        0.003,
        0.028,
        0.139,
        0.117,
        0.003,
        0.019,
        1.291,
        0.259,
        0.006,
        0.447,
        1.299,
        0.278,
        0.007,
        0.433,
        0.150,
        0.060,
        0.001,
        0.017,
        0.150,
        0.060,
        0.001,
        0.017,
        0.150,
        0.060,
        0.001,
        0.017,
        0.078,
        0.052,
        0.001,
        0.008,
    ],
    "Test Mean": [
        27.389,
        11.028,
        0.262,
        83.048,
        11.770,
        3.499,
        0.077,
        12.795,
        1.657,
        1.325,
        0.031,
        0.894,
        44.627,
        24.720,
        0.579,
        241.038,
        3.761,
        2.746,
        0.061,
        0.106,
        1.240,
        0.997,
        0.023,
        0.945,
        1.318,
        1.028,
        0.024,
        0.942,
        2.286,
        1.609,
        0.036,
        0.813,
        1.493,
        1.165,
        0.026,
        0.909,
    ],
    "Test Std": [
        34.597,
        12.547,
        0.293,
        166.992,
        12.547,
        2.252,
        0.048,
        21.542,
        0.205,
        0.184,
        0.004,
        0.032,
        62.814,
        34.231,
        0.803,
        455.914,
        2.594,
        1.456,
        0.033,
        1.256,
        0.060,
        0.073,
        0.002,
        0.005,
        0.058,
        0.063,
        0.002,
        0.005,
        0.268,
        0.086,
        0.002,
        0.044,
        0.092,
        0.046,
        0.001,
        0.011,
    ],
    "Train Period": [
        item for sublist in [[result[0]] * 4 for result in periods] for item in sublist
    ],
    "Test Period": [
        item for sublist in [[result[1]] * 4 for result in periods] for item in sublist
    ],
}

df = pd.DataFrame(data)

# %%
df = df.set_index(["Train Period", "Test Period"])

df[
    (
        df[df["Metric"] == "RMSE"]
        == df[df["Metric"] == "RMSE"][["Test Mean"]].min().values[0]
    )["Test Mean"]
]
# Out:
# /home/felipe/Documents/ccs28-venv/lib/python3.6/site-packages/ipykernel_launcher.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   import sys
#                                                       Validation  Repeats  \
# Train Period Test Period
# 2 years      One Month    Blocking Time Series - Period Specific       10
#              One Month    Blocking Time Series - Period Specific       10
#              One Month    Blocking Time Series - Period Specific       10
#              One Month    Blocking Time Series - Period Specific       10
#
#                           Splits Metric  Train Mean  Train Std  Test Mean  \
# Train Period Test Period
# 2 years      One Month       NaN   RMSE       1.274      0.150      1.240
#              One Month       NaN    MAE       0.904      0.060      0.997
#              One Month       NaN   MAPE       0.021      0.001      0.023
#              One Month       NaN     R2       0.932      0.017      0.945
#
#                           Test Std
# Train Period Test Period
# 2 years      One Month       0.060
#              One Month       0.073
#              One Month       0.002
#              One Month       0.005

# %%
idx = df[df["Metric"] == "RMSE"]["Test Mean"].idxmin()
df.iloc[idx : idx + 4]
# Out:
#                                 Validation  Repeats  Splits Metric  \
# 20  Blocking Time Series - Period Specific       10     NaN   RMSE
# 21  Blocking Time Series - Period Specific       10     NaN    MAE
# 22  Blocking Time Series - Period Specific       10     NaN   MAPE
# 23  Blocking Time Series - Period Specific       10     NaN     R2
#
#     Train Mean  Train Std  Test Mean  Test Std Train Period Test Period
# 20       1.274      0.150      1.240     0.060      2 years   One Month
# 21       0.904      0.060      0.997     0.073      2 years   One Month
# 22       0.021      0.001      0.023     0.002      2 years   One Month
# 23       0.932      0.017      0.945     0.005      2 years   One Month
