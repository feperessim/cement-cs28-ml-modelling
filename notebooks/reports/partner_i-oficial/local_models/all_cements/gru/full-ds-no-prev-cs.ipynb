# %%
# %load_ext nb_black

# %%
import pandas as pd
import numpy as np

# %%
def flat_list(lst):
    return [item for tup in list(lst) for item in tup]

# %%
def extract_and_fill_lists(text, train_rmse_mean, train_rmse_std, test_rmse_mean, test_rmse_std,
                           train_mae_mean, train_mae_std, test_mae_mean, test_mae_std,
                           train_mape_mean, train_mape_std, test_mape_mean, test_mape_std,
                           train_r2_mean, train_r2_std, test_r2_mean, test_r2_std):

    train_flag = False
    test_flag = False
    timesteps_flag = False

    for line in text.split("\n"):
        line = line.strip()

        if line.startswith("TIMESTEPS:"):
            timesteps_flag = True

        elif line.startswith("[TRAIN]"):
            train_flag = True
            test_flag = False

        elif line.startswith("[TEST]"):
            train_flag = False
            test_flag = True

        elif line.startswith("RMSE:"):
            parts = line.split(" ")
            if train_flag:
                train_rmse_mean.append(float(parts[1]))
                train_rmse_std.append(float(parts[2].lstrip("(").rstrip(")")))
            elif test_flag:
                test_rmse_mean.append(float(parts[1]))
                test_rmse_std.append(float(parts[2].lstrip("(").rstrip(")")))

        elif line.startswith("MAE:"):
            parts = line.split(" ")
            if train_flag:
                train_mae_mean.append(float(parts[1]))
                train_mae_std.append(float(parts[2].lstrip("(").rstrip(")")))
            elif test_flag:
                test_mae_mean.append(float(parts[1]))
                test_mae_std.append(float(parts[2].lstrip("(").rstrip(")")))

        elif line.startswith("MAPE:"):
            parts = line.split(" ")
            if train_flag:
                train_mape_mean.append(float(parts[1]))
                train_mape_std.append(float(parts[2].lstrip("(").rstrip(")")))
            elif test_flag:
                test_mape_mean.append(float(parts[1]))
                test_mape_std.append(float(parts[2].lstrip("(").rstrip(")")))

        elif line.startswith("R2:"):
            parts = line.split(" ")
            if train_flag:
                train_r2_mean.append(float(parts[1]))
                train_r2_std.append(float(parts[2].lstrip("(").rstrip(")")))
            elif test_flag:
                test_r2_mean.append(float(parts[1]))
                test_r2_std.append(float(parts[2].lstrip("(").rstrip(")")))

        elif line.startswith("="):
            train_flag = False
            test_flag = False
            timesteps_flag = False

        else:
            continue

# %% [markdown]
# # All Cements

# %%
results = []

# %% [markdown]
# ## No previous Compressive Strength

# %% [markdown]
# ## Repeated KFold Cross validation

# %% [markdown]
# ## Blocking Time Series Split Results

# %% [markdown]
# ## Time Series Split Cross Validation

# %% [markdown]
# ## Blocking Time Series Split Results - Period Specific

# %%
# Define the train and test periods for each row
periods = [
    ["6 months", "One Month"],
    ["11 months", "One Month"],
    ["1 year", "One Month"],
    ["1 year and one month", "One Month"],
    ["1 year and two months", "One Month"],
    ["2 years", "One Month"],
    ["2 years", "Two Months"],
    ["2 years", "One Year"],
    ["2 years, 8 months and 15 days", "8 months and 6 days"],
]

train_mean = []
test_mean = []

train_std = []
test_std = []

###########################
# 6 months", "One Month"  #
###########################
train_rmse_mean = [3.872, 1.19, 1.092, 1.089, 1.037, 1.096]
train_rmse_std = [1.552, 0.162, 0.167, 0.165, 0.073, 0.101]
test_rmse_mean = [25.898, 37.259, 40.005, 79.75, 154.839, 124.709]
test_rmse_std = [36.847, 73.833, 89.521, 111.181, 338.484, 249.205]
train_mae_mean = [2.92, 0.932, 0.869, 0.876, 0.829, 0.875]
train_mae_std = [1.212, 0.126, 0.133, 0.155, 0.061, 0.089]
test_mae_mean = [10.054, 18.009, 24.553, 35.278, 85.389, 39.797]
test_mae_std = [10.311, 34.388, 53.141, 54.682, 184.03, 77.431]
train_mape_mean = [0.069, 0.022, 0.02, 0.02, 0.019, 0.02]
train_mape_std = [0.029, 0.003, 0.003, 0.004, 0.001, 0.002]
test_mape_mean = [0.242, 0.416, 0.564, 0.871, 2.284, 0.901]
test_mape_std = [0.253, 0.784, 1.217, 1.296, 4.941, 1.751]
train_r2_mean = [0.313, 0.942, 0.952, 0.952, 0.958, 0.953]
train_r2_std = [0.488, 0.018, 0.018, 0.018, 0.007, 0.01]
test_r2_mean = [83.285, 279.566, 421.794, 676.095, 4452.979, 3463.478]
test_r2_std = [161.753, 773.967, 1151.431, 1074.967, 10990.519, 7343.68]


train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

###########################
# 11 months", "One Month  #
###########################
train_rmse_mean = [1.807, 1.059, 1.127, 1.1, 1.066, 1.089]
train_rmse_std = [0.348, 0.089, 0.189, 0.175, 0.112, 0.12]
test_rmse_mean = [16.588, 14.533, 12.517, 14.028, 1.677, 3.544]
test_rmse_std = [18.302, 18.095, 18.38, 19.007, 0.895, 4.883]
train_mae_mean = [1.339, 0.827, 0.897, 0.892, 0.843, 0.867]
train_mae_std = [0.267, 0.063, 0.164, 0.162, 0.102, 0.098]
test_mae_mean = [4.62, 4.851, 5.348, 7.117, 1.28, 1.806]
test_mae_std = [3.002, 4.471, 6.376, 8.835, 0.534, 1.613]
train_mape_mean = [0.031, 0.019, 0.021, 0.021, 0.02, 0.02]
train_mape_std = [0.006, 0.001, 0.004, 0.004, 0.002, 0.002]
test_mape_mean = [0.102, 0.106, 0.116, 0.153, 0.03, 0.041]
test_mape_std = [0.063, 0.095, 0.135, 0.187, 0.011, 0.036]
train_r2_mean = [0.865, 0.956, 0.949, 0.952, 0.955, 0.953]
train_r2_std = [0.06, 0.009, 0.02, 0.015, 0.009, 0.01]
test_r2_mean = [27.499, 22.353, 18.884, 20.341, 0.867, 0.493]
test_r2_std = [41.337, 41.312, 48.764, 41.198, 0.195, 3.619]

train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

###########################
# "1 year", "One Month"   #
###########################
train_rmse_mean = [1.708, 1.426, 1.116, 1.134, 1.125, 1.093]
train_rmse_std = [0.343, 0.245, 0.124, 0.193, 0.18, 0.126]
test_rmse_mean = [1.843, 1.904, 1.703, 1.856, 22.425, 3.184]
test_rmse_std = [0.413, 0.406, 0.244, 0.423, 55.806, 2.437]
train_mae_mean = [1.276, 1.177, 0.891, 0.936, 0.906, 0.874]
train_mae_std = [0.277, 0.222, 0.116, 0.191, 0.165, 0.131]
test_mae_mean = [1.516, 1.514, 1.355, 1.522, 15.223, 2.336]
test_mae_std = [0.379, 0.372, 0.205, 0.393, 37.008, 1.68]
train_mape_mean = [0.029, 0.027, 0.021, 0.022, 0.021, 0.02]
train_mape_std = [0.006, 0.005, 0.003, 0.005, 0.004, 0.003]
test_mape_mean = [0.036, 0.036, 0.032, 0.036, 0.35, 0.053]
test_mape_std = [0.009, 0.008, 0.005, 0.009, 0.847, 0.038]
train_r2_mean = [0.878, 0.917, 0.95, 0.948, 0.949, 0.952]
train_r2_std = [0.054, 0.027, 0.012, 0.02, 0.017, 0.012]
test_r2_mean = [0.861, 0.854, 0.884, 0.859, 154.823, 0.309]
test_r2_std = [0.072, 0.076, 0.043, 0.07, 517.671, 1.093]


train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

#########################################
# "1 year and one month", "One Month"   #
#########################################
train_rmse_mean = [1.648, 1.246, 1.1, 1.076, 1.133, 1.137]
train_rmse_std = [0.282, 0.173, 0.093, 0.124, 0.201, 0.171]
test_rmse_mean = [24.157, 244.632, 235.129, 215.988, 2.354, 1.484]
test_rmse_std = [25.4, 265.121, 288.044, 259.717, 0.922, 0.372]
train_mae_mean = [1.245, 0.933, 0.865, 0.869, 0.929, 0.932]
train_mae_std = [0.212, 0.108, 0.085, 0.128, 0.193, 0.171]
test_mae_mean = [13.672, 145.641, 165.4, 177.976, 2.032, 1.229]
test_mae_std = [13.866, 157.555, 200.954, 211.843, 0.865, 0.292]
train_mape_mean = [0.029, 0.022, 0.02, 0.02, 0.022, 0.022]
train_mape_std = [0.005, 0.002, 0.002, 0.003, 0.005, 0.004]
test_mape_mean = [0.321, 3.389, 3.775, 4.132, 0.047, 0.029]
test_mape_std = [0.327, 3.665, 4.583, 4.924, 0.02, 0.008]
train_r2_mean = [0.886, 0.936, 0.951, 0.953, 0.948, 0.948]
train_r2_std = [0.042, 0.016, 0.007, 0.012, 0.019, 0.015]
test_r2_mean = [49.079, 5624.052, 6210.348, 4557.336, 0.731, 0.911]
test_r2_std = [62.353, 7005.307, 9434.069, 7057.934, 0.256, 0.038]


train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

##########################################
# "1 year and two months", "One Month"   #
#########################################
train_rmse_mean = [1.638, 1.127, 1.197, 1.18, 1.111, 1.151]
train_rmse_std = [0.246, 0.043, 0.177, 0.141, 0.174, 0.194]
test_rmse_mean = [2.916, 2.355, 2.09, 2.194, 1.682, 1.454]
test_rmse_std = [0.967, 0.73, 0.493, 0.428, 0.46, 0.23]
train_mae_mean = [1.24, 0.88, 0.961, 0.944, 0.887, 0.94]
train_mae_std = [0.166, 0.035, 0.154, 0.111, 0.174, 0.176]
test_mae_mean = [2.308, 1.91, 1.693, 1.721, 1.402, 1.175]
test_mae_std = [0.597, 0.573, 0.341, 0.32, 0.396, 0.242]
train_mape_mean = [0.029, 0.021, 0.022, 0.022, 0.021, 0.022]
train_mape_std = [0.004, 0.001, 0.004, 0.003, 0.004, 0.004]
test_mape_mean = [0.052, 0.043, 0.039, 0.04, 0.032, 0.027]
test_mape_std = [0.014, 0.013, 0.008, 0.008, 0.008, 0.006]
train_r2_mean = [0.89, 0.95, 0.943, 0.945, 0.951, 0.947]
train_r2_std = [0.038, 0.003, 0.015, 0.013, 0.014, 0.017]
test_r2_mean = [0.608, 0.732, 0.804, 0.785, 0.867, 0.914]
test_r2_std = [0.289, 0.189, 0.103, 0.09, 0.068, 0.029]

train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

############################
# "2 years", "One Month"   #
############################
train_rmse_mean = [1.196, 1.018, 1.075, 1.045, 1.103, 1.099]
train_rmse_std = [0.076, 0.041, 0.084, 0.069, 0.162, 0.058]
test_rmse_mean = [1.258, 1.458, 1.368, 1.42, 1.387, 1.197]
test_rmse_std = [0.066, 0.058, 0.103, 0.086, 0.075, 0.121]
train_mae_mean = [0.877, 0.813, 0.857, 0.817, 0.92, 0.901]
train_mae_std = [0.046, 0.042, 0.094, 0.05, 0.155, 0.049]
test_mae_mean = [1.01, 1.211, 1.101, 1.115, 1.069, 0.91]
test_mae_std = [0.054, 0.073, 0.073, 0.047, 0.063, 0.114]
train_mape_mean = [0.02, 0.019, 0.02, 0.019, 0.022, 0.021]
train_mape_std = [0.001, 0.001, 0.002, 0.001, 0.004, 0.001]
test_mape_mean = [0.023, 0.028, 0.025, 0.025, 0.027, 0.022]
test_mape_std = [0.001, 0.002, 0.001, 0.001, 0.002, 0.003]
train_r2_mean = [0.941, 0.957, 0.952, 0.955, 0.949, 0.951]
train_r2_std = [0.007, 0.004, 0.008, 0.006, 0.016, 0.005]
test_r2_mean = [0.944, 0.928, 0.931, 0.93, 0.941, 0.948]
test_r2_std = [0.006, 0.006, 0.01, 0.008, 0.006, 0.01]

train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

############################
# "2 years", "Two Months"  #
############################
train_rmse_mean = [1.196, 1.018, 1.075, 1.045, 1.103, 1.099]
train_rmse_std = [0.076, 0.041, 0.084, 0.069, 0.162, 0.058]
test_rmse_mean = [1.414, 1.527, 1.534, 1.439, 1.353, 1.295]
test_rmse_std = [0.062, 0.056, 0.099, 0.081, 0.085, 0.134]
train_mae_mean = [0.877, 0.813, 0.857, 0.817, 0.92, 0.901]
train_mae_std = [0.046, 0.042, 0.094, 0.05, 0.155, 0.049]
test_mae_mean = [1.144, 1.248, 1.235, 1.158, 1.047, 1.0]
test_mae_std = [0.061, 0.054, 0.08, 0.053, 0.081, 0.13]
train_mape_mean = [0.02, 0.019, 0.02, 0.019, 0.022, 0.021]
train_mape_std = [0.001, 0.001, 0.002, 0.001, 0.004, 0.001]
test_mape_mean = [0.027, 0.03, 0.029, 0.027, 0.026, 0.023]
test_mape_std = [0.001, 0.001, 0.002, 0.001, 0.002, 0.003]
train_r2_mean = [0.941, 0.957, 0.952, 0.955, 0.949, 0.951]
train_r2_std = [0.007, 0.004, 0.008, 0.006, 0.016, 0.005]
test_r2_mean = [0.933, 0.926, 0.923, 0.932, 0.939, 0.942]
test_r2_std = [0.006, 0.005, 0.01, 0.008, 0.008, 0.012]


train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

##########################
# "2 years", "One Year"  #
##########################
train_rmse_mean = [1.196, 1.018, 1.075, 1.045, 1.103, 1.099]
train_rmse_std = [0.076, 0.041, 0.084, 0.069, 0.162, 0.058]
test_rmse_mean = [2.648, 2.347, 2.294, 2.186, 1.728, 1.7]
test_rmse_std = [0.381, 0.254, 0.114, 0.144, 0.047, 0.125]
train_mae_mean = [0.877, 0.813, 0.857, 0.817, 0.92, 0.901]
train_mae_std = [0.046, 0.042, 0.094, 0.05, 0.155, 0.049]
test_mae_mean = [1.841, 1.699, 1.722, 1.703, 1.355, 1.354]
test_mae_std = [0.123, 0.046, 0.094, 0.101, 0.059, 0.095]
train_mape_mean = [0.02, 0.019, 0.02, 0.019, 0.022, 0.021]
train_mape_std = [0.001, 0.001, 0.002, 0.001, 0.004, 0.001]
test_mape_mean = [0.041, 0.038, 0.038, 0.038, 0.031, 0.031]
test_mape_std = [0.003, 0.001, 0.002, 0.002, 0.001, 0.002]
train_r2_mean = [0.941, 0.957, 0.952, 0.955, 0.949, 0.951]
train_r2_std = [0.007, 0.004, 0.008, 0.006, 0.016, 0.005]
test_r2_mean = [0.748, 0.804, 0.813, 0.831, 0.893, 0.893]
test_r2_std = [0.073, 0.045, 0.019, 0.023, 0.006, 0.016]


train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

###########################################################
# "2 years, 8 months and 15 days", "8 months and 6 days"  #
###########################################################
train_rmse_mean = [1.169, 1.249, 1.113, 1.073, 1.103, 1.065]
train_rmse_std = [0.046, 0.138, 0.032, 0.017, 0.075, 0.037]
test_rmse_mean = [1.471, 1.585, 1.618, 1.569, 1.375, 1.317]
test_rmse_std = [0.05, 0.109, 0.102, 0.118, 0.08, 0.066]
train_mae_mean = [0.894, 1.027, 0.865, 0.844, 0.883, 0.85]
train_mae_std = [0.035, 0.141, 0.021, 0.02, 0.085, 0.03]
test_mae_mean = [1.143, 1.278, 1.283, 1.276, 1.107, 1.071]
test_mae_std = [0.046, 0.075, 0.08, 0.073, 0.053, 0.036]
train_mape_mean = [0.021, 0.024, 0.02, 0.019, 0.02, 0.02]
train_mape_std = [0.001, 0.003, 0.0, 0.001, 0.002, 0.001]
test_mape_mean = [0.026, 0.029, 0.029, 0.029, 0.025, 0.024]
test_mape_std = [0.001, 0.002, 0.002, 0.002, 0.001, 0.001]
train_r2_mean = [0.946, 0.938, 0.951, 0.955, 0.952, 0.955]
train_r2_std = [0.004, 0.014, 0.003, 0.001, 0.007, 0.003]
test_r2_mean = [0.912, 0.898, 0.894, 0.9, 0.923, 0.93]
test_r2_std = [0.006, 0.014, 0.013, 0.016, 0.009, 0.007]

train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

# Extract the relevant information and store it in a dictionary
data = {
    "Validation": ["Blocking Time Series - Period Specific"] * 216,
    "Repeats": [5] * 216,
    "Splits": [np.nan] * 216,
    "Metric": ["RMSE", "MAE", "MAPE", "R2"] * len(periods) * 6,
    "Time Steps": sorted([1, 3, 5, 7, 14, 21] * 4 * 9),
    "Train Mean": train_mean,
    "Train Std": train_std,
    "Test Mean": test_mean,
    "Test Std": test_std,
    "Train Period": [
        item
        for sublist in [[result[0]] * 4 * 6 for result in periods]
        for item in sublist
    ],
    "Test Period": [
        item
        for sublist in [[result[1]] * 4 * 6 for result in periods]
        for item in sublist
    ],
}

df = pd.DataFrame(data)

# %%
idx = df[df["Metric"] == "RMSE"]["Test Mean"].idxmin()
df.iloc[idx : idx + 4]
# Out:
#                                  Validation  Repeats  Splits Metric  \
# 140  Blocking Time Series - Period Specific        5     NaN   RMSE
# 141  Blocking Time Series - Period Specific        5     NaN    MAE
# 142  Blocking Time Series - Period Specific        5     NaN   MAPE
# 143  Blocking Time Series - Period Specific        5     NaN     R2
#
#      Time Steps  Train Mean  Train Std  Test Mean  Test Std Train Period  \
# 140           7       1.099      0.058      1.197     0.121      2 years
# 141           7       0.901      0.049      0.910     0.114      2 years
# 142           7       0.021      0.001      0.022     0.003      2 years
# 143           7       0.951      0.005      0.948     0.010      2 years
#
#     Test Period
# 140   One Month
# 141   One Month
# 142   One Month
# 143   One Month

# %%
s = """

"""

# %%
train_rmse_mean, train_rmse_std, test_rmse_mean, test_rmse_std = [], [], [], []
train_mae_mean, train_mae_std, test_mae_mean, test_mae_std = [], [], [], []
train_mape_mean, train_mape_std, test_mape_mean, test_mape_std = [], [], [], []
train_r2_mean, train_r2_std, test_r2_mean, test_r2_std = [], [], [], []

extract_and_fill_lists(
    s,
    train_rmse_mean,
    train_rmse_std,
    test_rmse_mean,
    test_rmse_std,
    train_mae_mean,
    train_mae_std,
    test_mae_mean,
    test_mae_std,
    train_mape_mean,
    train_mape_std,
    test_mape_mean,
    test_mape_std,
    train_r2_mean,
    train_r2_std,
    test_r2_mean,
    test_r2_std,
)

for x, y in zip(
    [
        "train_rmse_mean",
        "train_rmse_std",
        "test_rmse_mean",
        "test_rmse_std",
        "train_mae_mean",
        "train_mae_std",
        "test_mae_mean",
        "test_mae_std",
        "train_mape_mean",
        "train_mape_std",
        "test_mape_mean",
        "test_mape_std",
        "train_r2_mean",
        "train_r2_std",
        "test_r2_mean",
        "test_r2_std",
    ],
    [
        train_rmse_mean,
        train_rmse_std,
        test_rmse_mean,
        test_rmse_std,
        train_mae_mean,
        train_mae_std,
        test_mae_mean,
        test_mae_std,
        train_mape_mean,
        train_mape_std,
        test_mape_mean,
        test_mape_std,
        train_r2_mean,
        train_r2_std,
        test_r2_mean,
        test_r2_std,
    ],
):
    print(f"{x} = {y}")
# Out:
# train_rmse_mean = []
# train_rmse_std = []
# test_rmse_mean = []
# test_rmse_std = []
# train_mae_mean = []
# train_mae_std = []
# test_mae_mean = []
# test_mae_std = []
# train_mape_mean = []
# train_mape_std = []
# test_mape_mean = []
# test_mape_std = []
# train_r2_mean = []
# train_r2_std = []
# test_r2_mean = []
# test_r2_std = []
