# %%
# %load_ext nb_black

# %%
import pandas as pd
import numpy as np
import re

# %%
def flat_list(lst):
    return [item for tup in list(lst) for item in tup]

# %%
def extract_scores(s):
    pattern = r"\b([A-Z0-9]+):\s+([\d.]+)\s+\(([\d.]+)\)"
    scores = {"Train Mean": [], "Train Std": [], "Test Mean": [], "Test Std": []}
    current_scores = None
    for line in s.split("\n"):
        if "[TRAIN]" in line:
            current_scores = "Train"
        elif "[TEST]" in line:
            current_scores = "Test"
        match = re.search(pattern, line)
        if match:
            score_name = match.group(1)
            score_mean = float(match.group(2))
            score_std = float(match.group(3))
            scores[f"{current_scores} Mean"].append(score_mean)
            scores[f"{current_scores} Std"].append(score_std)
    return scores

# %% [markdown]
# # All Cements

# %%
results = []

# %% [markdown]
# ## No previous Compressive Strength

# %% [markdown]
# ## Repeated KFold Cross validation

# %%
data = {
    "Metric": ["RMSE", "MAE", "MAPE", "R2"],
    "Train Mean": [],
    "Train Std": [],
    "Test Mean": [],
    "Test Std": [],
    "Validation": ["Repeated KFold"] * 4,
    "Repeats": [10] * 4,
    "Splits": [10] * 4,
}
df = pd.DataFrame(data)
df = df[
    [
        "Validation",
        "Repeats",
        "Splits",
        "Metric",
        "Train Mean",
        "Train Std",
        "Test Mean",
        "Test Std",
    ]
]
results.append(df)

# %% [markdown]
# ## Blocking Time Series Split Results

# %%
df = [
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 10,
        "Splits": 5,
        "Metric": "RMSE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 10,
        "Splits": 5,
        "Metric": "MAE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 10,
        "Splits": 5,
        "Metric": "MAPE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 10,
        "Splits": 5,
        "Metric": "R2",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
]
df = pd.DataFrame(df)
results.append(df)

# %% [markdown]
# ## Time Series Split Cross Validation

# %%
# define dictionary with results
tss_results = {
    "Validation": "Time Series Split Cross Validation",
    "Repeats": 10,
    "Splits": 10,
    "RMSE Train Mean": ,
    "RMSE Train Std": ,
    "MAE Train Mean": ,
    "MAE Train Std": ,
    "MAPE Train Mean": ,
    "MAPE Train Std": ,
    "R2 Train Mean": ,
    "R2 Train Std": ,
    "RMSE Test Mean": ,
    "RMSE Test Std": ,
    "MAE Test Mean": ,
    "MAE Test Std": ,
    "MAPE Test Mean": ,
    "MAPE Test Std": ,
    "R2 Test Mean": ,
    "R2 Test Std": ,
}

# create dataframe
df = pd.DataFrame(
    columns=[
        "Validation",
        "Repeats",
        "Splits",
        "Metric",
        "Train Mean",
        "Train Std",
        "Test Mean",
        "Test Std",
    ]
)

# populate dataframe
for i, metric in enumerate(["RMSE", "MAE", "MAPE", "R2"]):
    df.loc[i * 4] = [
        tss_results["Validation"],
        tss_results["Repeats"],
        tss_results["Splits"],
        metric,
        tss_results[f"{metric} Train Mean"],
        tss_results[f"{metric} Train Std"],
        tss_results[f"{metric} Test Mean"],
        tss_results[f"{metric} Test Std"],
    ]
results.append(df)

# %% [markdown]
# ## Blocking Time Series Split Results - Period Specific

# %%
s = """
******
[TRAIN]
******
RMSE: 0.719 (0.090)
MAE: 0.559 (0.070)
MAPE: 0.013 (0.002)
R2: 0.980 (0.004)

======================

******
[TEST]
******
RMSE: 0.905 (0.162)
MAE: 0.675 (0.123)
MAPE: 0.016 (0.003)
R2: 0.965 (0.013)

======================

******
[TRAIN]
******
RMSE: 0.809 (0.163)
MAE: 0.634 (0.125)
MAPE: 0.015 (0.003)
R2: 0.974 (0.008)

======================

******
[TEST]
******
RMSE: 1.030 (0.183)
MAE: 0.753 (0.173)
MAPE: 0.017 (0.004)
R2: 0.956 (0.012)

======================

******
[TRAIN]
******
RMSE: 0.835 (0.139)
MAE: 0.653 (0.116)
MAPE: 0.015 (0.003)
R2: 0.972 (0.008)

======================

******
[TEST]
******
RMSE: 1.045 (0.202)
MAE: 0.859 (0.173)
MAPE: 0.020 (0.005)
R2: 0.958 (0.012)

======================

******
[TRAIN]
******
RMSE: 0.772 (0.004)
MAE: 0.594 (0.000)
MAPE: 0.014 (0.000)
R2: 0.976 (0.001)

======================

******
[TEST]
******
RMSE: 1.026 (0.233)
MAE: 0.730 (0.203)
MAPE: 0.017 (0.004)
R2: 0.961 (0.013)

======================

******
[TRAIN]
******
RMSE: 0.820 (0.048)
MAE: 0.634 (0.046)
MAPE: 0.015 (0.001)
R2: 0.973 (0.002)

======================

******
[TEST]
******
RMSE: 0.932 (0.274)
MAE: 0.775 (0.263)
MAPE: 0.017 (0.006)
R2: 0.966 (0.015)

======================

******
[TRAIN]
******
RMSE: 0.799 (0.000)
MAE: 0.617 (0.000)
MAPE: 0.014 (0.000)
R2: 0.974 (0.000)

======================

******
[TEST]
******
RMSE: 1.384 (0.000)
MAE: 1.093 (0.000)
MAPE: 0.025 (0.000)
R2: 0.932 (0.000)

======================

******
[TRAIN]
******
RMSE: 0.799 (0.000)
MAE: 0.617 (0.000)
MAPE: 0.014 (0.000)
R2: 0.974 (0.000)

======================

******
[TEST]
******
RMSE: 1.353 (0.000)
MAE: 1.074 (0.000)
MAPE: 0.025 (0.000)
R2: 0.939 (0.000)

======================

******
[TRAIN]
******
RMSE: 0.799 (0.000)
MAE: 0.617 (0.000)
MAPE: 0.014 (0.000)
R2: 0.974 (0.000)

======================

******
[TEST]
******
RMSE: 1.567 (0.000)
MAE: 1.199 (0.000)
MAPE: 0.027 (0.000)
R2: 0.913 (0.000)

======================
"""

# %%
## Define the train and test periods for each row
periods = [
    ["6 months", "One Month"],
    ["11 months", "One Month"],
    ["1 year", "One Month"],
    ["1 year and one month", "One Month"],
    ["1 year and two months", "One Month"],
    ["2 years", "One Month"],
    ["2 years", "Two Months"],
    ["2 years", "One Year"],
    # ["2 years, 8 months and 15 days", "8 months and 6 days"],
]

# Extract the relevant information and store it in a dictionary
data = {
    "Validation": ["Blocking Time Series - Period Specific"] * 32,
    "Repeats": [10] * 32,
    "Splits": [np.nan] * 32,
    "Metric": ["RMSE", "MAE", "MAPE", "R2"] * 8,
    "Train Mean": [],
    "Train Std": [],
    "Test Mean": [],
    "Test Std": [],
    "Train Period": [
        item for sublist in [[result[0]] * 4 for result in periods] for item in sublist
    ],
    "Test Period": [
        item for sublist in [[result[1]] * 4 for result in periods] for item in sublist
    ],
}


scores = extract_scores(s)


data["Train Mean"] = scores["Train Mean"]
data["Train Std"] = scores["Train Std"]
data["Test Mean"] = scores["Test Mean"]
data["Test Std"] = scores["Test Std"]


df = pd.DataFrame(data)

# %%
idx = df[df["Metric"] == "RMSE"]["Test Mean"].idxmin()
df.iloc[idx : idx + 4]
# Out:
#                                Validation  Repeats  Splits Metric  Train Mean  \
# 0  Blocking Time Series - Period Specific       10     NaN   RMSE       0.719
# 1  Blocking Time Series - Period Specific       10     NaN    MAE       0.559
# 2  Blocking Time Series - Period Specific       10     NaN   MAPE       0.013
# 3  Blocking Time Series - Period Specific       10     NaN     R2       0.980
#
#    Train Std  Test Mean  Test Std Train Period Test Period
# 0      0.090      0.905     0.162     6 months   One Month
# 1      0.070      0.675     0.123     6 months   One Month
# 2      0.002      0.016     0.003     6 months   One Month
# 3      0.004      0.965     0.013     6 months   One Month

# %%
df = df.set_index(["Train Period", "Test Period"])

df[
    (
        df[df["Metric"] == "RMSE"]
        == df[df["Metric"] == "RMSE"][["Test Mean"]].min().values[0]
    )["Test Mean"]
]
# Out:
# /home/felipe/Documents/ccs28-venv/lib/python3.6/site-packages/ipykernel_launcher.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   import sys
#                                                       Validation  Repeats  \
# Train Period Test Period
# 6 months     One Month    Blocking Time Series - Period Specific       10
#              One Month    Blocking Time Series - Period Specific       10
#              One Month    Blocking Time Series - Period Specific       10
#              One Month    Blocking Time Series - Period Specific       10
#
#                           Splits Metric  Train Mean  Train Std  Test Mean  \
# Train Period Test Period
# 6 months     One Month       NaN   RMSE       0.719      0.090      0.905
#              One Month       NaN    MAE       0.559      0.070      0.675
#              One Month       NaN   MAPE       0.013      0.002      0.016
#              One Month       NaN     R2       0.980      0.004      0.965
#
#                           Test Std
# Train Period Test Period
# 6 months     One Month       0.162
#              One Month       0.123
#              One Month       0.003
#              One Month       0.013
