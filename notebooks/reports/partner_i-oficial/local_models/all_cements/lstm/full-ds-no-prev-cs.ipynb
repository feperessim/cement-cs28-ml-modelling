# %%
# %load_ext nb_black

# %%
import pandas as pd
import numpy as np

# %%
def flat_list(lst):
    return [item for tup in list(lst) for item in tup]

# %%
def extract_numbers(text):
    values = []
    for line in text.split("\n"):
        line = line.strip()
        if line.startswith("RMSE:"):
            parts = line.split(" ")
            values.append(float(parts[1]))
            values.append(float(parts[2].lstrip("(").rstrip(")")))
        elif line.startswith("MAE:"):
            parts = line.split(" ")
            values.append(float(parts[1]))
            values.append(float(parts[2].lstrip("(").rstrip(")")))
        elif line.startswith("MAPE:"):
            parts = line.split(" ")
            values.append(float(parts[1]))
            values.append(float(parts[2].lstrip("(").rstrip(")")))
        elif line.startswith("R2:"):
            parts = line.split(" ")
            values.append(float(parts[1]))
            values.append(float(parts[2].lstrip("(").rstrip(")")))
    return values

# %%
def extract_and_fill_lists(text, train_rmse_mean, train_rmse_std, test_rmse_mean, test_rmse_std,
                           train_mae_mean, train_mae_std, test_mae_mean, test_mae_std,
                           train_mape_mean, train_mape_std, test_mape_mean, test_mape_std,
                           train_r2_mean, train_r2_std, test_r2_mean, test_r2_std):

    train_flag = False
    test_flag = False
    timesteps_flag = False

    for line in text.split("\n"):
        line = line.strip()

        if line.startswith("TIMESTEPS:"):
            timesteps_flag = True

        elif line.startswith("[TRAIN]"):
            train_flag = True
            test_flag = False

        elif line.startswith("[TEST]"):
            train_flag = False
            test_flag = True

        elif line.startswith("RMSE:"):
            parts = line.split(" ")
            if train_flag:
                train_rmse_mean.append(float(parts[1]))
                train_rmse_std.append(float(parts[2].lstrip("(").rstrip(")")))
            elif test_flag:
                test_rmse_mean.append(float(parts[1]))
                test_rmse_std.append(float(parts[2].lstrip("(").rstrip(")")))

        elif line.startswith("MAE:"):
            parts = line.split(" ")
            if train_flag:
                train_mae_mean.append(float(parts[1]))
                train_mae_std.append(float(parts[2].lstrip("(").rstrip(")")))
            elif test_flag:
                test_mae_mean.append(float(parts[1]))
                test_mae_std.append(float(parts[2].lstrip("(").rstrip(")")))

        elif line.startswith("MAPE:"):
            parts = line.split(" ")
            if train_flag:
                train_mape_mean.append(float(parts[1]))
                train_mape_std.append(float(parts[2].lstrip("(").rstrip(")")))
            elif test_flag:
                test_mape_mean.append(float(parts[1]))
                test_mape_std.append(float(parts[2].lstrip("(").rstrip(")")))

        elif line.startswith("R2:"):
            parts = line.split(" ")
            if train_flag:
                train_r2_mean.append(float(parts[1]))
                train_r2_std.append(float(parts[2].lstrip("(").rstrip(")")))
            elif test_flag:
                test_r2_mean.append(float(parts[1]))
                test_r2_std.append(float(parts[2].lstrip("(").rstrip(")")))

        elif line.startswith("="):
            train_flag = False
            test_flag = False
            timesteps_flag = False

        else:
            continue

# %% [markdown]
# # All Cements

# %%
results = []

# %% [markdown]
# ## No previous Compressive Strength

# %% [markdown]
# ## Repeated KFold Cross validation

# %%
data = {
    "Time Steps": sorted([1, 3, 5, 7, 14, 21] * 4),
    "Metric": ["RMSE", "MAE", "MAPE", "R2"] * 6,
    "Train Mean": [],
    "Train Std": [],
    "Test Mean": [],
    "Test Std": [],
    "Validation": ["Repeated KFold"] * 4 * 6,
    "Repeats": [10] * 4 * 6,
    "Splits": [10] * 4 * 6,
}


# For TIMESTEPS: 1
data["Train Mean"].extend([1.345, 0.986, 0.023, 0.923])
data["Train Std"].extend([0.373, 0.075, 0.002, 0.075])
data["Test Mean"].extend([1.406, 1.031, 0.024, 0.920])
data["Test Std"].extend([0.188, 0.096, 0.002, 0.025])

# For TIMESTEPS: 3
data["Train Mean"].extend([1.223, 0.953, 0.022, 0.941])
data["Train Std"].extend([0.109, 0.078, 0.002, 0.011])
data["Test Mean"].extend([1.536, 1.108, 0.026, 0.904])
data["Test Std"].extend([0.256, 0.093, 0.002, 0.038])

# For TIMESTEPS: 5
data["Train Mean"].extend([1.424, 1.174, 0.027, 0.918])
data["Train Std"].extend([0.234, 0.230, 0.005, 0.029])
data["Test Mean"].extend([1.660, 1.316, 0.031, 0.885])
data["Test Std"].extend([0.336, 0.243, 0.006, 0.063])

# For TIMESTEPS: 7
data["Train Mean"].extend([1.443, 1.175, 0.027, 0.915])
data["Train Std"].extend([0.295, 0.281, 0.007, 0.037])
data["Test Mean"].extend([1.626, 1.299, 0.030, 0.892])
data["Test Std"].extend([0.290, 0.270, 0.006, 0.039])

# For TIMESTEPS: 14
data["Train Mean"].extend([1.499, 1.208, 0.028, 0.909])
data["Train Std"].extend([0.267, 0.263, 0.006, 0.032])
data["Test Mean"].extend([1.657, 1.302, 0.030, 0.889])
data["Test Std"].extend([0.281, 0.265, 0.006, 0.039])


# For TIMESTEPS: 21
data["Train Mean"].extend([1.511, 1.273, 0.030, 0.903])
data["Train Std"].extend([0.441, 0.432, 0.010, 0.061])
data["Test Mean"].extend([1.663, 1.387, 0.032, 0.883])
data["Test Std"].extend([0.429, 0.428, 0.010, 0.065])

df = pd.DataFrame(data)
df = df[
    [
        "Validation",
        "Repeats",
        "Splits",
        "Time Steps",
        "Metric",
        "Train Mean",
        "Train Std",
        "Test Mean",
        "Test Std",
    ]
]
df
results.append(df)

# %% [markdown]
# ## Blocking Time Series Split Results

# %%
df = [
    # Timesteps = 1
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 1,
        "Metric": "RMSE",
        "Train Mean": 5.622,
        "Train Std": 2.329,
        "Test Mean": 135.200,
        "Test Std": 222.705,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 1,
        "Metric": "MAE",
        "Train Mean": 4.352,
        "Train Std": 1.918,
        "Test Mean": 22.215,
        "Test Std": 18.787,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 1,
        "Metric": "MAPE",
        "Train Mean": 0.102,
        "Train Std": 0.045,
        "Test Mean": 0.496,
        "Test Std": 0.397,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 1,
        "Metric": "R2",
        "Train Mean": 0.452,
        "Train Std": 1.089,
        "Test Mean": 2860.594,
        "Test Std": 6325.873,
    },
    # Timesteps = 3
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 3,
        "Metric": "RMSE",
        "Train Mean": 1.414,
        "Train Std": 0.186,
        "Test Mean": 49.054,
        "Test Std": 72.044,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 3,
        "Metric": "MAE",
        "Train Mean": 1.100,
        "Train Std": 0.146,
        "Test Mean": 28.691,
        "Test Std": 57.843,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 3,
        "Metric": "MAPE",
        "Train Mean": 0.025,
        "Train Std": 0.004,
        "Test Mean": 0.670,
        "Test Std": 1.353,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 3,
        "Metric": "R2",
        "Train Mean": 0.920,
        "Train Std": 0.023,
        "Test Mean": 313.717,
        "Test Std": 924.850,
    },
    # Timesteps = 5
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 5,
        "Metric": "RMSE",
        "Train Mean": 1.298,
        "Train Std": 0.258,
        "Test Mean": 90.524,
        "Test Std": 172.998,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 5,
        "Metric": "MAE",
        "Train Mean": 1.030,
        "Train Std": 0.214,
        "Test Mean": 61.525,
        "Test Std": 138.173,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 5,
        "Metric": "MAPE",
        "Train Mean": 0.024,
        "Train Std": 0.005,
        "Test Mean": 1.435,
        "Test Std": 3.225,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 5,
        "Metric": "R2",
        "Train Mean": 0.932,
        "Train Std": 0.029,
        "Test Mean": 1596.366,
        "Test Std": 4997.763,
    },
    # Timesteps = 7
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 7,
        "Metric": "RMSE",
        "Train Mean": 1.302,
        "Train Std": 0.232,
        "Test Mean": 106.920,
        "Test Std": 218.871,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 7,
        "Metric": "MAE",
        "Train Mean": 1.029,
        "Train Std": 0.186,
        "Test Mean": 75.467,
        "Test Std": 175.475,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 7,
        "Metric": "MAPE",
        "Train Mean": 0.024,
        "Train Std": 0.004,
        "Test Mean": 1.750,
        "Test Std": 4.069,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 7,
        "Metric": "R2",
        "Train Mean": 0.933,
        "Train Std": 0.023,
        "Test Mean": 2551.972,
        "Test Std": 7127.205,
    },
    # Timesteps = 14
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 14,
        "Metric": "RMSE",
        "Train Mean": 1.849,
        "Train Std": 0.628,
        "Test Mean": 183.109,
        "Test Std": 456.580,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 14,
        "Metric": "MAE",
        "Train Mean": 1.572,
        "Train Std": 0.598,
        "Test Mean": 132.358,
        "Test Std": 369.590,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 14,
        "Metric": "MAPE",
        "Train Mean": 0.036,
        "Train Std": 0.013,
        "Test Mean": 3.072,
        "Test Std": 8.567,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 14,
        "Metric": "R2",
        "Train Mean": 0.853,
        "Train Std": 0.115,
        "Test Mean": 10085.005,
        "Test Std": 38976.923,
    },
    # Timesteps = 21
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 21,
        "Metric": "RMSE",
        "Train Mean": 1.723,
        "Train Std": 0.472,
        "Test Mean": 229.552,
        "Test Std": 552.812,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 21,
        "Metric": "MAE",
        "Train Mean": 1.377,
        "Train Std": 0.386,
        "Test Mean": 173.411,
        "Test Std": 444.873,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 21,
        "Metric": "MAPE",
        "Train Mean": 0.032,
        "Train Std": 0.008,
        "Test Mean": 4.011,
        "Test Std": 10.287,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 21,
        "Metric": "R2",
        "Train Mean": 0.877,
        "Train Std": 0.070,
        "Test Mean": 14688.658,
        "Test Std": 50442.995,
    },
]

df = pd.DataFrame(df)
results.append(df)

# %% [markdown]
# ## Time Series Split Cross Validation

# %%
df = [
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 10,
        "Time Steps": 1,
        "Metric": "RMSE",
        "Train Mean": 2.557,
        "Train Std": 1.972,
        "Test Mean": 361.080,
        "Test Std": 742.269,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 10,
        "Time Steps": 1,
        "Metric": "MAE",
        "Train Mean": 1.888,
        "Train Std": 1.500,
        "Test Mean": 44.122,
        "Test Std": 84.564,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 10,
        "Time Steps": 1,
        "Metric": "MAPE",
        "Train Mean": 0.044,
        "Train Std": 0.035,
        "Test Mean": 0.976,
        "Test Std": 1.867,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 10,
        "Time Steps": 1,
        "Metric": "R2",
        "Train Mean": 0.563,
        "Train Std": 0.720,
        "Test Mean": 28623.226,
        "Test Std": 64474.619,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 10,
        "Time Steps": 3,
        "Metric": "RMSE",
        "Train Mean": 1.264,
        "Train Std": 0.186,
        "Test Mean": 165.181,
        "Test Std": 468.124,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 10,
        "Time Steps": 3,
        "Metric": "MAE",
        "Train Mean": 0.960,
        "Train Std": 0.126,
        "Test Mean": 34.048,
        "Test Std": 83.337,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 10,
        "Time Steps": 3,
        "Metric": "MAPE",
        "Train Mean": 0.022,
        "Train Std": 0.003,
        "Test Mean": 0.764,
        "Test Std": 1.847,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 10,
        "Time Steps": 3,
        "Metric": "R2",
        "Train Mean": 0.933,
        "Train Std": 0.022,
        "Test Mean": 9988.491,
        "Test Std": 35946.648,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 5,
        "Metric": "RMSE",
        "Train Mean": 1.372,
        "Train Std": 0.307,
        "Test Mean": 235.217,
        "Test Std": 644.322,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 5,
        "Metric": "MAE",
        "Train Mean": 1.093,
        "Train Std": 0.268,
        "Test Mean": 59.532,
        "Test Std": 147.689,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 5,
        "Metric": "MAPE",
        "Train Mean": 0.025,
        "Train Std": 0.006,
        "Test Mean": 1.343,
        "Test Std": 3.305,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 5,
        "Metric": "R2",
        "Train Mean": 0.919,
        "Train Std": 0.041,
        "Test Mean": 18972.646,
        "Test Std": 60413.474,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 7,
        "Metric": "RMSE",
        "Train Mean": 1.401,
        "Train Std": 0.329,
        "Test Mean": 200.999,
        "Test Std": 557.686,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 7,
        "Metric": "MAE",
        "Train Mean": 1.123,
        "Train Std": 0.288,
        "Test Mean": 62.435,
        "Test Std": 156.124,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 7,
        "Metric": "MAPE",
        "Train Mean": 0.026,
        "Train Std": 0.007,
        "Test Mean": 1.402,
        "Test Std": 3.478,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 7,
        "Metric": "R2",
        "Train Mean": 0.915,
        "Train Std": 0.043,
        "Test Mean": 14193.046,
        "Test Std": 50579.566,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 14,
        "Metric": "RMSE",
        "Train Mean": 1.517,
        "Train Std": 0.369,
        "Test Mean": 46.429,
        "Test Std": 178.434,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 14,
        "Metric": "MAE",
        "Train Mean": 1.244,
        "Train Std": 0.368,
        "Test Mean": 26.840,
        "Test Std": 109.175,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 14,
        "Metric": "MAPE",
        "Train Mean": 0.029,
        "Train Std": 0.008,
        "Test Mean": 0.623,
        "Test Std": 2.526,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 14,
        "Metric": "R2",
        "Train Mean": 0.901,
        "Train Std": 0.051,
        "Test Mean": 1412.837,
        "Test Std": 8939.534,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 21,
        "Metric": "RMSE",
        "Train Mean": 1.389,
        "Train Std": 0.353,
        "Test Mean": 56.929,
        "Test Std": 237.800,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 21,
        "Metric": "MAE",
        "Train Mean": 1.123,
        "Train Std": 0.324,
        "Test Mean": 34.833,
        "Test Std": 154.084,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 21,
        "Metric": "MAPE",
        "Train Mean": 0.026,
        "Train Std": 0.007,
        "Test Mean": 0.799,
        "Test Std": 3.521,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 21,
        "Metric": "R2",
        "Train Mean": 0.917,
        "Train Std": 0.046,
        "Test Mean": 2576.243,
        "Test Std": 16384.944,
    },
]

df = pd.DataFrame(df)
results.append(df)

# %% [markdown]
# ## Blocking Time Series Split Results - Period Specific

# %%
# Define the train and test periods for each row
periods = [
    ["6 months", "One Month"],
    ["11 months", "One Month"],
    ["1 year", "One Month"],
    ["1 year and one month", "One Month"],
    ["1 year and two months", "One Month"],
    ["2 years", "One Month"],
    ["2 years", "Two Months"],
    ["2 years", "One Year"],
    ["2 years, 8 months and 15 days", "8 months and 6 days"],
]

train_mean = []
test_mean = []

train_std = []
test_std = []

###########################
# 6 months", "One Month"  #
###########################
train_rmse_mean = [4.537, 1.227, 1.168, 1.206, 1.412, 1.553]
train_mae_mean = [3.395, 0.962, 0.922, 0.957, 1.134, 1.260]
train_mape_mean = [0.080, 0.022, 0.021, 0.022, 0.026, 0.029]
train_r2_mean = [0.016, 0.939, 0.946, 0.941, 0.918, 0.901]

test_rmse_mean = [29.129, 28.099, 56.254, 93.636, 138.623, 26.821]
test_mae_mean = [11.285, 13.354, 31.618, 50.129, 66.542, 10.584]
test_mape_mean = [0.272, 0.308, 0.719, 1.174, 1.765, 0.243]
test_r2_mean = [109.238, 142.680, 1040.942, 1642.733, 3257.072, 152.221]

train_rmse_std = [2.051, 0.135, 0.143, 0.181, 0.315, 0.378]
train_mae_std = [1.550, 0.090, 0.110, 0.132, 0.272, 0.344]
train_mape_std = [0.037, 0.002, 0.002, 0.003, 0.006, 0.008]
train_r2_std = [0.742, 0.015, 0.015, 0.021, 0.038, 0.049]

test_rmse_std = [42.514, 52.131, 143.278, 174.361, 286.556, 52.124]
test_mae_std = [11.937, 23.192, 76.192, 106.963, 134.083, 16.988]
test_mape_std = [0.294, 0.522, 1.727, 2.446, 3.587, 0.387]
test_r2_std = [211.015, 440.659, 3746.992, 4848.541, 8151.641, 428.035]

train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

###########################
# 11 months", "One Month  #
###########################
train_rmse_mean = [2.124, 1.136, 1.199, 1.247, 1.285, 1.367]
train_rmse_std = [0.590, 0.102, 0.188, 0.260, 0.154, 0.259]
test_rmse_mean = [21.999, 15.556, 11.220, 11.287, 3.105, 4.075]
test_rmse_std = [23.747, 20.007, 12.603, 13.361, 2.198, 2.969]

train_mae_mean = [1.566, 0.876, 0.937, 0.998, 1.021, 1.085]
train_mae_std = [0.424, 0.080, 0.132, 0.217, 0.136, 0.202]
test_mae_mean = [6.051, 5.039, 4.690, 5.441, 2.192, 2.619]
test_mae_std = [3.846, 4.481, 3.999, 5.481, 1.023, 1.382]

train_mape_mean = [0.036, 0.020, 0.022, 0.023, 0.023, 0.025]
train_mape_std = [0.010, 0.002, 0.003, 0.005, 0.003, 0.005]
test_mape_mean = [0.133, 0.110, 0.102, 0.117, 0.050, 0.061]
test_mape_std = [0.081, 0.095, 0.084, 0.116, 0.022, 0.032]

train_r2_mean = [0.805, 0.949, 0.942, 0.937, 0.934, 0.925]
train_r2_std = [0.121, 0.009, 0.020, 0.027, 0.017, 0.028]
test_r2_mean = [47.922, 26.840, 10.466, 10.724, 0.462, 0.035]
test_r2_std = [71.556, 54.115, 18.640, 18.512, 0.925, 1.396]


train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

###########################
# "1 year", "One Month"   #
###########################
train_rmse_mean = [1.938, 1.383, 1.252, 1.428, 1.357, 1.376]
train_rmse_std = [0.627, 0.208, 0.248, 0.253, 0.242, 0.316]
test_rmse_mean = [2.321, 1.731, 1.767, 2.183, 39.315, 8.17]
test_rmse_std = [0.788, 0.185, 0.23, 0.873, 87.029, 7.246]
train_mae_mean = [1.446, 1.119, 1.002, 1.166, 1.096, 1.1]
train_mae_std = [0.451, 0.196, 0.241, 0.253, 0.219, 0.276]
test_mae_mean = [1.881, 1.38, 1.362, 1.812, 18.596, 6.458]
test_mae_std = [0.613, 0.177, 0.195, 0.851, 36.323, 5.604]
train_mape_mean = [0.033, 0.026, 0.023, 0.027, 0.025, 0.026]
train_mape_std = [0.01, 0.005, 0.006, 0.006, 0.005, 0.007]
test_mape_mean = [0.045, 0.033, 0.032, 0.043, 0.411, 0.148]
test_mape_std = [0.014, 0.003, 0.004, 0.02, 0.792, 0.128]
train_r2_mean = [0.832, 0.923, 0.936, 0.917, 0.925, 0.92]
train_r2_std = [0.116, 0.022, 0.027, 0.031, 0.027, 0.036]
test_r2_mean = [0.762, 0.885, 0.873, 0.774, 391.876, 4.196]
test_r2_std = [0.182, 0.04, 0.05, 0.239, 1191.83, 6.403]

train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

#########################################
# "1 year and one month", "One Month"   #
#########################################
train_rmse_mean = [2.142, 1.224, 1.199, 1.231, 1.745, 1.309]
train_rmse_std = [0.61, 0.227, 0.087, 0.229, 0.544, 0.305]
test_rmse_mean = [7.159, 62.378, 105.127, 127.72, 4.976, 1.819]
test_rmse_std = [6.809, 86.264, 155.507, 204.637, 5.398, 0.308]
train_mae_mean = [1.544, 0.9, 0.917, 0.994, 1.49, 1.063]
train_mae_std = [0.349, 0.121, 0.063, 0.221, 0.541, 0.291]
test_mae_mean = [4.502, 36.288, 67.996, 93.141, 4.301, 1.483]
test_mae_std = [3.762, 48.51, 98.234, 146.275, 4.786, 0.292]
train_mape_mean = [0.036, 0.021, 0.021, 0.023, 0.035, 0.025]
train_mape_std = [0.008, 0.003, 0.002, 0.005, 0.012, 0.007]
test_mape_mean = [0.104, 0.846, 1.542, 2.15, 0.098, 0.035]
test_mape_std = [0.088, 1.136, 2.226, 3.378, 0.11, 0.007]
train_r2_mean = [0.796, 0.938, 0.942, 0.937, 0.866, 0.929]
train_r2_std = [0.127, 0.023, 0.008, 0.027, 0.089, 0.041]
test_r2_mean = [2.962, 488.833, 1581.927, 2323.569, 1.433, 0.863]
test_r2_std = [6.432, 812.326, 2889.133, 4976.606, 5.268, 0.056]

train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

##########################################
# "1 year and two months", "One Month"   #
#########################################
train_rmse_mean = [2.102, 1.2, 1.291, 1.298, 1.422, 1.351]
train_rmse_std = [0.569, 0.103, 0.149, 0.261, 0.383, 0.182]
test_rmse_mean = [3.793, 2.884, 2.548, 3.266, 2.557, 2.244]
test_rmse_std = [1.451, 1.339, 0.625, 1.433, 0.796, 0.544]
train_mae_mean = [1.517, 0.937, 1.046, 1.022, 1.167, 1.097]
train_mae_std = [0.295, 0.093, 0.152, 0.216, 0.388, 0.17]
test_mae_mean = [2.933, 2.318, 1.865, 2.09, 2.107, 1.821]
test_mae_std = [0.909, 0.955, 0.33, 0.64, 0.559, 0.535]
train_mape_mean = [0.035, 0.022, 0.024, 0.024, 0.027, 0.025]
train_mape_std = [0.007, 0.002, 0.003, 0.005, 0.009, 0.004]
test_mape_mean = [0.066, 0.053, 0.042, 0.048, 0.049, 0.042]
test_mape_std = [0.021, 0.022, 0.008, 0.015, 0.013, 0.012]
train_r2_mean = [0.808, 0.943, 0.933, 0.931, 0.914, 0.927]
train_r2_std = [0.115, 0.011, 0.017, 0.033, 0.058, 0.022]
test_r2_mean = [0.307, 0.544, 0.708, 0.445, 0.68, 0.791]
test_r2_std = [0.526, 0.455, 0.159, 0.552, 0.236, 0.091]

train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

############################
# "2 years", "One Month"   #
############################
train_rmse_mean = [1.266, 1.064, 1.14, 1.05, 1.373, 1.194]
train_rmse_std = [0.08, 0.036, 0.055, 0.045, 0.344, 0.103]
test_rmse_mean = [1.446, 1.547, 1.487, 1.285, 1.645, 1.305]
test_rmse_std = [0.096, 0.124, 0.165, 0.14, 0.251, 0.201]
train_mae_mean = [0.93, 0.838, 0.881, 0.839, 1.109, 0.93]
train_mae_std = [0.038, 0.025, 0.057, 0.034, 0.299, 0.074]
test_mae_mean = [1.155, 1.256, 1.182, 0.995, 1.306, 0.98]
test_mae_std = [0.096, 0.083, 0.152, 0.086, 0.256, 0.158]
train_mape_mean = [0.022, 0.02, 0.02, 0.02, 0.026, 0.022]
train_mape_std = [0.001, 0.001, 0.001, 0.001, 0.007, 0.002]
test_mape_mean = [0.026, 0.029, 0.027, 0.023, 0.033, 0.023]
test_mape_std = [0.002, 0.002, 0.003, 0.002, 0.006, 0.003]
train_r2_mean = [0.933, 0.953, 0.946, 0.954, 0.918, 0.942]
train_r2_std = [0.009, 0.003, 0.005, 0.004, 0.041, 0.01]
test_r2_mean = [0.926, 0.918, 0.917, 0.942, 0.915, 0.937]
test_r2_std = [0.01, 0.013, 0.019, 0.012, 0.025, 0.019]


train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

############################
# "2 years", "Two Months"  #
############################
train_rmse_mean = [1.266, 1.064, 1.14, 1.05, 1.373, 1.194]
train_rmse_std = [0.08, 0.036, 0.055, 0.045, 0.344, 0.103]
test_rmse_mean = [1.622, 1.589, 1.586, 1.304, 1.595, 1.456]
test_rmse_std = [0.082, 0.092, 0.11, 0.121, 0.226, 0.107]
train_mae_mean = [0.93, 0.838, 0.881, 0.839, 1.109, 0.93]
train_mae_std = [0.038, 0.025, 0.057, 0.034, 0.299, 0.074]
test_mae_mean = [1.322, 1.285, 1.288, 1.046, 1.251, 1.108]
test_mae_std = [0.083, 0.054, 0.113, 0.099, 0.249, 0.084]
train_mape_mean = [0.022, 0.02, 0.02, 0.02, 0.026, 0.022]
train_mape_std = [0.001, 0.001, 0.001, 0.001, 0.007, 0.002]
test_mape_mean = [0.031, 0.03, 0.03, 0.024, 0.031, 0.025]
test_mape_std = [0.002, 0.001, 0.002, 0.002, 0.006, 0.002]
train_r2_mean = [0.933, 0.953, 0.946, 0.954, 0.918, 0.942]
train_r2_std = [0.009, 0.003, 0.005, 0.004, 0.041, 0.01]
test_r2_mean = [0.912, 0.92, 0.917, 0.944, 0.914, 0.927]
test_r2_std = [0.009, 0.009, 0.012, 0.011, 0.024, 0.01]

train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

##########################
# "2 years", "One Year"  #
##########################
train_rmse_mean = [1.266, 1.064, 1.14, 1.05, 1.373, 1.194]
train_rmse_std = [0.08, 0.036, 0.055, 0.045, 0.344, 0.103]
test_rmse_mean = [3.355, 3.137, 2.993, 2.593, 2.075, 2.717]
test_rmse_std = [0.944, 0.892, 0.604, 0.251, 0.211, 0.643]
train_mae_mean = [0.93, 0.838, 0.881, 0.839, 1.109, 0.93]
train_mae_std = [0.038, 0.025, 0.057, 0.034, 0.299, 0.074]
test_mae_mean = [2.191, 2.001, 2.071, 1.96, 1.596, 2.031]
test_mae_std = [0.169, 0.277, 0.163, 0.194, 0.169, 0.426]
train_mape_mean = [0.022, 0.02, 0.02, 0.02, 0.026, 0.022]
train_mape_std = [0.001, 0.001, 0.001, 0.001, 0.007, 0.002]
test_mape_mean = [0.049, 0.045, 0.046, 0.044, 0.036, 0.046]
test_mape_std = [0.004, 0.006, 0.004, 0.004, 0.003, 0.01]
train_r2_mean = [0.933, 0.953, 0.946, 0.954, 0.918, 0.942]
train_r2_std = [0.009, 0.003, 0.005, 0.004, 0.041, 0.01]
test_r2_mean = [0.572, 0.625, 0.669, 0.762, 0.845, 0.714]
test_r2_std = [0.269, 0.208, 0.146, 0.045, 0.031, 0.131]


train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

###########################################################
# "2 years, 8 months and 15 days", "8 months and 6 days"  #
###########################################################
train_rmse_mean = [1.225, 1.306, 1.155, 1.153, 1.129, 1.153]
train_rmse_std = [0.078, 0.077, 0.043, 0.037, 0.073, 0.083]
test_rmse_mean = [1.627, 1.74, 1.62, 1.564, 1.528, 1.505]
test_rmse_std = [0.122, 0.094, 0.074, 0.11, 0.13, 0.064]
train_mae_mean = [0.914, 1.073, 0.917, 0.92, 0.889, 0.914]
train_mae_std = [0.033, 0.068, 0.041, 0.049, 0.041, 0.061]
test_mae_mean = [1.199, 1.389, 1.299, 1.269, 1.216, 1.179]
test_mae_std = [0.067, 0.074, 0.075, 0.067, 0.105, 0.042]
train_mape_mean = [0.021, 0.025, 0.021, 0.021, 0.021, 0.021]
train_mape_std = [0.001, 0.002, 0.001, 0.001, 0.001, 0.002]
test_mape_mean = [0.027, 0.031, 0.029, 0.029, 0.028, 0.027]
test_mape_std = [0.001, 0.002, 0.002, 0.001, 0.002, 0.001]
train_r2_mean = [0.941, 0.933, 0.948, 0.948, 0.95, 0.948]
train_r2_std = [0.008, 0.008, 0.004, 0.003, 0.006, 0.008]
test_r2_mean = [0.892, 0.877, 0.893, 0.9, 0.905, 0.908]
test_r2_std = [0.016, 0.013, 0.01, 0.014, 0.016, 0.008]

train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))


# Extract the relevant information and store it in a dictionary
data = {
    "Validation": ["Blocking Time Series - Period Specific"] * 216,
    "Repeats": [5] * 216,
    "Splits": [np.nan] * 216,
    "Metric": ["RMSE", "MAE", "MAPE", "R2"] * len(periods) * 6,
    "Time Steps": sorted([1, 3, 5, 7, 14, 21] * 4 * 9),
    "Train Mean": train_mean,
    "Train Std": train_std,
    "Test Mean": test_mean,
    "Test Std": test_std,
    "Train Period": [
        item
        for sublist in [[result[0]] * 4 * 6 for result in periods]
        for item in sublist
    ],
    "Test Period": [
        item
        for sublist in [[result[1]] * 4 * 6 for result in periods]
        for item in sublist
    ],
}

df = pd.DataFrame(data)

# %%
idx = df[df["Metric"] == "RMSE"]["Test Mean"].idxmin()
df.iloc[idx : idx + 4]
# Out:
#                                  Validation  Repeats  Splits Metric  \
# 132  Blocking Time Series - Period Specific        5     NaN   RMSE
# 133  Blocking Time Series - Period Specific        5     NaN    MAE
# 134  Blocking Time Series - Period Specific        5     NaN   MAPE
# 135  Blocking Time Series - Period Specific        5     NaN     R2
#
#      Time Steps  Train Mean  Train Std  Test Mean  Test Std Train Period  \
# 132           7       1.050      0.045      1.285     0.140      2 years
# 133           7       0.839      0.034      0.995     0.086      2 years
# 134           7       0.020      0.001      0.023     0.002      2 years
# 135           7       0.954      0.004      0.942     0.012      2 years
#
#     Test Period
# 132   One Month
# 133   One Month
# 134   One Month
# 135   One Month

# %%
s = """

"""

# %%
train_rmse_mean, train_rmse_std, test_rmse_mean, test_rmse_std = [], [], [], []
train_mae_mean, train_mae_std, test_mae_mean, test_mae_std = [], [], [], []
train_mape_mean, train_mape_std, test_mape_mean, test_mape_std = [], [], [], []
train_r2_mean, train_r2_std, test_r2_mean, test_r2_std = [], [], [], []

extract_and_fill_lists(
    s,
    train_rmse_mean,
    train_rmse_std,
    test_rmse_mean,
    test_rmse_std,
    train_mae_mean,
    train_mae_std,
    test_mae_mean,
    test_mae_std,
    train_mape_mean,
    train_mape_std,
    test_mape_mean,
    test_mape_std,
    train_r2_mean,
    train_r2_std,
    test_r2_mean,
    test_r2_std,
)

for x, y in zip(
    [
        "train_rmse_mean",
        "train_rmse_std",
        "test_rmse_mean",
        "test_rmse_std",
        "train_mae_mean",
        "train_mae_std",
        "test_mae_mean",
        "test_mae_std",
        "train_mape_mean",
        "train_mape_std",
        "test_mape_mean",
        "test_mape_std",
        "train_r2_mean",
        "train_r2_std",
        "test_r2_mean",
        "test_r2_std",
    ],
    [
        train_rmse_mean,
        train_rmse_std,
        test_rmse_mean,
        test_rmse_std,
        train_mae_mean,
        train_mae_std,
        test_mae_mean,
        test_mae_std,
        train_mape_mean,
        train_mape_std,
        test_mape_mean,
        test_mape_std,
        train_r2_mean,
        train_r2_std,
        test_r2_mean,
        test_r2_std,
    ],
):
    print(f"{x} = {y}")
# Out:
# train_rmse_mean = []
# train_rmse_std = []
# test_rmse_mean = []
# test_rmse_std = []
# train_mae_mean = []
# train_mae_std = []
# test_mae_mean = []
# test_mae_std = []
# train_mape_mean = []
# train_mape_std = []
# test_mape_mean = []
# test_mape_std = []
# train_r2_mean = []
# train_r2_std = []
# test_r2_mean = []
# test_r2_std = []

# %%
# df = df.set_index(["Train Period", "Test Period"])

# df[
#     (
#         df[df["Metric"] == "RMSE"]
#         == df[df["Metric"] == "RMSE"][["Test Mean"]].min().values[0]
#     )["Test Mean"]
# ]
