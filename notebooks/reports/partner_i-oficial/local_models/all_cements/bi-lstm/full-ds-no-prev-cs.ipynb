# %%
# %load_ext nb_black

# %%
import pandas as pd
import numpy as np

# %%
def flat_list(lst):
    return [item for tup in list(lst) for item in tup]

# %%
def extract_and_fill_lists(text, train_rmse_mean, train_rmse_std, test_rmse_mean, test_rmse_std,
                           train_mae_mean, train_mae_std, test_mae_mean, test_mae_std,
                           train_mape_mean, train_mape_std, test_mape_mean, test_mape_std,
                           train_r2_mean, train_r2_std, test_r2_mean, test_r2_std):

    train_flag = False
    test_flag = False
    timesteps_flag = False

    for line in text.split("\n"):
        line = line.strip()

        if line.startswith("TIMESTEPS:"):
            timesteps_flag = True

        elif line.startswith("[TRAIN]"):
            train_flag = True
            test_flag = False

        elif line.startswith("[TEST]"):
            train_flag = False
            test_flag = True

        elif line.startswith("RMSE:"):
            parts = line.split(" ")
            if train_flag:
                train_rmse_mean.append(float(parts[1]))
                train_rmse_std.append(float(parts[2].lstrip("(").rstrip(")")))
            elif test_flag:
                test_rmse_mean.append(float(parts[1]))
                test_rmse_std.append(float(parts[2].lstrip("(").rstrip(")")))

        elif line.startswith("MAE:"):
            parts = line.split(" ")
            if train_flag:
                train_mae_mean.append(float(parts[1]))
                train_mae_std.append(float(parts[2].lstrip("(").rstrip(")")))
            elif test_flag:
                test_mae_mean.append(float(parts[1]))
                test_mae_std.append(float(parts[2].lstrip("(").rstrip(")")))

        elif line.startswith("MAPE:"):
            parts = line.split(" ")
            if train_flag:
                train_mape_mean.append(float(parts[1]))
                train_mape_std.append(float(parts[2].lstrip("(").rstrip(")")))
            elif test_flag:
                test_mape_mean.append(float(parts[1]))
                test_mape_std.append(float(parts[2].lstrip("(").rstrip(")")))

        elif line.startswith("R2:"):
            parts = line.split(" ")
            if train_flag:
                train_r2_mean.append(float(parts[1]))
                train_r2_std.append(float(parts[2].lstrip("(").rstrip(")")))
            elif test_flag:
                test_r2_mean.append(float(parts[1]))
                test_r2_std.append(float(parts[2].lstrip("(").rstrip(")")))

        elif line.startswith("="):
            train_flag = False
            test_flag = False
            timesteps_flag = False

        else:
            continue

# %% [markdown]
# # All Cements

# %%
results = []

# %% [markdown]
# ## No previous Compressive Strength

# %% [markdown]
# ## Repeated KFold Cross validation

# %% [markdown]
# ## Blocking Time Series Split Results

# %% [markdown]
# ## Time Series Split Cross Validation

# %% [markdown]
# ## Blocking Time Series Split Results - Period Specific

# %%
# Define the train and test periods for each row
periods = [
    ["6 months", "One Month"],
    ["11 months", "One Month"],
    ["1 year", "One Month"],
    ["1 year and one month", "One Month"],
    ["1 year and two months", "One Month"],
    ["2 years", "One Month"],
    ["2 years", "Two Months"],
    ["2 years", "One Year"],
    ["2 years, 8 months and 15 days", "8 months and 6 days"],
]

train_mean = []
test_mean = []

train_std = []
test_std = []

###########################
# 6 months", "One Month"  #
###########################
train_rmse_mean = [2.98, 0.955, 1.018, 1.425, 1.483, 1.516]
train_rmse_std = [1.272, 0.153, 0.131, 0.308, 0.486, 0.43]
test_rmse_mean = [19.988, 24.153, 51.855, 209.407, 301.36, 289.908]
test_rmse_std = [29.906, 42.431, 106.801, 321.221, 641.027, 697.901]
train_mae_mean = [2.289, 0.746, 0.809, 1.206, 1.261, 1.268]
train_mae_std = [0.943, 0.106, 0.112, 0.32, 0.476, 0.42]
test_mae_mean = [8.142, 14.119, 35.867, 91.625, 171.071, 93.218]
test_mae_std = [8.616, 23.523, 73.693, 129.381, 362.343, 219.272]
train_mape_mean = [0.054, 0.017, 0.019, 0.028, 0.029, 0.029]
train_mape_std = [0.023, 0.002, 0.003, 0.008, 0.011, 0.01]
test_mape_mean = [0.197, 0.329, 0.827, 2.296, 4.598, 2.1]
test_mape_std = [0.213, 0.54, 1.699, 3.199, 9.778, 4.936]
train_r2_mean = [0.584, 0.963, 0.959, 0.916, 0.905, 0.902]
train_r2_std = [0.302, 0.014, 0.012, 0.04, 0.067, 0.059]
test_r2_mean = [52.628, 96.722, 618.808, 5044.839, 16128.421, 25478.454]
test_r2_std = [105.432, 239.964, 1635.059, 9736.989, 39248.366, 72250.348]


train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

###########################
# 11 months", "One Month  #
###########################
train_rmse_mean = [1.539, 0.985, 1.138, 1.04, 1.335, 1.317]
train_rmse_std = [0.291, 0.07, 0.29, 0.247, 0.348, 0.3]
test_rmse_mean = [21.94, 13.988, 16.972, 16.221, 2.78, 12.17]
test_rmse_std = [23.553, 15.09, 19.687, 22.281, 1.098, 16.713]
train_mae_mean = [1.165, 0.769, 0.93, 0.836, 1.094, 1.069]
train_mae_std = [0.215, 0.059, 0.269, 0.217, 0.33, 0.283]
test_mae_mean = [5.661, 5.591, 8.043, 8.4, 2.046, 5.229]
test_mae_std = [3.866, 4.328, 7.495, 10.83, 0.611, 5.619]
train_mape_mean = [0.027, 0.018, 0.022, 0.019, 0.025, 0.024]
train_mape_std = [0.005, 0.001, 0.006, 0.005, 0.007, 0.006]
test_mape_mean = [0.125, 0.123, 0.175, 0.18, 0.046, 0.12]
test_mape_std = [0.082, 0.092, 0.158, 0.229, 0.013, 0.13]
train_r2_mean = [0.903, 0.962, 0.947, 0.955, 0.925, 0.928]
train_r2_std = [0.044, 0.005, 0.025, 0.025, 0.04, 0.036]
test_r2_mean = [47.377, 17.356, 26.183, 28.044, 0.667, 16.559]
test_r2_std = [66.983, 30.127, 43.321, 54.684, 0.279, 34.264]


train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

###########################
# "1 year", "One Month"   #
###########################
train_rmse_mean = [1.467, 0.955, 1.019, 1.137, 1.232, 1.372]
train_rmse_std = [0.235, 0.109, 0.146, 0.222, 0.209, 0.281]
test_rmse_mean = [1.953, 1.75, 1.811, 2.108, 85.524, 5.066]
test_rmse_std = [0.356, 0.291, 0.31, 0.548, 131.731, 3.249]
train_mae_mean = [1.114, 0.732, 0.801, 0.906, 1.005, 1.12]
train_mae_std = [0.174, 0.062, 0.111, 0.213, 0.195, 0.253]
test_mae_mean = [1.561, 1.381, 1.432, 1.697, 55.264, 3.849]
test_mae_std = [0.264, 0.187, 0.276, 0.504, 83.085, 2.251]
train_mape_mean = [0.026, 0.017, 0.018, 0.021, 0.023, 0.026]
train_mape_std = [0.004, 0.001, 0.003, 0.005, 0.004, 0.006]
test_mape_mean = [0.037, 0.033, 0.034, 0.04, 1.262, 0.087]
test_mape_std = [0.006, 0.005, 0.007, 0.012, 1.89, 0.05]
train_r2_mean = [0.912, 0.963, 0.958, 0.947, 0.939, 0.922]
train_r2_std = [0.033, 0.009, 0.013, 0.024, 0.02, 0.031]
test_r2_mean = [0.847, 0.885, 0.871, 0.819, 1061.694, 0.55]
test_r2_std = [0.069, 0.041, 0.048, 0.095, 2070.178, 1.898]

train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

#########################################
# "1 year and one month", "One Month"   #
#########################################
train_rmse_mean = [1.515, 1.13, 1.115, 1.014, 1.005, 1.105]
train_rmse_std = [0.246, 0.246, 0.329, 0.114, 0.066, 0.159]
test_rmse_mean = [11.519, 142.354, 263.361, 313.018, 3.141, 2.4]
test_rmse_std = [12.129, 153.218, 335.912, 424.294, 1.456, 0.966]
train_mae_mean = [1.149, 0.821, 0.899, 0.796, 0.806, 0.873]
train_mae_std = [0.185, 0.117, 0.331, 0.084, 0.058, 0.117]
test_mae_mean = [6.781, 95.233, 199.891, 261.832, 2.517, 2.028]
test_mae_std = [6.602, 103.157, 254.544, 351.159, 1.272, 0.862]
train_mape_mean = [0.027, 0.019, 0.021, 0.019, 0.019, 0.02]
train_mape_std = [0.004, 0.003, 0.008, 0.002, 0.001, 0.003]
test_mape_mean = [0.159, 2.224, 4.582, 6.083, 0.057, 0.046]
test_mape_std = [0.157, 2.41, 5.834, 8.151, 0.029, 0.02]
train_r2_mean = [0.904, 0.946, 0.946, 0.958, 0.96, 0.952]
train_r2_std = [0.034, 0.022, 0.037, 0.009, 0.005, 0.013]
test_r2_mean = [10.396, 1889.686, 8184.458, 11105.059, 0.478, 0.71]
test_r2_std = [16.423, 2311.391, 15878.927, 23422.483, 0.49, 0.23]

train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

##########################################
# "1 year and two months", "One Month"   #
#########################################
train_rmse_mean = [1.475, 1.081, 1.148, 1.201, 1.132, 1.218]
train_rmse_std = [0.174, 0.115, 0.104, 0.149, 0.2, 0.151]
test_rmse_mean = [3.409, 2.504, 2.975, 2.311, 2.078, 1.764]
test_rmse_std = [1.478, 1.119, 0.666, 0.412, 0.638, 0.334]
train_mae_mean = [1.123, 0.836, 0.909, 0.946, 0.907, 0.957]
train_mae_std = [0.111, 0.078, 0.077, 0.122, 0.197, 0.106]
test_mae_mean = [2.577, 1.86, 2.048, 1.841, 1.648, 1.396]
test_mae_std = [0.897, 0.715, 0.424, 0.272, 0.562, 0.295]
train_mape_mean = [0.026, 0.019, 0.021, 0.022, 0.021, 0.022]
train_mape_std = [0.003, 0.002, 0.002, 0.003, 0.005, 0.002]
test_mape_mean = [0.057, 0.042, 0.047, 0.042, 0.038, 0.032]
test_mape_std = [0.021, 0.016, 0.01, 0.006, 0.013, 0.007]
train_r2_mean = [0.911, 0.954, 0.947, 0.943, 0.948, 0.941]
train_r2_std = [0.025, 0.009, 0.011, 0.014, 0.022, 0.014]
test_r2_mean = [0.416, 0.661, 0.613, 0.766, 0.789, 0.873]
test_r2_std = [0.487, 0.332, 0.175, 0.076, 0.145, 0.048]


train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

############################
# "2 years", "One Month"   #
############################
train_rmse_mean = [1.061, 1.087, 1.034, 1.075, 1.064, 1.35]
train_rmse_std = [0.043, 0.056, 0.125, 0.087, 0.172, 0.163]
test_rmse_mean = [1.299, 1.405, 1.448, 1.404, 1.467, 1.192]
test_rmse_std = [0.061, 0.118, 0.125, 0.173, 0.075, 0.058]
train_mae_mean = [0.799, 0.836, 0.808, 0.848, 0.823, 1.105]
train_mae_std = [0.025, 0.073, 0.108, 0.067, 0.131, 0.153]
test_mae_mean = [1.03, 1.113, 1.148, 1.105, 1.159, 0.986]
test_mae_std = [0.069, 0.083, 0.105, 0.123, 0.049, 0.051]
train_mape_mean = [0.019, 0.019, 0.019, 0.02, 0.019, 0.025]
train_mape_std = [0.001, 0.002, 0.002, 0.001, 0.003, 0.003]
test_mape_mean = [0.024, 0.025, 0.026, 0.025, 0.028, 0.023]
test_mape_std = [0.002, 0.002, 0.002, 0.003, 0.001, 0.001]
train_r2_mean = [0.953, 0.951, 0.955, 0.952, 0.953, 0.925]
train_r2_std = [0.004, 0.005, 0.011, 0.008, 0.017, 0.018]
test_r2_mean = [0.94, 0.933, 0.922, 0.931, 0.934, 0.949]
test_r2_std = [0.006, 0.012, 0.013, 0.016, 0.007, 0.005]

train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))


############################
# "2 years", "Two Months"  #
############################
train_rmse_mean = [1.061, 1.087, 1.034, 1.075, 1.064, 1.35]
train_rmse_std = [0.043, 0.056, 0.125, 0.087, 0.172, 0.163]
test_rmse_mean = [1.454, 1.521, 1.604, 1.534, 1.355, 1.648]
test_rmse_std = [0.069, 0.108, 0.091, 0.12, 0.121, 0.174]
train_mae_mean = [0.799, 0.836, 0.808, 0.848, 0.823, 1.105]
train_mae_std = [0.025, 0.073, 0.108, 0.067, 0.131, 0.153]
test_mae_mean = [1.137, 1.244, 1.309, 1.257, 1.046, 1.323]
test_mae_std = [0.076, 0.113, 0.09, 0.111, 0.091, 0.151]
train_mape_mean = [0.019, 0.019, 0.019, 0.02, 0.019, 0.025]
train_mape_std = [0.001, 0.002, 0.002, 0.001, 0.003, 0.003]
test_mape_mean = [0.027, 0.029, 0.031, 0.029, 0.025, 0.031]
test_mape_std = [0.002, 0.002, 0.002, 0.002, 0.002, 0.004]
train_r2_mean = [0.953, 0.951, 0.955, 0.952, 0.953, 0.925]
train_r2_std = [0.004, 0.005, 0.011, 0.008, 0.017, 0.018]
test_r2_mean = [0.929, 0.927, 0.916, 0.922, 0.938, 0.906]
test_r2_std = [0.007, 0.011, 0.01, 0.012, 0.012, 0.019]


train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

##########################
# "2 years", "One Year"  #
##########################
train_rmse_mean = [1.061, 1.087, 1.034, 1.075, 1.064, 1.35]
train_rmse_std = [0.043, 0.056, 0.125, 0.087, 0.172, 0.163]
test_rmse_mean = [2.645, 2.459, 2.645, 2.769, 2.398, 2.465]
test_rmse_std = [0.206, 0.145, 0.376, 0.109, 0.666, 0.319]
train_mae_mean = [0.799, 0.836, 0.808, 0.848, 0.823, 1.105]
train_mae_std = [0.025, 0.073, 0.108, 0.067, 0.131, 0.153]
test_mae_mean = [1.874, 1.934, 2.026, 2.21, 1.873, 1.981]
test_mae_std = [0.109, 0.176, 0.256, 0.104, 0.528, 0.277]
train_mape_mean = [0.019, 0.019, 0.019, 0.02, 0.019, 0.025]
train_mape_std = [0.001, 0.002, 0.002, 0.001, 0.003, 0.003]
test_mape_mean = [0.042, 0.043, 0.045, 0.049, 0.042, 0.045]
test_mape_std = [0.002, 0.004, 0.006, 0.002, 0.012, 0.006]
train_r2_mean = [0.953, 0.951, 0.955, 0.952, 0.953, 0.925]
train_r2_std = [0.004, 0.005, 0.011, 0.008, 0.017, 0.018]
test_r2_mean = [0.752, 0.786, 0.747, 0.73, 0.779, 0.773]
test_r2_std = [0.038, 0.025, 0.071, 0.021, 0.131, 0.058]


train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

###########################################################
# "2 years, 8 months and 15 days", "8 months and 6 days"  #
###########################################################
train_rmse_mean = [1.129, 1.014, 1.354, 1.366, 1.309, 1.233]
train_rmse_std = [0.027, 0.035, 0.197, 0.205, 0.228, 0.197]
test_rmse_mean = [1.621, 1.81, 2.189, 2.272, 2.021, 1.909]
test_rmse_std = [0.044, 0.133, 0.279, 0.161, 0.224, 0.229]
train_mae_mean = [0.844, 0.778, 1.106, 1.108, 1.051, 0.977]
train_mae_std = [0.018, 0.021, 0.179, 0.195, 0.213, 0.184]
test_mae_mean = [1.244, 1.443, 1.769, 1.857, 1.632, 1.533]
test_mae_std = [0.031, 0.11, 0.248, 0.147, 0.184, 0.229]
train_mape_mean = [0.019, 0.018, 0.025, 0.025, 0.024, 0.022]
train_mape_std = [0.0, 0.0, 0.004, 0.004, 0.005, 0.004]
test_mape_mean = [0.028, 0.032, 0.04, 0.042, 0.037, 0.035]
test_mape_std = [0.001, 0.002, 0.006, 0.003, 0.004, 0.005]
train_r2_mean = [0.95, 0.96, 0.927, 0.925, 0.931, 0.939]
train_r2_std = [0.002, 0.003, 0.02, 0.021, 0.023, 0.02]
test_r2_mean = [0.893, 0.867, 0.803, 0.79, 0.833, 0.85]
test_r2_std = [0.006, 0.02, 0.047, 0.03, 0.036, 0.037]

train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))


# Extract the relevant information and store it in a dictionary
data = {
    "Validation": ["Blocking Time Series - Period Specific"] * 216,
    "Repeats": [5] * 216,
    "Splits": [np.nan] * 216,
    "Metric": ["RMSE", "MAE", "MAPE", "R2"] * len(periods) * 6,
    "Time Steps": sorted([1, 3, 5, 7, 14, 21] * 4 * 9),
    "Train Mean": train_mean,
    "Train Std": train_std,
    "Test Mean": test_mean,
    "Test Std": test_std,
    "Train Period": [
        item
        for sublist in [[result[0]] * 4 * 6 for result in periods]
        for item in sublist
    ],
    "Test Period": [
        item
        for sublist in [[result[1]] * 4 * 6 for result in periods]
        for item in sublist
    ],
}

df = pd.DataFrame(data)

# %%
idx = df[df["Metric"] == "RMSE"]["Test Mean"].idxmin()
df.iloc[idx : idx + 4]
# Out:
#                                  Validation  Repeats  Splits Metric  \
# 140  Blocking Time Series - Period Specific        5     NaN   RMSE
# 141  Blocking Time Series - Period Specific        5     NaN    MAE
# 142  Blocking Time Series - Period Specific        5     NaN   MAPE
# 143  Blocking Time Series - Period Specific        5     NaN     R2
#
#      Time Steps  Train Mean  Train Std  Test Mean  Test Std Train Period  \
# 140           7       1.350      0.163      1.192     0.058      2 years
# 141           7       1.105      0.153      0.986     0.051      2 years
# 142           7       0.025      0.003      0.023     0.001      2 years
# 143           7       0.925      0.018      0.949     0.005      2 years
#
#     Test Period
# 140   One Month
# 141   One Month
# 142   One Month
# 143   One Month

# %%
s = """

"""

# %%
train_rmse_mean, train_rmse_std, test_rmse_mean, test_rmse_std = [], [], [], []
train_mae_mean, train_mae_std, test_mae_mean, test_mae_std = [], [], [], []
train_mape_mean, train_mape_std, test_mape_mean, test_mape_std = [], [], [], []
train_r2_mean, train_r2_std, test_r2_mean, test_r2_std = [], [], [], []

extract_and_fill_lists(
    s,
    train_rmse_mean,
    train_rmse_std,
    test_rmse_mean,
    test_rmse_std,
    train_mae_mean,
    train_mae_std,
    test_mae_mean,
    test_mae_std,
    train_mape_mean,
    train_mape_std,
    test_mape_mean,
    test_mape_std,
    train_r2_mean,
    train_r2_std,
    test_r2_mean,
    test_r2_std,
)

for x, y in zip(
    [
        "train_rmse_mean",
        "train_rmse_std",
        "test_rmse_mean",
        "test_rmse_std",
        "train_mae_mean",
        "train_mae_std",
        "test_mae_mean",
        "test_mae_std",
        "train_mape_mean",
        "train_mape_std",
        "test_mape_mean",
        "test_mape_std",
        "train_r2_mean",
        "train_r2_std",
        "test_r2_mean",
        "test_r2_std",
    ],
    [
        train_rmse_mean,
        train_rmse_std,
        test_rmse_mean,
        test_rmse_std,
        train_mae_mean,
        train_mae_std,
        test_mae_mean,
        test_mae_std,
        train_mape_mean,
        train_mape_std,
        test_mape_mean,
        test_mape_std,
        train_r2_mean,
        train_r2_std,
        test_r2_mean,
        test_r2_std,
    ],
):
    print(f"{x} = {y}")
# Out:
# train_rmse_mean = []
# train_rmse_std = []
# test_rmse_mean = []
# test_rmse_std = []
# train_mae_mean = []
# train_mae_std = []
# test_mae_mean = []
# test_mae_std = []
# train_mape_mean = []
# train_mape_std = []
# test_mape_mean = []
# test_mape_std = []
# train_r2_mean = []
# train_r2_std = []
# test_r2_mean = []
# test_r2_std = []
