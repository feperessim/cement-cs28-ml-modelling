# %%
# %load_ext nb_black

# %%
import pandas as pd
import os
import glob

# %%
import warnings

# Suppress specific FutureWarning
warnings.filterwarnings("ignore", category=FutureWarning, module="seaborn._oldcore")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.preprocessing import StandardScaler

# %%
def read_csv_files_grouped(csv_files, plant, header=[0, 1]):
    results = []
    for filepath in csv_files:
        df = pd.read_csv(filepath, header=header, low_memory=False)
        df["plant"] = plant  # Add the 'plant' column
        results.append(df)
    df = pd.concat(results, ignore_index=True)
    return df

# %%
def read_csv_files_full(csv_files, plant):
    results = []
    for filepath in csv_files:
        df = pd.read_csv(filepath, low_memory=False)
        df["plant"] = plant  # Add the 'plant' column
        results.append(df)
    df = pd.concat(results, ignore_index=True)
    return df

# %% [markdown]
# ### Renaming the Columns

# %%
def preprocess_rename_columns(df):
    df.columns = pd.MultiIndex.from_tuples(
        list(
            {
                col: (col[0], "") if "Unnamed" in col[1] else col for col in df.columns
            }.values()
        )
    )
    return df

# %% [markdown]
# ### Changing the order_of columns Columns

# %%
def preprocess_change_columns_order(df, column, pos):
    # Get the list of columns
    cols = df.columns.tolist()
    # Remove the specified column
    cols.remove(column)
    # Insert the column at the desired position
    cols.insert(pos, column)
    # Reorder the DataFrame columns
    return df[cols]

# %%
def read_csv_files_path(csv_files_path_dict, path, plant):
    csv_files = glob.glob(os.path.join(path, "*.csv"))
    csv_files_path_dict[plant] = csv_files
    return csv_files_path_dict

# %% [markdown]
# # Reading The files

# %%
csv_files_path_grouped = dict()
csv_files_path_full = dict()

# %% [markdown]
# ## partner_i

# %%
path_grouped = "/home/peressim/projects/ccs28-ml-modelling/reports/results/local_models/partner_i-oficial/all_cements/grouped/"
path_full = "/home/peressim/projects/ccs28-ml-modelling/reports/results/local_models/partner_i-oficial/all_cements/full/"
plant = "partner_i"

csv_files_path_full = read_csv_files_path(csv_files_path_full, path_full, plant)

csv_files_path_grouped = read_csv_files_path(
    csv_files_path_grouped, path_grouped, plant
)

# %% [markdown]
# ## partner_ii

# %%
path_grouped = "/home/peressim/projects/ccs28-ml-modelling/reports/results/local_models/partner_ii/all_cements/grouped/"
path_full = "/home/peressim/projects/ccs28-ml-modelling/reports/results/local_models/partner_ii/all_cements/full/"
plant = "partner_ii"

csv_files_path_full = read_csv_files_path(csv_files_path_full, path_full, plant)

csv_files_path_grouped = read_csv_files_path(
    csv_files_path_grouped, path_grouped, plant
)

# %% [markdown]
# ## partner_iv

# %%
path_grouped = "/home/peressim/projects/ccs28-ml-modelling/reports/results/local_models/partner_iv/all_cements/grouped/"
path_full = "/home/peressim/projects/ccs28-ml-modelling/reports/results/local_models/partner_iv/all_cements/full/"
plant = "partner_iv"
csv_files_path_full = read_csv_files_path(csv_files_path_full, path_full, plant)
csv_files_path_grouped = read_csv_files_path(
    csv_files_path_grouped, path_grouped, plant
)

# %% [markdown]
# ### 203

# %%
plants_203 = ["av", "c", "d", "g", "m", "y"]

for plant in plants_203:
    path_grouped = f"/home/peressim/projects/ccs28-ml-modelling/reports/results/local_models/203/{plant}/grouped/"
    path_full = f"/home/peressim/projects/ccs28-ml-modelling/reports/results/local_models/203/{plant}/full/"
    csv_files_path_full = read_csv_files_path(csv_files_path_full, path_full, plant)
    csv_files_path_grouped = read_csv_files_path(
        csv_files_path_grouped, path_grouped, plant
    )

# %% [markdown]
# ### 204

# %%
plants_204 = ["a", "ab", "ae", "aq", "ay", "f", "i", "o", "r", "t"]

for plant in plants_204:
    path_grouped = f"/home/peressim/projects/ccs28-ml-modelling/reports/results/local_models/204/{plant}/grouped/"
    path_full = f"/home/peressim/projects/ccs28-ml-modelling/reports/results/local_models/204/{plant}/full/"
    csv_files_path_full = read_csv_files_path(csv_files_path_full, path_full, plant)
    csv_files_path_grouped = read_csv_files_path(
        csv_files_path_grouped, path_grouped, plant
    )

# %% [markdown]
# ### 206

# %%
plants_206 = ["b"]

for plant in plants_206:
    path_grouped = f"/home/peressim/projects/ccs28-ml-modelling/reports/results/local_models/206/{plant}/grouped/"
    path_full = f"/home/peressim/projects/ccs28-ml-modelling/reports/results/local_models/206/{plant}/full/"
    csv_files_path_full = read_csv_files_path(csv_files_path_full, path_full, plant)
    csv_files_path_grouped = read_csv_files_path(
        csv_files_path_grouped, path_grouped, plant
    )

# %% [markdown]
# ### 207

# %%
plants_207 = ["at"]

for plant in plants_207:
    path_grouped = f"/home/peressim/projects/ccs28-ml-modelling/reports/results/local_models/207/{plant}/grouped/"
    path_full = f"/home/peressim/projects/ccs28-ml-modelling/reports/results/local_models/207/{plant}/full/"
    csv_files_path_full = read_csv_files_path(csv_files_path_full, path_full, plant)
    csv_files_path_grouped = read_csv_files_path(
        csv_files_path_grouped, path_grouped, plant
    )

# %% [markdown]
# ### 209

# %%
plants_209 = [
    "aa",
    "ac",
    "ag",
    "ai",
    "am",
    "an",
    "ap",
    "as",
    "az",
    "e",
    "h",
    "j",
    "k",
    "l",
    "n",
    "p",
    "q",
    "s",
    "u",
    "v",
    "w",
    "x",
    "z",
]

for plant in plants_209:
    path_grouped = f"/home/peressim/projects/ccs28-ml-modelling/reports/results/local_models/209/{plant}/grouped/"
    path_full = f"/home/peressim/projects/ccs28-ml-modelling/reports/results/local_models/209/{plant}/full/"
    csv_files_path_full = read_csv_files_path(csv_files_path_full, path_full, plant)
    csv_files_path_grouped = read_csv_files_path(
        csv_files_path_grouped, path_grouped, plant
    )

# %% [markdown]
# ### Reading all data

# %% [markdown]
# #### Full

# %%
dfs_plant = dict()
column = ("plant", "")
pos = 2

for plant, csv_files in csv_files_path_full.items():
    df = read_csv_files_full(csv_files, plant)
    df["plant"] = plant
    dfs_plant[plant] = df

# %%
df_full = pd.concat(dfs_plant.values(), ignore_index=True)

# %%
df_full.shape
# Out:
# (281092, 23)

# %%
filter_df = df_full[df_full["R2 Test"] < 0].reset_index(drop=True)

filter_df["CP"] = (
    filter_df["Company"].astype(str) + "_" + filter_df["plant"].astype(str)
)

filter_df["CP"].unique()

print(filter_df.shape)
# Out:
# (67889, 24)

# %%
patterns = [
    "Chemical + Mineralogical + Feature Engineering",
    "Chemical + Mineralogical + CS7 + One-Hot",
    "Chemical + Mineralogical + Physical + One-Hot",
    "Chemical + Mineralogical + CS3 + One-Hot",
    "Chemical + Mineralogical + CS3 + CS7 + One-Hot",
    "Chemical + Mineralogical + One-Hot",
    "Chemical + Mineralogical + CS1 + CS3 + CS7 + One-Hot",
    "Chemical + Mineralogical + CS1 + CS3 + One-Hot",
    "Chemical + Mineralogical + CS1 + One-Hot",
    "Chemical + Mineralogical + CS2 + One-Hot",
    "Chemical + Feature Engineering",
]

FEATURES_TO_REPLACE_1 = {
    "Chemical + Mineralogical + CS3 + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS3": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS1": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS1 + CS3": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS1 + CS3 + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS2": "Chemical + Mineralogical + Early CS",
    "Chemical + CS1 + CS3 + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + CS3 + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + CS3": "Chemical + Mineralogical + Early CS",
    "Chemical + CS1 + CS3": "Chemical + Mineralogical + Early CS",
    "Chemical + CS1": "Chemical + Mineralogical + Early CS",
    "Chemical + CS1 + CS7": "Chemical + Mineralogical + Early CS",
}

FEATURES_TO_REPLACE_2 = {
    "Chemical": "Chemical + Mineralogical",
    "Chemical + Properties CS Less": "Chemical + Mineralogical + Physical - Early CS",
    "Chemical + Mineralogical + Properties CS Less": "Chemical + Mineralogical + Physical - Early CS",
    "Chemical + Physical": "Chemical + Mineralogical + Physical",
}

df_full = df_full[~df_full["Features"].apply(lambda x: x in patterns)].reset_index(
    drop=True
)

df_full = df_full[~df_full["Cross Validation"].eq("Out of time Split")].reset_index(
    drop=True
)

# removing afterwards
df_full = df_full[~df_full["Cross Validation"].eq("Repeated KFold")].reset_index(
    drop=True
)

df_full["Features_bkp"] = df_full["Features"].copy()
df_full["Features"] = df_full["Features"].replace(FEATURES_TO_REPLACE_1)

df_full["Features"] = df_full["Features"].replace(FEATURES_TO_REPLACE_2)


# removing afterwards
df_full = df_full[
    ~df_full["Features"].eq("Chemical + Mineralogical + Early CS")
].reset_index(drop=True)

# %%
df_full["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split', 'Time Series Split'], dtype=object)

# %%
df_full["Features"].unique()
# Out:
# array(['Chemical + Mineralogical + Physical',
#        'Chemical + Mineralogical + Physical - Early CS',
#        'Chemical + Mineralogical'], dtype=object)

# %%
df_full["Features_bkp"].unique()
# Out:
# array(['Chemical + Mineralogical + Physical',
#        'Chemical + Mineralogical + Properties CS Less',
#        'Chemical + Mineralogical', 'Chemical + Properties CS Less',
#        'Chemical + Physical', 'Chemical'], dtype=object)

# %%
df_full.shape
# Out:
# (60150, 24)

# %%
df_full[["RMSE Test", "MAE Test", "MAPE Test", "R2 Test"]].describe().round(2).T
# Out:
#              count   mean     std       min   25%   50%   75%     max
# RMSE Test  60150.0   4.75    7.26      0.26  2.11  3.23  5.30  776.07
# MAE Test   60150.0   3.61    4.66      0.20  1.65  2.52  4.14  476.59
# MAPE Test  60150.0   0.08    0.11      0.01  0.04  0.06  0.10   10.22
# R2 Test    60150.0 -14.07  371.64 -68227.01 -1.03  0.43  0.81    0.99

# %%
df_full[df_full["R2 Test"] < 0][["Company", "plant"]]["plant"].nunique()
# Out:
# 43

# %%
df_full[df_full["R2 Test"].eq(df_full["R2 Test"].min())]
# Out:
#           Category Company                  Features Data Shape  Timesteps  \
# 34236  Local Model     209  Chemical + Mineralogical  (749, 10)       14.0
#
#       Model  Model Params           Scaler  Scaler Params Imputer  ...  \
# 34236  LSTM           NaN  Standard Scaler            NaN  Median  ...
#
#        MAE Train MAPE Train  R2 Train   RMSE Test    MAE Test  MAPE Test  \
# 34236   0.994235   0.024087 -0.070757  776.071016  476.590659  10.224767
#
#             R2 Test  plant  Plant  Features_bkp
# 34236 -68227.008082     ac     AC      Chemical
#
# [1 rows x 24 columns]

# %%
df_full[(df_full["R2 Test"].eq(df_full["R2 Test"].min()))]["Cross Validation"]
# Out:
# 34236    Time Series Split
# Name: Cross Validation, dtype: object

# %%
filter_df = df_full[df_full["R2 Test"] < 0].reset_index(drop=True)

print(filter_df.shape)
# Out:
# (23104, 24)

# %% [markdown]
# # Example for thesis

# %%
# Function to compare two models strictly based on means only
def strictly_dominates(model1, model2):
    """Return True if model1 strictly dominates model2, False otherwise."""
    # Check if model1 is at least as good as model2 in all metrics
    at_least_as_good = (
        model1["RMSE_mean"] <= model2["RMSE_mean"]
        and model1["MAE_mean"] <= model2["MAE_mean"]
        and model1["MAPE_mean"] <= model2["MAPE_mean"]
        and model1["R2_mean"] >= model2["R2_mean"]
    )

    # Check if model1 is strictly better in at least one metric
    strictly_better_in_one = (
        model1["RMSE_mean"] < model2["RMSE_mean"]
        or model1["MAE_mean"] < model2["MAE_mean"]
        or model1["MAPE_mean"] < model2["MAPE_mean"]
        or model1["R2_mean"] > model2["R2_mean"]
    )

    # Model1 strictly dominates Model2 if it is at least as good in all metrics and
    # strictly better in at least one metric
    return at_least_as_good and strictly_better_in_one

# %%
# Topological Sorting
def topological_sort(graph):
    """Perform topological sorting on the given graph."""
    in_degree = {u: 0 for u in graph}
    for u in graph:
        for v in graph[u]:
            in_degree[v] += 1

    queue = deque([u for u in graph if in_degree[u] == 0])
    topo_order = []

    while queue:
        u = queue.popleft()
        topo_order.append(u)

        for v in graph[u]:
            in_degree[v] -= 1
            if in_degree[v] == 0:
                queue.append(v)

    return topo_order

# %%
import pandas as pd
import numpy as np
from collections import deque, defaultdict

# Sample DataFrame containing the results for each model, including standard deviations
data = {
    'Model': ['Model1', 'Model2', 'Model3', 'Model4'],
    'RMSE_mean': [1.5, 2.0, 2.5, 2.1],
    'RMSE_std': [0.2, 0.25, 0.3, 0.25],
    'MAE_mean': [1.0, 1.5, 2.0, 1.4],
    'MAE_std': [0.1, 0.15, 0.2, 0.12],
    'MAPE_mean': [3.0, 4.0, 5.0, 2.8],
    'MAPE_std': [0.5, 0.6, 0.7, 0.4],
    'R2_mean': [0.9, 0.85, 0.8, 0.75],
    'R2_std': [0.05, 0.06, 0.07, 0.08]
}


df = pd.DataFrame(data)



# Create the dominance matrix
n = len(df)
dominance_matrix = np.zeros((n, n), dtype=bool)

for i in range(n):
    for j in range(n):
        if i != j:
            dominance_matrix[i, j] = strictly_dominates(df.iloc[i], df.iloc[j])

# Create the dominance graph
dominance_graph = {i: [] for i in range(n)}
for i in range(n):
    for j in range(n):
        if dominance_matrix[i, j]:
            dominance_graph[i].append(j)

# Topological Sorting
def topological_sort(graph):
    """Perform topological sorting on the given graph."""
    in_degree = {u: 0 for u in graph}
    for u in graph:
        for v in graph[u]:
            in_degree[v] += 1
    
    queue = deque([u for u in graph if in_degree[u] == 0])
    topo_order = []
    
    while queue:
        u = queue.popleft()
        topo_order.append(u)
        
        for v in graph[u]:
            in_degree[v] -= 1
            if in_degree[v] == 0:
                queue.append(v)
    
    return topo_order

# Get the topological order
topo_order = topological_sort(dominance_graph)

# Categorize models based on dominance
dominates_any = np.any(dominance_matrix, axis=1)
dominated_by_any = np.any(dominance_matrix, axis=0)

dominating_models = [df['Model'].iloc[i] for i in range(n) if dominates_any[i] and not dominated_by_any[i]]
non_dominated_models = [df['Model'].iloc[i] for i in range(n) if not dominates_any[i] and not dominated_by_any[i]]
failing_models = [df['Model'].iloc[i] for i in range(n) if dominated_by_any[i]]

print("Dominating Models:", dominating_models)
print("Non-Dominated Models:", non_dominated_models)
print("Failing Models:", failing_models)

# Map the topological order to the model names
sorted_models = [df['Model'].iloc[i] for i in topo_order]
print("Models in order of dominance:", sorted_models)

# Visualization of the dominance graph
import networkx as nx
import matplotlib.pyplot as plt

G = nx.DiGraph(dominance_graph)
labels = {i: df['Model'].iloc[i] for i in range(n)}
pos = nx.spring_layout(G, seed=48, k=1.5)
#pos = nx.kamada_kawai_layout(G)

pos[3] = np.mean([pos[0], pos[1]], axis=1) + np.array([-0.4, 0.6])

nx.draw(G, pos, labels=labels, with_labels=True, node_size=2100, node_color="skyblue", font_size=10, font_color="black", font_weight="bold", arrows=True)
plt.title("Dominance Graph")
plt.show()
# Out:
# Dominating Models: ['Model1']
# Non-Dominated Models: ['Model4']
# Failing Models: ['Model2', 'Model3']
# Models in order of dominance: ['Model1', 'Model4', 'Model2', 'Model3']

# %%
import pandas as pd
import numpy as np
from collections import deque, defaultdict
import networkx as nx
import matplotlib.pyplot as plt

# Sample DataFrame containing the results for each model, including standard deviations
data = {
    #'Model': ['Model A', 'Model B', 'Model C', 'Model D'],
    'Model': ['A', 'B', 'C', 'D'],
    'RMSE_mean': [1.5, 2.0, 2.5, 2.1],
    'RMSE_std': [0.2, 0.25, 0.3, 0.25],
    'MAE_mean': [1.0, 1.5, 2.0, 1.4],
    'MAE_std': [0.1, 0.15, 0.2, 0.12],
    'MAPE_mean': [3.0, 4.0, 5.0, 2.8],
    'MAPE_std': [0.5, 0.6, 0.7, 0.4],
    'R2_mean': [0.9, 0.85, 0.8, 0.75],
    'R2_std': [0.05, 0.06, 0.07, 0.08]
}

df = pd.DataFrame(data)

# Create the dominance matrix
n = len(df)
dominance_matrix = np.zeros((n, n), dtype=bool)

for i in range(n):
    for j in range(n):
        if i != j:
            dominance_matrix[i, j] = strictly_dominates(df.iloc[i], df.iloc[j])

# Create the dominance graph
dominance_graph = {i: [] for i in range(n)}
for i in range(n):
    for j in range(n):
        if dominance_matrix[i, j]:
            dominance_graph[i].append(j)

# Create the NetworkX graph
G = nx.DiGraph(dominance_graph)

# Apply transitive reduction
G_reduced = nx.transitive_reduction(G)


# Get the topological order
topo_order = topological_sort(dominance_graph)

# Categorize models based on dominance
dominates_any = np.any(dominance_matrix, axis=1)
dominated_by_any = np.any(dominance_matrix, axis=0)

dominant_models = [df['Model'].iloc[i] for i in range(n) if dominates_any[i] and not dominated_by_any[i]]
non_dominated_models = [df['Model'].iloc[i] for i in range(n) if not dominates_any[i] and not dominated_by_any[i]]
failing_models = [df['Model'].iloc[i] for i in range(n) if dominated_by_any[i]]

print("Dominating Models:", dominant_models)
print("Non-Dominated Models:", non_dominated_models)
print("Failing Models:", failing_models)

# Map the topological order to the model names
sorted_models = [df['Model'].iloc[i] for i in topo_order]
print("Models in order of dominance:", sorted_models)

# Visualization of the reduced dominance graph
labels = {i: df['Model'].iloc[i] for i in range(n)}
pos = nx.spring_layout(G_reduced, seed=48, k=1.5)
# pos = nx.kamada_kawai_layout(G)

pos[3] = np.mean([pos[0], pos[1]], axis=1) + np.array([-0.3, 0.7])
# pos[1] = pos[0] + 0.02
# pos[2] = pos[1] + 0.05


#pos[1] = pos[1] + np.array([0.0, 0.2])
# pos[2] = pos[2] + np.array([0.01, 0.2])
# pos[2] = np.mean([pos[2], pos[0]], axis=1)
# pos[0] = pos[2] - pos[0]

fig, axes = plt.subplots(1, 1, figsize=(6.5, 5), sharex=False)  # 1 row, 2 columns
nx.draw(G_reduced, pos, ax=axes, labels=labels, with_labels=True, node_size=2100, node_color="skyblue", font_size=10, font_color="black", font_weight="bold", arrows=True)

# pos[3] = np.mean([pos[0], pos[1]], axis=1) + np.array([-0.3, 0.7])
#nx.draw(G_reduced, pos, labels=labels, with_labels=True, node_size=2100, node_color="skyblue", font_size=10, font_color="black", font_weight="bold", arrows=True)

#plt.title("Reduced Dominance Graph")
plt.title("Dominance Graph")
plt.show()
# Out:
# Dominating Models: ['A']
# Non-Dominated Models: ['D']
# Failing Models: ['B', 'C']
# Models in order of dominance: ['A', 'D', 'B', 'C']

# %%
data = {
    #'Model': ['Model A', 'Model B', 'Model C', 'Model D'],
    "Model": ["A", "B", "C", "D"],
    "RMSE_mean": [1.5, 2.0, 2.5, 2.1],
    "RMSE_std": [0.2, 0.25, 0.3, 0.25],
    "MAE_mean": [1.0, 1.5, 2.0, 1.4],
    "MAE_std": [0.1, 0.15, 0.2, 0.12],
    "MAPE_mean": [3.0, 4.0, 5.0, 2.8],
    "MAPE_std": [0.5, 0.6, 0.7, 0.4],
    "R2_mean": [0.9, 0.85, 0.8, 0.75],
    "R2_std": [0.05, 0.06, 0.07, 0.08],
}

df = pd.DataFrame(data)

# %%
df[["Model", "RMSE_mean", "MAE_mean", "MAPE_mean", "R2_mean"]]

# df = df.set_index("Model")

df
# Out:
#   Model  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  MAPE_std  R2_mean  \
# 0     A        1.5      0.20       1.0     0.10        3.0       0.5     0.90
# 1     B        2.0      0.25       1.5     0.15        4.0       0.6     0.85
# 2     C        2.5      0.30       2.0     0.20        5.0       0.7     0.80
# 3     D        2.1      0.25       1.4     0.12        2.8       0.4     0.75
#
#    R2_std
# 0    0.05
# 1    0.06
# 2    0.07
# 3    0.08

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
standardized_metrics = scaler.fit_transform(
    df[["RMSE_mean", "MAE_mean", "MAPE_mean", "R2_mean"]]
)

# Creating a new dataframe with standardized values
standardized_df = pd.DataFrame(
    standardized_metrics,
    columns=["RMSE_mean", "MAE_mean", "MAPE_mean", "R2_mean"],
)

# Summing all metrics and subtracting R2_mean
standardized_df["Result"] = (
    standardized_df[["RMSE_mean", "MAE_mean", "MAPE_mean"]].sum(axis=1)
    - standardized_df["R2_mean"]
)

# %%
standardized_df["Model"] = df["Model"]
standardized_df
# Out:
#    RMSE_mean  MAE_mean  MAPE_mean   R2_mean    Result Model
# 0  -1.473911 -1.333539  -0.797724  1.341641 -4.946814     A
# 1  -0.070186  0.070186   0.341882  0.447214 -0.105332     B
# 2   1.333539  1.473911   1.481487 -0.447214  4.736151     C
# 3   0.210559 -0.210559  -1.025645 -1.341641  0.315996     D

# %%
import pandas as pd
import numpy as np
from collections import deque, defaultdict
import networkx as nx
import matplotlib.pyplot as plt

df = standardized_df
# Function to compare two models strictly
def strictly_dominates(model1, model2):
    """Return True if model1 strictly dominates model2, False otherwise."""
    return model1['Result'] < model2['Result']

# Create the dominance matrix
n = len(df)
dominance_matrix = np.zeros((n, n), dtype=bool)

for i in range(n):
    for j in range(n):
        if i != j:
            dominance_matrix[i, j] = strictly_dominates(df.iloc[i], df.iloc[j])

# Create the dominance graph
dominance_graph = {i: [] for i in range(n)}
for i in range(n):
    for j in range(n):
        if dominance_matrix[i, j]:
            dominance_graph[i].append(j)

# Create the NetworkX graph
G = nx.DiGraph(dominance_graph)

# Apply transitive reduction
G_reduced = nx.transitive_reduction(G)

# Topological Sorting
def topological_sort(graph):
    """Perform topological sorting on the given graph."""
    in_degree = {u: 0 for u in graph}
    for u in graph:
        for v in graph[u]:
            in_degree[v] += 1
    
    queue = deque([u for u in graph if in_degree[u] == 0])
    topo_order = []
    
    while queue:
        u = queue.popleft()
        topo_order.append(u)
        
        for v in graph[u]:
            in_degree[v] -= 1
            if in_degree[v] == 0:
                queue.append(v)
    
    return topo_order

# Get the topological order
topo_order = topological_sort(dominance_graph)

# Categorize models based on dominance
dominates_any = np.any(dominance_matrix, axis=1)
dominated_by_any = np.any(dominance_matrix, axis=0)

dominant_models = [df['Model'].iloc[i] for i in range(n) if dominates_any[i] and not dominated_by_any[i]]
non_dominated_models = [df['Model'].iloc[i] for i in range(n) if not dominates_any[i] and not dominated_by_any[i]]
failing_models = [df['Model'].iloc[i] for i in range(n) if dominated_by_any[i]]

print("Dominating Models:", dominant_models)
print("Non-Dominated Models:", non_dominated_models)
print("Failing Models:", failing_models)

# Map the topological order to the model names
sorted_models = [df['Model'].iloc[i] for i in topo_order]
print("Models in order of dominance:", sorted_models)

# Visualization of the reduced dominance graph
labels = {i: df['Model'].iloc[i] for i in range(n)}
pos = nx.spring_layout(G_reduced, seed=48, k=1.5)
# pos = nx.kamada_kawai_layout(G)

# pos[3] = np.mean([pos[0], pos[1]], axis=1) + np.array([-0.3, 0.7])
# pos[1] = pos[0] + 0.02
# pos[2] = pos[1] + 0.05


#pos[1] = pos[1] + np.array([0.0, 0.2])
# pos[2] = pos[2] + np.array([0.01, 0.2])
# pos[2] = np.mean([pos[2], pos[0]], axis=1)
# pos[0] = pos[2] - pos[0]

fig, axes = plt.subplots(1, 1, figsize=(6.5, 5), sharex=False)  # 1 row, 2 columns
nx.draw(G_reduced, pos, ax=axes, labels=labels, with_labels=True, node_size=2100, node_color="skyblue", font_size=10, font_color="black", font_weight="bold", arrows=True)

# pos[3] = np.mean([pos[0], pos[1]], axis=1) + np.array([-0.3, 0.7])
#nx.draw(G_reduced, pos, labels=labels, with_labels=True, node_size=2100, node_color="skyblue", font_size=10, font_color="black", font_weight="bold", arrows=True)

#plt.title("Reduced Dominance Graph")
plt.title("Dominance Graph")
plt.show()
# Out:
# Dominating Models: ['A']
# Non-Dominated Models: []
# Failing Models: ['B', 'C', 'D']
# Models in order of dominance: ['A', 'B', 'D', 'C']

# %%
dominance_matrix
# Out:
# array([[False,  True,  True,  True],
#        [False, False,  True,  True],
#        [False, False, False, False],
#        [False, False,  True, False]])

# %%
import pandas as pd
import numpy as np
from collections import deque, defaultdict
import networkx as nx
import matplotlib.pyplot as plt

# Sample DataFrame containing the results for each model, including standard deviations
data = {
    'Model': ['Model1', 'Model2', 'Model3', 'Model4'],
    'RMSE_mean': [1.5, 2.0, 2.5, 2.1],
    'RMSE_std': [0.2, 0.25, 0.3, 0.25],
    'MAE_mean': [1.0, 1.5, 2.0, 1.4],
    'MAE_std': [0.1, 0.15, 0.2, 0.12],
    'MAPE_mean': [3.0, 4.0, 5.0, 2.8],
    'MAPE_std': [0.5, 0.6, 0.7, 0.4],
    'R2_mean': [0.9, 0.85, 0.8, 0.75],
    'R2_std': [0.05, 0.06, 0.07, 0.08]
}

df = pd.DataFrame(data)

# Function to compare two models strictly
def strictly_dominates(model1, model2):
    """Return True if model1 strictly dominates model2, False otherwise."""
    return (model1['RMSE_mean'] < model2['RMSE_mean'] and
            model1['MAE_mean'] < model2['MAE_mean'] and
            model1['MAPE_mean'] < model2['MAPE_mean'] and
            model1['R2_mean'] > model2['R2_mean'])

# Create the dominance matrix
n = len(df)
dominance_matrix = np.zeros((n, n), dtype=bool)

for i in range(n):
    for j in range(n):
        if i != j:
            dominance_matrix[i, j] = strictly_dominates(df.iloc[i], df.iloc[j])

# Create the dominance graph
dominance_graph = {i: [] for i in range(n)}
for i in range(n):
    for j in range(n):
        if dominance_matrix[i, j]:
            dominance_graph[i].append(j)

# Create the NetworkX graph
G = nx.DiGraph(dominance_graph)

# Apply transitive reduction
G_reduced = nx.transitive_reduction(G)

# Topological Sorting
def topological_sort(graph):
    """Perform topological sorting on the given graph."""
    in_degree = {u: 0 for u in graph}
    for u in graph:
        for v in graph[u]:
            in_degree[v] += 1
    
    queue = deque([u for u in graph if in_degree[u] == 0])
    topo_order = []
    
    while queue:
        u = queue.popleft()
        topo_order.append(u)
        
        for v in graph[u]:
            in_degree[v] -= 1
            if in_degree[v] == 0:
                queue.append(v)
    
    return topo_order

# Get the topological order
topo_order = topological_sort(dominance_graph)

# Categorize models based on dominance
dominates_any = np.any(dominance_matrix, axis=1)
dominated_by_any = np.any(dominance_matrix, axis=0)

dominant_models = [df['Model'].iloc[i] for i in range(n) if not dominated_by_any[i]]
non_dominated_models = [df['Model'].iloc[i] for i in range(n) if not dominates_any[i] and not dominated_by_any[i]]
failing_models = [df['Model'].iloc[i] for i in range(n) if dominated_by_any[i] and not dominates_any[i]]

print("Dominant Models:", dominant_models)
print("Non-Dominated Models:", non_dominated_models)
print("Failing Models:", failing_models)

# Map the topological order to the model names
sorted_models = [df['Model'].iloc[i] for i in topo_order]
print("Models in order of dominance:", sorted_models)

# Visualization of the reduced dominance graph
labels = {i: df['Model'].iloc[i] for i in range(n)}
pos = nx.spring_layout(G_reduced, seed=48, k=1.5)

pos[3] = np.mean([pos[0], pos[1]], axis=1) + np.array([-0.3, 0.7])

nx.draw(G_reduced, pos, labels=labels, with_labels=True, node_size=2100, node_color="skyblue", font_size=10, font_color="black", font_weight="bold", arrows=True)
plt.title("Dominance Graph")
plt.show()
# Out:
# Dominant Models: ['Model1', 'Model4']
# Non-Dominated Models: ['Model4']
# Failing Models: ['Model3']
# Models in order of dominance: ['Model1', 'Model4', 'Model2', 'Model3']

# %%
df_full.shape
# Out:
# (60150, 24)

# %%
df_full["plant"].unique()
# Out:
# array(['partner_i', 'partner_ii', 'partner_iv', 'av', 'c', 'd', 'g', 'm', 'y', 'a', 'ab',
#        'ae', 'aq', 'ay', 'f', 'i', 'o', 'r', 't', 'b', 'at', 'aa', 'ac',
#        'ag', 'ai', 'am', 'an', 'ap', 'as', 'az', 'e', 'h', 'j', 'k', 'l',
#        'n', 'p', 'q', 's', 'u', 'v', 'w', 'x', 'z'], dtype=object)

# %%
df_full_ecics = df_full[df_full["plant"].isin(["partner_i", "partner_ii", "partner_iv"])].reset_index(
    drop=True
)
df_full_ecics = df_full[~df_full["plant"].isin(["partner_i", "partner_ii", "partner_iv"])].reset_index(
    drop=True
)

# %%
df_full.shape
# Out:
# (60150, 24)

# %%
df_full_ecics.shape
# Out:
# (55695, 24)

# %%
df_full_ecics.shape
# Out:
# (55695, 24)

# %%
df_full_ecics[["RMSE Test", "MAE Test", "MAPE Test", "R2 Test"]].describe().round(2).T
# Out:
#              count   mean     std       min   25%   50%   75%     max
# RMSE Test  55695.0   4.66    7.46      0.26  2.05  3.13  5.09  776.07
# MAE Test   55695.0   3.52    4.75      0.20  1.61  2.44  3.96  476.59
# MAPE Test  55695.0   0.08    0.11      0.01  0.04  0.06  0.09   10.22
# R2 Test    55695.0 -14.93  386.18 -68227.01 -0.91  0.47  0.83    0.99

# %%
df_full_ecics[["RMSE Test", "MAE Test", "MAPE Test", "R2 Test"]].describe().round(2).T
# Out:
#              count   mean     std       min   25%   50%   75%     max
# RMSE Test  55695.0   4.66    7.46      0.26  2.05  3.13  5.09  776.07
# MAE Test   55695.0   3.52    4.75      0.20  1.61  2.44  3.96  476.59
# MAPE Test  55695.0   0.08    0.11      0.01  0.04  0.06  0.09   10.22
# R2 Test    55695.0 -14.93  386.18 -68227.01 -0.91  0.47  0.83    0.99

# %% [markdown]
# # Analysis (full results)

# %%
df_full_inn = df_full[df_full["plant"].isin(["partner_i", "partner_ii", "partner_iv"])].reset_index(
    drop=True
)
df_full_ecics = df_full[~df_full["plant"].isin(["partner_i", "partner_ii", "partner_iv"])].reset_index(
    drop=True
)

# %% [markdown]
# ## ECICS

# %%
df_full_ecics.shape
# Out:
# (55695, 24)

# %%
df_full_ecics["Company"].unique()
# Out:
# array([203, 204, 206, 207, 209], dtype=object)

# %% [markdown]
# ### Variable Grouping: CM

# %%
df_full_ecics["Features"].unique()
# Out:
# array(['Chemical + Mineralogical + Physical - Early CS',
#        'Chemical + Mineralogical + Physical', 'Chemical + Mineralogical'],
#       dtype=object)

# %%
df_results_full_cm = (
    df_full_ecics[df_full_ecics["Features"].eq("Chemical + Mineralogical")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_full_cm["Features"].unique()
# Out:
# array(['Chemical + Mineralogical'], dtype=object)

# %%
df_results_full_cm.shape
# Out:
# (18595, 24)

# %% [markdown]
# #### K-Fold

# %%
df_results_full_cm["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split', 'Time Series Split'], dtype=object)

# %%
df_results_full_cm_kf = (
    df_results_full_cm[df_results_full_cm["Cross Validation"].eq("Repeated KFold")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_full_cm_kf["Cross Validation"].unique()
# Out:
# array([], dtype=object)

# %%
df_results_full_cm_kf.shape
# Out:
# (0, 24)

# %%
df_results_full_cm_kf.groupby(["Company", "Model", "Timesteps"], dropna=False)[
    "RMSE Test"
].mean().shape
# Out:
# (0,)

# %% [markdown]
# ### Blocking time series

# %%
df_results_full_cm["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split', 'Time Series Split'], dtype=object)

# %%
df_results_full_cm_btss = (
    df_results_full_cm[
        df_results_full_cm["Cross Validation"].eq("Blocking Time Series Split")
    ]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_full_cm_btss["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split'], dtype=object)

# %%
df_results_full_cm_btss.shape
# Out:
# (9110, 24)

# %%
df_results_full_cm_btss.groupby(
    ["Company", "Plant", "Model", "Timesteps"], dropna=False
)["RMSE Test"].mean().shape
# Out:
# (714,)

# %% [markdown]
# ### Time Series Split

# %%
df_results_full_cm["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split', 'Time Series Split'], dtype=object)

# %%
df_results_full_cm_tss = (
    df_results_full_cm[df_results_full_cm["Cross Validation"].eq("Time Series Split")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_full_cm_tss["Cross Validation"].unique()
# Out:
# array(['Time Series Split'], dtype=object)

# %%
df_results_full_cm_tss.shape
# Out:
# (9485, 24)

# %%
df_results_full_cm_tss.groupby(
    ["Company", "Plant", "Model", "Timesteps"], dropna=False
)["RMSE Test"].mean().shape
# Out:
# (741,)

# %% [markdown]
# ### Variable Grouping: CM-P

# %%
df_full_ecics["Features"].unique()
# Out:
# array(['Chemical + Mineralogical + Physical - Early CS',
#        'Chemical + Mineralogical + Physical', 'Chemical + Mineralogical'],
#       dtype=object)

# %%
df_results_full_cm_p = (
    df_full_ecics[
        df_full_ecics["Features"].eq("Chemical + Mineralogical + Physical - Early CS")
    ]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_full_cm_p["Features"].unique()
# Out:
# array(['Chemical + Mineralogical + Physical - Early CS'], dtype=object)

# %%
df_results_full_cm_p.shape
# Out:
# (18595, 24)

# %% [markdown]
# ### K-Fold

# %%
# df_results_full_cm_p["Cross Validation"].unique()

# %%
# df_results_full_cm_p_kf = (
#     df_results_full_cm_p[df_results_full_cm_p["Cross Validation"].eq("Repeated KFold")]
#     .copy()
#     .reset_index(drop=True)
# )

# %%
# df_results_full_cm_p_kf["Cross Validation"].unique()

# %%
# df_results_full_cm_p_kf.shape

# %%
# df_results_full_cm_kf.groupby(["Company", "Model", "Timesteps"], dropna=False)[
#     "RMSE Test"
# ].mean().shape

# %% [markdown]
# ### Blocking time series

# %%
df_results_full_cm_p["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split', 'Time Series Split'], dtype=object)

# %%
df_results_full_cm_p_btss = (
    df_results_full_cm_p[
        df_results_full_cm_p["Cross Validation"].eq("Blocking Time Series Split")
    ]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_full_cm_p_btss["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split'], dtype=object)

# %%
df_results_full_cm_p_btss.shape
# Out:
# (9110, 24)

# %%
df_results_full_cm_p_btss.shape, df_results_full_cm_btss.shape
# Out:
# ((9110, 24), (9110, 24))

# %%
df_results_full_cm_p_btss.groupby(
    ["Company", "Cross Validation", "Plant", "Model", "Timesteps"], dropna=False
)["RMSE Test"].mean().shape
# Out:
# (714,)

# %%
df_results_full_cm_btss.shape, df_results_full_cm_p_btss.shape

df1 = df_results_full_cm_btss
df2 = df_results_full_cm_p_btss

grouping_columns = ["Company", "Plant", "Model", "Timesteps"]

# %%
# Group by and get sizes for both datasets
group_sizes_df1 = df1.groupby(grouping_columns, dropna=False).size()
group_sizes_df2 = df2.groupby(grouping_columns, dropna=False).size()

# Compare group sizes directly
group_size_diff = group_sizes_df1.compare(group_sizes_df2)
print("Differences in group sizes:")
print(group_size_diff)
# Out:
# Differences in group sizes:
# Empty DataFrame
# Columns: [self, other]
# Index: []

# %%
# Group by and get sizes for both datasets
group_sizes_df1 = df1.groupby(grouping_columns, dropna=False).size()
group_sizes_df2 = df2.groupby(grouping_columns, dropna=False).size()

# Compare group sizes directly
group_size_diff = group_sizes_df2.compare(group_sizes_df1)
print("Differences in group sizes:")
print(group_size_diff)
# Out:
# Differences in group sizes:
# Empty DataFrame
# Columns: [self, other]
# Index: []

# %% [markdown]
# ### Time Series Split

# %%
df_results_full_cm_p["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split', 'Time Series Split'], dtype=object)

# %%
df_results_full_cm_p_tss = (
    df_results_full_cm_p[
        df_results_full_cm_p["Cross Validation"].eq("Time Series Split")
    ]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_full_cm_p_tss["Cross Validation"].unique()
# Out:
# array(['Time Series Split'], dtype=object)

# %%
df_results_full_cm_p_tss.shape
# Out:
# (9485, 24)

# %%
df_results_full_cm_p_tss.groupby(
    ["Company", "Model", "Plant", "Timesteps"], dropna=False
)["RMSE Test"].mean().shape
# Out:
# (741,)

# %% [markdown]
# ### Variable Grouping: CM-P-CS

# %%
df_full_ecics["Features"].unique()
# Out:
# array(['Chemical + Mineralogical + Physical - Early CS',
#        'Chemical + Mineralogical + Physical', 'Chemical + Mineralogical'],
#       dtype=object)

# %%
df_results_full_cm_p_cs = (
    df_full_ecics[df_full_ecics["Features"].eq("Chemical + Mineralogical + Physical")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_full_cm_p_cs["Features"].unique()
# Out:
# array(['Chemical + Mineralogical + Physical'], dtype=object)

# %%
df_results_full_cm_p_cs.shape
# Out:
# (18505, 24)

# %% [markdown]
# ### K-Fold

# %%
df_results_full_cm_p_cs["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split', 'Time Series Split'], dtype=object)

# %%
df_results_full_cm_p_cs_kf = (
    df_results_full_cm_p_cs[
        df_results_full_cm_p_cs["Cross Validation"].eq("Repeated KFold")
    ]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_full_cm_p_cs_kf["Cross Validation"].unique()
# Out:
# array([], dtype=object)

# %%
df_results_full_cm_p_cs_kf.shape
# Out:
# (0, 24)

# %%
df_results_full_cm_p_cs_kf.groupby(["Company", "Model", "Timesteps"], dropna=False)[
    "RMSE Test"
].mean().shape
# Out:
# (0,)

# %% [markdown]
# ### Blocking time series

# %%
df_results_full_cm_p_cs["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split', 'Time Series Split'], dtype=object)

# %%
df_results_full_cm_p_cs_btss = (
    df_results_full_cm_p_cs[
        df_results_full_cm_p_cs["Cross Validation"].eq("Blocking Time Series Split")
    ]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_full_cm_p_cs_btss["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split'], dtype=object)

# %%
df_results_full_cm_p_cs_btss.shape
# Out:
# (9110, 24)

# %%
df_results_full_cm_p_cs_btss.groupby(
    ["Company", "Plant", "Model", "Timesteps"], dropna=False
)["RMSE Test"].mean().shape
# Out:
# (714,)

# %% [markdown]
# ### Time Series Split

# %%
df_results_full_cm_p_cs["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split', 'Time Series Split'], dtype=object)

# %%
df_results_full_cm_p_cs_tss = (
    df_results_full_cm_p_cs[
        df_results_full_cm_p_cs["Cross Validation"].eq("Time Series Split")
    ]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_full_cm_p_cs_tss["Cross Validation"].unique()
# Out:
# array(['Time Series Split'], dtype=object)

# %%
df_results_full_cm_p_cs_tss.shape
# Out:
# (9395, 24)

# %%
df_results_full_cm_p_cs_tss.groupby(
    ["Company", "Plant", "Model", "Timesteps"], dropna=False
)["RMSE Test"].mean().shape
# Out:
# (735,)

# %% [markdown]
# # Grouped Dataset

# %%
dfs_plant = dict()
column = ("plant", "")
pos = 2

for plant, csv_files in csv_files_path_grouped.items():
    df = read_csv_files_grouped(csv_files, plant)
    df["plant"] = plant
    df = preprocess_rename_columns(df)
    df = preprocess_change_columns_order(df, column, pos)
    dfs_plant[plant] = df

# %%
df = pd.concat(dfs_plant)
df_copy = df.copy()
df_copy = (
    df_copy.reset_index(level=0)
    .rename({"level_0": "Plant"}, axis=1)
    .reset_index(drop=True)
)

# %%
df_copy.shape
# Out:
# (26084, 26)

# %%
filter_df = df_copy[df_copy["Company"].isin(["partner_i", "partner_ii", "partner_iv"])]

# %%
filter_df[["RMSE Test", "MAE Test", "MAPE Test", "R2 Test"]].describe().T
# Out:
#                  count      mean        std         min       25%       50%  \
# RMSE Test mean  2988.0  3.936802   2.629864    0.906304  2.176814  3.292064
#           std   2988.0  1.335608   1.807978    0.000000  0.159884  0.451459
# MAE Test  mean  2988.0  3.055642   1.919555    0.708813  1.662497  2.550537
#           std   2988.0  1.010559   1.378716    0.000000  0.114215  0.338375
# MAPE Test mean  2988.0  0.070164   0.043779    0.016380  0.039206  0.058431
#           std   2988.0  0.023317   0.031710    0.000000  0.002688  0.008326
# R2 Test   mean  2988.0 -2.014462  13.004017 -526.750990 -0.915806  0.332616
#           std   2988.0  3.244529  14.427714    0.000000  0.039575  0.198876
#
#                      75%         max
# RMSE Test mean  5.033506   50.349352
#           std   2.072176   34.573759
# MAE Test  mean  3.922136   21.774882
#           std   1.505030   12.915692
# MAPE Test mean  0.089626    0.463917
#           std   0.034544    0.276922
# R2 Test   mean  0.717860    0.967455
#           std   1.578444  492.863866

# %% [markdown]
# ## Preprocessing steps

# %%
patterns = [
    "Chemical + Mineralogical + Feature Engineering",
    "Chemical + Mineralogical + CS7 + One-Hot",
    "Chemical + Mineralogical + Physical + One-Hot",
    "Chemical + Mineralogical + CS3 + One-Hot",
    "Chemical + Mineralogical + CS3 + CS7 + One-Hot",
    "Chemical + Mineralogical + One-Hot",
    "Chemical + Mineralogical + CS1 + CS3 + CS7 + One-Hot",
    "Chemical + Mineralogical + CS1 + CS3 + One-Hot",
    "Chemical + Mineralogical + CS1 + One-Hot",
    "Chemical + Mineralogical + CS2 + One-Hot",
    "Chemical + Feature Engineering",
]

replace_dict = {
    "Chemical + Mineralogical + CS3 + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS3": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS1": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS1 + CS3": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS1 + CS3 + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS2": "Chemical + Mineralogical + Early CS",
    "Chemical + CS1 + CS3 + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + CS3 + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + CS3": "Chemical + Mineralogical + Early CS",
    "Chemical + CS1 + CS3": "Chemical + Mineralogical + Early CS",
    "Chemical + CS1": "Chemical + Mineralogical + Early CS",
    "Chemical + CS1 + CS7": "Chemical + Mineralogical + Early CS",
}

replace_dict_2 = {
    "Chemical": "Chemical + Mineralogical",
    "Chemical + Properties CS Less": "Chemical + Mineralogical + Physical - Early CS",
    "Chemical + Mineralogical + Properties CS Less": "Chemical + Mineralogical + Physical - Early CS",
    "Chemical + Physical": "Chemical + Mineralogical + Physical",
}

df_copy = df_copy[~df_copy["Cross Validation"].eq("Out of time Split")].reset_index(
    drop=True
)

# Removing afterwards
df_copy = df_copy[~df_copy["Cross Validation"].eq("Repeated KFold")].reset_index(
    drop=True
)

df_copy = df_copy[~df_copy["Features"].apply(lambda x: x in patterns)].reset_index(
    drop=True
)
df_copy["Features_bkp"] = df_copy["Features"].copy()
df_copy["Features"] = df_copy["Features"].replace(replace_dict)

df_copy["Features"] = df_copy["Features"].replace(replace_dict_2)

# Removing afterwards
df_copy = df_copy[
    ~df_copy["Features"].eq("Chemical + Mineralogical + Early CS")
].reset_index(drop=True)

# %%
df_copy[("MAPE Train", "mean")] = df_copy[("MAPE Train", "mean")] * 100
df_copy[("MAPE Train", "std")] = df_copy[("MAPE Train", "std")] * 100
df_copy[("MAPE Test", "mean")] = df_copy[("MAPE Test", "mean")] * 100
df_copy[("MAPE Test", "std")] = df_copy[("MAPE Test", "std")] * 100

df_copy["Model_bkp"] = df_copy["Model"].copy()
df_copy["Model_bkp_2"] = df_copy["Model"] + df_copy["Timesteps"].apply(
    lambda x: "" if pd.isna(x) else "_" + str(x)
)
df_copy["Model"] = df_copy["Model"].replace(
    {
        "MLP": "Neural Networks",
        "LSTM": "Neural Networks",
        "GRU": "Neural Networks",
        "BidirectionalLSTM": "Neural Networks",
        "BidirectionalGRU": "Neural Networks",
        "Transformer": "Neural Networks",
        "Decision Tree": "Trees",
        "Random Forest": "Trees",
        "XGBoost": "Trees",
    }
)

# %%
df_copy["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split', 'Time Series Split'], dtype=object)

# %%
df_copy["Features"].unique()
# Out:
# array(['Chemical + Mineralogical',
#        'Chemical + Mineralogical + Physical - Early CS',
#        'Chemical + Mineralogical + Physical'], dtype=object)

# %%
df_copy["Model"].unique()
# Out:
# array(['Neural Networks', 'Trees', 'Linear Regression'], dtype=object)

# %%
df_copy["Model_bkp"].unique()
# Out:
# array(['Transformer', 'MLP', 'BidirectionalLSTM', 'XGBoost',
#        'BidirectionalGRU', 'GRU', 'Linear Regression', 'Decision Tree',
#        'Random Forest', 'LSTM'], dtype=object)

# %%
df_copy["Model_bkp_2"].unique()
# Out:
# array(['Transformer_1.0', 'Transformer_7.0', 'Transformer_14.0', 'MLP',
#        'BidirectionalLSTM_1.0', 'BidirectionalLSTM_7.0',
#        'BidirectionalLSTM_14.0', 'XGBoost', 'BidirectionalGRU_1.0',
#        'BidirectionalGRU_7.0', 'BidirectionalGRU_14.0', 'GRU_1.0',
#        'GRU_7.0', 'GRU_14.0', 'Linear Regression', 'Decision Tree',
#        'Random Forest', 'LSTM_1.0', 'LSTM_7.0', 'LSTM_14.0'], dtype=object)

# %%
df_copy.shape
# Out:
# (4704, 29)

# %%
df_copy_grouped = df_copy.copy()

# %%
df_copy[
    [
        ("RMSE Test", "mean"),
        ("MAE Test", "mean"),
        ("MAPE Test", "mean"),
        ("R2 Test", "mean"),
    ]
].describe().round(2).T
# Out:
#                  count   mean     std      min   25%   50%   75%    max
# RMSE Test mean  4704.0   4.37    3.50     0.74  2.27  3.41  5.29  65.45
# MAE Test  mean  4704.0   3.32    2.50     0.56  1.74  2.63  4.04  41.17
# MAPE Test mean  4704.0   7.70    5.82     1.32  4.10  6.11  9.29  89.16
# R2 Test   mean  4704.0 -11.84  120.40 -4690.18 -1.65  0.20  0.75   0.98

# %%
(df_copy[("R2 Test", "mean")] < 0).sum()
# Out:
# 2108

# %%
(df_copy[("MAPE Test", "mean")] > 100).sum()
# Out:
# 0

# %%
(df_copy[("RMSE Test", "mean")] > 100).sum()
# Out:
# 0

# %%
(df_copy[("MAE Test", "mean")] > 100).sum()
# Out:
# 0

# %%
(
    (df_copy[("R2 Test", "mean")] < 0)
    | (df_copy[("MAPE Test", "mean")] > 100)
    | (df_copy[("RMSE Test", "mean")] > 100)
    | (df_copy[("MAE Test", "mean")] > 100)
).sum()
# Out:
# 2108

# %%
df_copy_2 = df_copy.copy()

# %%
df_copy = df_copy[
    ~(
        (df_copy[("R2 Test", "mean")] < 0)
        | (df_copy[("MAPE Test", "mean")] > 100)
        | (df_copy[("RMSE Test", "mean")] > 100)
        | (df_copy[("MAE Test", "mean")] > 100)
    )
].reset_index(drop=True)

# %%
set(df_copy_2["Plant"].unique()) - set(df_copy["Plant"].unique())
# Out:
# {'ag'}

# %%
df_copy[
    [
        ("RMSE Test", "mean"),
        ("MAE Test", "mean"),
        ("MAPE Test", "mean"),
        ("R2 Test", "mean"),
    ]
].describe().round(2).T
# Out:
#                  count  mean   std   min   25%   50%   75%    max
# RMSE Test mean  2596.0  2.65  1.05  0.74  1.87  2.47  3.27   6.91
# MAE Test  mean  2596.0  2.06  0.82  0.56  1.46  1.90  2.53   5.33
# MAPE Test mean  2596.0  4.83  1.87  1.32  3.45  4.47  5.93  11.87
# R2 Test   mean  2596.0  0.64  0.27  0.00  0.45  0.72  0.86   0.98

# %%
em_copy = df_copy[
    [
        ("RMSE Test", "mean"),
        ("MAE Test", "mean"),
        ("MAPE Test", "mean"),
        ("R2 Test", "mean"),
    ]
].copy()

em_copy.columns = ["RMSE", "MAE", "MAPE", "R2"]
em_copy.describe().round(2).T
# Out:
#        count  mean   std   min   25%   50%   75%    max
# RMSE  2596.0  2.65  1.05  0.74  1.87  2.47  3.27   6.91
# MAE   2596.0  2.06  0.82  0.56  1.46  1.90  2.53   5.33
# MAPE  2596.0  4.83  1.87  1.32  3.45  4.47  5.93  11.87
# R2    2596.0  0.64  0.27  0.00  0.45  0.72  0.86   0.98

# %%
df_copy[
    [
        ("RMSE Test", "std"),
        ("MAE Test", "std"),
        ("MAPE Test", "std"),
        ("R2 Test", "std"),
    ]
].describe().round(2).T
# Out:
#                 count  mean   std   min   25%   50%   75%   max
# RMSE Test std  2596.0  0.83  0.65  0.03  0.37  0.63  1.08  5.08
# MAE Test  std  2596.0  0.62  0.49  0.03  0.28  0.47  0.80  4.44
# MAPE Test std  2596.0  1.45  1.14  0.06  0.66  1.12  1.84  9.73
# R2 Test   std  2596.0  0.26  0.26  0.00  0.06  0.15  0.38  2.06

# %%
df_copy.shape
# Out:
# (2596, 29)

# %%
df_copy["plant"].unique()
# Out:
# array(['partner_i', 'partner_ii', 'partner_iv', 'av', 'c', 'd', 'g', 'm', 'y', 'a', 'ab',
#        'ae', 'aq', 'ay', 'f', 'i', 'o', 'r', 't', 'b', 'at', 'aa', 'ac',
#        'ai', 'am', 'an', 'ap', 'as', 'az', 'e', 'h', 'j', 'k', 'l', 'n',
#        'p', 'q', 's', 'u', 'v', 'w', 'x', 'z'], dtype=object)

# %%
df_inn_groupd = df_copy_grouped[df_copy_grouped["plant"].isin(["partner_i", "partner_ii", "partner_iv"])]
df_ecics_groupd = df_copy_grouped[
    ~df_copy_grouped["plant"].isin(["partner_i", "partner_ii", "partner_iv"])
]

# %%
df_inn_groupd.shape
# Out:
# (345, 29)

# %%
df_ecics_groupd.shape
# Out:
# (4359, 29)

# %%
df_full.shape
# Out:
# (60150, 24)

# %%
cols_groupby = [
    # "Category",
    # "Company",
    "plant",
    # "Data Shape",
    "Timesteps",
    "Features_bkp",
    "Model",
    "Cross Validation",
    "Cross Validation Params",
]

cols_agg = ["RMSE Train", "MAE Train", "MAPE Train", "R2 Train"] + [
    "RMSE Test",
    "MAE Test",
    "MAPE Test",
    "R2 Test",
]

df_results_to_save = (
    df_full.groupby(cols_groupby, dropna=False)[cols_agg]
    .agg(["mean", lambda series: pd.Series(series.std(ddof=0), name="std")])
    .reset_index()
    .rename(columns={"<lambda_0>": "std"})
)

# %%
# df_full["Model"]

# %%
df_results_to_save.shape
# Out:
# (4704, 22)

# %%
df_copy_grouped.shape
# Out:
# (4704, 29)

# %%
# for e in df_copy_grouped[
#     (df_copy_grouped[("R2 Test", "mean")] < 0) &
#     df_copy_grouped["Model"].isin(["Trees", "Linear Regression"])][["Company", "Plant"]]["Plant"].unique():
#     print(e)

# %% [markdown]
# # Topological Analysis - NEW

# %% [markdown]
# ## Definitions

# %%
# Function to compare two models strictly based on means only
def dominates(model1, model2):
    """Return True if model1 strictly dominates model2, False otherwise."""
    # Check if model1 is at least as good as model2 in all metrics
    at_least_as_good = (
        model1["RMSE_mean"] <= model2["RMSE_mean"]
        and model1["MAE_mean"] <= model2["MAE_mean"]
        and model1["MAPE_mean"] <= model2["MAPE_mean"]
        and model1["R2_mean"] >= model2["R2_mean"]
    )

    # Check if model1 is strictly better in at least one metric
    strictly_better_in_one = (
        model1["RMSE_mean"] < model2["RMSE_mean"]
        or model1["MAE_mean"] < model2["MAE_mean"]
        or model1["MAPE_mean"] < model2["MAPE_mean"]
        or model1["R2_mean"] > model2["R2_mean"]
    )

    # Model1 strictly dominates Model2 if it is at least as good in all metrics and
    # strictly better in at least one metric
    return at_least_as_good and strictly_better_in_one

# %%
def get_dominance_matrix_and_graph(df):
    n = len(df)
    dominance_matrix = np.zeros((n, n), dtype=bool)

    for i in range(n):
        for j in range(n):
            if i != j:
                dominance_matrix[i, j] = dominates(df.iloc[i], df.iloc[j])

    # Create the dominance graph
    dominance_graph = {i: [] for i in range(n)}
    for i in range(n):
        for j in range(n):
            if dominance_matrix[i, j]:
                dominance_graph[i].append(j)

    return dominance_matrix, dominance_graph

# %%
# Topological Sorting
def topological_sort(graph):
    """Perform topological sorting on the given graph."""
    in_degree = {u: 0 for u in graph}
    for u in graph:
        for v in graph[u]:
            in_degree[v] += 1

    queue = deque([u for u in graph if in_degree[u] == 0])
    topo_order = []

    while queue:
        u = queue.popleft()
        topo_order.append(u)

        for v in graph[u]:
            in_degree[v] -= 1
            if in_degree[v] == 0:
                queue.append(v)

    return topo_order

# %%
# Function to find the top models in each group
def find_top_models(group):
    max_net_dominance = group["Net_Dominance"].max()
    top_models = group[group["Net_Dominance"] == max_net_dominance]
    return top_models

# %% [markdown]
# ### Dominance Analysis and SCPM

# %%
def compute_scpm(df):
    scaler = StandardScaler()
    standardized_metrics = scaler.fit_transform(
        df[["RMSE_mean", "MAE_mean", "MAPE_mean", "R2_mean"]]
    )

    # Creating a new dataframe with standardized values
    standardized_df = pd.DataFrame(
        standardized_metrics,
        columns=["RMSE_mean", "MAE_mean", "MAPE_mean", "R2_mean"],
    )

    # Summing all metrics and subtracting R2_mean
    standardized_df["Result"] = (
        standardized_df[["RMSE_mean", "MAE_mean", "MAPE_mean"]].sum(axis=1)
        - standardized_df["R2_mean"]
    )

    df["SCPM"] = standardized_df["Result"]
    return df

# %%
def make_dominance_analysis(df):
    # Compute dominance matrix and graph
    dominance_matrix, dominance_graph = get_dominance_matrix_and_graph(df)

    # Get the topological order
    topo_order = topological_sort(dominance_graph)
    df = df.copy()
    n = len(topo_order)

    # Identify Dominant Models
    dominant_models = [
        df["Model_bkp_2"].iloc[i]
        for i in range(len(df))
        if not np.any(dominance_matrix[:, i])
    ]

    # Identify Non-Dominant Models
    non_dominant_models = [
        df["Model_bkp_2"].iloc[i]
        for i in range(len(df))
        if np.any(dominance_matrix[:, i])
    ]

    # Identify Models that are both dominated and dominate at least one
    intermediate_models = [
        df["Model_bkp_2"].iloc[i]
        for i in range(len(df))
        if np.any(dominance_matrix[:, i]) and np.any(dominance_matrix[i, :])
    ]

    # Add count of times each model is dominated by others
    df["Dominated_Count"] = np.sum(dominance_matrix, axis=0)

    # Classify models
    df["Classification"] = "intermediate_model"  # default to intermediate_model
    df.loc[
        ~np.any(dominance_matrix, axis=1) & np.any(dominance_matrix, axis=0),
        "Classification",
    ] = "non_dominant_model"
    df.loc[~np.any(dominance_matrix, axis=0), "Classification"] = "dominant_model"

    # Map the topological order to the model names and get dominance counts
    sorted_models = [df["Model"].iloc[i] for i in topo_order]

    df_sorted = df.iloc[topo_order].copy()
    df_sorted["Dominates_Count"] = dominance_matrix.sum(axis=1)[topo_order]
    df_sorted_topo = df_sorted.copy()

    df_sorted = df_sorted.sort_values(by="Dominates_Count", ascending=False)
    df_sorted_count = df_sorted.copy()

    return {
        "dominance_matrix": dominance_matrix,
        "dominance_graph": dominance_graph,
        "df_sorted_topo": df_sorted_topo,
        "df_sorted_count": df_sorted_count,
    }

# %% [markdown]
# # Analysis

# %% [markdown]
# ## ECICS

# %%
# Filter only ECICS project
df_ecics_grouped = df_copy_grouped[
    ~df_copy_grouped["plant"].isin(["partner_i", "partner_ii", "partner_iv"])
]

# %%
df_results = df_ecics_grouped[
    [
        ("Company", ""),
        ("plant", ""),
        ("Cross Validation", ""),
        ("Features", ""),
        ('Features_bkp', ''),
        ("Model", ""),
        ("Model_bkp", ""),         
        ('Model_bkp_2',''),
        ("Timesteps", ""),
        ("RMSE Test", "mean"),
        ("MAE Test", "mean"),
        ("MAPE Test", "mean"),
        ("R2 Test", "mean"),
        ("RMSE Test", "std"),
        ("MAE Test", "std"),
        ("MAPE Test", "std"),
        ("R2 Test", "std"),
    ]
].copy()
df_results = df_results.reset_index(drop=True)

# Rename columns
new_column_names = [
    "Company",
    "Plant",
    "Cross Validation",
    "Features",
    "Features_bkp",
    "Model",
    "Model_bkp",
    "Model_bkp_2",
    "Timesteps",
    "RMSE_mean",
    "MAE_mean",
    "MAPE_mean",
    "R2_mean",
    "RMSE_std",
    "MAE_std",
    "MAPE_std",
    "R2_std",
]

df_results.columns = new_column_names

# %%
df_results.shape
# Out:
# (4359, 17)

# %%
df_results["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split', 'Time Series Split'], dtype=object)

# %% [markdown]
# ## Variable Grouping: CM

# %%
df_results["Features"].unique()
# Out:
# array(['Chemical + Mineralogical + Physical', 'Chemical + Mineralogical',
#        'Chemical + Mineralogical + Physical - Early CS'], dtype=object)

# %%
df_results_cm = (
    df_results[df_results["Features"].eq("Chemical + Mineralogical")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm["Features"].unique()
# Out:
# array(['Chemical + Mineralogical'], dtype=object)

# %%
df_results_cm.shape
# Out:
# (1455, 17)

# %% [markdown]
# #### K-Fold

# %%
df_results_cm["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split', 'Time Series Split'], dtype=object)

# %%
df_results_cm_kf = (
    df_results_cm[df_results_cm["Cross Validation"].eq("Repeated KFold")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_kf["Cross Validation"].unique()
# Out:
# array([], dtype=object)

# %%
df_results_cm_kf.shape
# Out:
# (0, 17)

# %%
df_results_cm_kf_partner_i = df_results_cm_kf[
    df_results_cm_kf["Plant"].eq("partner_i")
].copy()
df_results_cm_kf_partner_ii = df_results_cm_kf[
    df_results_cm_kf["Plant"].eq("partner_ii")
].copy()
df_results_cm_kf_partner_iv = df_results_cm_kf[
    df_results_cm_kf["Plant"].eq("partner_iv")
].copy()

# %% [markdown]
# ###### SCPM computation

# %%
# df_results_cm_kf = compute_scpm(df_results_cm_kf)

# %% [markdown]
# ##### Dominance Analysis

# %%
# dominance_dict = make_dominance_analysis(df_results_cm_kf)
# dominance_matrix_cm_kf = dominance_dict["dominance_matrix"]
# dominance_graph_cm_kf = dominance_dict["dominance_graph"]
# df_sorted_count = dominance_dict["df_sorted_count"]
# df_sorted_topo = dominance_dict["df_sorted_topo"]

# %%
# dominance_matrix_cm_kf.shape, len(dominance_graph_cm_kf)

# %%
# df_sorted_topo["Classification"].value_counts()

# %%
# df_sorted_topo.to_csv(
#     "../../../../reports/results/local_models/ecics/ecics_dominance_analysis_cm_kf.csv",
#     index=False,
# )

# %%
# df_sorted_topo.head(5)

# %%
# df_sorted_topo_cols = df_sorted_topo[
#     [
#         # "Model",
#         # "Model_bkp",
#         "Model_bkp_2",
#         "RMSE_mean",
#         "RMSE_std",
#         "MAE_mean",
#         "MAE_std",
#         "MAPE_mean",
#         "MAPE_std",
#         "R2_mean",
#         "R2_std",
#         "SCPM",
#         "Dominated_Count",
#         "Classification",
#         "Dominates_Count",
#         "Plant",
#     ]
# ].round(2)

# %% [markdown]
# ##### Top dominant models

# %%
# # Top 4
# df_sorted_topo_cols.iloc[0:2]

# %% [markdown]
# ##### Top intermediate models

# %%
# df_sorted_topo_cols[
#     df_sorted_topo_cols["Classification"].eq("intermediate_model")
# ].sort_values(by="Dominates_Count", ascending=False).iloc[:2]

# %% [markdown]
# ##### Top non dominant models

# %%
# df_sorted_topo_cols[
#     df_sorted_topo_cols["Classification"].eq("non_dominant_model")
# ].sort_values(by="Dominated_Count", ascending=True).iloc[:2]

# %%
# df_sorted_topo.columns

# %%
# round(58 / 60, 2), round(31 / 60, 2)

# %%
# df_sorted_topo_models_cols = df_sorted_topo[
#     [
#         "Model",
#         # "Model_bkp",
#         # "Model_bkp_2",
#         "RMSE_mean",
#         "RMSE_std",
#         "MAE_mean",
#         "MAE_std",
#         "MAPE_mean",
#         "MAPE_std",
#         "R2_mean",
#         "R2_std",
#         "SCPM",
#         "Dominated_Count",
#         "Dominates_Count",
#         "Classification",
#         "Plant",
#     ]
# ]  # .round(2)

# %%
# df_sorted_topo["Model"].value_counts()

# %%
# df_sorted_topo_models_grouped = df_sorted_topo_models_cols.groupby("Model").describe().T

# %%
# pd.set_option("display.max_rows", None)
# df_sorted_topo_models_grouped

# %%
# df_sorted_topo_models_cols = df_sorted_topo[
#     [
#         "Model",
#         "Dominated_Count",
#         "Dominates_Count",
#         "Classification",
#     ]
# ]

# %%
# df_sorted_topo_models_cols.groupby("Model").describe().round(2)

# %%
# df_sorted_topo_models_cols.groupby("Model")["Classification"].describe()

# %%
# df_sorted_topo_models_cols.groupby("Model")[["Classification"]].value_counts()

# %%
# (
#     df_sorted_topo_models_cols.groupby("Model")[["Classification"]]
#     .value_counts(normalize=True)
#     .to_frame()
#     * 100
# ).round(2)

# %%
# df_sorted_topo_models_cols

# %%
# summary_stats = df_sorted_topo_models_cols.groupby("Model").agg(
#     Total_Models=("Model", "count"),
#     Mean_Dominance_Count=("Dominates_Count", "mean"),
#     Median_Dominance_Count=("Dominates_Count", "median"),
#     Total_Dominated=("Dominated_Count", "sum"),
#     Total_Dominating=("Dominates_Count", "sum"),
# )

# total_models = summary_stats[
#     "Total_Models"
# ].sum()  # Get the total number of models across all categories
# summary_stats["Dominance Proportion"] = summary_stats["Total_Dominating"] / total_models

# %%
# summary_stats

# %%
# df_sorted_topo_models_grouped.T

# %% [markdown]
# ### SCPM Analysis

# %%
# cols = [
#     # "Model",
#     # "Model_bkp",
#     "Model_bkp_2",
#     "RMSE_mean",
#     "RMSE_std",
#     "MAE_mean",
#     "MAE_std",
#     "MAPE_mean",
#     "MAPE_std",
#     "R2_mean",
#     "R2_std",
#     "SCPM",
#     "Dominated_Count",
#     "Dominates_Count",
#     "Classification",
#     "Plant",
# ]

# %%
# df_sorted_scpm = df_sorted_topo.sort_values(by="SCPM").copy()

# %%
# # (df_sorted_topo[cols].reset_index() == df_sorted_scpm[cols].reset_index()).all(axis=1)
# df_sorted_scpm["topo_scmp_order_eq"] = df_sorted_topo.index == df_sorted_scpm.index

# %%
# df_sorted_topo[cols].round(2).head(5)

# %%
# df_sorted_scpm[cols + ["topo_scmp_order_eq"]].round(2).head(5)

# %% [markdown]
# ### Blocking time series

# %%
df_results_cm["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split', 'Time Series Split'], dtype=object)

# %%
df_results_cm_btss = (
    df_results_cm[df_results_cm["Cross Validation"].eq("Blocking Time Series Split")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_btss["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split'], dtype=object)

# %%
df_results_cm_btss.shape
# Out:
# (714, 17)

# %% [markdown]
# ###### SCPM computation

# %%
df_results_cm_btss = compute_scpm(df_results_cm_btss)

# %% [markdown]
# ##### Dominance Analysis

# %%
# Per project
dominance_dict = make_dominance_analysis(df_results_cm_btss)
dominance_matrix_cm_btss = dominance_dict["dominance_matrix"]
dominance_graph_cm_btss = dominance_dict["dominance_graph"]
df_sorted_count = dominance_dict["df_sorted_count"]
df_sorted_topo = dominance_dict["df_sorted_topo"]

# %%
dominance_matrix_cm_btss.shape, len(dominance_graph_cm_btss)
# Out:
# ((714, 714), 714)

# %%
df_sorted_topo["Classification"].value_counts()
# Out:
# Classification
# intermediate_model    711
# dominant_model          2
# non_dominant_model      1
# Name: count, dtype: int64

# %%
df_sorted_topo.to_csv(
    "../../../../reports/results/local_models/ecics/ecics_dominance_analysis_cm_btss.csv",
    index=False,
)

# %%
df_sorted_topo.head(5)
# Out:
#     Company Plant            Cross Validation                  Features  \
# 633     209     s  Blocking Time Series Split  Chemical + Mineralogical
# 696     209     x  Blocking Time Series Split  Chemical + Mineralogical
# 624     209     s  Blocking Time Series Split  Chemical + Mineralogical
# 636     209     s  Blocking Time Series Split  Chemical + Mineralogical
# 688     209     w  Blocking Time Series Split  Chemical + Mineralogical
#
#     Features_bkp              Model          Model_bkp        Model_bkp_2  \
# 633     Chemical              Trees      Random Forest      Random Forest
# 696     Chemical  Linear Regression  Linear Regression  Linear Regression
# 624     Chemical    Neural Networks        Transformer    Transformer_1.0
# 636     Chemical              Trees      Decision Tree      Decision Tree
# 688     Chemical              Trees      Random Forest      Random Forest
#
#      Timesteps  RMSE_mean  ...  MAPE_mean   R2_mean  RMSE_std   MAE_std  \
# 633        NaN   1.063663  ...   1.924550  0.958068  0.290868  0.151661
# 696        NaN   1.052150  ...   2.280657  0.273824  0.370891  0.358083
# 624        1.0   1.101367  ...   2.281702  0.953325  0.310278  0.265886
# 636        NaN   1.178945  ...   2.122180  0.948914  0.312617  0.146540
# 688        NaN   1.347412  ...   2.014756  0.912050  0.477162  0.190533
#
#      MAPE_std    R2_std      SCPM  Dominated_Count      Classification  \
# 633  0.377315  0.025461 -3.423501                0      dominant_model
# 696  0.857604  0.591609 -3.338381                0      dominant_model
# 624  0.686515  0.026202 -3.302713                1  intermediate_model
# 636  0.362208  0.029458 -3.320527                1  intermediate_model
# 688  0.396607  0.069741 -3.286253                1  intermediate_model
#
#     Dominates_Count
# 633             712
# 696             411
# 624             706
# 636             706
# 688             687
#
# [5 rows x 21 columns]

# %%
df_sorted_topo_cols = df_sorted_topo[
    [
        # "Model",
        # "Model_bkp",
        "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Classification",
        "Dominates_Count",
        "Plant",
    ]
].round(2)

# %% [markdown]
# ###### Dominant Models

# %%
# Top 5
df_sorted_topo_cols.sort_values(
    by=["Dominates_Count", "SCPM"], ascending=[False, True]
).iloc[:5].round(2)
# Out:
#            Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 633      Random Forest       1.06      0.29      0.79     0.15       1.92
# 636      Decision Tree       1.18      0.31      0.87     0.15       2.12
# 624    Transformer_1.0       1.10      0.31      0.91     0.27       2.28
# 625    Transformer_7.0       1.14      0.39      0.94     0.29       2.42
# 634  Linear Regression       1.29      0.19      1.02     0.17       2.51
#
#      MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 633      0.38     0.96    0.03 -3.42                0      dominant_model
# 636      0.36     0.95    0.03 -3.32                1  intermediate_model
# 624      0.69     0.95    0.03 -3.30                1  intermediate_model
# 625      0.77     0.95    0.04 -3.26                2  intermediate_model
# 634      0.38     0.94    0.01 -3.16                4  intermediate_model
#
#      Dominates_Count Plant
# 633              712     s
# 636              706     s
# 624              706     s
# 625              701     s
# 634              695     s

# %%
# Top 4
df_sorted_topo_cols.iloc[0:5]
# Out:
#            Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 633      Random Forest       1.06      0.29      0.79     0.15       1.92
# 696  Linear Regression       1.05      0.37      0.85     0.36       2.28
# 624    Transformer_1.0       1.10      0.31      0.91     0.27       2.28
# 636      Decision Tree       1.18      0.31      0.87     0.15       2.12
# 688      Random Forest       1.35      0.48      0.87     0.19       2.01
#
#      MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 633      0.38     0.96    0.03 -3.42                0      dominant_model
# 696      0.86     0.27    0.59 -3.34                0      dominant_model
# 624      0.69     0.95    0.03 -3.30                1  intermediate_model
# 636      0.36     0.95    0.03 -3.32                1  intermediate_model
# 688      0.40     0.91    0.07 -3.29                1  intermediate_model
#
#      Dominates_Count Plant
# 633              712     s
# 696              411     x
# 624              706     s
# 636              706     s
# 688              687     w

# %%
df_sorted_topo_cols[df_sorted_topo_cols["Classification"].eq("dominant_model")].shape
# Out:
# (2, 14)

# %% [markdown]
# ###### Intermediate models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].sort_values(by=["Dominates_Count", "SCPM"], ascending=[False, True]).iloc[:3]
# Out:
#          Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 636    Decision Tree       1.18      0.31      0.87     0.15       2.12
# 624  Transformer_1.0       1.10      0.31      0.91     0.27       2.28
# 625  Transformer_7.0       1.14      0.39      0.94     0.29       2.42
#
#      MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 636      0.36     0.95    0.03 -3.32                1  intermediate_model
# 624      0.69     0.95    0.03 -3.30                1  intermediate_model
# 625      0.77     0.95    0.04 -3.26                2  intermediate_model
#
#      Dominates_Count Plant
# 636              706     s
# 624              706     s
# 625              701     s

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].shape
# Out:
# (711, 14)

# %% [markdown]
# ###### non-dominant models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].sort_values(by=["Dominates_Count", "SCPM"], ascending=[False, True]).iloc[:2]
# Out:
#                 Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  \
# 241  BidirectionalLSTM_14.0      30.05     35.31     24.72    26.08
#
#      MAPE_mean  MAPE_std  R2_mean   R2_std  SCPM  Dominated_Count  \
# 241      55.37     61.28 -2366.68  5551.74  42.9              713
#
#          Classification  Dominates_Count Plant
# 241  non_dominant_model                0     i

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].shape
# Out:
# (1, 14)

# %% [markdown]
# ###### Statistics per model type

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        # "Model_bkp",
        # "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
        "Plant",
    ]
]  # .round(2)

# %%
df_sorted_topo["Model"].value_counts()
# Out:
# Model
# Neural Networks      551
# Trees                122
# Linear Regression     41
# Name: count, dtype: int64

# %%
df_sorted_topo_models_grouped = df_sorted_topo_models_cols.groupby("Model").describe().T

# %%
# pd.set_option("display.max_rows", None)
# df_sorted_topo_models_grouped

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
    ]
]

# %%
(
    df_sorted_topo_models_cols.groupby("Model")[["Classification"]]
    .value_counts(normalize=True)
    .to_frame()
    * 100
).round(2)
# Out:
#                                       proportion
# Model             Classification
# Linear Regression intermediate_model       97.56
#                   dominant_model            2.44
# Neural Networks   intermediate_model       99.82
#                   non_dominant_model        0.18
# Trees             intermediate_model       99.18
#                   dominant_model            0.82

# %%
df_sorted_topo_models_cols.groupby("Model").describe().round(2).T
# Out:
# Model                  Linear Regression  Neural Networks   Trees
# Dominated_Count count              41.00           551.00  122.00
#                 mean               97.63           329.65   87.67
#                 std                87.08           196.97   79.31
#                 min                 0.00             1.00    0.00
#                 25%                26.00           158.50   26.00
#                 50%                71.00           332.00   64.50
#                 75%               138.00           495.00  127.50
#                 max               296.00           713.00  299.00
# Dominates_Count count              41.00           551.00  122.00
#                 mean              416.83           228.53  437.11
#                 std               127.94           180.07  126.38
#                 min               193.00             0.00  205.00
#                 25%               318.00            72.50  347.75
#                 50%               413.00           189.00  423.00
#                 75%               507.00           355.50  519.75
#                 max               695.00           706.00  712.00

# %%
# df_sorted_topo_models_cols

# %%
df_sorted_topo_models_cols.groupby("Model")["Classification"].describe()
# Out:
#                   count unique                 top freq
# Model
# Linear Regression    41      2  intermediate_model   40
# Neural Networks     551      2  intermediate_model  550
# Trees               122      2  intermediate_model  121

# %%
df_sorted_topo_models_cols.groupby("Model")[["Classification"]].value_counts()
# Out:
# Model              Classification
# Linear Regression  intermediate_model     40
#                    dominant_model          1
# Neural Networks    intermediate_model    550
#                    non_dominant_model      1
# Trees              intermediate_model    121
#                    dominant_model          1
# Name: count, dtype: int64

# %%
# df_sorted_topo_models_cols

# %%
summary_stats = df_sorted_topo_models_cols.groupby("Model").agg(
    Total_Models=("Model", "count"),
    Mean_Dominance_Count=("Dominates_Count", "mean"),
    Median_Dominance_Count=("Dominates_Count", "median"),
    Total_Dominated=("Dominated_Count", "sum"),
    Total_Dominating=("Dominates_Count", "sum"),
)

total_models = summary_stats[
    "Total_Models"
].sum()  # Get the total number of models across all categories
summary_stats["Dominance Proportion"] = summary_stats["Total_Dominating"] / total_models

# %%
summary_stats
# Out:
#                    Total_Models  Mean_Dominance_Count  Median_Dominance_Count  \
# Model
# Linear Regression            41            416.829268                   413.0
# Neural Networks             551            228.531760                   189.0
# Trees                       122            437.106557                   423.0
#
#                    Total_Dominated  Total_Dominating  Dominance Proportion
# Model
# Linear Regression             4003             17090             23.935574
# Neural Networks             181639            125921            176.359944
# Trees                        10696             53327             74.687675

# %%
df_sorted_topo_models_grouped.T
# Out:
#                   RMSE_mean                                                    \
#                       count      mean       std       min       25%       50%
# Model
# Linear Regression      41.0  2.381784  0.795074  1.052150  1.887676  2.150860
# Neural Networks       551.0  5.224267  3.311905  1.101367  2.921219  4.330239
# Trees                 122.0  2.323853  0.701561  1.063663  1.775221  2.295258
#
#                                        RMSE_std            ...  \
#                         75%        max    count      mean  ...
# Model                                                      ...
# Linear Regression  2.802053   4.573757     41.0  0.623843  ...
# Neural Networks    6.372593  30.046243    551.0  2.510151  ...
# Trees              2.741802   4.380579    122.0  0.652316  ...
#
#                   Dominated_Count        Dominates_Count              \
#                               75%    max           count        mean
# Model
# Linear Regression           138.0  296.0            41.0  416.829268
# Neural Networks             495.0  713.0           551.0  228.531760
# Trees                       127.5  299.0           122.0  437.106557
#
#
#                           std    min     25%    50%     75%    max
# Model
# Linear Regression  127.942742  193.0  318.00  413.0  507.00  695.0
# Neural Networks    180.065832    0.0   72.50  189.0  355.50  706.0
# Trees              126.379123  205.0  347.75  423.0  519.75  712.0
#
# [3 rows x 88 columns]

# %% [markdown]
# ### SCPM Analysis

# %%
cols = [
    # "Model",
    # "Model_bkp",
    "Model_bkp_2",
    "RMSE_mean",
    "RMSE_std",
    "MAE_mean",
    "MAE_std",
    "MAPE_mean",
    "MAPE_std",
    "R2_mean",
    "R2_std",
    "SCPM",
    "Dominated_Count",
    "Dominates_Count",
    "Classification",
    "Plant",
]

# %% [markdown]
# #### SCPM Analysis by Project

# %%
df_sorted_scpm = df_sorted_topo.sort_values(by="SCPM").copy()

# %%
# (df_sorted_topo[cols].reset_index() == df_sorted_scpm[cols].reset_index()).all(axis=1)
df_sorted_scpm["topo_scmp_order_eq"] = df_sorted_topo.index == df_sorted_scpm.index

# %%
df_sorted_scpm[cols + ["topo_scmp_order_eq"]].round(2).head(5)
# Out:
#            Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 633      Random Forest       1.06      0.29      0.79     0.15       1.92
# 696  Linear Regression       1.05      0.37      0.85     0.36       2.28
# 636      Decision Tree       1.18      0.31      0.87     0.15       2.12
# 624    Transformer_1.0       1.10      0.31      0.91     0.27       2.28
# 391  Linear Regression       1.10      0.53      0.87     0.39       2.37
#
#      MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count  Dominates_Count  \
# 633      0.38     0.96    0.03 -3.42                0              712
# 696      0.86     0.27    0.59 -3.34                0              411
# 636      0.36     0.95    0.03 -3.32                1              706
# 624      0.69     0.95    0.03 -3.30                1              706
# 391      1.10    -0.78    1.05 -3.29                2              275
#
#          Classification Plant  topo_scmp_order_eq
# 633      dominant_model     s                True
# 696      dominant_model     x                True
# 636  intermediate_model     s               False
# 624  intermediate_model     s               False
# 391  intermediate_model    ag               False

# %% [markdown]
# ### Time Series Split

# %%
df_results_cm["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split', 'Time Series Split'], dtype=object)

# %%
df_results_cm_tss = (
    df_results_cm[df_results_cm["Cross Validation"].eq("Time Series Split")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_tss["Cross Validation"].unique()
# Out:
# array(['Time Series Split'], dtype=object)

# %%
df_results_cm_tss.shape
# Out:
# (741, 17)

# %% [markdown]
# ###### SCPM computation

# %%
df_results_cm_tss = compute_scpm(df_results_cm_tss)

# %% [markdown]
# ##### Dominance Analysis

# %%
# Per project
dominance_dict = make_dominance_analysis(df_results_cm_tss)
dominance_matrix_cm_tss = dominance_dict["dominance_matrix"]
dominance_graph_cm_tss = dominance_dict["dominance_graph"]
df_sorted_count = dominance_dict["df_sorted_count"]
df_sorted_topo = dominance_dict["df_sorted_topo"]

# %%
dominance_matrix_cm_tss.shape, len(dominance_graph_cm_tss)
# Out:
# ((741, 741), 741)

# %%
df_sorted_topo["Classification"].value_counts()
# Out:
# Classification
# intermediate_model    738
# dominant_model          2
# non_dominant_model      1
# Name: count, dtype: int64

# %%
df_sorted_topo.to_csv(
    "../../../../reports/results/local_models/ecics/ecics_dominance_analysis_cm_tss.csv",
    index=False,
)

# %%
df_sorted_topo.head(5)
# Out:
#     Company Plant   Cross Validation                  Features Features_bkp  \
# 636     209     s  Time Series Split  Chemical + Mineralogical     Chemical
# 649     209     s  Time Series Split  Chemical + Mineralogical     Chemical
# 400     209    ag  Time Series Split  Chemical + Mineralogical     Chemical
# 637     209     s  Time Series Split  Chemical + Mineralogical     Chemical
# 650     209     s  Time Series Split  Chemical + Mineralogical     Chemical
#
#                  Model          Model_bkp        Model_bkp_2  Timesteps  \
# 636    Neural Networks        Transformer    Transformer_1.0        1.0
# 649              Trees      Random Forest      Random Forest        NaN
# 400              Trees      Random Forest      Random Forest        NaN
# 637    Neural Networks        Transformer    Transformer_7.0        7.0
# 650  Linear Regression  Linear Regression  Linear Regression        NaN
#
#      RMSE_mean  ...  MAPE_mean   R2_mean  RMSE_std   MAE_std  MAPE_std  \
# 636   1.174792  ...   2.139835  0.947505  0.297583  0.209304  0.450223
# 649   1.189475  ...   2.049671  0.946343  0.284627  0.126587  0.291970
# 400   1.175271  ...   2.715182 -0.725349  0.217511  0.218284  0.640332
# 637   1.354375  ...   2.594853  0.929044  0.376346  0.303135  0.688145
# 650   1.365165  ...   2.595642  0.929227  0.341606  0.248860  0.559864
#
#        R2_std      SCPM  Dominated_Count      Classification Dominates_Count
# 636  0.024692 -2.695839                0      dominant_model             739
# 649  0.021361 -2.723590                0      dominant_model             738
# 400  0.680439 -2.533990                1  intermediate_model             205
# 637  0.036551 -2.489012                2  intermediate_model             728
# 650  0.032124 -2.494687                2  intermediate_model             728
#
# [5 rows x 21 columns]

# %%
df_sorted_topo_cols = df_sorted_topo[
    [
        # "Model",
        # "Model_bkp",
        "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Classification",
        "Dominates_Count",
        "Plant",
    ]
]  # .round(2)

# %% [markdown]
# ###### Dominant Models

# %%
# Top 5
df_sorted_topo_cols.sort_values(
    by=["Dominates_Count", "SCPM"], ascending=[False, True]
).iloc[:5].round(2)
# Out:
#            Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 636    Transformer_1.0       1.17      0.30      0.87     0.21       2.14
# 649      Random Forest       1.19      0.28      0.83     0.13       2.05
# 652      Decision Tree       1.37      0.47      0.88     0.16       2.15
# 650  Linear Regression       1.37      0.34      1.04     0.25       2.60
# 637    Transformer_7.0       1.35      0.38      1.06     0.30       2.59
#
#      MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 636      0.45     0.95    0.02 -2.70                0      dominant_model
# 649      0.29     0.95    0.02 -2.72                0      dominant_model
# 652      0.38     0.93    0.04 -2.64                2  intermediate_model
# 650      0.56     0.93    0.03 -2.49                2  intermediate_model
# 637      0.69     0.93    0.04 -2.49                2  intermediate_model
#
#      Dominates_Count Plant
# 636              739     s
# 649              738     s
# 652              729     s
# 650              728     s
# 637              728     s

# %%
# Top 4
df_sorted_topo_cols.iloc[0:2].sort_values(by="Dominates_Count", ascending=False).round(
    2
)
# Out:
#          Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 636  Transformer_1.0       1.17      0.30      0.87     0.21       2.14
# 649    Random Forest       1.19      0.28      0.83     0.13       2.05
#
#      MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count  Classification  \
# 636      0.45     0.95    0.02 -2.70                0  dominant_model
# 649      0.29     0.95    0.02 -2.72                0  dominant_model
#
#      Dominates_Count Plant
# 636              739     s
# 649              738     s

# %%
df_sorted_topo_cols[df_sorted_topo_cols["Classification"].eq("dominant_model")].shape
# Out:
# (2, 14)

# %% [markdown]
# ###### Intermediate models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].sort_values(by=["Dominates_Count", "SCPM"], ascending=[False, True]).iloc[:4].round(2)
# Out:
#            Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 652      Decision Tree       1.37      0.47      0.88     0.16       2.15
# 650  Linear Regression       1.37      0.34      1.04     0.25       2.60
# 637    Transformer_7.0       1.35      0.38      1.06     0.30       2.59
# 709      Random Forest       1.44      0.33      0.95     0.14       2.24
#
#      MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 652      0.38     0.93    0.04 -2.64                2  intermediate_model
# 650      0.56     0.93    0.03 -2.49                2  intermediate_model
# 637      0.69     0.93    0.04 -2.49                2  intermediate_model
# 709      0.33     0.92    0.04 -2.58                3  intermediate_model
#
#      Dominates_Count Plant
# 652              729     s
# 650              728     s
# 637              728     s
# 709              721     w

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].shape
# Out:
# (738, 14)

# %% [markdown]
# ###### non-dominant models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].sort_values(by=["Dominates_Count", "SCPM"], ascending=[False, True]).iloc[:3]
# Out:
#     Model_bkp_2  RMSE_mean    RMSE_std   MAE_mean     MAE_std  MAPE_mean  \
# 399   LSTM_14.0  65.449606  192.271746  41.170103  117.956109  89.161413
#
#        MAPE_std     R2_mean        R2_std       SCPM  Dominated_Count  \
# 399  252.921332 -4690.17829  16986.104525  69.171894              740
#
#          Classification  Dominates_Count Plant
# 399  non_dominant_model                0    ac

# %%
df_sorted_topo_cols[df_sorted_topo_cols["Plant"].eq("ac")]["R2_mean"].describe()
# Out:
# count      20.000000
# mean     -270.587391
# std      1041.435671
# min     -4690.178290
# 25%       -81.198330
# 50%       -17.970826
# 75%         0.149308
# max         0.310772
# Name: R2_mean, dtype: float64

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].shape
# Out:
# (1, 14)

# %% [markdown]
# ###### Statistics per model type

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        # "Model_bkp",
        # "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
        "Plant",
    ]
]  # .round(2)

# %%
df_sorted_topo["Model"].value_counts()
# Out:
# Model
# Neural Networks      578
# Trees                122
# Linear Regression     41
# Name: count, dtype: int64

# %%
df_sorted_topo_models_grouped = df_sorted_topo_models_cols.groupby("Model").describe().T

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
    ]
]

# %%
(
    df_sorted_topo_models_cols.groupby("Model")[["Classification"]]
    .value_counts(normalize=True)
    .to_frame()
    * 100
).round(2)
# Out:
#                                       proportion
# Model             Classification
# Linear Regression intermediate_model      100.00
# Neural Networks   intermediate_model       99.65
#                   dominant_model            0.17
#                   non_dominant_model        0.17
# Trees             intermediate_model       99.18
#                   dominant_model            0.82

# %%
df_sorted_topo_models_cols.groupby("Model").describe().round(2).T
# Out:
# Model                  Linear Regression  Neural Networks   Trees
# Dominated_Count count              41.00           578.00  122.00
#                 mean              151.20           311.20  120.58
#                 std               118.88           204.60  107.18
#                 min                 2.00             0.00    0.00
#                 25%                41.00           142.25   28.25
#                 50%               157.00           283.00   85.50
#                 75%               228.00           466.00  201.75
#                 max               445.00           740.00  407.00
# Dominates_Count count              41.00           578.00  122.00
#                 mean              340.49           240.52  391.83
#                 std               172.73           194.83  182.04
#                 min                86.00             0.00   60.00
#                 25%               219.00            78.00  243.50
#                 50%               292.00           175.50  347.50
#                 75%               457.00           367.00  545.50
#                 max               728.00           739.00  738.00

# %%
# df_sorted_topo_models_cols

# %%
df_sorted_topo_models_cols.groupby("Model")["Classification"].describe()
# Out:
#                   count unique                 top freq
# Model
# Linear Regression    41      1  intermediate_model   41
# Neural Networks     578      3  intermediate_model  576
# Trees               122      2  intermediate_model  121

# %%
df_sorted_topo_models_cols.groupby("Model")[["Classification"]].value_counts()
# Out:
# Model              Classification
# Linear Regression  intermediate_model     41
# Neural Networks    intermediate_model    576
#                    dominant_model          1
#                    non_dominant_model      1
# Trees              intermediate_model    121
#                    dominant_model          1
# Name: count, dtype: int64

# %%
summary_stats = df_sorted_topo_models_cols.groupby("Model").agg(
    Total_Models=("Model", "count"),
    Mean_Dominance_Count=("Dominates_Count", "mean"),
    Median_Dominance_Count=("Dominates_Count", "median"),
    Total_Dominated=("Dominated_Count", "sum"),
    Total_Dominating=("Dominates_Count", "sum"),
)

total_models = summary_stats[
    "Total_Models"
].sum()  # Get the total number of models across all categories
summary_stats["Dominance Proportion"] = summary_stats["Total_Dominating"] / total_models

# %%
summary_stats.round(2)
# Out:
#                    Total_Models  Mean_Dominance_Count  Median_Dominance_Count  \
# Model
# Linear Regression            41                340.49                   292.0
# Neural Networks             578                240.52                   175.5
# Trees                       122                391.83                   347.5
#
#                    Total_Dominated  Total_Dominating  Dominance Proportion
# Model
# Linear Regression             6199             13960                 18.84
# Neural Networks             179876            139023                187.62
# Trees                        14711             47803                 64.51

# %%
df_sorted_topo_models_grouped.T
# Out:
#                   RMSE_mean                                                    \
#                       count      mean       std       min       25%       50%
# Model
# Linear Regression      41.0  2.815406  1.004526  1.349361  2.075770  2.681598
# Neural Networks       578.0  4.701288  4.184280  1.174792  2.801997  3.678526
# Trees                 122.0  2.599659  0.892692  1.175271  1.947185  2.478336
#
#                                        RMSE_std            ...  \
#                         75%        max    count      mean  ...
# Model                                                      ...
# Linear Regression  3.275565   5.433704     41.0  0.623249  ...
# Neural Networks    5.277179  65.449606    578.0  3.293455  ...
# Trees              3.133986   6.405931    122.0  0.544322  ...
#
#                   Dominated_Count        Dominates_Count              \
#                               75%    max           count        mean
# Model
# Linear Regression          228.00  445.0            41.0  340.487805
# Neural Networks            466.00  740.0           578.0  240.524221
# Trees                      201.75  407.0           122.0  391.827869
#
#
#                           std   min    25%    50%    75%    max
# Model
# Linear Regression  172.731167  86.0  219.0  292.0  457.0  728.0
# Neural Networks    194.827241   0.0   78.0  175.5  367.0  739.0
# Trees              182.037172  60.0  243.5  347.5  545.5  738.0
#
# [3 rows x 88 columns]

# %% [markdown]
# ### SCPM Analysis

# %%
cols = [
    # "Model",
    # "Model_bkp",
    "Model_bkp_2",
    "RMSE_mean",
    "RMSE_std",
    "MAE_mean",
    "MAE_std",
    "MAPE_mean",
    "MAPE_std",
    "R2_mean",
    "R2_std",
    "SCPM",
    "Dominated_Count",
    "Dominates_Count",
    "Classification",
    "Plant",
]

# %% [markdown]
# #### SCPM Analysis by Project

# %%
df_sorted_scpm = df_sorted_topo.sort_values(by="SCPM").copy()

# %%
# (df_sorted_topo[cols].reset_index() == df_sorted_scpm[cols].reset_index()).all(axis=1)
df_sorted_scpm["topo_scmp_order_eq"] = df_sorted_topo.index == df_sorted_scpm.index

# %%
df_sorted_scpm[cols + ["topo_scmp_order_eq"]].round(2).head(5)
# Out:
#          Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 649    Random Forest       1.19      0.28      0.83     0.13       2.05
# 636  Transformer_1.0       1.17      0.30      0.87     0.21       2.14
# 652    Decision Tree       1.37      0.47      0.88     0.16       2.15
# 709    Random Forest       1.44      0.33      0.95     0.14       2.24
# 688          XGBoost       1.25      0.38      0.97     0.33       2.62
#
#      MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count  Dominates_Count  \
# 649      0.29     0.95    0.02 -2.72                0              738
# 636      0.45     0.95    0.02 -2.70                0              739
# 652      0.38     0.93    0.04 -2.64                2              729
# 709      0.33     0.92    0.04 -2.58                3              721
# 688      0.82     0.81    0.10 -2.55                2              628
#
#          Classification Plant  topo_scmp_order_eq
# 649      dominant_model     s               False
# 636      dominant_model     s               False
# 652  intermediate_model     s               False
# 709  intermediate_model     w               False
# 688  intermediate_model     v               False

# %% [markdown]
# ### Variable Grouping: CM-P

# %%
df_results["Features"].unique()
# Out:
# array(['Chemical + Mineralogical + Physical', 'Chemical + Mineralogical',
#        'Chemical + Mineralogical + Physical - Early CS'], dtype=object)

# %%
df_results_cm_p = (
    df_results[
        df_results["Features"].eq("Chemical + Mineralogical + Physical - Early CS")
    ]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_p["Features"].unique()
# Out:
# array(['Chemical + Mineralogical + Physical - Early CS'], dtype=object)

# %%
df_results_cm_p.shape
# Out:
# (1455, 17)

# %% [markdown]
# #### K-Fold

# %%
# df_results_cm_p["Cross Validation"].unique()

# %%
# df_results_cm_p_kf = (
#     df_results_cm_p[df_results_cm_p["Cross Validation"].eq("Repeated KFold")]
#     .copy()
#     .reset_index(drop=True)
# )

# %%
# df_results_cm_p_kf["Cross Validation"].unique()

# %%
# df_results_cm_p_kf.shape

# %%
# df_results_cm_p_kf_partner_i = df_results_cm_p_kf[
#     df_results_cm_p_kf["Plant"].eq("partner_i")
# ].copy()
# df_results_cm_p_kf_partner_ii = df_results_cm_p_kf[
#     df_results_cm_p_kf["Plant"].eq("partner_ii")
# ].copy()
# df_results_cm_p_kf_partner_iv = df_results_cm_p_kf[
#     df_results_cm_p_kf["Plant"].eq("partner_iv")
# ].copy()

# %% [markdown]
# ###### SCPM computation

# %%
# df_results_cm_p_kf = compute_scpm(df_results_cm_p_kf)

# %% [markdown]
# ##### Dominance Analysis

# %%
# dominance_dict = make_dominance_analysis(df_results_cm_p_kf)
# dominance_matrix_cm_p_kf = dominance_dict["dominance_matrix"]
# dominance_graph_cm_p_kf = dominance_dict["dominance_graph"]
# df_sorted_count = dominance_dict["df_sorted_count"]
# df_sorted_topo = dominance_dict["df_sorted_topo"]

# %%
# dominance_matrix_cm_p_kf.shape, len(dominance_graph_cm_p_kf)

# %%
# df_sorted_topo["Classification"].value_counts()

# %%
# df_sorted_topo.to_csv(
#     "../../../../reports/results/local_models/ecics/ecics_dominance_analysis_cm_p_kf.csv",
#     index=False,
# )

# %%
# df_sorted_topo.head(5)

# %%
# df_sorted_topo_cols = df_sorted_topo[
#     [
#         # "Model",
#         # "Model_bkp",
#         "Model_bkp_2",
#         "RMSE_mean",
#         "RMSE_std",
#         "MAE_mean",
#         "MAE_std",
#         "MAPE_mean",
#         "MAPE_std",
#         "R2_mean",
#         "R2_std",
#         "SCPM",
#         "Dominated_Count",
#         "Classification",
#         "Dominates_Count",
#         "Plant",
#     ]
# ].round(2)

# %% [markdown]
# ##### Top dominant models

# %%
# # Top 4
# df_sorted_topo_cols.iloc[0:2]

# %% [markdown]
# ##### Top intermediate models

# %%
# df_sorted_topo_cols[
#     df_sorted_topo_cols["Classification"].eq("intermediate_model")
# ].sort_values(by="Dominates_Count", ascending=False).iloc[:2]

# %% [markdown]
# ##### Top non dominant models

# %%
# df_sorted_topo_cols[
#     df_sorted_topo_cols["Classification"].eq("non_dominant_model")
# ].sort_values(by="Dominated_Count", ascending=True).iloc[:2]

# %%
# df_sorted_topo_models_cols = df_sorted_topo[
#     [
#         "Model",
#         # "Model_bkp",
#         # "Model_bkp_2",
#         "RMSE_mean",
#         "RMSE_std",
#         "MAE_mean",
#         "MAE_std",
#         "MAPE_mean",
#         "MAPE_std",
#         "R2_mean",
#         "R2_std",
#         "SCPM",
#         "Dominated_Count",
#         "Dominates_Count",
#         "Classification",
#         "Plant",
#     ]
# ]  # .round(2)

# %%
# df_sorted_topo["Model"].value_counts()

# %%
# df_sorted_topo_models_grouped = df_sorted_topo_models_cols.groupby("Model").describe().T

# %%
# df_sorted_topo_models_cols = df_sorted_topo[
#     [
#         "Model",
#         "Dominated_Count",
#         "Dominates_Count",
#         "Classification",
#     ]
# ]

# %%
# df_sorted_topo_models_cols.groupby("Model").describe().round(2)

# %%
# df_sorted_topo_models_cols.groupby("Model")["Classification"].describe()

# %%
# df_sorted_topo_models_cols.groupby("Model")[["Classification"]].value_counts()

# %%
# (
#     df_sorted_topo_models_cols.groupby("Model")[["Classification"]]
#     .value_counts(normalize=True)
#     .to_frame()
#     * 100
# ).round(2)

# %%
# summary_stats = df_sorted_topo_models_cols.groupby("Model").agg(
#     Total_Models=("Model", "count"),
#     Mean_Dominance_Count=("Dominates_Count", "mean"),
#     Median_Dominance_Count=("Dominates_Count", "median"),
#     Total_Dominated=("Dominated_Count", "sum"),
#     Total_Dominating=("Dominates_Count", "sum"),
# )

# total_models = summary_stats[
#     "Total_Models"
# ].sum()  # Get the total number of models across all categories
# summary_stats["Dominance Proportion"] = summary_stats["Total_Dominating"] / total_models

# %%
# summary_stats

# %%
# df_sorted_topo_models_grouped.T

# %% [markdown]
# ### SCPM Analysis

# %%
# cols = [
#     # "Model",
#     # "Model_bkp",
#     "Model_bkp_2",
#     "RMSE_mean",
#     "RMSE_std",
#     "MAE_mean",
#     "MAE_std",
#     "MAPE_mean",
#     "MAPE_std",
#     "R2_mean",
#     "R2_std",
#     "SCPM",
#     "Dominated_Count",
#     "Dominates_Count",
#     "Classification",
#     "Plant",
# ]

# %%
# df_sorted_scpm = df_sorted_topo.sort_values(by="SCPM").copy()

# %%
# # (df_sorted_topo[cols].reset_index() == df_sorted_scpm[cols].reset_index()).all(axis=1)
# df_sorted_scpm["topo_scmp_order_eq"] = df_sorted_topo.index == df_sorted_scpm.index

# %%
# df_sorted_topo[cols].round(2).head(5)

# %%
# df_sorted_scpm[cols + ["topo_scmp_order_eq"]].round(2).head(5)

# %% [markdown]
# ### Blocking time series

# %%
df_results_cm_p["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split', 'Time Series Split'], dtype=object)

# %%
df_results_cm_p_btss = (
    df_results_cm_p[
        df_results_cm_p["Cross Validation"].eq("Blocking Time Series Split")
    ]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_p_btss["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split'], dtype=object)

# %%
df_results_cm_p.shape, df_results_cm_p_btss.shape
# Out:
# ((1455, 17), (714, 17))

# %% [markdown]
# ###### SCPM computation

# %%
df_results_cm_p_btss = compute_scpm(df_results_cm_p_btss)

# %% [markdown]
# ##### Dominance Analysis

# %%
# Per project
dominance_dict = make_dominance_analysis(df_results_cm_p_btss)
dominance_matrix_cm_p_btss = dominance_dict["dominance_matrix"]
dominance_graph_cm_p_btss = dominance_dict["dominance_graph"]
df_sorted_count = dominance_dict["df_sorted_count"]
df_sorted_topo = dominance_dict["df_sorted_topo"]

# %%
dominance_matrix_cm_p_btss.shape, len(dominance_graph_cm_p_btss)
# Out:
# ((714, 714), 714)

# %%
df_sorted_topo["Classification"].value_counts()
# Out:
# Classification
# intermediate_model    710
# non_dominant_model      3
# dominant_model          1
# Name: count, dtype: int64

# %%
df_sorted_topo.to_csv(
    "../../../../reports/results/local_models/ecics/ecics_dominance_analysis_cm_p_btss.csv",
    index=False,
)

# %%
df_sorted_topo.head(5)
# Out:
#     Company Plant            Cross Validation  \
# 419     209    am  Blocking Time Series Split
# 35      203     c  Blocking Time Series Split
# 429     209    am  Blocking Time Series Split
# 432     209    am  Blocking Time Series Split
# 628     209     s  Blocking Time Series Split
#
#                                            Features  \
# 419  Chemical + Mineralogical + Physical - Early CS
# 35   Chemical + Mineralogical + Physical - Early CS
# 429  Chemical + Mineralogical + Physical - Early CS
# 432  Chemical + Mineralogical + Physical - Early CS
# 628  Chemical + Mineralogical + Physical - Early CS
#
#                       Features_bkp            Model      Model_bkp  \
# 419  Chemical + Properties CS Less            Trees  Random Forest
# 35   Chemical + Properties CS Less  Neural Networks    Transformer
# 429  Chemical + Properties CS Less  Neural Networks    Transformer
# 432  Chemical + Properties CS Less            Trees  Decision Tree
# 628  Chemical + Properties CS Less            Trees  Random Forest
#
#          Model_bkp_2  Timesteps  RMSE_mean  ...  MAPE_mean   R2_mean  \
# 419    Random Forest        NaN   1.029710  ...   1.917995  0.969237
# 35   Transformer_1.0        1.0   1.113216  ...   1.971579  0.963484
# 429  Transformer_1.0        1.0   1.103488  ...   2.256438  0.964245
# 432    Decision Tree        NaN   1.116811  ...   2.070391  0.964066
# 628    Random Forest        NaN   1.062346  ...   1.995175  0.959648
#
#      RMSE_std   MAE_std  MAPE_std    R2_std      SCPM  Dominated_Count  \
# 419  0.052213  0.050918  0.125568  0.006512 -3.319889                0
# 35   0.210617  0.094078  0.188811  0.011791 -3.277099                1
# 429  0.112704  0.126219  0.311139  0.010544 -3.198423                1
# 432  0.079368  0.077877  0.197413  0.006216 -3.247932                1
# 628  0.216000  0.136839  0.330688  0.017070 -3.290988                1
#
#          Classification Dominates_Count
# 419      dominant_model             713
# 35   intermediate_model             708
# 429  intermediate_model             699
# 432  intermediate_model             707
# 628  intermediate_model             708
#
# [5 rows x 21 columns]

# %%
df_sorted_topo_cols = df_sorted_topo[
    [
        # "Model",
        # "Model_bkp",
        "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Classification",
        "Dominates_Count",
        "Plant",
    ]
].round(2)

# %% [markdown]
# ###### Dominant Models

# %%
# Top 5
df_sorted_topo_cols.sort_values(
    by=["Dominates_Count", "SCPM"], ascending=[False, True]
).iloc[:5].round(2)
# Out:
#          Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 419    Random Forest       1.03      0.05      0.79     0.05       1.92
# 628    Random Forest       1.06      0.22      0.81     0.14       2.00
# 35   Transformer_1.0       1.11      0.21      0.82     0.09       1.97
# 432    Decision Tree       1.12      0.08      0.86     0.08       2.07
# 429  Transformer_1.0       1.10      0.11      0.92     0.13       2.26
#
#      MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 419      0.13     0.97    0.01 -3.32                0      dominant_model
# 628      0.33     0.96    0.02 -3.29                1  intermediate_model
# 35       0.19     0.96    0.01 -3.28                1  intermediate_model
# 432      0.20     0.96    0.01 -3.25                1  intermediate_model
# 429      0.31     0.96    0.01 -3.20                1  intermediate_model
#
#      Dominates_Count Plant
# 419              713    am
# 628              708     s
# 35               708     c
# 432              707    am
# 429              699    am

# %%
# Top 4
df_sorted_topo_cols.iloc[0:5]
# Out:
#          Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 419    Random Forest       1.03      0.05      0.79     0.05       1.92
# 35   Transformer_1.0       1.11      0.21      0.82     0.09       1.97
# 429  Transformer_1.0       1.10      0.11      0.92     0.13       2.26
# 432    Decision Tree       1.12      0.08      0.86     0.08       2.07
# 628    Random Forest       1.06      0.22      0.81     0.14       2.00
#
#      MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 419      0.13     0.97    0.01 -3.32                0      dominant_model
# 35       0.19     0.96    0.01 -3.28                1  intermediate_model
# 429      0.31     0.96    0.01 -3.20                1  intermediate_model
# 432      0.20     0.96    0.01 -3.25                1  intermediate_model
# 628      0.33     0.96    0.02 -3.29                1  intermediate_model
#
#      Dominates_Count Plant
# 419              713    am
# 35               708     c
# 429              699    am
# 432              707    am
# 628              708     s

# %%
df_sorted_topo_cols[df_sorted_topo_cols["Classification"].eq("dominant_model")].shape
# Out:
# (1, 14)

# %% [markdown]
# ###### Intermediate models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].sort_values(by=["Dominates_Count", "SCPM"], ascending=[False, True]).iloc[:3]
# Out:
#          Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 628    Random Forest       1.06      0.22      0.81     0.14       2.00
# 35   Transformer_1.0       1.11      0.21      0.82     0.09       1.97
# 432    Decision Tree       1.12      0.08      0.86     0.08       2.07
#
#      MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 628      0.33     0.96    0.02 -3.29                1  intermediate_model
# 35       0.19     0.96    0.01 -3.28                1  intermediate_model
# 432      0.20     0.96    0.01 -3.25                1  intermediate_model
#
#      Dominates_Count Plant
# 628              708     s
# 35               708     c
# 432              707    am

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].shape
# Out:
# (710, 14)

# %% [markdown]
# ###### non-dominant models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].sort_values(by=["Dominated_Count", "SCPM"], ascending=[True, True]).iloc[:3]
# Out:
#                 Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  \
# 237   BidirectionalLSTM_7.0      29.70     24.08     23.82    19.83
# 241               LSTM_14.0      18.84     18.25     17.44    17.81
# 238  BidirectionalLSTM_14.0      29.37     24.49     25.24    19.72
#
#      MAPE_mean  MAPE_std  R2_mean   R2_std   SCPM  Dominated_Count  \
# 237      53.84     40.48   -48.53    58.13  22.05              679
# 241      36.29     35.20 -1177.65  2090.61  28.21              708
# 238      54.92     43.10 -1142.56  2031.77  36.55              711
#
#          Classification  Dominates_Count Plant
# 237  non_dominant_model                0     i
# 241  non_dominant_model                0     i
# 238  non_dominant_model                0     i

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].shape
# Out:
# (3, 14)

# %% [markdown]
# ###### Statistics per model type

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        # "Model_bkp",
        # "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
        "Plant",
    ]
]  # .round(2)

# %%
df_sorted_topo["Model"].value_counts()
# Out:
# Model
# Neural Networks      551
# Trees                122
# Linear Regression     41
# Name: count, dtype: int64

# %%
df_sorted_topo_models_grouped = df_sorted_topo_models_cols.groupby("Model").describe().T

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
    ]
]

# %%
(
    df_sorted_topo_models_cols.groupby("Model")[["Classification"]]
    .value_counts(normalize=True)
    .to_frame()
    * 100
).round(2)
# Out:
#                                       proportion
# Model             Classification
# Linear Regression intermediate_model      100.00
# Neural Networks   intermediate_model       99.46
#                   non_dominant_model        0.54
# Trees             intermediate_model       99.18
#                   dominant_model            0.82

# %%
df_sorted_topo_models_cols.groupby("Model").describe().round(2).T
# Out:
# Model                  Linear Regression  Neural Networks   Trees
# Dominated_Count count              41.00           551.00  122.00
#                 mean               80.68           338.87   90.19
#                 std                74.46           190.73   67.46
#                 min                 3.00             1.00    0.00
#                 25%                28.00           178.00   38.50
#                 50%                58.00           343.00   75.00
#                 75%               115.00           496.50  134.50
#                 max               303.00           711.00  306.00
# Dominates_Count count              41.00           551.00  122.00
#                 mean              465.95           230.22  451.44
#                 std               136.58           183.45  120.67
#                 min               218.00             0.00  179.00
#                 25%               355.00            77.00  369.25
#                 50%               468.00           188.00  436.00
#                 75%               597.00           363.50  528.00
#                 max               699.00           708.00  713.00

# %%
df_sorted_topo_models_cols.groupby("Model")["Classification"].describe()
# Out:
#                   count unique                 top freq
# Model
# Linear Regression    41      1  intermediate_model   41
# Neural Networks     551      2  intermediate_model  548
# Trees               122      2  intermediate_model  121

# %%
df_sorted_topo_models_cols.groupby("Model")[["Classification"]].value_counts()
# Out:
# Model              Classification
# Linear Regression  intermediate_model     41
# Neural Networks    intermediate_model    548
#                    non_dominant_model      3
# Trees              intermediate_model    121
#                    dominant_model          1
# Name: count, dtype: int64

# %%
summary_stats = df_sorted_topo_models_cols.groupby("Model").agg(
    Total_Models=("Model", "count"),
    Mean_Dominance_Count=("Dominates_Count", "mean"),
    Median_Dominance_Count=("Dominates_Count", "median"),
    Total_Dominated=("Dominated_Count", "sum"),
    Total_Dominating=("Dominates_Count", "sum"),
)

total_models = summary_stats[
    "Total_Models"
].sum()  # Get the total number of models across all categories
summary_stats["Dominance Proportion"] = summary_stats["Total_Dominating"] / total_models

# %%
summary_stats
# Out:
#                    Total_Models  Mean_Dominance_Count  Median_Dominance_Count  \
# Model
# Linear Regression            41            465.951220                   468.0
# Neural Networks             551            230.215971                   188.0
# Trees                       122            451.442623                   436.0
#
#                    Total_Dominated  Total_Dominating  Dominance Proportion
# Model
# Linear Regression             3308             19104             26.756303
# Neural Networks             186718            126849            177.659664
# Trees                        11003             55076             77.137255

# %%
df_sorted_topo_models_grouped.T
# Out:
#                   RMSE_mean                                                    \
#                       count      mean       std       min       25%       50%
# Model
# Linear Regression      41.0  1.993126  0.700183  1.115907  1.564440  1.798545
# Neural Networks       551.0  5.413753  3.585196  1.083244  2.992432  4.560200
# Trees                 122.0  2.097506  0.675628  1.029710  1.621655  2.005559
#
#                                        RMSE_std            ...  \
#                         75%        max    count      mean  ...
# Model                                                      ...
# Linear Regression  2.302138   4.097758     41.0  0.462651  ...
# Neural Networks    6.843937  29.702019    551.0  2.438009  ...
# Trees              2.426605   4.588340    122.0  0.576371  ...
#
#                   Dominated_Count        Dominates_Count              \
#                               75%    max           count        mean
# Model
# Linear Regression           115.0  303.0            41.0  465.951220
# Neural Networks             496.5  711.0           551.0  230.215971
# Trees                       134.5  306.0           122.0  451.442623
#
#
#                           std    min     25%    50%    75%    max
# Model
# Linear Regression  136.576343  218.0  355.00  468.0  597.0  699.0
# Neural Networks    183.445118    0.0   77.00  188.0  363.5  708.0
# Trees              120.672568  179.0  369.25  436.0  528.0  713.0
#
# [3 rows x 88 columns]

# %% [markdown]
# ### SCPM Analysis

# %%
cols = [
    # "Model",
    # "Model_bkp",
    "Model_bkp_2",
    "RMSE_mean",
    "RMSE_std",
    "MAE_mean",
    "MAE_std",
    "MAPE_mean",
    "MAPE_std",
    "R2_mean",
    "R2_std",
    "SCPM",
    "Dominated_Count",
    "Dominates_Count",
    "Classification",
    "Plant",
]

# %% [markdown]
# #### SCPM Analysis by Project

# %%
df_sorted_scpm = df_sorted_topo.sort_values(by="SCPM").copy()

# %%
df_sorted_scpm["topo_scmp_order_eq"] = df_sorted_topo.index == df_sorted_scpm.index

# %%
df_sorted_scpm[cols + ["topo_scmp_order_eq"]].round(2).head(5)
# Out:
#          Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 419    Random Forest       1.03      0.05      0.79     0.05       1.92
# 628    Random Forest       1.06      0.22      0.81     0.14       2.00
# 35   Transformer_1.0       1.11      0.21      0.82     0.09       1.97
# 432    Decision Tree       1.12      0.08      0.86     0.08       2.07
# 25     Random Forest       1.16      0.34      0.86     0.22       2.09
#
#      MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count  Dominates_Count  \
# 419      0.13     0.97    0.01 -3.32                0              713
# 628      0.33     0.96    0.02 -3.29                1              708
# 35       0.19     0.96    0.01 -3.28                1              708
# 432      0.20     0.96    0.01 -3.25                1              707
# 25       0.55     0.96    0.02 -3.23                4              698
#
#          Classification Plant  topo_scmp_order_eq
# 419      dominant_model    am                True
# 628  intermediate_model     s               False
# 35   intermediate_model     c               False
# 432  intermediate_model    am                True
# 25   intermediate_model     c               False

# %% [markdown]
# ### Time Series Split

# %%
df_results_cm_p["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split', 'Time Series Split'], dtype=object)

# %%
df_results_cm_p_tss = (
    df_results_cm_p[df_results_cm_p["Cross Validation"].eq("Time Series Split")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_p_tss["Cross Validation"].unique()
# Out:
# array(['Time Series Split'], dtype=object)

# %%
df_results_cm_p_tss.shape
# Out:
# (741, 17)

# %% [markdown]
# ###### SCPM computation

# %%
df_results_cm_p_tss = compute_scpm(df_results_cm_p_tss)

# %% [markdown]
# ##### Dominance Analysis

# %%
# Per project
dominance_dict = make_dominance_analysis(df_results_cm_p_tss)
dominance_matrix_cm_p_tss = dominance_dict["dominance_matrix"]
dominance_graph_cm_p_tss = dominance_dict["dominance_graph"]
df_sorted_count = dominance_dict["df_sorted_count"]
df_sorted_topo = dominance_dict["df_sorted_topo"]

# %%
dominance_matrix_cm_p_tss.shape, len(dominance_graph_cm_p_tss)
# Out:
# ((741, 741), 741)

# %%
df_sorted_topo["Classification"].value_counts()
# Out:
# Classification
# intermediate_model    737
# dominant_model          2
# non_dominant_model      2
# Name: count, dtype: int64

# %%
df_sorted_topo.to_csv(
    "../../../../reports/results/local_models/ecics/ecics_dominance_analysis_cm_p_tss.csv",
    index=False,
)

# %%
df_sorted_topo.head(5)
# Out:
#     Company Plant   Cross Validation  \
# 429     209    am  Time Series Split
# 701     209     w  Time Series Split
# 439     209    am  Time Series Split
# 436     209    am  Time Series Split
# 714     209     w  Time Series Split
#
#                                            Features  \
# 429  Chemical + Mineralogical + Physical - Early CS
# 701  Chemical + Mineralogical + Physical - Early CS
# 439  Chemical + Mineralogical + Physical - Early CS
# 436  Chemical + Mineralogical + Physical - Early CS
# 714  Chemical + Mineralogical + Physical - Early CS
#
#                       Features_bkp            Model         Model_bkp  \
# 429  Chemical + Properties CS Less            Trees     Random Forest
# 701  Chemical + Properties CS Less            Trees     Random Forest
# 439  Chemical + Properties CS Less  Neural Networks       Transformer
# 436  Chemical + Properties CS Less  Neural Networks  BidirectionalGRU
# 714  Chemical + Properties CS Less            Trees     Decision Tree
#
#               Model_bkp_2  Timesteps  RMSE_mean  ...  MAPE_mean   R2_mean  \
# 429         Random Forest        NaN   1.208376  ...   2.217570  0.958753
# 701         Random Forest        NaN   1.054868  ...   1.942043  0.956641
# 439       Transformer_1.0        1.0   1.210447  ...   2.423692  0.958424
# 436  BidirectionalGRU_1.0        1.0   1.231971  ...   2.274052  0.956541
# 714         Decision Tree        NaN   1.075055  ...   2.003345  0.956117
#
#      RMSE_std   MAE_std  MAPE_std    R2_std      SCPM  Dominated_Count  \
# 429  0.080687  0.075124  0.190960  0.005389 -2.674780                0
# 701  0.210776  0.131717  0.329345  0.018725 -2.814382                0
# 439  0.125062  0.126928  0.338465  0.008429 -2.607282                1
# 436  0.161695  0.134257  0.325140  0.012132 -2.647361                2
# 714  0.154502  0.114520  0.303765  0.011129 -2.791586                1
#
#          Classification Dominates_Count
# 429      dominant_model             735
# 701      dominant_model             738
# 439  intermediate_model             729
# 436  intermediate_model             732
# 714  intermediate_model             736
#
# [5 rows x 21 columns]

# %%
df_sorted_topo_cols = df_sorted_topo[
    [
        # "Model",
        # "Model_bkp",
        "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Classification",
        "Dominates_Count",
        "Plant",
    ]
].round(2)

# %% [markdown]
# ###### Dominant Models

# %%
# Top 5
df_sorted_topo_cols.sort_values(
    by=["Dominates_Count", "SCPM"], ascending=[False, True]
).iloc[:5].round(2)
# Out:
#               Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 701         Random Forest       1.05      0.21      0.81     0.13       1.94
# 714         Decision Tree       1.08      0.15      0.83     0.11       2.00
# 641         Random Forest       1.16      0.22      0.84     0.10       2.08
# 429         Random Forest       1.21      0.08      0.92     0.08       2.22
# 436  BidirectionalGRU_1.0       1.23      0.16      0.95     0.13       2.27
#
#      MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 701      0.33     0.96    0.02 -2.81                0      dominant_model
# 714      0.30     0.96    0.01 -2.79                1  intermediate_model
# 641      0.24     0.95    0.02 -2.75                2  intermediate_model
# 429      0.19     0.96    0.01 -2.67                0      dominant_model
# 436      0.33     0.96    0.01 -2.65                2  intermediate_model
#
#      Dominates_Count Plant
# 701              738     w
# 714              736     w
# 641              735     s
# 429              735    am
# 436              732    am

# %%
# Top 4
df_sorted_topo_cols.iloc[0:4].sort_values(by="Dominates_Count", ascending=False)
# Out:
#               Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 701         Random Forest       1.05      0.21      0.81     0.13       1.94
# 429         Random Forest       1.21      0.08      0.92     0.08       2.22
# 436  BidirectionalGRU_1.0       1.23      0.16      0.95     0.13       2.27
# 439       Transformer_1.0       1.21      0.13      0.99     0.13       2.42
#
#      MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 701      0.33     0.96    0.02 -2.81                0      dominant_model
# 429      0.19     0.96    0.01 -2.67                0      dominant_model
# 436      0.33     0.96    0.01 -2.65                2  intermediate_model
# 439      0.34     0.96    0.01 -2.61                1  intermediate_model
#
#      Dominates_Count Plant
# 701              738     w
# 429              735    am
# 436              732    am
# 439              729    am

# %%
df_sorted_topo_cols[df_sorted_topo_cols["Classification"].eq("dominant_model")].shape
# Out:
# (2, 14)

# %% [markdown]
# ###### Intermediate models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].sort_values(by=["Dominates_Count", "SCPM"], ascending=[False, True]).iloc[:3]
# Out:
#               Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 714         Decision Tree       1.08      0.15      0.83     0.11       2.00
# 641         Random Forest       1.16      0.22      0.84     0.10       2.08
# 436  BidirectionalGRU_1.0       1.23      0.16      0.95     0.13       2.27
#
#      MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 714      0.30     0.96    0.01 -2.79                1  intermediate_model
# 641      0.24     0.95    0.02 -2.75                2  intermediate_model
# 436      0.33     0.96    0.01 -2.65                2  intermediate_model
#
#      Dominates_Count Plant
# 714              736     w
# 641              735     s
# 436              732    am

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].shape
# Out:
# (737, 14)

# %% [markdown]
# ###### non-dominant models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].sort_values(by=["Dominates_Count", "SCPM"], ascending=[False, True]).iloc[:5]
# Out:
#     Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  MAPE_std  \
# 391   LSTM_14.0      45.81    103.20     29.60    64.21      64.29    137.72
# 400         MLP      31.65     44.91     26.17    37.04      71.56    101.81
#
#      R2_mean   R2_std   SCPM  Dominated_Count      Classification  \
# 391 -1459.51  4244.20  45.14              739  non_dominant_model
# 400 -2889.90  5595.66  52.96              739  non_dominant_model
#
#      Dominates_Count Plant
# 391                0    ac
# 400                0    ag

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].shape
# Out:
# (2, 14)

# %% [markdown]
# ###### Statistics per model type

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        # "Model_bkp",
        # "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
        "Plant",
    ]
]  # .round(2)

# %%
df_sorted_topo["Model"].value_counts()
# Out:
# Model
# Neural Networks      578
# Trees                122
# Linear Regression     41
# Name: count, dtype: int64

# %%
df_sorted_topo_models_grouped = df_sorted_topo_models_cols.groupby("Model").describe().T

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
    ]
]

# %%
(
    df_sorted_topo_models_cols.groupby("Model")[["Classification"]]
    .value_counts(normalize=True)
    .to_frame()
    * 100
).round(2)
# Out:
#                                       proportion
# Model             Classification
# Linear Regression intermediate_model      100.00
# Neural Networks   intermediate_model       99.65
#                   non_dominant_model        0.35
# Trees             intermediate_model       98.36
#                   dominant_model            1.64

# %%
df_sorted_topo_models_cols.groupby("Model").describe().round(2).T
# Out:
# Model                  Linear Regression  Neural Networks   Trees
# Dominated_Count count              41.00           578.00  122.00
#                 mean              120.83           323.38  117.72
#                 std               107.16           203.62   94.12
#                 min                 5.00             1.00    0.00
#                 25%                36.00           159.25   40.25
#                 50%                91.00           288.50   91.00
#                 75%               155.00           473.75  182.75
#                 max               405.00           739.00  415.00
# Dominates_Count count              41.00           578.00  122.00
#                 mean              402.29           242.06  408.39
#                 std               184.12           195.76  171.10
#                 min               123.00             0.00   69.00
#                 25%               226.00            78.25  272.50
#                 50%               388.00           196.50  378.00
#                 75%               546.00           352.75  545.50
#                 max               724.00           732.00  738.00

# %%
# df_sorted_topo_models_cols

# %%
df_sorted_topo_models_cols.groupby("Model")["Classification"].describe()
# Out:
#                   count unique                 top freq
# Model
# Linear Regression    41      1  intermediate_model   41
# Neural Networks     578      2  intermediate_model  576
# Trees               122      2  intermediate_model  120

# %%
df_sorted_topo_models_cols.groupby("Model")[["Classification"]].value_counts()
# Out:
# Model              Classification
# Linear Regression  intermediate_model     41
# Neural Networks    intermediate_model    576
#                    non_dominant_model      2
# Trees              intermediate_model    120
#                    dominant_model          2
# Name: count, dtype: int64

# %%
summary_stats = df_sorted_topo_models_cols.groupby("Model").agg(
    Total_Models=("Model", "count"),
    Mean_Dominance_Count=("Dominates_Count", "mean"),
    Median_Dominance_Count=("Dominates_Count", "median"),
    Total_Dominated=("Dominated_Count", "sum"),
    Total_Dominating=("Dominates_Count", "sum"),
)

total_models = summary_stats[
    "Total_Models"
].sum()  # Get the total number of models across all categories
summary_stats["Dominance Proportion"] = summary_stats["Total_Dominating"] / total_models

# %%
summary_stats.round(2)
# Out:
#                    Total_Models  Mean_Dominance_Count  Median_Dominance_Count  \
# Model
# Linear Regression            41                402.29                   388.0
# Neural Networks             578                242.06                   196.5
# Trees                       122                408.39                   378.0
#
#                    Total_Dominated  Total_Dominating  Dominance Proportion
# Model
# Linear Regression             4954             16494                 22.26
# Neural Networks             186914            139913                188.82
# Trees                        14362             49823                 67.24

# %%
df_sorted_topo_models_grouped.T
# Out:
#                   RMSE_mean                                                   \
#                       count      mean       std       min      25%       50%
# Model
# Linear Regression      41.0  2.373273  0.848884  1.283465  1.77633  2.285707
# Neural Networks       578.0  4.697463  4.002395  1.210447  2.70217  3.640916
# Trees                 122.0  2.389979  0.830438  1.054868  1.83224  2.199070
#
#                                        RMSE_std            ...  \
#                         75%        max    count      mean  ...
# Model                                                      ...
# Linear Regression  2.701500   4.422856     41.0  0.470685  ...
# Neural Networks    5.016255  45.811576    578.0  3.350501  ...
# Trees              2.829195   6.045234    122.0  0.536164  ...
#
#                   Dominated_Count        Dominates_Count              \
#                               75%    max           count        mean
# Model
# Linear Regression          155.00  405.0            41.0  402.292683
# Neural Networks            473.75  739.0           578.0  242.064014
# Trees                      182.75  415.0           122.0  408.385246
#
#
#                           std    min     25%    50%     75%    max
# Model
# Linear Regression  184.122139  123.0  226.00  388.0  546.00  724.0
# Neural Networks    195.760458    0.0   78.25  196.5  352.75  732.0
# Trees              171.097114   69.0  272.50  378.0  545.50  738.0
#
# [3 rows x 88 columns]

# %% [markdown]
# ### SCPM Analysis

# %%
cols = [
    # "Model",
    # "Model_bkp",
    "Model_bkp_2",
    "RMSE_mean",
    "RMSE_std",
    "MAE_mean",
    "MAE_std",
    "MAPE_mean",
    "MAPE_std",
    "R2_mean",
    "R2_std",
    "SCPM",
    "Dominated_Count",
    "Dominates_Count",
    "Classification",
    "Plant",
]

# %% [markdown]
# #### SCPM Analysis by Project

# %%
df_sorted_scpm = df_sorted_topo.sort_values(by="SCPM").copy()

# %%
# (df_sorted_topo[cols].reset_index() == df_sorted_scpm[cols].reset_index()).all(axis=1)
df_sorted_scpm["topo_scmp_order_eq"] = df_sorted_topo.index == df_sorted_scpm.index

# %%
df_sorted_scpm[cols + ["topo_scmp_order_eq"]].round(2).head(5)
# Out:
#        Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 701  Random Forest       1.05      0.21      0.81     0.13       1.94
# 714  Decision Tree       1.08      0.15      0.83     0.11       2.00
# 641  Random Forest       1.16      0.22      0.84     0.10       2.08
# 429  Random Forest       1.21      0.08      0.92     0.08       2.22
# 654  Decision Tree       1.43      0.44      0.86     0.12       2.11
#
#      MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count  Dominates_Count  \
# 701      0.33     0.96    0.02 -2.81                0              738
# 714      0.30     0.96    0.01 -2.79                1              736
# 641      0.24     0.95    0.02 -2.75                2              735
# 429      0.19     0.96    0.01 -2.67                0              735
# 654      0.29     0.92    0.04 -2.66                3              704
#
#          Classification Plant  topo_scmp_order_eq
# 701      dominant_model     w               False
# 714  intermediate_model     w               False
# 641  intermediate_model     s               False
# 429      dominant_model    am               False
# 654  intermediate_model     s               False

# %% [markdown]
# ### Variable Grouping: CM-P-CS

# %%
df_results["Features"].unique()
# Out:
# array(['Chemical + Mineralogical + Physical', 'Chemical + Mineralogical',
#        'Chemical + Mineralogical + Physical - Early CS'], dtype=object)

# %%
df_results_cm_p_cs = (
    df_results[df_results["Features"].eq("Chemical + Mineralogical + Physical")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_p_cs["Features"].unique()
# Out:
# array(['Chemical + Mineralogical + Physical'], dtype=object)

# %%
df_results_cm_p.shape
# Out:
# (1455, 17)

# %% [markdown]
# ### K-Fold

# %%
# df_results_cm_p_cs["Cross Validation"].unique()

# %%
# df_results_cm_p_cs_kf = (
#     df_results_cm_p_cs[df_results_cm_p_cs["Cross Validation"].eq("Repeated KFold")]
#     .copy()
#     .reset_index(drop=True)
# )

# %%
# df_results_cm_p_cs_kf["Cross Validation"].unique()

# %%
# df_results_cm_p_cs_kf.shape

# %%
# df_results_cm_p_cs_kf_partner_i = df_results_cm_p_cs_kf[
#     df_results_cm_p_cs_kf["Plant"].eq("partner_i")
# ].copy()
# df_results_cm_p_cs_kf_partner_ii = df_results_cm_p_cs_kf[
#     df_results_cm_p_cs_kf["Plant"].eq("partner_ii")
# ].copy()
# df_results_cm_p_cs_kf_partner_iv = df_results_cm_p_cs_kf[
#     df_results_cm_p_cs_kf["Plant"].eq("partner_iv")
# ].copy()

# %% [markdown]
# ###### SCPM computation

# %%
# df_results_cm_p_cs_kf = compute_scpm(df_results_cm_p_cs_kf)

# %% [markdown]
# ##### Dominance Analysis

# %%
# dominance_dict = make_dominance_analysis(df_results_cm_p_cs_kf)
# dominance_matrix_cm_p_cs_kf = dominance_dict["dominance_matrix"]
# dominance_graph_cm_p_cs_kf = dominance_dict["dominance_graph"]
# df_sorted_count = dominance_dict["df_sorted_count"]
# df_sorted_topo = dominance_dict["df_sorted_topo"]

# %%
# dominance_matrix_cm_p_cs_kf.shape, len(dominance_graph_cm_p_cs_kf)

# %%
# df_sorted_topo["Classification"].value_counts()

# %%
# df_sorted_topo.to_csv(
#     "../../../../reports/results/local_models/ecics/ecics_dominance_analysis_cm_p_cs_kf.csv",
#     index=False,
# )

# %%
# df_sorted_topo.head(5)

# %%
# df_sorted_topo_cols = df_sorted_topo[
#     [
#         # "Model",
#         # "Model_bkp",
#         "Model_bkp_2",
#         "RMSE_mean",
#         "RMSE_std",
#         "MAE_mean",
#         "MAE_std",
#         "MAPE_mean",
#         "MAPE_std",
#         "R2_mean",
#         "R2_std",
#         "SCPM",
#         "Dominated_Count",
#         "Classification",
#         "Dominates_Count",
#         "Plant",
#     ]
# ].round(2)

# %% [markdown]
# ##### Top dominant models

# %%
# # Top 4
# df_sorted_topo_cols.iloc[0:2]

# %% [markdown]
# ##### Top intermediate models

# %%
# df_sorted_topo_cols[
#     df_sorted_topo_cols["Classification"].eq("intermediate_model")
# ].sort_values(by="Dominates_Count", ascending=False).iloc[:2]

# %% [markdown]
# ##### Top non dominant models

# %%
# df_sorted_topo_cols[
#     df_sorted_topo_cols["Classification"].eq("non_dominant_model")
# ].sort_values(by="Dominated_Count", ascending=True).iloc[:2]

# %%
# df_sorted_topo_models_cols = df_sorted_topo[
#     [
#         "Model",
#         # "Model_bkp",
#         # "Model_bkp_2",
#         "RMSE_mean",
#         "RMSE_std",
#         "MAE_mean",
#         "MAE_std",
#         "MAPE_mean",
#         "MAPE_std",
#         "R2_mean",
#         "R2_std",
#         "SCPM",
#         "Dominated_Count",
#         "Dominates_Count",
#         "Classification",
#         "Plant",
#     ]
# ]  # .round(2)

# %%
# df_sorted_topo["Model"].value_counts()

# %%
# df_sorted_topo_models_grouped = df_sorted_topo_models_cols.groupby("Model").describe().T

# %%
# df_sorted_topo_models_cols = df_sorted_topo[
#     [
#         "Model",
#         "Dominated_Count",
#         "Dominates_Count",
#         "Classification",
#     ]
# ]

# %%
# df_sorted_topo_models_cols.groupby("Model").describe().round(2)

# %%
# df_sorted_topo_models_cols.groupby("Model")["Classification"].describe()

# %%
# df_sorted_topo_models_cols.groupby("Model")[["Classification"]].value_counts()

# %%
# (
#     df_sorted_topo_models_cols.groupby("Model")[["Classification"]]
#     .value_counts(normalize=True)
#     .to_frame()
#     * 100
# ).round(2)

# %%
# summary_stats = df_sorted_topo_models_cols.groupby("Model").agg(
#     Total_Models=("Model", "count"),
#     Mean_Dominance_Count=("Dominates_Count", "mean"),
#     Median_Dominance_Count=("Dominates_Count", "median"),
#     Total_Dominated=("Dominated_Count", "sum"),
#     Total_Dominating=("Dominates_Count", "sum"),
# )

# total_models = summary_stats[
#     "Total_Models"
# ].sum()  # Get the total number of models across all categories
# summary_stats["Dominance Proportion"] = summary_stats["Total_Dominating"] / total_models

# %%
# summary_stats

# %%
# df_sorted_topo_models_grouped.T

# %% [markdown]
# ### SCPM Analysis

# %%
# cols = [
#     # "Model",
#     # "Model_bkp",
#     "Model_bkp_2",
#     "RMSE_mean",
#     "RMSE_std",
#     "MAE_mean",
#     "MAE_std",
#     "MAPE_mean",
#     "MAPE_std",
#     "R2_mean",
#     "R2_std",
#     "SCPM",
#     "Dominated_Count",
#     "Dominates_Count",
#     "Classification",
#     "Plant",
# ]

# %%
# df_sorted_scpm = df_sorted_topo.sort_values(by="SCPM").copy()

# %%
# # (df_sorted_topo[cols].reset_index() == df_sorted_scpm[cols].reset_index()).all(axis=1)
# df_sorted_scpm["topo_scmp_order_eq"] = df_sorted_topo.index == df_sorted_scpm.index

# %%
# df_sorted_topo[cols].round(2).head(5)

# %%
# df_sorted_scpm[cols + ["topo_scmp_order_eq"]].round(2).head(5)

# %% [markdown]
# ### Blocking time series

# %%
df_results_cm_p_cs["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split', 'Time Series Split'], dtype=object)

# %%
df_results_cm_p_cs_btss = (
    df_results_cm_p_cs[
        df_results_cm_p_cs["Cross Validation"].eq("Blocking Time Series Split")
    ]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_p_cs_btss["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split'], dtype=object)

# %%
df_results_cm_p_cs.shape, df_results_cm_p_cs_btss.shape
# Out:
# ((1449, 17), (714, 17))

# %% [markdown]
# ###### SCPM computation

# %%
df_results_cm_p_cs_btss = compute_scpm(df_results_cm_p_cs_btss)

# %% [markdown]
# ##### Dominance Analysis

# %%
# Per project
dominance_dict = make_dominance_analysis(df_results_cm_p_cs_btss)
dominance_matrix_cm_p_cs_btss = dominance_dict["dominance_matrix"]
dominance_graph_cm_p_cs_btss = dominance_dict["dominance_graph"]
df_sorted_count = dominance_dict["df_sorted_count"]
df_sorted_topo = dominance_dict["df_sorted_topo"]

# %%
dominance_matrix_cm_p_cs_btss.shape, len(dominance_graph_cm_p_cs_btss)
# Out:
# ((714, 714), 714)

# %%
df_sorted_topo["Classification"].value_counts()
# Out:
# Classification
# intermediate_model    708
# non_dominant_model      4
# dominant_model          2
# Name: count, dtype: int64

# %%
df_sorted_topo.to_csv(
    "../../../../reports/results/local_models/ecics/ecics_dominance_analysis_cm_p_cs_btss.csv",
    index=False,
)

# %%
df_sorted_topo.head(5)
# Out:
#     Company Plant            Cross Validation  \
# 553     209     k  Blocking Time Series Split
# 624     209     s  Blocking Time Series Split
# 544     209     k  Blocking Time Series Split
# 631     209     s  Blocking Time Series Split
# 20      203     c  Blocking Time Series Split
#
#                                 Features         Features_bkp  \
# 553  Chemical + Mineralogical + Physical  Chemical + Physical
# 624  Chemical + Mineralogical + Physical  Chemical + Physical
# 544  Chemical + Mineralogical + Physical  Chemical + Physical
# 631  Chemical + Mineralogical + Physical  Chemical + Physical
# 20   Chemical + Mineralogical + Physical  Chemical + Physical
#
#                  Model          Model_bkp        Model_bkp_2  Timesteps  \
# 553  Linear Regression  Linear Regression  Linear Regression        NaN
# 624              Trees      Random Forest      Random Forest        NaN
# 544              Trees      Random Forest      Random Forest        NaN
# 631  Linear Regression  Linear Regression  Linear Regression        NaN
# 20               Trees      Random Forest      Random Forest        NaN
#
#      RMSE_mean  ...  MAPE_mean   R2_mean  RMSE_std   MAE_std  MAPE_std  \
# 553   0.764152  ...   1.323375  0.979176  0.165211  0.125128  0.315609
# 624   0.736056  ...   1.383532  0.980892  0.110052  0.060481  0.132223
# 544   0.827005  ...   1.505115  0.974471  0.213079  0.146063  0.354002
# 631   0.775060  ...   1.505647  0.979073  0.086191  0.077031  0.218936
# 20    0.876747  ...   1.544938  0.977017  0.192428  0.154084  0.326348
#
#        R2_std      SCPM  Dominated_Count      Classification Dominates_Count
# 553  0.014548 -3.635604                0      dominant_model             712
# 624  0.006670 -3.635736                0      dominant_model             712
# 544  0.020180 -3.552954                2  intermediate_model             707
# 631  0.005523 -3.585751                2  intermediate_model             710
# 20   0.008537 -3.526165                3  intermediate_model             707
#
# [5 rows x 21 columns]

# %%
df_sorted_topo_cols = df_sorted_topo[
    [
        # "Model",
        # "Model_bkp",
        "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Classification",
        "Dominates_Count",
        "Plant",
    ]
].round(2)

# %% [markdown]
# ###### Dominant Models

# %%
# Top 5
df_sorted_topo_cols.sort_values(
    by=["Dominates_Count", "SCPM"], ascending=[False, True]
).iloc[:5].round(2)
# Out:
#            Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 553  Linear Regression       0.76      0.17      0.57     0.13       1.32
# 624      Random Forest       0.74      0.11      0.56     0.06       1.38
# 631  Linear Regression       0.78      0.09      0.61     0.08       1.51
# 544      Random Forest       0.83      0.21      0.65     0.15       1.51
# 20       Random Forest       0.88      0.19      0.66     0.15       1.54
#
#      MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 553      0.32     0.98    0.01 -3.64                0      dominant_model
# 624      0.13     0.98    0.01 -3.64                0      dominant_model
# 631      0.22     0.98    0.01 -3.59                2  intermediate_model
# 544      0.35     0.97    0.02 -3.55                2  intermediate_model
# 20       0.33     0.98    0.01 -3.53                3  intermediate_model
#
#      Dominates_Count Plant
# 553              712     k
# 624              712     s
# 631              710     s
# 544              707     k
# 20               707     c

# %%
# Top 4
df_sorted_topo_cols.iloc[0:5]
# Out:
#            Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 553  Linear Regression       0.76      0.17      0.57     0.13       1.32
# 624      Random Forest       0.74      0.11      0.56     0.06       1.38
# 544      Random Forest       0.83      0.21      0.65     0.15       1.51
# 631  Linear Regression       0.78      0.09      0.61     0.08       1.51
# 20       Random Forest       0.88      0.19      0.66     0.15       1.54
#
#      MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 553      0.32     0.98    0.01 -3.64                0      dominant_model
# 624      0.13     0.98    0.01 -3.64                0      dominant_model
# 544      0.35     0.97    0.02 -3.55                2  intermediate_model
# 631      0.22     0.98    0.01 -3.59                2  intermediate_model
# 20       0.33     0.98    0.01 -3.53                3  intermediate_model
#
#      Dominates_Count Plant
# 553              712     k
# 624              712     s
# 544              707     k
# 631              710     s
# 20               707     c

# %%
df_sorted_topo_cols[df_sorted_topo_cols["Classification"].eq("dominant_model")].shape
# Out:
# (2, 14)

# %% [markdown]
# ###### Intermediate models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].sort_values(by=["Dominates_Count", "SCPM"], ascending=[False, True]).iloc[:3]
# Out:
#            Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 631  Linear Regression       0.78      0.09      0.61     0.08       1.51
# 544      Random Forest       0.83      0.21      0.65     0.15       1.51
# 20       Random Forest       0.88      0.19      0.66     0.15       1.54
#
#      MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 631      0.22     0.98    0.01 -3.59                2  intermediate_model
# 544      0.35     0.97    0.02 -3.55                2  intermediate_model
# 20       0.33     0.98    0.01 -3.53                3  intermediate_model
#
#      Dominates_Count Plant
# 631              710     s
# 544              707     k
# 20               707     c

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].shape
# Out:
# (708, 14)

# %% [markdown]
# ###### non-dominant models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].sort_values(by=["Dominated_Count", "SCPM"], ascending=[True, True]).iloc[:6]
# Out:
#                Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 248  BidirectionalLSTM_7.0      22.26     18.39     17.32    15.18      38.95
# 391                    MLP      14.08      2.65     13.02     2.65      34.98
# 600                    MLP      17.45      4.45     15.77     4.58      31.52
# 246              LSTM_14.0      16.53     17.07     15.11    17.14      31.57
#
#      MAPE_std  R2_mean   R2_std   SCPM  Dominated_Count      Classification  \
# 248     29.52   -26.14    35.01  16.63              656  non_dominant_model
# 391      6.82  -528.15   609.31  20.55              700  non_dominant_model
# 600      9.07  -269.57   242.53  17.54              708  non_dominant_model
# 246     33.72  -782.60  1272.65  26.06              710  non_dominant_model
#
#      Dominates_Count Plant
# 248                0     i
# 391                0    ag
# 600                0     p
# 246                0     i

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].shape
# Out:
# (4, 14)

# %% [markdown]
# ###### Statistics per model type

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        # "Model_bkp",
        # "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
        "Plant",
    ]
]  # .round(2)

# %%
df_sorted_topo["Model"].value_counts()
# Out:
# Model
# Neural Networks      551
# Trees                122
# Linear Regression     41
# Name: count, dtype: int64

# %%
df_sorted_topo_models_grouped = df_sorted_topo_models_cols.groupby("Model").describe().T

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
    ]
]

# %%
(
    df_sorted_topo_models_cols.groupby("Model")[["Classification"]]
    .value_counts(normalize=True)
    .to_frame()
    * 100
).round(2)
# Out:
#                                       proportion
# Model             Classification
# Linear Regression intermediate_model       97.56
#                   dominant_model            2.44
# Neural Networks   intermediate_model       99.27
#                   non_dominant_model        0.73
# Trees             intermediate_model       99.18
#                   dominant_model            0.82

# %%
df_sorted_topo_models_cols.groupby("Model").describe().round(2).T
# Out:
# Model                  Linear Regression  Neural Networks   Trees
# Dominated_Count count              41.00           551.00  122.00
#                 mean               56.90           349.12   83.02
#                 std                59.16           185.08   61.59
#                 min                 0.00             8.00    0.00
#                 25%                16.00           197.00   37.00
#                 50%                36.00           356.00   66.00
#                 75%                72.00           497.50  113.75
#                 max               225.00           710.00  266.00
# Dominates_Count count              41.00           551.00  122.00
#                 mean              514.46           228.25  475.14
#                 std               125.81           177.18  115.95
#                 min               278.00             0.00  239.00
#                 25%               400.00            77.00  383.50
#                 50%               509.00           194.00  462.50
#                 75%               619.00           364.00  553.75
#                 max               712.00           696.00  712.00

# %%
df_sorted_topo_models_cols.groupby("Model")["Classification"].describe()
# Out:
#                   count unique                 top freq
# Model
# Linear Regression    41      2  intermediate_model   40
# Neural Networks     551      2  intermediate_model  547
# Trees               122      2  intermediate_model  121

# %%
df_sorted_topo_models_cols.groupby("Model")[["Classification"]].value_counts()
# Out:
# Model              Classification
# Linear Regression  intermediate_model     40
#                    dominant_model          1
# Neural Networks    intermediate_model    547
#                    non_dominant_model      4
# Trees              intermediate_model    121
#                    dominant_model          1
# Name: count, dtype: int64

# %%
# df_sorted_topo_models_cols

# %%
summary_stats = df_sorted_topo_models_cols.groupby("Model").agg(
    Total_Models=("Model", "count"),
    Mean_Dominance_Count=("Dominates_Count", "mean"),
    Median_Dominance_Count=("Dominates_Count", "median"),
    Total_Dominated=("Dominated_Count", "sum"),
    Total_Dominating=("Dominates_Count", "sum"),
)

total_models = summary_stats[
    "Total_Models"
].sum()  # Get the total number of models across all categories
summary_stats["Dominance Proportion"] = summary_stats["Total_Dominating"] / total_models

# %%
summary_stats
# Out:
#                    Total_Models  Mean_Dominance_Count  Median_Dominance_Count  \
# Model
# Linear Regression            41            514.463415                   509.0
# Neural Networks             551            228.250454                   194.0
# Trees                       122            475.139344                   462.5
#
#                    Total_Dominated  Total_Dominating  Dominance Proportion
# Model
# Linear Regression             2333             21093             29.542017
# Neural Networks             192364            125766            176.142857
# Trees                        10129             57967             81.186275

# %%
df_sorted_topo_models_grouped.T
# Out:
#                   RMSE_mean                                                    \
#                       count      mean       std       min       25%       50%
# Model
# Linear Regression      41.0  1.493826  0.506908  0.764152  1.211020  1.372718
# Neural Networks       551.0  5.138426  3.182486  0.939625  2.777817  4.458311
# Trees                 122.0  1.724293  0.528999  0.736056  1.353551  1.629778
#
#                                        RMSE_std            ...  \
#                         75%        max    count      mean  ...
# Model                                                      ...
# Linear Regression  1.622754   2.931612     41.0  0.343669  ...
# Neural Networks    6.568332  22.257844    551.0  2.232859  ...
# Trees              1.997491   3.814470    122.0  0.448093  ...
#
#                   Dominated_Count        Dominates_Count              \
#                               75%    max           count        mean
# Model
# Linear Regression           72.00  225.0            41.0  514.463415
# Neural Networks            497.50  710.0           551.0  228.250454
# Trees                      113.75  266.0           122.0  475.139344
#
#
#                           std    min    25%    50%     75%    max
# Model
# Linear Regression  125.808604  278.0  400.0  509.0  619.00  712.0
# Neural Networks    177.180757    0.0   77.0  194.0  364.00  696.0
# Trees              115.951566  239.0  383.5  462.5  553.75  712.0
#
# [3 rows x 88 columns]

# %% [markdown]
# ### SCPM Analysis

# %%
cols = [
    # "Model",
    # "Model_bkp",
    "Model_bkp_2",
    "RMSE_mean",
    "RMSE_std",
    "MAE_mean",
    "MAE_std",
    "MAPE_mean",
    "MAPE_std",
    "R2_mean",
    "R2_std",
    "SCPM",
    "Dominated_Count",
    "Dominates_Count",
    "Classification",
    "Plant",
]

# %% [markdown]
# #### SCPM Analysis by Project

# %%
df_sorted_scpm = df_sorted_topo.sort_values(by="SCPM").copy()

# %%
df_sorted_scpm["topo_scmp_order_eq"] = df_sorted_topo.index == df_sorted_scpm.index

# %%
df_sorted_scpm[cols + ["topo_scmp_order_eq"]].round(5).head(5)
# Out:
#            Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 624      Random Forest    0.73606   0.11005   0.56235  0.06048    1.38353
# 553  Linear Regression    0.76415   0.16521   0.56618  0.12513    1.32338
# 631  Linear Regression    0.77506   0.08619   0.60510  0.07703    1.50565
# 544      Random Forest    0.82701   0.21308   0.64693  0.14606    1.50511
# 20       Random Forest    0.87675   0.19243   0.65788  0.15408    1.54494
#
#      MAPE_std  R2_mean   R2_std     SCPM  Dominated_Count  Dominates_Count  \
# 624   0.13222  0.98089  0.00667 -3.63574                0              712
# 553   0.31561  0.97918  0.01455 -3.63560                0              712
# 631   0.21894  0.97907  0.00552 -3.58575                2              710
# 544   0.35400  0.97447  0.02018 -3.55295                2              707
# 20    0.32635  0.97702  0.00854 -3.52617                3              707
#
#          Classification Plant  topo_scmp_order_eq
# 624      dominant_model     s               False
# 553      dominant_model     k               False
# 631  intermediate_model     s               False
# 544  intermediate_model     k               False
# 20   intermediate_model     c                True

# %% [markdown]
# ### Time Series Split

# %%
df_results_cm_p_cs["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split', 'Time Series Split'], dtype=object)

# %%
df_results_cm_p_cs_tss = (
    df_results_cm_p_cs[df_results_cm_p_cs["Cross Validation"].eq("Time Series Split")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_p_cs_tss["Cross Validation"].unique()
# Out:
# array(['Time Series Split'], dtype=object)

# %%
df_results_cm_p_cs_tss.shape
# Out:
# (735, 17)

# %% [markdown]
# ###### SCPM computation

# %%
df_results_cm_p_cs_tss = compute_scpm(df_results_cm_p_cs_tss)

# %% [markdown]
# ##### Dominance Analysis

# %%
# Per project
dominance_dict = make_dominance_analysis(df_results_cm_p_cs_tss)
dominance_matrix_cm_p_cs_tss = dominance_dict["dominance_matrix"]
dominance_graph_cm_p_cs_tss = dominance_dict["dominance_graph"]
df_sorted_count = dominance_dict["df_sorted_count"]
df_sorted_topo = dominance_dict["df_sorted_topo"]

# %%
dominance_matrix_cm_p_cs_tss.shape, len(dominance_graph_cm_p_cs_tss)
# Out:
# ((735, 735), 735)

# %%
df_sorted_topo["Classification"].value_counts()
# Out:
# Classification
# intermediate_model    729
# non_dominant_model      4
# dominant_model          2
# Name: count, dtype: int64

# %%
df_sorted_topo.to_csv(
    "../../../../reports/results/local_models/ecics/ecics_dominance_analysis_cm_p_cs_tss.csv",
    index=False,
)

# %%
df_sorted_topo.head(5)
# Out:
#     Company Plant   Cross Validation                             Features  \
# 554     209     k  Time Series Split  Chemical + Mineralogical + Physical
# 630     209     s  Time Series Split  Chemical + Mineralogical + Physical
# 545     209     k  Time Series Split  Chemical + Mineralogical + Physical
# 639     209     s  Time Series Split  Chemical + Mineralogical + Physical
# 641     209     s  Time Series Split  Chemical + Mineralogical + Physical
#
#             Features_bkp              Model          Model_bkp  \
# 554  Chemical + Physical  Linear Regression  Linear Regression
# 630  Chemical + Physical              Trees      Random Forest
# 545  Chemical + Physical              Trees      Random Forest
# 639  Chemical + Physical  Linear Regression  Linear Regression
# 641  Chemical + Physical    Neural Networks        Transformer
#
#            Model_bkp_2  Timesteps  RMSE_mean  ...  MAPE_mean   R2_mean  \
# 554  Linear Regression        NaN   0.800385  ...   1.425871  0.981168
# 630      Random Forest        NaN   0.743018  ...   1.389938  0.979396
# 545      Random Forest        NaN   0.854275  ...   1.539447  0.979093
# 639  Linear Regression        NaN   0.844350  ...   1.625278  0.973588
# 641    Transformer_1.0        1.0   0.817066  ...   1.624024  0.975219
#
#      RMSE_std   MAE_std  MAPE_std    R2_std      SCPM  Dominated_Count  \
# 554  0.182363  0.137824  0.322025  0.009499 -2.567808                0
# 630  0.084434  0.058095  0.132086  0.004491 -2.615872                0
# 545  0.141281  0.096530  0.214330  0.008800 -2.513740                2
# 639  0.121085  0.069025  0.157404  0.005804 -2.509517                2
# 641  0.088433  0.077860  0.193727  0.004620 -2.515017                2
#
#          Classification Dominates_Count
# 554      dominant_model             733
# 630      dominant_model             733
# 545  intermediate_model             730
# 639  intermediate_model             729
# 641  intermediate_model             729
#
# [5 rows x 21 columns]

# %%
df_sorted_topo_cols = df_sorted_topo[
    [
        # "Model",
        # "Model_bkp",
        "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Classification",
        "Dominates_Count",
        "Plant",
    ]
].round(2)

# %% [markdown]
# ###### Dominant Models

# %%
# Top 5
df_sorted_topo_cols.sort_values(
    by=["Dominates_Count", "SCPM"], ascending=[False, True]
).iloc[:5].round(2)
# Out:
#            Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 630      Random Forest       0.74      0.08      0.56     0.06       1.39
# 554  Linear Regression       0.80      0.18      0.62     0.14       1.43
# 545      Random Forest       0.85      0.14      0.67     0.10       1.54
# 641    Transformer_1.0       0.82      0.09      0.65     0.08       1.62
# 639  Linear Regression       0.84      0.12      0.65     0.07       1.63
#
#      MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 630      0.13     0.98    0.00 -2.62                0      dominant_model
# 554      0.32     0.98    0.01 -2.57                0      dominant_model
# 545      0.21     0.98    0.01 -2.51                2  intermediate_model
# 641      0.19     0.98    0.00 -2.52                2  intermediate_model
# 639      0.16     0.97    0.01 -2.51                2  intermediate_model
#
#      Dominates_Count Plant
# 630              733     s
# 554              733     k
# 545              730     k
# 641              729     s
# 639              729     s

# %%
# Top 2
df_sorted_topo_cols.iloc[0:2].sort_values(by="Dominates_Count", ascending=False)
# Out:
#            Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 554  Linear Regression       0.80      0.18      0.62     0.14       1.43
# 630      Random Forest       0.74      0.08      0.56     0.06       1.39
#
#      MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count  Classification  \
# 554      0.32     0.98    0.01 -2.57                0  dominant_model
# 630      0.13     0.98    0.00 -2.62                0  dominant_model
#
#      Dominates_Count Plant
# 554              733     k
# 630              733     s

# %%
df_sorted_topo_cols[df_sorted_topo_cols["Classification"].eq("dominant_model")].shape
# Out:
# (2, 14)

# %% [markdown]
# ###### Intermediate models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].sort_values(by=["Dominates_Count", "SCPM"], ascending=[False, True]).iloc[:4]
# Out:
#            Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 545      Random Forest       0.85      0.14      0.67     0.10       1.54
# 641    Transformer_1.0       0.82      0.09      0.65     0.08       1.62
# 639  Linear Regression       0.84      0.12      0.65     0.07       1.63
# 427  Linear Regression       0.92      0.04      0.73     0.03       1.79
#
#      MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 545      0.21     0.98    0.01 -2.51                2  intermediate_model
# 641      0.19     0.98    0.00 -2.52                2  intermediate_model
# 639      0.16     0.97    0.01 -2.51                2  intermediate_model
# 427      0.06     0.98    0.00 -2.42                3  intermediate_model
#
#      Dominates_Count Plant
# 545              730     k
# 641              729     s
# 639              729     s
# 427              727    am

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].shape
# Out:
# (729, 14)

# %% [markdown]
# ###### non-dominant models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].sort_values(by=["Dominated_Count", "SCPM"], ascending=[True, False]).iloc[:5]
# Out:
#                Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 395                    MLP      28.96     40.84     24.15    33.89      66.02
# 392  BidirectionalLSTM_7.0      31.42     51.72     21.33    34.91      46.85
# 390              LSTM_14.0      31.26     58.26     19.97    35.94      43.75
# 504              LSTM_14.0      40.43     80.53     19.95    37.43      49.32
#
#      MAPE_std  R2_mean   R2_std   SCPM  Dominated_Count      Classification  \
# 395     93.21 -2400.15  4821.11  49.80              729  non_dominant_model
# 392     75.14  -458.93   790.45  26.87              729  non_dominant_model
# 390     77.33  -517.36  1154.80  26.25              730  non_dominant_model
# 504     93.86  -875.18  2334.99  33.09              731  non_dominant_model
#
#      Dominates_Count Plant
# 395                0    ag
# 392                0    ac
# 390                0    ac
# 504                0     e

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].shape
# Out:
# (4, 14)

# %% [markdown]
# ###### Statistics per model type

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        # "Model_bkp",
        # "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
        "Plant",
    ]
]  # .round(2)

# %%
df_sorted_topo["Model"].value_counts()
# Out:
# Model
# Neural Networks      572
# Trees                122
# Linear Regression     41
# Name: count, dtype: int64

# %%
df_sorted_topo_models_grouped = df_sorted_topo_models_cols.groupby("Model").describe().T

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
    ]
]

# %%
(
    df_sorted_topo_models_cols.groupby("Model")[["Classification"]]
    .value_counts(normalize=True)
    .to_frame()
    * 100
).round(2)
# Out:
#                                       proportion
# Model             Classification
# Linear Regression intermediate_model       97.56
#                   dominant_model            2.44
# Neural Networks   intermediate_model       99.30
#                   non_dominant_model        0.70
# Trees             intermediate_model       99.18
#                   dominant_model            0.82

# %%
df_sorted_topo_models_cols.groupby("Model").describe().round(2).T
# Out:
# Model                  Linear Regression  Neural Networks   Trees
# Dominated_Count count              41.00           572.00  122.00
#                 mean               79.20           338.59  116.73
#                 std                83.11           200.82   92.94
#                 min                 0.00             2.00    0.00
#                 25%                17.00           170.00   49.25
#                 50%                46.00           325.50   85.00
#                 75%               108.00           497.00  166.50
#                 max               353.00           731.00  388.00
# Dominates_Count count              41.00           572.00  122.00
#                 mean              481.68           243.14  428.98
#                 std               166.53           190.68  155.82
#                 min               181.00             0.00   66.00
#                 25%               334.00            80.00  303.25
#                 50%               487.00           201.50  421.50
#                 75%               645.00           373.00  540.50
#                 max               733.00           729.00  733.00

# %%
# df_sorted_topo_models_cols

# %%
df_sorted_topo_models_cols.groupby("Model")["Classification"].describe()
# Out:
#                   count unique                 top freq
# Model
# Linear Regression    41      2  intermediate_model   40
# Neural Networks     572      2  intermediate_model  568
# Trees               122      2  intermediate_model  121

# %%
df_sorted_topo_models_cols.groupby("Model")[["Classification"]].value_counts()
# Out:
# Model              Classification
# Linear Regression  intermediate_model     40
#                    dominant_model          1
# Neural Networks    intermediate_model    568
#                    non_dominant_model      4
# Trees              intermediate_model    121
#                    dominant_model          1
# Name: count, dtype: int64

# %%
summary_stats = df_sorted_topo_models_cols.groupby("Model").agg(
    Total_Models=("Model", "count"),
    Mean_Dominance_Count=("Dominates_Count", "mean"),
    Median_Dominance_Count=("Dominates_Count", "median"),
    Total_Dominated=("Dominated_Count", "sum"),
    Total_Dominating=("Dominates_Count", "sum"),
)

total_models = summary_stats[
    "Total_Models"
].sum()  # Get the total number of models across all categories
summary_stats["Dominance Proportion"] = summary_stats["Total_Dominating"] / total_models

# %%
summary_stats.round(2)
# Out:
#                    Total_Models  Mean_Dominance_Count  Median_Dominance_Count  \
# Model
# Linear Regression            41                481.68                   487.0
# Neural Networks             572                243.14                   201.5
# Trees                       122                428.98                   421.5
#
#                    Total_Dominated  Total_Dominating  Dominance Proportion
# Model
# Linear Regression             3247             19749                 26.87
# Neural Networks             193674            139077                189.22
# Trees                        14241             52336                 71.21

# %%
df_sorted_topo_models_grouped.T
# Out:
#                   RMSE_mean                                                    \
#                       count      mean       std       min       25%       50%
# Model
# Linear Regression      41.0  1.608508  0.551316  0.800385  1.191155  1.492822
# Neural Networks       572.0  4.251789  4.241845  0.817066  2.244090  3.190366
# Trees                 122.0  1.863850  0.595623  0.743018  1.472725  1.745153
#
#                                        RMSE_std            ...  \
#                         75%        max    count      mean  ...
# Model                                                      ...
# Linear Regression  1.960015   3.121313     41.0  0.308952  ...
# Neural Networks    4.479370  40.426137    572.0  3.421153  ...
# Trees              2.215179   3.539236    122.0  0.398297  ...
#
#                   Dominated_Count        Dominates_Count              \
#                               75%    max           count        mean
# Model
# Linear Regression           108.0  353.0            41.0  481.682927
# Neural Networks             497.0  731.0           572.0  243.141608
# Trees                       166.5  388.0           122.0  428.983607
#
#
#                           std    min     25%    50%    75%    max
# Model
# Linear Regression  166.528142  181.0  334.00  487.0  645.0  733.0
# Neural Networks    190.680455    0.0   80.00  201.5  373.0  729.0
# Trees              155.819030   66.0  303.25  421.5  540.5  733.0
#
# [3 rows x 88 columns]

# %% [markdown]
# ### SCPM Analysis

# %%
cols = [
    # "Model",
    # "Model_bkp",
    "Model_bkp_2",
    "RMSE_mean",
    "RMSE_std",
    "MAE_mean",
    "MAE_std",
    "MAPE_mean",
    "MAPE_std",
    "R2_mean",
    "R2_std",
    "SCPM",
    "Dominated_Count",
    "Dominates_Count",
    "Classification",
    "Plant",
]

# %% [markdown]
# #### SCPM Analysis by Project

# %%
df_sorted_scpm = df_sorted_topo.sort_values(by="SCPM").copy()

# %%
# (df_sorted_topo[cols].reset_index() == df_sorted_scpm[cols].reset_index()).all(axis=1)
df_sorted_scpm["topo_scmp_order_eq"] = df_sorted_topo.index == df_sorted_scpm.index

# %%
df_sorted_scpm[cols + ["topo_scmp_order_eq"]].round(2).head(5)
# Out:
#            Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 630      Random Forest       0.74      0.08      0.56     0.06       1.39
# 554  Linear Regression       0.80      0.18      0.62     0.14       1.43
# 641    Transformer_1.0       0.82      0.09      0.65     0.08       1.62
# 545      Random Forest       0.85      0.14      0.67     0.10       1.54
# 639  Linear Regression       0.84      0.12      0.65     0.07       1.63
#
#      MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count  Dominates_Count  \
# 630      0.13     0.98    0.00 -2.62                0              733
# 554      0.32     0.98    0.01 -2.57                0              733
# 641      0.19     0.98    0.00 -2.52                2              729
# 545      0.21     0.98    0.01 -2.51                2              730
# 639      0.16     0.97    0.01 -2.51                2              729
#
#          Classification Plant  topo_scmp_order_eq
# 630      dominant_model     s               False
# 554      dominant_model     k               False
# 641  intermediate_model     s               False
# 545  intermediate_model     k               False
# 639  intermediate_model     s               False
