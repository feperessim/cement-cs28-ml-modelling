# %%
# %load_ext nb_black

# %%
import pandas as pd
import numpy as np
import re

# %%
def flat_list(lst):
    return [item for tup in list(lst) for item in tup]

# %%
def extract_scores(s):
    pattern = r"\b([A-Z0-9]+):\s+([\d.]+)\s+\(([\d.]+)\)"
    scores = {"Train Mean": [], "Train Std": [], "Test Mean": [], "Test Std": []}
    current_scores = None
    for line in s.split("\n"):
        if "[TRAIN]" in line:
            current_scores = "Train"
        elif "[TEST]" in line:
            current_scores = "Test"
        match = re.search(pattern, line)
        if match:
            score_name = match.group(1)
            score_mean = float(match.group(2))
            score_std = float(match.group(3))
            scores[f"{current_scores} Mean"].append(score_mean)
            scores[f"{current_scores} Std"].append(score_std)
    return scores

# %% [markdown]
# # All Cements

# %%
results = []

# %% [markdown]
# ## No previous Compressive Strength

# %% [markdown]
# ## Repeated KFold Cross validation

# %%
data = {
    "Metric": ["RMSE", "MAE", "MAPE", "R2"],
    "Train Mean": [],
    "Train Std": [],
    "Test Mean": [],
    "Test Std": [],
    "Validation": ["Repeated KFold"] * 4,
    "Repeats": [10] * 4,
    "Splits": [10] * 4,
}
df = pd.DataFrame(data)
df = df[
    [
        "Validation",
        "Repeats",
        "Splits",
        "Metric",
        "Train Mean",
        "Train Std",
        "Test Mean",
        "Test Std",
    ]
]
results.append(df)

# %% [markdown]
# ## Blocking Time Series Split Results

# %%
df = [
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 10,
        "Splits": 5,
        "Metric": "RMSE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 10,
        "Splits": 5,
        "Metric": "MAE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 10,
        "Splits": 5,
        "Metric": "MAPE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 10,
        "Splits": 5,
        "Metric": "R2",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
]
df = pd.DataFrame(df)
results.append(df)

# %% [markdown]
# ## Time Series Split Cross Validation

# %%
# define dictionary with results
tss_results = {
    "Validation": "Time Series Split Cross Validation",
    "Repeats": 10,
    "Splits": 10,
    "RMSE Train Mean": ,
    "RMSE Train Std": ,
    "MAE Train Mean": ,
    "MAE Train Std": ,
    "MAPE Train Mean": ,
    "MAPE Train Std": ,
    "R2 Train Mean": ,
    "R2 Train Std": ,
    "RMSE Test Mean": ,
    "RMSE Test Std": ,
    "MAE Test Mean": ,
    "MAE Test Std": ,
    "MAPE Test Mean": ,
    "MAPE Test Std": ,
    "R2 Test Mean": ,
    "R2 Test Std": ,
}

# create dataframe
df = pd.DataFrame(
    columns=[
        "Validation",
        "Repeats",
        "Splits",
        "Metric",
        "Train Mean",
        "Train Std",
        "Test Mean",
        "Test Std",
    ]
)

# populate dataframe
for i, metric in enumerate(["RMSE", "MAE", "MAPE", "R2"]):
    df.loc[i * 4] = [
        tss_results["Validation"],
        tss_results["Repeats"],
        tss_results["Splits"],
        metric,
        tss_results[f"{metric} Train Mean"],
        tss_results[f"{metric} Train Std"],
        tss_results[f"{metric} Test Mean"],
        tss_results[f"{metric} Test Std"],
    ]
results.append(df)

# %% [markdown]
# ## Blocking Time Series Split Results - Period Specific

# %%
s = """
******
[TRAIN]
******
RMSE: 1.875 (0.121)
MAE: 1.496 (0.115)
MAPE: 0.035 (0.003)
R2: 0.637 (0.090)

======================

******
[TEST]
******
RMSE: 2.201 (0.290)
MAE: 1.729 (0.239)
MAPE: 0.040 (0.004)
R2: 0.335 (0.287)

======================



******
[TRAIN]
******
RMSE: 1.962 (0.159)
MAE: 1.562 (0.112)
MAPE: 0.036 (0.002)
R2: 0.659 (0.048)

======================

******
[TEST]
******
RMSE: 2.277 (0.157)
MAE: 1.821 (0.018)
MAPE: 0.041 (0.001)
R2: 0.337 (0.092)

======================

******
[TRAIN]
******
RMSE: 1.976 (0.128)
MAE: 1.578 (0.091)
MAPE: 0.036 (0.002)
R2: 0.641 (0.052)

======================

******
[TEST]
******
RMSE: 2.319 (0.206)
MAE: 1.939 (0.142)
MAPE: 0.045 (0.002)
R2: 0.302 (0.025)

======================

******
[TRAIN]
******
RMSE: 1.970 (0.079)
MAE: 1.561 (0.067)
MAPE: 0.036 (0.001)
R2: 0.631 (0.044)

======================

******
[TEST]
******
RMSE: 2.573 (0.145)
MAE: 2.040 (0.304)
MAPE: 0.047 (0.005)
R2: 0.395 (0.054)

======================

******
[TRAIN]
******
RMSE: 2.008 (0.071)
MAE: 1.612 (0.034)
MAPE: 0.037 (0.001)
R2: 0.625 (0.036)

======================

******
[TEST]
******
RMSE: 2.669 (0.733)
MAE: 2.296 (0.702)
MAPE: 0.057 (0.019)
R2: 0.068 (0.458)

======================



******
[TRAIN]
******
RMSE: 2.053 (0.000)
MAE: 1.639 (0.000)
MAPE: 0.038 (0.000)
R2: 0.622 (0.000)

======================

******
[TEST]
******
RMSE: 1.915 (0.000)
MAE: 1.521 (0.000)
MAPE: 0.036 (0.000)
R2: 0.079 (0.000)

======================

******
[TRAIN]
******
RMSE: 2.053 (0.000)
MAE: 1.639 (0.000)
MAPE: 0.038 (0.000)
R2: 0.622 (0.000)

======================

******
[TEST]
******
RMSE: 1.959 (0.000)
MAE: 1.585 (0.000)
MAPE: 0.038 (0.000)
R2: 0.244 (0.000)

======================



******
[TRAIN]
******
RMSE: 2.053 (0.000)
MAE: 1.639 (0.000)
MAPE: 0.038 (0.000)
R2: 0.622 (0.000)

======================

******
[TEST]
******
RMSE: 3.535 (0.000)
MAE: 2.915 (0.000)
MAPE: 0.074 (0.000)
R2: 0.278 (0.000)

======================

******
[TRAIN]
******
RMSE: 2.033 (0.000)
MAE: 1.625 (0.000)
MAPE: 0.037 (0.000)
R2: 0.612 (0.000)

======================

******
[TEST]
******
RMSE: 3.817 (0.000)
MAE: 3.232 (0.000)
MAPE: 0.083 (0.000)
R2: 0.878 (0.000)

======================
"""

# %%
## Define the train and test periods for each row
periods = [
    ["6 months", "One Month"],
    ["11 months", "One Month"],
    ["1 year", "One Month"],
    ["1 year and one month", "One Month"],
    ["1 year and two months", "One Month"],
    ["2 years", "One Month"],
    ["2 years", "10 months and 27 days"],
    ["2 years", "One Year"],
    ["2 years and 3 months", "24 days predicts 7 months"],
]

# Extract the relevant information and store it in a dictionary
data = {
    "Validation": ["Blocking Time Series - Period Specific"] * 36,
    "Repeats": [1] * 36,
    "Splits": [np.nan] * 36,
    "Metric": ["RMSE", "MAE", "MAPE", "R2"] * 9,
    "Train Mean": [],
    "Train Std": [],
    "Test Mean": [],
    "Test Std": [],
    "Train Period": [
        item for sublist in [[result[0]] * 4 for result in periods] for item in sublist
    ],
    "Test Period": [
        item for sublist in [[result[1]] * 4 for result in periods] for item in sublist
    ],
}


scores = extract_scores(s)


data["Train Mean"] = scores["Train Mean"]
data["Train Std"] = scores["Train Std"]
data["Test Mean"] = scores["Test Mean"]
data["Test Std"] = scores["Test Std"]


df = pd.DataFrame(data)

# %%
idx = df[df["Metric"] == "RMSE"]["Test Mean"].idxmin()
df.iloc[idx : idx + 4]
# Out:
#                                 Validation  Repeats  Splits Metric  \
# 20  Blocking Time Series - Period Specific        1     NaN   RMSE
# 21  Blocking Time Series - Period Specific        1     NaN    MAE
# 22  Blocking Time Series - Period Specific        1     NaN   MAPE
# 23  Blocking Time Series - Period Specific        1     NaN     R2
#
#     Train Mean  Train Std  Test Mean  Test Std Train Period Test Period
# 20       2.053        0.0      1.915       0.0      2 years   One Month
# 21       1.639        0.0      1.521       0.0      2 years   One Month
# 22       0.038        0.0      0.036       0.0      2 years   One Month
# 23       0.622        0.0      0.079       0.0      2 years   One Month

# %%
df = df.set_index(["Train Period", "Test Period"])

df[
    (
        df[df["Metric"] == "RMSE"]
        == df[df["Metric"] == "RMSE"][["Test Mean"]].min().values[0]
    )["Test Mean"]
]
# Out:
# /home/felipe/Documents/ccs28-venv/lib/python3.6/site-packages/ipykernel_launcher.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   import sys
#                                                       Validation  Repeats  \
# Train Period Test Period
# 6 months     One Month    Blocking Time Series - Period Specific        1
#              One Month    Blocking Time Series - Period Specific        1
#              One Month    Blocking Time Series - Period Specific        1
#              One Month    Blocking Time Series - Period Specific        1
#
#                           Splits Metric  Train Mean  Train Std  Test Mean  \
# Train Period Test Period
# 6 months     One Month       NaN   RMSE       1.029      0.125      1.065
#              One Month       NaN    MAE       0.812      0.119      0.785
#              One Month       NaN   MAPE       0.019      0.003      0.019
#              One Month       NaN     R2       0.958      0.011      0.953
#
#                           Test Std
# Train Period Test Period
# 6 months     One Month       0.124
#              One Month       0.177
#              One Month       0.004
#              One Month       0.011
