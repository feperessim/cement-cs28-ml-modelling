# %%
# %load_ext nb_black

# %%
import pandas as pd
import numpy as np

# %%
def flat_list(lst):
    return [item for tup in list(lst) for item in tup]

# %%
def extract_numbers(text):
    values = []
    for line in text.split("\n"):
        line = line.strip()
        if line.startswith("RMSE:"):
            parts = line.split(" ")
            values.append(float(parts[1]))
            values.append(float(parts[2].lstrip("(").rstrip(")")))
        elif line.startswith("MAE:"):
            parts = line.split(" ")
            values.append(float(parts[1]))
            values.append(float(parts[2].lstrip("(").rstrip(")")))
        elif line.startswith("MAPE:"):
            parts = line.split(" ")
            values.append(float(parts[1]))
            values.append(float(parts[2].lstrip("(").rstrip(")")))
        elif line.startswith("R2:"):
            parts = line.split(" ")
            values.append(float(parts[1]))
            values.append(float(parts[2].lstrip("(").rstrip(")")))
    return values

# %%
def extract_and_fill_lists(text, train_rmse_mean, train_rmse_std, test_rmse_mean, test_rmse_std,
                           train_mae_mean, train_mae_std, test_mae_mean, test_mae_std,
                           train_mape_mean, train_mape_std, test_mape_mean, test_mape_std,
                           train_r2_mean, train_r2_std, test_r2_mean, test_r2_std):

    train_flag = False
    test_flag = False
    timesteps_flag = False

    for line in text.split("\n"):
        line = line.strip()

        if line.startswith("TIMESTEPS:"):
            timesteps_flag = True

        elif line.startswith("[TRAIN]"):
            train_flag = True
            test_flag = False

        elif line.startswith("[TEST]"):
            train_flag = False
            test_flag = True

        elif line.startswith("RMSE:"):
            parts = line.split(" ")
            if train_flag:
                train_rmse_mean.append(float(parts[1]))
                train_rmse_std.append(float(parts[2].lstrip("(").rstrip(")")))
            elif test_flag:
                test_rmse_mean.append(float(parts[1]))
                test_rmse_std.append(float(parts[2].lstrip("(").rstrip(")")))

        elif line.startswith("MAE:"):
            parts = line.split(" ")
            if train_flag:
                train_mae_mean.append(float(parts[1]))
                train_mae_std.append(float(parts[2].lstrip("(").rstrip(")")))
            elif test_flag:
                test_mae_mean.append(float(parts[1]))
                test_mae_std.append(float(parts[2].lstrip("(").rstrip(")")))

        elif line.startswith("MAPE:"):
            parts = line.split(" ")
            if train_flag:
                train_mape_mean.append(float(parts[1]))
                train_mape_std.append(float(parts[2].lstrip("(").rstrip(")")))
            elif test_flag:
                test_mape_mean.append(float(parts[1]))
                test_mape_std.append(float(parts[2].lstrip("(").rstrip(")")))

        elif line.startswith("R2:"):
            parts = line.split(" ")
            if train_flag:
                train_r2_mean.append(float(parts[1]))
                train_r2_std.append(float(parts[2].lstrip("(").rstrip(")")))
            elif test_flag:
                test_r2_mean.append(float(parts[1]))
                test_r2_std.append(float(parts[2].lstrip("(").rstrip(")")))

        elif line.startswith("="):
            train_flag = False
            test_flag = False
            timesteps_flag = False

        else:
            continue

# %% [markdown]
# # All Cements

# %%
results = []

# %% [markdown]
# ## No previous Compressive Strength

# %% [markdown]
# ## Repeated KFold Cross validation

# %%
data = {
    "Time Steps": sorted([1, 3, 5, 7, 14, 21] * 4),
    "Metric": ["RMSE", "MAE", "MAPE", "R2"] * 6,
    "Train Mean": [],
    "Train Std": [],
    "Test Mean": [],
    "Test Std": [],
    "Validation": ["Repeated KFold"] * 4 * 6,
    "Repeats": [10] * 4 * 6,
    "Splits": [10] * 4 * 6,
}


# For TIMESTEPS: 1
data["Train Mean"].extend([])
data["Train Std"].extend([])
data["Test Mean"].extend([])
data["Test Std"].extend([])

# For TIMESTEPS: 3
data["Train Mean"].extend([])
data["Train Std"].extend([])
data["Test Mean"].extend([])
data["Test Std"].extend([])

# For TIMESTEPS: 5
data["Train Mean"].extend([])
data["Train Std"].extend([])
data["Test Mean"].extend([])
data["Test Std"].extend([])

# For TIMESTEPS: 7
data["Train Mean"].extend([])
data["Train Std"].extend([])
data["Test Mean"].extend([])
data["Test Std"].extend([])

# For TIMESTEPS: 14
data["Train Mean"].extend([])
data["Train Std"].extend([])
data["Test Mean"].extend([])
data["Test Std"].extend([])


# For TIMESTEPS: 21
data["Train Mean"].extend([])
data["Train Std"].extend([])
data["Test Mean"].extend([])
data["Test Std"].extend([])

df = pd.DataFrame(data)
df = df[
    [
        "Validation",
        "Repeats",
        "Splits",
        "Time Steps",
        "Metric",
        "Train Mean",
        "Train Std",
        "Test Mean",
        "Test Std",
    ]
]
df
results.append(df)

# %% [markdown]
# ## Blocking Time Series Split Results

# %%
df = [
    # Timesteps = 1
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 1,
        "Metric": "RMSE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 1,
        "Metric": "MAE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 1,
        "Metric": "MAPE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 1,
        "Metric": "R2",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    # Timesteps = 3
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 3,
        "Metric": "RMSE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 3,
        "Metric": "MAE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 3,
        "Metric": "MAPE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 3,
        "Metric": "R2",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    # Timesteps = 5
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 5,
        "Metric": "RMSE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 5,
        "Metric": "MAE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 5,
        "Metric": "MAPE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 5,
        "Metric": "R2",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    # Timesteps = 7
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 7,
        "Metric": "RMSE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 7,
        "Metric": "MAE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 7,
        "Metric": "MAPE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 7,
        "Metric": "R2",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    # Timesteps = 14
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 14,
        "Metric": "RMSE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 14,
        "Metric": "MAE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 14,
        "Metric": "MAPE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 14,
        "Metric": "R2",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    # Timesteps = 21
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 21,
        "Metric": "RMSE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 21,
        "Metric": "MAE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 21,
        "Metric": "MAPE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 21,
        "Metric": "R2",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
]

df = pd.DataFrame(df)
results.append(df)

# %% [markdown]
# ## Time Series Split Cross Validation

# %%
df = [
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 10,
        "Time Steps": 1,
        "Metric": "RMSE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 10,
        "Time Steps": 1,
        "Metric": "MAE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 10,
        "Time Steps": 1,
        "Metric": "MAPE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 10,
        "Time Steps": 1,
        "Metric": "R2",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 10,
        "Time Steps": 3,
        "Metric": "RMSE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 10,
        "Time Steps": 3,
        "Metric": "MAE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 10,
        "Time Steps": 3,
        "Metric": "MAPE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 10,
        "Time Steps": 3,
        "Metric": "R2",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 5,
        "Metric": "RMSE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 5,
        "Metric": "MAE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 5,
        "Metric": "MAPE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 5,
        "Metric": "R2",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 7,
        "Metric": "RMSE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 7,
        "Metric": "MAE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 7,
        "Metric": "MAPE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 7,
        "Metric": "R2",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 14,
        "Metric": "RMSE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 14,
        "Metric": "MAE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 14,
        "Metric": "MAPE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 14,
        "Metric": "R2",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 21,
        "Metric": "RMSE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 21,
        "Metric": "MAE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 21,
        "Metric": "MAPE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 21,
        "Metric": "R2",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
]

df = pd.DataFrame(df)
results.append(df)

# %% [markdown]
# ## Blocking Time Series Split Results - Period Specific

# %%
# Define the train and test periods for each row
periods = [
    ["6 months", "One Month"],
    ["11 months", "One Month"],
    ["1 year", "One Month"],
    ["1 year and one month", "One Month"],
    ["1 year and two months", "One Month"],
    ["2 years", "One Month"],
    ["2 years", "10 months and 27 days"],
    ["2 years", "One Year"],
    ["2 years and 3 months", "24 days predicts 7 months"],
]

train_mean = []
test_mean = []

train_std = []
test_std = []

###########################
# 6 months", "One Month"  #
###########################
train_rmse_mean = [3.384, 1.926, 1.883, 1.788, 1.825, 1.851]
train_rmse_std = [1.136, 0.171, 0.225, 0.156, 0.148, 0.09]
test_rmse_mean = [24.229, 97.334, 95.322, 53.378, 2.888, 3.098]
test_rmse_std = [55.433, 198.188, 175.739, 91.952, 0.74, 1.208]
train_mae_mean = [2.736, 1.536, 1.512, 1.417, 1.454, 1.481]
train_mae_std = [0.933, 0.146, 0.17, 0.132, 0.132, 0.079]
test_mae_mean = [11.805, 42.735, 49.537, 13.032, 2.403, 2.622]
test_mae_std = [21.517, 83.811, 89.372, 17.782, 0.675, 1.157]
train_mape_mean = [0.064, 0.036, 0.035, 0.033, 0.033, 0.034]
train_mape_std = [0.021, 0.003, 0.004, 0.003, 0.003, 0.002]
test_mape_mean = [0.273, 0.948, 1.08, 0.327, 0.056, 0.062]
test_mape_std = [0.488, 1.847, 1.938, 0.46, 0.017, 0.027]
train_r2_mean = [0.289, 0.61, 0.638, 0.671, 0.65, 0.643]
train_r2_std = [0.759, 0.1, 0.128, 0.103, 0.104, 0.078]
test_r2_mean = [253.819, 4820.747, 4194.915, 1124.007, 0.225, 0.179]
test_r2_std = [907.557, 11458.891, 9361.331, 2355.078, 0.93, 1.124]


train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

###########################
# 11 months", "One Month  #
###########################
train_rmse_mean = [2.291, 1.96, 1.946, 1.917, 2.035, 2.006]
train_rmse_std = [0.117, 0.06, 0.147, 0.114, 0.112, 0.113]
test_rmse_mean = [2504.801, 1639.086, 1775.8, 2462.893, 3.439, 2.493]
test_rmse_std = [2525.454, 1818.75, 2088.536, 2916.306, 1.562, 0.319]
train_mae_mean = [1.806, 1.562, 1.544, 1.507, 1.611, 1.588]
train_mae_std = [0.083, 0.047, 0.121, 0.095, 0.091, 0.098]
test_mae_mean = [1131.43, 582.318, 766.299, 1349.689, 2.548, 2.106]
test_mae_std = [1135.551, 641.118, 874.712, 1546.025, 0.98, 0.325]
train_mape_mean = [0.041, 0.036, 0.036, 0.034, 0.037, 0.036]
train_mape_std = [0.002, 0.001, 0.003, 0.002, 0.002, 0.002]
test_mape_mean = [25.852, 13.595, 17.636, 31.917, 0.06, 0.048]
test_mape_std = [25.951, 14.973, 20.132, 36.648, 0.024, 0.006]
train_r2_mean = [0.537, 0.658, 0.659, 0.666, 0.612, 0.617]
train_r2_std = [0.04, 0.026, 0.062, 0.047, 0.036, 0.033]
test_r2_mean = [2124102.604, 1239141.286, 1306976.089, 3344399.446, 2.268, 0.189]
test_r2_std = [2199637.529, 1774974.929, 1964770.759, 5650197.172, 3.208, 0.133]

train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

###########################
# "1 year", "One Month"   #
###########################
train_rmse_mean = [2.213, 2.201, 2.112, 2.098, 2.056, 2.049]
train_rmse_std = [0.038, 0.166, 0.158, 0.164, 0.113, 0.151]
test_rmse_mean = [2.13, 2.47, 2.46, 2.25, 2.321, 2.212]
test_rmse_std = [0.277, 0.601, 0.506, 0.269, 0.302, 0.103]
train_mae_mean = [1.761, 1.76, 1.669, 1.667, 1.633, 1.627]
train_mae_std = [0.041, 0.139, 0.123, 0.131, 0.094, 0.126]
test_mae_mean = [1.826, 1.946, 2.03, 1.924, 1.913, 1.843]
test_mae_std = [0.242, 0.279, 0.373, 0.235, 0.31, 0.141]
train_mape_mean = [0.04, 0.041, 0.039, 0.039, 0.037, 0.037]
train_mape_std = [0.001, 0.003, 0.003, 0.003, 0.002, 0.002]
test_mape_mean = [0.043, 0.046, 0.047, 0.044, 0.043, 0.043]
test_mape_std = [0.005, 0.006, 0.008, 0.005, 0.007, 0.003]
train_r2_mean = [0.552, 0.548, 0.58, 0.585, 0.59, 0.59]
train_r2_std = [0.021, 0.072, 0.071, 0.073, 0.045, 0.066]
test_r2_mean = [0.415, 0.22, 0.247, 0.179, 0.399, 0.5]
test_r2_std = [0.033, 0.296, 0.2, 0.256, 0.074, 0.037]

train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

#########################################
# "1 year and one month", "One Month"   #
#########################################
train_rmse_mean = [2.238, 2.093, 2.09, 2.052, 2.236, 2.025]
train_rmse_std = [0.045, 0.089, 0.101, 0.101, 0.197, 0.086]
test_rmse_mean = [2.607, 2.475, 2.14, 2.526, 3.539, 2.565]
test_rmse_std = [0.27, 0.299, 0.43, 0.305, 1.373, 0.806]
train_mae_mean = [1.785, 1.683, 1.667, 1.621, 1.789, 1.619]
train_mae_std = [0.033, 0.073, 0.089, 0.079, 0.165, 0.07]
test_mae_mean = [2.043, 1.899, 1.667, 2.074, 3.114, 2.135]
test_mae_std = [0.4, 0.314, 0.401, 0.225, 1.409, 0.681]
train_mape_mean = [0.041, 0.039, 0.038, 0.037, 0.042, 0.037]
train_mape_std = [0.001, 0.001, 0.002, 0.002, 0.004, 0.002]
test_mape_mean = [0.047, 0.045, 0.039, 0.05, 0.076, 0.054]
test_mape_std = [0.008, 0.006, 0.009, 0.006, 0.036, 0.019]
train_r2_mean = [0.526, 0.581, 0.583, 0.595, 0.516, 0.604]
train_r2_std = [0.026, 0.049, 0.053, 0.053, 0.09, 0.033]
test_r2_mean = [0.375, 0.399, 0.506, 0.2, 1.769, 0.159]
test_r2_std = [0.113, 0.105, 0.169, 0.291, 2.311, 0.529]

train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

##########################################
# "1 year and two months", "One Month"   #
#########################################
train_rmse_mean = [2.246, 2.109, 2.148, 2.115, 2.239, 2.087]
train_rmse_std = [0.044, 0.055, 0.17, 0.167, 0.344, 0.104]
test_rmse_mean = [2.746, 2.389, 3.619, 3.215, 3.438, 3.06]
test_rmse_std = [0.737, 0.512, 0.721, 0.658, 1.682, 0.888]
train_mae_mean = [1.796, 1.683, 1.714, 1.675, 1.794, 1.663]
train_mae_std = [0.039, 0.031, 0.143, 0.14, 0.301, 0.084]
test_mae_mean = [2.363, 1.959, 2.761, 2.578, 3.155, 2.517]
test_mae_std = [0.692, 0.371, 0.949, 0.773, 1.708, 0.981]
train_mape_mean = [0.041, 0.038, 0.04, 0.039, 0.042, 0.039]
train_mape_std = [0.001, 0.001, 0.004, 0.004, 0.008, 0.002]
test_mape_mean = [0.059, 0.049, 0.069, 0.065, 0.08, 0.065]
test_mape_std = [0.02, 0.012, 0.027, 0.022, 0.046, 0.028]
train_r2_mean = [0.533, 0.583, 0.566, 0.584, 0.521, 0.607]
train_r2_std = [0.014, 0.031, 0.078, 0.07, 0.149, 0.03]
test_r2_mean = [0.016, 0.324, 0.504, 0.331, 1.803, 0.613]
test_r2_std = [0.475, 0.248, 0.567, 0.65, 2.765, 1.282]

train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

############################
# "2 years", "One Month"   #
############################
train_rmse_mean = [2.178, 2.196, 2.16, 2.037, 2.023, 2.031]
train_rmse_std = [0.022, 0.089, 0.113, 0.019, 0.044, 0.056]
test_rmse_mean = [2.136, 2.546, 3.01, 2.257, 2.016, 2.116]
test_rmse_std = [0.198, 0.35, 0.365, 0.217, 0.238, 0.149]
train_mae_mean = [1.738, 1.76, 1.726, 1.616, 1.605, 1.625]
train_mae_std = [0.02, 0.073, 0.09, 0.019, 0.04, 0.055]
test_mae_mean = [1.767, 1.949, 2.073, 1.763, 1.666, 1.805]
test_mae_std = [0.126, 0.179, 0.162, 0.135, 0.231, 0.133]
train_mape_mean = [0.04, 0.041, 0.04, 0.037, 0.037, 0.037]
train_mape_std = [0.0, 0.002, 0.002, 0.001, 0.001, 0.002]
test_mape_mean = [0.041, 0.046, 0.049, 0.042, 0.04, 0.041]
test_mape_std = [0.003, 0.004, 0.004, 0.003, 0.006, 0.003]
train_r2_mean = [0.574, 0.561, 0.572, 0.616, 0.611, 0.605]
train_r2_std = [0.008, 0.035, 0.045, 0.007, 0.017, 0.022]
test_r2_mean = [0.156, 0.204, 0.675, 0.218, 0.287, 0.295]
test_r2_std = [0.223, 0.342, 0.409, 0.155, 0.176, 0.102]


train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

############################
# "2 years", "Two Months"  #
############################
train_rmse_mean = [2.178, 2.196, 2.16, 2.037, 2.023, 2.031]
train_rmse_std = [0.022, 0.089, 0.113, 0.019, 0.044, 0.056]
test_rmse_mean = [1.968, 2.349, 2.672, 2.148, 2.149, 2.313]
test_rmse_std = [0.121, 0.236, 0.258, 0.186, 0.177, 0.148]
train_mae_mean = [1.738, 1.76, 1.726, 1.616, 1.605, 1.625]
train_mae_std = [0.02, 0.073, 0.09, 0.019, 0.04, 0.055]
test_mae_mean = [1.638, 1.831, 1.966, 1.748, 1.809, 1.853]
test_mae_std = [0.082, 0.139, 0.15, 0.141, 0.158, 0.124]
train_mape_mean = [0.04, 0.041, 0.04, 0.037, 0.037, 0.037]
train_mape_std = [0.0, 0.002, 0.002, 0.001, 0.001, 0.002]
test_mape_mean = [0.038, 0.043, 0.046, 0.041, 0.042, 0.043]
test_mape_std = [0.002, 0.003, 0.004, 0.003, 0.004, 0.003]
train_r2_mean = [0.574, 0.561, 0.572, 0.616, 0.611, 0.605]
train_r2_std = [0.008, 0.035, 0.045, 0.007, 0.017, 0.022]
test_r2_mean = [0.234, 0.025, 0.3, 0.164, 0.361, 0.382]
test_r2_std = [0.097, 0.198, 0.254, 0.15, 0.107, 0.079]


train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

##########################
# "2 years", "One Year"  #
##########################
train_rmse_mean = [2.178, 2.086, 2.237, 2.286, 2.228, 2.183]
train_rmse_std = [0.022, 0.027, 0.117, 0.075, 0.102, 0.107]
test_rmse_mean = [3.039, 3.394, 2.837, 2.78, 3.234, 3.411]
test_rmse_std = [0.079, 0.169, 0.106, 0.111, 0.266, 0.573]
train_mae_mean = [1.738, 1.67, 1.777, 1.812, 1.775, 1.74]
train_mae_std = [0.02, 0.021, 0.1, 0.06, 0.087, 0.084]
test_mae_mean = [2.428, 2.75, 2.273, 2.224, 2.595, 2.745]
test_mae_std = [0.063, 0.15, 0.097, 0.081, 0.196, 0.438]
train_mape_mean = [0.04, 0.038, 0.04, 0.041, 0.04, 0.039]
train_mape_std = [0.0, 0.001, 0.002, 0.001, 0.002, 0.002]
test_mape_mean = [0.061, 0.069, 0.056, 0.055, 0.065, 0.069]
test_mape_std = [0.002, 0.004, 0.003, 0.002, 0.005, 0.011]
train_r2_mean = [0.574, 0.609, 0.549, 0.53, 0.553, 0.571]
train_r2_std = [0.008, 0.01, 0.047, 0.03, 0.04, 0.041]
test_r2_mean = [0.055, 0.181, 0.175, 0.208, 0.078, 0.224]
test_r2_std = [0.049, 0.117, 0.061, 0.063, 0.175, 0.423]


train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

###########################################################
# "2 years, 8 months and 15 days", "8 months and 6 days"  #
###########################################################
train_rmse_mean = [2.096, 2.268, 2.255, 2.162, 2.106, 2.049]
train_rmse_std = [0.025, 0.108, 0.069, 0.074, 0.054, 0.022]
test_rmse_mean = [3.439, 2.877, 2.86, 3.321, 3.493, 3.361]
test_rmse_std = [0.078, 0.123, 0.162, 0.272, 0.295, 0.152]
train_mae_mean = [1.667, 1.82, 1.803, 1.723, 1.674, 1.637]
train_mae_std = [0.023, 0.086, 0.052, 0.062, 0.04, 0.013]
test_mae_mean = [2.909, 2.347, 2.317, 2.758, 2.91, 2.799]
test_mae_std = [0.082, 0.121, 0.157, 0.266, 0.315, 0.146]
train_mape_mean = [0.038, 0.041, 0.041, 0.04, 0.038, 0.037]
train_mape_std = [0.0, 0.002, 0.001, 0.002, 0.001, 0.0]
test_mape_mean = [0.075, 0.061, 0.06, 0.071, 0.076, 0.073]
test_mape_std = [0.002, 0.003, 0.004, 0.007, 0.008, 0.004]
train_r2_mean = [0.587, 0.515, 0.522, 0.56, 0.583, 0.605]
train_r2_std = [0.01, 0.046, 0.029, 0.03, 0.021, 0.008]
test_r2_mean = [0.525, 0.069, 0.058, 0.432, 0.584, 0.459]
test_r2_std = [0.069, 0.093, 0.119, 0.246, 0.282, 0.131]

train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))


# Extract the relevant information and store it in a dictionary
data = {
    "Validation": ["Blocking Time Series - Period Specific"] * 216,
    "Repeats": [5] * 216,
    "Splits": [np.nan] * 216,
    "Metric": ["RMSE", "MAE", "MAPE", "R2"] * len(periods) * 6,
    "Time Steps": sorted([1, 3, 5, 7, 14, 21] * 4 * 9),
    "Train Mean": train_mean,
    "Train Std": train_std,
    "Test Mean": test_mean,
    "Test Std": test_std,
    "Train Period": [
        item
        for sublist in [[result[0]] * 4 * 6 for result in periods]
        for item in sublist
    ],
    "Test Period": [
        item
        for sublist in [[result[1]] * 4 * 6 for result in periods]
        for item in sublist
    ],
}

df = pd.DataFrame(data)

# %%
idx = df[df["Metric"] == "RMSE"]["Test Mean"].idxmin()
df.iloc[idx : idx + 4]
# Out:
#                                  Validation  Repeats  Splits Metric  \
# 144  Blocking Time Series - Period Specific        5     NaN   RMSE
# 145  Blocking Time Series - Period Specific        5     NaN    MAE
# 146  Blocking Time Series - Period Specific        5     NaN   MAPE
# 147  Blocking Time Series - Period Specific        5     NaN     R2
#
#      Time Steps  Train Mean  Train Std  Test Mean  Test Std Train Period  \
# 144          14       2.178      0.022      1.968     0.121      2 years
# 145          14       1.738      0.020      1.638     0.082      2 years
# 146          14       0.040      0.000      0.038     0.002      2 years
# 147          14       0.574      0.008      0.234     0.097      2 years
#
#                Test Period
# 144  10 months and 27 days
# 145  10 months and 27 days
# 146  10 months and 27 days
# 147  10 months and 27 days

# %%
s = """

"""

# %%
train_rmse_mean, train_rmse_std, test_rmse_mean, test_rmse_std = [], [], [], []
train_mae_mean, train_mae_std, test_mae_mean, test_mae_std = [], [], [], []
train_mape_mean, train_mape_std, test_mape_mean, test_mape_std = [], [], [], []
train_r2_mean, train_r2_std, test_r2_mean, test_r2_std = [], [], [], []

extract_and_fill_lists(
    s,
    train_rmse_mean,
    train_rmse_std,
    test_rmse_mean,
    test_rmse_std,
    train_mae_mean,
    train_mae_std,
    test_mae_mean,
    test_mae_std,
    train_mape_mean,
    train_mape_std,
    test_mape_mean,
    test_mape_std,
    train_r2_mean,
    train_r2_std,
    test_r2_mean,
    test_r2_std,
)

for x, y in zip(
    [
        "train_rmse_mean",
        "train_rmse_std",
        "test_rmse_mean",
        "test_rmse_std",
        "train_mae_mean",
        "train_mae_std",
        "test_mae_mean",
        "test_mae_std",
        "train_mape_mean",
        "train_mape_std",
        "test_mape_mean",
        "test_mape_std",
        "train_r2_mean",
        "train_r2_std",
        "test_r2_mean",
        "test_r2_std",
    ],
    [
        train_rmse_mean,
        train_rmse_std,
        test_rmse_mean,
        test_rmse_std,
        train_mae_mean,
        train_mae_std,
        test_mae_mean,
        test_mae_std,
        train_mape_mean,
        train_mape_std,
        test_mape_mean,
        test_mape_std,
        train_r2_mean,
        train_r2_std,
        test_r2_mean,
        test_r2_std,
    ],
):
    print(f"{x} = {y}")
# Out:
# train_rmse_mean = [2.096, 2.268, 2.255, 2.162, 2.106, 2.049]
# train_rmse_std = [0.025, 0.108, 0.069, 0.074, 0.054, 0.022]
# test_rmse_mean = [3.439, 2.877, 2.86, 3.321, 3.493, 3.361]
# test_rmse_std = [0.078, 0.123, 0.162, 0.272, 0.295, 0.152]
# train_mae_mean = [1.667, 1.82, 1.803, 1.723, 1.674, 1.637]
# train_mae_std = [0.023, 0.086, 0.052, 0.062, 0.04, 0.013]
# test_mae_mean = [2.909, 2.347, 2.317, 2.758, 2.91, 2.799]
# test_mae_std = [0.082, 0.121, 0.157, 0.266, 0.315, 0.146]
# train_mape_mean = [0.038, 0.041, 0.041, 0.04, 0.038, 0.037]
# train_mape_std = [0.0, 0.002, 0.001, 0.002, 0.001, 0.0]
# test_mape_mean = [0.075, 0.061, 0.06, 0.071, 0.076, 0.073]
# test_mape_std = [0.002, 0.003, 0.004, 0.007, 0.008, 0.004]
# train_r2_mean = [0.587, 0.515, 0.522, 0.56, 0.583, 0.605]
# train_r2_std = [0.01, 0.046, 0.029, 0.03, 0.021, 0.008]
# test_r2_mean = [0.525, 0.069, 0.058, 0.432, 0.584, 0.459]
# test_r2_std = [0.069, 0.093, 0.119, 0.246, 0.282, 0.131]
