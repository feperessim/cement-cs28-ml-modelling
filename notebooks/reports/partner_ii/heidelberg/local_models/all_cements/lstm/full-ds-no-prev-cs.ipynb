# %%
# %load_ext nb_black

# %%
import pandas as pd
import numpy as np

# %%
def flat_list(lst):
    return [item for tup in list(lst) for item in tup]

# %%
def extract_numbers(text):
    values = []
    for line in text.split("\n"):
        line = line.strip()
        if line.startswith("RMSE:"):
            parts = line.split(" ")
            values.append(float(parts[1]))
            values.append(float(parts[2].lstrip("(").rstrip(")")))
        elif line.startswith("MAE:"):
            parts = line.split(" ")
            values.append(float(parts[1]))
            values.append(float(parts[2].lstrip("(").rstrip(")")))
        elif line.startswith("MAPE:"):
            parts = line.split(" ")
            values.append(float(parts[1]))
            values.append(float(parts[2].lstrip("(").rstrip(")")))
        elif line.startswith("R2:"):
            parts = line.split(" ")
            values.append(float(parts[1]))
            values.append(float(parts[2].lstrip("(").rstrip(")")))
    return values

# %%
def extract_and_fill_lists(text, train_rmse_mean, train_rmse_std, test_rmse_mean, test_rmse_std,
                           train_mae_mean, train_mae_std, test_mae_mean, test_mae_std,
                           train_mape_mean, train_mape_std, test_mape_mean, test_mape_std,
                           train_r2_mean, train_r2_std, test_r2_mean, test_r2_std):

    train_flag = False
    test_flag = False
    timesteps_flag = False

    for line in text.split("\n"):
        line = line.strip()

        if line.startswith("TIMESTEPS:"):
            timesteps_flag = True

        elif line.startswith("[TRAIN]"):
            train_flag = True
            test_flag = False

        elif line.startswith("[TEST]"):
            train_flag = False
            test_flag = True

        elif line.startswith("RMSE:"):
            parts = line.split(" ")
            if train_flag:
                train_rmse_mean.append(float(parts[1]))
                train_rmse_std.append(float(parts[2].lstrip("(").rstrip(")")))
            elif test_flag:
                test_rmse_mean.append(float(parts[1]))
                test_rmse_std.append(float(parts[2].lstrip("(").rstrip(")")))

        elif line.startswith("MAE:"):
            parts = line.split(" ")
            if train_flag:
                train_mae_mean.append(float(parts[1]))
                train_mae_std.append(float(parts[2].lstrip("(").rstrip(")")))
            elif test_flag:
                test_mae_mean.append(float(parts[1]))
                test_mae_std.append(float(parts[2].lstrip("(").rstrip(")")))

        elif line.startswith("MAPE:"):
            parts = line.split(" ")
            if train_flag:
                train_mape_mean.append(float(parts[1]))
                train_mape_std.append(float(parts[2].lstrip("(").rstrip(")")))
            elif test_flag:
                test_mape_mean.append(float(parts[1]))
                test_mape_std.append(float(parts[2].lstrip("(").rstrip(")")))

        elif line.startswith("R2:"):
            parts = line.split(" ")
            if train_flag:
                train_r2_mean.append(float(parts[1]))
                train_r2_std.append(float(parts[2].lstrip("(").rstrip(")")))
            elif test_flag:
                test_r2_mean.append(float(parts[1]))
                test_r2_std.append(float(parts[2].lstrip("(").rstrip(")")))

        elif line.startswith("="):
            train_flag = False
            test_flag = False
            timesteps_flag = False

        else:
            continue

# %% [markdown]
# # All Cements

# %%
results = []

# %% [markdown]
# ## No previous Compressive Strength

# %% [markdown]
# ## Repeated KFold Cross validation

# %%
data = {
    "Time Steps": sorted([1, 3, 5, 7, 14, 21] * 4),
    "Metric": ["RMSE", "MAE", "MAPE", "R2"] * 6,
    "Train Mean": [],
    "Train Std": [],
    "Test Mean": [],
    "Test Std": [],
    "Validation": ["Repeated KFold"] * 4 * 6,
    "Repeats": [10] * 4 * 6,
    "Splits": [10] * 4 * 6,
}


# For TIMESTEPS: 1
data["Train Mean"].extend([])
data["Train Std"].extend([])
data["Test Mean"].extend([])
data["Test Std"].extend([])

# For TIMESTEPS: 3
data["Train Mean"].extend([])
data["Train Std"].extend([])
data["Test Mean"].extend([])
data["Test Std"].extend([])

# For TIMESTEPS: 5
data["Train Mean"].extend([])
data["Train Std"].extend([])
data["Test Mean"].extend([])
data["Test Std"].extend([])

# For TIMESTEPS: 7
data["Train Mean"].extend([])
data["Train Std"].extend([])
data["Test Mean"].extend([])
data["Test Std"].extend([])

# For TIMESTEPS: 14
data["Train Mean"].extend([])
data["Train Std"].extend([])
data["Test Mean"].extend([])
data["Test Std"].extend([])


# For TIMESTEPS: 21
data["Train Mean"].extend([])
data["Train Std"].extend([])
data["Test Mean"].extend([])
data["Test Std"].extend([])

df = pd.DataFrame(data)
df = df[
    [
        "Validation",
        "Repeats",
        "Splits",
        "Time Steps",
        "Metric",
        "Train Mean",
        "Train Std",
        "Test Mean",
        "Test Std",
    ]
]
df
results.append(df)

# %% [markdown]
# ## Blocking Time Series Split Results

# %%
df = [
    # Timesteps = 1
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 1,
        "Metric": "RMSE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 1,
        "Metric": "MAE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 1,
        "Metric": "MAPE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 1,
        "Metric": "R2",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    # Timesteps = 3
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 3,
        "Metric": "RMSE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 3,
        "Metric": "MAE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 3,
        "Metric": "MAPE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 3,
        "Metric": "R2",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    # Timesteps = 5
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 5,
        "Metric": "RMSE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 5,
        "Metric": "MAE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 5,
        "Metric": "MAPE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 5,
        "Metric": "R2",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    # Timesteps = 7
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 7,
        "Metric": "RMSE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 7,
        "Metric": "MAE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 7,
        "Metric": "MAPE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 7,
        "Metric": "R2",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    # Timesteps = 14
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 14,
        "Metric": "RMSE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 14,
        "Metric": "MAE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 14,
        "Metric": "MAPE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 14,
        "Metric": "R2",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    # Timesteps = 21
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 21,
        "Metric": "RMSE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 21,
        "Metric": "MAE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 21,
        "Metric": "MAPE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 21,
        "Metric": "R2",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
]

df = pd.DataFrame(df)
results.append(df)

# %% [markdown]
# ## Time Series Split Cross Validation

# %%
df = [
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 10,
        "Time Steps": 1,
        "Metric": "RMSE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 10,
        "Time Steps": 1,
        "Metric": "MAE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 10,
        "Time Steps": 1,
        "Metric": "MAPE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 10,
        "Time Steps": 1,
        "Metric": "R2",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 10,
        "Time Steps": 3,
        "Metric": "RMSE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 10,
        "Time Steps": 3,
        "Metric": "MAE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 10,
        "Time Steps": 3,
        "Metric": "MAPE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 10,
        "Time Steps": 3,
        "Metric": "R2",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 5,
        "Metric": "RMSE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 5,
        "Metric": "MAE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 5,
        "Metric": "MAPE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 5,
        "Metric": "R2",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 7,
        "Metric": "RMSE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 7,
        "Metric": "MAE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 7,
        "Metric": "MAPE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 7,
        "Metric": "R2",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 14,
        "Metric": "RMSE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 14,
        "Metric": "MAE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 14,
        "Metric": "MAPE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 14,
        "Metric": "R2",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 21,
        "Metric": "RMSE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 21,
        "Metric": "MAE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 21,
        "Metric": "MAPE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 21,
        "Metric": "R2",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
]

df = pd.DataFrame(df)
results.append(df)

# %% [markdown]
# ## Blocking Time Series Split Results - Period Specific

# %%
# Define the train and test periods for each row
periods = [
    ["6 months", "One Month"],
    ["11 months", "One Month"],
    ["1 year", "One Month"],
    ["1 year and one month", "One Month"],
    ["1 year and two months", "One Month"],
    ["2 years", "One Month"],
    ["2 years", "10 months and 27 days"],
    ["2 years", "One Year"],
    ["2 years and 3 months", "24 days predicts 7 months"],
]
train_mean = []
test_mean = []

train_std = []
test_std = []

###########################
# 6 months", "One Month"  #
###########################
train_rmse_mean = [4.66, 1.991, 1.972, 1.905, 1.939, 2.037]
train_rmse_std = [2.065, 0.174, 0.2, 0.196, 0.161, 0.354]
test_rmse_mean = [48.217, 122.546, 129.808, 70.136, 6.337, 4.755]
test_rmse_std = [85.903, 253.032, 260.547, 120.619, 5.805, 2.488]
train_mae_mean = [3.76, 1.583, 1.577, 1.515, 1.536, 1.627]
train_mae_std = [1.679, 0.149, 0.164, 0.152, 0.132, 0.289]
test_mae_mean = [22.048, 51.679, 62.009, 17.112, 5.284, 3.859]
test_mae_std = [34.065, 102.977, 123.225, 23.937, 4.965, 2.045]
train_mape_mean = [0.087, 0.037, 0.036, 0.035, 0.035, 0.037]
train_mape_std = [0.039, 0.003, 0.004, 0.003, 0.003, 0.007]
test_mape_mean = [0.508, 1.151, 1.359, 0.428, 0.122, 0.091]
test_mape_std = [0.772, 2.278, 2.696, 0.617, 0.112, 0.045]
train_r2_mean = [1.622, 0.584, 0.606, 0.628, 0.61, 0.562]
train_r2_std = [1.919, 0.101, 0.127, 0.109, 0.098, 0.178]
test_r2_mean = [671.99, 7816.619, 8894.365, 1936.575, 5.089, 1.936]
test_r2_std = [1478.909, 18659.313, 22539.446, 4065.607, 9.269, 3.238]

train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

###########################
# 11 months", "One Month  #
###########################
train_rmse_mean = [2.938, 2.017, 1.984, 2.001, 2.062, 2.148]
train_rmse_std = [0.345, 0.052, 0.149, 0.141, 0.105, 0.21]
test_rmse_mean = [3620.68, 2770.158, 3240.824, 2969.711, 9.29, 3.141]
test_rmse_std = [3640.995, 3053.307, 3821.728, 3365.656, 7.371, 0.926]
train_mae_mean = [2.28, 1.61, 1.579, 1.572, 1.633, 1.704]
train_mae_std = [0.262, 0.04, 0.108, 0.099, 0.086, 0.165]
test_mae_mean = [1598.578, 957.985, 1237.221, 1393.617, 6.312, 2.458]
test_mae_std = [1605.754, 1056.496, 1472.516, 1529.82, 4.674, 0.601]
train_mape_mean = [0.052, 0.037, 0.036, 0.036, 0.038, 0.039]
train_mape_std = [0.006, 0.001, 0.003, 0.002, 0.002, 0.003]
test_mape_mean = [36.571, 22.367, 28.353, 33.118, 0.147, 0.056]
test_mape_std = [36.736, 24.675, 33.749, 36.381, 0.11, 0.015]
train_r2_mean = [0.232, 0.638, 0.646, 0.636, 0.602, 0.558]
train_r2_std = [0.165, 0.025, 0.063, 0.06, 0.036, 0.083]
test_r2_mean = [4426549.7, 3513417.804, 4366510.905, 4624289.13, 33.831, 0.516]
test_r2_std = [4529305.655, 4745579.715, 6761165.683, 6825717.629, 37.588, 1.153]


train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

###########################
# "1 year", "One Month"   #
###########################
train_rmse_mean = [2.437, 2.202, 2.198, 2.19, 2.227, 2.329]
train_rmse_std = [0.147, 0.145, 0.177, 0.192, 0.324, 0.292]
test_rmse_mean = [2.464, 2.284, 2.479, 2.33, 2.547, 3.329]
test_rmse_std = [0.539, 0.462, 0.451, 0.232, 0.31, 1.349]
train_mae_mean = [1.915, 1.755, 1.727, 1.732, 1.784, 1.879]
train_mae_std = [0.081, 0.124, 0.14, 0.152, 0.288, 0.261]
test_mae_mean = [2.074, 1.829, 2.051, 1.956, 2.124, 2.702]
test_mae_std = [0.386, 0.338, 0.334, 0.198, 0.288, 0.95]
train_mape_mean = [0.044, 0.041, 0.04, 0.04, 0.041, 0.042]
train_mape_std = [0.002, 0.003, 0.003, 0.004, 0.007, 0.005]
test_mape_mean = [0.049, 0.043, 0.047, 0.045, 0.048, 0.061]
test_mape_std = [0.009, 0.007, 0.007, 0.004, 0.006, 0.021]
train_r2_mean = [0.457, 0.548, 0.545, 0.548, 0.51, 0.465]
train_r2_std = [0.056, 0.065, 0.08, 0.085, 0.15, 0.134]
test_r2_mean = [0.223, 0.355, 0.228, 0.125, 0.252, 0.25]
test_r2_std = [0.178, 0.111, 0.192, 0.216, 0.215, 0.955]

train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

#########################################
# "1 year and one month", "One Month"   #
#########################################
train_rmse_mean = [2.448, 2.117, 2.119, 2.12, 2.385, 2.198]
train_rmse_std = [0.2, 0.056, 0.07, 0.101, 0.248, 0.301]
test_rmse_mean = [2.684, 2.636, 2.31, 2.374, 3.392, 3.137]
test_rmse_std = [0.507, 0.78, 0.299, 0.342, 1.16, 1.087]
train_mae_mean = [1.945, 1.694, 1.682, 1.68, 1.91, 1.751]
train_mae_std = [0.131, 0.047, 0.062, 0.088, 0.213, 0.256]
test_mae_mean = [2.135, 1.992, 1.744, 1.937, 2.911, 2.69]
test_mae_std = [0.523, 0.476, 0.239, 0.343, 1.109, 0.98]
train_mape_mean = [0.044, 0.039, 0.038, 0.038, 0.045, 0.041]
train_mape_std = [0.003, 0.001, 0.001, 0.002, 0.005, 0.006]
test_mape_mean = [0.049, 0.047, 0.041, 0.046, 0.071, 0.067]
test_mape_std = [0.011, 0.01, 0.005, 0.008, 0.028, 0.026]
train_r2_mean = [0.433, 0.573, 0.572, 0.568, 0.447, 0.525]
train_r2_std = [0.07, 0.037, 0.043, 0.054, 0.115, 0.139]
test_r2_mean = [0.324, 0.284, 0.427, 0.31, 1.431, 0.28]
test_r2_std = [0.229, 0.445, 0.163, 0.238, 1.874, 0.884]


train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

##########################################
# "1 year and two months", "One Month"   #
#########################################
train_rmse_mean = [2.477, 2.205, 2.206, 2.177, 2.19, 2.176]
train_rmse_std = [0.211, 0.076, 0.195, 0.126, 0.219, 0.186]
test_rmse_mean = [2.761, 2.281, 3.229, 2.959, 2.937, 2.761]
test_rmse_std = [0.691, 0.424, 1.115, 0.787, 1.393, 0.603]
train_mae_mean = [1.966, 1.754, 1.757, 1.73, 1.75, 1.736]
train_mae_std = [0.147, 0.049, 0.168, 0.092, 0.189, 0.159]
test_mae_mean = [2.376, 1.844, 2.685, 2.393, 2.639, 2.227]
test_mae_std = [0.645, 0.26, 1.079, 0.706, 1.387, 0.694]
train_mape_mean = [0.045, 0.04, 0.041, 0.04, 0.041, 0.04]
train_mape_std = [0.003, 0.001, 0.004, 0.002, 0.005, 0.004]
test_mape_mean = [0.059, 0.046, 0.068, 0.06, 0.067, 0.057]
test_mape_std = [0.018, 0.009, 0.03, 0.02, 0.038, 0.021]
train_r2_mean = [0.43, 0.545, 0.542, 0.56, 0.546, 0.572]
train_r2_std = [0.083, 0.041, 0.093, 0.05, 0.087, 0.061]
test_r2_mean = [0.013, 0.389, 0.291, 0.163, 1.007, 0.198]
test_r2_std = [0.446, 0.192, 0.807, 0.609, 1.985, 0.904]


train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

############################
# "2 years", "One Month"   #
############################
train_rmse_mean = [2.308, 2.141, 2.245, 2.134, 2.116, 2.05]
train_rmse_std = [0.027, 0.039, 0.173, 0.07, 0.076, 0.05]
test_rmse_mean = [2.294, 2.869, 2.849, 2.147, 2.73, 2.778]
test_rmse_std = [0.085, 0.376, 0.665, 0.101, 0.582, 1.092]
train_mae_mean = [1.829, 1.71, 1.789, 1.691, 1.677, 1.642]
train_mae_std = [0.025, 0.028, 0.136, 0.057, 0.057, 0.041]
test_mae_mean = [1.979, 2.095, 2.041, 1.751, 2.156, 2.047]
test_mae_std = [0.08, 0.134, 0.33, 0.078, 0.391, 0.45]
train_mape_mean = [0.042, 0.04, 0.042, 0.039, 0.039, 0.038]
train_mape_std = [0.001, 0.001, 0.003, 0.002, 0.002, 0.001]
test_mape_mean = [0.046, 0.049, 0.049, 0.042, 0.052, 0.046]
test_mape_std = [0.002, 0.003, 0.008, 0.002, 0.009, 0.009]
train_r2_mean = [0.521, 0.583, 0.536, 0.578, 0.574, 0.597]
train_r2_std = [0.011, 0.015, 0.072, 0.027, 0.031, 0.02]
test_r2_mean = [0.323, 0.526, 0.559, 0.297, 0.348, 0.396]
test_r2_std = [0.098, 0.386, 0.778, 0.067, 0.564, 1.205]


train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

############################
# "2 years", "Two Months"  #
############################
train_rmse_mean = [2.308, 2.141, 2.245, 2.134, 2.116, 2.05]
train_rmse_std = [0.027, 0.039, 0.173, 0.07, 0.076, 0.05]
test_rmse_mean = [2.152, 2.407, 2.615, 2.167, 3.146, 3.326]
test_rmse_std = [0.053, 0.198, 0.427, 0.107, 0.92, 1.13]
train_mae_mean = [1.829, 1.71, 1.789, 1.691, 1.677, 1.642]
train_mae_std = [0.025, 0.028, 0.136, 0.057, 0.057, 0.041]
test_mae_mean = [1.831, 1.786, 1.968, 1.772, 2.334, 2.517]
test_mae_std = [0.049, 0.06, 0.226, 0.084, 0.365, 0.629]
train_mape_mean = [0.042, 0.04, 0.042, 0.039, 0.039, 0.038]
train_mape_std = [0.001, 0.001, 0.003, 0.002, 0.002, 0.001]
test_mape_mean = [0.043, 0.042, 0.046, 0.042, 0.054, 0.057]
test_mape_std = [0.001, 0.001, 0.005, 0.002, 0.009, 0.013]
train_r2_mean = [0.521, 0.583, 0.536, 0.578, 0.574, 0.597]
train_r2_std = [0.011, 0.015, 0.072, 0.027, 0.031, 0.02]
test_r2_mean = [0.087, 0.021, 0.266, 0.154, 0.476, 0.42]
test_r2_std = [0.045, 0.164, 0.436, 0.084, 0.944, 1.065]


train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

##########################
# "2 years", "One Year"  #
##########################
train_rmse_mean = [2.308, 2.084, 2.194, 2.412, 2.23, 2.254]
train_rmse_std = [0.027, 0.02, 0.112, 0.127, 0.164, 0.211]
test_rmse_mean = [2.938, 3.362, 3.099, 2.736, 3.693, 5.53]
test_rmse_std = [0.13, 0.092, 0.328, 0.18, 0.502, 0.82]
train_mae_mean = [1.829, 1.67, 1.744, 1.937, 1.781, 1.805]
train_mae_std = [0.025, 0.016, 0.088, 0.116, 0.149, 0.19]
test_mae_mean = [2.384, 2.69, 2.416, 2.207, 2.964, 3.946]
test_mae_std = [0.071, 0.065, 0.207, 0.149, 0.386, 0.545]
train_mape_mean = [0.042, 0.038, 0.039, 0.043, 0.04, 0.041]
train_mape_std = [0.001, 0.0, 0.002, 0.002, 0.003, 0.004]
test_mape_mean = [0.06, 0.067, 0.059, 0.054, 0.074, 0.098]
test_mape_std = [0.002, 0.002, 0.005, 0.004, 0.01, 0.014]
train_r2_mean = [0.521, 0.61, 0.566, 0.476, 0.551, 0.54]
train_r2_std = [0.011, 0.008, 0.045, 0.054, 0.066, 0.088]
test_r2_mean = [0.115, 0.157, 0.006, 0.231, 0.421, 2.198]
test_r2_std = [0.079, 0.064, 0.215, 0.104, 0.392, 1.015]

train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

###########################################################
# "2 years, 8 months and 15 days", "8 months and 6 days"  #
###########################################################
train_rmse_mean = [2.162, 2.265, 2.34, 2.141, 2.116, 2.056]
train_rmse_std = [0.026, 0.034, 0.027, 0.061, 0.183, 0.03]
test_rmse_mean = [3.387, 3.034, 2.523, 3.37, 3.462, 3.651]
test_rmse_std = [0.094, 0.071, 0.045, 0.293, 0.448, 0.216]
train_mae_mean = [1.727, 1.819, 1.875, 1.707, 1.697, 1.641]
train_mae_std = [0.028, 0.027, 0.024, 0.051, 0.157, 0.022]
test_mae_mean = [2.851, 2.496, 2.009, 2.802, 2.932, 3.061]
test_mae_std = [0.099, 0.064, 0.047, 0.312, 0.416, 0.157]
train_mape_mean = [0.04, 0.041, 0.042, 0.039, 0.039, 0.037]
train_mape_std = [0.001, 0.001, 0.001, 0.001, 0.003, 0.0]
test_mape_mean = [0.074, 0.064, 0.052, 0.072, 0.076, 0.079]
test_mape_std = [0.003, 0.002, 0.001, 0.008, 0.011, 0.004]
train_r2_mean = [0.561, 0.518, 0.485, 0.569, 0.576, 0.603]
train_r2_std = [0.01, 0.014, 0.012, 0.025, 0.078, 0.012]
test_r2_mean = [0.48, 0.187, 0.179, 0.475, 0.571, 0.724]
test_r2_std = [0.083, 0.055, 0.029, 0.256, 0.365, 0.204]

train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))


# Extract the relevant information and store it in a dictionary
data = {
    "Validation": ["Blocking Time Series - Period Specific"] * 216,
    "Repeats": [5] * 216,
    "Splits": [np.nan] * 216,
    "Metric": ["RMSE", "MAE", "MAPE", "R2"] * len(periods) * 6,
    "Time Steps": sorted([1, 3, 5, 7, 14, 21] * 4 * 9),
    "Train Mean": train_mean,
    "Train Std": train_std,
    "Test Mean": test_mean,
    "Test Std": test_std,
    "Train Period": [
        item
        for sublist in [[result[0]] * 4 * 6 for result in periods]
        for item in sublist
    ],
    "Test Period": [
        item
        for sublist in [[result[1]] * 4 * 6 for result in periods]
        for item in sublist
    ],
}

df = pd.DataFrame(data)

# %%
idx = df[df["Metric"] == "RMSE"]["Test Mean"].idxmin()
df.iloc[idx : idx + 4]
# Out:
#                                  Validation  Repeats  Splits Metric  \
# 132  Blocking Time Series - Period Specific        5     NaN   RMSE
# 133  Blocking Time Series - Period Specific        5     NaN    MAE
# 134  Blocking Time Series - Period Specific        5     NaN   MAPE
# 135  Blocking Time Series - Period Specific        5     NaN     R2
#
#      Time Steps  Train Mean  Train Std  Test Mean  Test Std Train Period  \
# 132           7       2.134      0.070      2.147     0.101      2 years
# 133           7       1.691      0.057      1.751     0.078      2 years
# 134           7       0.039      0.002      0.042     0.002      2 years
# 135           7       0.578      0.027      0.297     0.067      2 years
#
#     Test Period
# 132   One Month
# 133   One Month
# 134   One Month
# 135   One Month

# %%
s = """

"""

# %%
train_rmse_mean, train_rmse_std, test_rmse_mean, test_rmse_std = [], [], [], []
train_mae_mean, train_mae_std, test_mae_mean, test_mae_std = [], [], [], []
train_mape_mean, train_mape_std, test_mape_mean, test_mape_std = [], [], [], []
train_r2_mean, train_r2_std, test_r2_mean, test_r2_std = [], [], [], []

extract_and_fill_lists(
    s,
    train_rmse_mean,
    train_rmse_std,
    test_rmse_mean,
    test_rmse_std,
    train_mae_mean,
    train_mae_std,
    test_mae_mean,
    test_mae_std,
    train_mape_mean,
    train_mape_std,
    test_mape_mean,
    test_mape_std,
    train_r2_mean,
    train_r2_std,
    test_r2_mean,
    test_r2_std,
)

for x, y in zip(
    [
        "train_rmse_mean",
        "train_rmse_std",
        "test_rmse_mean",
        "test_rmse_std",
        "train_mae_mean",
        "train_mae_std",
        "test_mae_mean",
        "test_mae_std",
        "train_mape_mean",
        "train_mape_std",
        "test_mape_mean",
        "test_mape_std",
        "train_r2_mean",
        "train_r2_std",
        "test_r2_mean",
        "test_r2_std",
    ],
    [
        train_rmse_mean,
        train_rmse_std,
        test_rmse_mean,
        test_rmse_std,
        train_mae_mean,
        train_mae_std,
        test_mae_mean,
        test_mae_std,
        train_mape_mean,
        train_mape_std,
        test_mape_mean,
        test_mape_std,
        train_r2_mean,
        train_r2_std,
        test_r2_mean,
        test_r2_std,
    ],
):
    print(f"{x} = {y}")
# Out:
# train_rmse_mean = [2.162, 2.265, 2.34, 2.141, 2.116, 2.056]
# train_rmse_std = [0.026, 0.034, 0.027, 0.061, 0.183, 0.03]
# test_rmse_mean = [3.387, 3.034, 2.523, 3.37, 3.462, 3.651]
# test_rmse_std = [0.094, 0.071, 0.045, 0.293, 0.448, 0.216]
# train_mae_mean = [1.727, 1.819, 1.875, 1.707, 1.697, 1.641]
# train_mae_std = [0.028, 0.027, 0.024, 0.051, 0.157, 0.022]
# test_mae_mean = [2.851, 2.496, 2.009, 2.802, 2.932, 3.061]
# test_mae_std = [0.099, 0.064, 0.047, 0.312, 0.416, 0.157]
# train_mape_mean = [0.04, 0.041, 0.042, 0.039, 0.039, 0.037]
# train_mape_std = [0.001, 0.001, 0.001, 0.001, 0.003, 0.0]
# test_mape_mean = [0.074, 0.064, 0.052, 0.072, 0.076, 0.079]
# test_mape_std = [0.003, 0.002, 0.001, 0.008, 0.011, 0.004]
# train_r2_mean = [0.561, 0.518, 0.485, 0.569, 0.576, 0.603]
# train_r2_std = [0.01, 0.014, 0.012, 0.025, 0.078, 0.012]
# test_r2_mean = [0.48, 0.187, 0.179, 0.475, 0.571, 0.724]
# test_r2_std = [0.083, 0.055, 0.029, 0.256, 0.365, 0.204]
