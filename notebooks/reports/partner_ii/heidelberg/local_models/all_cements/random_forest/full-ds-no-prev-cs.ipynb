# %%
# %load_ext nb_black

# %%
import pandas as pd
import numpy as np
import re

# %%
def flat_list(lst):
    return [item for tup in list(lst) for item in tup]

# %%
def extract_scores(s):
    pattern = r"\b([A-Z0-9]+):\s+([\d.]+)\s+\(([\d.]+)\)"
    scores = {"Train Mean": [], "Train Std": [], "Test Mean": [], "Test Std": []}
    current_scores = None
    for line in s.split("\n"):
        if "[TRAIN]" in line:
            current_scores = "Train"
        elif "[TEST]" in line:
            current_scores = "Test"
        match = re.search(pattern, line)
        if match:
            score_name = match.group(1)
            score_mean = float(match.group(2))
            score_std = float(match.group(3))
            scores[f"{current_scores} Mean"].append(score_mean)
            scores[f"{current_scores} Std"].append(score_std)
    return scores

# %% [markdown]
# # All Cements

# %%
results = []

# %% [markdown]
# ## No previous Compressive Strength

# %% [markdown]
# ## Repeated KFold Cross validation

# %%
data = {
    "Metric": ["RMSE", "MAE", "MAPE", "R2"],
    "Train Mean": [],
    "Train Std": [],
    "Test Mean": [],
    "Test Std": [],
    "Validation": ["Repeated KFold"] * 4,
    "Repeats": [10] * 4,
    "Splits": [10] * 4,
}
df = pd.DataFrame(data)
df = df[
    [
        "Validation",
        "Repeats",
        "Splits",
        "Metric",
        "Train Mean",
        "Train Std",
        "Test Mean",
        "Test Std",
    ]
]
results.append(df)

# %% [markdown]
# ## Blocking Time Series Split Results

# %%
df = [
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 10,
        "Splits": 5,
        "Metric": "RMSE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 10,
        "Splits": 5,
        "Metric": "MAE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 10,
        "Splits": 5,
        "Metric": "MAPE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 10,
        "Splits": 5,
        "Metric": "R2",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
]
df = pd.DataFrame(df)
results.append(df)

# %% [markdown]
# ## Time Series Split Cross Validation

# %%
# define dictionary with results
tss_results = {
    "Validation": "Time Series Split Cross Validation",
    "Repeats": 10,
    "Splits": 10,
    "RMSE Train Mean": ,
    "RMSE Train Std": ,
    "MAE Train Mean": ,
    "MAE Train Std": ,
    "MAPE Train Mean": ,
    "MAPE Train Std": ,
    "R2 Train Mean": ,
    "R2 Train Std": ,
    "RMSE Test Mean": ,
    "RMSE Test Std": ,
    "MAE Test Mean": ,
    "MAE Test Std": ,
    "MAPE Test Mean": ,
    "MAPE Test Std": ,
    "R2 Test Mean": ,
    "R2 Test Std": ,
}

# create dataframe
df = pd.DataFrame(
    columns=[
        "Validation",
        "Repeats",
        "Splits",
        "Metric",
        "Train Mean",
        "Train Std",
        "Test Mean",
        "Test Std",
    ]
)

# populate dataframe
for i, metric in enumerate(["RMSE", "MAE", "MAPE", "R2"]):
    df.loc[i * 4] = [
        tss_results["Validation"],
        tss_results["Repeats"],
        tss_results["Splits"],
        metric,
        tss_results[f"{metric} Train Mean"],
        tss_results[f"{metric} Train Std"],
        tss_results[f"{metric} Test Mean"],
        tss_results[f"{metric} Test Std"],
    ]
results.append(df)

# %% [markdown]
# ## Blocking Time Series Split Results - Period Specific

# %%
s = """


******
[TRAIN]
******
RMSE: 1.588 (0.113)
MAE: 1.289 (0.084)
MAPE: 0.030 (0.002)
R2: 0.739 (0.065)

======================

******
[TEST]
******
RMSE: 2.381 (0.323)
MAE: 1.891 (0.289)
MAPE: 0.044 (0.008)
R2: 0.117 (0.676)

======================



******
[TRAIN]
******
RMSE: 1.751 (0.125)
MAE: 1.409 (0.098)
MAPE: 0.032 (0.002)
R2: 0.729 (0.033)

======================

******
[TEST]
******
RMSE: 2.183 (0.198)
MAE: 1.722 (0.069)
MAPE: 0.039 (0.002)
R2: 0.397 (0.058)

======================

******
[TRAIN]
******
RMSE: 1.779 (0.106)
MAE: 1.425 (0.081)
MAPE: 0.033 (0.002)
R2: 0.709 (0.039)

======================

******
[TEST]
******
RMSE: 2.128 (0.212)
MAE: 1.774 (0.165)
MAPE: 0.041 (0.003)
R2: 0.413 (0.008)

======================

******
[TRAIN]
******
RMSE: 1.768 (0.053)
MAE: 1.424 (0.037)
MAPE: 0.033 (0.001)
R2: 0.703 (0.030)

======================

******
[TEST]
******
RMSE: 2.376 (0.090)
MAE: 1.855 (0.202)
MAPE: 0.043 (0.003)
R2: 0.485 (0.027)

======================

******
[TRAIN]
******
RMSE: 1.803 (0.041)
MAE: 1.447 (0.013)
MAPE: 0.033 (0.000)
R2: 0.698 (0.021)

======================

******
[TEST]
******
RMSE: 2.562 (0.646)
MAE: 2.204 (0.637)
MAPE: 0.055 (0.018)
R2: 0.150 (0.387)

======================

******
[TRAIN]
******
RMSE: 1.923 (0.000)
MAE: 1.544 (0.000)
MAPE: 0.035 (0.000)
R2: 0.668 (0.000)

======================

******
[TEST]
******
RMSE: 1.752 (0.000)
MAE: 1.437 (0.000)
MAPE: 0.034 (0.000)
R2: 0.229 (0.000)

======================

******
[TRAIN]
******
RMSE: 1.923 (0.000)
MAE: 1.544 (0.000)
MAPE: 0.035 (0.000)
R2: 0.668 (0.000)

======================

******
[TEST]
******
RMSE: 1.729 (0.000)
MAE: 1.405 (0.000)
MAPE: 0.033 (0.000)
R2: 0.411 (0.000)

======================

******
[TRAIN]
******
RMSE: 1.923 (0.000)
MAE: 1.544 (0.000)
MAPE: 0.035 (0.000)
R2: 0.668 (0.000)

======================

******
[TEST]
******
RMSE: 3.401 (0.000)
MAE: 2.751 (0.000)
MAPE: 0.070 (0.000)
R2: 0.184 (0.000)

======================

******
[TRAIN]
******
RMSE: 1.916 (0.000)
MAE: 1.528 (0.000)
MAPE: 0.035 (0.000)
R2: 0.655 (0.000)

======================

******
[TEST]
******
RMSE: 3.855 (0.000)
MAE: 3.282 (0.000)
MAPE: 0.085 (0.000)
R2: 0.916 (0.000)

======================
"""

# %%
## Define the train and test periods for each row
periods = [
    ["6 months", "One Month"],
    ["11 months", "One Month"],
    ["1 year", "One Month"],
    ["1 year and one month", "One Month"],
    ["1 year and two months", "One Month"],
    ["2 years", "One Month"],
    ["2 years", "10 months and 27 days"],
    ["2 years", "One Year"],
    ["2 years and 3 months", "24 days predicts 7 months"],
]

# Extract the relevant information and store it in a dictionary
data = {
    "Validation": ["Blocking Time Series - Period Specific"] * 36,
    "Repeats": [1] * 36,
    "Splits": [np.nan] * 36,
    "Metric": ["RMSE", "MAE", "MAPE", "R2"] * 9,
    "Train Mean": [],
    "Train Std": [],
    "Test Mean": [],
    "Test Std": [],
    "Train Period": [
        item for sublist in [[result[0]] * 4 for result in periods] for item in sublist
    ],
    "Test Period": [
        item for sublist in [[result[1]] * 4 for result in periods] for item in sublist
    ],
}


scores = extract_scores(s)


data["Train Mean"] = scores["Train Mean"]
data["Train Std"] = scores["Train Std"]
data["Test Mean"] = scores["Test Mean"]
data["Test Std"] = scores["Test Std"]


df = pd.DataFrame(data)

# %%
idx = df[df["Metric"] == "RMSE"]["Test Mean"].idxmin()
df.iloc[idx : idx + 4]
# Out:
#                                 Validation  Repeats  Splits Metric  \
# 24  Blocking Time Series - Period Specific        1     NaN   RMSE
# 25  Blocking Time Series - Period Specific        1     NaN    MAE
# 26  Blocking Time Series - Period Specific        1     NaN   MAPE
# 27  Blocking Time Series - Period Specific        1     NaN     R2
#
#     Train Mean  Train Std  Test Mean  Test Std Train Period  \
# 24       1.923        0.0      1.729       0.0      2 years
# 25       1.544        0.0      1.405       0.0      2 years
# 26       0.035        0.0      0.033       0.0      2 years
# 27       0.668        0.0      0.411       0.0      2 years
#
#               Test Period
# 24  10 months and 27 days
# 25  10 months and 27 days
# 26  10 months and 27 days
# 27  10 months and 27 days

# %%
df = df.set_index(["Train Period", "Test Period"])

df[
    (
        df[df["Metric"] == "RMSE"]
        == df[df["Metric"] == "RMSE"][["Test Mean"]].min().values[0]
    )["Test Mean"]
]
# Out:
# /home/felipe/Documents/ccs28-venv/lib/python3.6/site-packages/ipykernel_launcher.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   import sys
#                                                                 Validation  \
# Train Period Test Period
# 2 years      10 months and 27 days  Blocking Time Series - Period Specific
#              10 months and 27 days  Blocking Time Series - Period Specific
#              10 months and 27 days  Blocking Time Series - Period Specific
#              10 months and 27 days  Blocking Time Series - Period Specific
#
#                                     Repeats  Splits Metric  Train Mean  \
# Train Period Test Period
# 2 years      10 months and 27 days        1     NaN   RMSE       1.923
#              10 months and 27 days        1     NaN    MAE       1.544
#              10 months and 27 days        1     NaN   MAPE       0.035
#              10 months and 27 days        1     NaN     R2       0.668
#
#                                     Train Std  Test Mean  Test Std
# Train Period Test Period
# 2 years      10 months and 27 days        0.0      1.729       0.0
#              10 months and 27 days        0.0      1.405       0.0
#              10 months and 27 days        0.0      0.033       0.0
#              10 months and 27 days        0.0      0.411       0.0
