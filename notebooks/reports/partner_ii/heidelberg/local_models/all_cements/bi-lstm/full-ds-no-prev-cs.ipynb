# %%
# %load_ext nb_black

# %%
import pandas as pd
import numpy as np

# %%
def flat_list(lst):
    return [item for tup in list(lst) for item in tup]

# %%
def extract_numbers(text):
    values = []
    for line in text.split("\n"):
        line = line.strip()
        if line.startswith("RMSE:"):
            parts = line.split(" ")
            values.append(float(parts[1]))
            values.append(float(parts[2].lstrip("(").rstrip(")")))
        elif line.startswith("MAE:"):
            parts = line.split(" ")
            values.append(float(parts[1]))
            values.append(float(parts[2].lstrip("(").rstrip(")")))
        elif line.startswith("MAPE:"):
            parts = line.split(" ")
            values.append(float(parts[1]))
            values.append(float(parts[2].lstrip("(").rstrip(")")))
        elif line.startswith("R2:"):
            parts = line.split(" ")
            values.append(float(parts[1]))
            values.append(float(parts[2].lstrip("(").rstrip(")")))
    return values

# %%
def extract_and_fill_lists(text, train_rmse_mean, train_rmse_std, test_rmse_mean, test_rmse_std,
                           train_mae_mean, train_mae_std, test_mae_mean, test_mae_std,
                           train_mape_mean, train_mape_std, test_mape_mean, test_mape_std,
                           train_r2_mean, train_r2_std, test_r2_mean, test_r2_std):

    train_flag = False
    test_flag = False
    timesteps_flag = False

    for line in text.split("\n"):
        line = line.strip()

        if line.startswith("TIMESTEPS:"):
            timesteps_flag = True

        elif line.startswith("[TRAIN]"):
            train_flag = True
            test_flag = False

        elif line.startswith("[TEST]"):
            train_flag = False
            test_flag = True

        elif line.startswith("RMSE:"):
            parts = line.split(" ")
            if train_flag:
                train_rmse_mean.append(float(parts[1]))
                train_rmse_std.append(float(parts[2].lstrip("(").rstrip(")")))
            elif test_flag:
                test_rmse_mean.append(float(parts[1]))
                test_rmse_std.append(float(parts[2].lstrip("(").rstrip(")")))

        elif line.startswith("MAE:"):
            parts = line.split(" ")
            if train_flag:
                train_mae_mean.append(float(parts[1]))
                train_mae_std.append(float(parts[2].lstrip("(").rstrip(")")))
            elif test_flag:
                test_mae_mean.append(float(parts[1]))
                test_mae_std.append(float(parts[2].lstrip("(").rstrip(")")))

        elif line.startswith("MAPE:"):
            parts = line.split(" ")
            if train_flag:
                train_mape_mean.append(float(parts[1]))
                train_mape_std.append(float(parts[2].lstrip("(").rstrip(")")))
            elif test_flag:
                test_mape_mean.append(float(parts[1]))
                test_mape_std.append(float(parts[2].lstrip("(").rstrip(")")))

        elif line.startswith("R2:"):
            parts = line.split(" ")
            if train_flag:
                train_r2_mean.append(float(parts[1]))
                train_r2_std.append(float(parts[2].lstrip("(").rstrip(")")))
            elif test_flag:
                test_r2_mean.append(float(parts[1]))
                test_r2_std.append(float(parts[2].lstrip("(").rstrip(")")))

        elif line.startswith("="):
            train_flag = False
            test_flag = False
            timesteps_flag = False

        else:
            continue

# %% [markdown]
# # All Cements

# %%
results = []

# %% [markdown]
# ## No previous Compressive Strength

# %% [markdown]
# ## Repeated KFold Cross validation

# %%
data = {
    "Time Steps": sorted([1, 3, 5, 7, 14, 21] * 4),
    "Metric": ["RMSE", "MAE", "MAPE", "R2"] * 6,
    "Train Mean": [],
    "Train Std": [],
    "Test Mean": [],
    "Test Std": [],
    "Validation": ["Repeated KFold"] * 4 * 6,
    "Repeats": [10] * 4 * 6,
    "Splits": [10] * 4 * 6,
}


# For TIMESTEPS: 1
data["Train Mean"].extend([])
data["Train Std"].extend([])
data["Test Mean"].extend([])
data["Test Std"].extend([])

# For TIMESTEPS: 3
data["Train Mean"].extend([])
data["Train Std"].extend([])
data["Test Mean"].extend([])
data["Test Std"].extend([])

# For TIMESTEPS: 5
data["Train Mean"].extend([])
data["Train Std"].extend([])
data["Test Mean"].extend([])
data["Test Std"].extend([])

# For TIMESTEPS: 7
data["Train Mean"].extend([])
data["Train Std"].extend([])
data["Test Mean"].extend([])
data["Test Std"].extend([])

# For TIMESTEPS: 14
data["Train Mean"].extend([])
data["Train Std"].extend([])
data["Test Mean"].extend([])
data["Test Std"].extend([])


# For TIMESTEPS: 21
data["Train Mean"].extend([])
data["Train Std"].extend([])
data["Test Mean"].extend([])
data["Test Std"].extend([])

df = pd.DataFrame(data)
df = df[
    [
        "Validation",
        "Repeats",
        "Splits",
        "Time Steps",
        "Metric",
        "Train Mean",
        "Train Std",
        "Test Mean",
        "Test Std",
    ]
]
df
results.append(df)

# %% [markdown]
# ## Blocking Time Series Split Results

# %%
df = [
    # Timesteps = 1
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 1,
        "Metric": "RMSE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 1,
        "Metric": "MAE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 1,
        "Metric": "MAPE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 1,
        "Metric": "R2",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    # Timesteps = 3
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 3,
        "Metric": "RMSE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 3,
        "Metric": "MAE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 3,
        "Metric": "MAPE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 3,
        "Metric": "R2",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    # Timesteps = 5
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 5,
        "Metric": "RMSE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 5,
        "Metric": "MAE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 5,
        "Metric": "MAPE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 5,
        "Metric": "R2",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    # Timesteps = 7
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 7,
        "Metric": "RMSE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 7,
        "Metric": "MAE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 7,
        "Metric": "MAPE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 7,
        "Metric": "R2",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    # Timesteps = 14
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 14,
        "Metric": "RMSE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 14,
        "Metric": "MAE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 14,
        "Metric": "MAPE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 14,
        "Metric": "R2",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    # Timesteps = 21
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 21,
        "Metric": "RMSE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 21,
        "Metric": "MAE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 21,
        "Metric": "MAPE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 21,
        "Metric": "R2",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
]

df = pd.DataFrame(df)
results.append(df)

# %% [markdown]
# ## Time Series Split Cross Validation

# %%
df = [
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 10,
        "Time Steps": 1,
        "Metric": "RMSE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 10,
        "Time Steps": 1,
        "Metric": "MAE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 10,
        "Time Steps": 1,
        "Metric": "MAPE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 10,
        "Time Steps": 1,
        "Metric": "R2",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 10,
        "Time Steps": 3,
        "Metric": "RMSE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 10,
        "Time Steps": 3,
        "Metric": "MAE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 10,
        "Time Steps": 3,
        "Metric": "MAPE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 10,
        "Time Steps": 3,
        "Metric": "R2",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 5,
        "Metric": "RMSE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 5,
        "Metric": "MAE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 5,
        "Metric": "MAPE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 5,
        "Metric": "R2",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 7,
        "Metric": "RMSE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 7,
        "Metric": "MAE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 7,
        "Metric": "MAPE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 7,
        "Metric": "R2",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 14,
        "Metric": "RMSE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 14,
        "Metric": "MAE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 14,
        "Metric": "MAPE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 14,
        "Metric": "R2",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 21,
        "Metric": "RMSE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 21,
        "Metric": "MAE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 21,
        "Metric": "MAPE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Time Series Split Cross Validation",
        "Repeats": 5,
        "Splits": 5,
        "Time Steps": 21,
        "Metric": "R2",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
]

df = pd.DataFrame(df)
results.append(df)

# %% [markdown]
# ## Blocking Time Series Split Results - Period Specific

# %%
# Define the train and test periods for each row
periods = [
    ["6 months", "One Month"],
    ["11 months", "One Month"],
    ["1 year", "One Month"],
    ["1 year and one month", "One Month"],
    ["1 year and two months", "One Month"],
    ["2 years", "One Month"],
    ["2 years", "10 months and 27 days"],
    ["2 years", "One Year"],
    ["2 years and 3 months", "24 days predicts 7 months"],
]

train_mean = []
test_mean = []

train_std = []
test_std = []

###########################
# 6 months", "One Month"  #
###########################
train_rmse_mean = [3.908, 1.748, 1.795, 1.943, 2.126, 2.141]
train_rmse_std = [1.484, 0.247, 0.229, 0.405, 0.358, 0.396]
test_rmse_mean = [55.506, 109.619, 158.058, 53.85, 5.967, 6.927]
test_rmse_std = [99.262, 222.905, 314.636, 86.178, 4.861, 6.508]
train_mae_mean = [3.128, 1.391, 1.438, 1.59, 1.737, 1.753]
train_mae_std = [1.199, 0.212, 0.176, 0.388, 0.348, 0.375]
test_mae_mean = [24.314, 55.124, 90.273, 15.468, 4.744, 5.61]
test_mae_std = [39.001, 106.854, 173.87, 17.644, 3.997, 5.13]
train_mape_mean = [0.073, 0.033, 0.033, 0.036, 0.039, 0.04]
train_mape_std = [0.027, 0.005, 0.004, 0.009, 0.007, 0.008]
test_mape_mean = [0.559, 1.244, 2.014, 0.38, 0.109, 0.132]
test_mape_std = [0.884, 2.393, 3.884, 0.452, 0.091, 0.12]
train_r2_mean = [0.767, 0.675, 0.672, 0.603, 0.517, 0.513]
train_r2_std = [1.186, 0.107, 0.114, 0.188, 0.188, 0.191]
test_r2_mean = [891.738, 6102.824, 13014.267, 1025.245, 4.183, 8.181]
test_r2_std = [1778.431, 14897.161, 32543.577, 2171.65, 7.037, 20.639]


train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

###########################
# 11 months", "One Month  #
###########################
train_rmse_mean = [2.568, 1.85, 2.096, 1.849, 2.037, 1.983]
train_rmse_std = [0.16, 0.155, 0.361, 0.193, 0.127, 0.12]
test_rmse_mean = [4179.326, 5162.607, 5026.647, 4411.849, 5.238, 2.709]
test_rmse_std = [4187.296, 5207.345, 5322.695, 4710.551, 3.185, 0.275]
train_mae_mean = [2.007, 1.451, 1.672, 1.475, 1.611, 1.567]
train_mae_std = [0.143, 0.125, 0.289, 0.151, 0.112, 0.107]
test_mae_mean = [1833.171, 2178.541, 2564.197, 2900.065, 3.925, 2.221]
test_mae_std = [1835.213, 2195.389, 2705.568, 3069.537, 2.346, 0.263]
train_mape_mean = [0.046, 0.034, 0.039, 0.034, 0.037, 0.036]
train_mape_std = [0.003, 0.003, 0.007, 0.004, 0.002, 0.002]
test_mape_mean = [41.959, 50.604, 59.288, 67.898, 0.091, 0.051]
test_mape_std = [42.006, 50.992, 62.577, 71.874, 0.056, 0.006]
train_r2_mean = [0.418, 0.693, 0.593, 0.687, 0.61, 0.626]
train_r2_std = [0.062, 0.058, 0.146, 0.073, 0.047, 0.035]
test_r2_mean = [5876098.473, 11114839.137, 9321028.33, 9560753.45, 7.991, 0.017]
test_r2_std = [5936005.362, 11523760.085, 11391282.335, 12203002.864, 9.966, 0.273]


train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

###########################
# "1 year", "One Month"   #
###########################
train_rmse_mean = [2.333, 2.094, 2.004, 2.02, 2.059, 2.261]
train_rmse_std = [0.082, 0.104, 0.085, 0.093, 0.139, 0.383]
test_rmse_mean = [2.476, 2.067, 2.621, 2.331, 2.599, 2.62]
test_rmse_std = [0.608, 0.652, 0.782, 0.358, 0.328, 0.526]
train_mae_mean = [1.835, 1.681, 1.59, 1.599, 1.634, 1.813]
train_mae_std = [0.029, 0.101, 0.083, 0.083, 0.136, 0.346]
test_mae_mean = [2.07, 1.65, 2.026, 1.976, 2.147, 2.169]
test_mae_std = [0.437, 0.44, 0.552, 0.36, 0.3, 0.426]
train_mape_mean = [0.042, 0.038, 0.036, 0.037, 0.037, 0.041]
train_mape_std = [0.001, 0.002, 0.002, 0.002, 0.003, 0.007]
test_mape_mean = [0.049, 0.038, 0.046, 0.045, 0.048, 0.05]
test_mape_std = [0.01, 0.01, 0.012, 0.007, 0.006, 0.01]
train_r2_mean = [0.503, 0.593, 0.624, 0.617, 0.588, 0.489]
train_r2_std = [0.027, 0.046, 0.038, 0.042, 0.056, 0.176]
test_r2_mean = [0.214, 0.473, 0.179, 0.149, 0.236, 0.289]
test_r2_std = [0.221, 0.216, 0.242, 0.133, 0.165, 0.241]


train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

#########################################
# "1 year and one month", "One Month"   #
#########################################
train_rmse_mean = [2.291, 2.073, 2.15, 2.394, 1.974, 1.946]
train_rmse_std = [0.143, 0.078, 0.156, 0.167, 0.076, 0.093]
test_rmse_mean = [2.564, 2.539, 2.391, 2.337, 2.628, 2.34]
test_rmse_std = [0.516, 0.441, 0.505, 0.441, 0.806, 0.671]
train_mae_mean = [1.812, 1.656, 1.702, 1.924, 1.556, 1.535]
train_mae_std = [0.087, 0.078, 0.121, 0.146, 0.064, 0.084]
test_mae_mean = [2.035, 1.986, 1.867, 1.932, 2.218, 1.899]
test_mae_std = [0.54, 0.394, 0.243, 0.399, 0.752, 0.552]
train_mape_mean = [0.042, 0.038, 0.039, 0.043, 0.036, 0.035]
train_mape_std = [0.002, 0.001, 0.002, 0.003, 0.002, 0.002]
test_mape_mean = [0.047, 0.047, 0.044, 0.045, 0.054, 0.048]
test_mape_std = [0.011, 0.008, 0.006, 0.009, 0.02, 0.015]
train_r2_mean = [0.504, 0.59, 0.556, 0.449, 0.625, 0.634]
train_r2_std = [0.043, 0.045, 0.081, 0.088, 0.032, 0.037]
test_r2_mean = [0.381, 0.364, 0.377, 0.341, 0.416, 0.313]
test_r2_std = [0.227, 0.187, 0.283, 0.193, 1.05, 0.407]


train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

##########################################
# "1 year and two months", "One Month"   #
#########################################
train_rmse_mean = [2.319, 2.076, 2.03, 2.077, 2.07, 2.142]
train_rmse_std = [0.151, 0.067, 0.036, 0.061, 0.09, 0.219]
test_rmse_mean = [2.788, 2.324, 2.853, 2.801, 2.982, 2.584]
test_rmse_std = [0.706, 0.441, 0.708, 0.535, 1.134, 0.258]
train_mae_mean = [1.836, 1.644, 1.604, 1.633, 1.625, 1.698]
train_mae_std = [0.101, 0.058, 0.047, 0.047, 0.087, 0.189]
test_mae_mean = [2.404, 1.891, 2.254, 2.196, 2.628, 1.957]
test_mae_std = [0.672, 0.328, 0.626, 0.555, 1.183, 0.27]
train_mape_mean = [0.042, 0.038, 0.037, 0.037, 0.038, 0.039]
train_mape_std = [0.002, 0.001, 0.001, 0.001, 0.002, 0.004]
test_mape_mean = [0.06, 0.047, 0.057, 0.055, 0.066, 0.049]
test_mape_std = [0.019, 0.011, 0.019, 0.016, 0.033, 0.009]
train_r2_mean = [0.501, 0.596, 0.616, 0.601, 0.597, 0.582]
train_r2_std = [0.052, 0.035, 0.014, 0.023, 0.037, 0.084]
test_r2_mean = [0.007, 0.365, 0.045, 0.004, 0.843, 0.082]
test_r2_std = [0.46, 0.204, 0.424, 0.395, 1.69, 0.424]


train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

############################
# "2 years", "One Month"   #
############################
train_rmse_mean = [2.254, 2.059, 2.078, 2.072, 2.049, 1.945]
train_rmse_std = [0.013, 0.017, 0.032, 0.07, 0.087, 0.01]
test_rmse_mean = [2.194, 2.46, 2.754, 2.301, 1.893, 2.183]
test_rmse_std = [0.1, 0.124, 0.295, 0.388, 0.338, 0.201]
train_mae_mean = [1.788, 1.646, 1.642, 1.635, 1.624, 1.546]
train_mae_std = [0.011, 0.016, 0.028, 0.052, 0.078, 0.006]
test_mae_mean = [1.881, 2.077, 2.122, 1.779, 1.462, 1.838]
test_mae_std = [0.106, 0.082, 0.102, 0.193, 0.181, 0.151]
train_mape_mean = [0.041, 0.038, 0.038, 0.038, 0.037, 0.035]
train_mape_std = [0.0, 0.0, 0.001, 0.001, 0.002, 0.0]
test_mape_mean = [0.044, 0.048, 0.05, 0.043, 0.035, 0.041]
test_mape_std = [0.002, 0.002, 0.002, 0.005, 0.005, 0.003]
train_r2_mean = [0.544, 0.614, 0.605, 0.602, 0.6, 0.638]
train_r2_std = [0.005, 0.007, 0.012, 0.027, 0.034, 0.004]
test_r2_mean = [0.212, 0.106, 0.398, 0.172, 0.361, 0.247]
test_r2_std = [0.109, 0.109, 0.305, 0.294, 0.245, 0.139]


train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

############################
# "2 years", "Two Months"  #
############################
train_rmse_mean = [2.254, 2.059, 2.078, 2.072, 2.049, 1.945]
train_rmse_std = [0.013, 0.017, 0.032, 0.07, 0.087, 0.01]
test_rmse_mean = [2.072, 2.12, 2.58, 2.333, 2.314, 2.771]
test_rmse_std = [0.064, 0.09, 0.125, 0.339, 0.317, 0.709]
train_mae_mean = [1.788, 1.646, 1.642, 1.635, 1.624, 1.546]
train_mae_std = [0.011, 0.016, 0.028, 0.052, 0.078, 0.006]
test_mae_mean = [1.75, 1.748, 2.0, 1.873, 1.856, 2.181]
test_mae_std = [0.064, 0.07, 0.054, 0.203, 0.198, 0.376]
train_mape_mean = [0.041, 0.038, 0.038, 0.038, 0.037, 0.035]
train_mape_std = [0.0, 0.0, 0.001, 0.001, 0.002, 0.0]
test_mape_mean = [0.041, 0.041, 0.046, 0.044, 0.043, 0.05]
test_mape_std = [0.001, 0.002, 0.001, 0.005, 0.005, 0.008]
train_r2_mean = [0.544, 0.614, 0.605, 0.602, 0.6, 0.638]
train_r2_std = [0.005, 0.007, 0.012, 0.027, 0.034, 0.004]
test_r2_mean = [0.153, 0.212, 0.203, 0.0, 0.25, 0.059]
test_r2_std = [0.051, 0.065, 0.119, 0.301, 0.208, 0.527]


train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

##########################
# "2 years", "One Year"  #
############################
train_rmse_mean = [2.254, 2.155, 2.476, 2.369, 2.32, 2.334]
train_rmse_std = [0.013, 0.018, 0.158, 0.124, 0.157, 0.091]
test_rmse_mean = [2.898, 3.376, 3.412, 3.287, 4.03, 5.023]
test_rmse_std = [0.056, 0.093, 0.15, 0.118, 0.035, 0.873]
train_mae_mean = [1.788, 1.717, 1.995, 1.907, 1.869, 1.887]
train_mae_std = [0.011, 0.013, 0.149, 0.112, 0.151, 0.086]
test_mae_mean = [2.376, 2.718, 2.72, 2.67, 3.113, 3.679]
test_mae_std = [0.038, 0.07, 0.107, 0.096, 0.039, 0.46]
train_mape_mean = [0.041, 0.039, 0.045, 0.043, 0.042, 0.043]
train_mape_std = [0.0, 0.0, 0.003, 0.003, 0.003, 0.002]
test_mape_mean = [0.06, 0.067, 0.067, 0.066, 0.077, 0.091]
test_mape_std = [0.001, 0.002, 0.003, 0.002, 0.001, 0.011]
train_r2_mean = [0.544, 0.583, 0.447, 0.494, 0.514, 0.51]
train_r2_std = [0.005, 0.007, 0.07, 0.053, 0.067, 0.037]
test_r2_mean = [0.141, 0.167, 0.193, 0.107, 0.662, 1.659]
test_r2_std = [0.033, 0.064, 0.104, 0.081, 0.029, 0.899]

train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))

###########################################################
# "2 years, 8 months and 15 days", "8 months and 6 days"  #
###########################################################
train_rmse_mean = [2.125, 2.076, 2.115, 2.155, 2.061, 2.064]
train_rmse_std = [0.01, 0.034, 0.071, 0.171, 0.098, 0.103]
test_rmse_mean = [3.354, 3.474, 3.228, 3.051, 3.871, 3.481]
test_rmse_std = [0.074, 0.107, 0.223, 0.208, 0.129, 0.329]
train_mae_mean = [1.685, 1.658, 1.671, 1.706, 1.635, 1.642]
train_mae_std = [0.012, 0.028, 0.055, 0.143, 0.083, 0.087]
test_mae_mean = [2.832, 2.943, 2.676, 2.52, 3.146, 2.88]
test_mae_std = [0.073, 0.106, 0.19, 0.182, 0.139, 0.306]
train_mape_mean = [0.039, 0.038, 0.038, 0.038, 0.037, 0.037]
train_mape_std = [0.0, 0.001, 0.001, 0.003, 0.002, 0.002]
test_mape_mean = [0.073, 0.076, 0.069, 0.065, 0.082, 0.075]
test_mape_std = [0.002, 0.003, 0.005, 0.005, 0.004, 0.008]
train_r2_mean = [0.576, 0.595, 0.579, 0.561, 0.6, 0.599]
train_r2_std = [0.004, 0.013, 0.028, 0.073, 0.038, 0.041]
test_r2_mean = [0.451, 0.557, 0.349, 0.205, 0.933, 0.576]
test_r2_std = [0.063, 0.098, 0.187, 0.162, 0.13, 0.289]

train_mean += flat_list(
    zip(train_rmse_mean, train_mae_mean, train_mape_mean, train_r2_mean)
)

test_mean += flat_list(zip(test_rmse_mean, test_mae_mean, test_mape_mean, test_r2_mean))

train_std += flat_list(zip(train_rmse_std, train_mae_std, train_mape_std, train_r2_std))

test_std += flat_list(zip(test_rmse_std, test_mae_std, test_mape_std, test_r2_std))


# Extract the relevant information and store it in a dictionary
data = {
    "Validation": ["Blocking Time Series - Period Specific"] * 216,
    "Repeats": [5] * 216,
    "Splits": [np.nan] * 216,
    "Metric": ["RMSE", "MAE", "MAPE", "R2"] * len(periods) * 6,
    "Time Steps": sorted([1, 3, 5, 7, 14, 21] * 4 * 9),
    "Train Mean": train_mean,
    "Train Std": train_std,
    "Test Mean": test_mean,
    "Test Std": test_std,
    "Train Period": [
        item
        for sublist in [[result[0]] * 4 * 6 for result in periods]
        for item in sublist
    ],
    "Test Period": [
        item
        for sublist in [[result[1]] * 4 * 6 for result in periods]
        for item in sublist
    ],
}

df = pd.DataFrame(data)

# %%
idx = df[df["Metric"] == "RMSE"]["Test Mean"].idxmin()
df.iloc[idx : idx + 4]
# Out:
#                                  Validation  Repeats  Splits Metric  \
# 136  Blocking Time Series - Period Specific        5     NaN   RMSE
# 137  Blocking Time Series - Period Specific        5     NaN    MAE
# 138  Blocking Time Series - Period Specific        5     NaN   MAPE
# 139  Blocking Time Series - Period Specific        5     NaN     R2
#
#      Time Steps  Train Mean  Train Std  Test Mean  Test Std Train Period  \
# 136           7       2.049      0.087      1.893     0.338      2 years
# 137           7       1.624      0.078      1.462     0.181      2 years
# 138           7       0.037      0.002      0.035     0.005      2 years
# 139           7       0.600      0.034      0.361     0.245      2 years
#
#     Test Period
# 136   One Month
# 137   One Month
# 138   One Month
# 139   One Month

# %%
s = """

"""

# %%
train_rmse_mean, train_rmse_std, test_rmse_mean, test_rmse_std = [], [], [], []
train_mae_mean, train_mae_std, test_mae_mean, test_mae_std = [], [], [], []
train_mape_mean, train_mape_std, test_mape_mean, test_mape_std = [], [], [], []
train_r2_mean, train_r2_std, test_r2_mean, test_r2_std = [], [], [], []

extract_and_fill_lists(
    s,
    train_rmse_mean,
    train_rmse_std,
    test_rmse_mean,
    test_rmse_std,
    train_mae_mean,
    train_mae_std,
    test_mae_mean,
    test_mae_std,
    train_mape_mean,
    train_mape_std,
    test_mape_mean,
    test_mape_std,
    train_r2_mean,
    train_r2_std,
    test_r2_mean,
    test_r2_std,
)

for x, y in zip(
    [
        "train_rmse_mean",
        "train_rmse_std",
        "test_rmse_mean",
        "test_rmse_std",
        "train_mae_mean",
        "train_mae_std",
        "test_mae_mean",
        "test_mae_std",
        "train_mape_mean",
        "train_mape_std",
        "test_mape_mean",
        "test_mape_std",
        "train_r2_mean",
        "train_r2_std",
        "test_r2_mean",
        "test_r2_std",
    ],
    [
        train_rmse_mean,
        train_rmse_std,
        test_rmse_mean,
        test_rmse_std,
        train_mae_mean,
        train_mae_std,
        test_mae_mean,
        test_mae_std,
        train_mape_mean,
        train_mape_std,
        test_mape_mean,
        test_mape_std,
        train_r2_mean,
        train_r2_std,
        test_r2_mean,
        test_r2_std,
    ],
):
    print(f"{x} = {y}")
# Out:
# train_rmse_mean = [2.125, 2.076, 2.115, 2.155, 2.061, 2.064]
# train_rmse_std = [0.01, 0.034, 0.071, 0.171, 0.098, 0.103]
# test_rmse_mean = [3.354, 3.474, 3.228, 3.051, 3.871, 3.481]
# test_rmse_std = [0.074, 0.107, 0.223, 0.208, 0.129, 0.329]
# train_mae_mean = [1.685, 1.658, 1.671, 1.706, 1.635, 1.642]
# train_mae_std = [0.012, 0.028, 0.055, 0.143, 0.083, 0.087]
# test_mae_mean = [2.832, 2.943, 2.676, 2.52, 3.146, 2.88]
# test_mae_std = [0.073, 0.106, 0.19, 0.182, 0.139, 0.306]
# train_mape_mean = [0.039, 0.038, 0.038, 0.038, 0.037, 0.037]
# train_mape_std = [0.0, 0.001, 0.001, 0.003, 0.002, 0.002]
# test_mape_mean = [0.073, 0.076, 0.069, 0.065, 0.082, 0.075]
# test_mape_std = [0.002, 0.003, 0.005, 0.005, 0.004, 0.008]
# train_r2_mean = [0.576, 0.595, 0.579, 0.561, 0.6, 0.599]
# train_r2_std = [0.004, 0.013, 0.028, 0.073, 0.038, 0.041]
# test_r2_mean = [0.451, 0.557, 0.349, 0.205, 0.933, 0.576]
# test_r2_std = [0.063, 0.098, 0.187, 0.162, 0.13, 0.289]
