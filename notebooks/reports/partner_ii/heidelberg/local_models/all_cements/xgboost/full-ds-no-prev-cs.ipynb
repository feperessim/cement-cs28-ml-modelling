# %%
# %load_ext nb_black

# %%
import pandas as pd
import numpy as np
import re

# %%
def flat_list(lst):
    return [item for tup in list(lst) for item in tup]

# %%
def extract_scores(s):
    pattern = r"\b([A-Z0-9]+):\s+([\d.]+)\s+\(([\d.]+)\)"
    scores = {"Train Mean": [], "Train Std": [], "Test Mean": [], "Test Std": []}
    current_scores = None
    for line in s.split("\n"):
        if "[TRAIN]" in line:
            current_scores = "Train"
        elif "[TEST]" in line:
            current_scores = "Test"
        match = re.search(pattern, line)
        if match:
            score_name = match.group(1)
            score_mean = float(match.group(2))
            score_std = float(match.group(3))
            scores[f"{current_scores} Mean"].append(score_mean)
            scores[f"{current_scores} Std"].append(score_std)
    return scores

# %% [markdown]
# # All Cements

# %%
results = []

# %% [markdown]
# ## No previous Compressive Strength

# %% [markdown]
# ## Repeated KFold Cross validation

# %%
data = {
    "Metric": ["RMSE", "MAE", "MAPE", "R2"],
    "Train Mean": [],
    "Train Std": [],
    "Test Mean": [],
    "Test Std": [],
    "Validation": ["Repeated KFold"] * 4,
    "Repeats": [10] * 4,
    "Splits": [10] * 4,
}
df = pd.DataFrame(data)
df = df[
    [
        "Validation",
        "Repeats",
        "Splits",
        "Metric",
        "Train Mean",
        "Train Std",
        "Test Mean",
        "Test Std",
    ]
]
results.append(df)

# %% [markdown]
# ## Blocking Time Series Split Results

# %%
df = [
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 10,
        "Splits": 5,
        "Metric": "RMSE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 10,
        "Splits": 5,
        "Metric": "MAE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 10,
        "Splits": 5,
        "Metric": "MAPE",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
    {
        "Validation": "Blocking Time Series Split",
        "Repeats": 10,
        "Splits": 5,
        "Metric": "R2",
        "Train Mean": ,
        "Train Std": ,
        "Test Mean": ,
        "Test Std": ,
    },
]
df = pd.DataFrame(df)
results.append(df)

# %% [markdown]
# ## Time Series Split Cross Validation

# %%
# define dictionary with results
tss_results = {
    "Validation": "Time Series Split Cross Validation",
    "Repeats": 10,
    "Splits": 10,
    "RMSE Train Mean": ,
    "RMSE Train Std": ,
    "MAE Train Mean": ,
    "MAE Train Std": ,
    "MAPE Train Mean": ,
    "MAPE Train Std": ,
    "R2 Train Mean": ,
    "R2 Train Std": ,
    "RMSE Test Mean": ,
    "RMSE Test Std": ,
    "MAE Test Mean": ,
    "MAE Test Std": ,
    "MAPE Test Mean": ,
    "MAPE Test Std": ,
    "R2 Test Mean": ,
    "R2 Test Std": ,
}

# create dataframe
df = pd.DataFrame(
    columns=[
        "Validation",
        "Repeats",
        "Splits",
        "Metric",
        "Train Mean",
        "Train Std",
        "Test Mean",
        "Test Std",
    ]
)

# populate dataframe
for i, metric in enumerate(["RMSE", "MAE", "MAPE", "R2"]):
    df.loc[i * 4] = [
        tss_results["Validation"],
        tss_results["Repeats"],
        tss_results["Splits"],
        metric,
        tss_results[f"{metric} Train Mean"],
        tss_results[f"{metric} Train Std"],
        tss_results[f"{metric} Test Mean"],
        tss_results[f"{metric} Test Std"],
    ]
results.append(df)

# %% [markdown]
# ## Blocking Time Series Split Results - Period Specific

# %%
s = """


******
[TRAIN]
******
RMSE: 1.363 (0.102)
MAE: 1.081 (0.089)
MAPE: 0.025 (0.001)
R2: 0.810 (0.042)

======================

******
[TEST]
******
RMSE: 2.554 (0.458)
MAE: 2.016 (0.384)
MAPE: 0.046 (0.006)
R2: 0.182 (0.154)

======================

******
[TRAIN]
******
RMSE: 1.623 (0.087)
MAE: 1.301 (0.070)
MAPE: 0.030 (0.001)
R2: 0.768 (0.021)

======================

******
[TEST]
******
RMSE: 2.461 (0.015)
MAE: 2.019 (0.089)
MAPE: 0.045 (0.002)
R2: 0.197 (0.227)

======================

******
[TRAIN]
******
RMSE: 1.645 (0.077)
MAE: 1.313 (0.062)
MAPE: 0.030 (0.001)
R2: 0.752 (0.027)

======================

******
[TEST]
******
RMSE: 2.041 (0.292)
MAE: 1.698 (0.232)
MAPE: 0.039 (0.005)
R2: 0.464 (0.040)

======================

******
[TRAIN]
******
RMSE: 1.621 (0.008)
MAE: 1.303 (0.008)
MAPE: 0.030 (0.000)
R2: 0.751 (0.012)

======================

******
[TEST]
******
RMSE: 2.447 (0.307)
MAE: 1.971 (0.308)
MAPE: 0.045 (0.005)
R2: 0.448 (0.124)

======================

******
[TRAIN]
******
RMSE: 1.645 (0.020)
MAE: 1.311 (0.030)
MAPE: 0.030 (0.001)
R2: 0.749 (0.000)

======================

******
[TEST]
******
RMSE: 2.580 (0.536)
MAE: 2.186 (0.478)
MAPE: 0.054 (0.015)
R2: 0.153 (0.320)

======================


******
[TRAIN]
******
RMSE: 1.833 (0.000)
MAE: 1.471 (0.000)
MAPE: 0.033 (0.000)
R2: 0.698 (0.000)

======================

******
[TEST]
******
RMSE: 1.831 (0.000)
MAE: 1.381 (0.000)
MAPE: 0.032 (0.000)
R2: 0.158 (0.000)

======================

******
[TRAIN]
******
RMSE: 1.833 (0.000)
MAE: 1.471 (0.000)
MAPE: 0.033 (0.000)
R2: 0.698 (0.000)

======================

******
[TEST]
******
RMSE: 1.716 (0.000)
MAE: 1.299 (0.000)
MAPE: 0.030 (0.000)
R2: 0.420 (0.000)

======================

******
[TRAIN]
******
RMSE: 1.833 (0.000)
MAE: 1.471 (0.000)
MAPE: 0.033 (0.000)
R2: 0.698 (0.000)

======================

******
[TEST]
******
RMSE: 3.104 (0.000)
MAE: 2.498 (0.000)
MAPE: 0.063 (0.000)
R2: 0.014 (0.000)

======================

******
[TRAIN]
******
RMSE: 1.825 (0.000)
MAE: 1.460 (0.000)
MAPE: 0.033 (0.000)
R2: 0.687 (0.000)

======================

******
[TEST]
******
RMSE: 3.515 (0.000)
MAE: 2.978 (0.000)
MAPE: 0.077 (0.000)
R2: 0.593 (0.000)

======================

"""

# %%
## Define the train and test periods for each row
periods = [
    ["6 months", "One Month"],
    ["11 months", "One Month"],
    ["1 year", "One Month"],
    ["1 year and one month", "One Month"],
    ["1 year and two months", "One Month"],
    ["2 years", "One Month"],
    ["2 years", "10 months and 27 days"],
    ["2 years", "One Year"],
    ["2 years and 3 months", "24 days predicts 7 months"],
]

# Extract the relevant information and store it in a dictionary
data = {
    "Validation": ["Blocking Time Series - Period Specific"] * 36,
    "Repeats": [1] * 36,
    "Splits": [np.nan] * 36,
    "Metric": ["RMSE", "MAE", "MAPE", "R2"] * 9,
    "Train Mean": [],
    "Train Std": [],
    "Test Mean": [],
    "Test Std": [],
    "Train Period": [
        item for sublist in [[result[0]] * 4 for result in periods] for item in sublist
    ],
    "Test Period": [
        item for sublist in [[result[1]] * 4 for result in periods] for item in sublist
    ],
}


scores = extract_scores(s)


data["Train Mean"] = scores["Train Mean"]
data["Train Std"] = scores["Train Std"]
data["Test Mean"] = scores["Test Mean"]
data["Test Std"] = scores["Test Std"]


df = pd.DataFrame(data)

# %%
idx = df[df["Metric"] == "RMSE"]["Test Mean"].idxmin()
df.iloc[idx : idx + 4]
# Out:
#                                 Validation  Repeats  Splits Metric  \
# 24  Blocking Time Series - Period Specific        1     NaN   RMSE
# 25  Blocking Time Series - Period Specific        1     NaN    MAE
# 26  Blocking Time Series - Period Specific        1     NaN   MAPE
# 27  Blocking Time Series - Period Specific        1     NaN     R2
#
#     Train Mean  Train Std  Test Mean  Test Std Train Period  \
# 24       1.833        0.0      1.716       0.0      2 years
# 25       1.471        0.0      1.299       0.0      2 years
# 26       0.033        0.0      0.030       0.0      2 years
# 27       0.698        0.0      0.420       0.0      2 years
#
#               Test Period
# 24  10 months and 27 days
# 25  10 months and 27 days
# 26  10 months and 27 days
# 27  10 months and 27 days

# %%
df = df.set_index(["Train Period", "Test Period"])

df[
    (
        df[df["Metric"] == "RMSE"]
        == df[df["Metric"] == "RMSE"][["Test Mean"]].min().values[0]
    )["Test Mean"]
]
# Out:
# /home/felipe/Documents/ccs28-venv/lib/python3.6/site-packages/ipykernel_launcher.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   import sys
#                                                                 Validation  \
# Train Period Test Period
# 2 years      10 months and 27 days  Blocking Time Series - Period Specific
#              10 months and 27 days  Blocking Time Series - Period Specific
#              10 months and 27 days  Blocking Time Series - Period Specific
#              10 months and 27 days  Blocking Time Series - Period Specific
#
#                                     Repeats  Splits Metric  Train Mean  \
# Train Period Test Period
# 2 years      10 months and 27 days        1     NaN   RMSE       1.833
#              10 months and 27 days        1     NaN    MAE       1.471
#              10 months and 27 days        1     NaN   MAPE       0.033
#              10 months and 27 days        1     NaN     R2       0.698
#
#                                     Train Std  Test Mean  Test Std
# Train Period Test Period
# 2 years      10 months and 27 days        0.0      1.716       0.0
#              10 months and 27 days        0.0      1.299       0.0
#              10 months and 27 days        0.0      0.030       0.0
#              10 months and 27 days        0.0      0.420       0.0
