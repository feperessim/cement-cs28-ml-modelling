# %%
# %load_ext nb_black

# %%
import pandas as pd
import os
import glob
import numpy as np

# %%
import warnings

# Suppress specific FutureWarning
warnings.filterwarnings("ignore", category=FutureWarning, module="seaborn._oldcore")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.preprocessing import StandardScaler

# %%
from collections import deque, defaultdict

# %%
def read_csv_files_grouped(csv_files, plant, header=[0, 1]):
    results = []
    for filepath in csv_files:
        df = pd.read_csv(filepath, header=header, low_memory=False)
        df["plant"] = plant  # Add the 'plant' column
        results.append(df)
    df = pd.concat(results, ignore_index=True)
    return df

# %%
def read_csv_files_full(csv_files, plant):
    results = []
    for filepath in csv_files:
        df = pd.read_csv(filepath, low_memory=False)
        df["plant"] = plant  # Add the 'plant' column
        results.append(df)
    df = pd.concat(results, ignore_index=True)
    return df

# %% [markdown]
# ### Renaming the Columns

# %%
def preprocess_rename_columns(df):
    df.columns = pd.MultiIndex.from_tuples(
        list(
            {
                col: (col[0], "") if "Unnamed" in col[1] else col for col in df.columns
            }.values()
        )
    )
    return df

# %% [markdown]
# ### Changing the order_of columns Columns

# %%
def preprocess_change_columns_order(df, column, pos):
    # Get the list of columns
    cols = df.columns.tolist()
    # Remove the specified column
    cols.remove(column)
    # Insert the column at the desired position
    cols.insert(pos, column)
    # Reorder the DataFrame columns
    return df[cols]

# %%
def read_csv_files_path(csv_files_path_dict, path, plant):
    csv_files = glob.glob(os.path.join(path, "*.csv"))
    csv_files_path_dict[plant] = csv_files
    return csv_files_path_dict

# %% [markdown]
# # Topological Analysis - NEW

# %% [markdown]
# ## Definitions

# %%
# Function to compare two models strictly based on means only
def dominates(model1, model2):
    """Return True if model1 strictly dominates model2, False otherwise."""
    # Check if model1 is at least as good as model2 in all metrics
    at_least_as_good = (
        model1["RMSE_mean"] <= model2["RMSE_mean"]
        and model1["MAE_mean"] <= model2["MAE_mean"]
        and model1["MAPE_mean"] <= model2["MAPE_mean"]
        and model1["R2_mean"] >= model2["R2_mean"]
    )

    # Check if model1 is strictly better in at least one metric
    strictly_better_in_one = (
        model1["RMSE_mean"] < model2["RMSE_mean"]
        or model1["MAE_mean"] < model2["MAE_mean"]
        or model1["MAPE_mean"] < model2["MAPE_mean"]
        or model1["R2_mean"] > model2["R2_mean"]
    )

    # Model1 strictly dominates Model2 if it is at least as good in all metrics and
    # strictly better in at least one metric
    return at_least_as_good and strictly_better_in_one

# %%
def get_dominance_matrix_and_graph(df):
    n = len(df)
    dominance_matrix = np.zeros((n, n), dtype=bool)

    for i in range(n):
        for j in range(n):
            if i != j:
                dominance_matrix[i, j] = dominates(df.iloc[i], df.iloc[j])

    # Create the dominance graph
    dominance_graph = {i: [] for i in range(n)}
    for i in range(n):
        for j in range(n):
            if dominance_matrix[i, j]:
                dominance_graph[i].append(j)

    return dominance_matrix, dominance_graph

# %%
# Topological Sorting
def topological_sort(graph):
    """Perform topological sorting on the given graph."""
    in_degree = {u: 0 for u in graph}
    for u in graph:
        for v in graph[u]:
            in_degree[v] += 1

    queue = deque([u for u in graph if in_degree[u] == 0])
    topo_order = []

    while queue:
        u = queue.popleft()
        topo_order.append(u)

        for v in graph[u]:
            in_degree[v] -= 1
            if in_degree[v] == 0:
                queue.append(v)

    return topo_order

# %%
# Function to find the top models in each group
def find_top_models(group):
    max_net_dominance = group["Net_Dominance"].max()
    top_models = group[group["Net_Dominance"] == max_net_dominance]
    return top_models

# %% [markdown]
# ### Dominance Analysis and SCPM

# %%
def compute_scpm(df):
    scaler = StandardScaler()
    standardized_metrics = scaler.fit_transform(
        df[["RMSE_mean", "MAE_mean", "MAPE_mean", "R2_mean"]]
    )

    # Creating a new dataframe with standardized values
    standardized_df = pd.DataFrame(
        standardized_metrics,
        columns=["RMSE_mean", "MAE_mean", "MAPE_mean", "R2_mean"],
    )

    # Summing all metrics and subtracting R2_mean
    standardized_df["Result"] = (
        standardized_df[["RMSE_mean", "MAE_mean", "MAPE_mean"]].sum(axis=1)
        - standardized_df["R2_mean"]
    )

    df["SCPM"] = standardized_df["Result"]
    return df

# %%
def make_dominance_analysis(df):
    # Compute dominance matrix and graph
    dominance_matrix, dominance_graph = get_dominance_matrix_and_graph(df)

    # Get the topological order
    topo_order = topological_sort(dominance_graph)
    df = df.copy()
    n = len(topo_order)

    # Identify Dominant Models
    dominant_models = [
        df["Model_bkp_2"].iloc[i]
        for i in range(len(df))
        if not np.any(dominance_matrix[:, i])
    ]

    # Identify Non-Dominant Models
    non_dominant_models = [
        df["Model_bkp_2"].iloc[i]
        for i in range(len(df))
        if np.any(dominance_matrix[:, i])
    ]

    # Identify Models that are both dominated and dominate at least one
    intermediate_models = [
        df["Model_bkp_2"].iloc[i]
        for i in range(len(df))
        if np.any(dominance_matrix[:, i]) and np.any(dominance_matrix[i, :])
    ]

    # Add count of times each model is dominated by others
    df["Dominated_Count"] = np.sum(dominance_matrix, axis=0)

    # Classify models
    df["Classification"] = "intermediate_model"  # default to intermediate_model
    df.loc[
        ~np.any(dominance_matrix, axis=1) & np.any(dominance_matrix, axis=0),
        "Classification",
    ] = "non_dominant_model"
    df.loc[~np.any(dominance_matrix, axis=0), "Classification"] = "dominant_model"

    # Map the topological order to the model names and get dominance counts
    sorted_models = [df["Model"].iloc[i] for i in topo_order]

    df_sorted = df.iloc[topo_order].copy()
    df_sorted["Dominates_Count"] = dominance_matrix.sum(axis=1)[topo_order]
    df_sorted_topo = df_sorted.copy()

    df_sorted = df_sorted.sort_values(by="Dominates_Count", ascending=False)
    df_sorted_count = df_sorted.copy()

    return {
        "dominance_matrix": dominance_matrix,
        "dominance_graph": dominance_graph,
        "df_sorted_topo": df_sorted_topo,
        "df_sorted_count": df_sorted_count,
    }

# %% [markdown]
# # Pre Training Analysis

# %% [markdown]
# # Reading The files

# %%
csv_files_path_fine_tuning = dict()
csv_files_path_pre_train = dict()

# %% [markdown]
# ## 203

# %% [markdown]
# ### Plant C

# %%
path_pre_train = "/home/peressim/projects/ccs28-ml-modelling/reports/results/global_models/203/c/pre_training/full/"
plant = "c"

csv_files_path_pre_train = read_csv_files_path(
    csv_files_path_pre_train, path_pre_train, plant
)

# %% [markdown]
# ### Plant K

# %%
path_pre_train = "/home/peressim/projects/ccs28-ml-modelling/reports/results/global_models/209/k/pre_training/full/"
plant = "k"

csv_files_path_pre_train = read_csv_files_path(
    csv_files_path_pre_train, path_pre_train, plant
)

# %% [markdown]
# ## 204

# %% [markdown]
# ### Plant AB

# %%
path_pre_train = "/home/peressim/projects/ccs28-ml-modelling/reports/results/global_models/204/ab/pre_training/full/"
plant = "ab"

csv_files_path_pre_train = read_csv_files_path(
    csv_files_path_pre_train, path_pre_train, plant
)

# %% [markdown]
# ### Plant F

# %%
path_pre_train = "/home/peressim/projects/ccs28-ml-modelling/reports/results/global_models/204/f/pre_training/full/"
plant = "f"

csv_files_path_pre_train = read_csv_files_path(
    csv_files_path_pre_train, path_pre_train, plant
)

# %% [markdown]
# ## 206

# %% [markdown]
# ### Plant B

# %%
path_pre_train = "/home/peressim/projects/ccs28-ml-modelling/reports/results/global_models/206/b/pre_training/full/"
plant = "b"

csv_files_path_pre_train = read_csv_files_path(
    csv_files_path_pre_train, path_pre_train, plant
)

# %% [markdown]
# ## 207

# %% [markdown]
# ### Plant AT

# %%
path_pre_train = "/home/peressim/projects/ccs28-ml-modelling/reports/results/global_models/207/at/pre_training/full/"
plant = "at"

csv_files_path_pre_train = read_csv_files_path(
    csv_files_path_pre_train, path_pre_train, plant
)

# %% [markdown]
# ## 209

# %% [markdown]
# ### Plant S

# %%
path_pre_train = "/home/peressim/projects/ccs28-ml-modelling/reports/results/global_models/209/s/pre_training/full/"
plant = "s"

csv_files_path_pre_train = read_csv_files_path(
    csv_files_path_pre_train, path_pre_train, plant
)

# %% [markdown]
# ### Plant AM

# %%
path_pre_train = "/home/peressim/projects/ccs28-ml-modelling/reports/results/global_models/209/am/pre_training/full/"
plant = "am"

csv_files_path_pre_train = read_csv_files_path(
    csv_files_path_pre_train, path_pre_train, plant
)

# %% [markdown]
# ### Plant W

# %%
path_pre_train = "/home/peressim/projects/ccs28-ml-modelling/reports/results/global_models/209/w/pre_training/full/"
plant = "w"

csv_files_path_pre_train = read_csv_files_path(
    csv_files_path_pre_train, path_pre_train, plant
)

# %% [markdown]
# ### Plant K

# %%
path_pre_train = "/home/peressim/projects/ccs28-ml-modelling/reports/results/global_models/209/k/pre_training/full/"
plant = "k"

csv_files_path_pre_train = read_csv_files_path(
    csv_files_path_pre_train, path_pre_train, plant
)

# %% [markdown]
# ### Reading all data - pre training

# %% [markdown]
# #### Full

# %%
dfs_plant = dict()
column = ("plant", "")
pos = 2

for plant, csv_files in csv_files_path_pre_train.items():
    df = read_csv_files_full(csv_files, plant)
    df["plant"] = plant
    dfs_plant[plant] = df

# %%
df_pre_train = pd.concat(dfs_plant.values(), ignore_index=True)

# %%
df_pre_train.shape
# Out:
# (1533, 23)

# %% [markdown]
# ## Preprocessing

# %%
patterns = [
    "Chemical + Mineralogical + Feature Engineering",
    "Chemical + Mineralogical + CS7 + One-Hot",
    "Chemical + Mineralogical + Physical + One-Hot",
    "Chemical + Mineralogical + CS3 + One-Hot",
    "Chemical + Mineralogical + CS3 + CS7 + One-Hot",
    "Chemical + Mineralogical + One-Hot",
    "Chemical + Mineralogical + CS1 + CS3 + CS7 + One-Hot",
    "Chemical + Mineralogical + CS1 + CS3 + One-Hot",
    "Chemical + Mineralogical + CS1 + One-Hot",
    "Chemical + Mineralogical + CS2 + One-Hot",
    "Chemical + Feature Engineering",
]

FEATURES_TO_REPLACE_1 = {
    "Chemical + Mineralogical + CS3 + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS3": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS1": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS1 + CS3": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS1 + CS3 + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS2": "Chemical + Mineralogical + Early CS",
    "Chemical + CS1 + CS3 + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + CS3 + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + CS3": "Chemical + Mineralogical + Early CS",
    "Chemical + CS1 + CS3": "Chemical + Mineralogical + Early CS",
    "Chemical + CS1": "Chemical + Mineralogical + Early CS",
    "Chemical + CS1 + CS7": "Chemical + Mineralogical + Early CS",
}

FEATURES_TO_REPLACE_2 = {
    "Chemical": "Chemical + Mineralogical",
    "Chemical + Properties CS Less": "Chemical + Mineralogical + Physical - Early CS",
    "Chemical + Mineralogical + Properties CS Less": "Chemical + Mineralogical + Physical - Early CS",
    "Chemical + Physical": "Chemical + Mineralogical + Physical",
}

df_pre_train = df_pre_train[
    ~df_pre_train["Features"].apply(lambda x: x in patterns)
].reset_index(drop=True)

df_pre_train = df_pre_train[
    ~df_pre_train["Cross Validation"].eq("Out of time Split")
].reset_index(drop=True)

# removing afterwards
df_pre_train = df_pre_train[
    ~df_pre_train["Cross Validation"].eq("Repeated KFold")
].reset_index(drop=True)

df_pre_train["Features_bkp"] = df_pre_train["Features"].copy()
df_pre_train["Features"] = df_pre_train["Features"].replace(FEATURES_TO_REPLACE_1)

df_pre_train["Features"] = df_pre_train["Features"].replace(FEATURES_TO_REPLACE_2)


# removing afterwards
# df_pre_train = df_pre_train[
#     ~df_pre_train["Features"].eq("Chemical + Mineralogical + Early CS")
# ].reset_index(drop=True)

metrics_names = {
    "RMSE Test": "RMSE_mean",
    "MAE Test": "MAE_mean",
    "MAPE Test": "MAPE_mean",
    "R2 Test": "R2_mean",
}

df_pre_train = df_pre_train.rename(metrics_names, axis=1)

# %%
# Ensuring only the results of the best selected plants will be taken into account

cm = df_pre_train["Features"].eq("Chemical + Mineralogical")
cmp = df_pre_train["Features"].eq("Chemical + Mineralogical + Physical - Early CS")
cmpcs = df_pre_train["Features"].eq("Chemical + Mineralogical + Physical")

fs = df_pre_train["plant"].eq("s")
fab = df_pre_train["plant"].eq("ab")
ff = df_pre_train["plant"].eq("f")
fam = df_pre_train["plant"].eq("am")
fw = df_pre_train["plant"].eq("w")
fk = df_pre_train["plant"].eq("k")

fc = df_pre_train["plant"].eq("c")
fb = df_pre_train["plant"].eq("b")
fat = df_pre_train["plant"].eq("at")

f_final = (
    (cm & (fs | fc | fab | fb | fat | ff))
    | (cmp & (fam | fc | ff | fb | fat | fw))
    | (cmpcs & (fs | fk | fc | ff | fb | fat | fab))
)
df_pre_train = df_pre_train[f_final].reset_index(drop=True)

# %%
df_pre_train["Cross Validation"].unique()
# Out:
# array(['Out of time'], dtype=object)

# %%
df_pre_train["Features"].unique()
# Out:
# array(['Chemical + Mineralogical + Physical - Early CS',
#        'Chemical + Mineralogical + Physical', 'Chemical + Mineralogical'],
#       dtype=object)

# %%
df_pre_train["MAPE Train"] = df_pre_train["MAPE Train"] * 100
df_pre_train["MAPE_mean"] = df_pre_train["MAPE_mean"] * 100

df_pre_train["Model_bkp"] = df_pre_train["Model"].copy()
df_pre_train["Model_bkp_2"] = df_pre_train["Model"].apply(
    lambda x: "" if pd.isna(x) else "_" + str(x)
)

# %%
df_pre_train["Model_bkp_2"] = df_pre_train["Model_bkp_2"].apply(
    lambda x: "MLP"
    if "MLP" in x
    else "Bi-LSTM"
    if "Bi-LSTM" in x
    else "LSTM"
    if "LSTM" in x
    else "Conv1D"
    if "Conv1D" in x
    else "Transformer"
)

# %%
df_pre_train["Cross Validation"].unique()
# Out:
# array(['Out of time'], dtype=object)

# %%
df_pre_train["Features"].unique()
# Out:
# array(['Chemical + Mineralogical + Physical - Early CS',
#        'Chemical + Mineralogical + Physical', 'Chemical + Mineralogical'],
#       dtype=object)

# %%
df_pre_train["Features_bkp"].unique()
# Out:
# array(['Chemical + Properties CS Less', 'Chemical + Physical', 'Chemical'],
#       dtype=object)

# %%
df_pre_train.shape
# Out:
# (1387, 26)

# %%
df_pre_train[df_pre_train["Plant"].eq("F")]["Features"].unique()
# Out:
# array(['Chemical + Mineralogical + Physical - Early CS',
#        'Chemical + Mineralogical + Physical', 'Chemical + Mineralogical'],
#       dtype=object)

# %%
df_pre_train["Features"].unique()
# Out:
# array(['Chemical + Mineralogical + Physical - Early CS',
#        'Chemical + Mineralogical + Physical', 'Chemical + Mineralogical'],
#       dtype=object)

# %%
df_pre_train["Plant"].value_counts()
# Out:
# Plant
# C     219
# F     219
# B     219
# AT    219
# AB    146
# S     146
# K      73
# AM     73
# W      73
# Name: count, dtype: int64

# %%
df_pre_train.shape
# Out:
# (1387, 26)

# %% [markdown]
# # Global Analysis (pre train results)

# %% [markdown]
# ## ECICS

# %% [markdown]
# ### Variable Grouping: CM

# %% [markdown]
# #### Analysis of the best models identified in the Local Analysis

# %% [markdown]
# **Best models for variable groupping CM were from:**
#
# *BTiSS:*
#     Dominance analysis: Plant S
#     SCPM:Plant S
#
# *TiSS:*
#     Dominance analysis: Plant S
#     SCPM:Plant S

# %%
df_results_cm = (
    df_pre_train[df_pre_train["Features"].eq("Chemical + Mineralogical")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm["Features"].unique()
# Out:
# array(['Chemical + Mineralogical'], dtype=object)

# %%
df_results_cm.shape
# Out:
# (438, 26)

# %% [markdown]
# #### Hold Out

# %%
df_results_cm["Cross Validation"].unique()
# Out:
# array(['Out of time'], dtype=object)

# %%
df_results_cm_ho = (
    df_results_cm[df_results_cm["Cross Validation"].eq("Out of time")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_ho["Cross Validation"].unique()
# Out:
# array(['Out of time'], dtype=object)

# %%
df_results_cm_ho.shape
# Out:
# (438, 26)

# %% [markdown]
# ###### SCPM computation

# %%
df_results_cm_ho = compute_scpm(df_results_cm_ho)

# %% [markdown]
# ##### Dominance Analysis

# %%
dominance_dict = make_dominance_analysis(df_results_cm_ho)
dominance_matrix_cm_ho = dominance_dict["dominance_matrix"]
dominance_graph_cm_ho = dominance_dict["dominance_graph"]
df_sorted_count = dominance_dict["df_sorted_count"]
df_sorted_topo = dominance_dict["df_sorted_topo"]

# %%
dominance_matrix_cm_ho.shape, len(dominance_graph_cm_ho)
# Out:
# ((438, 438), 438)

# %%
df_sorted_topo["Classification"].value_counts()
# Out:
# Classification
# intermediate_model    435
# dominant_model          2
# non_dominant_model      1
# Name: count, dtype: int64

# %%
df_sorted_topo.head(5)
# Out:
#          Category  Company Plant                  Features   Data Shape  \
# 330  Global Model      207    AT  Chemical + Mineralogical  (62749, 12)
# 334  Global Model      207    AT  Chemical + Mineralogical  (62749, 12)
# 309  Global Model      207    AT  Chemical + Mineralogical  (62749, 12)
# 313  Global Model      207    AT  Chemical + Mineralogical  (62749, 12)
# 315  Global Model      207    AT  Chemical + Mineralogical  (62749, 12)
#
#      Timesteps      Model  Model Params           Scaler  Scaler Params  ...  \
# 330        7.0  Bi-LSTM11           NaN  Standard Scaler            NaN  ...
# 334       14.0  Bi-LSTM15           NaN  Standard Scaler            NaN  ...
# 309        7.0      LSTM5           NaN  Standard Scaler            NaN  ...
# 313       14.0      LSTM9           NaN  Standard Scaler            NaN  ...
# 315        7.0     LSTM11           NaN  Standard Scaler            NaN  ...
#
#     MAPE_mean   R2_mean plant Features_bkp  Model_bkp  Model_bkp_2      SCPM  \
# 330  4.101545  0.845872    at     Chemical  Bi-LSTM11      Bi-LSTM -1.006033
# 334  4.142043  0.853383    at     Chemical  Bi-LSTM15      Bi-LSTM -1.023931
# 309  4.139438  0.844656    at     Chemical      LSTM5         LSTM -0.986891
# 313  4.171853  0.848335    at     Chemical      LSTM9         LSTM -0.991743
# 315  4.250362  0.849726    at     Chemical     LSTM11         LSTM -0.976181
#
#      Dominated_Count      Classification  Dominates_Count
# 330                0      dominant_model              431
# 334                0      dominant_model              435
# 309                1  intermediate_model              429
# 313                1  intermediate_model              432
# 315                1  intermediate_model              428
#
# [5 rows x 30 columns]

# %%
df_sorted_topo_cols = df_sorted_topo[
    [
        "Model",
        # "Model_bkp",
        # "Model_bkp_2",
        "Timesteps",
        "RMSE_mean",
        "MAE_mean",
        "MAPE_mean",
        "R2_mean",
        "SCPM",
        "Dominated_Count",
        "Classification",
        "Dominates_Count",
        "Plant",
    ]
].round(2)

# %% [markdown]
# ##### Top dominant models

# %%
# Top 4
df_sorted_topo_cols.sort_values(by="Dominates_Count", ascending=False).iloc[0:3]
# Out:
#          Model  Timesteps  RMSE_mean  MAE_mean  MAPE_mean  R2_mean  SCPM  \
# 334  Bi-LSTM15       14.0       2.33      1.77       4.14     0.85 -1.02
# 313      LSTM9       14.0       2.37      1.79       4.17     0.85 -0.99
# 330  Bi-LSTM11        7.0       2.39      1.76       4.10     0.85 -1.01
#
#      Dominated_Count      Classification  Dominates_Count Plant
# 334                0      dominant_model              435    AT
# 313                1  intermediate_model              432    AT
# 330                0      dominant_model              431    AT

# %% [markdown]
# ##### Top intermediate models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].sort_values(by="Dominates_Count", ascending=False).iloc[:2]
# Out:
#      Model  Timesteps  RMSE_mean  MAE_mean  MAPE_mean  R2_mean  SCPM  \
# 313  LSTM9       14.0       2.37      1.79       4.17     0.85 -0.99
# 309  LSTM5        7.0       2.40      1.78       4.14     0.84 -0.99
#
#      Dominated_Count      Classification  Dominates_Count Plant
# 313                1  intermediate_model              432    AT
# 309                1  intermediate_model              429    AT

# %% [markdown]
# ##### Top non dominant models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].sort_values(by="Dominated_Count", ascending=True).iloc[:2]
# Out:
#          Model  Timesteps  RMSE_mean  MAE_mean  MAPE_mean  R2_mean   SCPM  \
# 258  Bi-LSTM12       14.0      36.27     35.77      82.27   -35.29  56.36
#
#      Dominated_Count      Classification  Dominates_Count Plant
# 258              437  non_dominant_model                0     B

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        # "Model",
        # "Model_bkp",
        "Model_bkp_2",
        "Timesteps",
        "RMSE_mean",
        "MAE_mean",
        "MAPE_mean",
        "R2_mean",
        "SCPM",
        "Dominated_Count",
        "Classification",
        "Dominates_Count",
        "Plant",
    ]
]  # .round(2)

# %%
df_sorted_topo["Model_bkp_2"].value_counts()
# Out:
# Model_bkp_2
# Bi-LSTM        90
# LSTM           90
# Conv1D         90
# Transformer    90
# MLP            78
# Name: count, dtype: int64

# %%
df_sorted_topo_models_grouped = (
    df_sorted_topo_models_cols.groupby("Model_bkp_2").describe().T
)

# %%
# pd.set_option("display.max_rows", None)
# df_sorted_topo_models_grouped

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model_bkp_2",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
    ]
]

# %%
df_sorted_topo_models_cols.groupby("Model_bkp_2").describe().round(2)
# Out:
#             Dominated_Count                                               \
#                       count    mean     std    min     25%    50%    75%
# Model_bkp_2
# Bi-LSTM                90.0  181.42  146.35    0.0   41.25  184.0  321.5
# Conv1D                 90.0  161.40   98.11    4.0   77.25  158.5  233.0
# LSTM                   90.0  157.47  127.32    1.0   42.00  133.5  263.0
# MLP                    78.0  158.83  109.95    7.0   61.50  137.0  257.5
# Transformer            90.0  316.63   67.52  201.0  259.00  304.5  380.5
#
#                    Dominates_Count                                       \
#                max           count    mean     std   min     25%    50%
# Model_bkp_2
# Bi-LSTM      437.0            90.0  220.16  141.95   0.0   75.00  220.0
# Conv1D       392.0            90.0  231.43   94.02  22.0  172.00  232.0
# LSTM         419.0            90.0  236.16  121.70  17.0  127.75  254.0
# MLP          360.0            78.0  219.21  100.03  43.0  119.50  252.0
# Transformer  431.0            90.0   76.86   50.52   4.0   27.50   83.5
#
#
#                 75%    max
# Model_bkp_2
# Bi-LSTM      329.00  435.0
# Conv1D       301.00  423.0
# LSTM         335.50  432.0
# MLP          293.50  390.0
# Transformer  113.75  195.0

# %%
df_sorted_topo_models_cols.groupby("Model_bkp_2")["Classification"].describe()
# Out:
#             count unique                 top freq
# Model_bkp_2
# Bi-LSTM        90      3  intermediate_model   87
# Conv1D         90      1  intermediate_model   90
# LSTM           90      1  intermediate_model   90
# MLP            78      1  intermediate_model   78
# Transformer    90      1  intermediate_model   90

# %%
df_sorted_topo_models_cols.groupby("Model_bkp_2")[["Classification"]].value_counts()
# Out:
# Model_bkp_2  Classification
# Bi-LSTM      intermediate_model    87
#              dominant_model         2
#              non_dominant_model     1
# Conv1D       intermediate_model    90
# LSTM         intermediate_model    90
# MLP          intermediate_model    78
# Transformer  intermediate_model    90
# Name: count, dtype: int64

# %%
(
    df_sorted_topo_models_cols.groupby("Model_bkp_2")[["Classification"]]
    .value_counts(normalize=True)
    .to_frame()
    * 100
).round(2)
# Out:
#                                 proportion
# Model_bkp_2 Classification
# Bi-LSTM     intermediate_model       96.67
#             dominant_model            2.22
#             non_dominant_model        1.11
# Conv1D      intermediate_model      100.00
# LSTM        intermediate_model      100.00
# MLP         intermediate_model      100.00
# Transformer intermediate_model      100.00

# %%
df_sorted_topo_models_cols
# Out:
#     Model_bkp_2  Dominated_Count  Dominates_Count      Classification
# 330     Bi-LSTM                0              431      dominant_model
# 334     Bi-LSTM                0              435      dominant_model
# 309        LSTM                1              429  intermediate_model
# 313        LSTM                1              432  intermediate_model
# 315        LSTM                1              428  intermediate_model
# ..          ...              ...              ...                 ...
# 112     Bi-LSTM              432                4  intermediate_model
# 109     Bi-LSTM              434                3  intermediate_model
# 39      Bi-LSTM              435                2  intermediate_model
# 331     Bi-LSTM              436                1  intermediate_model
# 258     Bi-LSTM              437                0  non_dominant_model
#
# [438 rows x 4 columns]

# %%
summary_stats = df_sorted_topo_models_cols.groupby("Model_bkp_2").agg(
    Total_Models=("Model_bkp_2", "count"),
    Mean_Dominance_Count=("Dominates_Count", "mean"),
    Median_Dominance_Count=("Dominates_Count", "median"),
    Total_Dominated=("Dominated_Count", "sum"),
    Total_Dominating=("Dominates_Count", "sum"),
)

total_models = summary_stats[
    "Total_Models"
].sum()  # Get the total number of models across all categories
summary_stats["Dominance Proportion"] = summary_stats["Total_Dominating"] / total_models

# %%
summary_stats
# Out:
#              Total_Models  Mean_Dominance_Count  Median_Dominance_Count  \
# Model_bkp_2
# Bi-LSTM                90            220.155556                   220.0
# Conv1D                 90            231.433333                   232.0
# LSTM                   90            236.155556                   254.0
# MLP                    78            219.205128                   252.0
# Transformer            90             76.855556                    83.5
#
#              Total_Dominated  Total_Dominating  Dominance Proportion
# Model_bkp_2
# Bi-LSTM                16328             19814             45.237443
# Conv1D                 14526             20829             47.554795
# LSTM                   14172             21254             48.525114
# MLP                    12389             17098             39.036530
# Transformer            28497              6917             15.792237

# %%
df_sorted_topo_models_grouped.T
# Out:
#             Timesteps                                                 \
#                 count      mean       std  min  25%  50%   75%   max
# Model_bkp_2
# Bi-LSTM          90.0  7.333333  5.342221  1.0  1.0  7.0  14.0  14.0
# Conv1D           90.0  7.333333  5.342221  1.0  1.0  7.0  14.0  14.0
# LSTM             90.0  7.333333  5.342221  1.0  1.0  7.0  14.0  14.0
# MLP               0.0       NaN       NaN  NaN  NaN  NaN   NaN   NaN
# Transformer      90.0  7.333333  5.342221  1.0  1.0  7.0  14.0  14.0
#
#             RMSE_mean            ... Dominated_Count        Dominates_Count  \
#                 count      mean  ...             75%    max           count
# Model_bkp_2                      ...
# Bi-LSTM          90.0  3.938663  ...           321.5  437.0            90.0
# Conv1D           90.0  2.822161  ...           233.0  392.0            90.0
# LSTM             90.0  2.847826  ...           263.0  419.0            90.0
# MLP              78.0  2.907567  ...           257.5  360.0            78.0
# Transformer      90.0  3.300154  ...           380.5  431.0            90.0
#
#
#                    mean         std   min     25%    50%     75%    max
# Model_bkp_2
# Bi-LSTM      220.155556  141.947364   0.0   75.00  220.0  329.00  435.0
# Conv1D       231.433333   94.024626  22.0  172.00  232.0  301.00  423.0
# LSTM         236.155556  121.698089  17.0  127.75  254.0  335.50  432.0
# MLP          219.205128  100.029653  43.0  119.50  252.0  293.50  390.0
# Transformer   76.855556   50.522564   4.0   27.50   83.5  113.75  195.0
#
# [5 rows x 64 columns]

# %% [markdown]
# ### SCPM Analysis

# %%
cols = [
    "Model",
    # "Model_bkp",
    "Model_bkp_2",
    "Timesteps",
    "RMSE_mean",
    "MAE_mean",
    "MAPE_mean",
    "R2_mean",
    "SCPM",
    "Dominated_Count",
    "Dominates_Count",
    "Classification",
    "Plant",
]

# %%
df_sorted_scpm = df_sorted_topo.sort_values(by="SCPM").copy()

# %%
# (df_sorted_topo[cols].reset_index() == df_sorted_scpm[cols].reset_index()).all(axis=1)
df_sorted_scpm["topo_scmp_order_eq"] = df_sorted_topo.index == df_sorted_scpm.index

# %%
# df_sorted_topo[cols].round(2).head(5)

# %%
df_sorted_scpm[cols + ["topo_scmp_order_eq"]].round(2).head(7)
# Out:
#          Model Model_bkp_2  Timesteps  RMSE_mean  MAE_mean  MAPE_mean  \
# 334  Bi-LSTM15     Bi-LSTM       14.0       2.33      1.77       4.14
# 330  Bi-LSTM11     Bi-LSTM        7.0       2.39      1.76       4.10
# 313      LSTM9        LSTM       14.0       2.37      1.79       4.17
# 309      LSTM5        LSTM        7.0       2.40      1.78       4.14
# 315     LSTM11        LSTM        7.0       2.36      1.80       4.25
# 32    Bi-LSTM5     Bi-LSTM        7.0       2.39      1.79       4.20
# 321   Bi-LSTM2     Bi-LSTM        7.0       2.36      1.80       4.27
#
#      R2_mean  SCPM  Dominated_Count  Dominates_Count      Classification  \
# 334     0.85 -1.02                0              435      dominant_model
# 330     0.85 -1.01                0              431      dominant_model
# 313     0.85 -0.99                1              432  intermediate_model
# 309     0.84 -0.99                1              429  intermediate_model
# 315     0.85 -0.98                1              428  intermediate_model
# 32      0.84 -0.98                2              426  intermediate_model
# 321     0.85 -0.98                1              427  intermediate_model
#
#     Plant  topo_scmp_order_eq
# 334    AT               False
# 330    AT               False
# 313    AT               False
# 309    AT               False
# 315    AT                True
# 32      C               False
# 321    AT               False

# %%
df_sorted_scpm[cols + ["topo_scmp_order_eq"]].head(1)
# Out:
#          Model Model_bkp_2  Timesteps  RMSE_mean  MAE_mean  MAPE_mean  \
# 334  Bi-LSTM15     Bi-LSTM       14.0   2.334487   1.76689   4.142043
#
#       R2_mean      SCPM  Dominated_Count  Dominates_Count  Classification  \
# 334  0.853383 -1.023931                0              435  dominant_model
#
#     Plant  topo_scmp_order_eq
# 334    AT               False

# %% [markdown]
# ### Variable Grouping: CM-P

# %% [markdown]
# #### Analysis of the best models identified in the Local Analysis

# %% [markdown]
# **Best models for variable groupping CM-P were from:**
#
# *BTiSS:*
#     Dominance analysis: Plant AM
#     SCPM:Plant AM
#
# *TiSS:*
#     Dominance analysis: Plant W
#     SCPM:Plant W

# %%
df_pre_train["Features"].unique()
# Out:
# array(['Chemical + Mineralogical + Physical - Early CS',
#        'Chemical + Mineralogical + Physical', 'Chemical + Mineralogical'],
#       dtype=object)

# %%
df_results_cm_p = (
    df_pre_train[
        df_pre_train["Features"].eq("Chemical + Mineralogical + Physical - Early CS")
    ]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_p.shape
# Out:
# (438, 26)

# %% [markdown]
# #### Hold Out

# %%
df_results_cm_p["Cross Validation"].unique()
# Out:
# array(['Out of time'], dtype=object)

# %%
df_results_cm_p_ho = (
    df_results_cm_p[df_results_cm_p["Cross Validation"].eq("Out of time")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_p_ho["Cross Validation"].unique()
# Out:
# array(['Out of time'], dtype=object)

# %%
df_results_cm_p_ho.shape
# Out:
# (438, 26)

# %% [markdown]
# ###### SCPM computation

# %%
df_results_cm_p_ho = compute_scpm(df_results_cm_p_ho)

# %% [markdown]
# ##### Dominance Analysis

# %%
dominance_dict = make_dominance_analysis(df_results_cm_p_ho)
dominance_matrix_cm_p_am_ho = dominance_dict["dominance_matrix"]
dominance_graph_cm_p_am_ho = dominance_dict["dominance_graph"]
df_sorted_count = dominance_dict["df_sorted_count"]
df_sorted_topo = dominance_dict["df_sorted_topo"]

# %%
dominance_matrix_cm_p_am_ho.shape, len(dominance_graph_cm_p_am_ho)
# Out:
# ((438, 438), 438)

# %%
df_sorted_topo["Classification"].value_counts()
# Out:
# Classification
# intermediate_model    435
# dominant_model          2
# non_dominant_model      1
# Name: count, dtype: int64

# %%
# df_sorted_topo.to_csv(
#     "../../../../reports/results/local_models/ecics/ecics_dominance_analysis_cm_kf.csv",
#     index=False,
# )

# %%
df_sorted_topo.head(5)
# Out:
#          Category  Company Plant  \
# 285  Global Model      207    AT
# 289  Global Model      207    AT
# 288  Global Model      207    AT
# 290  Global Model      207    AT
# 284  Global Model      207    AT
#
#                                            Features   Data Shape  Timesteps  \
# 285  Chemical + Mineralogical + Physical - Early CS  (62749, 16)        NaN
# 289  Chemical + Mineralogical + Physical - Early CS  (62749, 16)        NaN
# 288  Chemical + Mineralogical + Physical - Early CS  (62749, 16)        NaN
# 290  Chemical + Mineralogical + Physical - Early CS  (62749, 16)        NaN
# 284  Chemical + Mineralogical + Physical - Early CS  (62749, 16)        NaN
#
#       Model  Model Params           Scaler  Scaler Params  ... MAPE_mean  \
# 285   MLP_7           NaN  Standard Scaler            NaN  ...  3.514956
# 289  MLP_11           NaN  Standard Scaler            NaN  ...  3.517973
# 288  MLP_10           NaN  Standard Scaler            NaN  ...  3.535726
# 290  MLP_12           NaN  Standard Scaler            NaN  ...  3.635425
# 284   MLP_6           NaN  Standard Scaler            NaN  ...  3.616965
#
#       R2_mean plant                   Features_bkp  Model_bkp  Model_bkp_2  \
# 285  0.891546    at  Chemical + Properties CS Less      MLP_7          MLP
# 289  0.893385    at  Chemical + Properties CS Less     MLP_11          MLP
# 288  0.885287    at  Chemical + Properties CS Less     MLP_10          MLP
# 290  0.887517    at  Chemical + Properties CS Less     MLP_12          MLP
# 284  0.885106    at  Chemical + Properties CS Less      MLP_6          MLP
#
#          SCPM  Dominated_Count      Classification  Dominates_Count
# 285 -1.776500                0      dominant_model              436
# 289 -1.784692                0      dominant_model              436
# 288 -1.741880                2  intermediate_model              434
# 290 -1.723327                2  intermediate_model              432
# 284 -1.719407                3  intermediate_model              433
#
# [5 rows x 30 columns]

# %%
df_sorted_topo_cols = df_sorted_topo[
    [
        "Model",
        # "Model_bkp",
        # "Model_bkp_2",
        "Timesteps",
        "RMSE_mean",
        "MAE_mean",
        "MAPE_mean",
        "R2_mean",
        "SCPM",
        "Dominated_Count",
        "Classification",
        "Dominates_Count",
        "Plant",
    ]
].round(2)

# %% [markdown]
# ##### Top dominant models

# %%
# Top 4
df_sorted_topo_cols.sort_values(by="Dominates_Count", ascending=False).iloc[0:3]
# Out:
#       Model  Timesteps  RMSE_mean  MAE_mean  MAPE_mean  R2_mean  SCPM  \
# 285   MLP_7        NaN       2.01      1.49       3.51     0.89 -1.78
# 289  MLP_11        NaN       1.99      1.49       3.52     0.89 -1.78
# 288  MLP_10        NaN       2.06      1.51       3.54     0.89 -1.74
#
#      Dominated_Count      Classification  Dominates_Count Plant
# 285                0      dominant_model              436    AT
# 289                0      dominant_model              436    AT
# 288                2  intermediate_model              434    AT

# %% [markdown]
# ##### Top intermediate models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].sort_values(by="Dominates_Count", ascending=False).iloc[:2]
# Out:
#       Model  Timesteps  RMSE_mean  MAE_mean  MAPE_mean  R2_mean  SCPM  \
# 288  MLP_10        NaN       2.06      1.51       3.54     0.89 -1.74
# 284   MLP_6        NaN       2.07      1.54       3.62     0.89 -1.72
#
#      Dominated_Count      Classification  Dominates_Count Plant
# 288                2  intermediate_model              434    AT
# 284                3  intermediate_model              433    AT

# %% [markdown]
# ##### Top non dominant models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].sort_values(by="Dominated_Count", ascending=True).iloc[:2]
# Out:
#         Model  Timesteps  RMSE_mean  MAE_mean  MAPE_mean  R2_mean  SCPM  \
# 178  Bi-LSTM3       14.0      33.06     32.51      74.59   -29.15  46.3
#
#      Dominated_Count      Classification  Dominates_Count Plant
# 178              437  non_dominant_model                0     B

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        # "Model",
        # "Model_bkp",
        "Model_bkp_2",
        "Timesteps",
        "RMSE_mean",
        "MAE_mean",
        "MAPE_mean",
        "R2_mean",
        "SCPM",
        "Dominated_Count",
        "Classification",
        "Dominates_Count",
        "Plant",
    ]
]  # .round(2)

# %%
df_sorted_topo["Model_bkp_2"].value_counts()
# Out:
# Model_bkp_2
# Conv1D         90
# Bi-LSTM        90
# LSTM           90
# Transformer    90
# MLP            78
# Name: count, dtype: int64

# %%
df_sorted_topo_models_grouped = (
    df_sorted_topo_models_cols.groupby("Model_bkp_2").describe().T
)

# %%
# pd.set_option("display.max_rows", None)
# df_sorted_topo_models_grouped

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model_bkp_2",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
    ]
]

# %%
df_sorted_topo_models_cols.groupby("Model_bkp_2").describe().round(2)
# Out:
#             Dominated_Count                                               \
#                       count    mean    std    min     25%    50%     75%
# Model_bkp_2
# Bi-LSTM                90.0  302.58  93.97   76.0  227.50  295.0  388.50
# Conv1D                 90.0  127.69  60.01   39.0   94.00  119.5  148.00
# LSTM                   90.0  284.70  92.67   93.0  201.75  287.5  362.50
# MLP                    78.0   31.77  22.16    0.0   13.25   28.0   50.00
# Transformer            90.0  277.10  69.02  145.0  226.75  275.0  323.75
#
#                    Dominates_Count                                       \
#                max           count    mean    std    min     25%    50%
# Model_bkp_2
# Bi-LSTM      437.0            90.0  118.02  86.63    0.0   40.00  113.0
# Conv1D       402.0            90.0  291.39  59.35   28.0  269.25  304.0
# LSTM         422.0            90.0  134.82  87.04    9.0   63.25  121.5
# MLP           81.0            78.0  388.28  26.43  336.0  369.25  384.0
# Transformer  430.0            90.0  138.86  63.41    6.0   99.00  137.0
#
#
#                 75%    max
# Model_bkp_2
# Bi-LSTM      188.50  340.0
# Conv1D       326.50  363.0
# LSTM         212.00  319.0
# MLP          408.75  436.0
# Transformer  180.50  281.0

# %%
df_sorted_topo_models_cols.groupby("Model_bkp_2")["Classification"].describe()
# Out:
#             count unique                 top freq
# Model_bkp_2
# Bi-LSTM        90      2  intermediate_model   89
# Conv1D         90      1  intermediate_model   90
# LSTM           90      1  intermediate_model   90
# MLP            78      2  intermediate_model   76
# Transformer    90      1  intermediate_model   90

# %%
df_sorted_topo_models_cols.groupby("Model_bkp_2")[["Classification"]].value_counts()
# Out:
# Model_bkp_2  Classification
# Bi-LSTM      intermediate_model    89
#              non_dominant_model     1
# Conv1D       intermediate_model    90
# LSTM         intermediate_model    90
# MLP          intermediate_model    76
#              dominant_model         2
# Transformer  intermediate_model    90
# Name: count, dtype: int64

# %%
(
    df_sorted_topo_models_cols.groupby("Model_bkp_2")[["Classification"]]
    .value_counts(normalize=True)
    .to_frame()
    * 100
).round(2)
# Out:
#                                 proportion
# Model_bkp_2 Classification
# Bi-LSTM     intermediate_model       98.89
#             non_dominant_model        1.11
# Conv1D      intermediate_model      100.00
# LSTM        intermediate_model      100.00
# MLP         intermediate_model       97.44
#             dominant_model            2.56
# Transformer intermediate_model      100.00

# %%
df_sorted_topo_models_cols
# Out:
#     Model_bkp_2  Dominated_Count  Dominates_Count      Classification
# 285         MLP                0              436      dominant_model
# 289         MLP                0              436      dominant_model
# 288         MLP                2              434  intermediate_model
# 290         MLP                2              432  intermediate_model
# 284         MLP                3              433  intermediate_model
# ..          ...              ...              ...                 ...
# 257     Bi-LSTM              433                4  intermediate_model
# 41      Bi-LSTM              434                3  intermediate_model
# 332     Bi-LSTM              435                2  intermediate_model
# 111     Bi-LSTM              436                1  intermediate_model
# 178     Bi-LSTM              437                0  non_dominant_model
#
# [438 rows x 4 columns]

# %%
summary_stats = df_sorted_topo_models_cols.groupby("Model_bkp_2").agg(
    Total_Models=("Model_bkp_2", "count"),
    Mean_Dominance_Count=("Dominates_Count", "mean"),
    Median_Dominance_Count=("Dominates_Count", "median"),
    Total_Dominated=("Dominated_Count", "sum"),
    Total_Dominating=("Dominates_Count", "sum"),
)

total_models = summary_stats[
    "Total_Models"
].sum()  # Get the total number of models across all categories
summary_stats["Dominance Proportion"] = summary_stats["Total_Dominating"] / total_models

# %%
summary_stats
# Out:
#              Total_Models  Mean_Dominance_Count  Median_Dominance_Count  \
# Model_bkp_2
# Bi-LSTM                90            118.022222                   113.0
# Conv1D                 90            291.388889                   304.0
# LSTM                   90            134.822222                   121.5
# MLP                    78            388.282051                   384.0
# Transformer            90            138.855556                   137.0
#
#              Total_Dominated  Total_Dominating  Dominance Proportion
# Model_bkp_2
# Bi-LSTM                27232             10622             24.251142
# Conv1D                 11492             26225             59.874429
# LSTM                   25623             12134             27.703196
# MLP                     2478             30286             69.146119
# Transformer            24939             12497             28.531963

# %%
df_sorted_topo_models_grouped.T
# Out:
#             Timesteps                                                 \
#                 count      mean       std  min  25%  50%   75%   max
# Model_bkp_2
# Bi-LSTM          90.0  7.333333  5.342221  1.0  1.0  7.0  14.0  14.0
# Conv1D           90.0  7.333333  5.342221  1.0  1.0  7.0  14.0  14.0
# LSTM             90.0  7.333333  5.342221  1.0  1.0  7.0  14.0  14.0
# MLP               0.0       NaN       NaN  NaN  NaN  NaN   NaN   NaN
# Transformer      90.0  7.333333  5.342221  1.0  1.0  7.0  14.0  14.0
#
#             RMSE_mean            ... Dominated_Count        Dominates_Count  \
#                 count      mean  ...             75%    max           count
# Model_bkp_2                      ...
# Bi-LSTM          90.0  5.181954  ...          388.50  437.0            90.0
# Conv1D           90.0  2.709816  ...          148.00  402.0            90.0
# LSTM             90.0  3.797851  ...          362.50  422.0            90.0
# MLP              78.0  2.286617  ...           50.00   81.0            78.0
# Transformer      90.0  3.543584  ...          323.75  430.0            90.0
#
#
#                    mean        std    min     25%    50%     75%    max
# Model_bkp_2
# Bi-LSTM      118.022222  86.628352    0.0   40.00  113.0  188.50  340.0
# Conv1D       291.388889  59.346383   28.0  269.25  304.0  326.50  363.0
# LSTM         134.822222  87.038617    9.0   63.25  121.5  212.00  319.0
# MLP          388.282051  26.428977  336.0  369.25  384.0  408.75  436.0
# Transformer  138.855556  63.410835    6.0   99.00  137.0  180.50  281.0
#
# [5 rows x 64 columns]

# %% [markdown]
# ### SCPM Analysis

# %%
cols = [
    "Model",
    # "Model_bkp",
    "Model_bkp_2",
    "Timesteps",
    "RMSE_mean",
    "MAE_mean",
    "MAPE_mean",
    "R2_mean",
    "SCPM",
    "Dominated_Count",
    "Dominates_Count",
    "Classification",
    "Plant",
]

# %%
df_sorted_scpm = df_sorted_topo.sort_values(by="SCPM").copy()

# %%
# (df_sorted_topo[cols].reset_index() == df_sorted_scpm[cols].reset_index()).all(axis=1)
df_sorted_scpm["topo_scmp_order_eq"] = df_sorted_topo.index == df_sorted_scpm.index

# %%
# df_sorted_topo[cols].round(2).head(5)

# %%
df_sorted_scpm[cols + ["topo_scmp_order_eq"]].round(2).head(7)
# Out:
#       Model Model_bkp_2  Timesteps  RMSE_mean  MAE_mean  MAPE_mean  R2_mean  \
# 289  MLP_11         MLP        NaN       1.99      1.49       3.52     0.89
# 285   MLP_7         MLP        NaN       2.01      1.49       3.51     0.89
# 288  MLP_10         MLP        NaN       2.06      1.51       3.54     0.89
# 290  MLP_12         MLP        NaN       2.04      1.54       3.64     0.89
# 284   MLP_6         MLP        NaN       2.07      1.54       3.62     0.89
# 283   MLP_5         MLP        NaN       2.09      1.54       3.63     0.88
# 291  MLP_13         MLP        NaN       2.10      1.57       3.70     0.88
#
#      SCPM  Dominated_Count  Dominates_Count      Classification Plant  \
# 289 -1.78                0              436      dominant_model    AT
# 285 -1.78                0              436      dominant_model    AT
# 288 -1.74                2              434  intermediate_model    AT
# 290 -1.72                2              432  intermediate_model    AT
# 284 -1.72                3              433  intermediate_model    AT
# 283 -1.70                4              432  intermediate_model    AT
# 291 -1.68                6              429  intermediate_model    AT
#
#      topo_scmp_order_eq
# 289               False
# 285               False
# 288                True
# 290                True
# 284                True
# 283                True
# 291               False

# %% [markdown]
# ### Variable Grouping: CM-P-CS

# %% [markdown]
# #### Analysis of the best models identified in the Local Analysis

# %% [markdown]
# **Best models for variable groupping CM-P-CS were from:**
#
# *BTiSS:*
#     Dominance analysis: Plant S
#     SCPM:Plant S and K
#
# *TiSS:*
#     Dominance analysis: Plant S
#     SCPM:Plant S

# %%
df_pre_train["Features"].unique()
# Out:
# array(['Chemical + Mineralogical + Physical - Early CS',
#        'Chemical + Mineralogical + Physical', 'Chemical + Mineralogical'],
#       dtype=object)

# %%
df_results_cm_p_cs = (
    df_pre_train[df_pre_train["Features"].eq("Chemical + Mineralogical + Physical")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_p_cs.shape
# Out:
# (511, 26)

# %%
# Here is the reason why the variable group cm-p-cs has more results
df_results_cm_p_cs["Plant"].nunique(), df_results_cm_p[
    "Plant"
].nunique(), df_results_cm["Plant"].nunique()
# Out:
# (7, 6, 6)

# %% [markdown]
# #### Hold Out

# %%
df_results_cm_p_cs["Cross Validation"].unique()
# Out:
# array(['Out of time'], dtype=object)

# %%
df_results_cm_p_cs_ho = (
    df_results_cm_p_cs[df_results_cm_p_cs["Cross Validation"].eq("Out of time")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_p_cs_ho["Cross Validation"].unique()
# Out:
# array(['Out of time'], dtype=object)

# %%
df_results_cm_p_cs_ho.shape
# Out:
# (511, 26)

# %% [markdown]
# ###### SCPM computation

# %%
df_results_cm_p_cs_ho = compute_scpm(df_results_cm_p_cs_ho)

# %% [markdown]
# ##### Dominance Analysis

# %%
dominance_dict = make_dominance_analysis(df_results_cm_p_cs_ho)
dominance_matrix_cm_p_cs_s_ho = dominance_dict["dominance_matrix"]
dominance_graph_cm_p_cs_s_ho = dominance_dict["dominance_graph"]
df_sorted_count = dominance_dict["df_sorted_count"]
df_sorted_topo = dominance_dict["df_sorted_topo"]

# %%
dominance_matrix_cm_p_cs_s_ho.shape, len(dominance_graph_cm_p_cs_s_ho)
# Out:
# ((511, 511), 511)

# %%
df_sorted_topo["Classification"].value_counts()
# Out:
# Classification
# intermediate_model    508
# non_dominant_model      2
# dominant_model          1
# Name: count, dtype: int64

# %%
df_sorted_topo.head(5)
# Out:
#          Category  Company Plant                             Features  \
# 385  Global Model      207    AT  Chemical + Mineralogical + Physical
# 390  Global Model      207    AT  Chemical + Mineralogical + Physical
# 386  Global Model      207    AT  Chemical + Mineralogical + Physical
# 391  Global Model      207    AT  Chemical + Mineralogical + Physical
# 464  Global Model      209     S  Chemical + Mineralogical + Physical
#
#       Data Shape  Timesteps   Model  Model Params           Scaler  \
# 385  (62749, 18)        NaN   MLP_6           NaN  Standard Scaler
# 390  (62749, 18)        NaN  MLP_11           NaN  Standard Scaler
# 386  (62749, 18)        NaN   MLP_7           NaN  Standard Scaler
# 391  (62749, 18)        NaN  MLP_12           NaN  Standard Scaler
# 464  (61946, 17)        NaN  MLP_12           NaN  Standard Scaler
#
#      Scaler Params  ... MAPE_mean   R2_mean plant         Features_bkp  \
# 385            NaN  ...  2.505854  0.944895    at  Chemical + Physical
# 390            NaN  ...  2.525874  0.944668    at  Chemical + Physical
# 386            NaN  ...  2.541619  0.942447    at  Chemical + Physical
# 391            NaN  ...  2.591030  0.942710    at  Chemical + Physical
# 464            NaN  ...  2.567879  0.940373     s  Chemical + Physical
#
#      Model_bkp  Model_bkp_2      SCPM  Dominated_Count      Classification  \
# 385      MLP_6          MLP -1.593756                0      dominant_model
# 390     MLP_11          MLP -1.587341                1  intermediate_model
# 386      MLP_7          MLP -1.571952                2  intermediate_model
# 391     MLP_12          MLP -1.558880                2  intermediate_model
# 464     MLP_12          MLP -1.562532                3  intermediate_model
#
#      Dominates_Count
# 385              510
# 390              509
# 386              507
# 391              505
# 464              504
#
# [5 rows x 30 columns]

# %%
df_sorted_topo_cols = df_sorted_topo[
    [
        "Model",
        # "Model_bkp",
        # "Model_bkp_2",
        "Timesteps",
        "RMSE_mean",
        "MAE_mean",
        "MAPE_mean",
        "R2_mean",
        "SCPM",
        "Dominated_Count",
        "Classification",
        "Dominates_Count",
        "Plant",
    ]
].round(2)

# %% [markdown]
# ##### Top dominant models

# %%
# Top 4
df_sorted_topo_cols.sort_values(by="Dominates_Count", ascending=False).iloc[0:3]
# Out:
#       Model  Timesteps  RMSE_mean  MAE_mean  MAPE_mean  R2_mean  SCPM  \
# 385   MLP_6        NaN       1.43      1.07       2.51     0.94 -1.59
# 390  MLP_11        NaN       1.43      1.07       2.53     0.94 -1.59
# 386   MLP_7        NaN       1.46      1.08       2.54     0.94 -1.57
#
#      Dominated_Count      Classification  Dominates_Count Plant
# 385                0      dominant_model              510    AT
# 390                1  intermediate_model              509    AT
# 386                2  intermediate_model              507    AT

# %% [markdown]
# ##### Top intermediate models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].sort_values(by="Dominates_Count", ascending=False).iloc[:2]
# Out:
#       Model  Timesteps  RMSE_mean  MAE_mean  MAPE_mean  R2_mean  SCPM  \
# 390  MLP_11        NaN       1.43      1.07       2.53     0.94 -1.59
# 386   MLP_7        NaN       1.46      1.08       2.54     0.94 -1.57
#
#      Dominated_Count      Classification  Dominates_Count Plant
# 390                1  intermediate_model              509    AT
# 386                2  intermediate_model              507    AT

# %% [markdown]
# ##### Top non dominant models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].sort_values(by="Dominated_Count", ascending=True).iloc[:2]
# Out:
#          Model  Timesteps  RMSE_mean  MAE_mean  MAPE_mean  R2_mean   SCPM  \
# 246     MLP_13        NaN      49.65      1.84       4.51   -67.67  32.74
# 346  Bi-LSTM12       14.0      28.06     27.40      62.55   -20.71  32.56
#
#      Dominated_Count      Classification  Dominates_Count Plant
# 246              294  non_dominant_model                0     F
# 346              509  non_dominant_model                0     B

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        # "Model",
        # "Model_bkp",
        "Model_bkp_2",
        "Timesteps",
        "RMSE_mean",
        "MAE_mean",
        "MAPE_mean",
        "R2_mean",
        "SCPM",
        "Dominated_Count",
        "Classification",
        "Dominates_Count",
        "Plant",
    ]
]  # .round(2)

# %%
df_sorted_topo["Model_bkp_2"].value_counts()
# Out:
# Model_bkp_2
# Conv1D         105
# Bi-LSTM        105
# LSTM           105
# Transformer    105
# MLP             91
# Name: count, dtype: int64

# %%
df_sorted_topo_models_grouped = (
    df_sorted_topo_models_cols.groupby("Model_bkp_2").describe().T
)

# %%
# pd.set_option("display.max_rows", None)
# df_sorted_topo_models_grouped

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model_bkp_2",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
    ]
]

# %%
df_sorted_topo_models_cols.groupby("Model_bkp_2").describe().round(2)
# Out:
#             Dominated_Count                                              \
#                       count    mean     std    min    25%    50%    75%
# Model_bkp_2
# Bi-LSTM               105.0  335.26  114.56   77.0  251.0  328.0  443.0
# Conv1D                105.0  144.64   59.98   61.0  100.0  128.0  176.0
# LSTM                  105.0  314.93  120.53   88.0  219.0  312.0  442.0
# MLP                    91.0   52.08   55.31    0.0   17.0   36.0   61.5
# Transformer           105.0  355.90   78.31  139.0  316.0  366.0  409.0
#
#                    Dominates_Count                                       \
#                max           count    mean     std    min    25%    50%
# Model_bkp_2
# Bi-LSTM      509.0           105.0  157.40  107.43    0.0   60.0  154.0
# Conv1D       322.0           105.0  338.95   63.25  158.0  297.0  351.0
# LSTM         508.0           105.0  177.80  113.50    1.0   60.0  195.0
# MLP          294.0            91.0  442.05   73.68    0.0  438.0  461.0
# Transformer  499.0           105.0  138.60   72.75    7.0   89.0  127.0
#
#
#                75%    max
# Model_bkp_2
# Bi-LSTM      239.0  416.0
# Conv1D       388.0  437.0
# LSTM         266.0  412.0
# MLP          478.5  510.0
# Transformer  175.0  346.0

# %%
df_sorted_topo_models_cols.groupby("Model_bkp_2")["Classification"].describe()
# Out:
#             count unique                 top freq
# Model_bkp_2
# Bi-LSTM       105      2  intermediate_model  104
# Conv1D        105      1  intermediate_model  105
# LSTM          105      1  intermediate_model  105
# MLP            91      3  intermediate_model   89
# Transformer   105      1  intermediate_model  105

# %%
df_sorted_topo_models_cols.groupby("Model_bkp_2")[["Classification"]].value_counts()
# Out:
# Model_bkp_2  Classification
# Bi-LSTM      intermediate_model    104
#              non_dominant_model      1
# Conv1D       intermediate_model    105
# LSTM         intermediate_model    105
# MLP          intermediate_model     89
#              dominant_model          1
#              non_dominant_model      1
# Transformer  intermediate_model    105
# Name: count, dtype: int64

# %%
(
    df_sorted_topo_models_cols.groupby("Model_bkp_2")[["Classification"]]
    .value_counts(normalize=True)
    .to_frame()
    * 100
).round(2)
# Out:
#                                 proportion
# Model_bkp_2 Classification
# Bi-LSTM     intermediate_model       99.05
#             non_dominant_model        0.95
# Conv1D      intermediate_model      100.00
# LSTM        intermediate_model      100.00
# MLP         intermediate_model       97.80
#             dominant_model            1.10
#             non_dominant_model        1.10
# Transformer intermediate_model      100.00

# %%
df_sorted_topo_models_cols
# Out:
#     Model_bkp_2  Dominated_Count  Dominates_Count      Classification
# 385         MLP                0              510      dominant_model
# 390         MLP                1              509  intermediate_model
# 386         MLP                2              507  intermediate_model
# 391         MLP                2              505  intermediate_model
# 464         MLP                3              504  intermediate_model
# ..          ...              ...              ...                 ...
# 297        LSTM              505                4  intermediate_model
# 419     Bi-LSTM              506                3  intermediate_model
# 5          LSTM              507                2  intermediate_model
# 229        LSTM              508                1  intermediate_model
# 346     Bi-LSTM              509                0  non_dominant_model
#
# [511 rows x 4 columns]

# %%
summary_stats = df_sorted_topo_models_cols.groupby("Model_bkp_2").agg(
    Total_Models=("Model_bkp_2", "count"),
    Mean_Dominance_Count=("Dominates_Count", "mean"),
    Median_Dominance_Count=("Dominates_Count", "median"),
    Total_Dominated=("Dominated_Count", "sum"),
    Total_Dominating=("Dominates_Count", "sum"),
)

total_models = summary_stats[
    "Total_Models"
].sum()  # Get the total number of models across all categories
summary_stats["Dominance Proportion"] = summary_stats["Total_Dominating"] / total_models

# %%
summary_stats
# Out:
#              Total_Models  Mean_Dominance_Count  Median_Dominance_Count  \
# Model_bkp_2
# Bi-LSTM               105            157.400000                   154.0
# Conv1D                105            338.952381                   351.0
# LSTM                  105            177.800000                   195.0
# MLP                    91            442.054945                   461.0
# Transformer           105            138.600000                   127.0
#
#              Total_Dominated  Total_Dominating  Dominance Proportion
# Model_bkp_2
# Bi-LSTM                35202             16527             32.342466
# Conv1D                 15187             35590             69.647750
# LSTM                   33068             18669             36.534247
# MLP                     4739             40227             78.722114
# Transformer            37370             14553             28.479452

# %%
df_sorted_topo_models_grouped.T
# Out:
#             Timesteps                                                 \
#                 count      mean       std  min  25%  50%   75%   max
# Model_bkp_2
# Bi-LSTM         105.0  7.333333  5.337939  1.0  1.0  7.0  14.0  14.0
# Conv1D          105.0  7.333333  5.337939  1.0  1.0  7.0  14.0  14.0
# LSTM            105.0  7.333333  5.337939  1.0  1.0  7.0  14.0  14.0
# MLP               0.0       NaN       NaN  NaN  NaN  NaN   NaN   NaN
# Transformer     105.0  7.333333  5.337939  1.0  1.0  7.0  14.0  14.0
#
#             RMSE_mean            ... Dominated_Count        Dominates_Count  \
#                 count      mean  ...             75%    max           count
# Model_bkp_2                      ...
# Bi-LSTM         105.0  3.986665  ...           443.0  509.0           105.0
# Conv1D          105.0  1.918330  ...           176.0  322.0           105.0
# LSTM            105.0  3.649342  ...           442.0  508.0           105.0
# MLP              91.0  2.140752  ...            61.5  294.0            91.0
# Transformer     105.0  3.065799  ...           409.0  499.0           105.0
#
#
#                    mean         std    min    25%    50%    75%    max
# Model_bkp_2
# Bi-LSTM      157.400000  107.433038    0.0   60.0  154.0  239.0  416.0
# Conv1D       338.952381   63.253668  158.0  297.0  351.0  388.0  437.0
# LSTM         177.800000  113.504863    1.0   60.0  195.0  266.0  412.0
# MLP          442.054945   73.681652    0.0  438.0  461.0  478.5  510.0
# Transformer  138.600000   72.747403    7.0   89.0  127.0  175.0  346.0
#
# [5 rows x 64 columns]

# %% [markdown]
# ### SCPM Analysis

# %%
cols = [
    "Model",
    # "Model_bkp",
    "Model_bkp_2",
    "Timesteps",
    "RMSE_mean",
    "MAE_mean",
    "MAPE_mean",
    "R2_mean",
    "SCPM",
    "Dominated_Count",
    "Dominates_Count",
    "Classification",
    "Plant",
]

# %%
df_sorted_scpm = df_sorted_topo.sort_values(by="SCPM").copy()

# %%
# (df_sorted_topo[cols].reset_index() == df_sorted_scpm[cols].reset_index()).all(axis=1)
df_sorted_scpm["topo_scmp_order_eq"] = df_sorted_topo.index == df_sorted_scpm.index

# %%
# df_sorted_topo[cols].round(2).head(5)

# %%
df_sorted_scpm[cols + ["topo_scmp_order_eq"]].round(2).head(7)
# Out:
#       Model Model_bkp_2  Timesteps  RMSE_mean  MAE_mean  MAPE_mean  R2_mean  \
# 385   MLP_6         MLP        NaN       1.43      1.07       2.51     0.94
# 390  MLP_11         MLP        NaN       1.43      1.07       2.53     0.94
# 386   MLP_7         MLP        NaN       1.46      1.08       2.54     0.94
# 464  MLP_12         MLP        NaN       1.47      1.09       2.57     0.94
# 391  MLP_12         MLP        NaN       1.46      1.10       2.59     0.94
# 384   MLP_5         MLP        NaN       1.49      1.10       2.57     0.94
# 389  MLP_10         MLP        NaN       1.49      1.11       2.61     0.94
#
#      SCPM  Dominated_Count  Dominates_Count      Classification Plant  \
# 385 -1.59                0              510      dominant_model    AT
# 390 -1.59                1              509  intermediate_model    AT
# 386 -1.57                2              507  intermediate_model    AT
# 464 -1.56                3              504  intermediate_model     S
# 391 -1.56                2              505  intermediate_model    AT
# 384 -1.55                4              502  intermediate_model    AT
# 389 -1.54                4              501  intermediate_model    AT
#
#      topo_scmp_order_eq
# 385                True
# 390                True
# 386                True
# 464               False
# 391               False
# 384               False
# 389                True

# %% [markdown]
# # Global Analysis (fine tuning results)

# %% [markdown]
# # Definitions

# %% [markdown]
# # Topological Analysis - NEW

# %% [markdown]
# ## Definitions

# %%
# Function to compare two models strictly based on means only
def dominates(model1, model2):
    """Return True if model1 strictly dominates model2, False otherwise."""
    # Check if model1 is at least as good as model2 in all metrics
    at_least_as_good = (
        model1["RMSE_mean"] <= model2["RMSE_mean"]
        and model1["MAE_mean"] <= model2["MAE_mean"]
        and model1["MAPE_mean"] <= model2["MAPE_mean"]
        and model1["R2_mean"] >= model2["R2_mean"]
    )

    # Check if model1 is strictly better in at least one metric
    strictly_better_in_one = (
        model1["RMSE_mean"] < model2["RMSE_mean"]
        or model1["MAE_mean"] < model2["MAE_mean"]
        or model1["MAPE_mean"] < model2["MAPE_mean"]
        or model1["R2_mean"] > model2["R2_mean"]
    )

    # Model1 strictly dominates Model2 if it is at least as good in all metrics and
    # strictly better in at least one metric
    return at_least_as_good and strictly_better_in_one

# %%
def get_dominance_matrix_and_graph(df):
    n = len(df)
    dominance_matrix = np.zeros((n, n), dtype=bool)

    for i in range(n):
        for j in range(n):
            if i != j:
                dominance_matrix[i, j] = dominates(df.iloc[i], df.iloc[j])

    # Create the dominance graph
    dominance_graph = {i: [] for i in range(n)}
    for i in range(n):
        for j in range(n):
            if dominance_matrix[i, j]:
                dominance_graph[i].append(j)

    return dominance_matrix, dominance_graph

# %%
# Topological Sorting
def topological_sort(graph):
    """Perform topological sorting on the given graph."""
    in_degree = {u: 0 for u in graph}
    for u in graph:
        for v in graph[u]:
            in_degree[v] += 1

    queue = deque([u for u in graph if in_degree[u] == 0])
    topo_order = []

    while queue:
        u = queue.popleft()
        topo_order.append(u)

        for v in graph[u]:
            in_degree[v] -= 1
            if in_degree[v] == 0:
                queue.append(v)

    return topo_order

# %%
# Function to find the top models in each group
def find_top_models(group):
    max_net_dominance = group["Net_Dominance"].max()
    top_models = group[group["Net_Dominance"] == max_net_dominance]
    return top_models

# %% [markdown]
# ### Dominance Analysis and SCPM

# %%
def compute_scpm(df):
    scaler = StandardScaler()
    standardized_metrics = scaler.fit_transform(
        df[["RMSE_mean", "MAE_mean", "MAPE_mean", "R2_mean"]]
    )

    # Creating a new dataframe with standardized values
    standardized_df = pd.DataFrame(
        standardized_metrics,
        columns=["RMSE_mean", "MAE_mean", "MAPE_mean", "R2_mean"],
    )

    # Summing all metrics and subtracting R2_mean
    standardized_df["Result"] = (
        standardized_df[["RMSE_mean", "MAE_mean", "MAPE_mean"]].sum(axis=1)
        - standardized_df["R2_mean"]
    )

    df["SCPM"] = standardized_df["Result"]
    return df

# %%
def make_dominance_analysis(df):
    # Compute dominance matrix and graph
    dominance_matrix, dominance_graph = get_dominance_matrix_and_graph(df)

    # Get the topological order
    topo_order = topological_sort(dominance_graph)
    df = df.copy()
    n = len(topo_order)

    # Identify Dominant Models
    dominant_models = [
        df["Model_bkp_2"].iloc[i]
        for i in range(len(df))
        if not np.any(dominance_matrix[:, i])
    ]

    # Identify Non-Dominant Models
    non_dominant_models = [
        df["Model_bkp_2"].iloc[i]
        for i in range(len(df))
        if np.any(dominance_matrix[:, i])
    ]

    # Identify Models that are both dominated and dominate at least one
    intermediate_models = [
        df["Model_bkp_2"].iloc[i]
        for i in range(len(df))
        if np.any(dominance_matrix[:, i]) and np.any(dominance_matrix[i, :])
    ]

    # Add count of times each model is dominated by others
    df["Dominated_Count"] = np.sum(dominance_matrix, axis=0)

    # Classify models
    df["Classification"] = "intermediate_model"  # default to intermediate_model
    df.loc[
        ~np.any(dominance_matrix, axis=1) & np.any(dominance_matrix, axis=0),
        "Classification",
    ] = "non_dominant_model"
    df.loc[~np.any(dominance_matrix, axis=0), "Classification"] = "dominant_model"

    # Map the topological order to the model names and get dominance counts
    sorted_models = [df["Model"].iloc[i] for i in topo_order]

    df_sorted = df.iloc[topo_order].copy()
    df_sorted["Dominates_Count"] = dominance_matrix.sum(axis=1)[topo_order]
    df_sorted_topo = df_sorted.copy()

    df_sorted = df_sorted.sort_values(by="Dominates_Count", ascending=False)
    df_sorted_count = df_sorted.copy()

    return {
        "dominance_matrix": dominance_matrix,
        "dominance_graph": dominance_graph,
        "df_sorted_topo": df_sorted_topo,
        "df_sorted_count": df_sorted_count,
    }

# %% [markdown]
# # Reading The files

# %%
csv_files_path_fine_tuning_full = dict()
csv_files_path_fine_tuning_grouped = dict()

# %% [markdown]
# ## 203

# %% [markdown]
# ### Plant C

# %%
path_fine_tuning_full = "/home/peressim/projects/ccs28-ml-modelling/reports/results/global_models/203/c/fine_tuning/full/"
path_fine_tuning_grouped = "/home/peressim/projects/ccs28-ml-modelling/reports/results/global_models/203/c/fine_tuning/grouped/"
plant = "c"

csv_files_path_fine_tuning_full = read_csv_files_path(
    csv_files_path_fine_tuning_full, path_fine_tuning_full, plant
)

csv_files_path_fine_tuning_grouped = read_csv_files_path(
    csv_files_path_fine_tuning_grouped, path_fine_tuning_grouped, plant
)

# %% [markdown]
# ## 204

# %% [markdown]
# ### Plant F

# %%
path_fine_tuning_full = "/home/peressim/projects/ccs28-ml-modelling/reports/results/global_models/204/f/fine_tuning/full/"
path_fine_tuning_grouped = "/home/peressim/projects/ccs28-ml-modelling/reports/results/global_models/204/f/fine_tuning/grouped/"
plant = "f"

csv_files_path_fine_tuning_full = read_csv_files_path(
    csv_files_path_fine_tuning_full, path_fine_tuning_full, plant
)

csv_files_path_fine_tuning_grouped = read_csv_files_path(
    csv_files_path_fine_tuning_grouped, path_fine_tuning_grouped, plant
)

# %% [markdown]
# ### Plant AB

# %%
path_fine_tuning_full = "/home/peressim/projects/ccs28-ml-modelling/reports/results/global_models/204/ab/fine_tuning/full/"
path_fine_tuning_grouped = "/home/peressim/projects/ccs28-ml-modelling/reports/results/global_models/204/ab/fine_tuning/grouped/"
plant = "ab"

csv_files_path_fine_tuning_full = read_csv_files_path(
    csv_files_path_fine_tuning_full, path_fine_tuning_full, plant
)

csv_files_path_fine_tuning_grouped = read_csv_files_path(
    csv_files_path_fine_tuning_grouped, path_fine_tuning_grouped, plant
)

# %% [markdown]
# ## 206

# %% [markdown]
# ### Plant B

# %%
path_fine_tuning_full = "/home/peressim/projects/ccs28-ml-modelling/reports/results/global_models/206/b/fine_tuning/full/"
path_fine_tuning_grouped = "/home/peressim/projects/ccs28-ml-modelling/reports/results/global_models/206/b/fine_tuning/grouped/"
plant = "b"

csv_files_path_fine_tuning_full = read_csv_files_path(
    csv_files_path_fine_tuning_full, path_fine_tuning_full, plant
)

csv_files_path_fine_tuning_grouped = read_csv_files_path(
    csv_files_path_fine_tuning_grouped, path_fine_tuning_grouped, plant
)

# %% [markdown]
# ## 207

# %% [markdown]
# ### Plant AT

# %%
path_fine_tuning_full = "/home/peressim/projects/ccs28-ml-modelling/reports/results/global_models/207/at/fine_tuning/full/"
path_fine_tuning_grouped = "/home/peressim/projects/ccs28-ml-modelling/reports/results/global_models/207/at/fine_tuning/grouped/"
plant = "at"

csv_files_path_fine_tuning_full = read_csv_files_path(
    csv_files_path_fine_tuning_full, path_fine_tuning_full, plant
)

csv_files_path_fine_tuning_grouped = read_csv_files_path(
    csv_files_path_fine_tuning_grouped, path_fine_tuning_grouped, plant
)

# %% [markdown]
# ## 209

# %% [markdown]
# ### Plant S

# %%
path_fine_tuning_full = "/home/peressim/projects/ccs28-ml-modelling/reports/results/global_models/209/s/fine_tuning/full/"
path_fine_tuning_grouped = "/home/peressim/projects/ccs28-ml-modelling/reports/results/global_models/209/s/fine_tuning/grouped/"
plant = "s"

csv_files_path_fine_tuning_full = read_csv_files_path(
    csv_files_path_fine_tuning_full, path_fine_tuning_full, plant
)

csv_files_path_fine_tuning_grouped = read_csv_files_path(
    csv_files_path_fine_tuning_grouped, path_fine_tuning_grouped, plant
)

# %% [markdown]
# ### Plant AM

# %%
path_fine_tuning_full = "/home/peressim/projects/ccs28-ml-modelling/reports/results/global_models/209/am/fine_tuning/full/"
path_fine_tuning_grouped = "/home/peressim/projects/ccs28-ml-modelling/reports/results/global_models/209/am/fine_tuning/grouped/"
plant = "am"

csv_files_path_fine_tuning_full = read_csv_files_path(
    csv_files_path_fine_tuning_full, path_fine_tuning_full, plant
)

csv_files_path_fine_tuning_grouped = read_csv_files_path(
    csv_files_path_fine_tuning_grouped, path_fine_tuning_grouped, plant
)

# %% [markdown]
# ### Plant W

# %%
path_fine_tuning_full = "/home/peressim/projects/ccs28-ml-modelling/reports/results/global_models/209/w/fine_tuning/full/"
path_fine_tuning_grouped = "/home/peressim/projects/ccs28-ml-modelling/reports/results/global_models/209/w/fine_tuning/grouped/"
plant = "w"

csv_files_path_fine_tuning_full = read_csv_files_path(
    csv_files_path_fine_tuning_full, path_fine_tuning_full, plant
)

csv_files_path_fine_tuning_grouped = read_csv_files_path(
    csv_files_path_fine_tuning_grouped, path_fine_tuning_grouped, plant
)

# %% [markdown]
# ### Plant K

# %%
path_fine_tuning_full = "/home/peressim/projects/ccs28-ml-modelling/reports/results/global_models/209/k/fine_tuning/full/"
path_fine_tuning_grouped = "/home/peressim/projects/ccs28-ml-modelling/reports/results/global_models/209/k/fine_tuning/grouped/"
plant = "k"

csv_files_path_fine_tuning_full = read_csv_files_path(
    csv_files_path_fine_tuning_full, path_fine_tuning_full, plant
)

csv_files_path_fine_tuning_grouped = read_csv_files_path(
    csv_files_path_fine_tuning_grouped, path_fine_tuning_grouped, plant
)

# %% [markdown]
# ### Reading all data - pre training

# %% [markdown]
# #### Full

# %%
dfs_plant = dict()
column = ("plant", "")
pos = 2

for plant, csv_files in csv_files_path_fine_tuning_full.items():
    df = read_csv_files_full(csv_files, plant)
    df["plant"] = plant
    dfs_plant[plant] = df

# %%
df_fine_tuning_full = pd.concat(dfs_plant.values(), ignore_index=True)

# %%
df_fine_tuning_full.shape
# Out:
# (4185, 23)

# %%
df_fine_tuning_full_copy = (
    df_fine_tuning_full[
        df_fine_tuning_full["Cross Validation"].isin(
            ["Blocking Time Series Split", "Time Series Split"]
        )
    ]
    .copy()
    .reset_index(drop=True)
)

# %%
df_fine_tuning_full_copy.shape
# Out:
# (3120, 23)

# %%
df_fine_tuning_full_copy["Cross Validation"].value_counts()
# Out:
# Cross Validation
# Blocking Time Series Split    1560
# Time Series Split             1560
# Name: count, dtype: int64

# %%
df_fine_tuning_full_copy["Features"].value_counts()
# Out:
# Features
# Chemical + Physical              1200
# Chemical                         1020
# Chemical + Properties CS Less     900
# Name: count, dtype: int64

# %%
df_fine_tuning_full_copy[
    df_fine_tuning_full_copy["Features"].eq("Chemical")
    & df_fine_tuning_full_copy["Cross Validation"].eq("Blocking Time Series Split")
].shape
# Out:
# (510, 23)

# %%
df_fine_tuning_full_copy[
    df_fine_tuning_full_copy["Features"].eq("Chemical")
    & df_fine_tuning_full_copy["Cross Validation"].eq("Time Series Split")
].shape
# Out:
# (510, 23)

# %%
df_fine_tuning_full_copy[
    df_fine_tuning_full_copy["Features"].eq("Chemical + Properties CS Less")
    & df_fine_tuning_full_copy["Cross Validation"].eq("Blocking Time Series Split")
].shape
# Out:
# (450, 23)

# %%
df_fine_tuning_full_copy[
    df_fine_tuning_full_copy["Features"].eq("Chemical + Properties CS Less")
    & df_fine_tuning_full_copy["Cross Validation"].eq("Time Series Split")
].shape
# Out:
# (450, 23)

# %%
df_fine_tuning_full_copy[
    df_fine_tuning_full_copy["Features"].eq("Chemical + Physical")
    & df_fine_tuning_full_copy["Cross Validation"].eq("Blocking Time Series Split")
].shape
# Out:
# (600, 23)

# %%
df_fine_tuning_full_copy[
    df_fine_tuning_full_copy["Features"].eq("Chemical + Physical")
    & df_fine_tuning_full_copy["Cross Validation"].eq("Time Series Split")
    & ~df_fine_tuning_full_copy["Plant"].eq("K")
].shape
# Out:
# (525, 23)

# %% [markdown]
# #### Grouped

# %%
dfs_plant = dict()
column = ("plant", "")
pos = 2

for plant, csv_files in csv_files_path_fine_tuning_grouped.items():
    df = read_csv_files_grouped(csv_files, plant)
    df["plant"] = plant
    df = preprocess_rename_columns(df)
    df = preprocess_change_columns_order(df, column, pos)
    dfs_plant[plant] = df

# %%
df_fine_tuning_grouped = pd.concat(dfs_plant.values(), ignore_index=True)

# %%
df_fine_tuning_grouped.shape
# Out:
# (327, 25)

# %%
df_copy = df_fine_tuning_grouped.copy()
df_copy = (
    df_copy.reset_index(level=0)
    .rename({"level_0": "Plant"}, axis=1)
    .reset_index(drop=True)
)

# %% [markdown]
# ## Preprocessing steps

# %%
patterns = [
    "Chemical + Mineralogical + Feature Engineering",
    "Chemical + Mineralogical + CS7 + One-Hot",
    "Chemical + Mineralogical + Physical + One-Hot",
    "Chemical + Mineralogical + CS3 + One-Hot",
    "Chemical + Mineralogical + CS3 + CS7 + One-Hot",
    "Chemical + Mineralogical + One-Hot",
    "Chemical + Mineralogical + CS1 + CS3 + CS7 + One-Hot",
    "Chemical + Mineralogical + CS1 + CS3 + One-Hot",
    "Chemical + Mineralogical + CS1 + One-Hot",
    "Chemical + Mineralogical + CS2 + One-Hot",
    "Chemical + Feature Engineering",
]

replace_dict = {
    "Chemical + Mineralogical + CS3 + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS3": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS1": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS1 + CS3": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS1 + CS3 + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS2": "Chemical + Mineralogical + Early CS",
    "Chemical + CS1 + CS3 + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + CS3 + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + CS3": "Chemical + Mineralogical + Early CS",
    "Chemical + CS1 + CS3": "Chemical + Mineralogical + Early CS",
    "Chemical + CS1": "Chemical + Mineralogical + Early CS",
    "Chemical + CS1 + CS7": "Chemical + Mineralogical + Early CS",
}

replace_dict_2 = {
    "Chemical": "Chemical + Mineralogical",
    "Chemical + Properties CS Less": "Chemical + Mineralogical + Physical - Early CS",
    "Chemical + Mineralogical + Properties CS Less": "Chemical + Mineralogical + Physical - Early CS",
    "Chemical + Physical": "Chemical + Mineralogical + Physical",
}

df_copy = df_copy[~df_copy["Cross Validation"].eq("Out of time Split")].reset_index(
    drop=True
)

# Removing afterwards
df_copy = df_copy[~df_copy["Cross Validation"].eq("Repeated KFold")].reset_index(
    drop=True
)

df_copy = df_copy[~df_copy["Features"].apply(lambda x: x in patterns)].reset_index(
    drop=True
)
df_copy["Features_bkp"] = df_copy["Features"].copy()
df_copy["Features"] = df_copy["Features"].replace(replace_dict)

df_copy["Features"] = df_copy["Features"].replace(replace_dict_2)

# This plant wasn't between the best models for this variable grouping configuration, hence it was removed
# df_copy = df_copy[
#     ~(
#         df_copy["plant"].eq("am")
#         & df_copy["Features"].eq("Chemical + Mineralogical + Physical - Early CS")
#     )
# ]

# %%
df_copy["plant"].unique()
# Out:
# array(['c', 'f', 'ab', 'b', 'at', 's', 'am', 'w', 'k'], dtype=object)

# %%
# Ensuring only the results of the best selected plants will be taken into account

cm = df_copy["Features"].eq("Chemical + Mineralogical")
cmp = df_copy["Features"].eq("Chemical + Mineralogical + Physical - Early CS")
cmpcs = df_copy["Features"].eq("Chemical + Mineralogical + Physical")

btss = df_copy["Cross Validation"].eq("Blocking Time Series Split")
tss = df_copy["Cross Validation"].eq("Time Series Split")

fs = df_copy["plant"].eq("s")
fab = df_copy["plant"].eq("ab")
ff = df_copy["plant"].eq("f")
fam = df_copy["plant"].eq("am")
fw = df_copy["plant"].eq("w")
fk = df_copy["plant"].eq("k")

fc = df_copy["plant"].eq("c")
fb = df_copy["plant"].eq("b")
fat = df_copy["plant"].eq("at")

f_final = (
    (cm & ((btss & (fs | fc | fab | fb | fat)) | (tss & (fs | fc | ff | fb | fat))))
    | (cmp & ((btss & (fam | fc | ff | fb | fat)) | (tss & (fw | fc | ff | fb | fat))))
    | (
        cmpcs
        & ((btss & (fs | fk | fc | ff | fb | fat)) | (tss & (fs | fc | fab | fb | fat)))
    )
)
df_copy = df_copy[f_final].reset_index(drop=True)

# %%
# for feature in df_copy["Features"].unique():
#     print()
#     cvs = df_copy["Cross Validation"].unique()
#     print("================================")
#     print("Feature: ", feature)
#     print("================================")
#     for cv in cvs:
#         print("================================")
#         print(cv)
#         print("================================")
#         plants_df = df_copy[
#             df_copy["Cross Validation"].eq(cv) & df_copy["Features"].eq(feature)
#         ]
#         for plant in plants_df["plant"].unique():
#             print(plant)
#         print("================================")
#         print()

# %%
df_copy[("MAPE Train", "mean")] = df_copy[("MAPE Train", "mean")] * 100
df_copy[("MAPE Train", "std")] = df_copy[("MAPE Train", "std")] * 100
df_copy[("MAPE Test", "mean")] = df_copy[("MAPE Test", "mean")] * 100
df_copy[("MAPE Test", "std")] = df_copy[("MAPE Test", "std")] * 100

df_copy["Model_bkp"] = df_copy["Model"].copy()
df_copy["Model_bkp_2"] = df_copy["Model"] + df_copy["Timesteps"].apply(
    lambda x: "" if pd.isna(x) else "_" + str(x)
)
df_copy["Model"] = df_copy["Model"].replace(
    {
        "MLP": "Neural Networks",
        "LSTM": "Neural Networks",
        "GRU": "Neural Networks",
        "BidirectionalLSTM": "Neural Networks",
        "BidirectionalGRU": "Neural Networks",
        "Transformer": "Neural Networks",
        "Decision Tree": "Trees",
        "Random Forest": "Trees",
        "XGBoost": "Trees",
    }
)

# %%
df_copy["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split', 'Time Series Split'], dtype=object)

# %%
df_copy["Features"].unique()
# Out:
# array(['Chemical + Mineralogical', 'Chemical + Mineralogical + Physical',
#        'Chemical + Mineralogical + Physical - Early CS'], dtype=object)

# %%
df_copy["Model"].unique()
# Out:
# array(['Neural Networks', 'Conv1D'], dtype=object)

# %%
df_copy["Model_bkp"].unique()
# Out:
# array(['Transformer', 'MLP', 'BidirectionalLSTM', 'Conv1D', 'LSTM'],
#       dtype=object)

# %%
df_copy["Model_bkp_2"].unique()
# Out:
# array(['Transformer_7.0', 'MLP', 'BidirectionalLSTM_7.0', 'Conv1D_7.0',
#        'BidirectionalLSTM_1.0', 'LSTM_1.0', 'LSTM_7.0', 'Conv1D_14.0',
#        'Transformer_1.0', 'BidirectionalLSTM_14.0', 'Transformer_14.0',
#        'LSTM_14.0', 'Conv1D_1.0'], dtype=object)

# %%
df_copy.shape
# Out:
# (155, 29)

# %%
df_copy_grouped = df_copy.copy()

# %%
df_copy[
    [
        ("RMSE Test", "mean"),
        ("MAE Test", "mean"),
        ("MAPE Test", "mean"),
        ("R2 Test", "mean"),
    ]
].describe().round(2).T
# Out:
#                 count   mean     std       min   25%   50%   75%     max
# RMSE Test mean  155.0   5.46   36.26      0.71  1.65  2.05  2.84  453.49
# MAE Test  mean  155.0   3.41   20.03      0.54  1.23  1.56  2.06  250.83
# MAPE Test mean  155.0   7.66   43.69      1.34  2.86  3.60  4.71  547.28
# R2 Test   mean  155.0 -79.24  985.03 -12263.58 -0.04  0.67  0.93    0.98

# %%
df_copy["plant"].unique()
# Out:
# array(['c', 'f', 'ab', 'b', 'at', 's', 'am', 'w', 'k'], dtype=object)

# %%
df_copy["Features"].value_counts()
# Out:
# Features
# Chemical + Mineralogical + Physical               55
# Chemical + Mineralogical                          50
# Chemical + Mineralogical + Physical - Early CS    50
# Name: count, dtype: int64

# %%
df_copy[df_copy["plant"].eq("am")]["Features"].value_counts()
# Out:
# Features
# Chemical + Mineralogical + Physical - Early CS    5
# Name: count, dtype: int64

# %%
df_copy["plant"].value_counts()
# Out:
# plant
# c     30
# b     30
# at    30
# f     20
# s     20
# ab    10
# am     5
# w      5
# k      5
# Name: count, dtype: int64

# %% [markdown]
# # Global Analysis (fine tuning results)

# %% [markdown]
# ## ECICS

# %%
df_ecics_grouped = df_copy.copy()

# %%
df_results = df_ecics_grouped[
    [
        ("Company", ""),
        ("plant", ""),
        ("Cross Validation", ""),
        ("Features", ""),
        ('Features_bkp', ''),
        ("Model", ""),
        ("Model_bkp", ""),         
        ('Model_bkp_2',''),
        ("Timesteps", ""),
        ("RMSE Test", "mean"),
        ("MAE Test", "mean"),
        ("MAPE Test", "mean"),
        ("R2 Test", "mean"),
        ("RMSE Test", "std"),
        ("MAE Test", "std"),
        ("MAPE Test", "std"),
        ("R2 Test", "std"),
    ]
].copy()
df_results = df_results.reset_index(drop=True)

# Rename columns
new_column_names = [
    "Company",
    "Plant",
    "Cross Validation",
    "Features",
    "Features_bkp",
    "Model",
    "Model_bkp",
    "Model_bkp_2",
    "Timesteps",
    "RMSE_mean",
    "MAE_mean",
    "MAPE_mean",
    "R2_mean",
    "RMSE_std",
    "MAE_std",
    "MAPE_std",
    "R2_std",
]

df_results.columns = new_column_names

# %%
df_results.shape
# Out:
# (155, 17)

# %%
df_results["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split', 'Time Series Split'], dtype=object)

# %% [markdown]
# ## Variable Grouping: CM

# %% [markdown]
# #### Analysis of the best models identified in the Local Analysis

# %% [markdown]
# **Best models for variable groupping CM were from:**
#
# *BTiSS:*
#     Dominance analysis: Plant S
#     SCPM:Plant S
#
# *TiSS:*
#     Dominance analysis: Plant S
#     SCPM:Plant S

# %%
df_results["Features"].unique()
# Out:
# array(['Chemical + Mineralogical', 'Chemical + Mineralogical + Physical',
#        'Chemical + Mineralogical + Physical - Early CS'], dtype=object)

# %%
df_results_cm = (
    df_results[df_results["Features"].eq("Chemical + Mineralogical")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm["Features"].unique()
# Out:
# array(['Chemical + Mineralogical'], dtype=object)

# %%
df_results_cm.shape
# Out:
# (50, 17)

# %% [markdown]
# ### Blocking time series

# %%
df_results_cm["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split', 'Time Series Split'], dtype=object)

# %%
df_results_cm_btss = (
    df_results_cm[df_results_cm["Cross Validation"].eq("Blocking Time Series Split")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_btss["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split'], dtype=object)

# %%
df_results_cm_btss.shape
# Out:
# (25, 17)

# %% [markdown]
# ###### SCPM computation

# %%
df_results_cm_btss = compute_scpm(df_results_cm_btss)

# %% [markdown]
# ##### Dominance Analysis

# %%
# Per project
dominance_dict = make_dominance_analysis(df_results_cm_btss)
dominance_matrix_cm_btss = dominance_dict["dominance_matrix"]
dominance_graph_cm_btss = dominance_dict["dominance_graph"]
df_sorted_count = dominance_dict["df_sorted_count"]
df_sorted_topo = dominance_dict["df_sorted_topo"]

# %%
dominance_matrix_cm_btss.shape, len(dominance_graph_cm_btss)
# Out:
# ((25, 25), 25)

# %%
df_sorted_topo["Classification"].value_counts()
# Out:
# Classification
# intermediate_model    22
# dominant_model         2
# non_dominant_model     1
# Name: count, dtype: int64

# %%
# df_sorted_topo.to_csv(
#     "../../../../reports/results/global_models/ecics/ecics_209_s_dominance_analysis_cm_btss.csv",
#     index=False,
# )

# %%
df_sorted_topo.head(5)
# Out:
#     Company Plant            Cross Validation                  Features  \
# 20      209     s  Blocking Time Series Split  Chemical + Mineralogical
# 23      209     s  Blocking Time Series Split  Chemical + Mineralogical
# 22      209     s  Blocking Time Series Split  Chemical + Mineralogical
# 0       203     c  Blocking Time Series Split  Chemical + Mineralogical
# 3       203     c  Blocking Time Series Split  Chemical + Mineralogical
#
#    Features_bkp            Model    Model_bkp      Model_bkp_2  Timesteps  \
# 20     Chemical  Neural Networks  Transformer  Transformer_1.0        1.0
# 23     Chemical  Neural Networks          MLP              MLP        NaN
# 22     Chemical           Conv1D       Conv1D       Conv1D_7.0        7.0
# 0      Chemical  Neural Networks  Transformer  Transformer_7.0        7.0
# 3      Chemical  Neural Networks          MLP              MLP        NaN
#
#     RMSE_mean  ...  MAPE_mean   R2_mean  RMSE_std   MAE_std  MAPE_std  \
# 20   1.162410  ...   2.142578  0.946410  0.422754  0.235959  0.610615
# 23   1.213463  ...   2.326368  0.949241  0.137581  0.084595  0.223857
# 22   1.437166  ...   2.612071  0.929066  0.312455  0.202023  0.393569
# 0    2.070881  ...   3.262632  0.801263  1.701564  0.849215  2.633226
# 3    1.821639  ...   3.070525  0.898877  0.535745  0.323934  0.746508
#
#       R2_std      SCPM  Dominated_Count      Classification Dominates_Count
# 20  0.041380 -0.909737                0      dominant_model              23
# 23  0.011280 -0.905715                0      dominant_model              23
# 22  0.024494 -0.897757                2  intermediate_model              22
# 0   0.341221 -0.880159                3  intermediate_model              17
# 3   0.049300 -0.884689                3  intermediate_model              20
#
# [5 rows x 21 columns]

# %%
df_sorted_topo_cols = df_sorted_topo[
    [
        # "Model",
        # "Model_bkp",
        "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Classification",
        "Dominates_Count",
        "Plant",
    ]
].round(2)

# %% [markdown]
# ###### Dominant Models

# %%
# Top 4
df_sorted_topo_cols.iloc[0:5]
# Out:
#         Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 20  Transformer_1.0       1.16      0.42      0.86     0.24       2.14
# 23              MLP       1.21      0.14      0.94     0.08       2.33
# 22       Conv1D_7.0       1.44      0.31      1.08     0.20       2.61
# 0   Transformer_7.0       2.07      1.70      1.28     0.85       3.26
# 3               MLP       1.82      0.54      1.29     0.32       3.07
#
#     MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 20      0.61     0.95    0.04 -0.91                0      dominant_model
# 23      0.22     0.95    0.01 -0.91                0      dominant_model
# 22      0.39     0.93    0.02 -0.90                2  intermediate_model
# 0       2.63     0.80    0.34 -0.88                3  intermediate_model
# 3       0.75     0.90    0.05 -0.88                3  intermediate_model
#
#     Dominates_Count Plant
# 20               23     s
# 23               23     s
# 22               22     s
# 0                17     c
# 3                20     c

# %%
df_sorted_topo_cols[df_sorted_topo_cols["Classification"].eq("dominant_model")].shape
# Out:
# (2, 14)

# %% [markdown]
# ###### Intermediate models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].sort_values(by=["Dominates_Count", "SCPM"], ascending=[False, True]).iloc[:3]
# Out:
#          Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 22        Conv1D_7.0       1.44      0.31      1.08     0.20       2.61
# 3                MLP       1.82      0.54      1.29     0.32       3.07
# 5   Transformer_14.0       1.88      0.72      1.43     0.43       3.36
#
#     MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 22      0.39     0.93    0.02 -0.90                2  intermediate_model
# 3       0.75     0.90    0.05 -0.88                3  intermediate_model
# 5       1.06     0.85    0.18 -0.88                4  intermediate_model
#
#     Dominates_Count Plant
# 22               22     s
# 3                20     c
# 5                18    ab

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].shape
# Out:
# (22, 14)

# %% [markdown]
# ###### non-dominant models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].sort_values(by=["Dominates_Count", "SCPM"], ascending=[False, True]).iloc[:2]
# Out:
#              Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 6  BidirectionalLSTM_7.0     453.49    308.53    250.83   162.35     547.28
#
#    MAPE_std   R2_mean   R2_std   SCPM  Dominated_Count      Classification  \
# 6     354.3 -12263.58  19055.3  19.59               24  non_dominant_model
#
#    Dominates_Count Plant
# 6                0    ab

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].shape
# Out:
# (1, 14)

# %% [markdown]
# ###### Statistics per model type

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        # "Model_bkp",
        # "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
        "Plant",
    ]
]  # .round(2)

# %%
df_sorted_topo["Model"].value_counts()
# Out:
# Model
# Neural Networks    20
# Conv1D              5
# Name: count, dtype: int64

# %%
df_sorted_topo_models_grouped = df_sorted_topo_models_cols.groupby("Model").describe().T

# %%
# pd.set_option("display.max_rows", None)
# df_sorted_topo_models_grouped

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
    ]
]

# %%
(
    df_sorted_topo_models_cols.groupby("Model")[["Classification"]]
    .value_counts(normalize=True)
    .to_frame()
    * 100
).round(2)
# Out:
#                                     proportion
# Model           Classification
# Conv1D          intermediate_model       100.0
# Neural Networks intermediate_model        85.0
#                 dominant_model            10.0
#                 non_dominant_model         5.0

# %%
df_sorted_topo_models_cols.groupby("Model").describe().round(2).T
# Out:
# Model                  Conv1D  Neural Networks
# Dominated_Count count    5.00            20.00
#                 mean    10.80             9.75
#                 std      6.91             7.21
#                 min      2.00             0.00
#                 25%      8.00             4.00
#                 50%      9.00             8.50
#                 75%     15.00            12.50
#                 max     20.00            24.00
# Dominates_Count count    5.00            20.00
#                 mean     9.40            10.10
#                 std      7.67             7.41
#                 min      2.00             0.00
#                 25%      5.00             4.50
#                 50%      8.00             8.00
#                 75%     10.00            17.25
#                 max     22.00            23.00

# %%
# df_sorted_topo_models_cols

# %%
df_sorted_topo_models_cols.groupby("Model")["Classification"].describe()
# Out:
#                 count unique                 top freq
# Model
# Conv1D              5      1  intermediate_model    5
# Neural Networks    20      3  intermediate_model   17

# %%
df_sorted_topo_models_cols.groupby("Model")[["Classification"]].value_counts()
# Out:
# Model            Classification
# Conv1D           intermediate_model     5
# Neural Networks  intermediate_model    17
#                  dominant_model         2
#                  non_dominant_model     1
# Name: count, dtype: int64

# %%
# df_sorted_topo_models_cols

# %%
summary_stats = df_sorted_topo_models_cols.groupby("Model").agg(
    Total_Models=("Model", "count"),
    Mean_Dominance_Count=("Dominates_Count", "mean"),
    Median_Dominance_Count=("Dominates_Count", "median"),
    Total_Dominated=("Dominated_Count", "sum"),
    Total_Dominating=("Dominates_Count", "sum"),
)

total_models = summary_stats[
    "Total_Models"
].sum()  # Get the total number of models across all categories
summary_stats["Dominance Proportion"] = summary_stats["Total_Dominating"] / total_models

# %%
summary_stats
# Out:
#                  Total_Models  Mean_Dominance_Count  Median_Dominance_Count  \
# Model
# Conv1D                      5                   9.4                     8.0
# Neural Networks            20                  10.1                     8.0
#
#                  Total_Dominated  Total_Dominating  Dominance Proportion
# Model
# Conv1D                        54                47                  1.88
# Neural Networks              195               202                  8.08

# %%
df_sorted_topo_models_grouped.T
# Out:
#                 RMSE_mean                                             \
#                     count       mean         std       min       25%
# Model
# Conv1D                5.0   3.154597    1.266354  1.437166  2.967269
# Neural Networks      20.0  25.917390  100.670551  1.162410  2.019224
#
#                                                 RMSE_std             ...  \
#                       50%       75%         max    count       mean  ...
# Model                                                                ...
# Conv1D           3.075219  3.293655    4.999674      5.0   0.961512  ...
# Neural Networks  2.423043  3.902089  453.491348     20.0  16.749742  ...
#
#                 Dominated_Count       Dominates_Count                       \
#                             75%   max           count  mean       std  min
# Model
# Conv1D                     15.0  20.0             5.0   9.4  7.668116  2.0
# Neural Networks            12.5  24.0            20.0  10.1  7.411939  0.0
#
#
#                  25%  50%    75%   max
# Model
# Conv1D           5.0  8.0  10.00  22.0
# Neural Networks  4.5  8.0  17.25  23.0
#
# [2 rows x 88 columns]

# %% [markdown]
# ### SCPM Analysis

# %%
cols = [
    # "Model",
    # "Model_bkp",
    "Model_bkp_2",
    "RMSE_mean",
    "RMSE_std",
    "MAE_mean",
    "MAE_std",
    "MAPE_mean",
    "MAPE_std",
    "R2_mean",
    "R2_std",
    "SCPM",
    "Dominated_Count",
    "Dominates_Count",
    "Classification",
    "Plant",
]

# %% [markdown]
# #### SCPM Analysis by Project

# %%
df_sorted_scpm = df_sorted_topo.sort_values(by="SCPM").copy()

# %%
# (df_sorted_topo[cols].reset_index() == df_sorted_scpm[cols].reset_index()).all(axis=1)
df_sorted_scpm["topo_scmp_order_eq"] = df_sorted_topo.index == df_sorted_scpm.index

# %%
df_sorted_scpm[cols + ["topo_scmp_order_eq"]].round(2).head(5)
# Out:
#         Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 20  Transformer_1.0       1.16      0.42      0.86     0.24       2.14
# 23              MLP       1.21      0.14      0.94     0.08       2.33
# 22       Conv1D_7.0       1.44      0.31      1.08     0.20       2.61
# 3               MLP       1.82      0.54      1.29     0.32       3.07
# 0   Transformer_7.0       2.07      1.70      1.28     0.85       3.26
#
#     MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count  Dominates_Count  \
# 20      0.61     0.95    0.04 -0.91                0               23
# 23      0.22     0.95    0.01 -0.91                0               23
# 22      0.39     0.93    0.02 -0.90                2               22
# 3       0.75     0.90    0.05 -0.88                3               20
# 0       2.63     0.80    0.34 -0.88                3               17
#
#         Classification Plant  topo_scmp_order_eq
# 20      dominant_model     s                True
# 23      dominant_model     s                True
# 22  intermediate_model     s                True
# 3   intermediate_model     c               False
# 0   intermediate_model     c               False

# %% [markdown]
# ### Time Series Split

# %%
df_results_cm["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split', 'Time Series Split'], dtype=object)

# %%
df_results_cm_tss = (
    df_results_cm[df_results_cm["Cross Validation"].eq("Time Series Split")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_tss["Cross Validation"].unique()
# Out:
# array(['Time Series Split'], dtype=object)

# %%
df_results_cm_tss.shape
# Out:
# (25, 17)

# %% [markdown]
# ###### SCPM computation

# %%
df_results_cm_tss = compute_scpm(df_results_cm_tss)

# %% [markdown]
# ##### Dominance Analysis

# %%
# Per project
dominance_dict = make_dominance_analysis(df_results_cm_tss)
dominance_matrix_cm_tss = dominance_dict["dominance_matrix"]
dominance_graph_cm_tss = dominance_dict["dominance_graph"]
df_sorted_count = dominance_dict["df_sorted_count"]
df_sorted_topo = dominance_dict["df_sorted_topo"]

# %%
dominance_matrix_cm_tss.shape, len(dominance_graph_cm_tss)
# Out:
# ((25, 25), 25)

# %%
df_sorted_topo["Classification"].value_counts()
# Out:
# Classification
# intermediate_model    23
# dominant_model         1
# non_dominant_model     1
# Name: count, dtype: int64

# %%
# df_sorted_topo.to_csv(
#     "../../../../reports/results/global_models/ecics/ecics_209_s_dominance_analysis_cm_tss.csv",
#     index=False,
# )

# %%
df_sorted_topo.head(5)
# Out:
#     Company Plant   Cross Validation                  Features Features_bkp  \
# 20      209     s  Time Series Split  Chemical + Mineralogical     Chemical
# 5       204     f  Time Series Split  Chemical + Mineralogical     Chemical
# 23      209     s  Time Series Split  Chemical + Mineralogical     Chemical
# 8       204     f  Time Series Split  Chemical + Mineralogical     Chemical
# 22      209     s  Time Series Split  Chemical + Mineralogical     Chemical
#
#               Model    Model_bkp      Model_bkp_2  Timesteps  RMSE_mean  ...  \
# 20  Neural Networks  Transformer  Transformer_1.0        1.0   1.311009  ...
# 5   Neural Networks  Transformer  Transformer_1.0        1.0   1.741329  ...
# 23  Neural Networks          MLP              MLP        NaN   1.387445  ...
# 8   Neural Networks          MLP              MLP        NaN   1.791195  ...
# 22           Conv1D       Conv1D       Conv1D_7.0        7.0   1.557909  ...
#
#     MAPE_mean   R2_mean  RMSE_std   MAE_std  MAPE_std    R2_std      SCPM  \
# 20   2.147842  0.935433  0.216608  0.097950  0.192730  0.019644 -3.197405
# 5    2.935762  0.934552  0.236479  0.198124  0.448636  0.016690 -2.500113
# 23   2.446752  0.926810  0.355405  0.238475  0.506784  0.033572 -2.984878
# 8    3.229860  0.930404  0.260330  0.208885  0.500730  0.019883 -2.317810
# 22   2.823972  0.910436  0.148739  0.112064  0.215531  0.011473 -2.679780
#
#     Dominated_Count      Classification Dominates_Count
# 20                0      dominant_model              24
# 5                 1  intermediate_model              21
# 23                1  intermediate_model              21
# 8                 2  intermediate_model              20
# 22                2  intermediate_model              20
#
# [5 rows x 21 columns]

# %%
df_sorted_topo_cols = df_sorted_topo[
    [
        # "Model",
        # "Model_bkp",
        "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Classification",
        "Dominates_Count",
        "Plant",
    ]
]  # .round(2)

# %% [markdown]
# ###### Dominant Models

# %%
# Top 4
df_sorted_topo_cols.iloc[0:2].sort_values(by="Dominates_Count", ascending=False).round(
    2
)
# Out:
#         Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 20  Transformer_1.0       1.31      0.22      0.88      0.1       2.15
# 5   Transformer_1.0       1.74      0.24      1.27      0.2       2.94
#
#     MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 20      0.19     0.94    0.02  -3.2                0      dominant_model
# 5       0.45     0.93    0.02  -2.5                1  intermediate_model
#
#     Dominates_Count Plant
# 20               24     s
# 5                21     f

# %%
df_sorted_topo_cols[df_sorted_topo_cols["Classification"].eq("dominant_model")].shape
# Out:
# (1, 14)

# %% [markdown]
# ###### Intermediate models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].sort_values(by=["Dominates_Count", "SCPM"], ascending=[False, True]).iloc[:4].round(2)
# Out:
#         Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 23              MLP       1.39      0.36      1.00     0.24       2.45
# 5   Transformer_1.0       1.74      0.24      1.27     0.20       2.94
# 22       Conv1D_7.0       1.56      0.15      1.16     0.11       2.82
# 8               MLP       1.79      0.26      1.36     0.21       3.23
#
#     MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 23      0.51     0.93    0.03 -2.98                1  intermediate_model
# 5       0.45     0.93    0.02 -2.50                1  intermediate_model
# 22      0.22     0.91    0.01 -2.68                2  intermediate_model
# 8       0.50     0.93    0.02 -2.32                2  intermediate_model
#
#     Dominates_Count Plant
# 23               21     s
# 5                21     f
# 22               20     s
# 8                20     f

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].shape
# Out:
# (23, 14)

# %% [markdown]
# ###### non-dominant models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].sort_values(by=["Dominates_Count", "SCPM"], ascending=[False, True]).iloc[:3]
# Out:
#                Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean   MAE_std  \
# 16  BidirectionalLSTM_14.0  13.725374   6.50983  7.997681  2.775789
#
#     MAPE_mean  MAPE_std    R2_mean     R2_std       SCPM  Dominated_Count  \
# 16  17.917479  5.967878 -37.589314  47.748064  16.938688               24
#
#         Classification  Dominates_Count Plant
# 16  non_dominant_model                0    at

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].shape
# Out:
# (1, 14)

# %% [markdown]
# ###### Statistics per model type

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        # "Model_bkp",
        # "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
        "Plant",
    ]
]  # .round(2)

# %%
df_sorted_topo["Model"].value_counts()
# Out:
# Model
# Neural Networks    20
# Conv1D              5
# Name: count, dtype: int64

# %%
df_sorted_topo_models_grouped = df_sorted_topo_models_cols.groupby("Model").describe().T

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
    ]
]

# %%
(
    df_sorted_topo_models_cols.groupby("Model")[["Classification"]]
    .value_counts(normalize=True)
    .to_frame()
    * 100
).round(2)
# Out:
#                                     proportion
# Model           Classification
# Conv1D          intermediate_model       100.0
# Neural Networks intermediate_model        90.0
#                 dominant_model             5.0
#                 non_dominant_model         5.0

# %%
df_sorted_topo_models_cols.groupby("Model").describe().round(2).T
# Out:
# Model                  Conv1D  Neural Networks
# Dominated_Count count    5.00            20.00
#                 mean     9.40             9.70
#                 std      6.50             7.05
#                 min      2.00             0.00
#                 25%      5.00             5.00
#                 50%     10.00             7.50
#                 75%     11.00            17.00
#                 max     19.00            24.00
# Dominates_Count count    5.00            20.00
#                 mean    10.20             9.50
#                 std      7.79             7.47
#                 min      1.00             0.00
#                 25%      5.00             2.75
#                 50%      9.00             8.00
#                 75%     16.00            12.25
#                 max     20.00            24.00

# %%
# df_sorted_topo_models_cols

# %%
df_sorted_topo_models_cols.groupby("Model")["Classification"].describe()
# Out:
#                 count unique                 top freq
# Model
# Conv1D              5      1  intermediate_model    5
# Neural Networks    20      3  intermediate_model   18

# %%
df_sorted_topo_models_cols.groupby("Model")[["Classification"]].value_counts()
# Out:
# Model            Classification
# Conv1D           intermediate_model     5
# Neural Networks  intermediate_model    18
#                  dominant_model         1
#                  non_dominant_model     1
# Name: count, dtype: int64

# %%
summary_stats = df_sorted_topo_models_cols.groupby("Model").agg(
    Total_Models=("Model", "count"),
    Mean_Dominance_Count=("Dominates_Count", "mean"),
    Median_Dominance_Count=("Dominates_Count", "median"),
    Total_Dominated=("Dominated_Count", "sum"),
    Total_Dominating=("Dominates_Count", "sum"),
)

total_models = summary_stats[
    "Total_Models"
].sum()  # Get the total number of models across all categories
summary_stats["Dominance Proportion"] = summary_stats["Total_Dominating"] / total_models

# %%
summary_stats.round(2)
# Out:
#                  Total_Models  Mean_Dominance_Count  Median_Dominance_Count  \
# Model
# Conv1D                      5                  10.2                     9.0
# Neural Networks            20                   9.5                     8.0
#
#                  Total_Dominated  Total_Dominating  Dominance Proportion
# Model
# Conv1D                        47                51                  2.04
# Neural Networks              194               190                  7.60

# %%
df_sorted_topo_models_grouped.T
# Out:
#                 RMSE_mean                                                    \
#                     count      mean       std       min       25%       50%
# Model
# Conv1D                5.0  2.847972  1.194107  1.557909  2.020378  2.451850
# Neural Networks      20.0  3.597318  2.845631  1.311009  1.986867  2.905258
#
#                                      RMSE_std            ... Dominated_Count  \
#                       75%        max    count      mean  ...             75%
# Model                                                    ...
# Conv1D           3.967133   4.242589      5.0  0.659429  ...            11.0
# Neural Networks  3.730361  13.725374     20.0  1.214478  ...            17.0
#
#                       Dominates_Count                                         \
#                   max           count  mean       std  min   25%  50%    75%
# Model
# Conv1D           19.0             5.0  10.2  7.791020  1.0  5.00  9.0  16.00
# Neural Networks  24.0            20.0   9.5  7.465711  0.0  2.75  8.0  12.25
#
#
#                   max
# Model
# Conv1D           20.0
# Neural Networks  24.0
#
# [2 rows x 88 columns]

# %% [markdown]
# ### SCPM Analysis

# %%
cols = [
    # "Model",
    # "Model_bkp",
    "Model_bkp_2",
    "RMSE_mean",
    "RMSE_std",
    "MAE_mean",
    "MAE_std",
    "MAPE_mean",
    "MAPE_std",
    "R2_mean",
    "R2_std",
    "SCPM",
    "Dominated_Count",
    "Dominates_Count",
    "Classification",
    "Plant",
]

# %% [markdown]
# #### SCPM Analysis by Project

# %%
df_sorted_scpm = df_sorted_topo.sort_values(by="SCPM").copy()

# %%
# (df_sorted_topo[cols].reset_index() == df_sorted_scpm[cols].reset_index()).all(axis=1)
df_sorted_scpm["topo_scmp_order_eq"] = df_sorted_topo.index == df_sorted_scpm.index

# %%
df_sorted_scpm[cols + ["topo_scmp_order_eq"]].round(2).head(5)
# Out:
#         Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 20  Transformer_1.0       1.31      0.22      0.88     0.10       2.15
# 23              MLP       1.39      0.36      1.00     0.24       2.45
# 22       Conv1D_7.0       1.56      0.15      1.16     0.11       2.82
# 5   Transformer_1.0       1.74      0.24      1.27     0.20       2.94
# 8               MLP       1.79      0.26      1.36     0.21       3.23
#
#     MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count  Dominates_Count  \
# 20      0.19     0.94    0.02 -3.20                0               24
# 23      0.51     0.93    0.03 -2.98                1               21
# 22      0.22     0.91    0.01 -2.68                2               20
# 5       0.45     0.93    0.02 -2.50                1               21
# 8       0.50     0.93    0.02 -2.32                2               20
#
#         Classification Plant  topo_scmp_order_eq
# 20      dominant_model     s                True
# 23  intermediate_model     s               False
# 22  intermediate_model     s               False
# 5   intermediate_model     f               False
# 8   intermediate_model     f               False

# %% [markdown]
# ## Variable Grouping: CM-P

# %% [markdown]
# #### Analysis of the best models identified in the Local Analysis

# %% [markdown]
# **Best models for variable groupping CM-P were from:**
#
# *BTiSS:*
#     Dominance analysis: Plant AM
#     SCPM:Plant AM
#
# *TiSS:*
#     Dominance analysis: Plant W
#     SCPM:Plant W

# %%
df_results["Features"].unique()
# Out:
# array(['Chemical + Mineralogical', 'Chemical + Mineralogical + Physical',
#        'Chemical + Mineralogical + Physical - Early CS'], dtype=object)

# %%
df_results_cm_p = (
    df_results[
        df_results["Features"].eq("Chemical + Mineralogical + Physical - Early CS")
    ]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_p["Features"].unique()
# Out:
# array(['Chemical + Mineralogical + Physical - Early CS'], dtype=object)

# %%
df_results_cm_p.shape
# Out:
# (50, 17)

# %% [markdown]
# ### Blocking time series

# %%
df_results_cm_p["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split', 'Time Series Split'], dtype=object)

# %%
df_results_cm_p_btss = (
    df_results_cm_p[
        df_results_cm_p["Cross Validation"].eq("Blocking Time Series Split")
    ]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_p_btss["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split'], dtype=object)

# %%
df_results_cm_p_btss.shape
# Out:
# (25, 17)

# %% [markdown]
# ###### SCPM computation

# %%
df_results_cm_p_btss = compute_scpm(df_results_cm_p_btss)

# %% [markdown]
# ##### Dominance Analysis

# %%
# Per project
dominance_dict = make_dominance_analysis(df_results_cm_p_btss)
dominance_matrix_cm_p_btss = dominance_dict["dominance_matrix"]
dominance_graph_cm_p_btss = dominance_dict["dominance_graph"]
df_sorted_count = dominance_dict["df_sorted_count"]
df_sorted_topo = dominance_dict["df_sorted_topo"]

# %%
dominance_matrix_cm_p_btss.shape, len(dominance_graph_cm_p_btss)
# Out:
# ((25, 25), 25)

# %%
df_sorted_topo["Classification"].value_counts()
# Out:
# Classification
# intermediate_model    23
# dominant_model         1
# non_dominant_model     1
# Name: count, dtype: int64

# %%
# df_sorted_topo.to_csv(
#     "../../../../reports/results/global_models/ecics/ecics_209_am_dominance_analysis_cm_p_btss.csv",
#     index=False,
# )

# %%
df_sorted_topo.head(5)
# Out:
#     Company Plant            Cross Validation  \
# 20      209    am  Blocking Time Series Split
# 4       203     c  Blocking Time Series Split
# 5       204     f  Blocking Time Series Split
# 23      209    am  Blocking Time Series Split
# 2       203     c  Blocking Time Series Split
#
#                                           Features  \
# 20  Chemical + Mineralogical + Physical - Early CS
# 4   Chemical + Mineralogical + Physical - Early CS
# 5   Chemical + Mineralogical + Physical - Early CS
# 23  Chemical + Mineralogical + Physical - Early CS
# 2   Chemical + Mineralogical + Physical - Early CS
#
#                      Features_bkp            Model    Model_bkp  \
# 20  Chemical + Properties CS Less  Neural Networks          MLP
# 4   Chemical + Properties CS Less  Neural Networks  Transformer
# 5   Chemical + Properties CS Less  Neural Networks          MLP
# 23  Chemical + Properties CS Less           Conv1D       Conv1D
# 2   Chemical + Properties CS Less  Neural Networks         LSTM
#
#         Model_bkp_2  Timesteps  RMSE_mean  ...  MAPE_mean   R2_mean  RMSE_std  \
# 20              MLP        NaN   0.977688  ...   1.817851  0.972777  0.079910
# 4   Transformer_1.0        1.0   1.375060  ...   2.090569  0.943194  0.296677
# 5               MLP        NaN   1.372538  ...   2.516835  0.957256  0.295185
# 23       Conv1D_7.0        7.0   1.321790  ...   2.439990  0.951914  0.151181
# 2          LSTM_1.0        1.0   1.499910  ...   2.547190  0.933078  0.297040
#
#      MAE_std  MAPE_std    R2_std      SCPM  Dominated_Count  \
# 20  0.055835  0.125100  0.002697 -5.601157                0
# 4   0.146197  0.293774  0.021891 -4.441716                1
# 5   0.228292  0.564297  0.018385 -3.613390                1
# 23  0.094707  0.219578  0.007694 -3.905356                1
# 2   0.098587  0.237979  0.026938 -3.392459                3
#
#         Classification Dominates_Count
# 20      dominant_model              24
# 4   intermediate_model              19
# 5   intermediate_model              18
# 23  intermediate_model              21
# 2   intermediate_model              15
#
# [5 rows x 21 columns]

# %%
df_sorted_topo_cols = df_sorted_topo[
    [
        # "Model",
        # "Model_bkp",
        "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Classification",
        "Dominates_Count",
        "Plant",
    ]
].round(2)

# %% [markdown]
# ###### Dominant Models

# %%
# Top 4
df_sorted_topo_cols.iloc[0:5]
# Out:
#         Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 20              MLP       0.98      0.08      0.75     0.06       1.82
# 4   Transformer_1.0       1.38      0.30      0.87     0.15       2.09
# 5               MLP       1.37      0.30      1.08     0.23       2.52
# 23       Conv1D_7.0       1.32      0.15      1.01     0.09       2.44
# 2          LSTM_1.0       1.50      0.30      1.06     0.10       2.55
#
#     MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 20      0.13     0.97    0.00 -5.60                0      dominant_model
# 4       0.29     0.94    0.02 -4.44                1  intermediate_model
# 5       0.56     0.96    0.02 -3.61                1  intermediate_model
# 23      0.22     0.95    0.01 -3.91                1  intermediate_model
# 2       0.24     0.93    0.03 -3.39                3  intermediate_model
#
#     Dominates_Count Plant
# 20               24    am
# 4                19     c
# 5                18     f
# 23               21    am
# 2                15     c

# %%
df_sorted_topo_cols[df_sorted_topo_cols["Classification"].eq("dominant_model")].shape
# Out:
# (1, 14)

# %% [markdown]
# ###### Intermediate models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].sort_values(by=["Dominates_Count", "SCPM"], ascending=[False, True]).iloc[:3]
# Out:
#         Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 23       Conv1D_7.0       1.32      0.15      1.01     0.09       2.44
# 4   Transformer_1.0       1.38      0.30      0.87     0.15       2.09
# 5               MLP       1.37      0.30      1.08     0.23       2.52
#
#     MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 23      0.22     0.95    0.01 -3.91                1  intermediate_model
# 4       0.29     0.94    0.02 -4.44                1  intermediate_model
# 5       0.56     0.96    0.02 -3.61                1  intermediate_model
#
#     Dominates_Count Plant
# 23               21    am
# 4                19     c
# 5                18     f

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].shape
# Out:
# (23, 14)

# %% [markdown]
# ###### non-dominant models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].sort_values(by=["Dominates_Count", "SCPM"], ascending=[False, True]).iloc[:2]
# Out:
#    Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  MAPE_std  \
# 12    LSTM_1.0       3.41      0.94      2.68     0.95       5.98      1.88
#
#     R2_mean  R2_std   SCPM  Dominated_Count      Classification  \
# 12    -3.31    5.94  10.89               24  non_dominant_model
#
#     Dominates_Count Plant
# 12                0     b

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].shape
# Out:
# (1, 14)

# %% [markdown]
# ###### Statistics per model type

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        # "Model_bkp",
        # "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
        "Plant",
    ]
]  # .round(2)

# %%
df_sorted_topo["Model"].value_counts()
# Out:
# Model
# Neural Networks    20
# Conv1D              5
# Name: count, dtype: int64

# %%
df_sorted_topo_models_grouped = df_sorted_topo_models_cols.groupby("Model").describe().T

# %%
# pd.set_option("display.max_rows", None)
# df_sorted_topo_models_grouped

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
    ]
]

# %%
(
    df_sorted_topo_models_cols.groupby("Model")[["Classification"]]
    .value_counts(normalize=True)
    .to_frame()
    * 100
).round(2)
# Out:
#                                     proportion
# Model           Classification
# Conv1D          intermediate_model       100.0
# Neural Networks intermediate_model        90.0
#                 dominant_model             5.0
#                 non_dominant_model         5.0

# %%
df_sorted_topo_models_cols.groupby("Model").describe().round(2).T
# Out:
# Model                  Conv1D  Neural Networks
# Dominated_Count count    5.00            20.00
#                 mean     9.60             9.35
#                 std      6.11             6.84
#                 min      1.00             0.00
#                 25%      6.00             3.00
#                 50%     11.00            11.00
#                 75%     14.00            12.00
#                 max     16.00            24.00
# Dominates_Count count    5.00            20.00
#                 mean     9.40             9.40
#                 std      8.17             7.70
#                 min      3.00             0.00
#                 25%      3.00             3.25
#                 50%      5.00             6.00
#                 75%     15.00            15.50
#                 max     21.00            24.00

# %%
# df_sorted_topo_models_cols

# %%
df_sorted_topo_models_cols.groupby("Model")["Classification"].describe()
# Out:
#                 count unique                 top freq
# Model
# Conv1D              5      1  intermediate_model    5
# Neural Networks    20      3  intermediate_model   18

# %%
df_sorted_topo_models_cols.groupby("Model")[["Classification"]].value_counts()
# Out:
# Model            Classification
# Conv1D           intermediate_model     5
# Neural Networks  intermediate_model    18
#                  dominant_model         1
#                  non_dominant_model     1
# Name: count, dtype: int64

# %%
# df_sorted_topo_models_cols

# %%
summary_stats = df_sorted_topo_models_cols.groupby("Model").agg(
    Total_Models=("Model", "count"),
    Mean_Dominance_Count=("Dominates_Count", "mean"),
    Median_Dominance_Count=("Dominates_Count", "median"),
    Total_Dominated=("Dominated_Count", "sum"),
    Total_Dominating=("Dominates_Count", "sum"),
)

total_models = summary_stats[
    "Total_Models"
].sum()  # Get the total number of models across all categories
summary_stats["Dominance Proportion"] = summary_stats["Total_Dominating"] / total_models

# %%
summary_stats
# Out:
#                  Total_Models  Mean_Dominance_Count  Median_Dominance_Count  \
# Model
# Conv1D                      5                   9.4                     5.0
# Neural Networks            20                   9.4                     6.0
#
#                  Total_Dominated  Total_Dominating  Dominance Proportion
# Model
# Conv1D                        48                47                  1.88
# Neural Networks              187               188                  7.52

# %%
df_sorted_topo_models_grouped.T
# Out:
#                 RMSE_mean                                                    \
#                     count      mean       std       min       25%       50%
# Model
# Conv1D                5.0  1.934973  0.516749  1.321790  1.420810  2.279616
# Neural Networks      20.0  2.055055  0.693566  0.977688  1.474158  2.015422
#
#                                     RMSE_std            ... Dominated_Count  \
#                       75%       max    count      mean  ...             75%
# Model                                                   ...
# Conv1D           2.289793  2.362857      5.0  0.579923  ...            14.0
# Neural Networks  2.656925  3.406710     20.0  0.634770  ...            12.0
#
#                       Dominates_Count                                       \
#                   max           count mean       std  min   25%  50%   75%
# Model
# Conv1D           16.0             5.0  9.4  8.173127  3.0  3.00  5.0  15.0
# Neural Networks  24.0            20.0  9.4  7.700991  0.0  3.25  6.0  15.5
#
#
#                   max
# Model
# Conv1D           21.0
# Neural Networks  24.0
#
# [2 rows x 88 columns]

# %% [markdown]
# ### SCPM Analysis

# %%
cols = [
    # "Model",
    # "Model_bkp",
    "Model_bkp_2",
    "RMSE_mean",
    "RMSE_std",
    "MAE_mean",
    "MAE_std",
    "MAPE_mean",
    "MAPE_std",
    "R2_mean",
    "R2_std",
    "SCPM",
    "Dominated_Count",
    "Dominates_Count",
    "Classification",
    "Plant",
]

# %% [markdown]
# #### SCPM Analysis by Project

# %%
df_sorted_scpm = df_sorted_topo.sort_values(by="SCPM").copy()

# %%
# (df_sorted_topo[cols].reset_index() == df_sorted_scpm[cols].reset_index()).all(axis=1)
df_sorted_scpm["topo_scmp_order_eq"] = df_sorted_topo.index == df_sorted_scpm.index

# %%
df_sorted_scpm[cols + ["topo_scmp_order_eq"]].round(2).head(5)
# Out:
#         Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 20              MLP       0.98      0.08      0.75     0.06       1.82
# 4   Transformer_1.0       1.38      0.30      0.87     0.15       2.09
# 23       Conv1D_7.0       1.32      0.15      1.01     0.09       2.44
# 5               MLP       1.37      0.30      1.08     0.23       2.52
# 24  Transformer_1.0       1.37      0.24      1.06     0.21       2.58
#
#     MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count  Dominates_Count  \
# 20      0.13     0.97    0.00 -5.60                0               24
# 4       0.29     0.94    0.02 -4.44                1               19
# 23      0.22     0.95    0.01 -3.91                1               21
# 5       0.56     0.96    0.02 -3.61                1               18
# 24      0.51     0.94    0.03 -3.59                2               18
#
#         Classification Plant  topo_scmp_order_eq
# 20      dominant_model    am                True
# 4   intermediate_model     c                True
# 23  intermediate_model    am               False
# 5   intermediate_model     f               False
# 24  intermediate_model    am               False

# %% [markdown]
# ### Time Series Split

# %%
df_results_cm_p = (
    df_results[
        df_results["Features"].eq("Chemical + Mineralogical + Physical - Early CS")
    ]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_p["Features"].unique()
# Out:
# array(['Chemical + Mineralogical + Physical - Early CS'], dtype=object)

# %%
df_results_cm_p.shape
# Out:
# (50, 17)

# %%
df_results_cm["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split', 'Time Series Split'], dtype=object)

# %%
df_results_cm_p_tss = (
    df_results_cm_p[df_results_cm_p["Cross Validation"].eq("Time Series Split")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_p_tss["Cross Validation"].unique()
# Out:
# array(['Time Series Split'], dtype=object)

# %%
df_results_cm_p_tss.shape
# Out:
# (25, 17)

# %% [markdown]
# ###### SCPM computation

# %%
df_results_cm_p_tss = compute_scpm(df_results_cm_p_tss)

# %% [markdown]
# ##### Dominance Analysis

# %%
# Per project
dominance_dict = make_dominance_analysis(df_results_cm_p_tss)
dominance_matrix_cm_p_tss = dominance_dict["dominance_matrix"]
dominance_graph_cm_p_tss = dominance_dict["dominance_graph"]
df_sorted_count = dominance_dict["df_sorted_count"]
df_sorted_topo = dominance_dict["df_sorted_topo"]

# %%
dominance_matrix_cm_tss.shape, len(dominance_graph_cm_tss)
# Out:
# ((25, 25), 25)

# %%
df_sorted_topo["Classification"].value_counts()
# Out:
# Classification
# intermediate_model    19
# dominant_model         3
# non_dominant_model     3
# Name: count, dtype: int64

# %%
# df_sorted_topo.to_csv(
#     "../../../../reports/results/global_models/ecics/ecics_209_w_dominance_analysis_cm_p_tss.csv",
#     index=False,
# )

# %%
df_sorted_topo.head(5)
# Out:
#     Company Plant   Cross Validation  \
# 5       204     f  Time Series Split
# 9       204     f  Time Series Split
# 20      209     w  Time Series Split
# 8       204     f  Time Series Split
# 22      209     w  Time Series Split
#
#                                           Features  \
# 5   Chemical + Mineralogical + Physical - Early CS
# 9   Chemical + Mineralogical + Physical - Early CS
# 20  Chemical + Mineralogical + Physical - Early CS
# 8   Chemical + Mineralogical + Physical - Early CS
# 22  Chemical + Mineralogical + Physical - Early CS
#
#                      Features_bkp            Model    Model_bkp  \
# 5   Chemical + Properties CS Less  Neural Networks          MLP
# 9   Chemical + Properties CS Less  Neural Networks  Transformer
# 20  Chemical + Properties CS Less  Neural Networks          MLP
# 8   Chemical + Properties CS Less           Conv1D       Conv1D
# 22  Chemical + Properties CS Less  Neural Networks         LSTM
#
#         Model_bkp_2  Timesteps  RMSE_mean  ...  MAPE_mean   R2_mean  RMSE_std  \
# 5               MLP        NaN   1.626909  ...   3.036724  0.942175  0.273138
# 9   Transformer_1.0        1.0   1.638910  ...   2.901188  0.940758  0.317922
# 20              MLP        NaN   1.317312  ...   2.463852  0.931815  0.244525
# 8        Conv1D_7.0        7.0   1.753235  ...   3.195430  0.930707  0.307386
# 22         LSTM_7.0        7.0   1.660127  ...   2.971102  0.887714  0.438231
#
#      MAE_std  MAPE_std    R2_std      SCPM  Dominated_Count  \
# 5   0.197504  0.477115  0.020827 -3.297952                0
# 9   0.223103  0.511231  0.022433 -3.445487                0
# 20  0.193443  0.375366  0.026493 -4.506880                0
# 8   0.236634  0.523346  0.022692 -2.824788                3
# 22  0.291369  0.646294  0.058431 -3.266957                2
#
#         Classification Dominates_Count
# 5       dominant_model              21
# 9       dominant_model              22
# 20      dominant_model              22
# 8   intermediate_model              19
# 22  intermediate_model              19
#
# [5 rows x 21 columns]

# %%
df_sorted_topo_cols = df_sorted_topo[
    [
        # "Model",
        # "Model_bkp",
        "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Classification",
        "Dominates_Count",
        "Plant",
    ]
]  # .round(2)

# %% [markdown]
# ###### Dominant Models

# %%
# Top 4
df_sorted_topo_cols.iloc[0:2].sort_values(by="Dominates_Count", ascending=False).round(
    2
)
# Out:
#        Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 9  Transformer_1.0       1.64      0.32      1.26     0.22       2.90
# 5              MLP       1.63      0.27      1.29     0.20       3.04
#
#    MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count  Classification  \
# 9      0.51     0.94    0.02 -3.45                0  dominant_model
# 5      0.48     0.94    0.02 -3.30                0  dominant_model
#
#    Dominates_Count Plant
# 9               22     f
# 5               21     f

# %%
df_sorted_topo_cols[df_sorted_topo_cols["Classification"].eq("dominant_model")].shape
# Out:
# (3, 14)

# %% [markdown]
# ###### Intermediate models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].sort_values(by=["Dominates_Count", "SCPM"], ascending=[False, True]).iloc[:4].round(2)
# Out:
#               Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 22               LSTM_7.0       1.66      0.44      1.27     0.29       2.97
# 8              Conv1D_7.0       1.75      0.31      1.40     0.24       3.20
# 21  BidirectionalLSTM_1.0       1.87      0.58      1.42     0.41       3.28
# 4         Transformer_1.0       2.00      0.40      1.37     0.23       3.15
#
#     MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 22      0.65     0.89    0.06 -3.27                2  intermediate_model
# 8       0.52     0.93    0.02 -2.82                3  intermediate_model
# 21      0.93     0.85    0.09 -2.48                5  intermediate_model
# 4       0.52     0.88    0.04 -2.59                4  intermediate_model
#
#     Dominates_Count Plant
# 22               19     w
# 8                19     f
# 21               14     w
# 4                13     c

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].shape
# Out:
# (19, 14)

# %% [markdown]
# ###### non-dominant models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].sort_values(by=["Dominates_Count", "SCPM"], ascending=[False, True]).iloc[:3]
# Out:
#               Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean   MAE_std  MAPE_mean  \
# 1   BidirectionalLSTM_1.0   5.702331  3.531040  2.016202  0.266670   4.662165
# 16  BidirectionalLSTM_1.0   4.276940  1.591414  3.100156  0.948780   6.951162
# 18            Conv1D_14.0   4.167680  1.181910  3.329923  1.021107   7.550541
#
#     MAPE_std   R2_mean    R2_std       SCPM  Dominated_Count  \
# 1   0.697932 -0.333849  1.696471   5.404330               17
# 16  2.304203 -1.250738  1.117185   9.199412               22
# 18  2.237200 -1.263940  1.299202  10.013210               22
#
#         Classification  Dominates_Count Plant
# 1   non_dominant_model                0     c
# 16  non_dominant_model                0    at
# 18  non_dominant_model                0    at

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].shape
# Out:
# (3, 14)

# %% [markdown]
# ###### Statistics per model type

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        # "Model_bkp",
        # "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
        "Plant",
    ]
]  # .round(2)

# %%
df_sorted_topo["Model"].value_counts()
# Out:
# Model
# Neural Networks    20
# Conv1D              5
# Name: count, dtype: int64

# %%
df_sorted_topo_models_grouped = df_sorted_topo_models_cols.groupby("Model").describe().T

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
    ]
]

# %%
(
    df_sorted_topo_models_cols.groupby("Model")[["Classification"]]
    .value_counts(normalize=True)
    .to_frame()
    * 100
).round(2)
# Out:
#                                     proportion
# Model           Classification
# Conv1D          intermediate_model        80.0
#                 non_dominant_model        20.0
# Neural Networks intermediate_model        75.0
#                 dominant_model            15.0
#                 non_dominant_model        10.0

# %%
df_sorted_topo_models_cols.groupby("Model").describe().round(2).T
# Out:
# Model                  Conv1D  Neural Networks
# Dominated_Count count    5.00            20.00
#                 mean    10.80             8.85
#                 std      6.98             6.94
#                 min      3.00             0.00
#                 25%      8.00             4.00
#                 50%     10.00             7.00
#                 75%     11.00            13.75
#                 max     22.00            22.00
# Dominates_Count count    5.00            20.00
#                 mean     7.40             9.70
#                 std      7.23             7.20
#                 min      0.00             0.00
#                 25%      3.00             3.75
#                 50%      7.00             9.50
#                 75%      8.00            13.25
#                 max     19.00            22.00

# %%
# df_sorted_topo_models_cols

# %%
df_sorted_topo_models_cols.groupby("Model")["Classification"].describe()
# Out:
#                 count unique                 top freq
# Model
# Conv1D              5      2  intermediate_model    4
# Neural Networks    20      3  intermediate_model   15

# %%
df_sorted_topo_models_cols.groupby("Model")[["Classification"]].value_counts()
# Out:
# Model            Classification
# Conv1D           intermediate_model     4
#                  non_dominant_model     1
# Neural Networks  intermediate_model    15
#                  dominant_model         3
#                  non_dominant_model     2
# Name: count, dtype: int64

# %%
summary_stats = df_sorted_topo_models_cols.groupby("Model").agg(
    Total_Models=("Model", "count"),
    Mean_Dominance_Count=("Dominates_Count", "mean"),
    Median_Dominance_Count=("Dominates_Count", "median"),
    Total_Dominated=("Dominated_Count", "sum"),
    Total_Dominating=("Dominates_Count", "sum"),
)

total_models = summary_stats[
    "Total_Models"
].sum()  # Get the total number of models across all categories
summary_stats["Dominance Proportion"] = summary_stats["Total_Dominating"] / total_models

# %%
summary_stats.round(2)
# Out:
#                  Total_Models  Mean_Dominance_Count  Median_Dominance_Count  \
# Model
# Conv1D                      5                   7.4                     7.0
# Neural Networks            20                   9.7                     9.5
#
#                  Total_Dominated  Total_Dominating  Dominance Proportion
# Model
# Conv1D                        54                37                  1.48
# Neural Networks              177               194                  7.76

# %%
df_sorted_topo_models_grouped.T
# Out:
#                 RMSE_mean                                                    \
#                     count      mean       std       min       25%       50%
# Model
# Conv1D                5.0  2.597912  0.957984  1.753235  1.896894  2.557865
# Neural Networks      20.0  2.436073  1.048140  1.317312  1.865776  2.009159
#
#                                     RMSE_std            ... Dominated_Count  \
#                       75%       max    count      mean  ...             75%
# Model                                                   ...
# Conv1D           2.613889  4.167680      5.0  0.810398  ...           11.00
# Neural Networks  2.689787  5.702331     20.0  0.737678  ...           13.75
#
#                       Dominates_Count                                        \
#                   max           count mean       std  min   25%  50%    75%
# Model
# Conv1D           22.0             5.0  7.4  7.231874  0.0  3.00  7.0   8.00
# Neural Networks  22.0            20.0  9.7  7.204531  0.0  3.75  9.5  13.25
#
#
#                   max
# Model
# Conv1D           19.0
# Neural Networks  22.0
#
# [2 rows x 88 columns]

# %% [markdown]
# ### SCPM Analysis

# %%
cols = [
    # "Model",
    # "Model_bkp",
    "Model_bkp_2",
    "RMSE_mean",
    "RMSE_std",
    "MAE_mean",
    "MAE_std",
    "MAPE_mean",
    "MAPE_std",
    "R2_mean",
    "R2_std",
    "SCPM",
    "Dominated_Count",
    "Dominates_Count",
    "Classification",
    "Plant",
]

# %% [markdown]
# #### SCPM Analysis by Project

# %%
df_sorted_scpm = df_sorted_topo.sort_values(by="SCPM").copy()

# %%
# (df_sorted_topo[cols].reset_index() == df_sorted_scpm[cols].reset_index()).all(axis=1)
df_sorted_scpm["topo_scmp_order_eq"] = df_sorted_topo.index == df_sorted_scpm.index

# %%
df_sorted_scpm[cols + ["topo_scmp_order_eq"]].round(2).head(5)
# Out:
#         Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 20              MLP       1.32      0.24      1.04     0.19       2.46
# 9   Transformer_1.0       1.64      0.32      1.26     0.22       2.90
# 5               MLP       1.63      0.27      1.29     0.20       3.04
# 22         LSTM_7.0       1.66      0.44      1.27     0.29       2.97
# 8        Conv1D_7.0       1.75      0.31      1.40     0.24       3.20
#
#     MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count  Dominates_Count  \
# 20      0.38     0.93    0.03 -4.51                0               22
# 9       0.51     0.94    0.02 -3.45                0               22
# 5       0.48     0.94    0.02 -3.30                0               21
# 22      0.65     0.89    0.06 -3.27                2               19
# 8       0.52     0.93    0.02 -2.82                3               19
#
#         Classification Plant  topo_scmp_order_eq
# 20      dominant_model     w               False
# 9       dominant_model     f                True
# 5       dominant_model     f               False
# 22  intermediate_model     w               False
# 8   intermediate_model     f               False

# %% [markdown]
# ## Variable Grouping: CM-P-CS

# %% [markdown]
# #### Analysis of the best models identified in the Local Analysis

# %% [markdown]
# **Best models for variable groupping CM-P-CS were from:**
#
# *BTiSS:*
#     Dominance analysis: Plant S and Plant K
#     SCPM: Plant S and Plant K
#
# *TiSS:*
#     Dominance analysis: Plant S
#     SCPM: Plant S

# %%
df_results["Features"].unique()
# Out:
# array(['Chemical + Mineralogical', 'Chemical + Mineralogical + Physical',
#        'Chemical + Mineralogical + Physical - Early CS'], dtype=object)

# %%
df_results_cm_p_cs = (
    df_results[df_results["Features"].eq("Chemical + Mineralogical + Physical")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_p_cs["Features"].unique()
# Out:
# array(['Chemical + Mineralogical + Physical'], dtype=object)

# %%
df_results_cm_p_cs.shape
# Out:
# (55, 17)

# %% [markdown]
# ### Plant S

# %%
df_results_cm_p_cs = df_results_cm_p_cs[
    df_results_cm_p_cs["Plant"].eq("s")
].reset_index(drop=True)

# %% [markdown]
# ### Blocking time series

# %%
df_results_cm_p_cs["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split', 'Time Series Split'], dtype=object)

# %%
df_results_cm_p_cs_btss = (
    df_results_cm_p_cs[
        df_results_cm_p_cs["Cross Validation"].eq("Blocking Time Series Split")
    ]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_p_cs_btss["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split'], dtype=object)

# %%
df_results_cm_p_cs_btss.shape
# Out:
# (5, 17)

# %% [markdown]
# ###### SCPM computation

# %%
df_results_cm_p_cs_btss = compute_scpm(df_results_cm_p_cs_btss)

# %% [markdown]
# ##### Dominance Analysis

# %%
# Per project
dominance_dict = make_dominance_analysis(df_results_cm_p_cs_btss)
dominance_matrix_cm_p_cs_btss = dominance_dict["dominance_matrix"]
dominance_graph_cm_p_cs_btss = dominance_dict["dominance_graph"]
df_sorted_count = dominance_dict["df_sorted_count"]
df_sorted_topo = dominance_dict["df_sorted_topo"]

# %%
dominance_matrix_cm_p_cs_btss.shape, len(dominance_graph_cm_p_cs_btss)
# Out:
# ((5, 5), 5)

# %%
df_sorted_topo["Classification"].value_counts()
# Out:
# Classification
# intermediate_model    3
# dominant_model        1
# non_dominant_model    1
# Name: count, dtype: int64

# %%
# df_sorted_topo.to_csv(
#     "../../../../reports/results/global_models/ecics/ecics_209_s_dominance_analysis_cm_p_cs_btss.csv",
#     index=False,
# )

# %%
df_sorted_topo.head(5)
# Out:
#    Company Plant            Cross Validation  \
# 0      209     s  Blocking Time Series Split
# 1      209     s  Blocking Time Series Split
# 4      209     s  Blocking Time Series Split
# 3      209     s  Blocking Time Series Split
# 2      209     s  Blocking Time Series Split
#
#                               Features         Features_bkp            Model  \
# 0  Chemical + Mineralogical + Physical  Chemical + Physical  Neural Networks
# 1  Chemical + Mineralogical + Physical  Chemical + Physical           Conv1D
# 4  Chemical + Mineralogical + Physical  Chemical + Physical  Neural Networks
# 3  Chemical + Mineralogical + Physical  Chemical + Physical  Neural Networks
# 2  Chemical + Mineralogical + Physical  Chemical + Physical  Neural Networks
#
#            Model_bkp            Model_bkp_2  Timesteps  RMSE_mean  ...  \
# 0                MLP                    MLP        NaN   0.706974  ...
# 1             Conv1D             Conv1D_1.0        1.0   0.909706  ...
# 4  BidirectionalLSTM  BidirectionalLSTM_1.0        1.0   1.090873  ...
# 3               LSTM               LSTM_1.0        1.0   1.115614  ...
# 2        Transformer        Transformer_1.0        1.0   1.670219  ...
#
#    MAPE_mean   R2_mean  RMSE_std   MAE_std  MAPE_std    R2_std      SCPM  \
# 0   1.343428  0.982151  0.131605  0.091949  0.217774  0.006596 -5.297239
# 1   1.770868  0.971428  0.138244  0.104172  0.235113  0.008137 -2.180513
# 4   2.068817  0.958023  0.197852  0.182819  0.414481  0.015695  0.307526
# 3   2.069726  0.957110  0.100757  0.115338  0.305806  0.008406  0.493156
# 2   2.615050  0.900631  0.494400  0.187695  0.453612  0.047080  6.677070
#
#    Dominated_Count      Classification Dominates_Count
# 0                0      dominant_model               4
# 1                1  intermediate_model               3
# 4                2  intermediate_model               2
# 3                3  intermediate_model               1
# 2                4  non_dominant_model               0
#
# [5 rows x 21 columns]

# %%
df_sorted_topo_cols = df_sorted_topo[
    [
        # "Model",
        # "Model_bkp",
        "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Classification",
        "Dominates_Count",
        "Plant",
    ]
].round(2)

# %% [markdown]
# ###### Dominant Models

# %%
# Top 4
df_sorted_topo_cols.iloc[0:5]
# Out:
#              Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 0                    MLP       0.71      0.13      0.54     0.09       1.34
# 1             Conv1D_1.0       0.91      0.14      0.72     0.10       1.77
# 4  BidirectionalLSTM_1.0       1.09      0.20      0.83     0.18       2.07
# 3               LSTM_1.0       1.12      0.10      0.84     0.12       2.07
# 2        Transformer_1.0       1.67      0.49      1.03     0.19       2.62
#
#    MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 0      0.22     0.98    0.01 -5.30                0      dominant_model
# 1      0.24     0.97    0.01 -2.18                1  intermediate_model
# 4      0.41     0.96    0.02  0.31                2  intermediate_model
# 3      0.31     0.96    0.01  0.49                3  intermediate_model
# 2      0.45     0.90    0.05  6.68                4  non_dominant_model
#
#    Dominates_Count Plant
# 0                4     s
# 1                3     s
# 4                2     s
# 3                1     s
# 2                0     s

# %%
df_sorted_topo_cols[df_sorted_topo_cols["Classification"].eq("dominant_model")].shape
# Out:
# (1, 14)

# %% [markdown]
# ###### Intermediate models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].sort_values(by=["Dominates_Count", "SCPM"], ascending=[False, True]).iloc[:3]
# Out:
#              Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 1             Conv1D_1.0       0.91      0.14      0.72     0.10       1.77
# 4  BidirectionalLSTM_1.0       1.09      0.20      0.83     0.18       2.07
# 3               LSTM_1.0       1.12      0.10      0.84     0.12       2.07
#
#    MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 1      0.24     0.97    0.01 -2.18                1  intermediate_model
# 4      0.41     0.96    0.02  0.31                2  intermediate_model
# 3      0.31     0.96    0.01  0.49                3  intermediate_model
#
#    Dominates_Count Plant
# 1                3     s
# 4                2     s
# 3                1     s

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].shape
# Out:
# (3, 14)

# %% [markdown]
# ###### non-dominant models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].sort_values(by=["Dominates_Count", "SCPM"], ascending=[False, True]).iloc[:2]
# Out:
#        Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 2  Transformer_1.0       1.67      0.49      1.03     0.19       2.62
#
#    MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 2      0.45      0.9    0.05  6.68                4  non_dominant_model
#
#    Dominates_Count Plant
# 2                0     s

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].shape
# Out:
# (1, 14)

# %% [markdown]
# ###### Statistics per model type

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        # "Model_bkp",
        # "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
        "Plant",
    ]
]  # .round(2)

# %%
df_sorted_topo["Model"].value_counts()
# Out:
# Model
# Neural Networks    4
# Conv1D             1
# Name: count, dtype: int64

# %%
df_sorted_topo_models_grouped = df_sorted_topo_models_cols.groupby("Model").describe().T

# %%
# pd.set_option("display.max_rows", None)
# df_sorted_topo_models_grouped

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
    ]
]

# %%
(
    df_sorted_topo_models_cols.groupby("Model")[["Classification"]]
    .value_counts(normalize=True)
    .to_frame()
    * 100
).round(2)
# Out:
#                                     proportion
# Model           Classification
# Conv1D          intermediate_model       100.0
# Neural Networks intermediate_model        50.0
#                 dominant_model            25.0
#                 non_dominant_model        25.0

# %%
df_sorted_topo_models_cols.groupby("Model").describe().round(2).T
# Out:
# Model                  Conv1D  Neural Networks
# Dominated_Count count     1.0             4.00
#                 mean      1.0             2.25
#                 std       NaN             1.71
#                 min       1.0             0.00
#                 25%       1.0             1.50
#                 50%       1.0             2.50
#                 75%       1.0             3.25
#                 max       1.0             4.00
# Dominates_Count count     1.0             4.00
#                 mean      3.0             1.75
#                 std       NaN             1.71
#                 min       3.0             0.00
#                 25%       3.0             0.75
#                 50%       3.0             1.50
#                 75%       3.0             2.50
#                 max       3.0             4.00

# %%
# df_sorted_topo_models_cols

# %%
df_sorted_topo_models_cols.groupby("Model")["Classification"].describe()
# Out:
#                 count unique                 top freq
# Model
# Conv1D              1      1  intermediate_model    1
# Neural Networks     4      3  intermediate_model    2

# %%
df_sorted_topo_models_cols.groupby("Model")[["Classification"]].value_counts()
# Out:
# Model            Classification
# Conv1D           intermediate_model    1
# Neural Networks  intermediate_model    2
#                  dominant_model        1
#                  non_dominant_model    1
# Name: count, dtype: int64

# %%
# df_sorted_topo_models_cols

# %%
summary_stats = df_sorted_topo_models_cols.groupby("Model").agg(
    Total_Models=("Model", "count"),
    Mean_Dominance_Count=("Dominates_Count", "mean"),
    Median_Dominance_Count=("Dominates_Count", "median"),
    Total_Dominated=("Dominated_Count", "sum"),
    Total_Dominating=("Dominates_Count", "sum"),
)

total_models = summary_stats[
    "Total_Models"
].sum()  # Get the total number of models across all categories
summary_stats["Dominance Proportion"] = summary_stats["Total_Dominating"] / total_models

# %%
summary_stats
# Out:
#                  Total_Models  Mean_Dominance_Count  Median_Dominance_Count  \
# Model
# Conv1D                      1                  3.00                     3.0
# Neural Networks             4                  1.75                     1.5
#
#                  Total_Dominated  Total_Dominating  Dominance Proportion
# Model
# Conv1D                         1                 3                   0.6
# Neural Networks                9                 7                   1.4

# %%
df_sorted_topo_models_grouped.T
# Out:
#                 RMSE_mean                                                    \
#                     count      mean       std       min       25%       50%
# Model
# Conv1D                1.0  0.909706       NaN  0.909706  0.909706  0.909706
# Neural Networks       4.0  1.145920  0.396448  0.706974  0.994898  1.103244
#
#                                     RMSE_std            ... Dominated_Count  \
#                       75%       max    count      mean  ...             75%
# Model                                                   ...
# Conv1D           0.909706  0.909706      1.0  0.138244  ...            1.00
# Neural Networks  1.254266  1.670219      4.0  0.231153  ...            3.25
#
#                      Dominates_Count
#                  max           count  mean       std  min   25%  50%  75%  max
# Model
# Conv1D           1.0             1.0  3.00       NaN  3.0  3.00  3.0  3.0  3.0
# Neural Networks  4.0             4.0  1.75  1.707825  0.0  0.75  1.5  2.5  4.0
#
# [2 rows x 88 columns]

# %% [markdown]
# ### SCPM Analysis

# %%
cols = [
    # "Model",
    # "Model_bkp",
    "Model_bkp_2",
    "RMSE_mean",
    "RMSE_std",
    "MAE_mean",
    "MAE_std",
    "MAPE_mean",
    "MAPE_std",
    "R2_mean",
    "R2_std",
    "SCPM",
    "Dominated_Count",
    "Dominates_Count",
    "Classification",
    "Plant",
]

# %% [markdown]
# #### SCPM Analysis by Project

# %%
df_sorted_scpm = df_sorted_topo.sort_values(by="SCPM").copy()

# %%
# (df_sorted_topo[cols].reset_index() == df_sorted_scpm[cols].reset_index()).all(axis=1)
df_sorted_scpm["topo_scmp_order_eq"] = df_sorted_topo.index == df_sorted_scpm.index

# %%
df_sorted_scpm[cols + ["topo_scmp_order_eq"]].round(2).head(5)
# Out:
#              Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 0                    MLP       0.71      0.13      0.54     0.09       1.34
# 1             Conv1D_1.0       0.91      0.14      0.72     0.10       1.77
# 4  BidirectionalLSTM_1.0       1.09      0.20      0.83     0.18       2.07
# 3               LSTM_1.0       1.12      0.10      0.84     0.12       2.07
# 2        Transformer_1.0       1.67      0.49      1.03     0.19       2.62
#
#    MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count  Dominates_Count  \
# 0      0.22     0.98    0.01 -5.30                0                4
# 1      0.24     0.97    0.01 -2.18                1                3
# 4      0.41     0.96    0.02  0.31                2                2
# 3      0.31     0.96    0.01  0.49                3                1
# 2      0.45     0.90    0.05  6.68                4                0
#
#        Classification Plant  topo_scmp_order_eq
# 0      dominant_model     s                True
# 1  intermediate_model     s                True
# 4  intermediate_model     s                True
# 3  intermediate_model     s                True
# 2  non_dominant_model     s                True

# %%
df_results_cm_p_cs = (
    df_results[df_results["Features"].eq("Chemical + Mineralogical + Physical")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_p_cs["Features"].unique()
# Out:
# array(['Chemical + Mineralogical + Physical'], dtype=object)

# %%
df_results_cm_p_cs.shape
# Out:
# (55, 17)

# %% [markdown]
# ### Blocking time series

# %%
df_results_cm_p_cs["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split', 'Time Series Split'], dtype=object)

# %%
df_results_cm_p_cs_btss = (
    df_results_cm_p_cs[
        df_results_cm_p_cs["Cross Validation"].eq("Blocking Time Series Split")
    ]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_p_cs_btss["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split'], dtype=object)

# %%
df_results_cm_p_cs_btss.shape
# Out:
# (30, 17)

# %% [markdown]
# ###### SCPM computation

# %%
df_results_cm_p_cs_btss = compute_scpm(df_results_cm_p_cs_btss)

# %% [markdown]
# ##### Dominance Analysis

# %%
# Per project
dominance_dict = make_dominance_analysis(df_results_cm_p_cs_btss)
dominance_matrix_cm_p_cs_btss = dominance_dict["dominance_matrix"]
dominance_graph_cm_p_cs_btss = dominance_dict["dominance_graph"]
df_sorted_count = dominance_dict["df_sorted_count"]
df_sorted_topo = dominance_dict["df_sorted_topo"]

# %%
dominance_matrix_cm_p_cs_btss.shape, len(dominance_graph_cm_p_cs_btss)
# Out:
# ((30, 30), 30)

# %%
df_sorted_topo["Classification"].value_counts()
# Out:
# Classification
# intermediate_model    25
# non_dominant_model     4
# dominant_model         1
# Name: count, dtype: int64

# %%
# df_sorted_topo.to_csv(
#     "../../../../reports/results/global_models/ecics/ecics_209_k_dominance_analysis_cm_p_cs_btss.csv",
#     index=False,
# )

# %%
df_sorted_topo.head(5)
# Out:
#     Company Plant            Cross Validation  \
# 20      209     s  Blocking Time Series Split
# 25      209     k  Blocking Time Series Split
# 21      209     s  Blocking Time Series Split
# 0       203     c  Blocking Time Series Split
# 24      209     s  Blocking Time Series Split
#
#                                Features         Features_bkp            Model  \
# 20  Chemical + Mineralogical + Physical  Chemical + Physical  Neural Networks
# 25  Chemical + Mineralogical + Physical  Chemical + Physical  Neural Networks
# 21  Chemical + Mineralogical + Physical  Chemical + Physical           Conv1D
# 0   Chemical + Mineralogical + Physical  Chemical + Physical  Neural Networks
# 24  Chemical + Mineralogical + Physical  Chemical + Physical  Neural Networks
#
#             Model_bkp            Model_bkp_2  Timesteps  RMSE_mean  ...  \
# 20                MLP                    MLP        NaN   0.706974  ...
# 25                MLP                    MLP        NaN   0.856619  ...
# 21             Conv1D             Conv1D_1.0        1.0   0.909706  ...
# 0                 MLP                    MLP        NaN   1.083815  ...
# 24  BidirectionalLSTM  BidirectionalLSTM_1.0        1.0   1.090873  ...
#
#     MAPE_mean   R2_mean  RMSE_std   MAE_std  MAPE_std    R2_std      SCPM  \
# 20   1.343428  0.982151  0.131605  0.091949  0.217774  0.006596 -5.207017
# 25   1.566781  0.973031  0.215978  0.157436  0.394729  0.019362 -4.615279
# 21   1.770868  0.971428  0.138244  0.104172  0.235113  0.008137 -4.318579
# 0    2.040679  0.966125  0.127806  0.089256  0.240282  0.005697 -3.681784
# 24   2.068817  0.958023  0.197852  0.182819  0.414481  0.015695 -3.649509
#
#     Dominated_Count      Classification Dominates_Count
# 20                0      dominant_model              29
# 25                1  intermediate_model              28
# 21                2  intermediate_model              27
# 0                 3  intermediate_model              25
# 24                3  intermediate_model              25
#
# [5 rows x 21 columns]

# %%
df_sorted_topo_cols = df_sorted_topo[
    [
        # "Model",
        # "Model_bkp",
        "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Classification",
        "Dominates_Count",
        "Plant",
    ]
].round(2)

# %% [markdown]
# ###### Dominant Models

# %%
# Top 4
df_sorted_topo_cols.iloc[0:5]
# Out:
#               Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 20                    MLP       0.71      0.13      0.54     0.09       1.34
# 25                    MLP       0.86      0.22      0.67     0.16       1.57
# 21             Conv1D_1.0       0.91      0.14      0.72     0.10       1.77
# 0                     MLP       1.08      0.13      0.84     0.09       2.04
# 24  BidirectionalLSTM_1.0       1.09      0.20      0.83     0.18       2.07
#
#     MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 20      0.22     0.98    0.01 -5.21                0      dominant_model
# 25      0.39     0.97    0.02 -4.62                1  intermediate_model
# 21      0.24     0.97    0.01 -4.32                2  intermediate_model
# 0       0.24     0.97    0.01 -3.68                3  intermediate_model
# 24      0.41     0.96    0.02 -3.65                3  intermediate_model
#
#     Dominates_Count Plant
# 20               29     s
# 25               28     k
# 21               27     s
# 0                25     c
# 24               25     s

# %%
df_sorted_topo_cols[df_sorted_topo_cols["Classification"].eq("dominant_model")].shape
# Out:
# (1, 14)

# %% [markdown]
# ###### Intermediate models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].sort_values(by=["Dominates_Count", "SCPM"], ascending=[False, True]).iloc[:3]
# Out:
#    Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  MAPE_std  \
# 25         MLP       0.86      0.22      0.67     0.16       1.57      0.39
# 21  Conv1D_1.0       0.91      0.14      0.72     0.10       1.77      0.24
# 0          MLP       1.08      0.13      0.84     0.09       2.04      0.24
#
#     R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 25     0.97    0.02 -4.62                1  intermediate_model
# 21     0.97    0.01 -4.32                2  intermediate_model
# 0      0.97    0.01 -3.68                3  intermediate_model
#
#     Dominates_Count Plant
# 25               28     k
# 21               27     s
# 0                25     c

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].shape
# Out:
# (25, 14)

# %% [markdown]
# ###### non-dominant models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].sort_values(by=["Dominates_Count", "SCPM"], ascending=[False, True]).iloc[:2]
# Out:
#    Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  MAPE_std  \
# 11  Conv1D_1.0       2.33      0.84      1.88     0.73       4.28      1.60
# 18    LSTM_1.0       2.87      1.09      2.15     0.77       4.82      1.64
#
#     R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 11    -1.31    3.39  5.17               24  non_dominant_model
# 18    -0.83    2.28  5.88               26  non_dominant_model
#
#     Dominates_Count Plant
# 11                0     b
# 18                0    at

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].shape
# Out:
# (4, 14)

# %% [markdown]
# ###### Statistics per model type

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        # "Model_bkp",
        # "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
        "Plant",
    ]
]  # .round(2)

# %%
df_sorted_topo["Model"].value_counts()
# Out:
# Model
# Neural Networks    24
# Conv1D              6
# Name: count, dtype: int64

# %%
df_sorted_topo_models_grouped = df_sorted_topo_models_cols.groupby("Model").describe().T

# %%
# pd.set_option("display.max_rows", None)
# df_sorted_topo_models_grouped

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
    ]
]

# %%
(
    df_sorted_topo_models_cols.groupby("Model")[["Classification"]]
    .value_counts(normalize=True)
    .to_frame()
    * 100
).round(2)
# Out:
#                                     proportion
# Model           Classification
# Conv1D          intermediate_model       66.67
#                 non_dominant_model       33.33
# Neural Networks intermediate_model       87.50
#                 non_dominant_model        8.33
#                 dominant_model            4.17

# %%
df_sorted_topo_models_cols.groupby("Model").describe().round(2).T
# Out:
# Model                  Conv1D  Neural Networks
# Dominated_Count count    6.00            24.00
#                 mean    13.17            11.46
#                 std      8.47             6.74
#                 min      2.00             0.00
#                 25%      7.50             6.75
#                 50%     13.00            13.00
#                 75%     19.25            16.00
#                 max     24.00            26.00
# Dominates_Count count    6.00            24.00
#                 mean    11.00            12.00
#                 std     11.35             9.90
#                 min      0.00             0.00
#                 25%      1.00             3.00
#                 50%      9.50            10.00
#                 75%     18.75            20.75
#                 max     27.00            29.00

# %%
# df_sorted_topo_models_cols

# %%
df_sorted_topo_models_cols.groupby("Model")["Classification"].describe()
# Out:
#                 count unique                 top freq
# Model
# Conv1D              6      2  intermediate_model    4
# Neural Networks    24      3  intermediate_model   21

# %%
df_sorted_topo_models_cols.groupby("Model")[["Classification"]].value_counts()
# Out:
# Model            Classification
# Conv1D           intermediate_model     4
#                  non_dominant_model     2
# Neural Networks  intermediate_model    21
#                  non_dominant_model     2
#                  dominant_model         1
# Name: count, dtype: int64

# %%
# df_sorted_topo_models_cols

# %%
summary_stats = df_sorted_topo_models_cols.groupby("Model").agg(
    Total_Models=("Model", "count"),
    Mean_Dominance_Count=("Dominates_Count", "mean"),
    Median_Dominance_Count=("Dominates_Count", "median"),
    Total_Dominated=("Dominated_Count", "sum"),
    Total_Dominating=("Dominates_Count", "sum"),
)

total_models = summary_stats[
    "Total_Models"
].sum()  # Get the total number of models across all categories
summary_stats["Dominance Proportion"] = summary_stats["Total_Dominating"] / total_models

# %%
summary_stats
# Out:
#                  Total_Models  Mean_Dominance_Count  Median_Dominance_Count  \
# Model
# Conv1D                      6                  11.0                     9.5
# Neural Networks            24                  12.0                    10.0
#
#                  Total_Dominated  Total_Dominating  Dominance Proportion
# Model
# Conv1D                        79                66                   2.2
# Neural Networks              275               288                   9.6

# %%
df_sorted_topo_models_grouped.T
# Out:
#                 RMSE_mean                                                    \
#                     count      mean       std       min       25%       50%
# Model
# Conv1D                6.0  2.013751  0.950187  0.909706  1.444368  1.922693
# Neural Networks      24.0  1.882511  0.902998  0.706974  1.440724  1.849106
#
#                                     RMSE_std            ... Dominated_Count  \
#                       75%       max    count      mean  ...             75%
# Model                                                   ...
# Conv1D           2.279499  3.644053      6.0  0.959340  ...           19.25
# Neural Networks  2.034806  5.339302     24.0  0.611644  ...           16.00
#
#                       Dominates_Count                                          \
#                   max           count  mean        std  min  25%   50%    75%
# Model
# Conv1D           24.0             6.0  11.0  11.349009  0.0  1.0   9.5  18.75
# Neural Networks  26.0            24.0  12.0   9.903886  0.0  3.0  10.0  20.75
#
#
#                   max
# Model
# Conv1D           27.0
# Neural Networks  29.0
#
# [2 rows x 88 columns]

# %% [markdown]
# ### SCPM Analysis

# %%
cols = [
    # "Model",
    # "Model_bkp",
    "Model_bkp_2",
    "RMSE_mean",
    "RMSE_std",
    "MAE_mean",
    "MAE_std",
    "MAPE_mean",
    "MAPE_std",
    "R2_mean",
    "R2_std",
    "SCPM",
    "Dominated_Count",
    "Dominates_Count",
    "Classification",
    "Plant",
]

# %% [markdown]
# #### SCPM Analysis by Project

# %%
df_sorted_scpm = df_sorted_topo.sort_values(by="SCPM").copy()

# %%
# (df_sorted_topo[cols].reset_index() == df_sorted_scpm[cols].reset_index()).all(axis=1)
df_sorted_scpm["topo_scmp_order_eq"] = df_sorted_topo.index == df_sorted_scpm.index

# %%
df_sorted_scpm[cols + ["topo_scmp_order_eq"]].round(2).head(5)
# Out:
#               Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 20                    MLP       0.71      0.13      0.54     0.09       1.34
# 25                    MLP       0.86      0.22      0.67     0.16       1.57
# 21             Conv1D_1.0       0.91      0.14      0.72     0.10       1.77
# 0                     MLP       1.08      0.13      0.84     0.09       2.04
# 24  BidirectionalLSTM_1.0       1.09      0.20      0.83     0.18       2.07
#
#     MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count  Dominates_Count  \
# 20      0.22     0.98    0.01 -5.21                0               29
# 25      0.39     0.97    0.02 -4.62                1               28
# 21      0.24     0.97    0.01 -4.32                2               27
# 0       0.24     0.97    0.01 -3.68                3               25
# 24      0.41     0.96    0.02 -3.65                3               25
#
#         Classification Plant  topo_scmp_order_eq
# 20      dominant_model     s                True
# 25  intermediate_model     k                True
# 21  intermediate_model     s                True
# 0   intermediate_model     c                True
# 24  intermediate_model     s                True

# %% [markdown]
# ### Time Series Split

# %%
df_results_cm_p_cs = (
    df_results[
        df_results["Features"].eq("Chemical + Mineralogical + Physical")
        & ~df_results["Plant"].eq("k")
    ]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_p_cs["Features"].unique()
# Out:
# array(['Chemical + Mineralogical + Physical'], dtype=object)

# %%
df_results_cm_p_cs.shape
# Out:
# (50, 17)

# %%
df_results_cm_p_cs["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split', 'Time Series Split'], dtype=object)

# %%
df_results_cm_p_cs_tss = (
    df_results_cm_p_cs[df_results_cm_p_cs["Cross Validation"].eq("Time Series Split")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_p_cs_tss["Cross Validation"].unique()
# Out:
# array(['Time Series Split'], dtype=object)

# %%
df_results_cm_p_cs_tss.shape
# Out:
# (25, 17)

# %% [markdown]
# ###### SCPM computation

# %%
df_results_cm_p_cs_tss = compute_scpm(df_results_cm_p_cs_tss)

# %% [markdown]
# ##### Dominance Analysis

# %%
# Per project
dominance_dict = make_dominance_analysis(df_results_cm_p_cs_tss)
dominance_matrix_cm_p_cs_tss = dominance_dict["dominance_matrix"]
dominance_graph_cm_p_cs_tss = dominance_dict["dominance_graph"]
df_sorted_count = dominance_dict["df_sorted_count"]
df_sorted_topo = dominance_dict["df_sorted_topo"]

# %%
dominance_matrix_cm_p_cs_tss.shape, len(dominance_graph_cm_p_cs_tss)
# Out:
# ((25, 25), 25)

# %%
df_sorted_topo["Classification"].value_counts()
# Out:
# Classification
# intermediate_model    20
# non_dominant_model     4
# dominant_model         1
# Name: count, dtype: int64

# %%
# df_sorted_topo.to_csv(
#     "../../../../reports/results/global_models/ecics/ecics_209_s_dominance_analysis_cm_p_cs_tss.csv",
#     index=False,
# )

# %%
df_sorted_topo.head(5)
# Out:
#     Company Plant   Cross Validation                             Features  \
# 20      209     s  Time Series Split  Chemical + Mineralogical + Physical
# 21      209     s  Time Series Split  Chemical + Mineralogical + Physical
# 23      209     s  Time Series Split  Chemical + Mineralogical + Physical
# 24      209     s  Time Series Split  Chemical + Mineralogical + Physical
# 0       203     c  Time Series Split  Chemical + Mineralogical + Physical
#
#            Features_bkp            Model          Model_bkp  \
# 20  Chemical + Physical  Neural Networks                MLP
# 21  Chemical + Physical           Conv1D             Conv1D
# 23  Chemical + Physical  Neural Networks               LSTM
# 24  Chemical + Physical  Neural Networks  BidirectionalLSTM
# 0   Chemical + Physical  Neural Networks                MLP
#
#               Model_bkp_2  Timesteps  RMSE_mean  ...  MAPE_mean   R2_mean  \
# 20                    MLP        NaN   0.790668  ...   1.452909  0.976708
# 21             Conv1D_1.0        1.0   0.970570  ...   1.735976  0.964481
# 23               LSTM_1.0        1.0   1.179825  ...   1.759961  0.940172
# 24  BidirectionalLSTM_1.0        1.0   1.185788  ...   1.972467  0.946583
# 0                     MLP        NaN   1.555784  ...   2.545077  0.929168
#
#     RMSE_std   MAE_std  MAPE_std    R2_std      SCPM  Dominated_Count  \
# 20  0.101774  0.063122  0.146045  0.005290 -4.738469                0
# 21  0.203195  0.087436  0.188137  0.012758 -4.112339                1
# 23  0.527326  0.156331  0.385089  0.055051 -3.932824                2
# 24  0.239995  0.148219  0.380745  0.021361 -3.570323                2
# 0   0.217635  0.243941  0.472629  0.017320 -2.186171                4
#
#         Classification Dominates_Count
# 20      dominant_model              24
# 21  intermediate_model              23
# 23  intermediate_model              20
# 24  intermediate_model              21
# 0   intermediate_model              15
#
# [5 rows x 21 columns]

# %%
df_sorted_topo_cols = df_sorted_topo[
    [
        # "Model",
        # "Model_bkp",
        "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Classification",
        "Dominates_Count",
        "Plant",
    ]
]  # .round(2)

# %% [markdown]
# ###### Dominant Models

# %%
# Top 4
df_sorted_topo_cols.iloc[0:2].sort_values(by="Dominates_Count", ascending=False).round(
    2
)
# Out:
#    Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  MAPE_std  \
# 20         MLP       0.79       0.1      0.58     0.06       1.45      0.15
# 21  Conv1D_1.0       0.97       0.2      0.71     0.09       1.74      0.19
#
#     R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 20     0.98    0.01 -4.74                0      dominant_model
# 21     0.96    0.01 -4.11                1  intermediate_model
#
#     Dominates_Count Plant
# 20               24     s
# 21               23     s

# %%
df_sorted_topo_cols[df_sorted_topo_cols["Classification"].eq("dominant_model")].shape
# Out:
# (1, 14)

# %% [markdown]
# ###### Intermediate models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].sort_values(by=["Dominates_Count", "SCPM"], ascending=[False, True]).iloc[:4].round(2)
# Out:
#               Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 21             Conv1D_1.0       0.97      0.20      0.71     0.09       1.74
# 24  BidirectionalLSTM_1.0       1.19      0.24      0.79     0.15       1.97
# 23               LSTM_1.0       1.18      0.53      0.71     0.16       1.76
# 5                     MLP       1.50      0.45      1.15     0.31       2.57
#
#     MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 21      0.19     0.96    0.01 -4.11                1  intermediate_model
# 24      0.38     0.95    0.02 -3.57                2  intermediate_model
# 23      0.39     0.94    0.06 -3.93                2  intermediate_model
# 5       0.58     0.94    0.02 -2.10                3  intermediate_model
#
#     Dominates_Count Plant
# 21               23     s
# 24               21     s
# 23               20     s
# 5                18    ab

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].shape
# Out:
# (20, 14)

# %% [markdown]
# ###### non-dominant models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].sort_values(by=["Dominates_Count", "SCPM"], ascending=[False, True]).iloc[:3]
# Out:
#         Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean   MAE_std  MAPE_mean  \
# 8          LSTM_7.0   3.140499  1.621540  2.385823  1.149827   5.315326
# 16       Conv1D_7.0   2.801010  0.378777  2.242115  0.283773   5.041565
# 17  Transformer_1.0   2.965125  0.646830  2.243967  0.393951   5.186654
#
#     MAPE_std   R2_mean    R2_std      SCPM  Dominated_Count  \
# 8   2.237891  0.730408  0.243026  4.116160               13
# 16  0.418911 -0.128617  0.613507  4.174323               21
# 17  1.132405 -0.099444  0.395899  4.380655               21
#
#         Classification  Dominates_Count Plant
# 8   non_dominant_model                0    ab
# 16  non_dominant_model                0    at
# 17  non_dominant_model                0    at

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].shape
# Out:
# (4, 14)

# %% [markdown]
# ###### Statistics per model type

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        # "Model_bkp",
        # "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
        "Plant",
    ]
]  # .round(2)

# %%
df_sorted_topo["Model"].value_counts()
# Out:
# Model
# Neural Networks    20
# Conv1D              5
# Name: count, dtype: int64

# %%
df_sorted_topo_models_grouped = df_sorted_topo_models_cols.groupby("Model").describe().T

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
    ]
]

# %%
(
    df_sorted_topo_models_cols.groupby("Model")[["Classification"]]
    .value_counts(normalize=True)
    .to_frame()
    * 100
).round(2)
# Out:
#                                     proportion
# Model           Classification
# Conv1D          intermediate_model        80.0
#                 non_dominant_model        20.0
# Neural Networks intermediate_model        80.0
#                 non_dominant_model        15.0
#                 dominant_model             5.0

# %%
df_sorted_topo_models_cols.groupby("Model").describe().round(2).T
# Out:
# Model                  Conv1D  Neural Networks
# Dominated_Count count    5.00            20.00
#                 mean     9.40             9.70
#                 std      7.37             6.33
#                 min      1.00             0.00
#                 25%      6.00             4.00
#                 50%      9.00            10.00
#                 75%     10.00            13.25
#                 max     21.00            21.00
# Dominates_Count count    5.00            20.00
#                 mean    11.20             9.25
#                 std      8.53             7.67
#                 min      0.00             0.00
#                 25%      8.00             3.75
#                 50%     10.00             6.00
#                 75%     15.00            16.00
#                 max     23.00            24.00

# %%
# df_sorted_topo_models_cols

# %%
df_sorted_topo_models_cols.groupby("Model")["Classification"].describe()
# Out:
#                 count unique                 top freq
# Model
# Conv1D              5      2  intermediate_model    4
# Neural Networks    20      3  intermediate_model   16

# %%
df_sorted_topo_models_cols.groupby("Model")[["Classification"]].value_counts()
# Out:
# Model            Classification
# Conv1D           intermediate_model     4
#                  non_dominant_model     1
# Neural Networks  intermediate_model    16
#                  non_dominant_model     3
#                  dominant_model         1
# Name: count, dtype: int64

# %%
summary_stats = df_sorted_topo_models_cols.groupby("Model").agg(
    Total_Models=("Model", "count"),
    Mean_Dominance_Count=("Dominates_Count", "mean"),
    Median_Dominance_Count=("Dominates_Count", "median"),
    Total_Dominated=("Dominated_Count", "sum"),
    Total_Dominating=("Dominates_Count", "sum"),
)

total_models = summary_stats[
    "Total_Models"
].sum()  # Get the total number of models across all categories
summary_stats["Dominance Proportion"] = summary_stats["Total_Dominating"] / total_models

# %%
summary_stats.round(2)
# Out:
#                  Total_Models  Mean_Dominance_Count  Median_Dominance_Count  \
# Model
# Conv1D                      5                 11.20                    10.0
# Neural Networks            20                  9.25                     6.0
#
#                  Total_Dominated  Total_Dominating  Dominance Proportion
# Model
# Conv1D                        47                56                  2.24
# Neural Networks              194               185                  7.40

# %%
df_sorted_topo_models_grouped.T
# Out:
#                 RMSE_mean                                                    \
#                     count      mean       std       min       25%       50%
# Model
# Conv1D                5.0  1.790462  0.662044  0.970570  1.579179  1.714384
# Neural Networks      20.0  2.360903  1.957232  0.790668  1.525315  1.987519
#
#                                      RMSE_std           ... Dominated_Count  \
#                       75%        max    count     mean  ...             75%
# Model                                                   ...
# Conv1D           1.887169   2.801010      5.0  0.35460  ...           10.00
# Neural Networks  2.509695  10.232263     20.0  0.95165  ...           13.25
#
#                       Dominates_Count                                          \
#                   max           count   mean       std  min   25%   50%   75%
# Model
# Conv1D           21.0             5.0  11.20  8.526429  0.0  8.00  10.0  15.0
# Neural Networks  21.0            20.0   9.25  7.670003  0.0  3.75   6.0  16.0
#
#
#                   max
# Model
# Conv1D           23.0
# Neural Networks  24.0
#
# [2 rows x 88 columns]

# %% [markdown]
# ### SCPM Analysis

# %%
cols = [
    # "Model",
    # "Model_bkp",
    "Model_bkp_2",
    "RMSE_mean",
    "RMSE_std",
    "MAE_mean",
    "MAE_std",
    "MAPE_mean",
    "MAPE_std",
    "R2_mean",
    "R2_std",
    "SCPM",
    "Dominated_Count",
    "Dominates_Count",
    "Classification",
    "Plant",
]

# %% [markdown]
# #### SCPM Analysis by Project

# %%
df_sorted_scpm = df_sorted_topo.sort_values(by="SCPM").copy()

# %%
# (df_sorted_topo[cols].reset_index() == df_sorted_scpm[cols].reset_index()).all(axis=1)
df_sorted_scpm["topo_scmp_order_eq"] = df_sorted_topo.index == df_sorted_scpm.index

# %%
df_sorted_scpm[cols + ["topo_scmp_order_eq"]].round(2).head(5)
# Out:
#               Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 20                    MLP       0.79      0.10      0.58     0.06       1.45
# 21             Conv1D_1.0       0.97      0.20      0.71     0.09       1.74
# 23               LSTM_1.0       1.18      0.53      0.71     0.16       1.76
# 24  BidirectionalLSTM_1.0       1.19      0.24      0.79     0.15       1.97
# 22        Transformer_1.0       1.37      0.36      0.90     0.16       2.19
#
#     MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count  Dominates_Count  \
# 20      0.15     0.98    0.01 -4.74                0               24
# 21      0.19     0.96    0.01 -4.11                1               23
# 23      0.39     0.94    0.06 -3.93                2               20
# 24      0.38     0.95    0.02 -3.57                2               21
# 22      0.32     0.93    0.03 -3.03                4               16
#
#         Classification Plant  topo_scmp_order_eq
# 20      dominant_model     s                True
# 21  intermediate_model     s                True
# 23  intermediate_model     s                True
# 24  intermediate_model     s                True
# 22  intermediate_model     s               False
