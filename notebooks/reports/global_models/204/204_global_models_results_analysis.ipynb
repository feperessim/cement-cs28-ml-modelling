# %%
# %load_ext nb_black

# %%
import pandas as pd
import os
import glob
import numpy as np

# %%
import warnings

# Suppress specific FutureWarning
warnings.filterwarnings("ignore", category=FutureWarning, module="seaborn._oldcore")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.preprocessing import StandardScaler

# %%
from collections import deque, defaultdict

# %%
def read_csv_files_grouped(csv_files, plant, header=[0, 1]):
    results = []
    for filepath in csv_files:
        df = pd.read_csv(filepath, header=header, low_memory=False)
        df["plant"] = plant  # Add the 'plant' column
        results.append(df)
    df = pd.concat(results, ignore_index=True)
    return df

# %%
def read_csv_files_full(csv_files, plant):
    results = []
    for filepath in csv_files:
        df = pd.read_csv(filepath, low_memory=False)
        df["plant"] = plant  # Add the 'plant' column
        results.append(df)
    df = pd.concat(results, ignore_index=True)
    return df

# %% [markdown]
# ### Renaming the Columns

# %%
def preprocess_rename_columns(df):
    df.columns = pd.MultiIndex.from_tuples(
        list(
            {
                col: (col[0], "") if "Unnamed" in col[1] else col for col in df.columns
            }.values()
        )
    )
    return df

# %% [markdown]
# ### Changing the order_of columns Columns

# %%
def preprocess_change_columns_order(df, column, pos):
    # Get the list of columns
    cols = df.columns.tolist()
    # Remove the specified column
    cols.remove(column)
    # Insert the column at the desired position
    cols.insert(pos, column)
    # Reorder the DataFrame columns
    return df[cols]

# %%
def read_csv_files_path(csv_files_path_dict, path, plant):
    csv_files = glob.glob(os.path.join(path, "*.csv"))
    csv_files_path_dict[plant] = csv_files
    return csv_files_path_dict

# %% [markdown]
# # Topological Analysis - NEW

# %% [markdown]
# ## Definitions

# %%
# Function to compare two models strictly based on means only
def dominates(model1, model2):
    """Return True if model1 strictly dominates model2, False otherwise."""
    # Check if model1 is at least as good as model2 in all metrics
    at_least_as_good = (
        model1["RMSE_mean"] <= model2["RMSE_mean"]
        and model1["MAE_mean"] <= model2["MAE_mean"]
        and model1["MAPE_mean"] <= model2["MAPE_mean"]
        and model1["R2_mean"] >= model2["R2_mean"]
    )

    # Check if model1 is strictly better in at least one metric
    strictly_better_in_one = (
        model1["RMSE_mean"] < model2["RMSE_mean"]
        or model1["MAE_mean"] < model2["MAE_mean"]
        or model1["MAPE_mean"] < model2["MAPE_mean"]
        or model1["R2_mean"] > model2["R2_mean"]
    )

    # Model1 strictly dominates Model2 if it is at least as good in all metrics and
    # strictly better in at least one metric
    return at_least_as_good and strictly_better_in_one

# %%
def get_dominance_matrix_and_graph(df):
    n = len(df)
    dominance_matrix = np.zeros((n, n), dtype=bool)

    for i in range(n):
        for j in range(n):
            if i != j:
                dominance_matrix[i, j] = dominates(df.iloc[i], df.iloc[j])

    # Create the dominance graph
    dominance_graph = {i: [] for i in range(n)}
    for i in range(n):
        for j in range(n):
            if dominance_matrix[i, j]:
                dominance_graph[i].append(j)

    return dominance_matrix, dominance_graph

# %%
# Topological Sorting
def topological_sort(graph):
    """Perform topological sorting on the given graph."""
    in_degree = {u: 0 for u in graph}
    for u in graph:
        for v in graph[u]:
            in_degree[v] += 1

    queue = deque([u for u in graph if in_degree[u] == 0])
    topo_order = []

    while queue:
        u = queue.popleft()
        topo_order.append(u)

        for v in graph[u]:
            in_degree[v] -= 1
            if in_degree[v] == 0:
                queue.append(v)

    return topo_order

# %%
# Function to find the top models in each group
def find_top_models(group):
    max_net_dominance = group["Net_Dominance"].max()
    top_models = group[group["Net_Dominance"] == max_net_dominance]
    return top_models

# %% [markdown]
# ### Dominance Analysis and SCPM

# %%
def compute_scpm(df):
    scaler = StandardScaler()
    standardized_metrics = scaler.fit_transform(
        df[["RMSE_mean", "MAE_mean", "MAPE_mean", "R2_mean"]]
    )

    # Creating a new dataframe with standardized values
    standardized_df = pd.DataFrame(
        standardized_metrics,
        columns=["RMSE_mean", "MAE_mean", "MAPE_mean", "R2_mean"],
    )

    # Summing all metrics and subtracting R2_mean
    standardized_df["Result"] = (
        standardized_df[["RMSE_mean", "MAE_mean", "MAPE_mean"]].sum(axis=1)
        - standardized_df["R2_mean"]
    )

    df["SCPM"] = standardized_df["Result"]
    return df

# %%
def make_dominance_analysis(df):
    # Compute dominance matrix and graph
    dominance_matrix, dominance_graph = get_dominance_matrix_and_graph(df)

    # Get the topological order
    topo_order = topological_sort(dominance_graph)
    df = df.copy()
    n = len(topo_order)

    # Identify Dominant Models
    dominant_models = [
        df["Model_bkp_2"].iloc[i]
        for i in range(len(df))
        if not np.any(dominance_matrix[:, i])
    ]

    # Identify Non-Dominant Models
    non_dominant_models = [
        df["Model_bkp_2"].iloc[i]
        for i in range(len(df))
        if np.any(dominance_matrix[:, i])
    ]

    # Identify Models that are both dominated and dominate at least one
    intermediate_models = [
        df["Model_bkp_2"].iloc[i]
        for i in range(len(df))
        if np.any(dominance_matrix[:, i]) and np.any(dominance_matrix[i, :])
    ]

    # Add count of times each model is dominated by others
    df["Dominated_Count"] = np.sum(dominance_matrix, axis=0)

    # Classify models
    df["Classification"] = "intermediate_model"  # default to intermediate_model
    df.loc[
        ~np.any(dominance_matrix, axis=1) & np.any(dominance_matrix, axis=0),
        "Classification",
    ] = "non_dominant_model"
    df.loc[~np.any(dominance_matrix, axis=0), "Classification"] = "dominant_model"

    # Map the topological order to the model names and get dominance counts
    sorted_models = [df["Model"].iloc[i] for i in topo_order]

    df_sorted = df.iloc[topo_order].copy()
    df_sorted["Dominates_Count"] = dominance_matrix.sum(axis=1)[topo_order]
    df_sorted_topo = df_sorted.copy()

    df_sorted = df_sorted.sort_values(by="Dominates_Count", ascending=False)
    df_sorted_count = df_sorted.copy()

    return {
        "dominance_matrix": dominance_matrix,
        "dominance_graph": dominance_graph,
        "df_sorted_topo": df_sorted_topo,
        "df_sorted_count": df_sorted_count,
    }

# %% [markdown]
# # Pre Training Analysis

# %% [markdown]
# # Reading The files

# %%
csv_files_path_fine_tuning = dict()
csv_files_path_pre_train = dict()

# %% [markdown]
# ## 204

# %% [markdown]
# ### Plant AB

# %%
path_pre_train = "/home/peressim/projects/ccs28-ml-modelling/reports/results/global_models/204/ab/pre_training/full/"
plant = "ab"

csv_files_path_pre_train = read_csv_files_path(
    csv_files_path_pre_train, path_pre_train, plant
)

# %% [markdown]
# ## 204

# %% [markdown]
# ### Plant F

# %%
path_pre_train = "/home/peressim/projects/ccs28-ml-modelling/reports/results/global_models/204/f/pre_training/full/"
plant = "f"

csv_files_path_pre_train = read_csv_files_path(
    csv_files_path_pre_train, path_pre_train, plant
)

# %% [markdown]
# ### Reading all data - pre training

# %% [markdown]
# #### Full

# %%
dfs_plant = dict()
column = ("plant", "")
pos = 2

for plant, csv_files in csv_files_path_pre_train.items():
    df = read_csv_files_full(csv_files, plant)
    df["plant"] = plant
    dfs_plant[plant] = df

# %%
df_pre_train = pd.concat(dfs_plant.values(), ignore_index=True)

# %%
df_pre_train.shape
# Out:
# (438, 23)

# %% [markdown]
# ## Preprocessing

# %%
patterns = [
    "Chemical + Mineralogical + Feature Engineering",
    "Chemical + Mineralogical + CS7 + One-Hot",
    "Chemical + Mineralogical + Physical + One-Hot",
    "Chemical + Mineralogical + CS3 + One-Hot",
    "Chemical + Mineralogical + CS3 + CS7 + One-Hot",
    "Chemical + Mineralogical + One-Hot",
    "Chemical + Mineralogical + CS1 + CS3 + CS7 + One-Hot",
    "Chemical + Mineralogical + CS1 + CS3 + One-Hot",
    "Chemical + Mineralogical + CS1 + One-Hot",
    "Chemical + Mineralogical + CS2 + One-Hot",
    "Chemical + Feature Engineering",
]

FEATURES_TO_REPLACE_1 = {
    "Chemical + Mineralogical + CS3 + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS3": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS1": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS1 + CS3": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS1 + CS3 + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS2": "Chemical + Mineralogical + Early CS",
    "Chemical + CS1 + CS3 + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + CS3 + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + CS3": "Chemical + Mineralogical + Early CS",
    "Chemical + CS1 + CS3": "Chemical + Mineralogical + Early CS",
    "Chemical + CS1": "Chemical + Mineralogical + Early CS",
    "Chemical + CS1 + CS7": "Chemical + Mineralogical + Early CS",
}

FEATURES_TO_REPLACE_2 = {
    "Chemical": "Chemical + Mineralogical",
    "Chemical + Properties CS Less": "Chemical + Mineralogical + Physical - Early CS",
    "Chemical + Mineralogical + Properties CS Less": "Chemical + Mineralogical + Physical - Early CS",
    "Chemical + Physical": "Chemical + Mineralogical + Physical",
}

df_pre_train = df_pre_train[
    ~df_pre_train["Features"].apply(lambda x: x in patterns)
].reset_index(drop=True)

df_pre_train = df_pre_train[
    ~df_pre_train["Cross Validation"].eq("Out of time Split")
].reset_index(drop=True)

# removing afterwards
df_pre_train = df_pre_train[
    ~df_pre_train["Cross Validation"].eq("Repeated KFold")
].reset_index(drop=True)

df_pre_train["Features_bkp"] = df_pre_train["Features"].copy()
df_pre_train["Features"] = df_pre_train["Features"].replace(FEATURES_TO_REPLACE_1)

df_pre_train["Features"] = df_pre_train["Features"].replace(FEATURES_TO_REPLACE_2)


# removing afterwards
# df_pre_train = df_pre_train[
#     ~df_pre_train["Features"].eq("Chemical + Mineralogical + Early CS")
# ].reset_index(drop=True)

metrics_names = {
    "RMSE Test": "RMSE_mean",
    "MAE Test": "MAE_mean",
    "MAPE Test": "MAPE_mean",
    "R2 Test": "R2_mean",
}

df_pre_train = df_pre_train.rename(metrics_names, axis=1)

# %%
df_pre_train["Features"].unique()
# Out:
# array(['Chemical + Mineralogical + Physical - Early CS',
#        'Chemical + Mineralogical + Physical', 'Chemical + Mineralogical'],
#       dtype=object)

# %%
df_pre_train["MAPE Train"] = df_pre_train["MAPE Train"] * 100
df_pre_train["MAPE_mean"] = df_pre_train["MAPE_mean"] * 100

df_pre_train["Model_bkp"] = df_pre_train["Model"].copy()
df_pre_train["Model_bkp_2"] = df_pre_train["Model"].apply(
    lambda x: "" if pd.isna(x) else "_" + str(x)
)

# %%
df_pre_train["Model_bkp_2"] = df_pre_train["Model_bkp_2"].apply(
    lambda x: "MLP"
    if "MLP" in x
    else "Bi-LSTM"
    if "Bi-LSTM" in x
    else "LSTM"
    if "LSTM" in x
    else "Conv1D"
    if "Conv1D" in x
    else "Transformer"
)

# %%
df_pre_train["Cross Validation"].unique()
# Out:
# array(['Out of time'], dtype=object)

# %%
df_pre_train["Features"].unique()
# Out:
# array(['Chemical + Mineralogical + Physical - Early CS',
#        'Chemical + Mineralogical + Physical', 'Chemical + Mineralogical'],
#       dtype=object)

# %%
df_pre_train["Features_bkp"].unique()
# Out:
# array(['Chemical + Properties CS Less', 'Chemical + Physical', 'Chemical'],
#       dtype=object)

# %%
df_pre_train.shape
# Out:
# (438, 26)

# %%
df_pre_train["Features"].unique()
# Out:
# array(['Chemical + Mineralogical + Physical - Early CS',
#        'Chemical + Mineralogical + Physical', 'Chemical + Mineralogical'],
#       dtype=object)

# %%
df_results_cm = (
    df_pre_train[df_pre_train["Features"].eq("Chemical + Mineralogical")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm["Features"].unique()
# Out:
# array(['Chemical + Mineralogical'], dtype=object)

# %%
df_results_cm.shape
# Out:
# (146, 26)

# %% [markdown]
# # Global Analysis (pre train results)

# %% [markdown]
# ## ECICS - 204

# %% [markdown]
# ### Variable Grouping: CM

# %% [markdown]
# #### Analysis of the best models identified in the Local Analysis

# %% [markdown]
# **Best models for variable groupping CM were from:**
#
# *BTiSS:*
#     Dominance analysis: Plant AB
#     SCPM:Plant AB
#
# *TiSS:*
#     Dominance analysis: Plant F
#     SCPM:Plant F

# %% [markdown]
# ### Plant AB

# %% [markdown]
# #### Hold Out

# %%
df_results_cm = (
    df_pre_train[df_pre_train["Features"].eq("Chemical + Mineralogical")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm["Features"].unique()
# Out:
# array(['Chemical + Mineralogical'], dtype=object)

# %%
df_results_cm.shape
# Out:
# (146, 26)

# %%
df_results_cm = df_results_cm[df_results_cm["Plant"].eq("AB")].reset_index(drop=True)

# %%
df_results_cm["Cross Validation"].unique()
# Out:
# array(['Out of time'], dtype=object)

# %%
df_results_cm_ho = (
    df_results_cm[df_results_cm["Cross Validation"].eq("Out of time")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_ho["Cross Validation"].unique()
# Out:
# array(['Out of time'], dtype=object)

# %%
df_results_cm_ho.shape
# Out:
# (73, 26)

# %% [markdown]
# ###### SCPM computation

# %%
df_results_cm_ho = compute_scpm(df_results_cm_ho)

# %% [markdown]
# ##### Dominance Analysis

# %%
dominance_dict = make_dominance_analysis(df_results_cm_ho)
dominance_matrix_cm_ho = dominance_dict["dominance_matrix"]
dominance_graph_cm_ho = dominance_dict["dominance_graph"]
df_sorted_count = dominance_dict["df_sorted_count"]
df_sorted_topo = dominance_dict["df_sorted_topo"]

# %%
dominance_matrix_cm_ho.shape, len(dominance_graph_cm_ho)
# Out:
# ((73, 73), 73)

# %%
df_sorted_topo["Classification"].value_counts()
# Out:
# Classification
# intermediate_model    71
# dominant_model         1
# non_dominant_model     1
# Name: count, dtype: int64

# %%
# df_sorted_topo.to_csv(
#     "../../../../reports/results/local_models/ecics/ecics_dominance_analysis_cm_kf.csv",
#     index=False,
# )

# %%
df_sorted_topo.head(5)
# Out:
#         Category  Company Plant                  Features  Data Shape  \
# 41  Global Model      204    AB  Chemical + Mineralogical  (62581, 5)
# 33  Global Model      204    AB  Chemical + Mineralogical  (62581, 5)
# 38  Global Model      204    AB  Chemical + Mineralogical  (62581, 5)
# 24  Global Model      204    AB  Chemical + Mineralogical  (62581, 5)
# 15  Global Model      204    AB  Chemical + Mineralogical  (62581, 5)
#
#     Timesteps      Model  Model Params           Scaler  Scaler Params  ...  \
# 41        7.0  Bi-LSTM14           NaN  Standard Scaler            NaN  ...
# 33       14.0   Bi-LSTM6           NaN  Standard Scaler            NaN  ...
# 38        7.0  Bi-LSTM11           NaN  Standard Scaler            NaN  ...
# 24       14.0     LSTM12           NaN  Standard Scaler            NaN  ...
# 15       14.0      LSTM3           NaN  Standard Scaler            NaN  ...
#
#    MAPE_mean   R2_mean plant Features_bkp  Model_bkp  Model_bkp_2      SCPM  \
# 41  4.312253  0.830659    ab     Chemical  Bi-LSTM14      Bi-LSTM -2.763996
# 33  4.523614  0.822068    ab     Chemical   Bi-LSTM6      Bi-LSTM -2.473252
# 38  4.367373  0.817875    ab     Chemical  Bi-LSTM11      Bi-LSTM -2.576770
# 24  4.464608  0.816831    ab     Chemical     LSTM12         LSTM -2.462590
# 15  4.572102  0.815705    ab     Chemical      LSTM3         LSTM -2.344712
#
#     Dominated_Count      Classification  Dominates_Count
# 41                0      dominant_model               72
# 33                1  intermediate_model               69
# 38                1  intermediate_model               70
# 24                2  intermediate_model               69
# 15                4  intermediate_model               66
#
# [5 rows x 30 columns]

# %%
df_sorted_topo_cols = df_sorted_topo[
    [
        "Model",
        # "Model_bkp",
        # "Model_bkp_2",
        "Timesteps",
        "RMSE_mean",
        "MAE_mean",
        "MAPE_mean",
        "R2_mean",
        "SCPM",
        "Dominated_Count",
        "Classification",
        "Dominates_Count",
        "Plant",
    ]
].round(2)

# %% [markdown]
# ##### Top dominant models

# %%
# Top 4
df_sorted_topo_cols.sort_values(by="Dominates_Count", ascending=False).iloc[0:3]
# Out:
#         Model  Timesteps  RMSE_mean  MAE_mean  MAPE_mean  R2_mean  SCPM  \
# 41  Bi-LSTM14        7.0       2.49      1.83       4.31     0.83 -2.76
# 38  Bi-LSTM11        7.0       2.58      1.86       4.37     0.82 -2.58
# 24     LSTM12       14.0       2.59      1.91       4.46     0.82 -2.46
#
#     Dominated_Count      Classification  Dominates_Count Plant
# 41                0      dominant_model               72    AB
# 38                1  intermediate_model               70    AB
# 24                2  intermediate_model               69    AB

# %% [markdown]
# ##### Top intermediate models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].sort_values(by="Dominates_Count", ascending=False).iloc[:2]
# Out:
#         Model  Timesteps  RMSE_mean  MAE_mean  MAPE_mean  R2_mean  SCPM  \
# 38  Bi-LSTM11        7.0       2.58      1.86       4.37     0.82 -2.58
# 33   Bi-LSTM6       14.0       2.55      1.91       4.52     0.82 -2.47
#
#     Dominated_Count      Classification  Dominates_Count Plant
# 38                1  intermediate_model               70    AB
# 33                1  intermediate_model               69    AB

# %% [markdown]
# ##### Top non dominant models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].sort_values(by="Dominated_Count", ascending=True).iloc[:2]
# Out:
#        Model  Timesteps  RMSE_mean  MAE_mean  MAPE_mean  R2_mean   SCPM  \
# 36  Bi-LSTM9       14.0      11.29      8.54      19.26    -2.49  30.74
#
#     Dominated_Count      Classification  Dominates_Count Plant
# 36               72  non_dominant_model                0    AB

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        # "Model",
        # "Model_bkp",
        "Model_bkp_2",
        "Timesteps",
        "RMSE_mean",
        "MAE_mean",
        "MAPE_mean",
        "R2_mean",
        "SCPM",
        "Dominated_Count",
        "Classification",
        "Dominates_Count",
        "Plant",
    ]
]  # .round(2)

# %%
df_sorted_topo["Model_bkp_2"].value_counts()
# Out:
# Model_bkp_2
# Bi-LSTM        15
# LSTM           15
# Conv1D         15
# Transformer    15
# MLP            13
# Name: count, dtype: int64

# %%
df_sorted_topo_models_grouped = (
    df_sorted_topo_models_cols.groupby("Model_bkp_2").describe().T
)

# %%
# pd.set_option("display.max_rows", None)
# df_sorted_topo_models_grouped

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model_bkp_2",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
    ]
]

# %%
df_sorted_topo_models_cols.groupby("Model_bkp_2").describe().round(2)
# Out:
#             Dominated_Count                                              \
#                       count   mean    std   min   25%   50%   75%   max
# Model_bkp_2
# Bi-LSTM                15.0  31.13  28.85   0.0   4.5  20.0  56.5  72.0
# Conv1D                 15.0  31.40  17.22   9.0  18.0  24.0  47.5  57.0
# LSTM                   15.0  26.40  23.60   2.0   9.0  13.0  52.0  65.0
# MLP                    13.0  32.69  10.13  19.0  26.0  29.0  42.0  50.0
# Transformer            15.0  43.87  19.25  19.0  28.5  36.0  66.0  70.0
#
#             Dominates_Count
#                       count   mean    std   min   25%   50%   75%   max
# Model_bkp_2
# Bi-LSTM                15.0  38.87  29.07   0.0  11.5  47.0  66.5  72.0
# Conv1D                 15.0  34.47  18.10  10.0  17.5  37.0  50.0  61.0
# LSTM                   15.0  42.67  23.04   7.0  18.5  56.0  59.5  69.0
# MLP                    13.0  29.69   6.87  22.0  24.0  30.0  35.0  43.0
# Transformer            15.0  19.40  13.24   1.0   5.0  24.0  31.0  39.0

# %%
df_sorted_topo_models_cols.groupby("Model_bkp_2")["Classification"].describe()
# Out:
#             count unique                 top freq
# Model_bkp_2
# Bi-LSTM        15      3  intermediate_model   13
# Conv1D         15      1  intermediate_model   15
# LSTM           15      1  intermediate_model   15
# MLP            13      1  intermediate_model   13
# Transformer    15      1  intermediate_model   15

# %%
df_sorted_topo_models_cols.groupby("Model_bkp_2")[["Classification"]].value_counts()
# Out:
# Model_bkp_2  Classification
# Bi-LSTM      intermediate_model    13
#              dominant_model         1
#              non_dominant_model     1
# Conv1D       intermediate_model    15
# LSTM         intermediate_model    15
# MLP          intermediate_model    13
# Transformer  intermediate_model    15
# Name: count, dtype: int64

# %%
(
    df_sorted_topo_models_cols.groupby("Model_bkp_2")[["Classification"]]
    .value_counts(normalize=True)
    .to_frame()
    * 100
).round(2)
# Out:
#                                 proportion
# Model_bkp_2 Classification
# Bi-LSTM     intermediate_model       86.67
#             dominant_model            6.67
#             non_dominant_model        6.67
# Conv1D      intermediate_model      100.00
# LSTM        intermediate_model      100.00
# MLP         intermediate_model      100.00
# Transformer intermediate_model      100.00

# %%
df_sorted_topo_models_cols
# Out:
#     Model_bkp_2  Dominated_Count  Dominates_Count      Classification
# 41      Bi-LSTM                0               72      dominant_model
# 33      Bi-LSTM                1               69  intermediate_model
# 38      Bi-LSTM                1               70  intermediate_model
# 24         LSTM                2               69  intermediate_model
# 15         LSTM                4               66  intermediate_model
# ..          ...              ...              ...                 ...
# 46  Transformer               68                4  intermediate_model
# 43  Transformer               69                3  intermediate_model
# 39      Bi-LSTM               70                1  intermediate_model
# 55  Transformer               70                1  intermediate_model
# 36      Bi-LSTM               72                0  non_dominant_model
#
# [73 rows x 4 columns]

# %%
summary_stats = df_sorted_topo_models_cols.groupby("Model_bkp_2").agg(
    Total_Models=("Model_bkp_2", "count"),
    Mean_Dominance_Count=("Dominates_Count", "mean"),
    Median_Dominance_Count=("Dominates_Count", "median"),
    Total_Dominated=("Dominated_Count", "sum"),
    Total_Dominating=("Dominates_Count", "sum"),
)

total_models = summary_stats[
    "Total_Models"
].sum()  # Get the total number of models across all categories
summary_stats["Dominance Proportion"] = summary_stats["Total_Dominating"] / total_models

# %%
summary_stats
# Out:
#              Total_Models  Mean_Dominance_Count  Median_Dominance_Count  \
# Model_bkp_2
# Bi-LSTM                15             38.866667                    47.0
# Conv1D                 15             34.466667                    37.0
# LSTM                   15             42.666667                    56.0
# MLP                    13             29.692308                    30.0
# Transformer            15             19.400000                    24.0
#
#              Total_Dominated  Total_Dominating  Dominance Proportion
# Model_bkp_2
# Bi-LSTM                  467               583              7.986301
# Conv1D                   471               517              7.082192
# LSTM                     396               640              8.767123
# MLP                      425               386              5.287671
# Transformer              658               291              3.986301

# %%
df_sorted_topo_models_grouped.T
# Out:
#             Timesteps                                                 \
#                 count      mean       std  min  25%  50%   75%   max
# Model_bkp_2
# Bi-LSTM          15.0  7.333333  5.498918  1.0  1.0  7.0  14.0  14.0
# Conv1D           15.0  7.333333  5.498918  1.0  1.0  7.0  14.0  14.0
# LSTM             15.0  7.333333  5.498918  1.0  1.0  7.0  14.0  14.0
# MLP               0.0       NaN       NaN  NaN  NaN  NaN   NaN   NaN
# Transformer      15.0  7.333333  5.498918  1.0  1.0  7.0  14.0  14.0
#
#             RMSE_mean            ... Dominated_Count       Dominates_Count  \
#                 count      mean  ...             75%   max           count
# Model_bkp_2                      ...
# Bi-LSTM          15.0  3.643373  ...            56.5  72.0            15.0
# Conv1D           15.0  3.119560  ...            47.5  57.0            15.0
# LSTM             15.0  3.026647  ...            52.0  65.0            15.0
# MLP              13.0  3.183583  ...            42.0  50.0            13.0
# Transformer      15.0  3.464101  ...            66.0  70.0            15.0
#
#
#                   mean        std   min   25%   50%   75%   max
# Model_bkp_2
# Bi-LSTM      38.866667  29.066099   0.0  11.5  47.0  66.5  72.0
# Conv1D       34.466667  18.102354  10.0  17.5  37.0  50.0  61.0
# LSTM         42.666667  23.036203   7.0  18.5  56.0  59.5  69.0
# MLP          29.692308   6.872465  22.0  24.0  30.0  35.0  43.0
# Transformer  19.400000  13.243867   1.0   5.0  24.0  31.0  39.0
#
# [5 rows x 64 columns]

# %% [markdown]
# ### SCPM Analysis

# %%
cols = [
    "Model",
    # "Model_bkp",
    "Model_bkp_2",
    "Timesteps",
    "RMSE_mean",
    "MAE_mean",
    "MAPE_mean",
    "R2_mean",
    "SCPM",
    "Dominated_Count",
    "Dominates_Count",
    "Classification",
    "Plant",
]

# %%
df_sorted_scpm = df_sorted_topo.sort_values(by="SCPM").copy()

# %%
# (df_sorted_topo[cols].reset_index() == df_sorted_scpm[cols].reset_index()).all(axis=1)
df_sorted_scpm["topo_scmp_order_eq"] = df_sorted_topo.index == df_sorted_scpm.index

# %%
# df_sorted_topo[cols].round(2).head(5)

# %%
df_sorted_scpm[cols + ["topo_scmp_order_eq"]].round(2).head(7)
# Out:
#         Model Model_bkp_2  Timesteps  RMSE_mean  MAE_mean  MAPE_mean  R2_mean  \
# 41  Bi-LSTM14     Bi-LSTM        7.0       2.49      1.83       4.31     0.83
# 38  Bi-LSTM11     Bi-LSTM        7.0       2.58      1.86       4.37     0.82
# 33   Bi-LSTM6     Bi-LSTM       14.0       2.55      1.91       4.52     0.82
# 24     LSTM12        LSTM       14.0       2.59      1.91       4.46     0.82
# 29   Bi-LSTM2     Bi-LSTM        7.0       2.60      1.93       4.54     0.82
# 15      LSTM3        LSTM       14.0       2.59      1.94       4.57     0.82
# 42  Bi-LSTM15     Bi-LSTM       14.0       2.62      1.94       4.57     0.81
#
#     SCPM  Dominated_Count  Dominates_Count      Classification Plant  \
# 41 -2.76                0               72      dominant_model    AB
# 38 -2.58                1               70  intermediate_model    AB
# 33 -2.47                1               69  intermediate_model    AB
# 24 -2.46                2               69  intermediate_model    AB
# 29 -2.38                4               67  intermediate_model    AB
# 15 -2.34                4               66  intermediate_model    AB
# 42 -2.31                5               66  intermediate_model    AB
#
#     topo_scmp_order_eq
# 41                True
# 38               False
# 33               False
# 24                True
# 29               False
# 15               False
# 42                True

# %%
df_sorted_scpm[cols + ["topo_scmp_order_eq"]].head(1)
# Out:
#         Model Model_bkp_2  Timesteps  RMSE_mean  MAE_mean  MAPE_mean  \
# 41  Bi-LSTM14     Bi-LSTM        7.0   2.486856  1.834692   4.312253
#
#      R2_mean      SCPM  Dominated_Count  Dominates_Count  Classification  \
# 41  0.830659 -2.763996                0               72  dominant_model
#
#    Plant  topo_scmp_order_eq
# 41    AB                True

# %% [markdown]
# ### Plant F

# %% [markdown]
# #### Hold Out

# %%
df_results_cm = (
    df_pre_train[df_pre_train["Features"].eq("Chemical + Mineralogical")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm["Features"].unique()
# Out:
# array(['Chemical + Mineralogical'], dtype=object)

# %%
df_results_cm.shape
# Out:
# (146, 26)

# %%
df_results_cm = df_results_cm[df_results_cm["Plant"].eq("F")].reset_index(drop=True)

# %%
df_results_cm["Cross Validation"].unique()
# Out:
# array(['Out of time'], dtype=object)

# %%
df_results_cm_ho = (
    df_results_cm[df_results_cm["Cross Validation"].eq("Out of time")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_ho["Cross Validation"].unique()
# Out:
# array(['Out of time'], dtype=object)

# %%
df_results_cm_ho.shape
# Out:
# (73, 26)

# %% [markdown]
# ###### SCPM computation

# %%
df_results_cm_ho = compute_scpm(df_results_cm_ho)

# %% [markdown]
# ##### Dominance Analysis

# %%
dominance_dict = make_dominance_analysis(df_results_cm_ho)
dominance_matrix_cm_ho = dominance_dict["dominance_matrix"]
dominance_graph_cm_ho = dominance_dict["dominance_graph"]
df_sorted_count = dominance_dict["df_sorted_count"]
df_sorted_topo = dominance_dict["df_sorted_topo"]

# %%
dominance_matrix_cm_ho.shape, len(dominance_graph_cm_ho)
# Out:
# ((73, 73), 73)

# %%
df_sorted_topo["Classification"].value_counts()
# Out:
# Classification
# intermediate_model    69
# dominant_model         3
# non_dominant_model     1
# Name: count, dtype: int64

# %%
# df_sorted_topo.to_csv(
#     "../../../../reports/results/local_models/ecics/ecics_dominance_analysis_cm_kf.csv",
#     index=False,
# )

# %%
df_sorted_topo.head(5)
# Out:
#         Category  Company Plant                  Features  Data Shape  \
# 14  Global Model      204     F  Chemical + Mineralogical  (62318, 9)
# 33  Global Model      204     F  Chemical + Mineralogical  (62318, 9)
# 36  Global Model      204     F  Chemical + Mineralogical  (62318, 9)
# 39  Global Model      204     F  Chemical + Mineralogical  (62318, 9)
# 10  Global Model      204     F  Chemical + Mineralogical  (62318, 9)
#
#     Timesteps      Model  Model Params           Scaler  Scaler Params  ...  \
# 14        7.0      LSTM2           NaN  Standard Scaler            NaN  ...
# 33       14.0   Bi-LSTM6           NaN  Standard Scaler            NaN  ...
# 36       14.0   Bi-LSTM9           NaN  Standard Scaler            NaN  ...
# 39       14.0  Bi-LSTM12           NaN  Standard Scaler            NaN  ...
# 10        NaN     MLP_11           NaN  Standard Scaler            NaN  ...
#
#    MAPE_mean   R2_mean plant Features_bkp  Model_bkp  Model_bkp_2      SCPM  \
# 14  4.451310  0.827792     f     Chemical      LSTM2         LSTM -4.408101
# 33  4.219215  0.827575     f     Chemical   Bi-LSTM6      Bi-LSTM -4.952151
# 36  4.443989  0.832924     f     Chemical   Bi-LSTM9      Bi-LSTM -4.580752
# 39  4.304836  0.824702     f     Chemical  Bi-LSTM12      Bi-LSTM -4.541505
# 10  4.436817  0.802472     f     Chemical     MLP_11          MLP -3.530093
#
#     Dominated_Count      Classification  Dominates_Count
# 14                0      dominant_model               68
# 33                0      dominant_model               70
# 36                0      dominant_model               68
# 39                1  intermediate_model               69
# 10                2  intermediate_model               51
#
# [5 rows x 30 columns]

# %%
df_sorted_topo_cols = df_sorted_topo[
    [
        "Model",
        # "Model_bkp",
        # "Model_bkp_2",
        "Timesteps",
        "RMSE_mean",
        "MAE_mean",
        "MAPE_mean",
        "R2_mean",
        "SCPM",
        "Dominated_Count",
        "Classification",
        "Dominates_Count",
        "Plant",
    ]
].round(2)

# %% [markdown]
# ##### Top dominant models

# %%
# Top 4
df_sorted_topo_cols.sort_values(by="Dominates_Count", ascending=False).iloc[0:3]
# Out:
#         Model  Timesteps  RMSE_mean  MAE_mean  MAPE_mean  R2_mean  SCPM  \
# 33   Bi-LSTM6       14.0       2.49      1.80       4.22     0.83 -4.95
# 39  Bi-LSTM12       14.0       2.51      1.86       4.30     0.82 -4.54
# 14      LSTM2        7.0       2.49      1.88       4.45     0.83 -4.41
#
#     Dominated_Count      Classification  Dominates_Count Plant
# 33                0      dominant_model               70     F
# 39                1  intermediate_model               69     F
# 14                0      dominant_model               68     F

# %% [markdown]
# ##### Top intermediate models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].sort_values(by="Dominates_Count", ascending=False).iloc[:2]
# Out:
#         Model  Timesteps  RMSE_mean  MAE_mean  MAPE_mean  R2_mean  SCPM  \
# 39  Bi-LSTM12       14.0       2.51      1.86       4.30     0.82 -4.54
# 24     LSTM12       14.0       2.53      1.92       4.55     0.82 -3.91
#
#     Dominated_Count      Classification  Dominates_Count Plant
# 39                1  intermediate_model               69     F
# 24                4  intermediate_model               59     F

# %% [markdown]
# ##### Top non dominant models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].sort_values(by="Dominated_Count", ascending=True).iloc[:2]
# Out:
#             Model  Timesteps  RMSE_mean  MAE_mean  MAPE_mean  R2_mean   SCPM  \
# 46  Transformer_4        1.0       4.16      3.11       7.59     0.52  13.11
#
#     Dominated_Count      Classification  Dominates_Count Plant
# 46               72  non_dominant_model                0     F

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        # "Model",
        # "Model_bkp",
        "Model_bkp_2",
        "Timesteps",
        "RMSE_mean",
        "MAE_mean",
        "MAPE_mean",
        "R2_mean",
        "SCPM",
        "Dominated_Count",
        "Classification",
        "Dominates_Count",
        "Plant",
    ]
]  # .round(2)

# %%
df_sorted_topo["Model_bkp_2"].value_counts()
# Out:
# Model_bkp_2
# LSTM           15
# Bi-LSTM        15
# Conv1D         15
# Transformer    15
# MLP            13
# Name: count, dtype: int64

# %%
df_sorted_topo_models_grouped = (
    df_sorted_topo_models_cols.groupby("Model_bkp_2").describe().T
)

# %%
# pd.set_option("display.max_rows", None)
# df_sorted_topo_models_grouped

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model_bkp_2",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
    ]
]

# %%
df_sorted_topo_models_cols.groupby("Model_bkp_2").describe().round(2)
# Out:
#             Dominated_Count                                              \
#                       count   mean    std   min   25%   50%   75%   max
# Model_bkp_2
# Bi-LSTM                15.0  30.47  21.17   0.0  14.0  35.0  44.0  65.0
# Conv1D                 15.0  23.20  14.94   5.0  11.0  18.0  37.5  47.0
# LSTM                   15.0  27.07  26.04   0.0   4.0  18.0  51.0  70.0
# MLP                    13.0  17.62  12.49   2.0   8.0  15.0  27.0  38.0
# Transformer            15.0  58.20   7.71  44.0  53.5  58.0  62.5  72.0
#
#             Dominates_Count
#                       count   mean    std   min   25%   50%   75%   max
# Model_bkp_2
# Bi-LSTM                15.0  34.93  21.70   3.0  21.5  28.0  48.0  70.0
# Conv1D                 15.0  38.87  11.53  21.0  29.0  39.0  49.0  55.0
# LSTM                   15.0  36.33  23.30   1.0  17.0  41.0  56.5  68.0
# MLP                    13.0  39.85   7.01  26.0  38.0  39.0  43.0  51.0
# Transformer            15.0   9.53   7.19   0.0   4.5   8.0  14.0  25.0

# %%
df_sorted_topo_models_cols.groupby("Model_bkp_2")["Classification"].describe()
# Out:
#             count unique                 top freq
# Model_bkp_2
# Bi-LSTM        15      2  intermediate_model   13
# Conv1D         15      1  intermediate_model   15
# LSTM           15      2  intermediate_model   14
# MLP            13      1  intermediate_model   13
# Transformer    15      2  intermediate_model   14

# %%
df_sorted_topo_models_cols.groupby("Model_bkp_2")[["Classification"]].value_counts()
# Out:
# Model_bkp_2  Classification
# Bi-LSTM      intermediate_model    13
#              dominant_model         2
# Conv1D       intermediate_model    15
# LSTM         intermediate_model    14
#              dominant_model         1
# MLP          intermediate_model    13
# Transformer  intermediate_model    14
#              non_dominant_model     1
# Name: count, dtype: int64

# %%
(
    df_sorted_topo_models_cols.groupby("Model_bkp_2")[["Classification"]]
    .value_counts(normalize=True)
    .to_frame()
    * 100
).round(2)
# Out:
#                                 proportion
# Model_bkp_2 Classification
# Bi-LSTM     intermediate_model       86.67
#             dominant_model           13.33
# Conv1D      intermediate_model      100.00
# LSTM        intermediate_model       93.33
#             dominant_model            6.67
# MLP         intermediate_model      100.00
# Transformer intermediate_model       93.33
#             non_dominant_model        6.67

# %%
df_sorted_topo_models_cols
# Out:
#     Model_bkp_2  Dominated_Count  Dominates_Count      Classification
# 14         LSTM                0               68      dominant_model
# 33      Bi-LSTM                0               70      dominant_model
# 36      Bi-LSTM                0               68      dominant_model
# 39      Bi-LSTM                1               69  intermediate_model
# 10          MLP                2               51  intermediate_model
# ..          ...              ...              ...                 ...
# 48  Transformer               63                4  intermediate_model
# 57  Transformer               65                3  intermediate_model
# 22         LSTM               70                1  intermediate_model
# 43  Transformer               70                1  intermediate_model
# 46  Transformer               72                0  non_dominant_model
#
# [73 rows x 4 columns]

# %%
summary_stats = df_sorted_topo_models_cols.groupby("Model_bkp_2").agg(
    Total_Models=("Model_bkp_2", "count"),
    Mean_Dominance_Count=("Dominates_Count", "mean"),
    Median_Dominance_Count=("Dominates_Count", "median"),
    Total_Dominated=("Dominated_Count", "sum"),
    Total_Dominating=("Dominates_Count", "sum"),
)

total_models = summary_stats[
    "Total_Models"
].sum()  # Get the total number of models across all categories
summary_stats["Dominance Proportion"] = summary_stats["Total_Dominating"] / total_models

# %%
summary_stats
# Out:
#              Total_Models  Mean_Dominance_Count  Median_Dominance_Count  \
# Model_bkp_2
# Bi-LSTM                15             34.933333                    28.0
# Conv1D                 15             38.866667                    39.0
# LSTM                   15             36.333333                    41.0
# MLP                    13             39.846154                    39.0
# Transformer            15              9.533333                     8.0
#
#              Total_Dominated  Total_Dominating  Dominance Proportion
# Model_bkp_2
# Bi-LSTM                  457               524              7.178082
# Conv1D                   348               583              7.986301
# LSTM                     406               545              7.465753
# MLP                      229               518              7.095890
# Transformer              873               143              1.958904

# %%
df_sorted_topo_models_grouped.T
# Out:
#             Timesteps                                                 \
#                 count      mean       std  min  25%  50%   75%   max
# Model_bkp_2
# Bi-LSTM          15.0  7.333333  5.498918  1.0  1.0  7.0  14.0  14.0
# Conv1D           15.0  7.333333  5.498918  1.0  1.0  7.0  14.0  14.0
# LSTM             15.0  7.333333  5.498918  1.0  1.0  7.0  14.0  14.0
# MLP               0.0       NaN       NaN  NaN  NaN  NaN   NaN   NaN
# Transformer      15.0  7.333333  5.498918  1.0  1.0  7.0  14.0  14.0
#
#             RMSE_mean            ... Dominated_Count       Dominates_Count  \
#                 count      mean  ...             75%   max           count
# Model_bkp_2                      ...
# Bi-LSTM          15.0  2.880929  ...            44.0  65.0            15.0
# Conv1D           15.0  2.734598  ...            37.5  47.0            15.0
# LSTM             15.0  2.877480  ...            51.0  70.0            15.0
# MLP              13.0  2.780350  ...            27.0  38.0            13.0
# Transformer      15.0  3.356702  ...            62.5  72.0            15.0
#
#
#                   mean        std   min   25%   50%   75%   max
# Model_bkp_2
# Bi-LSTM      34.933333  21.704070   3.0  21.5  28.0  48.0  70.0
# Conv1D       38.866667  11.531737  21.0  29.0  39.0  49.0  55.0
# LSTM         36.333333  23.304404   1.0  17.0  41.0  56.5  68.0
# MLP          39.846154   7.010066  26.0  38.0  39.0  43.0  51.0
# Transformer   9.533333   7.189940   0.0   4.5   8.0  14.0  25.0
#
# [5 rows x 64 columns]

# %% [markdown]
# ### SCPM Analysis

# %%
cols = [
    "Model",
    # "Model_bkp",
    "Model_bkp_2",
    "Timesteps",
    "RMSE_mean",
    "MAE_mean",
    "MAPE_mean",
    "R2_mean",
    "SCPM",
    "Dominated_Count",
    "Dominates_Count",
    "Classification",
    "Plant",
]

# %%
df_sorted_scpm = df_sorted_topo.sort_values(by="SCPM").copy()

# %%
# (df_sorted_topo[cols].reset_index() == df_sorted_scpm[cols].reset_index()).all(axis=1)
df_sorted_scpm["topo_scmp_order_eq"] = df_sorted_topo.index == df_sorted_scpm.index

# %%
# df_sorted_topo[cols].round(2).head(5)

# %%
df_sorted_scpm[cols + ["topo_scmp_order_eq"]].round(2).head(7)
# Out:
#         Model Model_bkp_2  Timesteps  RMSE_mean  MAE_mean  MAPE_mean  R2_mean  \
# 33   Bi-LSTM6     Bi-LSTM       14.0       2.49      1.80       4.22     0.83
# 36   Bi-LSTM9     Bi-LSTM       14.0       2.45      1.88       4.44     0.83
# 39  Bi-LSTM12     Bi-LSTM       14.0       2.51      1.86       4.30     0.82
# 14      LSTM2        LSTM        7.0       2.49      1.88       4.45     0.83
# 26     LSTM14        LSTM        7.0       2.56      1.90       4.49     0.82
# 24     LSTM12        LSTM       14.0       2.53      1.92       4.55     0.82
# 23     LSTM11        LSTM        7.0       2.52      1.93       4.62     0.82
#
#     SCPM  Dominated_Count  Dominates_Count      Classification Plant  \
# 33 -4.95                0               70      dominant_model     F
# 36 -4.58                0               68      dominant_model     F
# 39 -4.54                1               69  intermediate_model     F
# 14 -4.41                0               68      dominant_model     F
# 26 -3.93                4               59  intermediate_model     F
# 24 -3.91                4               59  intermediate_model     F
# 23 -3.85                4               53  intermediate_model     F
#
#     topo_scmp_order_eq
# 33               False
# 36               False
# 39               False
# 14               False
# 26               False
# 24               False
# 23               False

# %%
df_sorted_scpm[cols + ["topo_scmp_order_eq"]].head(1)
# Out:
#        Model Model_bkp_2  Timesteps  RMSE_mean  MAE_mean  MAPE_mean   R2_mean  \
# 33  Bi-LSTM6     Bi-LSTM       14.0   2.488382   1.80098   4.219215  0.827575
#
#         SCPM  Dominated_Count  Dominates_Count  Classification Plant  \
# 33 -4.952151                0               70  dominant_model     F
#
#     topo_scmp_order_eq
# 33               False

# %% [markdown]
# ### Variable Grouping: CM-P

# %% [markdown]
# #### Analysis of the best models identified in the Local Analysis

# %% [markdown]
# **Best models for variable groupping CM-P were from:**
#
# *BTiSS:*
#     Dominance analysis: Plant F
#     SCPM:Plant F
#
# *TiSS:*
#     Dominance analysis: Plant F
#     SCPM:Plant F

# %%
df_pre_train["Features"].unique()
# Out:
# array(['Chemical + Mineralogical + Physical - Early CS',
#        'Chemical + Mineralogical + Physical', 'Chemical + Mineralogical'],
#       dtype=object)

# %%
df_results_cm_p = (
    df_pre_train[
        df_pre_train["Features"].eq("Chemical + Mineralogical + Physical - Early CS")
    ]
    .copy()
    .reset_index(drop=True)
)

# %% [markdown]
# ### Plant F

# %%
df_results_cm_p_am = df_results_cm_p[df_results_cm_p["Plant"].eq("F")].reset_index(
    drop=True
)

# %%
df_results_cm_p_am.shape
# Out:
# (73, 26)

# %% [markdown]
# #### Hold Out

# %%
df_results_cm_p_am["Cross Validation"].unique()
# Out:
# array(['Out of time'], dtype=object)

# %%
df_results_cm_p_am_ho = (
    df_results_cm_p_am[df_results_cm_p_am["Cross Validation"].eq("Out of time")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_p_am_ho["Cross Validation"].unique()
# Out:
# array(['Out of time'], dtype=object)

# %%
df_results_cm_p_am_ho.shape
# Out:
# (73, 26)

# %% [markdown]
# ###### SCPM computation

# %%
df_results_cm_p_am_ho = compute_scpm(df_results_cm_p_am_ho)

# %% [markdown]
# ##### Dominance Analysis

# %%
dominance_dict = make_dominance_analysis(df_results_cm_p_am_ho)
dominance_matrix_cm_p_am_ho = dominance_dict["dominance_matrix"]
dominance_graph_cm_p_am_ho = dominance_dict["dominance_graph"]
df_sorted_count = dominance_dict["df_sorted_count"]
df_sorted_topo = dominance_dict["df_sorted_topo"]

# %%
dominance_matrix_cm_p_am_ho.shape, len(dominance_graph_cm_p_am_ho)
# Out:
# ((73, 73), 73)

# %%
df_sorted_topo["Classification"].value_counts()
# Out:
# Classification
# intermediate_model    71
# dominant_model         1
# non_dominant_model     1
# Name: count, dtype: int64

# %%
df_sorted_topo.head(5)
# Out:
#         Category  Company Plant  \
# 66  Global Model      204     F
# 71  Global Model      204     F
# 70  Global Model      204     F
# 65  Global Model      204     F
# 63  Global Model      204     F
#
#                                           Features   Data Shape  Timesteps  \
# 66  Chemical + Mineralogical + Physical - Early CS  (62318, 14)        NaN
# 71  Chemical + Mineralogical + Physical - Early CS  (62318, 14)        NaN
# 70  Chemical + Mineralogical + Physical - Early CS  (62318, 14)        NaN
# 65  Chemical + Mineralogical + Physical - Early CS  (62318, 14)        NaN
# 63  Chemical + Mineralogical + Physical - Early CS  (62318, 14)        NaN
#
#      Model  Model Params           Scaler  Scaler Params  ... MAPE_mean  \
# 66   MLP_7           NaN  Standard Scaler            NaN  ...  3.687292
# 71  MLP_12           NaN  Standard Scaler            NaN  ...  3.795167
# 70  MLP_11           NaN  Standard Scaler            NaN  ...  3.813354
# 65   MLP_6           NaN  Standard Scaler            NaN  ...  3.864181
# 63   MLP_4           NaN  Standard Scaler            NaN  ...  3.971155
#
#      R2_mean plant                   Features_bkp  Model_bkp  Model_bkp_2  \
# 66  0.868935     f  Chemical + Properties CS Less      MLP_7          MLP
# 71  0.864139     f  Chemical + Properties CS Less     MLP_12          MLP
# 70  0.862341     f  Chemical + Properties CS Less     MLP_11          MLP
# 65  0.855133     f  Chemical + Properties CS Less      MLP_6          MLP
# 63  0.848673     f  Chemical + Properties CS Less      MLP_4          MLP
#
#         SCPM  Dominated_Count      Classification  Dominates_Count
# 66 -1.503910                0      dominant_model               72
# 71 -1.467262                1  intermediate_model               71
# 70 -1.458000                2  intermediate_model               70
# 65 -1.428462                3  intermediate_model               69
# 63 -1.386158                4  intermediate_model               66
#
# [5 rows x 30 columns]

# %%
df_sorted_topo_cols = df_sorted_topo[
    [
        "Model",
        # "Model_bkp",
        # "Model_bkp_2",
        "Timesteps",
        "RMSE_mean",
        "MAE_mean",
        "MAPE_mean",
        "R2_mean",
        "SCPM",
        "Dominated_Count",
        "Classification",
        "Dominates_Count",
        "Plant",
    ]
].round(2)

# %% [markdown]
# ##### Top dominant models

# %%
# Top 4
df_sorted_topo_cols.sort_values(by="Dominates_Count", ascending=False).iloc[0:3]
# Out:
#      Model  Timesteps  RMSE_mean  MAE_mean  MAPE_mean  R2_mean  SCPM  \
# 66   MLP_7        NaN       2.17      1.57       3.69     0.87 -1.50
# 71  MLP_12        NaN       2.21      1.60       3.80     0.86 -1.47
# 70  MLP_11        NaN       2.22      1.61       3.81     0.86 -1.46
#
#     Dominated_Count      Classification  Dominates_Count Plant
# 66                0      dominant_model               72     F
# 71                1  intermediate_model               71     F
# 70                2  intermediate_model               70     F

# %% [markdown]
# ##### Top intermediate models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].sort_values(by="Dominates_Count", ascending=False).iloc[:2]
# Out:
#      Model  Timesteps  RMSE_mean  MAE_mean  MAPE_mean  R2_mean  SCPM  \
# 71  MLP_12        NaN       2.21      1.60       3.80     0.86 -1.47
# 70  MLP_11        NaN       2.22      1.61       3.81     0.86 -1.46
#
#     Dominated_Count      Classification  Dominates_Count Plant
# 71                1  intermediate_model               71     F
# 70                2  intermediate_model               70     F

# %% [markdown]
# ##### Top non dominant models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].sort_values(by="Dominated_Count", ascending=True).iloc[:2]
# Out:
#        Model  Timesteps  RMSE_mean  MAE_mean  MAPE_mean  R2_mean   SCPM  \
# 38  Bi-LSTM9       14.0      31.79     31.22      71.97   -27.14  32.94
#
#     Dominated_Count      Classification  Dominates_Count Plant
# 38               72  non_dominant_model                0     F

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        # "Model",
        # "Model_bkp",
        "Model_bkp_2",
        "Timesteps",
        "RMSE_mean",
        "MAE_mean",
        "MAPE_mean",
        "R2_mean",
        "SCPM",
        "Dominated_Count",
        "Classification",
        "Dominates_Count",
        "Plant",
    ]
]  # .round(2)

# %%
df_sorted_topo["Model_bkp_2"].value_counts()
# Out:
# Model_bkp_2
# Conv1D         15
# Transformer    15
# Bi-LSTM        15
# LSTM           15
# MLP            13
# Name: count, dtype: int64

# %%
df_sorted_topo_models_grouped = (
    df_sorted_topo_models_cols.groupby("Model_bkp_2").describe().T
)

# %%
# pd.set_option("display.max_rows", None)
# df_sorted_topo_models_grouped

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model_bkp_2",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
    ]
]

# %%
df_sorted_topo_models_cols.groupby("Model_bkp_2").describe().round(2)
# Out:
#             Dominated_Count                                              \
#                       count   mean    std   min   25%   50%   75%   max
# Model_bkp_2
# Bi-LSTM                15.0  48.47  15.31  29.0  33.0  53.0  61.0  72.0
# Conv1D                 15.0  19.40   5.08  12.0  15.5  17.0  23.5  28.0
# LSTM                   15.0  54.53  11.23  34.0  46.0  57.0  64.5  70.0
# MLP                    13.0   5.23   3.35   0.0   3.0   5.0   7.0  12.0
# Transformer            15.0  43.00  12.58  22.0  36.0  40.0  50.5  70.0
#
#             Dominates_Count
#                       count   mean    std   min   25%   50%   75%   max
# Model_bkp_2
# Bi-LSTM                15.0  21.20  14.73   0.0   8.5  17.0  36.0  43.0
# Conv1D                 15.0  50.93   4.56  44.0  47.0  52.0  54.0  59.0
# LSTM                   15.0  15.40  10.28   1.0   6.0  14.0  23.5  35.0
# MLP                    13.0  65.15   4.43  59.0  61.0  66.0  69.0  72.0
# Transformer            15.0  25.93  11.53   1.0  21.0  27.0  33.0  46.0

# %%
df_sorted_topo_models_cols.groupby("Model_bkp_2")["Classification"].describe()
# Out:
#             count unique                 top freq
# Model_bkp_2
# Bi-LSTM        15      2  intermediate_model   14
# Conv1D         15      1  intermediate_model   15
# LSTM           15      1  intermediate_model   15
# MLP            13      2  intermediate_model   12
# Transformer    15      1  intermediate_model   15

# %%
df_sorted_topo_models_cols.groupby("Model_bkp_2")[["Classification"]].value_counts()
# Out:
# Model_bkp_2  Classification
# Bi-LSTM      intermediate_model    14
#              non_dominant_model     1
# Conv1D       intermediate_model    15
# LSTM         intermediate_model    15
# MLP          intermediate_model    12
#              dominant_model         1
# Transformer  intermediate_model    15
# Name: count, dtype: int64

# %%
(
    df_sorted_topo_models_cols.groupby("Model_bkp_2")[["Classification"]]
    .value_counts(normalize=True)
    .to_frame()
    * 100
).round(2)
# Out:
#                                 proportion
# Model_bkp_2 Classification
# Bi-LSTM     intermediate_model       93.33
#             non_dominant_model        6.67
# Conv1D      intermediate_model      100.00
# LSTM        intermediate_model      100.00
# MLP         intermediate_model       92.31
#             dominant_model            7.69
# Transformer intermediate_model      100.00

# %%
df_sorted_topo_models_cols
# Out:
#     Model_bkp_2  Dominated_Count  Dominates_Count      Classification
# 66          MLP                0               72      dominant_model
# 71          MLP                1               71  intermediate_model
# 70          MLP                2               70  intermediate_model
# 65          MLP                3               69  intermediate_model
# 63          MLP                4               66  intermediate_model
# ..          ...              ...              ...                 ...
# 44      Bi-LSTM               67                4  intermediate_model
# 7          LSTM               69                3  intermediate_model
# 8          LSTM               70                1  intermediate_model
# 48  Transformer               70                1  intermediate_model
# 38      Bi-LSTM               72                0  non_dominant_model
#
# [73 rows x 4 columns]

# %%
summary_stats = df_sorted_topo_models_cols.groupby("Model_bkp_2").agg(
    Total_Models=("Model_bkp_2", "count"),
    Mean_Dominance_Count=("Dominates_Count", "mean"),
    Median_Dominance_Count=("Dominates_Count", "median"),
    Total_Dominated=("Dominated_Count", "sum"),
    Total_Dominating=("Dominates_Count", "sum"),
)

total_models = summary_stats[
    "Total_Models"
].sum()  # Get the total number of models across all categories
summary_stats["Dominance Proportion"] = summary_stats["Total_Dominating"] / total_models

# %%
summary_stats
# Out:
#              Total_Models  Mean_Dominance_Count  Median_Dominance_Count  \
# Model_bkp_2
# Bi-LSTM                15             21.200000                    17.0
# Conv1D                 15             50.933333                    52.0
# LSTM                   15             15.400000                    14.0
# MLP                    13             65.153846                    66.0
# Transformer            15             25.933333                    27.0
#
#              Total_Dominated  Total_Dominating  Dominance Proportion
# Model_bkp_2
# Bi-LSTM                  727               318              4.356164
# Conv1D                   291               764             10.465753
# LSTM                     818               231              3.164384
# MLP                       68               847             11.602740
# Transformer              645               389              5.328767

# %%
df_sorted_topo_models_grouped.T
# Out:
#             Timesteps                                                 \
#                 count      mean       std  min  25%  50%   75%   max
# Model_bkp_2
# Bi-LSTM          15.0  7.333333  5.498918  1.0  1.0  7.0  14.0  14.0
# Conv1D           15.0  7.333333  5.498918  1.0  1.0  7.0  14.0  14.0
# LSTM             15.0  7.333333  5.498918  1.0  1.0  7.0  14.0  14.0
# MLP               0.0       NaN       NaN  NaN  NaN  NaN   NaN   NaN
# Transformer      15.0  7.333333  5.498918  1.0  1.0  7.0  14.0  14.0
#
#             RMSE_mean            ... Dominated_Count       Dominates_Count  \
#                 count      mean  ...             75%   max           count
# Model_bkp_2                      ...
# Bi-LSTM          15.0  5.707708  ...            61.0  72.0            15.0
# Conv1D           15.0  2.640814  ...            23.5  28.0            15.0
# LSTM             15.0  4.323992  ...            64.5  70.0            15.0
# MLP              13.0  2.335588  ...             7.0  12.0            13.0
# Transformer      15.0  3.601294  ...            50.5  70.0            15.0
#
#
#                   mean        std   min   25%   50%   75%   max
# Model_bkp_2
# Bi-LSTM      21.200000  14.731890   0.0   8.5  17.0  36.0  43.0
# Conv1D       50.933333   4.558613  44.0  47.0  52.0  54.0  59.0
# LSTM         15.400000  10.280356   1.0   6.0  14.0  23.5  35.0
# MLP          65.153846   4.431820  59.0  61.0  66.0  69.0  72.0
# Transformer  25.933333  11.529259   1.0  21.0  27.0  33.0  46.0
#
# [5 rows x 64 columns]

# %% [markdown]
# ### SCPM Analysis

# %%
cols = [
    "Model",
    # "Model_bkp",
    "Model_bkp_2",
    "Timesteps",
    "RMSE_mean",
    "MAE_mean",
    "MAPE_mean",
    "R2_mean",
    "SCPM",
    "Dominated_Count",
    "Dominates_Count",
    "Classification",
    "Plant",
]

# %%
df_sorted_scpm = df_sorted_topo.sort_values(by="SCPM").copy()

# %%
# (df_sorted_topo[cols].reset_index() == df_sorted_scpm[cols].reset_index()).all(axis=1)
df_sorted_scpm["topo_scmp_order_eq"] = df_sorted_topo.index == df_sorted_scpm.index

# %%
# df_sorted_topo[cols].round(2).head(5)

# %%
df_sorted_scpm[cols + ["topo_scmp_order_eq"]].round(2).head(7)
# Out:
#      Model Model_bkp_2  Timesteps  RMSE_mean  MAE_mean  MAPE_mean  R2_mean  \
# 66   MLP_7         MLP        NaN       2.17      1.57       3.69     0.87
# 71  MLP_12         MLP        NaN       2.21      1.60       3.80     0.86
# 70  MLP_11         MLP        NaN       2.22      1.61       3.81     0.86
# 65   MLP_6         MLP        NaN       2.28      1.62       3.86     0.86
# 69  MLP_10         MLP        NaN       2.35      1.64       3.89     0.85
# 67   MLP_8         MLP        NaN       2.35      1.65       3.91     0.85
# 63   MLP_4         MLP        NaN       2.33      1.67       3.97     0.85
#
#     SCPM  Dominated_Count  Dominates_Count      Classification Plant  \
# 66 -1.50                0               72      dominant_model     F
# 71 -1.47                1               71  intermediate_model     F
# 70 -1.46                2               70  intermediate_model     F
# 65 -1.43                3               69  intermediate_model     F
# 69 -1.40                4               67  intermediate_model     F
# 67 -1.39                5               66  intermediate_model     F
# 63 -1.39                4               66  intermediate_model     F
#
#     topo_scmp_order_eq
# 66                True
# 71                True
# 70                True
# 65                True
# 69               False
# 67               False
# 63               False

# %% [markdown]
# ### Variable Grouping: CM-P-CS

# %% [markdown]
# #### Analysis of the best models identified in the Local Analysis

# %% [markdown]
# **Best models for variable groupping CM-P-CS were from:**
#
# *BTiSS:*
#     Dominance analysis: Plant F
#     SCPM:Plant F
#
# *TiSS:*
#     Dominance analysis: Plant AB
#     SCPM:Plant AB

# %%
df_pre_train["Features"].unique()
# Out:
# array(['Chemical + Mineralogical + Physical - Early CS',
#        'Chemical + Mineralogical + Physical', 'Chemical + Mineralogical'],
#       dtype=object)

# %% [markdown]
# ### Plant F

# %%
df_results_cm_p_cs = (
    df_pre_train[df_pre_train["Features"].eq("Chemical + Mineralogical + Physical")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_p_cs_s = df_results_cm_p_cs[
    df_results_cm_p_cs["Plant"].eq("F")
].reset_index(drop=True)

# %%
df_results_cm_p_cs_s.shape
# Out:
# (73, 26)

# %% [markdown]
# #### Hold Out

# %%
df_results_cm_p_cs_s["Cross Validation"].unique()
# Out:
# array(['Out of time'], dtype=object)

# %%
df_results_cm_p_cs_s_ho = (
    df_results_cm_p_cs_s[df_results_cm_p_cs_s["Cross Validation"].eq("Out of time")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_p_cs_s_ho["Cross Validation"].unique()
# Out:
# array(['Out of time'], dtype=object)

# %%
df_results_cm_p_cs_s_ho.shape
# Out:
# (73, 26)

# %% [markdown]
# ###### SCPM computation

# %%
df_results_cm_p_cs_s_ho = compute_scpm(df_results_cm_p_cs_s_ho)

# %% [markdown]
# ##### Dominance Analysis

# %%
dominance_dict = make_dominance_analysis(df_results_cm_p_cs_s_ho)
dominance_matrix_cm_p_cs_s_ho = dominance_dict["dominance_matrix"]
dominance_graph_cm_p_cs_s_ho = dominance_dict["dominance_graph"]
df_sorted_count = dominance_dict["df_sorted_count"]
df_sorted_topo = dominance_dict["df_sorted_topo"]

# %%
dominance_matrix_cm_p_cs_s_ho.shape, len(dominance_graph_cm_p_cs_s_ho)
# Out:
# ((73, 73), 73)

# %%
df_sorted_topo["Classification"].value_counts()
# Out:
# Classification
# intermediate_model    69
# dominant_model         2
# non_dominant_model     2
# Name: count, dtype: int64

# %%
df_sorted_topo.head(5)
# Out:
#         Category  Company Plant                             Features  \
# 25  Global Model      204     F  Chemical + Mineralogical + Physical
# 26  Global Model      204     F  Chemical + Mineralogical + Physical
# 16  Global Model      204     F  Chemical + Mineralogical + Physical
# 21  Global Model      204     F  Chemical + Mineralogical + Physical
# 20  Global Model      204     F  Chemical + Mineralogical + Physical
#
#      Data Shape  Timesteps   Model  Model Params           Scaler  \
# 25  (62318, 17)        NaN  MLP_11           NaN  Standard Scaler
# 26  (62318, 17)        NaN  MLP_12           NaN  Standard Scaler
# 16  (62318, 17)        NaN   MLP_2           NaN  Standard Scaler
# 21  (62318, 17)        NaN   MLP_7           NaN  Standard Scaler
# 20  (62318, 17)        NaN   MLP_6           NaN  Standard Scaler
#
#     Scaler Params  ... MAPE_mean   R2_mean plant         Features_bkp  \
# 25            NaN  ...  2.611097  0.937708     f  Chemical + Physical
# 26            NaN  ...  2.614679  0.938600     f  Chemical + Physical
# 16            NaN  ...  2.691875  0.936247     f  Chemical + Physical
# 21            NaN  ...  2.646504  0.934694     f  Chemical + Physical
# 20            NaN  ...  2.698501  0.934161     f  Chemical + Physical
#
#     Model_bkp  Model_bkp_2      SCPM  Dominated_Count      Classification  \
# 25     MLP_11          MLP -1.424678                0      dominant_model
# 26     MLP_12          MLP -1.425755                0      dominant_model
# 16      MLP_2          MLP -1.398345                2  intermediate_model
# 21      MLP_7          MLP -1.407392                2  intermediate_model
# 20      MLP_6          MLP -1.391619                4  intermediate_model
#
#     Dominates_Count
# 25               71
# 26               71
# 16               66
# 21               69
# 20               65
#
# [5 rows x 30 columns]

# %%
df_sorted_topo_cols = df_sorted_topo[
    [
        "Model",
        # "Model_bkp",
        # "Model_bkp_2",
        "Timesteps",
        "RMSE_mean",
        "MAE_mean",
        "MAPE_mean",
        "R2_mean",
        "SCPM",
        "Dominated_Count",
        "Classification",
        "Dominates_Count",
        "Plant",
    ]
].round(2)

# %% [markdown]
# ##### Top dominant models

# %%
# Top 4
df_sorted_topo_cols.sort_values(by="Dominates_Count", ascending=False).iloc[0:3]
# Out:
#      Model  Timesteps  RMSE_mean  MAE_mean  MAPE_mean  R2_mean  SCPM  \
# 25  MLP_11        NaN       1.50      1.11       2.61     0.94 -1.42
# 26  MLP_12        NaN       1.48      1.11       2.61     0.94 -1.43
# 21   MLP_7        NaN       1.53      1.13       2.65     0.93 -1.41
#
#     Dominated_Count      Classification  Dominates_Count Plant
# 25                0      dominant_model               71     F
# 26                0      dominant_model               71     F
# 21                2  intermediate_model               69     F

# %% [markdown]
# ##### Top intermediate models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].sort_values(by="Dominates_Count", ascending=False).iloc[:2]
# Out:
#     Model  Timesteps  RMSE_mean  MAE_mean  MAPE_mean  R2_mean  SCPM  \
# 21  MLP_7        NaN       1.53      1.13       2.65     0.93 -1.41
# 22  MLP_8        NaN       1.54      1.13       2.65     0.93 -1.40
#
#     Dominated_Count      Classification  Dominates_Count Plant
# 21                2  intermediate_model               69     F
# 22                3  intermediate_model               66     F

# %% [markdown]
# ##### Top non dominant models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].sort_values(by="Dominated_Count", ascending=True).iloc[:2]
# Out:
#      Model  Timesteps  RMSE_mean  MAE_mean  MAPE_mean  R2_mean   SCPM  \
# 27  MLP_13        NaN      49.65      1.84       4.51   -67.67  15.31
# 10  LSTM11        7.0      25.30     24.58      56.21   -16.82  21.27
#
#     Dominated_Count      Classification  Dominates_Count Plant
# 27               38  non_dominant_model                0     F
# 10               71  non_dominant_model                0     F

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        # "Model",
        # "Model_bkp",
        "Model_bkp_2",
        "Timesteps",
        "RMSE_mean",
        "MAE_mean",
        "MAPE_mean",
        "R2_mean",
        "SCPM",
        "Dominated_Count",
        "Classification",
        "Dominates_Count",
        "Plant",
    ]
]  # .round(2)

# %%
df_sorted_topo["Model_bkp_2"].value_counts()
# Out:
# Model_bkp_2
# Conv1D         15
# LSTM           15
# Bi-LSTM        15
# Transformer    15
# MLP            13
# Name: count, dtype: int64

# %%
df_sorted_topo_models_grouped = (
    df_sorted_topo_models_cols.groupby("Model_bkp_2").describe().T
)

# %%
# pd.set_option("display.max_rows", None)
# df_sorted_topo_models_grouped

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model_bkp_2",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
    ]
]

# %%
df_sorted_topo_models_cols.groupby("Model_bkp_2").describe().round(2)
# Out:
#             Dominated_Count                                              \
#                       count   mean    std   min   25%   50%   75%   max
# Model_bkp_2
# Bi-LSTM                15.0  45.53  16.23  19.0  35.5  43.0  60.0  70.0
# Conv1D                 15.0  23.00  11.76  11.0  14.5  20.0  32.0  43.0
# LSTM                   15.0  45.40  19.40  15.0  31.0  40.0  64.5  71.0
# MLP                    13.0   8.31  11.05   0.0   2.0   4.0   9.0  38.0
# Transformer            15.0  46.20  14.03  25.0  33.5  49.0  56.0  69.0
#
#             Dominates_Count
#                       count   mean    std   min   25%   50%   75%   max
# Model_bkp_2
# Bi-LSTM                15.0  23.33  15.68   1.0  10.5  22.0  33.5  52.0
# Conv1D                 15.0  45.60  13.65  23.0  36.0  48.0  56.0  61.0
# LSTM                   15.0  24.20  18.43   0.0   6.5  27.0  38.0  54.0
# MLP                    13.0  59.08  19.27   0.0  62.0  65.0  66.0  71.0
# Transformer            15.0  23.00  13.41   2.0  14.5  20.0  34.5  46.0

# %%
df_sorted_topo_models_cols.groupby("Model_bkp_2")["Classification"].describe()
# Out:
#             count unique                 top freq
# Model_bkp_2
# Bi-LSTM        15      1  intermediate_model   15
# Conv1D         15      1  intermediate_model   15
# LSTM           15      2  intermediate_model   14
# MLP            13      3  intermediate_model   10
# Transformer    15      1  intermediate_model   15

# %%
df_sorted_topo_models_cols.groupby("Model_bkp_2")[["Classification"]].value_counts()
# Out:
# Model_bkp_2  Classification
# Bi-LSTM      intermediate_model    15
# Conv1D       intermediate_model    15
# LSTM         intermediate_model    14
#              non_dominant_model     1
# MLP          intermediate_model    10
#              dominant_model         2
#              non_dominant_model     1
# Transformer  intermediate_model    15
# Name: count, dtype: int64

# %%
(
    df_sorted_topo_models_cols.groupby("Model_bkp_2")[["Classification"]]
    .value_counts(normalize=True)
    .to_frame()
    * 100
).round(2)
# Out:
#                                 proportion
# Model_bkp_2 Classification
# Bi-LSTM     intermediate_model      100.00
# Conv1D      intermediate_model      100.00
# LSTM        intermediate_model       93.33
#             non_dominant_model        6.67
# MLP         intermediate_model       76.92
#             dominant_model           15.38
#             non_dominant_model        7.69
# Transformer intermediate_model      100.00

# %%
df_sorted_topo_models_cols
# Out:
#     Model_bkp_2  Dominated_Count  Dominates_Count      Classification
# 25          MLP                0               71      dominant_model
# 26          MLP                0               71      dominant_model
# 16          MLP                2               66  intermediate_model
# 21          MLP                2               69  intermediate_model
# 20          MLP                4               65  intermediate_model
# ..          ...              ...              ...                 ...
# 11         LSTM               67                3  intermediate_model
# 54      Bi-LSTM               67                3  intermediate_model
# 65  Transformer               69                2  intermediate_model
# 51      Bi-LSTM               70                1  intermediate_model
# 10         LSTM               71                0  non_dominant_model
#
# [73 rows x 4 columns]

# %%
summary_stats = df_sorted_topo_models_cols.groupby("Model_bkp_2").agg(
    Total_Models=("Model_bkp_2", "count"),
    Mean_Dominance_Count=("Dominates_Count", "mean"),
    Median_Dominance_Count=("Dominates_Count", "median"),
    Total_Dominated=("Dominated_Count", "sum"),
    Total_Dominating=("Dominates_Count", "sum"),
)

total_models = summary_stats[
    "Total_Models"
].sum()  # Get the total number of models across all categories
summary_stats["Dominance Proportion"] = summary_stats["Total_Dominating"] / total_models

# %%
summary_stats
# Out:
#              Total_Models  Mean_Dominance_Count  Median_Dominance_Count  \
# Model_bkp_2
# Bi-LSTM                15             23.333333                    22.0
# Conv1D                 15             45.600000                    48.0
# LSTM                   15             24.200000                    27.0
# MLP                    13             59.076923                    65.0
# Transformer            15             23.000000                    20.0
#
#              Total_Dominated  Total_Dominating  Dominance Proportion
# Model_bkp_2
# Bi-LSTM                  683               350              4.794521
# Conv1D                   345               684              9.369863
# LSTM                     681               363              4.972603
# MLP                      108               768             10.520548
# Transformer              693               345              4.726027

# %%
df_sorted_topo_models_grouped.T
# Out:
#             Timesteps                                                 \
#                 count      mean       std  min  25%  50%   75%   max
# Model_bkp_2
# Bi-LSTM          15.0  7.333333  5.498918  1.0  1.0  7.0  14.0  14.0
# Conv1D           15.0  7.333333  5.498918  1.0  1.0  7.0  14.0  14.0
# LSTM             15.0  7.333333  5.498918  1.0  1.0  7.0  14.0  14.0
# MLP               0.0       NaN       NaN  NaN  NaN  NaN   NaN   NaN
# Transformer      15.0  7.333333  5.498918  1.0  1.0  7.0  14.0  14.0
#
#             RMSE_mean            ... Dominated_Count       Dominates_Count  \
#                 count      mean  ...             75%   max           count
# Model_bkp_2                      ...
# Bi-LSTM          15.0  3.326481  ...            60.0  70.0            15.0
# Conv1D           15.0  2.054101  ...            32.0  43.0            15.0
# LSTM             15.0  4.606979  ...            64.5  71.0            15.0
# MLP              13.0  5.285192  ...             9.0  38.0            13.0
# Transformer      15.0  2.911772  ...            56.0  69.0            15.0
#
#
#                   mean        std   min   25%   50%   75%   max
# Model_bkp_2
# Bi-LSTM      23.333333  15.682869   1.0  10.5  22.0  33.5  52.0
# Conv1D       45.600000  13.647606  23.0  36.0  48.0  56.0  61.0
# LSTM         24.200000  18.428239   0.0   6.5  27.0  38.0  54.0
# MLP          59.076923  19.267683   0.0  62.0  65.0  66.0  71.0
# Transformer  23.000000  13.405756   2.0  14.5  20.0  34.5  46.0
#
# [5 rows x 64 columns]

# %% [markdown]
# ### SCPM Analysis

# %%
cols = [
    "Model",
    # "Model_bkp",
    "Model_bkp_2",
    "Timesteps",
    "RMSE_mean",
    "MAE_mean",
    "MAPE_mean",
    "R2_mean",
    "SCPM",
    "Dominated_Count",
    "Dominates_Count",
    "Classification",
    "Plant",
]

# %%
df_sorted_scpm = df_sorted_topo.sort_values(by="SCPM").copy()

# %%
# (df_sorted_topo[cols].reset_index() == df_sorted_scpm[cols].reset_index()).all(axis=1)
df_sorted_scpm["topo_scmp_order_eq"] = df_sorted_topo.index == df_sorted_scpm.index

# %%
# df_sorted_topo[cols].round(2).head(5)

# %%
df_sorted_scpm[cols + ["topo_scmp_order_eq"]].round(2).head(7)
# Out:
#      Model Model_bkp_2  Timesteps  RMSE_mean  MAE_mean  MAPE_mean  R2_mean  \
# 26  MLP_12         MLP        NaN       1.48      1.11       2.61     0.94
# 25  MLP_11         MLP        NaN       1.50      1.11       2.61     0.94
# 21   MLP_7         MLP        NaN       1.53      1.13       2.65     0.93
# 22   MLP_8         MLP        NaN       1.54      1.13       2.65     0.93
# 24  MLP_10         MLP        NaN       1.54      1.14       2.67     0.93
# 16   MLP_2         MLP        NaN       1.51      1.14       2.69     0.94
# 19   MLP_5         MLP        NaN       1.55      1.14       2.69     0.93
#
#     SCPM  Dominated_Count  Dominates_Count      Classification Plant  \
# 26 -1.43                0               71      dominant_model     F
# 25 -1.42                0               71      dominant_model     F
# 21 -1.41                2               69  intermediate_model     F
# 22 -1.40                3               66  intermediate_model     F
# 24 -1.40                3               66  intermediate_model     F
# 16 -1.40                2               66  intermediate_model     F
# 19 -1.39                5               65  intermediate_model     F
#
#     topo_scmp_order_eq
# 26               False
# 25               False
# 21               False
# 22               False
# 24               False
# 16               False
# 19               False

# %% [markdown]
# ### Plant AB

# %%
df_results_cm_p_cs = (
    df_pre_train[df_pre_train["Features"].eq("Chemical + Mineralogical + Physical")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_p_cs_s = df_results_cm_p_cs[
    df_results_cm_p_cs["Plant"].eq("AB")
].reset_index(drop=True)

# %%
df_results_cm_p_cs_s.shape
# Out:
# (73, 26)

# %% [markdown]
# #### Hold Out

# %%
df_results_cm_p_cs_s["Cross Validation"].unique()
# Out:
# array(['Out of time'], dtype=object)

# %%
df_results_cm_p_cs_s_ho = (
    df_results_cm_p_cs_s[df_results_cm_p_cs_s["Cross Validation"].eq("Out of time")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_p_cs_s_ho["Cross Validation"].unique()
# Out:
# array(['Out of time'], dtype=object)

# %%
df_results_cm_p_cs_s_ho.shape
# Out:
# (73, 26)

# %% [markdown]
# ###### SCPM computation

# %%
df_results_cm_p_cs_s_ho = compute_scpm(df_results_cm_p_cs_s_ho)

# %% [markdown]
# ##### Dominance Analysis

# %%
dominance_dict = make_dominance_analysis(df_results_cm_p_cs_s_ho)
dominance_matrix_cm_p_cs_s_ho = dominance_dict["dominance_matrix"]
dominance_graph_cm_p_cs_s_ho = dominance_dict["dominance_graph"]
df_sorted_count = dominance_dict["df_sorted_count"]
df_sorted_topo = dominance_dict["df_sorted_topo"]

# %%
dominance_matrix_cm_p_cs_s_ho.shape, len(dominance_graph_cm_p_cs_s_ho)
# Out:
# ((73, 73), 73)

# %%
df_sorted_topo["Classification"].value_counts()
# Out:
# Classification
# intermediate_model    70
# dominant_model         2
# non_dominant_model     1
# Name: count, dtype: int64

# %%
df_sorted_topo.head(5)
# Out:
#         Category  Company Plant                             Features  \
# 20  Global Model      204    AB  Chemical + Mineralogical + Physical
# 25  Global Model      204    AB  Chemical + Mineralogical + Physical
# 21  Global Model      204    AB  Chemical + Mineralogical + Physical
# 16  Global Model      204    AB  Chemical + Mineralogical + Physical
# 26  Global Model      204    AB  Chemical + Mineralogical + Physical
#
#      Data Shape  Timesteps   Model  Model Params           Scaler  \
# 20  (62581, 13)        NaN   MLP_6           NaN  Standard Scaler
# 25  (62581, 13)        NaN  MLP_11           NaN  Standard Scaler
# 21  (62581, 13)        NaN   MLP_7           NaN  Standard Scaler
# 16  (62581, 13)        NaN   MLP_2           NaN  Standard Scaler
# 26  (62581, 13)        NaN  MLP_12           NaN  Standard Scaler
#
#     Scaler Params  ... MAPE_mean   R2_mean plant         Features_bkp  \
# 20            NaN  ...  2.702524  0.932954    ab  Chemical + Physical
# 25            NaN  ...  2.726625  0.933053    ab  Chemical + Physical
# 21            NaN  ...  2.793606  0.931116    ab  Chemical + Physical
# 16            NaN  ...  2.980284  0.923182    ab  Chemical + Physical
# 26            NaN  ...  2.993774  0.923704    ab  Chemical + Physical
#
#     Model_bkp  Model_bkp_2      SCPM  Dominated_Count      Classification  \
# 20      MLP_6          MLP -2.829402                0      dominant_model
# 25     MLP_11          MLP -2.818502                0      dominant_model
# 21      MLP_7          MLP -2.761625                2  intermediate_model
# 16      MLP_2          MLP -2.590370                3  intermediate_model
# 26     MLP_12          MLP -2.585847                3  intermediate_model
#
#     Dominates_Count
# 20               71
# 25               71
# 21               70
# 16               68
# 26               68
#
# [5 rows x 30 columns]

# %%
df_sorted_topo_cols = df_sorted_topo[
    [
        "Model",
        # "Model_bkp",
        # "Model_bkp_2",
        "Timesteps",
        "RMSE_mean",
        "MAE_mean",
        "MAPE_mean",
        "R2_mean",
        "SCPM",
        "Dominated_Count",
        "Classification",
        "Dominates_Count",
        "Plant",
    ]
].round(2)

# %% [markdown]
# ##### Top dominant models

# %%
# Top 4
df_sorted_topo_cols.sort_values(by="Dominates_Count", ascending=False).iloc[0:3]
# Out:
#      Model  Timesteps  RMSE_mean  MAE_mean  MAPE_mean  R2_mean  SCPM  \
# 20   MLP_6        NaN       1.56      1.15       2.70     0.93 -2.83
# 25  MLP_11        NaN       1.56      1.16       2.73     0.93 -2.82
# 21   MLP_7        NaN       1.59      1.19       2.79     0.93 -2.76
#
#     Dominated_Count      Classification  Dominates_Count Plant
# 20                0      dominant_model               71    AB
# 25                0      dominant_model               71    AB
# 21                2  intermediate_model               70    AB

# %% [markdown]
# ##### Top intermediate models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].sort_values(by="Dominates_Count", ascending=False).iloc[:2]
# Out:
#     Model  Timesteps  RMSE_mean  MAE_mean  MAPE_mean  R2_mean  SCPM  \
# 21  MLP_7        NaN       1.59      1.19       2.79     0.93 -2.76
# 16  MLP_2        NaN       1.67      1.26       2.98     0.92 -2.59
#
#     Dominated_Count      Classification  Dominates_Count Plant
# 21                2  intermediate_model               70    AB
# 16                3  intermediate_model               68    AB

# %% [markdown]
# ##### Top non dominant models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].sort_values(by="Dominated_Count", ascending=True).iloc[:2]
# Out:
#        Model  Timesteps  RMSE_mean  MAE_mean  MAPE_mean  R2_mean   SCPM  \
# 51  Bi-LSTM9       14.0      10.99      9.25      19.92    -2.31  19.68
#
#     Dominated_Count      Classification  Dominates_Count Plant
# 51               72  non_dominant_model                0    AB

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        # "Model",
        # "Model_bkp",
        "Model_bkp_2",
        "Timesteps",
        "RMSE_mean",
        "MAE_mean",
        "MAPE_mean",
        "R2_mean",
        "SCPM",
        "Dominated_Count",
        "Classification",
        "Dominates_Count",
        "Plant",
    ]
]  # .round(2)

# %%
df_sorted_topo["Model_bkp_2"].value_counts()
# Out:
# Model_bkp_2
# Conv1D         15
# LSTM           15
# Bi-LSTM        15
# Transformer    15
# MLP            13
# Name: count, dtype: int64

# %%
df_sorted_topo_models_grouped = (
    df_sorted_topo_models_cols.groupby("Model_bkp_2").describe().T
)

# %%
# pd.set_option("display.max_rows", None)
# df_sorted_topo_models_grouped

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model_bkp_2",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
    ]
]

# %%
df_sorted_topo_models_cols.groupby("Model_bkp_2").describe().round(2)
# Out:
#             Dominated_Count                                              \
#                       count   mean    std   min   25%   50%   75%   max
# Model_bkp_2
# Bi-LSTM                15.0  44.80  19.25  19.0  27.5  44.0  61.5  72.0
# Conv1D                 15.0  21.07   9.04  10.0  13.0  20.0  27.0  37.0
# LSTM                   15.0  45.20  16.44  19.0  34.5  46.0  59.0  67.0
# MLP                    13.0   7.15   7.30   0.0   3.0   6.0   9.0  28.0
# Transformer            15.0  52.60   8.66  41.0  45.0  52.0  58.0  70.0
#
#             Dominates_Count
#                       count   mean    std   min   25%   50%   75%   max
# Model_bkp_2
# Bi-LSTM                15.0  24.73  18.52   0.0   8.5  25.0  41.0  50.0
# Conv1D                 15.0  47.87   8.98  32.0  41.5  49.0  56.5  58.0
# LSTM                   15.0  23.93  15.97   3.0   9.5  23.0  34.0  52.0
# MLP                    13.0  63.62   8.67  39.0  63.0  66.0  68.0  71.0
# Transformer            15.0  18.20   8.86   2.0  11.5  19.0  25.0  31.0

# %%
df_sorted_topo_models_cols.groupby("Model_bkp_2")["Classification"].describe()
# Out:
#             count unique                 top freq
# Model_bkp_2
# Bi-LSTM        15      2  intermediate_model   14
# Conv1D         15      1  intermediate_model   15
# LSTM           15      1  intermediate_model   15
# MLP            13      2  intermediate_model   11
# Transformer    15      1  intermediate_model   15

# %%
df_sorted_topo_models_cols.groupby("Model_bkp_2")[["Classification"]].value_counts()
# Out:
# Model_bkp_2  Classification
# Bi-LSTM      intermediate_model    14
#              non_dominant_model     1
# Conv1D       intermediate_model    15
# LSTM         intermediate_model    15
# MLP          intermediate_model    11
#              dominant_model         2
# Transformer  intermediate_model    15
# Name: count, dtype: int64

# %%
(
    df_sorted_topo_models_cols.groupby("Model_bkp_2")[["Classification"]]
    .value_counts(normalize=True)
    .to_frame()
    * 100
).round(2)
# Out:
#                                 proportion
# Model_bkp_2 Classification
# Bi-LSTM     intermediate_model       93.33
#             non_dominant_model        6.67
# Conv1D      intermediate_model      100.00
# LSTM        intermediate_model      100.00
# MLP         intermediate_model       84.62
#             dominant_model           15.38
# Transformer intermediate_model      100.00

# %%
df_sorted_topo_models_cols
# Out:
#     Model_bkp_2  Dominated_Count  Dominates_Count      Classification
# 20          MLP                0               71      dominant_model
# 25          MLP                0               71      dominant_model
# 21          MLP                2               70  intermediate_model
# 16          MLP                3               68  intermediate_model
# 26          MLP                3               68  intermediate_model
# ..          ...              ...              ...                 ...
# 8          LSTM               67                3  intermediate_model
# 48      Bi-LSTM               67                3  intermediate_model
# 67  Transformer               70                2  intermediate_model
# 54      Bi-LSTM               71                1  intermediate_model
# 51      Bi-LSTM               72                0  non_dominant_model
#
# [73 rows x 4 columns]

# %%
summary_stats = df_sorted_topo_models_cols.groupby("Model_bkp_2").agg(
    Total_Models=("Model_bkp_2", "count"),
    Mean_Dominance_Count=("Dominates_Count", "mean"),
    Median_Dominance_Count=("Dominates_Count", "median"),
    Total_Dominated=("Dominated_Count", "sum"),
    Total_Dominating=("Dominates_Count", "sum"),
)

total_models = summary_stats[
    "Total_Models"
].sum()  # Get the total number of models across all categories
summary_stats["Dominance Proportion"] = summary_stats["Total_Dominating"] / total_models

# %%
summary_stats
# Out:
#              Total_Models  Mean_Dominance_Count  Median_Dominance_Count  \
# Model_bkp_2
# Bi-LSTM                15             24.733333                    25.0
# Conv1D                 15             47.866667                    49.0
# LSTM                   15             23.933333                    23.0
# MLP                    13             63.615385                    66.0
# Transformer            15             18.200000                    19.0
#
#              Total_Dominated  Total_Dominating  Dominance Proportion
# Model_bkp_2
# Bi-LSTM                  672               371              5.082192
# Conv1D                   316               718              9.835616
# LSTM                     678               359              4.917808
# MLP                       93               827             11.328767
# Transformer              789               273              3.739726

# %%
df_sorted_topo_models_grouped.T
# Out:
#             Timesteps                                                 \
#                 count      mean       std  min  25%  50%   75%   max
# Model_bkp_2
# Bi-LSTM          15.0  7.333333  5.498918  1.0  1.0  7.0  14.0  14.0
# Conv1D           15.0  7.333333  5.498918  1.0  1.0  7.0  14.0  14.0
# LSTM             15.0  7.333333  5.498918  1.0  1.0  7.0  14.0  14.0
# MLP               0.0       NaN       NaN  NaN  NaN  NaN   NaN   NaN
# Transformer      15.0  7.333333  5.498918  1.0  1.0  7.0  14.0  14.0
#
#             RMSE_mean            ... Dominated_Count       Dominates_Count  \
#                 count      mean  ...             75%   max           count
# Model_bkp_2                      ...
# Bi-LSTM          15.0  3.912101  ...            61.5  72.0            15.0
# Conv1D           15.0  2.009897  ...            27.0  37.0            15.0
# LSTM             15.0  3.183144  ...            59.0  67.0            15.0
# MLP              13.0  1.707924  ...             9.0  28.0            13.0
# Transformer      15.0  3.399303  ...            58.0  70.0            15.0
#
#
#                   mean        std   min   25%   50%   75%   max
# Model_bkp_2
# Bi-LSTM      24.733333  18.518202   0.0   8.5  25.0  41.0  50.0
# Conv1D       47.866667   8.975098  32.0  41.5  49.0  56.5  58.0
# LSTM         23.933333  15.966334   3.0   9.5  23.0  34.0  52.0
# MLP          63.615385   8.665434  39.0  63.0  66.0  68.0  71.0
# Transformer  18.200000   8.857604   2.0  11.5  19.0  25.0  31.0
#
# [5 rows x 64 columns]

# %% [markdown]
# ### SCPM Analysis

# %%
cols = [
    "Model",
    # "Model_bkp",
    "Model_bkp_2",
    "Timesteps",
    "RMSE_mean",
    "MAE_mean",
    "MAPE_mean",
    "R2_mean",
    "SCPM",
    "Dominated_Count",
    "Dominates_Count",
    "Classification",
    "Plant",
]

# %%
df_sorted_scpm = df_sorted_topo.sort_values(by="SCPM").copy()

# %%
# (df_sorted_topo[cols].reset_index() == df_sorted_scpm[cols].reset_index()).all(axis=1)
df_sorted_scpm["topo_scmp_order_eq"] = df_sorted_topo.index == df_sorted_scpm.index

# %%
# df_sorted_topo[cols].round(2).head(5)

# %%
df_sorted_scpm[cols + ["topo_scmp_order_eq"]].round(2).head(7)
# Out:
#      Model Model_bkp_2  Timesteps  RMSE_mean  MAE_mean  MAPE_mean  R2_mean  \
# 20   MLP_6         MLP        NaN       1.56      1.15       2.70     0.93
# 25  MLP_11         MLP        NaN       1.56      1.16       2.73     0.93
# 21   MLP_7         MLP        NaN       1.59      1.19       2.79     0.93
# 16   MLP_2         MLP        NaN       1.67      1.26       2.98     0.92
# 26  MLP_12         MLP        NaN       1.67      1.27       2.99     0.92
# 24  MLP_10         MLP        NaN       1.68      1.27       3.03     0.92
# 15   MLP_1         MLP        NaN       1.69      1.28       3.03     0.92
#
#     SCPM  Dominated_Count  Dominates_Count      Classification Plant  \
# 20 -2.83                0               71      dominant_model    AB
# 25 -2.82                0               71      dominant_model    AB
# 21 -2.76                2               70  intermediate_model    AB
# 16 -2.59                3               68  intermediate_model    AB
# 26 -2.59                3               68  intermediate_model    AB
# 24 -2.56                5               67  intermediate_model    AB
# 15 -2.55                6               66  intermediate_model    AB
#
#     topo_scmp_order_eq
# 20                True
# 25                True
# 21                True
# 16                True
# 26                True
# 24                True
# 15                True

# %% [markdown]
# # Global Analysis (fine tuning results)

# %% [markdown]
# # Definitions

# %% [markdown]
# # Topological Analysis - NEW

# %% [markdown]
# ## Definitions

# %%
# Function to compare two models strictly based on means only
def dominates(model1, model2):
    """Return True if model1 strictly dominates model2, False otherwise."""
    # Check if model1 is at least as good as model2 in all metrics
    at_least_as_good = (
        model1["RMSE_mean"] <= model2["RMSE_mean"]
        and model1["MAE_mean"] <= model2["MAE_mean"]
        and model1["MAPE_mean"] <= model2["MAPE_mean"]
        and model1["R2_mean"] >= model2["R2_mean"]
    )

    # Check if model1 is strictly better in at least one metric
    strictly_better_in_one = (
        model1["RMSE_mean"] < model2["RMSE_mean"]
        or model1["MAE_mean"] < model2["MAE_mean"]
        or model1["MAPE_mean"] < model2["MAPE_mean"]
        or model1["R2_mean"] > model2["R2_mean"]
    )

    # Model1 strictly dominates Model2 if it is at least as good in all metrics and
    # strictly better in at least one metric
    return at_least_as_good and strictly_better_in_one

# %%
def get_dominance_matrix_and_graph(df):
    n = len(df)
    dominance_matrix = np.zeros((n, n), dtype=bool)

    for i in range(n):
        for j in range(n):
            if i != j:
                dominance_matrix[i, j] = dominates(df.iloc[i], df.iloc[j])

    # Create the dominance graph
    dominance_graph = {i: [] for i in range(n)}
    for i in range(n):
        for j in range(n):
            if dominance_matrix[i, j]:
                dominance_graph[i].append(j)

    return dominance_matrix, dominance_graph

# %%
# Topological Sorting
def topological_sort(graph):
    """Perform topological sorting on the given graph."""
    in_degree = {u: 0 for u in graph}
    for u in graph:
        for v in graph[u]:
            in_degree[v] += 1

    queue = deque([u for u in graph if in_degree[u] == 0])
    topo_order = []

    while queue:
        u = queue.popleft()
        topo_order.append(u)

        for v in graph[u]:
            in_degree[v] -= 1
            if in_degree[v] == 0:
                queue.append(v)

    return topo_order

# %%
# Function to find the top models in each group
def find_top_models(group):
    max_net_dominance = group["Net_Dominance"].max()
    top_models = group[group["Net_Dominance"] == max_net_dominance]
    return top_models

# %% [markdown]
# ### Dominance Analysis and SCPM

# %%
def compute_scpm(df):
    scaler = StandardScaler()
    standardized_metrics = scaler.fit_transform(
        df[["RMSE_mean", "MAE_mean", "MAPE_mean", "R2_mean"]]
    )

    # Creating a new dataframe with standardized values
    standardized_df = pd.DataFrame(
        standardized_metrics,
        columns=["RMSE_mean", "MAE_mean", "MAPE_mean", "R2_mean"],
    )

    # Summing all metrics and subtracting R2_mean
    standardized_df["Result"] = (
        standardized_df[["RMSE_mean", "MAE_mean", "MAPE_mean"]].sum(axis=1)
        - standardized_df["R2_mean"]
    )

    df["SCPM"] = standardized_df["Result"]
    return df

# %%
def make_dominance_analysis(df):
    # Compute dominance matrix and graph
    dominance_matrix, dominance_graph = get_dominance_matrix_and_graph(df)

    # Get the topological order
    topo_order = topological_sort(dominance_graph)
    df = df.copy()
    n = len(topo_order)

    # Identify Dominant Models
    dominant_models = [
        df["Model_bkp_2"].iloc[i]
        for i in range(len(df))
        if not np.any(dominance_matrix[:, i])
    ]

    # Identify Non-Dominant Models
    non_dominant_models = [
        df["Model_bkp_2"].iloc[i]
        for i in range(len(df))
        if np.any(dominance_matrix[:, i])
    ]

    # Identify Models that are both dominated and dominate at least one
    intermediate_models = [
        df["Model_bkp_2"].iloc[i]
        for i in range(len(df))
        if np.any(dominance_matrix[:, i]) and np.any(dominance_matrix[i, :])
    ]

    # Add count of times each model is dominated by others
    df["Dominated_Count"] = np.sum(dominance_matrix, axis=0)

    # Classify models
    df["Classification"] = "intermediate_model"  # default to intermediate_model
    df.loc[
        ~np.any(dominance_matrix, axis=1) & np.any(dominance_matrix, axis=0),
        "Classification",
    ] = "non_dominant_model"
    df.loc[~np.any(dominance_matrix, axis=0), "Classification"] = "dominant_model"

    # Map the topological order to the model names and get dominance counts
    sorted_models = [df["Model"].iloc[i] for i in topo_order]

    df_sorted = df.iloc[topo_order].copy()
    df_sorted["Dominates_Count"] = dominance_matrix.sum(axis=1)[topo_order]
    df_sorted_topo = df_sorted.copy()

    df_sorted = df_sorted.sort_values(by="Dominates_Count", ascending=False)
    df_sorted_count = df_sorted.copy()

    return {
        "dominance_matrix": dominance_matrix,
        "dominance_graph": dominance_graph,
        "df_sorted_topo": df_sorted_topo,
        "df_sorted_count": df_sorted_count,
    }

# %% [markdown]
# # Reading The files

# %%
csv_files_path_fine_tuning_full = dict()
csv_files_path_fine_tuning_grouped = dict()

# %% [markdown]
# ## 204

# %% [markdown]
# ### Plant F

# %%
path_fine_tuning_full = "/home/peressim/projects/ccs28-ml-modelling/reports/results/global_models/204/f/fine_tuning/full/"
path_fine_tuning_grouped = "/home/peressim/projects/ccs28-ml-modelling/reports/results/global_models/204/f/fine_tuning/grouped/"
plant = "f"

csv_files_path_fine_tuning_full = read_csv_files_path(
    csv_files_path_fine_tuning_full, path_fine_tuning_full, plant
)

csv_files_path_fine_tuning_grouped = read_csv_files_path(
    csv_files_path_fine_tuning_grouped, path_fine_tuning_grouped, plant
)

# %% [markdown]
# ### Plant AB

# %%
path_fine_tuning_full = "/home/peressim/projects/ccs28-ml-modelling/reports/results/global_models/204/ab/fine_tuning/full/"
path_fine_tuning_grouped = "/home/peressim/projects/ccs28-ml-modelling/reports/results/global_models/204/ab/fine_tuning/grouped/"
plant = "ab"

csv_files_path_fine_tuning_full = read_csv_files_path(
    csv_files_path_fine_tuning_full, path_fine_tuning_full, plant
)

csv_files_path_fine_tuning_grouped = read_csv_files_path(
    csv_files_path_fine_tuning_grouped, path_fine_tuning_grouped, plant
)

# %% [markdown]
# ### Reading all data - pre training

# %% [markdown]
# #### Full

# %%
dfs_plant = dict()
column = ("plant", "")
pos = 2

for plant, csv_files in csv_files_path_fine_tuning_full.items():
    df = read_csv_files_full(csv_files, plant)
    df["plant"] = plant
    dfs_plant[plant] = df

# %%
df_fine_tuning_full = pd.concat(dfs_plant.values(), ignore_index=True)

# %%
df_fine_tuning_full.shape
# Out:
# (1023, 23)

# %% [markdown]
# #### Grouped

# %%
dfs_plant = dict()
column = ("plant", "")
pos = 2

for plant, csv_files in csv_files_path_fine_tuning_grouped.items():
    df = read_csv_files_grouped(csv_files, plant)
    df["plant"] = plant
    df = preprocess_rename_columns(df)
    df = preprocess_change_columns_order(df, column, pos)
    dfs_plant[plant] = df

# %%
df_fine_tuning_grouped = pd.concat(dfs_plant.values(), ignore_index=True)

# %%
df_fine_tuning_grouped.shape
# Out:
# (81, 25)

# %%
df_copy = df_fine_tuning_grouped.copy()
df_copy = (
    df_copy.reset_index(level=0)
    .rename({"level_0": "Plant"}, axis=1)
    .reset_index(drop=True)
)

# %% [markdown]
# ## Preprocessing steps

# %%
patterns = [
    "Chemical + Mineralogical + Feature Engineering",
    "Chemical + Mineralogical + CS7 + One-Hot",
    "Chemical + Mineralogical + Physical + One-Hot",
    "Chemical + Mineralogical + CS3 + One-Hot",
    "Chemical + Mineralogical + CS3 + CS7 + One-Hot",
    "Chemical + Mineralogical + One-Hot",
    "Chemical + Mineralogical + CS1 + CS3 + CS7 + One-Hot",
    "Chemical + Mineralogical + CS1 + CS3 + One-Hot",
    "Chemical + Mineralogical + CS1 + One-Hot",
    "Chemical + Mineralogical + CS2 + One-Hot",
    "Chemical + Feature Engineering",
]

replace_dict = {
    "Chemical + Mineralogical + CS3 + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS3": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS1": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS1 + CS3": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS1 + CS3 + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS2": "Chemical + Mineralogical + Early CS",
    "Chemical + CS1 + CS3 + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + CS3 + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + CS3": "Chemical + Mineralogical + Early CS",
    "Chemical + CS1 + CS3": "Chemical + Mineralogical + Early CS",
    "Chemical + CS1": "Chemical + Mineralogical + Early CS",
    "Chemical + CS1 + CS7": "Chemical + Mineralogical + Early CS",
}

replace_dict_2 = {
    "Chemical": "Chemical + Mineralogical",
    "Chemical + Properties CS Less": "Chemical + Mineralogical + Physical - Early CS",
    "Chemical + Mineralogical + Properties CS Less": "Chemical + Mineralogical + Physical - Early CS",
    "Chemical + Physical": "Chemical + Mineralogical + Physical",
}

df_copy = df_copy[~df_copy["Cross Validation"].eq("Out of time Split")].reset_index(
    drop=True
)

# Removing afterwards
df_copy = df_copy[~df_copy["Cross Validation"].eq("Repeated KFold")].reset_index(
    drop=True
)

df_copy = df_copy[~df_copy["Features"].apply(lambda x: x in patterns)].reset_index(
    drop=True
)
df_copy["Features_bkp"] = df_copy["Features"].copy()
df_copy["Features"] = df_copy["Features"].replace(replace_dict)

df_copy["Features"] = df_copy["Features"].replace(replace_dict_2)

# Removing afterwards
# df_copy = df_copy[
#     ~df_copy["Features"].eq("Chemical + Mineralogical + Early CS")
# ].reset_index(drop=True)

# %%
df_copy[("MAPE Train", "mean")] = df_copy[("MAPE Train", "mean")] * 100
df_copy[("MAPE Train", "std")] = df_copy[("MAPE Train", "std")] * 100
df_copy[("MAPE Test", "mean")] = df_copy[("MAPE Test", "mean")] * 100
df_copy[("MAPE Test", "std")] = df_copy[("MAPE Test", "std")] * 100

df_copy["Model_bkp"] = df_copy["Model"].copy()
df_copy["Model_bkp_2"] = df_copy["Model"] + df_copy["Timesteps"].apply(
    lambda x: "" if pd.isna(x) else "_" + str(x)
)
df_copy["Model"] = df_copy["Model"].replace(
    {
        "MLP": "Neural Networks",
        "LSTM": "Neural Networks",
        "GRU": "Neural Networks",
        "BidirectionalLSTM": "Neural Networks",
        "BidirectionalGRU": "Neural Networks",
        "Transformer": "Neural Networks",
        "Decision Tree": "Trees",
        "Random Forest": "Trees",
        "XGBoost": "Trees",
    }
)

# %%
df_copy["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split', 'Time Series Split'], dtype=object)

# %%
df_copy["Features"].unique()
# Out:
# array(['Chemical + Mineralogical', 'Chemical + Mineralogical + Physical',
#        'Chemical + Mineralogical + Physical - Early CS'], dtype=object)

# %%
df_copy["Model"].unique()
# Out:
# array(['Neural Networks', 'Conv1D'], dtype=object)

# %%
df_copy["Model_bkp"].unique()
# Out:
# array(['Transformer', 'MLP', 'BidirectionalLSTM', 'Conv1D', 'LSTM'],
#       dtype=object)

# %%
df_copy["Model_bkp_2"].unique()
# Out:
# array(['Transformer_1.0', 'MLP', 'BidirectionalLSTM_7.0', 'Conv1D_7.0',
#        'LSTM_7.0', 'BidirectionalLSTM_14.0', 'Transformer_14.0',
#        'LSTM_14.0', 'Conv1D_1.0', 'BidirectionalLSTM_1.0'], dtype=object)

# %%
df_copy.shape
# Out:
# (50, 29)

# %%
df_copy_grouped = df_copy.copy()

# %%
df_copy[
    [
        ("RMSE Test", "mean"),
        ("MAE Test", "mean"),
        ("MAPE Test", "mean"),
        ("R2 Test", "mean"),
    ]
].describe().round(2).T
# Out:
#                 count    mean      std       min   25%   50%   75%     max
# RMSE Test mean   50.0   15.16    67.51      1.37  1.66  2.02  3.17  453.49
# MAE Test  mean   50.0    8.41    36.68      1.08  1.26  1.57  2.33  250.83
# MAPE Test mean   50.0   18.40    79.71      2.52  2.94  3.64  5.26  547.28
# R2 Test   mean   50.0 -280.41  1747.47 -12263.58  0.69  0.87  0.94    0.96

# %%
df_copy["plant"].unique()
# Out:
# array(['f', 'ab'], dtype=object)

# %% [markdown]
# # Global Analysis (fine tuning results)

# %% [markdown]
# ## ECICS - 204

# %%
df_ecics_grouped = df_copy.copy()

# %%
df_results = df_ecics_grouped[
    [
        ("Company", ""),
        ("plant", ""),
        ("Cross Validation", ""),
        ("Features", ""),
        ('Features_bkp', ''),
        ("Model", ""),
        ("Model_bkp", ""),         
        ('Model_bkp_2',''),
        ("Timesteps", ""),
        ("RMSE Test", "mean"),
        ("MAE Test", "mean"),
        ("MAPE Test", "mean"),
        ("R2 Test", "mean"),
        ("RMSE Test", "std"),
        ("MAE Test", "std"),
        ("MAPE Test", "std"),
        ("R2 Test", "std"),
    ]
].copy()
df_results = df_results.reset_index(drop=True)

# Rename columns
new_column_names = [
    "Company",
    "Plant",
    "Cross Validation",
    "Features",
    "Features_bkp",
    "Model",
    "Model_bkp",
    "Model_bkp_2",
    "Timesteps",
    "RMSE_mean",
    "MAE_mean",
    "MAPE_mean",
    "R2_mean",
    "RMSE_std",
    "MAE_std",
    "MAPE_std",
    "R2_std",
]

df_results.columns = new_column_names

# %%
df_results.shape
# Out:
# (50, 17)

# %%
df_results["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split', 'Time Series Split'], dtype=object)

# %% [markdown]
# ## Variable Grouping: CM

# %% [markdown]
# #### Analysis of the best models identified in the Local Analysis

# %% [markdown]
# **Best models for variable groupping CM were from:**
#
# *BTiSS:*
#     Dominance analysis: Plant AB
#     SCPM:Plant AB
#
# *TiSS:*
#     Dominance analysis: Plant F
#     SCPM:Plant F

# %%
df_results["Features"].unique()
# Out:
# array(['Chemical + Mineralogical', 'Chemical + Mineralogical + Physical',
#        'Chemical + Mineralogical + Physical - Early CS'], dtype=object)

# %% [markdown]
# ### Plant AB

# %%
df_results_cm = (
    df_results[df_results["Features"].eq("Chemical + Mineralogical")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm["Features"].unique()
# Out:
# array(['Chemical + Mineralogical'], dtype=object)

# %%
df_results_cm.shape
# Out:
# (20, 17)

# %%
df_results_cm = df_results_cm[df_results_cm["Plant"].eq("ab")].reset_index(drop=True)

# %%
df_results_cm.shape
# Out:
# (10, 17)

# %% [markdown]
# ### Blocking time series

# %%
df_results_cm["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split', 'Time Series Split'], dtype=object)

# %%
df_results_cm_btss = (
    df_results_cm[df_results_cm["Cross Validation"].eq("Blocking Time Series Split")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_btss["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split'], dtype=object)

# %%
df_results_cm_btss.shape
# Out:
# (5, 17)

# %% [markdown]
# ###### SCPM computation

# %%
df_results_cm_btss = compute_scpm(df_results_cm_btss)

# %% [markdown]
# ##### Dominance Analysis

# %%
# Per project
dominance_dict = make_dominance_analysis(df_results_cm_btss)
dominance_matrix_cm_btss = dominance_dict["dominance_matrix"]
dominance_graph_cm_btss = dominance_dict["dominance_graph"]
df_sorted_count = dominance_dict["df_sorted_count"]
df_sorted_topo = dominance_dict["df_sorted_topo"]

# %%
dominance_matrix_cm_btss.shape, len(dominance_graph_cm_btss)
# Out:
# ((5, 5), 5)

# %%
df_sorted_topo["Classification"].value_counts()
# Out:
# Classification
# dominant_model        2
# intermediate_model    2
# non_dominant_model    1
# Name: count, dtype: int64

# %%
df_sorted_topo.to_csv(
    "../../../../reports/results/global_models/ecics/ecics_204_ab_dominance_analysis_cm_btss.csv",
    index=False,
)

# %%
df_sorted_topo.head(5)
# Out:
#    Company Plant            Cross Validation                  Features  \
# 0      204    ab  Blocking Time Series Split  Chemical + Mineralogical
# 3      204    ab  Blocking Time Series Split  Chemical + Mineralogical
# 2      204    ab  Blocking Time Series Split  Chemical + Mineralogical
# 4      204    ab  Blocking Time Series Split  Chemical + Mineralogical
# 1      204    ab  Blocking Time Series Split  Chemical + Mineralogical
#
#   Features_bkp            Model          Model_bkp            Model_bkp_2  \
# 0     Chemical  Neural Networks        Transformer       Transformer_14.0
# 3     Chemical  Neural Networks                MLP                    MLP
# 2     Chemical           Conv1D             Conv1D             Conv1D_7.0
# 4     Chemical  Neural Networks               LSTM              LSTM_14.0
# 1     Chemical  Neural Networks  BidirectionalLSTM  BidirectionalLSTM_7.0
#
#    Timesteps   RMSE_mean  ...   MAPE_mean       R2_mean    RMSE_std  \
# 0       14.0    1.877239  ...    3.364062      0.851889    0.717912
# 3        NaN    1.896281  ...    3.465779      0.873429    0.352691
# 2        7.0    3.293655  ...    5.815239      0.673772    0.655884
# 4       14.0    4.337385  ...    7.921215      0.420288    1.110210
# 1        7.0  453.491348  ...  547.284398 -12263.582957  308.529430
#
#       MAE_std    MAPE_std        R2_std      SCPM  Dominated_Count  \
# 0    0.431818    1.058992      0.177338 -2.021700                0
# 3    0.254013    0.647049      0.109899 -2.020546                0
# 2    0.550276    1.095785      0.137525 -1.991323                2
# 4    1.124117    2.368821      0.339841 -1.966287                3
# 1  162.354940  354.304036  19055.295331  7.999856                4
#
#        Classification Dominates_Count
# 0      dominant_model               3
# 3      dominant_model               3
# 2  intermediate_model               2
# 4  intermediate_model               1
# 1  non_dominant_model               0
#
# [5 rows x 21 columns]

# %%
df_sorted_topo_cols = df_sorted_topo[
    [
        # "Model",
        # "Model_bkp",
        "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Classification",
        "Dominates_Count",
        "Plant",
    ]
].round(2)

# %% [markdown]
# ###### Dominant Models

# %%
# Top 4
df_sorted_topo_cols.sort_values(
    by=["Dominates_Count", "SCPM"], ascending=[False, True]
).iloc[0:2]
# Out:
#         Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 0  Transformer_14.0       1.88      0.72      1.43     0.43       3.36
# 3               MLP       1.90      0.35      1.49     0.25       3.47
#
#    MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count  Classification  \
# 0      1.06     0.85    0.18 -2.02                0  dominant_model
# 3      0.65     0.87    0.11 -2.02                0  dominant_model
#
#    Dominates_Count Plant
# 0                3    ab
# 3                3    ab

# %%
df_sorted_topo_cols[df_sorted_topo_cols["Classification"].eq("dominant_model")].shape
# Out:
# (2, 14)

# %% [markdown]
# ###### Intermediate models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].sort_values(by=["Dominates_Count", "SCPM"], ascending=[False, True]).iloc[:3]
# Out:
#   Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  MAPE_std  \
# 2  Conv1D_7.0       3.29      0.66      2.54     0.55       5.82      1.10
# 4   LSTM_14.0       4.34      1.11      3.48     1.12       7.92      2.37
#
#    R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 2     0.67    0.14 -1.99                2  intermediate_model
# 4     0.42    0.34 -1.97                3  intermediate_model
#
#    Dominates_Count Plant
# 2                2    ab
# 4                1    ab

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].shape
# Out:
# (2, 14)

# %% [markdown]
# ###### non-dominant models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].sort_values(by=["Dominates_Count", "SCPM"], ascending=[False, True]).iloc[:2]
# Out:
#              Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 1  BidirectionalLSTM_7.0     453.49    308.53    250.83   162.35     547.28
#
#    MAPE_std   R2_mean   R2_std  SCPM  Dominated_Count      Classification  \
# 1     354.3 -12263.58  19055.3   8.0                4  non_dominant_model
#
#    Dominates_Count Plant
# 1                0    ab

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].shape
# Out:
# (1, 14)

# %% [markdown]
# ###### Statistics per model type

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        # "Model_bkp",
        # "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
        "Plant",
    ]
]  # .round(2)

# %%
df_sorted_topo["Model"].value_counts()
# Out:
# Model
# Neural Networks    4
# Conv1D             1
# Name: count, dtype: int64

# %%
df_sorted_topo_models_grouped = df_sorted_topo_models_cols.groupby("Model").describe().T

# %%
# pd.set_option("display.max_rows", None)
# df_sorted_topo_models_grouped

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
    ]
]

# %%
(
    df_sorted_topo_models_cols.groupby("Model")[["Classification"]]
    .value_counts(normalize=True)
    .to_frame()
    * 100
).round(2)
# Out:
#                                     proportion
# Model           Classification
# Conv1D          intermediate_model       100.0
# Neural Networks dominant_model            50.0
#                 intermediate_model        25.0
#                 non_dominant_model        25.0

# %%
df_sorted_topo_models_cols.groupby("Model").describe().round(2).T
# Out:
# Model                  Conv1D  Neural Networks
# Dominated_Count count     1.0             4.00
#                 mean      2.0             1.75
#                 std       NaN             2.06
#                 min       2.0             0.00
#                 25%       2.0             0.00
#                 50%       2.0             1.50
#                 75%       2.0             3.25
#                 max       2.0             4.00
# Dominates_Count count     1.0             4.00
#                 mean      2.0             1.75
#                 std       NaN             1.50
#                 min       2.0             0.00
#                 25%       2.0             0.75
#                 50%       2.0             2.00
#                 75%       2.0             3.00
#                 max       2.0             3.00

# %%
# df_sorted_topo_models_cols

# %%
df_sorted_topo_models_cols.groupby("Model")["Classification"].describe()
# Out:
#                 count unique                 top freq
# Model
# Conv1D              1      1  intermediate_model    1
# Neural Networks     4      3      dominant_model    2

# %%
df_sorted_topo_models_cols.groupby("Model")[["Classification"]].value_counts()
# Out:
# Model            Classification
# Conv1D           intermediate_model    1
# Neural Networks  dominant_model        2
#                  intermediate_model    1
#                  non_dominant_model    1
# Name: count, dtype: int64

# %%
# df_sorted_topo_models_cols

# %%
summary_stats = df_sorted_topo_models_cols.groupby("Model").agg(
    Total_Models=("Model", "count"),
    Mean_Dominance_Count=("Dominates_Count", "mean"),
    Median_Dominance_Count=("Dominates_Count", "median"),
    Total_Dominated=("Dominated_Count", "sum"),
    Total_Dominating=("Dominates_Count", "sum"),
)

total_models = summary_stats[
    "Total_Models"
].sum()  # Get the total number of models across all categories
summary_stats["Dominance Proportion"] = summary_stats["Total_Dominating"] / total_models

# %%
summary_stats
# Out:
#                  Total_Models  Mean_Dominance_Count  Median_Dominance_Count  \
# Model
# Conv1D                      1                  2.00                     2.0
# Neural Networks             4                  1.75                     2.0
#
#                  Total_Dominated  Total_Dominating  Dominance Proportion
# Model
# Conv1D                         2                 2                   0.4
# Neural Networks                7                 7                   1.4

# %%
df_sorted_topo_models_grouped.T
# Out:
#                 RMSE_mean                                              \
#                     count        mean         std       min       25%
# Model
# Conv1D                1.0    3.293655         NaN  3.293655  3.293655
# Neural Networks       4.0  115.400563  225.396817  1.877239  1.891521
#
#                                                   RMSE_std             ...  \
#                       50%         75%         max    count       mean  ...
# Model                                                                  ...
# Conv1D           3.293655    3.293655    3.293655      1.0   0.655884  ...
# Neural Networks  3.116833  116.625876  453.491348      4.0  77.677561  ...
#
#                 Dominated_Count      Dominates_Count                        \
#                             75%  max           count  mean  std  min   25%
# Model
# Conv1D                     2.00  2.0             1.0  2.00  NaN  2.0  2.00
# Neural Networks            3.25  4.0             4.0  1.75  1.5  0.0  0.75
#
#
#                  50%  75%  max
# Model
# Conv1D           2.0  2.0  2.0
# Neural Networks  2.0  3.0  3.0
#
# [2 rows x 88 columns]

# %% [markdown]
# ### SCPM Analysis

# %%
cols = [
    # "Model",
    # "Model_bkp",
    "Model_bkp_2",
    "RMSE_mean",
    "RMSE_std",
    "MAE_mean",
    "MAE_std",
    "MAPE_mean",
    "MAPE_std",
    "R2_mean",
    "R2_std",
    "SCPM",
    "Dominated_Count",
    "Dominates_Count",
    "Classification",
    "Plant",
]

# %%
df_sorted_scpm = df_sorted_topo.sort_values(by="SCPM").copy()

# %%
# (df_sorted_topo[cols].reset_index() == df_sorted_scpm[cols].reset_index()).all(axis=1)
df_sorted_scpm["topo_scmp_order_eq"] = df_sorted_topo.index == df_sorted_scpm.index

# %%
df_sorted_scpm[cols + ["topo_scmp_order_eq"]].round(2).head(5)
# Out:
#              Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 0       Transformer_14.0       1.88      0.72      1.43     0.43       3.36
# 3                    MLP       1.90      0.35      1.49     0.25       3.47
# 2             Conv1D_7.0       3.29      0.66      2.54     0.55       5.82
# 4              LSTM_14.0       4.34      1.11      3.48     1.12       7.92
# 1  BidirectionalLSTM_7.0     453.49    308.53    250.83   162.35     547.28
#
#    MAPE_std   R2_mean    R2_std  SCPM  Dominated_Count  Dominates_Count  \
# 0      1.06      0.85      0.18 -2.02                0                3
# 3      0.65      0.87      0.11 -2.02                0                3
# 2      1.10      0.67      0.14 -1.99                2                2
# 4      2.37      0.42      0.34 -1.97                3                1
# 1    354.30 -12263.58  19055.30  8.00                4                0
#
#        Classification Plant  topo_scmp_order_eq
# 0      dominant_model    ab                True
# 3      dominant_model    ab                True
# 2  intermediate_model    ab                True
# 4  intermediate_model    ab                True
# 1  non_dominant_model    ab                True

# %% [markdown]
# ### Plant F

# %%
df_results_cm = (
    df_results[df_results["Features"].eq("Chemical + Mineralogical")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm["Features"].unique()
# Out:
# array(['Chemical + Mineralogical'], dtype=object)

# %%
df_results_cm.shape
# Out:
# (20, 17)

# %%
df_results_cm = df_results_cm[df_results_cm["Plant"].eq("f")].reset_index(drop=True)

# %%
df_results_cm.shape
# Out:
# (10, 17)

# %% [markdown]
# ### Time Series Split

# %%
df_results_cm["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split', 'Time Series Split'], dtype=object)

# %%
df_results_cm_tss = (
    df_results_cm[df_results_cm["Cross Validation"].eq("Time Series Split")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_tss["Cross Validation"].unique()
# Out:
# array(['Time Series Split'], dtype=object)

# %%
df_results_cm_tss.shape
# Out:
# (5, 17)

# %% [markdown]
# ###### SCPM computation

# %%
df_results_cm_tss = compute_scpm(df_results_cm_tss)

# %% [markdown]
# ##### Dominance Analysis

# %%
# Per project
dominance_dict = make_dominance_analysis(df_results_cm_tss)
dominance_matrix_cm_tss = dominance_dict["dominance_matrix"]
dominance_graph_cm_tss = dominance_dict["dominance_graph"]
df_sorted_count = dominance_dict["df_sorted_count"]
df_sorted_topo = dominance_dict["df_sorted_topo"]

# %%
dominance_matrix_cm_tss.shape, len(dominance_graph_cm_tss)
# Out:
# ((5, 5), 5)

# %%
df_sorted_topo["Classification"].value_counts()
# Out:
# Classification
# intermediate_model    3
# dominant_model        1
# non_dominant_model    1
# Name: count, dtype: int64

# %%
df_sorted_topo.to_csv(
    "../../../../reports/results/global_models/ecics/ecics_204_f_dominance_analysis_cm_tss.csv",
    index=False,
)

# %%
df_sorted_topo.head(5)
# Out:
#    Company Plant   Cross Validation                  Features Features_bkp  \
# 0      204     f  Time Series Split  Chemical + Mineralogical     Chemical
# 3      204     f  Time Series Split  Chemical + Mineralogical     Chemical
# 2      204     f  Time Series Split  Chemical + Mineralogical     Chemical
# 1      204     f  Time Series Split  Chemical + Mineralogical     Chemical
# 4      204     f  Time Series Split  Chemical + Mineralogical     Chemical
#
#              Model          Model_bkp            Model_bkp_2  Timesteps  \
# 0  Neural Networks        Transformer        Transformer_1.0        1.0
# 3  Neural Networks                MLP                    MLP        NaN
# 2           Conv1D             Conv1D             Conv1D_7.0        7.0
# 1  Neural Networks  BidirectionalLSTM  BidirectionalLSTM_7.0        7.0
# 4  Neural Networks               LSTM               LSTM_7.0        7.0
#
#    RMSE_mean  ...  MAPE_mean   R2_mean  RMSE_std   MAE_std  MAPE_std  \
# 0   1.741329  ...   2.935762  0.934552  0.236479  0.198124  0.448636
# 3   1.791195  ...   3.229860  0.930404  0.260330  0.208885  0.500730
# 2   2.020378  ...   3.646712  0.900267  0.671155  0.447168  1.099442
# 1   3.079405  ...   5.103415  0.771033  0.988342  0.519538  1.253645
# 4   6.848880  ...   7.418795 -0.531873  4.692760  1.514150  3.876044
#
#      R2_std      SCPM  Dominated_Count      Classification Dominates_Count
# 0  0.016690 -3.110627                0      dominant_model               4
# 3  0.019883 -2.766405                1  intermediate_model               3
# 2  0.065173 -2.065939                2  intermediate_model               2
# 1  0.154638  0.432329                3  intermediate_model               1
# 4  2.184704  7.510642                4  non_dominant_model               0
#
# [5 rows x 21 columns]

# %%
df_sorted_topo_cols = df_sorted_topo[
    [
        # "Model",
        # "Model_bkp",
        "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Classification",
        "Dominates_Count",
        "Plant",
    ]
]  # .round(2)

# %% [markdown]
# ###### Dominant Models

# %%
# Top 4
df_sorted_topo_cols.iloc[0:2].sort_values(by="Dominates_Count", ascending=False).round(
    2
)
# Out:
#        Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 0  Transformer_1.0       1.74      0.24      1.27     0.20       2.94
# 3              MLP       1.79      0.26      1.36     0.21       3.23
#
#    MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 0      0.45     0.93    0.02 -3.11                0      dominant_model
# 3      0.50     0.93    0.02 -2.77                1  intermediate_model
#
#    Dominates_Count Plant
# 0                4     f
# 3                3     f

# %%
# Top 4
df_sorted_topo_cols.iloc[0:2].sort_values(
    by=["Dominates_Count", "SCPM"], ascending=[False, True]
).iloc[:4].round(2).round(2)
# Out:
#        Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 0  Transformer_1.0       1.74      0.24      1.27     0.20       2.94
# 3              MLP       1.79      0.26      1.36     0.21       3.23
#
#    MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 0      0.45     0.93    0.02 -3.11                0      dominant_model
# 3      0.50     0.93    0.02 -2.77                1  intermediate_model
#
#    Dominates_Count Plant
# 0                4     f
# 3                3     f

# %%
df_sorted_topo_cols[df_sorted_topo_cols["Classification"].eq("dominant_model")].shape
# Out:
# (1, 14)

# %% [markdown]
# ###### Intermediate models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].sort_values(by=["Dominates_Count", "SCPM"], ascending=[False, True]).iloc[:4].round(2)
# Out:
#              Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 3                    MLP       1.79      0.26      1.36     0.21       3.23
# 2             Conv1D_7.0       2.02      0.67      1.56     0.45       3.65
# 1  BidirectionalLSTM_7.0       3.08      0.99      2.17     0.52       5.10
#
#    MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 3      0.50     0.93    0.02 -2.77                1  intermediate_model
# 2      1.10     0.90    0.07 -2.07                2  intermediate_model
# 1      1.25     0.77    0.15  0.43                3  intermediate_model
#
#    Dominates_Count Plant
# 3                3     f
# 2                2     f
# 1                1     f

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].shape
# Out:
# (3, 14)

# %% [markdown]
# ###### non-dominant models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].sort_values(by=["Dominates_Count", "SCPM"], ascending=[False, True]).iloc[:3]
# Out:
#   Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  MAPE_std  \
# 4    LSTM_7.0    6.84888   4.69276  3.216369  1.51415   7.418795  3.876044
#
#     R2_mean    R2_std      SCPM  Dominated_Count      Classification  \
# 4 -0.531873  2.184704  7.510642                4  non_dominant_model
#
#    Dominates_Count Plant
# 4                0     f

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].shape
# Out:
# (1, 14)

# %% [markdown]
# ###### Statistics per model type

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        # "Model_bkp",
        # "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
        "Plant",
    ]
]  # .round(2)

# %%
df_sorted_topo["Model"].value_counts()
# Out:
# Model
# Neural Networks    4
# Conv1D             1
# Name: count, dtype: int64

# %%
df_sorted_topo_models_grouped = df_sorted_topo_models_cols.groupby("Model").describe().T

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
    ]
]

# %%
(
    df_sorted_topo_models_cols.groupby("Model")[["Classification"]]
    .value_counts(normalize=True)
    .to_frame()
    * 100
).round(2)
# Out:
#                                     proportion
# Model           Classification
# Conv1D          intermediate_model       100.0
# Neural Networks intermediate_model        50.0
#                 dominant_model            25.0
#                 non_dominant_model        25.0

# %%
df_sorted_topo_models_cols.groupby("Model").describe().round(2).T
# Out:
# Model                  Conv1D  Neural Networks
# Dominated_Count count     1.0             4.00
#                 mean      2.0             2.00
#                 std       NaN             1.83
#                 min       2.0             0.00
#                 25%       2.0             0.75
#                 50%       2.0             2.00
#                 75%       2.0             3.25
#                 max       2.0             4.00
# Dominates_Count count     1.0             4.00
#                 mean      2.0             2.00
#                 std       NaN             1.83
#                 min       2.0             0.00
#                 25%       2.0             0.75
#                 50%       2.0             2.00
#                 75%       2.0             3.25
#                 max       2.0             4.00

# %%
# df_sorted_topo_models_cols

# %%
df_sorted_topo_models_cols.groupby("Model")["Classification"].describe()
# Out:
#                 count unique                 top freq
# Model
# Conv1D              1      1  intermediate_model    1
# Neural Networks     4      3  intermediate_model    2

# %%
df_sorted_topo_models_cols.groupby("Model")[["Classification"]].value_counts()
# Out:
# Model            Classification
# Conv1D           intermediate_model    1
# Neural Networks  intermediate_model    2
#                  dominant_model        1
#                  non_dominant_model    1
# Name: count, dtype: int64

# %%
summary_stats = df_sorted_topo_models_cols.groupby("Model").agg(
    Total_Models=("Model", "count"),
    Mean_Dominance_Count=("Dominates_Count", "mean"),
    Median_Dominance_Count=("Dominates_Count", "median"),
    Total_Dominated=("Dominated_Count", "sum"),
    Total_Dominating=("Dominates_Count", "sum"),
)

total_models = summary_stats[
    "Total_Models"
].sum()  # Get the total number of models across all categories
summary_stats["Dominance Proportion"] = summary_stats["Total_Dominating"] / total_models

# %%
summary_stats.round(2)
# Out:
#                  Total_Models  Mean_Dominance_Count  Median_Dominance_Count  \
# Model
# Conv1D                      1                   2.0                     2.0
# Neural Networks             4                   2.0                     2.0
#
#                  Total_Dominated  Total_Dominating  Dominance Proportion
# Model
# Conv1D                         2                 2                   0.4
# Neural Networks                8                 8                   1.6

# %%
df_sorted_topo_models_grouped.T
# Out:
#                 RMSE_mean                                                    \
#                     count      mean       std       min       25%       50%
# Model
# Conv1D                1.0  2.020378       NaN  2.020378  2.020378  2.020378
# Neural Networks       4.0  3.365202  2.403619  1.741329  1.778729  2.435300
#
#                                     RMSE_std            ... Dominated_Count  \
#                       75%       max    count      mean  ...             75%
# Model                                                   ...
# Conv1D           2.020378  2.020378      1.0  0.671155  ...            2.00
# Neural Networks  4.021774  6.848880      4.0  1.544478  ...            3.25
#
#                      Dominates_Count
#                  max           count mean       std  min   25%  50%   75%  max
# Model
# Conv1D           2.0             1.0  2.0       NaN  2.0  2.00  2.0  2.00  2.0
# Neural Networks  4.0             4.0  2.0  1.825742  0.0  0.75  2.0  3.25  4.0
#
# [2 rows x 88 columns]

# %% [markdown]
# ### SCPM Analysis

# %%
cols = [
    # "Model",
    # "Model_bkp",
    "Model_bkp_2",
    "RMSE_mean",
    "RMSE_std",
    "MAE_mean",
    "MAE_std",
    "MAPE_mean",
    "MAPE_std",
    "R2_mean",
    "R2_std",
    "SCPM",
    "Dominated_Count",
    "Dominates_Count",
    "Classification",
    "Plant",
]

# %% [markdown]
# #### SCPM Analysis by Project

# %%
df_sorted_scpm = df_sorted_topo.sort_values(by="SCPM").copy()

# %%
# (df_sorted_topo[cols].reset_index() == df_sorted_scpm[cols].reset_index()).all(axis=1)
df_sorted_scpm["topo_scmp_order_eq"] = df_sorted_topo.index == df_sorted_scpm.index

# %%
df_sorted_scpm[cols + ["topo_scmp_order_eq"]].round(2).head(5)
# Out:
#              Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 0        Transformer_1.0       1.74      0.24      1.27     0.20       2.94
# 3                    MLP       1.79      0.26      1.36     0.21       3.23
# 2             Conv1D_7.0       2.02      0.67      1.56     0.45       3.65
# 1  BidirectionalLSTM_7.0       3.08      0.99      2.17     0.52       5.10
# 4               LSTM_7.0       6.85      4.69      3.22     1.51       7.42
#
#    MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count  Dominates_Count  \
# 0      0.45     0.93    0.02 -3.11                0                4
# 3      0.50     0.93    0.02 -2.77                1                3
# 2      1.10     0.90    0.07 -2.07                2                2
# 1      1.25     0.77    0.15  0.43                3                1
# 4      3.88    -0.53    2.18  7.51                4                0
#
#        Classification Plant  topo_scmp_order_eq
# 0      dominant_model     f                True
# 3  intermediate_model     f                True
# 2  intermediate_model     f                True
# 1  intermediate_model     f                True
# 4  non_dominant_model     f                True

# %% [markdown]
# ## Variable Grouping: CM-P

# %% [markdown]
# #### Analysis of the best models identified in the Local Analysis

# %% [markdown]
# **Best models for variable groupping CM-P were from:**
#
# *BTiSS:*
#     Dominance analysis: Plant F
#     SCPM:Plant F
#
# *TiSS:*
#     Dominance analysis: Plant F
#     SCPM:Plant F

# %%
df_results["Features"].unique()
# Out:
# array(['Chemical + Mineralogical', 'Chemical + Mineralogical + Physical',
#        'Chemical + Mineralogical + Physical - Early CS'], dtype=object)

# %%
df_results_cm_p = (
    df_results[
        df_results["Features"].eq("Chemical + Mineralogical + Physical - Early CS")
    ]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_p["Features"].unique()
# Out:
# array(['Chemical + Mineralogical + Physical - Early CS'], dtype=object)

# %%
df_results_cm_p.shape
# Out:
# (10, 17)

# %% [markdown]
# ### Blocking time series

# %%
df_results_cm_p["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split', 'Time Series Split'], dtype=object)

# %%
df_results_cm_p_btss = (
    df_results_cm_p[
        df_results_cm_p["Cross Validation"].eq("Blocking Time Series Split")
    ]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_p_btss["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split'], dtype=object)

# %%
df_results_cm_p_btss.shape
# Out:
# (5, 17)

# %% [markdown]
# ###### SCPM computation

# %%
df_results_cm_p_btss = compute_scpm(df_results_cm_p_btss)

# %% [markdown]
# ##### Dominance Analysis

# %%
# Per project
dominance_dict = make_dominance_analysis(df_results_cm_p_btss)
dominance_matrix_cm_p_btss = dominance_dict["dominance_matrix"]
dominance_graph_cm_p_btss = dominance_dict["dominance_graph"]
df_sorted_count = dominance_dict["df_sorted_count"]
df_sorted_topo = dominance_dict["df_sorted_topo"]

# %%
dominance_matrix_cm_p_btss.shape, len(dominance_graph_cm_p_btss)
# Out:
# ((5, 5), 5)

# %%
df_sorted_topo["Classification"].value_counts()
# Out:
# Classification
# intermediate_model    2
# non_dominant_model    2
# dominant_model        1
# Name: count, dtype: int64

# %%
df_sorted_topo.to_csv(
    "../../../../reports/results/global_models/ecics/ecics_204_f_dominance_analysis_cm_p_btss.csv",
    index=False,
)

# %%
df_sorted_topo.head(5)
# Out:
#    Company Plant            Cross Validation  \
# 0      204     f  Blocking Time Series Split
# 4      204     f  Blocking Time Series Split
# 3      204     f  Blocking Time Series Split
# 1      204     f  Blocking Time Series Split
# 2      204     f  Blocking Time Series Split
#
#                                          Features  \
# 0  Chemical + Mineralogical + Physical - Early CS
# 4  Chemical + Mineralogical + Physical - Early CS
# 3  Chemical + Mineralogical + Physical - Early CS
# 1  Chemical + Mineralogical + Physical - Early CS
# 2  Chemical + Mineralogical + Physical - Early CS
#
#                     Features_bkp            Model          Model_bkp  \
# 0  Chemical + Properties CS Less  Neural Networks                MLP
# 4  Chemical + Properties CS Less  Neural Networks        Transformer
# 3  Chemical + Properties CS Less           Conv1D             Conv1D
# 1  Chemical + Properties CS Less  Neural Networks  BidirectionalLSTM
# 2  Chemical + Properties CS Less  Neural Networks               LSTM
#
#              Model_bkp_2  Timesteps  RMSE_mean  ...  MAPE_mean   R2_mean  \
# 0                    MLP        NaN   1.372538  ...   2.516835  0.957256
# 4        Transformer_1.0        1.0   1.632891  ...   2.754794  0.940862
# 3             Conv1D_7.0        7.0   2.362857  ...   4.055819  0.834888
# 1  BidirectionalLSTM_7.0        7.0   2.960377  ...   4.810744  0.751327
# 2               LSTM_7.0        7.0   3.177365  ...   4.689686  0.637151
#
#    RMSE_std   MAE_std  MAPE_std    R2_std      SCPM  Dominated_Count  \
# 0  0.295185  0.228292  0.564297  0.018385 -5.010293                0
# 4  0.247506  0.207447  0.482094  0.014642 -4.045491                1
# 3  0.973011  0.729558  1.365477  0.143282  0.639894                2
# 1  0.840810  0.499236  1.142482  0.149506  3.624921                3
# 2  2.115640  1.185856  2.304105  0.545944  4.790969                3
#
#        Classification Dominates_Count
# 0      dominant_model               4
# 4  intermediate_model               3
# 3  intermediate_model               2
# 1  non_dominant_model               0
# 2  non_dominant_model               0
#
# [5 rows x 21 columns]

# %%
df_sorted_topo_cols = df_sorted_topo[
    [
        # "Model",
        # "Model_bkp",
        "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Classification",
        "Dominates_Count",
        "Plant",
    ]
].round(2)

# %% [markdown]
# ###### Dominant Models

# %%
# Top 4
df_sorted_topo_cols.iloc[0:5]
# Out:
#              Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 0                    MLP       1.37      0.30      1.08     0.23       2.52
# 4        Transformer_1.0       1.63      0.25      1.18     0.21       2.75
# 3             Conv1D_7.0       2.36      0.97      1.84     0.73       4.06
# 1  BidirectionalLSTM_7.0       2.96      0.84      2.14     0.50       4.81
# 2               LSTM_7.0       3.18      2.12      2.16     1.19       4.69
#
#    MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 0      0.56     0.96    0.02 -5.01                0      dominant_model
# 4      0.48     0.94    0.01 -4.05                1  intermediate_model
# 3      1.37     0.83    0.14  0.64                2  intermediate_model
# 1      1.14     0.75    0.15  3.62                3  non_dominant_model
# 2      2.30     0.64    0.55  4.79                3  non_dominant_model
#
#    Dominates_Count Plant
# 0                4     f
# 4                3     f
# 3                2     f
# 1                0     f
# 2                0     f

# %%
df_sorted_topo_cols[df_sorted_topo_cols["Classification"].eq("dominant_model")].shape
# Out:
# (1, 14)

# %% [markdown]
# ###### Intermediate models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].sort_values(by=["Dominates_Count", "SCPM"], ascending=[False, True]).iloc[:3]
# Out:
#        Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 4  Transformer_1.0       1.63      0.25      1.18     0.21       2.75
# 3       Conv1D_7.0       2.36      0.97      1.84     0.73       4.06
#
#    MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 4      0.48     0.94    0.01 -4.05                1  intermediate_model
# 3      1.37     0.83    0.14  0.64                2  intermediate_model
#
#    Dominates_Count Plant
# 4                3     f
# 3                2     f

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].shape
# Out:
# (2, 14)

# %% [markdown]
# ###### non-dominant models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].sort_values(by=["Dominates_Count", "SCPM"], ascending=[False, True]).iloc[:2]
# Out:
#              Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 1  BidirectionalLSTM_7.0       2.96      0.84      2.14     0.50       4.81
# 2               LSTM_7.0       3.18      2.12      2.16     1.19       4.69
#
#    MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 1      1.14     0.75    0.15  3.62                3  non_dominant_model
# 2      2.30     0.64    0.55  4.79                3  non_dominant_model
#
#    Dominates_Count Plant
# 1                0     f
# 2                0     f

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].shape
# Out:
# (2, 14)

# %% [markdown]
# ###### Statistics per model type

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        # "Model_bkp",
        # "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
        "Plant",
    ]
]  # .round(2)

# %%
df_sorted_topo["Model"].value_counts()
# Out:
# Model
# Neural Networks    4
# Conv1D             1
# Name: count, dtype: int64

# %%
df_sorted_topo_models_grouped = df_sorted_topo_models_cols.groupby("Model").describe().T

# %%
# pd.set_option("display.max_rows", None)
# df_sorted_topo_models_grouped

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
    ]
]

# %%
(
    df_sorted_topo_models_cols.groupby("Model")[["Classification"]]
    .value_counts(normalize=True)
    .to_frame()
    * 100
).round(2)
# Out:
#                                     proportion
# Model           Classification
# Conv1D          intermediate_model       100.0
# Neural Networks non_dominant_model        50.0
#                 dominant_model            25.0
#                 intermediate_model        25.0

# %%
df_sorted_topo_models_cols.groupby("Model").describe().round(2).T
# Out:
# Model                  Conv1D  Neural Networks
# Dominated_Count count     1.0             4.00
#                 mean      2.0             1.75
#                 std       NaN             1.50
#                 min       2.0             0.00
#                 25%       2.0             0.75
#                 50%       2.0             2.00
#                 75%       2.0             3.00
#                 max       2.0             3.00
# Dominates_Count count     1.0             4.00
#                 mean      2.0             1.75
#                 std       NaN             2.06
#                 min       2.0             0.00
#                 25%       2.0             0.00
#                 50%       2.0             1.50
#                 75%       2.0             3.25
#                 max       2.0             4.00

# %%
# df_sorted_topo_models_cols

# %%
df_sorted_topo_models_cols.groupby("Model")["Classification"].describe()
# Out:
#                 count unique                 top freq
# Model
# Conv1D              1      1  intermediate_model    1
# Neural Networks     4      3  non_dominant_model    2

# %%
df_sorted_topo_models_cols.groupby("Model")[["Classification"]].value_counts()
# Out:
# Model            Classification
# Conv1D           intermediate_model    1
# Neural Networks  non_dominant_model    2
#                  dominant_model        1
#                  intermediate_model    1
# Name: count, dtype: int64

# %%
# df_sorted_topo_models_cols

# %%
summary_stats = df_sorted_topo_models_cols.groupby("Model").agg(
    Total_Models=("Model", "count"),
    Mean_Dominance_Count=("Dominates_Count", "mean"),
    Median_Dominance_Count=("Dominates_Count", "median"),
    Total_Dominated=("Dominated_Count", "sum"),
    Total_Dominating=("Dominates_Count", "sum"),
)

total_models = summary_stats[
    "Total_Models"
].sum()  # Get the total number of models across all categories
summary_stats["Dominance Proportion"] = summary_stats["Total_Dominating"] / total_models

# %%
summary_stats
# Out:
#                  Total_Models  Mean_Dominance_Count  Median_Dominance_Count  \
# Model
# Conv1D                      1                  2.00                     2.0
# Neural Networks             4                  1.75                     1.5
#
#                  Total_Dominated  Total_Dominating  Dominance Proportion
# Model
# Conv1D                         2                 2                   0.4
# Neural Networks                7                 7                   1.4

# %%
df_sorted_topo_models_grouped.T
# Out:
#                 RMSE_mean                                                    \
#                     count      mean       std       min       25%       50%
# Model
# Conv1D                1.0  2.362857       NaN  2.362857  2.362857  2.362857
# Neural Networks       4.0  2.285793  0.914746  1.372538  1.567803  2.296634
#
#                                     RMSE_std            ... Dominated_Count  \
#                       75%       max    count      mean  ...             75%
# Model                                                   ...
# Conv1D           2.362857  2.362857      1.0  0.973011  ...             2.0
# Neural Networks  3.014624  3.177365      4.0  0.874785  ...             3.0
#
#                      Dominates_Count
#                  max           count  mean       std  min  25%  50%   75%  max
# Model
# Conv1D           2.0             1.0  2.00       NaN  2.0  2.0  2.0  2.00  2.0
# Neural Networks  3.0             4.0  1.75  2.061553  0.0  0.0  1.5  3.25  4.0
#
# [2 rows x 88 columns]

# %% [markdown]
# ### SCPM Analysis

# %%
cols = [
    # "Model",
    # "Model_bkp",
    "Model_bkp_2",
    "RMSE_mean",
    "RMSE_std",
    "MAE_mean",
    "MAE_std",
    "MAPE_mean",
    "MAPE_std",
    "R2_mean",
    "R2_std",
    "SCPM",
    "Dominated_Count",
    "Dominates_Count",
    "Classification",
    "Plant",
]

# %% [markdown]
# #### SCPM Analysis by Project

# %%
df_sorted_scpm = df_sorted_topo.sort_values(by="SCPM").copy()

# %%
# (df_sorted_topo[cols].reset_index() == df_sorted_scpm[cols].reset_index()).all(axis=1)
df_sorted_scpm["topo_scmp_order_eq"] = df_sorted_topo.index == df_sorted_scpm.index

# %%
df_sorted_scpm[cols + ["topo_scmp_order_eq"]].round(2).head(5)
# Out:
#              Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 0                    MLP       1.37      0.30      1.08     0.23       2.52
# 4        Transformer_1.0       1.63      0.25      1.18     0.21       2.75
# 3             Conv1D_7.0       2.36      0.97      1.84     0.73       4.06
# 1  BidirectionalLSTM_7.0       2.96      0.84      2.14     0.50       4.81
# 2               LSTM_7.0       3.18      2.12      2.16     1.19       4.69
#
#    MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count  Dominates_Count  \
# 0      0.56     0.96    0.02 -5.01                0                4
# 4      0.48     0.94    0.01 -4.05                1                3
# 3      1.37     0.83    0.14  0.64                2                2
# 1      1.14     0.75    0.15  3.62                3                0
# 2      2.30     0.64    0.55  4.79                3                0
#
#        Classification Plant  topo_scmp_order_eq
# 0      dominant_model     f                True
# 4  intermediate_model     f                True
# 3  intermediate_model     f                True
# 1  non_dominant_model     f                True
# 2  non_dominant_model     f                True

# %% [markdown]
# ### Time Series Split

# %% [markdown]
# ### Plant F

# %%
df_results_cm_p = (
    df_results[
        df_results["Features"].eq("Chemical + Mineralogical + Physical - Early CS")
    ]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_p["Features"].unique()
# Out:
# array(['Chemical + Mineralogical + Physical - Early CS'], dtype=object)

# %%
df_results_cm_p.shape
# Out:
# (10, 17)

# %%
df_results_cm_p = df_results_cm_p[df_results_cm_p["Plant"].eq("f")].reset_index(
    drop=True
)

# %%
df_results_cm["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split', 'Time Series Split'], dtype=object)

# %%
df_results_cm_p_tss = (
    df_results_cm_p[df_results_cm_p["Cross Validation"].eq("Time Series Split")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_p_tss["Cross Validation"].unique()
# Out:
# array(['Time Series Split'], dtype=object)

# %%
df_results_cm_p_tss.shape
# Out:
# (5, 17)

# %% [markdown]
# ###### SCPM computation

# %%
df_results_cm_p_tss = compute_scpm(df_results_cm_p_tss)

# %% [markdown]
# ##### Dominance Analysis

# %%
# Per project
dominance_dict = make_dominance_analysis(df_results_cm_p_tss)
dominance_matrix_cm_p_tss = dominance_dict["dominance_matrix"]
dominance_graph_cm_p_tss = dominance_dict["dominance_graph"]
df_sorted_count = dominance_dict["df_sorted_count"]
df_sorted_topo = dominance_dict["df_sorted_topo"]

# %%
dominance_matrix_cm_tss.shape, len(dominance_graph_cm_tss)
# Out:
# ((5, 5), 5)

# %%
df_sorted_topo["Classification"].value_counts()
# Out:
# Classification
# dominant_model        2
# intermediate_model    2
# non_dominant_model    1
# Name: count, dtype: int64

# %%
df_sorted_topo.to_csv(
    "../../../../reports/results/global_models/ecics/ecics_204_f_dominance_analysis_cm_p_tss.csv",
    index=False,
)

# %%
df_sorted_topo.head(5)
# Out:
#    Company Plant   Cross Validation  \
# 0      204     f  Time Series Split
# 4      204     f  Time Series Split
# 3      204     f  Time Series Split
# 2      204     f  Time Series Split
# 1      204     f  Time Series Split
#
#                                          Features  \
# 0  Chemical + Mineralogical + Physical - Early CS
# 4  Chemical + Mineralogical + Physical - Early CS
# 3  Chemical + Mineralogical + Physical - Early CS
# 2  Chemical + Mineralogical + Physical - Early CS
# 1  Chemical + Mineralogical + Physical - Early CS
#
#                     Features_bkp            Model          Model_bkp  \
# 0  Chemical + Properties CS Less  Neural Networks                MLP
# 4  Chemical + Properties CS Less  Neural Networks        Transformer
# 3  Chemical + Properties CS Less           Conv1D             Conv1D
# 2  Chemical + Properties CS Less  Neural Networks               LSTM
# 1  Chemical + Properties CS Less  Neural Networks  BidirectionalLSTM
#
#              Model_bkp_2  Timesteps  RMSE_mean  ...  MAPE_mean   R2_mean  \
# 0                    MLP        NaN   1.626909  ...   3.036724  0.942175
# 4        Transformer_1.0        1.0   1.638910  ...   2.901188  0.940758
# 3             Conv1D_7.0        7.0   1.753235  ...   3.195430  0.930707
# 2               LSTM_7.0        7.0   1.996658  ...   3.360978  0.906109
# 1  BidirectionalLSTM_7.0        7.0   2.744033  ...   4.732717  0.805571
#
#    RMSE_std   MAE_std  MAPE_std    R2_std      SCPM  Dominated_Count  \
# 0  0.273138  0.197504  0.477115  0.020827 -2.842768                0
# 4  0.317922  0.223103  0.511231  0.022433 -3.092237                0
# 3  0.307386  0.236634  0.523346  0.022692 -1.687823                2
# 2  0.598745  0.312867  0.685873  0.058599 -0.072028                3
# 1  1.136449  0.745373  1.851245  0.167596  7.694857                4
#
#        Classification Dominates_Count
# 0      dominant_model               3
# 4      dominant_model               3
# 3  intermediate_model               2
# 2  intermediate_model               1
# 1  non_dominant_model               0
#
# [5 rows x 21 columns]

# %%
df_sorted_topo_cols = df_sorted_topo[
    [
        # "Model",
        # "Model_bkp",
        "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Classification",
        "Dominates_Count",
        "Plant",
    ]
]  # .round(2)

# %% [markdown]
# ###### Dominant Models

# %%
# Top 4
df_sorted_topo_cols.sort_values(
    by=["Dominates_Count", "SCPM"], ascending=[False, True]
).iloc[:2].round(2)
# Out:
#        Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 4  Transformer_1.0       1.64      0.32      1.26     0.22       2.90
# 0              MLP       1.63      0.27      1.29     0.20       3.04
#
#    MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count  Classification  \
# 4      0.51     0.94    0.02 -3.09                0  dominant_model
# 0      0.48     0.94    0.02 -2.84                0  dominant_model
#
#    Dominates_Count Plant
# 4                3     f
# 0                3     f

# %%
df_sorted_topo_cols[df_sorted_topo_cols["Classification"].eq("dominant_model")].shape
# Out:
# (2, 14)

# %% [markdown]
# ###### Intermediate models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].sort_values(by=["Dominates_Count", "SCPM"], ascending=[False, True]).iloc[:4].round(2)
# Out:
#   Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  MAPE_std  \
# 3  Conv1D_7.0       1.75      0.31      1.40     0.24       3.20      0.52
# 2    LSTM_7.0       2.00      0.60      1.48     0.31       3.36      0.69
#
#    R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 3     0.93    0.02 -1.69                2  intermediate_model
# 2     0.91    0.06 -0.07                3  intermediate_model
#
#    Dominates_Count Plant
# 3                2     f
# 2                1     f

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].shape
# Out:
# (2, 14)

# %% [markdown]
# ###### non-dominant models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].sort_values(by=["Dominates_Count", "SCPM"], ascending=[False, True]).iloc[:3]
# Out:
#              Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean   MAE_std  MAPE_mean  \
# 1  BidirectionalLSTM_7.0   2.744033  1.136449   2.03343  0.745373   4.732717
#
#    MAPE_std   R2_mean    R2_std      SCPM  Dominated_Count  \
# 1  1.851245  0.805571  0.167596  7.694857                4
#
#        Classification  Dominates_Count Plant
# 1  non_dominant_model                0     f

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].shape
# Out:
# (1, 14)

# %% [markdown]
# ###### Statistics per model type

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        # "Model_bkp",
        # "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
        "Plant",
    ]
]  # .round(2)

# %%
df_sorted_topo["Model"].value_counts()
# Out:
# Model
# Neural Networks    4
# Conv1D             1
# Name: count, dtype: int64

# %%
df_sorted_topo_models_grouped = df_sorted_topo_models_cols.groupby("Model").describe().T

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
    ]
]

# %%
(
    df_sorted_topo_models_cols.groupby("Model")[["Classification"]]
    .value_counts(normalize=True)
    .to_frame()
    * 100
).round(2)
# Out:
#                                     proportion
# Model           Classification
# Conv1D          intermediate_model       100.0
# Neural Networks dominant_model            50.0
#                 intermediate_model        25.0
#                 non_dominant_model        25.0

# %%
df_sorted_topo_models_cols.groupby("Model").describe().round(2).T
# Out:
# Model                  Conv1D  Neural Networks
# Dominated_Count count     1.0             4.00
#                 mean      2.0             1.75
#                 std       NaN             2.06
#                 min       2.0             0.00
#                 25%       2.0             0.00
#                 50%       2.0             1.50
#                 75%       2.0             3.25
#                 max       2.0             4.00
# Dominates_Count count     1.0             4.00
#                 mean      2.0             1.75
#                 std       NaN             1.50
#                 min       2.0             0.00
#                 25%       2.0             0.75
#                 50%       2.0             2.00
#                 75%       2.0             3.00
#                 max       2.0             3.00

# %%
# df_sorted_topo_models_cols

# %%
df_sorted_topo_models_cols.groupby("Model")["Classification"].describe()
# Out:
#                 count unique                 top freq
# Model
# Conv1D              1      1  intermediate_model    1
# Neural Networks     4      3      dominant_model    2

# %%
df_sorted_topo_models_cols.groupby("Model")[["Classification"]].value_counts()
# Out:
# Model            Classification
# Conv1D           intermediate_model    1
# Neural Networks  dominant_model        2
#                  intermediate_model    1
#                  non_dominant_model    1
# Name: count, dtype: int64

# %%
summary_stats = df_sorted_topo_models_cols.groupby("Model").agg(
    Total_Models=("Model", "count"),
    Mean_Dominance_Count=("Dominates_Count", "mean"),
    Median_Dominance_Count=("Dominates_Count", "median"),
    Total_Dominated=("Dominated_Count", "sum"),
    Total_Dominating=("Dominates_Count", "sum"),
)

total_models = summary_stats[
    "Total_Models"
].sum()  # Get the total number of models across all categories
summary_stats["Dominance Proportion"] = summary_stats["Total_Dominating"] / total_models

# %%
summary_stats.round(2)
# Out:
#                  Total_Models  Mean_Dominance_Count  Median_Dominance_Count  \
# Model
# Conv1D                      1                  2.00                     2.0
# Neural Networks             4                  1.75                     2.0
#
#                  Total_Dominated  Total_Dominating  Dominance Proportion
# Model
# Conv1D                         2                 2                   0.4
# Neural Networks                7                 7                   1.4

# %%
df_sorted_topo_models_grouped.T
# Out:
#                 RMSE_mean                                                    \
#                     count      mean       std       min       25%       50%
# Model
# Conv1D                1.0  1.753235       NaN  1.753235  1.753235  1.753235
# Neural Networks       4.0  2.001628  0.523822  1.626909  1.635910  1.817784
#
#                                     RMSE_std            ... Dominated_Count  \
#                       75%       max    count      mean  ...             75%
# Model                                                   ...
# Conv1D           1.753235  1.753235      1.0  0.307386  ...            2.00
# Neural Networks  2.183502  2.744033      4.0  0.581564  ...            3.25
#
#                      Dominates_Count
#                  max           count  mean  std  min   25%  50%  75%  max
# Model
# Conv1D           2.0             1.0  2.00  NaN  2.0  2.00  2.0  2.0  2.0
# Neural Networks  4.0             4.0  1.75  1.5  0.0  0.75  2.0  3.0  3.0
#
# [2 rows x 88 columns]

# %% [markdown]
# ### SCPM Analysis

# %%
cols = [
    # "Model",
    # "Model_bkp",
    "Model_bkp_2",
    "RMSE_mean",
    "RMSE_std",
    "MAE_mean",
    "MAE_std",
    "MAPE_mean",
    "MAPE_std",
    "R2_mean",
    "R2_std",
    "SCPM",
    "Dominated_Count",
    "Dominates_Count",
    "Classification",
    "Plant",
]

# %% [markdown]
# #### SCPM Analysis by Project

# %%
df_sorted_scpm = df_sorted_topo.sort_values(by="SCPM").copy()

# %%
# (df_sorted_topo[cols].reset_index() == df_sorted_scpm[cols].reset_index()).all(axis=1)
df_sorted_scpm["topo_scmp_order_eq"] = df_sorted_topo.index == df_sorted_scpm.index

# %%
df_sorted_scpm[cols + ["topo_scmp_order_eq"]].round(2).head(5)
# Out:
#              Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 4        Transformer_1.0       1.64      0.32      1.26     0.22       2.90
# 0                    MLP       1.63      0.27      1.29     0.20       3.04
# 3             Conv1D_7.0       1.75      0.31      1.40     0.24       3.20
# 2               LSTM_7.0       2.00      0.60      1.48     0.31       3.36
# 1  BidirectionalLSTM_7.0       2.74      1.14      2.03     0.75       4.73
#
#    MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count  Dominates_Count  \
# 4      0.51     0.94    0.02 -3.09                0                3
# 0      0.48     0.94    0.02 -2.84                0                3
# 3      0.52     0.93    0.02 -1.69                2                2
# 2      0.69     0.91    0.06 -0.07                3                1
# 1      1.85     0.81    0.17  7.69                4                0
#
#        Classification Plant  topo_scmp_order_eq
# 4      dominant_model     f               False
# 0      dominant_model     f               False
# 3  intermediate_model     f                True
# 2  intermediate_model     f                True
# 1  non_dominant_model     f                True

# %% [markdown]
# ## Variable Grouping: CM-P-CS

# %% [markdown]
# #### Analysis of the best models identified in the Local Analysis

# %% [markdown]
# **Best models for variable groupping CM-P-CS were from:**
#
# *BTiSS:*
#     Dominance analysis: Plant S and Plant F
#     SCPM: Plant S and Plant F
#
# *TiSS:*
#     Dominance analysis: Plant AB
#     SCPM: Plant AB

# %%
df_results["Features"].unique()
# Out:
# array(['Chemical + Mineralogical', 'Chemical + Mineralogical + Physical',
#        'Chemical + Mineralogical + Physical - Early CS'], dtype=object)

# %% [markdown]
# ### Blocking time series

# %% [markdown]
# ### Plant F

# %%
df_results_cm_p_cs = (
    df_results[df_results["Features"].eq("Chemical + Mineralogical + Physical")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_p_cs["Features"].unique()
# Out:
# array(['Chemical + Mineralogical + Physical'], dtype=object)

# %%
df_results_cm_p_cs.shape
# Out:
# (20, 17)

# %%
df_results_cm_p_cs = df_results_cm_p_cs[
    df_results_cm_p_cs["Plant"].eq("f")
].reset_index(drop=True)

# %%
df_results_cm_p_cs["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split', 'Time Series Split'], dtype=object)

# %%
df_results_cm_p_cs_btss = (
    df_results_cm_p_cs[
        df_results_cm_p_cs["Cross Validation"].eq("Blocking Time Series Split")
    ]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_p_cs_btss["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split'], dtype=object)

# %%
df_results_cm_p_cs_btss.shape
# Out:
# (5, 17)

# %% [markdown]
# ###### SCPM computation

# %%
df_results_cm_p_cs_btss = compute_scpm(df_results_cm_p_cs_btss)

# %% [markdown]
# ##### Dominance Analysis

# %%
# Per project
dominance_dict = make_dominance_analysis(df_results_cm_p_cs_btss)
dominance_matrix_cm_p_cs_btss = dominance_dict["dominance_matrix"]
dominance_graph_cm_p_cs_btss = dominance_dict["dominance_graph"]
df_sorted_count = dominance_dict["df_sorted_count"]
df_sorted_topo = dominance_dict["df_sorted_topo"]

# %%
dominance_matrix_cm_p_cs_btss.shape, len(dominance_graph_cm_p_cs_btss)
# Out:
# ((5, 5), 5)

# %%
df_sorted_topo["Classification"].value_counts()
# Out:
# Classification
# intermediate_model    3
# dominant_model        1
# non_dominant_model    1
# Name: count, dtype: int64

# %%
df_sorted_topo.to_csv(
    "../../../../reports/results/global_models/ecics/ecics_204_f_dominance_analysis_cm_p_cs_btss.csv",
    index=False,
)

# %%
df_sorted_topo.head(5)
# Out:
#    Company Plant            Cross Validation  \
# 0      204     f  Blocking Time Series Split
# 1      204     f  Blocking Time Series Split
# 2      204     f  Blocking Time Series Split
# 4      204     f  Blocking Time Series Split
# 3      204     f  Blocking Time Series Split
#
#                               Features         Features_bkp            Model  \
# 0  Chemical + Mineralogical + Physical  Chemical + Physical  Neural Networks
# 1  Chemical + Mineralogical + Physical  Chemical + Physical           Conv1D
# 2  Chemical + Mineralogical + Physical  Chemical + Physical  Neural Networks
# 4  Chemical + Mineralogical + Physical  Chemical + Physical  Neural Networks
# 3  Chemical + Mineralogical + Physical  Chemical + Physical  Neural Networks
#
#            Model_bkp             Model_bkp_2  Timesteps  RMSE_mean  ...  \
# 0                MLP                     MLP        NaN   1.502942  ...
# 1             Conv1D              Conv1D_7.0        7.0   1.714714  ...
# 2        Transformer         Transformer_1.0        1.0   1.766226  ...
# 4  BidirectionalLSTM  BidirectionalLSTM_14.0       14.0   2.439164  ...
# 3               LSTM                LSTM_7.0        7.0   5.339302  ...
#
#    MAPE_mean   R2_mean  RMSE_std   MAE_std  MAPE_std    R2_std      SCPM  \
# 0   2.717972  0.949657  0.215928  0.182213  0.460453  0.014551 -3.274864
# 1   3.037118  0.922830  0.242213  0.192377  0.374853  0.019652 -2.404062
# 2   2.942542  0.931571  0.176847  0.206168  0.482162  0.012011 -2.617959
# 4   4.040735  0.602610  0.571468  0.432060  0.924047  0.109378  0.889620
# 3   6.174102  0.067397  2.754319  0.804991  1.922409  0.882470  7.407266
#
#    Dominated_Count      Classification Dominates_Count
# 0                0      dominant_model               4
# 1                1  intermediate_model               2
# 2                1  intermediate_model               2
# 4                3  intermediate_model               1
# 3                4  non_dominant_model               0
#
# [5 rows x 21 columns]

# %%
df_sorted_topo_cols = df_sorted_topo[
    [
        # "Model",
        # "Model_bkp",
        "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Classification",
        "Dominates_Count",
        "Plant",
    ]
].round(2)

# %% [markdown]
# ###### Dominant Models

# %%
# Top 4
df_sorted_topo_cols.sort_values(
    by=["Dominates_Count", "SCPM"], ascending=[False, True]
).iloc[:5]
# Out:
#               Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 0                     MLP       1.50      0.22      1.13     0.18       2.72
# 2         Transformer_1.0       1.77      0.18      1.26     0.21       2.94
# 1              Conv1D_7.0       1.71      0.24      1.35     0.19       3.04
# 4  BidirectionalLSTM_14.0       2.44      0.57      1.93     0.43       4.04
# 3                LSTM_7.0       5.34      2.75      2.62     0.80       6.17
#
#    MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 0      0.46     0.95    0.01 -3.27                0      dominant_model
# 2      0.48     0.93    0.01 -2.62                1  intermediate_model
# 1      0.37     0.92    0.02 -2.40                1  intermediate_model
# 4      0.92     0.60    0.11  0.89                3  intermediate_model
# 3      1.92     0.07    0.88  7.41                4  non_dominant_model
#
#    Dominates_Count Plant
# 0                4     f
# 2                2     f
# 1                2     f
# 4                1     f
# 3                0     f

# %%
df_sorted_topo_cols[df_sorted_topo_cols["Classification"].eq("dominant_model")].shape
# Out:
# (1, 14)

# %% [markdown]
# ###### Intermediate models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].sort_values(by=["Dominates_Count", "SCPM"], ascending=[False, True]).iloc[:3]
# Out:
#               Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 2         Transformer_1.0       1.77      0.18      1.26     0.21       2.94
# 1              Conv1D_7.0       1.71      0.24      1.35     0.19       3.04
# 4  BidirectionalLSTM_14.0       2.44      0.57      1.93     0.43       4.04
#
#    MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 2      0.48     0.93    0.01 -2.62                1  intermediate_model
# 1      0.37     0.92    0.02 -2.40                1  intermediate_model
# 4      0.92     0.60    0.11  0.89                3  intermediate_model
#
#    Dominates_Count Plant
# 2                2     f
# 1                2     f
# 4                1     f

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].shape
# Out:
# (3, 14)

# %% [markdown]
# ###### non-dominant models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].sort_values(by=["Dominates_Count", "SCPM"], ascending=[False, True]).iloc[:2]
# Out:
#   Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  MAPE_std  \
# 3    LSTM_7.0       5.34      2.75      2.62      0.8       6.17      1.92
#
#    R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 3     0.07    0.88  7.41                4  non_dominant_model
#
#    Dominates_Count Plant
# 3                0     f

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].shape
# Out:
# (1, 14)

# %% [markdown]
# ###### Statistics per model type

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        # "Model_bkp",
        # "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
        "Plant",
    ]
]  # .round(2)

# %%
df_sorted_topo["Model"].value_counts()
# Out:
# Model
# Neural Networks    4
# Conv1D             1
# Name: count, dtype: int64

# %%
df_sorted_topo_models_grouped = df_sorted_topo_models_cols.groupby("Model").describe().T

# %%
# pd.set_option("display.max_rows", None)
# df_sorted_topo_models_grouped

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
    ]
]

# %%
(
    df_sorted_topo_models_cols.groupby("Model")[["Classification"]]
    .value_counts(normalize=True)
    .to_frame()
    * 100
).round(2)
# Out:
#                                     proportion
# Model           Classification
# Conv1D          intermediate_model       100.0
# Neural Networks intermediate_model        50.0
#                 dominant_model            25.0
#                 non_dominant_model        25.0

# %%
df_sorted_topo_models_cols.groupby("Model").describe().round(2).T
# Out:
# Model                  Conv1D  Neural Networks
# Dominated_Count count     1.0             4.00
#                 mean      1.0             2.00
#                 std       NaN             1.83
#                 min       1.0             0.00
#                 25%       1.0             0.75
#                 50%       1.0             2.00
#                 75%       1.0             3.25
#                 max       1.0             4.00
# Dominates_Count count     1.0             4.00
#                 mean      2.0             1.75
#                 std       NaN             1.71
#                 min       2.0             0.00
#                 25%       2.0             0.75
#                 50%       2.0             1.50
#                 75%       2.0             2.50
#                 max       2.0             4.00

# %%
# df_sorted_topo_models_cols

# %%
df_sorted_topo_models_cols.groupby("Model")["Classification"].describe()
# Out:
#                 count unique                 top freq
# Model
# Conv1D              1      1  intermediate_model    1
# Neural Networks     4      3  intermediate_model    2

# %%
df_sorted_topo_models_cols.groupby("Model")[["Classification"]].value_counts()
# Out:
# Model            Classification
# Conv1D           intermediate_model    1
# Neural Networks  intermediate_model    2
#                  dominant_model        1
#                  non_dominant_model    1
# Name: count, dtype: int64

# %%
# df_sorted_topo_models_cols

# %%
summary_stats = df_sorted_topo_models_cols.groupby("Model").agg(
    Total_Models=("Model", "count"),
    Mean_Dominance_Count=("Dominates_Count", "mean"),
    Median_Dominance_Count=("Dominates_Count", "median"),
    Total_Dominated=("Dominated_Count", "sum"),
    Total_Dominating=("Dominates_Count", "sum"),
)

total_models = summary_stats[
    "Total_Models"
].sum()  # Get the total number of models across all categories
summary_stats["Dominance Proportion"] = summary_stats["Total_Dominating"] / total_models

# %%
summary_stats
# Out:
#                  Total_Models  Mean_Dominance_Count  Median_Dominance_Count  \
# Model
# Conv1D                      1                  2.00                     2.0
# Neural Networks             4                  1.75                     1.5
#
#                  Total_Dominated  Total_Dominating  Dominance Proportion
# Model
# Conv1D                         1                 2                   0.4
# Neural Networks                8                 7                   1.4

# %%
df_sorted_topo_models_grouped.T
# Out:
#                 RMSE_mean                                                    \
#                     count      mean       std       min       25%       50%
# Model
# Conv1D                1.0  1.714714       NaN  1.714714  1.714714  1.714714
# Neural Networks       4.0  2.761909  1.762905  1.502942  1.700405  2.102695
#
#                                     RMSE_std            ... Dominated_Count  \
#                       75%       max    count      mean  ...             75%
# Model                                                   ...
# Conv1D           1.714714  1.714714      1.0  0.242213  ...            1.00
# Neural Networks  3.164199  5.339302      4.0  0.929640  ...            3.25
#
#                      Dominates_Count
#                  max           count  mean       std  min   25%  50%  75%  max
# Model
# Conv1D           1.0             1.0  2.00       NaN  2.0  2.00  2.0  2.0  2.0
# Neural Networks  4.0             4.0  1.75  1.707825  0.0  0.75  1.5  2.5  4.0
#
# [2 rows x 88 columns]

# %% [markdown]
# ### SCPM Analysis

# %%
cols = [
    # "Model",
    # "Model_bkp",
    "Model_bkp_2",
    "RMSE_mean",
    "RMSE_std",
    "MAE_mean",
    "MAE_std",
    "MAPE_mean",
    "MAPE_std",
    "R2_mean",
    "R2_std",
    "SCPM",
    "Dominated_Count",
    "Dominates_Count",
    "Classification",
    "Plant",
]

# %% [markdown]
# #### SCPM Analysis by Project

# %%
df_sorted_scpm = df_sorted_topo.sort_values(by="SCPM").copy()

# %%
# (df_sorted_topo[cols].reset_index() == df_sorted_scpm[cols].reset_index()).all(axis=1)
df_sorted_scpm["topo_scmp_order_eq"] = df_sorted_topo.index == df_sorted_scpm.index

# %%
df_sorted_scpm[cols + ["topo_scmp_order_eq"]].round(2).head(5)
# Out:
#               Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 0                     MLP       1.50      0.22      1.13     0.18       2.72
# 2         Transformer_1.0       1.77      0.18      1.26     0.21       2.94
# 1              Conv1D_7.0       1.71      0.24      1.35     0.19       3.04
# 4  BidirectionalLSTM_14.0       2.44      0.57      1.93     0.43       4.04
# 3                LSTM_7.0       5.34      2.75      2.62     0.80       6.17
#
#    MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count  Dominates_Count  \
# 0      0.46     0.95    0.01 -3.27                0                4
# 2      0.48     0.93    0.01 -2.62                1                2
# 1      0.37     0.92    0.02 -2.40                1                2
# 4      0.92     0.60    0.11  0.89                3                1
# 3      1.92     0.07    0.88  7.41                4                0
#
#        Classification Plant  topo_scmp_order_eq
# 0      dominant_model     f                True
# 2  intermediate_model     f               False
# 1  intermediate_model     f               False
# 4  intermediate_model     f                True
# 3  non_dominant_model     f                True

# %% [markdown]
# ### Time Series Split

# %%
df_results_cm_p_cs = (
    df_results[df_results["Features"].eq("Chemical + Mineralogical + Physical")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_p_cs["Features"].unique()
# Out:
# array(['Chemical + Mineralogical + Physical'], dtype=object)

# %%
df_results_cm_p_cs.shape
# Out:
# (20, 17)

# %% [markdown]
# ### Plant AB

# %%
df_results_cm_p_cs = df_results_cm_p_cs[
    df_results_cm_p_cs["Plant"].eq("ab")
].reset_index(drop=True)

# %%
df_results_cm_p_cs["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split', 'Time Series Split'], dtype=object)

# %%
df_results_cm_p_cs_tss = (
    df_results_cm_p_cs[df_results_cm_p_cs["Cross Validation"].eq("Time Series Split")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_p_cs_tss["Cross Validation"].unique()
# Out:
# array(['Time Series Split'], dtype=object)

# %%
df_results_cm_p_cs_tss.shape
# Out:
# (5, 17)

# %% [markdown]
# ###### SCPM computation

# %%
df_results_cm_p_cs_tss = compute_scpm(df_results_cm_p_cs_tss)

# %% [markdown]
# ##### Dominance Analysis

# %%
# Per project
dominance_dict = make_dominance_analysis(df_results_cm_p_cs_tss)
dominance_matrix_cm_p_cs_tss = dominance_dict["dominance_matrix"]
dominance_graph_cm_p_cs_tss = dominance_dict["dominance_graph"]
df_sorted_count = dominance_dict["df_sorted_count"]
df_sorted_topo = dominance_dict["df_sorted_topo"]

# %%
dominance_matrix_cm_p_cs_tss.shape, len(dominance_graph_cm_p_cs_tss)
# Out:
# ((5, 5), 5)

# %%
df_sorted_topo["Classification"].value_counts()
# Out:
# Classification
# intermediate_model    3
# dominant_model        1
# non_dominant_model    1
# Name: count, dtype: int64

# %%
df_sorted_topo.to_csv(
    "../../../../reports/results/global_models/ecics/ecics_204_ab_dominance_analysis_cm_p_cs_tss.csv",
    index=False,
)

# %%
df_sorted_topo.head(5)
# Out:
#    Company Plant   Cross Validation                             Features  \
# 0      204    ab  Time Series Split  Chemical + Mineralogical + Physical
# 4      204    ab  Time Series Split  Chemical + Mineralogical + Physical
# 1      204    ab  Time Series Split  Chemical + Mineralogical + Physical
# 2      204    ab  Time Series Split  Chemical + Mineralogical + Physical
# 3      204    ab  Time Series Split  Chemical + Mineralogical + Physical
#
#           Features_bkp            Model          Model_bkp  \
# 0  Chemical + Physical  Neural Networks                MLP
# 4  Chemical + Physical  Neural Networks  BidirectionalLSTM
# 1  Chemical + Physical           Conv1D             Conv1D
# 2  Chemical + Physical  Neural Networks        Transformer
# 3  Chemical + Physical  Neural Networks               LSTM
#
#              Model_bkp_2  Timesteps  RMSE_mean  ...  MAPE_mean   R2_mean  \
# 0                    MLP        NaN   1.497268  ...   2.566292  0.944029
# 4  BidirectionalLSTM_1.0        1.0   1.561617  ...   2.644962  0.939912
# 1             Conv1D_1.0        1.0   1.579179  ...   2.767337  0.938225
# 2        Transformer_1.0        1.0   2.268476  ...   4.096342  0.871134
# 3               LSTM_7.0        7.0   3.140499  ...   5.315326  0.730408
#
#    RMSE_std   MAE_std  MAPE_std    R2_std      SCPM  Dominated_Count  \
# 0  0.449835  0.310156  0.577409  0.024374 -3.221203                0
# 4  0.287390  0.183725  0.309271  0.011093 -2.910494                1
# 1  0.376308  0.246950  0.450952  0.018989 -2.676357                2
# 2  0.402272  0.376864  0.880983  0.033584  1.698707                3
# 3  1.621540  1.149827  2.237891  0.243026  7.109347                4
#
#        Classification Dominates_Count
# 0      dominant_model               4
# 4  intermediate_model               3
# 1  intermediate_model               2
# 2  intermediate_model               1
# 3  non_dominant_model               0
#
# [5 rows x 21 columns]

# %%
df_sorted_topo_cols = df_sorted_topo[
    [
        # "Model",
        # "Model_bkp",
        "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Classification",
        "Dominates_Count",
        "Plant",
    ]
]  # .round(2)

# %% [markdown]
# ###### Dominant Models

# %%
# Top 4
df_sorted_topo_cols.iloc[0:2].sort_values(by="Dominates_Count", ascending=False).round(
    2
)
# Out:
#              Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 0                    MLP       1.50      0.45      1.15     0.31       2.57
# 4  BidirectionalLSTM_1.0       1.56      0.29      1.20     0.18       2.64
#
#    MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 0      0.58     0.94    0.02 -3.22                0      dominant_model
# 4      0.31     0.94    0.01 -2.91                1  intermediate_model
#
#    Dominates_Count Plant
# 0                4    ab
# 4                3    ab

# %%
df_sorted_topo_cols[df_sorted_topo_cols["Classification"].eq("dominant_model")].shape
# Out:
# (1, 14)

# %% [markdown]
# ###### Intermediate models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].sort_values(by=["Dominates_Count", "SCPM"], ascending=[False, True]).iloc[:4].round(2)
# Out:
#              Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 4  BidirectionalLSTM_1.0       1.56      0.29      1.20     0.18       2.64
# 1             Conv1D_1.0       1.58      0.38      1.23     0.25       2.77
# 2        Transformer_1.0       2.27      0.40      1.82     0.38       4.10
#
#    MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 4      0.31     0.94    0.01 -2.91                1  intermediate_model
# 1      0.45     0.94    0.02 -2.68                2  intermediate_model
# 2      0.88     0.87    0.03  1.70                3  intermediate_model
#
#    Dominates_Count Plant
# 4                3    ab
# 1                2    ab
# 2                1    ab

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].shape
# Out:
# (3, 14)

# %% [markdown]
# ###### non-dominant models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].sort_values(by=["Dominates_Count", "SCPM"], ascending=[False, True]).iloc[:3]
# Out:
#   Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean   MAE_std  MAPE_mean  MAPE_std  \
# 3    LSTM_7.0   3.140499   1.62154  2.385823  1.149827   5.315326  2.237891
#
#     R2_mean    R2_std      SCPM  Dominated_Count      Classification  \
# 3  0.730408  0.243026  7.109347                4  non_dominant_model
#
#    Dominates_Count Plant
# 3                0    ab

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].shape
# Out:
# (1, 14)

# %% [markdown]
# ###### Statistics per model type

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        # "Model_bkp",
        # "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
        "Plant",
    ]
]  # .round(2)

# %%
df_sorted_topo["Model"].value_counts()
# Out:
# Model
# Neural Networks    4
# Conv1D             1
# Name: count, dtype: int64

# %%
df_sorted_topo_models_grouped = df_sorted_topo_models_cols.groupby("Model").describe().T

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
    ]
]

# %%
(
    df_sorted_topo_models_cols.groupby("Model")[["Classification"]]
    .value_counts(normalize=True)
    .to_frame()
    * 100
).round(2)
# Out:
#                                     proportion
# Model           Classification
# Conv1D          intermediate_model       100.0
# Neural Networks intermediate_model        50.0
#                 dominant_model            25.0
#                 non_dominant_model        25.0

# %%
df_sorted_topo_models_cols.groupby("Model").describe().round(2).T
# Out:
# Model                  Conv1D  Neural Networks
# Dominated_Count count     1.0             4.00
#                 mean      2.0             2.00
#                 std       NaN             1.83
#                 min       2.0             0.00
#                 25%       2.0             0.75
#                 50%       2.0             2.00
#                 75%       2.0             3.25
#                 max       2.0             4.00
# Dominates_Count count     1.0             4.00
#                 mean      2.0             2.00
#                 std       NaN             1.83
#                 min       2.0             0.00
#                 25%       2.0             0.75
#                 50%       2.0             2.00
#                 75%       2.0             3.25
#                 max       2.0             4.00

# %%
# df_sorted_topo_models_cols

# %%
df_sorted_topo_models_cols.groupby("Model")["Classification"].describe()
# Out:
#                 count unique                 top freq
# Model
# Conv1D              1      1  intermediate_model    1
# Neural Networks     4      3  intermediate_model    2

# %%
df_sorted_topo_models_cols.groupby("Model")[["Classification"]].value_counts()
# Out:
# Model            Classification
# Conv1D           intermediate_model    1
# Neural Networks  intermediate_model    2
#                  dominant_model        1
#                  non_dominant_model    1
# Name: count, dtype: int64

# %%
summary_stats = df_sorted_topo_models_cols.groupby("Model").agg(
    Total_Models=("Model", "count"),
    Mean_Dominance_Count=("Dominates_Count", "mean"),
    Median_Dominance_Count=("Dominates_Count", "median"),
    Total_Dominated=("Dominated_Count", "sum"),
    Total_Dominating=("Dominates_Count", "sum"),
)

total_models = summary_stats[
    "Total_Models"
].sum()  # Get the total number of models across all categories
summary_stats["Dominance Proportion"] = summary_stats["Total_Dominating"] / total_models

# %%
summary_stats.round(2)
# Out:
#                  Total_Models  Mean_Dominance_Count  Median_Dominance_Count  \
# Model
# Conv1D                      1                   2.0                     2.0
# Neural Networks             4                   2.0                     2.0
#
#                  Total_Dominated  Total_Dominating  Dominance Proportion
# Model
# Conv1D                         2                 2                   0.4
# Neural Networks                8                 8                   1.6

# %%
df_sorted_topo_models_grouped.T
# Out:
#                 RMSE_mean                                                    \
#                     count      mean       std       min       25%       50%
# Model
# Conv1D                1.0  1.579179       NaN  1.579179  1.579179  1.579179
# Neural Networks       4.0  2.116965  0.766597  1.497268  1.545530  1.915047
#
#                                     RMSE_std            ... Dominated_Count  \
#                       75%       max    count      mean  ...             75%
# Model                                                   ...
# Conv1D           1.579179  1.579179      1.0  0.376308  ...            2.00
# Neural Networks  2.486482  3.140499      4.0  0.690260  ...            3.25
#
#                      Dominates_Count
#                  max           count mean       std  min   25%  50%   75%  max
# Model
# Conv1D           2.0             1.0  2.0       NaN  2.0  2.00  2.0  2.00  2.0
# Neural Networks  4.0             4.0  2.0  1.825742  0.0  0.75  2.0  3.25  4.0
#
# [2 rows x 88 columns]

# %% [markdown]
# ### SCPM Analysis

# %%
cols = [
    # "Model",
    # "Model_bkp",
    "Model_bkp_2",
    "RMSE_mean",
    "RMSE_std",
    "MAE_mean",
    "MAE_std",
    "MAPE_mean",
    "MAPE_std",
    "R2_mean",
    "R2_std",
    "SCPM",
    "Dominated_Count",
    "Dominates_Count",
    "Classification",
    "Plant",
]

# %% [markdown]
# #### SCPM Analysis by Project

# %%
df_sorted_scpm = df_sorted_topo.sort_values(by="SCPM").copy()

# %%
# (df_sorted_topo[cols].reset_index() == df_sorted_scpm[cols].reset_index()).all(axis=1)
df_sorted_scpm["topo_scmp_order_eq"] = df_sorted_topo.index == df_sorted_scpm.index

# %%
df_sorted_scpm[cols + ["topo_scmp_order_eq"]].round(2).head(5)
# Out:
#              Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 0                    MLP       1.50      0.45      1.15     0.31       2.57
# 4  BidirectionalLSTM_1.0       1.56      0.29      1.20     0.18       2.64
# 1             Conv1D_1.0       1.58      0.38      1.23     0.25       2.77
# 2        Transformer_1.0       2.27      0.40      1.82     0.38       4.10
# 3               LSTM_7.0       3.14      1.62      2.39     1.15       5.32
#
#    MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count  Dominates_Count  \
# 0      0.58     0.94    0.02 -3.22                0                4
# 4      0.31     0.94    0.01 -2.91                1                3
# 1      0.45     0.94    0.02 -2.68                2                2
# 2      0.88     0.87    0.03  1.70                3                1
# 3      2.24     0.73    0.24  7.11                4                0
#
#        Classification Plant  topo_scmp_order_eq
# 0      dominant_model    ab                True
# 4  intermediate_model    ab                True
# 1  intermediate_model    ab                True
# 2  intermediate_model    ab                True
# 3  non_dominant_model    ab                True
