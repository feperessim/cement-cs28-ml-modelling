# %%
# %load_ext nb_black

# %%
import pandas as pd
import os
import glob
import numpy as np

# %%
import warnings

# Suppress specific FutureWarning
warnings.filterwarnings("ignore", category=FutureWarning, module="seaborn._oldcore")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.preprocessing import StandardScaler

# %%
from collections import deque, defaultdict

# %%
def read_csv_files_grouped(csv_files, plant, header=[0, 1]):
    results = []
    for filepath in csv_files:
        df = pd.read_csv(filepath, header=header, low_memory=False)
        df["plant"] = plant  # Add the 'plant' column
        results.append(df)
    df = pd.concat(results, ignore_index=True)
    return df

# %%
def read_csv_files_full(csv_files, plant):
    results = []
    for filepath in csv_files:
        df = pd.read_csv(filepath, low_memory=False)
        df["plant"] = plant  # Add the 'plant' column
        results.append(df)
    df = pd.concat(results, ignore_index=True)
    return df

# %% [markdown]
# ### Renaming the Columns

# %%
def preprocess_rename_columns(df):
    df.columns = pd.MultiIndex.from_tuples(
        list(
            {
                col: (col[0], "") if "Unnamed" in col[1] else col for col in df.columns
            }.values()
        )
    )
    return df

# %% [markdown]
# ### Changing the order_of columns Columns

# %%
def preprocess_change_columns_order(df, column, pos):
    # Get the list of columns
    cols = df.columns.tolist()
    # Remove the specified column
    cols.remove(column)
    # Insert the column at the desired position
    cols.insert(pos, column)
    # Reorder the DataFrame columns
    return df[cols]

# %%
def read_csv_files_path(csv_files_path_dict, path, plant):
    csv_files = glob.glob(os.path.join(path, "*.csv"))
    csv_files_path_dict[plant] = csv_files
    return csv_files_path_dict

# %% [markdown]
# # Topological Analysis - NEW

# %% [markdown]
# ## Definitions

# %%
# Function to compare two models strictly based on means only
def dominates(model1, model2):
    """Return True if model1 strictly dominates model2, False otherwise."""
    # Check if model1 is at least as good as model2 in all metrics
    at_least_as_good = (
        model1["RMSE_mean"] <= model2["RMSE_mean"]
        and model1["MAE_mean"] <= model2["MAE_mean"]
        and model1["MAPE_mean"] <= model2["MAPE_mean"]
        and model1["R2_mean"] >= model2["R2_mean"]
    )

    # Check if model1 is strictly better in at least one metric
    strictly_better_in_one = (
        model1["RMSE_mean"] < model2["RMSE_mean"]
        or model1["MAE_mean"] < model2["MAE_mean"]
        or model1["MAPE_mean"] < model2["MAPE_mean"]
        or model1["R2_mean"] > model2["R2_mean"]
    )

    # Model1 strictly dominates Model2 if it is at least as good in all metrics and
    # strictly better in at least one metric
    return at_least_as_good and strictly_better_in_one

# %%
def get_dominance_matrix_and_graph(df):
    n = len(df)
    dominance_matrix = np.zeros((n, n), dtype=bool)

    for i in range(n):
        for j in range(n):
            if i != j:
                dominance_matrix[i, j] = dominates(df.iloc[i], df.iloc[j])

    # Create the dominance graph
    dominance_graph = {i: [] for i in range(n)}
    for i in range(n):
        for j in range(n):
            if dominance_matrix[i, j]:
                dominance_graph[i].append(j)

    return dominance_matrix, dominance_graph

# %%
# Topological Sorting
def topological_sort(graph):
    """Perform topological sorting on the given graph."""
    in_degree = {u: 0 for u in graph}
    for u in graph:
        for v in graph[u]:
            in_degree[v] += 1

    queue = deque([u for u in graph if in_degree[u] == 0])
    topo_order = []

    while queue:
        u = queue.popleft()
        topo_order.append(u)

        for v in graph[u]:
            in_degree[v] -= 1
            if in_degree[v] == 0:
                queue.append(v)

    return topo_order

# %%
# Function to find the top models in each group
def find_top_models(group):
    max_net_dominance = group["Net_Dominance"].max()
    top_models = group[group["Net_Dominance"] == max_net_dominance]
    return top_models

# %% [markdown]
# ### Dominance Analysis and SCPM

# %%
def compute_scpm(df):
    scaler = StandardScaler()
    standardized_metrics = scaler.fit_transform(
        df[["RMSE_mean", "MAE_mean", "MAPE_mean", "R2_mean"]]
    )

    # Creating a new dataframe with standardized values
    standardized_df = pd.DataFrame(
        standardized_metrics,
        columns=["RMSE_mean", "MAE_mean", "MAPE_mean", "R2_mean"],
    )

    # Summing all metrics and subtracting R2_mean
    standardized_df["Result"] = (
        standardized_df[["RMSE_mean", "MAE_mean", "MAPE_mean"]].sum(axis=1)
        - standardized_df["R2_mean"]
    )

    df["SCPM"] = standardized_df["Result"]
    return df

# %%
def make_dominance_analysis(df):
    # Compute dominance matrix and graph
    dominance_matrix, dominance_graph = get_dominance_matrix_and_graph(df)

    # Get the topological order
    topo_order = topological_sort(dominance_graph)
    df = df.copy()
    n = len(topo_order)

    # Identify Dominant Models
    dominant_models = [
        df["Model_bkp_2"].iloc[i]
        for i in range(len(df))
        if not np.any(dominance_matrix[:, i])
    ]

    # Identify Non-Dominant Models
    non_dominant_models = [
        df["Model_bkp_2"].iloc[i]
        for i in range(len(df))
        if np.any(dominance_matrix[:, i])
    ]

    # Identify Models that are both dominated and dominate at least one
    intermediate_models = [
        df["Model_bkp_2"].iloc[i]
        for i in range(len(df))
        if np.any(dominance_matrix[:, i]) and np.any(dominance_matrix[i, :])
    ]

    # Add count of times each model is dominated by others
    df["Dominated_Count"] = np.sum(dominance_matrix, axis=0)

    # Classify models
    df["Classification"] = "intermediate_model"  # default to intermediate_model
    df.loc[
        ~np.any(dominance_matrix, axis=1) & np.any(dominance_matrix, axis=0),
        "Classification",
    ] = "non_dominant_model"
    df.loc[~np.any(dominance_matrix, axis=0), "Classification"] = "dominant_model"

    # Map the topological order to the model names and get dominance counts
    sorted_models = [df["Model"].iloc[i] for i in topo_order]

    df_sorted = df.iloc[topo_order].copy()
    df_sorted["Dominates_Count"] = dominance_matrix.sum(axis=1)[topo_order]
    df_sorted_topo = df_sorted.copy()

    df_sorted = df_sorted.sort_values(by="Dominates_Count", ascending=False)
    df_sorted_count = df_sorted.copy()

    return {
        "dominance_matrix": dominance_matrix,
        "dominance_graph": dominance_graph,
        "df_sorted_topo": df_sorted_topo,
        "df_sorted_count": df_sorted_count,
    }

# %% [markdown]
# # Pre Training Analysis

# %% [markdown]
# # Reading The files

# %%
csv_files_path_fine_tuning = dict()
csv_files_path_pre_train = dict()

# %% [markdown]
# ## 209

# %% [markdown]
# ### Plant S

# %%
path_pre_train = "/home/peressim/projects/ccs28-ml-modelling/reports/results/global_models/209/s/pre_training/full/"
plant = "s"

csv_files_path_pre_train = read_csv_files_path(
    csv_files_path_pre_train, path_pre_train, plant
)

# %% [markdown]
# ### Plant AM

# %%
path_pre_train = "/home/peressim/projects/ccs28-ml-modelling/reports/results/global_models/209/am/pre_training/full/"
plant = "am"

csv_files_path_pre_train = read_csv_files_path(
    csv_files_path_pre_train, path_pre_train, plant
)

# %% [markdown]
# ### Plant W

# %%
path_pre_train = "/home/peressim/projects/ccs28-ml-modelling/reports/results/global_models/209/w/pre_training/full/"
plant = "w"

csv_files_path_pre_train = read_csv_files_path(
    csv_files_path_pre_train, path_pre_train, plant
)

# %% [markdown]
# ### Plant K

# %%
path_pre_train = "/home/peressim/projects/ccs28-ml-modelling/reports/results/global_models/209/k/pre_training/full/"
plant = "k"

csv_files_path_pre_train = read_csv_files_path(
    csv_files_path_pre_train, path_pre_train, plant
)

# %% [markdown]
# ### Reading all data - pre training

# %% [markdown]
# #### Full

# %%
dfs_plant = dict()
column = ("plant", "")
pos = 2

for plant, csv_files in csv_files_path_pre_train.items():
    df = read_csv_files_full(csv_files, plant)
    df["plant"] = plant
    dfs_plant[plant] = df

# %%
df_pre_train = pd.concat(dfs_plant.values(), ignore_index=True)

# %%
df_pre_train.shape
# Out:
# (511, 23)

# %% [markdown]
# ## Preprocessing

# %%
patterns = [
    "Chemical + Mineralogical + Feature Engineering",
    "Chemical + Mineralogical + CS7 + One-Hot",
    "Chemical + Mineralogical + Physical + One-Hot",
    "Chemical + Mineralogical + CS3 + One-Hot",
    "Chemical + Mineralogical + CS3 + CS7 + One-Hot",
    "Chemical + Mineralogical + One-Hot",
    "Chemical + Mineralogical + CS1 + CS3 + CS7 + One-Hot",
    "Chemical + Mineralogical + CS1 + CS3 + One-Hot",
    "Chemical + Mineralogical + CS1 + One-Hot",
    "Chemical + Mineralogical + CS2 + One-Hot",
    "Chemical + Feature Engineering",
]

FEATURES_TO_REPLACE_1 = {
    "Chemical + Mineralogical + CS3 + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS3": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS1": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS1 + CS3": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS1 + CS3 + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS2": "Chemical + Mineralogical + Early CS",
    "Chemical + CS1 + CS3 + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + CS3 + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + CS3": "Chemical + Mineralogical + Early CS",
    "Chemical + CS1 + CS3": "Chemical + Mineralogical + Early CS",
    "Chemical + CS1": "Chemical + Mineralogical + Early CS",
    "Chemical + CS1 + CS7": "Chemical + Mineralogical + Early CS",
}

FEATURES_TO_REPLACE_2 = {
    "Chemical": "Chemical + Mineralogical",
    "Chemical + Properties CS Less": "Chemical + Mineralogical + Physical - Early CS",
    "Chemical + Mineralogical + Properties CS Less": "Chemical + Mineralogical + Physical - Early CS",
    "Chemical + Physical": "Chemical + Mineralogical + Physical",
}

df_pre_train = df_pre_train[
    ~df_pre_train["Features"].apply(lambda x: x in patterns)
].reset_index(drop=True)

df_pre_train = df_pre_train[
    ~df_pre_train["Cross Validation"].eq("Out of time Split")
].reset_index(drop=True)

# removing afterwards
df_pre_train = df_pre_train[
    ~df_pre_train["Cross Validation"].eq("Repeated KFold")
].reset_index(drop=True)

df_pre_train["Features_bkp"] = df_pre_train["Features"].copy()
df_pre_train["Features"] = df_pre_train["Features"].replace(FEATURES_TO_REPLACE_1)

df_pre_train["Features"] = df_pre_train["Features"].replace(FEATURES_TO_REPLACE_2)


# removing afterwards
# df_pre_train = df_pre_train[
#     ~df_pre_train["Features"].eq("Chemical + Mineralogical + Early CS")
# ].reset_index(drop=True)

metrics_names = {
    "RMSE Test": "RMSE_mean",
    "MAE Test": "MAE_mean",
    "MAPE Test": "MAPE_mean",
    "R2 Test": "R2_mean",
}

df_pre_train = df_pre_train.rename(metrics_names, axis=1)

# %%
df_pre_train["Features"].unique()
# Out:
# array(['Chemical + Mineralogical + Physical', 'Chemical + Mineralogical',
#        'Chemical + Mineralogical + Physical - Early CS'], dtype=object)

# %%
df_pre_train["MAPE Train"] = df_pre_train["MAPE Train"] * 100
df_pre_train["MAPE_mean"] = df_pre_train["MAPE_mean"] * 100

df_pre_train["Model_bkp"] = df_pre_train["Model"].copy()
df_pre_train["Model_bkp_2"] = df_pre_train["Model"].apply(
    lambda x: "" if pd.isna(x) else "_" + str(x)
)

# %%
df_pre_train["Model_bkp_2"] = df_pre_train["Model_bkp_2"].apply(
    lambda x: "MLP"
    if "MLP" in x
    else "Bi-LSTM"
    if "Bi-LSTM" in x
    else "LSTM"
    if "LSTM" in x
    else "Conv1D"
    if "Conv1D" in x
    else "Transformer"
)

# %%
df_pre_train["Cross Validation"].unique()
# Out:
# array(['Out of time'], dtype=object)

# %%
df_pre_train["Features"].unique()
# Out:
# array(['Chemical + Mineralogical + Physical', 'Chemical + Mineralogical',
#        'Chemical + Mineralogical + Physical - Early CS'], dtype=object)

# %%
df_pre_train["Features_bkp"].unique()
# Out:
# array(['Chemical + Physical', 'Chemical', 'Chemical + Properties CS Less'],
#       dtype=object)

# %%
df_pre_train.shape
# Out:
# (511, 26)

# %%
df_pre_train["Features"].unique()
# Out:
# array(['Chemical + Mineralogical + Physical', 'Chemical + Mineralogical',
#        'Chemical + Mineralogical + Physical - Early CS'], dtype=object)

# %%
df_results_cm = (
    df_pre_train[df_pre_train["Features"].eq("Chemical + Mineralogical")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm["Features"].unique()
# Out:
# array(['Chemical + Mineralogical'], dtype=object)

# %%
df_results_cm.shape
# Out:
# (146, 26)

# %% [markdown]
# # Global Analysis (pre train results)

# %% [markdown]
# ## ECICS

# %% [markdown]
# ### Variable Grouping: CM

# %% [markdown]
# #### Analysis of the best models identified in the Local Analysis

# %% [markdown]
# **Best models for variable groupping CM were from:**
#
# *BTiSS:*
#     Dominance analysis: Plant S
#     SCPM:Plant S
#
# *TiSS:*
#     Dominance analysis: Plant S
#     SCPM:Plant S

# %% [markdown]
# #### Hold Out

# %%
df_results_cm = df_results_cm[df_results_cm["Plant"].eq("S")].reset_index(drop=True)

# %%
df_results_cm["Cross Validation"].unique()
# Out:
# array(['Out of time'], dtype=object)

# %%
df_results_cm_ho = (
    df_results_cm[df_results_cm["Cross Validation"].eq("Out of time")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_ho["Cross Validation"].unique()
# Out:
# array(['Out of time'], dtype=object)

# %%
df_results_cm_ho.shape
# Out:
# (73, 26)

# %% [markdown]
# ###### SCPM computation

# %%
df_results_cm_ho = compute_scpm(df_results_cm_ho)

# %% [markdown]
# ##### Dominance Analysis

# %%
dominance_dict = make_dominance_analysis(df_results_cm_ho)
dominance_matrix_cm_ho = dominance_dict["dominance_matrix"]
dominance_graph_cm_ho = dominance_dict["dominance_graph"]
df_sorted_count = dominance_dict["df_sorted_count"]
df_sorted_topo = dominance_dict["df_sorted_topo"]

# %%
dominance_matrix_cm_ho.shape, len(dominance_graph_cm_ho)
# Out:
# ((73, 73), 73)

# %%
df_sorted_topo["Classification"].value_counts()
# Out:
# Classification
# intermediate_model    69
# dominant_model         3
# non_dominant_model     1
# Name: count, dtype: int64

# %%
# df_sorted_topo.to_csv(
#     "../../../../reports/results/local_models/ecics/209_dominance_analysis_cm_kf.csv",
#     index=False,
# )

# %%
df_sorted_topo.head(5)
# Out:
#         Category  Company Plant                  Features   Data Shape  \
# 10  Global Model      209     S  Chemical + Mineralogical  (61946, 11)
# 18  Global Model      209     S  Chemical + Mineralogical  (61946, 11)
# 32  Global Model      209     S  Chemical + Mineralogical  (61946, 11)
# 5   Global Model      209     S  Chemical + Mineralogical  (61946, 11)
# 20  Global Model      209     S  Chemical + Mineralogical  (61946, 11)
#
#     Timesteps     Model  Model Params           Scaler  Scaler Params  ...  \
# 10        NaN    MLP_11           NaN  Standard Scaler            NaN  ...
# 18       14.0     LSTM6           NaN  Standard Scaler            NaN  ...
# 32        7.0  Bi-LSTM5           NaN  Standard Scaler            NaN  ...
# 5         NaN     MLP_6           NaN  Standard Scaler            NaN  ...
# 20        7.0     LSTM8           NaN  Standard Scaler            NaN  ...
#
#    MAPE_mean   R2_mean plant Features_bkp  Model_bkp  Model_bkp_2      SCPM  \
# 10  4.429864  0.811351     s     Chemical     MLP_11          MLP -3.903728
# 18  4.398563  0.828245     s     Chemical      LSTM6         LSTM -4.529758
# 32  4.339890  0.824900     s     Chemical   Bi-LSTM5      Bi-LSTM -4.507755
# 5   4.495524  0.802212     s     Chemical      MLP_6          MLP -3.341270
# 20  4.467514  0.814660     s     Chemical      LSTM8         LSTM -3.812872
#
#     Dominated_Count      Classification  Dominates_Count
# 10                0      dominant_model               59
# 18                0      dominant_model               70
# 32                0      dominant_model               70
# 5                 3  intermediate_model               54
# 20                2  intermediate_model               59
#
# [5 rows x 30 columns]

# %%
df_sorted_topo_cols = df_sorted_topo[
    [
        "Model",
        # "Model_bkp",
        # "Model_bkp_2",
        "Timesteps",
        "RMSE_mean",
        "MAE_mean",
        "MAPE_mean",
        "R2_mean",
        "SCPM",
        "Dominated_Count",
        "Classification",
        "Dominates_Count",
        "Plant",
    ]
].round(2)

# %% [markdown]
# ##### Top dominant models

# %%
# Top 4
df_sorted_topo_cols.sort_values(by="Dominates_Count", ascending=False).iloc[0:3]
# Out:
#        Model  Timesteps  RMSE_mean  MAE_mean  MAPE_mean  R2_mean  SCPM  \
# 32  Bi-LSTM5        7.0       2.51      1.87       4.34     0.82 -4.51
# 18     LSTM6       14.0       2.49      1.88       4.40     0.83 -4.53
# 21     LSTM9       14.0       2.51      1.92       4.54     0.82 -4.03
#
#     Dominated_Count      Classification  Dominates_Count Plant
# 32                0      dominant_model               70     S
# 18                0      dominant_model               70     S
# 21                2  intermediate_model               66     S

# %% [markdown]
# ##### Top intermediate models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].sort_values(by="Dominates_Count", ascending=False).iloc[:2]
# Out:
#         Model  Timesteps  RMSE_mean  MAE_mean  MAPE_mean  R2_mean  SCPM  \
# 21      LSTM9       14.0       2.51      1.92       4.54     0.82 -4.03
# 41  Bi-LSTM14        7.0       2.53      1.94       4.56     0.82 -3.83
#
#     Dominated_Count      Classification  Dominates_Count Plant
# 21                2  intermediate_model               66     S
# 41                3  intermediate_model               61     S

# %% [markdown]
# ##### Top non dominant models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].sort_values(by="Dominated_Count", ascending=True).iloc[:2]
# Out:
#         Model  Timesteps  RMSE_mean  MAE_mean  MAPE_mean  R2_mean   SCPM  \
# 39  Bi-LSTM12       14.0       4.58      3.71       8.36     0.42  20.89
#
#     Dominated_Count      Classification  Dominates_Count Plant
# 39               72  non_dominant_model                0     S

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        # "Model",
        # "Model_bkp",
        "Model_bkp_2",
        "Timesteps",
        "RMSE_mean",
        "MAE_mean",
        "MAPE_mean",
        "R2_mean",
        "SCPM",
        "Dominated_Count",
        "Classification",
        "Dominates_Count",
        "Plant",
    ]
]  # .round(2)

# %%
df_sorted_topo["Model_bkp_2"].value_counts()
# Out:
# Model_bkp_2
# LSTM           15
# Bi-LSTM        15
# Conv1D         15
# Transformer    15
# MLP            13
# Name: count, dtype: int64

# %%
df_sorted_topo_models_grouped = (
    df_sorted_topo_models_cols.groupby("Model_bkp_2").describe().T
)

# %%
# pd.set_option("display.max_rows", None)
# df_sorted_topo_models_grouped

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model_bkp_2",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
    ]
]

# %%
df_sorted_topo_models_cols.groupby("Model_bkp_2").describe().round(2)
# Out:
#             Dominated_Count                                              \
#                       count   mean    std   min   25%   50%   75%   max
# Model_bkp_2
# Bi-LSTM                15.0  29.20  26.38   0.0   4.5  17.0  53.0  72.0
# Conv1D                 15.0  28.67  14.90   6.0  18.0  27.0  41.5  47.0
# LSTM                   15.0  25.53  22.35   0.0   3.5  24.0  44.0  61.0
# MLP                    13.0  16.77  10.98   0.0   7.0  18.0  22.0  36.0
# Transformer            15.0  56.20   9.38  38.0  51.5  57.0  62.5  70.0
#
#             Dominates_Count
#                       count   mean    std   min   25%   50%   75%   max
# Model_bkp_2
# Bi-LSTM                15.0  35.60  23.92   0.0  16.0  44.0  56.5  70.0
# Conv1D                 15.0  34.60  10.95  21.0  26.0  30.0  44.5  52.0
# LSTM                   15.0  38.00  21.35   5.0  23.0  38.0  55.0  70.0
# MLP                    13.0  42.23   9.09  27.0  38.0  38.0  50.0  59.0
# Transformer            15.0   9.33   7.76   1.0   3.5   8.0  12.0  27.0

# %%
df_sorted_topo_models_cols.groupby("Model_bkp_2")["Classification"].describe()
# Out:
#             count unique                 top freq
# Model_bkp_2
# Bi-LSTM        15      3  intermediate_model   13
# Conv1D         15      1  intermediate_model   15
# LSTM           15      2  intermediate_model   14
# MLP            13      2  intermediate_model   12
# Transformer    15      1  intermediate_model   15

# %%
df_sorted_topo_models_cols.groupby("Model_bkp_2")[["Classification"]].value_counts()
# Out:
# Model_bkp_2  Classification
# Bi-LSTM      intermediate_model    13
#              dominant_model         1
#              non_dominant_model     1
# Conv1D       intermediate_model    15
# LSTM         intermediate_model    14
#              dominant_model         1
# MLP          intermediate_model    12
#              dominant_model         1
# Transformer  intermediate_model    15
# Name: count, dtype: int64

# %%
(
    df_sorted_topo_models_cols.groupby("Model_bkp_2")[["Classification"]]
    .value_counts(normalize=True)
    .to_frame()
    * 100
).round(2)
# Out:
#                                 proportion
# Model_bkp_2 Classification
# Bi-LSTM     intermediate_model       86.67
#             dominant_model            6.67
#             non_dominant_model        6.67
# Conv1D      intermediate_model      100.00
# LSTM        intermediate_model       93.33
#             dominant_model            6.67
# MLP         intermediate_model       92.31
#             dominant_model            7.69
# Transformer intermediate_model      100.00

# %%
df_sorted_topo_models_cols
# Out:
#     Model_bkp_2  Dominated_Count  Dominates_Count      Classification
# 10          MLP                0               59      dominant_model
# 18         LSTM                0               70      dominant_model
# 32      Bi-LSTM                0               70      dominant_model
# 5           MLP                3               54  intermediate_model
# 20         LSTM                2               59  intermediate_model
# ..          ...              ...              ...                 ...
# 40      Bi-LSTM               64                4  intermediate_model
# 52  Transformer               65                3  intermediate_model
# 43  Transformer               70                1  intermediate_model
# 47  Transformer               70                1  intermediate_model
# 39      Bi-LSTM               72                0  non_dominant_model
#
# [73 rows x 4 columns]

# %%
summary_stats = df_sorted_topo_models_cols.groupby("Model_bkp_2").agg(
    Total_Models=("Model_bkp_2", "count"),
    Mean_Dominance_Count=("Dominates_Count", "mean"),
    Median_Dominance_Count=("Dominates_Count", "median"),
    Total_Dominated=("Dominated_Count", "sum"),
    Total_Dominating=("Dominates_Count", "sum"),
)

total_models = summary_stats[
    "Total_Models"
].sum()  # Get the total number of models across all categories
summary_stats["Dominance Proportion"] = summary_stats["Total_Dominating"] / total_models

# %%
summary_stats
# Out:
#              Total_Models  Mean_Dominance_Count  Median_Dominance_Count  \
# Model_bkp_2
# Bi-LSTM                15             35.600000                    44.0
# Conv1D                 15             34.600000                    30.0
# LSTM                   15             38.000000                    38.0
# MLP                    13             42.230769                    38.0
# Transformer            15              9.333333                     8.0
#
#              Total_Dominated  Total_Dominating  Dominance Proportion
# Model_bkp_2
# Bi-LSTM                  438               534              7.315068
# Conv1D                   430               519              7.109589
# LSTM                     383               570              7.808219
# MLP                      218               549              7.520548
# Transformer              843               140              1.917808

# %%
df_sorted_topo_models_grouped.T
# Out:
#             Timesteps                                                 \
#                 count      mean       std  min  25%  50%   75%   max
# Model_bkp_2
# Bi-LSTM          15.0  7.333333  5.498918  1.0  1.0  7.0  14.0  14.0
# Conv1D           15.0  7.333333  5.498918  1.0  1.0  7.0  14.0  14.0
# LSTM             15.0  7.333333  5.498918  1.0  1.0  7.0  14.0  14.0
# MLP               0.0       NaN       NaN  NaN  NaN  NaN   NaN   NaN
# Transformer      15.0  7.333333  5.498918  1.0  1.0  7.0  14.0  14.0
#
#             RMSE_mean            ... Dominated_Count       Dominates_Count  \
#                 count      mean  ...             75%   max           count
# Model_bkp_2                      ...
# Bi-LSTM          15.0  2.948066  ...            53.0  72.0            15.0
# Conv1D           15.0  2.795011  ...            41.5  47.0            15.0
# LSTM             15.0  2.808583  ...            44.0  61.0            15.0
# MLP              13.0  2.762758  ...            22.0  36.0            13.0
# Transformer      15.0  3.188003  ...            62.5  70.0            15.0
#
#
#                   mean        std   min   25%   50%   75%   max
# Model_bkp_2
# Bi-LSTM      35.600000  23.921897   0.0  16.0  44.0  56.5  70.0
# Conv1D       34.600000  10.946624  21.0  26.0  30.0  44.5  52.0
# LSTM         38.000000  21.350811   5.0  23.0  38.0  55.0  70.0
# MLP          42.230769   9.093531  27.0  38.0  38.0  50.0  59.0
# Transformer   9.333333   7.761320   1.0   3.5   8.0  12.0  27.0
#
# [5 rows x 64 columns]

# %% [markdown]
# ### SCPM Analysis

# %%
cols = [
    "Model",
    # "Model_bkp",
    "Model_bkp_2",
    "Timesteps",
    "RMSE_mean",
    "MAE_mean",
    "MAPE_mean",
    "R2_mean",
    "SCPM",
    "Dominated_Count",
    "Dominates_Count",
    "Classification",
    "Plant",
]

# %%
df_sorted_scpm = df_sorted_topo.sort_values(by="SCPM").copy()

# %%
# (df_sorted_topo[cols].reset_index() == df_sorted_scpm[cols].reset_index()).all(axis=1)
df_sorted_scpm["topo_scmp_order_eq"] = df_sorted_topo.index == df_sorted_scpm.index

# %%
# df_sorted_topo[cols].round(2).head(5)

# %%
df_sorted_scpm[cols + ["topo_scmp_order_eq"]].round(2).head(7)
# Out:
#         Model Model_bkp_2  Timesteps  RMSE_mean  MAE_mean  MAPE_mean  R2_mean  \
# 18      LSTM6        LSTM       14.0       2.49      1.88       4.40     0.83
# 32   Bi-LSTM5     Bi-LSTM        7.0       2.51      1.87       4.34     0.82
# 21      LSTM9        LSTM       14.0       2.51      1.92       4.54     0.82
# 10     MLP_11         MLP        NaN       2.61      1.86       4.43     0.81
# 41  Bi-LSTM14     Bi-LSTM        7.0       2.53      1.94       4.56     0.82
# 20      LSTM8        LSTM        7.0       2.59      1.91       4.47     0.81
# 27     LSTM15        LSTM       14.0       2.53      1.96       4.61     0.82
#
#     SCPM  Dominated_Count  Dominates_Count      Classification Plant  \
# 18 -4.53                0               70      dominant_model     S
# 32 -4.51                0               70      dominant_model     S
# 21 -4.03                2               66  intermediate_model     S
# 10 -3.90                0               59      dominant_model     S
# 41 -3.83                3               61  intermediate_model     S
# 20 -3.81                2               59  intermediate_model     S
# 27 -3.74                3               55  intermediate_model     S
#
#     topo_scmp_order_eq
# 18               False
# 32               False
# 21               False
# 10               False
# 41               False
# 20               False
# 27               False

# %%
df_sorted_scpm[cols + ["topo_scmp_order_eq"]].head(1)
# Out:
#     Model Model_bkp_2  Timesteps  RMSE_mean  MAE_mean  MAPE_mean   R2_mean  \
# 18  LSTM6        LSTM       14.0     2.4899  1.879614   4.398563  0.828245
#
#         SCPM  Dominated_Count  Dominates_Count  Classification Plant  \
# 18 -4.529758                0               70  dominant_model     S
#
#     topo_scmp_order_eq
# 18               False

# %% [markdown]
# ### Variable Grouping: CM-P

# %% [markdown]
# #### Analysis of the best models identified in the Local Analysis

# %% [markdown]
# **Best models for variable groupping CM-P were from:**
#
# *BTiSS:*
#     Dominance analysis: Plant AM
#     SCPM:Plant AM
#
# *TiSS:*
#     Dominance analysis: Plant W
#     SCPM:Plant W

# %%
df_pre_train["Features"].unique()
# Out:
# array(['Chemical + Mineralogical + Physical', 'Chemical + Mineralogical',
#        'Chemical + Mineralogical + Physical - Early CS'], dtype=object)

# %%
df_results_cm_p = (
    df_pre_train[
        df_pre_train["Features"].eq("Chemical + Mineralogical + Physical - Early CS")
    ]
    .copy()
    .reset_index(drop=True)
)

# %% [markdown]
# ### Plant AM

# %%
df_results_cm_p_am = df_results_cm_p[df_results_cm_p["Plant"].eq("AM")].reset_index(
    drop=True
)

# %%
df_results_cm_p_am.shape
# Out:
# (73, 26)

# %% [markdown]
# #### Hold Out

# %%
df_results_cm_p_am["Cross Validation"].unique()
# Out:
# array(['Out of time'], dtype=object)

# %%
df_results_cm_p_am_ho = (
    df_results_cm_p_am[df_results_cm_p_am["Cross Validation"].eq("Out of time")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_p_am_ho["Cross Validation"].unique()
# Out:
# array(['Out of time'], dtype=object)

# %%
df_results_cm_p_am_ho.shape
# Out:
# (73, 26)

# %% [markdown]
# ###### SCPM computation

# %%
df_results_cm_p_am_ho = compute_scpm(df_results_cm_p_am_ho)

# %% [markdown]
# ##### Dominance Analysis

# %%
dominance_dict = make_dominance_analysis(df_results_cm_p_am_ho)
dominance_matrix_cm_p_am_ho = dominance_dict["dominance_matrix"]
dominance_graph_cm_p_am_ho = dominance_dict["dominance_graph"]
df_sorted_count = dominance_dict["df_sorted_count"]
df_sorted_topo = dominance_dict["df_sorted_topo"]

# %%
dominance_matrix_cm_p_am_ho.shape, len(dominance_graph_cm_p_am_ho)
# Out:
# ((73, 73), 73)

# %%
df_sorted_topo["Classification"].value_counts()
# Out:
# Classification
# intermediate_model    71
# dominant_model         1
# non_dominant_model     1
# Name: count, dtype: int64

# %%
# df_sorted_topo.to_csv(
#     "../../../../reports/results/local_models/ecics/209_dominance_analysis_cm_kf.csv",
#     index=False,
# )

# %%
df_sorted_topo.head(5)
# Out:
#         Category  Company Plant  \
# 72  Global Model      209    AM
# 70  Global Model      209    AM
# 71  Global Model      209    AM
# 65  Global Model      209    AM
# 66  Global Model      209    AM
#
#                                           Features   Data Shape  Timesteps  \
# 72  Chemical + Mineralogical + Physical - Early CS  (60402, 14)        NaN
# 70  Chemical + Mineralogical + Physical - Early CS  (60402, 14)        NaN
# 71  Chemical + Mineralogical + Physical - Early CS  (60402, 14)        NaN
# 65  Chemical + Mineralogical + Physical - Early CS  (60402, 14)        NaN
# 66  Chemical + Mineralogical + Physical - Early CS  (60402, 14)        NaN
#
#      Model  Model Params           Scaler  Scaler Params  ... MAPE_mean  \
# 72  MLP_13           NaN  Standard Scaler            NaN  ...  3.770625
# 70  MLP_11           NaN  Standard Scaler            NaN  ...  3.894766
# 71  MLP_12           NaN  Standard Scaler            NaN  ...  3.901887
# 65   MLP_6           NaN  Standard Scaler            NaN  ...  3.921627
# 66   MLP_7           NaN  Standard Scaler            NaN  ...  3.914836
#
#      R2_mean plant                   Features_bkp  Model_bkp  Model_bkp_2  \
# 72  0.867812    am  Chemical + Properties CS Less     MLP_13          MLP
# 70  0.858914    am  Chemical + Properties CS Less     MLP_11          MLP
# 71  0.863590    am  Chemical + Properties CS Less     MLP_12          MLP
# 65  0.855507    am  Chemical + Properties CS Less      MLP_6          MLP
# 66  0.854839    am  Chemical + Properties CS Less      MLP_7          MLP
#
#         SCPM  Dominated_Count      Classification  Dominates_Count
# 72 -1.713538                0      dominant_model               72
# 70 -1.646028                1  intermediate_model               70
# 71 -1.655878                1  intermediate_model               70
# 65 -1.621879                3  intermediate_model               68
# 66 -1.620015                3  intermediate_model               67
#
# [5 rows x 30 columns]

# %%
df_sorted_topo_cols = df_sorted_topo[
    [
        "Model",
        # "Model_bkp",
        # "Model_bkp_2",
        "Timesteps",
        "RMSE_mean",
        "MAE_mean",
        "MAPE_mean",
        "R2_mean",
        "SCPM",
        "Dominated_Count",
        "Classification",
        "Dominates_Count",
        "Plant",
    ]
].round(2)

# %% [markdown]
# ##### Top dominant models

# %%
# Top 4
df_sorted_topo_cols.sort_values(by="Dominates_Count", ascending=False).iloc[0:3]
# Out:
#      Model  Timesteps  RMSE_mean  MAE_mean  MAPE_mean  R2_mean  SCPM  \
# 72  MLP_13        NaN       2.18      1.60       3.77     0.87 -1.71
# 71  MLP_12        NaN       2.21      1.66       3.90     0.86 -1.66
# 70  MLP_11        NaN       2.25      1.64       3.89     0.86 -1.65
#
#     Dominated_Count      Classification  Dominates_Count Plant
# 72                0      dominant_model               72    AM
# 71                1  intermediate_model               70    AM
# 70                1  intermediate_model               70    AM

# %% [markdown]
# ##### Top intermediate models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].sort_values(by="Dominates_Count", ascending=False).iloc[:2]
# Out:
#      Model  Timesteps  RMSE_mean  MAE_mean  MAPE_mean  R2_mean  SCPM  \
# 70  MLP_11        NaN       2.25      1.64       3.89     0.86 -1.65
# 71  MLP_12        NaN       2.21      1.66       3.90     0.86 -1.66
#
#     Dominated_Count      Classification  Dominates_Count Plant
# 70                1  intermediate_model               70    AM
# 71                1  intermediate_model               70    AM

# %% [markdown]
# ##### Top non dominant models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].sort_values(by="Dominated_Count", ascending=True).iloc[:2]
# Out:
#         Model  Timesteps  RMSE_mean  MAE_mean  MAPE_mean  R2_mean  SCPM  \
# 40  Bi-LSTM11        7.0      25.36     24.65      56.02   -16.94  32.4
#
#     Dominated_Count      Classification  Dominates_Count Plant
# 40               72  non_dominant_model                0    AM

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        # "Model",
        # "Model_bkp",
        "Model_bkp_2",
        "Timesteps",
        "RMSE_mean",
        "MAE_mean",
        "MAPE_mean",
        "R2_mean",
        "SCPM",
        "Dominated_Count",
        "Classification",
        "Dominates_Count",
        "Plant",
    ]
]  # .round(2)

# %%
df_sorted_topo["Model_bkp_2"].value_counts()
# Out:
# Model_bkp_2
# Conv1D         15
# LSTM           15
# Bi-LSTM        15
# Transformer    15
# MLP            13
# Name: count, dtype: int64

# %%
df_sorted_topo_models_grouped = (
    df_sorted_topo_models_cols.groupby("Model_bkp_2").describe().T
)

# %%
# pd.set_option("display.max_rows", None)
# df_sorted_topo_models_grouped

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model_bkp_2",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
    ]
]

# %%
df_sorted_topo_models_cols.groupby("Model_bkp_2").describe().round(2)
# Out:
#             Dominated_Count                                              \
#                       count   mean    std   min   25%   50%   75%   max
# Model_bkp_2
# Bi-LSTM                15.0  51.73  15.81  23.0  41.5  52.0  67.0  72.0
# Conv1D                 15.0  24.13  15.51  13.0  15.5  16.0  26.0  67.0
# LSTM                   15.0  40.13  13.98  16.0  32.5  38.0  47.0  68.0
# MLP                    13.0   5.31   3.86   0.0   3.0   5.0   8.0  12.0
# Transformer            15.0  49.07  12.49  28.0  38.5  51.0  58.5  65.0
#
#             Dominates_Count
#                       count   mean    std   min   25%   50%   75%   max
# Model_bkp_2
# Bi-LSTM                15.0  18.47  15.12   0.0   4.5  18.0  28.5  48.0
# Conv1D                 15.0  44.67  14.72   5.0  43.0  50.0  50.5  59.0
# LSTM                   15.0  29.07  13.38   3.0  22.5  29.0  38.5  50.0
# MLP                    13.0  65.31   3.82  60.0  62.0  65.0  68.0  72.0
# Transformer            15.0  20.87  12.24   7.0  11.0  18.0  29.0  43.0

# %%
df_sorted_topo_models_cols.groupby("Model_bkp_2")["Classification"].describe()
# Out:
#             count unique                 top freq
# Model_bkp_2
# Bi-LSTM        15      2  intermediate_model   14
# Conv1D         15      1  intermediate_model   15
# LSTM           15      1  intermediate_model   15
# MLP            13      2  intermediate_model   12
# Transformer    15      1  intermediate_model   15

# %%
df_sorted_topo_models_cols.groupby("Model_bkp_2")[["Classification"]].value_counts()
# Out:
# Model_bkp_2  Classification
# Bi-LSTM      intermediate_model    14
#              non_dominant_model     1
# Conv1D       intermediate_model    15
# LSTM         intermediate_model    15
# MLP          intermediate_model    12
#              dominant_model         1
# Transformer  intermediate_model    15
# Name: count, dtype: int64

# %%
(
    df_sorted_topo_models_cols.groupby("Model_bkp_2")[["Classification"]]
    .value_counts(normalize=True)
    .to_frame()
    * 100
).round(2)
# Out:
#                                 proportion
# Model_bkp_2 Classification
# Bi-LSTM     intermediate_model       93.33
#             non_dominant_model        6.67
# Conv1D      intermediate_model      100.00
# LSTM        intermediate_model      100.00
# MLP         intermediate_model       92.31
#             dominant_model            7.69
# Transformer intermediate_model      100.00

# %%
df_sorted_topo_models_cols
# Out:
#    Model_bkp_2  Dominated_Count  Dominates_Count      Classification
# 72         MLP                0               72      dominant_model
# 70         MLP                1               70  intermediate_model
# 71         MLP                1               70  intermediate_model
# 65         MLP                3               68  intermediate_model
# 66         MLP                3               67  intermediate_model
# ..         ...              ...              ...                 ...
# 14        LSTM               68                3  intermediate_model
# 35     Bi-LSTM               68                3  intermediate_model
# 41     Bi-LSTM               70                1  intermediate_model
# 44     Bi-LSTM               70                1  intermediate_model
# 40     Bi-LSTM               72                0  non_dominant_model
#
# [73 rows x 4 columns]

# %%
summary_stats = df_sorted_topo_models_cols.groupby("Model_bkp_2").agg(
    Total_Models=("Model_bkp_2", "count"),
    Mean_Dominance_Count=("Dominates_Count", "mean"),
    Median_Dominance_Count=("Dominates_Count", "median"),
    Total_Dominated=("Dominated_Count", "sum"),
    Total_Dominating=("Dominates_Count", "sum"),
)

total_models = summary_stats[
    "Total_Models"
].sum()  # Get the total number of models across all categories
summary_stats["Dominance Proportion"] = summary_stats["Total_Dominating"] / total_models

# %%
summary_stats
# Out:
#              Total_Models  Mean_Dominance_Count  Median_Dominance_Count  \
# Model_bkp_2
# Bi-LSTM                15             18.466667                    18.0
# Conv1D                 15             44.666667                    50.0
# LSTM                   15             29.066667                    29.0
# MLP                    13             65.307692                    65.0
# Transformer            15             20.866667                    18.0
#
#              Total_Dominated  Total_Dominating  Dominance Proportion
# Model_bkp_2
# Bi-LSTM                  776               277              3.794521
# Conv1D                   362               670              9.178082
# LSTM                     602               436              5.972603
# MLP                       69               849             11.630137
# Transformer              736               313              4.287671

# %%
df_sorted_topo_models_grouped.T
# Out:
#             Timesteps                                                 \
#                 count      mean       std  min  25%  50%   75%   max
# Model_bkp_2
# Bi-LSTM          15.0  7.333333  5.498918  1.0  1.0  7.0  14.0  14.0
# Conv1D           15.0  7.333333  5.498918  1.0  1.0  7.0  14.0  14.0
# LSTM             15.0  7.333333  5.498918  1.0  1.0  7.0  14.0  14.0
# MLP               0.0       NaN       NaN  NaN  NaN  NaN   NaN   NaN
# Transformer      15.0  7.333333  5.498918  1.0  1.0  7.0  14.0  14.0
#
#             RMSE_mean            ... Dominated_Count       Dominates_Count  \
#                 count      mean  ...             75%   max           count
# Model_bkp_2                      ...
# Bi-LSTM          15.0  5.565634  ...            67.0  72.0            15.0
# Conv1D           15.0  2.963421  ...            26.0  67.0            15.0
# LSTM             15.0  3.412089  ...            47.0  68.0            15.0
# MLP              13.0  2.288615  ...             8.0  12.0            13.0
# Transformer      15.0  3.655390  ...            58.5  65.0            15.0
#
#
#                   mean        std   min   25%   50%   75%   max
# Model_bkp_2
# Bi-LSTM      18.466667  15.117949   0.0   4.5  18.0  28.5  48.0
# Conv1D       44.666667  14.724453   5.0  43.0  50.0  50.5  59.0
# LSTM         29.066667  13.376240   3.0  22.5  29.0  38.5  50.0
# MLP          65.307692   3.816294  60.0  62.0  65.0  68.0  72.0
# Transformer  20.866667  12.235001   7.0  11.0  18.0  29.0  43.0
#
# [5 rows x 64 columns]

# %% [markdown]
# ### SCPM Analysis

# %%
cols = [
    "Model",
    # "Model_bkp",
    "Model_bkp_2",
    "Timesteps",
    "RMSE_mean",
    "MAE_mean",
    "MAPE_mean",
    "R2_mean",
    "SCPM",
    "Dominated_Count",
    "Dominates_Count",
    "Classification",
    "Plant",
]

# %%
df_sorted_scpm = df_sorted_topo.sort_values(by="SCPM").copy()

# %%
# (df_sorted_topo[cols].reset_index() == df_sorted_scpm[cols].reset_index()).all(axis=1)
df_sorted_scpm["topo_scmp_order_eq"] = df_sorted_topo.index == df_sorted_scpm.index

# %%
# df_sorted_topo[cols].round(2).head(5)

# %%
df_sorted_scpm[cols + ["topo_scmp_order_eq"]].round(2).head(7)
# Out:
#      Model Model_bkp_2  Timesteps  RMSE_mean  MAE_mean  MAPE_mean  R2_mean  \
# 72  MLP_13         MLP        NaN       2.18      1.60       3.77     0.87
# 71  MLP_12         MLP        NaN       2.21      1.66       3.90     0.86
# 70  MLP_11         MLP        NaN       2.25      1.64       3.89     0.86
# 65   MLP_6         MLP        NaN       2.27      1.66       3.92     0.86
# 66   MLP_7         MLP        NaN       2.28      1.67       3.91     0.85
# 63   MLP_4         MLP        NaN       2.29      1.66       3.93     0.85
# 64   MLP_5         MLP        NaN       2.28      1.67       3.95     0.85
#
#     SCPM  Dominated_Count  Dominates_Count      Classification Plant  \
# 72 -1.71                0               72      dominant_model    AM
# 71 -1.66                1               70  intermediate_model    AM
# 70 -1.65                1               70  intermediate_model    AM
# 65 -1.62                3               68  intermediate_model    AM
# 66 -1.62                3               67  intermediate_model    AM
# 63 -1.61                4               65  intermediate_model    AM
# 64 -1.61                5               65  intermediate_model    AM
#
#     topo_scmp_order_eq
# 72                True
# 71               False
# 70               False
# 65                True
# 66                True
# 63                True
# 64                True

# %% [markdown]
# ### Plant W

# %%
df_results_cm_p_w = df_results_cm_p[df_results_cm_p["Plant"].eq("W")].reset_index(
    drop=True
)

# %%
df_results_cm_p_w.shape
# Out:
# (73, 26)

# %% [markdown]
# #### Hold Out

# %%
df_results_cm_p_w["Cross Validation"].unique()
# Out:
# array(['Out of time'], dtype=object)

# %%
df_results_cm_p_w_ho = (
    df_results_cm_p_w[df_results_cm_p_w["Cross Validation"].eq("Out of time")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_p_w_ho["Cross Validation"].unique()
# Out:
# array(['Out of time'], dtype=object)

# %%
df_results_cm_p_w_ho.shape
# Out:
# (73, 26)

# %% [markdown]
# ###### SCPM computation

# %%
df_results_cm_p_w_ho = compute_scpm(df_results_cm_p_w_ho)

# %% [markdown]
# ##### Dominance Analysis

# %%
dominance_dict = make_dominance_analysis(df_results_cm_p_w_ho)
dominance_matrix_cm_p_w_ho = dominance_dict["dominance_matrix"]
dominance_graph_cm_p_w_ho = dominance_dict["dominance_graph"]
df_sorted_count = dominance_dict["df_sorted_count"]
df_sorted_topo = dominance_dict["df_sorted_topo"]

# %%
dominance_matrix_cm_p_w_ho.shape, len(dominance_graph_cm_p_w_ho)
# Out:
# ((73, 73), 73)

# %%
df_sorted_topo["Classification"].value_counts()
# Out:
# Classification
# intermediate_model    70
# non_dominant_model     2
# dominant_model         1
# Name: count, dtype: int64

# %%
# df_sorted_topo.to_csv(
#     "../../../../reports/results/local_models/ecics/209_dominance_analysis_cm_kf.csv",
#     index=False,
# )

# %%
df_sorted_topo.head(5)
# Out:
#         Category  Company Plant  \
# 66  Global Model      209     W
# 65  Global Model      209     W
# 71  Global Model      209     W
# 69  Global Model      209     W
# 62  Global Model      209     W
#
#                                           Features   Data Shape  Timesteps  \
# 66  Chemical + Mineralogical + Physical - Early CS  (57588, 14)        NaN
# 65  Chemical + Mineralogical + Physical - Early CS  (57588, 14)        NaN
# 71  Chemical + Mineralogical + Physical - Early CS  (57588, 14)        NaN
# 69  Chemical + Mineralogical + Physical - Early CS  (57588, 14)        NaN
# 62  Chemical + Mineralogical + Physical - Early CS  (57588, 14)        NaN
#
#      Model  Model Params           Scaler  Scaler Params  ... MAPE_mean  \
# 66   MLP_7           NaN  Standard Scaler            NaN  ...  3.733926
# 65   MLP_6           NaN  Standard Scaler            NaN  ...  3.814427
# 71  MLP_12           NaN  Standard Scaler            NaN  ...  3.832613
# 69  MLP_10           NaN  Standard Scaler            NaN  ...  3.819649
# 62   MLP_3           NaN  Standard Scaler            NaN  ...  3.878092
#
#      R2_mean plant                   Features_bkp  Model_bkp  Model_bkp_2  \
# 66  0.864596     w  Chemical + Properties CS Less      MLP_7          MLP
# 65  0.861923     w  Chemical + Properties CS Less      MLP_6          MLP
# 71  0.863924     w  Chemical + Properties CS Less     MLP_12          MLP
# 69  0.858855     w  Chemical + Properties CS Less     MLP_10          MLP
# 62  0.861012     w  Chemical + Properties CS Less      MLP_3          MLP
#
#         SCPM  Dominated_Count      Classification  Dominates_Count
# 66 -4.765685                0      dominant_model               72
# 65 -4.639092                1  intermediate_model               70
# 71 -4.646422                1  intermediate_model               69
# 69 -4.582923                2  intermediate_model               68
# 62 -4.574210                3  intermediate_model               67
#
# [5 rows x 30 columns]

# %%
df_sorted_topo_cols = df_sorted_topo[
    [
        "Model",
        # "Model_bkp",
        # "Model_bkp_2",
        "Timesteps",
        "RMSE_mean",
        "MAE_mean",
        "MAPE_mean",
        "R2_mean",
        "SCPM",
        "Dominated_Count",
        "Classification",
        "Dominates_Count",
        "Plant",
    ]
].round(2)

# %% [markdown]
# ##### Top dominant models

# %%
# Top 4
df_sorted_topo_cols.sort_values(by="Dominates_Count", ascending=False).iloc[0:3]
# Out:
#      Model  Timesteps  RMSE_mean  MAE_mean  MAPE_mean  R2_mean  SCPM  \
# 66   MLP_7        NaN       2.17      1.56       3.73     0.86 -4.77
# 65   MLP_6        NaN       2.20      1.59       3.81     0.86 -4.64
# 71  MLP_12        NaN       2.18      1.60       3.83     0.86 -4.65
#
#     Dominated_Count      Classification  Dominates_Count Plant
# 66                0      dominant_model               72     W
# 65                1  intermediate_model               70     W
# 71                1  intermediate_model               69     W

# %% [markdown]
# ##### Top intermediate models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].sort_values(by="Dominates_Count", ascending=False).iloc[:2]
# Out:
#      Model  Timesteps  RMSE_mean  MAE_mean  MAPE_mean  R2_mean  SCPM  \
# 65   MLP_6        NaN       2.20      1.59       3.81     0.86 -4.64
# 71  MLP_12        NaN       2.18      1.60       3.83     0.86 -4.65
#
#     Dominated_Count      Classification  Dominates_Count Plant
# 65                1  intermediate_model               70     W
# 71                1  intermediate_model               69     W

# %% [markdown]
# ##### Top non dominant models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].sort_values(by="Dominated_Count", ascending=True).iloc[:2]
# Out:
#         Model  Timesteps  RMSE_mean  MAE_mean  MAPE_mean  R2_mean   SCPM  \
# 38   Bi-LSTM9       14.0       6.07      5.10      11.61    -0.05  14.34
# 41  Bi-LSTM12       14.0       5.97      5.13      11.93    -0.02  14.26
#
#     Dominated_Count      Classification  Dominates_Count Plant
# 38               71  non_dominant_model                0     W
# 41               71  non_dominant_model                0     W

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        # "Model",
        # "Model_bkp",
        "Model_bkp_2",
        "Timesteps",
        "RMSE_mean",
        "MAE_mean",
        "MAPE_mean",
        "R2_mean",
        "SCPM",
        "Dominated_Count",
        "Classification",
        "Dominates_Count",
        "Plant",
    ]
]  # .round(2)

# %%
df_sorted_topo["Model_bkp_2"].value_counts()
# Out:
# Model_bkp_2
# Conv1D         15
# LSTM           15
# Bi-LSTM        15
# Transformer    15
# MLP            13
# Name: count, dtype: int64

# %%
df_sorted_topo_models_grouped = (
    df_sorted_topo_models_cols.groupby("Model_bkp_2").describe().T
)

# %%
# pd.set_option("display.max_rows", None)
# df_sorted_topo_models_grouped

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model_bkp_2",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
    ]
]

# %%
df_sorted_topo_models_cols.groupby("Model_bkp_2").describe().round(2)
# Out:
#             Dominated_Count                                              \
#                       count   mean    std   min   25%   50%   75%   max
# Model_bkp_2
# Bi-LSTM                15.0  48.27  14.92  21.0  39.0  48.0  60.5  71.0
# Conv1D                 15.0  23.20  10.40  12.0  16.0  21.0  28.0  52.0
# LSTM                   15.0  41.53  16.81  18.0  28.0  43.0  57.5  69.0
# MLP                    13.0   5.54   4.07   0.0   2.0   6.0   9.0  12.0
# Transformer            15.0  51.33  12.51  33.0  41.5  51.0  61.5  69.0
#
#             Dominates_Count
#                       count   mean    std   min   25%   50%   75%   max
# Model_bkp_2
# Bi-LSTM                15.0  20.07  13.74   0.0   8.0  20.0  29.5  47.0
# Conv1D                 15.0  46.80  11.41  15.0  43.0  48.0  55.0  59.0
# LSTM                   15.0  27.53  17.13   2.0  11.5  26.0  43.5  51.0
# MLP                    13.0  65.38   3.93  58.0  63.0  65.0  68.0  72.0
# Transformer            15.0  18.07  11.09   2.0   9.5  17.0  26.5  37.0

# %%
df_sorted_topo_models_cols.groupby("Model_bkp_2")["Classification"].describe()
# Out:
#             count unique                 top freq
# Model_bkp_2
# Bi-LSTM        15      2  intermediate_model   13
# Conv1D         15      1  intermediate_model   15
# LSTM           15      1  intermediate_model   15
# MLP            13      2  intermediate_model   12
# Transformer    15      1  intermediate_model   15

# %%
df_sorted_topo_models_cols.groupby("Model_bkp_2")[["Classification"]].value_counts()
# Out:
# Model_bkp_2  Classification
# Bi-LSTM      intermediate_model    13
#              non_dominant_model     2
# Conv1D       intermediate_model    15
# LSTM         intermediate_model    15
# MLP          intermediate_model    12
#              dominant_model         1
# Transformer  intermediate_model    15
# Name: count, dtype: int64

# %%
(
    df_sorted_topo_models_cols.groupby("Model_bkp_2")[["Classification"]]
    .value_counts(normalize=True)
    .to_frame()
    * 100
).round(2)
# Out:
#                                 proportion
# Model_bkp_2 Classification
# Bi-LSTM     intermediate_model       86.67
#             non_dominant_model       13.33
# Conv1D      intermediate_model      100.00
# LSTM        intermediate_model      100.00
# MLP         intermediate_model       92.31
#             dominant_model            7.69
# Transformer intermediate_model      100.00

# %%
df_sorted_topo_models_cols
# Out:
#     Model_bkp_2  Dominated_Count  Dominates_Count      Classification
# 66          MLP                0               72      dominant_model
# 65          MLP                1               70  intermediate_model
# 71          MLP                1               69  intermediate_model
# 69          MLP                2               68  intermediate_model
# 62          MLP                3               67  intermediate_model
# ..          ...              ...              ...                 ...
# 48  Transformer               68                4  intermediate_model
# 14         LSTM               69                2  intermediate_model
# 57  Transformer               69                2  intermediate_model
# 38      Bi-LSTM               71                0  non_dominant_model
# 41      Bi-LSTM               71                0  non_dominant_model
#
# [73 rows x 4 columns]

# %%
summary_stats = df_sorted_topo_models_cols.groupby("Model_bkp_2").agg(
    Total_Models=("Model_bkp_2", "count"),
    Mean_Dominance_Count=("Dominates_Count", "mean"),
    Median_Dominance_Count=("Dominates_Count", "median"),
    Total_Dominated=("Dominated_Count", "sum"),
    Total_Dominating=("Dominates_Count", "sum"),
)

total_models = summary_stats[
    "Total_Models"
].sum()  # Get the total number of models across all categories
summary_stats["Dominance Proportion"] = summary_stats["Total_Dominating"] / total_models

# %%
summary_stats
# Out:
#              Total_Models  Mean_Dominance_Count  Median_Dominance_Count  \
# Model_bkp_2
# Bi-LSTM                15             20.066667                    20.0
# Conv1D                 15             46.800000                    48.0
# LSTM                   15             27.533333                    26.0
# MLP                    13             65.384615                    65.0
# Transformer            15             18.066667                    17.0
#
#              Total_Dominated  Total_Dominating  Dominance Proportion
# Model_bkp_2
# Bi-LSTM                  724               301              4.123288
# Conv1D                   348               702              9.616438
# LSTM                     623               413              5.657534
# MLP                       72               850             11.643836
# Transformer              770               271              3.712329

# %%
df_sorted_topo_models_grouped.T
# Out:
#             Timesteps                                                 \
#                 count      mean       std  min  25%  50%   75%   max
# Model_bkp_2
# Bi-LSTM          15.0  7.333333  5.498918  1.0  1.0  7.0  14.0  14.0
# Conv1D           15.0  7.333333  5.498918  1.0  1.0  7.0  14.0  14.0
# LSTM             15.0  7.333333  5.498918  1.0  1.0  7.0  14.0  14.0
# MLP               0.0       NaN       NaN  NaN  NaN  NaN   NaN   NaN
# Transformer      15.0  7.333333  5.498918  1.0  1.0  7.0  14.0  14.0
#
#             RMSE_mean            ... Dominated_Count       Dominates_Count  \
#                 count      mean  ...             75%   max           count
# Model_bkp_2                      ...
# Bi-LSTM          15.0  3.761277  ...            60.5  71.0            15.0
# Conv1D           15.0  2.796076  ...            28.0  52.0            15.0
# LSTM             15.0  3.381053  ...            57.5  69.0            15.0
# MLP              13.0  2.295701  ...             9.0  12.0            13.0
# Transformer      15.0  3.682079  ...            61.5  69.0            15.0
#
#
#                   mean        std   min   25%   50%   75%   max
# Model_bkp_2
# Bi-LSTM      20.066667  13.744956   0.0   8.0  20.0  29.5  47.0
# Conv1D       46.800000  11.409269  15.0  43.0  48.0  55.0  59.0
# LSTM         27.533333  17.133370   2.0  11.5  26.0  43.5  51.0
# MLP          65.384615   3.927223  58.0  63.0  65.0  68.0  72.0
# Transformer  18.066667  11.093542   2.0   9.5  17.0  26.5  37.0
#
# [5 rows x 64 columns]

# %% [markdown]
# ### SCPM Analysis

# %%
cols = [
    "Model",
    # "Model_bkp",
    "Model_bkp_2",
    "Timesteps",
    "RMSE_mean",
    "MAE_mean",
    "MAPE_mean",
    "R2_mean",
    "SCPM",
    "Dominated_Count",
    "Dominates_Count",
    "Classification",
    "Plant",
]

# %%
df_sorted_scpm = df_sorted_topo.sort_values(by="SCPM").copy()

# %%
# (df_sorted_topo[cols].reset_index() == df_sorted_scpm[cols].reset_index()).all(axis=1)
df_sorted_scpm["topo_scmp_order_eq"] = df_sorted_topo.index == df_sorted_scpm.index

# %%
# df_sorted_topo[cols].round(2).head(5)

# %%
df_sorted_scpm[cols + ["topo_scmp_order_eq"]].round(2).head(7)
# Out:
#      Model Model_bkp_2  Timesteps  RMSE_mean  MAE_mean  MAPE_mean  R2_mean  \
# 66   MLP_7         MLP        NaN       2.17      1.56       3.73     0.86
# 71  MLP_12         MLP        NaN       2.18      1.60       3.83     0.86
# 65   MLP_6         MLP        NaN       2.20      1.59       3.81     0.86
# 69  MLP_10         MLP        NaN       2.22      1.60       3.82     0.86
# 62   MLP_3         MLP        NaN       2.20      1.60       3.88     0.86
# 70  MLP_11         MLP        NaN       2.26      1.61       3.88     0.85
# 72  MLP_13         MLP        NaN       2.29      1.64       3.91     0.85
#
#     SCPM  Dominated_Count  Dominates_Count      Classification Plant  \
# 66 -4.77                0               72      dominant_model     W
# 71 -4.65                1               69  intermediate_model     W
# 65 -4.64                1               70  intermediate_model     W
# 69 -4.58                2               68  intermediate_model     W
# 62 -4.57                3               67  intermediate_model     W
# 70 -4.46                4               67  intermediate_model     W
# 72 -4.34                6               65  intermediate_model     W
#
#     topo_scmp_order_eq
# 66                True
# 71               False
# 65               False
# 69                True
# 62                True
# 70                True
# 72               False

# %% [markdown]
# ### Variable Grouping: CM-P-CS

# %% [markdown]
# #### Analysis of the best models identified in the Local Analysis

# %% [markdown]
# **Best models for variable groupping CM-P-CS were from:**
#
# *BTiSS:*
#     Dominance analysis: Plant S
#     SCPM:Plant S and K
#
# *TiSS:*
#     Dominance analysis: Plant S
#     SCPM:Plant S

# %%
df_pre_train["Features"].unique()
# Out:
# array(['Chemical + Mineralogical + Physical', 'Chemical + Mineralogical',
#        'Chemical + Mineralogical + Physical - Early CS'], dtype=object)

# %%
df_results_cm_p_cs = (
    df_pre_train[df_pre_train["Features"].eq("Chemical + Mineralogical + Physical")]
    .copy()
    .reset_index(drop=True)
)

# %% [markdown]
# ### Plant S

# %%
df_results_cm_p_cs_s = df_results_cm_p_cs[
    df_results_cm_p_cs["Plant"].eq("S")
].reset_index(drop=True)

# %%
df_results_cm_p_cs_s.shape
# Out:
# (73, 26)

# %% [markdown]
# #### Hold Out

# %%
df_results_cm_p_cs_s["Cross Validation"].unique()
# Out:
# array(['Out of time'], dtype=object)

# %%
df_results_cm_p_cs_s_ho = (
    df_results_cm_p_cs_s[df_results_cm_p_cs_s["Cross Validation"].eq("Out of time")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_p_cs_s_ho["Cross Validation"].unique()
# Out:
# array(['Out of time'], dtype=object)

# %%
df_results_cm_p_cs_s_ho.shape
# Out:
# (73, 26)

# %% [markdown]
# ###### SCPM computation

# %%
df_results_cm_p_cs_s_ho = compute_scpm(df_results_cm_p_cs_s_ho)

# %% [markdown]
# ##### Dominance Analysis

# %%
dominance_dict = make_dominance_analysis(df_results_cm_p_cs_s_ho)
dominance_matrix_cm_p_cs_s_ho = dominance_dict["dominance_matrix"]
dominance_graph_cm_p_cs_s_ho = dominance_dict["dominance_graph"]
df_sorted_count = dominance_dict["df_sorted_count"]
df_sorted_topo = dominance_dict["df_sorted_topo"]

# %%
dominance_matrix_cm_p_cs_s_ho.shape, len(dominance_graph_cm_p_cs_s_ho)
# Out:
# ((73, 73), 73)

# %%
df_sorted_topo["Classification"].value_counts()
# Out:
# Classification
# intermediate_model    71
# dominant_model         1
# non_dominant_model     1
# Name: count, dtype: int64

# %%
# df_sorted_topo.to_csv(
#     "../../../../reports/results/local_models/ecics/209_dominance_analysis_cm_kf.csv",
#     index=False,
# )

# %%
df_sorted_topo.head(5)
# Out:
#         Category  Company Plant                             Features  \
# 26  Global Model      209     S  Chemical + Mineralogical + Physical
# 20  Global Model      209     S  Chemical + Mineralogical + Physical
# 21  Global Model      209     S  Chemical + Mineralogical + Physical
# 25  Global Model      209     S  Chemical + Mineralogical + Physical
# 16  Global Model      209     S  Chemical + Mineralogical + Physical
#
#      Data Shape  Timesteps   Model  Model Params           Scaler  \
# 26  (61946, 17)        NaN  MLP_12           NaN  Standard Scaler
# 20  (61946, 17)        NaN   MLP_6           NaN  Standard Scaler
# 21  (61946, 17)        NaN   MLP_7           NaN  Standard Scaler
# 25  (61946, 17)        NaN  MLP_11           NaN  Standard Scaler
# 16  (61946, 17)        NaN   MLP_2           NaN  Standard Scaler
#
#     Scaler Params  ... MAPE_mean   R2_mean plant         Features_bkp  \
# 26            NaN  ...  2.567879  0.940373     s  Chemical + Physical
# 20            NaN  ...  2.627928  0.938022     s  Chemical + Physical
# 21            NaN  ...  2.638908  0.937571     s  Chemical + Physical
# 25            NaN  ...  2.661951  0.937755     s  Chemical + Physical
# 16            NaN  ...  2.679156  0.935337     s  Chemical + Physical
#
#     Model_bkp  Model_bkp_2      SCPM  Dominated_Count      Classification  \
# 26     MLP_12          MLP -1.560389                0      dominant_model
# 20      MLP_6          MLP -1.523449                1  intermediate_model
# 21      MLP_7          MLP -1.519538                1  intermediate_model
# 25     MLP_11          MLP -1.513479                2  intermediate_model
# 16      MLP_2          MLP -1.491462                4  intermediate_model
#
#     Dominates_Count
# 26               72
# 20               70
# 21               69
# 25               69
# 16               68
#
# [5 rows x 30 columns]

# %%
df_sorted_topo_cols = df_sorted_topo[
    [
        "Model",
        # "Model_bkp",
        # "Model_bkp_2",
        "Timesteps",
        "RMSE_mean",
        "MAE_mean",
        "MAPE_mean",
        "R2_mean",
        "SCPM",
        "Dominated_Count",
        "Classification",
        "Dominates_Count",
        "Plant",
    ]
].round(2)

# %% [markdown]
# ##### Top dominant models

# %%
# Top 4
df_sorted_topo_cols.sort_values(by="Dominates_Count", ascending=False).iloc[0:3]
# Out:
#      Model  Timesteps  RMSE_mean  MAE_mean  MAPE_mean  R2_mean  SCPM  \
# 26  MLP_12        NaN       1.47      1.09       2.57     0.94 -1.56
# 20   MLP_6        NaN       1.49      1.12       2.63     0.94 -1.52
# 21   MLP_7        NaN       1.50      1.12       2.64     0.94 -1.52
#
#     Dominated_Count      Classification  Dominates_Count Plant
# 26                0      dominant_model               72     S
# 20                1  intermediate_model               70     S
# 21                1  intermediate_model               69     S

# %% [markdown]
# ##### Top intermediate models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].sort_values(by="Dominates_Count", ascending=False).iloc[:2]
# Out:
#      Model  Timesteps  RMSE_mean  MAE_mean  MAPE_mean  R2_mean  SCPM  \
# 20   MLP_6        NaN       1.49      1.12       2.63     0.94 -1.52
# 25  MLP_11        NaN       1.50      1.12       2.66     0.94 -1.51
#
#     Dominated_Count      Classification  Dominates_Count Plant
# 20                1  intermediate_model               70     S
# 25                2  intermediate_model               69     S

# %% [markdown]
# ##### Top non dominant models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].sort_values(by="Dominated_Count", ascending=True).iloc[:2]
# Out:
#        Model  Timesteps  RMSE_mean  MAE_mean  MAPE_mean  R2_mean   SCPM  \
# 48  Bi-LSTM6       14.0      21.67     20.82      47.13   -12.01  32.17
#
#     Dominated_Count      Classification  Dominates_Count Plant
# 48               72  non_dominant_model                0     S

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        # "Model",
        # "Model_bkp",
        "Model_bkp_2",
        "Timesteps",
        "RMSE_mean",
        "MAE_mean",
        "MAPE_mean",
        "R2_mean",
        "SCPM",
        "Dominated_Count",
        "Classification",
        "Dominates_Count",
        "Plant",
    ]
]  # .round(2)

# %%
df_sorted_topo["Model_bkp_2"].value_counts()
# Out:
# Model_bkp_2
# Conv1D         15
# Bi-LSTM        15
# LSTM           15
# Transformer    15
# MLP            13
# Name: count, dtype: int64

# %%
df_sorted_topo_models_grouped = (
    df_sorted_topo_models_cols.groupby("Model_bkp_2").describe().T
)

# %%
# pd.set_option("display.max_rows", None)
# df_sorted_topo_models_grouped

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model_bkp_2",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
    ]
]

# %%
df_sorted_topo_models_cols.groupby("Model_bkp_2").describe().round(2)
# Out:
#             Dominated_Count                                              \
#                       count   mean    std   min   25%   50%   75%   max
# Model_bkp_2
# Bi-LSTM                15.0  46.67  18.15  11.0  33.5  46.0  62.5  72.0
# Conv1D                 15.0  18.33   6.18  11.0  14.0  15.0  23.5  29.0
# LSTM                   15.0  46.87  15.13  14.0  38.5  50.0  54.0  70.0
# MLP                    13.0   7.69   8.63   0.0   2.0   6.0   9.0  33.0
# Transformer            15.0  50.33  13.43  23.0  39.0  57.0  60.0  65.0
#
#             Dominates_Count
#                       count   mean    std   min   25%   50%   75%   max
# Model_bkp_2
# Bi-LSTM                15.0  23.40  17.46   0.0   6.5  25.0  34.5  59.0
# Conv1D                 15.0  48.47   6.07  38.0  46.0  49.0  51.0  59.0
# LSTM                   15.0  22.73  13.24   1.0  16.0  22.0  31.0  50.0
# MLP                    13.0  62.77  10.99  31.0  63.0  66.0  69.0  72.0
# Transformer            15.0  19.87  12.81   6.0  10.0  15.0  31.5  45.0

# %%
df_sorted_topo_models_cols.groupby("Model_bkp_2")["Classification"].describe()
# Out:
#             count unique                 top freq
# Model_bkp_2
# Bi-LSTM        15      2  intermediate_model   14
# Conv1D         15      1  intermediate_model   15
# LSTM           15      1  intermediate_model   15
# MLP            13      2  intermediate_model   12
# Transformer    15      1  intermediate_model   15

# %%
df_sorted_topo_models_cols.groupby("Model_bkp_2")[["Classification"]].value_counts()
# Out:
# Model_bkp_2  Classification
# Bi-LSTM      intermediate_model    14
#              non_dominant_model     1
# Conv1D       intermediate_model    15
# LSTM         intermediate_model    15
# MLP          intermediate_model    12
#              dominant_model         1
# Transformer  intermediate_model    15
# Name: count, dtype: int64

# %%
(
    df_sorted_topo_models_cols.groupby("Model_bkp_2")[["Classification"]]
    .value_counts(normalize=True)
    .to_frame()
    * 100
).round(2)
# Out:
#                                 proportion
# Model_bkp_2 Classification
# Bi-LSTM     intermediate_model       93.33
#             non_dominant_model        6.67
# Conv1D      intermediate_model      100.00
# LSTM        intermediate_model      100.00
# MLP         intermediate_model       92.31
#             dominant_model            7.69
# Transformer intermediate_model      100.00

# %%
df_sorted_topo_models_cols
# Out:
#    Model_bkp_2  Dominated_Count  Dominates_Count      Classification
# 26         MLP                0               72      dominant_model
# 20         MLP                1               70  intermediate_model
# 21         MLP                1               69  intermediate_model
# 25         MLP                2               69  intermediate_model
# 16         MLP                4               68  intermediate_model
# ..         ...              ...              ...                 ...
# 2         LSTM               68                4  intermediate_model
# 54     Bi-LSTM               69                3  intermediate_model
# 8         LSTM               70                1  intermediate_model
# 51     Bi-LSTM               70                1  intermediate_model
# 48     Bi-LSTM               72                0  non_dominant_model
#
# [73 rows x 4 columns]

# %%
summary_stats = df_sorted_topo_models_cols.groupby("Model_bkp_2").agg(
    Total_Models=("Model_bkp_2", "count"),
    Mean_Dominance_Count=("Dominates_Count", "mean"),
    Median_Dominance_Count=("Dominates_Count", "median"),
    Total_Dominated=("Dominated_Count", "sum"),
    Total_Dominating=("Dominates_Count", "sum"),
)

total_models = summary_stats[
    "Total_Models"
].sum()  # Get the total number of models across all categories
summary_stats["Dominance Proportion"] = summary_stats["Total_Dominating"] / total_models

# %%
summary_stats
# Out:
#              Total_Models  Mean_Dominance_Count  Median_Dominance_Count  \
# Model_bkp_2
# Bi-LSTM                15             23.400000                    25.0
# Conv1D                 15             48.466667                    49.0
# LSTM                   15             22.733333                    22.0
# MLP                    13             62.769231                    66.0
# Transformer            15             19.866667                    15.0
#
#              Total_Dominated  Total_Dominating  Dominance Proportion
# Model_bkp_2
# Bi-LSTM                  700               351              4.808219
# Conv1D                   275               727              9.958904
# LSTM                     703               341              4.671233
# MLP                      100               816             11.178082
# Transformer              755               298              4.082192

# %%
df_sorted_topo_models_grouped.T
# Out:
#             Timesteps                                                 \
#                 count      mean       std  min  25%  50%   75%   max
# Model_bkp_2
# Bi-LSTM          15.0  7.333333  5.498918  1.0  1.0  7.0  14.0  14.0
# Conv1D           15.0  7.333333  5.498918  1.0  1.0  7.0  14.0  14.0
# LSTM             15.0  7.333333  5.498918  1.0  1.0  7.0  14.0  14.0
# MLP               0.0       NaN       NaN  NaN  NaN  NaN   NaN   NaN
# Transformer      15.0  7.333333  5.498918  1.0  1.0  7.0  14.0  14.0
#
#             RMSE_mean            ... Dominated_Count       Dominates_Count  \
#                 count      mean  ...             75%   max           count
# Model_bkp_2                      ...
# Bi-LSTM          15.0  4.083984  ...            62.5  72.0            15.0
# Conv1D           15.0  1.848217  ...            23.5  29.0            15.0
# LSTM             15.0  2.795390  ...            54.0  70.0            15.0
# MLP              13.0  1.592532  ...             9.0  33.0            13.0
# Transformer      15.0  2.627488  ...            60.0  65.0            15.0
#
#
#                   mean        std   min   25%   50%   75%   max
# Model_bkp_2
# Bi-LSTM      23.400000  17.455249   0.0   6.5  25.0  34.5  59.0
# Conv1D       48.466667   6.069439  38.0  46.0  49.0  51.0  59.0
# LSTM         22.733333  13.236673   1.0  16.0  22.0  31.0  50.0
# MLP          62.769231  10.993588  31.0  63.0  66.0  69.0  72.0
# Transformer  19.866667  12.805505   6.0  10.0  15.0  31.5  45.0
#
# [5 rows x 64 columns]

# %% [markdown]
# ### SCPM Analysis

# %%
cols = [
    "Model",
    # "Model_bkp",
    "Model_bkp_2",
    "Timesteps",
    "RMSE_mean",
    "MAE_mean",
    "MAPE_mean",
    "R2_mean",
    "SCPM",
    "Dominated_Count",
    "Dominates_Count",
    "Classification",
    "Plant",
]

# %%
df_sorted_scpm = df_sorted_topo.sort_values(by="SCPM").copy()

# %%
# (df_sorted_topo[cols].reset_index() == df_sorted_scpm[cols].reset_index()).all(axis=1)
df_sorted_scpm["topo_scmp_order_eq"] = df_sorted_topo.index == df_sorted_scpm.index

# %%
# df_sorted_topo[cols].round(2).head(5)

# %%
df_sorted_scpm[cols + ["topo_scmp_order_eq"]].round(2).head(7)
# Out:
#      Model Model_bkp_2  Timesteps  RMSE_mean  MAE_mean  MAPE_mean  R2_mean  \
# 26  MLP_12         MLP        NaN       1.47      1.09       2.57     0.94
# 20   MLP_6         MLP        NaN       1.49      1.12       2.63     0.94
# 21   MLP_7         MLP        NaN       1.50      1.12       2.64     0.94
# 25  MLP_11         MLP        NaN       1.50      1.12       2.66     0.94
# 16   MLP_2         MLP        NaN       1.53      1.14       2.68     0.94
# 22   MLP_8         MLP        NaN       1.53      1.15       2.73     0.94
# 15   MLP_1         MLP        NaN       1.54      1.16       2.74     0.93
#
#     SCPM  Dominated_Count  Dominates_Count      Classification Plant  \
# 26 -1.56                0               72      dominant_model     S
# 20 -1.52                1               70  intermediate_model     S
# 21 -1.52                1               69  intermediate_model     S
# 25 -1.51                2               69  intermediate_model     S
# 16 -1.49                4               68  intermediate_model     S
# 22 -1.48                5               67  intermediate_model     S
# 15 -1.46                6               66  intermediate_model     S
#
#     topo_scmp_order_eq
# 26                True
# 20                True
# 21                True
# 25                True
# 16                True
# 22                True
# 15                True

# %% [markdown]
# ### Plant K

# %%
df_results_cm_p_cs_k = df_results_cm_p_cs[
    df_results_cm_p_cs["Plant"].eq("K")
].reset_index(drop=True)

# %%
df_results_cm_p_cs_k.shape
# Out:
# (73, 26)

# %% [markdown]
# #### Hold Out

# %%
df_results_cm_p_cs_k["Cross Validation"].unique()
# Out:
# array(['Out of time'], dtype=object)

# %%
df_results_cm_p_cs_k_ho = (
    df_results_cm_p_cs_k[df_results_cm_p_cs_k["Cross Validation"].eq("Out of time")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_p_cs_k_ho["Cross Validation"].unique()
# Out:
# array(['Out of time'], dtype=object)

# %%
df_results_cm_p_cs_k_ho.shape
# Out:
# (73, 26)

# %% [markdown]
# ###### SCPM computation

# %%
df_results_cm_p_cs_k_ho = compute_scpm(df_results_cm_p_cs_k_ho)

# %% [markdown]
# ##### Dominance Analysis

# %%
dominance_dict = make_dominance_analysis(df_results_cm_p_cs_k_ho)
dominance_matrix_cm_p_cs_k_ho = dominance_dict["dominance_matrix"]
dominance_graph_cm_p_cs_k_ho = dominance_dict["dominance_graph"]
df_sorted_count = dominance_dict["df_sorted_count"]
df_sorted_topo = dominance_dict["df_sorted_topo"]

# %%
dominance_matrix_cm_p_cs_k_ho.shape, len(dominance_graph_cm_p_cs_k_ho)
# Out:
# ((73, 73), 73)

# %%
df_sorted_topo["Classification"].value_counts()
# Out:
# Classification
# intermediate_model    71
# dominant_model         1
# non_dominant_model     1
# Name: count, dtype: int64

# %%
# df_sorted_topo.to_csv(
#     "../../../../reports/results/local_models/ecics/209_dominance_analysis_cm_kf.csv",
#     index=False,
# )

# %%
df_sorted_topo.head(5)
# Out:
#         Category  Company Plant                             Features  \
# 26  Global Model      209     K  Chemical + Mineralogical + Physical
# 21  Global Model      209     K  Chemical + Mineralogical + Physical
# 25  Global Model      209     K  Chemical + Mineralogical + Physical
# 20  Global Model      209     K  Chemical + Mineralogical + Physical
# 22  Global Model      209     K  Chemical + Mineralogical + Physical
#
#      Data Shape  Timesteps   Model  Model Params           Scaler  \
# 26  (60916, 16)        NaN  MLP_12           NaN  Standard Scaler
# 21  (60916, 16)        NaN   MLP_7           NaN  Standard Scaler
# 25  (60916, 16)        NaN  MLP_11           NaN  Standard Scaler
# 20  (60916, 16)        NaN   MLP_6           NaN  Standard Scaler
# 22  (60916, 16)        NaN   MLP_8           NaN  Standard Scaler
#
#     Scaler Params  ... MAPE_mean   R2_mean plant         Features_bkp  \
# 26            NaN  ...  2.624937  0.938098     k  Chemical + Physical
# 21            NaN  ...  2.656111  0.937947     k  Chemical + Physical
# 25            NaN  ...  2.644121  0.937268     k  Chemical + Physical
# 20            NaN  ...  2.660564  0.936892     k  Chemical + Physical
# 22            NaN  ...  2.730669  0.935629     k  Chemical + Physical
#
#     Model_bkp  Model_bkp_2      SCPM  Dominated_Count      Classification  \
# 26     MLP_12          MLP -3.128532                0      dominant_model
# 21      MLP_7          MLP -3.107214                1  intermediate_model
# 25     MLP_11          MLP -3.103618                1  intermediate_model
# 20      MLP_6          MLP -3.088933                3  intermediate_model
# 22      MLP_8          MLP -3.027017                4  intermediate_model
#
#     Dominates_Count
# 26               72
# 21               70
# 25               70
# 20               69
# 22               66
#
# [5 rows x 30 columns]

# %%
df_sorted_topo_cols = df_sorted_topo[
    [
        "Model",
        # "Model_bkp",
        # "Model_bkp_2",
        "Timesteps",
        "RMSE_mean",
        "MAE_mean",
        "MAPE_mean",
        "R2_mean",
        "SCPM",
        "Dominated_Count",
        "Classification",
        "Dominates_Count",
        "Plant",
    ]
].round(2)

# %% [markdown]
# ##### Top dominant models

# %%
# Top 4
df_sorted_topo_cols.sort_values(by="Dominates_Count", ascending=False).iloc[0:3]
# Out:
#      Model  Timesteps  RMSE_mean  MAE_mean  MAPE_mean  R2_mean  SCPM  \
# 26  MLP_12        NaN       1.50      1.12       2.62     0.94 -3.13
# 25  MLP_11        NaN       1.51      1.13       2.64     0.94 -3.10
# 21   MLP_7        NaN       1.51      1.13       2.66     0.94 -3.11
#
#     Dominated_Count      Classification  Dominates_Count Plant
# 26                0      dominant_model               72     K
# 25                1  intermediate_model               70     K
# 21                1  intermediate_model               70     K

# %% [markdown]
# ##### Top intermediate models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].sort_values(by="Dominates_Count", ascending=False).iloc[:2]
# Out:
#      Model  Timesteps  RMSE_mean  MAE_mean  MAPE_mean  R2_mean  SCPM  \
# 21   MLP_7        NaN       1.51      1.13       2.66     0.94 -3.11
# 25  MLP_11        NaN       1.51      1.13       2.64     0.94 -3.10
#
#     Dominated_Count      Classification  Dominates_Count Plant
# 21                1  intermediate_model               70     K
# 25                1  intermediate_model               70     K

# %% [markdown]
# ##### Top non dominant models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].sort_values(by="Dominated_Count", ascending=True).iloc[:2]
# Out:
#    Model  Timesteps  RMSE_mean  MAE_mean  MAPE_mean  R2_mean  SCPM  \
# 8  LSTM9       14.0       8.79      8.21      18.69    -1.11  20.7
#
#    Dominated_Count      Classification  Dominates_Count Plant
# 8               72  non_dominant_model                0     K

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        # "Model",
        # "Model_bkp",
        "Model_bkp_2",
        "Timesteps",
        "RMSE_mean",
        "MAE_mean",
        "MAPE_mean",
        "R2_mean",
        "SCPM",
        "Dominated_Count",
        "Classification",
        "Dominates_Count",
        "Plant",
    ]
]  # .round(2)

# %%
df_sorted_topo["Model_bkp_2"].value_counts()
# Out:
# Model_bkp_2
# Conv1D         15
# LSTM           15
# Bi-LSTM        15
# Transformer    15
# MLP            13
# Name: count, dtype: int64

# %%
df_sorted_topo_models_grouped = (
    df_sorted_topo_models_cols.groupby("Model_bkp_2").describe().T
)

# %%
# pd.set_option("display.max_rows", None)
# df_sorted_topo_models_grouped

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model_bkp_2",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
    ]
]

# %%
df_sorted_topo_models_cols.groupby("Model_bkp_2").describe().round(2)
# Out:
#             Dominated_Count                                              \
#                       count   mean    std   min   25%   50%   75%   max
# Model_bkp_2
# Bi-LSTM                15.0  48.27  13.64  27.0  40.0  46.0  58.0  69.0
# Conv1D                 15.0  19.73   7.66  10.0  13.5  18.0  23.0  38.0
# LSTM                   15.0  44.13  19.25  20.0  27.0  43.0  63.5  72.0
# MLP                    13.0   6.15   5.05   0.0   3.0   4.0   9.0  18.0
# Transformer            15.0  51.60  10.14  26.0  49.5  55.0  58.0  64.0
#
#             Dominates_Count
#                       count   mean    std   min   25%   50%   75%   max
# Model_bkp_2
# Bi-LSTM                15.0  21.47  12.93   1.0  12.0  24.0  31.0  39.0
# Conv1D                 15.0  48.87   8.31  32.0  44.0  52.0  55.5  60.0
# LSTM                   15.0  24.47  17.39   0.0   7.5  29.0  37.5  48.0
# MLP                    13.0  64.54   6.20  48.0  63.0  66.0  69.0  72.0
# Transformer            15.0  18.33   9.22   7.0  11.0  17.0  20.0  37.0

# %%
df_sorted_topo_models_cols.groupby("Model_bkp_2")["Classification"].describe()
# Out:
#             count unique                 top freq
# Model_bkp_2
# Bi-LSTM        15      1  intermediate_model   15
# Conv1D         15      1  intermediate_model   15
# LSTM           15      2  intermediate_model   14
# MLP            13      2  intermediate_model   12
# Transformer    15      1  intermediate_model   15

# %%
df_sorted_topo_models_cols.groupby("Model_bkp_2")[["Classification"]].value_counts()
# Out:
# Model_bkp_2  Classification
# Bi-LSTM      intermediate_model    15
# Conv1D       intermediate_model    15
# LSTM         intermediate_model    14
#              non_dominant_model     1
# MLP          intermediate_model    12
#              dominant_model         1
# Transformer  intermediate_model    15
# Name: count, dtype: int64

# %%
(
    df_sorted_topo_models_cols.groupby("Model_bkp_2")[["Classification"]]
    .value_counts(normalize=True)
    .to_frame()
    * 100
).round(2)
# Out:
#                                 proportion
# Model_bkp_2 Classification
# Bi-LSTM     intermediate_model      100.00
# Conv1D      intermediate_model      100.00
# LSTM        intermediate_model       93.33
#             non_dominant_model        6.67
# MLP         intermediate_model       92.31
#             dominant_model            7.69
# Transformer intermediate_model      100.00

# %%
df_sorted_topo_models_cols
# Out:
#    Model_bkp_2  Dominated_Count  Dominates_Count      Classification
# 26         MLP                0               72      dominant_model
# 21         MLP                1               70  intermediate_model
# 25         MLP                1               70  intermediate_model
# 20         MLP                3               69  intermediate_model
# 22         MLP                4               66  intermediate_model
# ..         ...              ...              ...                 ...
# 51     Bi-LSTM               68                2  intermediate_model
# 54     Bi-LSTM               68                3  intermediate_model
# 5         LSTM               70                1  intermediate_model
# 45     Bi-LSTM               69                1  intermediate_model
# 8         LSTM               72                0  non_dominant_model
#
# [73 rows x 4 columns]

# %%
summary_stats = df_sorted_topo_models_cols.groupby("Model_bkp_2").agg(
    Total_Models=("Model_bkp_2", "count"),
    Mean_Dominance_Count=("Dominates_Count", "mean"),
    Median_Dominance_Count=("Dominates_Count", "median"),
    Total_Dominated=("Dominated_Count", "sum"),
    Total_Dominating=("Dominates_Count", "sum"),
)

total_models = summary_stats[
    "Total_Models"
].sum()  # Get the total number of models across all categories
summary_stats["Dominance Proportion"] = summary_stats["Total_Dominating"] / total_models

# %%
summary_stats
# Out:
#              Total_Models  Mean_Dominance_Count  Median_Dominance_Count  \
# Model_bkp_2
# Bi-LSTM                15             21.466667                    24.0
# Conv1D                 15             48.866667                    52.0
# LSTM                   15             24.466667                    29.0
# MLP                    13             64.538462                    66.0
# Transformer            15             18.333333                    17.0
#
#              Total_Dominated  Total_Dominating  Dominance Proportion
# Model_bkp_2
# Bi-LSTM                  724               322              4.410959
# Conv1D                   296               733             10.041096
# LSTM                     662               367              5.027397
# MLP                       80               839             11.493151
# Transformer              774               275              3.767123

# %%
df_sorted_topo_models_grouped.T
# Out:
#             Timesteps                                                 \
#                 count      mean       std  min  25%  50%   75%   max
# Model_bkp_2
# Bi-LSTM          15.0  7.333333  5.498918  1.0  1.0  7.0  14.0  14.0
# Conv1D           15.0  7.333333  5.498918  1.0  1.0  7.0  14.0  14.0
# LSTM             15.0  7.333333  5.498918  1.0  1.0  7.0  14.0  14.0
# MLP               0.0       NaN       NaN  NaN  NaN  NaN   NaN   NaN
# Transformer      15.0  7.333333  5.498918  1.0  1.0  7.0  14.0  14.0
#
#             RMSE_mean            ... Dominated_Count       Dominates_Count  \
#                 count      mean  ...             75%   max           count
# Model_bkp_2                      ...
# Bi-LSTM          15.0  3.283718  ...            58.0  69.0            15.0
# Conv1D           15.0  1.926335  ...            23.0  38.0            15.0
# LSTM             15.0  3.365673  ...            63.5  72.0            15.0
# MLP              13.0  1.603941  ...             9.0  18.0            13.0
# Transformer      15.0  2.952267  ...            58.0  64.0            15.0
#
#
#                   mean        std   min   25%   50%   75%   max
# Model_bkp_2
# Bi-LSTM      21.466667  12.927637   1.0  12.0  24.0  31.0  39.0
# Conv1D       48.866667   8.305477  32.0  44.0  52.0  55.5  60.0
# LSTM         24.466667  17.389926   0.0   7.5  29.0  37.5  48.0
# MLP          64.538462   6.199669  48.0  63.0  66.0  69.0  72.0
# Transformer  18.333333   9.224708   7.0  11.0  17.0  20.0  37.0
#
# [5 rows x 64 columns]

# %% [markdown]
# ### SCPM Analysis

# %%
cols = [
    "Model",
    # "Model_bkp",
    "Model_bkp_2",
    "Timesteps",
    "RMSE_mean",
    "MAE_mean",
    "MAPE_mean",
    "R2_mean",
    "SCPM",
    "Dominated_Count",
    "Dominates_Count",
    "Classification",
    "Plant",
]

# %%
df_sorted_scpm = df_sorted_topo.sort_values(by="SCPM").copy()

# %%
# (df_sorted_topo[cols].reset_index() == df_sorted_scpm[cols].reset_index()).all(axis=1)
df_sorted_scpm["topo_scmp_order_eq"] = df_sorted_topo.index == df_sorted_scpm.index

# %%
# df_sorted_topo[cols].round(2).head(5)

# %%
df_sorted_scpm[cols + ["topo_scmp_order_eq"]].round(2).head(7)
# Out:
#      Model Model_bkp_2  Timesteps  RMSE_mean  MAE_mean  MAPE_mean  R2_mean  \
# 26  MLP_12         MLP        NaN       1.50      1.12       2.62     0.94
# 21   MLP_7         MLP        NaN       1.51      1.13       2.66     0.94
# 25  MLP_11         MLP        NaN       1.51      1.13       2.64     0.94
# 20   MLP_6         MLP        NaN       1.52      1.13       2.66     0.94
# 22   MLP_8         MLP        NaN       1.53      1.16       2.73     0.94
# 24  MLP_10         MLP        NaN       1.56      1.15       2.69     0.93
# 27  MLP_13         MLP        NaN       1.56      1.16       2.75     0.93
#
#     SCPM  Dominated_Count  Dominates_Count      Classification Plant  \
# 26 -3.13                0               72      dominant_model     K
# 21 -3.11                1               70  intermediate_model     K
# 25 -3.10                1               70  intermediate_model     K
# 20 -3.09                3               69  intermediate_model     K
# 22 -3.03                4               66  intermediate_model     K
# 24 -3.02                4               66  intermediate_model     K
# 27 -3.00                4               66  intermediate_model     K
#
#     topo_scmp_order_eq
# 26                True
# 21                True
# 25                True
# 20                True
# 22                True
# 24                True
# 27                True

# %% [markdown]
# # Global Analysis (fine tuning results)

# %% [markdown]
# # Definitions

# %% [markdown]
# # Topological Analysis - NEW

# %% [markdown]
# ## Definitions

# %%
# Function to compare two models strictly based on means only
def dominates(model1, model2):
    """Return True if model1 strictly dominates model2, False otherwise."""
    # Check if model1 is at least as good as model2 in all metrics
    at_least_as_good = (
        model1["RMSE_mean"] <= model2["RMSE_mean"]
        and model1["MAE_mean"] <= model2["MAE_mean"]
        and model1["MAPE_mean"] <= model2["MAPE_mean"]
        and model1["R2_mean"] >= model2["R2_mean"]
    )

    # Check if model1 is strictly better in at least one metric
    strictly_better_in_one = (
        model1["RMSE_mean"] < model2["RMSE_mean"]
        or model1["MAE_mean"] < model2["MAE_mean"]
        or model1["MAPE_mean"] < model2["MAPE_mean"]
        or model1["R2_mean"] > model2["R2_mean"]
    )

    # Model1 strictly dominates Model2 if it is at least as good in all metrics and
    # strictly better in at least one metric
    return at_least_as_good and strictly_better_in_one

# %%
def get_dominance_matrix_and_graph(df):
    n = len(df)
    dominance_matrix = np.zeros((n, n), dtype=bool)

    for i in range(n):
        for j in range(n):
            if i != j:
                dominance_matrix[i, j] = dominates(df.iloc[i], df.iloc[j])

    # Create the dominance graph
    dominance_graph = {i: [] for i in range(n)}
    for i in range(n):
        for j in range(n):
            if dominance_matrix[i, j]:
                dominance_graph[i].append(j)

    return dominance_matrix, dominance_graph

# %%
# Topological Sorting
def topological_sort(graph):
    """Perform topological sorting on the given graph."""
    in_degree = {u: 0 for u in graph}
    for u in graph:
        for v in graph[u]:
            in_degree[v] += 1

    queue = deque([u for u in graph if in_degree[u] == 0])
    topo_order = []

    while queue:
        u = queue.popleft()
        topo_order.append(u)

        for v in graph[u]:
            in_degree[v] -= 1
            if in_degree[v] == 0:
                queue.append(v)

    return topo_order

# %%
# Function to find the top models in each group
def find_top_models(group):
    max_net_dominance = group["Net_Dominance"].max()
    top_models = group[group["Net_Dominance"] == max_net_dominance]
    return top_models

# %% [markdown]
# ### Dominance Analysis and SCPM

# %%
def compute_scpm(df):
    scaler = StandardScaler()
    standardized_metrics = scaler.fit_transform(
        df[["RMSE_mean", "MAE_mean", "MAPE_mean", "R2_mean"]]
    )

    # Creating a new dataframe with standardized values
    standardized_df = pd.DataFrame(
        standardized_metrics,
        columns=["RMSE_mean", "MAE_mean", "MAPE_mean", "R2_mean"],
    )

    # Summing all metrics and subtracting R2_mean
    standardized_df["Result"] = (
        standardized_df[["RMSE_mean", "MAE_mean", "MAPE_mean"]].sum(axis=1)
        - standardized_df["R2_mean"]
    )

    df["SCPM"] = standardized_df["Result"]
    return df

# %%
def make_dominance_analysis(df):
    # Compute dominance matrix and graph
    dominance_matrix, dominance_graph = get_dominance_matrix_and_graph(df)

    # Get the topological order
    topo_order = topological_sort(dominance_graph)
    df = df.copy()
    n = len(topo_order)

    # Identify Dominant Models
    dominant_models = [
        df["Model_bkp_2"].iloc[i]
        for i in range(len(df))
        if not np.any(dominance_matrix[:, i])
    ]

    # Identify Non-Dominant Models
    non_dominant_models = [
        df["Model_bkp_2"].iloc[i]
        for i in range(len(df))
        if np.any(dominance_matrix[:, i])
    ]

    # Identify Models that are both dominated and dominate at least one
    intermediate_models = [
        df["Model_bkp_2"].iloc[i]
        for i in range(len(df))
        if np.any(dominance_matrix[:, i]) and np.any(dominance_matrix[i, :])
    ]

    # Add count of times each model is dominated by others
    df["Dominated_Count"] = np.sum(dominance_matrix, axis=0)

    # Classify models
    df["Classification"] = "intermediate_model"  # default to intermediate_model
    df.loc[
        ~np.any(dominance_matrix, axis=1) & np.any(dominance_matrix, axis=0),
        "Classification",
    ] = "non_dominant_model"
    df.loc[~np.any(dominance_matrix, axis=0), "Classification"] = "dominant_model"

    # Map the topological order to the model names and get dominance counts
    sorted_models = [df["Model"].iloc[i] for i in topo_order]

    df_sorted = df.iloc[topo_order].copy()
    df_sorted["Dominates_Count"] = dominance_matrix.sum(axis=1)[topo_order]
    df_sorted_topo = df_sorted.copy()

    df_sorted = df_sorted.sort_values(by="Dominates_Count", ascending=False)
    df_sorted_count = df_sorted.copy()

    return {
        "dominance_matrix": dominance_matrix,
        "dominance_graph": dominance_graph,
        "df_sorted_topo": df_sorted_topo,
        "df_sorted_count": df_sorted_count,
    }

# %% [markdown]
# # Reading The files

# %%
csv_files_path_fine_tuning_full = dict()
csv_files_path_fine_tuning_grouped = dict()

# %% [markdown]
# ## 209

# %% [markdown]
# ### Plant S

# %%
path_fine_tuning_full = "/home/peressim/projects/ccs28-ml-modelling/reports/results/global_models/209/s/fine_tuning/full/"
path_fine_tuning_grouped = "/home/peressim/projects/ccs28-ml-modelling/reports/results/global_models/209/s/fine_tuning/grouped/"
plant = "s"

csv_files_path_fine_tuning_full = read_csv_files_path(
    csv_files_path_fine_tuning_full, path_fine_tuning_full, plant
)

csv_files_path_fine_tuning_grouped = read_csv_files_path(
    csv_files_path_fine_tuning_grouped, path_fine_tuning_grouped, plant
)

# %% [markdown]
# ### Plant AM

# %%
path_fine_tuning_full = "/home/peressim/projects/ccs28-ml-modelling/reports/results/global_models/209/am/fine_tuning/full/"
path_fine_tuning_grouped = "/home/peressim/projects/ccs28-ml-modelling/reports/results/global_models/209/am/fine_tuning/grouped/"
plant = "am"

csv_files_path_fine_tuning_full = read_csv_files_path(
    csv_files_path_fine_tuning_full, path_fine_tuning_full, plant
)

csv_files_path_fine_tuning_grouped = read_csv_files_path(
    csv_files_path_fine_tuning_grouped, path_fine_tuning_grouped, plant
)

# %% [markdown]
# ### Plant W

# %%
path_fine_tuning_full = "/home/peressim/projects/ccs28-ml-modelling/reports/results/global_models/209/w/fine_tuning/full/"
path_fine_tuning_grouped = "/home/peressim/projects/ccs28-ml-modelling/reports/results/global_models/209/w/fine_tuning/grouped/"
plant = "w"

csv_files_path_fine_tuning_full = read_csv_files_path(
    csv_files_path_fine_tuning_full, path_fine_tuning_full, plant
)

csv_files_path_fine_tuning_grouped = read_csv_files_path(
    csv_files_path_fine_tuning_grouped, path_fine_tuning_grouped, plant
)

# %% [markdown]
# ### Plant K

# %%
path_fine_tuning_full = "/home/peressim/projects/ccs28-ml-modelling/reports/results/global_models/209/k/fine_tuning/full/"
path_fine_tuning_grouped = "/home/peressim/projects/ccs28-ml-modelling/reports/results/global_models/209/k/fine_tuning/grouped/"
plant = "k"

csv_files_path_fine_tuning_full = read_csv_files_path(
    csv_files_path_fine_tuning_full, path_fine_tuning_full, plant
)

csv_files_path_fine_tuning_grouped = read_csv_files_path(
    csv_files_path_fine_tuning_grouped, path_fine_tuning_grouped, plant
)

# %% [markdown]
# ### Reading all data - pre training

# %% [markdown]
# #### Full

# %%
dfs_plant = dict()
column = ("plant", "")
pos = 2

for plant, csv_files in csv_files_path_fine_tuning_full.items():
    df = read_csv_files_full(csv_files, plant)
    df["plant"] = plant
    dfs_plant[plant] = df

# %%
df_fine_tuning_full = pd.concat(dfs_plant.values(), ignore_index=True)

# %%
df_fine_tuning_full.shape
# Out:
# (1272, 23)

# %% [markdown]
# #### Grouped

# %%
dfs_plant = dict()
column = ("plant", "")
pos = 2

for plant, csv_files in csv_files_path_fine_tuning_grouped.items():
    df = read_csv_files_grouped(csv_files, plant)
    df["plant"] = plant
    df = preprocess_rename_columns(df)
    df = preprocess_change_columns_order(df, column, pos)
    dfs_plant[plant] = df

# %%
df_fine_tuning_grouped = pd.concat(dfs_plant.values(), ignore_index=True)

# %%
df_fine_tuning_grouped.shape
# Out:
# (96, 25)

# %%
df_copy = df_fine_tuning_grouped.copy()
df_copy = (
    df_copy.reset_index(level=0)
    .rename({"level_0": "Plant"}, axis=1)
    .reset_index(drop=True)
)

# %% [markdown]
# ## Preprocessing steps

# %%
patterns = [
    "Chemical + Mineralogical + Feature Engineering",
    "Chemical + Mineralogical + CS7 + One-Hot",
    "Chemical + Mineralogical + Physical + One-Hot",
    "Chemical + Mineralogical + CS3 + One-Hot",
    "Chemical + Mineralogical + CS3 + CS7 + One-Hot",
    "Chemical + Mineralogical + One-Hot",
    "Chemical + Mineralogical + CS1 + CS3 + CS7 + One-Hot",
    "Chemical + Mineralogical + CS1 + CS3 + One-Hot",
    "Chemical + Mineralogical + CS1 + One-Hot",
    "Chemical + Mineralogical + CS2 + One-Hot",
    "Chemical + Feature Engineering",
]

replace_dict = {
    "Chemical + Mineralogical + CS3 + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS3": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS1": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS1 + CS3": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS1 + CS3 + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS2": "Chemical + Mineralogical + Early CS",
    "Chemical + CS1 + CS3 + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + CS3 + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + CS3": "Chemical + Mineralogical + Early CS",
    "Chemical + CS1 + CS3": "Chemical + Mineralogical + Early CS",
    "Chemical + CS1": "Chemical + Mineralogical + Early CS",
    "Chemical + CS1 + CS7": "Chemical + Mineralogical + Early CS",
}

replace_dict_2 = {
    "Chemical": "Chemical + Mineralogical",
    "Chemical + Properties CS Less": "Chemical + Mineralogical + Physical - Early CS",
    "Chemical + Mineralogical + Properties CS Less": "Chemical + Mineralogical + Physical - Early CS",
    "Chemical + Physical": "Chemical + Mineralogical + Physical",
}

df_copy = df_copy[~df_copy["Cross Validation"].eq("Out of time Split")].reset_index(
    drop=True
)

# Removing afterwards
df_copy = df_copy[~df_copy["Cross Validation"].eq("Repeated KFold")].reset_index(
    drop=True
)

df_copy = df_copy[~df_copy["Features"].apply(lambda x: x in patterns)].reset_index(
    drop=True
)
df_copy["Features_bkp"] = df_copy["Features"].copy()
df_copy["Features"] = df_copy["Features"].replace(replace_dict)

df_copy["Features"] = df_copy["Features"].replace(replace_dict_2)

# Removing afterwards
# df_copy = df_copy[
#     ~df_copy["Features"].eq("Chemical + Mineralogical + Early CS")
# ].reset_index(drop=True)

# %%
df_copy[("MAPE Train", "mean")] = df_copy[("MAPE Train", "mean")] * 100
df_copy[("MAPE Train", "std")] = df_copy[("MAPE Train", "std")] * 100
df_copy[("MAPE Test", "mean")] = df_copy[("MAPE Test", "mean")] * 100
df_copy[("MAPE Test", "std")] = df_copy[("MAPE Test", "std")] * 100

df_copy["Model_bkp"] = df_copy["Model"].copy()
df_copy["Model_bkp_2"] = df_copy["Model"] + df_copy["Timesteps"].apply(
    lambda x: "" if pd.isna(x) else "_" + str(x)
)
df_copy["Model"] = df_copy["Model"].replace(
    {
        "MLP": "Neural Networks",
        "LSTM": "Neural Networks",
        "GRU": "Neural Networks",
        "BidirectionalLSTM": "Neural Networks",
        "BidirectionalGRU": "Neural Networks",
        "Transformer": "Neural Networks",
        "Decision Tree": "Trees",
        "Random Forest": "Trees",
        "XGBoost": "Trees",
    }
)

# %%
df_copy["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split', 'Time Series Split'], dtype=object)

# %%
df_copy["Features"].unique()
# Out:
# array(['Chemical + Mineralogical', 'Chemical + Mineralogical + Physical',
#        'Chemical + Mineralogical + Physical - Early CS'], dtype=object)

# %%
df_copy["Model"].unique()
# Out:
# array(['Neural Networks', 'Conv1D'], dtype=object)

# %%
df_copy["Model_bkp"].unique()
# Out:
# array(['Transformer', 'MLP', 'BidirectionalLSTM', 'Conv1D', 'LSTM'],
#       dtype=object)

# %%
df_copy["Model_bkp_2"].unique()
# Out:
# array(['Transformer_1.0', 'MLP', 'BidirectionalLSTM_7.0', 'Conv1D_7.0',
#        'LSTM_14.0', 'Conv1D_1.0', 'LSTM_1.0', 'BidirectionalLSTM_1.0',
#        'Transformer_14.0', 'BidirectionalLSTM_14.0', 'LSTM_7.0'],
#       dtype=object)

# %%
df_copy.shape
# Out:
# (68, 29)

# %%
df_copy_grouped = df_copy.copy()

# %%
df_copy[
    [
        ("RMSE Test", "mean"),
        ("MAE Test", "mean"),
        ("MAPE Test", "mean"),
        ("R2 Test", "mean"),
    ]
].describe().round(2).T
# Out:
#                 count  mean   std   min   25%   50%   75%   max
# RMSE Test mean   68.0  1.84  1.15  0.71  1.18  1.46  2.01  8.44
# MAE Test  mean   68.0  1.30  0.62  0.54  0.87  1.11  1.44  3.86
# MAPE Test mean   68.0  3.10  1.45  1.34  2.15  2.62  3.47  8.99
# R2 Test   mean   68.0  0.79  0.44 -1.78  0.85  0.93  0.95  0.98

# %%
df_copy["plant"].unique()
# Out:
# array(['s', 'am', 'w', 'k'], dtype=object)

# %% [markdown]
# # Global Analysis (fine tuning results)

# %% [markdown]
# ## 209

# %%
df_209_grouped = df_copy.copy()

# %%
df_results = df_209_grouped[
    [
        ("Company", ""),
        ("plant", ""),
        ("Cross Validation", ""),
        ("Features", ""),
        ('Features_bkp', ''),
        ("Model", ""),
        ("Model_bkp", ""),         
        ('Model_bkp_2',''),
        ("Timesteps", ""),
        ("RMSE Test", "mean"),
        ("MAE Test", "mean"),
        ("MAPE Test", "mean"),
        ("R2 Test", "mean"),
        ("RMSE Test", "std"),
        ("MAE Test", "std"),
        ("MAPE Test", "std"),
        ("R2 Test", "std"),
    ]
].copy()
df_results = df_results.reset_index(drop=True)

# Rename columns
new_column_names = [
    "Company",
    "Plant",
    "Cross Validation",
    "Features",
    "Features_bkp",
    "Model",
    "Model_bkp",
    "Model_bkp_2",
    "Timesteps",
    "RMSE_mean",
    "MAE_mean",
    "MAPE_mean",
    "R2_mean",
    "RMSE_std",
    "MAE_std",
    "MAPE_std",
    "R2_std",
]

df_results.columns = new_column_names

# %%
df_results.shape
# Out:
# (68, 17)

# %%
df_results["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split', 'Time Series Split'], dtype=object)

# %% [markdown]
# ## Variable Grouping: CM

# %% [markdown]
# #### Analysis of the best models identified in the Local Analysis

# %% [markdown]
# **Best models for variable groupping CM were from:**
#
# *BTiSS:*
#     Dominance analysis: Plant S
#     SCPM:Plant S
#
# *TiSS:*
#     Dominance analysis: Plant S
#     SCPM:Plant S

# %%
df_results["Features"].unique()
# Out:
# array(['Chemical + Mineralogical', 'Chemical + Mineralogical + Physical',
#        'Chemical + Mineralogical + Physical - Early CS'], dtype=object)

# %%
df_results_cm = (
    df_results[df_results["Features"].eq("Chemical + Mineralogical")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm["Features"].unique()
# Out:
# array(['Chemical + Mineralogical'], dtype=object)

# %%
df_results_cm.shape
# Out:
# (18, 17)

# %% [markdown]
# ### Plant S

# %%
df_results_cm = df_results_cm[df_results_cm["Plant"].eq("s")].reset_index(drop=True)

# %% [markdown]
# ### Blocking time series

# %%
df_results_cm["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split', 'Time Series Split'], dtype=object)

# %%
df_results_cm_btss = (
    df_results_cm[df_results_cm["Cross Validation"].eq("Blocking Time Series Split")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_btss["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split'], dtype=object)

# %%
df_results_cm_btss.shape
# Out:
# (5, 17)

# %% [markdown]
# ###### SCPM computation

# %%
df_results_cm_btss = compute_scpm(df_results_cm_btss)

# %% [markdown]
# ##### Dominance Analysis

# %%
# Per project
dominance_dict = make_dominance_analysis(df_results_cm_btss)
dominance_matrix_cm_btss = dominance_dict["dominance_matrix"]
dominance_graph_cm_btss = dominance_dict["dominance_graph"]
df_sorted_count = dominance_dict["df_sorted_count"]
df_sorted_topo = dominance_dict["df_sorted_topo"]

# %%
dominance_matrix_cm_btss.shape, len(dominance_graph_cm_btss)
# Out:
# ((5, 5), 5)

# %%
df_sorted_topo["Classification"].value_counts()
# Out:
# Classification
# dominant_model        2
# intermediate_model    2
# non_dominant_model    1
# Name: count, dtype: int64

# %%
df_sorted_topo.to_csv(
    "../../../../reports/results/global_models/ecics/209_s_dominance_analysis_cm_btss.csv",
    index=False,
)

# %%
df_sorted_topo.head(5)
# Out:
#    Company Plant            Cross Validation                  Features  \
# 0      209     s  Blocking Time Series Split  Chemical + Mineralogical
# 3      209     s  Blocking Time Series Split  Chemical + Mineralogical
# 2      209     s  Blocking Time Series Split  Chemical + Mineralogical
# 4      209     s  Blocking Time Series Split  Chemical + Mineralogical
# 1      209     s  Blocking Time Series Split  Chemical + Mineralogical
#
#   Features_bkp            Model          Model_bkp            Model_bkp_2  \
# 0     Chemical  Neural Networks        Transformer        Transformer_1.0
# 3     Chemical  Neural Networks                MLP                    MLP
# 2     Chemical           Conv1D             Conv1D             Conv1D_7.0
# 4     Chemical  Neural Networks               LSTM              LSTM_14.0
# 1     Chemical  Neural Networks  BidirectionalLSTM  BidirectionalLSTM_7.0
#
#    Timesteps  RMSE_mean  ...  MAPE_mean   R2_mean  RMSE_std   MAE_std  \
# 0        1.0   1.162410  ...   2.142578  0.946410  0.422754  0.235959
# 3        NaN   1.213463  ...   2.326368  0.949241  0.137581  0.084595
# 2        7.0   1.437166  ...   2.612071  0.929066  0.312455  0.202023
# 4       14.0   2.393818  ...   4.651054  0.760966  1.211175  0.869840
# 1        7.0   3.700777  ...   6.794265  0.313188  2.280101  1.430805
#
#    MAPE_std    R2_std      SCPM  Dominated_Count      Classification  \
# 0  0.610615  0.041380 -3.271616                0      dominant_model
# 3  0.223857  0.011280 -3.013663                0      dominant_model
# 2  0.393569  0.024494 -2.358700                2  intermediate_model
# 4  2.401948  0.296117  1.438587                3  intermediate_model
# 1  3.345232  1.190779  7.205392                4  non_dominant_model
#
#   Dominates_Count
# 0               3
# 3               3
# 2               2
# 4               1
# 1               0
#
# [5 rows x 21 columns]

# %%
df_sorted_topo_cols = df_sorted_topo[
    [
        # "Model",
        # "Model_bkp",
        "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Classification",
        "Dominates_Count",
        "Plant",
    ]
].round(2)

# %% [markdown]
# ###### Dominant Models

# %%
# Top 4
df_sorted_topo_cols.iloc[0:5]
# Out:
#              Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 0        Transformer_1.0       1.16      0.42      0.86     0.24       2.14
# 3                    MLP       1.21      0.14      0.94     0.08       2.33
# 2             Conv1D_7.0       1.44      0.31      1.08     0.20       2.61
# 4              LSTM_14.0       2.39      1.21      1.79     0.87       4.65
# 1  BidirectionalLSTM_7.0       3.70      2.28      2.80     1.43       6.79
#
#    MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 0      0.61     0.95    0.04 -3.27                0      dominant_model
# 3      0.22     0.95    0.01 -3.01                0      dominant_model
# 2      0.39     0.93    0.02 -2.36                2  intermediate_model
# 4      2.40     0.76    0.30  1.44                3  intermediate_model
# 1      3.35     0.31    1.19  7.21                4  non_dominant_model
#
#    Dominates_Count Plant
# 0                3     s
# 3                3     s
# 2                2     s
# 4                1     s
# 1                0     s

# %%
df_sorted_topo_cols[df_sorted_topo_cols["Classification"].eq("dominant_model")].shape
# Out:
# (2, 14)

# %% [markdown]
# ###### Intermediate models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].sort_values(by=["Dominates_Count", "SCPM"], ascending=[False, True]).iloc[:3]
# Out:
#   Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  MAPE_std  \
# 2  Conv1D_7.0       1.44      0.31      1.08     0.20       2.61      0.39
# 4   LSTM_14.0       2.39      1.21      1.79     0.87       4.65      2.40
#
#    R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 2     0.93    0.02 -2.36                2  intermediate_model
# 4     0.76    0.30  1.44                3  intermediate_model
#
#    Dominates_Count Plant
# 2                2     s
# 4                1     s

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].shape
# Out:
# (2, 14)

# %% [markdown]
# ###### non-dominant models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].sort_values(by=["Dominates_Count", "SCPM"], ascending=[False, True]).iloc[:2]
# Out:
#              Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 1  BidirectionalLSTM_7.0        3.7      2.28       2.8     1.43       6.79
#
#    MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 1      3.35     0.31    1.19  7.21                4  non_dominant_model
#
#    Dominates_Count Plant
# 1                0     s

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].shape
# Out:
# (1, 14)

# %% [markdown]
# ###### Statistics per model type

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        # "Model_bkp",
        # "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
        "Plant",
    ]
]  # .round(2)

# %%
df_sorted_topo["Model"].value_counts()
# Out:
# Model
# Neural Networks    4
# Conv1D             1
# Name: count, dtype: int64

# %%
df_sorted_topo_models_grouped = df_sorted_topo_models_cols.groupby("Model").describe().T

# %%
# pd.set_option("display.max_rows", None)
# df_sorted_topo_models_grouped

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
    ]
]

# %%
(
    df_sorted_topo_models_cols.groupby("Model")[["Classification"]]
    .value_counts(normalize=True)
    .to_frame()
    * 100
).round(2)
# Out:
#                                     proportion
# Model           Classification
# Conv1D          intermediate_model       100.0
# Neural Networks dominant_model            50.0
#                 intermediate_model        25.0
#                 non_dominant_model        25.0

# %%
df_sorted_topo_models_cols.groupby("Model").describe().round(2).T
# Out:
# Model                  Conv1D  Neural Networks
# Dominated_Count count     1.0             4.00
#                 mean      2.0             1.75
#                 std       NaN             2.06
#                 min       2.0             0.00
#                 25%       2.0             0.00
#                 50%       2.0             1.50
#                 75%       2.0             3.25
#                 max       2.0             4.00
# Dominates_Count count     1.0             4.00
#                 mean      2.0             1.75
#                 std       NaN             1.50
#                 min       2.0             0.00
#                 25%       2.0             0.75
#                 50%       2.0             2.00
#                 75%       2.0             3.00
#                 max       2.0             3.00

# %%
# df_sorted_topo_models_cols

# %%
df_sorted_topo_models_cols.groupby("Model")["Classification"].describe()
# Out:
#                 count unique                 top freq
# Model
# Conv1D              1      1  intermediate_model    1
# Neural Networks     4      3      dominant_model    2

# %%
df_sorted_topo_models_cols.groupby("Model")[["Classification"]].value_counts()
# Out:
# Model            Classification
# Conv1D           intermediate_model    1
# Neural Networks  dominant_model        2
#                  intermediate_model    1
#                  non_dominant_model    1
# Name: count, dtype: int64

# %%
# df_sorted_topo_models_cols

# %%
summary_stats = df_sorted_topo_models_cols.groupby("Model").agg(
    Total_Models=("Model", "count"),
    Mean_Dominance_Count=("Dominates_Count", "mean"),
    Median_Dominance_Count=("Dominates_Count", "median"),
    Total_Dominated=("Dominated_Count", "sum"),
    Total_Dominating=("Dominates_Count", "sum"),
)

total_models = summary_stats[
    "Total_Models"
].sum()  # Get the total number of models across all categories
summary_stats["Dominance Proportion"] = summary_stats["Total_Dominating"] / total_models

# %%
summary_stats
# Out:
#                  Total_Models  Mean_Dominance_Count  Median_Dominance_Count  \
# Model
# Conv1D                      1                  2.00                     2.0
# Neural Networks             4                  1.75                     2.0
#
#                  Total_Dominated  Total_Dominating  Dominance Proportion
# Model
# Conv1D                         2                 2                   0.4
# Neural Networks                7                 7                   1.4

# %%
df_sorted_topo_models_grouped.T
# Out:
#                 RMSE_mean                                                    \
#                     count      mean       std       min       25%       50%
# Model
# Conv1D                1.0  1.437166       NaN  1.437166  1.437166  1.437166
# Neural Networks       4.0  2.117617  1.198971  1.162410  1.200700  1.803641
#
#                                     RMSE_std            ... Dominated_Count  \
#                       75%       max    count      mean  ...             75%
# Model                                                   ...
# Conv1D           1.437166  1.437166      1.0  0.312455  ...            2.00
# Neural Networks  2.720558  3.700777      4.0  1.012903  ...            3.25
#
#                      Dominates_Count
#                  max           count  mean  std  min   25%  50%  75%  max
# Model
# Conv1D           2.0             1.0  2.00  NaN  2.0  2.00  2.0  2.0  2.0
# Neural Networks  4.0             4.0  1.75  1.5  0.0  0.75  2.0  3.0  3.0
#
# [2 rows x 88 columns]

# %% [markdown]
# ### SCPM Analysis

# %%
cols = [
    # "Model",
    # "Model_bkp",
    "Model_bkp_2",
    "RMSE_mean",
    "RMSE_std",
    "MAE_mean",
    "MAE_std",
    "MAPE_mean",
    "MAPE_std",
    "R2_mean",
    "R2_std",
    "SCPM",
    "Dominated_Count",
    "Dominates_Count",
    "Classification",
    "Plant",
]

# %% [markdown]
# #### SCPM Analysis by Project

# %%
df_sorted_scpm = df_sorted_topo.sort_values(by="SCPM").copy()

# %%
# (df_sorted_topo[cols].reset_index() == df_sorted_scpm[cols].reset_index()).all(axis=1)
df_sorted_scpm["topo_scmp_order_eq"] = df_sorted_topo.index == df_sorted_scpm.index

# %%
df_sorted_scpm[cols + ["topo_scmp_order_eq"]].round(2).head(5)
# Out:
#              Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 0        Transformer_1.0       1.16      0.42      0.86     0.24       2.14
# 3                    MLP       1.21      0.14      0.94     0.08       2.33
# 2             Conv1D_7.0       1.44      0.31      1.08     0.20       2.61
# 4              LSTM_14.0       2.39      1.21      1.79     0.87       4.65
# 1  BidirectionalLSTM_7.0       3.70      2.28      2.80     1.43       6.79
#
#    MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count  Dominates_Count  \
# 0      0.61     0.95    0.04 -3.27                0                3
# 3      0.22     0.95    0.01 -3.01                0                3
# 2      0.39     0.93    0.02 -2.36                2                2
# 4      2.40     0.76    0.30  1.44                3                1
# 1      3.35     0.31    1.19  7.21                4                0
#
#        Classification Plant  topo_scmp_order_eq
# 0      dominant_model     s                True
# 3      dominant_model     s                True
# 2  intermediate_model     s                True
# 4  intermediate_model     s                True
# 1  non_dominant_model     s                True

# %% [markdown]
# ### Time Series Split

# %%
df_results_cm["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split', 'Time Series Split'], dtype=object)

# %%
df_results_cm_tss = (
    df_results_cm[df_results_cm["Cross Validation"].eq("Time Series Split")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_tss["Cross Validation"].unique()
# Out:
# array(['Time Series Split'], dtype=object)

# %%
df_results_cm_tss.shape
# Out:
# (5, 17)

# %% [markdown]
# ###### SCPM computation

# %%
df_results_cm_tss = compute_scpm(df_results_cm_tss)

# %% [markdown]
# ##### Dominance Analysis

# %%
# Per project
dominance_dict = make_dominance_analysis(df_results_cm_tss)
dominance_matrix_cm_tss = dominance_dict["dominance_matrix"]
dominance_graph_cm_tss = dominance_dict["dominance_graph"]
df_sorted_count = dominance_dict["df_sorted_count"]
df_sorted_topo = dominance_dict["df_sorted_topo"]

# %%
dominance_matrix_cm_tss.shape, len(dominance_graph_cm_tss)
# Out:
# ((5, 5), 5)

# %%
df_sorted_topo["Classification"].value_counts()
# Out:
# Classification
# intermediate_model    3
# dominant_model        1
# non_dominant_model    1
# Name: count, dtype: int64

# %%
df_sorted_topo.to_csv(
    "../../../../reports/results/global_models/ecics/209_s_dominance_analysis_cm_tss.csv",
    index=False,
)

# %%
df_sorted_topo.head(5)
# Out:
#    Company Plant   Cross Validation                  Features Features_bkp  \
# 0      209     s  Time Series Split  Chemical + Mineralogical     Chemical
# 3      209     s  Time Series Split  Chemical + Mineralogical     Chemical
# 2      209     s  Time Series Split  Chemical + Mineralogical     Chemical
# 4      209     s  Time Series Split  Chemical + Mineralogical     Chemical
# 1      209     s  Time Series Split  Chemical + Mineralogical     Chemical
#
#              Model          Model_bkp            Model_bkp_2  Timesteps  \
# 0  Neural Networks        Transformer        Transformer_1.0        1.0
# 3  Neural Networks                MLP                    MLP        NaN
# 2           Conv1D             Conv1D             Conv1D_7.0        7.0
# 4  Neural Networks               LSTM              LSTM_14.0       14.0
# 1  Neural Networks  BidirectionalLSTM  BidirectionalLSTM_7.0        7.0
#
#    RMSE_mean  ...  MAPE_mean   R2_mean  RMSE_std   MAE_std  MAPE_std  \
# 0   1.311009  ...   2.147842  0.935433  0.216608  0.097950  0.192730
# 3   1.387445  ...   2.446752  0.926810  0.355405  0.238475  0.506784
# 2   1.557909  ...   2.823972  0.910436  0.148739  0.112064  0.215531
# 4   1.951237  ...   3.600900  0.856122  0.375631  0.313801  0.796740
# 1   2.907399  ...   5.452278  0.670463  0.727911  0.588969  1.413314
#
#      R2_std      SCPM  Dominated_Count      Classification Dominates_Count
# 0  0.019644 -3.554423                0      dominant_model               4
# 3  0.033572 -2.837274                1  intermediate_model               3
# 2  0.011473 -1.729965                2  intermediate_model               2
# 4  0.055328  0.665817                3  intermediate_model               1
# 1  0.145463  7.455845                4  non_dominant_model               0
#
# [5 rows x 21 columns]

# %%
df_sorted_topo_cols = df_sorted_topo[
    [
        # "Model",
        # "Model_bkp",
        "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Classification",
        "Dominates_Count",
        "Plant",
    ]
]  # .round(2)

# %% [markdown]
# ###### Dominant Models

# %%
# Top 4
df_sorted_topo_cols.iloc[0:2].sort_values(by="Dominates_Count", ascending=False).round(
    2
)
# Out:
#        Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 0  Transformer_1.0       1.31      0.22      0.88     0.10       2.15
# 3              MLP       1.39      0.36      1.00     0.24       2.45
#
#    MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 0      0.19     0.94    0.02 -3.55                0      dominant_model
# 3      0.51     0.93    0.03 -2.84                1  intermediate_model
#
#    Dominates_Count Plant
# 0                4     s
# 3                3     s

# %%
df_sorted_topo_cols[df_sorted_topo_cols["Classification"].eq("dominant_model")].shape
# Out:
# (1, 14)

# %% [markdown]
# ###### Intermediate models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].sort_values(by=["Dominates_Count", "SCPM"], ascending=[False, True]).iloc[:4].round(2)
# Out:
#   Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  MAPE_std  \
# 3         MLP       1.39      0.36      1.00     0.24       2.45      0.51
# 2  Conv1D_7.0       1.56      0.15      1.16     0.11       2.82      0.22
# 4   LSTM_14.0       1.95      0.38      1.41     0.31       3.60      0.80
#
#    R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 3     0.93    0.03 -2.84                1  intermediate_model
# 2     0.91    0.01 -1.73                2  intermediate_model
# 4     0.86    0.06  0.67                3  intermediate_model
#
#    Dominates_Count Plant
# 3                3     s
# 2                2     s
# 4                1     s

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].shape
# Out:
# (3, 14)

# %% [markdown]
# ###### non-dominant models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].sort_values(by=["Dominates_Count", "SCPM"], ascending=[False, True]).iloc[:3]
# Out:
#              Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean   MAE_std  MAPE_mean  \
# 1  BidirectionalLSTM_7.0   2.907399  0.727911  2.253783  0.588969   5.452278
#
#    MAPE_std   R2_mean    R2_std      SCPM  Dominated_Count  \
# 1  1.413314  0.670463  0.145463  7.455845                4
#
#        Classification  Dominates_Count Plant
# 1  non_dominant_model                0     s

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].shape
# Out:
# (1, 14)

# %% [markdown]
# ###### Statistics per model type

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        # "Model_bkp",
        # "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
        "Plant",
    ]
]  # .round(2)

# %%
df_sorted_topo["Model"].value_counts()
# Out:
# Model
# Neural Networks    4
# Conv1D             1
# Name: count, dtype: int64

# %%
df_sorted_topo_models_grouped = df_sorted_topo_models_cols.groupby("Model").describe().T

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
    ]
]

# %%
(
    df_sorted_topo_models_cols.groupby("Model")[["Classification"]]
    .value_counts(normalize=True)
    .to_frame()
    * 100
).round(2)
# Out:
#                                     proportion
# Model           Classification
# Conv1D          intermediate_model       100.0
# Neural Networks intermediate_model        50.0
#                 dominant_model            25.0
#                 non_dominant_model        25.0

# %%
df_sorted_topo_models_cols.groupby("Model").describe().round(2).T
# Out:
# Model                  Conv1D  Neural Networks
# Dominated_Count count     1.0             4.00
#                 mean      2.0             2.00
#                 std       NaN             1.83
#                 min       2.0             0.00
#                 25%       2.0             0.75
#                 50%       2.0             2.00
#                 75%       2.0             3.25
#                 max       2.0             4.00
# Dominates_Count count     1.0             4.00
#                 mean      2.0             2.00
#                 std       NaN             1.83
#                 min       2.0             0.00
#                 25%       2.0             0.75
#                 50%       2.0             2.00
#                 75%       2.0             3.25
#                 max       2.0             4.00

# %%
# df_sorted_topo_models_cols

# %%
df_sorted_topo_models_cols.groupby("Model")["Classification"].describe()
# Out:
#                 count unique                 top freq
# Model
# Conv1D              1      1  intermediate_model    1
# Neural Networks     4      3  intermediate_model    2

# %%
df_sorted_topo_models_cols.groupby("Model")[["Classification"]].value_counts()
# Out:
# Model            Classification
# Conv1D           intermediate_model    1
# Neural Networks  intermediate_model    2
#                  dominant_model        1
#                  non_dominant_model    1
# Name: count, dtype: int64

# %%
summary_stats = df_sorted_topo_models_cols.groupby("Model").agg(
    Total_Models=("Model", "count"),
    Mean_Dominance_Count=("Dominates_Count", "mean"),
    Median_Dominance_Count=("Dominates_Count", "median"),
    Total_Dominated=("Dominated_Count", "sum"),
    Total_Dominating=("Dominates_Count", "sum"),
)

total_models = summary_stats[
    "Total_Models"
].sum()  # Get the total number of models across all categories
summary_stats["Dominance Proportion"] = summary_stats["Total_Dominating"] / total_models

# %%
summary_stats.round(2)
# Out:
#                  Total_Models  Mean_Dominance_Count  Median_Dominance_Count  \
# Model
# Conv1D                      1                   2.0                     2.0
# Neural Networks             4                   2.0                     2.0
#
#                  Total_Dominated  Total_Dominating  Dominance Proportion
# Model
# Conv1D                         2                 2                   0.4
# Neural Networks                8                 8                   1.6

# %%
df_sorted_topo_models_grouped.T
# Out:
#                 RMSE_mean                                                    \
#                     count      mean       std       min       25%       50%
# Model
# Conv1D                1.0  1.557909       NaN  1.557909  1.557909  1.557909
# Neural Networks       4.0  1.889272  0.736351  1.311009  1.368336  1.669341
#
#                                     RMSE_std            ... Dominated_Count  \
#                       75%       max    count      mean  ...             75%
# Model                                                   ...
# Conv1D           1.557909  1.557909      1.0  0.148739  ...            2.00
# Neural Networks  2.190277  2.907399      4.0  0.418889  ...            3.25
#
#                      Dominates_Count
#                  max           count mean       std  min   25%  50%   75%  max
# Model
# Conv1D           2.0             1.0  2.0       NaN  2.0  2.00  2.0  2.00  2.0
# Neural Networks  4.0             4.0  2.0  1.825742  0.0  0.75  2.0  3.25  4.0
#
# [2 rows x 88 columns]

# %% [markdown]
# ### SCPM Analysis

# %%
cols = [
    # "Model",
    # "Model_bkp",
    "Model_bkp_2",
    "RMSE_mean",
    "RMSE_std",
    "MAE_mean",
    "MAE_std",
    "MAPE_mean",
    "MAPE_std",
    "R2_mean",
    "R2_std",
    "SCPM",
    "Dominated_Count",
    "Dominates_Count",
    "Classification",
    "Plant",
]

# %% [markdown]
# #### SCPM Analysis by Project

# %%
df_sorted_scpm = df_sorted_topo.sort_values(by="SCPM").copy()

# %%
# (df_sorted_topo[cols].reset_index() == df_sorted_scpm[cols].reset_index()).all(axis=1)
df_sorted_scpm["topo_scmp_order_eq"] = df_sorted_topo.index == df_sorted_scpm.index

# %%
df_sorted_scpm[cols + ["topo_scmp_order_eq"]].round(2).head(5)
# Out:
#              Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 0        Transformer_1.0       1.31      0.22      0.88     0.10       2.15
# 3                    MLP       1.39      0.36      1.00     0.24       2.45
# 2             Conv1D_7.0       1.56      0.15      1.16     0.11       2.82
# 4              LSTM_14.0       1.95      0.38      1.41     0.31       3.60
# 1  BidirectionalLSTM_7.0       2.91      0.73      2.25     0.59       5.45
#
#    MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count  Dominates_Count  \
# 0      0.19     0.94    0.02 -3.55                0                4
# 3      0.51     0.93    0.03 -2.84                1                3
# 2      0.22     0.91    0.01 -1.73                2                2
# 4      0.80     0.86    0.06  0.67                3                1
# 1      1.41     0.67    0.15  7.46                4                0
#
#        Classification Plant  topo_scmp_order_eq
# 0      dominant_model     s                True
# 3  intermediate_model     s                True
# 2  intermediate_model     s                True
# 4  intermediate_model     s                True
# 1  non_dominant_model     s                True

# %% [markdown]
# ## Variable Grouping: CM-P

# %% [markdown]
# #### Analysis of the best models identified in the Local Analysis

# %% [markdown]
# **Best models for variable groupping CM-P were from:**
#
# *BTiSS:*
#     Dominance analysis: Plant AM
#     SCPM:Plant AM
#
# *TiSS:*
#     Dominance analysis: Plant W
#     SCPM:Plant W

# %%
df_results["Features"].unique()
# Out:
# array(['Chemical + Mineralogical', 'Chemical + Mineralogical + Physical',
#        'Chemical + Mineralogical + Physical - Early CS'], dtype=object)

# %%
df_results_cm_p = (
    df_results[
        df_results["Features"].eq("Chemical + Mineralogical + Physical - Early CS")
    ]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_p["Features"].unique()
# Out:
# array(['Chemical + Mineralogical + Physical - Early CS'], dtype=object)

# %%
df_results_cm_p.shape
# Out:
# (20, 17)

# %% [markdown]
# ### Plant AM

# %%
df_results_cm_p = df_results_cm_p[df_results_cm_p["Plant"].eq("am")].reset_index(
    drop=True
)

# %% [markdown]
# ### Blocking time series

# %%
df_results_cm_p["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split', 'Time Series Split'], dtype=object)

# %%
df_results_cm_p_btss = (
    df_results_cm_p[
        df_results_cm_p["Cross Validation"].eq("Blocking Time Series Split")
    ]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_p_btss["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split'], dtype=object)

# %%
df_results_cm_p_btss.shape
# Out:
# (5, 17)

# %% [markdown]
# ###### SCPM computation

# %%
df_results_cm_p_btss = compute_scpm(df_results_cm_p_btss)

# %% [markdown]
# ##### Dominance Analysis

# %%
# Per project
dominance_dict = make_dominance_analysis(df_results_cm_p_btss)
dominance_matrix_cm_p_btss = dominance_dict["dominance_matrix"]
dominance_graph_cm_p_btss = dominance_dict["dominance_graph"]
df_sorted_count = dominance_dict["df_sorted_count"]
df_sorted_topo = dominance_dict["df_sorted_topo"]

# %%
dominance_matrix_cm_p_btss.shape, len(dominance_graph_cm_p_btss)
# Out:
# ((5, 5), 5)

# %%
df_sorted_topo["Classification"].value_counts()
# Out:
# Classification
# intermediate_model    3
# dominant_model        1
# non_dominant_model    1
# Name: count, dtype: int64

# %%
df_sorted_topo.to_csv(
    "../../../../reports/results/global_models/ecics/209_am_dominance_analysis_cm_p_btss.csv",
    index=False,
)

# %%
df_sorted_topo.head(5)
# Out:
#    Company Plant            Cross Validation  \
# 0      209    am  Blocking Time Series Split
# 3      209    am  Blocking Time Series Split
# 1      209    am  Blocking Time Series Split
# 4      209    am  Blocking Time Series Split
# 2      209    am  Blocking Time Series Split
#
#                                          Features  \
# 0  Chemical + Mineralogical + Physical - Early CS
# 3  Chemical + Mineralogical + Physical - Early CS
# 1  Chemical + Mineralogical + Physical - Early CS
# 4  Chemical + Mineralogical + Physical - Early CS
# 2  Chemical + Mineralogical + Physical - Early CS
#
#                     Features_bkp            Model          Model_bkp  \
# 0  Chemical + Properties CS Less  Neural Networks                MLP
# 3  Chemical + Properties CS Less           Conv1D             Conv1D
# 1  Chemical + Properties CS Less  Neural Networks  BidirectionalLSTM
# 4  Chemical + Properties CS Less  Neural Networks        Transformer
# 2  Chemical + Properties CS Less  Neural Networks               LSTM
#
#              Model_bkp_2  Timesteps  RMSE_mean  ...  MAPE_mean   R2_mean  \
# 0                    MLP        NaN   0.977688  ...   1.817851  0.972777
# 3             Conv1D_7.0        7.0   1.321790  ...   2.439990  0.951914
# 1  BidirectionalLSTM_7.0        7.0   1.396904  ...   2.591385  0.944418
# 4        Transformer_1.0        1.0   1.370688  ...   2.579751  0.942873
# 2               LSTM_7.0        7.0   1.783077  ...   3.162759  0.907087
#
#    RMSE_std   MAE_std  MAPE_std    R2_std      SCPM  Dominated_Count  \
# 0  0.079910  0.055835  0.125100  0.002697 -6.142056                0
# 3  0.151181  0.094707  0.219578  0.007694 -0.941569                1
# 1  0.214808  0.176594  0.422295  0.019869  0.468387                2
# 4  0.236311  0.214490  0.512886  0.026853  0.251325                2
# 2  0.344122  0.183404  0.423823  0.045363  6.363913                4
#
#        Classification Dominates_Count
# 0      dominant_model               4
# 3  intermediate_model               3
# 1  intermediate_model               1
# 4  intermediate_model               1
# 2  non_dominant_model               0
#
# [5 rows x 21 columns]

# %%
df_sorted_topo_cols = df_sorted_topo[
    [
        # "Model",
        # "Model_bkp",
        "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Classification",
        "Dominates_Count",
        "Plant",
    ]
].round(2)

# %% [markdown]
# ###### Dominant Models

# %%
# Top 4
df_sorted_topo_cols.iloc[0:5]
# Out:
#              Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 0                    MLP       0.98      0.08      0.75     0.06       1.82
# 3             Conv1D_7.0       1.32      0.15      1.01     0.09       2.44
# 1  BidirectionalLSTM_7.0       1.40      0.21      1.09     0.18       2.59
# 4        Transformer_1.0       1.37      0.24      1.06     0.21       2.58
# 2               LSTM_7.0       1.78      0.34      1.32     0.18       3.16
#
#    MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 0      0.13     0.97    0.00 -6.14                0      dominant_model
# 3      0.22     0.95    0.01 -0.94                1  intermediate_model
# 1      0.42     0.94    0.02  0.47                2  intermediate_model
# 4      0.51     0.94    0.03  0.25                2  intermediate_model
# 2      0.42     0.91    0.05  6.36                4  non_dominant_model
#
#    Dominates_Count Plant
# 0                4    am
# 3                3    am
# 1                1    am
# 4                1    am
# 2                0    am

# %%
df_sorted_topo_cols[df_sorted_topo_cols["Classification"].eq("dominant_model")].shape
# Out:
# (1, 14)

# %% [markdown]
# ###### Intermediate models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].sort_values(by=["Dominates_Count", "SCPM"], ascending=[False, True]).iloc[:3]
# Out:
#              Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 3             Conv1D_7.0       1.32      0.15      1.01     0.09       2.44
# 4        Transformer_1.0       1.37      0.24      1.06     0.21       2.58
# 1  BidirectionalLSTM_7.0       1.40      0.21      1.09     0.18       2.59
#
#    MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 3      0.22     0.95    0.01 -0.94                1  intermediate_model
# 4      0.51     0.94    0.03  0.25                2  intermediate_model
# 1      0.42     0.94    0.02  0.47                2  intermediate_model
#
#    Dominates_Count Plant
# 3                3    am
# 4                1    am
# 1                1    am

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].shape
# Out:
# (3, 14)

# %% [markdown]
# ###### non-dominant models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].sort_values(by=["Dominates_Count", "SCPM"], ascending=[False, True]).iloc[:2]
# Out:
#   Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  MAPE_std  \
# 2    LSTM_7.0       1.78      0.34      1.32     0.18       3.16      0.42
#
#    R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 2     0.91    0.05  6.36                4  non_dominant_model
#
#    Dominates_Count Plant
# 2                0    am

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].shape
# Out:
# (1, 14)

# %% [markdown]
# ###### Statistics per model type

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        # "Model_bkp",
        # "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
        "Plant",
    ]
]  # .round(2)

# %%
df_sorted_topo["Model"].value_counts()
# Out:
# Model
# Neural Networks    4
# Conv1D             1
# Name: count, dtype: int64

# %%
df_sorted_topo_models_grouped = df_sorted_topo_models_cols.groupby("Model").describe().T

# %%
# pd.set_option("display.max_rows", None)
# df_sorted_topo_models_grouped

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
    ]
]

# %%
(
    df_sorted_topo_models_cols.groupby("Model")[["Classification"]]
    .value_counts(normalize=True)
    .to_frame()
    * 100
).round(2)
# Out:
#                                     proportion
# Model           Classification
# Conv1D          intermediate_model       100.0
# Neural Networks intermediate_model        50.0
#                 dominant_model            25.0
#                 non_dominant_model        25.0

# %%
df_sorted_topo_models_cols.groupby("Model").describe().round(2).T
# Out:
# Model                  Conv1D  Neural Networks
# Dominated_Count count     1.0             4.00
#                 mean      1.0             2.00
#                 std       NaN             1.63
#                 min       1.0             0.00
#                 25%       1.0             1.50
#                 50%       1.0             2.00
#                 75%       1.0             2.50
#                 max       1.0             4.00
# Dominates_Count count     1.0             4.00
#                 mean      3.0             1.50
#                 std       NaN             1.73
#                 min       3.0             0.00
#                 25%       3.0             0.75
#                 50%       3.0             1.00
#                 75%       3.0             1.75
#                 max       3.0             4.00

# %%
# df_sorted_topo_models_cols

# %%
df_sorted_topo_models_cols.groupby("Model")["Classification"].describe()
# Out:
#                 count unique                 top freq
# Model
# Conv1D              1      1  intermediate_model    1
# Neural Networks     4      3  intermediate_model    2

# %%
df_sorted_topo_models_cols.groupby("Model")[["Classification"]].value_counts()
# Out:
# Model            Classification
# Conv1D           intermediate_model    1
# Neural Networks  intermediate_model    2
#                  dominant_model        1
#                  non_dominant_model    1
# Name: count, dtype: int64

# %%
# df_sorted_topo_models_cols

# %%
summary_stats = df_sorted_topo_models_cols.groupby("Model").agg(
    Total_Models=("Model", "count"),
    Mean_Dominance_Count=("Dominates_Count", "mean"),
    Median_Dominance_Count=("Dominates_Count", "median"),
    Total_Dominated=("Dominated_Count", "sum"),
    Total_Dominating=("Dominates_Count", "sum"),
)

total_models = summary_stats[
    "Total_Models"
].sum()  # Get the total number of models across all categories
summary_stats["Dominance Proportion"] = summary_stats["Total_Dominating"] / total_models

# %%
summary_stats
# Out:
#                  Total_Models  Mean_Dominance_Count  Median_Dominance_Count  \
# Model
# Conv1D                      1                   3.0                     3.0
# Neural Networks             4                   1.5                     1.0
#
#                  Total_Dominated  Total_Dominating  Dominance Proportion
# Model
# Conv1D                         1                 3                   0.6
# Neural Networks                8                 6                   1.2

# %%
df_sorted_topo_models_grouped.T
# Out:
#                 RMSE_mean                                                    \
#                     count      mean       std       min       25%       50%
# Model
# Conv1D                1.0  1.321790       NaN  1.321790  1.321790  1.321790
# Neural Networks       4.0  1.382089  0.328979  0.977688  1.272438  1.383796
#
#                                     RMSE_std            ... Dominated_Count  \
#                       75%       max    count      mean  ...             75%
# Model                                                   ...
# Conv1D           1.321790  1.321790      1.0  0.151181  ...             1.0
# Neural Networks  1.493447  1.783077      4.0  0.218788  ...             2.5
#
#                      Dominates_Count
#                  max           count mean       std  min   25%  50%   75%  max
# Model
# Conv1D           1.0             1.0  3.0       NaN  3.0  3.00  3.0  3.00  3.0
# Neural Networks  4.0             4.0  1.5  1.732051  0.0  0.75  1.0  1.75  4.0
#
# [2 rows x 88 columns]

# %% [markdown]
# ### SCPM Analysis

# %%
cols = [
    # "Model",
    # "Model_bkp",
    "Model_bkp_2",
    "RMSE_mean",
    "RMSE_std",
    "MAE_mean",
    "MAE_std",
    "MAPE_mean",
    "MAPE_std",
    "R2_mean",
    "R2_std",
    "SCPM",
    "Dominated_Count",
    "Dominates_Count",
    "Classification",
    "Plant",
]

# %% [markdown]
# #### SCPM Analysis by Project

# %%
df_sorted_scpm = df_sorted_topo.sort_values(by="SCPM").copy()

# %%
# (df_sorted_topo[cols].reset_index() == df_sorted_scpm[cols].reset_index()).all(axis=1)
df_sorted_scpm["topo_scmp_order_eq"] = df_sorted_topo.index == df_sorted_scpm.index

# %%
df_sorted_scpm[cols + ["topo_scmp_order_eq"]].round(2).head(5)
# Out:
#              Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 0                    MLP       0.98      0.08      0.75     0.06       1.82
# 3             Conv1D_7.0       1.32      0.15      1.01     0.09       2.44
# 4        Transformer_1.0       1.37      0.24      1.06     0.21       2.58
# 1  BidirectionalLSTM_7.0       1.40      0.21      1.09     0.18       2.59
# 2               LSTM_7.0       1.78      0.34      1.32     0.18       3.16
#
#    MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count  Dominates_Count  \
# 0      0.13     0.97    0.00 -6.14                0                4
# 3      0.22     0.95    0.01 -0.94                1                3
# 4      0.51     0.94    0.03  0.25                2                1
# 1      0.42     0.94    0.02  0.47                2                1
# 2      0.42     0.91    0.05  6.36                4                0
#
#        Classification Plant  topo_scmp_order_eq
# 0      dominant_model    am                True
# 3  intermediate_model    am                True
# 4  intermediate_model    am               False
# 1  intermediate_model    am               False
# 2  non_dominant_model    am                True

# %% [markdown]
# ### Time Series Split

# %%
df_results_cm_p = (
    df_results[
        df_results["Features"].eq("Chemical + Mineralogical + Physical - Early CS")
    ]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_p["Features"].unique()
# Out:
# array(['Chemical + Mineralogical + Physical - Early CS'], dtype=object)

# %%
df_results_cm_p.shape
# Out:
# (20, 17)

# %% [markdown]
# ### Plant W

# %%
df_results_cm_p = df_results_cm_p[df_results_cm_p["Plant"].eq("w")].reset_index(
    drop=True
)

# %%
df_results_cm["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split', 'Time Series Split'], dtype=object)

# %%
df_results_cm_p_tss = (
    df_results_cm_p[df_results_cm_p["Cross Validation"].eq("Time Series Split")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_p_tss["Cross Validation"].unique()
# Out:
# array(['Time Series Split'], dtype=object)

# %%
df_results_cm_p_tss.shape
# Out:
# (5, 17)

# %% [markdown]
# ###### SCPM computation

# %%
df_results_cm_p_tss = compute_scpm(df_results_cm_p_tss)

# %% [markdown]
# ##### Dominance Analysis

# %%
# Per project
dominance_dict = make_dominance_analysis(df_results_cm_p_tss)
dominance_matrix_cm_p_tss = dominance_dict["dominance_matrix"]
dominance_graph_cm_p_tss = dominance_dict["dominance_graph"]
df_sorted_count = dominance_dict["df_sorted_count"]
df_sorted_topo = dominance_dict["df_sorted_topo"]

# %%
dominance_matrix_cm_tss.shape, len(dominance_graph_cm_tss)
# Out:
# ((5, 5), 5)

# %%
df_sorted_topo["Classification"].value_counts()
# Out:
# Classification
# intermediate_model    3
# dominant_model        1
# non_dominant_model    1
# Name: count, dtype: int64

# %%
df_sorted_topo.to_csv(
    "../../../../reports/results/global_models/ecics/209_w_dominance_analysis_cm_p_tss.csv",
    index=False,
)

# %%
df_sorted_topo.head(5)
# Out:
#    Company Plant   Cross Validation  \
# 0      209     w  Time Series Split
# 2      209     w  Time Series Split
# 1      209     w  Time Series Split
# 4      209     w  Time Series Split
# 3      209     w  Time Series Split
#
#                                          Features  \
# 0  Chemical + Mineralogical + Physical - Early CS
# 2  Chemical + Mineralogical + Physical - Early CS
# 1  Chemical + Mineralogical + Physical - Early CS
# 4  Chemical + Mineralogical + Physical - Early CS
# 3  Chemical + Mineralogical + Physical - Early CS
#
#                     Features_bkp            Model          Model_bkp  \
# 0  Chemical + Properties CS Less  Neural Networks                MLP
# 2  Chemical + Properties CS Less  Neural Networks               LSTM
# 1  Chemical + Properties CS Less  Neural Networks  BidirectionalLSTM
# 4  Chemical + Properties CS Less  Neural Networks        Transformer
# 3  Chemical + Properties CS Less           Conv1D             Conv1D
#
#              Model_bkp_2  Timesteps  RMSE_mean  ...  MAPE_mean   R2_mean  \
# 0                    MLP        NaN   1.317312  ...   2.463852  0.931815
# 2               LSTM_7.0        7.0   1.660127  ...   2.971102  0.887714
# 1  BidirectionalLSTM_1.0        1.0   1.869280  ...   3.280013  0.852865
# 4        Transformer_1.0        1.0   1.868226  ...   3.331895  0.850222
# 3             Conv1D_7.0        7.0   2.613889  ...   4.963884  0.681428
#
#    RMSE_std   MAE_std  MAPE_std    R2_std      SCPM  Dominated_Count  \
# 0  0.244525  0.193443  0.375366  0.026493 -4.628705                0
# 2  0.438231  0.291369  0.646294  0.058431 -2.062591                1
# 1  0.583800  0.411514  0.934949  0.086808 -0.370473                2
# 4  0.680115  0.475889  1.040908  0.107215 -0.277492                2
# 3  1.245495  1.087790  2.356590  0.278160  7.339261                4
#
#        Classification Dominates_Count
# 0      dominant_model               4
# 2  intermediate_model               3
# 1  intermediate_model               1
# 4  intermediate_model               1
# 3  non_dominant_model               0
#
# [5 rows x 21 columns]

# %%
df_sorted_topo_cols = df_sorted_topo[
    [
        # "Model",
        # "Model_bkp",
        "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Classification",
        "Dominates_Count",
        "Plant",
    ]
]  # .round(2)

# %% [markdown]
# ###### Dominant Models

# %%
# Top 4
df_sorted_topo_cols.iloc[0:2].sort_values(by="Dominates_Count", ascending=False).round(
    2
)
# Out:
#   Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  MAPE_std  \
# 0         MLP       1.32      0.24      1.04     0.19       2.46      0.38
# 2    LSTM_7.0       1.66      0.44      1.27     0.29       2.97      0.65
#
#    R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 0     0.93    0.03 -4.63                0      dominant_model
# 2     0.89    0.06 -2.06                1  intermediate_model
#
#    Dominates_Count Plant
# 0                4     w
# 2                3     w

# %%
df_sorted_topo_cols[df_sorted_topo_cols["Classification"].eq("dominant_model")].shape
# Out:
# (1, 14)

# %% [markdown]
# ###### Intermediate models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].sort_values(by=["Dominates_Count", "SCPM"], ascending=[False, True]).iloc[:4].round(2)
# Out:
#              Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 2               LSTM_7.0       1.66      0.44      1.27     0.29       2.97
# 1  BidirectionalLSTM_1.0       1.87      0.58      1.42     0.41       3.28
# 4        Transformer_1.0       1.87      0.68      1.42     0.48       3.33
#
#    MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 2      0.65     0.89    0.06 -2.06                1  intermediate_model
# 1      0.93     0.85    0.09 -0.37                2  intermediate_model
# 4      1.04     0.85    0.11 -0.28                2  intermediate_model
#
#    Dominates_Count Plant
# 2                3     w
# 1                1     w
# 4                1     w

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].shape
# Out:
# (3, 14)

# %% [markdown]
# ###### non-dominant models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].sort_values(by=["Dominates_Count", "SCPM"], ascending=[False, True]).iloc[:3]
# Out:
#   Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  MAPE_std  \
# 3  Conv1D_7.0   2.613889  1.245495  2.116994  1.08779   4.963884   2.35659
#
#     R2_mean   R2_std      SCPM  Dominated_Count      Classification  \
# 3  0.681428  0.27816  7.339261                4  non_dominant_model
#
#    Dominates_Count Plant
# 3                0     w

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].shape
# Out:
# (1, 14)

# %% [markdown]
# ###### Statistics per model type

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        # "Model_bkp",
        # "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
        "Plant",
    ]
]  # .round(2)

# %%
df_sorted_topo["Model"].value_counts()
# Out:
# Model
# Neural Networks    4
# Conv1D             1
# Name: count, dtype: int64

# %%
df_sorted_topo_models_grouped = df_sorted_topo_models_cols.groupby("Model").describe().T

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
    ]
]

# %%
(
    df_sorted_topo_models_cols.groupby("Model")[["Classification"]]
    .value_counts(normalize=True)
    .to_frame()
    * 100
).round(2)
# Out:
#                                     proportion
# Model           Classification
# Conv1D          non_dominant_model       100.0
# Neural Networks intermediate_model        75.0
#                 dominant_model            25.0

# %%
df_sorted_topo_models_cols.groupby("Model").describe().round(2).T
# Out:
# Model                  Conv1D  Neural Networks
# Dominated_Count count     1.0             4.00
#                 mean      4.0             1.25
#                 std       NaN             0.96
#                 min       4.0             0.00
#                 25%       4.0             0.75
#                 50%       4.0             1.50
#                 75%       4.0             2.00
#                 max       4.0             2.00
# Dominates_Count count     1.0             4.00
#                 mean      0.0             2.25
#                 std       NaN             1.50
#                 min       0.0             1.00
#                 25%       0.0             1.00
#                 50%       0.0             2.00
#                 75%       0.0             3.25
#                 max       0.0             4.00

# %%
# df_sorted_topo_models_cols

# %%
df_sorted_topo_models_cols.groupby("Model")["Classification"].describe()
# Out:
#                 count unique                 top freq
# Model
# Conv1D              1      1  non_dominant_model    1
# Neural Networks     4      2  intermediate_model    3

# %%
df_sorted_topo_models_cols.groupby("Model")[["Classification"]].value_counts()
# Out:
# Model            Classification
# Conv1D           non_dominant_model    1
# Neural Networks  intermediate_model    3
#                  dominant_model        1
# Name: count, dtype: int64

# %%
summary_stats = df_sorted_topo_models_cols.groupby("Model").agg(
    Total_Models=("Model", "count"),
    Mean_Dominance_Count=("Dominates_Count", "mean"),
    Median_Dominance_Count=("Dominates_Count", "median"),
    Total_Dominated=("Dominated_Count", "sum"),
    Total_Dominating=("Dominates_Count", "sum"),
)

total_models = summary_stats[
    "Total_Models"
].sum()  # Get the total number of models across all categories
summary_stats["Dominance Proportion"] = summary_stats["Total_Dominating"] / total_models

# %%
summary_stats.round(2)
# Out:
#                  Total_Models  Mean_Dominance_Count  Median_Dominance_Count  \
# Model
# Conv1D                      1                  0.00                     0.0
# Neural Networks             4                  2.25                     2.0
#
#                  Total_Dominated  Total_Dominating  Dominance Proportion
# Model
# Conv1D                         4                 0                   0.0
# Neural Networks                5                 9                   1.8

# %%
df_sorted_topo_models_grouped.T
# Out:
#                 RMSE_mean                                                    \
#                     count      mean       std       min       25%       50%
# Model
# Conv1D                1.0  2.613889       NaN  2.613889  2.613889  2.613889
# Neural Networks       4.0  1.678736  0.260248  1.317312  1.574423  1.764176
#
#                                     RMSE_std            ... Dominated_Count  \
#                       75%       max    count      mean  ...             75%
# Model                                                   ...
# Conv1D           2.613889  2.613889      1.0  1.245495  ...             4.0
# Neural Networks  1.868490  1.869280      4.0  0.486668  ...             2.0
#
#                      Dominates_Count
#                  max           count  mean  std  min  25%  50%   75%  max
# Model
# Conv1D           4.0             1.0  0.00  NaN  0.0  0.0  0.0  0.00  0.0
# Neural Networks  2.0             4.0  2.25  1.5  1.0  1.0  2.0  3.25  4.0
#
# [2 rows x 88 columns]

# %% [markdown]
# ### SCPM Analysis

# %%
cols = [
    # "Model",
    # "Model_bkp",
    "Model_bkp_2",
    "RMSE_mean",
    "RMSE_std",
    "MAE_mean",
    "MAE_std",
    "MAPE_mean",
    "MAPE_std",
    "R2_mean",
    "R2_std",
    "SCPM",
    "Dominated_Count",
    "Dominates_Count",
    "Classification",
    "Plant",
]

# %% [markdown]
# #### SCPM Analysis by Project

# %%
df_sorted_scpm = df_sorted_topo.sort_values(by="SCPM").copy()

# %%
# (df_sorted_topo[cols].reset_index() == df_sorted_scpm[cols].reset_index()).all(axis=1)
df_sorted_scpm["topo_scmp_order_eq"] = df_sorted_topo.index == df_sorted_scpm.index

# %%
df_sorted_scpm[cols + ["topo_scmp_order_eq"]].round(2).head(5)
# Out:
#              Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 0                    MLP       1.32      0.24      1.04     0.19       2.46
# 2               LSTM_7.0       1.66      0.44      1.27     0.29       2.97
# 1  BidirectionalLSTM_1.0       1.87      0.58      1.42     0.41       3.28
# 4        Transformer_1.0       1.87      0.68      1.42     0.48       3.33
# 3             Conv1D_7.0       2.61      1.25      2.12     1.09       4.96
#
#    MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count  Dominates_Count  \
# 0      0.38     0.93    0.03 -4.63                0                4
# 2      0.65     0.89    0.06 -2.06                1                3
# 1      0.93     0.85    0.09 -0.37                2                1
# 4      1.04     0.85    0.11 -0.28                2                1
# 3      2.36     0.68    0.28  7.34                4                0
#
#        Classification Plant  topo_scmp_order_eq
# 0      dominant_model     w                True
# 2  intermediate_model     w                True
# 1  intermediate_model     w                True
# 4  intermediate_model     w                True
# 3  non_dominant_model     w                True

# %% [markdown]
# ## Variable Grouping: CM-P-CS

# %% [markdown]
# #### Analysis of the best models identified in the Local Analysis

# %% [markdown]
# **Best models for variable groupping CM-P-CS were from:**
#
# *BTiSS:*
#     Dominance analysis: Plant S and Plant K
#     SCPM: Plant S and Plant K
#
# *TiSS:*
#     Dominance analysis: Plant S
#     SCPM: Plant S

# %%
df_results["Features"].unique()
# Out:
# array(['Chemical + Mineralogical', 'Chemical + Mineralogical + Physical',
#        'Chemical + Mineralogical + Physical - Early CS'], dtype=object)

# %%
df_results_cm_p_cs = (
    df_results[df_results["Features"].eq("Chemical + Mineralogical + Physical")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_p_cs["Features"].unique()
# Out:
# array(['Chemical + Mineralogical + Physical'], dtype=object)

# %%
df_results_cm_p_cs.shape
# Out:
# (30, 17)

# %% [markdown]
# ### Plant S

# %%
df_results_cm_p_cs = df_results_cm_p_cs[
    df_results_cm_p_cs["Plant"].eq("s")
].reset_index(drop=True)

# %% [markdown]
# ### Blocking time series

# %%
df_results_cm_p_cs["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split', 'Time Series Split'], dtype=object)

# %%
df_results_cm_p_cs_btss = (
    df_results_cm_p_cs[
        df_results_cm_p_cs["Cross Validation"].eq("Blocking Time Series Split")
    ]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_p_cs_btss["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split'], dtype=object)

# %%
df_results_cm_p_cs_btss.shape
# Out:
# (5, 17)

# %% [markdown]
# ###### SCPM computation

# %%
df_results_cm_p_cs_btss = compute_scpm(df_results_cm_p_cs_btss)

# %% [markdown]
# ##### Dominance Analysis

# %%
# Per project
dominance_dict = make_dominance_analysis(df_results_cm_p_cs_btss)
dominance_matrix_cm_p_cs_btss = dominance_dict["dominance_matrix"]
dominance_graph_cm_p_cs_btss = dominance_dict["dominance_graph"]
df_sorted_count = dominance_dict["df_sorted_count"]
df_sorted_topo = dominance_dict["df_sorted_topo"]

# %%
dominance_matrix_cm_p_cs_btss.shape, len(dominance_graph_cm_p_cs_btss)
# Out:
# ((5, 5), 5)

# %%
df_sorted_topo["Classification"].value_counts()
# Out:
# Classification
# intermediate_model    3
# dominant_model        1
# non_dominant_model    1
# Name: count, dtype: int64

# %%
df_sorted_topo.to_csv(
    "../../../../reports/results/global_models/ecics/209_s_dominance_analysis_cm_p_cs_btss.csv",
    index=False,
)

# %%
df_sorted_topo.head(5)
# Out:
#    Company Plant            Cross Validation  \
# 0      209     s  Blocking Time Series Split
# 1      209     s  Blocking Time Series Split
# 4      209     s  Blocking Time Series Split
# 3      209     s  Blocking Time Series Split
# 2      209     s  Blocking Time Series Split
#
#                               Features         Features_bkp            Model  \
# 0  Chemical + Mineralogical + Physical  Chemical + Physical  Neural Networks
# 1  Chemical + Mineralogical + Physical  Chemical + Physical           Conv1D
# 4  Chemical + Mineralogical + Physical  Chemical + Physical  Neural Networks
# 3  Chemical + Mineralogical + Physical  Chemical + Physical  Neural Networks
# 2  Chemical + Mineralogical + Physical  Chemical + Physical  Neural Networks
#
#            Model_bkp            Model_bkp_2  Timesteps  RMSE_mean  ...  \
# 0                MLP                    MLP        NaN   0.706974  ...
# 1             Conv1D             Conv1D_1.0        1.0   0.909706  ...
# 4  BidirectionalLSTM  BidirectionalLSTM_1.0        1.0   1.090873  ...
# 3               LSTM               LSTM_1.0        1.0   1.115614  ...
# 2        Transformer        Transformer_1.0        1.0   1.670219  ...
#
#    MAPE_mean   R2_mean  RMSE_std   MAE_std  MAPE_std    R2_std      SCPM  \
# 0   1.343428  0.982151  0.131605  0.091949  0.217774  0.006596 -5.297239
# 1   1.770868  0.971428  0.138244  0.104172  0.235113  0.008137 -2.180513
# 4   2.068817  0.958023  0.197852  0.182819  0.414481  0.015695  0.307526
# 3   2.069726  0.957110  0.100757  0.115338  0.305806  0.008406  0.493156
# 2   2.615050  0.900631  0.494400  0.187695  0.453612  0.047080  6.677070
#
#    Dominated_Count      Classification Dominates_Count
# 0                0      dominant_model               4
# 1                1  intermediate_model               3
# 4                2  intermediate_model               2
# 3                3  intermediate_model               1
# 2                4  non_dominant_model               0
#
# [5 rows x 21 columns]

# %%
df_sorted_topo_cols = df_sorted_topo[
    [
        # "Model",
        # "Model_bkp",
        "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Classification",
        "Dominates_Count",
        "Plant",
    ]
].round(2)

# %% [markdown]
# ###### Dominant Models

# %%
# Top 4
df_sorted_topo_cols.iloc[0:5]
# Out:
#              Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 0                    MLP       0.71      0.13      0.54     0.09       1.34
# 1             Conv1D_1.0       0.91      0.14      0.72     0.10       1.77
# 4  BidirectionalLSTM_1.0       1.09      0.20      0.83     0.18       2.07
# 3               LSTM_1.0       1.12      0.10      0.84     0.12       2.07
# 2        Transformer_1.0       1.67      0.49      1.03     0.19       2.62
#
#    MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 0      0.22     0.98    0.01 -5.30                0      dominant_model
# 1      0.24     0.97    0.01 -2.18                1  intermediate_model
# 4      0.41     0.96    0.02  0.31                2  intermediate_model
# 3      0.31     0.96    0.01  0.49                3  intermediate_model
# 2      0.45     0.90    0.05  6.68                4  non_dominant_model
#
#    Dominates_Count Plant
# 0                4     s
# 1                3     s
# 4                2     s
# 3                1     s
# 2                0     s

# %%
df_sorted_topo_cols[df_sorted_topo_cols["Classification"].eq("dominant_model")].shape
# Out:
# (1, 14)

# %% [markdown]
# ###### Intermediate models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].sort_values(by=["Dominates_Count", "SCPM"], ascending=[False, True]).iloc[:3]
# Out:
#              Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 1             Conv1D_1.0       0.91      0.14      0.72     0.10       1.77
# 4  BidirectionalLSTM_1.0       1.09      0.20      0.83     0.18       2.07
# 3               LSTM_1.0       1.12      0.10      0.84     0.12       2.07
#
#    MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 1      0.24     0.97    0.01 -2.18                1  intermediate_model
# 4      0.41     0.96    0.02  0.31                2  intermediate_model
# 3      0.31     0.96    0.01  0.49                3  intermediate_model
#
#    Dominates_Count Plant
# 1                3     s
# 4                2     s
# 3                1     s

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].shape
# Out:
# (3, 14)

# %% [markdown]
# ###### non-dominant models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].sort_values(by=["Dominates_Count", "SCPM"], ascending=[False, True]).iloc[:2]
# Out:
#        Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 2  Transformer_1.0       1.67      0.49      1.03     0.19       2.62
#
#    MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 2      0.45      0.9    0.05  6.68                4  non_dominant_model
#
#    Dominates_Count Plant
# 2                0     s

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].shape
# Out:
# (1, 14)

# %% [markdown]
# ###### Statistics per model type

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        # "Model_bkp",
        # "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
        "Plant",
    ]
]  # .round(2)

# %%
df_sorted_topo["Model"].value_counts()
# Out:
# Model
# Neural Networks    4
# Conv1D             1
# Name: count, dtype: int64

# %%
df_sorted_topo_models_grouped = df_sorted_topo_models_cols.groupby("Model").describe().T

# %%
# pd.set_option("display.max_rows", None)
# df_sorted_topo_models_grouped

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
    ]
]

# %%
(
    df_sorted_topo_models_cols.groupby("Model")[["Classification"]]
    .value_counts(normalize=True)
    .to_frame()
    * 100
).round(2)
# Out:
#                                     proportion
# Model           Classification
# Conv1D          intermediate_model       100.0
# Neural Networks intermediate_model        50.0
#                 dominant_model            25.0
#                 non_dominant_model        25.0

# %%
df_sorted_topo_models_cols.groupby("Model").describe().round(2).T
# Out:
# Model                  Conv1D  Neural Networks
# Dominated_Count count     1.0             4.00
#                 mean      1.0             2.25
#                 std       NaN             1.71
#                 min       1.0             0.00
#                 25%       1.0             1.50
#                 50%       1.0             2.50
#                 75%       1.0             3.25
#                 max       1.0             4.00
# Dominates_Count count     1.0             4.00
#                 mean      3.0             1.75
#                 std       NaN             1.71
#                 min       3.0             0.00
#                 25%       3.0             0.75
#                 50%       3.0             1.50
#                 75%       3.0             2.50
#                 max       3.0             4.00

# %%
# df_sorted_topo_models_cols

# %%
df_sorted_topo_models_cols.groupby("Model")["Classification"].describe()
# Out:
#                 count unique                 top freq
# Model
# Conv1D              1      1  intermediate_model    1
# Neural Networks     4      3  intermediate_model    2

# %%
df_sorted_topo_models_cols.groupby("Model")[["Classification"]].value_counts()
# Out:
# Model            Classification
# Conv1D           intermediate_model    1
# Neural Networks  intermediate_model    2
#                  dominant_model        1
#                  non_dominant_model    1
# Name: count, dtype: int64

# %%
# df_sorted_topo_models_cols

# %%
summary_stats = df_sorted_topo_models_cols.groupby("Model").agg(
    Total_Models=("Model", "count"),
    Mean_Dominance_Count=("Dominates_Count", "mean"),
    Median_Dominance_Count=("Dominates_Count", "median"),
    Total_Dominated=("Dominated_Count", "sum"),
    Total_Dominating=("Dominates_Count", "sum"),
)

total_models = summary_stats[
    "Total_Models"
].sum()  # Get the total number of models across all categories
summary_stats["Dominance Proportion"] = summary_stats["Total_Dominating"] / total_models

# %%
summary_stats
# Out:
#                  Total_Models  Mean_Dominance_Count  Median_Dominance_Count  \
# Model
# Conv1D                      1                  3.00                     3.0
# Neural Networks             4                  1.75                     1.5
#
#                  Total_Dominated  Total_Dominating  Dominance Proportion
# Model
# Conv1D                         1                 3                   0.6
# Neural Networks                9                 7                   1.4

# %%
df_sorted_topo_models_grouped.T
# Out:
#                 RMSE_mean                                                    \
#                     count      mean       std       min       25%       50%
# Model
# Conv1D                1.0  0.909706       NaN  0.909706  0.909706  0.909706
# Neural Networks       4.0  1.145920  0.396448  0.706974  0.994898  1.103244
#
#                                     RMSE_std            ... Dominated_Count  \
#                       75%       max    count      mean  ...             75%
# Model                                                   ...
# Conv1D           0.909706  0.909706      1.0  0.138244  ...            1.00
# Neural Networks  1.254266  1.670219      4.0  0.231153  ...            3.25
#
#                      Dominates_Count
#                  max           count  mean       std  min   25%  50%  75%  max
# Model
# Conv1D           1.0             1.0  3.00       NaN  3.0  3.00  3.0  3.0  3.0
# Neural Networks  4.0             4.0  1.75  1.707825  0.0  0.75  1.5  2.5  4.0
#
# [2 rows x 88 columns]

# %% [markdown]
# ### SCPM Analysis

# %%
cols = [
    # "Model",
    # "Model_bkp",
    "Model_bkp_2",
    "RMSE_mean",
    "RMSE_std",
    "MAE_mean",
    "MAE_std",
    "MAPE_mean",
    "MAPE_std",
    "R2_mean",
    "R2_std",
    "SCPM",
    "Dominated_Count",
    "Dominates_Count",
    "Classification",
    "Plant",
]

# %% [markdown]
# #### SCPM Analysis by Project

# %%
df_sorted_scpm = df_sorted_topo.sort_values(by="SCPM").copy()

# %%
# (df_sorted_topo[cols].reset_index() == df_sorted_scpm[cols].reset_index()).all(axis=1)
df_sorted_scpm["topo_scmp_order_eq"] = df_sorted_topo.index == df_sorted_scpm.index

# %%
df_sorted_scpm[cols + ["topo_scmp_order_eq"]].round(2).head(5)
# Out:
#              Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 0                    MLP       0.71      0.13      0.54     0.09       1.34
# 1             Conv1D_1.0       0.91      0.14      0.72     0.10       1.77
# 4  BidirectionalLSTM_1.0       1.09      0.20      0.83     0.18       2.07
# 3               LSTM_1.0       1.12      0.10      0.84     0.12       2.07
# 2        Transformer_1.0       1.67      0.49      1.03     0.19       2.62
#
#    MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count  Dominates_Count  \
# 0      0.22     0.98    0.01 -5.30                0                4
# 1      0.24     0.97    0.01 -2.18                1                3
# 4      0.41     0.96    0.02  0.31                2                2
# 3      0.31     0.96    0.01  0.49                3                1
# 2      0.45     0.90    0.05  6.68                4                0
#
#        Classification Plant  topo_scmp_order_eq
# 0      dominant_model     s                True
# 1  intermediate_model     s                True
# 4  intermediate_model     s                True
# 3  intermediate_model     s                True
# 2  non_dominant_model     s                True

# %% [markdown]
# ### Plant K

# %%
df_results_cm_p_cs = (
    df_results[df_results["Features"].eq("Chemical + Mineralogical + Physical")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_p_cs["Features"].unique()
# Out:
# array(['Chemical + Mineralogical + Physical'], dtype=object)

# %%
df_results_cm_p_cs.shape
# Out:
# (30, 17)

# %%
df_results_cm_p_cs = df_results_cm_p_cs[
    df_results_cm_p_cs["Plant"].eq("k")
].reset_index(drop=True)

# %% [markdown]
# ### Blocking time series

# %%
df_results_cm_p_cs["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split', 'Time Series Split'], dtype=object)

# %%
df_results_cm_p_cs_btss = (
    df_results_cm_p_cs[
        df_results_cm_p_cs["Cross Validation"].eq("Blocking Time Series Split")
    ]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_p_cs_btss["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split'], dtype=object)

# %%
df_results_cm_p_cs_btss.shape
# Out:
# (5, 17)

# %% [markdown]
# ###### SCPM computation

# %%
df_results_cm_p_cs_btss = compute_scpm(df_results_cm_p_cs_btss)

# %% [markdown]
# ##### Dominance Analysis

# %%
# Per project
dominance_dict = make_dominance_analysis(df_results_cm_p_cs_btss)
dominance_matrix_cm_p_cs_btss = dominance_dict["dominance_matrix"]
dominance_graph_cm_p_cs_btss = dominance_dict["dominance_graph"]
df_sorted_count = dominance_dict["df_sorted_count"]
df_sorted_topo = dominance_dict["df_sorted_topo"]

# %%
dominance_matrix_cm_p_cs_btss.shape, len(dominance_graph_cm_p_cs_btss)
# Out:
# ((5, 5), 5)

# %%
df_sorted_topo["Classification"].value_counts()
# Out:
# Classification
# intermediate_model    3
# dominant_model        1
# non_dominant_model    1
# Name: count, dtype: int64

# %%
df_sorted_topo.to_csv(
    "../../../../reports/results/global_models/ecics/209_k_dominance_analysis_cm_p_cs_btss.csv",
    index=False,
)

# %%
df_sorted_topo.head(5)
# Out:
#    Company Plant            Cross Validation  \
# 0      209     k  Blocking Time Series Split
# 1      209     k  Blocking Time Series Split
# 2      209     k  Blocking Time Series Split
# 3      209     k  Blocking Time Series Split
# 4      209     k  Blocking Time Series Split
#
#                               Features         Features_bkp            Model  \
# 0  Chemical + Mineralogical + Physical  Chemical + Physical  Neural Networks
# 1  Chemical + Mineralogical + Physical  Chemical + Physical           Conv1D
# 2  Chemical + Mineralogical + Physical  Chemical + Physical  Neural Networks
# 3  Chemical + Mineralogical + Physical  Chemical + Physical  Neural Networks
# 4  Chemical + Mineralogical + Physical  Chemical + Physical  Neural Networks
#
#            Model_bkp            Model_bkp_2  Timesteps  RMSE_mean  ...  \
# 0                MLP                    MLP        NaN   0.856619  ...
# 1             Conv1D             Conv1D_7.0        7.0   1.354252  ...
# 2        Transformer        Transformer_1.0        1.0   1.593303  ...
# 3               LSTM               LSTM_7.0        7.0   1.903208  ...
# 4  BidirectionalLSTM  BidirectionalLSTM_7.0        7.0   2.451529  ...
#
#    MAPE_mean   R2_mean  RMSE_std   MAE_std  MAPE_std    R2_std      SCPM  \
# 0   1.566781  0.973031  0.215978  0.157436  0.394729  0.019362 -5.707534
# 1   2.585411  0.940697  0.188048  0.163273  0.390112  0.021273 -1.677612
# 2   2.741630  0.917879  0.274851  0.117771  0.283808  0.042359 -0.573354
# 3   3.439258  0.875586  0.368892  0.271958  0.669841  0.066889  2.319616
# 4   3.550908  0.638752  1.831327  0.477803  1.016197  0.787869  5.638884
#
#    Dominated_Count      Classification Dominates_Count
# 0                0      dominant_model               4
# 1                1  intermediate_model               3
# 2                2  intermediate_model               2
# 3                3  intermediate_model               1
# 4                4  non_dominant_model               0
#
# [5 rows x 21 columns]

# %%
df_sorted_topo_cols = df_sorted_topo[
    [
        # "Model",
        # "Model_bkp",
        "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Classification",
        "Dominates_Count",
        "Plant",
    ]
].round(2)

# %% [markdown]
# ###### Dominant Models

# %%
# Top 4
df_sorted_topo_cols.iloc[0:5]
# Out:
#              Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 0                    MLP       0.86      0.22      0.67     0.16       1.57
# 1             Conv1D_7.0       1.35      0.19      1.10     0.16       2.59
# 2        Transformer_1.0       1.59      0.27      1.18     0.12       2.74
# 3               LSTM_7.0       1.90      0.37      1.48     0.27       3.44
# 4  BidirectionalLSTM_7.0       2.45      1.83      1.52     0.48       3.55
#
#    MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 0      0.39     0.97    0.02 -5.71                0      dominant_model
# 1      0.39     0.94    0.02 -1.68                1  intermediate_model
# 2      0.28     0.92    0.04 -0.57                2  intermediate_model
# 3      0.67     0.88    0.07  2.32                3  intermediate_model
# 4      1.02     0.64    0.79  5.64                4  non_dominant_model
#
#    Dominates_Count Plant
# 0                4     k
# 1                3     k
# 2                2     k
# 3                1     k
# 4                0     k

# %%
df_sorted_topo_cols[df_sorted_topo_cols["Classification"].eq("dominant_model")].shape
# Out:
# (1, 14)

# %% [markdown]
# ###### Intermediate models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].sort_values(by=["Dominates_Count", "SCPM"], ascending=[False, True]).iloc[:3]
# Out:
#        Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 1       Conv1D_7.0       1.35      0.19      1.10     0.16       2.59
# 2  Transformer_1.0       1.59      0.27      1.18     0.12       2.74
# 3         LSTM_7.0       1.90      0.37      1.48     0.27       3.44
#
#    MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 1      0.39     0.94    0.02 -1.68                1  intermediate_model
# 2      0.28     0.92    0.04 -0.57                2  intermediate_model
# 3      0.67     0.88    0.07  2.32                3  intermediate_model
#
#    Dominates_Count Plant
# 1                3     k
# 2                2     k
# 3                1     k

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].shape
# Out:
# (3, 14)

# %% [markdown]
# ###### non-dominant models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].sort_values(by=["Dominates_Count", "SCPM"], ascending=[False, True]).iloc[:2]
# Out:
#              Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 4  BidirectionalLSTM_7.0       2.45      1.83      1.52     0.48       3.55
#
#    MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 4      1.02     0.64    0.79  5.64                4  non_dominant_model
#
#    Dominates_Count Plant
# 4                0     k

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].shape
# Out:
# (1, 14)

# %% [markdown]
# ###### Statistics per model type

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        # "Model_bkp",
        # "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
        "Plant",
    ]
]  # .round(2)

# %%
df_sorted_topo["Model"].value_counts()
# Out:
# Model
# Neural Networks    4
# Conv1D             1
# Name: count, dtype: int64

# %%
df_sorted_topo_models_grouped = df_sorted_topo_models_cols.groupby("Model").describe().T

# %%
# pd.set_option("display.max_rows", None)
# df_sorted_topo_models_grouped

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
    ]
]

# %%
(
    df_sorted_topo_models_cols.groupby("Model")[["Classification"]]
    .value_counts(normalize=True)
    .to_frame()
    * 100
).round(2)
# Out:
#                                     proportion
# Model           Classification
# Conv1D          intermediate_model       100.0
# Neural Networks intermediate_model        50.0
#                 dominant_model            25.0
#                 non_dominant_model        25.0

# %%
df_sorted_topo_models_cols.groupby("Model").describe().round(2).T
# Out:
# Model                  Conv1D  Neural Networks
# Dominated_Count count     1.0             4.00
#                 mean      1.0             2.25
#                 std       NaN             1.71
#                 min       1.0             0.00
#                 25%       1.0             1.50
#                 50%       1.0             2.50
#                 75%       1.0             3.25
#                 max       1.0             4.00
# Dominates_Count count     1.0             4.00
#                 mean      3.0             1.75
#                 std       NaN             1.71
#                 min       3.0             0.00
#                 25%       3.0             0.75
#                 50%       3.0             1.50
#                 75%       3.0             2.50
#                 max       3.0             4.00

# %%
# df_sorted_topo_models_cols

# %%
df_sorted_topo_models_cols.groupby("Model")["Classification"].describe()
# Out:
#                 count unique                 top freq
# Model
# Conv1D              1      1  intermediate_model    1
# Neural Networks     4      3  intermediate_model    2

# %%
df_sorted_topo_models_cols.groupby("Model")[["Classification"]].value_counts()
# Out:
# Model            Classification
# Conv1D           intermediate_model    1
# Neural Networks  intermediate_model    2
#                  dominant_model        1
#                  non_dominant_model    1
# Name: count, dtype: int64

# %%
# df_sorted_topo_models_cols

# %%
summary_stats = df_sorted_topo_models_cols.groupby("Model").agg(
    Total_Models=("Model", "count"),
    Mean_Dominance_Count=("Dominates_Count", "mean"),
    Median_Dominance_Count=("Dominates_Count", "median"),
    Total_Dominated=("Dominated_Count", "sum"),
    Total_Dominating=("Dominates_Count", "sum"),
)

total_models = summary_stats[
    "Total_Models"
].sum()  # Get the total number of models across all categories
summary_stats["Dominance Proportion"] = summary_stats["Total_Dominating"] / total_models

# %%
summary_stats
# Out:
#                  Total_Models  Mean_Dominance_Count  Median_Dominance_Count  \
# Model
# Conv1D                      1                  3.00                     3.0
# Neural Networks             4                  1.75                     1.5
#
#                  Total_Dominated  Total_Dominating  Dominance Proportion
# Model
# Conv1D                         1                 3                   0.6
# Neural Networks                9                 7                   1.4

# %%
df_sorted_topo_models_grouped.T
# Out:
#                 RMSE_mean                                                    \
#                     count      mean       std       min       25%       50%
# Model
# Conv1D                1.0  1.354252       NaN  1.354252  1.354252  1.354252
# Neural Networks       4.0  1.701165  0.665522  0.856619  1.409132  1.748256
#
#                                     RMSE_std            ... Dominated_Count  \
#                       75%       max    count      mean  ...             75%
# Model                                                   ...
# Conv1D           1.354252  1.354252      1.0  0.188048  ...            1.00
# Neural Networks  2.040288  2.451529      4.0  0.672762  ...            3.25
#
#                      Dominates_Count
#                  max           count  mean       std  min   25%  50%  75%  max
# Model
# Conv1D           1.0             1.0  3.00       NaN  3.0  3.00  3.0  3.0  3.0
# Neural Networks  4.0             4.0  1.75  1.707825  0.0  0.75  1.5  2.5  4.0
#
# [2 rows x 88 columns]

# %% [markdown]
# ### SCPM Analysis

# %%
cols = [
    # "Model",
    # "Model_bkp",
    "Model_bkp_2",
    "RMSE_mean",
    "RMSE_std",
    "MAE_mean",
    "MAE_std",
    "MAPE_mean",
    "MAPE_std",
    "R2_mean",
    "R2_std",
    "SCPM",
    "Dominated_Count",
    "Dominates_Count",
    "Classification",
    "Plant",
]

# %% [markdown]
# #### SCPM Analysis by Project

# %%
df_sorted_scpm = df_sorted_topo.sort_values(by="SCPM").copy()

# %%
# (df_sorted_topo[cols].reset_index() == df_sorted_scpm[cols].reset_index()).all(axis=1)
df_sorted_scpm["topo_scmp_order_eq"] = df_sorted_topo.index == df_sorted_scpm.index

# %%
df_sorted_scpm[cols + ["topo_scmp_order_eq"]].round(2).head(5)
# Out:
#              Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 0                    MLP       0.86      0.22      0.67     0.16       1.57
# 1             Conv1D_7.0       1.35      0.19      1.10     0.16       2.59
# 2        Transformer_1.0       1.59      0.27      1.18     0.12       2.74
# 3               LSTM_7.0       1.90      0.37      1.48     0.27       3.44
# 4  BidirectionalLSTM_7.0       2.45      1.83      1.52     0.48       3.55
#
#    MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count  Dominates_Count  \
# 0      0.39     0.97    0.02 -5.71                0                4
# 1      0.39     0.94    0.02 -1.68                1                3
# 2      0.28     0.92    0.04 -0.57                2                2
# 3      0.67     0.88    0.07  2.32                3                1
# 4      1.02     0.64    0.79  5.64                4                0
#
#        Classification Plant  topo_scmp_order_eq
# 0      dominant_model     k                True
# 1  intermediate_model     k                True
# 2  intermediate_model     k                True
# 3  intermediate_model     k                True
# 4  non_dominant_model     k                True

# %% [markdown]
# ### Time Series Split

# %%
df_results_cm_p_cs = (
    df_results[df_results["Features"].eq("Chemical + Mineralogical + Physical")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_p_cs["Features"].unique()
# Out:
# array(['Chemical + Mineralogical + Physical'], dtype=object)

# %%
df_results_cm_p_cs.shape
# Out:
# (30, 17)

# %% [markdown]
# ### Plant S

# %%
df_results_cm_p_cs = df_results_cm_p_cs[
    df_results_cm_p_cs["Plant"].eq("s")
].reset_index(drop=True)

# %%
df_results_cm_p_cs["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split', 'Time Series Split'], dtype=object)

# %%
df_results_cm_p_cs_tss = (
    df_results_cm_p_cs[df_results_cm_p_cs["Cross Validation"].eq("Time Series Split")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_p_cs_tss["Cross Validation"].unique()
# Out:
# array(['Time Series Split'], dtype=object)

# %%
df_results_cm_p_cs_tss.shape
# Out:
# (5, 17)

# %% [markdown]
# ###### SCPM computation

# %%
df_results_cm_p_cs_tss = compute_scpm(df_results_cm_p_cs_tss)

# %% [markdown]
# ##### Dominance Analysis

# %%
# Per project
dominance_dict = make_dominance_analysis(df_results_cm_p_cs_tss)
dominance_matrix_cm_p_cs_tss = dominance_dict["dominance_matrix"]
dominance_graph_cm_p_cs_tss = dominance_dict["dominance_graph"]
df_sorted_count = dominance_dict["df_sorted_count"]
df_sorted_topo = dominance_dict["df_sorted_topo"]

# %%
dominance_matrix_cm_p_cs_tss.shape, len(dominance_graph_cm_p_cs_tss)
# Out:
# ((5, 5), 5)

# %%
df_sorted_topo["Classification"].value_counts()
# Out:
# Classification
# intermediate_model    3
# dominant_model        1
# non_dominant_model    1
# Name: count, dtype: int64

# %%
df_sorted_topo.to_csv(
    "../../../../reports/results/global_models/ecics/209_s_dominance_analysis_cm_p_cs_tss.csv",
    index=False,
)

# %%
df_sorted_topo.head(5)
# Out:
#    Company Plant   Cross Validation                             Features  \
# 0      209     s  Time Series Split  Chemical + Mineralogical + Physical
# 1      209     s  Time Series Split  Chemical + Mineralogical + Physical
# 3      209     s  Time Series Split  Chemical + Mineralogical + Physical
# 4      209     s  Time Series Split  Chemical + Mineralogical + Physical
# 2      209     s  Time Series Split  Chemical + Mineralogical + Physical
#
#           Features_bkp            Model          Model_bkp  \
# 0  Chemical + Physical  Neural Networks                MLP
# 1  Chemical + Physical           Conv1D             Conv1D
# 3  Chemical + Physical  Neural Networks               LSTM
# 4  Chemical + Physical  Neural Networks  BidirectionalLSTM
# 2  Chemical + Physical  Neural Networks        Transformer
#
#              Model_bkp_2  Timesteps  RMSE_mean  ...  MAPE_mean   R2_mean  \
# 0                    MLP        NaN   0.790668  ...   1.452909  0.976708
# 1             Conv1D_1.0        1.0   0.970570  ...   1.735976  0.964481
# 3               LSTM_1.0        1.0   1.179825  ...   1.759961  0.940172
# 4  BidirectionalLSTM_1.0        1.0   1.185788  ...   1.972467  0.946583
# 2        Transformer_1.0        1.0   1.374921  ...   2.189240  0.926756
#
#    RMSE_std   MAE_std  MAPE_std    R2_std      SCPM  Dominated_Count  \
# 0  0.101774  0.063122  0.146045  0.005290 -5.984823                0
# 1  0.203195  0.087436  0.188137  0.012758 -2.078415                1
# 3  0.527326  0.156331  0.385089  0.055051  0.501405                2
# 4  0.239995  0.148219  0.380745  0.021361  1.820974                2
# 2  0.360852  0.158361  0.318648  0.034609  5.740860                4
#
#        Classification Dominates_Count
# 0      dominant_model               4
# 1  intermediate_model               3
# 3  intermediate_model               1
# 4  intermediate_model               1
# 2  non_dominant_model               0
#
# [5 rows x 21 columns]

# %%
df_sorted_topo_cols = df_sorted_topo[
    [
        # "Model",
        # "Model_bkp",
        "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Classification",
        "Dominates_Count",
        "Plant",
    ]
]  # .round(2)

# %% [markdown]
# ###### Dominant Models

# %%
# Top 4
df_sorted_topo_cols.iloc[0:2].sort_values(by="Dominates_Count", ascending=False).round(
    2
)
# Out:
#   Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  MAPE_std  \
# 0         MLP       0.79       0.1      0.58     0.06       1.45      0.15
# 1  Conv1D_1.0       0.97       0.2      0.71     0.09       1.74      0.19
#
#    R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 0     0.98    0.01 -5.98                0      dominant_model
# 1     0.96    0.01 -2.08                1  intermediate_model
#
#    Dominates_Count Plant
# 0                4     s
# 1                3     s

# %%
df_sorted_topo_cols[df_sorted_topo_cols["Classification"].eq("dominant_model")].shape
# Out:
# (1, 14)

# %% [markdown]
# ###### Intermediate models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].sort_values(by=["Dominates_Count", "SCPM"], ascending=[False, True]).iloc[:4].round(2)
# Out:
#              Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 1             Conv1D_1.0       0.97      0.20      0.71     0.09       1.74
# 3               LSTM_1.0       1.18      0.53      0.71     0.16       1.76
# 4  BidirectionalLSTM_1.0       1.19      0.24      0.79     0.15       1.97
#
#    MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 1      0.19     0.96    0.01 -2.08                1  intermediate_model
# 3      0.39     0.94    0.06  0.50                2  intermediate_model
# 4      0.38     0.95    0.02  1.82                2  intermediate_model
#
#    Dominates_Count Plant
# 1                3     s
# 3                1     s
# 4                1     s

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].shape
# Out:
# (3, 14)

# %% [markdown]
# ###### non-dominant models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].sort_values(by=["Dominates_Count", "SCPM"], ascending=[False, True]).iloc[:3]
# Out:
#        Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean   MAE_std  MAPE_mean  \
# 2  Transformer_1.0   1.374921  0.360852  0.895846  0.158361    2.18924
#
#    MAPE_std   R2_mean    R2_std     SCPM  Dominated_Count      Classification  \
# 2  0.318648  0.926756  0.034609  5.74086                4  non_dominant_model
#
#    Dominates_Count Plant
# 2                0     s

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].shape
# Out:
# (1, 14)

# %% [markdown]
# ###### Statistics per model type

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        # "Model_bkp",
        # "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
        "Plant",
    ]
]  # .round(2)

# %%
df_sorted_topo["Model"].value_counts()
# Out:
# Model
# Neural Networks    4
# Conv1D             1
# Name: count, dtype: int64

# %%
df_sorted_topo_models_grouped = df_sorted_topo_models_cols.groupby("Model").describe().T

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
    ]
]

# %%
(
    df_sorted_topo_models_cols.groupby("Model")[["Classification"]]
    .value_counts(normalize=True)
    .to_frame()
    * 100
).round(2)
# Out:
#                                     proportion
# Model           Classification
# Conv1D          intermediate_model       100.0
# Neural Networks intermediate_model        50.0
#                 dominant_model            25.0
#                 non_dominant_model        25.0

# %%
df_sorted_topo_models_cols.groupby("Model").describe().round(2).T
# Out:
# Model                  Conv1D  Neural Networks
# Dominated_Count count     1.0             4.00
#                 mean      1.0             2.00
#                 std       NaN             1.63
#                 min       1.0             0.00
#                 25%       1.0             1.50
#                 50%       1.0             2.00
#                 75%       1.0             2.50
#                 max       1.0             4.00
# Dominates_Count count     1.0             4.00
#                 mean      3.0             1.50
#                 std       NaN             1.73
#                 min       3.0             0.00
#                 25%       3.0             0.75
#                 50%       3.0             1.00
#                 75%       3.0             1.75
#                 max       3.0             4.00

# %%
# df_sorted_topo_models_cols

# %%
df_sorted_topo_models_cols.groupby("Model")["Classification"].describe()
# Out:
#                 count unique                 top freq
# Model
# Conv1D              1      1  intermediate_model    1
# Neural Networks     4      3  intermediate_model    2

# %%
df_sorted_topo_models_cols.groupby("Model")[["Classification"]].value_counts()
# Out:
# Model            Classification
# Conv1D           intermediate_model    1
# Neural Networks  intermediate_model    2
#                  dominant_model        1
#                  non_dominant_model    1
# Name: count, dtype: int64

# %%
summary_stats = df_sorted_topo_models_cols.groupby("Model").agg(
    Total_Models=("Model", "count"),
    Mean_Dominance_Count=("Dominates_Count", "mean"),
    Median_Dominance_Count=("Dominates_Count", "median"),
    Total_Dominated=("Dominated_Count", "sum"),
    Total_Dominating=("Dominates_Count", "sum"),
)

total_models = summary_stats[
    "Total_Models"
].sum()  # Get the total number of models across all categories
summary_stats["Dominance Proportion"] = summary_stats["Total_Dominating"] / total_models

# %%
summary_stats.round(2)
# Out:
#                  Total_Models  Mean_Dominance_Count  Median_Dominance_Count  \
# Model
# Conv1D                      1                   3.0                     3.0
# Neural Networks             4                   1.5                     1.0
#
#                  Total_Dominated  Total_Dominating  Dominance Proportion
# Model
# Conv1D                         1                 3                   0.6
# Neural Networks                8                 6                   1.2

# %%
df_sorted_topo_models_grouped.T
# Out:
#                 RMSE_mean                                                    \
#                     count      mean       std       min       25%       50%
# Model
# Conv1D                1.0  0.970570       NaN  0.970570  0.970570  0.970570
# Neural Networks       4.0  1.132801  0.245422  0.790668  1.082536  1.182807
#
#                                     RMSE_std            ... Dominated_Count  \
#                       75%       max    count      mean  ...             75%
# Model                                                   ...
# Conv1D           0.970570  0.970570      1.0  0.203195  ...             1.0
# Neural Networks  1.233071  1.374921      4.0  0.307487  ...             2.5
#
#                      Dominates_Count
#                  max           count mean       std  min   25%  50%   75%  max
# Model
# Conv1D           1.0             1.0  3.0       NaN  3.0  3.00  3.0  3.00  3.0
# Neural Networks  4.0             4.0  1.5  1.732051  0.0  0.75  1.0  1.75  4.0
#
# [2 rows x 88 columns]

# %% [markdown]
# ### SCPM Analysis

# %%
cols = [
    # "Model",
    # "Model_bkp",
    "Model_bkp_2",
    "RMSE_mean",
    "RMSE_std",
    "MAE_mean",
    "MAE_std",
    "MAPE_mean",
    "MAPE_std",
    "R2_mean",
    "R2_std",
    "SCPM",
    "Dominated_Count",
    "Dominates_Count",
    "Classification",
    "Plant",
]

# %% [markdown]
# #### SCPM Analysis by Project

# %%
df_sorted_scpm = df_sorted_topo.sort_values(by="SCPM").copy()

# %%
# (df_sorted_topo[cols].reset_index() == df_sorted_scpm[cols].reset_index()).all(axis=1)
df_sorted_scpm["topo_scmp_order_eq"] = df_sorted_topo.index == df_sorted_scpm.index

# %%
df_sorted_scpm[cols + ["topo_scmp_order_eq"]].round(2).head(5)
# Out:
#              Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 0                    MLP       0.79      0.10      0.58     0.06       1.45
# 1             Conv1D_1.0       0.97      0.20      0.71     0.09       1.74
# 3               LSTM_1.0       1.18      0.53      0.71     0.16       1.76
# 4  BidirectionalLSTM_1.0       1.19      0.24      0.79     0.15       1.97
# 2        Transformer_1.0       1.37      0.36      0.90     0.16       2.19
#
#    MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count  Dominates_Count  \
# 0      0.15     0.98    0.01 -5.98                0                4
# 1      0.19     0.96    0.01 -2.08                1                3
# 3      0.39     0.94    0.06  0.50                2                1
# 4      0.38     0.95    0.02  1.82                2                1
# 2      0.32     0.93    0.03  5.74                4                0
#
#        Classification Plant  topo_scmp_order_eq
# 0      dominant_model     s                True
# 1  intermediate_model     s                True
# 3  intermediate_model     s                True
# 4  intermediate_model     s                True
# 2  non_dominant_model     s                True
