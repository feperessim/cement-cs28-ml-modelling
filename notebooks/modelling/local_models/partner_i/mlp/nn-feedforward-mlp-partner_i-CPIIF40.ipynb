# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import keras_tuner as kt
import matplotlib.pyplot as plt
import time

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV

from keras.wrappers.scikit_learn import KerasRegressor

# %% [markdown]
# # Neural Network Feedforward - Multiple layers

# %% [markdown]
# # Baseline models
#
# First we will train a baseline model and verify its overall performance on each of the three datasets.

# %%
def get_baseline_model():
    model = tf.keras.Sequential()
    
    model.add(tf.keras.layers.Dense(units=1))
    opt = tf.keras.optimizers.Adam(learning_rate=0.01)
    model.compile(optimizer=opt, loss='mse', metrics=[tf.keras.metrics.RootMeanSquaredError(name="RMSE")])
    return model

# %%
def plot_predictions(model, df, index, x, y):
    d = df['Data/Hora'].values
    test_series = pd.DataFrame({'ccs28':y}, index=pd.to_datetime(d))
    pred_series = model.predict(scaler.transform(x))
    pred_series = pd.DataFrame({'ccs28-pred' : pred_series.squeeze()}, index=pd.to_datetime(d))

    fig, ax = plt.subplots(1, 1, sharex=True, sharey=True, figsize=(15, 7))

    test_series.plot(ax=ax)
    ax.axvline(test_series.index[index], color='r') # end of train dataset
    pred_series[index:].plot(ax=ax)
    ax.grid(which="both")
    ax.legend(["train and test series", "end of train series", 'predicted'], loc="upper left")
    # ax.set_xlabel('Period', labelpad=20, fontsize=15)
    ax.set_ylabel('Compressive Strength - MPa', labelpad=20, fontsize=15)
    plt.show()

# %%
name = "dados-historicos-partner_i-cement-CPIIF40.csv"
df_r3d_and_r7d = pd.read_csv("../../data/interim/" + "r3d-and-r7d-" + name)
df_r3d_only = pd.read_csv("../../data/interim/" + "r3d-only-" + name)
df_no_r3d_r7d = pd.read_csv("../../data/interim/" + "no-r3d-r7d-" + name)

# %%
seed = 47
scaler = StandardScaler()

# %% [markdown]
# <h3> Baseline model - Dataset: df_no_r3d_r7d</h3>

# %%
y = df_no_r3d_r7d['R28D'].values
x = df_no_r3d_r7d.drop(['Data/Hora', 'R28D'], axis=1).values
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=seed, shuffle=False)
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
model = get_baseline_model()
model.fit(x_train, y_train, batch_size=32, epochs=1000, verbose=0)
model.evaluate(x_test, y_test)
# Out:
# 2/2 [==============================] - 0s 2ms/step - loss: 3.7175 - RMSE: 1.9281
# [3.7174618244171143, 1.9280720949172974]

# %%
index = -53
plot_predictions(model, df_no_r3d_r7d, index, x, y)

# %% [markdown]
# <h3> Baseline model - Dataset: df_r3d_only</h3>

# %%
y = df_r3d_only['R28D'].values
x = df_r3d_only.drop(['Data/Hora', 'R28D'], axis=1).values
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=seed, shuffle=False)
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
model = get_baseline_model()
model.fit(x_train, y_train, batch_size=32, epochs=1000, verbose=0)
model.evaluate(x_test, y_test)
# Out:
# 2/2 [==============================] - 0s 2ms/step - loss: 4.8398 - RMSE: 2.2000
# [4.839837551116943, 2.199963092803955]

# %%
index = -53
plot_predictions(model, df_r3d_only, index, x, y)

# %% [markdown]
# <h3> Baseline model - Dataset: df_r3d_and_r7d</h3>

# %%
y = df_r3d_and_r7d['R28D'].values
x = df_r3d_and_r7d.drop(['Data/Hora', 'R28D'], axis=1).values
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=seed, shuffle=False)
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
model = get_baseline_model()
model.fit(x_train, y_train, batch_size=32, epochs=1000, verbose=0)
model.evaluate(x_test, y_test)
# Out:
# 2/2 [==============================] - 0s 2ms/step - loss: 3.7545 - RMSE: 1.9376
# [3.754462718963623, 1.9376436471939087]

# %%
index = -53
plot_predictions(model, df_r3d_and_r7d, index, x, y)

# %% [markdown]
# # Grid Search CV
#
# Before doing Repeated Cross Validation, we shall search for the best parameters. To do so, Keras Tuner will be used
# to accomplish the Grid Search.

# %% [markdown]
# <h3>GridCV - Scikit Learn</h3>

# %%
def create_keras_model(activation='swish', dropout_rate=0.0, n_units=0, n_layers=0, learning_rate=1e-3):
    model = tf.keras.Sequential()
    
    for _ in range(n_layers):
        model.add(tf.keras.layers.Dense(units=n_units, activation=activation))
    model.add(tf.keras.layers.Dropout(dropout_rate))
    model.add(tf.keras.layers.Dense(1))
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
                  loss="mse",
                  metrics=[tf.keras.metrics.RootMeanSquaredError(name="RMSE")])
    return model

# %%
def make_grid_search(x, y):
    activation = ['relu', 'swish', 'selu', 'linear']
    dropout_rate = [0.0, 0.1]
    n_units = [16, 32]
    n_layers = [0, 1, 2, 3]
    learning_rate = [0.001, 0.01, 0.1]
    epochs = [200]
    batches = [32]

    param_grid = dict(model__activation=activation,
                      model__dropout_rate=dropout_rate, 
                      model__n_units=n_units,
                      model__n_layers=n_layers, 
                      model__learning_rate=learning_rate,
                      model__epochs=epochs,
                      model__batch_size=batches)

    model = KerasRegressor(build_fn=create_keras_model, epochs=30, batch_size=32, verbose=0)
    pipeline = Pipeline(steps=[('transformer', StandardScaler()), ('model', model)])

    grid = GridSearchCV(estimator=pipeline, 
                        param_grid=param_grid,
                        n_jobs=-1,
                        cv=3, 
                        scoring='neg_root_mean_squared_error')
    
    # grid_result = grid.fit(scaler.fit_transform(x), y)
    grid_result = grid.fit(x, y)

    print("Best: %f using %s\n" % (grid_result.best_score_, grid_result.best_params_))
    means = grid_result.cv_results_['mean_test_score']
    stds = grid_result.cv_results_['std_test_score']
    params = grid_result.cv_results_['params']
    for mean, stdev, param in zip(means, stds, params):
        print("%f (%f) with: %r" % (mean, stdev, param))
    return grid

# %% [markdown]
# <h3>GridCV 1</h3>
#
# <b>Dataset: df_no_r3d_r7d:</b> In this dataset the R3D and R7D variables are not considered.

# %%
y = df_no_r3d_r7d['R28D'].values
x = df_no_r3d_r7d.drop(['Data/Hora', 'R28D'], axis=1).values
start = time.time()
gridcv1 = make_grid_search(x, y)
end = time.time()
print("\nMinutes Elapsed: ", (end - start)/60)
# Out:
# Best: -1.802320 using {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 3, 'model__n_units': 32}
#
# -46.036884 (1.015527) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 0, 'model__n_units': 16}
# -47.270638 (1.338482) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 0, 'model__n_units': 32}
# -21.745769 (2.417840) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 1, 'model__n_units': 16}
# -25.879262 (6.563530) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 1, 'model__n_units': 32}
# -18.039746 (4.510855) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 2, 'model__n_units': 16}
# -17.576235 (5.452477) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 2, 'model__n_units': 32}
# -19.101148 (9.713932) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 3, 'model__n_units': 16}
# -15.986101 (7.059710) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 3, 'model__n_units': 32}
# -30.047990 (0.939596) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 0, 'model__n_units': 16}
# -30.056632 (0.501408) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 0, 'model__n_units': 32}
# -18.835437 (1.877488) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 1, 'model__n_units': 16}
# -16.605687 (7.167449) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 1, 'model__n_units': 32}
# -17.087482 (9.923780) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 2, 'model__n_units': 16}
# -17.139805 (11.113827) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 2, 'model__n_units': 32}
# -15.471807 (8.150764) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 3, 'model__n_units': 16}
# -16.774199 (8.395364) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 3, 'model__n_units': 32}
# -2.665028 (0.560552) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 0, 'model__n_units': 16}
# -2.659067 (0.558397) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 0, 'model__n_units': 32}
# -13.575670 (5.598262) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 1, 'model__n_units': 16}
# -15.611853 (8.075194) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 1, 'model__n_units': 32}
# -9.692090 (1.833986) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 2, 'model__n_units': 16}
# -13.792063 (6.787426) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 2, 'model__n_units': 32}
# -9.384433 (6.057555) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 3, 'model__n_units': 16}
# -14.444776 (8.770309) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 3, 'model__n_units': 32}
# -47.408461 (0.963561) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 0, 'model__n_units': 16}
# -46.690503 (0.373148) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 0, 'model__n_units': 32}
# -22.857319 (2.253763) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 1, 'model__n_units': 16}
# -18.280484 (2.411196) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 1, 'model__n_units': 32}
# -19.211609 (8.509842) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 2, 'model__n_units': 16}
# -16.550510 (7.644216) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 2, 'model__n_units': 32}
# -18.608374 (9.098884) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 3, 'model__n_units': 16}
# -16.476879 (6.681231) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 3, 'model__n_units': 32}
# -30.281820 (0.864803) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 0, 'model__n_units': 16}
# -30.194614 (1.028353) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 0, 'model__n_units': 32}
# -10.145628 (3.864752) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 1, 'model__n_units': 16}
# -11.386405 (4.183269) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 1, 'model__n_units': 32}
# -12.354447 (6.354555) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 2, 'model__n_units': 16}
# -13.657929 (5.727167) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 2, 'model__n_units': 32}
# -11.401688 (3.938728) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 3, 'model__n_units': 16}
# -11.824324 (5.928002) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 3, 'model__n_units': 32}
# -2.271185 (0.350606) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 0, 'model__n_units': 16}
# -2.279876 (0.450012) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 0, 'model__n_units': 32}
# -3.390626 (0.998099) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 1, 'model__n_units': 16}
# -5.365056 (2.315852) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 1, 'model__n_units': 32}
# -2.997524 (0.608226) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 2, 'model__n_units': 16}
# -3.357642 (0.945076) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 2, 'model__n_units': 32}
# -2.282943 (0.112725) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 3, 'model__n_units': 16}
#
with: {'model__activation': 'linear', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 3, 'model__n_units': 32}
# -46.941254 (0.552228) with: {'model__activation': 'linear', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 0, 'model__n_units': 16}
# -46.842676 (1.147602) with: {'model__activation': 'linear', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 0, 'model__n_units': 32}
# -3.850908 (1.183344) with: {'model__activation': 'linear', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 1, 'model__n_units': 16}
# -2.443183 (0.397705) with: {'model__activation': 'linear', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 1, 'model__n_units': 32}
# -3.420513 (1.158365) with: {'model__activation': 'linear', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 2, 'model__n_units': 16}
# -2.694687 (0.395888) with: {'model__activation': 'linear', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 2, 'model__n_units': 32}
# -3.179561 (1.332227) with: {'model__activation': 'linear', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 3, 'model__n_units': 16}
# -5.740864 (4.004598) with: {'model__activation': 'linear', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 3, 'model__n_units': 32}
# -30.068810 (0.888687) with: {'model__activation': 'linear', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 0, 'model__n_units': 16}
# -29.958916 (0.939243) with: {'model__activation': 'linear', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 0, 'model__n_units': 32}
# -4.163390 (0.570667) with: {'model__activation': 'linear', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 1, 'model__n_units': 16}
# -4.101257 (1.765907) with: {'model__activation': 'linear', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 1, 'model__n_units': 32}
# -4.307211 (1.412714) with: {'model__activation': 'linear', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 2, 'model__n_units': 16}
# -4.629345 (1.847428) with: {'model__activation': 'linear', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 2, 'model__n_units': 32}
# -2.821747 (0.349958) with: {'model__activation': 'linear', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 3, 'model__n_units': 16}
# -2.922949 (0.329700) with: {'model__activation': 'linear', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 3, 'model__n_units': 32}
# -2.158932 (0.366746) with: {'model__activation': 'linear', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 0, 'model__n_units': 16}
# -2.240284 (0.358124) with: {'model__activation': 'linear', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 0, 'model__n_units': 32}
# -4.481036 (1.768432) with: {'model__activation': 'linear', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 1, 'model__n_units': 16}
# -4.819372 (2.026467) with: {'model__activation': 'linear', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 1, 'model__n_units': 32}
# -2.745152 (0.724844) with: {'model__activation': 'linear', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 2, 'model__n_units': 16}
# -2.658775 (0.676778) with: {'model__activation': 'linear', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 2, 'model__n_units': 32}
# -2.722299 (0.541111) with: {'model__activation': 'linear', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 3, 'model__n_units': 16}
# -2.538344 (0.565269) with: {'model__activation': 'linear', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 3, 'model__n_units': 32}
#
# Minutes Elapsed:  10.76635120709737

# %%
gridcv1.best_params_
# Out:
# {'model__activation': 'swish',
#  'model__batch_size': 32,
#  'model__dropout_rate': 0.1,
#  'model__epochs': 200,
#  'model__learning_rate': 0.1,
#  'model__n_layers': 3,
#  'model__n_units': 32}

# %% [markdown]
# <h3>GridCV 2</h3>
#
# <b>Dataset: df_r3d_only:</b> In this dataset only R3D is considered.

# %%
y = df_r3d_only['R28D'].values
x = df_r3d_only.drop(['Data/Hora', 'R28D'], axis=1).values
start = time.time()
gridcv2 = make_grid_search(x, y)
end = time.time()
print("\nMinutes Elapsed: ", (end - start)/60)
# Out:
# Best: -1.783833 using {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 3, 'model__n_units': 32}
#
# -46.254424 (0.184427) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 0, 'model__n_units': 16}
# -45.885565 (0.340007) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 0, 'model__n_units': 32}
# -21.360331 (3.384866) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 1, 'model__n_units': 16}
# -22.407744 (3.638396) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 1, 'model__n_units': 32}
# -19.949184 (8.498133) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 2, 'model__n_units': 16}
# -19.109552 (7.915926) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 2, 'model__n_units': 32}
# -20.972273 (8.785814) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 3, 'model__n_units': 16}
# -16.187194 (8.107868) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 3, 'model__n_units': 32}
# -30.093654 (0.640151) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 0, 'model__n_units': 16}
# -30.113030 (0.612463) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 0, 'model__n_units': 32}
# -16.408182 (6.498505) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 1, 'model__n_units': 16}
# -18.695257 (5.912335) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 1, 'model__n_units': 32}
# -18.600437 (5.434339) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 2, 'model__n_units': 16}
# -17.483061 (8.179363) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 2, 'model__n_units': 32}
# -14.816933 (4.824510) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 3, 'model__n_units': 16}
# -16.007919 (4.675933) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 3, 'model__n_units': 32}
# -2.376400 (0.518268) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 0, 'model__n_units': 16}
# -2.455533 (0.654255) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 0, 'model__n_units': 32}
# -18.661675 (7.979172) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 1, 'model__n_units': 16}
# -16.064269 (6.522626) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 1, 'model__n_units': 32}
# -12.087347 (5.034492) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 2, 'model__n_units': 16}
# -12.957783 (4.544463) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 2, 'model__n_units': 32}
# -10.009447 (3.907241) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 3, 'model__n_units': 16}
# -14.377420 (4.761639) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 3, 'model__n_units': 32}
# -47.405933 (0.515758) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 0, 'model__n_units': 16}
# -47.228221 (1.367391) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 0, 'model__n_units': 32}
# -20.157244 (1.606974) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 1, 'model__n_units': 16}
# -21.535586 (4.357593) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 1, 'model__n_units': 32}
# -19.395335 (4.020780) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 2, 'model__n_units': 16}
# -19.090658 (9.213859) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 2, 'model__n_units': 32}
# -23.116810 (9.543728) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 3, 'model__n_units': 16}
# -20.061431 (8.780236) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 3, 'model__n_units': 32}
# -30.061910 (0.704080) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 0, 'model__n_units': 16}
# -29.971382 (0.476201) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 0, 'model__n_units': 32}
# -10.163157 (3.723338) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 1, 'model__n_units': 16}
# -12.272404 (4.700715) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 1, 'model__n_units': 32}
# -16.228349 (6.746987) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 2, 'model__n_units': 16}
# -18.217629 (8.273417) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 2, 'model__n_units': 32}
# -11.929348 (3.599953) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 3, 'model__n_units': 16}
# -12.640396 (4.881247) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 3, 'model__n_units': 32}
# -2.058913 (0.386592) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 0, 'model__n_units': 16}
# -2.087177 (0.388822) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 0, 'model__n_units': 32}
# -2.934137 (0.850493) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 1, 'model__n_units': 16}
# -5.021338 (2.417660) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 1, 'model__n_units': 32}
# -3.143185 (1.430851) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 2, 'model__n_units': 16}
# -3.483983 (1.605601) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 2, 'model__n_units': 32}
# -2.007114 (0.272703) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 3, 'model__n_units': 16}
# -1.987113 (0.403585) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 3, 'model__n_units': 32}
# -46.862158 (0.192848) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 0, 'model__n_units': 16}
# -47.069846 (1.087787) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 0, 'model__n_units': 32}
# -26.344776 (13.110274) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 1, 'model__n_units': 16}
# -22.556694 (5.782240) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 1, 'model__n_units': 32}
# -21.954672 (5.880972) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 2, 'model__n_units': 16}
# -24.393814 (8.300779) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 2, 'model__n_units': 32}
# -18.855959 (4.898125) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 3, 'model__n_units': 16}
# -18.378319 (4.444714) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 3, 'model__n_units': 32}
# -30.194977 (0.582216) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 0, 'model__n_units': 16}
# -29.978236 (0.538656) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 0, 'model__n_units': 32}
# -17.410878 (4.590346) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 1, 'model__n_units': 16}
# -18.714904 (4.204492) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 1, 'model__n_units': 32}
# -18.248969 (5.336299) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 2, 'model__n_units': 16}
# -20.630103 (10.335606) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 2, 'model__n_units': 32}
# -13.614037 (5.850839) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 3, 'model__n_units': 16}
# -12.751016 (5.287806) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 3, 'model__n_units': 32}
# -2.333464 (0.497722) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 0, 'model__n_units': 16}
# -2.391837 (0.537555) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 0, 'model__n_units': 32}
# -19.190028 (8.089973) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 1, 'model__n_units': 16}
# -14.790913 (4.106656) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 1, 'model__n_units': 32}
# -14.555701 (8.554944) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 2, 'model__n_units': 16}
# -15.468434 (5.953968) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 2, 'model__n_units': 32}
#
with: {'model__activation': 'linear', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 3, 'model__n_units': 16}
# -2.431208 (0.511046) with: {'model__activation': 'linear', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 3, 'model__n_units': 32}
#
# Minutes Elapsed:  9.713398631413778

# %%
gridcv2.best_params_
# Out:
# {'model__activation': 'swish',
#  'model__batch_size': 32,
#  'model__dropout_rate': 0.1,
#  'model__epochs': 200,
#  'model__learning_rate': 0.1,
#  'model__n_layers': 3,
#  'model__n_units': 32}

# %% [markdown]
# <h3>GridCV 3</h3>
#
# <b>Dataset: df_r3d_and_r7d:</b> In this dataset R3D and R7D are considered.

# %%
y = df_r3d_and_r7d['R28D'].values
x = df_r3d_and_r7d.drop(['Data/Hora', 'R28D'], axis=1).values
start = time.time()
gridcv3 = make_grid_search(x, y)
end = time.time()
print("\nMinutes Elapsed: ", (end - start)/60)
# Out:
# Best: -1.859486 using {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 0, 'model__n_units': 16}
#
# -47.383780 (1.609791) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 0, 'model__n_units': 16}
# -47.565526 (0.082873) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 0, 'model__n_units': 32}
# -23.735915 (0.530994) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 1, 'model__n_units': 16}
# -20.921387 (1.485017) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 1, 'model__n_units': 32}
# -21.473406 (5.458019) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 2, 'model__n_units': 16}
# -20.582513 (10.185733) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 2, 'model__n_units': 32}
# -19.146199 (9.643949) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 3, 'model__n_units': 16}
# -20.694741 (11.454505) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 3, 'model__n_units': 32}
# -30.062975 (0.551536) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 0, 'model__n_units': 16}
# -29.963170 (1.008249) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 0, 'model__n_units': 32}
# -19.326043 (6.636397) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 1, 'model__n_units': 16}
# -18.053762 (5.077116) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 1, 'model__n_units': 32}
# -15.799714 (5.849556) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 2, 'model__n_units': 16}
# -17.647428 (9.155801) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 2, 'model__n_units': 32}
# -18.544040 (9.428296) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 3, 'model__n_units': 16}
# -16.029310 (7.584232) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 3, 'model__n_units': 32}
# -2.277638 (0.708475) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 0, 'model__n_units': 16}
# -2.166340 (0.606006) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 0, 'model__n_units': 32}
# -14.660176 (4.397286) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 1, 'model__n_units': 16}
# -14.951079 (3.367888) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 1, 'model__n_units': 32}
# -13.922465 (4.660473) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 2, 'model__n_units': 16}
# -14.199227 (3.961109) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 2, 'model__n_units': 32}
# -9.438150 (4.715670) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 3, 'model__n_units': 16}
# -16.328321 (10.115403) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 3, 'model__n_units': 32}
# -46.714293 (0.087838) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 0, 'model__n_units': 16}
# -47.079867 (1.032086) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 0, 'model__n_units': 32}
# -19.460539 (3.191984) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 1, 'model__n_units': 16}
# -21.265972 (4.136516) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 1, 'model__n_units': 32}
# -21.305549 (6.613295) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 2, 'model__n_units': 16}
# -20.589991 (9.268855) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 2, 'model__n_units': 32}
# -18.157510 (5.042934) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 3, 'model__n_units': 16}
# -19.031019 (8.698311) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 3, 'model__n_units': 32}
# -30.228803 (0.557429) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 0, 'model__n_units': 16}
# -29.836356 (0.470751) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 0, 'model__n_units': 32}
# -11.474671 (2.716355) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 1, 'model__n_units': 16}
# -12.074521 (3.078165) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 1, 'model__n_units': 32}
# -16.066208 (8.059390) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 2, 'model__n_units': 16}
# -14.541096 (5.859956) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 2, 'model__n_units': 32}
# -12.193050 (4.199020) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 3, 'model__n_units': 16}
# -16.682267 (7.740690) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 3, 'model__n_units': 32}
# -1.859486 (0.409807) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 0, 'model__n_units': 16}
# -1.880292 (0.393565) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 0, 'model__n_units': 32}
# -3.476430 (1.008201) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 1, 'model__n_units': 16}
# -6.179442 (0.966904) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 1, 'model__n_units': 32}
# -2.950234 (0.866518) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 2, 'model__n_units': 16}
# -4.173389 (0.937898) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 2, 'model__n_units': 32}
# -2.126610 (0.403995) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 3, 'model__n_units': 16}
# -2.050386 (0.391995) with: {'model__activation': 'relu', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 3, 'model__n_units': 32}
# -47.642972 (0.623730) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 0, 'model__n_units': 16}
# -47.253580 (0.965299) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 0, 'model__n_units': 32}
# -28.908360 (8.917625) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 1, 'model__n_units': 16}
# -23.675406 (5.802901) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 1, 'model__n_units': 32}
# -22.816800 (6.467538) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 2, 'model__n_units': 16}
# -26.128618 (10.235475) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 2, 'model__n_units': 32}
# -20.507865 (6.398617) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 3, 'model__n_units': 16}
# -22.180817 (11.074124) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 3, 'model__n_units': 32}
# -30.073342 (0.518667) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 0, 'model__n_units': 16}
# -29.953689 (0.389467) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 0, 'model__n_units': 32}
# -12.916659 (3.322584) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 1, 'model__n_units': 16}
# -21.355225 (3.624904) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 1, 'model__n_units': 32}
# -19.321850 (6.675088) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 2, 'model__n_units': 16}
# -22.945298 (6.877732) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 2, 'model__n_units': 32}
# -12.909715 (2.465329) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 3, 'model__n_units': 16}
# -9.290534 (1.130819) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 3, 'model__n_units': 32}
# -2.173724 (0.612241) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 0, 'model__n_units': 16}
# -2.173918 (0.591709) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 0, 'model__n_units': 32}
# -18.414986 (6.567191) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 1, 'model__n_units': 16}
# -17.294080 (4.345353) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 1, 'model__n_units': 32}
# -14.946923 (4.644939) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 2, 'model__n_units': 16}
# -13.857702 (5.696500) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 2, 'model__n_units': 32}
# -6.166728 (2.910178) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 3, 'model__n_units': 16}
# -10.952400 (3.840448) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.0, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 3, 'model__n_units': 32}
# -46.496529 (1.245743) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 0, 'model__n_units': 16}
# -46.572981 (1.050846) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 0, 'model__n_units': 32}
# -23.627762 (6.158403) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 1, 'model__n_units': 16}
# -23.556196 (7.298121) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 1, 'model__n_units': 32}
# -21.703556 (4.662505) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 2, 'model__n_units': 16}
# -22.476799 (9.566452) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 2, 'model__n_units': 32}
# -22.707131 (8.097756) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 3, 'model__n_units': 16}
# -22.024055 (7.286088) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.001, 'model__n_layers': 3, 'model__n_units': 32}
# -29.958816 (0.660929) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 0, 'model__n_units': 16}
# -29.968374 (0.374593) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 0, 'model__n_units': 32}
# -10.937376 (3.478915) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 1, 'model__n_units': 16}
# -15.887168 (6.121312) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 1, 'model__n_units': 32}
# -13.227370 (2.465421) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 2, 'model__n_units': 16}
# -13.978606 (7.282894) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 2, 'model__n_units': 32}
# -7.952074 (1.513900) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 3, 'model__n_units': 16}
# -4.869432 (2.067958) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.01, 'model__n_layers': 3, 'model__n_units': 32}
# -1.936916 (0.428352) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 0, 'model__n_units': 16}
# -1.966299 (0.461728) with: {'model__activation': 'swish', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 0, 'model__n_units': 32}
#
with: {'model__activation': 'linear', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 2, 'model__n_units': 16}
# -2.381244 (0.138621) with: {'model__activation': 'linear', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 2, 'model__n_units': 32}
# -2.444052 (0.720168) with: {'model__activation': 'linear', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 3, 'model__n_units': 16}
# -2.514488 (0.592451) with: {'model__activation': 'linear', 'model__batch_size': 32, 'model__dropout_rate': 0.1, 'model__epochs': 200, 'model__learning_rate': 0.1, 'model__n_layers': 3, 'model__n_units': 32}
#
# Minutes Elapsed:  8.978046039740244

# %%
gridcv3.best_params_
# Out:
# {'model__activation': 'relu',
#  'model__batch_size': 32,
#  'model__dropout_rate': 0.1,
#  'model__epochs': 200,
#  'model__learning_rate': 0.1,
#  'model__n_layers': 0,
#  'model__n_units': 16}

# %% [markdown]
# <h2>Repeated KFold Cross validation</h2>
#
# Here we will make a Repeated KFold Cross validation with all 3 datasets using the best parameters found
# in the GridSearch cv

# %%
def make_repeated_kfold_cross_validation(grid, x, y):
    activation = grid.best_params_['model__activation']
    dropout_rate = grid.best_params_['model__dropout_rate']
    n_units = grid.best_params_['model__n_units']
    n_layers = grid.best_params_['model__n_layers']
    learning_rate = grid.best_params_['model__learning_rate']
    batch_size = grid.best_params_['model__batch_size']
    epochs = grid.best_params_['model__epochs']

    rkf = RepeatedKFold(n_splits=10, n_repeats=10, random_state=seed)
    scores = []

    start = time.time()
    for train, test in rkf.split(x):
        model = create_keras_model(activation=activation,
                                   dropout_rate=dropout_rate,
                                   n_units=n_units,
                                   n_layers=n_layers,
                                   learning_rate=learning_rate)
        model.fit(scaler.fit_transform(x[train]), y[train], epochs=epochs, batch_size=batch_size, verbose=0)
        rmse = model.evaluate(scaler.transform(x[test]), y[test], verbose=0)
        scores.append(rmse[1])
    
    print('RMSE: %.3f (%.3f)' % (np.mean(scores), np.std(scores)))
    end = time.time()
    print("Minutes Elapsed: ", (end - start)/60)
    return rkf, scores

# %% [markdown]
# <h3>Experiment 1</h3>
# <h4> Repeated KFold Cross Validation - df_no_r3d_r7d</h4>
#
# <b>Dataset: df_no_r3d_r7d:</b> In this dataset the R3D and R7D variables are not considered.

# %%
y = df_no_r3d_r7d['R28D'].values
x = df_no_r3d_r7d.drop(['Data/Hora', 'R28D'], axis=1).values
rkf1, scores = make_repeated_kfold_cross_validation(gridcv1, x, y)
# Out:
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_test_function.<locals>.test_function at 0x7f51781b7e18> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f51783cd950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# RMSE: 2.408 (4.517)
# Minutes Elapsed:  4.689332922299703

# %%
plt.figure(figsize=(15,8))
plt.ylabel('RMSE', labelpad=20, fontsize=15)
plt.xlabel('Repeats', labelpad=20, fontsize=15)
plt.boxplot(np.reshape(scores, (10,10)), labels=[str(r) for r in range(1, 11)], showmeans=True)
plt.show()

# %%
activation = gridcv1.best_params_['model__activation']
dropout_rate = gridcv1.best_params_['model__dropout_rate']
n_units = gridcv1.best_params_['model__n_units']
n_layers = gridcv1.best_params_['model__n_layers']
learning_rate = gridcv1.best_params_['model__learning_rate']
batch_size = gridcv1.best_params_['model__batch_size']
epochs = gridcv1.best_params_['model__epochs']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=seed, shuffle=False)
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

model = create_keras_model(activation=activation,
                                   dropout_rate=dropout_rate,
                                   n_units=n_units,
                                   n_layers=n_layers,
                                   learning_rate=learning_rate)

model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size, verbose=0)
rmse = model.evaluate(x_test, y_test, verbose=0)
print('RMSE: %.3f' % rmse[1])
# Out:
# RMSE: 1.754

# %%
index = -53
plot_predictions(model, df_no_r3d_r7d, index, x, y)

# %% [markdown]
# <h3>Experiment 2</h3>
# <h4> Repeated KFold Cross Validation - df_r3d_only</h4>
#
# <b>Dataset: df_r3d_only:</b> In this dataset only R3D is considered.

# %%
y = df_r3d_only['R28D'].values
x = df_r3d_only.drop(['Data/Hora', 'R28D'], axis=1).values
rkf2, scores = make_repeated_kfold_cross_validation(gridcv2, x, y)
# Out:
# RMSE: 2.297 (4.068)
# Minutes Elapsed:  6.302614148457845

# %%
plt.figure(figsize=(15,8))
plt.ylabel('RMSE', labelpad=20, fontsize=15)
plt.xlabel('Repeats', labelpad=20, fontsize=15)
plt.boxplot(np.reshape(scores, (10,10)), labels=[str(r) for r in range(1, 11)], showmeans=True)
plt.show()

# %%
activation = gridcv2.best_params_['model__activation']
dropout_rate = gridcv2.best_params_['model__dropout_rate']
n_units = gridcv2.best_params_['model__n_units']
n_layers = gridcv2.best_params_['model__n_layers']
learning_rate = gridcv2.best_params_['model__learning_rate']
batch_size = gridcv2.best_params_['model__batch_size']
epochs = gridcv2.best_params_['model__epochs']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=seed, shuffle=False)
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

model = create_keras_model(activation=activation,
                                   dropout_rate=dropout_rate,
                                   n_units=n_units,
                                   n_layers=n_layers,
                                   learning_rate=learning_rate)

model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size, verbose=0)
rmse = model.evaluate(x_test, y_test, verbose=0)
print('RMSE: %.3f' % rmse[1])
# Out:
# RMSE: 2.406

# %%
index = -53
plot_predictions(model, df_r3d_only, index, x, y)

# %% [markdown]
# <h3>Experiment 3</h3>
# <h4> Repeated KFold Cross Validation - df_r3d_and_r7d</h4>
#
# <b>Dataset: df_r3d_and_r7d:</b> In this dataset both R3D and R7D are considered.

# %%
y = df_r3d_and_r7d['R28D'].values
x = df_r3d_and_r7d.drop(['Data/Hora', 'R28D'], axis=1).values
rkf3, scores = make_repeated_kfold_cross_validation(gridcv3, x, y)
# Out:
# RMSE: 1.255 (0.142)
# Minutes Elapsed:  3.8727569500605266

# %%
plt.figure(figsize=(15,8))
plt.ylabel('RMSE', labelpad=20, fontsize=15)
plt.xlabel('Repeats', labelpad=20, fontsize=15)
plt.boxplot(np.reshape(scores, (10,10)), labels=[str(r) for r in range(1, 11)], showmeans=True)
plt.show()

# %%
activation = gridcv3.best_params_['model__activation']
dropout_rate = gridcv3.best_params_['model__dropout_rate']
n_units = gridcv3.best_params_['model__n_units']
n_layers = gridcv3.best_params_['model__n_layers']
learning_rate = gridcv3.best_params_['model__learning_rate']
batch_size = gridcv3.best_params_['model__batch_size']
epochs = gridcv3.best_params_['model__epochs']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=seed, shuffle=False)
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

model = create_keras_model(activation=activation,
                                   dropout_rate=dropout_rate,
                                   n_units=n_units,
                                   n_layers=n_layers,
                                   learning_rate=learning_rate)

model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size, verbose=0)
rmse = model.evaluate(x_test, y_test, verbose=0)
print('RMSE: %.3f' % rmse[1])
# Out:
# RMSE: 1.829

# %%
index = -53
plot_predictions(model, df_r3d_and_r7d, index, x, y)
