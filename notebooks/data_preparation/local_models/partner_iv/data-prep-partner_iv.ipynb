# %%
# %load_ext nb_black

# %%
import pandas as pd
import numpy as np

import datetime as dt

# %% [markdown]
# ## Reading the dataset

# %%
xlsx = pd.ExcelFile(
    "../../../../data/raw/partner_iv/DB_Master_CP1_latest.xlsx", engine="openpyxl"
)

# %%
df_cem_a = pd.read_excel(xlsx, sheet_name="Cem A exp control", skiprows=[1, 2])
df_cem_a = df_cem_a[
    [col for col in df_cem_a.columns.fillna("Unnamed") if "Unnamed" not in col]
]

# %%
df_cem_b = pd.read_excel(xlsx, sheet_name="Cem B exp control", skiprows=[1, 2])
df_cem_b = df_cem_b[
    [col for col in df_cem_b.columns.fillna("Unnamed") if "Unnamed" not in col]
]

# %%
df_cem_c = pd.read_excel(xlsx, sheet_name="Cem c exp control", skiprows=[1, 2])
df_cem_c = df_cem_c[
    [col for col in df_cem_c.columns.fillna("Unnamed") if "Unnamed" not in col]
]

df_cem_c["data"] = pd.TimedeltaIndex(df_cem_c["data"], unit="d") + dt.datetime(
    1900, 1, 1
)

# %%
df = pd.concat([df_cem_a, df_cem_b, df_cem_c], ignore_index=True, axis=0)

# %% [markdown]
# ## Initial Preprocessing

# %%
df["cem_type"] = (
    df["CEM A expedition control"]
    .combine_first(df["CEM B  expedition control"])
    .combine_first(df["CEM C  expedition control"])
)

# %% [markdown]
# ### Removing features
#
# Here we will drop some features that may not contribute to the performance of the models that will be fitted on this data.
#
# 1. Removing features with features having 60% or more of missing values
# 2. Removing features related to the properties of Cement
# 3. Removing features with zero variance
# 4. Removing features with more than 70% of zeros

# %% [markdown]
# <h3>Percentage of missing values:</h3>
#
# <table>
#     <th>Full Dataset:</th>
#     <th></th>
#     <tr>
#         <td>silo</td>
#         <td>100</td>
#     </tr>
#     <tr>
#         <td>tratt. 63 µm</td>
#         <td>100</td>
#     </tr>
#     <tr>
#         <td>tratt. 40 µm</td>
#         <td>100</td>
#     </tr>
#     <tr>
#     <td>tratt. 32 µm</td>
#     <td>100</td>
#     </tr>
#     <tr>
#     <td>7 days strenght</td>
#     <td>97.952917</td>
#     <tr/>
#     <tr>
#     <td>rihcl</td>
#     <td>93.551689</td>
#     <tr/>
#     <tr>
#     <td>LOI</td>
#     <td>20.266121</td>
#     <tr/>
# </table>
#
# <table>
#     <th>CEM A</th>
#     <th></th>
#         <tr>
#         <td>silo</td>
#         <td>100</td>
#     </tr>
#     <tr>
#         <td>tratt. 63 µm</td>
#         <td>100</td>
#     </tr>
#     <tr>
#         <td>tratt. 40 µm</td>
#         <td>100</td>
#     </tr>
#     <tr>
#     <td>tratt. 32 µm</td>
#     <td>100</td>
#     </tr>
#     <tr>
#     <td>7 days strenght</td>
#     <td>100.000000</td>
#     <tr/>
#     <tr>
#     <td>rihcl</td>
#     <td>80.434783</td>
#     <tr/>
#     <tr>
#     <td>LOI</td>
#     <td>19.875776</td>
#     <tr/>
# </table>
#
# <table>
#     <th>CEM B</th>
#     <th></th>
#         <tr>
#         <td>silo</td>
#         <td>100</td>
#     </tr>
#     <tr>
#         <td>tratt. 63 µm</td>
#         <td>100</td>
#     </tr>
#     <tr>
#         <td>tratt. 40 µm</td>
#         <td>100</td>
#     </tr>
#     <tr>
#     <td>tratt. 32 µm</td>
#     <td>100</td>
#     </tr>
#     <tr>
#     <td>7 days strenght</td>
#     <td>100.000000</td>
#     <tr/>
#     <tr>
#     <td>rihcl</td>
#     <td>100.000000</td>
#     <tr/>
#     <tr>
#     <td>LOI</td>
#     <td>19.756839</td>
#     <tr/>
# </table>
#
# <table>
#     <th>CEM C</th>
#     <th></th>
#     <th></th>
#         <tr>
#         <td>silo</td>
#         <td>100</td>
#     </tr>
#     <tr>
#         <td>tratt. 63 µm</td>
#         <td>100</td>
#     </tr>
#     <tr>
#         <td>tratt. 40 µm</td>
#         <td>100</td>
#     </tr>
#     <tr>
#     <td>tratt. 32 µm</td>
#     <td>100</td>
#     </tr>
#     <tr>
#     <td>7 days strenght</td>
#     <td>93.865031</td>
#     <tr/>
#     <tr>
#     <td>rihcl</td>
#     <td>100.000000</td>
#     <tr/>
#     <tr>
#     <td>LOI</td>
#     <td>21.165644</td>
#     <tr/>
# </table>

# %%
FEATURES_TO_DROP_ALL_CEMENTS = [
    # Missing Values
    "silo",
    "tratt. 63 µm",
    "tratt. 40 µm",
    "tratt. 32 µm",
    "7 days strenght",
    "rihcl",
    # Missing values that cause troubles with cross validation techniques
    "LOI",
    # Features with more than 70% percent of repeated values (low variance)
    # Useless Features
    "CEM A expedition control",
    "CEM B  expedition control",
    "CEM C  expedition control",
    "sigla",
    "SampleName",
]

FEATURES_TO_DROP_CEM_A = [
    # Missing Values
    "tratt. 63 µm",
    "tratt. 40 µm",
    "tratt. 32 µm",
    "7 days strenght",
    "rihcl",
    # Missing values that cause troubles with cross validation techniques
    "LOI",
    # Useless Features
    "CEM A expedition control",
    "sigla",
    "SampleName",
]

FEATURES_TO_DROP_CEM_B = [
    # Missing Values
    "silo",
    "tratt. 63 µm",
    "tratt. 40 µm",
    "tratt. 32 µm",
    "7 days strenght",
    "rihcl",
    # Missing values that cause troubles with cross validation techniques
    "LOI",
    # Useless Features
    "CEM B  expedition control",
    "sigla",
    "SampleName",
]

FEATURES_TO_DROP_CEM_C = [
    # Missing Values
    "silo",
    "tratt. 63 µm",
    "tratt. 40 µm",
    "tratt. 32 µm",
    "7 days strenght",
    "rihcl",
    # Missing values that cause troubles with cross validation techniques
    "LOI",
    # Useless Features
    "CEM C  expedition control",
    "sigla",
    "SampleName",
]

# %%
df = df.drop(labels=FEATURES_TO_DROP_ALL_CEMENTS, axis=1)
df_cem_a = df_cem_a.drop(labels=FEATURES_TO_DROP_CEM_A, axis=1)
df_cem_b = df_cem_b.drop(labels=FEATURES_TO_DROP_CEM_B, axis=1)
df_cem_c = df_cem_c.drop(labels=FEATURES_TO_DROP_CEM_C, axis=1)

# %% [markdown]
# ### Drop rows where the target variable is null

# %%
df = df[df["28 days strenght"].notna()]
df_cem_a = df_cem_a[df_cem_a["28 days strenght"].notna()]
df_cem_b = df_cem_b[df_cem_b["28 days strenght"].notna()]
df_cem_c = df_cem_c[df_cem_c["28 days strenght"].notna()]

# %%
(df.isna().sum().sort_values(ascending=False) / df.shape[0] * 100).to_frame(
    name="Missing (%)"
).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_6452d_row0_col0, #T_6452d_row1_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_6452d_row2_col0, #T_6452d_row3_col0, #T_6452d_row4_col0, #T_6452d_row5_col0, #T_6452d_row6_col0, #T_6452d_row7_col0, #T_6452d_row8_col0, #T_6452d_row9_col0, #T_6452d_row10_col0, #T_6452d_row11_col0, #T_6452d_row12_col0, #T_6452d_row13_col0, #T_6452d_row14_col0, #T_6452d_row15_col0, #T_6452d_row16_col0, #T_6452d_row17_col0, #T_6452d_row18_col0, #T_6452d_row19_col0, #T_6452d_row20_col0, #T_6452d_row21_col0, #T_6452d_row22_col0, #T_6452d_row23_col0, #T_6452d_row24_col0 {
#   background-color: #6d010e;
#   color: #f1f1f1;
# }
# #T_6452d_row25_col0 {
#   background-color: #fdd2bf;
#   color: #000000;
# }
# #T_6452d_row26_col0 {
#   background-color: #fee7db;
#   color: #000000;
# }
# #T_6452d_row27_col0 {
#   background-color: #ffebe2;
#   color: #000000;
# }
# #T_6452d_row28_col0, #T_6452d_row29_col0 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_6452d_row30_col0, #T_6452d_row31_col0 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_6452d_row32_col0, #T_6452d_row33_col0, #T_6452d_row34_col0, #T_6452d_row35_col0, #T_6452d_row36_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_6452d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6452d_level0_col0" class="col_heading level0 col0" >Missing (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6452d_level0_row0" class="row_heading level0 row0" >CO2_XRD</th>
#       <td id="T_6452d_row0_col0" class="data row0 col0" >8.455115</td>
#     </tr>
#     <tr>
#       <th id="T_6452d_level0_row1" class="row_heading level0 row1" >SO3_XRD</th>
#       <td id="T_6452d_row1_col0" class="data row1 col0" >8.455115</td>
#     </tr>
#     <tr>
#       <th id="T_6452d_level0_row2" class="row_heading level0 row2" >C3A cub</th>
#       <td id="T_6452d_row2_col0" class="data row2 col0" >8.350731</td>
#     </tr>
#     <tr>
#       <th id="T_6452d_level0_row3" class="row_heading level0 row3" >Belite_beta</th>
#       <td id="T_6452d_row3_col0" class="data row3 col0" >8.350731</td>
#     </tr>
#     <tr>
#       <th id="T_6452d_level0_row4" class="row_heading level0 row4" >Gesso</th>
#       <td id="T_6452d_row4_col0" class="data row4 col0" >8.350731</td>
#     </tr>
#     <tr>
#       <th id="T_6452d_level0_row5" class="row_heading level0 row5" >Aphthitalite – (K,Na)3(SO4)2</th>
#       <td id="T_6452d_row5_col0" class="data row5 col0" >8.350731</td>
#     </tr>
#     <tr>
#       <th id="T_6452d_level0_row6" class="row_heading level0 row6" >Langbeinite – MgK2(SO4)2</th>
#       <td id="T_6452d_row6_col0" class="data row6 col0" >8.350731</td>
#     </tr>
#     <tr>
#       <th id="T_6452d_level0_row7" class="row_heading level0 row7" >K2SO4</th>
#       <td id="T_6452d_row7_col0" class="data row7 col0" >8.350731</td>
#     </tr>
#     <tr>
#       <th id="T_6452d_level0_row8" class="row_heading level0 row8" >Quartz</th>
#       <td id="T_6452d_row8_col0" class="data row8 col0" >8.350731</td>
#     </tr>
#     <tr>
#       <th id="T_6452d_level0_row9" class="row_heading level0 row9" >Periclasio (MgO)</th>
#       <td id="T_6452d_row9_col0" class="data row9 col0" >8.350731</td>
#     </tr>
#     <tr>
#       <th id="T_6452d_level0_row10" class="row_heading level0 row10" >Calce libera</th>
#       <td id="T_6452d_row10_col0" class="data row10 col0" >8.350731</td>
#     </tr>
#     <tr>
#       <th id="T_6452d_level0_row11" class="row_heading level0 row11" >Ca(OH)2</th>
#       <td id="T_6452d_row11_col0" class="data row11 col0" >8.350731</td>
#     </tr>
#     <tr>
#       <th id="T_6452d_level0_row12" class="row_heading level0 row12" >CaO</th>
#       <td id="T_6452d_row12_col0" class="data row12 col0" >8.350731</td>
#     </tr>
#     <tr>
#       <th id="T_6452d_level0_row13" class="row_heading level0 row13" >C4AF</th>
#       <td id="T_6452d_row13_col0" class="data row13 col0" >8.350731</td>
#     </tr>
#     <tr>
#       <th id="T_6452d_level0_row14" class="row_heading level0 row14" >C3A tot</th>
#       <td id="T_6452d_row14_col0" class="data row14 col0" >8.350731</td>
#     </tr>
#     <tr>
#       <th id="T_6452d_level0_row15" class="row_heading level0 row15" >C3A_ortho</th>
#       <td id="T_6452d_row15_col0" class="data row15 col0" >8.350731</td>
#     </tr>
#     <tr>
#       <th id="T_6452d_level0_row16" class="row_heading level0 row16" >C3S_CS (taglia dei cristalliti C3S)</th>
#       <td id="T_6452d_row16_col0" class="data row16 col0" >8.350731</td>
#     </tr>
#     <tr>
#       <th id="T_6452d_level0_row17" class="row_heading level0 row17" >Anidrite</th>
#       <td id="T_6452d_row17_col0" class="data row17 col0" >8.350731</td>
#     </tr>
#     <tr>
#       <th id="T_6452d_level0_row18" class="row_heading level0 row18" >Ratio_M1 (rapporto M1/M3)</th>
#       <td id="T_6452d_row18_col0" class="data row18 col0" >8.350731</td>
#     </tr>
#     <tr>
#       <th id="T_6452d_level0_row19" class="row_heading level0 row19" >Alite_Sum C3S tot</th>
#       <td id="T_6452d_row19_col0" class="data row19 col0" >8.350731</td>
#     </tr>
#     <tr>
#       <th id="T_6452d_level0_row20" class="row_heading level0 row20" >Alite_M1 C3S M1</th>
#       <td id="T_6452d_row20_col0" class="data row20 col0" >8.350731</td>
#     </tr>
#     <tr>
#       <th id="T_6452d_level0_row21" class="row_heading level0 row21" >Alite_M3 C3S M3</th>
#       <td id="T_6452d_row21_col0" class="data row21 col0" >8.350731</td>
#     </tr>
#     <tr>
#       <th id="T_6452d_level0_row22" class="row_heading level0 row22" >R_wp</th>
#       <td id="T_6452d_row22_col0" class="data row22 col0" >8.350731</td>
#     </tr>
#     <tr>
#       <th id="T_6452d_level0_row23" class="row_heading level0 row23" >Calcite – CaCO3</th>
#       <td id="T_6452d_row23_col0" class="data row23 col0" >8.350731</td>
#     </tr>
#     <tr>
#       <th id="T_6452d_level0_row24" class="row_heading level0 row24" >Emiidrato</th>
#       <td id="T_6452d_row24_col0" class="data row24 col0" >8.350731</td>
#     </tr>
#     <tr>
#       <th id="T_6452d_level0_row25" class="row_heading level0 row25" >Soundness</th>
#       <td id="T_6452d_row25_col0" class="data row25 col0" >1.461378</td>
#     </tr>
#     <tr>
#       <th id="T_6452d_level0_row26" class="row_heading level0 row26" >flow</th>
#       <td id="T_6452d_row26_col0" class="data row26 col0" >0.730689</td>
#     </tr>
#     <tr>
#       <th id="T_6452d_level0_row27" class="row_heading level0 row27" >Initial Setting Time</th>
#       <td id="T_6452d_row27_col0" class="data row27 col0" >0.521921</td>
#     </tr>
#     <tr>
#       <th id="T_6452d_level0_row28" class="row_heading level0 row28" >residuo 24 micron</th>
#       <td id="T_6452d_row28_col0" class="data row28 col0" >0.313152</td>
#     </tr>
#     <tr>
#       <th id="T_6452d_level0_row29" class="row_heading level0 row29" >Blaine</th>
#       <td id="T_6452d_row29_col0" class="data row29 col0" >0.313152</td>
#     </tr>
#     <tr>
#       <th id="T_6452d_level0_row30" class="row_heading level0 row30" >SO3</th>
#       <td id="T_6452d_row30_col0" class="data row30 col0" >0.104384</td>
#     </tr>
#     <tr>
#       <th id="T_6452d_level0_row31" class="row_heading level0 row31" >ph2oimm</th>
#       <td id="T_6452d_row31_col0" class="data row31 col0" >0.104384</td>
#     </tr>
#     <tr>
#       <th id="T_6452d_level0_row32" class="row_heading level0 row32" >data</th>
#       <td id="T_6452d_row32_col0" class="data row32 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6452d_level0_row33" class="row_heading level0 row33" >28 days strenght</th>
#       <td id="T_6452d_row33_col0" class="data row33 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6452d_level0_row34" class="row_heading level0 row34" >2 days strenght</th>
#       <td id="T_6452d_row34_col0" class="data row34 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6452d_level0_row35" class="row_heading level0 row35" >Cl-</th>
#       <td id="T_6452d_row35_col0" class="data row35 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6452d_level0_row36" class="row_heading level0 row36" >cem_type</th>
#       <td id="T_6452d_row36_col0" class="data row36 col0" >0.000000</td>
#     </tr>
#   </tbody>

# %%
df.describe().T
# Out:
#                                      count                           mean  \
# data                                   958  2021-04-20 12:34:34.321503232
# SO3                                  957.0                       2.969927
# Cl-                                  958.0                       0.049674
# Blaine                               955.0                    3514.092147
# ph2oimm                              957.0                       28.44232
# Initial Setting Time                 953.0                     214.994753
# Soundness                            944.0                       0.725636
# flow                                 951.0                     107.711882
# 2 days strenght                      958.0                      28.300939
# 28 days strenght                     958.0                      49.042276
# residuo 24 micron                    955.0                       37.30201
# R_wp                                 878.0                       5.584351
# Alite_M3 C3S M3                      878.0                        28.7132
# Alite_M1 C3S M1                      878.0                      29.622392
# Alite_Sum C3S tot                    878.0                      58.334191
# Ratio_M1 (rapporto M1/M3)            878.0                      50.935197
# C3S_CS (taglia dei cristalliti C3S)  878.0                     237.981002
# Belite_beta                          878.0                       8.183468
# C3A cub                              878.0                       2.014772
# C3A_ortho                            878.0                       2.018331
# C3A tot                              878.0                       4.031953
# C4AF                                 878.0                       10.07074
# CaO                                  878.0                       0.765626
# Ca(OH)2                              878.0                        1.06365
# Calce libera                         878.0                       1.569613
# Periclasio (MgO)                     878.0                       0.441241
# Quartz                               878.0                        0.57709
# K2SO4                                878.0                       1.091435
# Langbeinite – MgK2(SO4)2             878.0                       0.244009
# Aphthitalite – (K,Na)3(SO4)2         878.0                       0.798314
# Gesso                                878.0                       1.394926
# Emiidrato                            878.0                       0.379385
# Anidrite                             878.0                       0.686845
# Calcite – CaCO3                      878.0                      11.943212
# SO3_XRD                              877.0                       2.277412
# CO2_XRD                              877.0                       5.254111
#
#                                                      min                  25%  \
# data                                 2019-10-07 00:00:00  2020-07-15 12:00:00
# SO3                                                 1.77                  2.7
# Cl-                                                0.011                0.022
# Blaine                                            2654.0               3335.0
# ph2oimm                                             24.6                 28.0
# Initial Setting Time                               115.0                190.0
# Soundness                                            0.0                  0.0
# flow                                                78.0                 98.0
# 2 days strenght                                     17.9                 24.4
# 28 days strenght                                    34.4                 42.5
# residuo 24 micron                                   24.1                 35.0
# R_wp                                                5.01                 5.41
# Alite_M3 C3S M3                                    14.15               24.235
# Alite_M1 C3S M1                                    17.63              25.8325
# Alite_Sum C3S tot                                  41.09                50.69
# Ratio_M1 (rapporto M1/M3)                          33.72              45.8525
# C3S_CS (taglia dei cristalliti C3S)               143.76               225.82
# Belite_beta                                         1.43                 6.51
# C3A cub                                             0.73                 1.76
# C3A_ortho                                           0.51                 1.49
# C3A tot                                             2.09                 3.45
# C4AF                                                6.44               8.6825
# CaO                                                  0.0               0.2225
# Ca(OH)2                                              0.0               0.4625
# Calce libera                                        0.07                 0.91
# Periclasio (MgO)                                    0.01                  0.3
# Quartz                                               0.0                 0.16
# K2SO4                                               0.42                  0.9
# Langbeinite – MgK2(SO4)2                             0.0                  0.1
# Aphthitalite – (K,Na)3(SO4)2                        0.16                 0.62
# Gesso                                                0.0                 0.47
# Emiidrato                                            0.0                  0.0
# Anidrite                                             0.0                 0.15
# Calcite – CaCO3                                      0.1               5.0925
# SO3_XRD                                              1.4                 1.97
# CO2_XRD                                             0.04                 2.24
#
#                                                      50%                  75%  \
# data                                 2021-04-22 12:00:00  2022-01-21 00:00:00
# SO3                                                 2.96                 3.23
# Cl-                                                0.054                 0.07
# Blaine                                            3499.0               3666.0
# ph2oimm                                             28.4                 29.0
# Initial Setting Time                               210.0                230.0
# Soundness                                            1.0                  1.0
# flow                                               110.0                118.0
# 2 days strenght                                     29.4                 31.9
# 28 days strenght                                    50.8                 54.1
# residuo 24 micron                                   37.3                 39.7
# R_wp                                                5.56                 5.73
# Alite_M3 C3S M3                                   28.435                 32.8
# Alite_M1 C3S M1                                    29.47               33.065
# Alite_Sum C3S tot                                  60.89                64.21
# Ratio_M1 (rapporto M1/M3)                          50.92                56.11
# C3S_CS (taglia dei cristalliti C3S)              239.145                251.5
# Belite_beta                                         8.11               9.7475
# C3A cub                                             2.02                 2.27
# C3A_ortho                                            1.9                 2.45
# C3A tot                                             3.94               4.5675
# C4AF                                               10.43                11.32
# CaO                                                 0.62                 1.24
# Ca(OH)2                                             0.96                 1.54
# Calce libera                                        1.62                 2.11
# Periclasio (MgO)                                    0.43                 0.57
# Quartz                                              0.48                 0.91
# K2SO4                                               1.07                 1.24
# Langbeinite – MgK2(SO4)2                            0.21                 0.36
# Aphthitalite – (K,Na)3(SO4)2                        0.78                 0.99
# Gesso                                               1.34               2.1975
# Emiidrato                                           0.15               0.5775
# Anidrite                                           0.415                 1.16
# Calcite – CaCO3                                    8.685               21.395
# SO3_XRD                                             2.26                 2.56
# CO2_XRD                                             3.81                 9.41
#
#                                                      max         std
# data                                 2022-10-21 00:00:00         NaN
# SO3                                                 3.91    0.353675
# Cl-                                                0.099    0.023952
# Blaine                                            4771.0  274.100021
# ph2oimm                                             31.0    0.688486
# Initial Setting Time                               390.0   37.538145
# Soundness                                            3.0    0.617816
# flow                                               132.0   11.715085
# 2 days strenght                                     37.3    4.574196
# 28 days strenght                                    65.4    6.617852
# residuo 24 micron                                   46.4    3.273676
# R_wp                                                9.26    0.266377
# Alite_M3 C3S M3                                    45.19    6.014556
# Alite_M1 C3S M1                                    45.58    5.176509
# Alite_Sum C3S tot                                  72.96    7.494005
# Ratio_M1 (rapporto M1/M3)                          68.77    7.078642
# C3S_CS (taglia dei cristalliti C3S)               306.68   21.463213
# Belite_beta                                        17.41    2.372578
# C3A cub                                             4.54    0.411328
# C3A_ortho                                           3.95    0.678926
# C3A tot                                             6.78    0.789722
# C4AF                                               13.55    1.579632
# CaO                                                 2.95    0.616677
# Ca(OH)2                                             3.73    0.720152
# Calce libera                                        4.34    0.755983
# Periclasio (MgO)                                    1.38    0.182031
# Quartz                                              2.84    0.443966
# K2SO4                                               3.95    0.280643
# Langbeinite – MgK2(SO4)2                            0.85    0.182636
# Aphthitalite – (K,Na)3(SO4)2                        1.56    0.238951
# Gesso                                               4.24     1.02755
# Emiidrato                                           2.81    0.513404
# Anidrite                                            2.82    0.648762
# Calcite – CaCO3                                    29.91    8.677272
# SO3_XRD                                             4.19    0.405013
# CO2_XRD                                            14.45     3.83097

# %%
df.describe(exclude="number").T
# Out:
#          count unique    top freq                           mean  \
# data       958    NaN    NaN  NaN  2021-04-20 12:34:34.321503232
# cem_type   958      3  CEM B  323                            NaN
#
#                           min                  25%                  50%  \
# data      2019-10-07 00:00:00  2020-07-15 12:00:00  2021-04-22 12:00:00
# cem_type                  NaN                  NaN                  NaN
#
#                           75%                  max
# data      2022-01-21 00:00:00  2022-10-21 00:00:00
# cem_type                  NaN                  NaN

# %%
(df_cem_a.isna().sum().sort_values(ascending=False) / df_cem_a.shape[0] * 100).to_frame(
    name="Missing (%)"
).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_b3cdf_row0_col0, #T_b3cdf_row1_col0, #T_b3cdf_row2_col0, #T_b3cdf_row3_col0, #T_b3cdf_row4_col0, #T_b3cdf_row5_col0, #T_b3cdf_row6_col0, #T_b3cdf_row7_col0, #T_b3cdf_row8_col0, #T_b3cdf_row9_col0, #T_b3cdf_row10_col0, #T_b3cdf_row11_col0, #T_b3cdf_row12_col0, #T_b3cdf_row13_col0, #T_b3cdf_row14_col0, #T_b3cdf_row15_col0, #T_b3cdf_row16_col0, #T_b3cdf_row17_col0, #T_b3cdf_row18_col0, #T_b3cdf_row19_col0, #T_b3cdf_row20_col0, #T_b3cdf_row21_col0, #T_b3cdf_row22_col0, #T_b3cdf_row23_col0, #T_b3cdf_row24_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_b3cdf_row25_col0, #T_b3cdf_row26_col0 {
#   background-color: #fee3d6;
#   color: #000000;
# }
# #T_b3cdf_row27_col0 {
#   background-color: #fee9df;
#   color: #000000;
# }
# #T_b3cdf_row28_col0, #T_b3cdf_row29_col0, #T_b3cdf_row30_col0 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_b3cdf_row31_col0, #T_b3cdf_row32_col0, #T_b3cdf_row33_col0, #T_b3cdf_row34_col0, #T_b3cdf_row35_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_b3cdf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b3cdf_level0_col0" class="col_heading level0 col0" >Missing (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b3cdf_level0_row0" class="row_heading level0 row0" >C3A cub</th>
#       <td id="T_b3cdf_row0_col0" class="data row0 col0" >8.571429</td>
#     </tr>
#     <tr>
#       <th id="T_b3cdf_level0_row1" class="row_heading level0 row1" >K2SO4</th>
#       <td id="T_b3cdf_row1_col0" class="data row1 col0" >8.571429</td>
#     </tr>
#     <tr>
#       <th id="T_b3cdf_level0_row2" class="row_heading level0 row2" >C4AF</th>
#       <td id="T_b3cdf_row2_col0" class="data row2 col0" >8.571429</td>
#     </tr>
#     <tr>
#       <th id="T_b3cdf_level0_row3" class="row_heading level0 row3" >CaO</th>
#       <td id="T_b3cdf_row3_col0" class="data row3 col0" >8.571429</td>
#     </tr>
#     <tr>
#       <th id="T_b3cdf_level0_row4" class="row_heading level0 row4" >Ca(OH)2</th>
#       <td id="T_b3cdf_row4_col0" class="data row4 col0" >8.571429</td>
#     </tr>
#     <tr>
#       <th id="T_b3cdf_level0_row5" class="row_heading level0 row5" >Calce libera</th>
#       <td id="T_b3cdf_row5_col0" class="data row5 col0" >8.571429</td>
#     </tr>
#     <tr>
#       <th id="T_b3cdf_level0_row6" class="row_heading level0 row6" >Periclasio (MgO)</th>
#       <td id="T_b3cdf_row6_col0" class="data row6 col0" >8.571429</td>
#     </tr>
#     <tr>
#       <th id="T_b3cdf_level0_row7" class="row_heading level0 row7" >Quartz</th>
#       <td id="T_b3cdf_row7_col0" class="data row7 col0" >8.571429</td>
#     </tr>
#     <tr>
#       <th id="T_b3cdf_level0_row8" class="row_heading level0 row8" >Langbeinite – MgK2(SO4)2</th>
#       <td id="T_b3cdf_row8_col0" class="data row8 col0" >8.571429</td>
#     </tr>
#     <tr>
#       <th id="T_b3cdf_level0_row9" class="row_heading level0 row9" >C3A_ortho</th>
#       <td id="T_b3cdf_row9_col0" class="data row9 col0" >8.571429</td>
#     </tr>
#     <tr>
#       <th id="T_b3cdf_level0_row10" class="row_heading level0 row10" >Aphthitalite – (K,Na)3(SO4)2</th>
#       <td id="T_b3cdf_row10_col0" class="data row10 col0" >8.571429</td>
#     </tr>
#     <tr>
#       <th id="T_b3cdf_level0_row11" class="row_heading level0 row11" >Gesso</th>
#       <td id="T_b3cdf_row11_col0" class="data row11 col0" >8.571429</td>
#     </tr>
#     <tr>
#       <th id="T_b3cdf_level0_row12" class="row_heading level0 row12" >Emiidrato</th>
#       <td id="T_b3cdf_row12_col0" class="data row12 col0" >8.571429</td>
#     </tr>
#     <tr>
#       <th id="T_b3cdf_level0_row13" class="row_heading level0 row13" >Anidrite</th>
#       <td id="T_b3cdf_row13_col0" class="data row13 col0" >8.571429</td>
#     </tr>
#     <tr>
#       <th id="T_b3cdf_level0_row14" class="row_heading level0 row14" >Calcite – CaCO3</th>
#       <td id="T_b3cdf_row14_col0" class="data row14 col0" >8.571429</td>
#     </tr>
#     <tr>
#       <th id="T_b3cdf_level0_row15" class="row_heading level0 row15" >SO3_XRD</th>
#       <td id="T_b3cdf_row15_col0" class="data row15 col0" >8.571429</td>
#     </tr>
#     <tr>
#       <th id="T_b3cdf_level0_row16" class="row_heading level0 row16" >C3A tot</th>
#       <td id="T_b3cdf_row16_col0" class="data row16 col0" >8.571429</td>
#     </tr>
#     <tr>
#       <th id="T_b3cdf_level0_row17" class="row_heading level0 row17" >CO2_XRD</th>
#       <td id="T_b3cdf_row17_col0" class="data row17 col0" >8.571429</td>
#     </tr>
#     <tr>
#       <th id="T_b3cdf_level0_row18" class="row_heading level0 row18" >C3S_CS (taglia dei cristalliti C3S)</th>
#       <td id="T_b3cdf_row18_col0" class="data row18 col0" >8.571429</td>
#     </tr>
#     <tr>
#       <th id="T_b3cdf_level0_row19" class="row_heading level0 row19" >Ratio_M1 (rapporto M1/M3)</th>
#       <td id="T_b3cdf_row19_col0" class="data row19 col0" >8.571429</td>
#     </tr>
#     <tr>
#       <th id="T_b3cdf_level0_row20" class="row_heading level0 row20" >Alite_Sum C3S tot</th>
#       <td id="T_b3cdf_row20_col0" class="data row20 col0" >8.571429</td>
#     </tr>
#     <tr>
#       <th id="T_b3cdf_level0_row21" class="row_heading level0 row21" >Alite_M1 C3S M1</th>
#       <td id="T_b3cdf_row21_col0" class="data row21 col0" >8.571429</td>
#     </tr>
#     <tr>
#       <th id="T_b3cdf_level0_row22" class="row_heading level0 row22" >Alite_M3 C3S M3</th>
#       <td id="T_b3cdf_row22_col0" class="data row22 col0" >8.571429</td>
#     </tr>
#     <tr>
#       <th id="T_b3cdf_level0_row23" class="row_heading level0 row23" >R_wp</th>
#       <td id="T_b3cdf_row23_col0" class="data row23 col0" >8.571429</td>
#     </tr>
#     <tr>
#       <th id="T_b3cdf_level0_row24" class="row_heading level0 row24" >Belite_beta</th>
#       <td id="T_b3cdf_row24_col0" class="data row24 col0" >8.571429</td>
#     </tr>
#     <tr>
#       <th id="T_b3cdf_level0_row25" class="row_heading level0 row25" >flow</th>
#       <td id="T_b3cdf_row25_col0" class="data row25 col0" >0.952381</td>
#     </tr>
#     <tr>
#       <th id="T_b3cdf_level0_row26" class="row_heading level0 row26" >Soundness</th>
#       <td id="T_b3cdf_row26_col0" class="data row26 col0" >0.952381</td>
#     </tr>
#     <tr>
#       <th id="T_b3cdf_level0_row27" class="row_heading level0 row27" >Initial Setting Time</th>
#       <td id="T_b3cdf_row27_col0" class="data row27 col0" >0.634921</td>
#     </tr>
#     <tr>
#       <th id="T_b3cdf_level0_row28" class="row_heading level0 row28" >Blaine</th>
#       <td id="T_b3cdf_row28_col0" class="data row28 col0" >0.317460</td>
#     </tr>
#     <tr>
#       <th id="T_b3cdf_level0_row29" class="row_heading level0 row29" >residuo 24 micron</th>
#       <td id="T_b3cdf_row29_col0" class="data row29 col0" >0.317460</td>
#     </tr>
#     <tr>
#       <th id="T_b3cdf_level0_row30" class="row_heading level0 row30" >ph2oimm</th>
#       <td id="T_b3cdf_row30_col0" class="data row30 col0" >0.317460</td>
#     </tr>
#     <tr>
#       <th id="T_b3cdf_level0_row31" class="row_heading level0 row31" >SO3</th>
#       <td id="T_b3cdf_row31_col0" class="data row31 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b3cdf_level0_row32" class="row_heading level0 row32" >Cl-</th>
#       <td id="T_b3cdf_row32_col0" class="data row32 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b3cdf_level0_row33" class="row_heading level0 row33" >28 days strenght</th>
#       <td id="T_b3cdf_row33_col0" class="data row33 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b3cdf_level0_row34" class="row_heading level0 row34" >2 days strenght</th>
#       <td id="T_b3cdf_row34_col0" class="data row34 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b3cdf_level0_row35" class="row_heading level0 row35" >data</th>
#       <td id="T_b3cdf_row35_col0" class="data row35 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_cem_a.describe().T
# Out:
#                                      count                           mean  \
# data                                   315  2021-04-27 03:53:08.571428608
# SO3                                  315.0                       2.612952
# Cl-                                  315.0                       0.022038
# Blaine                               314.0                    3482.678344
# ph2oimm                              314.0                      28.465605
# Initial Setting Time                 313.0                     212.891374
# Soundness                            312.0                       0.615385
# flow                                 312.0                      112.00641
# 2 days strenght                      315.0                      30.630794
# 28 days strenght                     315.0                      54.311111
# residuo 24 micron                    314.0                      35.683312
# R_wp                                 288.0                        5.52375
# Alite_M3 C3S M3                      288.0                      32.547847
# Alite_M1 C3S M1                      288.0                      32.969201
# Alite_Sum C3S tot                    288.0                      65.515069
# Ratio_M1 (rapporto M1/M3)            288.0                      50.408005
# C3S_CS (taglia dei cristalliti C3S)  288.0                     236.964097
# Belite_beta                          288.0                       9.138594
# C3A cub                              288.0                       2.197674
# C3A_ortho                            288.0                       2.203247
# C3A tot                              288.0                       4.399427
# C4AF                                 288.0                      11.400208
# CaO                                  288.0                       0.303542
# Ca(OH)2                              288.0                       0.747587
# Calce libera                         288.0                       0.868229
# Periclasio (MgO)                     288.0                       0.466389
# Quartz                               288.0                       0.140747
# K2SO4                                288.0                       1.023576
# Langbeinite – MgK2(SO4)2             288.0                       0.112812
# Aphthitalite – (K,Na)3(SO4)2         288.0                       0.814271
# Gesso                                288.0                       1.004219
# Emiidrato                            288.0                       0.308715
# Anidrite                             288.0                       0.572431
# Calcite – CaCO3                      288.0                       4.059271
# SO3_XRD                              288.0                       1.895556
# CO2_XRD                              288.0                       1.784531
#
#                                                      min                  25%  \
# data                                 2019-10-25 00:00:00  2020-07-26 00:00:00
# SO3                                                 1.77                 2.48
# Cl-                                                0.011                0.016
# Blaine                                            2703.0              3314.75
# ph2oimm                                             24.6                 28.0
# Initial Setting Time                               140.0                190.0
# Soundness                                            0.0                  0.0
# flow                                                88.0                100.0
# 2 days strenght                                     24.7                 28.9
# 28 days strenght                                    46.6                 51.9
# residuo 24 micron                                   24.2                 33.5
# R_wp                                                5.01                 5.37
# Alite_M3 C3S M3                                    19.87                28.31
# Alite_M1 C3S M1                                    22.49              29.6825
# Alite_Sum C3S tot                                  56.56                63.71
# Ratio_M1 (rapporto M1/M3)                          34.13               44.935
# C3S_CS (taglia dei cristalliti C3S)               156.87             224.1675
# Belite_beta                                         3.08               7.7125
# C3A cub                                             1.29               1.9675
# C3A_ortho                                           0.75               1.6775
# C3A tot                                             2.69                 3.84
# C4AF                                                8.97              10.9475
# CaO                                                  0.0                  0.1
# Ca(OH)2                                              0.0               0.3275
# Calce libera                                        0.15                 0.59
# Periclasio (MgO)                                    0.12                 0.34
# Quartz                                               0.0                 0.08
# K2SO4                                               0.47                 0.86
# Langbeinite – MgK2(SO4)2                             0.0                 0.04
# Aphthitalite – (K,Na)3(SO4)2                        0.26                 0.61
# Gesso                                                0.0                 0.21
# Emiidrato                                            0.0                  0.0
# Anidrite                                             0.0                 0.06
# Calcite – CaCO3                                      0.1               2.3025
# SO3_XRD                                              1.4               1.7475
# CO2_XRD                                             0.04               1.0075
#
#                                                      50%                  75%  \
# data                                 2021-05-03 00:00:00  2022-01-23 12:00:00
# SO3                                                 2.62                 2.75
# Cl-                                                0.018                0.023
# Blaine                                            3488.5              3645.75
# ph2oimm                                             28.4                 28.8
# Initial Setting Time                               210.0                230.0
# Soundness                                            1.0                  1.0
# flow                                               115.0                122.0
# 2 days strenght                                     30.6                 32.6
# 28 days strenght                                    54.2                 56.3
# residuo 24 micron                                   35.5                 37.8
# R_wp                                                 5.5                 5.67
# Alite_M3 C3S M3                                     32.1               36.745
# Alite_M1 C3S M1                                    32.87              35.8775
# Alite_Sum C3S tot                                   65.5               67.265
# Ratio_M1 (rapporto M1/M3)                          50.09              55.5225
# C3S_CS (taglia dei cristalliti C3S)              238.065             249.3625
# Belite_beta                                          9.2                10.61
# C3A cub                                             2.16               2.3625
# C3A_ortho                                          2.095               2.6675
# C3A tot                                            4.355               4.9125
# C4AF                                               11.44              11.8825
# CaO                                                 0.24                 0.43
# Ca(OH)2                                             0.65               1.0125
# Calce libera                                        0.78                1.075
# Periclasio (MgO)                                   0.465               0.5825
# Quartz                                              0.13                 0.17
# K2SO4                                                1.0                 1.16
# Langbeinite – MgK2(SO4)2                             0.1                 0.16
# Aphthitalite – (K,Na)3(SO4)2                        0.84                 1.01
# Gesso                                               0.92                1.645
# Emiidrato                                           0.09               0.4525
# Anidrite                                            0.31                 1.07
# Calcite – CaCO3                                    4.105               5.7025
# SO3_XRD                                              1.9                 2.02
# CO2_XRD                                            1.805               2.5025
#
#                                                      max         std
# data                                 2022-10-19 00:00:00         NaN
# SO3                                                 2.98    0.189969
# Cl-                                                 0.07    0.009984
# Blaine                                            4316.0  256.813868
# ph2oimm                                             31.0    0.674048
# Initial Setting Time                               345.0   33.239048
# Soundness                                            3.0    0.560908
# flow                                               132.0   12.194299
# 2 days strenght                                     37.2    2.592217
# 28 days strenght                                    65.4    3.394315
# residuo 24 micron                                   44.2     3.24585
# R_wp                                                6.36    0.210759
# Alite_M3 C3S M3                                    45.19    5.334975
# Alite_M1 C3S M1                                    45.58    4.604864
# Alite_Sum C3S tot                                  72.96    2.537698
# Ratio_M1 (rapporto M1/M3)                          66.96     7.32055
# C3S_CS (taglia dei cristalliti C3S)               286.18    20.30683
# Belite_beta                                        16.81    2.235557
# C3A cub                                             4.54    0.383217
# C3A_ortho                                           3.95    0.701641
# C3A tot                                             6.78    0.769522
# C4AF                                               13.55     0.73164
# CaO                                                 1.75    0.263222
# Ca(OH)2                                             2.31    0.529534
# Calce libera                                        2.39    0.418332
# Periclasio (MgO)                                     1.1    0.173292
# Quartz                                              0.69    0.087494
# K2SO4                                               2.15    0.251705
# Langbeinite – MgK2(SO4)2                             0.5    0.093883
# Aphthitalite – (K,Na)3(SO4)2                         1.5    0.243521
# Gesso                                               3.44    0.760912
# Emiidrato                                           2.12     0.44128
# Anidrite                                            1.94    0.578649
# Calcite – CaCO3                                     8.66    2.046737
# SO3_XRD                                             3.08    0.225102
# CO2_XRD                                             3.81     0.89974

# %%
df_cem_a.describe(exclude="number").T
# Out:
#      count                           mean                  min  \
# data   315  2021-04-27 03:53:08.571428608  2019-10-25 00:00:00
#
#                       25%                  50%                  75%  \
# data  2020-07-26 00:00:00  2021-05-03 00:00:00  2022-01-23 12:00:00
#
#                       max
# data  2022-10-19 00:00:00

# %%
(df_cem_b.isna().sum().sort_values(ascending=False) / df_cem_b.shape[0] * 100).to_frame(
    name="Missing (%)"
).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_dbfc3_row0_col0, #T_dbfc3_row1_col0, #T_dbfc3_row2_col0, #T_dbfc3_row3_col0, #T_dbfc3_row4_col0, #T_dbfc3_row5_col0, #T_dbfc3_row6_col0, #T_dbfc3_row7_col0, #T_dbfc3_row8_col0, #T_dbfc3_row9_col0, #T_dbfc3_row10_col0, #T_dbfc3_row11_col0, #T_dbfc3_row12_col0, #T_dbfc3_row13_col0, #T_dbfc3_row14_col0, #T_dbfc3_row15_col0, #T_dbfc3_row16_col0, #T_dbfc3_row17_col0, #T_dbfc3_row18_col0, #T_dbfc3_row19_col0, #T_dbfc3_row20_col0, #T_dbfc3_row21_col0, #T_dbfc3_row22_col0, #T_dbfc3_row23_col0, #T_dbfc3_row24_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_dbfc3_row25_col0 {
#   background-color: #fcb69b;
#   color: #000000;
# }
# #T_dbfc3_row26_col0, #T_dbfc3_row27_col0, #T_dbfc3_row28_col0 {
#   background-color: #fee8de;
#   color: #000000;
# }
# #T_dbfc3_row29_col0, #T_dbfc3_row30_col0 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_dbfc3_row31_col0, #T_dbfc3_row32_col0, #T_dbfc3_row33_col0, #T_dbfc3_row34_col0, #T_dbfc3_row35_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_dbfc3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dbfc3_level0_col0" class="col_heading level0 col0" >Missing (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dbfc3_level0_row0" class="row_heading level0 row0" >C3A cub</th>
#       <td id="T_dbfc3_row0_col0" class="data row0 col0" >8.049536</td>
#     </tr>
#     <tr>
#       <th id="T_dbfc3_level0_row1" class="row_heading level0 row1" >K2SO4</th>
#       <td id="T_dbfc3_row1_col0" class="data row1 col0" >8.049536</td>
#     </tr>
#     <tr>
#       <th id="T_dbfc3_level0_row2" class="row_heading level0 row2" >C4AF</th>
#       <td id="T_dbfc3_row2_col0" class="data row2 col0" >8.049536</td>
#     </tr>
#     <tr>
#       <th id="T_dbfc3_level0_row3" class="row_heading level0 row3" >CaO</th>
#       <td id="T_dbfc3_row3_col0" class="data row3 col0" >8.049536</td>
#     </tr>
#     <tr>
#       <th id="T_dbfc3_level0_row4" class="row_heading level0 row4" >Ca(OH)2</th>
#       <td id="T_dbfc3_row4_col0" class="data row4 col0" >8.049536</td>
#     </tr>
#     <tr>
#       <th id="T_dbfc3_level0_row5" class="row_heading level0 row5" >Calce libera</th>
#       <td id="T_dbfc3_row5_col0" class="data row5 col0" >8.049536</td>
#     </tr>
#     <tr>
#       <th id="T_dbfc3_level0_row6" class="row_heading level0 row6" >Periclasio (MgO)</th>
#       <td id="T_dbfc3_row6_col0" class="data row6 col0" >8.049536</td>
#     </tr>
#     <tr>
#       <th id="T_dbfc3_level0_row7" class="row_heading level0 row7" >Quartz</th>
#       <td id="T_dbfc3_row7_col0" class="data row7 col0" >8.049536</td>
#     </tr>
#     <tr>
#       <th id="T_dbfc3_level0_row8" class="row_heading level0 row8" >Langbeinite – MgK2(SO4)2</th>
#       <td id="T_dbfc3_row8_col0" class="data row8 col0" >8.049536</td>
#     </tr>
#     <tr>
#       <th id="T_dbfc3_level0_row9" class="row_heading level0 row9" >C3A_ortho</th>
#       <td id="T_dbfc3_row9_col0" class="data row9 col0" >8.049536</td>
#     </tr>
#     <tr>
#       <th id="T_dbfc3_level0_row10" class="row_heading level0 row10" >Aphthitalite – (K,Na)3(SO4)2</th>
#       <td id="T_dbfc3_row10_col0" class="data row10 col0" >8.049536</td>
#     </tr>
#     <tr>
#       <th id="T_dbfc3_level0_row11" class="row_heading level0 row11" >Gesso</th>
#       <td id="T_dbfc3_row11_col0" class="data row11 col0" >8.049536</td>
#     </tr>
#     <tr>
#       <th id="T_dbfc3_level0_row12" class="row_heading level0 row12" >Emiidrato</th>
#       <td id="T_dbfc3_row12_col0" class="data row12 col0" >8.049536</td>
#     </tr>
#     <tr>
#       <th id="T_dbfc3_level0_row13" class="row_heading level0 row13" >Anidrite</th>
#       <td id="T_dbfc3_row13_col0" class="data row13 col0" >8.049536</td>
#     </tr>
#     <tr>
#       <th id="T_dbfc3_level0_row14" class="row_heading level0 row14" >Calcite – CaCO3</th>
#       <td id="T_dbfc3_row14_col0" class="data row14 col0" >8.049536</td>
#     </tr>
#     <tr>
#       <th id="T_dbfc3_level0_row15" class="row_heading level0 row15" >SO3_XRD</th>
#       <td id="T_dbfc3_row15_col0" class="data row15 col0" >8.049536</td>
#     </tr>
#     <tr>
#       <th id="T_dbfc3_level0_row16" class="row_heading level0 row16" >C3A tot</th>
#       <td id="T_dbfc3_row16_col0" class="data row16 col0" >8.049536</td>
#     </tr>
#     <tr>
#       <th id="T_dbfc3_level0_row17" class="row_heading level0 row17" >CO2_XRD</th>
#       <td id="T_dbfc3_row17_col0" class="data row17 col0" >8.049536</td>
#     </tr>
#     <tr>
#       <th id="T_dbfc3_level0_row18" class="row_heading level0 row18" >C3S_CS (taglia dei cristalliti C3S)</th>
#       <td id="T_dbfc3_row18_col0" class="data row18 col0" >8.049536</td>
#     </tr>
#     <tr>
#       <th id="T_dbfc3_level0_row19" class="row_heading level0 row19" >Ratio_M1 (rapporto M1/M3)</th>
#       <td id="T_dbfc3_row19_col0" class="data row19 col0" >8.049536</td>
#     </tr>
#     <tr>
#       <th id="T_dbfc3_level0_row20" class="row_heading level0 row20" >Alite_Sum C3S tot</th>
#       <td id="T_dbfc3_row20_col0" class="data row20 col0" >8.049536</td>
#     </tr>
#     <tr>
#       <th id="T_dbfc3_level0_row21" class="row_heading level0 row21" >Alite_M1 C3S M1</th>
#       <td id="T_dbfc3_row21_col0" class="data row21 col0" >8.049536</td>
#     </tr>
#     <tr>
#       <th id="T_dbfc3_level0_row22" class="row_heading level0 row22" >Alite_M3 C3S M3</th>
#       <td id="T_dbfc3_row22_col0" class="data row22 col0" >8.049536</td>
#     </tr>
#     <tr>
#       <th id="T_dbfc3_level0_row23" class="row_heading level0 row23" >R_wp</th>
#       <td id="T_dbfc3_row23_col0" class="data row23 col0" >8.049536</td>
#     </tr>
#     <tr>
#       <th id="T_dbfc3_level0_row24" class="row_heading level0 row24" >Belite_beta</th>
#       <td id="T_dbfc3_row24_col0" class="data row24 col0" >8.049536</td>
#     </tr>
#     <tr>
#       <th id="T_dbfc3_level0_row25" class="row_heading level0 row25" >Soundness</th>
#       <td id="T_dbfc3_row25_col0" class="data row25 col0" >2.167183</td>
#     </tr>
#     <tr>
#       <th id="T_dbfc3_level0_row26" class="row_heading level0 row26" >Blaine</th>
#       <td id="T_dbfc3_row26_col0" class="data row26 col0" >0.619195</td>
#     </tr>
#     <tr>
#       <th id="T_dbfc3_level0_row27" class="row_heading level0 row27" >residuo 24 micron</th>
#       <td id="T_dbfc3_row27_col0" class="data row27 col0" >0.619195</td>
#     </tr>
#     <tr>
#       <th id="T_dbfc3_level0_row28" class="row_heading level0 row28" >flow</th>
#       <td id="T_dbfc3_row28_col0" class="data row28 col0" >0.619195</td>
#     </tr>
#     <tr>
#       <th id="T_dbfc3_level0_row29" class="row_heading level0 row29" >SO3</th>
#       <td id="T_dbfc3_row29_col0" class="data row29 col0" >0.309598</td>
#     </tr>
#     <tr>
#       <th id="T_dbfc3_level0_row30" class="row_heading level0 row30" >Initial Setting Time</th>
#       <td id="T_dbfc3_row30_col0" class="data row30 col0" >0.309598</td>
#     </tr>
#     <tr>
#       <th id="T_dbfc3_level0_row31" class="row_heading level0 row31" >Cl-</th>
#       <td id="T_dbfc3_row31_col0" class="data row31 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_dbfc3_level0_row32" class="row_heading level0 row32" >28 days strenght</th>
#       <td id="T_dbfc3_row32_col0" class="data row32 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_dbfc3_level0_row33" class="row_heading level0 row33" >ph2oimm</th>
#       <td id="T_dbfc3_row33_col0" class="data row33 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_dbfc3_level0_row34" class="row_heading level0 row34" >2 days strenght</th>
#       <td id="T_dbfc3_row34_col0" class="data row34 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_dbfc3_level0_row35" class="row_heading level0 row35" >data</th>
#       <td id="T_dbfc3_row35_col0" class="data row35 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_cem_b.describe().T
# Out:
#                                      count                           mean  \
# data                                   323  2021-04-14 02:13:44.767801856
# SO3                                  322.0                       3.234224
# Cl-                                  323.0                       0.059226
# Blaine                               321.0                    3402.713396
# ph2oimm                              323.0                      28.817028
# Initial Setting Time                 322.0                     205.295031
# Soundness                            316.0                       0.813291
# flow                                 321.0                     107.538941
# 2 days strenght                      323.0                      31.477709
# 28 days strenght                     323.0                      52.093808
# residuo 24 micron                    321.0                      36.566542
# R_wp                                 297.0                       5.540875
# Alite_M3 C3S M3                      297.0                      30.275825
# Alite_M1 C3S M1                      297.0                      30.478451
# Alite_Sum C3S tot                    297.0                      60.753131
# Ratio_M1 (rapporto M1/M3)            297.0                      50.201541
# C3S_CS (taglia dei cristalliti C3S)  297.0                     236.321178
# Belite_beta                          297.0                       8.095354
# C3A cub                              297.0                       2.138586
# C3A_ortho                            297.0                        2.03266
# C3A tot                              297.0                       4.170438
# C4AF                                 297.0                      10.586296
# CaO                                  297.0                       0.975084
# Ca(OH)2                              297.0                       1.331751
# Calce libera                         297.0                       1.982256
# Periclasio (MgO)                     297.0                       0.420067
# Quartz                               297.0                       0.513939
# K2SO4                                297.0                       1.105084
# Langbeinite – MgK2(SO4)2             297.0                       0.208653
# Aphthitalite – (K,Na)3(SO4)2         297.0                       0.828923
# Gesso                                297.0                       1.357576
# Emiidrato                            297.0                       0.531515
# Anidrite                             297.0                       0.790438
# Calcite – CaCO3                      297.0                       8.337609
# SO3_XRD                              297.0                       2.407104
# CO2_XRD                              297.0                       3.665623
#
#                                                      min                  25%  \
# data                                 2019-10-07 00:00:00  2020-07-07 00:00:00
# SO3                                                 2.48                 3.04
# Cl-                                                0.015                 0.05
# Blaine                                            2757.0               3248.0
# ph2oimm                                             25.4                 28.4
# Initial Setting Time                               115.0                180.0
# Soundness                                            0.0                  0.0
# flow                                                85.0                 98.0
# 2 days strenght                                     23.3                 29.8
# 28 days strenght                                    45.0                50.15
# residuo 24 micron                                   24.1                 34.8
# R_wp                                                5.02                 5.38
# Alite_M3 C3S M3                                    18.58                27.33
# Alite_M1 C3S M1                                    19.81                27.48
# Alite_Sum C3S tot                                  49.09                59.12
# Ratio_M1 (rapporto M1/M3)                          33.72                46.17
# C3S_CS (taglia dei cristalliti C3S)               152.61               224.43
# Belite_beta                                         2.07                 6.15
# C3A cub                                             1.45                 1.93
# C3A_ortho                                           0.51                 1.49
# C3A tot                                             2.57                 3.65
# C4AF                                                7.62                10.01
# CaO                                                  0.0                 0.39
# Ca(OH)2                                             0.04                 0.63
# Calce libera                                        0.07                 1.54
# Periclasio (MgO)                                    0.06                 0.29
# Quartz                                               0.0                 0.36
# K2SO4                                               0.49                 0.94
# Langbeinite – MgK2(SO4)2                             0.0                 0.11
# Aphthitalite – (K,Na)3(SO4)2                        0.16                 0.65
# Gesso                                                0.0                 0.42
# Emiidrato                                            0.0                 0.03
# Anidrite                                             0.0                 0.15
# Calcite – CaCO3                                     2.96                 6.37
# SO3_XRD                                             1.43                 2.16
# CO2_XRD                                              1.3                  2.8
#
#                                                      50%                  75%  \
# data                                 2021-04-19 00:00:00  2022-01-18 00:00:00
# SO3                                                3.255               3.4575
# Cl-                                                0.061                0.071
# Blaine                                            3378.0               3505.0
# ph2oimm                                             28.8                 29.2
# Initial Setting Time                               195.0                225.0
# Soundness                                            1.0                  1.0
# flow                                               110.0                117.0
# 2 days strenght                                     31.4                 33.1
# 28 days strenght                                    52.0                 54.0
# residuo 24 micron                                   36.6                 38.2
# R_wp                                                5.52                 5.69
# Alite_M3 C3S M3                                    30.27                33.17
# Alite_M1 C3S M1                                    30.69                33.13
# Alite_Sum C3S tot                                  61.05                62.37
# Ratio_M1 (rapporto M1/M3)                           50.1                54.96
# C3S_CS (taglia dei cristalliti C3S)               238.05                249.5
# Belite_beta                                         8.02                 9.75
# C3A cub                                             2.11                 2.34
# C3A_ortho                                           1.88                 2.46
# C3A tot                                             4.05                 4.67
# C4AF                                               10.65                11.21
# CaO                                                 0.93                 1.46
# Ca(OH)2                                             1.32                 1.83
# Calce libera                                        1.97                 2.37
# Periclasio (MgO)                                    0.39                 0.52
# Quartz                                              0.48                 0.65
# K2SO4                                               1.09                 1.25
# Langbeinite – MgK2(SO4)2                            0.19                 0.29
# Aphthitalite – (K,Na)3(SO4)2                        0.84                 1.01
# Gesso                                                1.2                 2.21
# Emiidrato                                            0.3                 0.86
# Anidrite                                            0.61                 1.29
# Calcite – CaCO3                                     8.65                 9.83
# SO3_XRD                                             2.39                 2.64
# CO2_XRD                                              3.8                 4.32
#
#                                                      max         std
# data                                 2022-10-19 00:00:00         NaN
# SO3                                                 3.91    0.301798
# Cl-                                                0.094    0.016461
# Blaine                                            4771.0  236.431779
# ph2oimm                                             30.6    0.575796
# Initial Setting Time                               330.0   36.410047
# Soundness                                            2.0    0.642377
# flow                                               128.0   11.021536
# 2 days strenght                                     37.3    2.393677
# 28 days strenght                                    59.6    2.625359
# residuo 24 micron                                   45.3    2.637925
# R_wp                                                6.19    0.218004
# Alite_M3 C3S M3                                    42.25      4.4471
# Alite_M1 C3S M1                                    41.87    4.136839
# Alite_Sum C3S tot                                  67.68    2.555308
# Ratio_M1 (rapporto M1/M3)                          67.46    6.739967
# C3S_CS (taglia dei cristalliti C3S)               280.55   19.858764
# Belite_beta                                        17.41    2.548444
# C3A cub                                             3.35    0.313534
# C3A_ortho                                           3.88    0.689797
# C3A tot                                             6.21    0.711551
# C4AF                                               13.29    0.930067
# CaO                                                 2.95    0.672389
# Ca(OH)2                                             3.73    0.799101
# Calce libera                                        4.34    0.699891
# Periclasio (MgO)                                     1.1    0.173562
# Quartz                                              2.16    0.244738
# K2SO4                                               1.88    0.258427
# Langbeinite – MgK2(SO4)2                            0.68    0.135026
# Aphthitalite – (K,Na)3(SO4)2                        1.56    0.253302
# Gesso                                               4.19    1.056305
# Emiidrato                                           2.81    0.629057
# Anidrite                                            2.82    0.705922
# Calcite – CaCO3                                    15.88    2.399987
# SO3_XRD                                             3.45    0.349983
# CO2_XRD                                             6.98    1.055367

# %%
df_cem_b.describe(exclude="number").T
# Out:
#      count                           mean                  min  \
# data   323  2021-04-14 02:13:44.767801856  2019-10-07 00:00:00
#
#                       25%                  50%                  75%  \
# data  2020-07-07 00:00:00  2021-04-19 00:00:00  2022-01-18 00:00:00
#
#                       max
# data  2022-10-19 00:00:00

# %%
(df_cem_c.isna().sum().sort_values(ascending=False) / df_cem_c.shape[0] * 100).to_frame(
    name="Missing (%)"
).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_98938_row0_col0, #T_98938_row1_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_98938_row2_col0, #T_98938_row3_col0, #T_98938_row4_col0, #T_98938_row5_col0, #T_98938_row6_col0, #T_98938_row7_col0, #T_98938_row8_col0, #T_98938_row9_col0, #T_98938_row10_col0, #T_98938_row11_col0, #T_98938_row12_col0, #T_98938_row13_col0, #T_98938_row14_col0, #T_98938_row15_col0, #T_98938_row16_col0, #T_98938_row17_col0, #T_98938_row18_col0, #T_98938_row19_col0, #T_98938_row20_col0, #T_98938_row21_col0, #T_98938_row22_col0, #T_98938_row23_col0, #T_98938_row24_col0 {
#   background-color: #79040f;
#   color: #f1f1f1;
# }
# #T_98938_row25_col0 {
#   background-color: #fedbcc;
#   color: #000000;
# }
# #T_98938_row26_col0, #T_98938_row27_col0 {
#   background-color: #fee9df;
#   color: #000000;
# }
# #T_98938_row28_col0, #T_98938_row29_col0, #T_98938_row30_col0, #T_98938_row31_col0, #T_98938_row32_col0, #T_98938_row33_col0, #T_98938_row34_col0, #T_98938_row35_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_98938">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_98938_level0_col0" class="col_heading level0 col0" >Missing (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_98938_level0_row0" class="row_heading level0 row0" >CO2_XRD</th>
#       <td id="T_98938_row0_col0" class="data row0 col0" >8.750000</td>
#     </tr>
#     <tr>
#       <th id="T_98938_level0_row1" class="row_heading level0 row1" >SO3_XRD</th>
#       <td id="T_98938_row1_col0" class="data row1 col0" >8.750000</td>
#     </tr>
#     <tr>
#       <th id="T_98938_level0_row2" class="row_heading level0 row2" >K2SO4</th>
#       <td id="T_98938_row2_col0" class="data row2 col0" >8.437500</td>
#     </tr>
#     <tr>
#       <th id="T_98938_level0_row3" class="row_heading level0 row3" >C4AF</th>
#       <td id="T_98938_row3_col0" class="data row3 col0" >8.437500</td>
#     </tr>
#     <tr>
#       <th id="T_98938_level0_row4" class="row_heading level0 row4" >CaO</th>
#       <td id="T_98938_row4_col0" class="data row4 col0" >8.437500</td>
#     </tr>
#     <tr>
#       <th id="T_98938_level0_row5" class="row_heading level0 row5" >Ca(OH)2</th>
#       <td id="T_98938_row5_col0" class="data row5 col0" >8.437500</td>
#     </tr>
#     <tr>
#       <th id="T_98938_level0_row6" class="row_heading level0 row6" >Calce libera</th>
#       <td id="T_98938_row6_col0" class="data row6 col0" >8.437500</td>
#     </tr>
#     <tr>
#       <th id="T_98938_level0_row7" class="row_heading level0 row7" >Periclasio (MgO)</th>
#       <td id="T_98938_row7_col0" class="data row7 col0" >8.437500</td>
#     </tr>
#     <tr>
#       <th id="T_98938_level0_row8" class="row_heading level0 row8" >Quartz</th>
#       <td id="T_98938_row8_col0" class="data row8 col0" >8.437500</td>
#     </tr>
#     <tr>
#       <th id="T_98938_level0_row9" class="row_heading level0 row9" >Langbeinite – MgK2(SO4)2</th>
#       <td id="T_98938_row9_col0" class="data row9 col0" >8.437500</td>
#     </tr>
#     <tr>
#       <th id="T_98938_level0_row10" class="row_heading level0 row10" >C3A_ortho</th>
#       <td id="T_98938_row10_col0" class="data row10 col0" >8.437500</td>
#     </tr>
#     <tr>
#       <th id="T_98938_level0_row11" class="row_heading level0 row11" >Aphthitalite – (K,Na)3(SO4)2</th>
#       <td id="T_98938_row11_col0" class="data row11 col0" >8.437500</td>
#     </tr>
#     <tr>
#       <th id="T_98938_level0_row12" class="row_heading level0 row12" >Gesso</th>
#       <td id="T_98938_row12_col0" class="data row12 col0" >8.437500</td>
#     </tr>
#     <tr>
#       <th id="T_98938_level0_row13" class="row_heading level0 row13" >Emiidrato</th>
#       <td id="T_98938_row13_col0" class="data row13 col0" >8.437500</td>
#     </tr>
#     <tr>
#       <th id="T_98938_level0_row14" class="row_heading level0 row14" >Anidrite</th>
#       <td id="T_98938_row14_col0" class="data row14 col0" >8.437500</td>
#     </tr>
#     <tr>
#       <th id="T_98938_level0_row15" class="row_heading level0 row15" >Calcite – CaCO3</th>
#       <td id="T_98938_row15_col0" class="data row15 col0" >8.437500</td>
#     </tr>
#     <tr>
#       <th id="T_98938_level0_row16" class="row_heading level0 row16" >C3A tot</th>
#       <td id="T_98938_row16_col0" class="data row16 col0" >8.437500</td>
#     </tr>
#     <tr>
#       <th id="T_98938_level0_row17" class="row_heading level0 row17" >C3A cub</th>
#       <td id="T_98938_row17_col0" class="data row17 col0" >8.437500</td>
#     </tr>
#     <tr>
#       <th id="T_98938_level0_row18" class="row_heading level0 row18" >C3S_CS (taglia dei cristalliti C3S)</th>
#       <td id="T_98938_row18_col0" class="data row18 col0" >8.437500</td>
#     </tr>
#     <tr>
#       <th id="T_98938_level0_row19" class="row_heading level0 row19" >Ratio_M1 (rapporto M1/M3)</th>
#       <td id="T_98938_row19_col0" class="data row19 col0" >8.437500</td>
#     </tr>
#     <tr>
#       <th id="T_98938_level0_row20" class="row_heading level0 row20" >Alite_Sum C3S tot</th>
#       <td id="T_98938_row20_col0" class="data row20 col0" >8.437500</td>
#     </tr>
#     <tr>
#       <th id="T_98938_level0_row21" class="row_heading level0 row21" >Alite_M1 C3S M1</th>
#       <td id="T_98938_row21_col0" class="data row21 col0" >8.437500</td>
#     </tr>
#     <tr>
#       <th id="T_98938_level0_row22" class="row_heading level0 row22" >Alite_M3 C3S M3</th>
#       <td id="T_98938_row22_col0" class="data row22 col0" >8.437500</td>
#     </tr>
#     <tr>
#       <th id="T_98938_level0_row23" class="row_heading level0 row23" >R_wp</th>
#       <td id="T_98938_row23_col0" class="data row23 col0" >8.437500</td>
#     </tr>
#     <tr>
#       <th id="T_98938_level0_row24" class="row_heading level0 row24" >Belite_beta</th>
#       <td id="T_98938_row24_col0" class="data row24 col0" >8.437500</td>
#     </tr>
#     <tr>
#       <th id="T_98938_level0_row25" class="row_heading level0 row25" >Soundness</th>
#       <td id="T_98938_row25_col0" class="data row25 col0" >1.250000</td>
#     </tr>
#     <tr>
#       <th id="T_98938_level0_row26" class="row_heading level0 row26" >flow</th>
#       <td id="T_98938_row26_col0" class="data row26 col0" >0.625000</td>
#     </tr>
#     <tr>
#       <th id="T_98938_level0_row27" class="row_heading level0 row27" >Initial Setting Time</th>
#       <td id="T_98938_row27_col0" class="data row27 col0" >0.625000</td>
#     </tr>
#     <tr>
#       <th id="T_98938_level0_row28" class="row_heading level0 row28" >SO3</th>
#       <td id="T_98938_row28_col0" class="data row28 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_98938_level0_row29" class="row_heading level0 row29" >ph2oimm</th>
#       <td id="T_98938_row29_col0" class="data row29 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_98938_level0_row30" class="row_heading level0 row30" >Cl-</th>
#       <td id="T_98938_row30_col0" class="data row30 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_98938_level0_row31" class="row_heading level0 row31" >Blaine</th>
#       <td id="T_98938_row31_col0" class="data row31 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_98938_level0_row32" class="row_heading level0 row32" >28 days strenght</th>
#       <td id="T_98938_row32_col0" class="data row32 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_98938_level0_row33" class="row_heading level0 row33" >2 days strenght</th>
#       <td id="T_98938_row33_col0" class="data row33 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_98938_level0_row34" class="row_heading level0 row34" >residuo 24 micron</th>
#       <td id="T_98938_row34_col0" class="data row34 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_98938_level0_row35" class="row_heading level0 row35" >data</th>
#       <td id="T_98938_row35_col0" class="data row35 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_cem_c.describe().T
# Out:
#                                      count                 mean  \
# data                                   320  2021-04-20 11:33:00
# SO3                                  320.0             3.055375
# Cl-                                  320.0             0.067237
# Blaine                               320.0           3656.64375
# ph2oimm                              320.0             28.04125
# Initial Setting Time                 318.0           226.886792
# Soundness                            316.0             0.746835
# flow                                 318.0           103.672956
# 2 days strenght                      320.0            22.800937
# 28 days strenght                     320.0            40.775625
# residuo 24 micron                    320.0            39.628125
# R_wp                                 293.0             5.687986
# Alite_M3 C3S M3                      293.0            23.360034
# Alite_M1 C3S M1                      293.0            25.464949
# Alite_Sum C3S tot                    293.0            48.823891
# Ratio_M1 (rapporto M1/M3)            293.0            52.197065
# C3S_CS (taglia dei cristalliti C3S)  293.0           240.663038
# Belite_beta                          293.0             7.333959
# C3A cub                              293.0             1.709488
# C3A_ortho                            293.0             1.822048
# C3A tot                              293.0             3.530375
# C4AF                                 293.0             8.241365
# CaO                                  293.0             1.007509
# Ca(OH)2                              293.0              1.10256
# Calce libera                         293.0             1.840751
# Periclasio (MgO)                     293.0             0.437986
# Quartz                               293.0                 1.07
# K2SO4                                293.0               1.1443
# Langbeinite – MgK2(SO4)2             293.0             0.408805
# Aphthitalite – (K,Na)3(SO4)2         293.0             0.751604
# Gesso                                293.0             1.816826
# Emiidrato                            293.0             0.294642
# Anidrite                             293.0               0.6943
# Calcite – CaCO3                      293.0             23.34744
# SO3_XRD                              292.0             2.522123
# CO2_XRD                              292.0            10.291849
#
#                                                      min                  25%  \
# data                                 2019-10-16 00:00:00  2020-07-16 12:00:00
# SO3                                                  2.5                 2.91
# Cl-                                                0.021                 0.06
# Blaine                                            2654.0              3499.75
# ph2oimm                                             26.4                 27.6
# Initial Setting Time                               160.0                200.0
# Soundness                                            0.0                  0.0
# flow                                                78.0                 93.0
# 2 days strenght                                     17.9                 21.4
# 28 days strenght                                    34.4                 38.6
# residuo 24 micron                                   32.6                 38.0
# R_wp                                                5.08                 5.48
# Alite_M3 C3S M3                                    14.15                20.41
# Alite_M1 C3S M1                                    17.63                22.67
# Alite_Sum C3S tot                                  41.09                46.82
# Ratio_M1 (rapporto M1/M3)                          34.42                46.84
# C3S_CS (taglia dei cristalliti C3S)               143.76               227.87
# Belite_beta                                         1.43                 6.12
# C3A cub                                             0.73                 1.48
# C3A_ortho                                           0.57                 1.39
# C3A tot                                             2.09                 3.05
# C4AF                                                6.44                 7.68
# CaO                                                 0.01                 0.55
# Ca(OH)2                                             0.04                 0.55
# Calce libera                                        0.22                 1.55
# Periclasio (MgO)                                    0.01                 0.29
# Quartz                                              0.27                 0.88
# K2SO4                                               0.42                 0.96
# Langbeinite – MgK2(SO4)2                            0.02                  0.3
# Aphthitalite – (K,Na)3(SO4)2                        0.25                 0.61
# Gesso                                                0.0                 0.85
# Emiidrato                                            0.0                  0.0
# Anidrite                                            0.02                 0.22
# Calcite – CaCO3                                    13.49                 21.4
# SO3_XRD                                             1.89               2.2875
# CO2_XRD                                             5.93               9.4175
#
#                                                      50%                  75%  \
# data                                 2021-04-23 12:00:00  2022-01-21 12:00:00
# SO3                                                 3.07                  3.2
# Cl-                                                 0.07                0.076
# Blaine                                            3620.5               3785.0
# ph2oimm                                             28.0                 28.4
# Initial Setting Time                               220.0                240.0
# Soundness                                            1.0                  1.0
# flow                                               106.0                112.0
# 2 days strenght                                     22.5                 24.4
# 28 days strenght                                   40.65                 42.5
# residuo 24 micron                                   39.9                 41.3
# R_wp                                                5.64                 5.84
# Alite_M3 C3S M3                                    23.08                26.01
# Alite_M1 C3S M1                                    25.34                28.04
# Alite_Sum C3S tot                                  48.75                50.69
# Ratio_M1 (rapporto M1/M3)                          52.06                57.98
# C3S_CS (taglia dei cristalliti C3S)               240.99               255.63
# Belite_beta                                         7.43                 8.53
# C3A cub                                             1.69                 1.93
# C3A_ortho                                            1.7                 2.22
# C3A tot                                             3.47                 3.98
# C4AF                                                 8.2                  8.8
# CaO                                                 1.02                 1.39
# Ca(OH)2                                             1.09                 1.52
# Calce libera                                        1.93                  2.2
# Periclasio (MgO)                                    0.43                 0.57
# Quartz                                              1.03                 1.25
# K2SO4                                               1.14                 1.31
# Langbeinite – MgK2(SO4)2                            0.39                 0.53
# Aphthitalite – (K,Na)3(SO4)2                        0.72                 0.88
# Gesso                                                1.9                  2.7
# Emiidrato                                           0.13                 0.44
# Anidrite                                            0.42                 1.02
# Calcite – CaCO3                                     23.7                25.91
# SO3_XRD                                              2.5                  2.7
# CO2_XRD                                            10.42                11.39
#
#                                                      max        std
# data                                 2022-10-21 00:00:00        NaN
# SO3                                                 3.49   0.209815
# Cl-                                                0.099   0.013911
# Blaine                                            4389.0  264.68623
# ph2oimm                                             31.0   0.579686
# Initial Setting Time                               390.0  39.498749
# Soundness                                            2.0    0.63182
# flow                                               125.0  10.403831
# 2 days strenght                                     28.5    2.10916
# 28 days strenght                                    49.1   2.774328
# residuo 24 micron                                   46.4   2.486168
# R_wp                                                9.26   0.323969
# Alite_M3 C3S M3                                    35.85    3.85812
# Alite_M1 C3S M1                                    35.55   3.626892
# Alite_Sum C3S tot                                  58.34   2.856277
# Ratio_M1 (rapporto M1/M3)                          68.77   7.025063
# C3S_CS (taglia dei cristalliti C3S)               306.68  23.821565
# Belite_beta                                        12.33   1.944013
# C3A cub                                             2.89   0.349364
# C3A_ortho                                           3.46   0.587877
# C3A tot                                              5.3   0.610505
# C4AF                                               10.93   0.848263
# CaO                                                  2.7   0.549406
# Ca(OH)2                                             3.08   0.679385
# Calce libera                                        3.55    0.56193
# Periclasio (MgO)                                    1.38   0.195901
# Quartz                                              2.84   0.296843
# K2SO4                                               3.95   0.314714
# Langbeinite – MgK2(SO4)2                            0.85   0.165946
# Aphthitalite – (K,Na)3(SO4)2                        1.43   0.211584
# Gesso                                               4.24   1.067925
# Emiidrato                                           1.97   0.404296
# Anidrite                                            2.61   0.637166
# Calcite – CaCO3                                    29.91   3.340197
# SO3_XRD                                             4.19   0.312513
# CO2_XRD                                            14.45   1.514508

# %%
df_cem_c.describe(exclude="number").T
# Out:
#      count                 mean                  min                  25%  \
# data   320  2021-04-20 11:33:00  2019-10-16 00:00:00  2020-07-16 12:00:00
#
#                       50%                  75%                  max
# data  2021-04-23 12:00:00  2022-01-21 12:00:00  2022-10-21 00:00:00

# %% [markdown]
# ### Sort the dataset by date

# %%
df = df.sort_values(by="data")
df_cem_a = df_cem_a.sort_values(by="data")
df_cem_b = df_cem_b.sort_values(by="data")
df_cem_c = df_cem_c.sort_values(by="data")

# %% [markdown]
# ### Renaming some features
#
# The key idea here is to create a pattern among different datasets in order to facilitate reusing the same code

# %%
features_name_dict = {
    "data": "Date",
    "2 days strenght": "CS2",
    "28 days strenght": "CS28",
}

df = df.rename(features_name_dict, axis=1)
df_cem_a = df_cem_a.rename(features_name_dict, axis=1)
df_cem_b = df_cem_b.rename(features_name_dict, axis=1)
df_cem_c = df_cem_c.rename(features_name_dict, axis=1)

# %% [markdown]
# ### Grouping and computing mean daily of features
#
# Datasets with various cements we group by date and cement type
# Datasets with a single type of cement we compute the mean only.

# %%
print(df.shape)
print(df_cem_a.shape)
print(df_cem_b.shape)
print(df_cem_c.shape)
# Out:
# (958, 37)
# (315, 36)
# (323, 36)
# (320, 36)

# %%
# df = df.groupby(["Date", "cem_type"]).mean().reset_index()
# df_cem_a = df_cem_a.groupby(["Date"]).mean().reset_index()
# df_cem_b = df_cem_b.groupby(["Date"]).mean().reset_index()
# df_cem_c = df_cem_c.groupby(["Date"]).mean().reset_index()

# %%
# print(df.shape)
# print(df_cem_a.shape)
# print(df_cem_b.shape)
# print(df_cem_c.shape)

# %% [markdown]
# ## Saving the dataset

# %% [markdown]
# <h3>Saving for feature engineering</h3>

# %%
df.to_csv("../../../../data/interim/partner_iv/cement-shipping.csv", index=False)
df_cem_a.to_csv("../../../../data/interim/partner_iv/cem_a.csv", index=False)
df_cem_b.to_csv("../../../../data/interim/partner_iv/cem_b.csv", index=False)
df_cem_c.to_csv("../../../../data/interim/partner_iv/cem_c.csv", index=False)
