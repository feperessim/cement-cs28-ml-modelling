# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Reading the dataset

# %%
xls = pd.ExcelFile(
    "../../../data/raw/Inter/estudo.xlsm", engine="openpyxl"
)
df = pd.read_excel(xls, "dados")#, parse_dates=["Data"])

df_2018_2019 = pd.read_excel(
    "../../../data/raw/Inter/Dados_CAJ_2018_19.xlsx",
    engine="openpyxl",
    #parse_dates=["Data"],
)

# %% [markdown]
# ## Initial Preprocessing

# %%
# 2008-2017
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df = df[~df.isna().all(axis=1)]
df = df.rename({"G75�": "G75", "G44�": "G44"}, axis=1)

# 2018-2019
df_2018_2019 = df_2018_2019.rename({"G75�": "G75", "G44�": "G44"}, axis=1)
df_2018_2019["Data"] = pd.to_datetime(df_2018_2019["Data"], format="%d/%m/%Y")
df["Data"] = pd.to_datetime(df["Data"], format="%Y/%m/%d")
df = pd.concat([df, df_2018_2019]).reset_index(drop=True)

# %%
df_cpiif32 = df[df["COD_PROD"] ==  "CPIIF32"].reset_index(drop=True)
df_cpiif40 = df[df["COD_PROD"] ==  "CPIIF40"].reset_index(drop=True)

# %% [markdown]
# # Removing Useless Features
#
# Here we will drop some features that may not contribute to the performance of the models that will be fitted on this data.

# %% [markdown]
# <h3>Percentage of missing values:</h3>
#
# <table>
#     <th>Full Dataset:</th>
#     <th> </th>
#     <tr>
#         <td>RIC_OBS</td>
#         <td>100.000000</td>
#     </tr>
#     <tr>
#         <td>RIE_OBS</td>
#         <td>100.000000</td>
#     </tr>
#     <tr>
#         <td>Rept</td>
#         <td>100.000000</td>
#     </tr>
#     <tr>
#     <td>RC91</td>
#     <td>99.695013</td>
#     </tr>
#     <tr>
#     <td>Nat1</td>
#     <td>99.605310</td>
#     <tr/>
#     <tr>
#     <td>CO2</td>
#     <td>99.551489</td>
#     <tr/>
#     <tr>
#     <td>NA2O</td>
#     <td>82.579835</td>
#     <tr/>
#     <tr>
#     <td>EXP</td>
#     <td>78.238249</td>
#     <tr/>
#     <tr>
#     <td>RC1</td>
#     <td>42.752063</td>
#     <tr/>
#     <tr>
#     <td>MVOL</td>
#     <td>28.040904</td>
#     <tr/>
#     <tr>
#     <td>RICARB</td>
#     <td>18.066021</td>
#     <tr/>
# </table>
#
# <table>
#     <th>CPIIF40</th>
#     <th></th>
#     <tr>
#         <td>TiO2</td>
#         <td>99.836334</td>
#     </tr>
#     <tr>
#         <td>Ca(OH)2</td>
#         <td>99.836334</td>
#     </tr>
#     <tr>
#         <td>CaCO3</td>
#         <td>99.836334</td>
#     </tr>
#     <tr>
#     <td>Langbeinite</td>
#     <td>69.558101</td>
#     </tr>
#     <tr>
#     <td>1 day Compressive strength</td>
#     <td>100.000000</td>
#     </tr>
# </table>
#
# <table>
#     <th>CPIIF32</th>
#     <th></th>
#     <tr>
#         <td>TiO2</td>
#         <td>100.000000</td>
#     </tr>
#     <tr>
#         <td>Ca(OH)2</td>
#         <td>100.000000</td>
#     </tr>
#     <tr>
#         <td>CaCO3</td>
#         <td>100.000000</td>
#     </tr>
#     <tr>
#         <td>Langbeinite</td>
#         <td>68.646081</td>
#     </tr>
#     <tr>
#         <td>1 day Compressive strength</td>
#         <td>100.000000</td>
#     </tr>
#     <tr>
#         <td>#400</td>
#         <td>100.000000</td>
#     </tr>
# </table>

# %%
FEATURES_TO_DROP = [
    # Missing Values
    "RIC_OBS",
    "RIE_OBS",
    "Rept",
    "RC91",
    "Nat1",
    "CO2",
    "NA2O",
    "EXP",

    # Features with zero variance
    # or more than 70% percent of zeros
    
    # Properties
    "IP",     # Initial setting time
    "FP",     # Final setting time
    "SBL",    # Blaine
    "G75",    # Fineness
    "G44",    # Fineness
    "MVOL",   # Density,
    "RICARB", # Insoluble residue
    "AGP",    # Paste consistency water
    "PF",     # Fire Loss

    # Useless Features
    "RIC", 
    "Nat",
    "Nat1",
    "Lp",
    "Ec",
    "Lc",
    "RIE",
    "COD_MN",
    "COD_ENT",
    "COD_VAR_PROD"
]

# %% [markdown]
# ### Removing features with features having 60% or more of missing values
#
# ### Removing features related to the properties of Cement
#
# ### Removing features with zero variance
#
# ### Removing features with more than 70% of zeros

# %%
df = df.drop(labels=FEATURES_TO_DROP, axis=1)
df_cpiif32 = df_cpiif32.drop(labels=FEATURES_TO_DROP + ["COD_PROD"], axis=1)
df_cpiif40 = df_cpiif40.drop(labels=FEATURES_TO_DROP + ["COD_PROD"], axis=1)

# %% [markdown]
# ### Drop rows where the target variable is null

# %%
df = df[df["RC28"].notna()]
df_cpiif32 = df_cpiif32[df_cpiif32["RC28"].notna()]
df_cpiif40 = df_cpiif40[df_cpiif40["RC28"].notna()]

# %%
(df.isna().sum().sort_values(ascending=False)/df.shape[0] * 100).to_frame(
    name="Missing (%)"
).style.background_gradient(cmap="Reds")
# Out:
# <style  type="text/css" >
# #T_69252ce2_5ad2_11ed_871f_dcfb48751facrow0_col0{
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }#T_69252ce2_5ad2_11ed_871f_dcfb48751facrow1_col0{
#             background-color:  #ffece4;
#             color:  #000000;
#         }#T_69252ce2_5ad2_11ed_871f_dcfb48751facrow2_col0{
#             background-color:  #ffede5;
#             color:  #000000;
#         }#T_69252ce2_5ad2_11ed_871f_dcfb48751facrow3_col0,#T_69252ce2_5ad2_11ed_871f_dcfb48751facrow4_col0,#T_69252ce2_5ad2_11ed_871f_dcfb48751facrow5_col0,#T_69252ce2_5ad2_11ed_871f_dcfb48751facrow6_col0,#T_69252ce2_5ad2_11ed_871f_dcfb48751facrow7_col0{
#             background-color:  #ffeee6;
#             color:  #000000;
#         }#T_69252ce2_5ad2_11ed_871f_dcfb48751facrow8_col0{
#             background-color:  #ffeee7;
#             color:  #000000;
#         }#T_69252ce2_5ad2_11ed_871f_dcfb48751facrow9_col0,#T_69252ce2_5ad2_11ed_871f_dcfb48751facrow10_col0,#T_69252ce2_5ad2_11ed_871f_dcfb48751facrow11_col0,#T_69252ce2_5ad2_11ed_871f_dcfb48751facrow12_col0,#T_69252ce2_5ad2_11ed_871f_dcfb48751facrow13_col0{
#             background-color:  #fff5f0;
#             color:  #000000;
#         }</style><table id="T_69252ce2_5ad2_11ed_871f_dcfb48751fac" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Missing (%)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_69252ce2_5ad2_11ed_871f_dcfb48751faclevel0_row0" class="row_heading level0 row0" >RC1</th>
#                         <td id="T_69252ce2_5ad2_11ed_871f_dcfb48751facrow0_col0" class="data row0 col0" >42.726128</td>
#             </tr>
#             <tr>
#                         <th id="T_69252ce2_5ad2_11ed_871f_dcfb48751faclevel0_row1" class="row_heading level0 row1" >P2O5</th>
#                         <td id="T_69252ce2_5ad2_11ed_871f_dcfb48751facrow1_col0" class="data row1 col0" >2.319727</td>
#             </tr>
#             <tr>
#                         <th id="T_69252ce2_5ad2_11ed_871f_dcfb48751faclevel0_row2" class="row_heading level0 row2" >K2O</th>
#                         <td id="T_69252ce2_5ad2_11ed_871f_dcfb48751facrow2_col0" class="data row2 col0" >2.032009</td>
#             </tr>
#             <tr>
#                         <th id="T_69252ce2_5ad2_11ed_871f_dcfb48751faclevel0_row3" class="row_heading level0 row3" >FE2O3</th>
#                         <td id="T_69252ce2_5ad2_11ed_871f_dcfb48751facrow3_col0" class="data row3 col0" >1.996044</td>
#             </tr>
#             <tr>
#                         <th id="T_69252ce2_5ad2_11ed_871f_dcfb48751faclevel0_row4" class="row_heading level0 row4" >SIO2</th>
#                         <td id="T_69252ce2_5ad2_11ed_871f_dcfb48751facrow4_col0" class="data row4 col0" >1.996044</td>
#             </tr>
#             <tr>
#                         <th id="T_69252ce2_5ad2_11ed_871f_dcfb48751faclevel0_row5" class="row_heading level0 row5" >CAOT</th>
#                         <td id="T_69252ce2_5ad2_11ed_871f_dcfb48751facrow5_col0" class="data row5 col0" >1.996044</td>
#             </tr>
#             <tr>
#                         <th id="T_69252ce2_5ad2_11ed_871f_dcfb48751faclevel0_row6" class="row_heading level0 row6" >AL2O3</th>
#                         <td id="T_69252ce2_5ad2_11ed_871f_dcfb48751facrow6_col0" class="data row6 col0" >1.996044</td>
#             </tr>
#             <tr>
#                         <th id="T_69252ce2_5ad2_11ed_871f_dcfb48751faclevel0_row7" class="row_heading level0 row7" >MGO</th>
#                         <td id="T_69252ce2_5ad2_11ed_871f_dcfb48751facrow7_col0" class="data row7 col0" >1.870167</td>
#             </tr>
#             <tr>
#                         <th id="T_69252ce2_5ad2_11ed_871f_dcfb48751faclevel0_row8" class="row_heading level0 row8" >SO3</th>
#                         <td id="T_69252ce2_5ad2_11ed_871f_dcfb48751facrow8_col0" class="data row8 col0" >1.744291</td>
#             </tr>
#             <tr>
#                         <th id="T_69252ce2_5ad2_11ed_871f_dcfb48751faclevel0_row9" class="row_heading level0 row9" >RC7</th>
#                         <td id="T_69252ce2_5ad2_11ed_871f_dcfb48751facrow9_col0" class="data row9 col0" >0.017982</td>
#             </tr>
#             <tr>
#                         <th id="T_69252ce2_5ad2_11ed_871f_dcfb48751faclevel0_row10" class="row_heading level0 row10" >RC28</th>
#                         <td id="T_69252ce2_5ad2_11ed_871f_dcfb48751facrow10_col0" class="data row10 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_69252ce2_5ad2_11ed_871f_dcfb48751faclevel0_row11" class="row_heading level0 row11" >RC3</th>
#                         <td id="T_69252ce2_5ad2_11ed_871f_dcfb48751facrow11_col0" class="data row11 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_69252ce2_5ad2_11ed_871f_dcfb48751faclevel0_row12" class="row_heading level0 row12" >COD_PROD</th>
#                         <td id="T_69252ce2_5ad2_11ed_871f_dcfb48751facrow12_col0" class="data row12 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_69252ce2_5ad2_11ed_871f_dcfb48751faclevel0_row13" class="row_heading level0 row13" >Data</th>
#                         <td id="T_69252ce2_5ad2_11ed_871f_dcfb48751facrow13_col0" class="data row13 col0" >0.000000</td>
#             </tr>
#     </tbody></table>

# %%
(df_cpiif32.isna().sum().sort_values(ascending=False)/df_cpiif32.shape[0] * 100).to_frame(
    name="Missing (%)"
).style.background_gradient(cmap="Reds")
# Out:
# <style  type="text/css" >
# #T_69252ce3_5ad2_11ed_871f_dcfb48751facrow0_col0{
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }#T_69252ce3_5ad2_11ed_871f_dcfb48751facrow1_col0{
#             background-color:  #ffeee7;
#             color:  #000000;
#         }#T_69252ce3_5ad2_11ed_871f_dcfb48751facrow2_col0,#T_69252ce3_5ad2_11ed_871f_dcfb48751facrow3_col0,#T_69252ce3_5ad2_11ed_871f_dcfb48751facrow4_col0,#T_69252ce3_5ad2_11ed_871f_dcfb48751facrow5_col0,#T_69252ce3_5ad2_11ed_871f_dcfb48751facrow6_col0,#T_69252ce3_5ad2_11ed_871f_dcfb48751facrow7_col0{
#             background-color:  #ffefe8;
#             color:  #000000;
#         }#T_69252ce3_5ad2_11ed_871f_dcfb48751facrow8_col0{
#             background-color:  #fff0e8;
#             color:  #000000;
#         }#T_69252ce3_5ad2_11ed_871f_dcfb48751facrow9_col0,#T_69252ce3_5ad2_11ed_871f_dcfb48751facrow10_col0,#T_69252ce3_5ad2_11ed_871f_dcfb48751facrow11_col0,#T_69252ce3_5ad2_11ed_871f_dcfb48751facrow12_col0{
#             background-color:  #fff5f0;
#             color:  #000000;
#         }</style><table id="T_69252ce3_5ad2_11ed_871f_dcfb48751fac" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Missing (%)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_69252ce3_5ad2_11ed_871f_dcfb48751faclevel0_row0" class="row_heading level0 row0" >RC1</th>
#                         <td id="T_69252ce3_5ad2_11ed_871f_dcfb48751facrow0_col0" class="data row0 col0" >62.957075</td>
#             </tr>
#             <tr>
#                         <th id="T_69252ce3_5ad2_11ed_871f_dcfb48751faclevel0_row1" class="row_heading level0 row1" >P2O5</th>
#                         <td id="T_69252ce3_5ad2_11ed_871f_dcfb48751facrow1_col0" class="data row1 col0" >2.596714</td>
#             </tr>
#             <tr>
#                         <th id="T_69252ce3_5ad2_11ed_871f_dcfb48751faclevel0_row2" class="row_heading level0 row2" >K2O</th>
#                         <td id="T_69252ce3_5ad2_11ed_871f_dcfb48751facrow2_col0" class="data row2 col0" >2.411235</td>
#             </tr>
#             <tr>
#                         <th id="T_69252ce3_5ad2_11ed_871f_dcfb48751faclevel0_row3" class="row_heading level0 row3" >FE2O3</th>
#                         <td id="T_69252ce3_5ad2_11ed_871f_dcfb48751facrow3_col0" class="data row3 col0" >2.358241</td>
#             </tr>
#             <tr>
#                         <th id="T_69252ce3_5ad2_11ed_871f_dcfb48751faclevel0_row4" class="row_heading level0 row4" >SIO2</th>
#                         <td id="T_69252ce3_5ad2_11ed_871f_dcfb48751facrow4_col0" class="data row4 col0" >2.358241</td>
#             </tr>
#             <tr>
#                         <th id="T_69252ce3_5ad2_11ed_871f_dcfb48751faclevel0_row5" class="row_heading level0 row5" >CAOT</th>
#                         <td id="T_69252ce3_5ad2_11ed_871f_dcfb48751facrow5_col0" class="data row5 col0" >2.358241</td>
#             </tr>
#             <tr>
#                         <th id="T_69252ce3_5ad2_11ed_871f_dcfb48751faclevel0_row6" class="row_heading level0 row6" >AL2O3</th>
#                         <td id="T_69252ce3_5ad2_11ed_871f_dcfb48751facrow6_col0" class="data row6 col0" >2.358241</td>
#             </tr>
#             <tr>
#                         <th id="T_69252ce3_5ad2_11ed_871f_dcfb48751faclevel0_row7" class="row_heading level0 row7" >MGO</th>
#                         <td id="T_69252ce3_5ad2_11ed_871f_dcfb48751facrow7_col0" class="data row7 col0" >2.252252</td>
#             </tr>
#             <tr>
#                         <th id="T_69252ce3_5ad2_11ed_871f_dcfb48751faclevel0_row8" class="row_heading level0 row8" >SO3</th>
#                         <td id="T_69252ce3_5ad2_11ed_871f_dcfb48751facrow8_col0" class="data row8 col0" >2.066773</td>
#             </tr>
#             <tr>
#                         <th id="T_69252ce3_5ad2_11ed_871f_dcfb48751faclevel0_row9" class="row_heading level0 row9" >RC7</th>
#                         <td id="T_69252ce3_5ad2_11ed_871f_dcfb48751facrow9_col0" class="data row9 col0" >0.026497</td>
#             </tr>
#             <tr>
#                         <th id="T_69252ce3_5ad2_11ed_871f_dcfb48751faclevel0_row10" class="row_heading level0 row10" >RC28</th>
#                         <td id="T_69252ce3_5ad2_11ed_871f_dcfb48751facrow10_col0" class="data row10 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_69252ce3_5ad2_11ed_871f_dcfb48751faclevel0_row11" class="row_heading level0 row11" >RC3</th>
#                         <td id="T_69252ce3_5ad2_11ed_871f_dcfb48751facrow11_col0" class="data row11 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_69252ce3_5ad2_11ed_871f_dcfb48751faclevel0_row12" class="row_heading level0 row12" >Data</th>
#                         <td id="T_69252ce3_5ad2_11ed_871f_dcfb48751facrow12_col0" class="data row12 col0" >0.000000</td>
#             </tr>
#     </tbody></table>

# %%
(df_cpiif40.isna().sum().sort_values(ascending=False)/df_cpiif40.shape[0] * 100).to_frame(
    name="Missing (%)"
).style.background_gradient(cmap="Reds")
# Out:
# <style  type="text/css" >
# #T_69252ce4_5ad2_11ed_871f_dcfb48751facrow0_col0{
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }#T_69252ce4_5ad2_11ed_871f_dcfb48751facrow1_col0,#T_69252ce4_5ad2_11ed_871f_dcfb48751facrow2_col0,#T_69252ce4_5ad2_11ed_871f_dcfb48751facrow3_col0,#T_69252ce4_5ad2_11ed_871f_dcfb48751facrow4_col0,#T_69252ce4_5ad2_11ed_871f_dcfb48751facrow5_col0{
#             background-color:  #d72322;
#             color:  #f1f1f1;
#         }#T_69252ce4_5ad2_11ed_871f_dcfb48751facrow6_col0,#T_69252ce4_5ad2_11ed_871f_dcfb48751facrow7_col0{
#             background-color:  #f0402f;
#             color:  #f1f1f1;
#         }#T_69252ce4_5ad2_11ed_871f_dcfb48751facrow8_col0,#T_69252ce4_5ad2_11ed_871f_dcfb48751facrow9_col0,#T_69252ce4_5ad2_11ed_871f_dcfb48751facrow10_col0,#T_69252ce4_5ad2_11ed_871f_dcfb48751facrow11_col0,#T_69252ce4_5ad2_11ed_871f_dcfb48751facrow12_col0{
#             background-color:  #fff5f0;
#             color:  #000000;
#         }</style><table id="T_69252ce4_5ad2_11ed_871f_dcfb48751fac" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Missing (%)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_69252ce4_5ad2_11ed_871f_dcfb48751faclevel0_row0" class="row_heading level0 row0" >P2O5</th>
#                         <td id="T_69252ce4_5ad2_11ed_871f_dcfb48751facrow0_col0" class="data row0 col0" >1.734751</td>
#             </tr>
#             <tr>
#                         <th id="T_69252ce4_5ad2_11ed_871f_dcfb48751faclevel0_row1" class="row_heading level0 row1" >FE2O3</th>
#                         <td id="T_69252ce4_5ad2_11ed_871f_dcfb48751facrow1_col0" class="data row1 col0" >1.231114</td>
#             </tr>
#             <tr>
#                         <th id="T_69252ce4_5ad2_11ed_871f_dcfb48751faclevel0_row2" class="row_heading level0 row2" >SIO2</th>
#                         <td id="T_69252ce4_5ad2_11ed_871f_dcfb48751facrow2_col0" class="data row2 col0" >1.231114</td>
#             </tr>
#             <tr>
#                         <th id="T_69252ce4_5ad2_11ed_871f_dcfb48751faclevel0_row3" class="row_heading level0 row3" >K2O</th>
#                         <td id="T_69252ce4_5ad2_11ed_871f_dcfb48751facrow3_col0" class="data row3 col0" >1.231114</td>
#             </tr>
#             <tr>
#                         <th id="T_69252ce4_5ad2_11ed_871f_dcfb48751faclevel0_row4" class="row_heading level0 row4" >CAOT</th>
#                         <td id="T_69252ce4_5ad2_11ed_871f_dcfb48751facrow4_col0" class="data row4 col0" >1.231114</td>
#             </tr>
#             <tr>
#                         <th id="T_69252ce4_5ad2_11ed_871f_dcfb48751faclevel0_row5" class="row_heading level0 row5" >AL2O3</th>
#                         <td id="T_69252ce4_5ad2_11ed_871f_dcfb48751facrow5_col0" class="data row5 col0" >1.231114</td>
#             </tr>
#             <tr>
#                         <th id="T_69252ce4_5ad2_11ed_871f_dcfb48751faclevel0_row6" class="row_heading level0 row6" >SO3</th>
#                         <td id="T_69252ce4_5ad2_11ed_871f_dcfb48751facrow6_col0" class="data row6 col0" >1.063234</td>
#             </tr>
#             <tr>
#                         <th id="T_69252ce4_5ad2_11ed_871f_dcfb48751faclevel0_row7" class="row_heading level0 row7" >MGO</th>
#                         <td id="T_69252ce4_5ad2_11ed_871f_dcfb48751facrow7_col0" class="data row7 col0" >1.063234</td>
#             </tr>
#             <tr>
#                         <th id="T_69252ce4_5ad2_11ed_871f_dcfb48751faclevel0_row8" class="row_heading level0 row8" >RC1</th>
#                         <td id="T_69252ce4_5ad2_11ed_871f_dcfb48751facrow8_col0" class="data row8 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_69252ce4_5ad2_11ed_871f_dcfb48751faclevel0_row9" class="row_heading level0 row9" >RC28</th>
#                         <td id="T_69252ce4_5ad2_11ed_871f_dcfb48751facrow9_col0" class="data row9 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_69252ce4_5ad2_11ed_871f_dcfb48751faclevel0_row10" class="row_heading level0 row10" >RC7</th>
#                         <td id="T_69252ce4_5ad2_11ed_871f_dcfb48751facrow10_col0" class="data row10 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_69252ce4_5ad2_11ed_871f_dcfb48751faclevel0_row11" class="row_heading level0 row11" >RC3</th>
#                         <td id="T_69252ce4_5ad2_11ed_871f_dcfb48751facrow11_col0" class="data row11 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_69252ce4_5ad2_11ed_871f_dcfb48751faclevel0_row12" class="row_heading level0 row12" >Data</th>
#                         <td id="T_69252ce4_5ad2_11ed_871f_dcfb48751facrow12_col0" class="data row12 col0" >0.000000</td>
#             </tr>
#     </tbody></table>

# %%
df.describe().T
# Out:
#         count       mean       std    min    25%    50%    75%    max
# RC3    5561.0  23.013181  5.483241   5.60  18.10  23.50  27.50  39.50
# RC7    5560.0  31.455960  6.443364   8.90  25.70  32.20  36.70  51.40
# RC28   5561.0  47.585197  6.948911  28.10  41.60  48.80  52.80  64.00
# AL2O3  5450.0   3.779171  0.412620   1.39   3.47   3.78   4.05   5.92
# CAOT   5450.0  56.277451  1.743092   5.89  55.37  56.05  57.14  62.82
# K2O    5448.0   0.279939  0.774718   0.02   0.22   0.26   0.31  57.06
# MGO    5457.0   6.037064  0.916290   0.29   5.78   6.07   6.35  61.10
# SIO2   5450.0  16.060031  1.260572   0.00  15.27  16.39  16.97  20.37
# FE2O3  5450.0   3.722193  0.534989   1.70   3.32   3.67   4.07  16.70
# SO3    5464.0   2.682041  0.237515   0.60   2.54   2.67   2.81   4.41
# P2O5   5432.0   0.905431  0.127136   0.00   0.84   0.91   0.98   2.91
# RC1    3185.0  11.973802  2.926278   1.80  10.20  12.30  14.00  21.70

# %%
df_cpiif32.describe().T
# Out:
#         count       mean       std    min    25%    50%    75%    max
# RC3    3774.0  20.359028  4.374606   5.60  17.00  19.50  23.90  34.50
# RC7    3773.0  28.305484  5.115720   8.90  24.40  27.40  32.60  43.20
# RC28   3774.0  44.230742  5.643229  28.10  39.10  44.90  49.00  59.30
# AL2O3  3685.0   3.627775  0.362145   2.68   3.36   3.61   3.86   5.92
# CAOT   3685.0  55.892499  1.621989   5.89  55.13  55.84  56.59  61.97
# K2O    3683.0   0.281852  0.939208   0.10   0.23   0.26   0.30  57.06
# MGO    3689.0   6.064888  0.568579   0.29   5.80   6.12   6.41   8.11
# SIO2   3685.0  15.732404  1.301391   2.66  14.53  16.02  16.77  20.37
# FE2O3  3685.0   3.751788  0.611057   1.70   3.27   3.66   4.24  16.70
# SO3    3696.0   2.668872  0.226915   0.60   2.54   2.65   2.77   4.41
# P2O5   3676.0   0.893934  0.130447   0.00   0.82   0.89   0.97   1.60
# RC1    1398.0   9.894406  2.669098   1.80   7.70  10.00  11.90  18.40

# %%
df_cpiif40.describe().T
# Out:
#         count       mean       std    min      25%    50%    75%    max
# RC3    1787.0  28.618539  2.616630  19.60  26.9000  28.70  30.30  39.50
# RC7    1787.0  38.107750  2.951655  28.20  36.1000  38.10  40.10  51.40
# RC28   1787.0  54.669536  3.008993  43.50  52.5000  54.30  56.70  64.00
# AL2O3  1765.0   4.095258  0.322759   1.39   3.8700   4.09   4.33   5.24
# CAOT   1765.0  57.081161  1.713270  28.23  55.8300  56.64  58.18  62.82
# K2O    1765.0   0.275949  0.109753   0.02   0.1600   0.29   0.35   0.64
# MGO    1768.0   5.979010  1.382999   2.85   5.7100   6.01   6.21  61.10
# SIO2   1765.0  16.744057  0.824106   0.00  16.3500  16.81  17.20  19.95
# FE2O3  1765.0   3.660402  0.314106   2.61   3.4400   3.67   3.88   6.24
# SO3    1768.0   2.709570  0.256160   0.72   2.5575   2.71   2.87   3.72
# P2O5   1756.0   0.929499  0.116321   0.51   0.8700   0.93   0.99   2.91
# RC1    1787.0  13.600548  1.913417   6.60  12.3000  13.60  14.70  21.70

# %% [markdown]
# ### Sort the dataset by date

# %%
df = df.sort_values(by="Data")
df_cpiif32 = df_cpiif32.sort_values(by="Data")
df_cpiif40 = df_cpiif40.sort_values(by="Data")

# %% [markdown]
# ## Saving the dataset

# %% [markdown]
# <h3>Saving for feature engineering</h3>

# %%
df.to_csv("../../../data/interim/Inter/cement-shipping.csv", index=False)
df_cpiif32.to_csv("../../../data/interim/Inter/cpiif32.csv", index=False)
df_cpiif40.to_csv("../../../data/interim/Inter/cpiif40.csv", index=False)
