# %%
# %load_ext nb_black

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

from scipy.stats import pearsonr
from collections import Counter

# %%
def convert_to_float(value):
    try:
        # If it's a string enclosed in single quotes, remove quotes and replace comma with dot
        if isinstance(value, str):
            return float(value.replace(",", "."))
        else:
            return float(value)
    except ValueError as e:
        print(e)
        return float("nan")

# %%
def preprocess_numeric_cols(df, columns):
    for col in columns:
        df[col] = df[col].astype(str)  # Ensure string type for string operations
        df[col] = df[col].str.replace("#", "")  # Remove '#' characters
        df[col] = df[col].str.replace(",", ".")  # Replace ',' with '.' for decimals
    return df

# %% [markdown]
# # Data preparation - 209 plant N data

# %% [markdown]
# ### Reading the files and extracting relevant information:

# %%
plant = "N"
xls_files = {}

xls = pd.ExcelFile(
    f"../../../data/raw/209/EMBRAPII hubIC IACC_CIMENTO_{plant}.xlsx",
    engine="openpyxl",
)
xls_files[plant] = xls

# %%
print("Plant: ", plant, xls.sheet_names)
# Out:
# Plant:  N ['INSTRUÇÕES', 'Clínquer', '80', '66', '94']

# %%
cement_types_per_plant = []
CEMENT_TYPE_COLS = ["Tipo de cimento", "Classe de resistência"]
dataframes = []

for plant, xls in xls_files.items():
    for sheet_name in xls.sheet_names[2:]:
        df = pd.read_excel(xls_files[plant], sheet_name, header=[1, 2])

        if not df[CEMENT_TYPE_COLS].iloc[2:].isna().all().all():
            cement_type = (
                df[CEMENT_TYPE_COLS]
                .loc[2:]
                .astype(str)
                .sum(axis=1)
                .str.replace(" ", "")
                .str.replace("-", "")
                .str.replace("nan", "")
                .unique()
            )

        else:
            cement_type = (
                df[[("Obs.", "Unnamed: 8_level_1")]]
                .loc[2:]
                .astype(str)
                .sum(axis=1)
                .str.replace(" ", "")
                .str.replace("-", "")
                .unique()
            )

        cement_types_per_plant.append((plant, sheet_name, cement_type))
        dataframes.append(df)

# %%
cement_types_per_plant
# Out:
# [('N', '80', array(['CPIIF40'], dtype=object)),
#  ('N', '66', array(['CPIIF32'], dtype=object)),
#  ('N', '94', array(['CPVARI'], dtype=object))]

# %%
cements = []
for tup in cement_types_per_plant:
    cements.append(tup[2][0])
Counter(cements)
# Out:
# Counter({'CPIIF40': 1, 'CPIIF32': 1, 'CPVARI': 1})

# %%
dataframes = []

for plant, xls in xls_files.items():
    for sheet_name in xls.sheet_names[2:]:
        df = pd.read_excel(xls_files[plant], sheet_name, header=[0, 1, 2])
        df["Unnamed: 0_level_0", "Unnamed: 0_level_1", "Unnamed: 0_level_2"] = plant
        dataframes.append(df.drop([0, 1], axis=0).reset_index(drop=True).copy())

# %%
df = pd.concat(dataframes, axis=0).reset_index(drop=True)

# %% [markdown]
# ## Initial Preprocessing

# %%
df = pd.concat(
    [
        df["Unnamed: 0_level_0", "Unnamed: 0_level_1", "Unnamed: 0_level_2"],
        df["Dados iniciais"],
        df["Cimento"]["Composição"].rename(
            {"Sulfato de cálcio": "Sulfato de cálcio (composição)"}, axis=1
        ),
        df["Cimento"]["Análise mineralógica"],
        df["Cimento"]["Análise química"],
        df["Característias físicas do cimento"],
        df["Propriedades do cimento"],
    ],
    axis=1,
)

# %%
# df.info()

# %% [markdown]
# ### 1. Dropping columns where either there is no data nor it contributes to the analysis
# ### 2. Renaming columns to a short identifiable name

# %%
COLUMNS_TO_DROP = [
    ("Data", "Medida"),
    ("Horário", "Produção"),
    ("Horário", "Medida"),
    ("Obs.", "Unnamed: 148_level_2"),
    ("Tipo de cimento", "Unnamed: 6_level_2"),
    ("Classe de resistência", "Unnamed: 7_level_2"),
    ("Obs.", "Unnamed: 8_level_2"),
    "Obs.",
    ("Obs.", "Unnamed: 148_level_2"),
    ("Unnamed: 141_level_1", "Obs."),
    # ("Unnamed: 139_level_1", "#400"),
]

COLUMNS_TO_RENAME = {
    ("Unnamed: 0_level_0", "Unnamed: 0_level_1", "Unnamed: 0_level_2"): "Plant",
    ("Cidade", "Unnamed: 1_level_2"): "City",
    ("Data", "Produção"): "Date",  # Arrumar!
    ("Unnamed: 136_level_1", "Blaine"): "Blaine",
    ("Unnamed: 137_level_1", "#200"): "#200",
    ("Unnamed: 138_level_1", "#325"): "#325",
    ("Unnamed: 139_level_1", "#400"): "#400",
    ("Unnamed: 140_level_1", "Massa específica"): "Specific Gravity",
    ("Tempo de pega", "Inicio"): "Initial setting time",
    ("Tempo de pega", "Fim"): "Final setting time",
    ("Resistência à compressão", "1 d"): "CS1",
    ("Resistência à compressão", "3 d"): "CS3",
    ("Resistência à compressão", "7 d"): "CS7",
    ("Resistência à compressão", "28 d"): "CS28",
    "Perda ao fogo": "Loss on Ignition",
    "Resíduo insolúvel": "Insoluble Residue",
    "Clínquer": "Clinker",
    "Fíler calcário": "Calcareous filler",
    "Cinza volante": "Fly ash",
    "Escória": "Slag",
    "Argila calcinada": "Calcined clay",
    "Sulfato de cálcio": "Calcium sulfate",
    "C3S total": "Total C3S",
    "C2S total": "Total C2S",
    "C2S alpha": "Alpha C2S",
    "C2S beta": "Beta C2S",
    "C2S gama": "Gamma C2S",
    "C4AF": "C4AF",
    "C3A": "C3A",
    "C3A cubic": "Cubic C3A",
    "C3A orto": "Orthorhombic C3A",
    "CaO livre": "Free CaO",
    "Portlandita": "Portlandite",
    "Periclasio": "Periclase",
    "Arcanita": "Arcanite",
    "Aphthalita": "Aphthitalite",
    "Langbeinita": "Langbeinite",
    "Bassanita": "Bassanite",
    "Anidrita": "Anhydrite",
    "Calcita": "Calcite",
    "Dolomita": "Dolomite",
    "Quartzo": "Quartz",
    "Muscovita": "Muscovite",
    "Sulfato de cálcio (composição)": "Calcium sulfate (composition)",
}

# %% [markdown]
# ### Defining a single variable to identify Cement Type

# %%
# Single variable for the Cement Type
df["Cement_Type"] = (
    df[
        [
            ("Tipo de cimento", "Unnamed: 6_level_2"),
            ("Classe de resistência", "Unnamed: 7_level_2"),
            ("Obs.", "Unnamed: 8_level_2"),
        ]
    ]
    .fillna("")
    .astype(str)
    .sum(axis=1)
)

# # Preprocessing
df["Cement_Type"] = df["Cement_Type"].replace("Fibro", "Fibrocimento")

# Preprocessing
df["Cement_Type"] = (
    df["Cement_Type"]
    .str.replace("Expedido", "")
    .str.replace("Linha 9", "")
    .str.replace("Itajaí", "")
    .str.replace("D-G", "")
    .str.replace("D-E", "")
    .str.replace("DF2", "")
    .str.replace("CPIIF40", "CP II-F-40")
    .str.replace("CPIIF40", "CP II-F40")
    .str.replace("CP VARI", "CP V-ARI")
    .str.replace("CPVARI", "CP V-ARI")
    .str.replace("CP V-RSARI", "CP V-ARI RS")
    .str.replace("CP III-RS40", "CP III-40 RS")
    .str.replace("CP III-RS32", "CP III-32 RS")
    .str.replace("CP IV-RS32", "CP IV-32 RS")
    .str.replace("CP III40", "CP III-40")
    .str.replace("CP III32", "CP III-32")
    .str.replace("CP I-S40", "CP I-S-40")
    .str.replace("CP I40", "CP I-40")
    .str.replace("CP II-E32", "CP II-E-32")
    .str.replace("CP II-E40", "CP II-E-40")
    .str.replace("CP II-F FIBRO40", "CP II-F-40")
    .str.replace("CP II-F32", "CP II-F-32")
    .str.replace("CP II-F40", "CP II-F-40")
    .str.replace("CP II-Z32", "CP II-Z-32")
    .str.replace("CP II-Z40", "CP II-Z-40")
    .str.replace("CP IV32", "CP IV-32")
    .str.replace("CP IND", "CP I")
    .str.replace("CPINDCC", "CP I")
    .str.strip()
)

df = df.drop(COLUMNS_TO_DROP, axis=1).rename(COLUMNS_TO_RENAME, axis=1).copy()
df = df.drop([0]).reset_index(drop=True)
df = df.infer_objects()

# %% [markdown]
# ### Dropping and rename the columns defined above

# %% [markdown]
# ### Cleaning and converting numeric columns to float

# %%
NUMERIC_COLUMNS = [
    "Calcium sulfate (composition)",
    "Clinker",
    "Calcareous filler",
    "Fly ash",
    "Slag",
    "Calcined clay",
    "Calcium sulfate",
    "Total C3S",
    "Total C2S",
    "Alpha C2S",
    "Beta C2S",
    "Gamma C2S",
    "C4AF",
    "C3A",
    "Cubic C3A",
    "Orthorhombic C3A",
    "Free CaO",
    "Portlandite",
    "Periclase",
    "Arcanite",
    "Aphthitalite",
    "Langbeinite",
    "Bassanite",
    "Anhydrite",
    "Calcite",
    "Dolimita",
    "Quartz",
    "Muscovite",
    "CaO",
    "MgO",
    "Na2O",
    "Al2O3",
    "SiO2",
    "SO3",
    "K2O",
    "TiO2",
    "Fe2O3",
    "Loss on Ignition",
    "Insoluble Residue",
    "Blaine",
    "#200",
    "#325",
    "#400",
    "Specific Gravity",
    "Final setting time",
    "Initial setting time",
    "CS1",
    "CS3",
    "CS7",
    "CS28",
]

df = preprocess_numeric_cols(df, NUMERIC_COLUMNS)

# Preprocessing to fix numeric columns
df[NUMERIC_COLUMNS] = df[NUMERIC_COLUMNS].map(convert_to_float)

# Converting Date to pandas datetime
df["Date"] = pd.to_datetime(df["Date"])

# Drop rows completely missing
index_to_keep = (
    df.drop(["Plant", "Date", "Cement_Type"], axis=1).dropna(axis=0, how="all").index
)
df = df.iloc[index_to_keep].reset_index(drop=True)

df = df.infer_objects()
# Out:
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '

# %% [markdown]
# ## Dropping missing features

# %% [markdown]
# ### Drop rows completely missing

# %%
index_to_keep = (
    df.drop(["Plant", "City", "Date", "Cement_Type"], axis=1)
    .dropna(axis=0, how="all")
    .index
)
df = df.iloc[index_to_keep].reset_index(drop=True)

# %% [markdown]
# ### Removing features
#  that will be fitted on this data.
#
# 1. Removing features with features having ~50% or more of missing values
# 2. Removing features with zero variance
# 3. Removing features with more than 70% of zeros

# %%
(df.isna().sum() / df.shape[0] * 100).sort_values(ascending=False).to_frame(
    name="Missing (%)"
).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_610c0_row0_col0, #T_610c0_row1_col0, #T_610c0_row2_col0, #T_610c0_row3_col0, #T_610c0_row4_col0, #T_610c0_row5_col0, #T_610c0_row6_col0, #T_610c0_row7_col0, #T_610c0_row8_col0, #T_610c0_row9_col0, #T_610c0_row10_col0, #T_610c0_row11_col0, #T_610c0_row12_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_610c0_row13_col0, #T_610c0_row14_col0, #T_610c0_row15_col0, #T_610c0_row16_col0 {
#   background-color: #d42121;
#   color: #f1f1f1;
# }
# #T_610c0_row17_col0 {
#   background-color: #fc7f5f;
#   color: #f1f1f1;
# }
# #T_610c0_row18_col0 {
#   background-color: #fc997a;
#   color: #000000;
# }
# #T_610c0_row19_col0 {
#   background-color: #fcc2aa;
#   color: #000000;
# }
# #T_610c0_row20_col0 {
#   background-color: #fdd3c1;
#   color: #000000;
# }
# #T_610c0_row21_col0, #T_610c0_row22_col0 {
#   background-color: #fdd7c6;
#   color: #000000;
# }
# #T_610c0_row23_col0, #T_610c0_row24_col0, #T_610c0_row25_col0, #T_610c0_row26_col0, #T_610c0_row27_col0, #T_610c0_row28_col0, #T_610c0_row29_col0 {
#   background-color: #fed9c9;
#   color: #000000;
# }
# #T_610c0_row30_col0 {
#   background-color: #fff0e9;
#   color: #000000;
# }
# #T_610c0_row31_col0 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_610c0_row32_col0, #T_610c0_row33_col0, #T_610c0_row34_col0, #T_610c0_row35_col0, #T_610c0_row36_col0, #T_610c0_row37_col0, #T_610c0_row38_col0, #T_610c0_row39_col0, #T_610c0_row40_col0, #T_610c0_row41_col0, #T_610c0_row42_col0, #T_610c0_row43_col0, #T_610c0_row44_col0, #T_610c0_row45_col0, #T_610c0_row46_col0, #T_610c0_row47_col0, #T_610c0_row48_col0, #T_610c0_row49_col0, #T_610c0_row50_col0, #T_610c0_row51_col0, #T_610c0_row52_col0, #T_610c0_row53_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_610c0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_610c0_level0_col0" class="col_heading level0 col0" >Missing (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_610c0_level0_row0" class="row_heading level0 row0" >Specific Gravity</th>
#       <td id="T_610c0_row0_col0" class="data row0 col0" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_610c0_level0_row1" class="row_heading level0 row1" >Muscovite</th>
#       <td id="T_610c0_row1_col0" class="data row1 col0" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_610c0_level0_row2" class="row_heading level0 row2" >CS1</th>
#       <td id="T_610c0_row2_col0" class="data row2 col0" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_610c0_level0_row3" class="row_heading level0 row3" >Clinker</th>
#       <td id="T_610c0_row3_col0" class="data row3 col0" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_610c0_level0_row4" class="row_heading level0 row4" >Calcareous filler</th>
#       <td id="T_610c0_row4_col0" class="data row4 col0" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_610c0_level0_row5" class="row_heading level0 row5" >Fly ash</th>
#       <td id="T_610c0_row5_col0" class="data row5 col0" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_610c0_level0_row6" class="row_heading level0 row6" >Slag</th>
#       <td id="T_610c0_row6_col0" class="data row6 col0" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_610c0_level0_row7" class="row_heading level0 row7" >Calcined clay</th>
#       <td id="T_610c0_row7_col0" class="data row7 col0" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_610c0_level0_row8" class="row_heading level0 row8" >Calcium sulfate</th>
#       <td id="T_610c0_row8_col0" class="data row8 col0" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_610c0_level0_row9" class="row_heading level0 row9" >Anhydrite</th>
#       <td id="T_610c0_row9_col0" class="data row9 col0" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_610c0_level0_row10" class="row_heading level0 row10" >Alpha C2S</th>
#       <td id="T_610c0_row10_col0" class="data row10 col0" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_610c0_level0_row11" class="row_heading level0 row11" >Beta C2S</th>
#       <td id="T_610c0_row11_col0" class="data row11 col0" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_610c0_level0_row12" class="row_heading level0 row12" >Gamma C2S</th>
#       <td id="T_610c0_row12_col0" class="data row12 col0" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_610c0_level0_row13" class="row_heading level0 row13" >C3A</th>
#       <td id="T_610c0_row13_col0" class="data row13 col0" >71.696150</td>
#     </tr>
#     <tr>
#       <th id="T_610c0_level0_row14" class="row_heading level0 row14" >Total C2S</th>
#       <td id="T_610c0_row14_col0" class="data row14 col0" >71.696150</td>
#     </tr>
#     <tr>
#       <th id="T_610c0_level0_row15" class="row_heading level0 row15" >Total C3S</th>
#       <td id="T_610c0_row15_col0" class="data row15 col0" >71.696150</td>
#     </tr>
#     <tr>
#       <th id="T_610c0_level0_row16" class="row_heading level0 row16" >Calcium sulfate (composition)</th>
#       <td id="T_610c0_row16_col0" class="data row16 col0" >71.696150</td>
#     </tr>
#     <tr>
#       <th id="T_610c0_level0_row17" class="row_heading level0 row17" >Quartz</th>
#       <td id="T_610c0_row17_col0" class="data row17 col0" >43.496358</td>
#     </tr>
#     <tr>
#       <th id="T_610c0_level0_row18" class="row_heading level0 row18" >Periclase</th>
#       <td id="T_610c0_row18_col0" class="data row18 col0" >35.483871</td>
#     </tr>
#     <tr>
#       <th id="T_610c0_level0_row19" class="row_heading level0 row19" >Bassanite</th>
#       <td id="T_610c0_row19_col0" class="data row19 col0" >22.684703</td>
#     </tr>
#     <tr>
#       <th id="T_610c0_level0_row20" class="row_heading level0 row20" >Aphthitalite</th>
#       <td id="T_610c0_row20_col0" class="data row20 col0" >16.857440</td>
#     </tr>
#     <tr>
#       <th id="T_610c0_level0_row21" class="row_heading level0 row21" >Langbeinite</th>
#       <td id="T_610c0_row21_col0" class="data row21 col0" >15.712799</td>
#     </tr>
#     <tr>
#       <th id="T_610c0_level0_row22" class="row_heading level0 row22" >Portlandite</th>
#       <td id="T_610c0_row22_col0" class="data row22 col0" >15.712799</td>
#     </tr>
#     <tr>
#       <th id="T_610c0_level0_row23" class="row_heading level0 row23" >Arcanite</th>
#       <td id="T_610c0_row23_col0" class="data row23 col0" >15.192508</td>
#     </tr>
#     <tr>
#       <th id="T_610c0_level0_row24" class="row_heading level0 row24" >Dolimita</th>
#       <td id="T_610c0_row24_col0" class="data row24 col0" >15.192508</td>
#     </tr>
#     <tr>
#       <th id="T_610c0_level0_row25" class="row_heading level0 row25" >C4AF</th>
#       <td id="T_610c0_row25_col0" class="data row25 col0" >15.192508</td>
#     </tr>
#     <tr>
#       <th id="T_610c0_level0_row26" class="row_heading level0 row26" >Cubic C3A</th>
#       <td id="T_610c0_row26_col0" class="data row26 col0" >15.192508</td>
#     </tr>
#     <tr>
#       <th id="T_610c0_level0_row27" class="row_heading level0 row27" >Calcite</th>
#       <td id="T_610c0_row27_col0" class="data row27 col0" >15.192508</td>
#     </tr>
#     <tr>
#       <th id="T_610c0_level0_row28" class="row_heading level0 row28" >Orthorhombic C3A</th>
#       <td id="T_610c0_row28_col0" class="data row28 col0" >15.192508</td>
#     </tr>
#     <tr>
#       <th id="T_610c0_level0_row29" class="row_heading level0 row29" >Free CaO</th>
#       <td id="T_610c0_row29_col0" class="data row29 col0" >15.192508</td>
#     </tr>
#     <tr>
#       <th id="T_610c0_level0_row30" class="row_heading level0 row30" >CS28</th>
#       <td id="T_610c0_row30_col0" class="data row30 col0" >3.017690</td>
#     </tr>
#     <tr>
#       <th id="T_610c0_level0_row31" class="row_heading level0 row31" >CS7</th>
#       <td id="T_610c0_row31_col0" class="data row31 col0" >0.624350</td>
#     </tr>
#     <tr>
#       <th id="T_610c0_level0_row32" class="row_heading level0 row32" >Insoluble Residue</th>
#       <td id="T_610c0_row32_col0" class="data row32 col0" >0.312175</td>
#     </tr>
#     <tr>
#       <th id="T_610c0_level0_row33" class="row_heading level0 row33" >Loss on Ignition</th>
#       <td id="T_610c0_row33_col0" class="data row33 col0" >0.312175</td>
#     </tr>
#     <tr>
#       <th id="T_610c0_level0_row34"

# %%
for var, val in (
    (df.isna().sum() / df.shape[0] * 100).sort_values(ascending=False).items()
):
    s = f"""<tr>
        <td>{var}</td>
        <td>{round(val, 2)}</td>
    </tr>"""
    if val >= 40:
        # print(s)
        print(f'"{var}",')
# Out:
# "Specific Gravity",
# "Muscovite",
# "CS1",
# "Clinker",
# "Calcareous filler",
# "Fly ash",
# "Slag",
# "Calcined clay",
# "Calcium sulfate",
# "Anhydrite",
# "Alpha C2S",
# "Beta C2S",
# "Gamma C2S",
# "C3A",
# "Total C2S",
# "Total C3S",
# "Calcium sulfate (composition)",
# "Quartz",

# %% [markdown]
# <h3>Percentage of missing values:</h3>
# <table>
#     <th>Plant N - Full Dataset:</th>
#     <th></th>
#     <tr>
#             <td>Specific Gravity</td>
#             <td>100.0</td>
#         </tr>
#     <tr>
#             <td>Muscovite</td>
#             <td>100.0</td>
#         </tr>
#     <tr>
#             <td>CS1</td>
#             <td>100.0</td>
#         </tr>
#     <tr>
#             <td>Clinker</td>
#             <td>100.0</td>
#         </tr>
#     <tr>
#             <td>Calcareous filler</td>
#             <td>100.0</td>
#         </tr>
#     <tr>
#             <td>Fly ash</td>
#             <td>100.0</td>
#         </tr>
#     <tr>
#             <td>Slag</td>
#             <td>100.0</td>
#         </tr>
#     <tr>
#             <td>Calcined clay</td>
#             <td>100.0</td>
#         </tr>
#     <tr>
#             <td>Calcium sulfate</td>
#             <td>100.0</td>
#         </tr>
#     <tr>
#             <td>Anhydrite</td>
#             <td>100.0</td>
#         </tr>
#     <tr>
#             <td>Alpha C2S</td>
#             <td>100.0</td>
#         </tr>
#     <tr>
#             <td>Beta C2S</td>
#             <td>100.0</td>
#         </tr>
#     <tr>
#             <td>Gamma C2S</td>
#             <td>100.0</td>
#         </tr>
#     <tr>
#             <td>C3A</td>
#             <td>71.7</td>
#         </tr>
#     <tr>
#             <td>Total C2S</td>
#             <td>71.7</td>
#         </tr>
#     <tr>
#             <td>Total C3S</td>
#             <td>71.7</td>
#         </tr>
#     <tr>
#             <td>Calcium sulfate (composition)</td>
#             <td>71.7</td>
#         </tr>
#     <tr>
#         <td>Quartz</td>
#         <td>43.5</td>
#     </tr>
# </table>

# %%
FEATRUES_TO_DROP = [
    "Specific Gravity",
    "Muscovite",
    "CS1",
    "Clinker",
    "Calcareous filler",
    "Fly ash",
    "Slag",
    "Calcined clay",
    "Calcium sulfate",
    "Anhydrite",
    "Alpha C2S",
    "Beta C2S",
    "Gamma C2S",
    "C3A",
    "Total C2S",
    "Total C3S",
    "Calcium sulfate (composition)",
    "Quartz",
]
df = df.drop(labels=FEATRUES_TO_DROP, axis=1)

# %% [markdown]
# ### Removing features with more than 23% of zeros

# %%
zero_values = {}
for col in df.select_dtypes(include="number").columns:
    zero_percentages = (df[df[col].eq(0)].shape[0] / df.shape[0]) * 100
    zero_values[col] = zero_percentages

zero_percentages = pd.Series(zero_values, name=f"Zero (%) for {plant}")
zero_percentages = zero_percentages.sort_values(ascending=False)
zero_percentages = zero_percentages.to_frame(name=f"Zero (%) for {plant}")
zero_percentages.style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_16353_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_16353_row1_col0 {
#   background-color: #db2824;
#   color: #f1f1f1;
# }
# #T_16353_row2_col0 {
#   background-color: #fdd5c4;
#   color: #000000;
# }
# #T_16353_row3_col0 {
#   background-color: #fee9df;
#   color: #000000;
# }
# #T_16353_row4_col0 {
#   background-color: #feeae1;
#   color: #000000;
# }
# #T_16353_row5_col0 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_16353_row6_col0 {
#   background-color: #fff2ec;
#   color: #000000;
# }
# #T_16353_row7_col0, #T_16353_row8_col0, #T_16353_row9_col0, #T_16353_row10_col0, #T_16353_row11_col0, #T_16353_row12_col0, #T_16353_row13_col0, #T_16353_row14_col0, #T_16353_row15_col0, #T_16353_row16_col0, #T_16353_row17_col0, #T_16353_row18_col0, #T_16353_row19_col0, #T_16353_row20_col0, #T_16353_row21_col0, #T_16353_row22_col0, #T_16353_row23_col0, #T_16353_row24_col0, #T_16353_row25_col0, #T_16353_row26_col0, #T_16353_row27_col0, #T_16353_row28_col0, #T_16353_row29_col0, #T_16353_row30_col0, #T_16353_row31_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_16353">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_16353_level0_col0" class="col_heading level0 col0" >Zero (%) for N</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_16353_level0_row0" class="row_heading level0 row0" >#200</th>
#       <td id="T_16353_row0_col0" class="data row0 col0" >56.295525</td>
#     </tr>
#     <tr>
#       <th id="T_16353_level0_row1" class="row_heading level0 row1" >Dolimita</th>
#       <td id="T_16353_row1_col0" class="data row1 col0" >39.125911</td>
#     </tr>
#     <tr>
#       <th id="T_16353_level0_row2" class="row_heading level0 row2" >Langbeinite</th>
#       <td id="T_16353_row2_col0" class="data row2 col0" >9.157128</td>
#     </tr>
#     <tr>
#       <th id="T_16353_level0_row3" class="row_heading level0 row3" >Orthorhombic C3A</th>
#       <td id="T_16353_row3_col0" class="data row3 col0" >4.162331</td>
#     </tr>
#     <tr>
#       <th id="T_16353_level0_row4" class="row_heading level0 row4" >Aphthitalite</th>
#       <td id="T_16353_row4_col0" class="data row4 col0" >3.642040</td>
#     </tr>
#     <tr>
#       <th id="T_16353_level0_row5" class="row_heading level0 row5" >#325</th>
#       <td id="T_16353_row5_col0" class="data row5 col0" >2.809573</td>
#     </tr>
#     <tr>
#       <th id="T_16353_level0_row6" class="row_heading level0 row6" >Arcanite</th>
#       <td id="T_16353_row6_col0" class="data row6 col0" >1.040583</td>
#     </tr>
#     <tr>
#       <th id="T_16353_level0_row7" class="row_heading level0 row7" >Bassanite</th>
#       <td id="T_16353_row7_col0" class="data row7 col0" >0.208117</td>
#     </tr>
#     <tr>
#       <th id="T_16353_level0_row8" class="row_heading level0 row8" >#400</th>
#       <td id="T_16353_row8_col0" class="data row8 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_16353_level0_row9" class="row_heading level0 row9" >Loss on Ignition</th>
#       <td id="T_16353_row9_col0" class="data row9 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_16353_level0_row10" class="row_heading level0 row10" >Insoluble Residue</th>
#       <td id="T_16353_row10_col0" class="data row10 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_16353_level0_row11" class="row_heading level0 row11" >Blaine</th>
#       <td id="T_16353_row11_col0" class="data row11 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_16353_level0_row12" class="row_heading level0 row12" >C4AF</th>
#       <td id="T_16353_row12_col0" class="data row12 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_16353_level0_row13" class="row_heading level0 row13" >Initial setting time</th>
#       <td id="T_16353_row13_col0" class="data row13 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_16353_level0_row14" class="row_heading level0 row14" >TiO2</th>
#       <td id="T_16353_row14_col0" class="data row14 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_16353_level0_row15" class="row_heading level0 row15" >Final setting time</th>
#       <td id="T_16353_row15_col0" class="data row15 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_16353_level0_row16" class="row_heading level0 row16" >CS3</th>
#       <td id="T_16353_row16_col0" class="data row16 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_16353_level0_row17" class="row_heading level0 row17" >CS7</th>
#       <td id="T_16353_row17_col0" class="data row17 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_16353_level0_row18" class="row_heading level0 row18" >Fe2O3</th>
#       <td id="T_16353_row18_col0" class="data row18 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_16353_level0_row19" class="row_heading level0 row19" >SiO2</th>
#       <td id="T_16353_row19_col0" class="data row19 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_16353_level0_row20" class="row_heading level0 row20" >K2O</th>
#       <td id="T_16353_row20_col0" class="data row20 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_16353_level0_row21" class="row_heading level0 row21" >SO3</th>
#       <td id="T_16353_row21_col0" class="data row21 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_16353_level0_row22" class="row_heading level0 row22" >Cubic C3A</th>
#       <td id="T_16353_row22_col0" class="data row22 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_16353_level0_row23" class="row_heading level0 row23" >Al2O3</th>
#       <td id="T_16353_row23_col0" class="data row23 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_16353_level0_row24" class="row_heading level0 row24" >Na2O</th>
#       <td id="T_16353_row24_col0" class="data row24 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_16353_level0_row25" class="row_heading level0 row25" >MgO</th>
#       <td id="T_16353_row25_col0" class="data row25 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_16353_level0_row26" class="row_heading level0 row26" >CaO</th>
#       <td id="T_16353_row26_col0" class="data row26 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_16353_level0_row27" class="row_heading level0 row27" >Calcite</th>
#       <td id="T_16353_row27_col0" class="data row27 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_16353_level0_row28" class="row_heading level0 row28" >Periclase</th>
#       <td id="T_16353_row28_col0" class="data row28 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_16353_level0_row29" class="row_heading level0 row29" >Portlandite</th>
#       <td id="T_16353_row29_col0" class="data row29 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_16353_level0_row30" class="row_heading level0 row30" >Free CaO</th>
#       <td id="T_16353_row30_col0" class="data row30 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_16353_level0_row31" class="row_heading level0 row31" >CS28</th>
#       <td id="T_16353_row31_col0" class="data row31 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <h3>Percentage of zero values:</h3>
# <table>
#     <th>Plant A - Full Dataset:</th>
#     <th></th>
#     <tr>
#         <td>#200</td>
#         <td>56.30</td>
#     </tr>
#     <tr>
#         <td>Dolimita</td>
#         <td>39.13</td>
#     </tr>
#     <tr>
#         <td>Langbeinite</td>
#         <td>9.16</td>
#     </tr>
# </table>

# %%
FEATRUES_TO_DROP = ["Dolimita", "Langbeinite", "#200"]
df = df.drop(labels=FEATRUES_TO_DROP, axis=1)

# %% [markdown]
# ### Dropping variable with City and Plant identification

# %%
FEATRUES_TO_DROP = ["City", "Plant"]
df = df.drop(labels=FEATRUES_TO_DROP, axis=1)

# %% [markdown]
# ### Dropping rows where the target variable is null

# %%
df = df[df["CS28"].notna()]

# %% [markdown]
# ### Dropping rows where the target variable is zero

# %%
df = df[~df["CS28"].eq(0)]

# %%
df.shape
# Out:
# (932, 31)

# %%
# df.describe().T

# %%
# df_copy = df.copy()

# %% [markdown]
# ### Dropping rows where any other variable has a zero value

# %%
for col in df.columns:
    df = df[~df[col].eq(0)]

# %%
df.shape
# Out:
# (841, 31)

# %%
(df.isna().sum() / df.shape[0] * 100).sort_values(ascending=False).to_frame(
    name="Missing (%)"
).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_fb8d3_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_fb8d3_row1_col0 {
#   background-color: #db2824;
#   color: #f1f1f1;
# }
# #T_fb8d3_row2_col0 {
#   background-color: #fb6d4d;
#   color: #f1f1f1;
# }
# #T_fb8d3_row3_col0 {
#   background-color: #fb7b5b;
#   color: #f1f1f1;
# }
# #T_fb8d3_row4_col0, #T_fb8d3_row5_col0, #T_fb8d3_row6_col0, #T_fb8d3_row7_col0, #T_fb8d3_row8_col0, #T_fb8d3_row9_col0 {
#   background-color: #fc8060;
#   color: #f1f1f1;
# }
# #T_fb8d3_row10_col0, #T_fb8d3_row11_col0 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_fb8d3_row12_col0, #T_fb8d3_row13_col0, #T_fb8d3_row14_col0, #T_fb8d3_row15_col0, #T_fb8d3_row16_col0, #T_fb8d3_row17_col0, #T_fb8d3_row18_col0, #T_fb8d3_row19_col0, #T_fb8d3_row20_col0 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_fb8d3_row21_col0, #T_fb8d3_row22_col0, #T_fb8d3_row23_col0, #T_fb8d3_row24_col0, #T_fb8d3_row25_col0, #T_fb8d3_row26_col0, #T_fb8d3_row27_col0, #T_fb8d3_row28_col0, #T_fb8d3_row29_col0, #T_fb8d3_row30_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_fb8d3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fb8d3_level0_col0" class="col_heading level0 col0" >Missing (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fb8d3_level0_row0" class="row_heading level0 row0" >Periclase</th>
#       <td id="T_fb8d3_row0_col0" class="data row0 col0" >32.580262</td>
#     </tr>
#     <tr>
#       <th id="T_fb8d3_level0_row1" class="row_heading level0 row1" >Bassanite</th>
#       <td id="T_fb8d3_row1_col0" class="data row1 col0" >22.592152</td>
#     </tr>
#     <tr>
#       <th id="T_fb8d3_level0_row2" class="row_heading level0 row2" >Aphthitalite</th>
#       <td id="T_fb8d3_row2_col0" class="data row2 col0" >15.933413</td>
#     </tr>
#     <tr>
#       <th id="T_fb8d3_level0_row3" class="row_heading level0 row3" >Portlandite</th>
#       <td id="T_fb8d3_row3_col0" class="data row3 col0" >14.625446</td>
#     </tr>
#     <tr>
#       <th id="T_fb8d3_level0_row4" class="row_heading level0 row4" >Cubic C3A</th>
#       <td id="T_fb8d3_row4_col0" class="data row4 col0" >14.030916</td>
#     </tr>
#     <tr>
#       <th id="T_fb8d3_level0_row5" class="row_heading level0 row5" >Orthorhombic C3A</th>
#       <td id="T_fb8d3_row5_col0" class="data row5 col0" >14.030916</td>
#     </tr>
#     <tr>
#       <th id="T_fb8d3_level0_row6" class="row_heading level0 row6" >Free CaO</th>
#       <td id="T_fb8d3_row6_col0" class="data row6 col0" >14.030916</td>
#     </tr>
#     <tr>
#       <th id="T_fb8d3_level0_row7" class="row_heading level0 row7" >Arcanite</th>
#       <td id="T_fb8d3_row7_col0" class="data row7 col0" >14.030916</td>
#     </tr>
#     <tr>
#       <th id="T_fb8d3_level0_row8" class="row_heading level0 row8" >Calcite</th>
#       <td id="T_fb8d3_row8_col0" class="data row8 col0" >14.030916</td>
#     </tr>
#     <tr>
#       <th id="T_fb8d3_level0_row9" class="row_heading level0 row9" >C4AF</th>
#       <td id="T_fb8d3_row9_col0" class="data row9 col0" >14.030916</td>
#     </tr>
#     <tr>
#       <th id="T_fb8d3_level0_row10" class="row_heading level0 row10" >Insoluble Residue</th>
#       <td id="T_fb8d3_row10_col0" class="data row10 col0" >0.356718</td>
#     </tr>
#     <tr>
#       <th id="T_fb8d3_level0_row11" class="row_heading level0 row11" >Loss on Ignition</th>
#       <td id="T_fb8d3_row11_col0" class="data row11 col0" >0.356718</td>
#     </tr>
#     <tr>
#       <th id="T_fb8d3_level0_row12" class="row_heading level0 row12" >SiO2</th>
#       <td id="T_fb8d3_row12_col0" class="data row12 col0" >0.237812</td>
#     </tr>
#     <tr>
#       <th id="T_fb8d3_level0_row13" class="row_heading level0 row13" >K2O</th>
#       <td id="T_fb8d3_row13_col0" class="data row13 col0" >0.237812</td>
#     </tr>
#     <tr>
#       <th id="T_fb8d3_level0_row14" class="row_heading level0 row14" >Fe2O3</th>
#       <td id="T_fb8d3_row14_col0" class="data row14 col0" >0.237812</td>
#     </tr>
#     <tr>
#       <th id="T_fb8d3_level0_row15" class="row_heading level0 row15" >TiO2</th>
#       <td id="T_fb8d3_row15_col0" class="data row15 col0" >0.237812</td>
#     </tr>
#     <tr>
#       <th id="T_fb8d3_level0_row16" class="row_heading level0 row16" >Na2O</th>
#       <td id="T_fb8d3_row16_col0" class="data row16 col0" >0.237812</td>
#     </tr>
#     <tr>
#       <th id="T_fb8d3_level0_row17" class="row_heading level0 row17" >SO3</th>
#       <td id="T_fb8d3_row17_col0" class="data row17 col0" >0.237812</td>
#     </tr>
#     <tr>
#       <th id="T_fb8d3_level0_row18" class="row_heading level0 row18" >Al2O3</th>
#       <td id="T_fb8d3_row18_col0" class="data row18 col0" >0.237812</td>
#     </tr>
#     <tr>
#       <th id="T_fb8d3_level0_row19" class="row_heading level0 row19" >MgO</th>
#       <td id="T_fb8d3_row19_col0" class="data row19 col0" >0.237812</td>
#     </tr>
#     <tr>
#       <th id="T_fb8d3_level0_row20" class="row_heading level0 row20" >CaO</th>
#       <td id="T_fb8d3_row20_col0" class="data row20 col0" >0.237812</td>
#     </tr>
#     <tr>
#       <th id="T_fb8d3_level0_row21" class="row_heading level0 row21" >Final setting time</th>
#       <td id="T_fb8d3_row21_col0" class="data row21 col0" >0.118906</td>
#     </tr>
#     <tr>
#       <th id="T_fb8d3_level0_row22" class="row_heading level0 row22" >Initial setting time</th>
#       <td id="T_fb8d3_row22_col0" class="data row22 col0" >0.118906</td>
#     </tr>
#     <tr>
#       <th id="T_fb8d3_level0_row23" class="row_heading level0 row23" >CS28</th>
#       <td id="T_fb8d3_row23_col0" class="data row23 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fb8d3_level0_row24" class="row_heading level0 row24" >CS7</th>
#       <td id="T_fb8d3_row24_col0" class="data row24 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fb8d3_level0_row25" class="row_heading level0 row25" >CS3</th>
#       <td id="T_fb8d3_row25_col0" class="data row25 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fb8d3_level0_row26" class="row_heading level0 row26" >Date</th>
#       <td id="T_fb8d3_row26_col0" class="data row26 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fb8d3_level0_row27" class="row_heading level0 row27" >#400</th>
#       <td id="T_fb8d3_row27_col0" class="data row27 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fb8d3_level0_row28" class="row_heading level0 row28" >#325</th>
#       <td id="T_fb8d3_row28_col0" class="data row28 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fb8d3_level0_row29" class="row_heading level0 row29" >Blaine</th>
#       <td id="T_fb8d3_row29_col0" class="data row29 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fb8d3_level0_row30" class="row_heading level0 row30" >Cement_Type</th>
#       <td id="T_fb8d3_row30_col0" class="data row30 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Dropping rows with increased missing values after preprocessing

# %% [markdown]
# <h3>Percentage of missing values:</h3>
# <table>
#     <th>Plant A - Full Dataset:</th>
#     <th></th>
#     <tr>
#         <td>C3A</td>
#         <td>38.39</td>
#     </tr>
#     <tr>
#         <td>Aphthitalite</td>
#         <td>37.52</td>
#     </tr>
# </table>

# %%
# FEATRUES_TO_DROP = ["C3A", "Aphthitalite"]
# df = df.drop(labels=FEATRUES_TO_DROP, axis=1)

# %%
(df.isna().sum() / df.shape[0] * 100).sort_values(ascending=False).to_frame(
    name="Missing (%)"
).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_aef15_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_aef15_row1_col0 {
#   background-color: #db2824;
#   color: #f1f1f1;
# }
# #T_aef15_row2_col0 {
#   background-color: #fb6d4d;
#   color: #f1f1f1;
# }
# #T_aef15_row3_col0 {
#   background-color: #fb7b5b;
#   color: #f1f1f1;
# }
# #T_aef15_row4_col0, #T_aef15_row5_col0, #T_aef15_row6_col0, #T_aef15_row7_col0, #T_aef15_row8_col0, #T_aef15_row9_col0 {
#   background-color: #fc8060;
#   color: #f1f1f1;
# }
# #T_aef15_row10_col0, #T_aef15_row11_col0 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_aef15_row12_col0, #T_aef15_row13_col0, #T_aef15_row14_col0, #T_aef15_row15_col0, #T_aef15_row16_col0, #T_aef15_row17_col0, #T_aef15_row18_col0, #T_aef15_row19_col0, #T_aef15_row20_col0 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_aef15_row21_col0, #T_aef15_row22_col0, #T_aef15_row23_col0, #T_aef15_row24_col0, #T_aef15_row25_col0, #T_aef15_row26_col0, #T_aef15_row27_col0, #T_aef15_row28_col0, #T_aef15_row29_col0, #T_aef15_row30_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_aef15">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aef15_level0_col0" class="col_heading level0 col0" >Missing (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aef15_level0_row0" class="row_heading level0 row0" >Periclase</th>
#       <td id="T_aef15_row0_col0" class="data row0 col0" >32.580262</td>
#     </tr>
#     <tr>
#       <th id="T_aef15_level0_row1" class="row_heading level0 row1" >Bassanite</th>
#       <td id="T_aef15_row1_col0" class="data row1 col0" >22.592152</td>
#     </tr>
#     <tr>
#       <th id="T_aef15_level0_row2" class="row_heading level0 row2" >Aphthitalite</th>
#       <td id="T_aef15_row2_col0" class="data row2 col0" >15.933413</td>
#     </tr>
#     <tr>
#       <th id="T_aef15_level0_row3" class="row_heading level0 row3" >Portlandite</th>
#       <td id="T_aef15_row3_col0" class="data row3 col0" >14.625446</td>
#     </tr>
#     <tr>
#       <th id="T_aef15_level0_row4" class="row_heading level0 row4" >Cubic C3A</th>
#       <td id="T_aef15_row4_col0" class="data row4 col0" >14.030916</td>
#     </tr>
#     <tr>
#       <th id="T_aef15_level0_row5" class="row_heading level0 row5" >Orthorhombic C3A</th>
#       <td id="T_aef15_row5_col0" class="data row5 col0" >14.030916</td>
#     </tr>
#     <tr>
#       <th id="T_aef15_level0_row6" class="row_heading level0 row6" >Free CaO</th>
#       <td id="T_aef15_row6_col0" class="data row6 col0" >14.030916</td>
#     </tr>
#     <tr>
#       <th id="T_aef15_level0_row7" class="row_heading level0 row7" >Arcanite</th>
#       <td id="T_aef15_row7_col0" class="data row7 col0" >14.030916</td>
#     </tr>
#     <tr>
#       <th id="T_aef15_level0_row8" class="row_heading level0 row8" >Calcite</th>
#       <td id="T_aef15_row8_col0" class="data row8 col0" >14.030916</td>
#     </tr>
#     <tr>
#       <th id="T_aef15_level0_row9" class="row_heading level0 row9" >C4AF</th>
#       <td id="T_aef15_row9_col0" class="data row9 col0" >14.030916</td>
#     </tr>
#     <tr>
#       <th id="T_aef15_level0_row10" class="row_heading level0 row10" >Insoluble Residue</th>
#       <td id="T_aef15_row10_col0" class="data row10 col0" >0.356718</td>
#     </tr>
#     <tr>
#       <th id="T_aef15_level0_row11" class="row_heading level0 row11" >Loss on Ignition</th>
#       <td id="T_aef15_row11_col0" class="data row11 col0" >0.356718</td>
#     </tr>
#     <tr>
#       <th id="T_aef15_level0_row12" class="row_heading level0 row12" >SiO2</th>
#       <td id="T_aef15_row12_col0" class="data row12 col0" >0.237812</td>
#     </tr>
#     <tr>
#       <th id="T_aef15_level0_row13" class="row_heading level0 row13" >K2O</th>
#       <td id="T_aef15_row13_col0" class="data row13 col0" >0.237812</td>
#     </tr>
#     <tr>
#       <th id="T_aef15_level0_row14" class="row_heading level0 row14" >Fe2O3</th>
#       <td id="T_aef15_row14_col0" class="data row14 col0" >0.237812</td>
#     </tr>
#     <tr>
#       <th id="T_aef15_level0_row15" class="row_heading level0 row15" >TiO2</th>
#       <td id="T_aef15_row15_col0" class="data row15 col0" >0.237812</td>
#     </tr>
#     <tr>
#       <th id="T_aef15_level0_row16" class="row_heading level0 row16" >Na2O</th>
#       <td id="T_aef15_row16_col0" class="data row16 col0" >0.237812</td>
#     </tr>
#     <tr>
#       <th id="T_aef15_level0_row17" class="row_heading level0 row17" >SO3</th>
#       <td id="T_aef15_row17_col0" class="data row17 col0" >0.237812</td>
#     </tr>
#     <tr>
#       <th id="T_aef15_level0_row18" class="row_heading level0 row18" >Al2O3</th>
#       <td id="T_aef15_row18_col0" class="data row18 col0" >0.237812</td>
#     </tr>
#     <tr>
#       <th id="T_aef15_level0_row19" class="row_heading level0 row19" >MgO</th>
#       <td id="T_aef15_row19_col0" class="data row19 col0" >0.237812</td>
#     </tr>
#     <tr>
#       <th id="T_aef15_level0_row20" class="row_heading level0 row20" >CaO</th>
#       <td id="T_aef15_row20_col0" class="data row20 col0" >0.237812</td>
#     </tr>
#     <tr>
#       <th id="T_aef15_level0_row21" class="row_heading level0 row21" >Final setting time</th>
#       <td id="T_aef15_row21_col0" class="data row21 col0" >0.118906</td>
#     </tr>
#     <tr>
#       <th id="T_aef15_level0_row22" class="row_heading level0 row22" >Initial setting time</th>
#       <td id="T_aef15_row22_col0" class="data row22 col0" >0.118906</td>
#     </tr>
#     <tr>
#       <th id="T_aef15_level0_row23" class="row_heading level0 row23" >CS28</th>
#       <td id="T_aef15_row23_col0" class="data row23 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_aef15_level0_row24" class="row_heading level0 row24" >CS7</th>
#       <td id="T_aef15_row24_col0" class="data row24 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_aef15_level0_row25" class="row_heading level0 row25" >CS3</th>
#       <td id="T_aef15_row25_col0" class="data row25 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_aef15_level0_row26" class="row_heading level0 row26" >Date</th>
#       <td id="T_aef15_row26_col0" class="data row26 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_aef15_level0_row27" class="row_heading level0 row27" >#400</th>
#       <td id="T_aef15_row27_col0" class="data row27 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_aef15_level0_row28" class="row_heading level0 row28" >#325</th>
#       <td id="T_aef15_row28_col0" class="data row28 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_aef15_level0_row29" class="row_heading level0 row29" >Blaine</th>
#       <td id="T_aef15_row29_col0" class="data row29 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_aef15_level0_row30" class="row_heading level0 row30" >Cement_Type</th>
#       <td id="T_aef15_row30_col0" class="data row30 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.describe().T
# Out:
#                       count                           mean  \
# Date                    841  2022-05-13 17:34:44.661117696
# C4AF                  723.0                       8.232932
# Cubic C3A             723.0                       4.660954
# Orthorhombic C3A      723.0                       0.604343
# Free CaO              723.0                       1.207621
# Portlandite           718.0                        0.99851
# Periclase             567.0                       3.377266
# Arcanite              723.0                       0.896542
# Aphthitalite          707.0                        0.22901
# Bassanite             651.0                       0.926237
# Calcite               723.0                      15.683071
# CaO                   839.0                      59.490207
# MgO                   839.0                         5.1031
# Na2O                  839.0                       0.058527
# Al2O3                 839.0                       4.173092
# SiO2                  839.0                      17.184826
# SO3                   839.0                       3.450575
# K2O                   839.0                       0.891924
# TiO2                  839.0                       0.206977
# Fe2O3                 839.0                       2.507362
# Loss on Ignition      838.0                       7.705943
# Insoluble Residue     838.0                       1.919177
# Blaine                841.0                    4887.946492
# #325                  841.0                       3.482675
# #400                  841.0                       7.586611
# Initial setting time  840.0                     271.228571
# Final setting time    840.0                     324.454762
# CS3                   841.0                       32.61308
# CS7                   841.0                      37.045541
# CS28                  841.0                      43.953049
#
#                                       min                  25%  \
# Date                  2021-01-05 00:00:00  2021-10-09 00:00:00
# C4AF                                 5.47                7.545
# Cubic C3A                            2.36                 4.07
# Orthorhombic C3A                     0.01                 0.27
# Free CaO                             0.23                  0.9
# Portlandite                          0.02                 0.67
# Periclase                            2.01                 2.99
# Arcanite                             0.07                 0.67
# Aphthitalite                         0.01                 0.14
# Bassanite                            0.02                 0.48
# Calcite                              1.85               10.215
# CaO                                 54.93                58.55
# MgO                                  3.89                 4.82
# Na2O                                 0.01                 0.04
# Al2O3                                 3.5              3.93337
# SiO2                                13.54                16.49
# SO3                                  2.61                 3.24
# K2O                                  0.57                  0.8
# TiO2                                 0.16                  0.2
# Fe2O3                                2.11                  2.4
# Loss on Ignition                     4.06                 5.81
# Insoluble Residue                    0.31               1.2525
# Blaine                             4090.0               4600.0
# #325                                 0.02                 0.51
# #400                                 0.37                  1.9
# Initial setting time                180.0                235.0
# Final setting time                  220.0                290.0
# CS3                             20.799999                 25.1
# CS7                             25.200001            29.799999
# CS28                            32.099998                 36.0
#
#                                       50%                  75%  \
# Date                  2022-05-26 00:00:00  2022-12-27 00:00:00
# C4AF                                  8.2                 8.91
# Cubic C3A                            4.59                 5.18
# Orthorhombic C3A                      0.5                 0.87
# Free CaO                             1.15                 1.48
# Portlandite                          0.93                 1.28
# Periclase                            3.33                 3.78
# Arcanite                             0.89                 1.12
# Aphthitalite                         0.22                 0.31
# Bassanite                            0.82                 1.26
# Calcite                             11.56               22.765
# CaO                                 59.79                60.43
# MgO                                   5.1                 5.41
# Na2O                                 0.05                 0.07
# Al2O3                                4.23             4.384805
# SiO2                                17.31                17.93
# SO3                                  3.42                 3.64
# K2O                                  0.89                 0.97
# TiO2                                 0.21                 0.22
# Fe2O3                                2.52                 2.61
# Loss on Ignition                    6.235                10.33
# Insoluble Residue                    1.69               2.4025
# Blaine                             4830.0               5080.0
# #325                                  0.9                 7.35
# #400                                  2.7                14.96
# Initial setting time                260.0                310.0
# Final setting time                  315.0                360.0
# CS3                                  36.2                 38.1
# CS7                                  40.4                 42.5
# CS28                                 47.4                 50.0
#
#                                       max         std
# Date                  2023-07-25 00:00:00         NaN
# C4AF                                11.67    0.998744
# Cubic C3A                            7.67     0.80186
# Orthorhombic C3A                     3.11    0.438925
# Free CaO                             2.66    0.423136
# Portlandite                          2.76    0.474631
# Periclase                             4.9    0.534632
# Arcanite                             2.17    0.336324
# Aphthitalite                         0.68    0.119273
# Bassanite                            3.32    0.595125
# Calcite                             27.32    6.513359
# CaO                             62.139999    1.328879
# MgO                                  6.18    0.418902
# Na2O                                 0.22    0.030937
# Al2O3                                5.03    0.266427
# SiO2                                22.49    1.137177
# SO3                                  4.45    0.298457
# K2O                                   1.2    0.107934
# TiO2                                 0.26    0.014293
# Fe2O3                                3.09    0.152141
# Loss on Ignition                    12.27    2.331855
# Insoluble Residue                    7.14    0.928204
# Blaine                             5900.0  379.838848
# #325                                12.08    3.625787
# #400                                27.83    7.062992
# Initial setting time                370.0   44.373887
# Final setting time                  450.0   44.061993
# CS3                             42.900002    6.653626
# CS7                             48.700001     6.60469
# CS28                            55.599998    7.119078

# %%
df.describe(exclude="number").T
# Out:
#             count unique         top freq                           mean  \
# Date          841    NaN         NaN  NaN  2022-05-13 17:34:44.661117696
# Cement_Type   841      3  CP II-F-40  346                            NaN
#
#                              min                  25%                  50%  \
# Date         2021-01-05 00:00:00  2021-10-09 00:00:00  2022-05-26 00:00:00
# Cement_Type                  NaN                  NaN                  NaN
#
#                              75%                  max
# Date         2022-12-27 00:00:00  2023-07-25 00:00:00
# Cement_Type                  NaN                  NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 841 entries, 0 to 954
# Data columns (total 31 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  841 non-null    datetime64[ns]
#  1   C4AF                  723 non-null    float64
#  2   Cubic C3A             723 non-null    float64
#  3   Orthorhombic C3A      723 non-null    float64
#  4   Free CaO              723 non-null    float64
#  5   Portlandite           718 non-null    float64
#  6   Periclase             567 non-null    float64
#  7   Arcanite              723 non-null    float64
#  8   Aphthitalite          707 non-null    float64
#  9   Bassanite             651 non-null    float64
#  10  Calcite               723 non-null    float64
#  11  CaO                   839 non-null    float64
#  12  MgO                   839 non-null    float64
#  13  Na2O                  839 non-null    float64
#  14  Al2O3                 839 non-null    float64
#  15  SiO2                  839 non-null    float64
#  16  SO3                   839 non-null    float64
#  17  K2O                   839 non-null    float64
#  18  TiO2                  839 non-null    float64
#  19  Fe2O3                 839 non-null    float64
#  20  Loss on Ignition      838 non-null    float64
#  21  Insoluble Residue     838 non-null    float64
#  22  Blaine                841 non-null    float64
#  23  #325                  841 non-null    float64
#  24  #400                  841 non-null    float64
#  25  Initial setting time  840 non-null    float64
#  26  Final setting time    840 non-null    float64
#  27  CS3                   841 non-null    float64
#  28  CS7                   841 non-null    float64
#  29  CS28                  841 non-null    float64
#  30  Cement_Type           841 non-null    object
# dtypes: datetime64[ns](1), float64(29), object(1)
# memory usage: 210.2+ KB

# %% [markdown]
# ### Sort the dataset by date

# %%
# We first make sure Date column was infered correctly
df["Date"].dtype
# Out:
# dtype('<M8[ns]')

# %%
df = df.sort_values(by="Date")

# %% [markdown]
# ## Saving the dataset

# %% [markdown]
# <h3>Saving for feature engineering</h3>

# %%
df.to_csv("../../../data/interim/209/n.csv", index=False)
