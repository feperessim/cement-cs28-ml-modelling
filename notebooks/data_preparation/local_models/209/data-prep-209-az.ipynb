# %%
# %load_ext nb_black

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

from scipy.stats import pearsonr
from collections import Counter

# %%
def convert_to_float(value):
    try:
        # If it's a string enclosed in single quotes, remove quotes and replace comma with dot
        if isinstance(value, str):
            return float(value.replace(",", "."))
        else:
            return float(value)
    except ValueError as e:
        print(e)
        return float("nan")

# %%
def preprocess_numeric_cols(df, columns):
    for col in columns:
        df[col] = df[col].astype(str)  # Ensure string type for string operations
        df[col] = df[col].str.replace("#", "")  # Remove '#' characters
        df[col] = df[col].str.replace(",", ".")  # Replace ',' with '.' for decimals
    return df

# %% [markdown]
# # Data preparation - 209 plant aa data

# %% [markdown]
# ### Reading the files and extracting relevant information:

# %%
plant = "AZ"
xls_files = {}

xls = pd.ExcelFile(
    f"../../../data/raw/209/EMBRAPII hubIC IACC_CIMENTO_{plant}.xlsx",
    engine="openpyxl",
)
xls_files[plant] = xls

# %%
print("Plant: ", plant, xls.sheet_names)
# Out:
# Plant:  AZ ['INSTRUÇÕES', 'Clínquer', '4', '92', '70', '111', '156']

# %%
cement_types_per_plant = []
CEMENT_TYPE_COLS = ["Tipo de cimento", "Classe de resistência"]
dataframes = []

for plant, xls in xls_files.items():
    for sheet_name in xls.sheet_names[2:]:
        df = pd.read_excel(xls_files[plant], sheet_name, header=[1, 2])

        if not df[CEMENT_TYPE_COLS].iloc[2:].isna().all().all():
            cement_type = (
                df[CEMENT_TYPE_COLS]
                .loc[2:]
                .astype(str)
                .sum(axis=1)
                .str.replace(" ", "")
                .str.replace("-", "")
                .str.replace("nan", "")
                .unique()
            )

        else:
            cement_type = (
                df[[("Obs.", "Unnamed: 8_level_1")]]
                .loc[2:]
                .astype(str)
                .sum(axis=1)
                .str.replace(" ", "")
                .str.replace("-", "")
                .unique()
            )

        cement_types_per_plant.append((plant, sheet_name, cement_type))
        dataframes.append(df)

# %%
cement_types_per_plant
# Out:
# [('AZ', '4', array(['CPIIE40'], dtype=object)),
#  ('AZ', '92', array(['CPIIIRS32'], dtype=object)),
#  ('AZ', '70', array(['CPIND'], dtype=object)),
#  ('AZ', '111', array(['CPVARI'], dtype=object)),
#  ('AZ', '156', array(['CPIIIRS40'], dtype=object))]

# %%
cements = []
for tup in cement_types_per_plant:
    cements.append(tup[2][0])
Counter(cements)
# Out:
# Counter({'CPIIE40': 1,
#          'CPIIIRS32': 1,
#          'CPIND': 1,
#          'CPVARI': 1,
#          'CPIIIRS40': 1})

# %%
dataframes = []

for plant, xls in xls_files.items():
    for sheet_name in xls.sheet_names[2:]:
        df = pd.read_excel(xls_files[plant], sheet_name, header=[0, 1, 2])
        df["Unnamed: 0_level_0", "Unnamed: 0_level_1", "Unnamed: 0_level_2"] = plant
        dataframes.append(df.drop([0, 1], axis=0).reset_index(drop=True).copy())

# %%
df = pd.concat(dataframes, axis=0).reset_index(drop=True)

# %% [markdown]
# ## Initial Preprocessing

# %%
df = pd.concat(
    [
        df["Unnamed: 0_level_0", "Unnamed: 0_level_1", "Unnamed: 0_level_2"],
        df["Dados iniciais"],
        df["Cimento"]["Análise mineralógica"],
        df["Cimento"]["Análise química"],
        df["Característias físicas do cimento"],
        df["Propriedades do cimento"],
    ],
    axis=1,
)

# %%
# df.info()

# %% [markdown]
# ### 1. Dropping columns where either there is no data nor it contributes to the analysis
# ### 2. Renaming columns to a short identifiable name

# %%
COLUMNS_TO_DROP = [
    ("Data", "Medida"),
    ("Horário", "Produção"),
    ("Horário", "Medida"),
    ("Obs.", "Unnamed: 148_level_2"),
    ("Tipo de cimento", "Unnamed: 6_level_2"),
    ("Classe de resistência", "Unnamed: 7_level_2"),
    ("Obs.", "Unnamed: 8_level_2"),
    "Obs.",
    ("Obs.", "Unnamed: 148_level_2"),
    ("Unnamed: 141_level_1", "Obs."),
    # ("Unnamed: 139_level_1", "#400"),
]

COLUMNS_TO_RENAME = {
    ("Unnamed: 0_level_0", "Unnamed: 0_level_1", "Unnamed: 0_level_2"): "Plant",
    ("Cidade", "Unnamed: 1_level_2"): "City",
    ("Data", "Produção"): "Date",  # Arrumar!
    ("Unnamed: 136_level_1", "Blaine"): "Blaine",
    ("Unnamed: 137_level_1", "#200"): "#200",
    ("Unnamed: 138_level_1", "#325"): "#325",
    ("Unnamed: 139_level_1", "#400"): "#400",
    ("Unnamed: 140_level_1", "Massa específica"): "Specific Gravity",
    ("Tempo de pega", "Inicio"): "Initial setting time",
    ("Tempo de pega", "Fim"): "Final setting time",
    ("Resistência à compressão", "1 d"): "CS1",
    ("Resistência à compressão", "3 d"): "CS3",
    ("Resistência à compressão", "7 d"): "CS7",
    ("Resistência à compressão", "28 d"): "CS28",
    "Perda ao fogo": "Loss on Ignition",
    "Resíduo insolúvel": "Insoluble Residue",
    "Sulfato de cálcio": "Calcium sulfate",
    "C3S total": "Total C3S",
    "C2S total": "Total C2S",
    "C2S alpha": "Alpha C2S",
    "C2S beta": "Beta C2S",
    "C2S gama": "Gamma C2S",
    "C4AF": "C4AF",
    "C3A": "C3A",
    "C3A cubic": "Cubic C3A",
    "C3A orto": "Orthorhombic C3A",
    "CaO livre": "Free CaO",
    "Portlandita": "Portlandite",
    "Periclasio": "Periclase",
    "Arcanita": "Arcanite",
    "Aphthalita": "Aphthitalite",
    "Langbeinita": "Langbeinite",
    "Bassanita": "Bassanite",
    "Anidrita": "Anhydrite",
    "Calcita": "Calcite",
    "Dolomita": "Dolomite",
    "Quartzo": "Quartz",
    "Muscovita": "Muscovite",
}

# %% [markdown]
# ### Defining a single variable to identify Cement Type

# %%
# Single variable for the Cement Type
df["Cement_Type"] = (
    df[
        [
            ("Tipo de cimento", "Unnamed: 6_level_2"),
            ("Classe de resistência", "Unnamed: 7_level_2"),
            ("Obs.", "Unnamed: 8_level_2"),
        ]
    ]
    .fillna("")
    .astype(str)
    .sum(axis=1)
)

# # Preprocessing
df["Cement_Type"] = df["Cement_Type"].replace("Fibro", "Fibrocimento")

# Preprocessing
df["Cement_Type"] = (
    df["Cement_Type"]
    .str.replace("Expedido", "")
    .str.replace("Linha 9", "")
    .str.replace("Itajaí", "")
    .str.replace("D-G", "")
    .str.replace("D-E", "")
    .str.replace("DF2", "")
    .str.replace("CPIIF40", "CP II-F-40")
    .str.replace("CPIIF40", "CP II-F40")
    .str.replace("CP VARI", "CP V-ARI")
    .str.replace("CPVARI", "CP V-ARI")
    .str.replace("CP V-RSARI", "CP V-ARI RS")
    .str.replace("CP III-RS40", "CP III-40 RS")
    .str.replace("CP III-RS32", "CP III-32 RS")
    .str.replace("CP IV-RS32", "CP IV-32 RS")
    .str.replace("CP III40", "CP III-40")
    .str.replace("CP III32", "CP III-32")
    .str.replace("CP I-S40", "CP I-S-40")
    .str.replace("CP I40", "CP I-40")
    .str.replace("CP II-E32", "CP II-E-32")
    .str.replace("CP II-E40", "CP II-E-40")
    .str.replace("CP II-F FIBRO40", "CP II-F-40")
    .str.replace("CP II-F32", "CP II-F-32")
    .str.replace("CP II-F40", "CP II-F-40")
    .str.replace("CP II-Z32", "CP II-Z-32")
    .str.replace("CP II-Z40", "CP II-Z-40")
    .str.replace("CP IV32", "CP IV-32")
    .str.replace("CP IND", "CP I")
    .str.replace("CPINDCC", "CP I")
    .str.strip()
)

df = df.drop(COLUMNS_TO_DROP, axis=1).rename(COLUMNS_TO_RENAME, axis=1).copy()
df = df.drop([0]).reset_index(drop=True)
df = df.infer_objects()

# %% [markdown]
# ### Dropping and rename the columns defined above

# %% [markdown]
# ### Cleaning and converting numeric columns to float

# %%
NUMERIC_COLUMNS = [
    "Calcium sulfate",
    "Total C3S",
    "Total C2S",
    "Alpha C2S",
    "Beta C2S",
    "Gamma C2S",
    "C4AF",
    "C3A",
    "Cubic C3A",
    "Orthorhombic C3A",
    "Free CaO",
    "Portlandite",
    "Periclase",
    "Arcanite",
    "Aphthitalite",
    "Langbeinite",
    "Bassanite",
    "Anhydrite",
    "Calcite",
    "Dolimita",
    "Quartz",
    "Muscovite",
    "CaO",
    "MgO",
    "Na2O",
    "Al2O3",
    "SiO2",
    "SO3",
    "K2O",
    "TiO2",
    "Fe2O3",
    "Loss on Ignition",
    "Insoluble Residue",
    "Blaine",
    "#200",
    "#325",
    "#400",
    "Specific Gravity",
    "Final setting time",
    "Initial setting time",
    "CS1",
    "CS3",
    "CS7",
    "CS28",
]

df = preprocess_numeric_cols(df, NUMERIC_COLUMNS)

# Preprocessing to fix numeric columns
df[NUMERIC_COLUMNS] = df[NUMERIC_COLUMNS].map(convert_to_float)

# Converting Date to pandas datetime
df["Date"] = pd.to_datetime(df["Date"])

# Drop rows completely missing
index_to_keep = (
    df.drop(["Plant", "Date", "Cement_Type"], axis=1).dropna(axis=0, how="all").index
)
df = df.iloc[index_to_keep].reset_index(drop=True)

df = df.infer_objects()
# Out:
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '
# could not convert string to float: ' '

# %% [markdown]
# ## Dropping missing features

# %% [markdown]
# ### Drop rows completely missing

# %%
index_to_keep = (
    df.drop(["Plant", "City", "Date", "Cement_Type"], axis=1)
    .dropna(axis=0, how="all")
    .index
)
df = df.iloc[index_to_keep].reset_index(drop=True)

# %% [markdown]
# ### Removing features
#  that will be fitted on this data.
#
# 1. Removing features with features having ~50% or more of missing values
# 2. Removing features with zero variance
# 3. Removing features with more than 70% of zeros

# %%
(df.isna().sum() / df.shape[0] * 100).sort_values(ascending=False).to_frame(
    name="Missing (%)"
).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_e1386_row0_col0, #T_e1386_row1_col0, #T_e1386_row2_col0, #T_e1386_row3_col0, #T_e1386_row4_col0, #T_e1386_row5_col0, #T_e1386_row6_col0, #T_e1386_row7_col0, #T_e1386_row8_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_e1386_row9_col0, #T_e1386_row10_col0, #T_e1386_row11_col0 {
#   background-color: #fed9c9;
#   color: #000000;
# }
# #T_e1386_row12_col0, #T_e1386_row13_col0 {
#   background-color: #ffeee6;
#   color: #000000;
# }
# #T_e1386_row14_col0 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_e1386_row15_col0 {
#   background-color: #fff0e9;
#   color: #000000;
# }
# #T_e1386_row16_col0, #T_e1386_row17_col0, #T_e1386_row18_col0, #T_e1386_row19_col0, #T_e1386_row20_col0, #T_e1386_row21_col0 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_e1386_row22_col0, #T_e1386_row23_col0, #T_e1386_row24_col0, #T_e1386_row25_col0, #T_e1386_row26_col0, #T_e1386_row27_col0 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_e1386_row28_col0, #T_e1386_row29_col0, #T_e1386_row30_col0, #T_e1386_row31_col0, #T_e1386_row32_col0, #T_e1386_row33_col0, #T_e1386_row34_col0, #T_e1386_row35_col0, #T_e1386_row36_col0, #T_e1386_row37_col0, #T_e1386_row38_col0, #T_e1386_row39_col0, #T_e1386_row40_col0, #T_e1386_row41_col0, #T_e1386_row42_col0, #T_e1386_row43_col0, #T_e1386_row44_col0, #T_e1386_row45_col0, #T_e1386_row46_col0, #T_e1386_row47_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_e1386">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e1386_level0_col0" class="col_heading level0 col0" >Missing (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e1386_level0_row0" class="row_heading level0 row0" >Anhydrite</th>
#       <td id="T_e1386_row0_col0" class="data row0 col0" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e1386_level0_row1" class="row_heading level0 row1" >Beta C2S</th>
#       <td id="T_e1386_row1_col0" class="data row1 col0" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e1386_level0_row2" class="row_heading level0 row2" >CS1</th>
#       <td id="T_e1386_row2_col0" class="data row2 col0" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e1386_level0_row3" class="row_heading level0 row3" >Calcium sulfate</th>
#       <td id="T_e1386_row3_col0" class="data row3 col0" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e1386_level0_row4" class="row_heading level0 row4" >Gamma C2S</th>
#       <td id="T_e1386_row4_col0" class="data row4 col0" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e1386_level0_row5" class="row_heading level0 row5" >Specific Gravity</th>
#       <td id="T_e1386_row5_col0" class="data row5 col0" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e1386_level0_row6" class="row_heading level0 row6" >Alpha C2S</th>
#       <td id="T_e1386_row6_col0" class="data row6 col0" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e1386_level0_row7" class="row_heading level0 row7" >Total C3S</th>
#       <td id="T_e1386_row7_col0" class="data row7 col0" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e1386_level0_row8" class="row_heading level0 row8" >Total C2S</th>
#       <td id="T_e1386_row8_col0" class="data row8 col0" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e1386_level0_row9" class="row_heading level0 row9" >Cubic C3A</th>
#       <td id="T_e1386_row9_col0" class="data row9 col0" >15.117417</td>
#     </tr>
#     <tr>
#       <th id="T_e1386_level0_row10" class="row_heading level0 row10" >Orthorhombic C3A</th>
#       <td id="T_e1386_row10_col0" class="data row10 col0" >15.117417</td>
#     </tr>
#     <tr>
#       <th id="T_e1386_level0_row11" class="row_heading level0 row11" >Langbeinite</th>
#       <td id="T_e1386_row11_col0" class="data row11 col0" >15.117417</td>
#     </tr>
#     <tr>
#       <th id="T_e1386_level0_row12" class="row_heading level0 row12" >TiO2</th>
#       <td id="T_e1386_row12_col0" class="data row12 col0" >4.549902</td>
#     </tr>
#     <tr>
#       <th id="T_e1386_level0_row13" class="row_heading level0 row13" >#400</th>
#       <td id="T_e1386_row13_col0" class="data row13 col0" >4.500978</td>
#     </tr>
#     <tr>
#       <th id="T_e1386_level0_row14" class="row_heading level0 row14" >Insoluble Residue</th>
#       <td id="T_e1386_row14_col0" class="data row14 col0" >3.669276</td>
#     </tr>
#     <tr>
#       <th id="T_e1386_level0_row15" class="row_heading level0 row15" >Loss on Ignition</th>
#       <td id="T_e1386_row15_col0" class="data row15 col0" >2.935421</td>
#     </tr>
#     <tr>
#       <th id="T_e1386_level0_row16" class="row_heading level0 row16" >Calcite</th>
#       <td id="T_e1386_row16_col0" class="data row16 col0" >1.369863</td>
#     </tr>
#     <tr>
#       <th id="T_e1386_level0_row17" class="row_heading level0 row17" >Bassanite</th>
#       <td id="T_e1386_row17_col0" class="data row17 col0" >1.369863</td>
#     </tr>
#     <tr>
#       <th id="T_e1386_level0_row18" class="row_heading level0 row18" >Quartz</th>
#       <td id="T_e1386_row18_col0" class="data row18 col0" >1.369863</td>
#     </tr>
#     <tr>
#       <th id="T_e1386_level0_row19" class="row_heading level0 row19" >Muscovite</th>
#       <td id="T_e1386_row19_col0" class="data row19 col0" >1.369863</td>
#     </tr>
#     <tr>
#       <th id="T_e1386_level0_row20" class="row_heading level0 row20" >C3A</th>
#       <td id="T_e1386_row20_col0" class="data row20 col0" >1.369863</td>
#     </tr>
#     <tr>
#       <th id="T_e1386_level0_row21" class="row_heading level0 row21" >Dolimita</th>
#       <td id="T_e1386_row21_col0" class="data row21 col0" >1.320939</td>
#     </tr>
#     <tr>
#       <th id="T_e1386_level0_row22" class="row_heading level0 row22" >Portlandite</th>
#       <td id="T_e1386_row22_col0" class="data row22 col0" >1.076321</td>
#     </tr>
#     <tr>
#       <th id="T_e1386_level0_row23" class="row_heading level0 row23" >C4AF</th>
#       <td id="T_e1386_row23_col0" class="data row23 col0" >1.076321</td>
#     </tr>
#     <tr>
#       <th id="T_e1386_level0_row24" class="row_heading level0 row24" >Free CaO</th>
#       <td id="T_e1386_row24_col0" class="data row24 col0" >1.076321</td>
#     </tr>
#     <tr>
#       <th id="T_e1386_level0_row25" class="row_heading level0 row25" >Aphthitalite</th>
#       <td id="T_e1386_row25_col0" class="data row25 col0" >1.076321</td>
#     </tr>
#     <tr>
#       <th id="T_e1386_level0_row26" class="row_heading level0 row26" >Periclase</th>
#       <td id="T_e1386_row26_col0" class="data row26 col0" >1.076321</td>
#     </tr>
#     <tr>
#       <th id="T_e1386_level0_row27" class="row_heading level0 row27" >Arcanite</th>
#       <td id="T_e1386_row27_col0" class="data row27 col0" >1.076321</td>
#     </tr>
#     <tr>
#       <th id="T_e1386_level0_row28" class="row_heading level0 row28" >Al2O3</th>
#       <td id="T_e1386_row28_col0" class="data row28 col0" >0.244618</td>
#     </tr>
#     <tr>
#       <th id="T_e1386_level0_row29" class="row_heading level0 row29" >CaO</th>
#       <td id="T_e1386_row29_col0" class="data row29 col0" >0.244618</td>
#     </tr>
#     <tr>
#       <th id="T_e1386_level0_row30" class="row_heading level0 row30" >MgO</th>
#       <td id="T_e1386_row30_col0" class="data row30 col0" >0.048924</td>
#     </tr>
#     <tr>
#       <th id="T_e1386_level0_row31" class="row_heading level0 row31" >Na2O</th>
#       <td id="T_e1386_row31_col0" class="data row31 col0" >0.048924</td>
#     </tr>
#     <tr>
#       <th id="T_e1386_level0_row32" class="row_heading level0 row32" >SiO2</th>
#       <td id="T_e1386_row32_col0" class="data row32 col0" >0.048924</td>
#     </tr>
#     <tr>
#       <th id="T_e1386_level0_row33" class="row_heading level0 row33" >K2O</th>
#       <td id="T_e1386_row33_col0" class="data row33 col0" >0.048924</td>
#     </tr>
#     <tr>
#       <th id="T_e1386_level0_row34" class="row_heading level0 row34" >Fe2O3</th>
#       <td id="T_e1386_row34_col0" class="data row34 col0" >0.048924</td>
#     </tr>
#     <tr>
#       <th id="T_e1386_level0_row35" class="row_heading level0 row35" >SO3</th>
#       <td id="T_e1386_row35_col0" class="data row35 col0" >0.048924</td>
#     </tr>
#     <tr>
#       <th id="T_e1386_level0_row36" class="

# %% [markdown]
# <h3>Percentage of missing values:</h3>
# <table>
#     <th>Plant A - Full Dataset:</th>
#     <th></th>
#     <tr>
#         <td>Anhydrite</td>
#         <td>100.00</td>
#     </tr>
#     <tr>
#         <td>Beta C2S</td>
#         <td>100.00</td>
#     </tr>
#     <tr>
#         <td>CS1</td>
#         <td>100.00</td>
#     </tr>
#     <tr>
#         <td>Calcium sulfate</td>
#         <td>100.00</td>
#     </tr>
#     <tr>
#         <td>Gamma C2S</td>
#         <td>100.00</td>
#     </tr>
#     <tr>
#         <td>Specific Gravity</td>
#         <td>100.00</td>
#     </tr>
#     <tr>
#         <td>Alpha C2S</td>
#         <td>100.00</td>
#     </tr>
#     <tr>
#         <td>Total C3S</td>
#         <td>100.00</td>
#     </tr>
#     <tr>
#         <td>Total C2S</td>
#         <td>100.00</td>>
#     </tr>
# </table>

# %%
FEATRUES_TO_DROP = [
    "Anhydrite",
    "Beta C2S",
    "CS1",
    "Calcium sulfate",
    "Gamma C2S",
    "Specific Gravity",
    "Alpha C2S",
    "Total C3S",
    "Total C2S",
]

df = df.drop(labels=FEATRUES_TO_DROP, axis=1)

# %%
df.shape
# Out:
# (2044, 39)

# %% [markdown]
# ### Removing features with more than 23% of zeros

# %%
zero_values = {}
for col in df.select_dtypes(include="number").columns:
    zero_percentages = (df[df[col].eq(0)].shape[0] / df.shape[0]) * 100
    zero_values[col] = zero_percentages

zero_percentages = pd.Series(zero_values, name=f"Zero (%) for {plant}")
zero_percentages = zero_percentages.sort_values(ascending=False)
zero_percentages = zero_percentages.to_frame(name=f"Zero (%) for {plant}")
zero_percentages.style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_b53f6_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_b53f6_row1_col0 {
#   background-color: #d11e1f;
#   color: #f1f1f1;
# }
# #T_b53f6_row2_col0 {
#   background-color: #fc7f5f;
#   color: #f1f1f1;
# }
# #T_b53f6_row3_col0 {
#   background-color: #fc9879;
#   color: #000000;
# }
# #T_b53f6_row4_col0 {
#   background-color: #fdd5c4;
#   color: #000000;
# }
# #T_b53f6_row5_col0 {
#   background-color: #fee2d5;
#   color: #000000;
# }
# #T_b53f6_row6_col0 {
#   background-color: #fff2ec;
#   color: #000000;
# }
# #T_b53f6_row7_col0, #T_b53f6_row8_col0, #T_b53f6_row9_col0 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_b53f6_row10_col0, #T_b53f6_row11_col0, #T_b53f6_row12_col0, #T_b53f6_row13_col0, #T_b53f6_row14_col0, #T_b53f6_row15_col0, #T_b53f6_row16_col0, #T_b53f6_row17_col0, #T_b53f6_row18_col0, #T_b53f6_row19_col0, #T_b53f6_row20_col0, #T_b53f6_row21_col0, #T_b53f6_row22_col0, #T_b53f6_row23_col0, #T_b53f6_row24_col0, #T_b53f6_row25_col0, #T_b53f6_row26_col0, #T_b53f6_row27_col0, #T_b53f6_row28_col0, #T_b53f6_row29_col0, #T_b53f6_row30_col0, #T_b53f6_row31_col0, #T_b53f6_row32_col0, #T_b53f6_row33_col0, #T_b53f6_row34_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_b53f6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b53f6_level0_col0" class="col_heading level0 col0" >Zero (%) for AZ</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b53f6_level0_row0" class="row_heading level0 row0" >Dolimita</th>
#       <td id="T_b53f6_row0_col0" class="data row0 col0" >95.743640</td>
#     </tr>
#     <tr>
#       <th id="T_b53f6_level0_row1" class="row_heading level0 row1" >Arcanite</th>
#       <td id="T_b53f6_row1_col0" class="data row1 col0" >69.569472</td>
#     </tr>
#     <tr>
#       <th id="T_b53f6_level0_row2" class="row_heading level0 row2" >#200</th>
#       <td id="T_b53f6_row2_col0" class="data row2 col0" >41.585127</td>
#     </tr>
#     <tr>
#       <th id="T_b53f6_level0_row3" class="row_heading level0 row3" >Langbeinite</th>
#       <td id="T_b53f6_row3_col0" class="data row3 col0" >34.246575</td>
#     </tr>
#     <tr>
#       <th id="T_b53f6_level0_row4" class="row_heading level0 row4" >Free CaO</th>
#       <td id="T_b53f6_row4_col0" class="data row4 col0" >15.508806</td>
#     </tr>
#     <tr>
#       <th id="T_b53f6_level0_row5" class="row_heading level0 row5" >Aphthitalite</th>
#       <td id="T_b53f6_row5_col0" class="data row5 col0" >11.007828</td>
#     </tr>
#     <tr>
#       <th id="T_b53f6_level0_row6" class="row_heading level0 row6" >TiO2</th>
#       <td id="T_b53f6_row6_col0" class="data row6 col0" >1.663405</td>
#     </tr>
#     <tr>
#       <th id="T_b53f6_level0_row7" class="row_heading level0 row7" >Bassanite</th>
#       <td id="T_b53f6_row7_col0" class="data row7 col0" >0.587084</td>
#     </tr>
#     <tr>
#       <th id="T_b53f6_level0_row8" class="row_heading level0 row8" >Muscovite</th>
#       <td id="T_b53f6_row8_col0" class="data row8 col0" >0.587084</td>
#     </tr>
#     <tr>
#       <th id="T_b53f6_level0_row9" class="row_heading level0 row9" >#325</th>
#       <td id="T_b53f6_row9_col0" class="data row9 col0" >0.587084</td>
#     </tr>
#     <tr>
#       <th id="T_b53f6_level0_row10" class="row_heading level0 row10" >Quartz</th>
#       <td id="T_b53f6_row10_col0" class="data row10 col0" >0.342466</td>
#     </tr>
#     <tr>
#       <th id="T_b53f6_level0_row11" class="row_heading level0 row11" >Portlandite</th>
#       <td id="T_b53f6_row11_col0" class="data row11 col0" >0.244618</td>
#     </tr>
#     <tr>
#       <th id="T_b53f6_level0_row12" class="row_heading level0 row12" >Periclase</th>
#       <td id="T_b53f6_row12_col0" class="data row12 col0" >0.146771</td>
#     </tr>
#     <tr>
#       <th id="T_b53f6_level0_row13" class="row_heading level0 row13" >Orthorhombic C3A</th>
#       <td id="T_b53f6_row13_col0" class="data row13 col0" >0.146771</td>
#     </tr>
#     <tr>
#       <th id="T_b53f6_level0_row14" class="row_heading level0 row14" >Calcite</th>
#       <td id="T_b53f6_row14_col0" class="data row14 col0" >0.097847</td>
#     </tr>
#     <tr>
#       <th id="T_b53f6_level0_row15" class="row_heading level0 row15" >#400</th>
#       <td id="T_b53f6_row15_col0" class="data row15 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b53f6_level0_row16" class="row_heading level0 row16" >Blaine</th>
#       <td id="T_b53f6_row16_col0" class="data row16 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b53f6_level0_row17" class="row_heading level0 row17" >C4AF</th>
#       <td id="T_b53f6_row17_col0" class="data row17 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b53f6_level0_row18" class="row_heading level0 row18" >Initial setting time</th>
#       <td id="T_b53f6_row18_col0" class="data row18 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b53f6_level0_row19" class="row_heading level0 row19" >Final setting time</th>
#       <td id="T_b53f6_row19_col0" class="data row19 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b53f6_level0_row20" class="row_heading level0 row20" >CS3</th>
#       <td id="T_b53f6_row20_col0" class="data row20 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b53f6_level0_row21" class="row_heading level0 row21" >Loss on Ignition</th>
#       <td id="T_b53f6_row21_col0" class="data row21 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b53f6_level0_row22" class="row_heading level0 row22" >CS7</th>
#       <td id="T_b53f6_row22_col0" class="data row22 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b53f6_level0_row23" class="row_heading level0 row23" >Insoluble Residue</th>
#       <td id="T_b53f6_row23_col0" class="data row23 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b53f6_level0_row24" class="row_heading level0 row24" >Na2O</th>
#       <td id="T_b53f6_row24_col0" class="data row24 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b53f6_level0_row25" class="row_heading level0 row25" >Fe2O3</th>
#       <td id="T_b53f6_row25_col0" class="data row25 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b53f6_level0_row26" class="row_heading level0 row26" >K2O</th>
#       <td id="T_b53f6_row26_col0" class="data row26 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b53f6_level0_row27" class="row_heading level0 row27" >SO3</th>
#       <td id="T_b53f6_row27_col0" class="data row27 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b53f6_level0_row28" class="row_heading level0 row28" >SiO2</th>
#       <td id="T_b53f6_row28_col0" class="data row28 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b53f6_level0_row29" class="row_heading level0 row29" >Al2O3</th>
#       <td id="T_b53f6_row29_col0" class="data row29 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b53f6_level0_row30" class="row_heading level0 row30" >C3A</th>
#       <td id="T_b53f6_row30_col0" class="data row30 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b53f6_level0_row31" class="row_heading level0 row31" >MgO</th>
#       <td id="T_b53f6_row31_col0" class="data row31 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b53f6_level0_row32" class="row_heading level0 row32" >CaO</th>
#       <td id="T_b53f6_row32_col0" class="data row32 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b53f6_level0_row33" class="row_heading level0 row33" >Cubic C3A</th>
#       <td id="T_b53f6_row33_col0" class="data row33 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b53f6_level0_row34" class="row_heading level0 row34" >CS28</th>
#       <td id="T_b53f6_row34_col0" class="data row34 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <h3>Percentage of zero values:</h3>
# <table>
#     <th>Plant A - Full Dataset:</th>
#     <th></th>
#     <tr>
#         <td>Dolimita</td>
#         <td>95.74</td>
#     </tr>
#     <tr>
#         <td>Arcanite</td>
#         <td>69.57</td>
#     </tr>
#     <tr>
#         <td>#200</td>
#         <td>41.59</td>
#     </tr>
#     <tr>
#         <td>Langbeinite</td>
#         <td>34.25</td>
#     </tr>
#     <tr>
#         <td>Free CaO</td>
#         <td>15.51</td>
#     </tr>
#     <tr>
#         <td>Aphthitalite</td>
#         <td>11.01</td>
#     </tr>
# </table>

# %%
FEATRUES_TO_DROP = [
    "Dolimita",
    "Arcanite",
    "Langbeinite",
    "#200",
    "Free CaO",
    "Aphthitalite",
]
df = df.drop(labels=FEATRUES_TO_DROP, axis=1)

# %% [markdown]
# ### Dropping variable with City and Plant identification

# %%
FEATRUES_TO_DROP = ["City", "Plant"]
df = df.drop(labels=FEATRUES_TO_DROP, axis=1)

# %% [markdown]
# ### Dropping rows where the target variable is null

# %%
df = df[df["CS28"].notna()]

# %% [markdown]
# ### Dropping rows where the target variable is zero

# %%
df = df[~df["CS28"].eq(0)]

# %%
df.shape
# Out:
# (2044, 31)

# %%
# df.describe().T

# %%
# df_copy = df.copy()

# %% [markdown]
# ### Dropping rows where any other variable has a zero value

# %%
for col in df.columns:
    df = df[~df[col].eq(0)]

# %%
df.shape
# Out:
# (1966, 31)

# %%
(df.isna().sum() / df.shape[0] * 100).sort_values(ascending=False).to_frame(
    name="Missing (%)"
).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_a2206_row0_col0, #T_a2206_row1_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_a2206_row2_col0 {
#   background-color: #fca689;
#   color: #000000;
# }
# #T_a2206_row3_col0 {
#   background-color: #fca78b;
#   color: #000000;
# }
# #T_a2206_row4_col0 {
#   background-color: #fcbba1;
#   color: #000000;
# }
# #T_a2206_row5_col0 {
#   background-color: #fdcab5;
#   color: #000000;
# }
# #T_a2206_row6_col0, #T_a2206_row7_col0, #T_a2206_row8_col0, #T_a2206_row9_col0, #T_a2206_row10_col0 {
#   background-color: #fee5d9;
#   color: #000000;
# }
# #T_a2206_row11_col0, #T_a2206_row12_col0, #T_a2206_row13_col0 {
#   background-color: #fee9df;
#   color: #000000;
# }
# #T_a2206_row14_col0, #T_a2206_row15_col0 {
#   background-color: #fff2ec;
#   color: #000000;
# }
# #T_a2206_row16_col0, #T_a2206_row17_col0, #T_a2206_row18_col0, #T_a2206_row19_col0, #T_a2206_row20_col0, #T_a2206_row21_col0, #T_a2206_row22_col0, #T_a2206_row23_col0, #T_a2206_row24_col0, #T_a2206_row25_col0, #T_a2206_row26_col0, #T_a2206_row27_col0, #T_a2206_row28_col0, #T_a2206_row29_col0, #T_a2206_row30_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_a2206">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a2206_level0_col0" class="col_heading level0 col0" >Missing (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a2206_level0_row0" class="row_heading level0 row0" >Cubic C3A</th>
#       <td id="T_a2206_row0_col0" class="data row0 col0" >13.784334</td>
#     </tr>
#     <tr>
#       <th id="T_a2206_level0_row1" class="row_heading level0 row1" >Orthorhombic C3A</th>
#       <td id="T_a2206_row1_col0" class="data row1 col0" >13.784334</td>
#     </tr>
#     <tr>
#       <th id="T_a2206_level0_row2" class="row_heading level0 row2" >TiO2</th>
#       <td id="T_a2206_row2_col0" class="data row2 col0" >4.323499</td>
#     </tr>
#     <tr>
#       <th id="T_a2206_level0_row3" class="row_heading level0 row3" >#400</th>
#       <td id="T_a2206_row3_col0" class="data row3 col0" >4.272635</td>
#     </tr>
#     <tr>
#       <th id="T_a2206_level0_row4" class="row_heading level0 row4" >Insoluble Residue</th>
#       <td id="T_a2206_row4_col0" class="data row4 col0" >3.458800</td>
#     </tr>
#     <tr>
#       <th id="T_a2206_level0_row5" class="row_heading level0 row5" >Loss on Ignition</th>
#       <td id="T_a2206_row5_col0" class="data row5 col0" >2.797558</td>
#     </tr>
#     <tr>
#       <th id="T_a2206_level0_row6" class="row_heading level0 row6" >Quartz</th>
#       <td id="T_a2206_row6_col0" class="data row6 col0" >1.322482</td>
#     </tr>
#     <tr>
#       <th id="T_a2206_level0_row7" class="row_heading level0 row7" >C3A</th>
#       <td id="T_a2206_row7_col0" class="data row7 col0" >1.322482</td>
#     </tr>
#     <tr>
#       <th id="T_a2206_level0_row8" class="row_heading level0 row8" >Bassanite</th>
#       <td id="T_a2206_row8_col0" class="data row8 col0" >1.322482</td>
#     </tr>
#     <tr>
#       <th id="T_a2206_level0_row9" class="row_heading level0 row9" >Calcite</th>
#       <td id="T_a2206_row9_col0" class="data row9 col0" >1.322482</td>
#     </tr>
#     <tr>
#       <th id="T_a2206_level0_row10" class="row_heading level0 row10" >Muscovite</th>
#       <td id="T_a2206_row10_col0" class="data row10 col0" >1.322482</td>
#     </tr>
#     <tr>
#       <th id="T_a2206_level0_row11" class="row_heading level0 row11" >Portlandite</th>
#       <td id="T_a2206_row11_col0" class="data row11 col0" >1.017294</td>
#     </tr>
#     <tr>
#       <th id="T_a2206_level0_row12" class="row_heading level0 row12" >Periclase</th>
#       <td id="T_a2206_row12_col0" class="data row12 col0" >1.017294</td>
#     </tr>
#     <tr>
#       <th id="T_a2206_level0_row13" class="row_heading level0 row13" >C4AF</th>
#       <td id="T_a2206_row13_col0" class="data row13 col0" >1.017294</td>
#     </tr>
#     <tr>
#       <th id="T_a2206_level0_row14" class="row_heading level0 row14" >CaO</th>
#       <td id="T_a2206_row14_col0" class="data row14 col0" >0.254323</td>
#     </tr>
#     <tr>
#       <th id="T_a2206_level0_row15" class="row_heading level0 row15" >Al2O3</th>
#       <td id="T_a2206_row15_col0" class="data row15 col0" >0.254323</td>
#     </tr>
#     <tr>
#       <th id="T_a2206_level0_row16" class="row_heading level0 row16" >SiO2</th>
#       <td id="T_a2206_row16_col0" class="data row16 col0" >0.050865</td>
#     </tr>
#     <tr>
#       <th id="T_a2206_level0_row17" class="row_heading level0 row17" >Fe2O3</th>
#       <td id="T_a2206_row17_col0" class="data row17 col0" >0.050865</td>
#     </tr>
#     <tr>
#       <th id="T_a2206_level0_row18" class="row_heading level0 row18" >Na2O</th>
#       <td id="T_a2206_row18_col0" class="data row18 col0" >0.050865</td>
#     </tr>
#     <tr>
#       <th id="T_a2206_level0_row19" class="row_heading level0 row19" >K2O</th>
#       <td id="T_a2206_row19_col0" class="data row19 col0" >0.050865</td>
#     </tr>
#     <tr>
#       <th id="T_a2206_level0_row20" class="row_heading level0 row20" >SO3</th>
#       <td id="T_a2206_row20_col0" class="data row20 col0" >0.050865</td>
#     </tr>
#     <tr>
#       <th id="T_a2206_level0_row21" class="row_heading level0 row21" >MgO</th>
#       <td id="T_a2206_row21_col0" class="data row21 col0" >0.050865</td>
#     </tr>
#     <tr>
#       <th id="T_a2206_level0_row22" class="row_heading level0 row22" >Final setting time</th>
#       <td id="T_a2206_row22_col0" class="data row22 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a2206_level0_row23" class="row_heading level0 row23" >CS28</th>
#       <td id="T_a2206_row23_col0" class="data row23 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a2206_level0_row24" class="row_heading level0 row24" >CS7</th>
#       <td id="T_a2206_row24_col0" class="data row24 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a2206_level0_row25" class="row_heading level0 row25" >CS3</th>
#       <td id="T_a2206_row25_col0" class="data row25 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a2206_level0_row26" class="row_heading level0 row26" >Date</th>
#       <td id="T_a2206_row26_col0" class="data row26 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a2206_level0_row27" class="row_heading level0 row27" >Initial setting time</th>
#       <td id="T_a2206_row27_col0" class="data row27 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a2206_level0_row28" class="row_heading level0 row28" >#325</th>
#       <td id="T_a2206_row28_col0" class="data row28 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a2206_level0_row29" class="row_heading level0 row29" >Blaine</th>
#       <td id="T_a2206_row29_col0" class="data row29 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a2206_level0_row30" class="row_heading level0 row30" >Cement_Type</th>
#       <td id="T_a2206_row30_col0" class="data row30 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Dropping rows with increased missing values after preprocessing

# %% [markdown]
# <h3>Percentage of missing values:</h3>
# <table>
# </table>

# %%
# FEATRUES_TO_DROP = ["C3A", "Aphthitalite"]
# df = df.drop(labels=FEATRUES_TO_DROP, axis=1)

# %%
# (df.isna().sum() / df.shape[0] * 100).sort_values(ascending=False).to_frame(
#     name="Missing (%)"
# ).style.background_gradient(cmap="Reds")

# %%
df.describe().T
# Out:
#                        count                           mean  \
# Date                    1966  2022-04-12 00:17:34.730417152
# C4AF                  1946.0                       7.413248
# C3A                   1940.0                       2.451129
# Cubic C3A             1695.0                       2.197917
# Orthorhombic C3A      1695.0                       0.494283
# Portlandite           1946.0                       1.102852
# Periclase             1946.0                       0.442754
# Bassanite             1940.0                       1.295526
# Calcite               1940.0                       5.930041
# Quartz                1940.0                       1.044201
# Muscovite             1940.0                       0.343541
# CaO                   1961.0                      58.150607
# MgO                   1965.0                       2.543207
# Na2O                  1965.0                       0.269385
# Al2O3                 1961.0                       6.245308
# SiO2                  1965.0                      21.872839
# SO3                   1965.0                       3.549636
# K2O                   1965.0                       0.509776
# TiO2                  1881.0                        0.27935
# Fe2O3                 1965.0                       2.700317
# Loss on Ignition      1911.0                       4.152433
# Insoluble Residue     1898.0                       1.395574
# Blaine                1966.0                    5265.788403
# #325                  1966.0                       0.509578
# #400                  1882.0                       1.584054
# Initial setting time  1966.0                     175.322991
# Final setting time    1966.0                     239.935402
# CS3                   1966.0                       30.65763
# CS7                   1966.0                      38.718413
# CS28                  1966.0                      48.937721
#
#                                       min                  25%  \
# Date                  2021-01-04 00:00:00  2021-08-19 00:00:00
# C4AF                                 1.89               6.0425
# C3A                                  0.34                  1.7
# Cubic C3A                            0.02                  1.6
# Orthorhombic C3A                     0.01                 0.01
# Portlandite                          0.03                 0.67
# Periclase                            0.02                 0.31
# Bassanite                            0.03                 0.93
# Calcite                              0.42                 4.48
# Quartz                               0.02                  0.7
# Muscovite                            0.01                 0.23
# CaO                                 45.75            55.599998
# MgO                               1.30353              1.83124
# Na2O                              0.08231              0.23381
# Al2O3                                1.71                 4.92
# SiO2                            16.807381            19.139999
# SO3                                  2.42                 3.14
# K2O                                  0.37                 0.48
# TiO2                                0.123                0.215
# Fe2O3                             1.08788                 2.37
# Loss on Ignition                     1.23                 3.61
# Insoluble Residue                    0.31               1.0625
# Blaine                             4390.0               4820.0
# #325                                 0.01                  0.3
# #400                                 0.02                  0.8
# Initial setting time                 90.0                140.0
# Final setting time                  130.0                200.0
# CS3                                  14.1               25.125
# CS7                                  25.0            36.200001
# CS28                                 36.0            47.599998
#
#                                       50%                  75%  \
# Date                  2022-04-12 00:00:00  2022-12-03 00:00:00
# C4AF                                 8.32                 9.11
# C3A                                  2.31                 3.21
# Cubic C3A                            2.06                2.555
# Orthorhombic C3A                     0.35                 0.84
# Portlandite                         1.035                 1.42
# Periclase                            0.44                 0.56
# Bassanite                            1.26                 1.63
# Calcite                              5.26               7.3025
# Quartz                               0.93                 1.26
# Muscovite                            0.39                 0.47
# CaO                             60.009998            61.167801
# MgO                                   2.2                 2.99
# Na2O                                 0.26                 0.29
# Al2O3                                5.59                  7.0
# SiO2                            21.190001                23.33
# SO3                               3.44418                 3.92
# K2O                                   0.5                 0.54
# TiO2                                 0.26                0.328
# Fe2O3                                2.93              3.12218
# Loss on Ignition                     4.16                 4.63
# Insoluble Residue                    1.29                 1.61
# Blaine                             4980.0               5960.0
# #325                                  0.4                  0.7
# #400                                  1.4                  2.1
# Initial setting time                170.0                200.0
# Final setting time                  220.0                270.0
# CS3                                  32.5            37.074999
# CS7                             39.299999                 42.0
# CS28                            49.400002            51.400002
#
#                                       max         std
# Date                  2023-07-17 00:00:00         NaN
# C4AF                                11.56    2.321772
# C3A                                  7.56    1.134442
# Cubic C3A                            7.55    0.927621
# Orthorhombic C3A                     3.24    0.504097
# Portlandite                          4.29    0.599619
# Periclase                            1.52    0.185082
# Bassanite                            3.56     0.53886
# Calcite                              13.3    1.978259
# Quartz                               6.58     0.52976
# Muscovite                             0.6    0.138789
# CaO                             65.941788    4.569871
# MgO                                  5.88    0.923705
# Na2O                                 0.52    0.053988
# Al2O3                               11.56    1.673931
# SiO2                                31.17    3.195766
# SO3                               5.59581     0.51145
# K2O                               0.71423    0.048911
# TiO2                                0.551    0.074641
# Fe2O3                                3.83     0.61552
# Loss on Ignition                     7.15    0.738924
# Insoluble Residue                    4.41    0.491619
# Blaine                             6810.0  577.236343
# #325                                  3.6    0.378761
# #400                                  7.6    0.990679
# Initial setting time                355.0   44.676262
# Final setting time                 2015.0   72.664907
# CS3                                  43.0     7.48021
# CS7                             48.599998     4.67067
# CS28                                 57.5    3.699543

# %%
df.describe(exclude="number").T
# Out:
#             count unique   top freq                           mean  \
# Date         1966    NaN   NaN  NaN  2022-04-12 00:17:34.730417152
# Cement_Type  1966      5  CP I  635                            NaN
#
#                              min                  25%                  50%  \
# Date         2021-01-04 00:00:00  2021-08-19 00:00:00  2022-04-12 00:00:00
# Cement_Type                  NaN                  NaN                  NaN
#
#                              75%                  max
# Date         2022-12-03 00:00:00  2023-07-17 00:00:00
# Cement_Type                  NaN                  NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1966 entries, 0 to 2043
# Data columns (total 31 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  1966 non-null   datetime64[ns]
#  1   C4AF                  1946 non-null   float64
#  2   C3A                   1940 non-null   float64
#  3   Cubic C3A             1695 non-null   float64
#  4   Orthorhombic C3A      1695 non-null   float64
#  5   Portlandite           1946 non-null   float64
#  6   Periclase             1946 non-null   float64
#  7   Bassanite             1940 non-null   float64
#  8   Calcite               1940 non-null   float64
#  9   Quartz                1940 non-null   float64
#  10  Muscovite             1940 non-null   float64
#  11  CaO                   1961 non-null   float64
#  12  MgO                   1965 non-null   float64
#  13  Na2O                  1965 non-null   float64
#  14  Al2O3                 1961 non-null   float64
#  15  SiO2                  1965 non-null   float64
#  16  SO3                   1965 non-null   float64
#  17  K2O                   1965 non-null   float64
#  18  TiO2                  1881 non-null   float64
#  19  Fe2O3                 1965 non-null   float64
#  20  Loss on Ignition      1911 non-null   float64
#  21  Insoluble Residue     1898 non-null   float64
#  22  Blaine                1966 non-null   float64
#  23  #325                  1966 non-null   float64
#  24  #400                  1882 non-null   float64
#  25  Initial setting time  1966 non-null   float64
#  26  Final setting time    1966 non-null   float64
#  27  CS3                   1966 non-null   float64
#  28  CS7                   1966 non-null   float64
#  29  CS28                  1966 non-null   float64
#  30  Cement_Type           1966 non-null   object
# dtypes: datetime64[ns](1), float64(29), object(1)
# memory usage: 491.5+ KB

# %% [markdown]
# ### Sort the dataset by date

# %%
# We first make sure Date column was infered correctly
df["Date"].dtype
# Out:
# dtype('<M8[ns]')

# %%
df = df.sort_values(by="Date")

# %% [markdown]
# ## Saving the dataset

# %% [markdown]
# <h3>Saving for feature engineering</h3>

# %%
df.to_csv("../../../data/interim/209/az.csv", index=False)
