# %%
# %load_ext nb_black

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

from scipy.stats import pearsonr
from collections import Counter

# %%
def convert_to_float(value):
    try:
        # If it's a string enclosed in single quotes, remove quotes and replace comma with dot
        if isinstance(value, str):
            return float(value.replace(",", "."))
        else:
            return float(value)
    except ValueError as e:
        # print(e)
        return float("nan")

# %%
def preprocess_numeric_cols(df, columns):
    for col in columns:
        df[col] = df[col].astype(str)  # Ensure string type for string operations
        df[col] = df[col].str.replace("#", "")  # Remove '#' characters
        df[col] = df[col].str.replace(",", ".")  # Replace ',' with '.' for decimals
    return df

# %% [markdown]
# # Data preparation - 209 plant AM data

# %% [markdown]
# ### Reading the files and extracting relevant information:

# %%
plant = "AM"
xls_files = {}

xls = pd.ExcelFile(
    f"../../../../data/raw/209/EMBRAPII hubIC IACC_CIMENTO_{plant}.xlsx",
    engine="openpyxl",
)
xls_files[plant] = xls

# %%
print("Plant: ", plant, xls.sheet_names)
# Out:
# Plant:  AM ['INSTRUÇÕES', 'Clínquer', '185', '96', '15', '22', '20', '57', '107', '64']

# %%
cement_types_per_plant = []
CEMENT_TYPE_COLS = ["Tipo de cimento", "Classe de resistência"]
dataframes = []

for plant, xls in xls_files.items():
    for sheet_name in xls.sheet_names[2:]:
        df = pd.read_excel(xls_files[plant], sheet_name, header=[1, 2])

        if not df[CEMENT_TYPE_COLS].iloc[2:].isna().all().all():
            cement_type = (
                df[CEMENT_TYPE_COLS]
                .loc[2:]
                .astype(str)
                .sum(axis=1)
                .str.replace(" ", "")
                .str.replace("-", "")
                .str.replace("nan", "")
                .unique()
            )

        else:
            cement_type = (
                df[[("Obs.", "Unnamed: 8_level_1")]]
                .loc[2:]
                .astype(str)
                .sum(axis=1)
                .str.replace(" ", "")
                .str.replace("-", "")
                .unique()
            )

        cement_types_per_plant.append((plant, sheet_name, cement_type))
        dataframes.append(df)

# %%
cement_types_per_plant
# Out:
# [('AM', '185', array(['CPIIF40'], dtype=object)),
#  ('AM', '96', array(['CPIV32'], dtype=object)),
#  ('AM', '15', array(['CPVARI'], dtype=object)),
#  ('AM', '22', array(['CPIIF32'], dtype=object)),
#  ('AM', '20', array(['CPIIFFIBRO40'], dtype=object)),
#  ('AM', '57', array(['CPIIZ32'], dtype=object)),
#  ('AM', '107', array(['CPIIZ40'], dtype=object)),
#  ('AM', '64', array(['CPVARI'], dtype=object))]

# %%
cements = []
for tup in cement_types_per_plant:
    cements.append(tup[2][0])
Counter(cements)
# Out:
# Counter({'CPVARI': 2,
#          'CPIIF40': 1,
#          'CPIV32': 1,
#          'CPIIF32': 1,
#          'CPIIFFIBRO40': 1,
#          'CPIIZ32': 1,
#          'CPIIZ40': 1})

# %%
dataframes = []

for plant, xls in xls_files.items():
    for sheet_name in xls.sheet_names[2:]:
        df = pd.read_excel(xls_files[plant], sheet_name, header=[0, 1, 2])
        df["Unnamed: 0_level_0", "Unnamed: 0_level_1", "Unnamed: 0_level_2"] = plant
        dataframes.append(df.drop([0, 1], axis=0).reset_index(drop=True).copy())

# %%
df = pd.concat(dataframes, axis=0).reset_index(drop=True)

# %% [markdown]
# ## Initial Preprocessing

# %%
df = pd.concat(
    [
        df["Unnamed: 0_level_0", "Unnamed: 0_level_1", "Unnamed: 0_level_2"],
        df["Dados iniciais"],
        df["Cimento"]["Composição"].rename(
            {"Sulfato de cálcio": "Sulfato de cálcio (composição)"}, axis=1
        ),
        df["Cimento"]["Análise mineralógica"],
        df["Cimento"]["Análise química"],
        df["Característias físicas do cimento"],
        df["Propriedades do cimento"],
    ],
    axis=1,
)

# %%
# df.info()

# %% [markdown]
# ### 1. Dropping columns where either there is no data nor it contributes to the analysis
# ### 2. Renaming columns to a short identifiable name

# %%
COLUMNS_TO_DROP = [
    ("Data", "Medida"),
    ("Horário", "Produção"),
    ("Horário", "Medida"),
    ("Obs.", "Unnamed: 148_level_2"),
    ("Tipo de cimento", "Unnamed: 6_level_2"),
    ("Classe de resistência", "Unnamed: 7_level_2"),
    ("Obs.", "Unnamed: 8_level_2"),
    "Obs.",
    ("Obs.", "Unnamed: 148_level_2"),
    ("Unnamed: 141_level_1", "Obs."),
    # ("Unnamed: 139_level_1", "#400"),
]

COLUMNS_TO_RENAME = {
    ("Unnamed: 0_level_0", "Unnamed: 0_level_1", "Unnamed: 0_level_2"): "Plant",
    ("Cidade", "Unnamed: 1_level_2"): "City",
    ("Data", "Produção"): "Date",  # Arrumar!
    ("Unnamed: 136_level_1", "Blaine"): "Blaine",
    ("Unnamed: 137_level_1", "#200"): "#200",
    ("Unnamed: 138_level_1", "#325"): "#325",
    ("Unnamed: 139_level_1", "#400"): "#400",
    ("Unnamed: 140_level_1", "Massa específica"): "Specific Gravity",
    ("Tempo de pega", "Inicio"): "Initial setting time",
    ("Tempo de pega", "Fim"): "Final setting time",
    ("Resistência à compressão", "1 d"): "CS1",
    ("Resistência à compressão", "3 d"): "CS3",
    ("Resistência à compressão", "7 d"): "CS7",
    ("Resistência à compressão", "28 d"): "CS28",
    "Perda ao fogo": "Loss on Ignition",
    "Resíduo insolúvel": "Insoluble Residue",
    "Clínquer": "Clinker",
    "Fíler calcário": "Calcareous filler",
    "Cinza volante": "Fly ash",
    "Escória": "Slag",
    "Argila calcinada": "Calcined clay",
    "Sulfato de cálcio": "Calcium sulfate",
    "C3S total": "Total C3S",
    "C2S total": "Total C2S",
    "C2S alpha": "Alpha C2S",
    "C2S beta": "Beta C2S",
    "C2S gama": "Gamma C2S",
    "C4AF": "C4AF",
    "C3A": "C3A",
    "C3A cubic": "Cubic C3A",
    "C3A orto": "Orthorhombic C3A",
    "CaO livre": "Free CaO",
    "Portlandita": "Portlandite",
    "Periclasio": "Periclase",
    "Arcanita": "Arcanite",
    "Aphthalita": "Aphthitalite",
    "Langbeinita": "Langbeinite",
    "Bassanita": "Bassanite",
    "Anidrita": "Anhydrite",
    "Calcita": "Calcite",
    "Dolomita": "Dolomite",
    "Quartzo": "Quartz",
    "Muscovita": "Muscovite",
    "Sulfato de cálcio (composição)": "Calcium sulfate (composition)",
}

# %% [markdown]
# ### Defining a single variable to identify Cement Type

# %%
# Single variable for the Cement Type
df["Cement_Type"] = (
    df[
        [
            ("Tipo de cimento", "Unnamed: 6_level_2"),
            ("Classe de resistência", "Unnamed: 7_level_2"),
            ("Obs.", "Unnamed: 8_level_2"),
        ]
    ]
    .fillna("")
    .astype(str)
    .sum(axis=1)
)

# # Preprocessing
df["Cement_Type"] = df["Cement_Type"].replace("Fibro", "Fibrocimento")

# Preprocessing
df["Cement_Type"] = (
    df["Cement_Type"]
    .str.replace("Expedido", "")
    .str.replace("Linha 9", "")
    .str.replace("Itajaí", "")
    .str.replace("D-G", "")
    .str.replace("D-E", "")
    .str.replace("DF2", "")
    .str.replace("CPIIF40", "CP II-F-40")
    .str.replace("CPIIF40", "CP II-F40")
    .str.replace("CP VARI", "CP V-ARI")
    .str.replace("CPVARI", "CP V-ARI")
    .str.replace("CP V-RSARI", "CP V-ARI RS")
    .str.replace("CP III-RS40", "CP III-40 RS")
    .str.replace("CP III-RS32", "CP III-32 RS")
    .str.replace("CP IV-RS32", "CP IV-32 RS")
    .str.replace("CP III40", "CP III-40")
    .str.replace("CP III32", "CP III-32")
    .str.replace("CP I-S40", "CP I-S-40")
    .str.replace("CP I40", "CP I-40")
    .str.replace("CP II-E32", "CP II-E-32")
    .str.replace("CP II-E40", "CP II-E-40")
    .str.replace("CP II-F FIBRO40", "CP II-F-40")
    .str.replace("CP II-F32", "CP II-F-32")
    .str.replace("CP II-F40", "CP II-F-40")
    .str.replace("CP II-Z32", "CP II-Z-32")
    .str.replace("CP II-Z40", "CP II-Z-40")
    .str.replace("CP IV32", "CP IV-32")
    .str.replace("CP IND", "CP I")
    .str.replace("CPINDCC", "CP I")
    .str.strip()
)

df = df.drop(COLUMNS_TO_DROP, axis=1).rename(COLUMNS_TO_RENAME, axis=1).copy()
df = df.drop([0]).reset_index(drop=True)
df = df.infer_objects()

# %% [markdown]
# ### Dropping and rename the columns defined above

# %% [markdown]
# ### Cleaning and converting numeric columns to float

# %%
NUMERIC_COLUMNS = [
    "Calcium sulfate (composition)",
    "Clinker",
    "Calcareous filler",
    "Fly ash",
    "Slag",
    "Calcined clay",
    "Calcium sulfate",
    "Total C3S",
    "Total C2S",
    "Alpha C2S",
    "Beta C2S",
    "Gamma C2S",
    "C4AF",
    "C3A",
    "Cubic C3A",
    "Orthorhombic C3A",
    "Free CaO",
    "Portlandite",
    "Periclase",
    "Arcanite",
    "Aphthitalite",
    "Langbeinite",
    "Bassanite",
    "Anhydrite",
    "Calcite",
    "Dolimita",
    "Quartz",
    "Muscovite",
    "CaO",
    "MgO",
    "Na2O",
    "Al2O3",
    "SiO2",
    "SO3",
    "K2O",
    "TiO2",
    "Fe2O3",
    "Loss on Ignition",
    "Insoluble Residue",
    "Blaine",
    "#200",
    "#325",
    "#400",
    "Specific Gravity",
    "Final setting time",
    "Initial setting time",
    "CS1",
    "CS3",
    "CS7",
    "CS28",
]

df = preprocess_numeric_cols(df, NUMERIC_COLUMNS)

# Preprocessing to fix numeric columns
df[NUMERIC_COLUMNS] = df[NUMERIC_COLUMNS].map(convert_to_float)

# Converting Date to pandas datetime
df["Date"] = pd.to_datetime(df["Date"])

# Drop rows completely missing
index_to_keep = (
    df.drop(["Plant", "Date", "Cement_Type"], axis=1).dropna(axis=0, how="all").index
)
df = df.iloc[index_to_keep].reset_index(drop=True)

df = df.infer_objects()

# %% [markdown]
# ## Dropping missing features

# %% [markdown]
# ### Drop rows completely missing

# %%
index_to_keep = (
    df.drop(["Plant", "City", "Date", "Cement_Type"], axis=1)
    .dropna(axis=0, how="all")
    .index
)
df = df.iloc[index_to_keep].reset_index(drop=True)

# %% [markdown]
# ### Removing features
#  that will be fitted on this data.
#
# 1. Removing features with features having ~50% or more of missing values
# 2. Removing features with zero variance
# 3. Removing features with more than 70% of zeros

# %%
(df.isna().sum() / df.shape[0] * 100).sort_values(ascending=False).to_frame(
    name="Missing (%)"
).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_e635b_row0_col0, #T_e635b_row1_col0, #T_e635b_row2_col0, #T_e635b_row3_col0, #T_e635b_row4_col0, #T_e635b_row5_col0, #T_e635b_row6_col0, #T_e635b_row7_col0, #T_e635b_row8_col0, #T_e635b_row9_col0, #T_e635b_row10_col0, #T_e635b_row11_col0, #T_e635b_row12_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_e635b_row13_col0 {
#   background-color: #6d010e;
#   color: #f1f1f1;
# }
# #T_e635b_row14_col0, #T_e635b_row15_col0, #T_e635b_row16_col0 {
#   background-color: #8c0912;
#   color: #f1f1f1;
# }
# #T_e635b_row17_col0 {
#   background-color: #980c13;
#   color: #f1f1f1;
# }
# #T_e635b_row18_col0 {
#   background-color: #9c0d14;
#   color: #f1f1f1;
# }
# #T_e635b_row19_col0 {
#   background-color: #a10e15;
#   color: #f1f1f1;
# }
# #T_e635b_row20_col0 {
#   background-color: #a30f15;
#   color: #f1f1f1;
# }
# #T_e635b_row21_col0 {
#   background-color: #ac1117;
#   color: #f1f1f1;
# }
# #T_e635b_row22_col0, #T_e635b_row23_col0 {
#   background-color: #b21218;
#   color: #f1f1f1;
# }
# #T_e635b_row24_col0, #T_e635b_row25_col0, #T_e635b_row26_col0, #T_e635b_row27_col0 {
#   background-color: #b71319;
#   color: #f1f1f1;
# }
# #T_e635b_row28_col0 {
#   background-color: #c8171c;
#   color: #f1f1f1;
# }
# #T_e635b_row29_col0, #T_e635b_row30_col0 {
#   background-color: #e32f27;
#   color: #f1f1f1;
# }
# #T_e635b_row31_col0 {
#   background-color: #e93529;
#   color: #f1f1f1;
# }
# #T_e635b_row32_col0 {
#   background-color: #feeae1;
#   color: #000000;
# }
# #T_e635b_row33_col0 {
#   background-color: #fff0e9;
#   color: #000000;
# }
# #T_e635b_row34_col0, #T_e635b_row35_col0, #T_e635b_row36_col0 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_e635b_row37_col0, #T_e635b_row38_col0, #T_e635b_row39_col0, #T_e635b_row40_col0, #T_e635b_row41_col0, #T_e635b_row42_col0, #T_e635b_row43_col0, #T_e635b_row44_col0, #T_e635b_row45_col0, #T_e635b_row46_col0, #T_e635b_row47_col0, #T_e635b_row48_col0, #T_e635b_row49_col0, #T_e635b_row50_col0, #T_e635b_row51_col0, #T_e635b_row52_col0, #T_e635b_row53_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_e635b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e635b_level0_col0" class="col_heading level0 col0" >Missing (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e635b_level0_row0" class="row_heading level0 row0" >Calcite</th>
#       <td id="T_e635b_row0_col0" class="data row0 col0" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e635b_level0_row1" class="row_heading level0 row1" >Alpha C2S</th>
#       <td id="T_e635b_row1_col0" class="data row1 col0" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e635b_level0_row2" class="row_heading level0 row2" >Specific Gravity</th>
#       <td id="T_e635b_row2_col0" class="data row2 col0" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e635b_level0_row3" class="row_heading level0 row3" >TiO2</th>
#       <td id="T_e635b_row3_col0" class="data row3 col0" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e635b_level0_row4" class="row_heading level0 row4" >Muscovite</th>
#       <td id="T_e635b_row4_col0" class="data row4 col0" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e635b_level0_row5" class="row_heading level0 row5" >Arcanite</th>
#       <td id="T_e635b_row5_col0" class="data row5 col0" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e635b_level0_row6" class="row_heading level0 row6" >Gamma C2S</th>
#       <td id="T_e635b_row6_col0" class="data row6 col0" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e635b_level0_row7" class="row_heading level0 row7" >Calcium sulfate</th>
#       <td id="T_e635b_row7_col0" class="data row7 col0" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e635b_level0_row8" class="row_heading level0 row8" >Calcined clay</th>
#       <td id="T_e635b_row8_col0" class="data row8 col0" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e635b_level0_row9" class="row_heading level0 row9" >Slag</th>
#       <td id="T_e635b_row9_col0" class="data row9 col0" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e635b_level0_row10" class="row_heading level0 row10" >Clinker</th>
#       <td id="T_e635b_row10_col0" class="data row10 col0" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e635b_level0_row11" class="row_heading level0 row11" >Calcareous filler</th>
#       <td id="T_e635b_row11_col0" class="data row11 col0" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e635b_level0_row12" class="row_heading level0 row12" >Fly ash</th>
#       <td id="T_e635b_row12_col0" class="data row12 col0" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e635b_level0_row13" class="row_heading level0 row13" >Beta C2S</th>
#       <td id="T_e635b_row13_col0" class="data row13 col0" >98.574879</td>
#     </tr>
#     <tr>
#       <th id="T_e635b_level0_row14" class="row_heading level0 row14" >Total C2S</th>
#       <td id="T_e635b_row14_col0" class="data row14 col0" >92.439614</td>
#     </tr>
#     <tr>
#       <th id="T_e635b_level0_row15" class="row_heading level0 row15" >Quartz</th>
#       <td id="T_e635b_row15_col0" class="data row15 col0" >92.439614</td>
#     </tr>
#     <tr>
#       <th id="T_e635b_level0_row16" class="row_heading level0 row16" >Anhydrite</th>
#       <td id="T_e635b_row16_col0" class="data row16 col0" >92.439614</td>
#     </tr>
#     <tr>
#       <th id="T_e635b_level0_row17" class="row_heading level0 row17" >C3A</th>
#       <td id="T_e635b_row17_col0" class="data row17 col0" >89.975845</td>
#     </tr>
#     <tr>
#       <th id="T_e635b_level0_row18" class="row_heading level0 row18" >Bassanite</th>
#       <td id="T_e635b_row18_col0" class="data row18 col0" >89.299517</td>
#     </tr>
#     <tr>
#       <th id="T_e635b_level0_row19" class="row_heading level0 row19" >Total C3S</th>
#       <td id="T_e635b_row19_col0" class="data row19 col0" >88.043478</td>
#     </tr>
#     <tr>
#       <th id="T_e635b_level0_row20" class="row_heading level0 row20" >Calcium sulfate (composition)</th>
#       <td id="T_e635b_row20_col0" class="data row20 col0" >87.874396</td>
#     </tr>
#     <tr>
#       <th id="T_e635b_level0_row21" class="row_heading level0 row21" >#400</th>
#       <td id="T_e635b_row21_col0" class="data row21 col0" >84.975845</td>
#     </tr>
#     <tr>
#       <th id="T_e635b_level0_row22" class="row_heading level0 row22" >Cubic C3A</th>
#       <td id="T_e635b_row22_col0" class="data row22 col0" >82.898551</td>
#     </tr>
#     <tr>
#       <th id="T_e635b_level0_row23" class="row_heading level0 row23" >Orthorhombic C3A</th>
#       <td id="T_e635b_row23_col0" class="data row23 col0" >82.898551</td>
#     </tr>
#     <tr>
#       <th id="T_e635b_level0_row24" class="row_heading level0 row24" >Dolimita</th>
#       <td id="T_e635b_row24_col0" class="data row24 col0" >81.449275</td>
#     </tr>
#     <tr>
#       <th id="T_e635b_level0_row25" class="row_heading level0 row25" >Aphthitalite</th>
#       <td id="T_e635b_row25_col0" class="data row25 col0" >81.328502</td>
#     </tr>
#     <tr>
#       <th id="T_e635b_level0_row26" class="row_heading level0 row26" >Periclase</th>
#       <td id="T_e635b_row26_col0" class="data row26 col0" >81.328502</td>
#     </tr>
#     <tr>
#       <th id="T_e635b_level0_row27" class="row_heading level0 row27" >Langbeinite</th>
#       <td id="T_e635b_row27_col0" class="data row27 col0" >81.328502</td>
#     </tr>
#     <tr>
#       <th id="T_e635b_level0_row28" class="row_heading level0 row28" >CS1</th>
#       <td id="T_e635b_row28_col0" class="data row28 col0" >76.086957</td>
#     </tr>
#     <tr>
#       <th id="T_e635b_level0_row29" class="row_heading level0 row29" >C4AF</th>
#       <td id="T_e635b_row29_col0" class="data row29 col0" >66.594203</td>
#     </tr>
#     <tr>
#       <th id="T_e635b_level0_row30" class="row_heading level0 row30" >Free CaO</th>
#       <td id="T_e635b_row30_col0" class="data row30 col0" >66.545894</td>
#     </tr>
#     <tr>
#       <th id="T_e635b_level0_row31" class="row_heading level0 row31" >Portlandite</th>
#       <td id="T_e635b_row31_col0" class="data row31 col0" >64.710145</td>
#     </tr>
#     <tr>
#       <th id="T_e635b_level0_row32" class="row_heading level0 row32" >#200</th>
#       <td id="T_e635b

# %% [markdown]
# <h3>Percentage of missing values:</h3>
# <table>
#     <th>Plant AM - Full Dataset:</th>
#     <th></th>
#             <tr>
#                 <td>Calcite</td>
#                 <td>100.0</td>
#             </tr>
#             <tr>
#                 <td>Alpha C2S</td>
#                 <td>100.0</td>
#             </tr>
#             <tr>
#                 <td>Specific Gravity</td>
#                 <td>100.0</td>
#             </tr>
#             <tr>
#                 <td>TiO2</td>
#                 <td>100.0</td>
#             </tr>
#             <tr>
#                 <td>Muscovite</td>
#                 <td>100.0</td>
#             </tr>
#             <tr>
#                 <td>Arcanite</td>
#                 <td>100.0</td>
#             </tr>
#             <tr>
#                 <td>Gamma C2S</td>
#                 <td>100.0</td>
#             </tr>
#             <tr>
#                 <td>Calcium sulfate</td>
#                 <td>100.0</td>
#             </tr>
#             <tr>
#                 <td>Calcined clay</td>
#                 <td>100.0</td>
#             </tr>
#             <tr>
#                 <td>Slag</td>
#                 <td>100.0</td>
#             </tr>
#             <tr>
#                 <td>Clinker</td>
#                 <td>100.0</td>
#             </tr>
#             <tr>
#                 <td>Calcareous filler</td>
#                 <td>100.0</td>
#             </tr>
#             <tr>
#                 <td>Fly ash</td>
#                 <td>100.0</td>
#             </tr>
#             <tr>
#                 <td>Beta C2S</td>
#                 <td>98.57</td>
#             </tr>
#             <tr>
#                 <td>Total C2S</td>
#                 <td>92.44</td>
#             </tr>
#             <tr>
#                 <td>Quartz</td>
#                 <td>92.44</td>
#             </tr>
#             <tr>
#                 <td>Anhydrite</td>
#                 <td>92.44</td>
#             </tr>
#             <tr>
#                 <td>C3A</td>
#                 <td>89.98</td>
#             </tr>
#             <tr>
#                 <td>Bassanite</td>
#                 <td>89.3</td>
#             </tr>
#             <tr>
#                 <td>Total C3S</td>
#                 <td>88.04</td>
#             </tr>
#             <tr>
#                 <td>Calcium sulfate (composition)</td>
#                 <td>87.87</td>
#             </tr>
#             <tr>
#                 <td>#400</td>
#                 <td>84.98</td>
#             </tr>
#             <tr>
#                 <td>Cubic C3A</td>
#                 <td>82.9</td>
#             </tr>
#             <tr>
#                 <td>Orthorhombic C3A</td>
#                 <td>82.9</td>
#             </tr>
#             <tr>
#                 <td>Dolimita</td>
#                 <td>81.45</td>
#             </tr>
#             <tr>
#                 <td>Aphthitalite</td>
#                 <td>81.33</td>
#             </tr>
#             <tr>
#                 <td>Periclase</td>
#                 <td>81.33</td>
#             </tr>
#             <tr>
#                 <td>Langbeinite</td>
#                 <td>81.33</td>
#             </tr>
#             <tr>
#                 <td>CS1</td>
#                 <td>76.09</td>
#             </tr>
#             <tr>
#                 <td>C4AF</td>
#                 <td>66.59</td>
#             </tr>
#             <tr>
#                 <td>Free CaO</td>
#                 <td>66.55</td>
#             </tr>
#             <tr>
#                 <td>Portlandite</td>
#                 <td>64.71</td>
#             </tr>
# </table>

# %%
FEATRUES_TO_DROP = [
    "Calcite",
    "Alpha C2S",
    "Specific Gravity",
    "TiO2",
    "Muscovite",
    "Arcanite",
    "Gamma C2S",
    "Calcium sulfate",
    "Calcined clay",
    "Slag",
    "Clinker",
    "Calcareous filler",
    "Fly ash",
    "Beta C2S",
    "Total C2S",
    "Quartz",
    "Anhydrite",
    "C3A",
    "Bassanite",
    "Total C3S",
    "Calcium sulfate (composition)",
    "#400",
    "Cubic C3A",
    "Orthorhombic C3A",
    "Dolimita",
    "Aphthitalite",
    "Periclase",
    "Langbeinite",
    "CS1",
    "C4AF",
    "Free CaO",
    "Portlandite",
]
df = df.drop(labels=FEATRUES_TO_DROP, axis=1)

# %% [markdown]
# ### Removing features with more than 23% of zeros

# %%
zero_values = {}
for col in df.select_dtypes(include="number").columns:
    zero_percentages = (df[df[col].eq(0)].shape[0] / df.shape[0]) * 100
    zero_values[col] = zero_percentages

zero_percentages = pd.Series(zero_values, name=f"Zero (%) for {plant}")
zero_percentages = zero_percentages.sort_values(ascending=False)
zero_percentages = zero_percentages.to_frame(name=f"Zero (%) for {plant}")
zero_percentages.style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_76ce0_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_76ce0_row1_col0 {
#   background-color: #feeae0;
#   color: #000000;
# }
# #T_76ce0_row2_col0 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_76ce0_row3_col0 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_76ce0_row4_col0, #T_76ce0_row5_col0, #T_76ce0_row6_col0, #T_76ce0_row7_col0, #T_76ce0_row8_col0, #T_76ce0_row9_col0, #T_76ce0_row10_col0, #T_76ce0_row11_col0, #T_76ce0_row12_col0, #T_76ce0_row13_col0, #T_76ce0_row14_col0, #T_76ce0_row15_col0, #T_76ce0_row16_col0, #T_76ce0_row17_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_76ce0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_76ce0_level0_col0" class="col_heading level0 col0" >Zero (%) for AM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_76ce0_level0_row0" class="row_heading level0 row0" >#200</th>
#       <td id="T_76ce0_row0_col0" class="data row0 col0" >28.985507</td>
#     </tr>
#     <tr>
#       <th id="T_76ce0_level0_row1" class="row_heading level0 row1" >Na2O</th>
#       <td id="T_76ce0_row1_col0" class="data row1 col0" >1.932367</td>
#     </tr>
#     <tr>
#       <th id="T_76ce0_level0_row2" class="row_heading level0 row2" >#325</th>
#       <td id="T_76ce0_row2_col0" class="data row2 col0" >0.241546</td>
#     </tr>
#     <tr>
#       <th id="T_76ce0_level0_row3" class="row_heading level0 row3" >Insoluble Residue</th>
#       <td id="T_76ce0_row3_col0" class="data row3 col0" >0.193237</td>
#     </tr>
#     <tr>
#       <th id="T_76ce0_level0_row4" class="row_heading level0 row4" >K2O</th>
#       <td id="T_76ce0_row4_col0" class="data row4 col0" >0.024155</td>
#     </tr>
#     <tr>
#       <th id="T_76ce0_level0_row5" class="row_heading level0 row5" >Loss on Ignition</th>
#       <td id="T_76ce0_row5_col0" class="data row5 col0" >0.024155</td>
#     </tr>
#     <tr>
#       <th id="T_76ce0_level0_row6" class="row_heading level0 row6" >Blaine</th>
#       <td id="T_76ce0_row6_col0" class="data row6 col0" >0.024155</td>
#     </tr>
#     <tr>
#       <th id="T_76ce0_level0_row7" class="row_heading level0 row7" >CS7</th>
#       <td id="T_76ce0_row7_col0" class="data row7 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_76ce0_level0_row8" class="row_heading level0 row8" >CS3</th>
#       <td id="T_76ce0_row8_col0" class="data row8 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_76ce0_level0_row9" class="row_heading level0 row9" >Final setting time</th>
#       <td id="T_76ce0_row9_col0" class="data row9 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_76ce0_level0_row10" class="row_heading level0 row10" >Initial setting time</th>
#       <td id="T_76ce0_row10_col0" class="data row10 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_76ce0_level0_row11" class="row_heading level0 row11" >CaO</th>
#       <td id="T_76ce0_row11_col0" class="data row11 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_76ce0_level0_row12" class="row_heading level0 row12" >MgO</th>
#       <td id="T_76ce0_row12_col0" class="data row12 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_76ce0_level0_row13" class="row_heading level0 row13" >Fe2O3</th>
#       <td id="T_76ce0_row13_col0" class="data row13 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_76ce0_level0_row14" class="row_heading level0 row14" >SO3</th>
#       <td id="T_76ce0_row14_col0" class="data row14 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_76ce0_level0_row15" class="row_heading level0 row15" >SiO2</th>
#       <td id="T_76ce0_row15_col0" class="data row15 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_76ce0_level0_row16" class="row_heading level0 row16" >Al2O3</th>
#       <td id="T_76ce0_row16_col0" class="data row16 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_76ce0_level0_row17" class="row_heading level0 row17" >CS28</th>
#       <td id="T_76ce0_row17_col0" class="data row17 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.shape
# Out:
# (4140, 22)

# %% [markdown]
# <h3>Percentage of zero values:</h3>
# <table>
#     <th>Plant AM - Full Dataset:</th>
#     <th></th>
#     <tr>
#         <td>#200</td>
#         <td>28.99</td>
#     </tr>
# </table>
#
# Here we drop th #200 with only 28.99% of zeros because deleting on the lnes the dataset with current shape of 4140 drops to 2773, which is about 66.98% of the full dataset, meaning that the zeros occurrence are not contiguous in the dataset.

# %%
FEATRUES_TO_DROP = ["#200"]
df = df.drop(labels=FEATRUES_TO_DROP, axis=1)

# %% [markdown]
# ### Dropping variable with City and Plant identification

# %%
FEATRUES_TO_DROP = ["City", "Plant"]
df = df.drop(labels=FEATRUES_TO_DROP, axis=1)

# %% [markdown]
# ### Dropping rows where the target variable is null

# %%
df = df[df["CS28"].notna()]

# %% [markdown]
# ### Dropping rows where the target variable is zero

# %%
df = df[~df["CS28"].eq(0)]

# %%
df.shape
# Out:
# (4025, 19)

# %%
df.describe().T
# Out:
#                        count                           mean  \
# Date                    4025  2022-04-21 07:42:56.795030784
# CaO                   4020.0                      55.244476
# MgO                   4021.0                       5.938297
# Na2O                  4019.0                        0.17528
# Al2O3                 4020.0                       5.390938
# SiO2                  4020.0                      20.791825
# SO3                   4009.0                       2.883638
# K2O                   4019.0                       1.069346
# Fe2O3                 4020.0                       2.969836
# Loss on Ignition      3995.0                       5.608169
# Insoluble Residue     4022.0                         7.5093
# Blaine                4022.0                    4365.364993
# #325                  3995.0                       4.873615
# Initial setting time  4025.0                     265.597516
# Final setting time    4025.0                      333.55528
# CS3                   4024.0                      28.577237
# CS7                   4024.0                      33.605219
# CS28                  4025.0                      41.613138
#
#                                       min                  25%  \
# Date                  2021-01-04 00:00:00  2021-09-01 00:00:00
# CaO                                  32.0            52.369999
# MgO                                  2.68                 5.61
# Na2O                             -0.12633                 0.06
# Al2O3                                3.88              4.35726
# SiO2                                16.53                17.85
# SO3                                  1.35                 2.57
# K2O                                   0.0              0.91689
# Fe2O3                             2.30147             2.694358
# Loss on Ignition                      0.0                 4.47
# Insoluble Residue                     0.0                 1.12
# Blaine                                0.0               3752.5
# #325                                  0.0                  0.8
# Initial setting time                160.0                240.0
# Final setting time                  210.0                300.0
# CS3                                  19.0            22.700001
# CS7                                  24.5            27.200001
# CS28                                 33.0            34.900002
#
#                                       50%                  75%  \
# Date                  2022-05-06 00:00:00  2022-12-07 00:00:00
# CaO                              56.72681             59.19922
# MgO                                  5.93              6.38888
# Na2O                              0.16075                 0.24
# Al2O3                             4.79214                 6.07
# SiO2                                18.93            22.966985
# SO3                                  2.87                 3.22
# K2O                               1.05966                 1.19
# Fe2O3                                2.89                 3.16
# Loss on Ignition                     5.58                 6.93
# Insoluble Residue                     2.0                11.77
# Blaine                             4480.0               4970.0
# #325                                  1.7                 10.0
# Initial setting time                260.0                290.0
# Final setting time                  330.0                370.0
# CS3                             31.200001            33.700001
# CS7                                  36.5                 39.0
# CS28                                 44.6                 47.0
#
#                                       max         std
# Date                  2023-07-25 00:00:00         NaN
# CaO                             62.200001    4.803191
# MgO                                  8.57    0.598598
# Na2O                                 7.54    0.311532
# Al2O3                               11.41     1.39142
# SiO2                                35.86    3.737064
# SO3                                  4.32    0.455767
# K2O                                  1.79    0.181096
# Fe2O3                                4.68    0.371775
# Loss on Ignition                    13.92    1.445409
# Insoluble Residue                  1244.0   20.833407
# Blaine                             5490.0  604.879454
# #325                            16.700001    4.691365
# Initial setting time                350.0   35.183374
# Final setting time                  430.0   42.356277
# CS3                             38.599998    5.652739
# CS7                                  43.0    5.855301
# CS28                            53.799999    5.977734

# %%
# df_copy = df.copy()

# %% [markdown]
# ### Dropping rows where any other variable has a zero value

# %%
for col in df.columns:
    df = df[~df[col].eq(0)]

# %%
df.shape
# Out:
# (3925, 19)

# %%
(df.isna().sum() / df.shape[0] * 100).sort_values(ascending=False).to_frame(
    name="Missing (%)"
).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_092bf_row0_col0, #T_092bf_row1_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_092bf_row2_col0 {
#   background-color: #f85d42;
#   color: #f1f1f1;
# }
# #T_092bf_row3_col0, #T_092bf_row4_col0 {
#   background-color: #fdcab5;
#   color: #000000;
# }
# #T_092bf_row5_col0, #T_092bf_row6_col0, #T_092bf_row7_col0, #T_092bf_row8_col0 {
#   background-color: #fdd4c2;
#   color: #000000;
# }
# #T_092bf_row9_col0 {
#   background-color: #fedecf;
#   color: #000000;
# }
# #T_092bf_row10_col0, #T_092bf_row11_col0 {
#   background-color: #fee5d8;
#   color: #000000;
# }
# #T_092bf_row12_col0, #T_092bf_row13_col0 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_092bf_row14_col0, #T_092bf_row15_col0, #T_092bf_row16_col0, #T_092bf_row17_col0, #T_092bf_row18_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_092bf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_092bf_level0_col0" class="col_heading level0 col0" >Missing (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_092bf_level0_row0" class="row_heading level0 row0" >Loss on Ignition</th>
#       <td id="T_092bf_row0_col0" class="data row0 col0" >0.764331</td>
#     </tr>
#     <tr>
#       <th id="T_092bf_level0_row1" class="row_heading level0 row1" >#325</th>
#       <td id="T_092bf_row1_col0" class="data row1 col0" >0.764331</td>
#     </tr>
#     <tr>
#       <th id="T_092bf_level0_row2" class="row_heading level0 row2" >SO3</th>
#       <td id="T_092bf_row2_col0" class="data row2 col0" >0.407643</td>
#     </tr>
#     <tr>
#       <th id="T_092bf_level0_row3" class="row_heading level0 row3" >Na2O</th>
#       <td id="T_092bf_row3_col0" class="data row3 col0" >0.152866</td>
#     </tr>
#     <tr>
#       <th id="T_092bf_level0_row4" class="row_heading level0 row4" >K2O</th>
#       <td id="T_092bf_row4_col0" class="data row4 col0" >0.152866</td>
#     </tr>
#     <tr>
#       <th id="T_092bf_level0_row5" class="row_heading level0 row5" >Al2O3</th>
#       <td id="T_092bf_row5_col0" class="data row5 col0" >0.127389</td>
#     </tr>
#     <tr>
#       <th id="T_092bf_level0_row6" class="row_heading level0 row6" >SiO2</th>
#       <td id="T_092bf_row6_col0" class="data row6 col0" >0.127389</td>
#     </tr>
#     <tr>
#       <th id="T_092bf_level0_row7" class="row_heading level0 row7" >Fe2O3</th>
#       <td id="T_092bf_row7_col0" class="data row7 col0" >0.127389</td>
#     </tr>
#     <tr>
#       <th id="T_092bf_level0_row8" class="row_heading level0 row8" >CaO</th>
#       <td id="T_092bf_row8_col0" class="data row8 col0" >0.127389</td>
#     </tr>
#     <tr>
#       <th id="T_092bf_level0_row9" class="row_heading level0 row9" >MgO</th>
#       <td id="T_092bf_row9_col0" class="data row9 col0" >0.101911</td>
#     </tr>
#     <tr>
#       <th id="T_092bf_level0_row10" class="row_heading level0 row10" >Insoluble Residue</th>
#       <td id="T_092bf_row10_col0" class="data row10 col0" >0.076433</td>
#     </tr>
#     <tr>
#       <th id="T_092bf_level0_row11" class="row_heading level0 row11" >Blaine</th>
#       <td id="T_092bf_row11_col0" class="data row11 col0" >0.076433</td>
#     </tr>
#     <tr>
#       <th id="T_092bf_level0_row12" class="row_heading level0 row12" >CS3</th>
#       <td id="T_092bf_row12_col0" class="data row12 col0" >0.025478</td>
#     </tr>
#     <tr>
#       <th id="T_092bf_level0_row13" class="row_heading level0 row13" >CS7</th>
#       <td id="T_092bf_row13_col0" class="data row13 col0" >0.025478</td>
#     </tr>
#     <tr>
#       <th id="T_092bf_level0_row14" class="row_heading level0 row14" >CS28</th>
#       <td id="T_092bf_row14_col0" class="data row14 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_092bf_level0_row15" class="row_heading level0 row15" >Date</th>
#       <td id="T_092bf_row15_col0" class="data row15 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_092bf_level0_row16" class="row_heading level0 row16" >Final setting time</th>
#       <td id="T_092bf_row16_col0" class="data row16 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_092bf_level0_row17" class="row_heading level0 row17" >Initial setting time</th>
#       <td id="T_092bf_row17_col0" class="data row17 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_092bf_level0_row18" class="row_heading level0 row18" >Cement_Type</th>
#       <td id="T_092bf_row18_col0" class="data row18 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Dropping duplicated rows

# %% [markdown]
# <!-- <h3>Percentage of missing values:</h3>
# <table>
#     <th>Plant A - Full Dataset:</th>
#     <th></th>
#     <tr>
#         <td>C3A</td>
#         <td>38.39</td>
#     </tr>
#     <tr>
#         <td>Aphthitalite</td>
#         <td>37.52</td>
#     </tr>
# </table> -->

# %%
df.shape
# Out:
# (3925, 19)

# %%
df = df.reset_index(drop=True)

# %%
df = df.loc[df.select_dtypes("number").drop_duplicates().index].reset_index(drop=True)

chemical_vars = [
    "CaO",
    "MgO",
    "Na2O",
    "Al2O3",
    "SiO2",
    "SO3",
    "K2O",
    "Fe2O3",
    "Loss on Ignition",
    "Insoluble Residue",
]

df = df.loc[
    df.select_dtypes("number").drop_duplicates(subset=chemical_vars).index
].reset_index(drop=True)

# %%
df.shape
# Out:
# (3857, 19)

# %% [markdown]
# ### Dropping rows with negative values

# %%
df[df.drop(["Date"], axis=1).duplicated()].drop("Date", axis=1).select_dtypes(
    include="number"
).apply(lambda x: x < 0).sum().sort_values(ascending=False)
# Out:
# CaO                     0.0
# Insoluble Residue       0.0
# CS7                     0.0
# CS3                     0.0
# Final setting time      0.0
# Initial setting time    0.0
# #325                    0.0
# Blaine                  0.0
# Loss on Ignition        0.0
# MgO                     0.0
# Fe2O3                   0.0
# K2O                     0.0
# SO3                     0.0
# SiO2                    0.0
# Al2O3                   0.0
# Na2O                    0.0
# CS28                    0.0
# dtype: float64

# %% [markdown]
# ### Removing outliers

# %%
df.describe(percentiles=[0.99]).T
# Out:
#                        count                           mean  \
# Date                    3857  2022-04-20 06:06:15.213896960
# CaO                   3854.0                      55.199225
# MgO                   3855.0                       5.941118
# Na2O                  3853.0                        0.17863
# Al2O3                 3854.0                       5.405068
# SiO2                  3854.0                       20.83122
# SO3                   3843.0                       2.874147
# K2O                   3853.0                        1.07149
# Fe2O3                 3854.0                       2.973302
# Loss on Ignition      3830.0                       5.619093
# Insoluble Residue     3856.0                       7.618398
# Blaine                3856.0                     4361.46473
# #325                  3830.0                       4.894697
# Initial setting time  3857.0                     265.554835
# Final setting time    3857.0                      333.55328
# CS3                   3856.0                      28.525648
# CS7                   3856.0                          33.55
# CS28                  3857.0                      41.570827
#
#                                       min                  50%  \
# Date                  2021-01-04 00:00:00  2022-05-10 00:00:00
# CaO                                  32.0               55.945
# MgO                                  2.68                 5.93
# Na2O                             -0.12633              0.16973
# Al2O3                                3.88                4.935
# SiO2                                16.53                19.38
# SO3                                  1.35                 2.86
# K2O                                  0.04                 1.06
# Fe2O3                             2.30147                  2.9
# Loss on Ignition                     2.01                  5.6
# Insoluble Residue                    0.13                5.795
# Blaine                             3130.0               4480.0
# #325                                  0.1                  1.7
# Initial setting time                160.0                260.0
# Final setting time                  210.0                330.0
# CS3                                  19.0                 31.1
# CS7                                  24.5                 36.5
# CS28                                 33.0            44.599998
#
#                                       99%                  max        std
# Date                  2023-07-10 10:33:36  2023-07-25 00:00:00        NaN
# CaO                             60.673501            62.200001   4.848797
# MgO                                7.2546                 8.57   0.602642
# Na2O                                 0.45                 7.54   0.316887
# Al2O3                             10.3647                11.41   1.405527
# SiO2                              33.2488                35.86   3.767593
# SO3                                3.8858                 4.32   0.450475
# K2O                                  1.58                 1.79   0.180158
# Fe2O3                                4.23                 4.68   0.374168
# Loss on Ignition                   8.0371                12.86   1.433036
# Insoluble Residue                  29.798               1244.0  21.238711
# Blaine                             5300.0               5490.0  598.98476
# #325                                 13.4            16.700001   4.686245
# Initial setting time                330.0                350.0  35.341263
# Final setting time                  410.0                430.0  42.552528
# CS3                                  36.5            38.599998   5.638346
# CS7                             42.299999                 43.0   5.835923
# CS28                                 50.3            53.799999   5.958454

# %%
df = df.reset_index(drop=True)
df = df[df["Na2O"] < 0.5].reset_index(drop=True)
df = df[df["Insoluble Residue"] < 30].reset_index(drop=True)
df = df[df["#325"] < 20].reset_index(drop=True)
df = df.drop(df["Loss on Ignition"].idxmin()).reset_index(drop=True)

# %%
df.describe(percentiles=[0.99]).T
# Out:
#                        count                           mean  \
# Date                    3776  2022-04-22 13:12:04.576271104
# CaO                   3776.0                      55.445056
# MgO                   3776.0                       5.959343
# Na2O                  3776.0                        0.16113
# Al2O3                 3776.0                       5.327511
# SiO2                  3776.0                      20.627858
# SO3                   3766.0                       2.886735
# K2O                   3776.0                       1.064517
# Fe2O3                 3776.0                       2.953145
# Loss on Ignition      3776.0                       5.624797
# Insoluble Residue     3776.0                       6.921389
# Blaine                3776.0                    4359.477754
# #325                  3776.0                       4.926057
# Initial setting time  3776.0                     264.895392
# Final setting time    3776.0                     332.740996
# CS3                   3775.0                      28.631497
# CS7                   3775.0                      33.651841
# CS28                  3776.0                      41.596711
#
#                                       min                  50%  \
# Date                  2021-01-04 00:00:00  2022-05-12 00:00:00
# CaO                                  32.0            57.159266
# MgO                                  2.68                 5.94
# Na2O                             -0.12633                 0.16
# Al2O3                                3.88             4.726715
# SiO2                                16.53            18.790001
# SO3                                  1.58                 2.87
# K2O                                  0.71                 1.05
# Fe2O3                             2.30147                 2.88
# Loss on Ignition                     2.18                 5.61
# Insoluble Residue                    0.13                 1.98
# Blaine                             3130.0               4480.0
# #325                                  0.1                  1.7
# Initial setting time                160.0                260.0
# Final setting time                  210.0                330.0
# CS3                                  19.1            31.299999
# CS7                                  24.5                 36.5
# CS28                                 33.0            44.700001
#
#                                       99%                  max         std
# Date                  2023-07-10 06:00:00  2023-07-25 00:00:00         NaN
# CaO                             60.700001            62.200001    4.503489
# MgO                                7.2625                 8.57    0.590602
# Na2O                                  0.4              0.49898    0.105912
# Al2O3                               10.09                10.97    1.279093
# SiO2                               32.495                34.53    3.454666
# SO3                                  3.89                 4.32    0.439934
# K2O                                  1.53                  1.7    0.168933
# Fe2O3                                4.15                 4.68    0.343584
# Loss on Ignition                   8.0425                12.86    1.436693
# Insoluble Residue                 28.5425                29.97    6.851642
# Blaine                             5300.0               5490.0  603.205195
# #325                               13.425            16.700001    4.703178
# Initial setting time                330.0                350.0   35.198147
# Final setting time                  410.0                430.0   42.361049
# CS3                                  36.5            38.599998    5.616205
# CS7                             42.299999                 43.0    5.820236
# CS28                                 50.3            53.799999    5.998802

# %%
df.describe().T
# Out:
#                        count                           mean  \
# Date                    3776  2022-04-22 13:12:04.576271104
# CaO                   3776.0                      55.445056
# MgO                   3776.0                       5.959343
# Na2O                  3776.0                        0.16113
# Al2O3                 3776.0                       5.327511
# SiO2                  3776.0                      20.627858
# SO3                   3766.0                       2.886735
# K2O                   3776.0                       1.064517
# Fe2O3                 3776.0                       2.953145
# Loss on Ignition      3776.0                       5.624797
# Insoluble Residue     3776.0                       6.921389
# Blaine                3776.0                    4359.477754
# #325                  3776.0                       4.926057
# Initial setting time  3776.0                     264.895392
# Final setting time    3776.0                     332.740996
# CS3                   3775.0                      28.631497
# CS7                   3775.0                      33.651841
# CS28                  3776.0                      41.596711
#
#                                       min                  25%  \
# Date                  2021-01-04 00:00:00  2021-09-08 00:00:00
# CaO                                  32.0            52.470001
# MgO                                  2.68                 5.63
# Na2O                             -0.12633                 0.06
# Al2O3                                3.88                 4.35
# SiO2                                16.53            17.848237
# SO3                                  1.58                 2.57
# K2O                                  0.71                 0.92
# Fe2O3                             2.30147             2.693295
# Loss on Ignition                     2.18                 4.52
# Insoluble Residue                    0.13                 1.13
# Blaine                             3130.0               3750.0
# #325                                  0.1                  0.8
# Initial setting time                160.0                240.0
# Final setting time                  210.0                300.0
# CS3                                  19.1            22.799999
# CS7                                  24.5            27.200001
# CS28                                 33.0            34.799999
#
#                                       50%                  75%  \
# Date                  2022-05-12 00:00:00  2022-12-05 00:00:00
# CaO                             57.159266            59.227135
# MgO                                  5.94                  6.4
# Na2O                                 0.16                 0.24
# Al2O3                            4.726715                 6.03
# SiO2                            18.790001            22.879999
# SO3                                  2.87                 3.21
# K2O                                  1.05                 1.18
# Fe2O3                                2.88                 3.15
# Loss on Ignition                     5.61                 6.94
# Insoluble Residue                    1.98                11.65
# Blaine                             4480.0               4970.0
# #325                                  1.7                 10.1
# Initial setting time                260.0                290.0
# Final setting time                  330.0                365.0
# CS3                             31.299999                 33.7
# CS7                                  36.5                 39.0
# CS28                            44.700001                 47.0
#
#                                       max         std
# Date                  2023-07-25 00:00:00         NaN
# CaO                             62.200001    4.503489
# MgO                                  8.57    0.590602
# Na2O                              0.49898    0.105912
# Al2O3                               10.97    1.279093
# SiO2                                34.53    3.454666
# SO3                                  4.32    0.439934
# K2O                                   1.7    0.168933
# Fe2O3                                4.68    0.343584
# Loss on Ignition                    12.86    1.436693
# Insoluble Residue                   29.97    6.851642
# Blaine                             5490.0  603.205195
# #325                            16.700001    4.703178
# Initial setting time                350.0   35.198147
# Final setting time                  430.0   42.361049
# CS3                             38.599998    5.616205
# CS7                                  43.0    5.820236
# CS28                            53.799999    5.998802

# %%
df.describe(exclude="number").T
# Out:
#             count unique         top  freq                           mean  \
# Date         3776    NaN         NaN   NaN  2022-04-22 13:12:04.576271104
# Cement_Type  3776      6  CP II-Z-32  1179                            NaN
#
#                              min                  25%                  50%  \
# Date         2021-01-04 00:00:00  2021-09-08 00:00:00  2022-05-12 00:00:00
# Cement_Type                  NaN                  NaN                  NaN
#
#                              75%                  max
# Date         2022-12-05 00:00:00  2023-07-25 00:00:00
# Cement_Type                  NaN                  NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3776 entries, 0 to 3775
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  3776 non-null   datetime64[ns]
#  1   CaO                   3776 non-null   float64
#  2   MgO                   3776 non-null   float64
#  3   Na2O                  3776 non-null   float64
#  4   Al2O3                 3776 non-null   float64
#  5   SiO2                  3776 non-null   float64
#  6   SO3                   3766 non-null   float64
#  7   K2O                   3776 non-null   float64
#  8   Fe2O3                 3776 non-null   float64
#  9   Loss on Ignition      3776 non-null   float64
#  10  Insoluble Residue     3776 non-null   float64
#  11  Blaine                3776 non-null   float64
#  12  #325                  3776 non-null   float64
#  13  Initial setting time  3776 non-null   float64
#  14  Final setting time    3776 non-null   float64
#  15  CS3                   3775 non-null   float64
#  16  CS7                   3775 non-null   float64
#  17  CS28                  3776 non-null   float64
#  18  Cement_Type           3776 non-null   object
# dtypes: datetime64[ns](1), float64(17), object(1)
# memory usage: 560.6+ KB

# %% [markdown]
# ### Sort the dataset by date

# %%
# We first make sure Date column was infered correctly
df["Date"].dtype
# Out:
# dtype('<M8[ns]')

# %%
df = df.sort_values(by="Date")

# %% [markdown]
# ## Saving the dataset

# %% [markdown]
# <h3>Saving for feature engineering</h3>

# %%
df.to_csv("../../../../data/interim/209/am.csv", index=False)
