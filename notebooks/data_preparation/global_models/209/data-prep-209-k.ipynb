# %%
# %load_ext nb_black

# %%
import pandas as pd
import numpy as np
import missingno as msno

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading the datasets

# %% [markdown]
# ## Reading the global dataset

# %%
df = pd.read_csv("../../../../data/interim/Global-Dataset/global_dataset.csv")

# %% [markdown]
# ## Reading the local dataset for plant K

# %%
df_k = pd.read_csv("../../../../data/processed/209/k.csv")

# %%
df_k.shape
# Out:
# (3345, 19)

# %% [markdown]
# # Preprocessing of Global Dataset

# %% [markdown]
# ### Removing the plant to be fine-tuned

# %%
df.shape
# Out:
# (66111, 48)

# %%
df = df[df["Factory_Plant"] != "209_K"].reset_index(drop=True)

# %%
df.shape
# Out:
# (62765, 48)

# %% [markdown]
# ### Removing non-matching columns between the datasets

# %%
df = df[df_k.columns.to_list() + ["Factory_Plant"]]

# %%
df.shape
# Out:
# (62765, 20)

# %% [markdown]
# ## Removing missing features

# %%
(df.isna().sum() / df.shape[0] * 100).sort_values(ascending=False).to_frame(
    name="Missing (%)"
).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_a8cf1_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_a8cf1_row1_col0, #T_a8cf1_row2_col0, #T_a8cf1_row3_col0 {
#   background-color: #960b13;
#   color: #f1f1f1;
# }
# #T_a8cf1_row4_col0 {
#   background-color: #980c13;
#   color: #f1f1f1;
# }
# #T_a8cf1_row5_col0 {
#   background-color: #fb7c5c;
#   color: #f1f1f1;
# }
# #T_a8cf1_row6_col0 {
#   background-color: #fc8262;
#   color: #f1f1f1;
# }
# #T_a8cf1_row7_col0 {
#   background-color: #fc9e80;
#   color: #000000;
# }
# #T_a8cf1_row8_col0 {
#   background-color: #fcc2aa;
#   color: #000000;
# }
# #T_a8cf1_row9_col0 {
#   background-color: #fee1d4;
#   color: #000000;
# }
# #T_a8cf1_row10_col0 {
#   background-color: #fee3d6;
#   color: #000000;
# }
# #T_a8cf1_row11_col0 {
#   background-color: #ffeee6;
#   color: #000000;
# }
# #T_a8cf1_row12_col0 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_a8cf1_row13_col0 {
#   background-color: #fff0e9;
#   color: #000000;
# }
# #T_a8cf1_row14_col0 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_a8cf1_row15_col0 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_a8cf1_row16_col0, #T_a8cf1_row17_col0, #T_a8cf1_row18_col0, #T_a8cf1_row19_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_a8cf1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a8cf1_level0_col0" class="col_heading level0 col0" >Missing (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a8cf1_level0_row0" class="row_heading level0 row0" >Insoluble Residue</th>
#       <td id="T_a8cf1_row0_col0" class="data row0 col0" >28.292838</td>
#     </tr>
#     <tr>
#       <th id="T_a8cf1_level0_row1" class="row_heading level0 row1" >Fe2O3</th>
#       <td id="T_a8cf1_row1_col0" class="data row1 col0" >25.598662</td>
#     </tr>
#     <tr>
#       <th id="T_a8cf1_level0_row2" class="row_heading level0 row2" >Al2O3</th>
#       <td id="T_a8cf1_row2_col0" class="data row2 col0" >25.593882</td>
#     </tr>
#     <tr>
#       <th id="T_a8cf1_level0_row3" class="row_heading level0 row3" >SiO2</th>
#       <td id="T_a8cf1_row3_col0" class="data row3 col0" >25.568390</td>
#     </tr>
#     <tr>
#       <th id="T_a8cf1_level0_row4" class="row_heading level0 row4" >CaO</th>
#       <td id="T_a8cf1_row4_col0" class="data row4 col0" >25.426591</td>
#     </tr>
#     <tr>
#       <th id="T_a8cf1_level0_row5" class="row_heading level0 row5" >#325</th>
#       <td id="T_a8cf1_row5_col0" class="data row5 col0" >12.570700</td>
#     </tr>
#     <tr>
#       <th id="T_a8cf1_level0_row6" class="row_heading level0 row6" >Na2O</th>
#       <td id="T_a8cf1_row6_col0" class="data row6 col0" >11.950928</td>
#     </tr>
#     <tr>
#       <th id="T_a8cf1_level0_row7" class="row_heading level0 row7" >K2O</th>
#       <td id="T_a8cf1_row7_col0" class="data row7 col0" >9.510077</td>
#     </tr>
#     <tr>
#       <th id="T_a8cf1_level0_row8" class="row_heading level0 row8" >CS3</th>
#       <td id="T_a8cf1_row8_col0" class="data row8 col0" >6.444675</td>
#     </tr>
#     <tr>
#       <th id="T_a8cf1_level0_row9" class="row_heading level0 row9" >Initial setting time</th>
#       <td id="T_a8cf1_row9_col0" class="data row9 col0" >3.388831</td>
#     </tr>
#     <tr>
#       <th id="T_a8cf1_level0_row10" class="row_heading level0 row10" >MgO</th>
#       <td id="T_a8cf1_row10_col0" class="data row10 col0" >3.186489</td>
#     </tr>
#     <tr>
#       <th id="T_a8cf1_level0_row11" class="row_heading level0 row11" >Final setting time</th>
#       <td id="T_a8cf1_row11_col0" class="data row11 col0" >1.245917</td>
#     </tr>
#     <tr>
#       <th id="T_a8cf1_level0_row12" class="row_heading level0 row12" >SO3</th>
#       <td id="T_a8cf1_row12_col0" class="data row12 col0" >1.018083</td>
#     </tr>
#     <tr>
#       <th id="T_a8cf1_level0_row13" class="row_heading level0 row13" >Loss on Ignition</th>
#       <td id="T_a8cf1_row13_col0" class="data row13 col0" >0.791843</td>
#     </tr>
#     <tr>
#       <th id="T_a8cf1_level0_row14" class="row_heading level0 row14" >Blaine</th>
#       <td id="T_a8cf1_row14_col0" class="data row14 col0" >0.309089</td>
#     </tr>
#     <tr>
#       <th id="T_a8cf1_level0_row15" class="row_heading level0 row15" >CS7</th>
#       <td id="T_a8cf1_row15_col0" class="data row15 col0" >0.143392</td>
#     </tr>
#     <tr>
#       <th id="T_a8cf1_level0_row16" class="row_heading level0 row16" >Cement_Type</th>
#       <td id="T_a8cf1_row16_col0" class="data row16 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a8cf1_level0_row17" class="row_heading level0 row17" >Date</th>
#       <td id="T_a8cf1_row17_col0" class="data row17 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a8cf1_level0_row18" class="row_heading level0 row18" >CS28</th>
#       <td id="T_a8cf1_row18_col0" class="data row18 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a8cf1_level0_row19" class="row_heading level0 row19" >Factory_Plant</th>
#       <td id="T_a8cf1_row19_col0" class="data row19 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %%
missing_counts = df.isnull().sum()
plt.figure(figsize=(12, 6))
plt.bar(missing_counts.index, missing_counts.values)
plt.xticks(rotation=60)
plt.xlabel("Columns")
plt.ylabel("Number of Missing Values")
plt.title("Missing Values per Column")
plt.show()

# %% [markdown]
# ### Removing features with many zeros when applicable

# %%
zero_values = {}
for col in df.select_dtypes(include="number").columns:
    zero_percentages = (df[df[col].eq(0)].shape[0] / df.shape[0]) * 100
    zero_values[col] = zero_percentages

zero_percentages = pd.Series(zero_values, name=f"Zero (%) for Global Dataset")
zero_percentages = zero_percentages.sort_values(ascending=False)
zero_percentages = zero_percentages.to_frame(name=f"Zero (%) for Global Dataset")
zero_percentages.style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_2557c_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_2557c_row1_col0 {
#   background-color: #fc8b6b;
#   color: #f1f1f1;
# }
# #T_2557c_row2_col0 {
#   background-color: #fdc5ae;
#   color: #000000;
# }
# #T_2557c_row3_col0 {
#   background-color: #feeae1;
#   color: #000000;
# }
# #T_2557c_row4_col0 {
#   background-color: #ffece3;
#   color: #000000;
# }
# #T_2557c_row5_col0, #T_2557c_row6_col0 {
#   background-color: #ffece4;
#   color: #000000;
# }
# #T_2557c_row7_col0 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_2557c_row8_col0 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_2557c_row9_col0, #T_2557c_row10_col0 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_2557c_row11_col0, #T_2557c_row12_col0, #T_2557c_row13_col0, #T_2557c_row14_col0, #T_2557c_row15_col0, #T_2557c_row16_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_2557c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2557c_level0_col0" class="col_heading level0 col0" >Zero (%) for Global Dataset</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2557c_level0_row0" class="row_heading level0 row0" >Na2O</th>
#       <td id="T_2557c_row0_col0" class="data row0 col0" >1.676093</td>
#     </tr>
#     <tr>
#       <th id="T_2557c_level0_row1" class="row_heading level0 row1" >Insoluble Residue</th>
#       <td id="T_2557c_row1_col0" class="data row1 col0" >0.667570</td>
#     </tr>
#     <tr>
#       <th id="T_2557c_level0_row2" class="row_heading level0 row2" >#325</th>
#       <td id="T_2557c_row2_col0" class="data row2 col0" >0.361667</td>
#     </tr>
#     <tr>
#       <th id="T_2557c_level0_row3" class="row_heading level0 row3" >Loss on Ignition</th>
#       <td id="T_2557c_row3_col0" class="data row3 col0" >0.105154</td>
#     </tr>
#     <tr>
#       <th id="T_2557c_level0_row4" class="row_heading level0 row4" >Blaine</th>
#       <td id="T_2557c_row4_col0" class="data row4 col0" >0.097188</td>
#     </tr>
#     <tr>
#       <th id="T_2557c_level0_row5" class="row_heading level0 row5" >Initial setting time</th>
#       <td id="T_2557c_row5_col0" class="data row5 col0" >0.087628</td>
#     </tr>
#     <tr>
#       <th id="T_2557c_level0_row6" class="row_heading level0 row6" >Final setting time</th>
#       <td id="T_2557c_row6_col0" class="data row6 col0" >0.086035</td>
#     </tr>
#     <tr>
#       <th id="T_2557c_level0_row7" class="row_heading level0 row7" >SO3</th>
#       <td id="T_2557c_row7_col0" class="data row7 col0" >0.065323</td>
#     </tr>
#     <tr>
#       <th id="T_2557c_level0_row8" class="row_heading level0 row8" >MgO</th>
#       <td id="T_2557c_row8_col0" class="data row8 col0" >0.022305</td>
#     </tr>
#     <tr>
#       <th id="T_2557c_level0_row9" class="row_heading level0 row9" >K2O</th>
#       <td id="T_2557c_row9_col0" class="data row9 col0" >0.012746</td>
#     </tr>
#     <tr>
#       <th id="T_2557c_level0_row10" class="row_heading level0 row10" >Fe2O3</th>
#       <td id="T_2557c_row10_col0" class="data row10 col0" >0.007966</td>
#     </tr>
#     <tr>
#       <th id="T_2557c_level0_row11" class="row_heading level0 row11" >CS7</th>
#       <td id="T_2557c_row11_col0" class="data row11 col0" >0.004780</td>
#     </tr>
#     <tr>
#       <th id="T_2557c_level0_row12" class="row_heading level0 row12" >SiO2</th>
#       <td id="T_2557c_row12_col0" class="data row12 col0" >0.004780</td>
#     </tr>
#     <tr>
#       <th id="T_2557c_level0_row13" class="row_heading level0 row13" >CaO</th>
#       <td id="T_2557c_row13_col0" class="data row13 col0" >0.001593</td>
#     </tr>
#     <tr>
#       <th id="T_2557c_level0_row14" class="row_heading level0 row14" >Al2O3</th>
#       <td id="T_2557c_row14_col0" class="data row14 col0" >0.001593</td>
#     </tr>
#     <tr>
#       <th id="T_2557c_level0_row15" class="row_heading level0 row15" >CS3</th>
#       <td id="T_2557c_row15_col0" class="data row15 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2557c_level0_row16" class="row_heading level0 row16" >CS28</th>
#       <td id="T_2557c_row16_col0" class="data row16 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Drop rows where the target variable is null

# %%
df = df[df["CS28"].notna()]

# %% [markdown]
# ### Dropping rows where the target variable is zero

# %%
df = df[~df["CS28"].eq(0)]

# %% [markdown]
# ### Dropping rows where any other variable has a zero value - except #200

# %%
for col in df.columns:
    if col != "#200":
        df = df[~df[col].eq(0)]

# %%
(df.isna().sum() / df.shape[0] * 100).sort_values(ascending=False).to_frame(
    name="Missing (%)"
).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_5dbb6_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_5dbb6_row1_col0, #T_5dbb6_row2_col0, #T_5dbb6_row3_col0 {
#   background-color: #800610;
#   color: #f1f1f1;
# }
# #T_5dbb6_row4_col0 {
#   background-color: #820711;
#   color: #f1f1f1;
# }
# #T_5dbb6_row5_col0 {
#   background-color: #fb7656;
#   color: #f1f1f1;
# }
# #T_5dbb6_row6_col0 {
#   background-color: #fb7d5d;
#   color: #f1f1f1;
# }
# #T_5dbb6_row7_col0 {
#   background-color: #fc9b7c;
#   color: #000000;
# }
# #T_5dbb6_row8_col0 {
#   background-color: #fcbea5;
#   color: #000000;
# }
# #T_5dbb6_row9_col0 {
#   background-color: #fee1d3;
#   color: #000000;
# }
# #T_5dbb6_row10_col0 {
#   background-color: #fee2d5;
#   color: #000000;
# }
# #T_5dbb6_row11_col0 {
#   background-color: #ffeee6;
#   color: #000000;
# }
# #T_5dbb6_row12_col0 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_5dbb6_row13_col0 {
#   background-color: #fff0e9;
#   color: #000000;
# }
# #T_5dbb6_row14_col0 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_5dbb6_row15_col0 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_5dbb6_row16_col0, #T_5dbb6_row17_col0, #T_5dbb6_row18_col0, #T_5dbb6_row19_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_5dbb6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5dbb6_level0_col0" class="col_heading level0 col0" >Missing (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5dbb6_level0_row0" class="row_heading level0 row0" >Insoluble Residue</th>
#       <td id="T_5dbb6_row0_col0" class="data row0 col0" >27.710290</td>
#     </tr>
#     <tr>
#       <th id="T_5dbb6_level0_row1" class="row_heading level0 row1" >Fe2O3</th>
#       <td id="T_5dbb6_row1_col0" class="data row1 col0" >26.298509</td>
#     </tr>
#     <tr>
#       <th id="T_5dbb6_level0_row2" class="row_heading level0 row2" >Al2O3</th>
#       <td id="T_5dbb6_row2_col0" class="data row2 col0" >26.295226</td>
#     </tr>
#     <tr>
#       <th id="T_5dbb6_level0_row3" class="row_heading level0 row3" >SiO2</th>
#       <td id="T_5dbb6_row3_col0" class="data row3 col0" >26.268961</td>
#     </tr>
#     <tr>
#       <th id="T_5dbb6_level0_row4" class="row_heading level0 row4" >CaO</th>
#       <td id="T_5dbb6_row4_col0" class="data row4 col0" >26.122858</td>
#     </tr>
#     <tr>
#       <th id="T_5dbb6_level0_row5" class="row_heading level0 row5" >#325</th>
#       <td id="T_5dbb6_row5_col0" class="data row5 col0" >12.819292</td>
#     </tr>
#     <tr>
#       <th id="T_5dbb6_level0_row6" class="row_heading level0 row6" >Na2O</th>
#       <td id="T_5dbb6_row6_col0" class="data row6 col0" >12.187274</td>
#     </tr>
#     <tr>
#       <th id="T_5dbb6_level0_row7" class="row_heading level0 row7" >K2O</th>
#       <td id="T_5dbb6_row7_col0" class="data row7 col0" >9.731433</td>
#     </tr>
#     <tr>
#       <th id="T_5dbb6_level0_row8" class="row_heading level0 row8" >CS3</th>
#       <td id="T_5dbb6_row8_col0" class="data row8 col0" >6.630442</td>
#     </tr>
#     <tr>
#       <th id="T_5dbb6_level0_row9" class="row_heading level0 row9" >Initial setting time</th>
#       <td id="T_5dbb6_row9_col0" class="data row9 col0" >3.455578</td>
#     </tr>
#     <tr>
#       <th id="T_5dbb6_level0_row10" class="row_heading level0 row10" >MgO</th>
#       <td id="T_5dbb6_row10_col0" class="data row10 col0" >3.217545</td>
#     </tr>
#     <tr>
#       <th id="T_5dbb6_level0_row11" class="row_heading level0 row11" >Final setting time</th>
#       <td id="T_5dbb6_row11_col0" class="data row11 col0" >1.237770</td>
#     </tr>
#     <tr>
#       <th id="T_5dbb6_level0_row12" class="row_heading level0 row12" >SO3</th>
#       <td id="T_5dbb6_row12_col0" class="data row12 col0" >1.040777</td>
#     </tr>
#     <tr>
#       <th id="T_5dbb6_level0_row13" class="row_heading level0 row13" >Loss on Ignition</th>
#       <td id="T_5dbb6_row13_col0" class="data row13 col0" >0.764988</td>
#     </tr>
#     <tr>
#       <th id="T_5dbb6_level0_row14" class="row_heading level0 row14" >Blaine</th>
#       <td id="T_5dbb6_row14_col0" class="data row14 col0" >0.300414</td>
#     </tr>
#     <tr>
#       <th id="T_5dbb6_level0_row15" class="row_heading level0 row15" >CS7</th>
#       <td id="T_5dbb6_row15_col0" class="data row15 col0" >0.141178</td>
#     </tr>
#     <tr>
#       <th id="T_5dbb6_level0_row16" class="row_heading level0 row16" >Cement_Type</th>
#       <td id="T_5dbb6_row16_col0" class="data row16 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5dbb6_level0_row17" class="row_heading level0 row17" >Date</th>
#       <td id="T_5dbb6_row17_col0" class="data row17 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5dbb6_level0_row18" class="row_heading level0 row18" >CS28</th>
#       <td id="T_5dbb6_row18_col0" class="data row18 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5dbb6_level0_row19" class="row_heading level0 row19" >Factory_Plant</th>
#       <td id="T_5dbb6_row19_col0" class="data row19 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %%
zero_values = {}
for col in df.select_dtypes(include="number").columns:
    zero_percentages = (df[df[col].eq(0)].shape[0] / df.shape[0]) * 100
    zero_values[col] = zero_percentages

zero_percentages = pd.Series(zero_values, name=f"Zero (%) for Global Dataset")
zero_percentages = zero_percentages.sort_values(ascending=False)
zero_percentages = zero_percentages.to_frame(name=f"Zero (%) for Global Dataset")
zero_percentages.style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_92176_row0_col0, #T_92176_row1_col0, #T_92176_row2_col0, #T_92176_row3_col0, #T_92176_row4_col0, #T_92176_row5_col0, #T_92176_row6_col0, #T_92176_row7_col0, #T_92176_row8_col0, #T_92176_row9_col0, #T_92176_row10_col0, #T_92176_row11_col0, #T_92176_row12_col0, #T_92176_row13_col0, #T_92176_row14_col0, #T_92176_row15_col0, #T_92176_row16_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_92176">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_92176_level0_col0" class="col_heading level0 col0" >Zero (%) for Global Dataset</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_92176_level0_row0" class="row_heading level0 row0" >CaO</th>
#       <td id="T_92176_row0_col0" class="data row0 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_92176_level0_row1" class="row_heading level0 row1" >Insoluble Residue</th>
#       <td id="T_92176_row1_col0" class="data row1 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_92176_level0_row2" class="row_heading level0 row2" >CS7</th>
#       <td id="T_92176_row2_col0" class="data row2 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_92176_level0_row3" class="row_heading level0 row3" >CS3</th>
#       <td id="T_92176_row3_col0" class="data row3 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_92176_level0_row4" class="row_heading level0 row4" >Final setting time</th>
#       <td id="T_92176_row4_col0" class="data row4 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_92176_level0_row5" class="row_heading level0 row5" >Initial setting time</th>
#       <td id="T_92176_row5_col0" class="data row5 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_92176_level0_row6" class="row_heading level0 row6" >#325</th>
#       <td id="T_92176_row6_col0" class="data row6 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_92176_level0_row7" class="row_heading level0 row7" >Blaine</th>
#       <td id="T_92176_row7_col0" class="data row7 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_92176_level0_row8" class="row_heading level0 row8" >Loss on Ignition</th>
#       <td id="T_92176_row8_col0" class="data row8 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_92176_level0_row9" class="row_heading level0 row9" >MgO</th>
#       <td id="T_92176_row9_col0" class="data row9 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_92176_level0_row10" class="row_heading level0 row10" >Fe2O3</th>
#       <td id="T_92176_row10_col0" class="data row10 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_92176_level0_row11" class="row_heading level0 row11" >K2O</th>
#       <td id="T_92176_row11_col0" class="data row11 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_92176_level0_row12" class="row_heading level0 row12" >SO3</th>
#       <td id="T_92176_row12_col0" class="data row12 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_92176_level0_row13" class="row_heading level0 row13" >SiO2</th>
#       <td id="T_92176_row13_col0" class="data row13 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_92176_level0_row14" class="row_heading level0 row14" >Al2O3</th>
#       <td id="T_92176_row14_col0" class="data row14 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_92176_level0_row15" class="row_heading level0 row15" >Na2O</th>
#       <td id="T_92176_row15_col0" class="data row15 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_92176_level0_row16" class="row_heading level0 row16" >CS28</th>
#       <td id="T_92176_row16_col0" class="data row16 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.shape
# Out:
# (60916, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 60916 entries, 0 to 62764
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  60916 non-null  object
#  1   CaO                   45003 non-null  float64
#  2   MgO                   58956 non-null  float64
#  3   Na2O                  53492 non-null  float64
#  4   Al2O3                 44898 non-null  float64
#  5   SiO2                  44914 non-null  float64
#  6   SO3                   60282 non-null  float64
#  7   K2O                   54988 non-null  float64
#  8   Fe2O3                 44896 non-null  float64
#  9   Loss on Ignition      60450 non-null  float64
#  10  Insoluble Residue     44036 non-null  float64
#  11  Blaine                60733 non-null  float64
#  12  #325                  53107 non-null  float64
#  13  Initial setting time  58811 non-null  float64
#  14  Final setting time    60162 non-null  float64
#  15  CS3                   56877 non-null  float64
#  16  CS7                   60830 non-null  float64
#  17  CS28                  60916 non-null  float64
#  18  Cement_Type           60916 non-null  object
#  19  Factory_Plant         60916 non-null  object
# dtypes: float64(17), object(3)
# memory usage: 9.8+ MB

# %% [markdown]
# ### Sort the dataset by date

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df = df.sort_values(by="Date")

# %% [markdown]
# ## Saving the dataset

# %% [markdown]
# <h3>Saving for feature engineering</h3>

# %%
df.to_csv("../../../../data/interim/209/global_k.csv", index=False)
