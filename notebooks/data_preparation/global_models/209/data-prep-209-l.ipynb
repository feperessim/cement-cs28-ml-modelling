# %%
# %load_ext nb_black

# %%
import pandas as pd
import numpy as np
import missingno as msno

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading the datasets

# %% [markdown]
# ## Reading the global dataset

# %%
df = pd.read_csv("../../../../data/interim/Global-Dataset/global_dataset.csv")

# %% [markdown]
# ## Reading the local dataset for plant l

# %%
df_l = pd.read_csv("../../../../data/processed/209/l.csv")

# %% [markdown]
# # Preprocessing of Global Dataset

# %% [markdown]
# ### Removing the plant to be fine-tuned

# %%
df.shape
# Out:
# (66111, 48)

# %%
df = df[df["Factory_Plant"] != "209_L"].reset_index(drop=True)

# %%
df.shape
# Out:
# (64629, 48)

# %% [markdown]
# ### Removing non-matching columns between the datasets

# %%
df = df[df_l.columns.to_list() + ["Factory_Plant"]]

# %%
df.shape
# Out:
# (64629, 19)

# %% [markdown]
# ## Removing missing features

# %%
(df.isna().sum() / df.shape[0] * 100).sort_values(ascending=False).to_frame(
    name="Missing (%)"
).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_c5b8e_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_c5b8e_row1_col0, #T_c5b8e_row2_col0, #T_c5b8e_row3_col0 {
#   background-color: #960b13;
#   color: #f1f1f1;
# }
# #T_c5b8e_row4_col0 {
#   background-color: #980c13;
#   color: #f1f1f1;
# }
# #T_c5b8e_row5_col0 {
#   background-color: #fc8262;
#   color: #f1f1f1;
# }
# #T_c5b8e_row6_col0 {
#   background-color: #fc9e80;
#   color: #000000;
# }
# #T_c5b8e_row7_col0 {
#   background-color: #fcc2aa;
#   color: #000000;
# }
# #T_c5b8e_row8_col0 {
#   background-color: #fdd7c6;
#   color: #000000;
# }
# #T_c5b8e_row9_col0 {
#   background-color: #fee3d6;
#   color: #000000;
# }
# #T_c5b8e_row10_col0 {
#   background-color: #ffeee6;
#   color: #000000;
# }
# #T_c5b8e_row11_col0 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_c5b8e_row12_col0 {
#   background-color: #fff0e9;
#   color: #000000;
# }
# #T_c5b8e_row13_col0 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_c5b8e_row14_col0 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_c5b8e_row15_col0, #T_c5b8e_row16_col0, #T_c5b8e_row17_col0, #T_c5b8e_row18_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_c5b8e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c5b8e_level0_col0" class="col_heading level0 col0" >Missing (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c5b8e_level0_row0" class="row_heading level0 row0" >Insoluble Residue</th>
#       <td id="T_c5b8e_row0_col0" class="data row0 col0" >27.490755</td>
#     </tr>
#     <tr>
#       <th id="T_c5b8e_level0_row1" class="row_heading level0 row1" >Fe2O3</th>
#       <td id="T_c5b8e_row1_col0" class="data row1 col0" >24.875830</td>
#     </tr>
#     <tr>
#       <th id="T_c5b8e_level0_row2" class="row_heading level0 row2" >Al2O3</th>
#       <td id="T_c5b8e_row2_col0" class="data row2 col0" >24.869641</td>
#     </tr>
#     <tr>
#       <th id="T_c5b8e_level0_row3" class="row_heading level0 row3" >SiO2</th>
#       <td id="T_c5b8e_row3_col0" class="data row3 col0" >24.844884</td>
#     </tr>
#     <tr>
#       <th id="T_c5b8e_level0_row4" class="row_heading level0 row4" >CaO</th>
#       <td id="T_c5b8e_row4_col0" class="data row4 col0" >24.707175</td>
#     </tr>
#     <tr>
#       <th id="T_c5b8e_level0_row5" class="row_heading level0 row5" >Na2O</th>
#       <td id="T_c5b8e_row5_col0" class="data row5 col0" >11.620171</td>
#     </tr>
#     <tr>
#       <th id="T_c5b8e_level0_row6" class="row_heading level0 row6" >K2O</th>
#       <td id="T_c5b8e_row6_col0" class="data row6 col0" >9.249718</td>
#     </tr>
#     <tr>
#       <th id="T_c5b8e_level0_row7" class="row_heading level0 row7" >CS3</th>
#       <td id="T_c5b8e_row7_col0" class="data row7 col0" >6.263442</td>
#     </tr>
#     <tr>
#       <th id="T_c5b8e_level0_row8" class="row_heading level0 row8" >Initial setting time</th>
#       <td id="T_c5b8e_row8_col0" class="data row8 col0" >4.329326</td>
#     </tr>
#     <tr>
#       <th id="T_c5b8e_level0_row9" class="row_heading level0 row9" >MgO</th>
#       <td id="T_c5b8e_row9_col0" class="data row9 col0" >3.106964</td>
#     </tr>
#     <tr>
#       <th id="T_c5b8e_level0_row10" class="row_heading level0 row10" >Final setting time</th>
#       <td id="T_c5b8e_row10_col0" class="data row10 col0" >1.219267</td>
#     </tr>
#     <tr>
#       <th id="T_c5b8e_level0_row11" class="row_heading level0 row11" >SO3</th>
#       <td id="T_c5b8e_row11_col0" class="data row11 col0" >1.002646</td>
#     </tr>
#     <tr>
#       <th id="T_c5b8e_level0_row12" class="row_heading level0 row12" >Loss on Ignition</th>
#       <td id="T_c5b8e_row12_col0" class="data row12 col0" >0.776741</td>
#     </tr>
#     <tr>
#       <th id="T_c5b8e_level0_row13" class="row_heading level0 row13" >Blaine</th>
#       <td id="T_c5b8e_row13_col0" class="data row13 col0" >0.309459</td>
#     </tr>
#     <tr>
#       <th id="T_c5b8e_level0_row14" class="row_heading level0 row14" >CS7</th>
#       <td id="T_c5b8e_row14_col0" class="data row14 col0" >0.139256</td>
#     </tr>
#     <tr>
#       <th id="T_c5b8e_level0_row15" class="row_heading level0 row15" >Cement_Type</th>
#       <td id="T_c5b8e_row15_col0" class="data row15 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c5b8e_level0_row16" class="row_heading level0 row16" >Date</th>
#       <td id="T_c5b8e_row16_col0" class="data row16 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c5b8e_level0_row17" class="row_heading level0 row17" >CS28</th>
#       <td id="T_c5b8e_row17_col0" class="data row17 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c5b8e_level0_row18" class="row_heading level0 row18" >Factory_Plant</th>
#       <td id="T_c5b8e_row18_col0" class="data row18 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %%
# msno.matrix(df.loc[(df["CS1"].notna() == True)])

# %%
missing_counts = df.isnull().sum()
plt.figure(figsize=(12, 6))
plt.bar(missing_counts.index, missing_counts.values)
plt.xticks(rotation=60)
plt.xlabel("Columns")
plt.ylabel("Number of Missing Values")
plt.title("Missing Values per Column")
plt.show()

# %% [markdown]
# ### Removing features with many zeros when applicable

# %%
zero_values = {}
for col in df.select_dtypes(include="number").columns:
    zero_percentages = (df[df[col].eq(0)].shape[0] / df.shape[0]) * 100
    zero_values[col] = zero_percentages

zero_percentages = pd.Series(zero_values, name=f"Zero (%) for Global Dataset")
zero_percentages = zero_percentages.sort_values(ascending=False)
zero_percentages = zero_percentages.to_frame(name=f"Zero (%) for Global Dataset")
zero_percentages.style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_39395_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_39395_row1_col0 {
#   background-color: #fc8161;
#   color: #f1f1f1;
# }
# #T_39395_row2_col0 {
#   background-color: #feeae0;
#   color: #000000;
# }
# #T_39395_row3_col0 {
#   background-color: #ffebe2;
#   color: #000000;
# }
# #T_39395_row4_col0, #T_39395_row5_col0 {
#   background-color: #ffece3;
#   color: #000000;
# }
# #T_39395_row6_col0 {
#   background-color: #ffeee7;
#   color: #000000;
# }
# #T_39395_row7_col0 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_39395_row8_col0 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_39395_row9_col0 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_39395_row10_col0, #T_39395_row11_col0, #T_39395_row12_col0, #T_39395_row13_col0, #T_39395_row14_col0, #T_39395_row15_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_39395">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_39395_level0_col0" class="col_heading level0 col0" >Zero (%) for Global Dataset</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_39395_level0_row0" class="row_heading level0 row0" >Na2O</th>
#       <td id="T_39395_row0_col0" class="data row0 col0" >1.519442</td>
#     </tr>
#     <tr>
#       <th id="T_39395_level0_row1" class="row_heading level0 row1" >Insoluble Residue</th>
#       <td id="T_39395_row1_col0" class="data row1 col0" >0.648316</td>
#     </tr>
#     <tr>
#       <th id="T_39395_level0_row2" class="row_heading level0 row2" >Loss on Ignition</th>
#       <td id="T_39395_row2_col0" class="data row2 col0" >0.102121</td>
#     </tr>
#     <tr>
#       <th id="T_39395_level0_row3" class="row_heading level0 row3" >Blaine</th>
#       <td id="T_39395_row3_col0" class="data row3 col0" >0.094385</td>
#     </tr>
#     <tr>
#       <th id="T_39395_level0_row4" class="row_heading level0 row4" >Initial setting time</th>
#       <td id="T_39395_row4_col0" class="data row4 col0" >0.085101</td>
#     </tr>
#     <tr>
#       <th id="T_39395_level0_row5" class="row_heading level0 row5" >Final setting time</th>
#       <td id="T_39395_row5_col0" class="data row5 col0" >0.083554</td>
#     </tr>
#     <tr>
#       <th id="T_39395_level0_row6" class="row_heading level0 row6" >SO3</th>
#       <td id="T_39395_row6_col0" class="data row6 col0" >0.063439</td>
#     </tr>
#     <tr>
#       <th id="T_39395_level0_row7" class="row_heading level0 row7" >MgO</th>
#       <td id="T_39395_row7_col0" class="data row7 col0" >0.021662</td>
#     </tr>
#     <tr>
#       <th id="T_39395_level0_row8" class="row_heading level0 row8" >K2O</th>
#       <td id="T_39395_row8_col0" class="data row8 col0" >0.012378</td>
#     </tr>
#     <tr>
#       <th id="T_39395_level0_row9" class="row_heading level0 row9" >Fe2O3</th>
#       <td id="T_39395_row9_col0" class="data row9 col0" >0.007736</td>
#     </tr>
#     <tr>
#       <th id="T_39395_level0_row10" class="row_heading level0 row10" >SiO2</th>
#       <td id="T_39395_row10_col0" class="data row10 col0" >0.004642</td>
#     </tr>
#     <tr>
#       <th id="T_39395_level0_row11" class="row_heading level0 row11" >CS7</th>
#       <td id="T_39395_row11_col0" class="data row11 col0" >0.004642</td>
#     </tr>
#     <tr>
#       <th id="T_39395_level0_row12" class="row_heading level0 row12" >CaO</th>
#       <td id="T_39395_row12_col0" class="data row12 col0" >0.001547</td>
#     </tr>
#     <tr>
#       <th id="T_39395_level0_row13" class="row_heading level0 row13" >Al2O3</th>
#       <td id="T_39395_row13_col0" class="data row13 col0" >0.001547</td>
#     </tr>
#     <tr>
#       <th id="T_39395_level0_row14" class="row_heading level0 row14" >CS3</th>
#       <td id="T_39395_row14_col0" class="data row14 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_39395_level0_row15" class="row_heading level0 row15" >CS28</th>
#       <td id="T_39395_row15_col0" class="data row15 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Drop rows where the target variable is null

# %%
df = df[df["CS28"].notna()]

# %% [markdown]
# ### Dropping rows where the target variable is zero

# %%
df = df[~df["CS28"].eq(0)]

# %% [markdown]
# ### Dropping rows where any other variable has a zero value - except #200

# %%
for col in df.columns:
    if col != "#200":
        df = df[~df[col].eq(0)]

# %%
(df.isna().sum() / df.shape[0] * 100).sort_values(ascending=False).to_frame(
    name="Missing (%)"
).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_aebf2_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_aebf2_row1_col0, #T_aebf2_row2_col0, #T_aebf2_row3_col0 {
#   background-color: #800610;
#   color: #f1f1f1;
# }
# #T_aebf2_row4_col0 {
#   background-color: #820711;
#   color: #f1f1f1;
# }
# #T_aebf2_row5_col0 {
#   background-color: #fb7d5d;
#   color: #f1f1f1;
# }
# #T_aebf2_row6_col0 {
#   background-color: #fc9b7c;
#   color: #000000;
# }
# #T_aebf2_row7_col0 {
#   background-color: #fcbea5;
#   color: #000000;
# }
# #T_aebf2_row8_col0 {
#   background-color: #fdd4c2;
#   color: #000000;
# }
# #T_aebf2_row9_col0 {
#   background-color: #fee2d5;
#   color: #000000;
# }
# #T_aebf2_row10_col0 {
#   background-color: #ffeee6;
#   color: #000000;
# }
# #T_aebf2_row11_col0 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_aebf2_row12_col0 {
#   background-color: #fff0e9;
#   color: #000000;
# }
# #T_aebf2_row13_col0 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_aebf2_row14_col0 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_aebf2_row15_col0, #T_aebf2_row16_col0, #T_aebf2_row17_col0, #T_aebf2_row18_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_aebf2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aebf2_level0_col0" class="col_heading level0 col0" >Missing (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aebf2_level0_row0" class="row_heading level0 row0" >Insoluble Residue</th>
#       <td id="T_aebf2_row0_col0" class="data row0 col0" >26.810629</td>
#     </tr>
#     <tr>
#       <th id="T_aebf2_level0_row1" class="row_heading level0 row1" >Fe2O3</th>
#       <td id="T_aebf2_row1_col0" class="data row1 col0" >25.424911</td>
#     </tr>
#     <tr>
#       <th id="T_aebf2_level0_row2" class="row_heading level0 row2" >Al2O3</th>
#       <td id="T_aebf2_row2_col0" class="data row2 col0" >25.418569</td>
#     </tr>
#     <tr>
#       <th id="T_aebf2_level0_row3" class="row_heading level0 row3" >SiO2</th>
#       <td id="T_aebf2_row3_col0" class="data row3 col0" >25.393201</td>
#     </tr>
#     <tr>
#       <th id="T_aebf2_level0_row4" class="row_heading level0 row4" >CaO</th>
#       <td id="T_aebf2_row4_col0" class="data row4 col0" >25.252093</td>
#     </tr>
#     <tr>
#       <th id="T_aebf2_level0_row5" class="row_heading level0 row5" >Na2O</th>
#       <td id="T_aebf2_row5_col0" class="data row5 col0" >11.802385</td>
#     </tr>
#     <tr>
#       <th id="T_aebf2_level0_row6" class="row_heading level0 row6" >K2O</th>
#       <td id="T_aebf2_row6_col0" class="data row6 col0" >9.419394</td>
#     </tr>
#     <tr>
#       <th id="T_aebf2_level0_row7" class="row_heading level0 row7" >CS3</th>
#       <td id="T_aebf2_row7_col0" class="data row7 col0" >6.410134</td>
#     </tr>
#     <tr>
#       <th id="T_aebf2_level0_row8" class="row_heading level0 row8" >Initial setting time</th>
#       <td id="T_aebf2_row8_col0" class="data row8 col0" >4.425101</td>
#     </tr>
#     <tr>
#       <th id="T_aebf2_level0_row9" class="row_heading level0 row9" >MgO</th>
#       <td id="T_aebf2_row9_col0" class="data row9 col0" >3.126585</td>
#     </tr>
#     <tr>
#       <th id="T_aebf2_level0_row10" class="row_heading level0 row10" >Final setting time</th>
#       <td id="T_aebf2_row10_col0" class="data row10 col0" >1.231925</td>
#     </tr>
#     <tr>
#       <th id="T_aebf2_level0_row11" class="row_heading level0 row11" >SO3</th>
#       <td id="T_aebf2_row11_col0" class="data row11 col0" >1.025812</td>
#     </tr>
#     <tr>
#       <th id="T_aebf2_level0_row12" class="row_heading level0 row12" >Loss on Ignition</th>
#       <td id="T_aebf2_row12_col0" class="data row12 col0" >0.746766</td>
#     </tr>
#     <tr>
#       <th id="T_aebf2_level0_row13" class="row_heading level0 row13" >Blaine</th>
#       <td id="T_aebf2_row13_col0" class="data row13 col0" >0.305999</td>
#     </tr>
#     <tr>
#       <th id="T_aebf2_level0_row14" class="row_heading level0 row14" >CS7</th>
#       <td id="T_aebf2_row14_col0" class="data row14 col0" >0.136352</td>
#     </tr>
#     <tr>
#       <th id="T_aebf2_level0_row15" class="row_heading level0 row15" >Cement_Type</th>
#       <td id="T_aebf2_row15_col0" class="data row15 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_aebf2_level0_row16" class="row_heading level0 row16" >Date</th>
#       <td id="T_aebf2_row16_col0" class="data row16 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_aebf2_level0_row17" class="row_heading level0 row17" >CS28</th>
#       <td id="T_aebf2_row17_col0" class="data row17 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_aebf2_level0_row18" class="row_heading level0 row18" >Factory_Plant</th>
#       <td id="T_aebf2_row18_col0" class="data row18 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %%
zero_values = {}
for col in df.select_dtypes(include="number").columns:
    zero_percentages = (df[df[col].eq(0)].shape[0] / df.shape[0]) * 100
    zero_values[col] = zero_percentages

zero_percentages = pd.Series(zero_values, name=f"Zero (%) for Global Dataset")
zero_percentages = zero_percentages.sort_values(ascending=False)
zero_percentages = zero_percentages.to_frame(name=f"Zero (%) for Global Dataset")
zero_percentages.style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_815da_row0_col0, #T_815da_row1_col0, #T_815da_row2_col0, #T_815da_row3_col0, #T_815da_row4_col0, #T_815da_row5_col0, #T_815da_row6_col0, #T_815da_row7_col0, #T_815da_row8_col0, #T_815da_row9_col0, #T_815da_row10_col0, #T_815da_row11_col0, #T_815da_row12_col0, #T_815da_row13_col0, #T_815da_row14_col0, #T_815da_row15_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_815da">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_815da_level0_col0" class="col_heading level0 col0" >Zero (%) for Global Dataset</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_815da_level0_row0" class="row_heading level0 row0" >CaO</th>
#       <td id="T_815da_row0_col0" class="data row0 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_815da_level0_row1" class="row_heading level0 row1" >MgO</th>
#       <td id="T_815da_row1_col0" class="data row1 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_815da_level0_row2" class="row_heading level0 row2" >Na2O</th>
#       <td id="T_815da_row2_col0" class="data row2 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_815da_level0_row3" class="row_heading level0 row3" >Al2O3</th>
#       <td id="T_815da_row3_col0" class="data row3 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_815da_level0_row4" class="row_heading level0 row4" >SiO2</th>
#       <td id="T_815da_row4_col0" class="data row4 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_815da_level0_row5" class="row_heading level0 row5" >SO3</th>
#       <td id="T_815da_row5_col0" class="data row5 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_815da_level0_row6" class="row_heading level0 row6" >K2O</th>
#       <td id="T_815da_row6_col0" class="data row6 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_815da_level0_row7" class="row_heading level0 row7" >Fe2O3</th>
#       <td id="T_815da_row7_col0" class="data row7 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_815da_level0_row8" class="row_heading level0 row8" >Loss on Ignition</th>
#       <td id="T_815da_row8_col0" class="data row8 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_815da_level0_row9" class="row_heading level0 row9" >Insoluble Residue</th>
#       <td id="T_815da_row9_col0" class="data row9 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_815da_level0_row10" class="row_heading level0 row10" >Blaine</th>
#       <td id="T_815da_row10_col0" class="data row10 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_815da_level0_row11" class="row_heading level0 row11" >Initial setting time</th>
#       <td id="T_815da_row11_col0" class="data row11 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_815da_level0_row12" class="row_heading level0 row12" >Final setting time</th>
#       <td id="T_815da_row12_col0" class="data row12 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_815da_level0_row13" class="row_heading level0 row13" >CS3</th>
#       <td id="T_815da_row13_col0" class="data row13 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_815da_level0_row14" class="row_heading level0 row14" >CS7</th>
#       <td id="T_815da_row14_col0" class="data row14 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_815da_level0_row15" class="row_heading level0 row15" >CS28</th>
#       <td id="T_815da_row15_col0" class="data row15 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.shape
# Out:
# (63072, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 63072 entries, 0 to 64628
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  63072 non-null  object
#  1   CaO                   47145 non-null  float64
#  2   MgO                   61100 non-null  float64
#  3   Na2O                  55628 non-null  float64
#  4   Al2O3                 47040 non-null  float64
#  5   SiO2                  47056 non-null  float64
#  6   SO3                   62425 non-null  float64
#  7   K2O                   57131 non-null  float64
#  8   Fe2O3                 47036 non-null  float64
#  9   Loss on Ignition      62601 non-null  float64
#  10  Insoluble Residue     46162 non-null  float64
#  11  Blaine                62879 non-null  float64
#  12  Initial setting time  60281 non-null  float64
#  13  Final setting time    62295 non-null  float64
#  14  CS3                   59029 non-null  float64
#  15  CS7                   62986 non-null  float64
#  16  CS28                  63072 non-null  float64
#  17  Cement_Type           63072 non-null  object
#  18  Factory_Plant         63072 non-null  object
# dtypes: float64(16), object(3)
# memory usage: 9.6+ MB

# %% [markdown]
# ### Sort the dataset by date

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df = df.sort_values(by="Date")

# %% [markdown]
# ## Saving the dataset

# %% [markdown]
# <h3>Saving for feature engineering</h3>

# %%
df.to_csv("../../../../data/interim/209/global_l.csv", index=False)
