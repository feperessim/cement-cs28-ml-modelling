# %%
# %load_ext nb_black

# %%
import pandas as pd
import numpy as np
import missingno as msno

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading the datasets

# %% [markdown]
# ## Reading the global dataset

# %%
df = pd.read_csv("../../../../data/interim/Global-Dataset/global_dataset.csv")

# %% [markdown]
# ## Reading the local dataset for plant S

# %%
df_am = pd.read_csv("../../../../data/processed/209/s.csv")

# %% [markdown]
# # Preprocessing of Global Dataset

# %% [markdown]
# ### Removing the plant to be fine-tuned

# %%
df.shape
# Out:
# (66111, 48)

# %%
df = df[df["Factory_Plant"] != "209_S"].reset_index(drop=True)

# %%
df.shape
# Out:
# (64616, 48)

# %% [markdown]
# ### Removing non-matching columns between the datasets

# %%
df = df[df_am.columns.to_list() + ["Factory_Plant"]]

# %%
df.shape
# Out:
# (64616, 21)

# %% [markdown]
# ## Removing missing features

# %%
(df.isna().sum() / df.shape[0] * 100).sort_values(ascending=False).to_frame(
    name="Missing (%)"
).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_b45be_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_b45be_row1_col0 {
#   background-color: #7c0510;
#   color: #f1f1f1;
# }
# #T_b45be_row2_col0 {
#   background-color: #fca588;
#   color: #000000;
# }
# #T_b45be_row3_col0, #T_b45be_row4_col0, #T_b45be_row5_col0, #T_b45be_row6_col0 {
#   background-color: #fcaf93;
#   color: #000000;
# }
# #T_b45be_row7_col0 {
#   background-color: #fedecf;
#   color: #000000;
# }
# #T_b45be_row8_col0 {
#   background-color: #fee3d7;
#   color: #000000;
# }
# #T_b45be_row9_col0 {
#   background-color: #fee9df;
#   color: #000000;
# }
# #T_b45be_row10_col0 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_b45be_row11_col0 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_b45be_row12_col0 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_b45be_row13_col0, #T_b45be_row14_col0 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_b45be_row15_col0, #T_b45be_row16_col0, #T_b45be_row17_col0, #T_b45be_row18_col0, #T_b45be_row19_col0, #T_b45be_row20_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_b45be">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b45be_level0_col0" class="col_heading level0 col0" >Missing (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b45be_level0_row0" class="row_heading level0 row0" >Free CaO</th>
#       <td id="T_b45be_row0_col0" class="data row0 col0" >86.576080</td>
#     </tr>
#     <tr>
#       <th id="T_b45be_level0_row1" class="row_heading level0 row1" >#400</th>
#       <td id="T_b45be_row1_col0" class="data row1 col0" >82.615761</td>
#     </tr>
#     <tr>
#       <th id="T_b45be_level0_row2" class="row_heading level0 row2" >Insoluble Residue</th>
#       <td id="T_b45be_row2_col0" class="data row2 col0" >27.490095</td>
#     </tr>
#     <tr>
#       <th id="T_b45be_level0_row3" class="row_heading level0 row3" >Fe2O3</th>
#       <td id="T_b45be_row3_col0" class="data row3 col0" >24.873096</td>
#     </tr>
#     <tr>
#       <th id="T_b45be_level0_row4" class="row_heading level0 row4" >Al2O3</th>
#       <td id="T_b45be_row4_col0" class="data row4 col0" >24.862263</td>
#     </tr>
#     <tr>
#       <th id="T_b45be_level0_row5" class="row_heading level0 row5" >SiO2</th>
#       <td id="T_b45be_row5_col0" class="data row5 col0" >24.842144</td>
#     </tr>
#     <tr>
#       <th id="T_b45be_level0_row6" class="row_heading level0 row6" >CaO</th>
#       <td id="T_b45be_row6_col0" class="data row6 col0" >24.704408</td>
#     </tr>
#     <tr>
#       <th id="T_b45be_level0_row7" class="row_heading level0 row7" >Na2O</th>
#       <td id="T_b45be_row7_col0" class="data row7 col0" >11.614770</td>
#     </tr>
#     <tr>
#       <th id="T_b45be_level0_row8" class="row_heading level0 row8" >K2O</th>
#       <td id="T_b45be_row8_col0" class="data row8 col0" >9.243841</td>
#     </tr>
#     <tr>
#       <th id="T_b45be_level0_row9" class="row_heading level0 row9" >CS3</th>
#       <td id="T_b45be_row9_col0" class="data row9 col0" >6.260059</td>
#     </tr>
#     <tr>
#       <th id="T_b45be_level0_row10" class="row_heading level0 row10" >Initial setting time</th>
#       <td id="T_b45be_row10_col0" class="data row10 col0" >4.300792</td>
#     </tr>
#     <tr>
#       <th id="T_b45be_level0_row11" class="row_heading level0 row11" >MgO</th>
#       <td id="T_b45be_row11_col0" class="data row11 col0" >3.101399</td>
#     </tr>
#     <tr>
#       <th id="T_b45be_level0_row12" class="row_heading level0 row12" >Final setting time</th>
#       <td id="T_b45be_row12_col0" class="data row12 col0" >1.188560</td>
#     </tr>
#     <tr>
#       <th id="T_b45be_level0_row13" class="row_heading level0 row13" >SO3</th>
#       <td id="T_b45be_row13_col0" class="data row13 col0" >0.995110</td>
#     </tr>
#     <tr>
#       <th id="T_b45be_level0_row14" class="row_heading level0 row14" >Loss on Ignition</th>
#       <td id="T_b45be_row14_col0" class="data row14 col0" >0.773802</td>
#     </tr>
#     <tr>
#       <th id="T_b45be_level0_row15" class="row_heading level0 row15" >Blaine</th>
#       <td id="T_b45be_row15_col0" class="data row15 col0" >0.290950</td>
#     </tr>
#     <tr>
#       <th id="T_b45be_level0_row16" class="row_heading level0 row16" >CS7</th>
#       <td id="T_b45be_row16_col0" class="data row16 col0" >0.136189</td>
#     </tr>
#     <tr>
#       <th id="T_b45be_level0_row17" class="row_heading level0 row17" >Cement_Type</th>
#       <td id="T_b45be_row17_col0" class="data row17 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b45be_level0_row18" class="row_heading level0 row18" >Date</th>
#       <td id="T_b45be_row18_col0" class="data row18 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b45be_level0_row19" class="row_heading level0 row19" >CS28</th>
#       <td id="T_b45be_row19_col0" class="data row19 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b45be_level0_row20" class="row_heading level0 row20" >Factory_Plant</th>
#       <td id="T_b45be_row20_col0" class="data row20 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %%
# msno.matrix(df.loc[(df["CS1"].notna() == True)])

# %%
missing_counts = df.isnull().sum()
plt.figure(figsize=(12, 6))
plt.bar(missing_counts.index, missing_counts.values)
plt.xticks(rotation=60)
plt.xlabel("Columns")
plt.ylabel("Number of Missing Values")
plt.title("Missing Values per Column")
plt.show()

# %% [markdown]
# ### Removing features with many zeros when applicable

# %%
zero_values = {}
for col in df.select_dtypes(include="number").columns:
    zero_percentages = (df[df[col].eq(0)].shape[0] / df.shape[0]) * 100
    zero_values[col] = zero_percentages

zero_percentages = pd.Series(zero_values, name=f"Zero (%) for Global Dataset")
zero_percentages = zero_percentages.sort_values(ascending=False)
zero_percentages = zero_percentages.to_frame(name=f"Zero (%) for Global Dataset")
zero_percentages.style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_9a068_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_9a068_row1_col0 {
#   background-color: #6d010e;
#   color: #f1f1f1;
# }
# #T_9a068_row2_col0 {
#   background-color: #fc8b6b;
#   color: #f1f1f1;
# }
# #T_9a068_row3_col0 {
#   background-color: #feeae1;
#   color: #000000;
# }
# #T_9a068_row4_col0 {
#   background-color: #ffece3;
#   color: #000000;
# }
# #T_9a068_row5_col0, #T_9a068_row6_col0 {
#   background-color: #ffece4;
#   color: #000000;
# }
# #T_9a068_row7_col0 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_9a068_row8_col0 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_9a068_row9_col0, #T_9a068_row10_col0 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_9a068_row11_col0, #T_9a068_row12_col0, #T_9a068_row13_col0, #T_9a068_row14_col0, #T_9a068_row15_col0, #T_9a068_row16_col0, #T_9a068_row17_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_9a068">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9a068_level0_col0" class="col_heading level0 col0" >Zero (%) for Global Dataset</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9a068_level0_row0" class="row_heading level0 row0" >Na2O</th>
#       <td id="T_9a068_row0_col0" class="data row0 col0" >1.628080</td>
#     </tr>
#     <tr>
#       <th id="T_9a068_level0_row1" class="row_heading level0 row1" >Free CaO</th>
#       <td id="T_9a068_row1_col0" class="data row1 col0" >1.607961</td>
#     </tr>
#     <tr>
#       <th id="T_9a068_level0_row2" class="row_heading level0 row2" >Insoluble Residue</th>
#       <td id="T_9a068_row2_col0" class="data row2 col0" >0.648446</td>
#     </tr>
#     <tr>
#       <th id="T_9a068_level0_row3" class="row_heading level0 row3" >Loss on Ignition</th>
#       <td id="T_9a068_row3_col0" class="data row3 col0" >0.102142</td>
#     </tr>
#     <tr>
#       <th id="T_9a068_level0_row4" class="row_heading level0 row4" >Blaine</th>
#       <td id="T_9a068_row4_col0" class="data row4 col0" >0.094404</td>
#     </tr>
#     <tr>
#       <th id="T_9a068_level0_row5" class="row_heading level0 row5" >Initial setting time</th>
#       <td id="T_9a068_row5_col0" class="data row5 col0" >0.085118</td>
#     </tr>
#     <tr>
#       <th id="T_9a068_level0_row6" class="row_heading level0 row6" >Final setting time</th>
#       <td id="T_9a068_row6_col0" class="data row6 col0" >0.083571</td>
#     </tr>
#     <tr>
#       <th id="T_9a068_level0_row7" class="row_heading level0 row7" >SO3</th>
#       <td id="T_9a068_row7_col0" class="data row7 col0" >0.063452</td>
#     </tr>
#     <tr>
#       <th id="T_9a068_level0_row8" class="row_heading level0 row8" >MgO</th>
#       <td id="T_9a068_row8_col0" class="data row8 col0" >0.021666</td>
#     </tr>
#     <tr>
#       <th id="T_9a068_level0_row9" class="row_heading level0 row9" >K2O</th>
#       <td id="T_9a068_row9_col0" class="data row9 col0" >0.012381</td>
#     </tr>
#     <tr>
#       <th id="T_9a068_level0_row10" class="row_heading level0 row10" >Fe2O3</th>
#       <td id="T_9a068_row10_col0" class="data row10 col0" >0.007738</td>
#     </tr>
#     <tr>
#       <th id="T_9a068_level0_row11" class="row_heading level0 row11" >#400</th>
#       <td id="T_9a068_row11_col0" class="data row11 col0" >0.006190</td>
#     </tr>
#     <tr>
#       <th id="T_9a068_level0_row12" class="row_heading level0 row12" >SiO2</th>
#       <td id="T_9a068_row12_col0" class="data row12 col0" >0.004643</td>
#     </tr>
#     <tr>
#       <th id="T_9a068_level0_row13" class="row_heading level0 row13" >CS7</th>
#       <td id="T_9a068_row13_col0" class="data row13 col0" >0.004643</td>
#     </tr>
#     <tr>
#       <th id="T_9a068_level0_row14" class="row_heading level0 row14" >Al2O3</th>
#       <td id="T_9a068_row14_col0" class="data row14 col0" >0.001548</td>
#     </tr>
#     <tr>
#       <th id="T_9a068_level0_row15" class="row_heading level0 row15" >CaO</th>
#       <td id="T_9a068_row15_col0" class="data row15 col0" >0.001548</td>
#     </tr>
#     <tr>
#       <th id="T_9a068_level0_row16" class="row_heading level0 row16" >CS3</th>
#       <td id="T_9a068_row16_col0" class="data row16 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9a068_level0_row17" class="row_heading level0 row17" >CS28</th>
#       <td id="T_9a068_row17_col0" class="data row17 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Drop rows where the target variable is null

# %%
df = df[df["CS28"].notna()]

# %% [markdown]
# ### Dropping rows where the target variable is zero

# %%
df = df[~df["CS28"].eq(0)]

# %% [markdown]
# ### Dropping rows where any other variable has a zero value - except #200

# %%
for col in df.columns:
    if col != "#200":
        df = df[~df[col].eq(0)]

# %%
(df.isna().sum() / df.shape[0] * 100).sort_values(ascending=False).to_frame(
    name="Missing (%)"
).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_48247_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_48247_row1_col0 {
#   background-color: #7e0610;
#   color: #f1f1f1;
# }
# #T_48247_row2_col0 {
#   background-color: #fca78b;
#   color: #000000;
# }
# #T_48247_row3_col0, #T_48247_row4_col0, #T_48247_row5_col0 {
#   background-color: #fcad90;
#   color: #000000;
# }
# #T_48247_row6_col0 {
#   background-color: #fcae92;
#   color: #000000;
# }
# #T_48247_row7_col0 {
#   background-color: #fedecf;
#   color: #000000;
# }
# #T_48247_row8_col0 {
#   background-color: #fee3d7;
#   color: #000000;
# }
# #T_48247_row9_col0 {
#   background-color: #fee8de;
#   color: #000000;
# }
# #T_48247_row10_col0 {
#   background-color: #ffece4;
#   color: #000000;
# }
# #T_48247_row11_col0 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_48247_row12_col0 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_48247_row13_col0 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_48247_row14_col0 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_48247_row15_col0, #T_48247_row16_col0, #T_48247_row17_col0, #T_48247_row18_col0, #T_48247_row19_col0, #T_48247_row20_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_48247">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_48247_level0_col0" class="col_heading level0 col0" >Missing (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_48247_level0_row0" class="row_heading level0 row0" >Free CaO</th>
#       <td id="T_48247_row0_col0" class="data row0 col0" >87.755464</td>
#     </tr>
#     <tr>
#       <th id="T_48247_level0_row1" class="row_heading level0 row1" >#400</th>
#       <td id="T_48247_row1_col0" class="data row1 col0" >83.593775</td>
#     </tr>
#     <tr>
#       <th id="T_48247_level0_row2" class="row_heading level0 row2" >Insoluble Residue</th>
#       <td id="T_48247_row2_col0" class="data row2 col0" >27.157524</td>
#     </tr>
#     <tr>
#       <th id="T_48247_level0_row3" class="row_heading level0 row3" >Fe2O3</th>
#       <td id="T_48247_row3_col0" class="data row3 col0" >25.858005</td>
#     </tr>
#     <tr>
#       <th id="T_48247_level0_row4" class="row_heading level0 row4" >Al2O3</th>
#       <td id="T_48247_row4_col0" class="data row4 col0" >25.846705</td>
#     </tr>
#     <tr>
#       <th id="T_48247_level0_row5" class="row_heading level0 row5" >SiO2</th>
#       <td id="T_48247_row5_col0" class="data row5 col0" >25.825719</td>
#     </tr>
#     <tr>
#       <th id="T_48247_level0_row6" class="row_heading level0 row6" >CaO</th>
#       <td id="T_48247_row6_col0" class="data row6 col0" >25.693346</td>
#     </tr>
#     <tr>
#       <th id="T_48247_level0_row7" class="row_heading level0 row7" >Na2O</th>
#       <td id="T_48247_row7_col0" class="data row7 col0" >11.987860</td>
#     </tr>
#     <tr>
#       <th id="T_48247_level0_row8" class="row_heading level0 row8" >K2O</th>
#       <td id="T_48247_row8_col0" class="data row8 col0" >9.561554</td>
#     </tr>
#     <tr>
#       <th id="T_48247_level0_row9" class="row_heading level0 row9" >CS3</th>
#       <td id="T_48247_row9_col0" class="data row9 col0" >6.520195</td>
#     </tr>
#     <tr>
#       <th id="T_48247_level0_row10" class="row_heading level0 row10" >Initial setting time</th>
#       <td id="T_48247_row10_col0" class="data row10 col0" >4.466794</td>
#     </tr>
#     <tr>
#       <th id="T_48247_level0_row11" class="row_heading level0 row11" >MgO</th>
#       <td id="T_48247_row11_col0" class="data row11 col0" >3.167275</td>
#     </tr>
#     <tr>
#       <th id="T_48247_level0_row12" class="row_heading level0 row12" >Final setting time</th>
#       <td id="T_48247_row12_col0" class="data row12 col0" >1.213961</td>
#     </tr>
#     <tr>
#       <th id="T_48247_level0_row13" class="row_heading level0 row13" >SO3</th>
#       <td id="T_48247_row13_col0" class="data row13 col0" >1.026701</td>
#     </tr>
#     <tr>
#       <th id="T_48247_level0_row14" class="row_heading level0 row14" >Loss on Ignition</th>
#       <td id="T_48247_row14_col0" class="data row14 col0" >0.661867</td>
#     </tr>
#     <tr>
#       <th id="T_48247_level0_row15" class="row_heading level0 row15" >Blaine</th>
#       <td id="T_48247_row15_col0" class="data row15 col0" >0.279275</td>
#     </tr>
#     <tr>
#       <th id="T_48247_level0_row16" class="row_heading level0 row16" >CS7</th>
#       <td id="T_48247_row16_col0" class="data row16 col0" >0.130759</td>
#     </tr>
#     <tr>
#       <th id="T_48247_level0_row17" class="row_heading level0 row17" >Cement_Type</th>
#       <td id="T_48247_row17_col0" class="data row17 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_48247_level0_row18" class="row_heading level0 row18" >Date</th>
#       <td id="T_48247_row18_col0" class="data row18 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_48247_level0_row19" class="row_heading level0 row19" >CS28</th>
#       <td id="T_48247_row19_col0" class="data row19 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_48247_level0_row20" class="row_heading level0 row20" >Factory_Plant</th>
#       <td id="T_48247_row20_col0" class="data row20 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %%
zero_values = {}
for col in df.select_dtypes(include="number").columns:
    zero_percentages = (df[df[col].eq(0)].shape[0] / df.shape[0]) * 100
    zero_values[col] = zero_percentages

zero_percentages = pd.Series(zero_values, name=f"Zero (%) for Global Dataset")
zero_percentages = zero_percentages.sort_values(ascending=False)
zero_percentages = zero_percentages.to_frame(name=f"Zero (%) for Global Dataset")
zero_percentages.style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_8bd5c_row0_col0, #T_8bd5c_row1_col0, #T_8bd5c_row2_col0, #T_8bd5c_row3_col0, #T_8bd5c_row4_col0, #T_8bd5c_row5_col0, #T_8bd5c_row6_col0, #T_8bd5c_row7_col0, #T_8bd5c_row8_col0, #T_8bd5c_row9_col0, #T_8bd5c_row10_col0, #T_8bd5c_row11_col0, #T_8bd5c_row12_col0, #T_8bd5c_row13_col0, #T_8bd5c_row14_col0, #T_8bd5c_row15_col0, #T_8bd5c_row16_col0, #T_8bd5c_row17_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_8bd5c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8bd5c_level0_col0" class="col_heading level0 col0" >Zero (%) for Global Dataset</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8bd5c_level0_row0" class="row_heading level0 row0" >Free CaO</th>
#       <td id="T_8bd5c_row0_col0" class="data row0 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8bd5c_level0_row1" class="row_heading level0 row1" >CaO</th>
#       <td id="T_8bd5c_row1_col0" class="data row1 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8bd5c_level0_row2" class="row_heading level0 row2" >CS7</th>
#       <td id="T_8bd5c_row2_col0" class="data row2 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8bd5c_level0_row3" class="row_heading level0 row3" >CS3</th>
#       <td id="T_8bd5c_row3_col0" class="data row3 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8bd5c_level0_row4" class="row_heading level0 row4" >Final setting time</th>
#       <td id="T_8bd5c_row4_col0" class="data row4 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8bd5c_level0_row5" class="row_heading level0 row5" >Initial setting time</th>
#       <td id="T_8bd5c_row5_col0" class="data row5 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8bd5c_level0_row6" class="row_heading level0 row6" >#400</th>
#       <td id="T_8bd5c_row6_col0" class="data row6 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8bd5c_level0_row7" class="row_heading level0 row7" >Blaine</th>
#       <td id="T_8bd5c_row7_col0" class="data row7 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8bd5c_level0_row8" class="row_heading level0 row8" >Insoluble Residue</th>
#       <td id="T_8bd5c_row8_col0" class="data row8 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8bd5c_level0_row9" class="row_heading level0 row9" >Loss on Ignition</th>
#       <td id="T_8bd5c_row9_col0" class="data row9 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8bd5c_level0_row10" class="row_heading level0 row10" >Fe2O3</th>
#       <td id="T_8bd5c_row10_col0" class="data row10 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8bd5c_level0_row11" class="row_heading level0 row11" >K2O</th>
#       <td id="T_8bd5c_row11_col0" class="data row11 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8bd5c_level0_row12" class="row_heading level0 row12" >SO3</th>
#       <td id="T_8bd5c_row12_col0" class="data row12 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8bd5c_level0_row13" class="row_heading level0 row13" >SiO2</th>
#       <td id="T_8bd5c_row13_col0" class="data row13 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8bd5c_level0_row14" class="row_heading level0 row14" >Al2O3</th>
#       <td id="T_8bd5c_row14_col0" class="data row14 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8bd5c_level0_row15" class="row_heading level0 row15" >Na2O</th>
#       <td id="T_8bd5c_row15_col0" class="data row15 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8bd5c_level0_row16" class="row_heading level0 row16" >MgO</th>
#       <td id="T_8bd5c_row16_col0" class="data row16 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8bd5c_level0_row17" class="row_heading level0 row17" >CS28</th>
#       <td id="T_8bd5c_row17_col0" class="data row17 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.shape
# Out:
# (61946, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 61946 entries, 0 to 64615
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  61946 non-null  object
#  1   Free CaO              7585 non-null   float64
#  2   CaO                   46030 non-null  float64
#  3   MgO                   59984 non-null  float64
#  4   Na2O                  54520 non-null  float64
#  5   Al2O3                 45935 non-null  float64
#  6   SiO2                  45948 non-null  float64
#  7   SO3                   61310 non-null  float64
#  8   K2O                   56023 non-null  float64
#  9   Fe2O3                 45928 non-null  float64
#  10  Loss on Ignition      61536 non-null  float64
#  11  Insoluble Residue     45123 non-null  float64
#  12  Blaine                61773 non-null  float64
#  13  #400                  10163 non-null  float64
#  14  Initial setting time  59179 non-null  float64
#  15  Final setting time    61194 non-null  float64
#  16  CS3                   57907 non-null  float64
#  17  CS7                   61865 non-null  float64
#  18  CS28                  61946 non-null  float64
#  19  Cement_Type           61946 non-null  object
#  20  Factory_Plant         61946 non-null  object
# dtypes: float64(18), object(3)
# memory usage: 10.4+ MB

# %% [markdown]
# ### Sort the dataset by date

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df = df.sort_values(by="Date")

# %% [markdown]
# ## Saving the dataset

# %% [markdown]
# <h3>Saving for feature engineering</h3>

# %%
df.to_csv("../../../../data/interim/209/global_s.csv", index=False)
