# %%
# %load_ext nb_black

# %%
import pandas as pd
import numpy as np
import missingno as msno

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading the datasets

# %% [markdown]
# ## Reading the global dataset

# %%
df = pd.read_csv("../../../../data/interim/Global-Dataset/global_dataset.csv")

# %% [markdown]
# ## Reading the local dataset for plant AT

# %%
df_u = pd.read_csv("../../../../data/processed/209/u.csv")

# %% [markdown]
# # Preprocessing of Global Dataset

# %% [markdown]
# ### Removing the plant to be fine-tuned

# %%
df.shape
# Out:
# (66111, 48)

# %%
df = df[df["Factory_Plant"] != "209_U"].reset_index(drop=True)

# %%
df.shape
# Out:
# (65032, 48)

# %% [markdown]
# ### Removing non-matching columns between the datasets

# %%
df = df[df_u.columns.to_list() + ["Factory_Plant"]]

# %%
df.shape
# Out:
# (65032, 21)

# %% [markdown]
# ## Removing missing features

# %%
(df.isna().sum() / df.shape[0] * 100).sort_values(ascending=False).to_frame(
    name="Missing (%)"
).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_a28a0_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_a28a0_row1_col0, #T_a28a0_row2_col0, #T_a28a0_row3_col0 {
#   background-color: #940b13;
#   color: #f1f1f1;
# }
# #T_a28a0_row4_col0 {
#   background-color: #980c13;
#   color: #f1f1f1;
# }
# #T_a28a0_row5_col0 {
#   background-color: #fb7b5b;
#   color: #f1f1f1;
# }
# #T_a28a0_row6_col0 {
#   background-color: #fc8262;
#   color: #f1f1f1;
# }
# #T_a28a0_row7_col0 {
#   background-color: #fc9e80;
#   color: #000000;
# }
# #T_a28a0_row8_col0 {
#   background-color: #fcc2aa;
#   color: #000000;
# }
# #T_a28a0_row9_col0 {
#   background-color: #fdd7c6;
#   color: #000000;
# }
# #T_a28a0_row10_col0 {
#   background-color: #fed8c7;
#   color: #000000;
# }
# #T_a28a0_row11_col0 {
#   background-color: #fee3d6;
#   color: #000000;
# }
# #T_a28a0_row12_col0 {
#   background-color: #ffeee7;
#   color: #000000;
# }
# #T_a28a0_row13_col0 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_a28a0_row14_col0 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_a28a0_row15_col0 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_a28a0_row16_col0 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_a28a0_row17_col0, #T_a28a0_row18_col0, #T_a28a0_row19_col0, #T_a28a0_row20_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_a28a0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a28a0_level0_col0" class="col_heading level0 col0" >Missing (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a28a0_level0_row0" class="row_heading level0 row0" >Insoluble Residue</th>
#       <td id="T_a28a0_row0_col0" class="data row0 col0" >27.209681</td>
#     </tr>
#     <tr>
#       <th id="T_a28a0_level0_row1" class="row_heading level0 row1" >Fe2O3</th>
#       <td id="T_a28a0_row1_col0" class="data row1 col0" >24.700148</td>
#     </tr>
#     <tr>
#       <th id="T_a28a0_level0_row2" class="row_heading level0 row2" >Al2O3</th>
#       <td id="T_a28a0_row2_col0" class="data row2 col0" >24.693997</td>
#     </tr>
#     <tr>
#       <th id="T_a28a0_level0_row3" class="row_heading level0 row3" >SiO2</th>
#       <td id="T_a28a0_row3_col0" class="data row3 col0" >24.669394</td>
#     </tr>
#     <tr>
#       <th id="T_a28a0_level0_row4" class="row_heading level0 row4" >CaO</th>
#       <td id="T_a28a0_row4_col0" class="data row4 col0" >24.532538</td>
#     </tr>
#     <tr>
#       <th id="T_a28a0_level0_row5" class="row_heading level0 row5" >#325</th>
#       <td id="T_a28a0_row5_col0" class="data row5 col0" >12.135564</td>
#     </tr>
#     <tr>
#       <th id="T_a28a0_level0_row6" class="row_heading level0 row6" >Na2O</th>
#       <td id="T_a28a0_row6_col0" class="data row6 col0" >11.526633</td>
#     </tr>
#     <tr>
#       <th id="T_a28a0_level0_row7" class="row_heading level0 row7" >K2O</th>
#       <td id="T_a28a0_row7_col0" class="data row7 col0" >9.170870</td>
#     </tr>
#     <tr>
#       <th id="T_a28a0_level0_row8" class="row_heading level0 row8" >CS3</th>
#       <td id="T_a28a0_row8_col0" class="data row8 col0" >6.204638</td>
#     </tr>
#     <tr>
#       <th id="T_a28a0_level0_row9" class="row_heading level0 row9" >Initial setting time</th>
#       <td id="T_a28a0_row9_col0" class="data row9 col0" >4.259442</td>
#     </tr>
#     <tr>
#       <th id="T_a28a0_level0_row10" class="row_heading level0 row10" >#200</th>
#       <td id="T_a28a0_row10_col0" class="data row10 col0" >4.204084</td>
#     </tr>
#     <tr>
#       <th id="T_a28a0_level0_row11" class="row_heading level0 row11" >MgO</th>
#       <td id="T_a28a0_row11_col0" class="data row11 col0" >3.067721</td>
#     </tr>
#     <tr>
#       <th id="T_a28a0_level0_row12" class="row_heading level0 row12" >Final setting time</th>
#       <td id="T_a28a0_row12_col0" class="data row12 col0" >1.168655</td>
#     </tr>
#     <tr>
#       <th id="T_a28a0_level0_row13" class="row_heading level0 row13" >SO3</th>
#       <td id="T_a28a0_row13_col0" class="data row13 col0" >0.973367</td>
#     </tr>
#     <tr>
#       <th id="T_a28a0_level0_row14" class="row_heading level0 row14" >Loss on Ignition</th>
#       <td id="T_a28a0_row14_col0" class="data row14 col0" >0.707344</td>
#     </tr>
#     <tr>
#       <th id="T_a28a0_level0_row15" class="row_heading level0 row15" >Blaine</th>
#       <td id="T_a28a0_row15_col0" class="data row15 col0" >0.259872</td>
#     </tr>
#     <tr>
#       <th id="T_a28a0_level0_row16" class="row_heading level0 row16" >CS7</th>
#       <td id="T_a28a0_row16_col0" class="data row16 col0" >0.118403</td>
#     </tr>
#     <tr>
#       <th id="T_a28a0_level0_row17" class="row_heading level0 row17" >Cement_Type</th>
#       <td id="T_a28a0_row17_col0" class="data row17 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a28a0_level0_row18" class="row_heading level0 row18" >Date</th>
#       <td id="T_a28a0_row18_col0" class="data row18 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a28a0_level0_row19" class="row_heading level0 row19" >CS28</th>
#       <td id="T_a28a0_row19_col0" class="data row19 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a28a0_level0_row20" class="row_heading level0 row20" >Factory_Plant</th>
#       <td id="T_a28a0_row20_col0" class="data row20 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %%
# msno.matrix(df.loc[(df["CS1"].notna() == True)])

# %%
missing_counts = df.isnull().sum()
plt.figure(figsize=(12, 6))
plt.bar(missing_counts.index, missing_counts.values)
plt.xticks(rotation=60)
plt.xlabel("Columns")
plt.ylabel("Number of Missing Values")
plt.title("Missing Values per Column")
plt.show()

# %% [markdown]
# ### Removing features with many zeros when applicable

# %%
zero_values = {}
for col in df.select_dtypes(include="number").columns:
    zero_percentages = (df[df[col].eq(0)].shape[0] / df.shape[0]) * 100
    zero_values[col] = zero_percentages

zero_percentages = pd.Series(zero_values, name=f"Zero (%) for Global Dataset")
zero_percentages = zero_percentages.sort_values(ascending=False)
zero_percentages = zero_percentages.to_frame(name=f"Zero (%) for Global Dataset")
zero_percentages.style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_90914_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_90914_row1_col0 {
#   background-color: #fee2d5;
#   color: #000000;
# }
# #T_90914_row2_col0 {
#   background-color: #ffeee6;
#   color: #000000;
# }
# #T_90914_row3_col0 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_90914_row4_col0, #T_90914_row5_col0, #T_90914_row6_col0, #T_90914_row7_col0, #T_90914_row8_col0 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_90914_row9_col0, #T_90914_row10_col0, #T_90914_row11_col0, #T_90914_row12_col0, #T_90914_row13_col0, #T_90914_row14_col0, #T_90914_row15_col0, #T_90914_row16_col0, #T_90914_row17_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_90914">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_90914_level0_col0" class="col_heading level0 col0" >Zero (%) for Global Dataset</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_90914_level0_row0" class="row_heading level0 row0" >#200</th>
#       <td id="T_90914_row0_col0" class="data row0 col0" >14.159183</td>
#     </tr>
#     <tr>
#       <th id="T_90914_level0_row1" class="row_heading level0 row1" >Na2O</th>
#       <td id="T_90914_row1_col0" class="data row1 col0" >1.606901</td>
#     </tr>
#     <tr>
#       <th id="T_90914_level0_row2" class="row_heading level0 row2" >Insoluble Residue</th>
#       <td id="T_90914_row2_col0" class="data row2 col0" >0.644298</td>
#     </tr>
#     <tr>
#       <th id="T_90914_level0_row3" class="row_heading level0 row3" >#325</th>
#       <td id="T_90914_row3_col0" class="data row3 col0" >0.349059</td>
#     </tr>
#     <tr>
#       <th id="T_90914_level0_row4" class="row_heading level0 row4" >Loss on Ignition</th>
#       <td id="T_90914_row4_col0" class="data row4 col0" >0.101488</td>
#     </tr>
#     <tr>
#       <th id="T_90914_level0_row5" class="row_heading level0 row5" >Blaine</th>
#       <td id="T_90914_row5_col0" class="data row5 col0" >0.093800</td>
#     </tr>
#     <tr>
#       <th id="T_90914_level0_row6" class="row_heading level0 row6" >Initial setting time</th>
#       <td id="T_90914_row6_col0" class="data row6 col0" >0.084574</td>
#     </tr>
#     <tr>
#       <th id="T_90914_level0_row7" class="row_heading level0 row7" >Final setting time</th>
#       <td id="T_90914_row7_col0" class="data row7 col0" >0.083036</td>
#     </tr>
#     <tr>
#       <th id="T_90914_level0_row8" class="row_heading level0 row8" >SO3</th>
#       <td id="T_90914_row8_col0" class="data row8 col0" >0.063046</td>
#     </tr>
#     <tr>
#       <th id="T_90914_level0_row9" class="row_heading level0 row9" >MgO</th>
#       <td id="T_90914_row9_col0" class="data row9 col0" >0.021528</td>
#     </tr>
#     <tr>
#       <th id="T_90914_level0_row10" class="row_heading level0 row10" >K2O</th>
#       <td id="T_90914_row10_col0" class="data row10 col0" >0.012302</td>
#     </tr>
#     <tr>
#       <th id="T_90914_level0_row11" class="row_heading level0 row11" >Fe2O3</th>
#       <td id="T_90914_row11_col0" class="data row11 col0" >0.007689</td>
#     </tr>
#     <tr>
#       <th id="T_90914_level0_row12" class="row_heading level0 row12" >CS7</th>
#       <td id="T_90914_row12_col0" class="data row12 col0" >0.004613</td>
#     </tr>
#     <tr>
#       <th id="T_90914_level0_row13" class="row_heading level0 row13" >SiO2</th>
#       <td id="T_90914_row13_col0" class="data row13 col0" >0.004613</td>
#     </tr>
#     <tr>
#       <th id="T_90914_level0_row14" class="row_heading level0 row14" >CaO</th>
#       <td id="T_90914_row14_col0" class="data row14 col0" >0.001538</td>
#     </tr>
#     <tr>
#       <th id="T_90914_level0_row15" class="row_heading level0 row15" >Al2O3</th>
#       <td id="T_90914_row15_col0" class="data row15 col0" >0.001538</td>
#     </tr>
#     <tr>
#       <th id="T_90914_level0_row16" class="row_heading level0 row16" >CS3</th>
#       <td id="T_90914_row16_col0" class="data row16 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_90914_level0_row17" class="row_heading level0 row17" >CS28</th>
#       <td id="T_90914_row17_col0" class="data row17 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Drop rows where the target variable is null

# %%
df = df[df["CS28"].notna()]

# %% [markdown]
# ### Dropping rows where the target variable is zero

# %%
df = df[~df["CS28"].eq(0)]

# %% [markdown]
# ### Dropping rows where any other variable has a zero value - except #200

# %%
for col in df.columns:
    if col != "#200":
        df = df[~df[col].eq(0)]

# %%
(df.isna().sum() / df.shape[0] * 100).sort_values(ascending=False).to_frame(
    name="Missing (%)"
).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_05e9e_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_05e9e_row1_col0, #T_05e9e_row2_col0, #T_05e9e_row3_col0 {
#   background-color: #7e0610;
#   color: #f1f1f1;
# }
# #T_05e9e_row4_col0 {
#   background-color: #800610;
#   color: #f1f1f1;
# }
# #T_05e9e_row5_col0 {
#   background-color: #fb7656;
#   color: #f1f1f1;
# }
# #T_05e9e_row6_col0 {
#   background-color: #fb7d5d;
#   color: #f1f1f1;
# }
# #T_05e9e_row7_col0 {
#   background-color: #fc997a;
#   color: #000000;
# }
# #T_05e9e_row8_col0 {
#   background-color: #fcbea5;
#   color: #000000;
# }
# #T_05e9e_row9_col0 {
#   background-color: #fdd5c4;
#   color: #000000;
# }
# #T_05e9e_row10_col0 {
#   background-color: #fdd7c6;
#   color: #000000;
# }
# #T_05e9e_row11_col0 {
#   background-color: #fee2d5;
#   color: #000000;
# }
# #T_05e9e_row12_col0 {
#   background-color: #ffeee6;
#   color: #000000;
# }
# #T_05e9e_row13_col0 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_05e9e_row14_col0 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_05e9e_row15_col0 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_05e9e_row16_col0 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_05e9e_row17_col0, #T_05e9e_row18_col0, #T_05e9e_row19_col0, #T_05e9e_row20_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_05e9e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_05e9e_level0_col0" class="col_heading level0 col0" >Missing (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_05e9e_level0_row0" class="row_heading level0 row0" >Insoluble Residue</th>
#       <td id="T_05e9e_row0_col0" class="data row0 col0" >26.613388</td>
#     </tr>
#     <tr>
#       <th id="T_05e9e_level0_row1" class="row_heading level0 row1" >Fe2O3</th>
#       <td id="T_05e9e_row1_col0" class="data row1 col0" >25.345783</td>
#     </tr>
#     <tr>
#       <th id="T_05e9e_level0_row2" class="row_heading level0 row2" >Al2O3</th>
#       <td id="T_05e9e_row2_col0" class="data row2 col0" >25.341035</td>
#     </tr>
#     <tr>
#       <th id="T_05e9e_level0_row3" class="row_heading level0 row3" >SiO2</th>
#       <td id="T_05e9e_row3_col0" class="data row3 col0" >25.315715</td>
#     </tr>
#     <tr>
#       <th id="T_05e9e_level0_row4" class="row_heading level0 row4" >CaO</th>
#       <td id="T_05e9e_row4_col0" class="data row4 col0" >25.174869</td>
#     </tr>
#     <tr>
#       <th id="T_05e9e_level0_row5" class="row_heading level0 row5" >#325</th>
#       <td id="T_05e9e_row5_col0" class="data row5 col0" >12.361133</td>
#     </tr>
#     <tr>
#       <th id="T_05e9e_level0_row6" class="row_heading level0 row6" >Na2O</th>
#       <td id="T_05e9e_row6_col0" class="data row6 col0" >11.740782</td>
#     </tr>
#     <tr>
#       <th id="T_05e9e_level0_row7" class="row_heading level0 row7" >K2O</th>
#       <td id="T_05e9e_row7_col0" class="data row7 col0" >9.373319</td>
#     </tr>
#     <tr>
#       <th id="T_05e9e_level0_row8" class="row_heading level0 row8" >CS3</th>
#       <td id="T_05e9e_row8_col0" class="data row8 col0" >6.376009</td>
#     </tr>
#     <tr>
#       <th id="T_05e9e_level0_row9" class="row_heading level0 row9" >Initial setting time</th>
#       <td id="T_05e9e_row9_col0" class="data row9 col0" >4.348789</td>
#     </tr>
#     <tr>
#       <th id="T_05e9e_level0_row10" class="row_heading level0 row10" >#200</th>
#       <td id="T_05e9e_row10_col0" class="data row10 col0" >4.236430</td>
#     </tr>
#     <tr>
#       <th id="T_05e9e_level0_row11" class="row_heading level0 row11" >MgO</th>
#       <td id="T_05e9e_row11_col0" class="data row11 col0" >3.093844</td>
#     </tr>
#     <tr>
#       <th id="T_05e9e_level0_row12" class="row_heading level0 row12" >Final setting time</th>
#       <td id="T_05e9e_row12_col0" class="data row12 col0" >1.158411</td>
#     </tr>
#     <tr>
#       <th id="T_05e9e_level0_row13" class="row_heading level0 row13" >SO3</th>
#       <td id="T_05e9e_row13_col0" class="data row13 col0" >0.993828</td>
#     </tr>
#     <tr>
#       <th id="T_05e9e_level0_row14" class="row_heading level0 row14" >Loss on Ignition</th>
#       <td id="T_05e9e_row14_col0" class="data row14 col0" >0.678905</td>
#     </tr>
#     <tr>
#       <th id="T_05e9e_level0_row15" class="row_heading level0 row15" >Blaine</th>
#       <td id="T_05e9e_row15_col0" class="data row15 col0" >0.250040</td>
#     </tr>
#     <tr>
#       <th id="T_05e9e_level0_row16" class="row_heading level0 row16" >CS7</th>
#       <td id="T_05e9e_row16_col0" class="data row16 col0" >0.115525</td>
#     </tr>
#     <tr>
#       <th id="T_05e9e_level0_row17" class="row_heading level0 row17" >Cement_Type</th>
#       <td id="T_05e9e_row17_col0" class="data row17 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_05e9e_level0_row18" class="row_heading level0 row18" >Date</th>
#       <td id="T_05e9e_row18_col0" class="data row18 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_05e9e_level0_row19" class="row_heading level0 row19" >CS28</th>
#       <td id="T_05e9e_row19_col0" class="data row19 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_05e9e_level0_row20" class="row_heading level0 row20" >Factory_Plant</th>
#       <td id="T_05e9e_row20_col0" class="data row20 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %%
zero_values = {}
for col in df.select_dtypes(include="number").columns:
    zero_percentages = (df[df[col].eq(0)].shape[0] / df.shape[0]) * 100
    zero_values[col] = zero_percentages

zero_percentages = pd.Series(zero_values, name=f"Zero (%) for Global Dataset")
zero_percentages = zero_percentages.sort_values(ascending=False)
zero_percentages = zero_percentages.to_frame(name=f"Zero (%) for Global Dataset")
zero_percentages.style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_d9575_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_d9575_row1_col0, #T_d9575_row2_col0, #T_d9575_row3_col0, #T_d9575_row4_col0, #T_d9575_row5_col0, #T_d9575_row6_col0, #T_d9575_row7_col0, #T_d9575_row8_col0, #T_d9575_row9_col0, #T_d9575_row10_col0, #T_d9575_row11_col0, #T_d9575_row12_col0, #T_d9575_row13_col0, #T_d9575_row14_col0, #T_d9575_row15_col0, #T_d9575_row16_col0, #T_d9575_row17_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_d9575">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d9575_level0_col0" class="col_heading level0 col0" >Zero (%) for Global Dataset</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d9575_level0_row0" class="row_heading level0 row0" >#200</th>
#       <td id="T_d9575_row0_col0" class="data row0 col0" >14.086090</td>
#     </tr>
#     <tr>
#       <th id="T_d9575_level0_row1" class="row_heading level0 row1" >CaO</th>
#       <td id="T_d9575_row1_col0" class="data row1 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d9575_level0_row2" class="row_heading level0 row2" >MgO</th>
#       <td id="T_d9575_row2_col0" class="data row2 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d9575_level0_row3" class="row_heading level0 row3" >CS7</th>
#       <td id="T_d9575_row3_col0" class="data row3 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d9575_level0_row4" class="row_heading level0 row4" >CS3</th>
#       <td id="T_d9575_row4_col0" class="data row4 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d9575_level0_row5" class="row_heading level0 row5" >Final setting time</th>
#       <td id="T_d9575_row5_col0" class="data row5 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d9575_level0_row6" class="row_heading level0 row6" >Initial setting time</th>
#       <td id="T_d9575_row6_col0" class="data row6 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d9575_level0_row7" class="row_heading level0 row7" >#325</th>
#       <td id="T_d9575_row7_col0" class="data row7 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d9575_level0_row8" class="row_heading level0 row8" >Blaine</th>
#       <td id="T_d9575_row8_col0" class="data row8 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d9575_level0_row9" class="row_heading level0 row9" >Insoluble Residue</th>
#       <td id="T_d9575_row9_col0" class="data row9 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d9575_level0_row10" class="row_heading level0 row10" >Loss on Ignition</th>
#       <td id="T_d9575_row10_col0" class="data row10 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d9575_level0_row11" class="row_heading level0 row11" >Fe2O3</th>
#       <td id="T_d9575_row11_col0" class="data row11 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d9575_level0_row12" class="row_heading level0 row12" >K2O</th>
#       <td id="T_d9575_row12_col0" class="data row12 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d9575_level0_row13" class="row_heading level0 row13" >SO3</th>
#       <td id="T_d9575_row13_col0" class="data row13 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d9575_level0_row14" class="row_heading level0 row14" >SiO2</th>
#       <td id="T_d9575_row14_col0" class="data row14 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d9575_level0_row15" class="row_heading level0 row15" >Al2O3</th>
#       <td id="T_d9575_row15_col0" class="data row15 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d9575_level0_row16" class="row_heading level0 row16" >Na2O</th>
#       <td id="T_d9575_row16_col0" class="data row16 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d9575_level0_row17" class="row_heading level0 row17" >CS28</th>
#       <td id="T_d9575_row17_col0" class="data row17 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.shape
# Out:
# (63190, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 63190 entries, 0 to 65031
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  63190 non-null  object
#  1   CaO                   47282 non-null  float64
#  2   MgO                   61235 non-null  float64
#  3   Na2O                  55771 non-null  float64
#  4   Al2O3                 47177 non-null  float64
#  5   SiO2                  47193 non-null  float64
#  6   SO3                   62562 non-null  float64
#  7   K2O                   57267 non-null  float64
#  8   Fe2O3                 47174 non-null  float64
#  9   Loss on Ignition      62761 non-null  float64
#  10  Insoluble Residue     46373 non-null  float64
#  11  Blaine                63032 non-null  float64
#  12  #200                  60513 non-null  float64
#  13  #325                  55379 non-null  float64
#  14  Initial setting time  60442 non-null  float64
#  15  Final setting time    62458 non-null  float64
#  16  CS3                   59161 non-null  float64
#  17  CS7                   63117 non-null  float64
#  18  CS28                  63190 non-null  float64
#  19  Cement_Type           63190 non-null  object
#  20  Factory_Plant         63190 non-null  object
# dtypes: float64(18), object(3)
# memory usage: 10.6+ MB

# %% [markdown]
# ### Sort the dataset by date

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df = df.sort_values(by="Date")

# %% [markdown]
# ## Saving the dataset

# %% [markdown]
# <h3>Saving for feature engineering</h3>

# %%
df.to_csv("../../../../data/interim/209/global_u.csv", index=False)
