# %%
# %load_ext nb_black

# %%
import pandas as pd
import numpy as np
import missingno as msno

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading the datasets

# %% [markdown]
# ## Reading the global dataset

# %%
df = pd.read_csv("../../../../data/interim/Global-Dataset/global_dataset.csv")

# %% [markdown]
# ## Reading the local dataset for plant AT

# %%
df_at = pd.read_csv("../../../../data/processed/207/at.csv")

# %% [markdown]
# # Preprocessing of Global Dataset

# %% [markdown]
# ### Removing the plant to be fine-tuned

# %%
df.shape
# Out:
# (66111, 48)

# %%
df = df[df["Factory_Plant"] != "207_AT"].reset_index(drop=True)

# %%
df.shape
# Out:
# (64378, 48)

# %% [markdown]
# ### Removing non-matching columns between the datasets

# %%
df = df[df_at.columns.to_list() + ["Factory_Plant"]]

# %%
df.shape
# Out:
# (64378, 22)

# %% [markdown]
# ## Removing missing features

# %%
(df.isna().sum() / df.shape[0] * 100).sort_values(ascending=False).to_frame(
    name="Missing (%)"
).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_5299a_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_5299a_row1_col0 {
#   background-color: #8c0912;
#   color: #f1f1f1;
# }
# #T_5299a_row2_col0 {
#   background-color: #fca98c;
#   color: #000000;
# }
# #T_5299a_row3_col0, #T_5299a_row4_col0, #T_5299a_row5_col0 {
#   background-color: #fcb296;
#   color: #000000;
# }
# #T_5299a_row6_col0 {
#   background-color: #fcb398;
#   color: #000000;
# }
# #T_5299a_row7_col0 {
#   background-color: #fedfd0;
#   color: #000000;
# }
# #T_5299a_row8_col0 {
#   background-color: #fee4d8;
#   color: #000000;
# }
# #T_5299a_row9_col0 {
#   background-color: #feeae0;
#   color: #000000;
# }
# #T_5299a_row10_col0, #T_5299a_row11_col0 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_5299a_row12_col0 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_5299a_row13_col0 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_5299a_row14_col0, #T_5299a_row15_col0 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_5299a_row16_col0, #T_5299a_row17_col0, #T_5299a_row18_col0, #T_5299a_row19_col0, #T_5299a_row20_col0, #T_5299a_row21_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_5299a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5299a_level0_col0" class="col_heading level0 col0" >Missing (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5299a_level0_row0" class="row_heading level0 row0" >Specific Gravity</th>
#       <td id="T_5299a_row0_col0" class="data row0 col0" >89.744944</td>
#     </tr>
#     <tr>
#       <th id="T_5299a_level0_row1" class="row_heading level0 row1" >#400</th>
#       <td id="T_5299a_row1_col0" class="data row1 col0" >82.941377</td>
#     </tr>
#     <tr>
#       <th id="T_5299a_level0_row2" class="row_heading level0 row2" >Insoluble Residue</th>
#       <td id="T_5299a_row2_col0" class="data row2 col0" >27.599491</td>
#     </tr>
#     <tr>
#       <th id="T_5299a_level0_row3" class="row_heading level0 row3" >Fe2O3</th>
#       <td id="T_5299a_row3_col0" class="data row3 col0" >24.974370</td>
#     </tr>
#     <tr>
#       <th id="T_5299a_level0_row4" class="row_heading level0 row4" >Al2O3</th>
#       <td id="T_5299a_row4_col0" class="data row4 col0" >24.968157</td>
#     </tr>
#     <tr>
#       <th id="T_5299a_level0_row5" class="row_heading level0 row5" >SiO2</th>
#       <td id="T_5299a_row5_col0" class="data row5 col0" >24.943304</td>
#     </tr>
#     <tr>
#       <th id="T_5299a_level0_row6" class="row_heading level0 row6" >CaO</th>
#       <td id="T_5299a_row6_col0" class="data row6 col0" >24.805058</td>
#     </tr>
#     <tr>
#       <th id="T_5299a_level0_row7" class="row_heading level0 row7" >Na2O</th>
#       <td id="T_5299a_row7_col0" class="data row7 col0" >11.667029</td>
#     </tr>
#     <tr>
#       <th id="T_5299a_level0_row8" class="row_heading level0 row8" >K2O</th>
#       <td id="T_5299a_row8_col0" class="data row8 col0" >9.287334</td>
#     </tr>
#     <tr>
#       <th id="T_5299a_level0_row9" class="row_heading level0 row9" >CS3</th>
#       <td id="T_5299a_row9_col0" class="data row9 col0" >6.287862</td>
#     </tr>
#     <tr>
#       <th id="T_5299a_level0_row10" class="row_heading level0 row10" >Initial setting time</th>
#       <td id="T_5299a_row10_col0" class="data row10 col0" >4.346205</td>
#     </tr>
#     <tr>
#       <th id="T_5299a_level0_row11" class="row_heading level0 row11" >#200</th>
#       <td id="T_5299a_row11_col0" class="data row11 col0" >4.253006</td>
#     </tr>
#     <tr>
#       <th id="T_5299a_level0_row12" class="row_heading level0 row12" >MgO</th>
#       <td id="T_5299a_row12_col0" class="data row12 col0" >3.122185</td>
#     </tr>
#     <tr>
#       <th id="T_5299a_level0_row13" class="row_heading level0 row13" >Final setting time</th>
#       <td id="T_5299a_row13_col0" class="data row13 col0" >1.224021</td>
#     </tr>
#     <tr>
#       <th id="T_5299a_level0_row14" class="row_heading level0 row14" >SO3</th>
#       <td id="T_5299a_row14_col0" class="data row14 col0" >1.008108</td>
#     </tr>
#     <tr>
#       <th id="T_5299a_level0_row15" class="row_heading level0 row15" >Loss on Ignition</th>
#       <td id="T_5299a_row15_col0" class="data row15 col0" >0.781323</td>
#     </tr>
#     <tr>
#       <th id="T_5299a_level0_row16" class="row_heading level0 row16" >Blaine</th>
#       <td id="T_5299a_row16_col0" class="data row16 col0" >0.310665</td>
#     </tr>
#     <tr>
#       <th id="T_5299a_level0_row17" class="row_heading level0 row17" >CS7</th>
#       <td id="T_5299a_row17_col0" class="data row17 col0" >0.139799</td>
#     </tr>
#     <tr>
#       <th id="T_5299a_level0_row18" class="row_heading level0 row18" >Cement_Type</th>
#       <td id="T_5299a_row18_col0" class="data row18 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5299a_level0_row19" class="row_heading level0 row19" >Date</th>
#       <td id="T_5299a_row19_col0" class="data row19 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5299a_level0_row20" class="row_heading level0 row20" >CS28</th>
#       <td id="T_5299a_row20_col0" class="data row20 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5299a_level0_row21" class="row_heading level0 row21" >Factory_Plant</th>
#       <td id="T_5299a_row21_col0" class="data row21 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %%
# msno.matrix(df.loc[(df["CS1"].notna() == True)])

# %%
missing_counts = df.isnull().sum()
plt.figure(figsize=(12, 6))
plt.bar(missing_counts.index, missing_counts.values)
plt.xticks(rotation=60)
plt.xlabel("Columns")
plt.ylabel("Number of Missing Values")
plt.title("Missing Values per Column")
plt.show()

# %% [markdown]
# ### Removing features with many zeros when applicable

# %%
zero_values = {}
for col in df.select_dtypes(include="number").columns:
    zero_percentages = (df[df[col].eq(0)].shape[0] / df.shape[0]) * 100
    zero_values[col] = zero_percentages

zero_percentages = pd.Series(zero_values, name=f"Zero (%) for Global Dataset")
zero_percentages = zero_percentages.sort_values(ascending=False)
zero_percentages = zero_percentages.to_frame(name=f"Zero (%) for Global Dataset")
zero_percentages.style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_1297e_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_1297e_row1_col0 {
#   background-color: #fee2d5;
#   color: #000000;
# }
# #T_1297e_row2_col0 {
#   background-color: #ffeee6;
#   color: #000000;
# }
# #T_1297e_row3_col0, #T_1297e_row4_col0, #T_1297e_row5_col0, #T_1297e_row6_col0, #T_1297e_row7_col0 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_1297e_row8_col0, #T_1297e_row9_col0, #T_1297e_row10_col0, #T_1297e_row11_col0, #T_1297e_row12_col0, #T_1297e_row13_col0, #T_1297e_row14_col0, #T_1297e_row15_col0, #T_1297e_row16_col0, #T_1297e_row17_col0, #T_1297e_row18_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_1297e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1297e_level0_col0" class="col_heading level0 col0" >Zero (%) for Global Dataset</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1297e_level0_row0" class="row_heading level0 row0" >#200</th>
#       <td id="T_1297e_row0_col0" class="data row0 col0" >14.303023</td>
#     </tr>
#     <tr>
#       <th id="T_1297e_level0_row1" class="row_heading level0 row1" >Na2O</th>
#       <td id="T_1297e_row1_col0" class="data row1 col0" >1.630992</td>
#     </tr>
#     <tr>
#       <th id="T_1297e_level0_row2" class="row_heading level0 row2" >Insoluble Residue</th>
#       <td id="T_1297e_row2_col0" class="data row2 col0" >0.650843</td>
#     </tr>
#     <tr>
#       <th id="T_1297e_level0_row3" class="row_heading level0 row3" >Loss on Ignition</th>
#       <td id="T_1297e_row3_col0" class="data row3 col0" >0.102519</td>
#     </tr>
#     <tr>
#       <th id="T_1297e_level0_row4" class="row_heading level0 row4" >Blaine</th>
#       <td id="T_1297e_row4_col0" class="data row4 col0" >0.094753</td>
#     </tr>
#     <tr>
#       <th id="T_1297e_level0_row5" class="row_heading level0 row5" >Initial setting time</th>
#       <td id="T_1297e_row5_col0" class="data row5 col0" >0.085433</td>
#     </tr>
#     <tr>
#       <th id="T_1297e_level0_row6" class="row_heading level0 row6" >Final setting time</th>
#       <td id="T_1297e_row6_col0" class="data row6 col0" >0.083880</td>
#     </tr>
#     <tr>
#       <th id="T_1297e_level0_row7" class="row_heading level0 row7" >SO3</th>
#       <td id="T_1297e_row7_col0" class="data row7 col0" >0.063686</td>
#     </tr>
#     <tr>
#       <th id="T_1297e_level0_row8" class="row_heading level0 row8" >MgO</th>
#       <td id="T_1297e_row8_col0" class="data row8 col0" >0.021747</td>
#     </tr>
#     <tr>
#       <th id="T_1297e_level0_row9" class="row_heading level0 row9" >K2O</th>
#       <td id="T_1297e_row9_col0" class="data row9 col0" >0.012427</td>
#     </tr>
#     <tr>
#       <th id="T_1297e_level0_row10" class="row_heading level0 row10" >Fe2O3</th>
#       <td id="T_1297e_row10_col0" class="data row10 col0" >0.007767</td>
#     </tr>
#     <tr>
#       <th id="T_1297e_level0_row11" class="row_heading level0 row11" >#400</th>
#       <td id="T_1297e_row11_col0" class="data row11 col0" >0.006213</td>
#     </tr>
#     <tr>
#       <th id="T_1297e_level0_row12" class="row_heading level0 row12" >CS7</th>
#       <td id="T_1297e_row12_col0" class="data row12 col0" >0.004660</td>
#     </tr>
#     <tr>
#       <th id="T_1297e_level0_row13" class="row_heading level0 row13" >SiO2</th>
#       <td id="T_1297e_row13_col0" class="data row13 col0" >0.004660</td>
#     </tr>
#     <tr>
#       <th id="T_1297e_level0_row14" class="row_heading level0 row14" >CaO</th>
#       <td id="T_1297e_row14_col0" class="data row14 col0" >0.001553</td>
#     </tr>
#     <tr>
#       <th id="T_1297e_level0_row15" class="row_heading level0 row15" >Al2O3</th>
#       <td id="T_1297e_row15_col0" class="data row15 col0" >0.001553</td>
#     </tr>
#     <tr>
#       <th id="T_1297e_level0_row16" class="row_heading level0 row16" >Specific Gravity</th>
#       <td id="T_1297e_row16_col0" class="data row16 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1297e_level0_row17" class="row_heading level0 row17" >CS3</th>
#       <td id="T_1297e_row17_col0" class="data row17 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1297e_level0_row18" class="row_heading level0 row18" >CS28</th>
#       <td id="T_1297e_row18_col0" class="data row18 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Drop rows where the target variable is null

# %%
df = df[df["CS28"].notna()]

# %% [markdown]
# ### Dropping rows where the target variable is zero

# %%
df = df[~df["CS28"].eq(0)]

# %% [markdown]
# ### Dropping rows where any other variable has a zero value - except #200

# %%
for col in df.columns:
    if col != "#200":
        df = df[~df[col].eq(0)]

# %%
(df.isna().sum() / df.shape[0] * 100).sort_values(ascending=False).to_frame(
    name="Missing (%)"
).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_d22f5_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_d22f5_row1_col0 {
#   background-color: #8c0912;
#   color: #f1f1f1;
# }
# #T_d22f5_row2_col0 {
#   background-color: #fcaa8d;
#   color: #000000;
# }
# #T_d22f5_row3_col0, #T_d22f5_row4_col0, #T_d22f5_row5_col0 {
#   background-color: #fcaf93;
#   color: #000000;
# }
# #T_d22f5_row6_col0 {
#   background-color: #fcb095;
#   color: #000000;
# }
# #T_d22f5_row7_col0 {
#   background-color: #fedfd0;
#   color: #000000;
# }
# #T_d22f5_row8_col0 {
#   background-color: #fee3d7;
#   color: #000000;
# }
# #T_d22f5_row9_col0 {
#   background-color: #fee9df;
#   color: #000000;
# }
# #T_d22f5_row10_col0, #T_d22f5_row11_col0 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_d22f5_row12_col0 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_d22f5_row13_col0 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_d22f5_row14_col0, #T_d22f5_row15_col0 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_d22f5_row16_col0, #T_d22f5_row17_col0, #T_d22f5_row18_col0, #T_d22f5_row19_col0, #T_d22f5_row20_col0, #T_d22f5_row21_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_d22f5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d22f5_level0_col0" class="col_heading level0 col0" >Missing (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d22f5_level0_row0" class="row_heading level0 row0" >Specific Gravity</th>
#       <td id="T_d22f5_row0_col0" class="data row0 col0" >89.481904</td>
#     </tr>
#     <tr>
#       <th id="T_d22f5_level0_row1" class="row_heading level0 row1" >#400</th>
#       <td id="T_d22f5_row1_col0" class="data row1 col0" >82.590958</td>
#     </tr>
#     <tr>
#       <th id="T_d22f5_level0_row2" class="row_heading level0 row2" >Insoluble Residue</th>
#       <td id="T_d22f5_row2_col0" class="data row2 col0" >26.950230</td>
#     </tr>
#     <tr>
#       <th id="T_d22f5_level0_row3" class="row_heading level0 row3" >Fe2O3</th>
#       <td id="T_d22f5_row3_col0" class="data row3 col0" >25.557379</td>
#     </tr>
#     <tr>
#       <th id="T_d22f5_level0_row4" class="row_heading level0 row4" >Al2O3</th>
#       <td id="T_d22f5_row4_col0" class="data row4 col0" >25.551005</td>
#     </tr>
#     <tr>
#       <th id="T_d22f5_level0_row5" class="row_heading level0 row5" >SiO2</th>
#       <td id="T_d22f5_row5_col0" class="data row5 col0" >25.525506</td>
#     </tr>
#     <tr>
#       <th id="T_d22f5_level0_row6" class="row_heading level0 row6" >CaO</th>
#       <td id="T_d22f5_row6_col0" class="data row6 col0" >25.383671</td>
#     </tr>
#     <tr>
#       <th id="T_d22f5_level0_row7" class="row_heading level0 row7" >Na2O</th>
#       <td id="T_d22f5_row7_col0" class="data row7 col0" >11.864731</td>
#     </tr>
#     <tr>
#       <th id="T_d22f5_level0_row8" class="row_heading level0 row8" >K2O</th>
#       <td id="T_d22f5_row8_col0" class="data row8 col0" >9.469474</td>
#     </tr>
#     <tr>
#       <th id="T_d22f5_level0_row9" class="row_heading level0 row9" >CS3</th>
#       <td id="T_d22f5_row9_col0" class="data row9 col0" >6.443131</td>
#     </tr>
#     <tr>
#       <th id="T_d22f5_level0_row10" class="row_heading level0 row10" >Initial setting time</th>
#       <td id="T_d22f5_row10_col0" class="data row10 col0" >4.447880</td>
#     </tr>
#     <tr>
#       <th id="T_d22f5_level0_row11" class="row_heading level0 row11" >#200</th>
#       <td id="T_d22f5_row11_col0" class="data row11 col0" >4.278953</td>
#     </tr>
#     <tr>
#       <th id="T_d22f5_level0_row12" class="row_heading level0 row12" >MgO</th>
#       <td id="T_d22f5_row12_col0" class="data row12 col0" >3.145867</td>
#     </tr>
#     <tr>
#       <th id="T_d22f5_level0_row13" class="row_heading level0 row13" >Final setting time</th>
#       <td id="T_d22f5_row13_col0" class="data row13 col0" >1.238267</td>
#     </tr>
#     <tr>
#       <th id="T_d22f5_level0_row14" class="row_heading level0 row14" >SO3</th>
#       <td id="T_d22f5_row14_col0" class="data row14 col0" >1.032686</td>
#     </tr>
#     <tr>
#       <th id="T_d22f5_level0_row15" class="row_heading level0 row15" >Loss on Ignition</th>
#       <td id="T_d22f5_row15_col0" class="data row15 col0" >0.752203</td>
#     </tr>
#     <tr>
#       <th id="T_d22f5_level0_row16" class="row_heading level0 row16" >Blaine</th>
#       <td id="T_d22f5_row16_col0" class="data row16 col0" >0.307575</td>
#     </tr>
#     <tr>
#       <th id="T_d22f5_level0_row17" class="row_heading level0 row17" >CS7</th>
#       <td id="T_d22f5_row17_col0" class="data row17 col0" >0.137054</td>
#     </tr>
#     <tr>
#       <th id="T_d22f5_level0_row18" class="row_heading level0 row18" >Cement_Type</th>
#       <td id="T_d22f5_row18_col0" class="data row18 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d22f5_level0_row19" class="row_heading level0 row19" >Date</th>
#       <td id="T_d22f5_row19_col0" class="data row19 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d22f5_level0_row20" class="row_heading level0 row20" >CS28</th>
#       <td id="T_d22f5_row20_col0" class="data row20 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d22f5_level0_row21" class="row_heading level0 row21" >Factory_Plant</th>
#       <td id="T_d22f5_row21_col0" class="data row21 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %%
zero_values = {}
for col in df.select_dtypes(include="number").columns:
    zero_percentages = (df[df[col].eq(0)].shape[0] / df.shape[0]) * 100
    zero_values[col] = zero_percentages

zero_percentages = pd.Series(zero_values, name=f"Zero (%) for Global Dataset")
zero_percentages = zero_percentages.sort_values(ascending=False)
zero_percentages = zero_percentages.to_frame(name=f"Zero (%) for Global Dataset")
zero_percentages.style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_38c63_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_38c63_row1_col0, #T_38c63_row2_col0, #T_38c63_row3_col0, #T_38c63_row4_col0, #T_38c63_row5_col0, #T_38c63_row6_col0, #T_38c63_row7_col0, #T_38c63_row8_col0, #T_38c63_row9_col0, #T_38c63_row10_col0, #T_38c63_row11_col0, #T_38c63_row12_col0, #T_38c63_row13_col0, #T_38c63_row14_col0, #T_38c63_row15_col0, #T_38c63_row16_col0, #T_38c63_row17_col0, #T_38c63_row18_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_38c63">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_38c63_level0_col0" class="col_heading level0 col0" >Zero (%) for Global Dataset</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_38c63_level0_row0" class="row_heading level0 row0" >#200</th>
#       <td id="T_38c63_row0_col0" class="data row0 col0" >14.463976</td>
#     </tr>
#     <tr>
#       <th id="T_38c63_level0_row1" class="row_heading level0 row1" >CaO</th>
#       <td id="T_38c63_row1_col0" class="data row1 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_38c63_level0_row2" class="row_heading level0 row2" >Blaine</th>
#       <td id="T_38c63_row2_col0" class="data row2 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_38c63_level0_row3" class="row_heading level0 row3" >CS7</th>
#       <td id="T_38c63_row3_col0" class="data row3 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_38c63_level0_row4" class="row_heading level0 row4" >CS3</th>
#       <td id="T_38c63_row4_col0" class="data row4 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_38c63_level0_row5" class="row_heading level0 row5" >Final setting time</th>
#       <td id="T_38c63_row5_col0" class="data row5 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_38c63_level0_row6" class="row_heading level0 row6" >Initial setting time</th>
#       <td id="T_38c63_row6_col0" class="data row6 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_38c63_level0_row7" class="row_heading level0 row7" >Specific Gravity</th>
#       <td id="T_38c63_row7_col0" class="data row7 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_38c63_level0_row8" class="row_heading level0 row8" >#400</th>
#       <td id="T_38c63_row8_col0" class="data row8 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_38c63_level0_row9" class="row_heading level0 row9" >Insoluble Residue</th>
#       <td id="T_38c63_row9_col0" class="data row9 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_38c63_level0_row10" class="row_heading level0 row10" >MgO</th>
#       <td id="T_38c63_row10_col0" class="data row10 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_38c63_level0_row11" class="row_heading level0 row11" >Loss on Ignition</th>
#       <td id="T_38c63_row11_col0" class="data row11 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_38c63_level0_row12" class="row_heading level0 row12" >Fe2O3</th>
#       <td id="T_38c63_row12_col0" class="data row12 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_38c63_level0_row13" class="row_heading level0 row13" >K2O</th>
#       <td id="T_38c63_row13_col0" class="data row13 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_38c63_level0_row14" class="row_heading level0 row14" >SO3</th>
#       <td id="T_38c63_row14_col0" class="data row14 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_38c63_level0_row15" class="row_heading level0 row15" >SiO2</th>
#       <td id="T_38c63_row15_col0" class="data row15 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_38c63_level0_row16" class="row_heading level0 row16" >Al2O3</th>
#       <td id="T_38c63_row16_col0" class="data row16 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_38c63_level0_row17" class="row_heading level0 row17" >Na2O</th>
#       <td id="T_38c63_row17_col0" class="data row17 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_38c63_level0_row18" class="row_heading level0 row18" >CS28</th>
#       <td id="T_38c63_row18_col0" class="data row18 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.shape
# Out:
# (62749, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 62749 entries, 0 to 64377
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  62749 non-null  object
#  1   CaO                   46821 non-null  float64
#  2   MgO                   60775 non-null  float64
#  3   Na2O                  55304 non-null  float64
#  4   Al2O3                 46716 non-null  float64
#  5   SiO2                  46732 non-null  float64
#  6   SO3                   62101 non-null  float64
#  7   K2O                   56807 non-null  float64
#  8   Fe2O3                 46712 non-null  float64
#  9   Loss on Ignition      62277 non-null  float64
#  10  Insoluble Residue     45838 non-null  float64
#  11  Blaine                62556 non-null  float64
#  12  #200                  60064 non-null  float64
#  13  #400                  10924 non-null  float64
#  14  Specific Gravity      6600 non-null   float64
#  15  Initial setting time  59958 non-null  float64
#  16  Final setting time    61972 non-null  float64
#  17  CS3                   58706 non-null  float64
#  18  CS7                   62663 non-null  float64
#  19  CS28                  62749 non-null  float64
#  20  Cement_Type           62749 non-null  object
#  21  Factory_Plant         62749 non-null  object
# dtypes: float64(19), object(3)
# memory usage: 11.0+ MB

# %% [markdown]
# ### Sort the dataset by date

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df = df.sort_values(by="Date")

# %% [markdown]
# ## Saving the dataset

# %% [markdown]
# <h3>Saving for feature engineering</h3>

# %%
df.to_csv("../../../../data/interim/207/global_at.csv", index=False)
