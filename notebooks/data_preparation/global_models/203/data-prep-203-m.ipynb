# %%
# %load_ext nb_black

# %%
import pandas as pd
import numpy as np
import missingno as msno

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading the datasets

# %% [markdown]
# ## Reading the global dataset

# %%
df = pd.read_csv("../../../../data/interim/Global-Dataset/global_dataset.csv")

# %% [markdown]
# ## Reading the local dataset for plant M

# %%
df_m = pd.read_csv("../../../../data/processed/203/m.csv")

# %% [markdown]
# # Preprocessing of Global Dataset

# %% [markdown]
# ### Removing the plant to be fine-tuned

# %%
df.shape
# Out:
# (66111, 48)

# %%
df = df[df["Factory_Plant"] != "203_M"].reset_index(drop=True)

# %%
df.shape
# Out:
# (60212, 48)

# %% [markdown]
# ### Removing non-matching columns between the datasets

# %%
df = df[df_m.columns.to_list() + ["Factory_Plant"]]

# %%
df.shape
# Out:
# (60212, 17)

# %% [markdown]
# ## Removing missing features

# %%
(df.isna().sum() / df.shape[0] * 100).sort_values(ascending=False).to_frame(
    name="Missing (%)"
).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_d685d_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_d685d_row1_col0 {
#   background-color: #fcbfa7;
#   color: #000000;
# }
# #T_d685d_row2_col0 {
#   background-color: #fcc4ad;
#   color: #000000;
# }
# #T_d685d_row3_col0 {
#   background-color: #fdd7c6;
#   color: #000000;
# }
# #T_d685d_row4_col0 {
#   background-color: #fee7dc;
#   color: #000000;
# }
# #T_d685d_row5_col0 {
#   background-color: #fee9df;
#   color: #000000;
# }
# #T_d685d_row6_col0 {
#   background-color: #ffece3;
#   color: #000000;
# }
# #T_d685d_row7_col0 {
#   background-color: #ffeee7;
#   color: #000000;
# }
# #T_d685d_row8_col0 {
#   background-color: #fff2eb;
#   color: #000000;
# }
# #T_d685d_row9_col0 {
#   background-color: #fff2ec;
#   color: #000000;
# }
# #T_d685d_row10_col0 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_d685d_row11_col0 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_d685d_row12_col0, #T_d685d_row13_col0, #T_d685d_row14_col0, #T_d685d_row15_col0, #T_d685d_row16_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_d685d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d685d_level0_col0" class="col_heading level0 col0" >Missing (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d685d_level0_row0" class="row_heading level0 row0" >CS1</th>
#       <td id="T_d685d_row0_col0" class="data row0 col0" >55.211586</td>
#     </tr>
#     <tr>
#       <th id="T_d685d_level0_row1" class="row_heading level0 row1" >#325</th>
#       <td id="T_d685d_row1_col0" class="data row1 col0" >12.982462</td>
#     </tr>
#     <tr>
#       <th id="T_d685d_level0_row2" class="row_heading level0 row2" >Na2O</th>
#       <td id="T_d685d_row2_col0" class="data row2 col0" >12.240085</td>
#     </tr>
#     <tr>
#       <th id="T_d685d_level0_row3" class="row_heading level0 row3" >K2O</th>
#       <td id="T_d685d_row3_col0" class="data row3 col0" >8.724175</td>
#     </tr>
#     <tr>
#       <th id="T_d685d_level0_row4" class="row_heading level0 row4" >Initial setting time</th>
#       <td id="T_d685d_row4_col0" class="data row4 col0" >4.598751</td>
#     </tr>
#     <tr>
#       <th id="T_d685d_level0_row5" class="row_heading level0 row5" >CS3</th>
#       <td id="T_d685d_row5_col0" class="data row5 col0" >3.887929</td>
#     </tr>
#     <tr>
#       <th id="T_d685d_level0_row6" class="row_heading level0 row6" >MgO</th>
#       <td id="T_d685d_row6_col0" class="data row6 col0" >3.195376</td>
#     </tr>
#     <tr>
#       <th id="T_d685d_level0_row7" class="row_heading level0 row7" >#200</th>
#       <td id="T_d685d_row7_col0" class="data row7 col0" >2.255364</td>
#     </tr>
#     <tr>
#       <th id="T_d685d_level0_row8" class="row_heading level0 row8" >Final setting time</th>
#       <td id="T_d685d_row8_col0" class="data row8 col0" >1.262207</td>
#     </tr>
#     <tr>
#       <th id="T_d685d_level0_row9" class="row_heading level0 row9" >SO3</th>
#       <td id="T_d685d_row9_col0" class="data row9 col0" >0.935030</td>
#     </tr>
#     <tr>
#       <th id="T_d685d_level0_row10" class="row_heading level0 row10" >Loss on Ignition</th>
#       <td id="T_d685d_row10_col0" class="data row10 col0" >0.694214</td>
#     </tr>
#     <tr>
#       <th id="T_d685d_level0_row11" class="row_heading level0 row11" >Blaine</th>
#       <td id="T_d685d_row11_col0" class="data row11 col0" >0.303926</td>
#     </tr>
#     <tr>
#       <th id="T_d685d_level0_row12" class="row_heading level0 row12" >CS7</th>
#       <td id="T_d685d_row12_col0" class="data row12 col0" >0.141168</td>
#     </tr>
#     <tr>
#       <th id="T_d685d_level0_row13" class="row_heading level0 row13" >Cement_Type</th>
#       <td id="T_d685d_row13_col0" class="data row13 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d685d_level0_row14" class="row_heading level0 row14" >Date</th>
#       <td id="T_d685d_row14_col0" class="data row14 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d685d_level0_row15" class="row_heading level0 row15" >CS28</th>
#       <td id="T_d685d_row15_col0" class="data row15 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d685d_level0_row16" class="row_heading level0 row16" >Factory_Plant</th>
#       <td id="T_d685d_row16_col0" class="data row16 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %%
msno.matrix(df.loc[(df["CS1"].notna() == True)])
# Out:
# <Axes: >

# %%
missing_counts = df.isnull().sum()
plt.figure(figsize=(12, 6))
plt.bar(missing_counts.index, missing_counts.values)
plt.xticks(rotation=60)
plt.xlabel("Columns")
plt.ylabel("Number of Missing Values")
plt.title("Missing Values per Column")
plt.show()

# %% [markdown]
# ### Removing features with many zeros when applicable

# %%
zero_values = {}
for col in df.select_dtypes(include="number").columns:
    zero_percentages = (df[df[col].eq(0)].shape[0] / df.shape[0]) * 100
    zero_values[col] = zero_percentages

zero_percentages = pd.Series(zero_values, name=f"Zero (%) for Global Dataset")
zero_percentages = zero_percentages.sort_values(ascending=False)
zero_percentages = zero_percentages.to_frame(name=f"Zero (%) for Global Dataset")
zero_percentages.style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_8bb85_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_8bb85_row1_col0 {
#   background-color: #fee2d5;
#   color: #000000;
# }
# #T_8bb85_row2_col0 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_8bb85_row3_col0, #T_8bb85_row4_col0, #T_8bb85_row5_col0, #T_8bb85_row6_col0, #T_8bb85_row7_col0 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_8bb85_row8_col0, #T_8bb85_row9_col0, #T_8bb85_row10_col0, #T_8bb85_row11_col0, #T_8bb85_row12_col0, #T_8bb85_row13_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_8bb85">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8bb85_level0_col0" class="col_heading level0 col0" >Zero (%) for Global Dataset</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8bb85_level0_row0" class="row_heading level0 row0" >#200</th>
#       <td id="T_8bb85_row0_col0" class="data row0 col0" >15.237826</td>
#     </tr>
#     <tr>
#       <th id="T_8bb85_level0_row1" class="row_heading level0 row1" >Na2O</th>
#       <td id="T_8bb85_row1_col0" class="data row1 col0" >1.743838</td>
#     </tr>
#     <tr>
#       <th id="T_8bb85_level0_row2" class="row_heading level0 row2" >#325</th>
#       <td id="T_8bb85_row2_col0" class="data row2 col0" >0.375340</td>
#     </tr>
#     <tr>
#       <th id="T_8bb85_level0_row3" class="row_heading level0 row3" >Loss on Ignition</th>
#       <td id="T_8bb85_row3_col0" class="data row3 col0" >0.109613</td>
#     </tr>
#     <tr>
#       <th id="T_8bb85_level0_row4" class="row_heading level0 row4" >Blaine</th>
#       <td id="T_8bb85_row4_col0" class="data row4 col0" >0.101309</td>
#     </tr>
#     <tr>
#       <th id="T_8bb85_level0_row5" class="row_heading level0 row5" >Initial setting time</th>
#       <td id="T_8bb85_row5_col0" class="data row5 col0" >0.091344</td>
#     </tr>
#     <tr>
#       <th id="T_8bb85_level0_row6" class="row_heading level0 row6" >Final setting time</th>
#       <td id="T_8bb85_row6_col0" class="data row6 col0" >0.089683</td>
#     </tr>
#     <tr>
#       <th id="T_8bb85_level0_row7" class="row_heading level0 row7" >SO3</th>
#       <td id="T_8bb85_row7_col0" class="data row7 col0" >0.068093</td>
#     </tr>
#     <tr>
#       <th id="T_8bb85_level0_row8" class="row_heading level0 row8" >MgO</th>
#       <td id="T_8bb85_row8_col0" class="data row8 col0" >0.023251</td>
#     </tr>
#     <tr>
#       <th id="T_8bb85_level0_row9" class="row_heading level0 row9" >K2O</th>
#       <td id="T_8bb85_row9_col0" class="data row9 col0" >0.013286</td>
#     </tr>
#     <tr>
#       <th id="T_8bb85_level0_row10" class="row_heading level0 row10" >CS7</th>
#       <td id="T_8bb85_row10_col0" class="data row10 col0" >0.004982</td>
#     </tr>
#     <tr>
#       <th id="T_8bb85_level0_row11" class="row_heading level0 row11" >CS1</th>
#       <td id="T_8bb85_row11_col0" class="data row11 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8bb85_level0_row12" class="row_heading level0 row12" >CS3</th>
#       <td id="T_8bb85_row12_col0" class="data row12 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8bb85_level0_row13" class="row_heading level0 row13" >CS28</th>
#       <td id="T_8bb85_row13_col0" class="data row13 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Drop rows where the target variable is null

# %%
df = df[df["CS28"].notna()]

# %% [markdown]
# ### Dropping rows where the target variable is zero

# %%
df = df[~df["CS28"].eq(0)]

# %% [markdown]
# ### Dropping rows where any other variable has a zero value - except #200

# %%
for col in df.columns:
    if col != "#200":
        df = df[~df[col].eq(0)]

# %%
(df.isna().sum() / df.shape[0] * 100).sort_values(ascending=False).to_frame(
    name="Missing (%)"
).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_3e874_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_3e874_row1_col0 {
#   background-color: #fcbfa7;
#   color: #000000;
# }
# #T_3e874_row2_col0 {
#   background-color: #fcc4ad;
#   color: #000000;
# }
# #T_3e874_row3_col0 {
#   background-color: #fdd7c6;
#   color: #000000;
# }
# #T_3e874_row4_col0 {
#   background-color: #fee7dc;
#   color: #000000;
# }
# #T_3e874_row5_col0 {
#   background-color: #fee9df;
#   color: #000000;
# }
# #T_3e874_row6_col0 {
#   background-color: #ffece3;
#   color: #000000;
# }
# #T_3e874_row7_col0 {
#   background-color: #ffeee7;
#   color: #000000;
# }
# #T_3e874_row8_col0 {
#   background-color: #fff2eb;
#   color: #000000;
# }
# #T_3e874_row9_col0 {
#   background-color: #fff2ec;
#   color: #000000;
# }
# #T_3e874_row10_col0 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_3e874_row11_col0 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_3e874_row12_col0, #T_3e874_row13_col0, #T_3e874_row14_col0, #T_3e874_row15_col0, #T_3e874_row16_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_3e874">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3e874_level0_col0" class="col_heading level0 col0" >Missing (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3e874_level0_row0" class="row_heading level0 row0" >CS1</th>
#       <td id="T_3e874_row0_col0" class="data row0 col0" >55.830611</td>
#     </tr>
#     <tr>
#       <th id="T_3e874_level0_row1" class="row_heading level0 row1" >#325</th>
#       <td id="T_3e874_row1_col0" class="data row1 col0" >13.161835</td>
#     </tr>
#     <tr>
#       <th id="T_3e874_level0_row2" class="row_heading level0 row2" >Na2O</th>
#       <td id="T_3e874_row2_col0" class="data row2 col0" >12.408126</td>
#     </tr>
#     <tr>
#       <th id="T_3e874_level0_row3" class="row_heading level0 row3" >K2O</th>
#       <td id="T_3e874_row3_col0" class="data row3 col0" >8.867565</td>
#     </tr>
#     <tr>
#       <th id="T_3e874_level0_row4" class="row_heading level0 row4" >Initial setting time</th>
#       <td id="T_3e874_row4_col0" class="data row4 col0" >4.673676</td>
#     </tr>
#     <tr>
#       <th id="T_3e874_level0_row5" class="row_heading level0 row5" >CS3</th>
#       <td id="T_3e874_row5_col0" class="data row5 col0" >3.972710</td>
#     </tr>
#     <tr>
#       <th id="T_3e874_level0_row6" class="row_heading level0 row6" >MgO</th>
#       <td id="T_3e874_row6_col0" class="data row6 col0" >3.205390</td>
#     </tr>
#     <tr>
#       <th id="T_3e874_level0_row7" class="row_heading level0 row7" >#200</th>
#       <td id="T_3e874_row7_col0" class="data row7 col0" >2.215190</td>
#     </tr>
#     <tr>
#       <th id="T_3e874_level0_row8" class="row_heading level0 row8" >Final setting time</th>
#       <td id="T_3e874_row8_col0" class="data row8 col0" >1.245406</td>
#     </tr>
#     <tr>
#       <th id="T_3e874_level0_row9" class="row_heading level0 row9" >SO3</th>
#       <td id="T_3e874_row9_col0" class="data row9 col0" >0.949367</td>
#     </tr>
#     <tr>
#       <th id="T_3e874_level0_row10" class="row_heading level0 row10" >Loss on Ignition</th>
#       <td id="T_3e874_row10_col0" class="data row10 col0" >0.658432</td>
#     </tr>
#     <tr>
#       <th id="T_3e874_level0_row11" class="row_heading level0 row11" >Blaine</th>
#       <td id="T_3e874_row11_col0" class="data row11 col0" >0.292636</td>
#     </tr>
#     <tr>
#       <th id="T_3e874_level0_row12" class="row_heading level0 row12" >CS7</th>
#       <td id="T_3e874_row12_col0" class="data row12 col0" >0.137811</td>
#     </tr>
#     <tr>
#       <th id="T_3e874_level0_row13" class="row_heading level0 row13" >Cement_Type</th>
#       <td id="T_3e874_row13_col0" class="data row13 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3e874_level0_row14" class="row_heading level0 row14" >Date</th>
#       <td id="T_3e874_row14_col0" class="data row14 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3e874_level0_row15" class="row_heading level0 row15" >CS28</th>
#       <td id="T_3e874_row15_col0" class="data row15 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3e874_level0_row16" class="row_heading level0 row16" >Factory_Plant</th>
#       <td id="T_3e874_row16_col0" class="data row16 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %%
zero_values = {}
for col in df.select_dtypes(include="number").columns:
    zero_percentages = (df[df[col].eq(0)].shape[0] / df.shape[0]) * 100
    zero_values[col] = zero_percentages

zero_percentages = pd.Series(zero_values, name=f"Zero (%) for Global Dataset")
zero_percentages = zero_percentages.sort_values(ascending=False)
zero_percentages = zero_percentages.to_frame(name=f"Zero (%) for Global Dataset")
zero_percentages.style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_bfb17_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_bfb17_row1_col0, #T_bfb17_row2_col0, #T_bfb17_row3_col0, #T_bfb17_row4_col0, #T_bfb17_row5_col0, #T_bfb17_row6_col0, #T_bfb17_row7_col0, #T_bfb17_row8_col0, #T_bfb17_row9_col0, #T_bfb17_row10_col0, #T_bfb17_row11_col0, #T_bfb17_row12_col0, #T_bfb17_row13_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_bfb17">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bfb17_level0_col0" class="col_heading level0 col0" >Zero (%) for Global Dataset</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bfb17_level0_row0" class="row_heading level0 row0" >#200</th>
#       <td id="T_bfb17_row0_col0" class="data row0 col0" >15.097999</td>
#     </tr>
#     <tr>
#       <th id="T_bfb17_level0_row1" class="row_heading level0 row1" >MgO</th>
#       <td id="T_bfb17_row1_col0" class="data row1 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bfb17_level0_row2" class="row_heading level0 row2" >Na2O</th>
#       <td id="T_bfb17_row2_col0" class="data row2 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bfb17_level0_row3" class="row_heading level0 row3" >SO3</th>
#       <td id="T_bfb17_row3_col0" class="data row3 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bfb17_level0_row4" class="row_heading level0 row4" >K2O</th>
#       <td id="T_bfb17_row4_col0" class="data row4 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bfb17_level0_row5" class="row_heading level0 row5" >Loss on Ignition</th>
#       <td id="T_bfb17_row5_col0" class="data row5 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bfb17_level0_row6" class="row_heading level0 row6" >Blaine</th>
#       <td id="T_bfb17_row6_col0" class="data row6 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bfb17_level0_row7" class="row_heading level0 row7" >#325</th>
#       <td id="T_bfb17_row7_col0" class="data row7 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bfb17_level0_row8" class="row_heading level0 row8" >Initial setting time</th>
#       <td id="T_bfb17_row8_col0" class="data row8 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bfb17_level0_row9" class="row_heading level0 row9" >Final setting time</th>
#       <td id="T_bfb17_row9_col0" class="data row9 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bfb17_level0_row10" class="row_heading level0 row10" >CS1</th>
#       <td id="T_bfb17_row10_col0" class="data row10 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bfb17_level0_row11" class="row_heading level0 row11" >CS3</th>
#       <td id="T_bfb17_row11_col0" class="data row11 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bfb17_level0_row12" class="row_heading level0 row12" >CS7</th>
#       <td id="T_bfb17_row12_col0" class="data row12 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bfb17_level0_row13" class="row_heading level0 row13" >CS28</th>
#       <td id="T_bfb17_row13_col0" class="data row13 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.shape
# Out:
# (58776, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 58776 entries, 0 to 60211
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  58776 non-null  object
#  1   MgO                   56892 non-null  float64
#  2   Na2O                  51483 non-null  float64
#  3   SO3                   58218 non-null  float64
#  4   K2O                   53564 non-null  float64
#  5   Loss on Ignition      58389 non-null  float64
#  6   Blaine                58604 non-null  float64
#  7   #200                  57474 non-null  float64
#  8   #325                  51040 non-null  float64
#  9   Initial setting time  56029 non-null  float64
#  10  Final setting time    58044 non-null  float64
#  11  CS1                   25961 non-null  float64
#  12  CS3                   56441 non-null  float64
#  13  CS7                   58695 non-null  float64
#  14  CS28                  58776 non-null  float64
#  15  Cement_Type           58776 non-null  object
#  16  Factory_Plant         58776 non-null  object
# dtypes: float64(14), object(3)
# memory usage: 8.1+ MB

# %% [markdown]
# ### Sort the dataset by date

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df = df.sort_values(by="Date")

# %% [markdown]
# ## Saving the dataset

# %% [markdown]
# <h3>Saving for feature engineering</h3>

# %%
df.to_csv("../../../../data/interim/203/global_m.csv", index=False)
