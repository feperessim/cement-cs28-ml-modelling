# %%
# %load_ext nb_black

# %%
import pandas as pd
import numpy as np
import missingno as msno

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading the datasets

# %% [markdown]
# ## Reading the global dataset

# %%
df = pd.read_csv("../../../../data/interim/Global-Dataset/global_dataset.csv")

# %% [markdown]
# ## Reading the local dataset for plant C

# %%
df_c = pd.read_csv("../../../../data/processed/203/c.csv")

# %% [markdown]
# # Preprocessing of Global Dataset

# %% [markdown]
# ### Removing the plant to be fine-tuned

# %%
df.shape
# Out:
# (66111, 48)

# %%
df = df[df["Factory_Plant"] != " "].reset_index(drop=True)

# %%
df.shape
# Out:
# (66111, 48)

# %% [markdown]
# ### Removing non-matching columns between the datasets

# %%
df = df[df_c.columns.to_list() + ["Factory_Plant"]]

# %%
df.shape
# Out:
# (66111, 23)

# %% [markdown]
# ## Removing missing features

# %%
(df.isna().sum() / df.shape[0] * 100).sort_values(ascending=False).to_frame(
    name="Missing (%)"
).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_4f8a2_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_4f8a2_row1_col0 {
#   background-color: #f34a36;
#   color: #f1f1f1;
# }
# #T_4f8a2_row2_col0 {
#   background-color: #fca689;
#   color: #000000;
# }
# #T_4f8a2_row3_col0, #T_4f8a2_row4_col0, #T_4f8a2_row5_col0 {
#   background-color: #fcb095;
#   color: #000000;
# }
# #T_4f8a2_row6_col0 {
#   background-color: #fcb296;
#   color: #000000;
# }
# #T_4f8a2_row7_col0 {
#   background-color: #fedccd;
#   color: #000000;
# }
# #T_4f8a2_row8_col0 {
#   background-color: #fedfd0;
#   color: #000000;
# }
# #T_4f8a2_row9_col0 {
#   background-color: #fee4d8;
#   color: #000000;
# }
# #T_4f8a2_row10_col0 {
#   background-color: #fee9df;
#   color: #000000;
# }
# #T_4f8a2_row11_col0, #T_4f8a2_row12_col0 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_4f8a2_row13_col0 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_4f8a2_row14_col0 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_4f8a2_row15_col0, #T_4f8a2_row16_col0 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_4f8a2_row17_col0, #T_4f8a2_row18_col0, #T_4f8a2_row19_col0, #T_4f8a2_row20_col0, #T_4f8a2_row21_col0, #T_4f8a2_row22_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_4f8a2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4f8a2_level0_col0" class="col_heading level0 col0" >Missing (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4f8a2_level0_row0" class="row_heading level0 row0" >TiO2</th>
#       <td id="T_4f8a2_row0_col0" class="data row0 col0" >85.926699</td>
#     </tr>
#     <tr>
#       <th id="T_4f8a2_level0_row1" class="row_heading level0 row1" >CS1</th>
#       <td id="T_4f8a2_row1_col0" class="data row1 col0" >50.286639</td>
#     </tr>
#     <tr>
#       <th id="T_4f8a2_level0_row2" class="row_heading level0 row2" >Insoluble Residue</th>
#       <td id="T_4f8a2_row2_col0" class="data row2 col0" >26.876012</td>
#     </tr>
#     <tr>
#       <th id="T_4f8a2_level0_row3" class="row_heading level0 row3" >Fe2O3</th>
#       <td id="T_4f8a2_row3_col0" class="data row3 col0" >24.319705</td>
#     </tr>
#     <tr>
#       <th id="T_4f8a2_level0_row4" class="row_heading level0 row4" >Al2O3</th>
#       <td id="T_4f8a2_row4_col0" class="data row4 col0" >24.313654</td>
#     </tr>
#     <tr>
#       <th id="T_4f8a2_level0_row5" class="row_heading level0 row5" >SiO2</th>
#       <td id="T_4f8a2_row5_col0" class="data row5 col0" >24.289453</td>
#     </tr>
#     <tr>
#       <th id="T_4f8a2_level0_row6" class="row_heading level0 row6" >CaO</th>
#       <td id="T_4f8a2_row6_col0" class="data row6 col0" >24.154831</td>
#     </tr>
#     <tr>
#       <th id="T_4f8a2_level0_row7" class="row_heading level0 row7" >#325</th>
#       <td id="T_4f8a2_row7_col0" class="data row7 col0" >11.943549</td>
#     </tr>
#     <tr>
#       <th id="T_4f8a2_level0_row8" class="row_heading level0 row8" >Na2O</th>
#       <td id="T_4f8a2_row8_col0" class="data row8 col0" >11.361196</td>
#     </tr>
#     <tr>
#       <th id="T_4f8a2_level0_row9" class="row_heading level0 row9" >K2O</th>
#       <td id="T_4f8a2_row9_col0" class="data row9 col0" >9.043881</td>
#     </tr>
#     <tr>
#       <th id="T_4f8a2_level0_row10" class="row_heading level0 row10" >CS3</th>
#       <td id="T_4f8a2_row10_col0" class="data row10 col0" >6.123036</td>
#     </tr>
#     <tr>
#       <th id="T_4f8a2_level0_row11" class="row_heading level0 row11" >Initial setting time</th>
#       <td id="T_4f8a2_row11_col0" class="data row11 col0" >4.232276</td>
#     </tr>
#     <tr>
#       <th id="T_4f8a2_level0_row12" class="row_heading level0 row12" >#200</th>
#       <td id="T_4f8a2_row12_col0" class="data row12 col0" >4.141520</td>
#     </tr>
#     <tr>
#       <th id="T_4f8a2_level0_row13" class="row_heading level0 row13" >MgO</th>
#       <td id="T_4f8a2_row13_col0" class="data row13 col0" >3.040341</td>
#     </tr>
#     <tr>
#       <th id="T_4f8a2_level0_row14" class="row_heading level0 row14" >Final setting time</th>
#       <td id="T_4f8a2_row14_col0" class="data row14 col0" >1.191935</td>
#     </tr>
#     <tr>
#       <th id="T_4f8a2_level0_row15" class="row_heading level0 row15" >SO3</th>
#       <td id="T_4f8a2_row15_col0" class="data row15 col0" >0.981682</td>
#     </tr>
#     <tr>
#       <th id="T_4f8a2_level0_row16" class="row_heading level0 row16" >Loss on Ignition</th>
#       <td id="T_4f8a2_row16_col0" class="data row16 col0" >0.760842</td>
#     </tr>
#     <tr>
#       <th id="T_4f8a2_level0_row17" class="row_heading level0 row17" >Blaine</th>
#       <td id="T_4f8a2_row17_col0" class="data row17 col0" >0.302522</td>
#     </tr>
#     <tr>
#       <th id="T_4f8a2_level0_row18" class="row_heading level0 row18" >CS7</th>
#       <td id="T_4f8a2_row18_col0" class="data row18 col0" >0.136135</td>
#     </tr>
#     <tr>
#       <th id="T_4f8a2_level0_row19" class="row_heading level0 row19" >Cement_Type</th>
#       <td id="T_4f8a2_row19_col0" class="data row19 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4f8a2_level0_row20" class="row_heading level0 row20" >Date</th>
#       <td id="T_4f8a2_row20_col0" class="data row20 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4f8a2_level0_row21" class="row_heading level0 row21" >CS28</th>
#       <td id="T_4f8a2_row21_col0" class="data row21 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4f8a2_level0_row22" class="row_heading level0 row22" >Factory_Plant</th>
#       <td id="T_4f8a2_row22_col0" class="data row22 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %%
msno.matrix(df.loc[(df["CS1"].notna() == True)])
# Out:
# <Axes: >

# %%
missing_counts = df.isnull().sum()
plt.figure(figsize=(12, 6))
plt.bar(missing_counts.index, missing_counts.values)
plt.xticks(rotation=60)
plt.xlabel("Columns")
plt.ylabel("Number of Missing Values")
plt.title("Missing Values per Column")
plt.show()

# %% [markdown]
# ### Removing features with many zeros when applicable

# %%
zero_values = {}
for col in df.select_dtypes(include="number").columns:
    zero_percentages = (df[df[col].eq(0)].shape[0] / df.shape[0]) * 100
    zero_values[col] = zero_percentages

zero_percentages = pd.Series(zero_values, name=f"Zero (%) for Global Dataset")
zero_percentages = zero_percentages.sort_values(ascending=False)
zero_percentages = zero_percentages.to_frame(name=f"Zero (%) for Global Dataset")
zero_percentages.style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_c0c18_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_c0c18_row1_col0 {
#   background-color: #fee2d5;
#   color: #000000;
# }
# #T_c0c18_row2_col0 {
#   background-color: #ffeee6;
#   color: #000000;
# }
# #T_c0c18_row3_col0 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_c0c18_row4_col0, #T_c0c18_row5_col0, #T_c0c18_row6_col0, #T_c0c18_row7_col0, #T_c0c18_row8_col0, #T_c0c18_row9_col0 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_c0c18_row10_col0, #T_c0c18_row11_col0, #T_c0c18_row12_col0, #T_c0c18_row13_col0, #T_c0c18_row14_col0, #T_c0c18_row15_col0, #T_c0c18_row16_col0, #T_c0c18_row17_col0, #T_c0c18_row18_col0, #T_c0c18_row19_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_c0c18">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c0c18_level0_col0" class="col_heading level0 col0" >Zero (%) for Global Dataset</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c0c18_level0_row0" class="row_heading level0 row0" >#200</th>
#       <td id="T_c0c18_row0_col0" class="data row0 col0" >13.928091</td>
#     </tr>
#     <tr>
#       <th id="T_c0c18_level0_row1" class="row_heading level0 row1" >Na2O</th>
#       <td id="T_c0c18_row1_col0" class="data row1 col0" >1.591263</td>
#     </tr>
#     <tr>
#       <th id="T_c0c18_level0_row2" class="row_heading level0 row2" >Insoluble Residue</th>
#       <td id="T_c0c18_row2_col0" class="data row2 col0" >0.633783</td>
#     </tr>
#     <tr>
#       <th id="T_c0c18_level0_row3" class="row_heading level0 row3" >#325</th>
#       <td id="T_c0c18_row3_col0" class="data row3 col0" >0.343362</td>
#     </tr>
#     <tr>
#       <th id="T_c0c18_level0_row4" class="row_heading level0 row4" >Loss on Ignition</th>
#       <td id="T_c0c18_row4_col0" class="data row4 col0" >0.099832</td>
#     </tr>
#     <tr>
#       <th id="T_c0c18_level0_row5" class="row_heading level0 row5" >Blaine</th>
#       <td id="T_c0c18_row5_col0" class="data row5 col0" >0.092269</td>
#     </tr>
#     <tr>
#       <th id="T_c0c18_level0_row6" class="row_heading level0 row6" >Initial setting time</th>
#       <td id="T_c0c18_row6_col0" class="data row6 col0" >0.083193</td>
#     </tr>
#     <tr>
#       <th id="T_c0c18_level0_row7" class="row_heading level0 row7" >Final setting time</th>
#       <td id="T_c0c18_row7_col0" class="data row7 col0" >0.081681</td>
#     </tr>
#     <tr>
#       <th id="T_c0c18_level0_row8" class="row_heading level0 row8" >SO3</th>
#       <td id="T_c0c18_row8_col0" class="data row8 col0" >0.062017</td>
#     </tr>
#     <tr>
#       <th id="T_c0c18_level0_row9" class="row_heading level0 row9" >TiO2</th>
#       <td id="T_c0c18_row9_col0" class="data row9 col0" >0.055966</td>
#     </tr>
#     <tr>
#       <th id="T_c0c18_level0_row10" class="row_heading level0 row10" >MgO</th>
#       <td id="T_c0c18_row10_col0" class="data row10 col0" >0.021177</td>
#     </tr>
#     <tr>
#       <th id="T_c0c18_level0_row11" class="row_heading level0 row11" >K2O</th>
#       <td id="T_c0c18_row11_col0" class="data row11 col0" >0.012101</td>
#     </tr>
#     <tr>
#       <th id="T_c0c18_level0_row12" class="row_heading level0 row12" >Fe2O3</th>
#       <td id="T_c0c18_row12_col0" class="data row12 col0" >0.007563</td>
#     </tr>
#     <tr>
#       <th id="T_c0c18_level0_row13" class="row_heading level0 row13" >CS7</th>
#       <td id="T_c0c18_row13_col0" class="data row13 col0" >0.004538</td>
#     </tr>
#     <tr>
#       <th id="T_c0c18_level0_row14" class="row_heading level0 row14" >SiO2</th>
#       <td id="T_c0c18_row14_col0" class="data row14 col0" >0.004538</td>
#     </tr>
#     <tr>
#       <th id="T_c0c18_level0_row15" class="row_heading level0 row15" >CaO</th>
#       <td id="T_c0c18_row15_col0" class="data row15 col0" >0.001513</td>
#     </tr>
#     <tr>
#       <th id="T_c0c18_level0_row16" class="row_heading level0 row16" >Al2O3</th>
#       <td id="T_c0c18_row16_col0" class="data row16 col0" >0.001513</td>
#     </tr>
#     <tr>
#       <th id="T_c0c18_level0_row17" class="row_heading level0 row17" >CS1</th>
#       <td id="T_c0c18_row17_col0" class="data row17 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c0c18_level0_row18" class="row_heading level0 row18" >CS3</th>
#       <td id="T_c0c18_row18_col0" class="data row18 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c0c18_level0_row19" class="row_heading level0 row19" >CS28</th>
#       <td id="T_c0c18_row19_col0" class="data row19 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Drop rows where the target variable is null

# %%
df = df[df["CS28"].notna()]

# %% [markdown]
# ### Dropping rows where the target variable is zero

# %%
df = df[~df["CS28"].eq(0)]

# %% [markdown]
# ### Dropping rows where any other variable has a zero value - except #200

# %%
for col in df.columns:
    if col != "#200":
        df = df[~df[col].eq(0)]

# %%
(df.isna().sum() / df.shape[0] * 100).sort_values(ascending=False).to_frame(
    name="Missing (%)"
).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_8061f_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_8061f_row1_col0 {
#   background-color: #f24734;
#   color: #f1f1f1;
# }
# #T_8061f_row2_col0 {
#   background-color: #fca98c;
#   color: #000000;
# }
# #T_8061f_row3_col0, #T_8061f_row4_col0, #T_8061f_row5_col0 {
#   background-color: #fcae92;
#   color: #000000;
# }
# #T_8061f_row6_col0 {
#   background-color: #fcaf93;
#   color: #000000;
# }
# #T_8061f_row7_col0 {
#   background-color: #fedbcc;
#   color: #000000;
# }
# #T_8061f_row8_col0 {
#   background-color: #fedecf;
#   color: #000000;
# }
# #T_8061f_row9_col0 {
#   background-color: #fee3d7;
#   color: #000000;
# }
# #T_8061f_row10_col0 {
#   background-color: #fee9df;
#   color: #000000;
# }
# #T_8061f_row11_col0, #T_8061f_row12_col0 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_8061f_row13_col0 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_8061f_row14_col0 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_8061f_row15_col0, #T_8061f_row16_col0 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_8061f_row17_col0, #T_8061f_row18_col0, #T_8061f_row19_col0, #T_8061f_row20_col0, #T_8061f_row21_col0, #T_8061f_row22_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_8061f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8061f_level0_col0" class="col_heading level0 col0" >Missing (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8061f_level0_row0" class="row_heading level0 row0" >TiO2</th>
#       <td id="T_8061f_row0_col0" class="data row0 col0" >85.848190</td>
#     </tr>
#     <tr>
#       <th id="T_8061f_level0_row1" class="row_heading level0 row1" >CS1</th>
#       <td id="T_8061f_row1_col0" class="data row1 col0" >50.712339</td>
#     </tr>
#     <tr>
#       <th id="T_8061f_level0_row2" class="row_heading level0 row2" >Insoluble Residue</th>
#       <td id="T_8061f_row2_col0" class="data row2 col0" >26.287271</td>
#     </tr>
#     <tr>
#       <th id="T_8061f_level0_row3" class="row_heading level0 row3" >Fe2O3</th>
#       <td id="T_8061f_row3_col0" class="data row3 col0" >24.960685</td>
#     </tr>
#     <tr>
#       <th id="T_8061f_level0_row4" class="row_heading level0 row4" >Al2O3</th>
#       <td id="T_8061f_row4_col0" class="data row4 col0" >24.956014</td>
#     </tr>
#     <tr>
#       <th id="T_8061f_level0_row5" class="row_heading level0 row5" >SiO2</th>
#       <td id="T_8061f_row5_col0" class="data row5 col0" >24.931102</td>
#     </tr>
#     <tr>
#       <th id="T_8061f_level0_row6" class="row_heading level0 row6" >CaO</th>
#       <td id="T_8061f_row6_col0" class="data row6 col0" >24.792526</td>
#     </tr>
#     <tr>
#       <th id="T_8061f_level0_row7" class="row_heading level0 row7" >#325</th>
#       <td id="T_8061f_row7_col0" class="data row7 col0" >12.168159</td>
#     </tr>
#     <tr>
#       <th id="T_8061f_level0_row8" class="row_heading level0 row8" >Na2O</th>
#       <td id="T_8061f_row8_col0" class="data row8 col0" >11.574932</td>
#     </tr>
#     <tr>
#       <th id="T_8061f_level0_row9" class="row_heading level0 row9" >K2O</th>
#       <td id="T_8061f_row9_col0" class="data row9 col0" >9.245621</td>
#     </tr>
#     <tr>
#       <th id="T_8061f_level0_row10" class="row_heading level0 row10" >CS3</th>
#       <td id="T_8061f_row10_col0" class="data row10 col0" >6.293499</td>
#     </tr>
#     <tr>
#       <th id="T_8061f_level0_row11" class="row_heading level0 row11" >Initial setting time</th>
#       <td id="T_8061f_row11_col0" class="data row11 col0" >4.322304</td>
#     </tr>
#     <tr>
#       <th id="T_8061f_level0_row12" class="row_heading level0 row12" >#200</th>
#       <td id="T_8061f_row12_col0" class="data row12 col0" >4.174387</td>
#     </tr>
#     <tr>
#       <th id="T_8061f_level0_row13" class="row_heading level0 row13" >MgO</th>
#       <td id="T_8061f_row13_col0" class="data row13 col0" >3.067341</td>
#     </tr>
#     <tr>
#       <th id="T_8061f_level0_row14" class="row_heading level0 row14" >Final setting time</th>
#       <td id="T_8061f_row14_col0" class="data row14 col0" >1.183340</td>
#     </tr>
#     <tr>
#       <th id="T_8061f_level0_row15" class="row_heading level0 row15" >SO3</th>
#       <td id="T_8061f_row15_col0" class="data row15 col0" >1.002725</td>
#     </tr>
#     <tr>
#       <th id="T_8061f_level0_row16" class="row_heading level0 row16" >Loss on Ignition</th>
#       <td id="T_8061f_row16_col0" class="data row16 col0" >0.727131</td>
#     </tr>
#     <tr>
#       <th id="T_8061f_level0_row17" class="row_heading level0 row17" >Blaine</th>
#       <td id="T_8061f_row17_col0" class="data row17 col0" >0.294278</td>
#     </tr>
#     <tr>
#       <th id="T_8061f_level0_row18" class="row_heading level0 row18" >CS7</th>
#       <td id="T_8061f_row18_col0" class="data row18 col0" >0.133904</td>
#     </tr>
#     <tr>
#       <th id="T_8061f_level0_row19" class="row_heading level0 row19" >Cement_Type</th>
#       <td id="T_8061f_row19_col0" class="data row19 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8061f_level0_row20" class="row_heading level0 row20" >Date</th>
#       <td id="T_8061f_row20_col0" class="data row20 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8061f_level0_row21" class="row_heading level0 row21" >CS28</th>
#       <td id="T_8061f_row21_col0" class="data row21 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8061f_level0_row22" class="row_heading level0 row22" >Factory_Plant</th>
#       <td id="T_8061f_row22_col0" class="data row22 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %%
zero_values = {}
for col in df.select_dtypes(include="number").columns:
    zero_percentages = (df[df[col].eq(0)].shape[0] / df.shape[0]) * 100
    zero_values[col] = zero_percentages

zero_percentages = pd.Series(zero_values, name=f"Zero (%) for Global Dataset")
zero_percentages = zero_percentages.sort_values(ascending=False)
zero_percentages = zero_percentages.to_frame(name=f"Zero (%) for Global Dataset")
zero_percentages.style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_f65e1_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_f65e1_row1_col0, #T_f65e1_row2_col0, #T_f65e1_row3_col0, #T_f65e1_row4_col0, #T_f65e1_row5_col0, #T_f65e1_row6_col0, #T_f65e1_row7_col0, #T_f65e1_row8_col0, #T_f65e1_row9_col0, #T_f65e1_row10_col0, #T_f65e1_row11_col0, #T_f65e1_row12_col0, #T_f65e1_row13_col0, #T_f65e1_row14_col0, #T_f65e1_row15_col0, #T_f65e1_row16_col0, #T_f65e1_row17_col0, #T_f65e1_row18_col0, #T_f65e1_row19_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_f65e1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f65e1_level0_col0" class="col_heading level0 col0" >Zero (%) for Global Dataset</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f65e1_level0_row0" class="row_heading level0 row0" >#200</th>
#       <td id="T_f65e1_row0_col0" class="data row0 col0" >13.854418</td>
#     </tr>
#     <tr>
#       <th id="T_f65e1_level0_row1" class="row_heading level0 row1" >CaO</th>
#       <td id="T_f65e1_row1_col0" class="data row1 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f65e1_level0_row2" class="row_heading level0 row2" >MgO</th>
#       <td id="T_f65e1_row2_col0" class="data row2 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f65e1_level0_row3" class="row_heading level0 row3" >CS7</th>
#       <td id="T_f65e1_row3_col0" class="data row3 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f65e1_level0_row4" class="row_heading level0 row4" >CS3</th>
#       <td id="T_f65e1_row4_col0" class="data row4 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f65e1_level0_row5" class="row_heading level0 row5" >CS1</th>
#       <td id="T_f65e1_row5_col0" class="data row5 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f65e1_level0_row6" class="row_heading level0 row6" >Final setting time</th>
#       <td id="T_f65e1_row6_col0" class="data row6 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f65e1_level0_row7" class="row_heading level0 row7" >Initial setting time</th>
#       <td id="T_f65e1_row7_col0" class="data row7 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f65e1_level0_row8" class="row_heading level0 row8" >#325</th>
#       <td id="T_f65e1_row8_col0" class="data row8 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f65e1_level0_row9" class="row_heading level0 row9" >Blaine</th>
#       <td id="T_f65e1_row9_col0" class="data row9 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f65e1_level0_row10" class="row_heading level0 row10" >Insoluble Residue</th>
#       <td id="T_f65e1_row10_col0" class="data row10 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f65e1_level0_row11" class="row_heading level0 row11" >Loss on Ignition</th>
#       <td id="T_f65e1_row11_col0" class="data row11 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f65e1_level0_row12" class="row_heading level0 row12" >Fe2O3</th>
#       <td id="T_f65e1_row12_col0" class="data row12 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f65e1_level0_row13" class="row_heading level0 row13" >TiO2</th>
#       <td id="T_f65e1_row13_col0" class="data row13 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f65e1_level0_row14" class="row_heading level0 row14" >K2O</th>
#       <td id="T_f65e1_row14_col0" class="data row14 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f65e1_level0_row15" class="row_heading level0 row15" >SO3</th>
#       <td id="T_f65e1_row15_col0" class="data row15 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f65e1_level0_row16" class="row_heading level0 row16" >SiO2</th>
#       <td id="T_f65e1_row16_col0" class="data row16 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f65e1_level0_row17" class="row_heading level0 row17" >Al2O3</th>
#       <td id="T_f65e1_row17_col0" class="data row17 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f65e1_level0_row18" class="row_heading level0 row18" >Na2O</th>
#       <td id="T_f65e1_row18_col0" class="data row18 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f65e1_level0_row19" class="row_heading level0 row19" >CS28</th>
#       <td id="T_f65e1_row19_col0" class="data row19 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.shape
# Out:
# (64225, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 64225 entries, 0 to 66110
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  64225 non-null  object
#  1   CaO                   48302 non-null  float64
#  2   MgO                   62255 non-null  float64
#  3   Na2O                  56791 non-null  float64
#  4   Al2O3                 48197 non-null  float64
#  5   SiO2                  48213 non-null  float64
#  6   SO3                   63581 non-null  float64
#  7   K2O                   58287 non-null  float64
#  8   TiO2                  9089 non-null   float64
#  9   Fe2O3                 48194 non-null  float64
#  10  Loss on Ignition      63758 non-null  float64
#  11  Insoluble Residue     47342 non-null  float64
#  12  Blaine                64036 non-null  float64
#  13  #200                  61544 non-null  float64
#  14  #325                  56410 non-null  float64
#  15  Initial setting time  61449 non-null  float64
#  16  Final setting time    63465 non-null  float64
#  17  CS1                   31655 non-null  float64
#  18  CS3                   60183 non-null  float64
#  19  CS7                   64139 non-null  float64
#  20  CS28                  64225 non-null  float64
#  21  Cement_Type           64225 non-null  object
#  22  Factory_Plant         64225 non-null  object
# dtypes: float64(20), object(3)
# memory usage: 11.8+ MB

# %% [markdown]
# ### Dropping columns with significant amount of missing values

# %%
cols_missing_vals_to_drop = [
    "TiO2",
    "CS1",
]
df = df.drop(cols_missing_vals_to_drop, axis=1).reset_index(drop=True)

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %% [markdown]
# ### Sort the dataset by date

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df = df.sort_values(by="Date")

# %% [markdown]
# ## Saving the dataset

# %% [markdown]
# <h3>Saving for feature engineering</h3>

# %%
df.to_csv("../../../../data/interim/203/global_c.csv", index=False)
