# %%
# %load_ext nb_black

# %%
import pandas as pd
import numpy as np
import missingno as msno

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading the datasets

# %% [markdown]
# ## Reading the global dataset

# %%
df = pd.read_csv("../../../../data/interim/Global-Dataset/global_dataset.csv")

# %% [markdown]
# ## Reading the local dataset for plant AV

# %%
df_av = pd.read_csv("../../../../data/processed/203/av.csv")

# %% [markdown]
# # Preprocessing of Global Dataset

# %% [markdown]
# ### Removing the plant to be fine-tuned

# %%
df.shape
# Out:
# (66111, 48)

# %%
df = df[df["Factory_Plant"] != "203_AV"].reset_index(drop=True)

# %%
df.shape
# Out:
# (64601, 48)

# %% [markdown]
# ### Removing non-matching columns between the datasets

# %%
df = df[df_av.columns.to_list() + ["Factory_Plant"]]

# %%
df.shape
# Out:
# (64601, 22)

# %% [markdown]
# ## Removing missing features

# %%
(df.isna().sum() / df.shape[0] * 100).sort_values(ascending=False).to_frame(
    name="Missing (%)"
).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_b8114_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_b8114_row1_col0 {
#   background-color: #f85d42;
#   color: #f1f1f1;
# }
# #T_b8114_row2_col0, #T_b8114_row3_col0, #T_b8114_row4_col0 {
#   background-color: #fb7050;
#   color: #f1f1f1;
# }
# #T_b8114_row5_col0 {
#   background-color: #fb7151;
#   color: #f1f1f1;
# }
# #T_b8114_row6_col0 {
#   background-color: #fcbfa7;
#   color: #000000;
# }
# #T_b8114_row7_col0 {
#   background-color: #fcc3ab;
#   color: #000000;
# }
# #T_b8114_row8_col0 {
#   background-color: #fdd0bc;
#   color: #000000;
# }
# #T_b8114_row9_col0 {
#   background-color: #fee1d3;
#   color: #000000;
# }
# #T_b8114_row10_col0, #T_b8114_row11_col0 {
#   background-color: #fee7dc;
#   color: #000000;
# }
# #T_b8114_row12_col0 {
#   background-color: #ffebe2;
#   color: #000000;
# }
# #T_b8114_row13_col0 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_b8114_row14_col0 {
#   background-color: #fff2ec;
#   color: #000000;
# }
# #T_b8114_row15_col0 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_b8114_row16_col0 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_b8114_row17_col0, #T_b8114_row18_col0, #T_b8114_row19_col0, #T_b8114_row20_col0, #T_b8114_row21_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_b8114">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b8114_level0_col0" class="col_heading level0 col0" >Missing (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b8114_level0_row0" class="row_heading level0 row0" >CS1</th>
#       <td id="T_b8114_row0_col0" class="data row0 col0" >51.462052</td>
#     </tr>
#     <tr>
#       <th id="T_b8114_level0_row1" class="row_heading level0 row1" >Insoluble Residue</th>
#       <td id="T_b8114_row1_col0" class="data row1 col0" >27.504218</td>
#     </tr>
#     <tr>
#       <th id="T_b8114_level0_row2" class="row_heading level0 row2" >Fe2O3</th>
#       <td id="T_b8114_row2_col0" class="data row2 col0" >24.888160</td>
#     </tr>
#     <tr>
#       <th id="T_b8114_level0_row3" class="row_heading level0 row3" >Al2O3</th>
#       <td id="T_b8114_row3_col0" class="data row3 col0" >24.881968</td>
#     </tr>
#     <tr>
#       <th id="T_b8114_level0_row4" class="row_heading level0 row4" >SiO2</th>
#       <td id="T_b8114_row4_col0" class="data row4 col0" >24.857200</td>
#     </tr>
#     <tr>
#       <th id="T_b8114_level0_row5" class="row_heading level0 row5" >CaO</th>
#       <td id="T_b8114_row5_col0" class="data row5 col0" >24.719432</td>
#     </tr>
#     <tr>
#       <th id="T_b8114_level0_row6" class="row_heading level0 row6" >#325</th>
#       <td id="T_b8114_row6_col0" class="data row6 col0" >12.222721</td>
#     </tr>
#     <tr>
#       <th id="T_b8114_level0_row7" class="row_heading level0 row7" >Na2O</th>
#       <td id="T_b8114_row7_col0" class="data row7 col0" >11.626755</td>
#     </tr>
#     <tr>
#       <th id="T_b8114_level0_row8" class="row_heading level0 row8" >K2O</th>
#       <td id="T_b8114_row8_col0" class="data row8 col0" >9.255275</td>
#     </tr>
#     <tr>
#       <th id="T_b8114_level0_row9" class="row_heading level0 row9" >CS3</th>
#       <td id="T_b8114_row9_col0" class="data row9 col0" >6.266157</td>
#     </tr>
#     <tr>
#       <th id="T_b8114_level0_row10" class="row_heading level0 row10" >Initial setting time</th>
#       <td id="T_b8114_row10_col0" class="data row10 col0" >4.331202</td>
#     </tr>
#     <tr>
#       <th id="T_b8114_level0_row11" class="row_heading level0 row11" >#200</th>
#       <td id="T_b8114_row11_col0" class="data row11 col0" >4.238324</td>
#     </tr>
#     <tr>
#       <th id="T_b8114_level0_row12" class="row_heading level0 row12" >MgO</th>
#       <td id="T_b8114_row12_col0" class="data row12 col0" >3.111407</td>
#     </tr>
#     <tr>
#       <th id="T_b8114_level0_row13" class="row_heading level0 row13" >Final setting time</th>
#       <td id="T_b8114_row13_col0" class="data row13 col0" >1.219795</td>
#     </tr>
#     <tr>
#       <th id="T_b8114_level0_row14" class="row_heading level0 row14" >SO3</th>
#       <td id="T_b8114_row14_col0" class="data row14 col0" >1.004628</td>
#     </tr>
#     <tr>
#       <th id="T_b8114_level0_row15" class="row_heading level0 row15" >Loss on Ignition</th>
#       <td id="T_b8114_row15_col0" class="data row15 col0" >0.778626</td>
#     </tr>
#     <tr>
#       <th id="T_b8114_level0_row16" class="row_heading level0 row16" >Blaine</th>
#       <td id="T_b8114_row16_col0" class="data row16 col0" >0.309593</td>
#     </tr>
#     <tr>
#       <th id="T_b8114_level0_row17" class="row_heading level0 row17" >CS7</th>
#       <td id="T_b8114_row17_col0" class="data row17 col0" >0.139317</td>
#     </tr>
#     <tr>
#       <th id="T_b8114_level0_row18" class="row_heading level0 row18" >Cement_Type</th>
#       <td id="T_b8114_row18_col0" class="data row18 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b8114_level0_row19" class="row_heading level0 row19" >Date</th>
#       <td id="T_b8114_row19_col0" class="data row19 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b8114_level0_row20" class="row_heading level0 row20" >CS28</th>
#       <td id="T_b8114_row20_col0" class="data row20 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b8114_level0_row21" class="row_heading level0 row21" >Factory_Plant</th>
#       <td id="T_b8114_row21_col0" class="data row21 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %%
msno.matrix(df.loc[(df["CS1"].notna() == True)])
# Out:
# <Axes: >

# %%
missing_counts = df.isnull().sum()
plt.figure(figsize=(12, 6))
plt.bar(missing_counts.index, missing_counts.values)
plt.xticks(rotation=60)
plt.xlabel("Columns")
plt.ylabel("Number of Missing Values")
plt.title("Missing Values per Column")
plt.show()

# %% [markdown]
# ### Removing features with many zeros when applicable

# %%
zero_values = {}
for col in df.select_dtypes(include="number").columns:
    zero_percentages = (df[df[col].eq(0)].shape[0] / df.shape[0]) * 100
    zero_values[col] = zero_percentages

zero_percentages = pd.Series(zero_values, name=f"Zero (%) for Global Dataset")
zero_percentages = zero_percentages.sort_values(ascending=False)
zero_percentages = zero_percentages.to_frame(name=f"Zero (%) for Global Dataset")
zero_percentages.style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_47e41_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_47e41_row1_col0 {
#   background-color: #fee2d5;
#   color: #000000;
# }
# #T_47e41_row2_col0 {
#   background-color: #ffeee6;
#   color: #000000;
# }
# #T_47e41_row3_col0 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_47e41_row4_col0, #T_47e41_row5_col0, #T_47e41_row6_col0, #T_47e41_row7_col0, #T_47e41_row8_col0 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_47e41_row9_col0, #T_47e41_row10_col0, #T_47e41_row11_col0, #T_47e41_row12_col0, #T_47e41_row13_col0, #T_47e41_row14_col0, #T_47e41_row15_col0, #T_47e41_row16_col0, #T_47e41_row17_col0, #T_47e41_row18_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_47e41">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_47e41_level0_col0" class="col_heading level0 col0" >Zero (%) for Global Dataset</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_47e41_level0_row0" class="row_heading level0 row0" >#200</th>
#       <td id="T_47e41_row0_col0" class="data row0 col0" >14.250553</td>
#     </tr>
#     <tr>
#       <th id="T_47e41_level0_row1" class="row_heading level0 row1" >Na2O</th>
#       <td id="T_47e41_row1_col0" class="data row1 col0" >1.628458</td>
#     </tr>
#     <tr>
#       <th id="T_47e41_level0_row2" class="row_heading level0 row2" >Insoluble Residue</th>
#       <td id="T_47e41_row2_col0" class="data row2 col0" >0.648597</td>
#     </tr>
#     <tr>
#       <th id="T_47e41_level0_row3" class="row_heading level0 row3" >#325</th>
#       <td id="T_47e41_row3_col0" class="data row3 col0" >0.351388</td>
#     </tr>
#     <tr>
#       <th id="T_47e41_level0_row4" class="row_heading level0 row4" >Loss on Ignition</th>
#       <td id="T_47e41_row4_col0" class="data row4 col0" >0.102166</td>
#     </tr>
#     <tr>
#       <th id="T_47e41_level0_row5" class="row_heading level0 row5" >Blaine</th>
#       <td id="T_47e41_row5_col0" class="data row5 col0" >0.094426</td>
#     </tr>
#     <tr>
#       <th id="T_47e41_level0_row6" class="row_heading level0 row6" >Initial setting time</th>
#       <td id="T_47e41_row6_col0" class="data row6 col0" >0.085138</td>
#     </tr>
#     <tr>
#       <th id="T_47e41_level0_row7" class="row_heading level0 row7" >Final setting time</th>
#       <td id="T_47e41_row7_col0" class="data row7 col0" >0.083590</td>
#     </tr>
#     <tr>
#       <th id="T_47e41_level0_row8" class="row_heading level0 row8" >SO3</th>
#       <td id="T_47e41_row8_col0" class="data row8 col0" >0.063467</td>
#     </tr>
#     <tr>
#       <th id="T_47e41_level0_row9" class="row_heading level0 row9" >MgO</th>
#       <td id="T_47e41_row9_col0" class="data row9 col0" >0.021671</td>
#     </tr>
#     <tr>
#       <th id="T_47e41_level0_row10" class="row_heading level0 row10" >K2O</th>
#       <td id="T_47e41_row10_col0" class="data row10 col0" >0.012384</td>
#     </tr>
#     <tr>
#       <th id="T_47e41_level0_row11" class="row_heading level0 row11" >Fe2O3</th>
#       <td id="T_47e41_row11_col0" class="data row11 col0" >0.007740</td>
#     </tr>
#     <tr>
#       <th id="T_47e41_level0_row12" class="row_heading level0 row12" >CS7</th>
#       <td id="T_47e41_row12_col0" class="data row12 col0" >0.004644</td>
#     </tr>
#     <tr>
#       <th id="T_47e41_level0_row13" class="row_heading level0 row13" >SiO2</th>
#       <td id="T_47e41_row13_col0" class="data row13 col0" >0.004644</td>
#     </tr>
#     <tr>
#       <th id="T_47e41_level0_row14" class="row_heading level0 row14" >CaO</th>
#       <td id="T_47e41_row14_col0" class="data row14 col0" >0.001548</td>
#     </tr>
#     <tr>
#       <th id="T_47e41_level0_row15" class="row_heading level0 row15" >Al2O3</th>
#       <td id="T_47e41_row15_col0" class="data row15 col0" >0.001548</td>
#     </tr>
#     <tr>
#       <th id="T_47e41_level0_row16" class="row_heading level0 row16" >CS1</th>
#       <td id="T_47e41_row16_col0" class="data row16 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_47e41_level0_row17" class="row_heading level0 row17" >CS3</th>
#       <td id="T_47e41_row17_col0" class="data row17 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_47e41_level0_row18" class="row_heading level0 row18" >CS28</th>
#       <td id="T_47e41_row18_col0" class="data row18 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Drop rows where the target variable is null

# %%
df = df[df["CS28"].notna()]

# %% [markdown]
# ### Dropping rows where the target variable is zero

# %%
df = df[~df["CS28"].eq(0)]

# %% [markdown]
# ### Dropping rows where any other variable has a zero value - except #200

# %%
for col in df.columns:
    if col != "#200":
        df = df[~df[col].eq(0)]

# %%
(df.isna().sum() / df.shape[0] * 100).sort_values(ascending=False).to_frame(
    name="Missing (%)"
).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_f44f1_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_f44f1_row1_col0 {
#   background-color: #f96346;
#   color: #f1f1f1;
# }
# #T_f44f1_row2_col0, #T_f44f1_row3_col0, #T_f44f1_row4_col0, #T_f44f1_row5_col0 {
#   background-color: #fb6d4d;
#   color: #f1f1f1;
# }
# #T_f44f1_row6_col0 {
#   background-color: #fcbea5;
#   color: #000000;
# }
# #T_f44f1_row7_col0 {
#   background-color: #fcc2aa;
#   color: #000000;
# }
# #T_f44f1_row8_col0 {
#   background-color: #fdd0bc;
#   color: #000000;
# }
# #T_f44f1_row9_col0 {
#   background-color: #fee1d3;
#   color: #000000;
# }
# #T_f44f1_row10_col0, #T_f44f1_row11_col0 {
#   background-color: #fee7dc;
#   color: #000000;
# }
# #T_f44f1_row12_col0 {
#   background-color: #ffebe2;
#   color: #000000;
# }
# #T_f44f1_row13_col0, #T_f44f1_row14_col0 {
#   background-color: #fff2eb;
#   color: #000000;
# }
# #T_f44f1_row15_col0 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_f44f1_row16_col0 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_f44f1_row17_col0, #T_f44f1_row18_col0, #T_f44f1_row19_col0, #T_f44f1_row20_col0, #T_f44f1_row21_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_f44f1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f44f1_level0_col0" class="col_heading level0 col0" >Missing (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f44f1_level0_row0" class="row_heading level0 row0" >CS1</th>
#       <td id="T_f44f1_row0_col0" class="data row0 col0" >51.956910</td>
#     </tr>
#     <tr>
#       <th id="T_f44f1_level0_row1" class="row_heading level0 row1" >Insoluble Residue</th>
#       <td id="T_f44f1_row1_col0" class="data row1 col0" >26.915477</td>
#     </tr>
#     <tr>
#       <th id="T_f44f1_level0_row2" class="row_heading level0 row2" >Fe2O3</th>
#       <td id="T_f44f1_row2_col0" class="data row2 col0" >25.546596</td>
#     </tr>
#     <tr>
#       <th id="T_f44f1_level0_row3" class="row_heading level0 row3" >Al2O3</th>
#       <td id="T_f44f1_row3_col0" class="data row3 col0" >25.541815</td>
#     </tr>
#     <tr>
#       <th id="T_f44f1_level0_row4" class="row_heading level0 row4" >SiO2</th>
#       <td id="T_f44f1_row4_col0" class="data row4 col0" >25.516318</td>
#     </tr>
#     <tr>
#       <th id="T_f44f1_level0_row5" class="row_heading level0 row5" >CaO</th>
#       <td id="T_f44f1_row5_col0" class="data row5 col0" >25.374490</td>
#     </tr>
#     <tr>
#       <th id="T_f44f1_level0_row6" class="row_heading level0 row6" >#325</th>
#       <td id="T_f44f1_row6_col0" class="data row6 col0" >12.453786</td>
#     </tr>
#     <tr>
#       <th id="T_f44f1_level0_row7" class="row_heading level0 row7" >Na2O</th>
#       <td id="T_f44f1_row7_col0" class="data row7 col0" >11.846634</td>
#     </tr>
#     <tr>
#       <th id="T_f44f1_level0_row8" class="row_heading level0 row8" >K2O</th>
#       <td id="T_f44f1_row8_col0" class="data row8 col0" >9.462647</td>
#     </tr>
#     <tr>
#       <th id="T_f44f1_level0_row9" class="row_heading level0 row9" >CS3</th>
#       <td id="T_f44f1_row9_col0" class="data row9 col0" >6.441229</td>
#     </tr>
#     <tr>
#       <th id="T_f44f1_level0_row10" class="row_heading level0 row10" >Initial setting time</th>
#       <td id="T_f44f1_row10_col0" class="data row10 col0" >4.423763</td>
#     </tr>
#     <tr>
#       <th id="T_f44f1_level0_row11" class="row_heading level0 row11" >#200</th>
#       <td id="T_f44f1_row11_col0" class="data row11 col0" >4.272374</td>
#     </tr>
#     <tr>
#       <th id="T_f44f1_level0_row12" class="row_heading level0 row12" >MgO</th>
#       <td id="T_f44f1_row12_col0" class="data row12 col0" >3.139342</td>
#     </tr>
#     <tr>
#       <th id="T_f44f1_level0_row13" class="row_heading level0 row13" >Final setting time</th>
#       <td id="T_f44f1_row13_col0" class="data row13 col0" >1.211117</td>
#     </tr>
#     <tr>
#       <th id="T_f44f1_level0_row14" class="row_heading level0 row14" >SO3</th>
#       <td id="T_f44f1_row14_col0" class="data row14 col0" >1.026262</td>
#     </tr>
#     <tr>
#       <th id="T_f44f1_level0_row15" class="row_heading level0 row15" >Loss on Ignition</th>
#       <td id="T_f44f1_row15_col0" class="data row15 col0" >0.752167</td>
#     </tr>
#     <tr>
#       <th id="T_f44f1_level0_row16" class="row_heading level0 row16" >Blaine</th>
#       <td id="T_f44f1_row16_col0" class="data row16 col0" >0.301186</td>
#     </tr>
#     <tr>
#       <th id="T_f44f1_level0_row17" class="row_heading level0 row17" >CS7</th>
#       <td id="T_f44f1_row17_col0" class="data row17 col0" >0.137047</td>
#     </tr>
#     <tr>
#       <th id="T_f44f1_level0_row18" class="row_heading level0 row18" >Cement_Type</th>
#       <td id="T_f44f1_row18_col0" class="data row18 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f44f1_level0_row19" class="row_heading level0 row19" >Date</th>
#       <td id="T_f44f1_row19_col0" class="data row19 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f44f1_level0_row20" class="row_heading level0 row20" >CS28</th>
#       <td id="T_f44f1_row20_col0" class="data row20 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f44f1_level0_row21" class="row_heading level0 row21" >Factory_Plant</th>
#       <td id="T_f44f1_row21_col0" class="data row21 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %%
zero_values = {}
for col in df.select_dtypes(include="number").columns:
    zero_percentages = (df[df[col].eq(0)].shape[0] / df.shape[0]) * 100
    zero_values[col] = zero_percentages

zero_percentages = pd.Series(zero_values, name=f"Zero (%) for Global Dataset")
zero_percentages = zero_percentages.sort_values(ascending=False)
zero_percentages = zero_percentages.to_frame(name=f"Zero (%) for Global Dataset")
zero_percentages.style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_d5a39_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_d5a39_row1_col0, #T_d5a39_row2_col0, #T_d5a39_row3_col0, #T_d5a39_row4_col0, #T_d5a39_row5_col0, #T_d5a39_row6_col0, #T_d5a39_row7_col0, #T_d5a39_row8_col0, #T_d5a39_row9_col0, #T_d5a39_row10_col0, #T_d5a39_row11_col0, #T_d5a39_row12_col0, #T_d5a39_row13_col0, #T_d5a39_row14_col0, #T_d5a39_row15_col0, #T_d5a39_row16_col0, #T_d5a39_row17_col0, #T_d5a39_row18_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_d5a39">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d5a39_level0_col0" class="col_heading level0 col0" >Zero (%) for Global Dataset</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d5a39_level0_row0" class="row_heading level0 row0" >#200</th>
#       <td id="T_d5a39_row0_col0" class="data row0 col0" >14.181221</td>
#     </tr>
#     <tr>
#       <th id="T_d5a39_level0_row1" class="row_heading level0 row1" >CaO</th>
#       <td id="T_d5a39_row1_col0" class="data row1 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d5a39_level0_row2" class="row_heading level0 row2" >Blaine</th>
#       <td id="T_d5a39_row2_col0" class="data row2 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d5a39_level0_row3" class="row_heading level0 row3" >CS7</th>
#       <td id="T_d5a39_row3_col0" class="data row3 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d5a39_level0_row4" class="row_heading level0 row4" >CS3</th>
#       <td id="T_d5a39_row4_col0" class="data row4 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d5a39_level0_row5" class="row_heading level0 row5" >CS1</th>
#       <td id="T_d5a39_row5_col0" class="data row5 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d5a39_level0_row6" class="row_heading level0 row6" >Final setting time</th>
#       <td id="T_d5a39_row6_col0" class="data row6 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d5a39_level0_row7" class="row_heading level0 row7" >Initial setting time</th>
#       <td id="T_d5a39_row7_col0" class="data row7 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d5a39_level0_row8" class="row_heading level0 row8" >#325</th>
#       <td id="T_d5a39_row8_col0" class="data row8 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d5a39_level0_row9" class="row_heading level0 row9" >Insoluble Residue</th>
#       <td id="T_d5a39_row9_col0" class="data row9 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d5a39_level0_row10" class="row_heading level0 row10" >MgO</th>
#       <td id="T_d5a39_row10_col0" class="data row10 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d5a39_level0_row11" class="row_heading level0 row11" >Loss on Ignition</th>
#       <td id="T_d5a39_row11_col0" class="data row11 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d5a39_level0_row12" class="row_heading level0 row12" >Fe2O3</th>
#       <td id="T_d5a39_row12_col0" class="data row12 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d5a39_level0_row13" class="row_heading level0 row13" >K2O</th>
#       <td id="T_d5a39_row13_col0" class="data row13 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d5a39_level0_row14" class="row_heading level0 row14" >SO3</th>
#       <td id="T_d5a39_row14_col0" class="data row14 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d5a39_level0_row15" class="row_heading level0 row15" >SiO2</th>
#       <td id="T_d5a39_row15_col0" class="data row15 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d5a39_level0_row16" class="row_heading level0 row16" >Al2O3</th>
#       <td id="T_d5a39_row16_col0" class="data row16 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d5a39_level0_row17" class="row_heading level0 row17" >Na2O</th>
#       <td id="T_d5a39_row17_col0" class="data row17 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d5a39_level0_row18" class="row_heading level0 row18" >CS28</th>
#       <td id="T_d5a39_row18_col0" class="data row18 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.shape
# Out:
# (62752, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 62752 entries, 0 to 64600
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  62752 non-null  object
#  1   CaO                   46829 non-null  float64
#  2   MgO                   60782 non-null  float64
#  3   Na2O                  55318 non-null  float64
#  4   Al2O3                 46724 non-null  float64
#  5   SiO2                  46740 non-null  float64
#  6   SO3                   62108 non-null  float64
#  7   K2O                   56814 non-null  float64
#  8   Fe2O3                 46721 non-null  float64
#  9   Loss on Ignition      62280 non-null  float64
#  10  Insoluble Residue     45862 non-null  float64
#  11  Blaine                62563 non-null  float64
#  12  #200                  60071 non-null  float64
#  13  #325                  54937 non-null  float64
#  14  Initial setting time  59976 non-null  float64
#  15  Final setting time    61992 non-null  float64
#  16  CS1                   30148 non-null  float64
#  17  CS3                   58710 non-null  float64
#  18  CS7                   62666 non-null  float64
#  19  CS28                  62752 non-null  float64
#  20  Cement_Type           62752 non-null  object
#  21  Factory_Plant         62752 non-null  object
# dtypes: float64(19), object(3)
# memory usage: 11.0+ MB

# %% [markdown]
# ### Sort the dataset by date

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df = df.sort_values(by="Date")

# %% [markdown]
# ## Saving the dataset

# %% [markdown]
# <h3>Saving for feature engineering</h3>

# %%
df.to_csv("../../../../data/interim/203/global_av.csv", index=False)
