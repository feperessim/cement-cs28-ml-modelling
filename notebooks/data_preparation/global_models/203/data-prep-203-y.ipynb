# %%
# %load_ext nb_black

# %%
import pandas as pd
import numpy as np
import missingno as msno

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading the datasets

# %% [markdown]
# ## Reading the global dataset

# %%
df = pd.read_csv("../../../../data/interim/Global-Dataset/global_dataset.csv")

# %% [markdown]
# ## Reading the local dataset for plant Y

# %%
df_y = pd.read_csv("../../../../data/processed/203/y.csv")

# %% [markdown]
# # Preprocessing of Global Dataset

# %% [markdown]
# ### Removing the plant to be fine-tuned

# %%
df.shape
# Out:
# (66111, 48)

# %%
df = df[df["Factory_Plant"] != "203_Y"].reset_index(drop=True)

# %%
df.shape
# Out:
# (65014, 48)

# %% [markdown]
# ### Removing non-matching columns between the datasets

# %%
df = df[df_y.columns.to_list() + ["Factory_Plant"]]

# %%
df.shape
# Out:
# (65014, 22)

# %% [markdown]
# ## Removing missing features

# %%
(df.isna().sum() / df.shape[0] * 100).sort_values(ascending=False).to_frame(
    name="Missing (%)"
).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_8306e_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_8306e_row1_col0 {
#   background-color: #f85d42;
#   color: #f1f1f1;
# }
# #T_8306e_row2_col0, #T_8306e_row3_col0, #T_8306e_row4_col0 {
#   background-color: #fb7050;
#   color: #f1f1f1;
# }
# #T_8306e_row5_col0 {
#   background-color: #fb7151;
#   color: #f1f1f1;
# }
# #T_8306e_row6_col0 {
#   background-color: #fcbfa7;
#   color: #000000;
# }
# #T_8306e_row7_col0 {
#   background-color: #fcc3ab;
#   color: #000000;
# }
# #T_8306e_row8_col0 {
#   background-color: #fdd1be;
#   color: #000000;
# }
# #T_8306e_row9_col0 {
#   background-color: #fee1d3;
#   color: #000000;
# }
# #T_8306e_row10_col0, #T_8306e_row11_col0 {
#   background-color: #fee7dc;
#   color: #000000;
# }
# #T_8306e_row12_col0 {
#   background-color: #ffebe2;
#   color: #000000;
# }
# #T_8306e_row13_col0 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_8306e_row14_col0 {
#   background-color: #fff2ec;
#   color: #000000;
# }
# #T_8306e_row15_col0 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_8306e_row16_col0 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_8306e_row17_col0, #T_8306e_row18_col0, #T_8306e_row19_col0, #T_8306e_row20_col0, #T_8306e_row21_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_8306e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8306e_level0_col0" class="col_heading level0 col0" >Missing (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8306e_level0_row0" class="row_heading level0 row0" >CS1</th>
#       <td id="T_8306e_row0_col0" class="data row0 col0" >51.135140</td>
#     </tr>
#     <tr>
#       <th id="T_8306e_level0_row1" class="row_heading level0 row1" >Insoluble Residue</th>
#       <td id="T_8306e_row1_col0" class="data row1 col0" >27.327960</td>
#     </tr>
#     <tr>
#       <th id="T_8306e_level0_row2" class="row_heading level0 row2" >Al2O3</th>
#       <td id="T_8306e_row2_col0" class="data row2 col0" >24.694681</td>
#     </tr>
#     <tr>
#       <th id="T_8306e_level0_row3" class="row_heading level0 row3" >Fe2O3</th>
#       <td id="T_8306e_row3_col0" class="data row3 col0" >24.674685</td>
#     </tr>
#     <tr>
#       <th id="T_8306e_level0_row4" class="row_heading level0 row4" >SiO2</th>
#       <td id="T_8306e_row4_col0" class="data row4 col0" >24.670071</td>
#     </tr>
#     <tr>
#       <th id="T_8306e_level0_row5" class="row_heading level0 row5" >CaO</th>
#       <td id="T_8306e_row5_col0" class="data row5 col0" >24.533177</td>
#     </tr>
#     <tr>
#       <th id="T_8306e_level0_row6" class="row_heading level0 row6" >#325</th>
#       <td id="T_8306e_row6_col0" class="data row6 col0" >12.000492</td>
#     </tr>
#     <tr>
#       <th id="T_8306e_level0_row7" class="row_heading level0 row7" >Na2O</th>
#       <td id="T_8306e_row7_col0" class="data row7 col0" >11.523672</td>
#     </tr>
#     <tr>
#       <th id="T_8306e_level0_row8" class="row_heading level0 row8" >K2O</th>
#       <td id="T_8306e_row8_col0" class="data row8 col0" >9.167256</td>
#     </tr>
#     <tr>
#       <th id="T_8306e_level0_row9" class="row_heading level0 row9" >CS3</th>
#       <td id="T_8306e_row9_col0" class="data row9 col0" >6.224813</td>
#     </tr>
#     <tr>
#       <th id="T_8306e_level0_row10" class="row_heading level0 row10" >Initial setting time</th>
#       <td id="T_8306e_row10_col0" class="data row10 col0" >4.303688</td>
#     </tr>
#     <tr>
#       <th id="T_8306e_level0_row11" class="row_heading level0 row11" >#200</th>
#       <td id="T_8306e_row11_col0" class="data row11 col0" >4.211401</td>
#     </tr>
#     <tr>
#       <th id="T_8306e_level0_row12" class="row_heading level0 row12" >MgO</th>
#       <td id="T_8306e_row12_col0" class="data row12 col0" >3.062417</td>
#     </tr>
#     <tr>
#       <th id="T_8306e_level0_row13" class="row_heading level0 row13" >Final setting time</th>
#       <td id="T_8306e_row13_col0" class="data row13 col0" >1.212047</td>
#     </tr>
#     <tr>
#       <th id="T_8306e_level0_row14" class="row_heading level0 row14" >SO3</th>
#       <td id="T_8306e_row14_col0" class="data row14 col0" >0.969022</td>
#     </tr>
#     <tr>
#       <th id="T_8306e_level0_row15" class="row_heading level0 row15" >Loss on Ignition</th>
#       <td id="T_8306e_row15_col0" class="data row15 col0" >0.764451</td>
#     </tr>
#     <tr>
#       <th id="T_8306e_level0_row16" class="row_heading level0 row16" >Blaine</th>
#       <td id="T_8306e_row16_col0" class="data row16 col0" >0.307626</td>
#     </tr>
#     <tr>
#       <th id="T_8306e_level0_row17" class="row_heading level0 row17" >CS7</th>
#       <td id="T_8306e_row17_col0" class="data row17 col0" >0.138432</td>
#     </tr>
#     <tr>
#       <th id="T_8306e_level0_row18" class="row_heading level0 row18" >Cement_Type</th>
#       <td id="T_8306e_row18_col0" class="data row18 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8306e_level0_row19" class="row_heading level0 row19" >Date</th>
#       <td id="T_8306e_row19_col0" class="data row19 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8306e_level0_row20" class="row_heading level0 row20" >CS28</th>
#       <td id="T_8306e_row20_col0" class="data row20 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8306e_level0_row21" class="row_heading level0 row21" >Factory_Plant</th>
#       <td id="T_8306e_row21_col0" class="data row21 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %%
msno.matrix(df.loc[(df["CS1"].notna() == True)])
# Out:
# <Axes: >

# %%
missing_counts = df.isnull().sum()
plt.figure(figsize=(12, 6))
plt.bar(missing_counts.index, missing_counts.values)
plt.xticks(rotation=60)
plt.xlabel("Columns")
plt.ylabel("Number of Missing Values")
plt.title("Missing Values per Column")
plt.show()

# %% [markdown]
# ### Removing features with many zeros when applicable

# %%
zero_values = {}
for col in df.select_dtypes(include="number").columns:
    zero_percentages = (df[df[col].eq(0)].shape[0] / df.shape[0]) * 100
    zero_values[col] = zero_percentages

zero_percentages = pd.Series(zero_values, name=f"Zero (%) for Global Dataset")
zero_percentages = zero_percentages.sort_values(ascending=False)
zero_percentages = zero_percentages.to_frame(name=f"Zero (%) for Global Dataset")
zero_percentages.style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_1c822_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_1c822_row1_col0 {
#   background-color: #fee2d5;
#   color: #000000;
# }
# #T_1c822_row2_col0 {
#   background-color: #ffeee6;
#   color: #000000;
# }
# #T_1c822_row3_col0 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_1c822_row4_col0, #T_1c822_row5_col0, #T_1c822_row6_col0, #T_1c822_row7_col0, #T_1c822_row8_col0 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_1c822_row9_col0, #T_1c822_row10_col0, #T_1c822_row11_col0, #T_1c822_row12_col0, #T_1c822_row13_col0, #T_1c822_row14_col0, #T_1c822_row15_col0, #T_1c822_row16_col0, #T_1c822_row17_col0, #T_1c822_row18_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_1c822">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1c822_level0_col0" class="col_heading level0 col0" >Zero (%) for Global Dataset</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1c822_level0_row0" class="row_heading level0 row0" >#200</th>
#       <td id="T_1c822_row0_col0" class="data row0 col0" >13.806257</td>
#     </tr>
#     <tr>
#       <th id="T_1c822_level0_row1" class="row_heading level0 row1" >Na2O</th>
#       <td id="T_1c822_row1_col0" class="data row1 col0" >1.616575</td>
#     </tr>
#     <tr>
#       <th id="T_1c822_level0_row2" class="row_heading level0 row2" >Insoluble Residue</th>
#       <td id="T_1c822_row2_col0" class="data row2 col0" >0.644477</td>
#     </tr>
#     <tr>
#       <th id="T_1c822_level0_row3" class="row_heading level0 row3" >#325</th>
#       <td id="T_1c822_row3_col0" class="data row3 col0" >0.341465</td>
#     </tr>
#     <tr>
#       <th id="T_1c822_level0_row4" class="row_heading level0 row4" >Loss on Ignition</th>
#       <td id="T_1c822_row4_col0" class="data row4 col0" >0.101517</td>
#     </tr>
#     <tr>
#       <th id="T_1c822_level0_row5" class="row_heading level0 row5" >Blaine</th>
#       <td id="T_1c822_row5_col0" class="data row5 col0" >0.093826</td>
#     </tr>
#     <tr>
#       <th id="T_1c822_level0_row6" class="row_heading level0 row6" >Initial setting time</th>
#       <td id="T_1c822_row6_col0" class="data row6 col0" >0.084597</td>
#     </tr>
#     <tr>
#       <th id="T_1c822_level0_row7" class="row_heading level0 row7" >Final setting time</th>
#       <td id="T_1c822_row7_col0" class="data row7 col0" >0.083059</td>
#     </tr>
#     <tr>
#       <th id="T_1c822_level0_row8" class="row_heading level0 row8" >SO3</th>
#       <td id="T_1c822_row8_col0" class="data row8 col0" >0.063063</td>
#     </tr>
#     <tr>
#       <th id="T_1c822_level0_row9" class="row_heading level0 row9" >MgO</th>
#       <td id="T_1c822_row9_col0" class="data row9 col0" >0.021534</td>
#     </tr>
#     <tr>
#       <th id="T_1c822_level0_row10" class="row_heading level0 row10" >K2O</th>
#       <td id="T_1c822_row10_col0" class="data row10 col0" >0.012305</td>
#     </tr>
#     <tr>
#       <th id="T_1c822_level0_row11" class="row_heading level0 row11" >Fe2O3</th>
#       <td id="T_1c822_row11_col0" class="data row11 col0" >0.007691</td>
#     </tr>
#     <tr>
#       <th id="T_1c822_level0_row12" class="row_heading level0 row12" >CS7</th>
#       <td id="T_1c822_row12_col0" class="data row12 col0" >0.004614</td>
#     </tr>
#     <tr>
#       <th id="T_1c822_level0_row13" class="row_heading level0 row13" >SiO2</th>
#       <td id="T_1c822_row13_col0" class="data row13 col0" >0.004614</td>
#     </tr>
#     <tr>
#       <th id="T_1c822_level0_row14" class="row_heading level0 row14" >CaO</th>
#       <td id="T_1c822_row14_col0" class="data row14 col0" >0.001538</td>
#     </tr>
#     <tr>
#       <th id="T_1c822_level0_row15" class="row_heading level0 row15" >Al2O3</th>
#       <td id="T_1c822_row15_col0" class="data row15 col0" >0.001538</td>
#     </tr>
#     <tr>
#       <th id="T_1c822_level0_row16" class="row_heading level0 row16" >CS1</th>
#       <td id="T_1c822_row16_col0" class="data row16 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1c822_level0_row17" class="row_heading level0 row17" >CS3</th>
#       <td id="T_1c822_row17_col0" class="data row17 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1c822_level0_row18" class="row_heading level0 row18" >CS28</th>
#       <td id="T_1c822_row18_col0" class="data row18 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Drop rows where the target variable is null

# %%
df = df[df["CS28"].notna()]

# %% [markdown]
# ### Dropping rows where the target variable is zero

# %%
df = df[~df["CS28"].eq(0)]

# %% [markdown]
# ### Dropping rows where any other variable has a zero value - except #200

# %%
for col in df.columns:
    if col != "#200":
        df = df[~df[col].eq(0)]

# %%
(df.isna().sum() / df.shape[0] * 100).sort_values(ascending=False).to_frame(
    name="Missing (%)"
).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_0e8a9_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_0e8a9_row1_col0 {
#   background-color: #f96346;
#   color: #f1f1f1;
# }
# #T_0e8a9_row2_col0, #T_0e8a9_row3_col0, #T_0e8a9_row4_col0 {
#   background-color: #fb6d4d;
#   color: #f1f1f1;
# }
# #T_0e8a9_row5_col0 {
#   background-color: #fb6e4e;
#   color: #f1f1f1;
# }
# #T_0e8a9_row6_col0 {
#   background-color: #fcbfa7;
#   color: #000000;
# }
# #T_0e8a9_row7_col0 {
#   background-color: #fcc2aa;
#   color: #000000;
# }
# #T_0e8a9_row8_col0 {
#   background-color: #fdd0bc;
#   color: #000000;
# }
# #T_0e8a9_row9_col0 {
#   background-color: #fee1d3;
#   color: #000000;
# }
# #T_0e8a9_row10_col0, #T_0e8a9_row11_col0 {
#   background-color: #fee7dc;
#   color: #000000;
# }
# #T_0e8a9_row12_col0 {
#   background-color: #ffebe2;
#   color: #000000;
# }
# #T_0e8a9_row13_col0 {
#   background-color: #fff2eb;
#   color: #000000;
# }
# #T_0e8a9_row14_col0 {
#   background-color: #fff2ec;
#   color: #000000;
# }
# #T_0e8a9_row15_col0 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_0e8a9_row16_col0 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_0e8a9_row17_col0, #T_0e8a9_row18_col0, #T_0e8a9_row19_col0, #T_0e8a9_row20_col0, #T_0e8a9_row21_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_0e8a9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0e8a9_level0_col0" class="col_heading level0 col0" >Missing (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0e8a9_level0_row0" class="row_heading level0 row0" >CS1</th>
#       <td id="T_0e8a9_row0_col0" class="data row0 col0" >51.612290</td>
#     </tr>
#     <tr>
#       <th id="T_0e8a9_level0_row1" class="row_heading level0 row1" >Insoluble Residue</th>
#       <td id="T_0e8a9_row1_col0" class="data row1 col0" >26.735369</td>
#     </tr>
#     <tr>
#       <th id="T_0e8a9_level0_row2" class="row_heading level0 row2" >Al2O3</th>
#       <td id="T_0e8a9_row2_col0" class="data row2 col0" >25.342325</td>
#     </tr>
#     <tr>
#       <th id="T_0e8a9_level0_row3" class="row_heading level0 row3" >Fe2O3</th>
#       <td id="T_0e8a9_row3_col0" class="data row3 col0" >25.321746</td>
#     </tr>
#     <tr>
#       <th id="T_0e8a9_level0_row4" class="row_heading level0 row4" >SiO2</th>
#       <td id="T_0e8a9_row4_col0" class="data row4 col0" >25.316997</td>
#     </tr>
#     <tr>
#       <th id="T_0e8a9_level0_row5" class="row_heading level0 row5" >CaO</th>
#       <td id="T_0e8a9_row5_col0" class="data row5 col0" >25.176109</td>
#     </tr>
#     <tr>
#       <th id="T_0e8a9_level0_row6" class="row_heading level0 row6" >#325</th>
#       <td id="T_0e8a9_row6_col0" class="data row6 col0" >12.222381</td>
#     </tr>
#     <tr>
#       <th id="T_0e8a9_level0_row7" class="row_heading level0 row7" >Na2O</th>
#       <td id="T_0e8a9_row7_col0" class="data row7 col0" >11.737981</td>
#     </tr>
#     <tr>
#       <th id="T_0e8a9_level0_row8" class="row_heading level0 row8" >K2O</th>
#       <td id="T_0e8a9_row8_col0" class="data row8 col0" >9.369806</td>
#     </tr>
#     <tr>
#       <th id="T_0e8a9_level0_row9" class="row_heading level0 row9" >CS3</th>
#       <td id="T_0e8a9_row9_col0" class="data row9 col0" >6.396923</td>
#     </tr>
#     <tr>
#       <th id="T_0e8a9_level0_row10" class="row_heading level0 row10" >Initial setting time</th>
#       <td id="T_0e8a9_row10_col0" class="data row10 col0" >4.394421</td>
#     </tr>
#     <tr>
#       <th id="T_0e8a9_level0_row11" class="row_heading level0 row11" >#200</th>
#       <td id="T_0e8a9_row11_col0" class="data row11 col0" >4.244036</td>
#     </tr>
#     <tr>
#       <th id="T_0e8a9_level0_row12" class="row_heading level0 row12" >MgO</th>
#       <td id="T_0e8a9_row12_col0" class="data row12 col0" >3.088442</td>
#     </tr>
#     <tr>
#       <th id="T_0e8a9_level0_row13" class="row_heading level0 row13" >Final setting time</th>
#       <td id="T_0e8a9_row13_col0" class="data row13 col0" >1.203084</td>
#     </tr>
#     <tr>
#       <th id="T_0e8a9_level0_row14" class="row_heading level0 row14" >SO3</th>
#       <td id="T_0e8a9_row14_col0" class="data row14 col0" >0.989378</td>
#     </tr>
#     <tr>
#       <th id="T_0e8a9_level0_row15" class="row_heading level0 row15" >Loss on Ignition</th>
#       <td id="T_0e8a9_row15_col0" class="data row15 col0" >0.737680</td>
#     </tr>
#     <tr>
#       <th id="T_0e8a9_level0_row16" class="row_heading level0 row16" >Blaine</th>
#       <td id="T_0e8a9_row16_col0" class="data row16 col0" >0.299188</td>
#     </tr>
#     <tr>
#       <th id="T_0e8a9_level0_row17" class="row_heading level0 row17" >CS7</th>
#       <td id="T_0e8a9_row17_col0" class="data row17 col0" >0.136138</td>
#     </tr>
#     <tr>
#       <th id="T_0e8a9_level0_row18" class="row_heading level0 row18" >Cement_Type</th>
#       <td id="T_0e8a9_row18_col0" class="data row18 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0e8a9_level0_row19" class="row_heading level0 row19" >Date</th>
#       <td id="T_0e8a9_row19_col0" class="data row19 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0e8a9_level0_row20" class="row_heading level0 row20" >CS28</th>
#       <td id="T_0e8a9_row20_col0" class="data row20 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0e8a9_level0_row21" class="row_heading level0 row21" >Factory_Plant</th>
#       <td id="T_0e8a9_row21_col0" class="data row21 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %%
zero_values = {}
for col in df.select_dtypes(include="number").columns:
    zero_percentages = (df[df[col].eq(0)].shape[0] / df.shape[0]) * 100
    zero_values[col] = zero_percentages

zero_percentages = pd.Series(zero_values, name=f"Zero (%) for Global Dataset")
zero_percentages = zero_percentages.sort_values(ascending=False)
zero_percentages = zero_percentages.to_frame(name=f"Zero (%) for Global Dataset")
zero_percentages.style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_180d1_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_180d1_row1_col0, #T_180d1_row2_col0, #T_180d1_row3_col0, #T_180d1_row4_col0, #T_180d1_row5_col0, #T_180d1_row6_col0, #T_180d1_row7_col0, #T_180d1_row8_col0, #T_180d1_row9_col0, #T_180d1_row10_col0, #T_180d1_row11_col0, #T_180d1_row12_col0, #T_180d1_row13_col0, #T_180d1_row14_col0, #T_180d1_row15_col0, #T_180d1_row16_col0, #T_180d1_row17_col0, #T_180d1_row18_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_180d1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_180d1_level0_col0" class="col_heading level0 col0" >Zero (%) for Global Dataset</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_180d1_level0_row0" class="row_heading level0 row0" >#200</th>
#       <td id="T_180d1_row0_col0" class="data row0 col0" >13.729401</td>
#     </tr>
#     <tr>
#       <th id="T_180d1_level0_row1" class="row_heading level0 row1" >CaO</th>
#       <td id="T_180d1_row1_col0" class="data row1 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_180d1_level0_row2" class="row_heading level0 row2" >Blaine</th>
#       <td id="T_180d1_row2_col0" class="data row2 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_180d1_level0_row3" class="row_heading level0 row3" >CS7</th>
#       <td id="T_180d1_row3_col0" class="data row3 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_180d1_level0_row4" class="row_heading level0 row4" >CS3</th>
#       <td id="T_180d1_row4_col0" class="data row4 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_180d1_level0_row5" class="row_heading level0 row5" >CS1</th>
#       <td id="T_180d1_row5_col0" class="data row5 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_180d1_level0_row6" class="row_heading level0 row6" >Final setting time</th>
#       <td id="T_180d1_row6_col0" class="data row6 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_180d1_level0_row7" class="row_heading level0 row7" >Initial setting time</th>
#       <td id="T_180d1_row7_col0" class="data row7 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_180d1_level0_row8" class="row_heading level0 row8" >#325</th>
#       <td id="T_180d1_row8_col0" class="data row8 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_180d1_level0_row9" class="row_heading level0 row9" >Insoluble Residue</th>
#       <td id="T_180d1_row9_col0" class="data row9 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_180d1_level0_row10" class="row_heading level0 row10" >MgO</th>
#       <td id="T_180d1_row10_col0" class="data row10 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_180d1_level0_row11" class="row_heading level0 row11" >Loss on Ignition</th>
#       <td id="T_180d1_row11_col0" class="data row11 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_180d1_level0_row12" class="row_heading level0 row12" >Fe2O3</th>
#       <td id="T_180d1_row12_col0" class="data row12 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_180d1_level0_row13" class="row_heading level0 row13" >K2O</th>
#       <td id="T_180d1_row13_col0" class="data row13 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_180d1_level0_row14" class="row_heading level0 row14" >SO3</th>
#       <td id="T_180d1_row14_col0" class="data row14 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_180d1_level0_row15" class="row_heading level0 row15" >SiO2</th>
#       <td id="T_180d1_row15_col0" class="data row15 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_180d1_level0_row16" class="row_heading level0 row16" >Al2O3</th>
#       <td id="T_180d1_row16_col0" class="data row16 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_180d1_level0_row17" class="row_heading level0 row17" >Na2O</th>
#       <td id="T_180d1_row17_col0" class="data row17 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_180d1_level0_row18" class="row_heading level0 row18" >CS28</th>
#       <td id="T_180d1_row18_col0" class="data row18 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.shape
# Out:
# (63171, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 63171 entries, 0 to 65013
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  63171 non-null  object
#  1   CaO                   47267 non-null  float64
#  2   MgO                   61220 non-null  float64
#  3   Na2O                  55756 non-null  float64
#  4   Al2O3                 47162 non-null  float64
#  5   SiO2                  47178 non-null  float64
#  6   SO3                   62546 non-null  float64
#  7   K2O                   57252 non-null  float64
#  8   Fe2O3                 47175 non-null  float64
#  9   Loss on Ignition      62705 non-null  float64
#  10  Insoluble Residue     46282 non-null  float64
#  11  Blaine                62982 non-null  float64
#  12  #200                  60490 non-null  float64
#  13  #325                  55450 non-null  float64
#  14  Initial setting time  60395 non-null  float64
#  15  Final setting time    62411 non-null  float64
#  16  CS1                   30567 non-null  float64
#  17  CS3                   59130 non-null  float64
#  18  CS7                   63085 non-null  float64
#  19  CS28                  63171 non-null  float64
#  20  Cement_Type           63171 non-null  object
#  21  Factory_Plant         63171 non-null  object
# dtypes: float64(19), object(3)
# memory usage: 11.1+ MB

# %% [markdown]
# ### Sort the dataset by date

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df = df.sort_values(by="Date")

# %% [markdown]
# ## Saving the dataset

# %% [markdown]
# <h3>Saving for feature engineering</h3>

# %%
df.to_csv("../../../../data/interim/203/global_y.csv", index=False)
