# %%
# %load_ext nb_black

# %%
import pandas as pd
import numpy as np
import missingno as msno

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading the datasets

# %% [markdown]
# ## Reading the global dataset

# %%
df = pd.read_csv("../../../../data/interim/Global-Dataset/global_dataset.csv")

# %% [markdown]
# ## Reading the local dataset for plant Y

# %%
df_i = pd.read_csv("../../../../data/processed/204/i.csv")

# %% [markdown]
# # Preprocessing of Global Dataset

# %% [markdown]
# ### Removing the plant to be fine-tuned

# %%
df.shape
# Out:
# (66111, 48)

# %%
df = df[df["Factory_Plant"] != "204_I"].reset_index(drop=True)

# %%
df.shape
# Out:
# (65208, 48)

# %% [markdown]
# ### Removing non-matching columns between the datasets

# %%
df = df[df_i.columns.to_list() + ["Factory_Plant"]]

# %%
df.shape
# Out:
# (65208, 21)

# %% [markdown]
# ## Removing missing features

# %%
(df.isna().sum() / df.shape[0] * 100).sort_values(ascending=False).to_frame(
    name="Missing (%)"
).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_f596f_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_f596f_row1_col0, #T_f596f_row2_col0, #T_f596f_row3_col0 {
#   background-color: #fb7050;
#   color: #f1f1f1;
# }
# #T_f596f_row4_col0 {
#   background-color: #fb7151;
#   color: #f1f1f1;
# }
# #T_f596f_row5_col0 {
#   background-color: #fcbfa7;
#   color: #000000;
# }
# #T_f596f_row6_col0 {
#   background-color: #fcc3ab;
#   color: #000000;
# }
# #T_f596f_row7_col0 {
#   background-color: #fdd1be;
#   color: #000000;
# }
# #T_f596f_row8_col0 {
#   background-color: #fee1d3;
#   color: #000000;
# }
# #T_f596f_row9_col0, #T_f596f_row10_col0 {
#   background-color: #fee7dc;
#   color: #000000;
# }
# #T_f596f_row11_col0 {
#   background-color: #ffebe2;
#   color: #000000;
# }
# #T_f596f_row12_col0 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_f596f_row13_col0 {
#   background-color: #fff2ec;
#   color: #000000;
# }
# #T_f596f_row14_col0 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_f596f_row15_col0 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_f596f_row16_col0, #T_f596f_row17_col0, #T_f596f_row18_col0, #T_f596f_row19_col0, #T_f596f_row20_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_f596f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f596f_level0_col0" class="col_heading level0 col0" >Missing (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f596f_level0_row0" class="row_heading level0 row0" >CS1</th>
#       <td id="T_f596f_row0_col0" class="data row0 col0" >50.983008</td>
#     </tr>
#     <tr>
#       <th id="T_f596f_level0_row1" class="row_heading level0 row1" >Fe2O3</th>
#       <td id="T_f596f_row1_col0" class="data row1 col0" >24.595142</td>
#     </tr>
#     <tr>
#       <th id="T_f596f_level0_row2" class="row_heading level0 row2" >Al2O3</th>
#       <td id="T_f596f_row2_col0" class="data row2 col0" >24.589007</td>
#     </tr>
#     <tr>
#       <th id="T_f596f_level0_row3" class="row_heading level0 row3" >SiO2</th>
#       <td id="T_f596f_row3_col0" class="data row3 col0" >24.564471</td>
#     </tr>
#     <tr>
#       <th id="T_f596f_level0_row4" class="row_heading level0 row4" >CaO</th>
#       <td id="T_f596f_row4_col0" class="data row4 col0" >24.427984</td>
#     </tr>
#     <tr>
#       <th id="T_f596f_level0_row5" class="row_heading level0 row5" >#325</th>
#       <td id="T_f596f_row5_col0" class="data row5 col0" >12.108944</td>
#     </tr>
#     <tr>
#       <th id="T_f596f_level0_row6" class="row_heading level0 row6" >Na2O</th>
#       <td id="T_f596f_row6_col0" class="data row6 col0" >11.457183</td>
#     </tr>
#     <tr>
#       <th id="T_f596f_level0_row7" class="row_heading level0 row7" >K2O</th>
#       <td id="T_f596f_row7_col0" class="data row7 col0" >9.107778</td>
#     </tr>
#     <tr>
#       <th id="T_f596f_level0_row8" class="row_heading level0 row8" >CS3</th>
#       <td id="T_f596f_row8_col0" class="data row8 col0" >6.207827</td>
#     </tr>
#     <tr>
#       <th id="T_f596f_level0_row9" class="row_heading level0 row9" >Initial setting time</th>
#       <td id="T_f596f_row9_col0" class="data row9 col0" >4.290885</td>
#     </tr>
#     <tr>
#       <th id="T_f596f_level0_row10" class="row_heading level0 row10" >#200</th>
#       <td id="T_f596f_row10_col0" class="data row10 col0" >4.198871</td>
#     </tr>
#     <tr>
#       <th id="T_f596f_level0_row11" class="row_heading level0 row11" >MgO</th>
#       <td id="T_f596f_row11_col0" class="data row11 col0" >3.021102</td>
#     </tr>
#     <tr>
#       <th id="T_f596f_level0_row12" class="row_heading level0 row12" >Final setting time</th>
#       <td id="T_f596f_row12_col0" class="data row12 col0" >1.208441</td>
#     </tr>
#     <tr>
#       <th id="T_f596f_level0_row13" class="row_heading level0 row13" >SO3</th>
#       <td id="T_f596f_row13_col0" class="data row13 col0" >0.993743</td>
#     </tr>
#     <tr>
#       <th id="T_f596f_level0_row14" class="row_heading level0 row14" >Loss on Ignition</th>
#       <td id="T_f596f_row14_col0" class="data row14 col0" >0.771378</td>
#     </tr>
#     <tr>
#       <th id="T_f596f_level0_row15" class="row_heading level0 row15" >Blaine</th>
#       <td id="T_f596f_row15_col0" class="data row15 col0" >0.306711</td>
#     </tr>
#     <tr>
#       <th id="T_f596f_level0_row16" class="row_heading level0 row16" >CS7</th>
#       <td id="T_f596f_row16_col0" class="data row16 col0" >0.138020</td>
#     </tr>
#     <tr>
#       <th id="T_f596f_level0_row17" class="row_heading level0 row17" >Cement_Type</th>
#       <td id="T_f596f_row17_col0" class="data row17 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f596f_level0_row18" class="row_heading level0 row18" >Date</th>
#       <td id="T_f596f_row18_col0" class="data row18 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f596f_level0_row19" class="row_heading level0 row19" >CS28</th>
#       <td id="T_f596f_row19_col0" class="data row19 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f596f_level0_row20" class="row_heading level0 row20" >Factory_Plant</th>
#       <td id="T_f596f_row20_col0" class="data row20 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %%
msno.matrix(df.loc[(df["CS1"].notna() == True)])
# Out:
# <Axes: >

# %%
missing_counts = df.isnull().sum()
plt.figure(figsize=(12, 6))
plt.bar(missing_counts.index, missing_counts.values)
plt.xticks(rotation=60)
plt.xlabel("Columns")
plt.ylabel("Number of Missing Values")
plt.title("Missing Values per Column")
plt.show()

# %% [markdown]
# ### Removing features with many zeros when applicable

# %%
zero_values = {}
for col in df.select_dtypes(include="number").columns:
    zero_percentages = (df[df[col].eq(0)].shape[0] / df.shape[0]) * 100
    zero_values[col] = zero_percentages

zero_percentages = pd.Series(zero_values, name=f"Zero (%) for Global Dataset")
zero_percentages = zero_percentages.sort_values(ascending=False)
zero_percentages = zero_percentages.to_frame(name=f"Zero (%) for Global Dataset")
zero_percentages.style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_8a3d2_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_8a3d2_row1_col0 {
#   background-color: #fee2d5;
#   color: #000000;
# }
# #T_8a3d2_row2_col0 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_8a3d2_row3_col0, #T_8a3d2_row4_col0, #T_8a3d2_row5_col0, #T_8a3d2_row6_col0, #T_8a3d2_row7_col0 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_8a3d2_row8_col0, #T_8a3d2_row9_col0, #T_8a3d2_row10_col0, #T_8a3d2_row11_col0, #T_8a3d2_row12_col0, #T_8a3d2_row13_col0, #T_8a3d2_row14_col0, #T_8a3d2_row15_col0, #T_8a3d2_row16_col0, #T_8a3d2_row17_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_8a3d2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8a3d2_level0_col0" class="col_heading level0 col0" >Zero (%) for Global Dataset</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8a3d2_level0_row0" class="row_heading level0 row0" >#200</th>
#       <td id="T_8a3d2_row0_col0" class="data row0 col0" >14.119433</td>
#     </tr>
#     <tr>
#       <th id="T_8a3d2_level0_row1" class="row_heading level0 row1" >Na2O</th>
#       <td id="T_8a3d2_row1_col0" class="data row1 col0" >1.613299</td>
#     </tr>
#     <tr>
#       <th id="T_8a3d2_level0_row2" class="row_heading level0 row2" >#325</th>
#       <td id="T_8a3d2_row2_col0" class="data row2 col0" >0.345050</td>
#     </tr>
#     <tr>
#       <th id="T_8a3d2_level0_row3" class="row_heading level0 row3" >Loss on Ignition</th>
#       <td id="T_8a3d2_row3_col0" class="data row3 col0" >0.096614</td>
#     </tr>
#     <tr>
#       <th id="T_8a3d2_level0_row4" class="row_heading level0 row4" >Blaine</th>
#       <td id="T_8a3d2_row4_col0" class="data row4 col0" >0.093547</td>
#     </tr>
#     <tr>
#       <th id="T_8a3d2_level0_row5" class="row_heading level0 row5" >Initial setting time</th>
#       <td id="T_8a3d2_row5_col0" class="data row5 col0" >0.084345</td>
#     </tr>
#     <tr>
#       <th id="T_8a3d2_level0_row6" class="row_heading level0 row6" >Final setting time</th>
#       <td id="T_8a3d2_row6_col0" class="data row6 col0" >0.082812</td>
#     </tr>
#     <tr>
#       <th id="T_8a3d2_level0_row7" class="row_heading level0 row7" >SO3</th>
#       <td id="T_8a3d2_row7_col0" class="data row7 col0" >0.062876</td>
#     </tr>
#     <tr>
#       <th id="T_8a3d2_level0_row8" class="row_heading level0 row8" >MgO</th>
#       <td id="T_8a3d2_row8_col0" class="data row8 col0" >0.021470</td>
#     </tr>
#     <tr>
#       <th id="T_8a3d2_level0_row9" class="row_heading level0 row9" >K2O</th>
#       <td id="T_8a3d2_row9_col0" class="data row9 col0" >0.009201</td>
#     </tr>
#     <tr>
#       <th id="T_8a3d2_level0_row10" class="row_heading level0 row10" >Fe2O3</th>
#       <td id="T_8a3d2_row10_col0" class="data row10 col0" >0.007668</td>
#     </tr>
#     <tr>
#       <th id="T_8a3d2_level0_row11" class="row_heading level0 row11" >CS7</th>
#       <td id="T_8a3d2_row11_col0" class="data row11 col0" >0.004601</td>
#     </tr>
#     <tr>
#       <th id="T_8a3d2_level0_row12" class="row_heading level0 row12" >SiO2</th>
#       <td id="T_8a3d2_row12_col0" class="data row12 col0" >0.004601</td>
#     </tr>
#     <tr>
#       <th id="T_8a3d2_level0_row13" class="row_heading level0 row13" >CaO</th>
#       <td id="T_8a3d2_row13_col0" class="data row13 col0" >0.001534</td>
#     </tr>
#     <tr>
#       <th id="T_8a3d2_level0_row14" class="row_heading level0 row14" >Al2O3</th>
#       <td id="T_8a3d2_row14_col0" class="data row14 col0" >0.001534</td>
#     </tr>
#     <tr>
#       <th id="T_8a3d2_level0_row15" class="row_heading level0 row15" >CS1</th>
#       <td id="T_8a3d2_row15_col0" class="data row15 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8a3d2_level0_row16" class="row_heading level0 row16" >CS3</th>
#       <td id="T_8a3d2_row16_col0" class="data row16 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8a3d2_level0_row17" class="row_heading level0 row17" >CS28</th>
#       <td id="T_8a3d2_row17_col0" class="data row17 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Drop rows where the target variable is null

# %%
df = df[df["CS28"].notna()]

# %% [markdown]
# ### Dropping rows where the target variable is zero

# %%
df = df[~df["CS28"].eq(0)]

# %% [markdown]
# ### Dropping rows where any other variable has a zero value - except #200

# %%
for col in df.columns:
    if col != "#200":
        df = df[~df[col].eq(0)]

# %%
(df.isna().sum() / df.shape[0] * 100).sort_values(ascending=False).to_frame(
    name="Missing (%)"
).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_9e08e_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_9e08e_row1_col0, #T_9e08e_row2_col0, #T_9e08e_row3_col0 {
#   background-color: #fb6e4e;
#   color: #f1f1f1;
# }
# #T_9e08e_row4_col0 {
#   background-color: #fb7050;
#   color: #f1f1f1;
# }
# #T_9e08e_row5_col0 {
#   background-color: #fcbfa7;
#   color: #000000;
# }
# #T_9e08e_row6_col0 {
#   background-color: #fcc3ab;
#   color: #000000;
# }
# #T_9e08e_row7_col0 {
#   background-color: #fdd0bc;
#   color: #000000;
# }
# #T_9e08e_row8_col0 {
#   background-color: #fee1d3;
#   color: #000000;
# }
# #T_9e08e_row9_col0 {
#   background-color: #fee7dc;
#   color: #000000;
# }
# #T_9e08e_row10_col0 {
#   background-color: #fee8dd;
#   color: #000000;
# }
# #T_9e08e_row11_col0 {
#   background-color: #ffebe2;
#   color: #000000;
# }
# #T_9e08e_row12_col0, #T_9e08e_row13_col0 {
#   background-color: #fff2eb;
#   color: #000000;
# }
# #T_9e08e_row14_col0 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_9e08e_row15_col0 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_9e08e_row16_col0, #T_9e08e_row17_col0, #T_9e08e_row18_col0, #T_9e08e_row19_col0, #T_9e08e_row20_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_9e08e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9e08e_level0_col0" class="col_heading level0 col0" >Missing (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9e08e_level0_row0" class="row_heading level0 row0" >CS1</th>
#       <td id="T_9e08e_row0_col0" class="data row0 col0" >51.456752</td>
#     </tr>
#     <tr>
#       <th id="T_9e08e_level0_row1" class="row_heading level0 row1" >Fe2O3</th>
#       <td id="T_9e08e_row1_col0" class="data row1 col0" >25.075268</td>
#     </tr>
#     <tr>
#       <th id="T_9e08e_level0_row2" class="row_heading level0 row2" >Al2O3</th>
#       <td id="T_9e08e_row2_col0" class="data row2 col0" >25.070564</td>
#     </tr>
#     <tr>
#       <th id="T_9e08e_level0_row3" class="row_heading level0 row3" >SiO2</th>
#       <td id="T_9e08e_row3_col0" class="data row3 col0" >25.045475</td>
#     </tr>
#     <tr>
#       <th id="T_9e08e_level0_row4" class="row_heading level0 row4" >CaO</th>
#       <td id="T_9e08e_row4_col0" class="data row4 col0" >24.905915</td>
#     </tr>
#     <tr>
#       <th id="T_9e08e_level0_row5" class="row_heading level0 row5" >#325</th>
#       <td id="T_9e08e_row5_col0" class="data row5 col0" >12.254594</td>
#     </tr>
#     <tr>
#       <th id="T_9e08e_level0_row6" class="row_heading level0 row6" >Na2O</th>
#       <td id="T_9e08e_row6_col0" class="data row6 col0" >11.594430</td>
#     </tr>
#     <tr>
#       <th id="T_9e08e_level0_row7" class="row_heading level0 row7" >K2O</th>
#       <td id="T_9e08e_row7_col0" class="data row7 col0" >9.248573</td>
#     </tr>
#     <tr>
#       <th id="T_9e08e_level0_row8" class="row_heading level0 row8" >CS3</th>
#       <td id="T_9e08e_row8_col0" class="data row8 col0" >6.338205</td>
#     </tr>
#     <tr>
#       <th id="T_9e08e_level0_row9" class="row_heading level0 row9" >Initial setting time</th>
#       <td id="T_9e08e_row9_col0" class="data row9 col0" >4.353008</td>
#     </tr>
#     <tr>
#       <th id="T_9e08e_level0_row10" class="row_heading level0 row10" >#200</th>
#       <td id="T_9e08e_row10_col0" class="data row10 col0" >4.205607</td>
#     </tr>
#     <tr>
#       <th id="T_9e08e_level0_row11" class="row_heading level0 row11" >MgO</th>
#       <td id="T_9e08e_row11_col0" class="data row11 col0" >3.026407</td>
#     </tr>
#     <tr>
#       <th id="T_9e08e_level0_row12" class="row_heading level0 row12" >Final setting time</th>
#       <td id="T_9e08e_row12_col0" class="data row12 col0" >1.191746</td>
#     </tr>
#     <tr>
#       <th id="T_9e08e_level0_row13" class="row_heading level0 row13" >SO3</th>
#       <td id="T_9e08e_row13_col0" class="data row13 col0" >1.008279</td>
#     </tr>
#     <tr>
#       <th id="T_9e08e_level0_row14" class="row_heading level0 row14" >Loss on Ignition</th>
#       <td id="T_9e08e_row14_col0" class="data row14 col0" >0.740137</td>
#     </tr>
#     <tr>
#       <th id="T_9e08e_level0_row15" class="row_heading level0 row15" >Blaine</th>
#       <td id="T_9e08e_row15_col0" class="data row15 col0" >0.296368</td>
#     </tr>
#     <tr>
#       <th id="T_9e08e_level0_row16" class="row_heading level0 row16" >CS7</th>
#       <td id="T_9e08e_row16_col0" class="data row16 col0" >0.134855</td>
#     </tr>
#     <tr>
#       <th id="T_9e08e_level0_row17" class="row_heading level0 row17" >Cement_Type</th>
#       <td id="T_9e08e_row17_col0" class="data row17 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9e08e_level0_row18" class="row_heading level0 row18" >Date</th>
#       <td id="T_9e08e_row18_col0" class="data row18 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9e08e_level0_row19" class="row_heading level0 row19" >CS28</th>
#       <td id="T_9e08e_row19_col0" class="data row19 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9e08e_level0_row20" class="row_heading level0 row20" >Factory_Plant</th>
#       <td id="T_9e08e_row20_col0" class="data row20 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %%
zero_values = {}
for col in df.select_dtypes(include="number").columns:
    zero_percentages = (df[df[col].eq(0)].shape[0] / df.shape[0]) * 100
    zero_values[col] = zero_percentages

zero_percentages = pd.Series(zero_values, name=f"Zero (%) for Global Dataset")
zero_percentages = zero_percentages.sort_values(ascending=False)
zero_percentages = zero_percentages.to_frame(name=f"Zero (%) for Global Dataset")
zero_percentages.style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_e1c24_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_e1c24_row1_col0, #T_e1c24_row2_col0, #T_e1c24_row3_col0, #T_e1c24_row4_col0, #T_e1c24_row5_col0, #T_e1c24_row6_col0, #T_e1c24_row7_col0, #T_e1c24_row8_col0, #T_e1c24_row9_col0, #T_e1c24_row10_col0, #T_e1c24_row11_col0, #T_e1c24_row12_col0, #T_e1c24_row13_col0, #T_e1c24_row14_col0, #T_e1c24_row15_col0, #T_e1c24_row16_col0, #T_e1c24_row17_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_e1c24">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e1c24_level0_col0" class="col_heading level0 col0" >Zero (%) for Global Dataset</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e1c24_level0_row0" class="row_heading level0 row0" >#200</th>
#       <td id="T_e1c24_row0_col0" class="data row0 col0" >13.965377</td>
#     </tr>
#     <tr>
#       <th id="T_e1c24_level0_row1" class="row_heading level0 row1" >CaO</th>
#       <td id="T_e1c24_row1_col0" class="data row1 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e1c24_level0_row2" class="row_heading level0 row2" >MgO</th>
#       <td id="T_e1c24_row2_col0" class="data row2 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e1c24_level0_row3" class="row_heading level0 row3" >CS7</th>
#       <td id="T_e1c24_row3_col0" class="data row3 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e1c24_level0_row4" class="row_heading level0 row4" >CS3</th>
#       <td id="T_e1c24_row4_col0" class="data row4 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e1c24_level0_row5" class="row_heading level0 row5" >CS1</th>
#       <td id="T_e1c24_row5_col0" class="data row5 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e1c24_level0_row6" class="row_heading level0 row6" >Final setting time</th>
#       <td id="T_e1c24_row6_col0" class="data row6 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e1c24_level0_row7" class="row_heading level0 row7" >Initial setting time</th>
#       <td id="T_e1c24_row7_col0" class="data row7 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e1c24_level0_row8" class="row_heading level0 row8" >#325</th>
#       <td id="T_e1c24_row8_col0" class="data row8 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e1c24_level0_row9" class="row_heading level0 row9" >Blaine</th>
#       <td id="T_e1c24_row9_col0" class="data row9 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e1c24_level0_row10" class="row_heading level0 row10" >Loss on Ignition</th>
#       <td id="T_e1c24_row10_col0" class="data row10 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e1c24_level0_row11" class="row_heading level0 row11" >Fe2O3</th>
#       <td id="T_e1c24_row11_col0" class="data row11 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e1c24_level0_row12" class="row_heading level0 row12" >K2O</th>
#       <td id="T_e1c24_row12_col0" class="data row12 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e1c24_level0_row13" class="row_heading level0 row13" >SO3</th>
#       <td id="T_e1c24_row13_col0" class="data row13 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e1c24_level0_row14" class="row_heading level0 row14" >SiO2</th>
#       <td id="T_e1c24_row14_col0" class="data row14 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e1c24_level0_row15" class="row_heading level0 row15" >Al2O3</th>
#       <td id="T_e1c24_row15_col0" class="data row15 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e1c24_level0_row16" class="row_heading level0 row16" >Na2O</th>
#       <td id="T_e1c24_row16_col0" class="data row16 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e1c24_level0_row17" class="row_heading level0 row17" >CS28</th>
#       <td id="T_e1c24_row17_col0" class="data row17 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.shape
# Out:
# (63772, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 63772 entries, 0 to 65207
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  63772 non-null  object
#  1   CaO                   47889 non-null  float64
#  2   MgO                   61842 non-null  float64
#  3   Na2O                  56378 non-null  float64
#  4   Al2O3                 47784 non-null  float64
#  5   SiO2                  47800 non-null  float64
#  6   SO3                   63129 non-null  float64
#  7   K2O                   57874 non-null  float64
#  8   Fe2O3                 47781 non-null  float64
#  9   Loss on Ignition      63300 non-null  float64
#  10  Blaine                63583 non-null  float64
#  11  #200                  61090 non-null  float64
#  12  #325                  55957 non-null  float64
#  13  Initial setting time  60996 non-null  float64
#  14  Final setting time    63012 non-null  float64
#  15  CS1                   30957 non-null  float64
#  16  CS3                   59730 non-null  float64
#  17  CS7                   63686 non-null  float64
#  18  CS28                  63772 non-null  float64
#  19  Cement_Type           63772 non-null  object
#  20  Factory_Plant         63772 non-null  object
# dtypes: float64(18), object(3)
# memory usage: 10.7+ MB

# %% [markdown]
# ### Sort the dataset by date

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df = df.sort_values(by="Date")

# %% [markdown]
# ## Saving the dataset

# %% [markdown]
# <h3>Saving for feature engineering</h3>

# %%
df.to_csv("../../../../data/interim/204/global_i.csv", index=False)
