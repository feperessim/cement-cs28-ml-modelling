# %%
# %load_ext nb_black

# %%
import pandas as pd
import numpy as np
import missingno as msno

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading the datasets

# %% [markdown]
# ## Reading the global dataset

# %%
df = pd.read_csv("../../../../data/interim/Global-Dataset/global_dataset.csv")

# %% [markdown]
# ## Reading the local dataset for plant F

# %%
df_f = pd.read_csv("../../../../data/processed/204/f.csv")

# %% [markdown]
# # Preprocessing of Global Dataset

# %% [markdown]
# ### Removing the plant to be fine-tuned

# %%
df.shape
# Out:
# (66111, 48)

# %%
df = df[df["Factory_Plant"] != "204_F"].reset_index(drop=True)

# %%
df.shape
# Out:
# (63490, 48)

# %% [markdown]
# ### Removing non-matching columns between the datasets

# %%
df = df[df_f.columns.to_list() + ["Factory_Plant"]]

# %%
df.shape
# Out:
# (63490, 21)

# %% [markdown]
# ## Removing missing features

# %%
(df.isna().sum() / df.shape[0] * 100).sort_values(ascending=False).to_frame(
    name="Missing (%)"
).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_c1a3f_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_c1a3f_row1_col0 {
#   background-color: #fb6b4b;
#   color: #f1f1f1;
# }
# #T_c1a3f_row2_col0, #T_c1a3f_row3_col0, #T_c1a3f_row4_col0 {
#   background-color: #fb6c4c;
#   color: #f1f1f1;
# }
# #T_c1a3f_row5_col0 {
#   background-color: #fcbda4;
#   color: #000000;
# }
# #T_c1a3f_row6_col0 {
#   background-color: #fcc1a8;
#   color: #000000;
# }
# #T_c1a3f_row7_col0 {
#   background-color: #fdcebb;
#   color: #000000;
# }
# #T_c1a3f_row8_col0 {
#   background-color: #fee1d3;
#   color: #000000;
# }
# #T_c1a3f_row9_col0 {
#   background-color: #fee7db;
#   color: #000000;
# }
# #T_c1a3f_row10_col0 {
#   background-color: #fee7dc;
#   color: #000000;
# }
# #T_c1a3f_row11_col0 {
#   background-color: #ffebe2;
#   color: #000000;
# }
# #T_c1a3f_row12_col0 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_c1a3f_row13_col0 {
#   background-color: #fff2eb;
#   color: #000000;
# }
# #T_c1a3f_row14_col0 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_c1a3f_row15_col0 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_c1a3f_row16_col0, #T_c1a3f_row17_col0, #T_c1a3f_row18_col0, #T_c1a3f_row19_col0, #T_c1a3f_row20_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_c1a3f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c1a3f_level0_col0" class="col_heading level0 col0" >Missing (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c1a3f_level0_row0" class="row_heading level0 row0" >CS1</th>
#       <td id="T_c1a3f_row0_col0" class="data row0 col0" >50.995432</td>
#     </tr>
#     <tr>
#       <th id="T_c1a3f_level0_row1" class="row_heading level0 row1" >Fe2O3</th>
#       <td id="T_c1a3f_row1_col0" class="data row1 col0" >25.301622</td>
#     </tr>
#     <tr>
#       <th id="T_c1a3f_level0_row2" class="row_heading level0 row2" >Al2O3</th>
#       <td id="T_c1a3f_row2_col0" class="data row2 col0" >25.295322</td>
#     </tr>
#     <tr>
#       <th id="T_c1a3f_level0_row3" class="row_heading level0 row3" >SiO2</th>
#       <td id="T_c1a3f_row3_col0" class="data row3 col0" >25.270121</td>
#     </tr>
#     <tr>
#       <th id="T_c1a3f_level0_row4" class="row_heading level0 row4" >CaO</th>
#       <td id="T_c1a3f_row4_col0" class="data row4 col0" >25.129942</td>
#     </tr>
#     <tr>
#       <th id="T_c1a3f_level0_row5" class="row_heading level0 row5" >#325</th>
#       <td id="T_c1a3f_row5_col0" class="data row5 col0" >12.435029</td>
#     </tr>
#     <tr>
#       <th id="T_c1a3f_level0_row6" class="row_heading level0 row6" >Na2O</th>
#       <td id="T_c1a3f_row6_col0" class="data row6 col0" >11.808159</td>
#     </tr>
#     <tr>
#       <th id="T_c1a3f_level0_row7" class="row_heading level0 row7" >K2O</th>
#       <td id="T_c1a3f_row7_col0" class="data row7 col0" >9.395180</td>
#     </tr>
#     <tr>
#       <th id="T_c1a3f_level0_row8" class="row_heading level0 row8" >CS3</th>
#       <td id="T_c1a3f_row8_col0" class="data row8 col0" >6.374232</td>
#     </tr>
#     <tr>
#       <th id="T_c1a3f_level0_row9" class="row_heading level0 row9" >Initial setting time</th>
#       <td id="T_c1a3f_row9_col0" class="data row9 col0" >4.406993</td>
#     </tr>
#     <tr>
#       <th id="T_c1a3f_level0_row10" class="row_heading level0 row10" >#200</th>
#       <td id="T_c1a3f_row10_col0" class="data row10 col0" >4.312490</td>
#     </tr>
#     <tr>
#       <th id="T_c1a3f_level0_row11" class="row_heading level0 row11" >MgO</th>
#       <td id="T_c1a3f_row11_col0" class="data row11 col0" >3.143802</td>
#     </tr>
#     <tr>
#       <th id="T_c1a3f_level0_row12" class="row_heading level0 row12" >Final setting time</th>
#       <td id="T_c1a3f_row12_col0" class="data row12 col0" >1.241140</td>
#     </tr>
#     <tr>
#       <th id="T_c1a3f_level0_row13" class="row_heading level0 row13" >SO3</th>
#       <td id="T_c1a3f_row13_col0" class="data row13 col0" >1.000158</td>
#     </tr>
#     <tr>
#       <th id="T_c1a3f_level0_row14" class="row_heading level0 row14" >Loss on Ignition</th>
#       <td id="T_c1a3f_row14_col0" class="data row14 col0" >0.773350</td>
#     </tr>
#     <tr>
#       <th id="T_c1a3f_level0_row15" class="row_heading level0 row15" >Blaine</th>
#       <td id="T_c1a3f_row15_col0" class="data row15 col0" >0.315010</td>
#     </tr>
#     <tr>
#       <th id="T_c1a3f_level0_row16" class="row_heading level0 row16" >CS7</th>
#       <td id="T_c1a3f_row16_col0" class="data row16 col0" >0.140180</td>
#     </tr>
#     <tr>
#       <th id="T_c1a3f_level0_row17" class="row_heading level0 row17" >Cement_Type</th>
#       <td id="T_c1a3f_row17_col0" class="data row17 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c1a3f_level0_row18" class="row_heading level0 row18" >Date</th>
#       <td id="T_c1a3f_row18_col0" class="data row18 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c1a3f_level0_row19" class="row_heading level0 row19" >CS28</th>
#       <td id="T_c1a3f_row19_col0" class="data row19 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c1a3f_level0_row20" class="row_heading level0 row20" >Factory_Plant</th>
#       <td id="T_c1a3f_row20_col0" class="data row20 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %%
missing_counts = df.isnull().sum()
plt.figure(figsize=(12, 6))
plt.bar(missing_counts.index, missing_counts.values)
plt.xticks(rotation=60)
plt.xlabel("Columns")
plt.ylabel("Number of Missing Values")
plt.title("Missing Values per Column")
plt.show()

# %% [markdown]
# ### Removing features with many zeros when applicable

# %%
zero_values = {}
for col in df.select_dtypes(include="number").columns:
    zero_percentages = (df[df[col].eq(0)].shape[0] / df.shape[0]) * 100
    zero_values[col] = zero_percentages

zero_percentages = pd.Series(zero_values, name=f"Zero (%) for Global Dataset")
zero_percentages = zero_percentages.sort_values(ascending=False)
zero_percentages = zero_percentages.to_frame(name=f"Zero (%) for Global Dataset")
zero_percentages.style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_6f000_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_6f000_row1_col0 {
#   background-color: #fee3d6;
#   color: #000000;
# }
# #T_6f000_row2_col0 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_6f000_row3_col0, #T_6f000_row4_col0, #T_6f000_row5_col0, #T_6f000_row6_col0, #T_6f000_row7_col0 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_6f000_row8_col0, #T_6f000_row9_col0, #T_6f000_row10_col0, #T_6f000_row11_col0, #T_6f000_row12_col0, #T_6f000_row13_col0, #T_6f000_row14_col0, #T_6f000_row15_col0, #T_6f000_row16_col0, #T_6f000_row17_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_6f000">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6f000_level0_col0" class="col_heading level0 col0" >Zero (%) for Global Dataset</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6f000_level0_row0" class="row_heading level0 row0" >#200</th>
#       <td id="T_6f000_row0_col0" class="data row0 col0" >14.492046</td>
#     </tr>
#     <tr>
#       <th id="T_6f000_level0_row1" class="row_heading level0 row1" >Na2O</th>
#       <td id="T_6f000_row1_col0" class="data row1 col0" >1.636478</td>
#     </tr>
#     <tr>
#       <th id="T_6f000_level0_row2" class="row_heading level0 row2" >#325</th>
#       <td id="T_6f000_row2_col0" class="data row2 col0" >0.349661</td>
#     </tr>
#     <tr>
#       <th id="T_6f000_level0_row3" class="row_heading level0 row3" >Blaine</th>
#       <td id="T_6f000_row3_col0" class="data row3 col0" >0.091353</td>
#     </tr>
#     <tr>
#       <th id="T_6f000_level0_row4" class="row_heading level0 row4" >Initial setting time</th>
#       <td id="T_6f000_row4_col0" class="data row4 col0" >0.081903</td>
#     </tr>
#     <tr>
#       <th id="T_6f000_level0_row5" class="row_heading level0 row5" >Final setting time</th>
#       <td id="T_6f000_row5_col0" class="data row5 col0" >0.077178</td>
#     </tr>
#     <tr>
#       <th id="T_6f000_level0_row6" class="row_heading level0 row6" >Loss on Ignition</th>
#       <td id="T_6f000_row6_col0" class="data row6 col0" >0.067727</td>
#     </tr>
#     <tr>
#       <th id="T_6f000_level0_row7" class="row_heading level0 row7" >SO3</th>
#       <td id="T_6f000_row7_col0" class="data row7 col0" >0.061427</td>
#     </tr>
#     <tr>
#       <th id="T_6f000_level0_row8" class="row_heading level0 row8" >MgO</th>
#       <td id="T_6f000_row8_col0" class="data row8 col0" >0.022051</td>
#     </tr>
#     <tr>
#       <th id="T_6f000_level0_row9" class="row_heading level0 row9" >K2O</th>
#       <td id="T_6f000_row9_col0" class="data row9 col0" >0.012600</td>
#     </tr>
#     <tr>
#       <th id="T_6f000_level0_row10" class="row_heading level0 row10" >CS7</th>
#       <td id="T_6f000_row10_col0" class="data row10 col0" >0.004725</td>
#     </tr>
#     <tr>
#       <th id="T_6f000_level0_row11" class="row_heading level0 row11" >Fe2O3</th>
#       <td id="T_6f000_row11_col0" class="data row11 col0" >0.004725</td>
#     </tr>
#     <tr>
#       <th id="T_6f000_level0_row12" class="row_heading level0 row12" >SiO2</th>
#       <td id="T_6f000_row12_col0" class="data row12 col0" >0.003150</td>
#     </tr>
#     <tr>
#       <th id="T_6f000_level0_row13" class="row_heading level0 row13" >CaO</th>
#       <td id="T_6f000_row13_col0" class="data row13 col0" >0.001575</td>
#     </tr>
#     <tr>
#       <th id="T_6f000_level0_row14" class="row_heading level0 row14" >Al2O3</th>
#       <td id="T_6f000_row14_col0" class="data row14 col0" >0.001575</td>
#     </tr>
#     <tr>
#       <th id="T_6f000_level0_row15" class="row_heading level0 row15" >CS1</th>
#       <td id="T_6f000_row15_col0" class="data row15 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6f000_level0_row16" class="row_heading level0 row16" >CS3</th>
#       <td id="T_6f000_row16_col0" class="data row16 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6f000_level0_row17" class="row_heading level0 row17" >CS28</th>
#       <td id="T_6f000_row17_col0" class="data row17 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Drop rows where the target variable is null

# %%
df = df[df["CS28"].notna()]

# %% [markdown]
# ### Dropping rows where the target variable is zero

# %%
df = df[~df["CS28"].eq(0)]

# %% [markdown]
# ### Dropping rows where any other variable has a zero value - except #200

# %%
for col in df.columns:
    if col != "#200" and col != "#325":
        df = df[~df[col].eq(0)]

# %%
(df.isna().sum() / df.shape[0] * 100).sort_values(ascending=False).to_frame(
    name="Missing (%)"
).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_73640_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_73640_row1_col0, #T_73640_row2_col0, #T_73640_row3_col0 {
#   background-color: #fb6b4b;
#   color: #f1f1f1;
# }
# #T_73640_row4_col0 {
#   background-color: #fb6c4c;
#   color: #f1f1f1;
# }
# #T_73640_row5_col0 {
#   background-color: #fcbda4;
#   color: #000000;
# }
# #T_73640_row6_col0 {
#   background-color: #fcc1a8;
#   color: #000000;
# }
# #T_73640_row7_col0 {
#   background-color: #fdcebb;
#   color: #000000;
# }
# #T_73640_row8_col0 {
#   background-color: #fee0d2;
#   color: #000000;
# }
# #T_73640_row9_col0 {
#   background-color: #fee7db;
#   color: #000000;
# }
# #T_73640_row10_col0 {
#   background-color: #fee7dc;
#   color: #000000;
# }
# #T_73640_row11_col0 {
#   background-color: #ffebe2;
#   color: #000000;
# }
# #T_73640_row12_col0 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_73640_row13_col0 {
#   background-color: #fff2eb;
#   color: #000000;
# }
# #T_73640_row14_col0 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_73640_row15_col0 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_73640_row16_col0, #T_73640_row17_col0, #T_73640_row18_col0, #T_73640_row19_col0, #T_73640_row20_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_73640">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_73640_level0_col0" class="col_heading level0 col0" >Missing (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_73640_level0_row0" class="row_heading level0 row0" >CS1</th>
#       <td id="T_73640_row0_col0" class="data row0 col0" >51.566161</td>
#     </tr>
#     <tr>
#       <th id="T_73640_level0_row1" class="row_heading level0 row1" >Fe2O3</th>
#       <td id="T_73640_row1_col0" class="data row1 col0" >25.711672</td>
#     </tr>
#     <tr>
#       <th id="T_73640_level0_row2" class="row_heading level0 row2" >Al2O3</th>
#       <td id="T_73640_row2_col0" class="data row2 col0" >25.705254</td>
#     </tr>
#     <tr>
#       <th id="T_73640_level0_row3" class="row_heading level0 row3" >SiO2</th>
#       <td id="T_73640_row3_col0" class="data row3 col0" >25.679579</td>
#     </tr>
#     <tr>
#       <th id="T_73640_level0_row4" class="row_heading level0 row4" >CaO</th>
#       <td id="T_73640_row4_col0" class="data row4 col0" >25.536763</td>
#     </tr>
#     <tr>
#       <th id="T_73640_level0_row5" class="row_heading level0 row5" >#325</th>
#       <td id="T_73640_row5_col0" class="data row5 col0" >12.538913</td>
#     </tr>
#     <tr>
#       <th id="T_73640_level0_row6" class="row_heading level0 row6" >Na2O</th>
#       <td id="T_73640_row6_col0" class="data row6 col0" >11.924324</td>
#     </tr>
#     <tr>
#       <th id="T_73640_level0_row7" class="row_heading level0 row7" >K2O</th>
#       <td id="T_73640_row7_col0" class="data row7 col0" >9.512500</td>
#     </tr>
#     <tr>
#       <th id="T_73640_level0_row8" class="row_heading level0 row8" >CS3</th>
#       <td id="T_73640_row8_col0" class="data row8 col0" >6.486087</td>
#     </tr>
#     <tr>
#       <th id="T_73640_level0_row9" class="row_heading level0 row9" >Initial setting time</th>
#       <td id="T_73640_row9_col0" class="data row9 col0" >4.478642</td>
#     </tr>
#     <tr>
#       <th id="T_73640_level0_row10" class="row_heading level0 row10" >#200</th>
#       <td id="T_73640_row10_col0" class="data row10 col0" >4.311756</td>
#     </tr>
#     <tr>
#       <th id="T_73640_level0_row11" class="row_heading level0 row11" >MgO</th>
#       <td id="T_73640_row11_col0" class="data row11 col0" >3.145159</td>
#     </tr>
#     <tr>
#       <th id="T_73640_level0_row12" class="row_heading level0 row12" >Final setting time</th>
#       <td id="T_73640_row12_col0" class="data row12 col0" >1.246831</td>
#     </tr>
#     <tr>
#       <th id="T_73640_level0_row13" class="row_heading level0 row13" >SO3</th>
#       <td id="T_73640_row13_col0" class="data row13 col0" >1.017363</td>
#     </tr>
#     <tr>
#       <th id="T_73640_level0_row14" class="row_heading level0 row14" >Loss on Ignition</th>
#       <td id="T_73640_row14_col0" class="data row14 col0" >0.738149</td>
#     </tr>
#     <tr>
#       <th id="T_73640_level0_row15" class="row_heading level0 row15" >Blaine</th>
#       <td id="T_73640_row15_col0" class="data row15 col0" >0.309702</td>
#     </tr>
#     <tr>
#       <th id="T_73640_level0_row16" class="row_heading level0 row16" >CS7</th>
#       <td id="T_73640_row16_col0" class="data row16 col0" >0.136397</td>
#     </tr>
#     <tr>
#       <th id="T_73640_level0_row17" class="row_heading level0 row17" >Cement_Type</th>
#       <td id="T_73640_row17_col0" class="data row17 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_73640_level0_row18" class="row_heading level0 row18" >Date</th>
#       <td id="T_73640_row18_col0" class="data row18 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_73640_level0_row19" class="row_heading level0 row19" >CS28</th>
#       <td id="T_73640_row19_col0" class="data row19 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_73640_level0_row20" class="row_heading level0 row20" >Factory_Plant</th>
#       <td id="T_73640_row20_col0" class="data row20 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %%
zero_values = {}
for col in df.select_dtypes(include="number").columns:
    zero_percentages = (df[df[col].eq(0)].shape[0] / df.shape[0]) * 100
    zero_values[col] = zero_percentages

zero_percentages = pd.Series(zero_values, name=f"Zero (%) for Global Dataset")
zero_percentages = zero_percentages.sort_values(ascending=False)
zero_percentages = zero_percentages.to_frame(name=f"Zero (%) for Global Dataset")
zero_percentages.style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_18cd8_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_18cd8_row1_col0 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_18cd8_row2_col0, #T_18cd8_row3_col0, #T_18cd8_row4_col0, #T_18cd8_row5_col0, #T_18cd8_row6_col0, #T_18cd8_row7_col0, #T_18cd8_row8_col0, #T_18cd8_row9_col0, #T_18cd8_row10_col0, #T_18cd8_row11_col0, #T_18cd8_row12_col0, #T_18cd8_row13_col0, #T_18cd8_row14_col0, #T_18cd8_row15_col0, #T_18cd8_row16_col0, #T_18cd8_row17_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_18cd8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_18cd8_level0_col0" class="col_heading level0 col0" >Zero (%) for Global Dataset</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_18cd8_level0_row0" class="row_heading level0 row0" >#200</th>
#       <td id="T_18cd8_row0_col0" class="data row0 col0" >14.567220</td>
#     </tr>
#     <tr>
#       <th id="T_18cd8_level0_row1" class="row_heading level0 row1" >#325</th>
#       <td id="T_18cd8_row1_col0" class="data row1 col0" >0.349819</td>
#     </tr>
#     <tr>
#       <th id="T_18cd8_level0_row2" class="row_heading level0 row2" >CaO</th>
#       <td id="T_18cd8_row2_col0" class="data row2 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_18cd8_level0_row3" class="row_heading level0 row3" >MgO</th>
#       <td id="T_18cd8_row3_col0" class="data row3 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_18cd8_level0_row4" class="row_heading level0 row4" >CS7</th>
#       <td id="T_18cd8_row4_col0" class="data row4 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_18cd8_level0_row5" class="row_heading level0 row5" >CS3</th>
#       <td id="T_18cd8_row5_col0" class="data row5 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_18cd8_level0_row6" class="row_heading level0 row6" >CS1</th>
#       <td id="T_18cd8_row6_col0" class="data row6 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_18cd8_level0_row7" class="row_heading level0 row7" >Final setting time</th>
#       <td id="T_18cd8_row7_col0" class="data row7 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_18cd8_level0_row8" class="row_heading level0 row8" >Initial setting time</th>
#       <td id="T_18cd8_row8_col0" class="data row8 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_18cd8_level0_row9" class="row_heading level0 row9" >Blaine</th>
#       <td id="T_18cd8_row9_col0" class="data row9 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_18cd8_level0_row10" class="row_heading level0 row10" >Loss on Ignition</th>
#       <td id="T_18cd8_row10_col0" class="data row10 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_18cd8_level0_row11" class="row_heading level0 row11" >Fe2O3</th>
#       <td id="T_18cd8_row11_col0" class="data row11 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_18cd8_level0_row12" class="row_heading level0 row12" >K2O</th>
#       <td id="T_18cd8_row12_col0" class="data row12 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_18cd8_level0_row13" class="row_heading level0 row13" >SO3</th>
#       <td id="T_18cd8_row13_col0" class="data row13 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_18cd8_level0_row14" class="row_heading level0 row14" >SiO2</th>
#       <td id="T_18cd8_row14_col0" class="data row14 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_18cd8_level0_row15" class="row_heading level0 row15" >Al2O3</th>
#       <td id="T_18cd8_row15_col0" class="data row15 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_18cd8_level0_row16" class="row_heading level0 row16" >Na2O</th>
#       <td id="T_18cd8_row16_col0" class="data row16 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_18cd8_level0_row17" class="row_heading level0 row17" >CS28</th>
#       <td id="T_18cd8_row17_col0" class="data row17 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.shape
# Out:
# (62318, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 62318 entries, 0 to 63489
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  62318 non-null  object
#  1   CaO                   46404 non-null  float64
#  2   MgO                   60358 non-null  float64
#  3   Na2O                  54887 non-null  float64
#  4   Al2O3                 46299 non-null  float64
#  5   SiO2                  46315 non-null  float64
#  6   SO3                   61684 non-null  float64
#  7   K2O                   56390 non-null  float64
#  8   Fe2O3                 46295 non-null  float64
#  9   Loss on Ignition      61858 non-null  float64
#  10  Blaine                62125 non-null  float64
#  11  #200                  59631 non-null  float64
#  12  #325                  54504 non-null  float64
#  13  Initial setting time  59527 non-null  float64
#  14  Final setting time    61541 non-null  float64
#  15  CS1                   30183 non-null  float64
#  16  CS3                   58276 non-null  float64
#  17  CS7                   62233 non-null  float64
#  18  CS28                  62318 non-null  float64
#  19  Cement_Type           62318 non-null  object
#  20  Factory_Plant         62318 non-null  object
# dtypes: float64(18), object(3)
# memory usage: 10.5+ MB

# %% [markdown]
# ### Sort the dataset by date

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df = df.sort_values(by="Date")

# %% [markdown]
# ## Saving the dataset

# %% [markdown]
# <h3>Saving for feature engineering</h3>

# %%
df.to_csv("../../../../data/interim/204/global_f.csv", index=False)
