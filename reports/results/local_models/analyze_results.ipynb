# %%
# %load_ext nb_black
# Out:
# The nb_black extension is already loaded. To reload it, use:
#   %reload_ext nb_black

# %%
import pandas as pd
import os
import glob

# %%
import warnings

# Suppress specific FutureWarning
warnings.filterwarnings("ignore", category=FutureWarning, module="seaborn._oldcore")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.preprocessing import StandardScaler

# %%
def read_csv_files_grouped(csv_files, plant, header=[0, 1]):
    results = []
    for filepath in csv_files:
        df = pd.read_csv(filepath, header=header, low_memory=False)
        df["plant"] = plant  # Add the 'plant' column
        results.append(df)
    df = pd.concat(results, ignore_index=True)
    return df

# %%
def read_csv_files_full(csv_files, plant):
    results = []
    for filepath in csv_files:
        df = pd.read_csv(filepath, low_memory=False)
        df["plant"] = plant  # Add the 'plant' column
        results.append(df)
    df = pd.concat(results, ignore_index=True)
    return df

# %% [markdown]
# ### Renaming the Columns

# %%
def preprocess_rename_columns(df):
    df.columns = pd.MultiIndex.from_tuples(
        list(
            {
                col: (col[0], "") if "Unnamed" in col[1] else col for col in df.columns
            }.values()
        )
    )
    return df

# %% [markdown]
# ### Changing the order_of columns Columns

# %%
# def preprocess_change_columns_order(df, column, pos):
#     pd.concat([df[df.columns[:pos]], df[column], df[df.columns[pos:-1]]], axis=1)
#     return df

# %%
def preprocess_change_columns_order(df, column, pos):
    # Get the list of columns
    cols = df.columns.tolist()
    # Remove the specified column
    cols.remove(column)
    # Insert the column at the desired position
    cols.insert(pos, column)
    # Reorder the DataFrame columns
    return df[cols]

# %%
def read_csv_files_path(csv_files_path_dict, path, plant):
    csv_files = glob.glob(os.path.join(path, "*.csv"))
    csv_files_path_dict[plant] = csv_files
    return csv_files_path_dict

# %% [markdown]
# # Reading The files

# %%
csv_files_path_grouped = dict()
csv_files_path_full = dict()

# %% [markdown]
# ## partner_i

# %%
path_grouped = "/home/peressim/projects/ccs28-ml-modelling/reports/results/local_models/partner_i-oficial/all_cements/grouped/"
path_full = "/home/peressim/projects/ccs28-ml-modelling/reports/results/local_models/partner_i-oficial/all_cements/full/"
plant = "partner_i"

csv_files_path_full = read_csv_files_path(csv_files_path_full, path_full, plant)

csv_files_path_grouped = read_csv_files_path(
    csv_files_path_grouped, path_grouped, plant
)

# %% [markdown]
# ## partner_ii

# %%
path_grouped = "/home/peressim/projects/ccs28-ml-modelling/reports/results/local_models/partner_ii/all_cements/grouped/"
path_full = "/home/peressim/projects/ccs28-ml-modelling/reports/results/local_models/partner_ii/all_cements/full/"
plant = "partner_ii"

csv_files_path_full = read_csv_files_path(csv_files_path_full, path_full, plant)

csv_files_path_grouped = read_csv_files_path(
    csv_files_path_grouped, path_grouped, plant
)

# %% [markdown]
# ## partner_iv

# %%
path_grouped = "/home/peressim/projects/ccs28-ml-modelling/reports/results/local_models/partner_iv/all_cements/grouped/"
path_full = "/home/peressim/projects/ccs28-ml-modelling/reports/results/local_models/partner_iv/all_cements/full/"
plant = "partner_iv"
csv_files_path_full = read_csv_files_path(csv_files_path_full, path_full, plant)
csv_files_path_grouped = read_csv_files_path(
    csv_files_path_grouped, path_grouped, plant
)

# %% [markdown]
# ### 203

# %%
plants_203 = ["av", "c", "d", "g", "m", "y"]

for plant in plants_203:
    path_grouped = f"/home/peressim/projects/ccs28-ml-modelling/reports/results/local_models/203/{plant}/grouped/"
    path_full = f"/home/peressim/projects/ccs28-ml-modelling/reports/results/local_models/203/{plant}/full/"
    csv_files_path_full = read_csv_files_path(csv_files_path_full, path_full, plant)
    csv_files_path_grouped = read_csv_files_path(
        csv_files_path_grouped, path_grouped, plant
    )

# %% [markdown]
# ### 204

# %%
plants_204 = ["a", "ab", "ae", "aq", "ay", "f", "i", "o", "r", "t"]

for plant in plants_204:
    path_grouped = f"/home/peressim/projects/ccs28-ml-modelling/reports/results/local_models/204/{plant}/grouped/"
    path_full = f"/home/peressim/projects/ccs28-ml-modelling/reports/results/local_models/204/{plant}/full/"
    csv_files_path_full = read_csv_files_path(csv_files_path_full, path_full, plant)
    csv_files_path_grouped = read_csv_files_path(
        csv_files_path_grouped, path_grouped, plant
    )

# %% [markdown]
# ### 206

# %%
plants_206 = ["b"]

for plant in plants_206:
    path_grouped = f"/home/peressim/projects/ccs28-ml-modelling/reports/results/local_models/206/{plant}/grouped/"
    path_full = f"/home/peressim/projects/ccs28-ml-modelling/reports/results/local_models/206/{plant}/full/"
    csv_files_path_full = read_csv_files_path(csv_files_path_full, path_full, plant)
    csv_files_path_grouped = read_csv_files_path(
        csv_files_path_grouped, path_grouped, plant
    )

# %% [markdown]
# ### 207

# %%
plants_207 = ["at"]

for plant in plants_207:
    path_grouped = f"/home/peressim/projects/ccs28-ml-modelling/reports/results/local_models/207/{plant}/grouped/"
    path_full = f"/home/peressim/projects/ccs28-ml-modelling/reports/results/local_models/207/{plant}/full/"
    csv_files_path_full = read_csv_files_path(csv_files_path_full, path_full, plant)
    csv_files_path_grouped = read_csv_files_path(
        csv_files_path_grouped, path_grouped, plant
    )

# %% [markdown]
# ### 209

# %%
plants_209 = [
    "aa",
    "ac",
    "ag",
    "ai",
    "am",
    "an",
    "ap",
    "as",
    "az",
    "e",
    "h",
    "j",
    "k",
    "l",
    "n",
    "p",
    "q",
    "s",
    "u",
    "v",
    "w",
    "x",
    "z",
]

for plant in plants_209:
    path_grouped = f"/home/peressim/projects/ccs28-ml-modelling/reports/results/local_models/209/{plant}/grouped/"
    path_full = f"/home/peressim/projects/ccs28-ml-modelling/reports/results/local_models/209/{plant}/full/"
    csv_files_path_full = read_csv_files_path(csv_files_path_full, path_full, plant)
    csv_files_path_grouped = read_csv_files_path(
        csv_files_path_grouped, path_grouped, plant
    )

# %% [markdown]
# ### Reading all data

# %% [markdown]
# #### Full

# %%
dfs_plant = dict()
column = ("plant", "")
pos = 2

for plant, csv_files in csv_files_path_full.items():
    df = read_csv_files_full(csv_files, plant)
    df["plant"] = plant
    dfs_plant[plant] = df

# %%
df_full = pd.concat(dfs_plant.values(), ignore_index=True)

# %%
df_full.shape
# Out:
# (280876, 23)

# %%
filter_df = df_full[df_full["R2 Test"] < 0].reset_index(drop=True)

filter_df["CP"] = (
    filter_df["Company"].astype(str) + "_" + filter_df["plant"].astype(str)
)

filter_df["CP"].unique()

print(filter_df.shape)
# Out:
# (69676, 24)

# %%
patterns = [
    "Chemical + Mineralogical + Feature Engineering",
    "Chemical + Mineralogical + CS7 + One-Hot",
    "Chemical + Mineralogical + Physical + One-Hot",
    "Chemical + Mineralogical + CS3 + One-Hot",
    "Chemical + Mineralogical + CS3 + CS7 + One-Hot",
    "Chemical + Mineralogical + One-Hot",
    "Chemical + Mineralogical + CS1 + CS3 + CS7 + One-Hot",
    "Chemical + Mineralogical + CS1 + CS3 + One-Hot",
    "Chemical + Mineralogical + CS1 + One-Hot",
    "Chemical + Mineralogical + CS2 + One-Hot",
    "Chemical + Feature Engineering",
]

FEATURES_TO_REPLACE_1 = {
    "Chemical + Mineralogical + CS3 + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS3": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS1": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS1 + CS3": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS1 + CS3 + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS2": "Chemical + Mineralogical + Early CS",
    "Chemical + CS1 + CS3 + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + CS3 + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + CS3": "Chemical + Mineralogical + Early CS",
    "Chemical + CS1 + CS3": "Chemical + Mineralogical + Early CS",
    "Chemical + CS1": "Chemical + Mineralogical + Early CS",
    "Chemical + CS1 + CS7": "Chemical + Mineralogical + Early CS",
}

FEATURES_TO_REPLACE_2 = {
    "Chemical": "Chemical + Mineralogical",
    "Chemical + Properties CS Less": "Chemical + Mineralogical + Physical - Early CS",
    "Chemical + Mineralogical + Properties CS Less": "Chemical + Mineralogical + Physical - Early CS",
    "Chemical + Physical": "Chemical + Mineralogical + Physical",
}

df_full = df_full[~df_full["Features"].apply(lambda x: x in patterns)].reset_index(
    drop=True
)

df_full = df_full[~df_full["Cross Validation"].eq("Out of time Split")].reset_index(
    drop=True
)


df_full["Features_bkp"] = df_full["Features"].copy()
df_full["Features"] = df_full["Features"].replace(FEATURES_TO_REPLACE_1)

df_full["Features"] = df_full["Features"].replace(FEATURES_TO_REPLACE_2)

# %%
df_full["Cross Validation"].unique()
# Out:
# array(['Repeated KFold', 'Blocking Time Series Split',
#        'Time Series Split'], dtype=object)

# %%
df_full["Features"].unique()
# Out:
# array(['Chemical + Mineralogical + Early CS',
#        'Chemical + Mineralogical + Physical',
#        'Chemical + Mineralogical + Physical - Early CS',
#        'Chemical + Mineralogical'], dtype=object)

# %%
df_full["Features_bkp"].unique()
# Out:
# array(['Chemical + Mineralogical + CS3 + CS7',
#        'Chemical + Mineralogical + CS7', 'Chemical + Mineralogical + CS3',
#        'Chemical + Mineralogical + Physical',
#        'Chemical + Mineralogical + Properties CS Less',
#        'Chemical + Mineralogical', 'Chemical + Mineralogical + CS1',
#        'Chemical + Mineralogical + CS1 + CS3',
#        'Chemical + Mineralogical + CS1 + CS3 + CS7',
#        'Chemical + Mineralogical + CS2', 'Chemical + Properties CS Less',
#        'Chemical + CS1 + CS3 + CS7', 'Chemical + CS3 + CS7',
#        'Chemical + CS7', 'Chemical + Physical', 'Chemical + CS3',
#        'Chemical + CS1 + CS3', 'Chemical + CS1', 'Chemical',
#        'Chemical + CS1 + CS7'], dtype=object)

# %%
df_full.shape
# Out:
# (219670, 24)

# %%
df_full[["RMSE Test", "MAE Test", "MAPE Test", "R2 Test"]].describe().round(2).T
# Out:
#               count  mean     std       min   25%   50%   75%     max
# RMSE Test  219670.0  3.78    8.10      0.26  1.63  2.23  3.74  776.07
# MAE Test   219670.0  2.76    4.81      0.20  1.26  1.72  2.86  476.59
# MAPE Test  219670.0  0.06    0.12      0.01  0.03  0.04  0.07   10.22
# R2 Test    219670.0 -8.25  249.52 -68227.01  0.06  0.73  0.90    0.99

# %%
df_full[df_full["R2 Test"] < 0][["Company", "plant"]]["plant"].nunique()
# Out:
# 43

# %%
df_full[df_full["R2 Test"].eq(df_full["R2 Test"].min())]
# Out:
#            Category Company                  Features Data Shape  Timesteps  \
# 132936  Local Model     209  Chemical + Mineralogical  (749, 10)       14.0
#
#        Model  Model Params           Scaler  Scaler Params Imputer  ...  \
# 132936  LSTM           NaN  Standard Scaler            NaN  Median  ...
#
#         MAE Train MAPE Train  R2 Train   RMSE Test    MAE Test  MAPE Test  \
# 132936   0.994235   0.024087 -0.070757  776.071016  476.590659  10.224767
#
#              R2 Test  plant  Plant  Features_bkp
# 132936 -68227.008082     ac     AC      Chemical
#
# [1 rows x 24 columns]

# %%
df_full[(df_full["R2 Test"].eq(df_full["R2 Test"].min()))]["Cross Validation"]
# Out:
# 132936    Time Series Split
# Name: Cross Validation, dtype: object

# %%
filter_df = df_full[df_full["R2 Test"] < 0].reset_index(drop=True)

print(filter_df.shape)
# Out:
# (53009, 24)

# %% [markdown]
# # Topological Example

# %%
import pandas as pd
import numpy as np
from collections import deque, defaultdict

# Sample DataFrame containing the results for each model, including standard deviations
data = {
    'Model': ['Model1', 'Model2', 'Model3', 'Model4'],
    'RMSE_mean': [10, 15, 12, 8],
    'RMSE_std': [1, 2, 1.5, 0.8],
    'MAE_mean': [5, 7, 6, 4],
    'MAE_std': [0.5, 0.7, 0.6, 0.4],
    'MAPE_mean': [3, 4, 3.5, 2.5],
    'MAPE_std': [0.3, 0.4, 0.35, 0.25],
    'R2_mean': [0.9, 0.85, 0.88, 0.92],
    'R2_std': [0.05, 0.07, 0.06, 0.04]
}

df = pd.DataFrame(data)

# Function to compare two models strictly
def strictly_dominates(model1, model2):
    """Return True if model1 strictly dominates model2, False otherwise."""
    return (model1['RMSE_mean'] < model2['RMSE_mean'] and model1['RMSE_std'] < model2['RMSE_std'] and
            model1['MAE_mean'] < model2['MAE_mean'] and model1['MAE_std'] < model2['MAE_std'] and
            model1['MAPE_mean'] < model2['MAPE_mean'] and model1['MAPE_std'] < model2['MAPE_std'] and
            model1['R2_mean'] > model2['R2_mean'] and model1['R2_std'] < model2['R2_std'])

# Create the dominance matrix
n = len(df)
dominance_matrix = np.zeros((n, n), dtype=bool)

for i in range(n):
    for j in range(n):
        if i != j:
            dominance_matrix[i, j] = strictly_dominates(df.iloc[i], df.iloc[j])

# Create the dominance graph
dominance_graph = {i: [] for i in range(n)}
for i in range(n):
    for j in range(n):
        if dominance_matrix[i, j]:
            dominance_graph[i].append(j)

# Topological Sorting
def topological_sort(graph):
    """Perform topological sorting on the given graph."""
    in_degree = {u: 0 for u in graph}
    for u in graph:
        for v in graph[u]:
            in_degree[v] += 1
    
    queue = deque([u for u in graph if in_degree[u] == 0])
    topo_order = []
    
    while queue:
        u = queue.popleft()
        topo_order.append(u)
        
        for v in graph[u]:
            in_degree[v] -= 1
            if in_degree[v] == 0:
                queue.append(v)
    
    return topo_order

# Get the topological order
topo_order = topological_sort(dominance_graph)

# Categorize models based on dominance
dominates_any = np.any(dominance_matrix, axis=1)
dominated_by_any = np.any(dominance_matrix, axis=0)

dominating_models = [df['Model'].iloc[i] for i in range(n) if dominates_any[i] and not dominated_by_any[i]]
non_dominated_models = [df['Model'].iloc[i] for i in range(n) if not dominates_any[i] and not dominated_by_any[i]]
failing_models = [df['Model'].iloc[i] for i in range(n) if dominated_by_any[i]]

print("Dominating Models:", dominating_models)
print("Non-Dominated Models:", non_dominated_models)
print("Failing Models:", failing_models)

# Map the topological order to the model names
sorted_models = [df['Model'].iloc[i] for i in topo_order]
print("Models in order of dominance:", sorted_models)

# Visualization of the dominance graph
import networkx as nx
import matplotlib.pyplot as plt

G = nx.DiGraph(dominance_graph)
labels = {i: df['Model'].iloc[i] for i in range(n)}
pos = nx.spring_layout(G)
nx.draw(G, pos, labels=labels, with_labels=True, node_size=3000, node_color="skyblue", font_size=12, font_color="black", font_weight="bold", arrows=True)
plt.title("Dominance Graph")
plt.show()
# Out:
# Dominating Models: ['Model4']
# Non-Dominated Models: []
# Failing Models: ['Model1', 'Model2', 'Model3']
# Models in order of dominance: ['Model4', 'Model1', 'Model3', 'Model2']

# %%
# Count how many models each model dominates and is dominated by
dominates_count = np.sum(dominance_matrix, axis=1)
dominated_count = np.sum(dominance_matrix, axis=0)

# Add these counts to the DataFrame
df['Dominates_Count'] = dominates_count
df['Dominated_Count'] = dominated_count

# Models that dominate others but are not dominated
df['Dominates_Others'] = df['Dominates_Count'] > 0
df['Not_Dominated'] = df['Dominated_Count'] == 0

# Summary statistics
dominance_summary = {
    'Total Models': len(df),
    'Dominating Models': df['Dominates_Others'].sum(),
    'Non-Dominated Models': df['Not_Dominated'].sum(),
    'Failing Models': df['Dominated_Count'].sum()
}

print(dominance_summary)
# Out:
# {'Total Models': 4, 'Dominating Models': 3, 'Non-Dominated Models': 1, 'Failing Models': 6}

# %%
import seaborn as sns

# Plotting dominance count
sns.barplot(x=df['Model'], y=df['Dominates_Count'])
plt.title("Number of Models Dominated by Each Model")
plt.ylabel("Dominates Count")
plt.xlabel("Model")
plt.xticks(rotation=45)
plt.show()

sns.barplot(x=df['Model'], y=df['Dominated_Count'])
plt.title("Number of Models Dominating Each Model")
plt.ylabel("Dominated Count")
plt.xlabel("Model")
plt.xticks(rotation=45)
plt.show()

# %%
import pandas as pd

# Sample DataFrame containing the results for each model
data = {
    'Model': ['Model1', 'Model2', 'Model3', 'Model4'],
    'RMSE': [10, 15, 12, 8],
    'MAE': [5, 7, 6, 4],
    'MAPE': [3, 4, 3.5, 2.5],
    'R2': [0.9, 0.85, 0.88, 0.92]
}

df = pd.DataFrame(data)

# %%
df
# Out:
#     Model  RMSE  MAE  MAPE    R2
# 0  Model1    10    5   3.0  0.90
# 1  Model2    15    7   4.0  0.85
# 2  Model3    12    6   3.5  0.88
# 3  Model4     8    4   2.5  0.92

# %%
def dominates(model1, model2):
    """Return True if model1 dominates model2, False otherwise."""
    return (
        model1["RMSE"] <= model2["RMSE"]
        and model1["MAE"] <= model2["MAE"]
        and model1["MAPE"] <= model2["MAPE"]
        and model1["R2"] >= model2["R2"]
    )

# %%
import numpy as np

n = len(df)
dominance_matrix = np.zeros((n, n), dtype=bool)

for i in range(n):
    for j in range(n):
        if i != j:
            dominance_matrix[i, j] = dominates(df.iloc[i], df.iloc[j])

dominance_graph = {i: [] for i in range(n)}
for i in range(n):
    for j in range(n):
        if dominance_matrix[i, j]:
            dominance_graph[i].append(j)

# %%
dominance_matrix
# Out:
# array([[False,  True,  True, False],
#        [False, False, False, False],
#        [False,  True, False, False],
#        [ True,  True,  True, False]])

# %%
dominance_graph
# Out:
# {0: [1, 2], 1: [], 2: [1], 3: [0, 1, 2]}

# %%
from collections import deque

def topological_sort(graph):
    """Perform topological sorting on the given graph."""
    in_degree = {u: 0 for u in graph}
    for u in graph:
        for v in graph[u]:
            in_degree[v] += 1
    
    queue = deque([u for u in graph if in_degree[u] == 0])
    topo_order = []
    
    while queue:
        u = queue.popleft()
        topo_order.append(u)
        
        for v in graph[u]:
            in_degree[v] -= 1
            if in_degree[v] == 0:
                queue.append(v)
    
    return topo_order

topo_order = topological_sort(dominance_graph)

# Map the topological order to the model names
sorted_models = [df['Model'].iloc[i] for i in topo_order]
print("Models in order of dominance:", sorted_models)
# Out:
# Models in order of dominance: ['Model4', 'Model1', 'Model3', 'Model2']

# %%
import networkx as nx
import matplotlib.pyplot as plt

G = nx.DiGraph(dominance_graph)
labels = {i: df['Model'].iloc[i] for i in range(n)}
nx.draw(G, labels=labels, with_labels=True, node_size=1000, node_color="skyblue", font_size=12, font_color="black", font_weight="bold", arrows=True)
plt.show()

# %% [markdown]
# # Example for thesis

# %%
# Function to compare two models strictly based on means only
def strictly_dominates(model1, model2):
    """Return True if model1 strictly dominates model2, False otherwise."""
    # Check if model1 is at least as good as model2 in all metrics
    at_least_as_good = (
        model1["RMSE_mean"] <= model2["RMSE_mean"]
        and model1["MAE_mean"] <= model2["MAE_mean"]
        and model1["MAPE_mean"] <= model2["MAPE_mean"]
        and model1["R2_mean"] >= model2["R2_mean"]
    )

    # Check if model1 is strictly better in at least one metric
    strictly_better_in_one = (
        model1["RMSE_mean"] < model2["RMSE_mean"]
        or model1["MAE_mean"] < model2["MAE_mean"]
        or model1["MAPE_mean"] < model2["MAPE_mean"]
        or model1["R2_mean"] > model2["R2_mean"]
    )

    # Model1 strictly dominates Model2 if it is at least as good in all metrics and
    # strictly better in at least one metric
    return at_least_as_good and strictly_better_in_one

# %%
import pandas as pd
import numpy as np
from collections import deque, defaultdict

# Sample DataFrame containing the results for each model, including standard deviations
data = {
    'Model': ['Model1', 'Model2', 'Model3', 'Model4'],
    'RMSE_mean': [1.5, 2.0, 2.5, 2.1],
    'RMSE_std': [0.2, 0.25, 0.3, 0.25],
    'MAE_mean': [1.0, 1.5, 2.0, 1.4],
    'MAE_std': [0.1, 0.15, 0.2, 0.12],
    'MAPE_mean': [3.0, 4.0, 5.0, 2.8],
    'MAPE_std': [0.5, 0.6, 0.7, 0.4],
    'R2_mean': [0.9, 0.85, 0.8, 0.75],
    'R2_std': [0.05, 0.06, 0.07, 0.08]
}


df = pd.DataFrame(data)

# Function to compare two models strictly
# def strictly_dominates(model1, model2):
#     """Return True if model1 strictly dominates model2, False otherwise."""
#     return (model1['RMSE_mean'] < model2['RMSE_mean'] and
#             model1['MAE_mean'] < model2['MAE_mean'] and
#             model1['MAPE_mean'] < model2['MAPE_mean'] and
#             model1['R2_mean'] > model2['R2_mean'])

# Function to compare two models strictly based on means only
def strictly_dominates(model1, model2):
    """Return True if model1 strictly dominates model2, False otherwise."""
    # Check if model1 is at least as good as model2 in all metrics
    at_least_as_good = (model1['RMSE_mean'] <= model2['RMSE_mean'] and
                        model1['MAE_mean'] <= model2['MAE_mean'] and
                        model1['MAPE_mean'] <= model2['MAPE_mean'] and
                        model1['R2_mean'] >= model2['R2_mean'])
    
    # Check if model1 is strictly better in at least one metric
    strictly_better_in_one = (model1['RMSE_mean'] < model2['RMSE_mean'] or
                              model1['MAE_mean'] < model2['MAE_mean'] or
                              model1['MAPE_mean'] < model2['MAPE_mean'] or
                              model1['R2_mean'] > model2['R2_mean'])
    
    # Model1 strictly dominates Model2 if it is at least as good in all metrics and
    # strictly better in at least one metric
    return at_least_as_good and strictly_better_in_one


# Create the dominance matrix
n = len(df)
dominance_matrix = np.zeros((n, n), dtype=bool)

for i in range(n):
    for j in range(n):
        if i != j:
            dominance_matrix[i, j] = strictly_dominates(df.iloc[i], df.iloc[j])

# Create the dominance graph
dominance_graph = {i: [] for i in range(n)}
for i in range(n):
    for j in range(n):
        if dominance_matrix[i, j]:
            dominance_graph[i].append(j)

# Topological Sorting
def topological_sort(graph):
    """Perform topological sorting on the given graph."""
    in_degree = {u: 0 for u in graph}
    for u in graph:
        for v in graph[u]:
            in_degree[v] += 1
    
    queue = deque([u for u in graph if in_degree[u] == 0])
    topo_order = []
    
    while queue:
        u = queue.popleft()
        topo_order.append(u)
        
        for v in graph[u]:
            in_degree[v] -= 1
            if in_degree[v] == 0:
                queue.append(v)
    
    return topo_order

# Get the topological order
topo_order = topological_sort(dominance_graph)

# Categorize models based on dominance
dominates_any = np.any(dominance_matrix, axis=1)
dominated_by_any = np.any(dominance_matrix, axis=0)

dominating_models = [df['Model'].iloc[i] for i in range(n) if dominates_any[i] and not dominated_by_any[i]]
non_dominated_models = [df['Model'].iloc[i] for i in range(n) if not dominates_any[i] and not dominated_by_any[i]]
failing_models = [df['Model'].iloc[i] for i in range(n) if dominated_by_any[i]]

print("Dominating Models:", dominating_models)
print("Non-Dominated Models:", non_dominated_models)
print("Failing Models:", failing_models)

# Map the topological order to the model names
sorted_models = [df['Model'].iloc[i] for i in topo_order]
print("Models in order of dominance:", sorted_models)

# Visualization of the dominance graph
import networkx as nx
import matplotlib.pyplot as plt

G = nx.DiGraph(dominance_graph)
labels = {i: df['Model'].iloc[i] for i in range(n)}
pos = nx.spring_layout(G, seed=48, k=1.5)
#pos = nx.kamada_kawai_layout(G)

pos[3] = np.mean([pos[0], pos[1]], axis=1) + np.array([-0.4, 0.6])

nx.draw(G, pos, labels=labels, with_labels=True, node_size=2100, node_color="skyblue", font_size=10, font_color="black", font_weight="bold", arrows=True)
plt.title("Dominance Graph")
plt.show()
# Out:
# Dominating Models: ['Model1']
# Non-Dominated Models: ['Model4']
# Failing Models: ['Model2', 'Model3']
# Models in order of dominance: ['Model1', 'Model4', 'Model2', 'Model3']

# %%
import pandas as pd
import numpy as np
from collections import deque, defaultdict
import networkx as nx
import matplotlib.pyplot as plt

# Sample DataFrame containing the results for each model, including standard deviations
data = {
    #'Model': ['Model A', 'Model B', 'Model C', 'Model D'],
    'Model': ['A', 'B', 'C', 'D'],
    'RMSE_mean': [1.5, 2.0, 2.5, 2.1],
    'RMSE_std': [0.2, 0.25, 0.3, 0.25],
    'MAE_mean': [1.0, 1.5, 2.0, 1.4],
    'MAE_std': [0.1, 0.15, 0.2, 0.12],
    'MAPE_mean': [3.0, 4.0, 5.0, 2.8],
    'MAPE_std': [0.5, 0.6, 0.7, 0.4],
    'R2_mean': [0.9, 0.85, 0.8, 0.75],
    'R2_std': [0.05, 0.06, 0.07, 0.08]
}

df = pd.DataFrame(data)

# # Function to compare two models strictly
# def strictly_dominates(model1, model2):
#     """Return True if model1 strictly dominates model2, False otherwise."""
#     return (model1['RMSE_mean'] < model2['RMSE_mean'] and
#             model1['MAE_mean'] < model2['MAE_mean'] and
#             model1['MAPE_mean'] < model2['MAPE_mean'] and
#             model1['R2_mean'] > model2['R2_mean'])

# Create the dominance matrix
n = len(df)
dominance_matrix = np.zeros((n, n), dtype=bool)

for i in range(n):
    for j in range(n):
        if i != j:
            dominance_matrix[i, j] = strictly_dominates(df.iloc[i], df.iloc[j])

# Create the dominance graph
dominance_graph = {i: [] for i in range(n)}
for i in range(n):
    for j in range(n):
        if dominance_matrix[i, j]:
            dominance_graph[i].append(j)

# Create the NetworkX graph
G = nx.DiGraph(dominance_graph)

# Apply transitive reduction
G_reduced = nx.transitive_reduction(G)

# Topological Sorting
def topological_sort(graph):
    """Perform topological sorting on the given graph."""
    in_degree = {u: 0 for u in graph}
    for u in graph:
        for v in graph[u]:
            in_degree[v] += 1
    
    queue = deque([u for u in graph if in_degree[u] == 0])
    topo_order = []
    
    while queue:
        u = queue.popleft()
        topo_order.append(u)
        
        for v in graph[u]:
            in_degree[v] -= 1
            if in_degree[v] == 0:
                queue.append(v)
    
    return topo_order

# Get the topological order
topo_order = topological_sort(dominance_graph)

# Categorize models based on dominance
dominates_any = np.any(dominance_matrix, axis=1)
dominated_by_any = np.any(dominance_matrix, axis=0)

dominant_models = [df['Model'].iloc[i] for i in range(n) if dominates_any[i] and not dominated_by_any[i]]
non_dominated_models = [df['Model'].iloc[i] for i in range(n) if not dominates_any[i] and not dominated_by_any[i]]
failing_models = [df['Model'].iloc[i] for i in range(n) if dominated_by_any[i]]

print("Dominating Models:", dominant_models)
print("Non-Dominated Models:", non_dominated_models)
print("Failing Models:", failing_models)

# Map the topological order to the model names
sorted_models = [df['Model'].iloc[i] for i in topo_order]
print("Models in order of dominance:", sorted_models)

# Visualization of the reduced dominance graph
labels = {i: df['Model'].iloc[i] for i in range(n)}
pos = nx.spring_layout(G_reduced, seed=48, k=1.5)
# pos = nx.kamada_kawai_layout(G)

pos[3] = np.mean([pos[0], pos[1]], axis=1) + np.array([-0.3, 0.7])
# pos[1] = pos[0] + 0.02
# pos[2] = pos[1] + 0.05


#pos[1] = pos[1] + np.array([0.0, 0.2])
# pos[2] = pos[2] + np.array([0.01, 0.2])
# pos[2] = np.mean([pos[2], pos[0]], axis=1)
# pos[0] = pos[2] - pos[0]

fig, axes = plt.subplots(1, 1, figsize=(6.5, 5), sharex=False)  # 1 row, 2 columns
nx.draw(G_reduced, pos, ax=axes, labels=labels, with_labels=True, node_size=2100, node_color="skyblue", font_size=10, font_color="black", font_weight="bold", arrows=True)

# pos[3] = np.mean([pos[0], pos[1]], axis=1) + np.array([-0.3, 0.7])
#nx.draw(G_reduced, pos, labels=labels, with_labels=True, node_size=2100, node_color="skyblue", font_size=10, font_color="black", font_weight="bold", arrows=True)

#plt.title("Reduced Dominance Graph")
plt.title("Dominance Graph")
plt.show()
# Out:
# Dominating Models: ['A']
# Non-Dominated Models: ['D']
# Failing Models: ['B', 'C']
# Models in order of dominance: ['A', 'D', 'B', 'C']

# %%
data = {
    #'Model': ['Model A', 'Model B', 'Model C', 'Model D'],
    "Model": ["A", "B", "C", "D"],
    "RMSE_mean": [1.5, 2.0, 2.5, 2.1],
    "RMSE_std": [0.2, 0.25, 0.3, 0.25],
    "MAE_mean": [1.0, 1.5, 2.0, 1.4],
    "MAE_std": [0.1, 0.15, 0.2, 0.12],
    "MAPE_mean": [3.0, 4.0, 5.0, 2.8],
    "MAPE_std": [0.5, 0.6, 0.7, 0.4],
    "R2_mean": [0.9, 0.85, 0.8, 0.75],
    "R2_std": [0.05, 0.06, 0.07, 0.08],
}

df = pd.DataFrame(data)

# %%
df[["Model", "RMSE_mean", "MAE_mean", "MAPE_mean", "R2_mean"]]

# df = df.set_index("Model")

df
# Out:
#   Model  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  MAPE_std  R2_mean  \
# 0     A        1.5      0.20       1.0     0.10        3.0       0.5     0.90
# 1     B        2.0      0.25       1.5     0.15        4.0       0.6     0.85
# 2     C        2.5      0.30       2.0     0.20        5.0       0.7     0.80
# 3     D        2.1      0.25       1.4     0.12        2.8       0.4     0.75
#
#    R2_std
# 0    0.05
# 1    0.06
# 2    0.07
# 3    0.08

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
standardized_metrics = scaler.fit_transform(
    df[["RMSE_mean", "MAE_mean", "MAPE_mean", "R2_mean"]]
)

# Creating a new dataframe with standardized values
standardized_df = pd.DataFrame(
    standardized_metrics,
    columns=["RMSE_mean", "MAE_mean", "MAPE_mean", "R2_mean"],
)

# Summing all metrics and subtracting R2_mean
standardized_df["Result"] = (
    standardized_df[["RMSE_mean", "MAE_mean", "MAPE_mean"]].sum(axis=1)
    - standardized_df["R2_mean"]
)

# %%
standardized_df["Model"] = df["Model"]
standardized_df
# Out:
#    RMSE_mean  MAE_mean  MAPE_mean   R2_mean    Result Model
# 0  -1.473911 -1.333539  -0.797724  1.341641 -4.946814     A
# 1  -0.070186  0.070186   0.341882  0.447214 -0.105332     B
# 2   1.333539  1.473911   1.481487 -0.447214  4.736151     C
# 3   0.210559 -0.210559  -1.025645 -1.341641  0.315996     D

# %%
import pandas as pd
import numpy as np
from collections import deque, defaultdict
import networkx as nx
import matplotlib.pyplot as plt

df = standardized_df
# Function to compare two models strictly
def strictly_dominates(model1, model2):
    """Return True if model1 strictly dominates model2, False otherwise."""
    return model1['Result'] < model2['Result']

# Create the dominance matrix
n = len(df)
dominance_matrix = np.zeros((n, n), dtype=bool)

for i in range(n):
    for j in range(n):
        if i != j:
            dominance_matrix[i, j] = strictly_dominates(df.iloc[i], df.iloc[j])

# Create the dominance graph
dominance_graph = {i: [] for i in range(n)}
for i in range(n):
    for j in range(n):
        if dominance_matrix[i, j]:
            dominance_graph[i].append(j)

# Create the NetworkX graph
G = nx.DiGraph(dominance_graph)

# Apply transitive reduction
G_reduced = nx.transitive_reduction(G)

# Topological Sorting
def topological_sort(graph):
    """Perform topological sorting on the given graph."""
    in_degree = {u: 0 for u in graph}
    for u in graph:
        for v in graph[u]:
            in_degree[v] += 1
    
    queue = deque([u for u in graph if in_degree[u] == 0])
    topo_order = []
    
    while queue:
        u = queue.popleft()
        topo_order.append(u)
        
        for v in graph[u]:
            in_degree[v] -= 1
            if in_degree[v] == 0:
                queue.append(v)
    
    return topo_order

# Get the topological order
topo_order = topological_sort(dominance_graph)

# Categorize models based on dominance
dominates_any = np.any(dominance_matrix, axis=1)
dominated_by_any = np.any(dominance_matrix, axis=0)

dominant_models = [df['Model'].iloc[i] for i in range(n) if dominates_any[i] and not dominated_by_any[i]]
non_dominated_models = [df['Model'].iloc[i] for i in range(n) if not dominates_any[i] and not dominated_by_any[i]]
failing_models = [df['Model'].iloc[i] for i in range(n) if dominated_by_any[i]]

print("Dominating Models:", dominant_models)
print("Non-Dominated Models:", non_dominated_models)
print("Failing Models:", failing_models)

# Map the topological order to the model names
sorted_models = [df['Model'].iloc[i] for i in topo_order]
print("Models in order of dominance:", sorted_models)

# Visualization of the reduced dominance graph
labels = {i: df['Model'].iloc[i] for i in range(n)}
pos = nx.spring_layout(G_reduced, seed=48, k=1.5)
# pos = nx.kamada_kawai_layout(G)

# pos[3] = np.mean([pos[0], pos[1]], axis=1) + np.array([-0.3, 0.7])
# pos[1] = pos[0] + 0.02
# pos[2] = pos[1] + 0.05


#pos[1] = pos[1] + np.array([0.0, 0.2])
# pos[2] = pos[2] + np.array([0.01, 0.2])
# pos[2] = np.mean([pos[2], pos[0]], axis=1)
# pos[0] = pos[2] - pos[0]

fig, axes = plt.subplots(1, 1, figsize=(6.5, 5), sharex=False)  # 1 row, 2 columns
nx.draw(G_reduced, pos, ax=axes, labels=labels, with_labels=True, node_size=2100, node_color="skyblue", font_size=10, font_color="black", font_weight="bold", arrows=True)

# pos[3] = np.mean([pos[0], pos[1]], axis=1) + np.array([-0.3, 0.7])
#nx.draw(G_reduced, pos, labels=labels, with_labels=True, node_size=2100, node_color="skyblue", font_size=10, font_color="black", font_weight="bold", arrows=True)

#plt.title("Reduced Dominance Graph")
plt.title("Dominance Graph")
plt.show()
# Out:
# Dominating Models: ['A']
# Non-Dominated Models: []
# Failing Models: ['B', 'C', 'D']
# Models in order of dominance: ['A', 'B', 'D', 'C']

# %%
dominance_matrix
# Out:
# array([[False,  True,  True,  True],
#        [False, False,  True,  True],
#        [False, False, False, False],
#        [False, False,  True, False]])

# %%
# import pandas as pd
# import numpy as np
# from collections import deque, defaultdict
# import networkx as nx
# import matplotlib.pyplot as plt

# # Sample DataFrame containing the results for each model, including standard deviations
# data = {
#     'Model': ['Model1', 'Model2', 'Model3', 'Model4'],
#     'RMSE_mean': [1.5, 2.0, 2.5, 2.1],
#     'RMSE_std': [0.2, 0.25, 0.3, 0.25],
#     'MAE_mean': [1.0, 1.5, 2.0, 1.4],
#     'MAE_std': [0.1, 0.15, 0.2, 0.12],
#     'MAPE_mean': [3.0, 4.0, 5.0, 2.8],
#     'MAPE_std': [0.5, 0.6, 0.7, 0.4],
#     'R2_mean': [0.9, 0.85, 0.8, 0.75],
#     'R2_std': [0.05, 0.06, 0.07, 0.08]
# }

# df = pd.DataFrame(data)

# # Function to compare two models strictly
# def strictly_dominates(model1, model2):
#     """Return True if model1 strictly dominates model2, False otherwise."""
#     return (model1['RMSE_mean'] < model2['RMSE_mean'] and
#             model1['MAE_mean'] < model2['MAE_mean'] and
#             model1['MAPE_mean'] < model2['MAPE_mean'] and
#             model1['R2_mean'] > model2['R2_mean'])

# # Create the dominance matrix
# n = len(df)
# dominance_matrix = np.zeros((n, n), dtype=bool)

# for i in range(n):
#     for j in range(n):
#         if i != j:
#             dominance_matrix[i, j] = strictly_dominates(df.iloc[i], df.iloc[j])

# # Create the dominance graph
# dominance_graph = {i: [] for i in range(n)}
# for i in range(n):
#     for j in range(n):
#         if dominance_matrix[i, j]:
#             dominance_graph[i].append(j)

# # Create the NetworkX graph
# G = nx.DiGraph(dominance_graph)

# # Apply transitive reduction
# G_reduced = nx.transitive_reduction(G)

# # Topological Sorting
# def topological_sort(graph):
#     """Perform topological sorting on the given graph."""
#     in_degree = {u: 0 for u in graph}
#     for u in graph:
#         for v in graph[u]:
#             in_degree[v] += 1
    
#     queue = deque([u for u in graph if in_degree[u] == 0])
#     topo_order = []
    
#     while queue:
#         u = queue.popleft()
#         topo_order.append(u)
        
#         for v in graph[u]:
#             in_degree[v] -= 1
#             if in_degree[v] == 0:
#                 queue.append(v)
    
#     return topo_order

# # Get the topological order
# topo_order = topological_sort(dominance_graph)

# # Categorize models based on dominance
# dominates_any = np.any(dominance_matrix, axis=1)
# dominated_by_any = np.any(dominance_matrix, axis=0)

# dominant_models = [df['Model'].iloc[i] for i in range(n) if not dominated_by_any[i]]
# non_dominated_models = [df['Model'].iloc[i] for i in range(n) if not dominates_any[i] and not dominated_by_any[i]]
# failing_models = [df['Model'].iloc[i] for i in range(n) if dominated_by_any[i] and not dominates_any[i]]

# print("Dominant Models:", dominant_models)
# print("Non-Dominated Models:", non_dominated_models)
# print("Failing Models:", failing_models)

# # Map the topological order to the model names
# sorted_models = [df['Model'].iloc[i] for i in topo_order]
# print("Models in order of dominance:", sorted_models)

# # Visualization of the reduced dominance graph
# labels = {i: df['Model'].iloc[i] for i in range(n)}
# pos = nx.spring_layout(G_reduced, seed=48, k=1.5)

# pos[3] = np.mean([pos[0], pos[1]], axis=1) + np.array([-0.3, 0.7])

# nx.draw(G_reduced, pos, labels=labels, with_labels=True, node_size=2100, node_color="skyblue", font_size=10, font_color="black", font_weight="bold", arrows=True)
# plt.title("Dominance Graph")
# plt.show()

# %%
df_full.shape
# Out:
# (219670, 24)

# %%
df_full["plant"].unique()
# Out:
# array(['partner_i', 'partner_ii', 'partner_iv', 'av', 'c', 'd', 'g', 'm', 'y', 'a', 'ab',
#        'ae', 'aq', 'ay', 'f', 'i', 'o', 'r', 't', 'b', 'at', 'aa', 'ac',
#        'ag', 'ai', 'am', 'an', 'ap', 'as', 'az', 'e', 'h', 'j', 'k', 'l',
#        'n', 'p', 'q', 's', 'u', 'v', 'w', 'x', 'z'], dtype=object)

# %%
df_full_inn = df_full[df_full["plant"].isin(["partner_i", "partner_ii", "partner_iv"])].reset_index(
    drop=True
)
df_full_ecics = df_full[~df_full["plant"].isin(["partner_i", "partner_ii", "partner_iv"])].reset_index(
    drop=True
)

# %%
df_full.shape
# Out:
# (219670, 24)

# %%
df_full_inn.shape
# Out:
# (15325, 24)

# %%
df_full_ecics.shape
# Out:
# (204345, 24)

# %%
df_full_inn[["RMSE Test", "MAE Test", "MAPE Test", "R2 Test"]].describe().round(2).T
# Out:
#              count  mean    std     min   25%   50%   75%    max
# RMSE Test  15325.0  4.31   3.64    0.85  1.96  3.00  5.34  51.08
# MAE Test   15325.0  3.41   2.98    0.68  1.54  2.33  4.24  49.82
# MAPE Test  15325.0  0.08   0.07    0.02  0.04  0.05  0.10   1.08
# R2 Test    15325.0 -2.39  14.85 -500.62 -0.84  0.49  0.77   0.97

# %%
df_full_ecics[["RMSE Test", "MAE Test", "MAPE Test", "R2 Test"]].describe().round(2).T
# Out:
#               count  mean     std       min   25%   50%   75%     max
# RMSE Test  204345.0  3.74    8.34      0.26  1.61  2.19  3.64  776.07
# MAE Test   204345.0  2.71    4.92      0.20  1.25  1.69  2.77  476.59
# MAPE Test  204345.0  0.06    0.12      0.01  0.03  0.04  0.06   10.22
# R2 Test    204345.0 -8.68  258.67 -68227.01  0.12  0.74  0.91    0.99

# %% [markdown]
# # Analysis (full results)

# %%
df_full_inn = df_full[df_full["plant"].isin(["partner_i", "partner_ii", "partner_iv"])].reset_index(
    drop=True
)
df_full_ecics = df_full[~df_full["plant"].isin(["partner_i", "partner_ii", "partner_iv"])].reset_index(
    drop=True
)

# %% [markdown]
# ## INN

# %%
df_full_inn.shape
# Out:
# (15325, 24)

# %%
df_full_inn["Company"].unique()
# Out:
# array(['partner_i', 'partner_ii', 'partner_iv'], dtype=object)

# %% [markdown]
# ### Variable Grouping: CM

# %%
df_full_inn["Features"].unique()
# Out:
# array(['Chemical + Mineralogical + Early CS',
#        'Chemical + Mineralogical + Physical',
#        'Chemical + Mineralogical + Physical - Early CS',
#        'Chemical + Mineralogical'], dtype=object)

# %%
df_results_full_cm = (
    df_full_inn[df_full_inn["Features"].eq("Chemical + Mineralogical")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_full_cm["Features"].unique()
# Out:
# array(['Chemical + Mineralogical'], dtype=object)

# %%
df_results_full_cm.shape
# Out:
# (2385, 24)

# %% [markdown]
# #### K-Fold

# %%
df_results_full_cm["Cross Validation"].unique()
# Out:
# array(['Repeated KFold', 'Blocking Time Series Split',
#        'Time Series Split'], dtype=object)

# %%
df_results_full_cm_kf = (
    df_results_full_cm[df_results_full_cm["Cross Validation"].eq("Repeated KFold")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_full_cm_kf["Cross Validation"].unique()
# Out:
# array(['Repeated KFold'], dtype=object)

# %%
df_results_full_cm_kf.shape
# Out:
# (900, 24)

# %%
df_results_full_cm_kf.groupby(["Company", "Model", "Timesteps"], dropna=False)[
    "RMSE Test"
].mean().shape
# Out:
# (60,)

# %% [markdown]
# #### BTSS

# %%
df_results_full_cm["Cross Validation"].unique()
# Out:
# array(['Repeated KFold', 'Blocking Time Series Split',
#        'Time Series Split'], dtype=object)

# %%
df_results_full_cm_btss = (
    df_results_full_cm[
        df_results_full_cm["Cross Validation"].eq("Blocking Time Series Split")
    ]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_full_cm_btss["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split'], dtype=object)

# %%
df_results_full_cm_btss.shape
# Out:
# (705, 24)

# %%
df_results_full_cm_btss.groupby(["Company", "Model", "Timesteps"], dropna=False)[
    "RMSE Test"
].mean().shape
# Out:
# (55,)

# %%
# df_results_full_cm_kf

# %% [markdown]
# # Grouped Dataset

# %%
dfs_plant = dict()
column = ("plant", "")
pos = 2

for plant, csv_files in csv_files_path_grouped.items():
    df = read_csv_files_grouped(csv_files, plant)
    df["plant"] = plant
    df = preprocess_rename_columns(df)
    df = preprocess_change_columns_order(df, column, pos)
    dfs_plant[plant] = df

# %%
df = pd.concat(dfs_plant)
df_copy = df.copy()
df_copy = (
    df_copy.reset_index(level=0)
    .rename({"level_0": "Plant"}, axis=1)
    .reset_index(drop=True)
)

# %%
df_copy.shape
# Out:
# (26063, 26)

# %%
filter_df = df_copy[df_copy["Company"].isin(["partner_i", "partner_ii", "partner_iv"])]

# %%
# filter_df[("MAPE Test", "mean")].plot(kind="hist")

# %%
filter_df[["RMSE Test", "MAE Test", "MAPE Test", "R2 Test"]].describe().T
# Out:
#                  count      mean        std         min       25%       50%  \
# RMSE Test mean  2988.0  3.936802   2.629864    0.906304  2.176814  3.292064
#           std   2988.0  1.335608   1.807978    0.000000  0.159884  0.451459
# MAE Test  mean  2988.0  3.055642   1.919555    0.708813  1.662497  2.550537
#           std   2988.0  1.010559   1.378716    0.000000  0.114215  0.338375
# MAPE Test mean  2988.0  0.070164   0.043779    0.016380  0.039206  0.058431
#           std   2988.0  0.023317   0.031710    0.000000  0.002688  0.008326
# R2 Test   mean  2988.0 -2.014462  13.004017 -526.750990 -0.915806  0.332616
#           std   2988.0  3.244529  14.427714    0.000000  0.039575  0.198876
#
#                      75%         max
# RMSE Test mean  5.033506   50.349352
#           std   2.072176   34.573759
# MAE Test  mean  3.922136   21.774882
#           std   1.505030   12.915692
# MAPE Test mean  0.089626    0.463917
#           std   0.034544    0.276922
# ...

# %% [markdown]
# ## Preprocessing steps

# %%
patterns = [
    "Chemical + Mineralogical + Feature Engineering",
    "Chemical + Mineralogical + CS7 + One-Hot",
    "Chemical + Mineralogical + Physical + One-Hot",
    "Chemical + Mineralogical + CS3 + One-Hot",
    "Chemical + Mineralogical + CS3 + CS7 + One-Hot",
    "Chemical + Mineralogical + One-Hot",
    "Chemical + Mineralogical + CS1 + CS3 + CS7 + One-Hot",
    "Chemical + Mineralogical + CS1 + CS3 + One-Hot",
    "Chemical + Mineralogical + CS1 + One-Hot",
    "Chemical + Mineralogical + CS2 + One-Hot",
    "Chemical + Feature Engineering",
]

replace_dict = {
    "Chemical + Mineralogical + CS3 + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS3": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS1": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS1 + CS3": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS1 + CS3 + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + Mineralogical + CS2": "Chemical + Mineralogical + Early CS",
    "Chemical + CS1 + CS3 + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + CS3 + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + CS7": "Chemical + Mineralogical + Early CS",
    "Chemical + CS3": "Chemical + Mineralogical + Early CS",
    "Chemical + CS1 + CS3": "Chemical + Mineralogical + Early CS",
    "Chemical + CS1": "Chemical + Mineralogical + Early CS",
    "Chemical + CS1 + CS7": "Chemical + Mineralogical + Early CS",
}

replace_dict_2 = {
    "Chemical": "Chemical + Mineralogical",
    "Chemical + Properties CS Less": "Chemical + Mineralogical + Physical - Early CS",
    "Chemical + Mineralogical + Properties CS Less": "Chemical + Mineralogical + Physical - Early CS",
    "Chemical + Physical": "Chemical + Mineralogical + Physical",
}

df_copy = df_copy[~df_copy["Cross Validation"].eq("Out of time Split")].reset_index(
    drop=True
)

df_copy = df_copy[~df_copy["Features"].apply(lambda x: x in patterns)].reset_index(
    drop=True
)
df_copy["Features_bkp"] = df_copy["Features"].copy()
df_copy["Features"] = df_copy["Features"].replace(replace_dict)

df_copy["Features"] = df_copy["Features"].replace(replace_dict_2)

# %%
df_copy[("MAPE Train", "mean")] = df_copy[("MAPE Train", "mean")] * 100
df_copy[("MAPE Train", "std")] = df_copy[("MAPE Train", "std")] * 100
df_copy[("MAPE Test", "mean")] = df_copy[("MAPE Test", "mean")] * 100
df_copy[("MAPE Test", "std")] = df_copy[("MAPE Test", "std")] * 100

df_copy["Model_bkp"] = df_copy["Model"].copy()
df_copy["Model_bkp_2"] = df_copy["Model"] + df_copy["Timesteps"].apply(
    lambda x: "" if pd.isna(x) else "_" + str(x)
)
df_copy["Model"] = df_copy["Model"].replace(
    {
        "MLP": "Neural Networks",
        "LSTM": "Neural Networks",
        "GRU": "Neural Networks",
        "BidirectionalLSTM": "Neural Networks",
        "BidirectionalGRU": "Neural Networks",
        "Transformer": "Neural Networks",
        "Decision Tree": "Trees",
        "Random Forest": "Trees",
        "XGBoost": "Trees",
    }
)

# %%
df_copy["Features"].unique()
# Out:
# array(['Chemical + Mineralogical', 'Chemical + Mineralogical + Early CS',
#        'Chemical + Mineralogical + Physical - Early CS',
#        'Chemical + Mineralogical + Physical'], dtype=object)

# %%
df_copy["Model"].unique()
# Out:
# array(['Neural Networks', 'Trees', 'Linear Regression'], dtype=object)

# %%
df_copy["Model_bkp"].unique()
# Out:
# array(['Transformer', 'MLP', 'BidirectionalLSTM', 'XGBoost',
#        'BidirectionalGRU', 'Linear Regression', 'Random Forest', 'GRU',
#        'Decision Tree', 'LSTM'], dtype=object)

# %%
df_copy["Model_bkp_2"].unique()
# Out:
# array(['Transformer_1.0', 'Transformer_7.0', 'Transformer_14.0', 'MLP',
#        'BidirectionalLSTM_1.0', 'BidirectionalLSTM_7.0',
#        'BidirectionalLSTM_14.0', 'XGBoost', 'BidirectionalGRU_1.0',
#        'BidirectionalGRU_7.0', 'BidirectionalGRU_14.0',
#        'Linear Regression', 'Random Forest', 'GRU_1.0', 'GRU_7.0',
#        'GRU_14.0', 'Decision Tree', 'LSTM_1.0', 'LSTM_7.0', 'LSTM_14.0'],
#       dtype=object)

# %%
df_copy.shape
# Out:
# (16211, 29)

# %%
df_copy_grouped = df_copy.copy()

# %%
# df_copy["Features_bkp_2"] = df_copy["Features_bkp"].replace(
#     {
#         "Chemical + Mineralogical + CS3 + CS7": "Chemical + Mineralogical + Early CS",
#         "Chemical + Mineralogical + CS7": "Chemical + Mineralogical + Early CS",
#         "Chemical + Mineralogical + CS3": "Chemical + Mineralogical + Early CS",
#         "Chemical + Mineralogical + CS1": "Chemical + Mineralogical + Early CS",
#         "Chemical + Mineralogical + CS1 + CS3": "Chemical + Mineralogical + Early CS",
#         "Chemical + Mineralogical + CS1 + CS3 + CS7": "Chemical + Mineralogical + Early CS",
#         "Chemical + Mineralogical + CS2": "Chemical + Mineralogical + Early CS",
#         "Chemical + CS1 + CS3 + CS7": "Chemical + Mineralogical + Early CS",
#         "Chemical + CS3 + CS7": "Chemical + Mineralogical + Early CS",
#         "Chemical + CS7": "Chemical + Mineralogical + Early CS",
#         "Chemical + CS3": "Chemical + Mineralogical + Early CS",
#         "Chemical + CS1 + CS3": "Chemical + Mineralogical + Early CS",
#         "Chemical + CS1": "Chemical + Mineralogical + Early CS",
#         "Chemical + CS1 + CS7": "Chemical + Mineralogical + Early CS",
#     }
# )

# %%
df_copy[
    [
        ("RMSE Test", "mean"),
        ("MAE Test", "mean"),
        ("MAPE Test", "mean"),
        ("R2 Test", "mean"),
    ]
].describe().round(2).T
# Out:
#                   count  mean    std      min   25%   50%   75%     max
# RMSE Test mean  16211.0  3.60   4.04     0.69  1.75  2.45  4.11  151.38
# MAE Test  mean  16211.0  2.64   2.64     0.52  1.33  1.85  3.06   70.23
# MAPE Test mean  16211.0  6.14   6.35     1.30  3.09  4.25  7.04  188.89
# R2 Test   mean  16211.0 -7.35  91.23 -4690.18 -0.45  0.62  0.87    0.99

# %%
(df_copy[("R2 Test", "mean")] < 0).sum()
# Out:
# 4945

# %%
(df_copy[("MAPE Test", "mean")] > 100).sum()
# Out:
# 8

# %%
(df_copy[("RMSE Test", "mean")] > 100).sum()
# Out:
# 2

# %%
(df_copy[("MAE Test", "mean")] > 100).sum()
# Out:
# 0

# %%
(
    (df_copy[("R2 Test", "mean")] < 0)
    | (df_copy[("MAPE Test", "mean")] > 100)
    | (df_copy[("RMSE Test", "mean")] > 100)
    | (df_copy[("MAE Test", "mean")] > 100)
).sum()
# Out:
# 4945

# %%
round((5620 / 16251) * 100, 2)
# Out:
# 34.58

# %%
df_copy_2 = df_copy.copy()

# %%
df_copy = df_copy[
    ~(
        (df_copy[("R2 Test", "mean")] < 0)
        | (df_copy[("MAPE Test", "mean")] > 100)
        | (df_copy[("RMSE Test", "mean")] > 100)
        | (df_copy[("MAE Test", "mean")] > 100)
    )
].reset_index(drop=True)

# %%
set(df_copy_2["Plant"].unique()) - set(df_copy["Plant"].unique())
# Out:
# set()

# %%
df_copy[
    [
        ("RMSE Test", "mean"),
        ("MAE Test", "mean"),
        ("MAPE Test", "mean"),
        ("R2 Test", "mean"),
    ]
].describe().round(2).T
# Out:
#                   count  mean   std   min   25%   50%   75%    max
# RMSE Test mean  11266.0  2.20  0.91  0.69  1.58  1.99  2.62   6.99
# MAE Test  mean  11266.0  1.68  0.70  0.52  1.21  1.52  2.00   6.03
# MAPE Test mean  11266.0  3.91  1.61  1.30  2.82  3.51  4.60  14.24
# R2 Test   mean  11266.0  0.72  0.24  0.00  0.59  0.79  0.91   0.99

# %%
em_copy = df_copy[
    [
        ("RMSE Test", "mean"),
        ("MAE Test", "mean"),
        ("MAPE Test", "mean"),
        ("R2 Test", "mean"),
    ]
].copy()

em_copy.columns = ["RMSE", "MAE", "MAPE", "R2"]
em_copy.describe().round(2).T
# Out:
#         count  mean   std   min   25%   50%   75%    max
# RMSE  11266.0  2.20  0.91  0.69  1.58  1.99  2.62   6.99
# MAE   11266.0  1.68  0.70  0.52  1.21  1.52  2.00   6.03
# MAPE  11266.0  3.91  1.61  1.30  2.82  3.51  4.60  14.24
# R2    11266.0  0.72  0.24  0.00  0.59  0.79  0.91   0.99

# %%
df_copy[
    [
        ("RMSE Test", "std"),
        ("MAE Test", "std"),
        ("MAPE Test", "std"),
        ("R2 Test", "std"),
    ]
].describe().round(2).T
# Out:
#                  count  mean   std   min   25%   50%   75%   max
# RMSE Test std  11266.0  0.58  0.69  0.02  0.13  0.31  0.74  5.09
# MAE Test  std  11266.0  0.38  0.46  0.01  0.09  0.20  0.50  4.44
# MAPE Test std  11266.0  0.90  1.06  0.03  0.20  0.48  1.17  9.73
# R2 Test   std  11266.0  0.18  0.27  0.00  0.02  0.06  0.22  2.90

# %%
df_copy.shape
# Out:
# (11266, 29)

# %%
df_copy["plant"].unique()
# Out:
# array(['partner_i', 'partner_ii', 'partner_iv', 'av', 'c', 'd', 'g', 'm', 'y', 'a', 'ab',
#        'ae', 'aq', 'ay', 'f', 'i', 'o', 'r', 't', 'b', 'at', 'aa', 'ac',
#        'ag', 'ai', 'am', 'an', 'ap', 'as', 'az', 'e', 'h', 'j', 'k', 'l',
#        'n', 'p', 'q', 's', 'u', 'v', 'w', 'x', 'z'], dtype=object)

# %%
df_inn_groupd = df_copy_grouped[df_copy_grouped["plant"].isin(["partner_i", "partner_ii", "partner_iv"])]
df_ecics_groupd = df_copy_grouped[
    ~df_copy_grouped["plant"].isin(["partner_i", "partner_ii", "partner_iv"])
]

# %%
df_inn_groupd.shape
# Out:
# (1123, 29)

# %%
df_ecics_groupd.shape
# Out:
# (15088, 29)

# %%
df_full.shape
# Out:
# (219670, 24)

# %%
cols_groupby = [
    # "Category",
    # "Company",
    "plant",
    # "Data Shape",
    "Timesteps",
    "Features_bkp",
    "Model",
    "Cross Validation",
    "Cross Validation Params",
]

cols_agg = ["RMSE Train", "MAE Train", "MAPE Train", "R2 Train"] + [
    "RMSE Test",
    "MAE Test",
    "MAPE Test",
    "R2 Test",
]

df_results_to_save = (
    df_full.groupby(cols_groupby, dropna=False)[cols_agg]
    .agg(["mean", lambda series: pd.Series(series.std(ddof=0), name="std")])
    .reset_index()
    .rename(columns={"<lambda_0>": "std"})
)

# %%
# df_full["Model"]

# %%
df_results_to_save.shape
# Out:
# (16205, 22)

# %%
df_copy_grouped.shape
# Out:
# (16211, 29)

# %% [markdown]
# # Topological Analysis - NEW

# %% [markdown]
# ## Definitions

# %%
# Function to compare two models strictly based on means only
def dominates(model1, model2):
    """Return True if model1 strictly dominates model2, False otherwise."""
    # Check if model1 is at least as good as model2 in all metrics
    at_least_as_good = (
        model1["RMSE_mean"] <= model2["RMSE_mean"]
        and model1["MAE_mean"] <= model2["MAE_mean"]
        and model1["MAPE_mean"] <= model2["MAPE_mean"]
        and model1["R2_mean"] >= model2["R2_mean"]
    )

    # Check if model1 is strictly better in at least one metric
    strictly_better_in_one = (
        model1["RMSE_mean"] < model2["RMSE_mean"]
        or model1["MAE_mean"] < model2["MAE_mean"]
        or model1["MAPE_mean"] < model2["MAPE_mean"]
        or model1["R2_mean"] > model2["R2_mean"]
    )

    # Model1 strictly dominates Model2 if it is at least as good in all metrics and
    # strictly better in at least one metric
    return at_least_as_good and strictly_better_in_one

# %%
def get_dominance_matrix_and_graph(df):
    n = len(df)
    dominance_matrix = np.zeros((n, n), dtype=bool)

    for i in range(n):
        for j in range(n):
            if i != j:
                dominance_matrix[i, j] = dominates(df.iloc[i], df.iloc[j])

    # Create the dominance graph
    dominance_graph = {i: [] for i in range(n)}
    for i in range(n):
        for j in range(n):
            if dominance_matrix[i, j]:
                dominance_graph[i].append(j)

    return dominance_matrix, dominance_graph

# %%
# Topological Sorting
def topological_sort(graph):
    """Perform topological sorting on the given graph."""
    in_degree = {u: 0 for u in graph}
    for u in graph:
        for v in graph[u]:
            in_degree[v] += 1

    queue = deque([u for u in graph if in_degree[u] == 0])
    topo_order = []

    while queue:
        u = queue.popleft()
        topo_order.append(u)

        for v in graph[u]:
            in_degree[v] -= 1
            if in_degree[v] == 0:
                queue.append(v)

    return topo_order

# %%
# Function to find the top models in each group
def find_top_models(group):
    max_net_dominance = group["Net_Dominance"].max()
    top_models = group[group["Net_Dominance"] == max_net_dominance]
    return top_models

# %% [markdown]
# # Analysis

# %% [markdown]
# ## INN

# %%
# Filter only INN project
df_inn_grouped = df_copy_grouped[
    df_copy_grouped["plant"].isin(["partner_i", "partner_ii", "partner_iv"])
]

# %%
df_results = df_inn_grouped[
    [
        ("Company", ""),
        ("plant", ""),
        ("Cross Validation", ""),
        ("Features", ""),
        ('Features_bkp', ''),
        ("Model", ""),
        ("Model_bkp", ""),         
        ('Model_bkp_2',''),
        ("Timesteps", ""),
        ("RMSE Test", "mean"),
        ("MAE Test", "mean"),
        ("MAPE Test", "mean"),
        ("R2 Test", "mean"),
        ("RMSE Test", "std"),
        ("MAE Test", "std"),
        ("MAPE Test", "std"),
        ("R2 Test", "std"),
    ]
].copy()
df_results = df_results.reset_index(drop=True)

# Rename columns
new_column_names = [
    "Company",
    "Plant",
    "Cross Validation",
    "Features",
    "Features_bkp",
    "Model",
    "Model_bkp",
    "Model_bkp_2",
    "Timesteps",
    "RMSE_mean",
    "MAE_mean",
    "MAPE_mean",
    "R2_mean",
    "RMSE_std",
    "MAE_std",
    "MAPE_std",
    "R2_std",
]

df_results.columns = new_column_names

# %%
df_results.shape
# Out:
# (1123, 17)

# %%
df_results["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split', 'Repeated KFold',
#        'Time Series Split'], dtype=object)

# %% [markdown]
# ### Variable Grouping: CM

# %%
df_results["Features"].unique()
# Out:
# array(['Chemical + Mineralogical', 'Chemical + Mineralogical + Early CS',
#        'Chemical + Mineralogical + Physical - Early CS',
#        'Chemical + Mineralogical + Physical'], dtype=object)

# %%
df_results_cm = (
    df_results[df_results["Features"].eq("Chemical + Mineralogical")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm["Features"].unique()
# Out:
# array(['Chemical + Mineralogical'], dtype=object)

# %%
df_results_cm.shape
# Out:
# (175, 17)

# %% [markdown]
# #### K-Fold

# %%
df_results_cm["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split', 'Repeated KFold',
#        'Time Series Split'], dtype=object)

# %%
df_results_cm_kf = (
    df_results_cm[df_results_cm["Cross Validation"].eq("Repeated KFold")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_kf["Cross Validation"].unique()
# Out:
# array(['Repeated KFold'], dtype=object)

# %%
df_results_cm_kf.shape
# Out:
# (60, 17)

# %% [markdown]
# ###### SCPM computation

# %%
scaler = StandardScaler()
standardized_metrics = scaler.fit_transform(
    df_results_cm_kf[["RMSE_mean", "MAE_mean", "MAPE_mean", "R2_mean"]]
)

# Creating a new dataframe with standardized values
standardized_df = pd.DataFrame(
    standardized_metrics,
    columns=["RMSE_mean", "MAE_mean", "MAPE_mean", "R2_mean"],
)

# Summing all metrics and subtracting R2_mean
standardized_df["Result"] = (
    standardized_df[["RMSE_mean", "MAE_mean", "MAPE_mean"]].sum(axis=1)
    - standardized_df["R2_mean"]
)

df_results_cm_kf["SCPM"] = standardized_df["Result"]

# %% [markdown]
# ##### Dominance Analysis

# %%
dominance_matrix_cm_kf, dominance_graph_cm_kf = get_dominance_matrix_and_graph(
    df_results_cm_kf
)

# Get the topological order
topo_order = topological_sort(dominance_graph_cm_kf)
dominance_matrix = dominance_matrix_cm_kf
dominance_graph = dominance_graph_cm_kf
df = df_results_cm_kf.copy()
n = len(topo_order)

# %%
dominance_matrix_cm_kf.shape, len(dominance_graph_cm_kf)
# Out:
# ((60, 60), 60)

# %%
# Identify Dominant Models
dominant_models = [
    df["Model_bkp_2"].iloc[i]
    for i in range(len(df))
    if not np.any(dominance_matrix[:, i])
]

# Identify Non-Dominant Models
non_dominant_models = [
    df["Model_bkp_2"].iloc[i] for i in range(len(df)) if np.any(dominance_matrix[:, i])
]

# Identify Models that are both dominated and dominate at least one
intermediate_models = [
    df["Model_bkp_2"].iloc[i]
    for i in range(len(df))
    if np.any(dominance_matrix[:, i]) and np.any(dominance_matrix[i, :])
]

# %%
# Add count of times each model is dominated by others
df["Dominated_Count"] = np.sum(dominance_matrix, axis=0)

# Classify models
df["Classification"] = "intermediate_model"  # default to intermediate_model
df.loc[
    ~np.any(dominance_matrix, axis=1) & np.any(dominance_matrix, axis=0),
    "Classification",
] = "non_dominant_model"
df.loc[~np.any(dominance_matrix, axis=0), "Classification"] = "dominant_model"

# %%
# Map the topological order to the model names and get dominance counts
sorted_models = [df["Model"].iloc[i] for i in topo_order]
# df["Topo_Dominance_Order"] = topo_order
df_sorted = df.iloc[topo_order].copy()
df_sorted["Dominates_Count"] = dominance_matrix.sum(axis=1)[topo_order]
df_sorted_topo = df_sorted.copy()

df_sorted = df_sorted.sort_values(by="Dominates_Count", ascending=False)
df_sorted_count = df_sorted.copy()

# %%
df["Classification"].value_counts()
# Out:
# Classification
# intermediate_model    52
# non_dominant_model     6
# dominant_model         2
# Name: count, dtype: int64

# %%
df_sorted_topo.to_excel("INN_dominance_analysis_cm_kf.xlsx", index=False)

# %%
df_sorted_topo.head(5)
# Out:
#        Company Plant Cross Validation                  Features  \
# 18  partner_i  partner_i   Repeated KFold  Chemical + Mineralogical
# 43       partner_iv  partner_iv   Repeated KFold  Chemical + Mineralogical
# 15  partner_i  partner_i   Repeated KFold  Chemical + Mineralogical
# 2   partner_i  partner_i   Repeated KFold  Chemical + Mineralogical
# 9   partner_i  partner_i   Repeated KFold  Chemical + Mineralogical
#
#                 Features_bkp            Model          Model_bkp  \
# 18  Chemical + Mineralogical  Neural Networks               LSTM
# 43  Chemical + Mineralogical  Neural Networks   BidirectionalGRU
# 15  Chemical + Mineralogical  Neural Networks  BidirectionalLSTM
# 2   Chemical + Mineralogical  Neural Networks        Transformer
# 9   Chemical + Mineralogical  Neural Networks                GRU
#
#                Model_bkp_2  Timesteps  RMSE_mean  ...  MAPE_mean   R2_mean  \
# 18               LSTM_14.0       14.0   2.182129  ...   4.008130  0.813374
# ...

# %%
df_sorted_topo_cols = df_sorted_topo[
    [
        # "Model",
        # "Model_bkp",
        "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Classification",
        "Dominates_Count",
        "Plant",
    ]
].round(2)

# %% [markdown]
# ##### Top dominant models

# %%
# Top 4
df_sorted_topo_cols.iloc[0:2]
# Out:
#              Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 18             LSTM_14.0       2.18      0.25      1.72     0.20       4.01
# 43  BidirectionalGRU_1.0       2.80      0.18      2.15     0.14       4.47
#
#     MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count  Classification  \
# 18      0.48     0.81    0.04 -6.02                0  dominant_model
# 43      0.27     0.82    0.02 -2.73                0  dominant_model
#
#     Dominates_Count Plant
# 18               58  partner_i
# 43               31  partner_iv

# %% [markdown]
# ##### Top intermediate models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].sort_values(by="Dominates_Count", ascending=False).iloc[:2]
# Out:
#                Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 15  BidirectionalLSTM_14.0       2.19      0.19      1.74     0.17       4.07
# 9                 GRU_14.0       2.24      0.33      1.76     0.27       4.11
#
#     MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 15      0.41     0.81    0.03 -5.84                1  intermediate_model
# 9       0.59     0.80    0.06 -5.55                2  intermediate_model
#
#     Dominates_Count Plant
# 15               57  partner_i
# 9                54  partner_i

# %% [markdown]
# ##### Top non dominant models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].sort_values(by="Dominated_Count", ascending=True).iloc[:2]
# Out:
#       Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 50  Decision Tree       3.83      0.23      2.81     0.15       5.88
# 29       GRU_14.0       2.92      1.03      2.16     0.28       5.09
#
#     MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 50      0.34     0.66    0.05  4.47               26  non_dominant_model
# 29      0.71     0.11    0.97  2.57               27  non_dominant_model
#
#     Dominates_Count Plant
# 50                0  partner_iv
# 29                0  partner_ii

# %%
df_sorted_topo.columns
# Out:
# Index(['Company', 'Plant', 'Cross Validation', 'Features', 'Features_bkp',
#        'Model', 'Model_bkp', 'Model_bkp_2', 'Timesteps', 'RMSE_mean',
#        'MAE_mean', 'MAPE_mean', 'R2_mean', 'RMSE_std', 'MAE_std', 'MAPE_std',
#        'R2_std', 'SCPM', 'Dominated_Count', 'Classification',
#        'Dominates_Count'],
#       dtype='object')

# %%
round(58 / 60, 2), round(31 / 60, 2)
# Out:
# (0.97, 0.52)

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        # "Model_bkp",
        # "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
        "Plant",
    ]
]  # .round(2)

# %%
df_sorted_topo["Model"].value_counts()
# Out:
# Model
# Neural Networks      48
# Trees                 9
# Linear Regression     3
# Name: count, dtype: int64

# %%
df_sorted_topo_models_grouped = df_sorted_topo_models_cols.groupby("Model").describe().T

# %%
# pd.set_option("display.max_rows", None)
# df_sorted_topo_models_grouped

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
    ]
]

# %%
df_sorted_topo_models_cols.groupby("Model").describe().round(2)
# Out:
#                   Dominated_Count                                              \
#                             count   mean    std   min   25%   50%   75%   max
# Model
# Linear Regression             3.0  18.67  15.04   9.0  10.0  11.0  23.5  36.0
# Neural Networks              48.0  14.56  10.19   0.0   6.0  12.5  23.0  43.0
# Trees                         9.0  19.44   6.67  12.0  13.0  18.0  24.0  31.0
#
#                   Dominates_Count
#                             count   mean    std  min  25%   50%    75%   max
# Model
# Linear Regression             3.0  11.00  10.54  0.0  6.0  12.0  16.50  21.0
# Neural Networks              48.0  17.27  16.19  0.0  4.0  12.5  26.25  58.0
# Trees                         9.0   7.56   7.47  0.0  1.0   5.0  12.00  19.0

# %%
df_sorted_topo_models_cols.groupby("Model")["Classification"].describe()
# Out:
#                   count unique                 top freq
# Model
# Linear Regression     3      2  intermediate_model    2
# Neural Networks      48      3  intermediate_model   42
# Trees                 9      2  intermediate_model    8

# %%
df_sorted_topo_models_cols.groupby("Model")[["Classification"]].value_counts()
# Out:
# Model              Classification
# Linear Regression  intermediate_model     2
#                    non_dominant_model     1
# Neural Networks    intermediate_model    42
#                    non_dominant_model     4
#                    dominant_model         2
# Trees              intermediate_model     8
#                    non_dominant_model     1
# Name: count, dtype: int64

# %%
(
    df_sorted_topo_models_cols.groupby("Model")[["Classification"]]
    .value_counts(normalize=True)
    .to_frame()
    * 100
).round(2)
# Out:
#                                       proportion
# Model             Classification
# Linear Regression intermediate_model       66.67
#                   non_dominant_model       33.33
# Neural Networks   intermediate_model       87.50
#                   non_dominant_model        8.33
#                   dominant_model            4.17
# Trees             intermediate_model       88.89
#                   non_dominant_model       11.11

# %%
# df_sorted_topo_models_cols

# %%
summary_stats = df_sorted_topo_models_cols.groupby("Model").agg(
    Total_Models=("Model", "count"),
    Mean_Dominance_Count=("Dominates_Count", "mean"),
    Median_Dominance_Count=("Dominates_Count", "median"),
    Total_Dominated=("Dominated_Count", "sum"),
    Total_Dominating=("Dominates_Count", "sum"),
)

total_models = summary_stats[
    "Total_Models"
].sum()  # Get the total number of models across all categories
summary_stats["Dominance Proportion"] = summary_stats["Total_Dominating"] / total_models

# %%
summary_stats
# Out:
#                    Total_Models  Mean_Dominance_Count  Median_Dominance_Count  \
# Model
# Linear Regression             3             11.000000                    12.0
# Neural Networks              48             17.270833                    12.5
# Trees                         9              7.555556                     5.0
#
#                    Total_Dominated  Total_Dominating  Dominance Proportion
# Model
# Linear Regression               56                33              0.550000
# Neural Networks                699               829             13.816667
# Trees                          175                68              1.133333

# %%
df_sorted_topo_models_grouped.T
# Out:
#                   RMSE_mean                                                    \
#                       count      mean       std       min       25%       50%
# Model
# Linear Regression       3.0  3.042446  0.520634  2.516459  2.784891  3.053322
# Neural Networks        48.0  2.874670  0.458458  2.182129  2.460510  2.786124
# Trees                   9.0  3.148215  0.458979  2.508405  2.798250  3.173012
#
#                                       RMSE_std            ... Dominated_Count  \
#                         75%       max    count      mean  ...             75%
# Model                                                     ...
# Linear Regression  3.305440  3.557557      3.0  0.190341  ...            23.5
# Neural Networks    3.333713  3.694550     48.0  0.260578  ...            23.0
# Trees              3.379828  3.830563      9.0  0.176370  ...            24.0
#
#                         Dominates_Count                                        \
# ...

# %% [markdown]
# ### SCPM Analysis

# %%
cols = [
    # "Model",
    # "Model_bkp",
    "Model_bkp_2",
    "RMSE_mean",
    "RMSE_std",
    "MAE_mean",
    "MAE_std",
    "MAPE_mean",
    "MAPE_std",
    "R2_mean",
    "R2_std",
    "SCPM",
    "Dominated_Count",
    "Dominates_Count",
    "Classification",
    "Plant",
]

# %%
df_sorted_scpm = df_sorted_topo.sort_values(by="SCPM").copy()

# %%
# (df_sorted_topo[cols].reset_index() == df_sorted_scpm[cols].reset_index()).all(axis=1)
df_sorted_scpm["topo_scmp_order_eq"] = df_sorted_topo.index == df_sorted_scpm.index

# %%
df_sorted_topo[cols].round(2).head(5)
# Out:
#                Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 18               LSTM_14.0       2.18      0.25      1.72     0.20       4.01
# 43    BidirectionalGRU_1.0       2.80      0.18      2.15     0.14       4.47
# 15  BidirectionalLSTM_14.0       2.19      0.19      1.74     0.17       4.07
# 2         Transformer_14.0       2.36      0.52      1.75     0.32       4.17
# 9                 GRU_14.0       2.24      0.33      1.76     0.27       4.11
#
#     MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count  Dominates_Count  \
# 18      0.48     0.81    0.04 -6.02                0               58
# 43      0.27     0.82    0.02 -2.73                0               31
# 15      0.41     0.81    0.03 -5.84                1               57
# 2       0.79     0.77    0.10 -5.05                2               46
# 9       0.59     0.80    0.06 -5.55                2               54
#
#         Classification Plant
# 18      dominant_model  partner_i
# ...

# %%
df_sorted_scpm[cols + ["topo_scmp_order_eq"]].round(2).head(5)
# Out:
#                Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 18               LSTM_14.0       2.18      0.25      1.72     0.20       4.01
# 15  BidirectionalLSTM_14.0       2.19      0.19      1.74     0.17       4.07
# 9                 GRU_14.0       2.24      0.33      1.76     0.27       4.11
# 2         Transformer_14.0       2.36      0.52      1.75     0.32       4.17
# 1          Transformer_7.0       2.35      0.31      1.76     0.21       4.22
#
#     MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count  Dominates_Count  \
# 18      0.48     0.81    0.04 -6.02                0               58
# 15      0.41     0.81    0.03 -5.84                1               57
# 9       0.59     0.80    0.06 -5.55                2               54
# 2       0.79     0.77    0.10 -5.05                2               46
# 1       0.53     0.78    0.06 -5.04                3               47
#
#         Classification Plant  topo_scmp_order_eq
# ...

# %% [markdown]
# #### Blocking time series

# %%
df_results_cm["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split', 'Repeated KFold',
#        'Time Series Split'], dtype=object)

# %%
df_results_cm_btss = (
    df_results_cm[df_results_cm["Cross Validation"].eq("Blocking Time Series Split")]
    .copy()
    .reset_index(drop=True)
)

# %%
df_results_cm_btss["Cross Validation"].unique()
# Out:
# array(['Blocking Time Series Split'], dtype=object)

# %%
df_results_cm_btss.shape
# Out:
# (55, 17)

# %% [markdown]
# ###### SCPM computation

# %%
scaler = StandardScaler()
standardized_metrics = scaler.fit_transform(
    df_results_cm_btss[["RMSE_mean", "MAE_mean", "MAPE_mean", "R2_mean"]]
)

# Creating a new dataframe with standardized values
standardized_df = pd.DataFrame(
    standardized_metrics,
    columns=["RMSE_mean", "MAE_mean", "MAPE_mean", "R2_mean"],
)

# Summing all metrics and subtracting R2_mean
standardized_df["Result"] = (
    standardized_df[["RMSE_mean", "MAE_mean", "MAPE_mean"]].sum(axis=1)
    - standardized_df["R2_mean"]
)

df_results_cm_btss["SCPM"] = standardized_df["Result"]

# %% [markdown]
# ##### Dominance Analysis

# %%
dominance_matrix_cm_btss, dominance_graph_cm_btss = get_dominance_matrix_and_graph(
    df_results_cm_btss
)

# Get the topological order
topo_order = topological_sort(dominance_graph_cm_btss)
dominance_matrix = dominance_matrix_cm_btss
dominance_graph = dominance_graph_cm_btss
df = df_results_cm_btss.copy()
n = len(topo_order)

# %%
dominance_matrix_cm_btss.shape, len(dominance_graph_cm_btss)
# Out:
# ((55, 55), 55)

# %%
# Identify Dominant Models
dominant_models = [
    df["Model_bkp_2"].iloc[i]
    for i in range(len(df))
    if not np.any(dominance_matrix[:, i])
]

# Identify Non-Dominant Models
non_dominant_models = [
    df["Model_bkp_2"].iloc[i] for i in range(len(df)) if np.any(dominance_matrix[:, i])
]

# Identify Models that are both dominated and dominate at least one
intermediate_models = [
    df["Model_bkp_2"].iloc[i]
    for i in range(len(df))
    if np.any(dominance_matrix[:, i]) and np.any(dominance_matrix[i, :])
]

# %%
# Add count of times each model is dominated by others
df["Dominated_Count"] = np.sum(dominance_matrix, axis=0)

# Classify models
df["Classification"] = "intermediate_model"  # default to intermediate_model
df.loc[
    ~np.any(dominance_matrix, axis=1) & np.any(dominance_matrix, axis=0),
    "Classification",
] = "non_dominant_model"
df.loc[~np.any(dominance_matrix, axis=0), "Classification"] = "dominant_model"

# %%
# Map the topological order to the model names and get dominance counts
sorted_models = [df["Model"].iloc[i] for i in topo_order]
# df["Topo_Dominance_Order"] = topo_order
df_sorted = df.iloc[topo_order].copy()
df_sorted["Dominates_Count"] = dominance_matrix.sum(axis=1)[topo_order]
df_sorted_topo = df_sorted.copy()

df_sorted = df_sorted.sort_values(by="Dominates_Count", ascending=False)
df_sorted_count = df_sorted.copy()

# %%
df["Classification"].value_counts()
# Out:
# Classification
# intermediate_model    49
# dominant_model         5
# non_dominant_model     1
# Name: count, dtype: int64

# %%
df_sorted_topo.to_excel("INN_dominance_analysis_cm_btss.xlsx", index=False)

# %%
df_sorted_topo.head(5)
# Out:
#        Company Plant            Cross Validation                  Features  \
# 6   partner_i  partner_i  Blocking Time Series Split  Chemical + Mineralogical
# 12  partner_i  partner_i  Blocking Time Series Split  Chemical + Mineralogical
# 32  partner_ii  partner_ii  Blocking Time Series Split  Chemical + Mineralogical
# 46       partner_iv  partner_iv  Blocking Time Series Split  Chemical + Mineralogical
# 49       partner_iv  partner_iv  Blocking Time Series Split  Chemical + Mineralogical
#
#                 Features_bkp              Model          Model_bkp  \
# 6   Chemical + Mineralogical              Trees            XGBoost
# 12  Chemical + Mineralogical              Trees      Random Forest
# 32  Chemical + Mineralogical              Trees      Random Forest
# 46  Chemical + Mineralogical  Linear Regression  Linear Regression
# 49  Chemical + Mineralogical              Trees            XGBoost
#
#           Model_bkp_2  Timesteps  RMSE_mean  ...  MAPE_mean   R2_mean  \
# ...

# %%
df_sorted_topo_cols = df_sorted_topo[
    [
        # "Model",
        # "Model_bkp",
        "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Classification",
        "Dominates_Count",
        "Plant",
    ]
].round(2)

# %% [markdown]
# ###### Dominant Models

# %%
# Top 4
df_sorted_topo_cols.iloc[0:5]
# Out:
#           Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 6             XGBoost       3.30      0.43      2.47     0.38       5.94
# 12      Random Forest       3.45      0.46      2.43     0.39       5.84
# 32      Random Forest       2.67      0.34      2.04     0.21       4.62
# 46  Linear Regression       3.88      0.46      2.87     0.59       5.95
# 49            XGBoost       3.81      1.02      3.08     0.89       6.32
#
#     MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count  Classification  \
# 6       0.90     0.54    0.11 -4.28                0  dominant_model
# 12      0.96     0.50    0.13 -4.25                0  dominant_model
# 32      0.39     0.25    0.19 -4.96                0  dominant_model
# 46      1.15     0.60    0.12 -3.87                0  dominant_model
# 49      1.52     0.60    0.20 -3.73                0  dominant_model
#
#     Dominates_Count Plant
# 6                44  partner_i
# 12               44  partner_i
# ...

# %%
df_sorted_topo_cols[df_sorted_topo_cols["Classification"].eq("dominant_model")].shape
# Out:
# (5, 14)

# %%
df_sorted_topo_cols.loc[[32, 6]]
# Out:
#       Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 32  Random Forest       2.67      0.34      2.04     0.21       4.62
# 6         XGBoost       3.30      0.43      2.47     0.38       5.94
#
#     MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count  Classification  \
# 32      0.39     0.25    0.19 -4.96                0  dominant_model
# 6       0.90     0.54    0.11 -4.28                0  dominant_model
#
#     Dominates_Count Plant
# 32               45  partner_ii
# 6                44  partner_i

# %% [markdown]
# ###### Intermediate models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].sort_values(by=["Dominates_Count", "SCPM"], ascending=[False, True]).iloc[:2]
# Out:
#       Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 23        XGBoost       2.72      0.33       2.1     0.19       4.76
# 31  Decision Tree       3.04      0.61       2.3     0.35       5.24
#
#     MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count      Classification  \
# 23      0.25     0.24    0.11 -4.89                1  intermediate_model
# 31      0.61     0.07    0.19 -4.56                2  intermediate_model
#
#     Dominates_Count Plant
# 23               44  partner_ii
# 31               42  partner_ii

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("intermediate_model")
].shape
# Out:
# (49, 14)

# %% [markdown]
# ###### non-dominant models

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].sort_values(by=["Dominates_Count", "SCPM"], ascending=[False, True]).iloc[:2]
# Out:
#               Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 34  BidirectionalLSTM_7.0       12.6      6.36     10.66     5.46      25.46
#
#     MAPE_std  R2_mean  R2_std   SCPM  Dominated_Count      Classification  \
# 34     14.43   -51.66   87.77  11.53               54  non_dominant_model
#
#     Dominates_Count Plant
# 34                0  partner_ii

# %%
df_sorted_topo_cols[
    df_sorted_topo_cols["Classification"].eq("non_dominant_model")
].shape
# Out:
# (1, 14)

# %% [markdown]
# ###### Statistics per model type

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        # "Model_bkp",
        # "Model_bkp_2",
        "RMSE_mean",
        "RMSE_std",
        "MAE_mean",
        "MAE_std",
        "MAPE_mean",
        "MAPE_std",
        "R2_mean",
        "R2_std",
        "SCPM",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
        "Plant",
    ]
]  # .round(2)

# %%
df_sorted_topo["Model"].value_counts()
# Out:
# Model
# Neural Networks      43
# Trees                 9
# Linear Regression     3
# Name: count, dtype: int64

# %%
df_sorted_topo_models_grouped = df_sorted_topo_models_cols.groupby("Model").describe().T

# %%
# pd.set_option("display.max_rows", None)
# df_sorted_topo_models_grouped

# %%
df_sorted_topo_models_cols = df_sorted_topo[
    [
        "Model",
        "Dominated_Count",
        "Dominates_Count",
        "Classification",
    ]
]

# %%
(
    df_sorted_topo_models_cols.groupby("Model")[["Classification"]]
    .value_counts(normalize=True)
    .to_frame()
    * 100
).round(2)
# Out:
#                                       proportion
# Model             Classification
# Linear Regression intermediate_model       66.67
#                   dominant_model           33.33
# Neural Networks   intermediate_model       97.67
#                   non_dominant_model        2.33
# Trees             intermediate_model       55.56
#                   dominant_model           44.44

# %%
df_sorted_topo_models_cols.groupby("Model").describe().round(2).T
# Out:
# Model                  Linear Regression  Neural Networks  Trees
# Dominated_Count count                3.0            43.00   9.00
#                 mean                 2.0            25.53   1.44
#                 std                  2.0            11.86   2.01
#                 min                  0.0             2.00   0.00
#                 25%                  1.0            18.00   0.00
#                 50%                  2.0            23.00   1.00
#                 75%                  3.0            31.50   2.00
#                 max                  4.0            54.00   6.00
# Dominates_Count count                3.0            43.00   9.00
#                 mean                41.0            14.21  42.56
#                 std                  3.0            11.83   2.24
#                 min                 38.0             0.00  38.00
#                 25%                 39.5             4.00  41.00
# ...

# %%
# df_sorted_topo_models_cols

# %%
df_sorted_topo_models_cols.groupby("Model")["Classification"].describe()
# Out:
#                   count unique                 top freq
# Model
# Linear Regression     3      2  intermediate_model    2
# Neural Networks      43      2  intermediate_model   42
# Trees                 9      2  intermediate_model    5

# %%
df_sorted_topo_models_cols.groupby("Model")[["Classification"]].value_counts()
# Out:
# Model              Classification
# Linear Regression  intermediate_model     2
#                    dominant_model         1
# Neural Networks    intermediate_model    42
#                    non_dominant_model     1
# Trees              intermediate_model     5
#                    dominant_model         4
# Name: count, dtype: int64

# %%
# df_sorted_topo_models_cols

# %%
summary_stats = df_sorted_topo_models_cols.groupby("Model").agg(
    Total_Models=("Model", "count"),
    Mean_Dominance_Count=("Dominates_Count", "mean"),
    Median_Dominance_Count=("Dominates_Count", "median"),
    Total_Dominated=("Dominated_Count", "sum"),
    Total_Dominating=("Dominates_Count", "sum"),
)

total_models = summary_stats[
    "Total_Models"
].sum()  # Get the total number of models across all categories
summary_stats["Dominance Proportion"] = summary_stats["Total_Dominating"] / total_models

# %%
summary_stats
# Out:
#                    Total_Models  Mean_Dominance_Count  Median_Dominance_Count  \
# Model
# Linear Regression             3             41.000000                    41.0
# Neural Networks              43             14.209302                    11.0
# Trees                         9             42.555556                    44.0
#
#                    Total_Dominated  Total_Dominating  Dominance Proportion
# Model
# Linear Regression                6               123              2.236364
# Neural Networks               1098               611             11.109091
# Trees                           13               383              6.963636

# %%
df_sorted_topo_models_grouped.T
# Out:
#                   RMSE_mean                                                    \
#                       count      mean       std       min       25%       50%
# Model
# Linear Regression       3.0  3.683970  0.321825  3.312442  3.587676  3.862910
# Neural Networks        43.0  7.402893  2.328841  3.111002  5.894260  7.005784
# Trees                   9.0  3.504431  0.652352  2.665926  3.036289  3.450083
#
#                                        RMSE_std            ...  \
#                         75%        max    count      mean  ...
# Model                                                      ...
# Linear Regression  3.869734   3.876559      3.0  0.636657  ...
# Neural Networks    8.756786  12.601621     43.0  2.811346  ...
# Trees              3.833814   4.624518      9.0  0.734741  ...
#
#                   Dominated_Count       Dominates_Count                        \
#                               75%   max           count       mean        std
# Model
# ...

# %% [markdown]
# ### SCPM Analysis

# %%
cols = [
    # "Model",
    # "Model_bkp",
    "Model_bkp_2",
    "RMSE_mean",
    "RMSE_std",
    "MAE_mean",
    "MAE_std",
    "MAPE_mean",
    "MAPE_std",
    "R2_mean",
    "R2_std",
    "SCPM",
    "Dominated_Count",
    "Dominates_Count",
    "Classification",
    "Plant",
]

# %%
df_sorted_scpm = df_sorted_topo.sort_values(by="SCPM").copy()

# %%
# (df_sorted_topo[cols].reset_index() == df_sorted_scpm[cols].reset_index()).all(axis=1)
df_sorted_scpm["topo_scmp_order_eq"] = df_sorted_topo.index == df_sorted_scpm.index

# %%
df_sorted_scpm[cols + ["topo_scmp_order_eq"]].round(2).head(5)
# Out:
#         Model_bkp_2  RMSE_mean  RMSE_std  MAE_mean  MAE_std  MAPE_mean  \
# 32    Random Forest       2.67      0.34      2.04     0.21       4.62
# 23          XGBoost       2.72      0.33      2.10     0.19       4.76
# 31    Decision Tree       3.04      0.61      2.30     0.35       5.24
# 20  Transformer_1.0       3.11      0.99      2.39     0.72       5.50
# 6           XGBoost       3.30      0.43      2.47     0.38       5.94
#
#     MAPE_std  R2_mean  R2_std  SCPM  Dominated_Count  Dominates_Count  \
# 32      0.39     0.25    0.19 -4.96                0               45
# 23      0.25     0.24    0.11 -4.89                1               44
# 31      0.61     0.07    0.19 -4.56                2               42
# 20      1.50    -0.01    0.47 -4.43                3               40
# 6       0.90     0.54    0.11 -4.28                0               44
#
#         Classification Plant  topo_scmp_order_eq
# 32      dominant_model  partner_ii               False
# ...

# %%
# df_sorted_scpm

# %%
# # Categorize models based on dominance
# dominates_any = np.any(dominance_matrix, axis=1)
# dominated_by_any = np.any(dominance_matrix, axis=0)

# dominant_models = [
#     df["Model"].iloc[i]
#     for i in range(n)
#     if dominates_any[i] and not dominated_by_any[i]
# ]
# non_dominated_models = [
#     df["Model"].iloc[i]
#     for i in range(n)
#     if not dominated_by_any[i]  # Correct condition: not dominated by any
# ]
# failing_models = [df["Model"].iloc[i] for i in range(n) if dominated_by_any[i]]

# print("Dominating Models:", dominant_models)
# print("Non-Dominated Models:", non_dominated_models)
# print("Failing Models:", failing_models)

# # Map the topological order to the model names
# sorted_models = [df["Model"].iloc[i] for i in topo_order]
# print("Models in order of dominance:", sorted_models)
# Out:
# Dominating Models: ['Neural Networks', 'Neural Networks']
# Non-Dominated Models: ['Neural Networks', 'Neural Networks']
# ...

# %%
# Categorize models based on dominance
dominates_any = np.any(dominance_matrix, axis=1)
dominated_by_any = np.any(dominance_matrix, axis=0)

dominant_models = [
    df["Model"].iloc[i]
    for i in range(n)
    if dominates_any[i] and not dominated_by_any[i]
]
non_dominated_models = [
    df["Model"].iloc[i]
    for i in range(n)
    if not dominates_any[i] and not dominated_by_any[i]
]
failing_models = [df["Model"].iloc[i] for i in range(n) if dominated_by_any[i]]

print("Dominating Models:", dominant_models)
print("Non-Dominated Models:", non_dominated_models)
print("Failing Models:", failing_models)

# Map the topological order to the model names
sorted_models = [df["Model"].iloc[i] for i in topo_order]
print("Models in order of dominance:", sorted_models)
# Out:
# Dominating Models: ['Neural Networks', 'Neural Networks']
# Non-Dominated Models: []
# ...

# %%
# print(
#     "Dominance Analysis for INN Project, CM Variable Grouping, KFold Cross-validation:"
# )
# print("Dominance Matrix:")
# print(dominance_matrix)
# print("Dominance Graph:")
# print(dominance_graph)
# print("Topological Order:")
# print([df.iloc[i]["Model_bkp"] for i in topo_order])

# %%
# Categorize models based on dominance
dominates_any = np.any(dominance_matrix, axis=1)
dominated_by_any = np.any(dominance_matrix, axis=0)

dominant_models = [
    df["Model_bkp_2"].iloc[i]
    for i in range(len(df))
    if dominates_any[i] and not dominated_by_any[i]
]
non_dominated_models = [
    df["Model_bkp_2"].iloc[i]
    for i in range(len(df))
    if not dominates_any[i] and not dominated_by_any[i]
]
failing_models = [
    df["Model_bkp_2"].iloc[i] for i in range(len(df)) if dominated_by_any[i]
]

print("Dominating Models:", dominant_models)
# print("Non-Dominated Models:", non_dominated_models)
# print("Failing Models:", failing_models)

# Map the topological order to the model names
sorted_models = [df["Model_bkp_2"].iloc[i] for i in topo_order]
print("Models in order of dominance:", sorted_models)
# Out:
# Dominating Models: ['LSTM_14.0', 'BidirectionalGRU_1.0']
# ...

# %%
dominant_models

# %%
# Categorize models based on dominance
dominates_any = np.any(dominance_matrix, axis=1)
dominated_by_any = np.any(dominance_matrix, axis=0)

dominant_models = [
    df["Model_bkp_2"].iloc[i]
    for i in range(len(df))
    if dominates_any[i] and not dominated_by_any[i]
]
non_dominated_models = [
    df["Model_bkp_2"].iloc[i]
    for i in range(len(df))
    if not dominates_any[i] and not dominated_by_any[i]
]
failing_models = [
    df["Model_bkp_2"].iloc[i] for i in range(len(df)) if dominated_by_any[i]
]

print("Dominating Models:", dominant_models)
print("Non-Dominated Models:", non_dominated_models)
print("Failing Models:", failing_models)
# Out:
# Dominating Models: ['LSTM_14.0', 'BidirectionalGRU_1.0']
# Non-Dominated Models: []
# ...

# %%
# Create the NetworkX graph
G = nx.DiGraph(dominance_graph_cm_kf)

# Apply transitive reduction
G_reduced = nx.transitive_reduction(G)

# Categorize models based on dominance
dominates_any = np.any(dominance_matrix, axis=1)
dominated_by_any = np.any(dominance_matrix, axis=0)

dominant_models = [
    df["Model_bkp_2"].iloc[i]
    for i in range(n)
    if dominates_any[i] and not dominated_by_any[i]
]
non_dominated_models = [
    df["Model_bkp_2"].iloc[i]
    for i in range(n)
    if not dominates_any[i] and not dominated_by_any[i]
]
failing_models = [df["Model"].iloc[i] for i in range(n) if dominated_by_any[i]]

print("Dominating Models:", dominant_models)
print("Non-Dominated Models:", non_dominated_models)
print("Failing Models:", failing_models)
# Out:
# Dominating Models: ['LSTM_14.0', 'BidirectionalGRU_1.0']
# Non-Dominated Models: []
# ...

# %%
# Map the topological order to the model names
sorted_models = [df["Model_bkp"].iloc[i] for i in topo_order]
print("Models in order of dominance:", sorted_models)

# Visualization of the reduced dominance graph
labels = {i: df["Model_bkp_2"].iloc[i] for i in range(n)}
pos = nx.spring_layout(G_reduced, seed=48, k=1.5)


fig, axes = plt.subplots(1, 1, figsize=(6.5, 5), sharex=False)  # 1 row, 2 columns
nx.draw(
    G_reduced,
    pos,
    ax=axes,
    labels=labels,
    with_labels=True,
    node_size=2100,
    node_color="skyblue",
    font_size=10,
    font_color="black",
    font_weight="bold",
    arrows=True,
)

# plt.title("Dominance Graph")
# plt.show()
# Out:
# Models in order of dominance: ['LSTM', 'BidirectionalGRU', 'BidirectionalLSTM', 'Transformer', 'GRU', 'Transformer', 'Transformer', 'Transformer', 'GRU', 'BidirectionalGRU', 'BidirectionalGRU', 'BidirectionalLSTM', 'LSTM', 'BidirectionalLSTM', 'LSTM', 'BidirectionalLSTM', 'LSTM', 'MLP', 'MLP', 'BidirectionalGRU', 'Transformer', 'GRU', 'GRU', 'Linear Regression', 'GRU', 'XGBoost', 'Linear Regression', 'Random Forest', 'XGBoost', 'Transformer', 'Random Forest', 'BidirectionalLSTM', 'Random Forest', 'LSTM', 'GRU', 'MLP', 'LSTM', 'Decision Tree', 'BidirectionalLSTM', 'BidirectionalGRU', 'XGBoost', 'BidirectionalLSTM', 'Transformer', 'BidirectionalGRU', 'LSTM', 'LSTM', 'GRU', 'Decision Tree', 'BidirectionalLSTM', 'GRU', 'BidirectionalGRU', 'LSTM', 'BidirectionalGRU', 'Linear Regression', 'BidirectionalLSTM', 'GRU', 'Transformer', 'Decision Tree', 'BidirectionalGRU', 'Transformer']

# %%
import matplotlib.pyplot as plt
import networkx as nx
import pandas as pd

# Assuming df and G_reduced are already defined
# sorted_models = [df["Model_bkp"].iloc[i] for i in topo_order]
# print("Models in order of dominance:", sorted_models)

# Visualization of the reduced dominance graph
labels = {i: df["Model"].iloc[i] for i in range(n)}

# Try different layouts to see which one works best for your graph size
# pos = nx.spring_layout(G_reduced, seed=48, k=1.5)
# pos = nx.kamada_kawai_layout(G_reduced)
pos = nx.fruchterman_reingold_layout(G_reduced, k=1.5, seed=48)

# Increase figure size for large graphs
fig, ax = plt.subplots(figsize=(15, 15))

# Draw the graph
nx.draw(
    G_reduced,
    pos,
    ax=ax,
    labels=labels,
    with_labels=True,
    node_size=300,  # Reduced node size
    node_color="skyblue",
    font_size=5,    # Reduced font size
    font_color="black",
    font_weight="bold",
    arrows=True,
)

# Save the plot to a file for detailed examination
plt.savefig("dominance_graph_large.png", dpi=300)
plt.show()

# %%
    dominates_count = dominance_matrix.sum(axis=1)
    dominated_by_count = dominance_matrix.sum(axis=0)

    # Identify dominant models
    dominant_models = np.where(dominated_by_count == 0)[0]

    # Store the results with the group
    for i in range(n):
        dominates_list.append(dominates_count[i])
        dominated_by_list.append(dominated_by_count[i])
        dominant_model_list.append(i in dominant_models)

# %%
n = len(df_inn_grouped)
dominance_matrix = np.zeros((n, n), dtype=bool)

for i in range(n):
    for j in range(n):
        if i != j:
            dominance_matrix[i, j] = strictly_dominates(df.iloc[i], df.iloc[j])

# Create the dominance graph
dominance_graph = {i: [] for i in range(n)}
for i in range(n):
    for j in range(n):
        if dominance_matrix[i, j]:
            dominance_graph[i].append(j)

# Create the NetworkX graph
G = nx.DiGraph(dominance_graph)

# Apply transitive reduction
G_reduced = nx.transitive_reduction(G)


# Get the topological order
topo_order = topological_sort(dominance_graph)

# Categorize models based on dominance
dominates_any = np.any(dominance_matrix, axis=1)
dominated_by_any = np.any(dominance_matrix, axis=0)

dominant_models = [df['Model'].iloc[i] for i in range(n) if dominates_any[i] and not dominated_by_any[i]]
non_dominated_models = [df['Model'].iloc[i] for i in range(n) if not dominates_any[i] and not dominated_by_any[i]]
failing_models = [df['Model'].iloc[i] for i in range(n) if dominated_by_any[i]]

print("Dominating Models:", dominant_models)
print("Non-Dominated Models:", non_dominated_models)
print("Failing Models:", failing_models)

# Map the topological order to the model names
sorted_models = [df['Model'].iloc[i] for i in topo_order]
print("Models in order of dominance:", sorted_models)

# %% [markdown]
# # Topological Analysis

# %%
import pandas as pd
import numpy as np
from collections import deque, defaultdict


# Function to compare two models strictly
def strictly_dominates(model1, model2):
    """Return True if model1 strictly dominates model2, False otherwise."""
    return (
        model1["RMSE_mean"] < model2["RMSE_mean"]
        and model1["RMSE_std"] < model2["RMSE_std"]
        and model1["MAE_mean"] < model2["MAE_mean"]
        and model1["MAE_std"] < model2["MAE_std"]
        and model1["MAPE_mean"] < model2["MAPE_mean"]
        and model1["MAPE_std"] < model2["MAPE_std"]
        and model1["R2_mean"] > model2["R2_mean"]
        and model1["R2_std"] < model2["R2_std"]
    )

    # Function to determine strict dominance


def strictly_dominates(arr1, arr2):
    return (
        (arr1[:, None, 0] < arr2[:, 0])
        & (arr1[:, None, 1] < arr2[:, 1])  # RMSE_mean
        & (arr1[:, None, 2] < arr2[:, 2])  # RMSE_std
        & (arr1[:, None, 3] < arr2[:, 3])  # MAE_mean
        & (arr1[:, None, 4] < arr2[:, 4])  # MAE_std
        & (arr1[:, None, 5] < arr2[:, 5])  # MAPE_mean
        & (arr1[:, None, 6] > arr2[:, 6])  # MAPE_std
        & (arr1[:, None, 7] < arr2[:, 7])  # R2_mean  # R2_std
    )


# def strictly_dominates(arr1, arr2):
#     return (
#         (arr1[:, None, 0] < arr2[:, 0]) &  # RMSE_mean
#         (arr1[:, None, 1] < arr2[:, 1]) &  # RMSE_cv
#         (arr1[:, None, 2] < arr2[:, 2]) &  # MAE_mean
#         (arr1[:, None, 3] < arr2[:, 3]) &  # MAE_cv
#         (arr1[:, None, 4] < arr2[:, 4]) &  # MAPE_mean
#         (arr1[:, None, 5] < arr2[:, 5]) &  # MAPE_cv
#         (arr1[:, None, 6] > arr2[:, 6]) &  # R2_mean
#         (arr1[:, None, 7] < arr2[:, 7])    # R2_cv
#     )


# Function to find the top models in each group
def find_top_models(group):
    max_net_dominance = group["Net_Dominance"].max()
    top_models = group[group["Net_Dominance"] == max_net_dominance]
    return top_models


# Topological Sorting
def topological_sort(graph):
    """Perform topological sorting on the given graph."""
    in_degree = {u: 0 for u in graph}
    for u in graph:
        for v in graph[u]:
            in_degree[v] += 1

    queue = deque([u for u in graph if in_degree[u] == 0])
    topo_order = []

    while queue:
        u = queue.popleft()
        topo_order.append(u)

        for v in graph[u]:
            in_degree[v] -= 1
            if in_degree[v] == 0:
                queue.append(v)

    return topo_order

# %%
## df_results df_results.T.rename()

df_results = df_copy[
    [
        ("Company", ""),
        ("plant", ""),
        ("Cross Validation", ""),
        ("Features", ""),
        ("Model", ""),
        ("Model_bkp", ""),
        ("Timesteps", ""),
        ("RMSE Test", "mean"),
        ("MAE Test", "mean"),
        ("MAPE Test", "mean"),
        ("R2 Test", "mean"),
        ("RMSE Test", "std"),
        ("MAE Test", "std"),
        ("MAPE Test", "std"),
        ("R2 Test", "std"),
    ]
]
df_results = df_results.reset_index(drop=True)

# Rename columns
new_column_names = [
    "Company",
    "Plant",
    "Cross Validation",
    "Features",
    "Model",
    "Model_bkp",
    "Timesteps",
    "RMSE_mean",
    "MAE_mean",
    "MAPE_mean",
    "R2_mean",
    "RMSE_std",
    "MAE_std",
    "MAPE_std",
    "R2_std",
]

df_results.columns = new_column_names

df_results["Model_bkp2"] = df_results["Model_bkp"] + df_results["Timesteps"].fillna(
    -1
).astype(int).apply(lambda x: "_" + str(x) if x != -1 else "").astype(str)

# Normalize standard deviations using the coefficient of variation (CV)
df_results["RMSE_cv"] = df_results["RMSE_std"] / df_results["RMSE_mean"]
df_results["MAE_cv"] = df_results["MAE_std"] / df_results["MAE_mean"]
df_results["MAPE_cv"] = df_results["MAPE_std"] / df_results["MAPE_mean"]
df_results["R2_cv"] = df_results["R2_std"] / df_results["R2_mean"]

# %%
df_results.shape
# Out:
# (10631, 20)

# %%
# grouped = df_results.groupby(["Cross Validation", "Features", "Plant"])

# # Loop through each group
# for name, group in grouped:
#     if name == ("m", "Repeated KFold", "Chemical + Mineralogical + Early CS"):
#         print(group)
# grouped.apply(len).sort_values(ascending=False)

# %%
# Initialize lists to store the dominance counts
dominates_list = []
dominated_by_list = []
dominant_model_list = []

# Group by Cross Validation, Features, and Plant
grouped = df_results.groupby(["Cross Validation", "Features", "Plant"])

# Loop through each group
for name, group in grouped:
    n = len(group)
    group_values = group[
        [
            "RMSE_mean",
            "RMSE_std",
            "MAE_mean",
            "MAE_std",
            "MAPE_mean",
            "MAPE_std",
            "R2_mean",
            "R2_std",
        ]
    ].values

    #     group_values = group[
    #         [
    #             "RMSE_mean",
    #             "RMSE_cv",
    #             "MAE_mean",
    #             "MAE_cv",
    #             "MAPE_mean",
    #             "MAPE_cv",
    #             "R2_mean",
    #             "R2_cv",
    #         ]
    #     ].values

    # Calculate the dominance matrix using vectorized operations
    dominance_matrix = strictly_dominates(group_values, group_values)

    # Exclude self-comparisons
    # Necessary only for not stricktly comparisons.
    # np.fill_diagonal(dominance_matrix, False)

    # Calculate dominance counts for each model in the group
    dominates_count = dominance_matrix.sum(axis=1)
    dominated_by_count = dominance_matrix.sum(axis=0)

    # Identify dominant models
    dominant_models = np.where(dominated_by_count == 0)[0]

    # Store the results with the group
    for i in range(n):
        dominates_list.append(dominates_count[i])
        dominated_by_list.append(dominated_by_count[i])
        dominant_model_list.append(i in dominant_models)

# %%
df_results["Dominates"] = pd.Series(dominates_list, index=df_results.index)
df_results["Dominated_By"] = pd.Series(dominated_by_list, index=df_results.index)
df_results["Is_Dominant"] = pd.Series(dominant_model_list, index=df_results.index)
df_results["Net_Dominance"] = df_results["Dominates"] - df_results["Dominated_By"]

# %%
df_results["Is_Dominant"].value_counts()
# Out:
# Is_Dominant
# False    8729
# True     1902
# Name: count, dtype: int64

# %%
8729 + 1902
# Out:
# 10631

# %%
# # Further group by Cross Validation, Features, and Model to aggregate dominance counts
# final_grouped_df = df_results.groupby(['Cross Validation', 'Features', 'Model']).agg({
#     'Dominates': 'sum',
#     'Dominated_By': 'sum',
#     'Net_Dominance': 'sum',
#     'Is_Dominant': 'any',  # Check if any model in the group is dominant
#     'RMSE_mean': 'mean',  # or other aggregations as needed
#     'MAE_mean': 'mean',   # or other aggregations as needed
#     'MAPE_mean': 'mean',  # or other aggregations as needed
#     'R2_mean': 'mean'     # or other aggregations as needed
# }).reset_index()

# %%
# # Determine model classification after aggregation
# final_grouped_df['Classification'] = 'Not Dominated'
# final_grouped_df.loc[final_grouped_df['Dominates'] > 0, 'Classification'] = 'Dominating'
# final_grouped_df.loc[(final_grouped_df['Dominates'] == 0) & (final_grouped_df['Dominated_By'] > 0), 'Classification'] = 'Failing'

# %%
# Extract dominant models
dominant_models_df = df_results[df_results["Is_Dominant"]]

# %%
top_models_df = dominant_models_df.loc[
    dominant_models_df.groupby(["Cross Validation", "Features", "Plant"])[
        "Net_Dominance"
    ].idxmax()
]

# Sort by Cross Validation, Features, and Plant for better readability
top_models_df = top_models_df.sort_values(
    by=["Cross Validation", "Features", "Plant"]
).reset_index(drop=True)

# Display the top models DataFrame
# print(top_models_df)

# %%
# top_models_df.sort_values(by=["Plant", "Cross Validation", "Features"]).reset_index(
#     drop=True
# )

# %%
filtered = top_models_df[top_models_df["Plant"].eq("a")].reset_index(drop=True)
filtered = filtered[
    filtered["Cross Validation"].eq("Blocking Time Series Split")
].reset_index(drop=True)

# %%
# filtered[
#     [
#         "Cross Validation",
#         "Features",
#         "Model",
#         "Model_bkp2",
#         "RMSE_mean",
#         "MAE_mean",
#         "MAPE_mean",
#         "R2_mean",
#         "RMSE_cv",
#         "MAE_cv",
#         "MAPE_cv",
#         "R2_cv",
#     ]
# ]

# %%
filtered[
    [
        "Cross Validation",
        "Features",
        "Model_bkp2",
        "RMSE_mean",
        "MAE_mean",
        "MAPE_mean",
        "R2_mean",
        "RMSE_std",
        "MAE_std",
        "MAPE_std",
        "R2_std",
        "Dominates",
    ]
].rename({"Cross Validation": "CV", "Model_bkp2": "Model"}, axis=1)
# Out:
#                            CV                                        Features  \
# 0  Blocking Time Series Split                        Chemical + Mineralogical
# 1  Blocking Time Series Split             Chemical + Mineralogical + Early CS
# 2  Blocking Time Series Split             Chemical + Mineralogical + Physical
# 3  Blocking Time Series Split  Chemical + Mineralogical + Physical - Early CS
#
#            Model  RMSE_mean  MAE_mean  MAPE_mean   R2_mean  RMSE_std  \
# 0          GRU_1   3.753128  2.977617   7.146629  0.361526  1.308443
# 1          GRU_7   3.431946  2.753558   6.758195  0.387626  1.349524
# 2  Transformer_7   2.705642  2.308783   5.843621  0.640099  1.210182
# 3  Decision Tree   2.437246  2.053305   5.020870  0.696227  1.009805
#
#     MAE_std  MAPE_std    R2_std  Dominates
# 0  1.158017  2.521850  0.611989         16
# 1  0.948754  2.424656  0.668832         17
# 2  1.118013  3.033179  0.309788         10
# 3  0.849601  2.019861  0.324136         12

# %%
top_models_df[
    [
        "Plant",
        "Cross Validation",
        "Features",
        "Model_bkp2",
        "RMSE_mean",
        "MAE_mean",
        "MAPE_mean",
        "R2_mean",
        "RMSE_std",
        "MAE_std",
        "MAPE_std",
        "R2_std",
        "Dominates",
    ]
].rename({"Cross Validation": "CV", "Model_bkp2": "Model"}, axis=1)
# Out:
#     Plant                          CV  \
# 0       a  Blocking Time Series Split
# 1      aa  Blocking Time Series Split
# 2      ab  Blocking Time Series Split
# 3      ac  Blocking Time Series Split
# 4      ae  Blocking Time Series Split
# ..    ...                         ...
# 401     u           Time Series Split
# 402     v           Time Series Split
# 403  partner_i           Time Series Split
# 404     w           Time Series Split
# 405     y           Time Series Split
#
#                                            Features               Model  \
# 0                          Chemical + Mineralogical               GRU_1
# 1                          Chemical + Mineralogical       Transformer_7
# 2                          Chemical + Mineralogical       Transformer_7
# 3                          Chemical + Mineralogical       Decision Tree
# 4                          Chemical + Mineralogical              LSTM_1
# ...

# %%
fig, axes = plt.subplots(1, 1, figsize=(10, 8))
# axes
sns.countplot(data=top_models_df, x="Model_bkp2", ax=axes)
_ = plt.xticks(rotation=45, ha="right")  # Rotate by 45 degrees, align right

# %%
fig, axes = plt.subplots(1, 1, figsize=(6.5, 4))
axes
sns.countplot(data=top_models_df, x="Model", ax=axes)
# Out:
# <Axes: xlabel='Model', ylabel='count'>

# %%
filtered = top_models_df[top_models_df["Plant"].eq("a")].reset_index(drop=True)
filtered = filtered[filtered["Cross Validation"].eq("Time Series Split")].reset_index(
    drop=True
)

filtered[
    [
        "Cross Validation",
        "Features",
        "Model_bkp2",
        "RMSE_mean",
        "MAE_mean",
        "MAPE_mean",
        "R2_mean",
        "RMSE_std",
        "MAE_std",
        "MAPE_std",
        "R2_std",
        "Dominates",
    ]
].rename({"Cross Validation": "CV", "Model_bkp2": "Model"}, axis=1)
# Out:
#                   CV                                        Features  \
# 0  Time Series Split                        Chemical + Mineralogical
# 1  Time Series Split             Chemical + Mineralogical + Early CS
# 2  Time Series Split             Chemical + Mineralogical + Physical
# 3  Time Series Split  Chemical + Mineralogical + Physical - Early CS
#
#                 Model  RMSE_mean  MAE_mean  MAPE_mean   R2_mean  RMSE_std  \
# 0             LSTM_14   3.788348  2.990470   7.356457  0.338030  2.654636
# 1              GRU_14   2.791045  2.138962   5.365354  0.662736  1.783002
# 2  BidirectionalGRU_1   2.174160  1.688416   4.214839  0.850569  0.495262
# 3                 MLP   2.968331  2.388023   5.793217  0.665377  1.375896
#
#     MAE_std  MAPE_std    R2_std  Dominates
# 0  2.101849  5.073257  0.956658          3
# 1  1.416524  3.552341  0.455923         17
# 2  0.441131  1.024380  0.077185         15
# 3  1.130052  2.551283  0.368357         17

# %%
# dominant_models_df[dominant_models_df["Dominates"].eq(119)]

# %%
top_models_df.groupby(["Plant", "Cross Validation", "Features"])[
    "Model"
].value_counts().reset_index()["count"].unique()
# Out:
# array([1])

# %%
grouped = dominant_models_df.groupby(['Plant', 'Cross Validation', 'Features'])

# Apply the function to each group
top_models_per_group = grouped.apply(find_top_models).reset_index(drop=True)

# Sort by Plant, Cross Validation, and Features for better readability
top_models_per_group = top_models_per_group.sort_values(by=['Plant', 'Cross Validation', 'Features']).reset_index(drop=True)

# Check if there are more than one dominant model per group
dominance_check = top_models_per_group.groupby(['Plant', 'Cross Validation', 'Features'])['Model'].nunique()

# Print the unique values of counts of dominant models per group
# print(dominance_check.unique())

# Display the top models DataFrame
#print(top_models_per_group)

# %%
# top_models_per_group

# %%
# top_models_per_group.groupby(["Plant", "Cross Validation", "Features"])[
#     "Model"
# ].unique()

# %%
dominance_check.unique()
# Out:
# array([1, 2])

# %%
dominant_groups = top_models_per_group.groupby(
    ["Plant", "Cross Validation", "Features"]
).filter(lambda x: len(x) > 1)

dominant_groups = dominant_groups[
    ~dominant_groups["Features"].eq("Chemical + Mineralogical + Early CS")
]

# %%
# dominant_groups[
#     [
#         "Plant",
#         "Cross Validation",
#         "Features",
#         "Model",
#         "Model_bkp2",
#         "RMSE_mean",
#         "MAE_mean",
#         "MAPE_mean",
#         "R2_mean",
#         "RMSE_cv",
#         "MAE_cv",
#         "MAPE_cv",
#         "R2_cv",
#         "RMSE_std",
#         "MAE_std",
#         "MAPE_std",
#         "R2_std",
#     ]
# ]


dominant_groups[
    [
        "Plant",
        "Cross Validation",
        "Features",
        "Model_bkp2",
        "RMSE_mean",
        "MAE_mean",
        "MAPE_mean",
        "R2_mean",
        "RMSE_std",
        "MAE_std",
        "MAPE_std",
        "R2_std",
        "Dominates",
    ]
]
# Out:
#     Plant            Cross Validation  \
# 4       a  Blocking Time Series Split
# 5       a  Blocking Time Series Split
# 19     aa              Repeated KFold
# 20     aa              Repeated KFold
# 21     aa              Repeated KFold
# 22     aa              Repeated KFold
# 23     aa              Repeated KFold
# 52     ac           Time Series Split
# 53     ac           Time Series Split
# 143    av              Repeated KFold
# 144    av              Repeated KFold
# 166     b              Repeated KFold
# 167     b              Repeated KFold
# 180  partner_iv           Time Series Split
# 181  partner_iv           Time Series Split
# 229     g           Time Series Split
# 230     g           Time Series Split
# 270     k  Blocking Time Series Split
# 271     k  Blocking Time Series Split
# 281     l  Blocking Time Series Split
# 282     l  Blocking Time Series Split
# 294     m  Blocking Time Series Split
# 295     m  Blocking Time Series Split
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# ... (Your existing code for calculating dominance_matrix)

# Create a heatmap
sns.heatmap(dominance_matrix, annot=True, cmap="viridis", fmt="d")
plt.xlabel("Model")
plt.ylabel("Model")
plt.title("Dominance Matrix")
plt.show()

# %%
# ... (Code for calculating dominance_matrix)
print("Dominant Models:", dominant_models)

# Create heatmap
sns.heatmap(dominance_matrix, annot=True, cmap="viridis", fmt="d")
plt.xlabel("Model")
plt.ylabel("Model")
plt.title("Dominance Matrix")
plt.show()
# Out:
# Dominant Models: [ 5 11 15]

# %%
# top_models_per_group["Features"]

# %%
top_results = []

for cv in dominant_models_df["Cross Validation"].unique():
    for feat in dominant_models_df["Features"].unique():
        top_results.append(
            dominance_stats[
                (
                    dominance_stats["Cross Validation"].eq(cv)
                    & dominance_stats["Features"].eq(feat)
                )
            ]
            .sort_values(by="Net_Dominance", ascending=False)
            .iloc[[0]]
        )

# %%
top_results = []

for cv in dominance_stats["Cross Validation"].unique():
    for feat in dominance_stats["Features"].unique():
        top_results.append(
            dominance_stats[
                (
                    dominance_stats["Cross Validation"].eq(cv)
                    & dominance_stats["Features"].eq(feat)
                )
            ]
            .sort_values(by="Net_Dominance", ascending=False)
            .iloc[[0]]
        )

# %%
# Add the counts to the original DataFrame
df_results["Dominates"] = pd.Series(dominates_list, index=df_results.index)
df_results["Dominated_By"] = pd.Series(dominated_by_list, index=df_results.index)

# Determine model classification
df_results["Classification"] = "Not Dominated"
df_results.loc[df_results["Dominates"] > 0, "Classification"] = "Dominating"
df_results.loc[
    (df_results["Dominates"] == 0) & (df_results["Dominated_By"] > 0), "Classification"
] = "Failing"

# %%
# df_results

# %%
# Additional statistical analysis of dominance
dominance_stats = df_results.groupby('Model')[['Dominates', 'Dominated_By']].sum()
dominance_stats['Net_Dominance'] = dominance_stats['Dominates'] - dominance_stats['Dominated_By']

print("Dominance Statistics:")
dominance_stats
# Out:
# Dominance Statistics:
#                    Dominates  Dominated_By  Net_Dominance
# Model
# Linear Regression      16113         16321           -208
# Neural Networks       248892        247174           1718
# Trees                  48579         50089          -1510

# %%
df_results["Classification"].unique()
# Out:
# array(['Dominating', 'Failing', 'Not Dominated'], dtype=object)

# %%
# Additional statistical analysis of dominance
dominance_stats = df_results.groupby('Model_bkp')[['Dominates', 'Dominated_By']].sum()
dominance_stats['Net_Dominance'] = dominance_stats['Dominates'] - dominance_stats['Dominated_By']

print("Dominance Statistics:")
dominance_stats
# Out:
# Dominance Statistics:
#                    Dominates  Dominated_By  Net_Dominance
# Model_bkp
# BidirectionalGRU       44959         44246            713
# BidirectionalLSTM      45841         44391           1450
# Decision Tree          16660         15964            696
# GRU                    48996         48493            503
# LSTM                   45190         45639           -449
# Linear Regression      16113         16321           -208
# MLP                    17277         17573           -296
# Random Forest          16066         16476           -410
# Transformer            46629         46832           -203
# XGBoost                15853         17649          -1796

# %%
# df_results

# %%
dominance_stats = df_results.groupby('Model_bkp')[['Classification']].value_counts()
dominance_stats
# Out:
# Model_bkp          Classification
# BidirectionalGRU   Dominating        2145
#                    Failing            196
#                    Not Dominated        1
# BidirectionalLSTM  Dominating        2129
#                    Failing            199
#                    Not Dominated       11
# Decision Tree      Dominating         810
#                    Failing             83
#                    Not Dominated        1
# GRU                Dominating        2161
#                    Failing            213
#                    Not Dominated        1
# LSTM               Dominating        2171
#                    Failing            199
#                    Not Dominated        5
# Linear Regression  Dominating         800
#                    Failing             94
# MLP                Dominating         823
#                    Failing             72
#                    Not Dominated        2
# Random Forest      Dominating         808
# ...

# %%
dominance_stats = df_results.groupby('Model_bkp')[['Classification']].value_counts()
dominance_stats/dominance_stats.sum() * 100
# Out:
# Model_bkp          Classification
# BidirectionalGRU   Dominating        13.199188
#                    Failing            1.206080
#                    Not Dominated      0.006153
# BidirectionalLSTM  Dominating        13.100732
#                    Failing            1.224540
#                    Not Dominated      0.067688
# Decision Tree      Dominating         4.984309
#                    Failing            0.510738
#                    Not Dominated      0.006153
# GRU                Dominating        13.297643
#                    Failing            1.310689
#                    Not Dominated      0.006153
# LSTM               Dominating        13.359178
#                    Failing            1.224540
#                    Not Dominated      0.030767
# Linear Regression  Dominating         4.922774
#                    Failing            0.578426
# MLP                Dominating         5.064304
#                    Failing            0.443050
# ...

# %%
dominance_graph = {i: [] for i in range(n)}
for i in range(n):
    for j in range(n):
        if dominance_matrix[i, j]:
            dominance_graph[i].append(j)

# %%
topo_order = topological_sort(dominance_graph)

# Map the topological order to the model names
sorted_models = [df_results["Model_bkp"].iloc[i] for i in topo_order]
print("Models in order of dominance:", sorted_models)
# Out:
# Models in order of dominance: ['Transformer', 'Transformer', 'Transformer', 'Transformer', 'MLP', 'Transformer', 'Transformer', 'MLP', 'Transformer', 'Transformer', 'Transformer', 'Transformer', 'Transformer', 'Transformer', 'Transformer', 'Transformer', 'Transformer', 'Transformer', 'Transformer', 'Transformer']

# %%
# Additional statistical analysis of dominance
dominance_stats = df_results.groupby(["Model_bkp2", "Cross Validation", "Features"])[
    ["Dominates", "Dominated_By"]
].sum()
dominance_stats["Net_Dominance"] = (
    dominance_stats["Dominates"] - dominance_stats["Dominated_By"]
)

print("Dominance Statistics:")
dominance_stats

dominance_stats = dominance_stats.reset_index()

# dominance_stats
# Out:
# Dominance Statistics:

# %%
dominance_stats
# Out:
#              Model_bkp2            Cross Validation  \
# 0    BidirectionalGRU_1  Blocking Time Series Split
# 1    BidirectionalGRU_1  Blocking Time Series Split
# 2    BidirectionalGRU_1  Blocking Time Series Split
# 3    BidirectionalGRU_1  Blocking Time Series Split
# 4    BidirectionalGRU_1              Repeated KFold
# ..                  ...                         ...
# 235             XGBoost              Repeated KFold
# 236             XGBoost           Time Series Split
# 237             XGBoost           Time Series Split
# 238             XGBoost           Time Series Split
# 239             XGBoost           Time Series Split
#
#                                            Features  Dominates  Dominated_By  \
# 0                          Chemical + Mineralogical        787           675
# 1               Chemical + Mineralogical + Early CS       2820          2542
# 2               Chemical + Mineralogical + Physical        871           761
# ...

# %%
(dominance_stats["Net_Dominance"] == 0).any()
# Out:
# False

# %%
# dominance_stats

# %%
top_results = []

for cv in dominance_stats["Cross Validation"].unique():
    for feat in dominance_stats["Features"].unique():
        top_results.append(
            dominance_stats[
                (
                    dominance_stats["Cross Validation"].eq(cv)
                    & dominance_stats["Features"].eq(feat)
                )
            ]
            .sort_values(by="Net_Dominance", ascending=False)
            .iloc[[0]]
        )

# %%
pd.concat(top_results).rename({"Model_bkp2": "Model"}, axis=1)
# Out:
#                    Model            Cross Validation  \
# 192        Transformer_1  Blocking Time Series Split
# 157    Linear Regression  Blocking Time Series Split
# 38   BidirectionalLSTM_1  Blocking Time Series Split
# 123               LSTM_1  Blocking Time Series Split
# 112                GRU_7              Repeated KFold
# 149               LSTM_7              Repeated KFold
# 78         Decision Tree              Repeated KFold
# 7     BidirectionalGRU_1              Repeated KFold
# 20   BidirectionalGRU_14           Time Series Split
# 213       Transformer_14           Time Series Split
# 22   BidirectionalGRU_14           Time Series Split
# 71   BidirectionalLSTM_7           Time Series Split
#
#                                            Features  Dominates  Dominated_By  \
# 192                        Chemical + Mineralogical       1053           628
# 157             Chemical + Mineralogical + Early CS       3585          2641
# ...

# %%
dominance_stats
# Out:
#              Model_bkp2            Cross Validation  \
# 0    BidirectionalGRU_1  Blocking Time Series Split
# 1    BidirectionalGRU_1  Blocking Time Series Split
# 2    BidirectionalGRU_1  Blocking Time Series Split
# 3    BidirectionalGRU_1  Blocking Time Series Split
# 4    BidirectionalGRU_1              Repeated KFold
# ..                  ...                         ...
# 235             XGBoost              Repeated KFold
# 236             XGBoost           Time Series Split
# 237             XGBoost           Time Series Split
# 238             XGBoost           Time Series Split
# 239             XGBoost           Time Series Split
#
#                                            Features  Dominates  Dominated_By  \
# 0                          Chemical + Mineralogical        787           675
# 1               Chemical + Mineralogical + Early CS       2820          2542
# 2               Chemical + Mineralogical + Physical        871           761
# ...

# %%
# dominance_stats = dominance_stats.groupby(["Cross Validation", "Model_bkp2"])[
#     ["Dominates", "Dominated_By", "Net_Dominance"]
# ].sum()

# dominance_stats = dominance_stats.reset_index()

# %%
# dominance_stats = dominance_stats.sort_values(by="Net_Dominance", ascending=False)
# dominance_stats

# %%
# dominance_stats["Cross Validation"]
# Out:
#               Cross Validation            Model_bkp2  Dominates  Dominated_By  \
# 0   Blocking Time Series Split    BidirectionalGRU_1       5221          4764
# 1   Blocking Time Series Split   BidirectionalGRU_14       4090          4796
# 2   Blocking Time Series Split    BidirectionalGRU_7       4945          5327
# 3   Blocking Time Series Split   BidirectionalLSTM_1       5876          4587
# 4   Blocking Time Series Split  BidirectionalLSTM_14       4625          4271
# 5   Blocking Time Series Split   BidirectionalLSTM_7       5022          5150
# 6   Blocking Time Series Split         Decision Tree       5516          5507
# 7   Blocking Time Series Split                 GRU_1       5613          5534
# 8   Blocking Time Series Split                GRU_14       4592          4950
# 9   Blocking Time Series Split                 GRU_7       5976          5192
# 10  Blocking Time Series Split                LSTM_1       4943          5378
# ...

# %%
# Additional statistical analysis of dominance
dominance_stats = df_results.groupby("Model_bkp2")[["Dominates", "Dominated_By"]].sum()
dominance_stats["Net_Dominance"] = (
    dominance_stats["Dominates"] - dominance_stats["Dominated_By"]
)

print("Dominance Statistics:")

dominance_stats = dominance_stats.sort_values(by="Net_Dominance", ascending=False)
dominance_stats
# Out:
# Dominance Statistics:
#                       Dominates  Dominated_By  Net_Dominance
# Model_bkp2
# Transformer_14            16071         14185           1886
# BidirectionalGRU_1        15569         14266           1303
# BidirectionalLSTM_1       16033         14875           1158
# LSTM_7                    15709         14613           1096
# GRU_1                     17022         16024            998
# Decision Tree             16660         15964            696
# BidirectionalLSTM_7       15603         15034            569
# BidirectionalGRU_14       14774         14463            311
# GRU_7                     16621         16471            150
# Linear Regression         16113         16321           -208
# BidirectionalLSTM_14      14205         14482           -277
# MLP                       17277         17573           -296
# LSTM_1                    15403         15727           -324
# Random Forest             16066         16476           -410
# ...

# %%
# Additional statistical analysis of dominance
dominance_stats = df_results.groupby(['Model_bkp2', "Features"])[['Dominates', 'Dominated_By']].sum()
dominance_stats['Net_Dominance'] = dominance_stats['Dominates'] - dominance_stats['Dominated_By']

print("Dominance Statistics:")
dominance_stats = dominance_stats.sort_values(by="Net_Dominance", ascending=False)
dominance_stats
# Out:
# Dominance Statistics:
#                                                                      Dominates  \
# Model_bkp2          Features
# Transformer_14      Chemical + Mineralogical + Early CS                   9524
# MLP                 Chemical + Mineralogical + Early CS                  10190
# BidirectionalLSTM_1 Chemical + Mineralogical + Physical                   2731
# LSTM_7              Chemical + Mineralogical + Early CS                   8990
# GRU_7               Chemical + Mineralogical                              2897
# ...                                                                        ...
# LSTM_1              Chemical + Mineralogical + Early CS                   8303
# BidirectionalGRU_14 Chemical + Mineralogical + Physical - Early CS        1584
# Transformer_7       Chemical + Mineralogical + Early CS                   8510
# XGBoost             Chemical + Mineralogical + Early CS                   8822
# ...

# %%
# Additional statistical analysis of dominance
dominance_stats = df_results.groupby(["Model_bkp2", "Cross Validation"])[
    ["Dominates", "Dominated_By"]
].sum()
dominance_stats["Net_Dominance"] = (
    dominance_stats["Dominates"] - dominance_stats["Dominated_By"]
)

print("Dominance Statistics:")
dominance_stats = dominance_stats.sort_values(by="Net_Dominance", ascending=False)
dominance_stats
# Out:
# Dominance Statistics:
#                                                  Dominates  Dominated_By  \
# Model_bkp2           Cross Validation
# BidirectionalLSTM_1  Blocking Time Series Split       5876          4587
# Transformer_14       Time Series Split                5921          4646
# BidirectionalLSTM_7  Time Series Split                5401          4400
# BidirectionalGRU_14  Time Series Split                5501          4617
# Linear Regression    Blocking Time Series Split       5778          4922
# GRU_1                Time Series Split                5870          5077
# GRU_7                Blocking Time Series Split       5976          5192
# Transformer_14       Blocking Time Series Split       4897          4132
# LSTM_7               Repeated KFold                   5413          4674
# Decision Tree        Repeated KFold                   5742          5046
# BidirectionalGRU_1   Repeated KFold                   5376          4724
# ...

# %%
df_results["Features"].unique()
# Out:
# array(['Chemical + Mineralogical', 'Chemical + Mineralogical + Early CS',
#        'Chemical + Mineralogical + Physical - Early CS ',
#        'Chemical + Mineralogical + Physical'], dtype=object)

# %%
# Additional statistical analysis of dominance

dominance_stats = df_results[df_results["Features"].eq("Chemical + Mineralogical")].reset_index(drop=True)
dominance_stats = dominance_stats.groupby(['Model_bkp2'])[['Dominates', 'Dominated_By']].sum()
dominance_stats['Net_Dominance'] = dominance_stats['Dominates'] - dominance_stats['Dominated_By']

print("Dominance Statistics:")
dominance_stats = dominance_stats.sort_values(by="Net_Dominance", ascending=False)
dominance_stats[:5]
# Out:
# Dominance Statistics:
#                      Dominates  Dominated_By  Net_Dominance
# Model_bkp2
# GRU_7                     2897          2078            819
# BidirectionalGRU_14       2720          1928            792
# Decision Tree             2725          2059            666
# BidirectionalLSTM_1       2747          2152            595
# Transformer_1             2786          2378            408

# %%
dominance_stats = dominance_stats.sort_values(by="Net_Dominance", ascending=False)

# %%
dominance_stats.to_excel("dominance_results.xlsx")

# %%
# import seaborn as sns

# # Plotting dominance count
# sns.barplot(x=df_results['Model'], y=df_results['Dominates'])
# plt.title("Number of Models Dominated by Each Model")
# plt.ylabel("Dominates Count")
# plt.xlabel("Model")
# plt.xticks(rotation=45)
# plt.show()

# sns.barplot(x=df_results['Model'], y=df_results['Dominated_By'])
# plt.title("Number of Models Dominating Each Model")
# plt.ylabel("Dominated Count")
# plt.xlabel("Model")
# plt.xticks(rotation=45)
# plt.show()

# %%
# import networkx as nx
# import matplotlib.pyplot as plt

# G = nx.DiGraph(dominance_graph)
# labels = {i: df_results['Model'].iloc[i] for i in range(n)}
# nx.draw(G, labels=labels, with_labels=True, node_size=3000, node_color="skyblue", font_size=12, font_color="black", font_weight="bold", arrows=True)
# plt.show()

# %%
# Group statistics
group_stats = df_results.groupby(["Cross Validation", "Features", "Plant", "Model"])[
    ["Dominates", "Dominated_By"]
].sum()
group_stats["Net_Dominance"] = group_stats["Dominates"] - group_stats["Dominated_By"]

print("Group Statistics:")
group_stats
# Out:
# Group Statistics:
#                                                                                                     Dominates  \
# Cross Validation           Features                                        Plant Model
# Blocking Time Series Split Chemical + Mineralogical                        a     Linear Regression          0
#                                                                                  Neural Networks          118
#                                                                                  Trees                     18
#                                                                            aa    Linear Regression          7
#                                                                                  Neural Networks          281
# ...                                                                                                       ...
# ...

# %%
# Group statistics
group_stats = df_results.groupby(["Cross Validation", "Features", "Plant", "Model"])[
    ["Dominates", "Dominated_By"]
].sum()
group_stats["Net_Dominance"] = group_stats["Dominates"] - group_stats["Dominated_By"]

print("Group Statistics:")
print(group_stats)
# Out:
# Group Statistics:
#                                                                                                     Dominates  \
# Cross Validation           Features                                        Plant Model
# Blocking Time Series Split Chemical + Mineralogical                        a     Linear Regression          0
#                                                                                  Neural Networks          118
#                                                                                  Trees                     18
#                                                                            aa    Linear Regression          7
#                                                                                  Neural Networks          281
# ...                                                                                                       ...
# ...

# %%
df_results = (
    df_copy[[("RMSE Test", "mean"), ("MAE Test", "mean")]]
    .T.reset_index(level=1, drop=True)
    .T.melt()
    .rename({"variable": "Metric"}, axis=1)
    .replace({"RMSE Test": "RMSE", "MAE Test": "MAE"})
)

plt.figure(figsize=(6.5, 4))
ax = sns.boxplot(
    data=df_results,
    y="Metric",
    x="value",
    showfliers=False,
    linewidth=3,
    width=0.3,
    color="skyblue",
    # showmeans=True,
)
plt.title("Boxplot Distribution of Prediction error metrics (without outliers)")
plt.xlabel("Prediction Error (MPa)")
plt.grid(True)
plt.show()

# ax.xaxis.grid(True)
ax.set(ylabel="", xlabel="Prediction Error (MPa)")
sns.despine(trim=True, left=True)

# Add legend for the models
# plt.legend(title="Model")

# plt.show()

# %%
df_results = (
    df_copy[[("RMSE Test", "mean")]]
    .T.reset_index(level=1, drop=True)
    .T.melt()
    .rename({"variable": "Metric"}, axis=1)
    .replace({"RMSE Test": "RMSE"})
)

plt.figure(figsize=(6.5, 4))
sns.boxplot(
    data=df_results,
    y="Metric",
    x="value",
    showfliers=False,
    linewidth=3,
    width=0.3,
    color="skyblue",
    showmeans=True,
)
plt.title("Boxplot Distribution of Prediction error metrics (without outliers)")
plt.xlabel("Prediction Error (MPa)")
plt.grid(True)
plt.show()

# %%
df_results = (
    df_copy[[("MAE Test", "mean")]]
    .T.reset_index(level=1, drop=True)
    .T.melt()
    .rename({"variable": "Metric"}, axis=1)
    .replace({"MAE Test": "MAE"})
)

plt.figure(figsize=(6.5, 4))
sns.boxplot(
    data=df_results,
    y="Metric",
    x="value",
    showfliers=False,
    linewidth=3,
    width=0.3,
    color="skyblue",
    showmeans=True,
)
plt.title("Boxplot Distribution of Prediction error metrics (without outliers)")
plt.xlabel("Prediction Error (MPa)")
plt.grid(True)
plt.show()

# %%
df_results = (
    df_copy[[("MAPE Test", "mean")]]
    .T.reset_index(level=1, drop=True)
    .T.melt()
    .rename({"variable": "Metric"}, axis=1)
    .replace({"MAPE Test": "MAPE"})
)

plt.figure(figsize=(6.5, 4))
sns.boxplot(
    data=df_results,
    y="Metric",
    x="value",
    showfliers=False,
    linewidth=3,
    width=0.3,
    color="skyblue",
    showmeans=True,
)
plt.title("Boxplot Distribution of Prediction error metrics (without outliers)")
plt.xlabel("Prediction Error (MPa)")
plt.grid(True)
plt.show()

# %%
df_results = (
    df_copy[[("R2 Test", "mean")]]
    .T.reset_index(level=1, drop=True)
    .T.melt()
    .rename({"variable": "Metric"}, axis=1)
    .replace({"R2 Test": "R2"})
)

plt.figure(figsize=(6.5, 4))
sns.boxplot(
    data=df_results,
    y="Metric",
    x="value",
    showfliers=False,
    linewidth=3,
    width=0.3,
    color="skyblue",
    # showmeans=True,
)
plt.title("Boxplot Distribution of Prediction error metrics (without outliers)")
plt.xlabel("Prediction Error (MPa)")
plt.grid(True)
plt.show()

# %%
df_results = (
    df_copy[[("RMSE Test", "mean"), ("MAE Test", "mean")]]
    .T.reset_index(level=1, drop=True)
    .T.melt()
    .rename({"variable": "Metric"}, axis=1)
    .replace({"RMSE Test": "RMSE", "MAE Test": "MAE"})
)

plt.figure(figsize=(6.5, 4))
ax = sns.boxplot(
    data=df_results,
    y="Metric",
    x="value",
    showfliers=False,
    linewidth=3,
    width=0.3,
    color="skyblue",
    showmeans=True,
)
plt.title("Boxplot Distribution of Prediction error metrics (without outliers)")
plt.xlabel("Prediction Error (MPa)")
plt.grid(True)
plt.show()

# ax.xaxis.grid(True)
ax.set(ylabel="", xlabel="Prediction Error (MPa)")
sns.despine(trim=True, left=True)

# Add legend for the models
# plt.legend(title="Model")

# plt.show()

# %%
df_results = (
    df_copy[
        [
            ("RMSE Test", "mean"),
            ("MAE Test", "mean"),
            ("MAPE Test", "mean"),
            ("R2 Test", "mean"),
        ]
    ]
    .T.reset_index(level=1, drop=True)
    .T.melt()
    .rename({"variable": "Metric"}, axis=1)
    .replace(
        {"RMSE Test": "RMSE", "MAE Test": "MAE", "MAPE Test": "MAPE", "R2 Test": "R2"}
    )
)

# %%
# Create a figure with subplots
fig, axes = plt.subplots(
    2, 2, figsize=(10, 6), sharex=False
)  # Adjust figsize as needed

# Define the metrics and their corresponding y-axis labels
metrics = ["RMSE", "MAE", "MAPE", "R2"]
# y_labels = ["RMSE (MPa)", "MAE (MPa)", "MAPE (%)", "R2"]
x_labels = [
    "Prediction Error (MPa)",
    "Prediction Error (MPa)",
    "Prediction Error (%)",
    "Explained Variance Value",
]  # Add x-axis labels

# Plot each metric in a separate subplot
for i, metric in enumerate(metrics):
    row = i // 2  # Calculate row index
    col = i % 2  # Calculate column index

    # Filter data for the current metric
    metric_data = df_results[df_results["Metric"] == metric]

    # Create boxplot
    sns.boxplot(
        data=metric_data,
        y="Metric",
        x="value",
        ax=axes[row, col],
        showfliers=False,
        linewidth=3,
        width=0.3,
        color="skyblue",
        # showmeans=True,
    )

    # Set y-axis label
    # axes[row, col].set_ylabel(y_labels[i])
    axes[row, col].set_ylabel("")

    # Set x-axis label
    axes[row, col].set_xlabel(x_labels[i])

    # Remove spines and add grid
    sns.despine(trim=True, left=True, ax=axes[row, col])
    axes[row, col].grid(True)


# Set overall title
plt.suptitle("Distribution of Prediction Metrics (Mean Across Folds, Without Outliers)")

# Adjust layout for better spacing
plt.tight_layout()
# plt.autoscale(enable=True, axis="x")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# ... (Your existing code for preparing df_results)

# Create a figure with subplots
fig, axes = plt.subplots(
    2, 2, figsize=(10, 6), sharex=False
)  # Adjust figsize as needed

# Define the metrics and their corresponding y-axis labels
metrics = ["RMSE", "MAE", "MAPE", "R2"]
# y_labels = ["RMSE (MPa)", "MAE (MPa)", "MAPE", "R2"]
# x_labels = [
#     "Prediction Error (MPa)",
#     "Prediction Error (MPa)",
#     "Prediction Error (%)",
#     "Explained Variance Value",
# ]  # Add x-axis labels

y_labels = ["", "", "", ""]

x_labels = [
    "RMSE Value (MPa)",
    "MAE Value (MPa)",
    "MAPE Value (%)",
    "$R^2$ Value",
]  # Add x-axis labels


# Define x-axis limits for each metric
x_limits = {
    "RMSE": [0, 10],
    "MAE": [0, 7],
    "MAPE": [0, 15],
    "R2": [-4, 1],
}

# Plot each metric in a separate subplot
for i, metric in enumerate(metrics):
    row = i // 2  # Calculate row index
    col = i % 2  # Calculate column index

    # Filter data for the current metric
    metric_data = df_results[df_results["Metric"] == metric]

    # Create boxplot
    sns.boxplot(
        data=metric_data,
        # y="Metric",
        x="value",
        ax=axes[row, col],
        showfliers=False,
        linewidth=3,
        width=0.3,
        color="skyblue",
        # showmeans=True,
    )

    # Set y-axis label
    # axes[row, col].set_ylabel(y_labels[i])
    axes[row, col].set_ylabel("")

    # Set x-axis label
    axes[row, col].set_xlabel(x_labels[i])

    # Set x-axis limits
    axes[row, col].set_xlim(x_limits[metric][0], x_limits[metric][1])

    # Remove spines and add grid
    sns.despine(trim=True, left=True, ax=axes[row, col])
    axes[row, col].grid(True)

# Set overall title
plt.suptitle("Boxplot of Prediction Metrics (Without Outliers)")

# Adjust layout for better spacing
plt.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Define the metrics and their corresponding y-axis labels
metrics = ["RMSE", "MAE", "MAPE", "R2"]
y_labels = ["RMSE (MPa)", "MAE (MPa)", "MAPE (%)", "R2"]
x_labels = [
    "RMSE Value (MPa)",
    "MAE Value (MPa)",
    "MAPE Value (%)",
    "$R^2$ Value",
]  # Add x-axis labels

# Define x-axis limits for each metric
x_limits = {
    "RMSE": [0, 10],
    "MAE": [0, 7],
    "MAPE": [0, 14.2],  # Adjust the limit for MAPE
    "R2": [-4, 1],
}

# Create a figure with subplots
fig, axes = plt.subplots(
    2, 2, figsize=(10, 6), sharex=False
)  # Adjust figsize as needed

# Plot each metric in a separate subplot
for i, metric in enumerate(metrics):
    row = i // 2  # Calculate row index
    col = i % 2  # Calculate column index

    # Filter data for the current metric
    metric_data = df_results[df_results["Metric"] == metric]

    # Create histogram
    axes[row, col].hist(
        metric_data["value"],
        bins=30,
        range=x_limits[metric],  # Use the defined x-axis limits
        linewidth=1,
        color="skyblue",
        edgecolor="black",
    )

    # Set y-axis label
    axes[row, col].set_ylabel("Frequency")

    # Set x-axis label
    axes[row, col].set_xlabel(x_labels[i])

    # Remove spines and add grid
    sns.despine(trim=True, left=True, ax=axes[row, col])
    axes[row, col].grid(True)

# Set overall title
plt.suptitle("Histogram of Prediction Metrics (Without outliers)")

# Adjust layout for better spacing
plt.tight_layout()

plt.show()

# %%
df_agg = df_copy.copy()
df_agg.columns = df_agg.columns.map(lambda x: " ".join(x).strip())

# %%
df_results = df_agg.melt(
    id_vars=["Model", "Cross Validation", "Features"],
    value_vars=["RMSE Test mean", "MAE Test mean"],
    var_name="Metric",
    value_name="Error",
)

import seaborn as sns
import matplotlib.pyplot as plt

# Initialize the figure with a logarithmic x axis
f, ax = plt.subplots(figsize=(10, 8))

# Plot with boxplot and stripplot
sns.boxplot(
    data=df_results,
    x="Error",
    y="Metric",
    showfliers=False,
    linewidth=3,
    width=0.3,
    palette="vlag",
)

# Add in points to show each observation
sns.stripplot(
    data=df_results,
    x="Error",
    y="Metric",
    size=4,
    hue="Model",
    dodge=True,
    palette="Set1",
)

# Tweak the visual presentation
ax.xaxis.grid(True)
ax.set(ylabel="", xlabel="Prediction Error (MPa)")
sns.despine(trim=True, left=True)

# Add legend for the models
plt.legend(title="Model")

plt.show()

# %%
df_results = df_agg.melt(
    id_vars=["Model", "Cross Validation", "Features"],
    value_vars=["MAE Test mean"],
    var_name="Metric",
    value_name="Error",
)

import seaborn as sns
import matplotlib.pyplot as plt

# Initialize the figure with a logarithmic x axis
f, ax = plt.subplots(figsize=(10, 8))

# Plot with boxplot and stripplot
sns.boxplot(
    data=df_results,
    x="Error",
    y="Metric",
    showfliers=False,
    linewidth=3,
    width=0.3,
    palette="vlag",
)

# Add in points to show each observation
sns.stripplot(
    data=df_results,
    x="Error",
    y="Metric",
    size=4,
    hue="Model",
    dodge=True,
    palette="Set1",
)

# Tweak the visual presentation
ax.xaxis.grid(True)
ax.set(ylabel="", xlabel="Prediction Error (MPa)")
sns.despine(trim=True, left=True)

# Add legend for the models
plt.legend(title="Model")

plt.show()

# %%
df_results = df_agg.melt(
    id_vars=["Model", "Cross Validation", "Features"],
    value_vars=["MAPE Test mean"],
    var_name="Metric",
    value_name="Error",
)

import seaborn as sns
import matplotlib.pyplot as plt

# Initialize the figure with a logarithmic x axis
f, ax = plt.subplots(figsize=(10, 8))

# Plot with boxplot and stripplot
sns.boxplot(
    data=df_results,
    x="Error",
    y="Metric",
    showfliers=False,
    linewidth=3,
    width=0.3,
    palette="vlag",
)

# Add in points to show each observation
sns.stripplot(
    data=df_results,
    x="Error",
    y="Metric",
    size=4,
    hue="Model",
    dodge=True,
    palette="Set1",
)

# Tweak the visual presentation
ax.xaxis.grid(True)
ax.set(ylabel="", xlabel="Prediction Error (MPa)")
sns.despine(trim=True, left=True)

# Add legend for the models
plt.legend(title="Model")

plt.show()

# %%
df_results = df_agg.melt(
    id_vars=["Model", "Cross Validation", "Features"],
    value_vars=["R2 Test mean"],
    var_name="Metric",
    value_name="Error",
)

import seaborn as sns
import matplotlib.pyplot as plt

# Initialize the figure with a logarithmic x axis
f, ax = plt.subplots(figsize=(10, 8))

# Plot with boxplot and stripplot
sns.boxplot(
    data=df_results,
    x="Error",
    y="Metric",
    showfliers=False,
    linewidth=3,
    width=0.3,
    palette="vlag",
)

# Add in points to show each observation
sns.stripplot(
    data=df_results,
    x="Error",
    y="Metric",
    size=4,
    hue="Model",
    dodge=True,
    palette="Set1",
)

# Tweak the visual presentation
ax.xaxis.grid(True)
ax.set(ylabel="", xlabel="Prediction Error (MPa)")
sns.despine(trim=True, left=True)

# Add legend for the models
plt.legend(title="Model")

plt.show()

# %%
df_results = df_agg.melt(
    id_vars=["Model_bkp", "Cross Validation", "Features"],
    value_vars=["MAE Test mean"],
    var_name="Metric",
    value_name="Error",
)


# Facet by Cross Validation Method
g = sns.catplot(
    data=df_results, x="Error", y="Metric", hue="Model_bkp", col="Cross Validation", 
    kind="strip", dodge=True, height=4, aspect=1, palette="Set1"
)

g.set_axis_labels("Prediction Error (MPa)", "")
g.set_titles("{col_name}")
g.despine(trim=True)
plt.show()

# %%
df_results = df_agg.melt(
    id_vars=["Model", "Cross Validation", "Features"],
    value_vars=["MAE Test mean"],
    var_name="Metric",
    value_name="Error",
)


# Facet by Cross Validation Method
g = sns.catplot(
    data=df_results, x="Error", y="Metric", hue="Model", col="Cross Validation", 
    kind="strip", dodge=True, height=4, aspect=1, palette="Set1"
)

g.set_axis_labels("Prediction Error (MPa)", "")
g.set_titles("{col_name}")
g.despine(trim=True)
plt.show()

# %%
df_results = df_agg.melt(
    id_vars=["Model", "Cross Validation", "Features"],
    value_vars=["MAE Test mean"],
    var_name="Metric",
    value_name="Error",
)

# Facet by Input Type
g = sns.catplot(
    data=df_results,
    x="Error",
    y="Metric",
    hue="Model",
    col="Features",
    kind="strip",
    dodge=True,
    height=4,
    aspect=1,
    palette="Set1",
)

g.set_axis_labels("Prediction Error (MPa)", "")
g.set_titles("{col_name}")
g.despine(trim=True)
plt.show()

# %%
df_results = df_agg.melt(
    id_vars=["Model", "Cross Validation", "Features"],
    value_vars=["MAE Test mean"],
    var_name="Metric",
    value_name="Error",
)


# Facet by Cross Validation Method without hue for model type
g = sns.catplot(
    data=df_results, x="Error", y="Metric", col="Cross Validation", 
    kind="strip", dodge=True, height=4, aspect=1, palette="Set1"
)

g.set_axis_labels("Prediction Error (MPa)", "")
g.set_titles("{col_name}")
g.despine(trim=True)
plt.show()
# Out:
# /tmp/ipykernel_2198436/1048196172.py:10: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   g = sns.catplot(

# %%
# Facet by Cross Validation Method without hue for model type
g = sns.catplot(
    data=df_results, x="Error", y="Metric", col="Features", 
    kind="strip", dodge=True, height=4, aspect=1, palette="Set1"
)

g.set_axis_labels("Prediction Error (MPa)", "")
g.set_titles("{col_name}")
g.despine(trim=True)
plt.show()
# Out:
# /tmp/ipykernel_2198436/2258763093.py:2: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   g = sns.catplot(

# %%
# Facet by Cross Validation Method without hue for model type
g = sns.catplot(
    data=df_results, y="Error", x="Metric", col="Features", 
    kind="strip", dodge=True, height=4, aspect=1, palette="Set1"
)

g.set_axis_labels("Prediction Error (MPa)", "")
g.set_titles("{col_name}")
g.despine(trim=True)
plt.show()
# Out:
# /tmp/ipykernel_2198436/3939722875.py:2: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   g = sns.catplot(

# %%
# Facet by Cross Validation Method without hue for model type
g = sns.catplot(
    data=df_results, x="Error", y="Metric", col="Model", 
    kind="strip", dodge=True, height=4, aspect=1, palette="Set1"
)

g.set_axis_labels("Prediction Error (MPa)", "")
g.set_titles("{col_name}")
g.despine(trim=True)
plt.show()
# Out:
# /tmp/ipykernel_2198436/774301395.py:2: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   g = sns.catplot(

# %%
df_results = df_agg.melt(
    id_vars=["Model", "Cross Validation", "Features"],
    value_vars=["MAE Test mean"],
    var_name="Metric",
    value_name="Error",
)

# Facet by Cross Validation Method
g = sns.catplot(
    data=df_results, x="Error", y="Metric", hue="Model", col="Cross Validation", 
    kind="boxen", dodge=True, height=4, aspect=1, palette="Set1"
)

g.set_axis_labels("Prediction Error (MPa)", "")
g.set_titles("{col_name}")
g.despine(trim=True)
plt.show()
# Out:
# /home/peressim/virtual_environments/ccs28-venv/lib/python3.10/site-packages/seaborn/categorical.py:1794: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/peressim/virtual_environments/ccs28-venv/lib/python3.10/site-packages/seaborn/categorical.py:1794: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/peressim/virtual_environments/ccs28-venv/lib/python3.10/site-packages/seaborn/categorical.py:1794: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
df_results = df_agg.melt(
    id_vars=["Model_bkp", "Cross Validation", "Features"],
    value_vars=["MAE Test mean"],
    var_name="Metric",
    value_name="Error",
)

# Facet by Cross Validation Method
g = sns.catplot(
    data=df_results, x="Error", y="Metric", hue="Model_bkp", col="Cross Validation", 
    kind="boxen", dodge=True, height=4, aspect=1, palette="Set1"
)

g.set_axis_labels("Prediction Error (MPa)", "")
g.set_titles("{col_name}")
g.despine(trim=True)
plt.show()
# Out:
# /home/peressim/virtual_environments/ccs28-venv/lib/python3.10/site-packages/seaborn/categorical.py:1794: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/peressim/virtual_environments/ccs28-venv/lib/python3.10/site-packages/seaborn/categorical.py:1794: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/peressim/virtual_environments/ccs28-venv/lib/python3.10/site-packages/seaborn/categorical.py:1794: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
df_results = df_agg.melt(
    id_vars=["Model", "Cross Validation", "Features"],
    value_vars=["MAE Test mean"],
    var_name="Metric",
    value_name="Error",
)

# Facet by Cross Validation Method
g = sns.catplot(
    data=df_results, x="Model", y="Error", col="Cross Validation", 
    kind="violin", split=True, height=4, aspect=1, palette="Set1"
)

g.set_axis_labels("Model", "Prediction Error (MPa)")
g.set_titles("{col_name}")
g.despine(trim=True)
plt.show()

# %%
df_results = df_agg.melt(
    id_vars=["Model", "Cross Validation", "Features"],
    value_vars=["MAE Test mean"],
    var_name="Metric",
    value_name="Error",
)

# Facet by Cross Validation Method
g = sns.catplot(
    data=df_results, x="Error", y="Metric", hue="Model", col="Cross Validation", 
    kind="strip", jitter=True, height=4, aspect=1, palette="Set1"
)

g.set_axis_labels("Prediction Error (MPa)", "")
g.set_titles("{col_name}")
g.despine(trim=True)
plt.show()

# %%
df_results = df_agg.melt(
    id_vars=["Model_bkp", "Cross Validation", "Features"],
    value_vars=["MAE Test mean"],
    var_name="Metric",
    value_name="Error",
)

# Facet by Cross Validation Method
g = sns.catplot(
    data=df_results, x="Error", y="Metric", hue="Model_bkp", col="Cross Validation", 
    kind="strip", jitter=True, height=4, aspect=1, palette="Set1"
)

g.set_axis_labels("Prediction Error (MPa)", "")
g.set_titles("{col_name}")
g.despine(trim=True)
plt.show()

# %%
df_results = df_agg.melt(
    id_vars=["Model", "Cross Validation", "Features"],
    value_vars=["R2 Test mean"],
    var_name="Metric",
    value_name="Error",
)

# Facet by Cross Validation Method
g = sns.catplot(
    data=df_results, x="Error", y="Metric", hue="Model", col="Cross Validation", 
    kind="strip", jitter=True, height=4, aspect=1, palette="Set1"
)

g.set_axis_labels("Prediction Error (MPa)", "")
g.set_titles("{col_name}")
g.despine(trim=True)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df_results = df_agg.melt(
    id_vars=["Model", "Cross Validation", "Features"],
    value_vars=["MAE Test mean"],
    var_name="Metric",
    value_name="Error",
)

# Facet by Cross Validation Method with Jitter
g = sns.catplot(
    data=df_results, x="Error", y="Metric", hue="Model", col="Cross Validation", 
    kind="strip", dodge=True, height=4, aspect=1, palette="Set1", jitter=True
)

g.set_axis_labels("Prediction Error (MPa)", "")
g.set_titles("{col_name}")
g.despine(trim=True)
plt.show()

# %%
df_results = df_agg.melt(
    id_vars=["Model_bkp", "Cross Validation", "Features"],
    value_vars=["MAE Test mean"],
    var_name="Metric",
    value_name="Error",
)

# Facet by Cross Validation Method with Jitter
g = sns.catplot(
    data=df_results, x="Error", y="Metric", hue="Model_bkp", col="Cross Validation", 
    kind="strip", dodge=True, height=4, aspect=1, palette="Set1", jitter=True
)

g.set_axis_labels("Prediction Error (MPa)", "")
g.set_titles("{col_name}")
g.despine(trim=True)
plt.show()

# %%
# Facet by Cross Validation Method with Jitter
g = sns.catplot(
    data=df_results, x="Error", y="Metric", hue="Features", col="Cross Validation", 
    kind="strip", dodge=True, height=4, aspect=1, palette="Set1", jitter=True
)

g.set_axis_labels("Prediction Error (MPa)", "")
g.set_titles("{col_name}")
g.despine(trim=True)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df_results = df_agg.melt(
    id_vars=["Model", "Cross Validation", "Features"],
    value_vars=["MAE Test mean"],
    var_name="Metric",
    value_name="Error",
)

# Facet by Cross Validation Method with Jitter
g = sns.catplot(
    data=df_results, x="Error", y="Metric", hue="Model", col="Features", 
    kind="strip", dodge=True, height=4, aspect=1, palette="Set1", jitter=True
)

g.set_axis_labels("Prediction Error (MPa)", "")
g.set_titles("{col_name}")
g.despine(trim=True)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'df_full' is your DataFrame
df_results = df_agg.melt(
    id_vars=["Model", "Cross Validation", "Features"],
    value_vars=["MAE Test mean"],
    var_name="Metric",
    value_name="Error",
)

# Grouping Models
model_groups = {
    'Neural Networks': ['Transformer', 'MLP', 'BidirectionalLSTM', 'BidirectionalGRU', 'GRU', 'LSTM'],
    'Trees': ['Random Forest', 'Decision Tree'],
    'Linear Regression': ['Linear Regression'],
    'Boosting': ['XGBoost']
}

# Map models to groups
df_results['Model Group'] = df_results['Model'].map(
    lambda x: next((group for group, models in model_groups.items() if x in models), 'Other')
)

# Facet by Cross Validation Method with Jitter and Model Group
g = sns.catplot(
    data=df_results, x="Error", y="Metric", hue="Model Group", col="Cross Validation", 
    kind="strip", dodge=True, height=4, aspect=1, palette="Set1", jitter=True
)

g.set_axis_labels("Prediction Error (MPa)", "")
g.set_titles("{col_name}")
g.despine(trim=True)
plt.show()

# %%
df_results["Features"].map(
    lambda x: next((group for group, var in var_groups.items() if x in var), "Other")
).unique()
# Out:
# array(['CM', 'CM-ECS', 'Other', 'CM-PC-ECS'], dtype=object)

# %%
df_results = df_agg.melt(
    id_vars=["Model", "Cross Validation", "Features"],
    value_vars=["MAE Test mean"],
    var_name="Metric",
    value_name="Error",
)

# %%
df_results["Features"].unique()
# Out:
# array(['Chemical + Mineralogical', 'Chemical + Mineralogical + Early CS',
#        'Chemical + Mineralogical + Physical - Early CS ',
#        'Chemical + Mineralogical + Physical'], dtype=object)

# %% [markdown]
# # The ones

# %%
df_results = df_agg.melt(
    id_vars=["Model", "Cross Validation", "Features"],
    value_vars=["MAE Test mean"],
    var_name="Metric",
    value_name="Error",
)

# Grouping of_variables
var_groups = {
    "CM": ["Chemical + Mineralogical"],
    "CM-ECS": ["Chemical + Mineralogical + Early CS"],
    "CM-P": ["Chemical + Mineralogical + Physical - Early CS"],
    "CM-P-ECS": ["Chemical + Mineralogical + Physical"],
}

# Replace Cross Validation Method names with abbreviations
cv_abbreviations = {
    "Blocking Time Series Split": "BTSS",
    "Repeated KFold": "KF",
    "Time Series Split": "TSS",
}


# Map group of features
df_results["Features"] = df_results["Features"].map(
    lambda x: next((group for group, var in var_groups.items() if x in var), "Other")
)

df_results["Cross Validation"] = df_results["Cross Validation"].map(cv_abbreviations)
df_results["Metric"] = df_results["Metric"].replace("MAE Test mean", "")

# %%
# Facet by Cross Validation Method with Jitter and Model Group
g = sns.catplot(
    data=df_results, x="Error", y="Metric", hue="Model", col="Cross Validation", 
    kind="strip", dodge=True, height=4, aspect=1, palette="Set1", jitter=True
)

g.set_axis_labels("Prediction Error (MPa)", "")
g.set_xlabels("MAE (MPa)", "")


g.set_titles("{col_name}")
g.despine(trim=True)
plt.show()

# %%
# Facet by Cross Validation Method with Jitter and Model Group
g = sns.catplot(
    data=df_results, x="Error", y="Metric", hue="Model", col="Cross Validation", 
    kind="strip", dodge=True, height=4, aspect=1, palette="Set1", jitter=False
)

g.set_axis_labels("Prediction Error (MPa)", "")
g.set_xlabels("MAE (MPa)", "")


g.set_titles("{col_name}")
g.despine(trim=True)
plt.show()

# %%
g = sns.catplot(
    data=df_results,
    x="Error",
    y="Metric",
    hue="Model",
    col="Cross Validation",
    kind="box",
    dodge=True,
    height=4,
    aspect=1,
    palette="Set1",
    showmeans=True,
    showfliers=False,
)
g.set_axis_labels("MAE (MPa)", "")
g.set_titles("{col_name}")
g.despine(trim=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df_results is your DataFrame

g = sns.catplot(
    data=df_results,
    x="Cross Validation",
    y="Error",
    hue="Model",
    kind="bar",
    dodge=True,
    height=4,
    aspect=1.5,
    palette="Set1",
    errorbar="sd",
)

g.set_axis_labels("Cross Validation", "MAE (MPa)")
g.set_titles("{col_name}")
g.despine(trim=True)
plt.show()

# %%
# Facet by Variable with Jitter and Model Group
g = sns.catplot(
    data=df_results, x="Error", y="Metric", hue="Model", col="Features", 
    kind="strip", dodge=True, height=4, aspect=1, palette="Set1", jitter=True
)

g.set_axis_labels("Prediction Error (MPa)", "")
g.set_titles("{col_name}")
g.despine(trim=True)
plt.show()

# %%
# Facet by Variable with Jitter and Model Group
g = sns.catplot(
    data=df_results, x="Error", y="Metric", hue="Model", col="Features", 
    kind="strip", dodge=True, height=4, aspect=1, palette="Set1", jitter=False
)

g.set_axis_labels("Prediction Error (MPa)", "")
g.set_titles("{col_name}")
g.despine(trim=True)
plt.show()

# %%
g = sns.catplot(
    data=df_results,
    x="Error",
    y="Metric",
    hue="Model",
    col="Features",
    kind="box",
    dodge=True,
    height=4,
    aspect=1,
    palette="Set1",
    showmeans=True,
    showfliers=False,
)
g.set_axis_labels("Prediction Error (MPa)", "")
g.set_titles("{col_name}")
g.despine(trim=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df_results is your DataFrame

g = sns.catplot(
    data=df_results,
    x="Features",
    y="Error",
    hue="Model",
    kind="bar",
    dodge=True,
    height=4,
    aspect=1.5,
    palette="Set1",
    ci="sd",
)

g.set_axis_labels("Variable Grouping", "Mean Prediction Error (MPa)")
g.set_titles("{col_name}")
g.despine(trim=True)
plt.show()
# Out:
# /tmp/ipykernel_2198436/375513272.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   g = sns.catplot(

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df_results is your DataFrame

g = sns.catplot(
    data=df_results,
    x="Features",
    y="Error",
    hue="Model",
    kind="bar",
    dodge=True,
    height=4,
    aspect=1.5,
    palette="Set1",
    errorbar="sd",
)


g = sns.catplot(
    data=df_results,
    x="Cross Validation",
    y="Error",
    hue="Model",
    kind="bar",
    dodge=True,
    height=4,
    aspect=1.5,
    palette="Set1",
    errorbar="sd",
)

g.set_axis_labels("Cross Validation", "Mean Prediction Error (MPa)")
g.set_titles("{col_name}")
g.despine(trim=True)
plt.show()

# %%
# Bar chart with error bars (standard deviation)
g = sns.catplot(
    data=df_results,
    x="Cross Validation",
    y="Error",
    hue="Model",
    kind="bar",
    dodge=True,
    height=4,
    aspect=1,
    palette="Set1",
    ci="sd",
)

# Customize labels and titles
g.set_axis_labels("Cross Validation", "Mean MAE (MPa)")
g.set_titles("{col_name}")
g.despine(trim=True)
plt.show()
# Out:
# /home/peressim/virtual_environments/ccs28-venv/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /home/peressim/virtual_environments/ccs28-venv/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /tmp/ipykernel_2198436/2934639325.py:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   g = sns.catplot(
# ...

# %%
sns.violinplot(data=df_results, x="Cross Validation", y="Error", hue="Model", cut=1)
# Out:
# /home/peressim/virtual_environments/ccs28-venv/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /home/peressim/virtual_environments/ccs28-venv/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='Cross Validation', ylabel='Error'>

# %% [markdown]
# ### Defining the Columns to work with

# %%
cols = [
    ("Data Shape", ""),
    ("Model", ""),
    ("Features", ""),
    ("Cross Validation", ""),
    ("Cross Validation Params", ""),
    # ("Timesteps", ""),
    ("RMSE Test", "mean"),
    ("RMSE Test", "std"),
    ("MAE Test", "mean"),
    ("MAE Test", "std"),
    ("MAPE Test", "mean"),
    ("MAPE Test", "std"),
    ("R2 Test", "mean"),
    ("R2 Test", "std"),
]

# %%
cols_metrics = [
    ("RMSE Test", "mean"),
    ("RMSE Test", "std"),
    ("MAE Test", "mean"),
    ("MAE Test", "std"),
    ("MAPE Test", "mean"),
    ("MAPE Test", "std"),
    ("R2 Test", "mean"),
    ("R2 Test", "std"),
]

# %%
cols_group = [
    # ("plant", ""),
    ("Data Shape", ""),
    ("Model", ""),
    ("Features", ""),
    ("Cross Validation", ""),
]

# %%
cols_group_cics = [
    "Model",
    "Company",
    "Plant",
    "Features",
    "Cross Validation",
]

# %%
df_results[df_results["Error"] < 100]
# Out:
#                Model_bkp            Cross Validation  \
# 0            Transformer  Blocking Time Series Split
# 1            Transformer              Repeated KFold
# 2            Transformer           Time Series Split
# 3            Transformer  Blocking Time Series Split
# 4            Transformer              Repeated KFold
# ...                  ...                         ...
# 16246  BidirectionalLSTM  Blocking Time Series Split
# 16247  BidirectionalLSTM              Repeated KFold
# 16248  BidirectionalLSTM           Time Series Split
# 16249  BidirectionalLSTM              Repeated KFold
# 16250  BidirectionalLSTM           Time Series Split
#
#                                   Features         Metric      Error  \
# 0                 Chemical + Mineralogical  MAE Test mean   3.273348
# 1                 Chemical + Mineralogical  MAE Test mean   2.270771
# 2                 Chemical + Mineralogical  MAE Test mean   3.004426
# ...

# %%
to_replace = {
    "Chemical": "Chemical + Mineralogical",
    "Chemical + CS3": "Chemical + Mineralogical + CS3",
    "Chemical + CS3 + CS7": "Chemical + Mineralogical + CS3 + CS7",
    "Chemical + CS7": "Chemical + Mineralogical + CS7",
    "Chemical + Feature Engineering": "Chemical + Mineralogical + Feature Engineering",
    "Chemical + Physical": "Chemical + Mineralogical + Physical",
    "Chemical + Properties CS Less": "Chemical + Mineralogical + Properties CS Less",
}

# %%
index = df_copy[df_copy["Plant"].eq("aa")].index
df_copy.loc[index, ("Features", "")] = df_copy.loc[index, ("Features", "")].replace(
    to_replace
)

# %%
# Deleting results from the ("Chemical + Mineralogical + Feature Engineering")
# or ("Chemical + Feature Engineering")
df_copy = df_copy[
    ~df_copy["Features"].eq("Chemical + Mineralogical + Feature Engineering")
].reset_index(drop=True)

df_copy = df_copy[
    ~df_copy["Features"].eq("Chemical + Feature Engineering")
].reset_index(drop=True)

# %%
df_copy["Features"].unique()
# Out:
# array(['Chemical + Mineralogical',
#        'Chemical + Mineralogical + CS3 + CS7 + One-Hot',
#        'Chemical + Mineralogical + CS7',
#        'Chemical + Mineralogical + Physical + One-Hot',
#        'Chemical + Mineralogical + Properties CS Less',
#        'Chemical + Mineralogical + One-Hot',
#        'Chemical + Mineralogical + Physical',
#        'Chemical + Mineralogical + CS7 + One-Hot',
#        'Chemical + Mineralogical + CS3',
#        'Chemical + Mineralogical + CS3 + One-Hot',
#        'Chemical + Mineralogical + CS3 + CS7',
#        'Chemical + Mineralogical + CS1 + CS3 + CS7',
#        'Chemical + Mineralogical + CS1 + CS3 + CS7 + One-Hot',
#        'Chemical + Mineralogical + CS1',
#        'Chemical + Mineralogical + CS1 + CS3 + One-Hot',
#        'Chemical + Mineralogical + CS1 + CS3',
#        'Chemical + Mineralogical + CS1 + One-Hot',
#        'Chemical + Mineralogical + CS2',
#        'Chemical + Mineralogical + CS2 + One-Hot', 'Chemical + CS1',
# ...

# %%
# to_replace_groups = {
# # Grupo 1 (Variaveis químicas e mineralógicas)
# 'Chemical': "Quimicas e Mineralogicas"
# 'Chemical + Mineralogical'

# # Grupo 2 (Variavaris Quimicas, Mineralogicas, Caracteristicas e Propriedades Fisicas)
# 'Chemical + Physical (todas variaveis físicas)
# 'Chemical + CS1',
# 'Chemical + CS3',
# 'Chemical + CS7',
# 'Chemical + CS1 + CS3',
# 'Chemical + CS1 + CS7',
# 'Chemical + CS3 + CS7',
# 'Chemical + CS1 + CS3 + CS7',
# 'Chemical + Mineralogical + Physical (todas variaveis físicas),
# 'Chemical + Mineralogical + CS3',
# 'Chemical + Mineralogical + CS7',
# 'Chemical + Mineralogical + CS3 + CS7',

# # Grupo 3
# 'Chemical + Caracteristicas Físicas (incluí todas variáveis físicas com exceção de resistência compressiva)
# 'Chemical + Mineralogical + Properties CS Less (incluí todas variáveis físicas com exceção de resistência compressiva)'

# %%
to_replace_groups = {
    # Grupo 1
    "Chemical": "Quimicas e Mineralogicas",
    "Chemical + Mineralogical": "Quimicas e Mineralogicas",
    # Grupo 2
    "Chemical + Physical": "Quimicas, Mineralogicas, Caracteristicas e Propriedades Fisicas",
    "Chemical + CS1": "Quimicas, Mineralogicas, Caracteristicas e Propriedades Fisicas",
    "Chemical + CS3": "Quimicas, Mineralogicas, Caracteristicas e Propriedades Fisicas",
    "Chemical + CS7": "Quimicas, Mineralogicas, Caracteristicas e Propriedades Fisicas",
    "Chemical + CS1 + CS3": "Quimicas, Mineralogicas, Caracteristicas e Propriedades Fisicas",
    "Chemical + CS1 + CS7": "Quimicas, Mineralogicas, Caracteristicas e Propriedades Fisicas",
    "Chemical + CS3 + CS7": "Quimicas, Mineralogicas, Caracteristicas e Propriedades Fisicas",
    "Chemical + CS1 + CS3 + CS7": "Quimicas, Mineralogicas, Caracteristicas e Propriedades Fisicas",
    "Chemical + Mineralogical + Physical": "Quimicas, Mineralogicas, Caracteristicas e Propriedades Fisicas",
    "Chemical + Mineralogical + CS3": "Quimicas, Mineralogicas, Caracteristicas e Propriedades Fisicas",
    "Chemical + Mineralogical + CS7": "Quimicas, Mineralogicas, Caracteristicas e Propriedades Fisicas",
    "Chemical + Mineralogical + CS3 + CS7": "Quimicas, Mineralogicas, Caracteristicas e Propriedades Fisicas",
    # Grupo 3
    "Chemical + Properties CS Less": "Quimicas, Mineralogicas e Caracteristicas Fisicas",
    "Chemical + Mineralogical + Properties CS Less": "Quimicas, Mineralogicas e Caracteristicas Fisicas",
}

df_copy["Features"] = df_copy["Features"].replace(to_replace_groups)

# %%
to_replace_3 = {
    # Grupo 1
    "Linear Regression": "Regressao Linear",
    # Grupo 2
    "Decision Tree": "Arvores",
    "Random Forest": "Arvores",
    "XGBoost": "Arvores",
    # Grupo 3
    "Transformer": "Redes Neurais",
    "BidirectionalLSTM": "Redes Neurais",
    "BidirectionalGRU": "Redes Neurais",
    "LSTM": "Redes Neurais",
    "GRU": "Redes Neurais",
    "MLP": "Redes Neurais",
}

df_copy["Model"] = df_copy["Model"].replace(to_replace_3)

# %%
df_copy["Model"].unique()
# Out:
# array(['Redes Neurais', 'Arvores', 'Regressao Linear'], dtype=object)

# %%
# Group by specified columns and calculate metrics
grouped = df_copy.groupby(cols_group_cics)[cols_metrics]

# Calculate a score for each group based on metrics
df_copy["Score"] = df_copy[cols_metrics].apply(
    lambda x: x["RMSE Test", "mean"]
    + x["MAE Test", "mean"]
    + x["MAPE Test", "mean"]
    - x["R2 Test", "mean"],
    axis=1,
)

# Sort the DataFrame by score in descending order
df_sorted = df_copy.sort_values(by="Score", ascending=True)

# Group by specified columns and select the top row for each group
result = df_sorted.groupby(cols_group_cics).first().reset_index()

# Select only the columns of interest
# result = result[cols_group_cics + [col[0] for col in cols_metrics]]

# df_sorted.groupby(cols_group_cics)[cols_metrics].first().reset_index()
result = result[[(col, "") for col in cols_group_cics] + cols_metrics]
# Out:
# /tmp/ipykernel_1438886/1068109498.py:17: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   result = df_sorted.groupby(cols_group_cics).first().reset_index()

# %%
result = result.rename(
    {
        ("Model", ""): ("Modelos", ""),
        ("Company", ""): ("Empresa", ""),
        ("Plant", ""): ("Planta", ""),
        ("Features", ""): ("Conjunto de variaveis", ""),
        ("Cross Validation", ""): ("Validacao cruzada", ""),
    },
    axis=1,
)

# %%
result.to_excel("resultados_plantas.xlsx")

# %%
result.shape
# Out:
# (1368, 13)

# %%
result["R2 Test"]["mean"].describe()
# Out:
# count    1.368000e+03
# mean    -2.615885e+04
# std      3.979568e+05
# min     -8.211553e+06
# 25%      4.741201e-01
# 50%      7.681489e-01
# 75%      9.065815e-01
# max      9.853564e-01
# Name: mean, dtype: float64

# %% [markdown]
# # Linear Regression

# %%
df_linreg = df[df[("Model", "")] == "Linear Regression"][cols].copy()
# df_linreg = df_linreg.drop([("Model", "")], axis=1)
df_linreg = df_linreg[df_linreg["Cross Validation"] != "Out of time Split"]

# %%
df_linreg_chemical = df_linreg[df_linreg["Features"] == "Chemical"].drop(
    ["Cross Validation Params"], axis=1
)

df_linreg_chemical_group = (
    df_linreg_chemical.groupby(cols_group)[cols_metrics].min().sort_values(cols_metrics)
)
# Out:
# /tmp/ipykernel_1438886/836000293.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df_linreg_chemical = df_linreg[df_linreg["Features"] == "Chemical"].drop(

# %%
# df_linrefg_chemical_group.round(3)

# %%
df.reset_index()["Company"].unique()
# Out:
# array(['partner_i', 'partner_ii', 'partner_iv', 203, 204, 206, 207, 209],
#       dtype=object)

# %%
df.reset_index()["level_0"].unique().shape
# Out:
# (44,)

# %%
df_linreg_chemical_group = (
    df_linreg_chemical.groupby(cols_group)[cols_metrics].max().sort_values(cols_metrics)
)

# %%
# df_linreg_chemical_group

# %%
df_linreg_chemical_feature_engineering = df_linreg[
    df_linreg["Features"] == "Chemical + Feature Engineering"
].drop(["Cross Validation Params"], axis=1)

df_linreg_chemical_feature_engineering_group = (
    df_linreg_chemical_feature_engineering.groupby(cols_group)[cols_metrics]
    .min()
    .sort_values(cols_metrics)
)
# Out:
# /tmp/ipykernel_1438886/2942141213.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df_linreg_chemical_feature_engineering = df_linreg[df_linreg["Features"] == "Chemical + Feature Engineering"].drop(

# %%
df_linreg_chemical_feature_engineering_group.round(3)
# Out:
#                                                                                             RMSE Test  \
#                                                                                                  mean
# (Data Shape, ) (Model, )         (Features, )                   (Cross Validation, )
# (326, 11)      Linear Regression Chemical + Feature Engineering Repeated KFold                  1.050
# (484, 14)      Linear Regression Chemical + Feature Engineering Blocking Time Series Split      1.079
# (756, 11)      Linear Regression Chemical + Feature Engineering Repeated KFold                  1.123
# (484, 14)      Linear Regression Chemical + Feature Engineering Repeated KFold                  1.217
# (1495, 14)     Linear Regression Chemical + Feature Engineering Repeated KFold                  1.234
# ...                                                                                               ...
# ...

# %%
df_linrefg_chemical_properties_csless = df_linreg[
    df_linreg["Features"] == "Chemical + Properties CS Less"
].drop(["Cross Validation Params"], axis=1)

df_linrefg_chemical_properties_csless_group = (
    df_linrefg_chemical_properties_csless.groupby(cols_group)[cols_metrics]
    .min()
    .sort_values(cols_metrics)
)
# Out:
# /tmp/ipykernel_1438886/3513350848.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df_linrefg_chemical_properties_csless = df_linreg[

# %%
df_linrefg_chemical_properties_csless_group.round(3)
# Out:
#                                                                                           RMSE Test  \
#                                                                                                mean
# (Data Shape, ) (Model, )         (Features, )                  (Cross Validation, )
# (756, 14)      Linear Regression Chemical + Properties CS Less Repeated KFold                 1.106
# (484, 15)      Linear Regression Chemical + Properties CS Less Blocking Time Series Split     1.116
#                                                                Repeated KFold                 1.161
# (1495, 15)     Linear Regression Chemical + Properties CS Less Blocking Time Series Split     1.169
# (3345, 14)     Linear Regression Chemical + Properties CS Less Blocking Time Series Split     1.225
# ...                                                                                             ...
# ...

# %%
df_linrefg_chemical_physical = df_linreg[
    df_linreg["Features"] == "Chemical + Physical"
].drop(["Cross Validation Params"], axis=1)


df_linrefg_chemical_physical_group = (
    df_linrefg_chemical_physical.groupby(cols_group)[cols_metrics]
    .min()
    .sort_values(cols_metrics)
)
# Out:
# /tmp/ipykernel_1438886/3836724264.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df_linrefg_chemical_physical = df_linreg[

# %%
df_linrefg_chemical_physical_group.round(3)
# Out:
#                                                                                 RMSE Test  \
#                                                                                      mean
# (Data Shape, ) (Model, )         (Features, )        (Cross Validation, )
# (3345, 16)     Linear Regression Chemical + Physical Repeated KFold                 0.763
#                                                      Blocking Time Series Split     0.764
# (1495, 17)     Linear Regression Chemical + Physical Blocking Time Series Split     0.775
# (3345, 16)     Linear Regression Chemical + Physical Time Series Split              0.800
# (1011, 32)     Linear Regression Chemical + Physical Repeated KFold                 0.836
# ...                                                                                   ...
# (4687, 13)     Linear Regression Chemical + Physical Time Series Split              9.424
# (966, 19)      Linear Regression Chemical + Physical Repeated KFold                 9.431
# ...

# %% [markdown]
# # Neural Networks

# %%
neural_networks = [
    "MLP",
    "LSTM",
    "GRU",
    "BidirectionalGRU",
    "BidirectionalLSTM",
    "Transformer",
]
timesteps_col = ("Timesteps", "")

df_nn = df[df[("Model", "")].isin(neural_networks)][[timesteps_col] + cols].copy()
# df_nn = df_nn.drop([("Model", "")], axis=1)
df_nn = df_nn[df_nn["Cross Validation"] != "Out of time Split"]

# %%
df_nn_chemical = df_nn[df_nn["Features"] == "Chemical"].drop(
    ["Cross Validation Params"], axis=1
)

df_nn_chemical_group = (
    df_nn_chemical.groupby(cols_group + [timesteps_col], dropna=False)[cols_metrics]
    .min()
    .sort_values(cols_metrics)
)
# Out:
# /tmp/ipykernel_1438886/477741271.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df_nn_chemical = df_nn[df_nn["Features"] == "Chemical"].drop(

# %%
pd.set_option("display.max_rows", 30)  # Show all rows
pd.set_option("display.max_columns", 20)  # Show all columns

# %%
df_nn_chemical_group.tail(10).round(3)
# Out:
#                                                                                        RMSE Test  \
#                                                                                             mean
# (Data Shape, ) (Model, )         (Features, ) (Cross Validation, )       (Timesteps, )
# (966, 14)      BidirectionalGRU  Chemical     Time Series Split          14.0            350.851
#                GRU               Chemical     Blocking Time Series Split 1.0             393.869
#                LSTM              Chemical     Blocking Time Series Split 14.0            489.255
#                MLP               Chemical     Blocking Time Series Split NaN             572.403
#                BidirectionalGRU  Chemical     Blocking Time Series Split 7.0             770.290
#                BidirectionalLSTM Chemical     Time Series Split          14.0            796.878
#                GRU               Chemical     Blocking Time Series Split 7.0            1053.609
# ...

# %%
df_nn_chemical_feature_engineering = df_nn[
    df_nn["Features"] == "Chemical + Feature Engineering"
].drop(["Cross Validation Params"], axis=1)

df_nn_chemical_feature_engineering_group = (
    df_nn_chemical_feature_engineering.groupby(
        cols_group + [timesteps_col], dropna=False
    )[cols_metrics]
    .min()
    .sort_values(cols_metrics)
)
# Out:
# /tmp/ipykernel_1438886/1612923322.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df_nn_chemical_feature_engineering = df_nn[

# %%
df_nn_chemical_feature_engineering_group.tail(30).round(3)
# Out:
#                                                                                                          RMSE Test  \
#                                                                                                               mean
# (Data Shape, ) (Model, )         (Features, )                   (Cross Validation, )       (Timesteps, )
# (966, 15)      BidirectionalLSTM Chemical + Feature Engineering Repeated KFold             14.0            105.987
#                                                                 Time Series Split          7.0             110.332
#                                                                                            1.0             119.966
# (756, 11)      BidirectionalLSTM Chemical + Feature Engineering Blocking Time Series Split 7.0             125.893
# (966, 15)      LSTM              Chemical + Feature Engineering Blocking Time Series Split 1.0             144.341
# ...

# %%
df_nn_chemical_properties_cs_less = df_nn[
    df_nn["Features"] == "Chemical + Properties CS Less"
].drop(["Cross Validation Params"], axis=1)

df_nn_chemical_properties_cs_less_group = (
    df_nn_chemical_properties_cs_less.groupby(
        cols_group + [timesteps_col], dropna=False
    )[cols_metrics]
    .min()
    .sort_values(cols_metrics)
)
# Out:
# /tmp/ipykernel_1438886/2043271738.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df_nn_chemical_properties_cs_less = df_nn[

# %%
df_nn_chemical_properties_cs_less_group.tail(30).round(3)
# Out:
#                                                                                                         RMSE Test  \
#                                                                                                              mean
# (Data Shape, ) (Model, )         (Features, )                  (Cross Validation, )       (Timesteps, )
# (1552, 13)     BidirectionalLSTM Chemical + Properties CS Less Time Series Split          7.0             210.293
#                GRU               Chemical + Properties CS Less Repeated KFold             7.0             223.599
# (966, 17)      BidirectionalGRU  Chemical + Properties CS Less Time Series Split          14.0            265.341
# (1552, 13)     LSTM              Chemical + Properties CS Less Repeated KFold             7.0             265.747
# (966, 17)      LSTM              Chemical + Properties CS Less Blocking Time Series Split 1.0             267.575
# ...

# %%
filtered_df = df_nn_chemical_properties_cs_less_group[
    df_nn_chemical_properties_cs_less_group.index.get_level_values(("Model", ""))
    == "Transformer"
]

filtered_df.tail(15).round(3)
# Out:
#                                                                                                   RMSE Test  \
#                                                                                                        mean
# (Data Shape, ) (Model, )   (Features, )                  (Cross Validation, )       (Timesteps, )
# (966, 17)      Transformer Chemical + Properties CS Less Blocking Time Series Split 14.0              4.116
# (1552, 13)     Transformer Chemical + Properties CS Less Blocking Time Series Split 7.0               4.180
# (1242, 24)     Transformer Chemical + Properties CS Less Time Series Split          14.0              4.182
# (1081, 15)     Transformer Chemical + Properties CS Less Blocking Time Series Split 14.0              4.273
# (860, 13)      Transformer Chemical + Properties CS Less Time Series Split          14.0              4.382
# (6148, 10)     Transformer Chemical + Properties CS Less Time Series Split          14.0              4.404
# ...

# %%
filtered_df = df_nn_chemical_properties_cs_less_group[
    df_nn_chemical_properties_cs_less_group.index.get_level_values(("Model", ""))
    == "LSTM"
]

filtered_df.tail(15).round(3)
# Out:
#                                                                                                 RMSE Test  \
#                                                                                                      mean
# (Data Shape, ) (Model, ) (Features, )                  (Cross Validation, )       (Timesteps, )
# (1552, 13)     LSTM      Chemical + Properties CS Less Time Series Split          1.0              96.148
# (756, 14)      LSTM      Chemical + Properties CS Less Blocking Time Series Split 7.0              97.336
# (4687, 11)     LSTM      Chemical + Properties CS Less Time Series Split          14.0            101.156
#                                                        Repeated KFold             14.0            105.199
# (966, 17)      LSTM      Chemical + Properties CS Less Blocking Time Series Split 7.0             123.865
# (4687, 11)     LSTM      Chemical + Properties CS Less Time Series Split          1.0             154.022
# ...

# %%
filtered_df = df_nn_chemical_properties_cs_less_group[
    df_nn_chemical_properties_cs_less_group.index.get_level_values(("Model", ""))
    == "MLP"
]

filtered_df.tail(15).round(3)
# Out:
#                                                                                                 RMSE Test  \
#                                                                                                      mean
# (Data Shape, ) (Model, ) (Features, )                  (Cross Validation, )       (Timesteps, )
# (1242, 24)     MLP       Chemical + Properties CS Less Repeated KFold             NaN              21.279
# (294, 16)      MLP       Chemical + Properties CS Less Blocking Time Series Split NaN              21.960
# (1081, 15)     MLP       Chemical + Properties CS Less Blocking Time Series Split NaN              30.085
# (756, 14)      MLP       Chemical + Properties CS Less Blocking Time Series Split NaN              45.055
# (326, 15)      MLP       Chemical + Properties CS Less Time Series Split          NaN              54.583
# (1081, 15)     MLP       Chemical + Properties CS Less Time Series Split          NaN              57.962
# ...

# %%
df_nn_chemical_physical = df_nn[df_nn["Features"] == "Chemical + Physical"].drop(
    ["Cross Validation Params"], axis=1
)

df_nn_chemical_physical_group = (
    df_nn_chemical_physical.groupby(cols_group + [timesteps_col], dropna=False)[
        cols_metrics
    ]
    .min()
    .sort_values(cols_metrics)
)
# Out:
# /tmp/ipykernel_1438886/3021709723.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df_nn_chemical_physical = df_nn[df_nn["Features"] == "Chemical + Physical"].drop(

# %%
df_nn_chemical_physical_group.tail(15).round(3)
# Out:
#                                                                                               RMSE Test  \
#                                                                                                    mean
# (Data Shape, ) (Model, )         (Features, )        (Cross Validation, )       (Timesteps, )
# (1552, 15)     BidirectionalLSTM Chemical + Physical Repeated KFold             14.0            420.163
# (966, 19)      GRU               Chemical + Physical Blocking Time Series Split 1.0             423.113
# (1552, 15)     GRU               Chemical + Physical Repeated KFold             14.0            426.268
# (966, 19)      BidirectionalGRU  Chemical + Physical Blocking Time Series Split 1.0             437.649
# (1552, 15)     LSTM              Chemical + Physical Time Series Split          7.0             454.864
# (966, 19)      GRU               Chemical + Physical Blocking Time Series Split 14.0            455.266
# ...

# %% [markdown]
# # Trees

# %%
trees = ["Decision Tree", "Random Forest", "XGBoost"]

df_trees = df[df[("Model", "")].isin(trees)][cols].copy()
df_trees = df_trees[df_trees["Cross Validation"] != "Out of time Split"]

# %%
df_trees_chemical = df_trees[df_trees["Features"] == "Chemical"].drop(
    ["Cross Validation Params"], axis=1
)

df_trees_chemical_group = (
    df_trees_chemical.groupby(cols_group)[cols_metrics].min().sort_values(cols_metrics)
)
# Out:
# /tmp/ipykernel_1438886/3122962484.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df_trees_chemical = df_trees[df_trees["Features"] == "Chemical"].drop(

# %%
df_trees_chemical_group.tail(15).round(3)
# Out:
#                                                                      RMSE Test  \
#                                                                           mean
# (Data Shape, ) (Model, )     (Features, ) (Cross Validation, )
# (1510, 10)     Decision Tree Chemical     Time Series Split              4.112
# (1757, 9)      XGBoost       Chemical     Time Series Split              4.223
# (6148, 5)      Random Forest Chemical     Blocking Time Series Split     4.236
# (1757, 9)      Random Forest Chemical     Time Series Split              4.261
# (6148, 5)      XGBoost       Chemical     Blocking Time Series Split     4.274
#                Random Forest Chemical     Time Series Split              4.277
# (898, 9)       Decision Tree Chemical     Repeated KFold                 4.349
# (1757, 9)      Decision Tree Chemical     Time Series Split              4.363
# (898, 9)       Decision Tree Chemical     Time Series Split              4.429
# ...

# %%
df_trees_chemical_properties_cs_less = df_trees[
    df_trees["Features"] == "Chemical + Properties CS Less"
].drop(["Cross Validation Params"], axis=1)

df_trees_chemical_properties_cs_less_group = (
    df_trees_chemical_properties_cs_less.groupby(cols_group)[cols_metrics]
    .min()
    .sort_values(cols_metrics)
)
# Out:
# /tmp/ipykernel_1438886/987045803.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df_trees_chemical_properties_cs_less = df_trees[

# %%
df_trees_chemical_properties_cs_less_group.tail(15).round(3)
# Out:
#                                                                                       RMSE Test  \
#                                                                                            mean
# (Data Shape, ) (Model, )     (Features, )                  (Cross Validation, )
# (1510, 15)     Random Forest Chemical + Properties CS Less Time Series Split              3.739
# (6148, 10)     XGBoost       Chemical + Properties CS Less Blocking Time Series Split     3.744
# (2199, 15)     Random Forest Chemical + Properties CS Less Time Series Split              3.755
# (1098, 15)     Decision Tree Chemical + Properties CS Less Time Series Split              3.770
# (1757, 13)     Decision Tree Chemical + Properties CS Less Time Series Split              3.815
# (1510, 15)     XGBoost       Chemical + Properties CS Less Time Series Split              3.832
# (4687, 11)     Decision Tree Chemical + Properties CS Less Time Series Split              3.944
# ...

# %%
df_trees_chemical_physical = df_trees[
    df_trees["Features"] == "Chemical + Physical"
].drop(["Cross Validation Params"], axis=1)

df_trees_chemical_physical_group = (
    df_trees_chemical_physical.groupby(cols_group)[cols_metrics]
    .min()
    .sort_values(cols_metrics)
)
# Out:
# /tmp/ipykernel_1438886/3974295488.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df_trees_chemical_physical = df_trees[

# %%
df_trees_chemical_physical_group.tail(15).round(3)
# Out:
#                                                                             RMSE Test  \
#                                                                                  mean
# (Data Shape, ) (Model, )     (Features, )        (Cross Validation, )
# (484, 17)      Decision Tree Chemical + Physical Time Series Split              2.747
# (2199, 18)     XGBoost       Chemical + Physical Time Series Split              2.750
# (6148, 13)     XGBoost       Chemical + Physical Time Series Split              2.823
# (1510, 18)     XGBoost       Chemical + Physical Blocking Time Series Split     2.859
# (2199, 18)     Random Forest Chemical + Physical Time Series Split              2.918
# (593, 17)      XGBoost       Chemical + Physical Time Series Split              2.922
#                Decision Tree Chemical + Physical Blocking Time Series Split     2.942
# (898, 17)      XGBoost       Chemical + Physical Time Series Split              2.976
# ...
